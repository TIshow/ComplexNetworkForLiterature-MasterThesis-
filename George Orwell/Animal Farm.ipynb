# %%
# https://biblio.wiki/wiki/Animal_Farm

import nltk
from nltk.corpus import stopwords
import math
# %matplotlib inline

raw1 = open('Animal_Farm.txt').read()

# %%
tokens1 = nltk.word_tokenize(raw1)
sentence1 = nltk.sent_tokenize(raw1)

#The number of token
len(tokens1)
# Out:
# 34139

# %%
len(sentence1)
# Out:
# 1621

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer() #to make base form

tokens_low = [w.lower() for w in tokens1]

#The number of sort of words
len(set(tokens_low))

#複数形や過去形を別の単語としてカウントしてしまっているため，実際の異なり語数はさらに少ない
# Out:
# 3992

# %%
print (len(set(tokens_low))/len(tokens1))
# Out:
# 0.11693371217668942

# %%
list1 = [tokens1]

text = []
for i in list1:
    text.append(nltk.Text(i))
    
freq_list = []
for i in text:
    freq_list.append(nltk.FreqDist(w.lower() for w in i))

stopwords = nltk.corpus.stopwords.words('english')
symbols = ["'", '"', '`', '.', ',', '-', '!', '?', ':', ';', '(', ')', '...', "'s", '’', '”', '“','–','—', '…', '*' ,'``', "''",'--','mr.',"n't", 'dr.','sir', '‘', 'mr', 'm.' ]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#順位チェック
sorted(freq_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('animals', 245),
#  ('napoleon', 168),
#  ('farm', 164),
#  ('would', 138),
#  ('snowball', 131),
#  ('animal', 107),
#  ('boxer', 96),
#  ('pigs', 92),
#  ('said', 92),
#  ('jones', 82),
#  ('one', 77),
#  ('could', 76),
#  ('time', 74),
#  ('work', 72),
#  ('windmill', 71),
#  ('two', 69),
#  ('squealer', 67),
#  ('every', 58),
#  ('even', 56),
#  ('comrades', 54),
#  ('back', 53),
#  ('round', 52),
#  ('never', 51),
#  ('came', 50),
#  ('day', 49),
#  ('dogs', 48),
#  ('clover', 47),
#  ('moment', 41),
#  ('human', 41),
#  ('legs', 41),
#  ('comrade', 41),
#  ('made', 40),
#  ('old', 40),
#  ('long', 40),
#  ('days', 38),
#  ('first', 37),
#  ('ever', 37),
#  ('side', 36),
#  ('men', 36),
#  ('come', 35),
#  ('upon', 35),
#  ('four', 35),
#  ('sheep', 34),
#  ('farmhouse', 34),
#  ('frederick', 34),
#  ('way', 33),
#  ('three', 32),
#  ('good', 32),
#  ('benjamin', 31),
#  ('seemed', 31),
#  ('went', 29),
#  ('though', 29),
#  ('little', 29),
#  ('always', 28),
#  ('end', 28),
#  ('england', 28),
#  ('rebellion', 28),
#  ('another', 28),
#  ('pilkington', 28),
#  ('last', 27),
#  ('great', 27),
#  ('much', 26),
#  ('must', 26),
#  ('others', 26),
#  ('make', 25),
#  ('without', 25),
#  ('later', 25),
#  ('shall', 25),
#  ('away', 25),
#  ('night', 24),
#  ('yard', 24),
#  ('barn', 24),
#  ('still', 24),
#  ('nothing', 24),
#  ('well', 24),
#  ('almost', 24),
#  ('better', 24),
#  ('also', 24),
#  ('found', 24),
#  ('hens', 23),
#  ('saw', 23),
#  ('year', 23),
#  ('beings', 23),
#  ('set', 23),
#  ('say', 22),
#  ('pig', 22),
#  ('life', 22),
#  ('took', 22),
#  ('except', 22),
#  ('many', 22),
#  ('man', 22),
#  ('might', 22),
#  ('seen', 22),
#  ('began', 21),
#  ('battle', 21),
#  ('appeared', 21),
#  ('soon', 20),
#  ('put', 20),
#  ('mollie', 20),
#  ('thought', 20),
#  ('us', 20),
#  ('week', 20),
#  ('suddenly', 20),
#  ('hard', 20),
#  ('called', 19),
#  ('horses', 19),
#  ('given', 19),
#  ('food', 19),
#  ('whole', 19),
#  ('get', 19),
#  ('eyes', 19),
#  ('sunday', 19),
#  ('morning', 19),
#  ('like', 19),
#  ('read', 19),
#  ('already', 18),
#  ('major', 18),
#  ('cows', 18),
#  ('lay', 18),
#  ('together', 18),
#  ('heard', 18),
#  ('labour', 18),
#  ('enough', 18),
#  ('done', 18),
#  ('words', 18),
#  ('death', 18),
#  ('seven', 18),
#  ('go', 18),
#  ('summer', 18),
#  ('cried', 18),
#  ('gun', 18),
#  ('buildings', 17),
#  ('years', 17),
#  ('see', 17),
#  ('used', 17),
#  ('hay', 17),
#  ('right', 17),
#  ('worked', 17),
#  ('announced', 17),
#  ('white', 16),
#  ('among', 16),
#  ('place', 16),
#  ('happened', 16),
#  ('young', 16),
#  ('live', 16),
#  ('certain', 16),
#  ("'beasts", 16),
#  ('past', 16),
#  ('hoof', 16),
#  ('commandments', 16),
#  ('half', 16),
#  ('stone', 16),
#  ('whymper', 16),
#  ('van', 16),
#  ('gone', 15),
#  ('tail', 15),
#  ('looked', 15),
#  ('yet', 15),
#  ('know', 15),
#  ('taken', 15),
#  ('however', 15),
#  ('sent', 15),
#  ('able', 15),
#  ('foxwood', 15),
#  ('terrible', 15),
#  ('stood', 15),
#  ('remember', 14),
#  ('big', 14),
#  ('straw', 14),
#  ('fact', 14),
#  ('immediately', 14),
#  ('pigeons', 14),
#  ('muriel', 14),
#  ('something', 14),
#  ('fields', 14),
#  ('since', 14),
#  ('voice', 14),
#  ('late', 14),
#  ('coming', 14),
#  ('turned', 14),
#  ('full', 14),
#  ('harvest', 14),
#  ('forward', 14),
#  ('bad', 14),
#  ('orders', 14),
#  ('small', 13),
#  ('got', 13),
#  ('usual', 13),
#  ('face', 13),
#  ('eggs', 13),
#  ('feet', 13),
#  ('kind', 13),
#  ('take', 13),
#  ('need', 13),
#  ('anything', 13),
#  ('corn', 13),
#  ('things', 13),
#  ('outside', 13),
#  ('sometimes', 13),
#  ('necessary', 13),
#  ('cowshed', 13),
#  ('remembered', 13),
#  ('bed', 12),
#  ('willingdon', 12),
#  ('hour', 12),
#  ('gave', 12),
#  ('tremendous', 12),
#  ('beyond', 12),
#  ('finally', 12),
#  ('give', 12),
#  ('milk', 12),
#  ('rest', 12),
#  ('large', 12),
#  ('passed', 12),
#  ('black', 12),
#  ('evening', 12),
#  ('five', 12),
#  ('carried', 12),
#  ('believe', 12),
#  ('written', 12),
#  ('noticed', 12),
#  ('far', 12),
#  ('ground', 12),
#  ('flag', 12),
#  ('green', 12),
#  ('plans', 12),
#  ('word', 11),
#  ('name', 11),
#  ('sleep', 11),
#  ('asked', 11),
#  ('orchard', 11),
#  ('wall', 11),
#  ('speech', 11),
#  ('think', 11),
#  ('stall', 11),
#  ('let', 11),
#  ('part', 11),
#  ('enemy', 11),
#  ('rations', 11),
#  ('point', 11),
#  ('whatever', 11),
#  ('knew', 11),
#  ('known', 11),
#  ('mind', 11),
#  ('died', 11),
#  ('early', 11),
#  ('next', 11),
#  ('whether', 11),
#  ('harder', 11),
#  ('led', 11),
#  ('news', 11),
#  ('thing', 11),
#  ('pasture', 11),
#  ('field', 11),
#  ('pinchfield', 11),
#  ('felt', 11),
#  ('door', 10),
#  ('quite', 10),
#  ('behind', 10),
#  ('hoofs', 10),
#  ('moses', 10),
#  ('lives', 10),
#  ('short', 10),
#  ('times', 10),
#  ('run', 10),
#  ('money', 10),
#  ('meeting', 10),
#  ('discovered', 10),
#  ('sing', 10),
#  ('tune', 10),
#  ('beasts', 10),
#  ('several', 10),
#  ('anyone', 10),
#  ('broke', 10),
#  ('minutes', 10),
#  ('broken', 10),
#  ('going', 10),
#  ('dog', 10),
#  ('agreement', 10),
#  ('hours', 10),
#  ('case', 10),
#  ('finished', 10),
#  ('none', 10),
#  ('farms', 10),
#  ('attack', 10),
#  ('winter', 10),
#  ('timber', 10),
#  ('light', 9),
#  ('dream', 9),
#  ('everyone', 9),
#  ('spite', 9),
#  ('slowly', 9),
#  ('nearly', 9),
#  ('speaking', 9),
#  ('sugar', 9),
#  ('understand', 9),
#  ('sitting', 9),
#  ('spring', 9),
#  ('surely', 9),
#  ('silence', 9),
#  ('vote', 9),
#  ('song', 9),
#  ('held', 9),
#  ('dead', 9),
#  ('difficulty', 9),
#  ('believed', 9),
#  ('everything', 9),
#  ('singing', 9),
#  ('earlier', 9),
#  ('flung', 9),
#  ('rushed', 9),
#  ('air', 9),
#  ('honour', 9),
#  ('less', 9),
#  ('mornings', 9),
#  ('class', 9),
#  ('nine', 9),
#  ('intended', 9),
#  ('pile', 9),
#  ('following', 9),
#  ('cry', 9),
#  ('leader', 9),
#  ('commandment', 9),
#  ('manor', 8),
#  ('strange', 8),
#  ('raised', 8),
#  ('front', 8),
#  ('lost', 8),
#  ('throughout', 8),
#  ('longer', 8),
#  ('single', 8),
#  ('tell', 8),
#  ('sight', 8),
#  ('creatures', 8),
#  ('drink', 8),
#  ('equal', 8),
#  ('secret', 8),
#  ('new', 8),
#  ('reason', 8),
#  ('animalism', 8),
#  ('meetings', 8),
#  ('making', 8),
#  ('hedges', 8),
#  ('told', 8),
#  ('reading', 8),
#  ('world', 8),
#  ('frightened', 8),
#  ('window', 8),
#  ('yes', 8),
#  ('beds', 8),
#  ('learn', 8),
#  ('use', 8),
#  ('actually', 8),
#  ('either', 8),
#  ('garden', 8),
#  ('aside', 8),
#  ('often', 8),
#  ('bleating', 8),
#  ('victory', 8),
#  ('stalls', 8),
#  ('walls', 8),
#  ('building', 8),
#  ('expulsion', 8),
#  ('quarry', 8),
#  ('ordered', 8),
#  ('across', 7),
#  ('agreed', 7),
#  ('order', 7),
#  ('different', 7),
#  ('nose', 7),
#  ('usually', 7),
#  ('keep', 7),
#  ('nevertheless', 7),
#  ('ribbons', 7),
#  ('cat', 7),
#  ('saying', 7),
#  ('free', 7),
#  ('number', 7),
#  ('hundred', 7),
#  ('body', 7),
#  ('future', 7),
#  ('rats', 7),
#  ('trotter', 7),
#  ('afterwards', 7),
#  ('merely', 7),
#  ('towards', 7),
#  ('house', 7),
#  ('ran', 7),
#  ('barley', 7),
#  ('geese', 7),
#  ('spread', 7),
#  ('foot', 7),
#  ('named', 7),
#  ('beginning', 7),
#  ('questions', 7),
#  ('sound', 7),
#  ('ended', 7),
#  ('drinking', 7),
#  ('stand', 7),
#  ('road', 7),
#  ('gate', 7),
#  ('running', 7),
#  ('top', 7),
#  ('six', 7),
#  ('writing', 7),
#  ('letters', 7),
#  ('heart', 7),
#  ('happy', 7),
#  ('possible', 7),
#  ('nobody', 7),
#  ('true', 7),
#  ('kept', 7),
#  ('indeed', 7),
#  ('decided', 7),
#  ('twice', 7),
#  ('declared', 7),
#  ('apples', 7),
#  ('everywhere', 7),
#  ('hedge', 7),
#  ('hero', 7),
#  ('speeches', 7),
#  ('especially', 7),
#  ('built', 7),
#  ('cold', 7),
#  ('working', 7),
#  ('special', 7),
#  ('left', 7),
#  ('horse', 7),
#  ('beer', 6),
#  ('twelve', 6),
#  ('walking', 6),
#  ('care', 6),
#  ('hands', 6),
#  ('somewhat', 6),
#  ('talked', 6),
#  ('flies', 6),
#  ('alone', 6),
#  ('find', 6),
#  ('else', 6),
#  ('earth', 6),
#  ('living', 6),
#  ('speak', 6),
#  ('strength', 6),
#  ('simply', 6),
#  ('dozen', 6),
#  ('cruel', 6),
#  ('within', 6),
#  ('become', 6),
#  ('lies', 6),
#  ('crept', 6),
#  ('continued', 6),
#  ('forgotten', 6),
#  ('break', 6),
#  ('somehow', 6),
#  ('happen', 6),
#  ('contrary', 6),
#  ('besides', 6),
#  ('sugarcandy', 6),
#  ('mountain', 6),
#  ('accepted', 6),
#  ('kitchen', 6),
#  ('store-shed', 6),
#  ('horn', 6),
#  ('hungry', 6),
#  ('main', 6),
#  ('happening', 6),
#  ('act', 6),
#  ('hiding', 6),
#  ('harness-room', 6),
#  ('fire', 6),
#  ('ears', 6),
#  ('knoll', 6),
#  ('grass', 6),
#  ('pool', 6),
#  ('remained', 6),
#  ('piece', 6),
#  ('spot', 6),
#  ('begin', 6),
#  ('matter', 6),
#  ('attended', 6),
#  ('painted', 6),
#  ('onwards', 6),
#  ('disappeared', 6),
#  ('hind', 6),
#  ('inch', 6),
#  ('needed', 6),
#  ('fro', 6),
#  ('produced', 6),
#  ('various', 6),
#  ('refused', 6),
#  ('pieces', 6),
#  ('unable', 6),
#  ('reduced', 6),
#  ('hand', 6),
#  ('neighbouring', 6),
#  ('farmers', 6),
#  ('rumours', 6),
#  ('head', 6),
#  ('lying', 6),
#  ('pellets', 6),
#  ('wearing', 6),
#  ('blood', 6),
#  ('became', 6),
#  ('weather', 6),
#  ('moments', 6),
#  ('floor', 6),
#  ('least', 6),
#  ('corner', 6),
#  ('build', 6),
#  ('completed', 6),
#  ('effort', 6),
#  ('cockerel', 6),
#  ('terror', 6),
#  ('rebuilding', 6),
#  ('confessed', 6),
#  ('perhaps', 6),
#  ('table', 6),
#  ('company', 6),
#  ('kicked', 5),
#  ('mrs.', 5),
#  ('middle', 5),
#  ('boar', 5),
#  ('hear', 5),
#  ('grown', 5),
#  ('appearance', 5),
#  ('comfortable', 5),
#  ('enormous', 5),
#  ('instance', 5),
#  ('spent', 5),
#  ('sundays', 5),
#  ('inside', 5),
#  ('fell', 5),
#  ('near', 5),
#  ('red', 5),
#  ('present', 5),
#  ('slept', 5),
#  ('duty', 5),
#  ('miserable', 5),
#  ('support', 5),
#  ('dignity', 5),
#  ('real', 5),
#  ('abolished', 5),
#  ('creature', 5),
#  ('weak', 5),
#  ('bare', 5),
#  ('enemies', 5),
#  ('laid', 5),
#  ('bring', 5),
#  ('age', 5),
#  ('allowed', 5),
#  ('clear', 5),
#  ('resolution', 5),
#  ('listen', 5),
#  ('saved', 5),
#  ('question', 5),
#  ('sides', 5),
#  ('friend', 5),
#  ('alcohol', 5),
#  ('whips', 5),
#  ('completely', 5),
#  ('thinking', 5),
#  ('clearly', 5),
#  ('getting', 5),
#  ('difficult', 5),
#  ('skipping', 5),
#  ('whisking', 5),
#  ('spirit', 5),
#  ('means', 5),
#  ('distance', 5),
#  ('grew', 5),
#  ('expected', 5),
#  ('fallen', 5),
#  ('trying', 5),
#  ('flight', 5),
#  ('sprang', 5),
#  ('meanwhile', 5),
#  ('five-barred', 5),
#  ('hardly', 5),
#  ('gallop', 5),
#  ('sure', 5),
#  ('raced', 5),
#  ('tails', 5),
#  ('destroyed', 5),
#  ('snuffed', 5),
#  ('today', 5),
#  ('explained', 5),
#  ('form', 5),
#  ('yards', 5),
#  ('wrong', 5),
#  ('loud', 5),
#  ('business', 5),
#  ('leadership', 5),
#  ('course', 5),
#  ('ducks', 5),
#  ('arrangement', 5),
#  ('problem', 5),
#  ('according', 5),
#  ('excellent', 5),
#  ('impossible', 5),
#  ('extra', 5),
#  ('general', 5),
#  ('resolutions', 5),
#  ('debates', 5),
#  ('afternoon', 5),
#  ('evenings', 5),
#  ('brought', 5),
#  ('committee', 5),
#  ('learned', 5),
#  ('proved', 5),
#  ('leg', 5),
#  ('tired', 5),
#  ('taking', 5),
#  ('crop', 5),
#  ('secretly', 5),
#  ('talk', 5),
#  ('sticks', 5),
#  ('ahead', 5),
#  ('line', 5),
#  ('fired', 5),
#  ('dropped', 5),
#  ('skull', 5),
#  ('tried', 5),
#  ('tears', 5),
#  ('killed', 5),
#  ('water', 5),
#  ('look', 5),
#  ('warm', 5),
#  ('machinery', 5),
#  ('uttering', 5),
#  ('walked', 5),
#  ('sat', 5),
#  ('racing', 5),
#  ('previously', 5),
#  ('protested', 5),
#  ('deep', 5),
#  ("o'clock", 5),
#  ('nowadays', 5),
#  ('warned', 5),
#  ('prepared', 5),
#  ('dragged', 5),
#  ('voices', 5),
#  ('relations', 5),
#  ('moved', 5),
#  ('sheets', 5),
#  ('followed', 5),
#  ('thick', 5),
#  ('figures', 5),
#  ('faces', 5),
#  ('bought', 5),
#  ('toast', 5),
#  ('drew', 4),
#  ('glass', 4),
#  ('meet', 4),
#  ('regarded', 4),
#  ('ready', 4),
#  ('platform', 4),
#  ('stout', 4),
#  ('bluebell', 4),
#  ('jessie', 4),
#  ('settled', 4),
#  ('mare', 4),
#  ('strong', 4),
#  ('stupid', 4),
#  ('remark', 4),
#  ('sooner', 4),
#  ('ducklings', 4),
#  ('promptly', 4),
#  ('foolish', 4),
#  ('lump', 4),
#  ('tame', 4),
#  ('raven', 4),
#  ('perch', 4),
#  ('waiting', 4),
#  ('cleared', 4),
#  ('throat', 4),
#  ('months', 4),
#  ('feel', 4),
#  ('nature', 4),
#  ('breath', 4),
#  ('forced', 4),
#  ('instant', 4),
#  ('truth', 4),
#  ('land', 4),
#  ('soil', 4),
#  ('greater', 4),
#  ('twenty', 4),
#  ('answer', 4),
#  ('sold', 4),
#  ('lead', 4),
#  ('ones', 4),
#  ('muscles', 4),
#  ('sell', 4),
#  ('knacker', 4),
#  ('race', 4),
#  ('prosperity', 4),
#  ('goes', 4),
#  ('wear', 4),
#  ('clothes', 4),
#  ('trade', 4),
#  ('clever', 4),
#  ('simple', 4),
#  ('kill', 4),
#  ('sung', 4),
#  ('wheat', 4),
#  ('oats', 4),
#  ('buried', 4),
#  ('march', 4),
#  ('best', 4),
#  ('fat', 4),
#  ('shrill', 4),
#  ('turn', 4),
#  ('principles', 4),
#  ('met', 4),
#  ('master', 4),
#  ('want', 4),
#  ('worth', 4),
#  ('somewhere', 4),
#  ('season', 4),
#  ('hated', 4),
#  ('easily', 4),
#  ('occasionally', 4),
#  ('milked', 4),
#  ('drawing-room', 4),
#  ('help', 4),
#  ('accord', 4),
#  ('triumph', 4),
#  ('slipped', 4),
#  ('successfully', 4),
#  ('open', 4),
#  ('rubbish', 4),
#  ('wore', 4),
#  ('ration', 4),
#  ('biscuits', 4),
#  ('gazed', 4),
#  ('excitement', 4),
#  ('admiration', 4),
#  ('hayfield', 4),
#  ('halted', 4),
#  ('shoulders', 4),
#  ('entered', 4),
#  ('gazing', 4),
#  ('holding', 4),
#  ('breakfast', 4),
#  ('ladder', 4),
#  ('caused', 4),
#  ('inscribed', 4),
#  ('task', 4),
#  ('someone', 4),
#  ('mash', 4),
#  ('follow', 4),
#  ('toiled', 4),
#  ('bigger', 4),
#  ('standing', 4),
#  ('understood', 4),
#  ('regular', 4),
#  ('observed', 4),
#  ('hoisting', 4),
#  ('flagstaff', 4),
#  ('object', 4),
#  ('retiring', 4),
#  ('production', 4),
#  ('autumn', 4),
#  ('walk', 4),
#  ('effect', 4),
#  ('maxim', 4),
#  ('forth', 4),
#  ('imagine', 4),
#  ('whose', 4),
#  ('fighting', 4),
#  ('rapidly', 4),
#  ('stories', 4),
#  ('fully', 4),
#  ('managed', 4),
#  ('speed', 4),
#  ('rage', 4),
#  ('hearing', 4),
#  ('second', 4),
#  ('signal', 4),
#  ('fled', 4),
#  ('straight', 4),
#  ('stir', 4),
#  ('iron', 4),
#  ('somebody', 4),
#  ('solemn', 4),
#  ('really', 4),
#  ('weeks', 4),
#  ('decisions', 4),
#  ('violent', 4),
#  ('successful', 4),
#  ('close', 4),
#  ('quietly', 4),
#  ('electric', 4),
#  ('shed', 4),
#  ('detail', 4),
#  ('defeated', 4),
#  ('spoken', 4),
#  ('uttered', 4),
#  ('utter', 4),
#  ('hole', 4),
#  ('terrified', 4),
#  ('privately', 4),
#  ('huge', 4),
#  ('receive', 4),
#  ('thoughts', 4),
#  ('sacrifice', 4),
#  ('heavy', 4),
#  ('stop', 4),
#  ('feeling', 4),
#  ('songs', 4),
#  ('reality', 4),
#  ('meant', 4),
#  ('spoke', 4),
#  ('hold', 4),
#  ('boulder', 4),
#  ('arrangements', 4),
#  ('simultaneously', 4),
#  ('mill', 4),
#  ('foundations', 4),
#  ('pronounced', 4),
#  ('direction', 4),
#  ('covered', 4),
#  ('grain', 4),
#  ('stopped', 4),
#  ('smell', 4),
#  ('teeth', 4),
#  ('worse', 4),
#  ('wounded', 4),
#  ('added', 4),
#  ('surprise', 4),
#  ('paper', 4),
#  ('deadly', 4),
#  ('paid', 4),
#  ('glances', 4),
#  ('returned', 4),
#  ('shouted', 4),
#  ('seem', 4),
#  ('rumour', 4),
#  ('gentlemen', 4),
#  ('shut', 3),
#  ('lantern', 3),
#  ('boots', 3),
#  ('bedroom', 3),
#  ('stirring', 3),
#  ('fluttering', 3),
#  ('previous', 3),
#  ('lose', 3),
#  ('rather', 3),
#  ('cut', 3),
#  ('fourth', 3),
#  ('high', 3),
#  ('character', 3),
#  ('donkey', 3),
#  ('seldom', 3),
#  ('laugh', 3),
#  ('devoted', 3),
#  ('paddock', 3),
#  ('filed', 3),
#  ('asleep', 3),
#  ('chewing', 3),
#  ('mane', 3),
#  ('attention', 3),
#  ('die', 3),
#  ('wish', 3),
#  ('laborious', 3),
#  ('capable', 3),
#  ('happiness', 3),
#  ('leisure', 3),
#  ('slavery', 3),
#  ('stolen', 3),
#  ('scene', 3),
#  ('prevent', 3),
#  ('dung', 3),
#  ('calves', 3),
#  ('drop', 3),
#  ('market', 3),
#  ('pleasure', 3),
#  ('natural', 3),
#  ('porkers', 3),
#  ('power', 3),
#  ('rich', 3),
#  ('message', 3),
#  ('beneath', 3),
#  ('carry', 3),
#  ('struggle', 3),
#  ('argument', 3),
#  ('interest', 3),
#  ('interests', 3),
#  ('perfect', 3),
#  ('uproar', 3),
#  ('caught', 3),
#  ('wild', 3),
#  ('majority', 3),
#  ('ways', 3),
#  ('wings', 3),
#  ('smoke', 3),
#  ('engage', 3),
#  ('reminded', 3),
#  ('ago', 3),
#  ('memory', 3),
#  ('taught', 3),
#  ('sang', 3),
#  ('tidings', 3),
#  ('picture', 3),
#  ('blow', 3),
#  ('nights', 3),
#  ('sale', 3),
#  ('fierce-looking', 3),
#  ('talker', 3),
#  ('considered', 3),
#  ('referred', 3),
#  ('difference', 3),
#  ('firmly', 3),
#  ('convinced', 3),
#  ('existence', 3),
#  ('mysterious', 3),
#  ('country', 3),
#  ('sky', 3),
#  ('faithful', 3),
#  ('achieved', 3),
#  ('feeding', 3),
#  ('till', 3),
#  ('feed', 3),
#  ('bins', 3),
#  ('woke', 3),
#  ('butted', 3),
#  ('defend', 3),
#  ('heels', 3),
#  ('anywhere', 3),
#  ('traces', 3),
#  ('thrown', 3),
#  ('fetched', 3),
#  ('hat', 3),
#  ('served', 3),
#  ('everybody', 3),
#  ('tour', 3),
#  ('inspection', 3),
#  ('spinney', 3),
#  ('file', 3),
#  ('room', 3),
#  ('ribbon', 3),
#  ('admiring', 3),
#  ('manner', 3),
#  ('sharply', 3),
#  ('hanging', 3),
#  ('write', 3),
#  ('paint', 3),
#  ('succeeded', 3),
#  ('neatly', 3),
#  ('correct', 3),
#  ('benefit', 3),
#  ('nodded', 3),
#  ('quickly', 3),
#  ('uneasy', 3),
#  ('buckets', 3),
#  ('fairly', 3),
#  ('considerable', 3),
#  ('important', 3),
#  ('success', 3),
#  ('hoped', 3),
#  ('gathering', 3),
#  ('sun', 3),
#  ('moreover', 3),
#  ('sharp', 3),
#  ('gathered', 3),
#  ('eat', 3),
#  ('difficulties', 3),
#  ('style', 3),
#  ('possessed', 3),
#  ('threshing', 3),
#  ('machine', 3),
#  ('mighty', 3),
#  ('call', 3),
#  ('stole', 3),
#  ('republic', 3),
#  ('books', 3),
#  ('clean', 3),
#  ('league', 3),
#  ('classes', 3),
#  ('attempt', 3),
#  ('treated', 3),
#  ('advantage', 3),
#  ('roof', 3),
#  ('alphabet', 3),
#  ('letter', 3),
#  ('b', 3),
#  ('forelock', 3),
#  ('thoroughly', 3),
#  ('explanation', 3),
#  ('developed', 3),
#  ('start', 3),
#  ('growing', 3),
#  ('giving', 3),
#  ('mixed', 3),
#  ('assumed', 3),
#  ('equally', 3),
#  ('hope', 3),
#  ('privilege', 3),
#  ('sole', 3),
#  ('health', 3),
#  ('watching', 3),
#  ...]

# %%
#Turn all words to basic form
basic_form = [ps.stem(word) for word in tokens_low if not word in stopwords + symbols]

#Textを使うためにreviewをlistにぶち込む
basic_form = [basic_form]

#原型に戻した単語で、再び文を再構築する。
text = []
for i in basic_form:
    text.append(nltk.Text(i))
    
#Textからwords listを作る。
for i in text:
    words = [word for word in i]
    
words
# Out:
# ['jone',
#  'manor',
#  'farm',
#  'lock',
#  'hen-hous',
#  'night',
#  'drunk',
#  'rememb',
#  'shut',
#  'pop-hol',
#  'ring',
#  'light',
#  'lantern',
#  'danc',
#  'side',
#  'side',
#  'lurch',
#  'across',
#  'yard',
#  'kick',
#  'boot',
#  'back',
#  'door',
#  'drew',
#  'last',
#  'glass',
#  'beer',
#  'barrel',
#  'sculleri',
#  'made',
#  'way',
#  'bed',
#  'mrs.',
#  'jone',
#  'alreadi',
#  'snore',
#  'soon',
#  'light',
#  'bedroom',
#  'went',
#  'stir',
#  'flutter',
#  'farm',
#  'build',
#  'word',
#  'gone',
#  'round',
#  'day',
#  'old',
#  'major',
#  'prize',
#  'middl',
#  'white',
#  'boar',
#  'strang',
#  'dream',
#  'previou',
#  'night',
#  'wish',
#  'commun',
#  'anim',
#  'agre',
#  'meet',
#  'big',
#  'barn',
#  'soon',
#  'jone',
#  'safe',
#  'way',
#  'old',
#  'major',
#  'alway',
#  'call',
#  'though',
#  'name',
#  'exhibit',
#  'willingdon',
#  'beauti',
#  'highli',
#  'regard',
#  'farm',
#  'everyon',
#  'quit',
#  'readi',
#  'lose',
#  'hour',
#  'sleep',
#  'order',
#  'hear',
#  'say',
#  'one',
#  'end',
#  'big',
#  'barn',
#  'sort',
#  'rais',
#  'platform',
#  'major',
#  'alreadi',
#  'ensconc',
#  'bed',
#  'straw',
#  'lantern',
#  'hung',
#  'beam',
#  'twelv',
#  'year',
#  'old',
#  'late',
#  'grown',
#  'rather',
#  'stout',
#  'still',
#  'majestic-look',
#  'pig',
#  'wise',
#  'benevol',
#  'appear',
#  'spite',
#  'fact',
#  'tush',
#  'never',
#  'cut',
#  'long',
#  'anim',
#  'began',
#  'arriv',
#  'make',
#  'comfort',
#  'differ',
#  'fashion',
#  'first',
#  'came',
#  'three',
#  'dog',
#  'bluebel',
#  'jessi',
#  'pincher',
#  'pig',
#  'settl',
#  'straw',
#  'immedi',
#  'front',
#  'platform',
#  'hen',
#  'perch',
#  'window-sil',
#  'pigeon',
#  'flutter',
#  'rafter',
#  'sheep',
#  'cow',
#  'lay',
#  'behind',
#  'pig',
#  'began',
#  'chew',
#  'cud',
#  'two',
#  'cart-hors',
#  'boxer',
#  'clover',
#  'came',
#  'togeth',
#  'walk',
#  'slowli',
#  'set',
#  'vast',
#  'hairi',
#  'hoof',
#  'great',
#  'care',
#  'lest',
#  'small',
#  'anim',
#  'conceal',
#  'straw',
#  'clover',
#  'stout',
#  'motherli',
#  'mare',
#  'approach',
#  'middl',
#  'life',
#  'never',
#  'quit',
#  'got',
#  'figur',
#  'back',
#  'fourth',
#  'foal',
#  'boxer',
#  'enorm',
#  'beast',
#  'nearli',
#  'eighteen',
#  'hand',
#  'high',
#  'strong',
#  'two',
#  'ordinari',
#  'hors',
#  'put',
#  'togeth',
#  'white',
#  'stripe',
#  'nose',
#  'gave',
#  'somewhat',
#  'stupid',
#  'appear',
#  'fact',
#  'first-rat',
#  'intellig',
#  'univers',
#  'respect',
#  'steadi',
#  'charact',
#  'tremend',
#  'power',
#  'work',
#  'hors',
#  'came',
#  'muriel',
#  'white',
#  'goat',
#  'benjamin',
#  'donkey',
#  'benjamin',
#  'oldest',
#  'anim',
#  'farm',
#  'worst',
#  'temper',
#  'seldom',
#  'talk',
#  'usual',
#  'make',
#  'cynic',
#  'remark',
#  'instanc',
#  'would',
#  'say',
#  'god',
#  'given',
#  'tail',
#  'keep',
#  'fli',
#  'would',
#  'sooner',
#  'tail',
#  'fli',
#  'alon',
#  'among',
#  'anim',
#  'farm',
#  'never',
#  'laugh',
#  'ask',
#  'would',
#  'say',
#  'saw',
#  'noth',
#  'laugh',
#  'nevertheless',
#  'without',
#  'openli',
#  'admit',
#  'devot',
#  'boxer',
#  'two',
#  'usual',
#  'spent',
#  'sunday',
#  'togeth',
#  'small',
#  'paddock',
#  'beyond',
#  'orchard',
#  'graze',
#  'side',
#  'side',
#  'never',
#  'speak',
#  'two',
#  'hors',
#  'lain',
#  'brood',
#  'duckl',
#  'lost',
#  'mother',
#  'file',
#  'barn',
#  'cheep',
#  'feebli',
#  'wander',
#  'side',
#  'side',
#  'find',
#  'place',
#  'would',
#  'trodden',
#  'clover',
#  'made',
#  'sort',
#  'wall',
#  'round',
#  'great',
#  'foreleg',
#  'duckl',
#  'nestl',
#  'insid',
#  'promptli',
#  'fell',
#  'asleep',
#  'last',
#  'moment',
#  'molli',
#  'foolish',
#  'pretti',
#  'white',
#  'mare',
#  'drew',
#  'jone',
#  'trap',
#  'came',
#  'minc',
#  'daintili',
#  'chew',
#  'lump',
#  'sugar',
#  'took',
#  'place',
#  'near',
#  'front',
#  'began',
#  'flirt',
#  'white',
#  'mane',
#  'hope',
#  'draw',
#  'attent',
#  'red',
#  'ribbon',
#  'plait',
#  'last',
#  'came',
#  'cat',
#  'look',
#  'round',
#  'usual',
#  'warmest',
#  'place',
#  'final',
#  'squeez',
#  'boxer',
#  'clover',
#  'pur',
#  'contentedli',
#  'throughout',
#  'major',
#  'speech',
#  'without',
#  'listen',
#  'word',
#  'say',
#  'anim',
#  'present',
#  'except',
#  'mose',
#  'tame',
#  'raven',
#  'slept',
#  'perch',
#  'behind',
#  'back',
#  'door',
#  'major',
#  'saw',
#  'made',
#  'comfort',
#  'wait',
#  'attent',
#  'clear',
#  'throat',
#  'began',
#  '`comrad',
#  'heard',
#  'alreadi',
#  'strang',
#  'dream',
#  'last',
#  'night',
#  'come',
#  'dream',
#  'later',
#  'someth',
#  'els',
#  'say',
#  'first',
#  'think',
#  'comrad',
#  'shall',
#  'mani',
#  'month',
#  'longer',
#  'die',
#  'feel',
#  'duti',
#  'pass',
#  'wisdom',
#  'acquir',
#  'long',
#  'life',
#  'much',
#  'time',
#  'thought',
#  'lay',
#  'alon',
#  'stall',
#  'think',
#  'may',
#  'say',
#  'understand',
#  'natur',
#  'life',
#  'earth',
#  'well',
#  'anim',
#  'live',
#  'wish',
#  'speak',
#  '`now',
#  'comrad',
#  'natur',
#  'life',
#  'let',
#  'us',
#  'face',
#  'live',
#  'miser',
#  'labori',
#  'short',
#  'born',
#  'given',
#  'much',
#  'food',
#  'keep',
#  'breath',
#  'bodi',
#  'us',
#  'capabl',
#  'forc',
#  'work',
#  'last',
#  'atom',
#  'strength',
#  'instant',
#  'use',
#  'come',
#  'end',
#  'slaughter',
#  'hideou',
#  'cruelti',
#  'anim',
#  'england',
#  'know',
#  'mean',
#  'happi',
#  'leisur',
#  'year',
#  'old',
#  'anim',
#  'england',
#  'free',
#  'life',
#  'anim',
#  'miseri',
#  'slaveri',
#  'plain',
#  'truth',
#  '`but',
#  'simpli',
#  'part',
#  'order',
#  'natur',
#  'land',
#  'poor',
#  'afford',
#  'decent',
#  'life',
#  'dwell',
#  'upon',
#  'comrad',
#  'thousand',
#  'time',
#  'soil',
#  'england',
#  'fertil',
#  'climat',
#  'good',
#  'capabl',
#  'afford',
#  'food',
#  'abund',
#  'enorm',
#  'greater',
#  'number',
#  'anim',
#  'inhabit',
#  'singl',
#  'farm',
#  'would',
#  'support',
#  'dozen',
#  'hors',
#  'twenti',
#  'cow',
#  'hundr',
#  'sheep-and',
#  'live',
#  'comfort',
#  'digniti',
#  'almost',
#  'beyond',
#  'imagin',
#  'continu',
#  'miser',
#  'condit',
#  'nearli',
#  'whole',
#  'produc',
#  'labour',
#  'stolen',
#  'us',
#  'human',
#  'be',
#  'comrad',
#  'answer',
#  'problem',
#  'sum',
#  'singl',
#  'word-man',
#  'man',
#  'real',
#  'enemi',
#  'remov',
#  'man',
#  'scene',
#  'root',
#  'caus',
#  'hunger',
#  'overwork',
#  'abolish',
#  'ever',
#  'man',
#  'creatur',
#  'consum',
#  'without',
#  'produc',
#  'give',
#  'milk',
#  'lay',
#  'egg',
#  'weak',
#  'pull',
#  'plough',
#  'run',
#  'fast',
#  'enough',
#  'catch',
#  'rabbit',
#  'yet',
#  'lord',
#  'anim',
#  'set',
#  'work',
#  'give',
#  'back',
#  'bare',
#  'minimum',
#  'prevent',
#  'starv',
#  'rest',
#  'keep',
#  'labour',
#  'till',
#  'soil',
#  'dung',
#  'fertilis',
#  'yet',
#  'one',
#  'us',
#  'own',
#  'bare',
#  'skin',
#  'cow',
#  'see',
#  'mani',
#  'thousand',
#  'gallon',
#  'milk',
#  'given',
#  'last',
#  'year',
#  'happen',
#  'milk',
#  'breed',
#  'sturdi',
#  'calv',
#  'everi',
#  'drop',
#  'gone',
#  'throat',
#  'enemi',
#  'hen',
#  'mani',
#  'egg',
#  'laid',
#  'last',
#  'year',
#  'mani',
#  'egg',
#  'ever',
#  'hatch',
#  'chicken',
#  'rest',
#  'gone',
#  'market',
#  'bring',
#  'money',
#  'jone',
#  'men',
#  'clover',
#  'four',
#  'foal',
#  'bore',
#  'support',
#  'pleasur',
#  'old',
#  'age',
#  'sold',
#  'year',
#  'old-you',
#  'never',
#  'see',
#  'one',
#  'return',
#  'four',
#  'confin',
#  'labour',
#  'field',
#  'ever',
#  'except',
#  'bare',
#  'ration',
#  'stall',
#  'even',
#  'miser',
#  'live',
#  'lead',
#  'allow',
#  'reach',
#  'natur',
#  'span',
#  'grumbl',
#  'one',
#  'lucki',
#  'one',
#  'twelv',
#  'year',
#  'old',
#  'four',
#  'hundr',
#  'children',
#  'natur',
#  'life',
#  'pig',
#  'anim',
#  'escap',
#  'cruel',
#  'knife',
#  'end',
#  'young',
#  'porker',
#  'sit',
#  'front',
#  'everi',
#  'one',
#  'scream',
#  'live',
#  'block',
#  'within',
#  'year',
#  'horror',
#  'must',
#  'come-cow',
#  'pig',
#  'hen',
#  'sheep',
#  'everyon',
#  'even',
#  'hors',
#  'dog',
#  'better',
#  'fate',
#  'boxer',
#  'day',
#  'great',
#  'muscl',
#  'lose',
#  'power',
#  'jone',
#  'sell',
#  'knacker',
#  'cut',
#  'throat',
#  'boil',
#  'foxhound',
#  'dog',
#  'grow',
#  'old',
#  'toothless',
#  'jone',
#  'tie',
#  'brick',
#  'round',
#  'neck',
#  'drown',
#  'nearest',
#  'pond',
#  'crystal',
#  'clear',
#  'comrad',
#  'evil',
#  'life',
#  'spring',
#  'tyranni',
#  'human',
#  'be',
#  'get',
#  'rid',
#  'man',
#  'produc',
#  'labour',
#  'would',
#  'a1most',
#  'overnight',
#  'could',
#  'becom',
#  'rich',
#  'free',
#  'must',
#  'work',
#  'night',
#  'day',
#  'bodi',
#  'soul',
#  'overthrow',
#  'human',
#  'race',
#  'messag',
#  'comrad',
#  'rebellion',
#  'know',
#  'rebellion',
#  'come',
#  'might',
#  'week',
#  'hundr',
#  'year',
#  'know',
#  'sure',
#  'see',
#  'straw',
#  'beneath',
#  'feet',
#  'sooner',
#  'later',
#  'justic',
#  'done',
#  'fix',
#  'eye',
#  'comrad',
#  'throughout',
#  'short',
#  'remaind',
#  'live',
#  'pass',
#  'messag',
#  'mine',
#  'come',
#  'futur',
#  'gener',
#  'shall',
#  'carri',
#  'struggl',
#  'victori',
#  'rememb',
#  'comrad',
#  'resolut',
#  'must',
#  'never',
#  'falter',
#  'argument',
#  'must',
#  'lead',
#  'astray',
#  'never',
#  'listen',
#  'tell',
#  'man',
#  'anim',
#  'common',
#  'interest',
#  'prosper',
#  'one',
#  'prosper',
#  'other',
#  'lie',
#  'man',
#  'serv',
#  'interest',
#  'creatur',
#  'except',
#  'among',
#  'us',
#  'anim',
#  'let',
#  'perfect',
#  'uniti',
#  'perfect',
#  'comradeship',
#  'struggl',
#  'men',
#  'enemi',
#  'anim',
#  'comrad',
#  'moment',
#  'tremend',
#  'uproar',
#  'major',
#  'speak',
#  'four',
#  'larg',
#  'rat',
#  'crept',
#  'hole',
#  'sit',
#  'hindquart',
#  'listen',
#  'dog',
#  'suddenli',
#  'caught',
#  'sight',
#  'swift',
#  'dash',
#  'hole',
#  'rat',
#  'save',
#  'live',
#  'major',
#  'rais',
#  'trotter',
#  'silenc',
#  'comrad',
#  'said',
#  'point',
#  'must',
#  'settl',
#  'wild',
#  'creatur',
#  'rat',
#  'rabbits-ar',
#  'friend',
#  'enemi',
#  'let',
#  'us',
#  'put',
#  'vote',
#  'propos',
#  'question',
#  'meet',
#  'rat',
#  'comrad',
#  'vote',
#  'taken',
#  'agre',
#  'overwhelm',
#  'major',
#  'rat',
#  'comrad',
#  'four',
#  'dissenti',
#  'three',
#  'dog',
#  'cat',
#  'afterward',
#  'discov',
#  'vote',
#  'side',
#  'major',
#  'continu',
#  'littl',
#  'say',
#  'mere',
#  'repeat',
#  'rememb',
#  'alway',
#  'duti',
#  'enmiti',
#  'toward',
#  'man',
#  'way',
#  'whatev',
#  'goe',
#  'upon',
#  'two',
#  'leg',
#  'enemi',
#  'whatev',
#  'goe',
#  'upon',
#  'four',
#  'leg',
#  'wing',
#  'friend',
#  'rememb',
#  'also',
#  'fight',
#  'ing',
#  'man',
#  'must',
#  'come',
#  'resembl',
#  'even',
#  'conquer',
#  'adopt',
#  'vice',
#  'anim',
#  'must',
#  'ever',
#  'live',
#  'hous',
#  'sleep',
#  'bed',
#  'wear',
#  'cloth',
#  'drink',
#  'alcohol',
#  'smoke',
#  'tobacco',
#  'touch',
#  'money',
#  'engag',
#  'trade',
#  'habit',
#  'man',
#  'evil',
#  'anim',
#  'must',
#  'ever',
#  'tyrannis',
#  'kind',
#  'weak',
#  'strong',
#  'clever',
#  'simpl',
#  'brother',
#  'anim',
#  'must',
#  'ever',
#  'kill',
#  'anim',
#  'anim',
#  'equal',
#  'comrad',
#  'tell',
#  'dream',
#  'last',
#  'night',
#  'describ',
#  'dream',
#  'dream',
#  'earth',
#  'man',
#  'vanish',
#  'remind',
#  'someth',
#  'long',
#  'forgotten',
#  'mani',
#  'year',
#  'ago',
#  'littl',
#  'pig',
#  'mother',
#  'sow',
#  'use',
#  'sing',
#  ...]

# %%
#Basic に直して、頻度を確認する
freq_list_basic = []
for i in text:
    freq_list_basic.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

#順位チェック
sorted(freq_list_basic[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('anim', 360),
#  ('farm', 174),
#  ('napoleon', 168),
#  ('would', 138),
#  ('snowbal', 131),
#  ('pig', 114),
#  ('boxer', 96),
#  ('work', 96),
#  ('comrad', 95),
#  ('said', 92),
#  ('day', 87),
#  ('time', 84),
#  ('jone', 82),
#  ('one', 81),
#  ('could', 76),
#  ('even', 73),
#  ('windmil', 73),
#  ('two', 69),
#  ('squealer', 67),
#  ('dog', 58),
#  ('everi', 58),
#  ('back', 54),
#  ('round', 52),
#  ('never', 51),
#  ('came', 50),
#  ('come', 50),
#  ('clover', 47),
#  ('moment', 47),
#  ('leg', 47),
#  ('human', 45),
#  ('side', 41),
#  ('long', 41),
#  ('made', 40),
#  ('old', 40),
#  ('year', 40),
#  ('seem', 38),
#  ('first', 37),
#  ('ever', 37),
#  ('way', 36),
#  ('men', 36),
#  ('four', 36),
#  ('end', 35),
#  ('upon', 35),
#  ('sheep', 34),
#  ('live', 34),
#  ('farmhous', 34),
#  ('frederick', 34),
#  ('make', 33),
#  ('good', 33),
#  ('say', 32),
#  ('three', 32),
#  ('build', 31),
#  ('appear', 31),
#  ('benjamin', 31),
#  ('yard', 29),
#  ('went', 29),
#  ('word', 29),
#  ('though', 29),
#  ('order', 29),
#  ('happen', 29),
#  ('rebellion', 29),
#  ('littl', 29),
#  ('cri', 29),
#  ('rememb', 28),
#  ('alway', 28),
#  ('use', 28),
#  ('england', 28),
#  ('morn', 28),
#  ('anoth', 28),
#  ('go', 28),
#  ('command', 28),
#  ('pilkington', 28),
#  ('night', 27),
#  ('last', 27),
#  ('set', 27),
#  ('great', 27),
#  ('read', 27),
#  ('hoof', 26),
#  ('hors', 26),
#  ('much', 26),
#  ('must', 26),
#  ('hen', 25),
#  ('without', 25),
#  ('later', 25),
#  ('shall', 25),
#  ('field', 25),
#  ('away', 25),
#  ('barn', 24),
#  ('call', 24),
#  ('still', 24),
#  ('noth', 24),
#  ('sunday', 24),
#  ('look', 24),
#  ('thought', 24),
#  ('well', 24),
#  ('almost', 24),
#  ('better', 24),
#  ('get', 24),
#  ('week', 24),
#  ('also', 24),
#  ('believ', 24),
#  ('found', 24),
#  ('thing', 24),
#  ('saw', 23),
#  ('meet', 22),
#  ('hour', 22),
#  ('life', 22),
#  ('took', 22),
#  ('except', 22),
#  ('mani', 22),
#  ('labour', 22),
#  ('man', 22),
#  ('might', 22),
#  ('seen', 22),
#  ('like', 22),
#  ('battl', 22),
#  ('announc', 22),
#  ('major', 21),
#  ('began', 21),
#  ('put', 21),
#  ('eye', 21),
#  ('need', 21),
#  ('hard', 21),
#  ('follow', 21),
#  ('bed', 20),
#  ('soon', 20),
#  ('cow', 20),
#  ('usual', 20),
#  ('tail', 20),
#  ('place', 20),
#  ('molli', 20),
#  ('us', 20),
#  ('face', 20),
#  ('suddenli', 20),
#  ('voic', 20),
#  ('turn', 20),
#  ('gun', 20),
#  ('name', 19),
#  ('given', 19),
#  ('wall', 19),
#  ('stall', 19),
#  ('food', 19),
#  ('know', 19),
#  ('whole', 19),
#  ('sing', 19),
#  ('stone', 19),
#  ('alreadi', 18),
#  ('lay', 18),
#  ('togeth', 18),
#  ('speech', 18),
#  ('heard', 18),
#  ('enough', 18),
#  ('done', 18),
#  ('take', 18),
#  ('death', 18),
#  ('seven', 18),
#  ('summer', 18),
#  ('milk', 17),
#  ('run', 17),
#  ('see', 17),
#  ('carri', 17),
#  ('hay', 17),
#  ('plan', 17),
#  ('right', 17),
#  ('white', 16),
#  ('among', 16),
#  ('think', 16),
#  ('die', 16),
#  ('pass', 16),
#  ('enemi', 16),
#  ('give', 16),
#  ('young', 16),
#  ('certain', 16),
#  ("'beast", 16),
#  ('past', 16),
#  ('half', 16),
#  ('whymper', 16),
#  ('van', 16),
#  ('gone', 15),
#  ('late', 15),
#  ('fact', 15),
#  ('walk', 15),
#  ('speak', 15),
#  ('yet', 15),
#  ('ration', 15),
#  ('taken', 15),
#  ('drink', 15),
#  ('kind', 15),
#  ('howev', 15),
#  ('hedg', 15),
#  ('harvest', 15),
#  ('sent', 15),
#  ('learn', 15),
#  ('abl', 15),
#  ('foxwood', 15),
#  ('terribl', 15),
#  ('stood', 15),
#  ('big', 14),
#  ('sleep', 14),
#  ('straw', 14),
#  ('immedi', 14),
#  ('pigeon', 14),
#  ('muriel', 14),
#  ('ask', 14),
#  ('someth', 14),
#  ('egg', 14),
#  ('race', 14),
#  ('sure', 14),
#  ('sinc', 14),
#  ('mind', 14),
#  ('complet', 14),
#  ('begin', 14),
#  ('full', 14),
#  ('fire', 14),
#  ('forward', 14),
#  ('bad', 14),
#  ('small', 13),
#  ('got', 13),
#  ('hand', 13),
#  ('talk', 13),
#  ('final', 13),
#  ('creatur', 13),
#  ('feet', 13),
#  ('equal', 13),
#  ('song', 13),
#  ('anyth', 13),
#  ('corn', 13),
#  ('outsid', 13),
#  ('sometim', 13),
#  ('necessari', 13),
#  ('cowsh', 13),
#  ('utter', 13),
#  ('dream', 12),
#  ('willingdon', 12),
#  ('rais', 12),
#  ('beast', 12),
#  ('gave', 12),
#  ('tremend', 12),
#  ('beyond', 12),
#  ('let', 12),
#  ('rest', 12),
#  ('lie', 12),
#  ('larg', 12),
#  ('point', 12),
#  ('question', 12),
#  ('black', 12),
#  ('difficulti', 12),
#  ('minut', 12),
#  ('five', 12),
#  ('success', 12),
#  ('pastur', 12),
#  ('remain', 12),
#  ('piec', 12),
#  ('written', 12),
#  ('letter', 12),
#  ('notic', 12),
#  ('far', 12),
#  ('finish', 12),
#  ('arrang', 12),
#  ('ground', 12),
#  ('flag', 12),
#  ('green', 12),
#  ('class', 12),
#  ('rumour', 12),
#  ('door', 11),
#  ('orchard', 11),
#  ('part', 11),
#  ('whatev', 11),
#  ('kill', 11),
#  ('knew', 11),
#  ('tune', 11),
#  ('known', 11),
#  ('earli', 11),
#  ('next', 11),
#  ('reason', 11),
#  ('whether', 11),
#  ('harder', 11),
#  ('led', 11),
#  ('news', 11),
#  ('stand', 11),
#  ('pinchfield', 11),
#  ('felt', 11),
#  ('confess', 11),
#  ('stir', 10),
#  ('quit', 10),
#  ('differ', 10),
#  ('behind', 10),
#  ('care', 10),
#  ('ribbon', 10),
#  ('listen', 10),
#  ('mose', 10),
#  ('short', 10),
#  ('happi', 10),
#  ('imagin', 10),
#  ('produc', 10),
#  ('money', 10),
#  ('sit', 10),
#  ('gener', 10),
#  ('resolut', 10),
#  ('silenc', 10),
#  ('vote', 10),
#  ('discov', 10),
#  ('wear', 10),
#  ('sever', 10),
#  ('sound', 10),
#  ('anyon', 10),
#  ('broke', 10),
#  ('tri', 10),
#  ('broken', 10),
#  ('rush', 10),
#  ('write', 10),
#  ('agreement', 10),
#  ('case', 10),
#  ('none', 10),
#  ('attack', 10),
#  ('pile', 10),
#  ('winter', 10),
#  ('timber', 10),
#  ('light', 9),
#  ('kick', 9),
#  ('everyon', 9),
#  ('hear', 9),
#  ('spite', 9),
#  ('slowli', 9),
#  ('nearli', 9),
#  ('keep', 9),
#  ('sugar', 9),
#  ('hope', 9),
#  ('clear', 9),
#  ('feel', 9),
#  ('understand', 9),
#  ('bodi', 9),
#  ('number', 9),
#  ('hundr', 9),
#  ('continu', 9),
#  ('spring', 9),
#  ('victori', 9),
#  ('tell', 9),
#  ('save', 9),
#  ('trotter', 9),
#  ('march', 9),
#  ('secret', 9),
#  ('held', 9),
#  ('dead', 9),
#  ('everyth', 9),
#  ('earlier', 9),
#  ('accord', 9),
#  ('flung', 9),
#  ('gaze', 9),
#  ('air', 9),
#  ('paint', 9),
#  ('form', 9),
#  ('honour', 9),
#  ('less', 9),
#  ('possibl', 9),
#  ('retir', 9),
#  ('nine', 9),
#  ('appl', 9),
#  ('neighbour', 9),
#  ('intend', 9),
#  ('close', 9),
#  ('receiv', 9),
#  ('stop', 9),
#  ('leader', 9),
#  ('manor', 8),
#  ('strang', 8),
#  ('front', 8),
#  ('nose', 8),
#  ('fli', 8),
#  ('lost', 8),
#  ('find', 8),
#  ('throughout', 8),
#  ('longer', 8),
#  ('natur', 8),
#  ('mean', 8),
#  ('singl', 8),
#  ('drop', 8),
#  ('rat', 8),
#  ('sight', 8),
#  ('mere', 8),
#  ('toward', 8),
#  ('whip', 8),
#  ('spread', 8),
#  ('new', 8),
#  ('besid', 8),
#  ('especi', 8),
#  ('told', 8),
#  ('attend', 8),
#  ('farmer', 8),
#  ('world', 8),
#  ('direct', 8),
#  ('frighten', 8),
#  ('window', 8),
#  ('gate', 8),
#  ('act', 8),
#  ('hide', 8),
#  ('ear', 8),
#  ('destroy', 8),
#  ('top', 8),
#  ('ye', 8),
#  ('admir', 8),
#  ('hold', 8),
#  ('explain', 8),
#  ('reduc', 8),
#  ('heart', 8),
#  ('disappear', 8),
#  ('effort', 8),
#  ('inch', 8),
#  ('actual', 8),
#  ('either', 8),
#  ('garden', 8),
#  ('asid', 8),
#  ('decid', 8),
#  ('declar', 8),
#  ('prove', 8),
#  ('often', 8),
#  ('bleat', 8),
#  ('watch', 8),
#  ('head', 8),
#  ('shout', 8),
#  ('cover', 8),
#  ('expuls', 8),
#  ('quarri', 8),
#  ('drag', 8),
#  ('across', 7),
#  ('agre', 7),
#  ('comfort', 7),
#  ('enorm', 7),
#  ('remark', 7),
#  ('nevertheless', 7),
#  ('file', 7),
#  ('cat', 7),
#  ('present', 7),
#  ('wait', 7),
#  ('forc', 7),
#  ('free', 7),
#  ('problem', 7),
#  ('bare', 7),
#  ('allow', 7),
#  ('futur', 7),
#  ('interest', 7),
#  ('friend', 7),
#  ('afterward', 7),
#  ('hous', 7),
#  ('clever', 7),
#  ('memori', 7),
#  ('ran', 7),
#  ('barley', 7),
#  ('water', 7),
#  ('gees', 7),
#  ('foot', 7),
#  ('prepar', 7),
#  ('feed', 7),
#  ('want', 7),
#  ('accept', 7),
#  ('flight', 7),
#  ('road', 7),
#  ('gallop', 7),
#  ('enter', 7),
#  ('six', 7),
#  ('matter', 7),
#  ('gather', 7),
#  ('cockerel', 7),
#  ('nobodi', 7),
#  ('true', 7),
#  ('assembl', 7),
#  ('debat', 7),
#  ('committe', 7),
#  ('attempt', 7),
#  ('kept', 7),
#  ('inde', 7),
#  ('twice', 7),
#  ('manag', 7),
#  ('everywher', 7),
#  ('pellet', 7),
#  ('hero', 7),
#  ('electr', 7),
#  ('detail', 7),
#  ('built', 7),
#  ('cold', 7),
#  ('special', 7),
#  ('protest', 7),
#  ('growl', 7),
#  ('rebuild', 7),
#  ('left', 7),
#  ('glass', 6),
#  ('beer', 6),
#  ('boar', 6),
#  ('wish', 6),
#  ('twelv', 6),
#  ('approach', 6),
#  ('figur', 6),
#  ('somewhat', 6),
#  ('stupid', 6),
#  ('alon', 6),
#  ('near', 6),
#  ('throat', 6),
#  ('els', 6),
#  ('duti', 6),
#  ('earth', 6),
#  ('strength', 6),
#  ('simpli', 6),
#  ('support', 6),
#  ('dozen', 6),
#  ('caus', 6),
#  ('plough', 6),
#  ('starv', 6),
#  ('bring', 6),
#  ('return', 6),
#  ('lead', 6),
#  ('cruel', 6),
#  ('within', 6),
#  ('becom', 6),
#  ('struggl', 6),
#  ('prosper', 6),
#  ('crept', 6),
#  ('hole', 6),
#  ('fight', 6),
#  ('forgotten', 6),
#  ('break', 6),
#  ('toil', 6),
#  ('skip', 6),
#  ('whisk', 6),
#  ('somehow', 6),
#  ('principl', 6),
#  ('contrari', 6),
#  ('exist', 6),
#  ('sugarcandi', 6),
#  ('mountain', 6),
#  ('distanc', 6),
#  ('season', 6),
#  ('expect', 6),
#  ('kitchen', 6),
#  ('weed', 6),
#  ('store-sh', 6),
#  ('horn', 6),
#  ('hungri', 6),
#  ('main', 6),
#  ('trace', 6),
#  ('harness-room', 6),
#  ('open', 6),
#  ('decor', 6),
#  ('mark', 6),
#  ('knoll', 6),
#  ('crop', 6),
#  ('mouth', 6),
#  ('grass', 6),
#  ('snuf', 6),
#  ('inspect', 6),
#  ('pool', 6),
#  ('shoulder', 6),
#  ('spot', 6),
#  ('onward', 6),
#  ('studi', 6),
#  ('hind', 6),
#  ('busi', 6),
#  ('fro', 6),
#  ('machin', 6),
#  ('express', 6),
#  ('afternoon', 6),
#  ('variou', 6),
#  ('refus', 6),
#  ('unabl', 6),
#  ('maxim', 6),
#  ('instruct', 6),
#  ('chang', 6),
#  ('stick', 6),
#  ('oper', 6),
#  ('wound', 6),
#  ('blood', 6),
#  ('tear', 6),
#  ('celebr', 6),
#  ('becam', 6),
#  ('weather', 6),
#  ('floor', 6),
#  ('move', 6),
#  ('least', 6),
#  ('corner', 6),
#  ('increas', 6),
#  ('privat', 6),
#  ('relat', 6),
#  ('warn', 6),
#  ('meal', 6),
#  ('terror', 6),
#  ('perhap', 6),
#  ('tabl', 6),
#  ('compani', 6),
#  ('mrs.', 5),
#  ('middl', 5),
#  ('grown', 5),
#  ('cut', 5),
#  ('perch', 5),
#  ('respect', 5),
#  ('donkey', 5),
#  ('instanc', 5),
#  ('spent', 5),
#  ('insid', 5),
#  ('fell', 5),
#  ('draw', 5),
#  ('red', 5),
#  ('slept', 5),
#  ('month', 5),
#  ('miser', 5),
#  ('slaughter', 5),
#  ('digniti', 5),
#  ('real', 5),
#  ('remov', 5),
#  ('scene', 5),
#  ('abolish', 5),
#  ('weak', 5),
#  ('laid', 5),
#  ('age', 5),
#  ('sell', 5),
#  ('grow', 5),
#  ('argument', 5),
#  ('serv', 5),
#  ('alcohol', 5),
#  ('engag', 5),
#  ('sow', 5),
#  ('activ', 5),
#  ('clearli', 5),
#  ('teach', 5),
#  ('organis', 5),
#  ('argu', 5),
#  ('difficult', 5),
#  ('master', 5),
#  ('spirit', 5),
#  ('convinc', 5),
#  ('grew', 5),
#  ('hate', 5),
#  ('achiev', 5),
#  ('fallen', 5),
#  ('roof', 5),
#  ('triumph', 5),
#  ('possess', 5),
#  ('slip', 5),
#  ('sprang', 5),
#  ('meanwhil', 5),
#  ('chase', 5),
#  ('five-bar', 5),
#  ('hardli', 5),
#  ('excit', 5),
#  ('halt', 5),
#  ('today', 5),
#  ('book', 5),
#  ('wrong', 5),
#  ('loud', 5),
#  ('burst', 5),
#  ('task', 5),
#  ('mix', 5),
#  ('import', 5),
#  ('supervis', 5),
#  ('leadership', 5),
#  ('cours', 5),
#  ('duck', 5),
#  ('grain', 5),
#  ('leav', 5),
#  ('excel', 5),
#  ('imposs', 5),
#  ('extra', 5),
#  ('fail', 5),
#  ('object', 5),
#  ('brought', 5),
#  ('product', 5),
#  ('leagu', 5),
#  ('effect', 5),
#  ('start', 5),
#  ('tire', 5),
#  ('stori', 5),
#  ('secretli', 5),
#  ('idea', 5),
#  ('rage', 5),
#  ('ahead', 5),
#  ('charg', 5),
#  ('deal', 5),
#  ('second', 5),
#  ('line', 5),
#  ('terrifi', 5),
#  ('skull', 5),
#  ('stretch', 5),
#  ('pain', 5),
#  ('improv', 5),
#  ('warm', 5),
#  ('machineri', 5),
#  ('defeat', 5),
#  ('bound', 5),
#  ('sat', 5),
#  ('doubt', 5),
#  ('silent', 5),
#  ('previous', 5),
#  ('shock', 5),
#  ('deep', 5),
#  ("o'clock", 5),
#  ('nowaday', 5),
#  ('surpris', 5),
#  ('paper', 5),
#  ('boulder', 5),
#  ('process', 5),
#  ('fill', 5),
#  ('visit', 5),
#  ('rule', 5),
#  ('sheet', 5),
#  ('mill', 5),
#  ('traitor', 5),
#  ('pronounc', 5),
#  ('thick', 5),
#  ('empti', 5),
#  ('decre', 5),
#  ('ad', 5),
#  ('plot', 5),
#  ('agent', 5),
#  ('execut', 5),
#  ('pension', 5),
#  ('bought', 5),
#  ('toast', 5),
#  ('shut', 4),
#  ('lantern', 4),
#  ('drew', 4),
#  ('flutter', 4),
#  ('regard', 4),
#  ('readi', 4),
#  ('lose', 4),
#  ('platform', 4),
#  ('stout', 4),
#  ('arriv', 4),
#  ('bluebel', 4),
#  ('jessi', 4),
#  ('settl', 4),
#  ('chew', 4),
#  ('mare', 4),
#  ('strong', 4),
#  ('power', 4),
#  ('sooner', 4),
#  ('laugh', 4),
#  ('devot', 4),
#  ('duckl', 4),
#  ('mother', 4),
#  ('promptli', 4),
#  ('foolish', 4),
#  ('lump', 4),
#  ('mane', 4),
#  ('attent', 4),
#  ('tame', 4),
#  ('raven', 4),
#  ('labori', 4),
#  ('breath', 4),
#  ('instant', 4),
#  ('truth', 4),
#  ('land', 4),
#  ('soil', 4),
#  ('greater', 4),
#  ('twenti', 4),
#  ('condit', 4),
#  ('answer', 4),
#  ('pull', 4),
#  ('till', 4),
#  ('sold', 4),
#  ('reach', 4),
#  ('block', 4),
#  ('muscl', 4),
#  ('knacker', 4),
#  ('rich', 4),
#  ('messag', 4),
#  ('dash', 4),
#  ('repeat', 4),
#  ('goe', 4),
#  ('wing', 4),
#  ('adopt', 4),
#  ('cloth', 4),
#  ('trade', 4),
#  ('simpl', 4),
#  ('vanish', 4),
#  ('remind', 4),
#  ('sung', 4),
#  ('pictur', 4),
#  ('wheat', 4),
#  ('oat', 4),
#  ('blow', 4),
#  ('peac', 4),
#  ('buri', 4),
#  ('invent', 4),
#  ('best', 4),
#  ('fat', 4),
#  ('shrill', 4),
#  ('met', 4),
#  ('worth', 4),
#  ('mysteri', 4),
#  ('somewher', 4),
#  ('faith', 4),
#  ('easili', 4),
#  ('occasion', 4),
#  ('drawing-room', 4),
#  ('help', 4),
#  ('lash', 4),
#  ('rubbish', 4),
#  ('wore', 4),
#  ('biscuit', 4),
#  ('hayfield', 4),
#  ('fear', 4),
#  ('unanim', 4),
#  ('breakfast', 4),
#  ('ladder', 4),
#  ('succeed', 4),
#  ('inscrib', 4),
#  ('law', 4),
#  ('uneasi', 4),
#  ('someon', 4),
#  ('mash', 4),
#  ('bigger', 4),
#  ('understood', 4),
#  ('assum', 4),
#  ('thresh', 4),
#  ('regular', 4),
#  ('observ', 4),
#  ('hoist', 4),
#  ('flagstaff', 4),
#  ('treat', 4),
#  ('autumn', 4),
#  ('bird', 4),
#  ('explan', 4),
#  ('forth', 4),
#  ('collect', 4),
#  ('whose', 4),
#  ('complain', 4),
#  ('wonder', 4),
#  ('pretend', 4),
#  ('rapidli', 4),
#  ('fulli', 4),
#  ('affair', 4),
#  ('circul', 4),
#  ('speed', 4),
#  ('signal', 4),
#  ('fled', 4),
#  ('emerg', 4),
#  ('rear', 4),
#  ('straight', 4),
#  ('sorrow', 4),
#  ('iron', 4),
#  ('exclaim', 4),
#  ('somebodi', 4),
#  ('alarm', 4),
#  ('solemn', 4),
#  ('realli', 4),
#  ('discuss', 4),
#  ('suppli', 4),
#  ('stroke', 4),
#  ('report', 4),
#  ('enjoy', 4),
#  ('mention', 4),
#  ('decis', 4),
#  ('violent', 4),
#  ('complic', 4),
#  ('quietli', 4),
#  ('dynamo', 4),
#  ('shed', 4),
#  ('lift', 4),
#  ('procur', 4),
#  ('wast', 4),
#  ('slogan', 4),
#  ('apart', 4),
#  ('determin', 4),
#  ('spoken', 4),
#  ('huge', 4),
#  ('deliv', 4),
#  ('troubl', 4),
#  ('sacrific', 4),
#  ('heavi', 4),
#  ('compos', 4),
#  ('poem', 4),
#  ('realiti', 4),
#  ('meant', 4),
#  ('spoke', 4),
#  ('occur', 4),
#  ('critic', 4),
#  ('store', 4),
#  ('simultan', 4),
#  ('foundat', 4),
#  ('roar', 4),
#  ('alter', 4),
#  ('potato', 4),
#  ('smell', 4),
#  ('teeth', 4),
#  ('wors', 4),
#  ('paus', 4),
#  ('belli', 4),
#  ('deadli', 4),
#  ('purchas', 4),
#  ('paid', 4),
#  ('glanc', 4),
#  ('mug', 4),
#  ('gentlemen', 4),
#  ('ring', 3),
#  ('boot', 3),
#  ('bedroom', 3),
#  ('previou', 3),
#  ('rather', 3),
#  ('fashion', 3),
#  ('fourth', 3),
#  ('high', 3),
#  ('charact', 3),
#  ('seldom', 3),
#  ('admit', 3),
#  ('paddock', 3),
#  ('graze', 3),
#  ('asleep', 3),
#  ('born', 3),
#  ('capabl', 3),
#  ('cruelti', 3),
#  ('leisur', 3),
#  ('slaveri', 3),
#  ('thousand', 3),
#  ('stolen', 3),
#  ('root', 3),
#  ('catch', 3),
#  ('rabbit', 3),
#  ('prevent', 3),
#  ('dung', 3),
#  ('calv', 3),
#  ('market', 3),
#  ('pleasur', 3),
#  ('porker', 3),
#  ('boil', 3),
#  ('brick', 3),
#  ('neck', 3),
#  ('evil', 3),
#  ('beneath', 3),
#  ('perfect', 3),
#  ('uproar', 3),
#  ('caught', 3),
#  ('wild', 3),
#  ('smoke', 3),
#  ('touch', 3),
#  ('ago', 3),
#  ('taught', 3),
#  ('sang', 3),
#  ('joy', 3),
#  ('tide', 3),
#  ('fruit', 3),
#  ('bit', 3),
#  ('sale', 3),
#  ('fierce-look', 3),
#  ('talker', 3),
#  ('consid', 3),
#  ('movement', 3),
#  ('refer', 3),
#  ('firmli', 3),
#  ('countri', 3),
#  ('situat', 3),
#  ('sky', 3),
#  ('cloud', 3),
#  ('tale', 3),
#  ('bin', 3),
#  ('woke', 3),
#  ('bear', 3),
#  ('defend', 3),
#  ('heel', 3),
#  ('fortun', 3),
#  ('anywher', 3),
#  ('thrown', 3),
#  ('fetch', 3),
#  ('hat', 3),
#  ('everybodi', 3),
#  ('gambol', 3),
#  ('roll', 3),
#  ('tour', 3),
#  ('survey', 3),
#  ('spinney', 3),
#  ('disturb', 3),
#  ('tipto', 3),
#  ('room', 3),
#  ('whisper', 3),
#  ('luxuri', 3),
#  ('manner', 3),
#  ('sharpli', 3),
#  ('hang', 3),
#  ('spell', 3),
#  ('neatli', 3),
#  ('correct', 3),
#  ('benefit', 3),
#  ('nod', 3),
#  ('quickli', 3),
#  ('low', 3),
#  ('bucket', 3),
#  ('fairli', 3),
#  ('consider', 3),
#  ('sweat', 3),
#  ('tool', 3),
#  ('sun', 3),
#  ('moreov', 3),
#  ('sharp', 3),
#  ('eat', 3),
#  ('style', 3),
#  ('worker', 3),
#  ('mighti', 3),
#  ('push', 3),
#  ('bushel', 3),
#  ('stole', 3),
#  ('quarrel', 3),
#  ('reappear', 3),
#  ('intent', 3),
#  ...]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#文章を小文字化
sentence_small = [w.lower() for w in sentence1]

#いけそう。文ごとに取り出し、それぞれの単語を原型に戻す。それを再び再構築する！
form_sent = []
for sentence in sentence_small:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    form_sent.append(" ".join(form))
    
    
#ピリオドやカンマを消しまーす。Delte period and comma...めんどい...
form_sent2 = []

for i in form_sent:
    tokens = nltk.word_tokenize(i)
    form = [word for word in tokens if not word in stopwords + symbols]
    form_sent2.append(" ".join(form))
    
    
#次にこの新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化したい
text = []

for i in form_sent2:
    tokens = nltk.word_tokenize(i)
    for j in tokens:
        text.append(j)
        
text = [text]

# %%
#新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化

import matplotlib.pyplot as plt
# %matplotlib inline

f_list_new = []
for i in text:
    f_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in f_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
log_freq  = []
for i in f_list_new[0].values():
    log_freq.append(i)

#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_freq, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('freq(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#順位チェック
sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('anim', 321),
#  ('farm', 168),
#  ('napoleon', 168),
#  ('would', 138),
#  ('boxer', 96),
#  ('work', 95),
#  ('said', 92),
#  ('pig', 91),
#  ('snowbal', 82),
#  ('one', 80),
#  ('time', 80),
#  ('day', 77),
#  ('could', 76),
#  ('even', 70),
#  ('two', 69),
#  ('squealer', 67),
#  ('everi', 58),
#  ('back', 53),
#  ('round', 52),
#  ('never', 51),
#  ('comrades', 51),
#  ('came', 50),
#  ('snowball', 49),
#  ('clover', 47),
#  ('come', 46),
#  ('moment', 45),
#  ('dog', 44),
#  ('jones', 43),
#  ('long', 41),
#  ('human', 41),
#  ('made', 40),
#  ('old', 40),
#  ('side', 39),
#  ('jone', 39),
#  ('first', 37),
#  ('ever', 37),
#  ('seem', 37),
#  ('windmill', 37),
#  ('men', 36),
#  ('way', 35),
#  ('upon', 35),
#  ('four', 35),
#  ('windmil', 35),
#  ('sheep', 34),
#  ('leg', 34),
#  ('frederick', 34),
#  ('end', 33),
#  ('year', 33),
#  ('make', 33),
#  ('good', 33),
#  ('three', 32),
#  ('benjamin', 31),
#  ('comrad', 30),
#  ('went', 29),
#  ('though', 29),
#  ('say', 29),
#  ('rebellion', 29),
#  ('littl', 29),
#  ('alway', 28),
#  ('live', 28),
#  ('use', 28),
#  ('england', 28),
#  ('go', 28),
#  ('pilkington', 28),
#  ('night', 27),
#  ('last', 27),
#  ('order', 27),
#  ('appear', 27),
#  ('set', 27),
#  ('great', 27),
#  ('yard', 26),
#  ('animals', 26),
#  ('much', 26),
#  ('must', 26),
#  ('read', 26),
#  ('anoth', 26),
#  ('cri', 26),
#  ('without', 25),
#  ('later', 25),
#  ('shall', 25),
#  ('away', 25),
#  ('barn', 24),
#  ('still', 24),
#  ('look', 24),
#  ('well', 24),
#  ('almost', 24),
#  ('better', 24),
#  ('get', 24),
#  ('also', 24),
#  ('found', 24),
#  ('thing', 24),
#  ('word', 23),
#  ('pigs', 23),
#  ('hoof', 23),
#  ('saw', 23),
#  ('week', 23),
#  ('morn', 23),
#  ('life', 22),
#  ('sunday', 22),
#  ('took', 22),
#  ('except', 22),
#  ('mani', 22),
#  ('man', 22),
#  ('might', 22),
#  ('call', 22),
#  ('seen', 22),
#  ('like', 22),
#  ('major', 21),
#  ('began', 21),
#  ('put', 21),
#  ('noth', 21),
#  ('happen', 21),
#  ('field', 21),
#  ('believ', 21),
#  ('hard', 21),
#  ('build', 21),
#  ('command', 21),
#  ('rememb', 20),
#  ('soon', 20),
#  ('usual', 20),
#  ('tail', 20),
#  ('thought', 20),
#  ('us', 20),
#  ('labour', 20),
#  ('turn', 20),
#  ('battl', 20),
#  ('announc', 20),
#  ('meet', 19),
#  ('given', 19),
#  ('place', 19),
#  ('face', 19),
#  ('food', 19),
#  ('know', 19),
#  ('whole', 19),
#  ('gun', 19),
#  ('alreadi', 18),
#  ('name', 18),
#  ('lay', 18),
#  ('wall', 18),
#  ('heard', 18),
#  ('enough', 18),
#  ('done', 18),
#  ('take', 18),
#  ('death', 18),
#  ('seven', 18),
#  ('summer', 18),
#  ('stone', 18),
#  ('hour', 17),
#  ('stall', 17),
#  ('milk', 17),
#  ('see', 17),
#  ('carri', 17),
#  ('suddenli', 17),
#  ('sing', 17),
#  ('hay', 17),
#  ('need', 17),
#  ('right', 17),
#  ('farmhouse', 17),
#  ('farmhous', 17),
#  ('follow', 17),
#  ('white', 16),
#  ('hen', 16),
#  ('among', 16),
#  ('think', 16),
#  ('give', 16),
#  ('young', 16),
#  ('certain', 16),
#  ("'beast", 16),
#  ('past', 16),
#  ('half', 16),
#  ('whymper', 16),
#  ('van', 16),
#  ('bed', 15),
#  ('gone', 15),
#  ('late', 15),
#  ('fact', 15),
#  ('walk', 15),
#  ('hors', 15),
#  ('run', 15),
#  ('yet', 15),
#  ('taken', 15),
#  ('kind', 15),
#  ('however', 15),
#  ('harvest', 15),
#  ('sent', 15),
#  ('learn', 15),
#  ('abl', 15),
#  ('foxwood', 15),
#  ('stood', 15),
#  ('big', 14),
#  ('sleep', 14),
#  ('straw', 14),
#  ('dogs', 14),
#  ('muriel', 14),
#  ('ask', 14),
#  ('someth', 14),
#  ('die', 14),
#  ('race', 14),
#  ('eye', 14),
#  ('drink', 14),
#  ('sinc', 14),
#  ('mind', 14),
#  ('comrade', 14),
#  ('full', 14),
#  ('forward', 14),
#  ('bad', 14),
#  ('terribl', 14),
#  ('small', 13),
#  ('got', 13),
#  ('pass', 13),
#  ('feet', 13),
#  ('others', 13),
#  ('plan', 13),
#  ('fire', 13),
#  ('corn', 13),
#  ('sometim', 13),
#  ('utter', 13),
#  ('willingdon', 12),
#  ('rais', 12),
#  ('pigeon', 12),
#  ('gave', 12),
#  ('beyond', 12),
#  ('speech', 12),
#  ('let', 12),
#  ('rest', 12),
#  ('point', 12),
#  ('legs', 12),
#  ('black', 12),
#  ('talk', 12),
#  ('five', 12),
#  ('written', 12),
#  ('far', 12),
#  ('ground', 12),
#  ('flag', 12),
#  ('green', 12),
#  ('rumour', 12),
#  ('door', 11),
#  ('dream', 11),
#  ('cow', 11),
#  ('beast', 11),
#  ('tremend', 11),
#  ('orchard', 11),
#  ('mollie', 11),
#  ('speak', 11),
#  ('part', 11),
#  ('creatur', 11),
#  ('equal', 11),
#  ('knew', 11),
#  ('known', 11),
#  ('earli', 11),
#  ('next', 11),
#  ('whether', 11),
#  ('harder', 11),
#  ('led', 11),
#  ('news', 11),
#  ('stand', 11),
#  ('remain', 11),
#  ('piec', 11),
#  ('notic', 11),
#  ('pinchfield', 11),
#  ('felt', 11),
#  ('buildings', 10),
#  ('quit', 10),
#  ('behind', 10),
#  ('care', 10),
#  ('hand', 10),
#  ('listen', 10),
#  ('short', 10),
#  ('money', 10),
#  ('ration', 10),
#  ('sure', 10),
#  ('larg', 10),
#  ('vote', 10),
#  ('wear', 10),
#  ('song', 10),
#  ('tune', 10),
#  ('voic', 10),
#  ('complet', 10),
#  ('reason', 10),
#  ('sever', 10),
#  ('sound', 10),
#  ('anyth', 10),
#  ('anyon', 10),
#  ('days', 10),
#  ('broke', 10),
#  ('tri', 10),
#  ('minut', 10),
#  ('success', 10),
#  ('broken', 10),
#  ('rush', 10),
#  ('outsid', 10),
#  ('agreement', 10),
#  ('case', 10),
#  ('none', 10),
#  ('class', 10),
#  ('necessari', 10),
#  ('attack', 10),
#  ('pile', 10),
#  ('winter', 10),
#  ('timber', 10),
#  ('confess', 10),
#  ('light', 9),
#  ('stir', 9),
#  ('hear', 9),
#  ('spite', 9),
#  ('immedi', 9),
#  ('together', 9),
#  ('nearli', 9),
#  ('keep', 9),
#  ('togeth', 9),
#  ('sugar', 9),
#  ('feel', 9),
#  ('understand', 9),
#  ('number', 9),
#  ('horses', 9),
#  ('cows', 9),
#  ('hundr', 9),
#  ('beings', 9),
#  ('hens', 9),
#  ('egg', 9),
#  ('sit', 9),
#  ('spring', 9),
#  ('gener', 9),
#  ('tell', 9),
#  ('save', 9),
#  ('question', 9),
#  ('whatev', 9),
#  ('kill', 9),
#  ('march', 9),
#  ('secret', 9),
#  ('held', 9),
#  ('begin', 9),
#  ('dead', 9),
#  ('molli', 9),
#  ('lie', 9),
#  ('earlier', 9),
#  ('accord', 9),
#  ('flung', 9),
#  ('pastur', 9),
#  ('gaze', 9),
#  ('air', 9),
#  ('paint', 9),
#  ('letter', 9),
#  ('honour', 9),
#  ('finish', 9),
#  ('less', 9),
#  ('nine', 9),
#  ('cowshed', 9),
#  ('close', 9),
#  ('leader', 9),
#  ('manor', 8),
#  ('kick', 8),
#  ('strang', 8),
#  ('front', 8),
#  ('slowli', 8),
#  ('lost', 8),
#  ('find', 8),
#  ('hope', 8),
#  ('ribbon', 8),
#  ('final', 8),
#  ('throughout', 8),
#  ('clear', 8),
#  ('longer', 8),
#  ('singl', 8),
#  ('produc', 8),
#  ('enemi', 8),
#  ('sight', 8),
#  ('trotter', 8),
#  ('mere', 8),
#  ('toward', 8),
#  ('spread', 8),
#  ('new', 8),
#  ('voice', 8),
#  ('difficulti', 8),
#  ('especi', 8),
#  ('told', 8),
#  ('everyth', 8),
#  ('attend', 8),
#  ('farmer', 8),
#  ('world', 8),
#  ('window', 8),
#  ('act', 8),
#  ('hide', 8),
#  ('top', 8),
#  ('yes', 8),
#  ('hold', 8),
#  ('form', 8),
#  ('heart', 8),
#  ('effort', 8),
#  ('inch', 8),
#  ('actual', 8),
#  ('arrang', 8),
#  ('either', 8),
#  ('garden', 8),
#  ('decid', 8),
#  ('prove', 8),
#  ('often', 8),
#  ('bleat', 8),
#  ('watch', 8),
#  ('head', 8),
#  ('receiv', 8),
#  ('drag', 8),
#  ('across', 7),
#  ('comfort', 7),
#  ('nose', 7),
#  ('nevertheless', 7),
#  ('cat', 7),
#  ('present', 7),
#  ('mean', 7),
#  ('free', 7),
#  ('continu', 7),
#  ('bare', 7),
#  ('drop', 7),
#  ('allow', 7),
#  ('bodi', 7),
#  ('years', 7),
#  ('resolut', 7),
#  ('rat', 7),
#  ('friend', 7),
#  ('discov', 7),
#  ('clever', 7),
#  ('animal', 7),
#  ('ran', 7),
#  ('whip', 7),
#  ('barley', 7),
#  ('water', 7),
#  ('foot', 7),
#  ('eyes', 7),
#  ('feed', 7),
#  ('want', 7),
#  ('hedg', 7),
#  ('frighten', 7),
#  ('road', 7),
#  ('gate', 7),
#  ('gallop', 7),
#  ('destroy', 7),
#  ('admir', 7),
#  ('silenc', 7),
#  ('enter', 7),
#  ('six', 7),
#  ('gather', 7),
#  ('cockerel', 7),
#  ('true', 7),
#  ('kept', 7),
#  ('ear', 7),
#  ('indeed', 7),
#  ('twice', 7),
#  ('declar', 7),
#  ('appl', 7),
#  ('manag', 7),
#  ('intend', 7),
#  ('hero', 7),
#  ('detail', 7),
#  ('cover', 7),
#  ('built', 7),
#  ('cold', 7),
#  ('special', 7),
#  ('stop', 7),
#  ('rebuild', 7),
#  ('left', 7),
#  ('glass', 6),
#  ('beer', 6),
#  ('boar', 6),
#  ('agre', 6),
#  ('everyon', 6),
#  ('differ', 6),
#  ('enorm', 6),
#  ('somewhat', 6),
#  ('stupid', 6),
#  ('remark', 6),
#  ('file', 6),
#  ('near', 6),
#  ('throat', 6),
#  ('natur', 6),
#  ('earth', 6),
#  ('forc', 6),
#  ('strength', 6),
#  ('happi', 6),
#  ('simpli', 6),
#  ('support', 6),
#  ('dozen', 6),
#  ('bring', 6),
#  ('cruel', 6),
#  ('within', 6),
#  ('becom', 6),
#  ('futur', 6),
#  ('interest', 6),
#  ('crept', 6),
#  ('hole', 6),
#  ('forgotten', 6),
#  ('words', 6),
#  ('break', 6),
#  ('gees', 6),
#  ('prepar', 6),
#  ('whisk', 6),
#  ('somehow', 6),
#  ('animalism', 6),
#  ('sugarcandi', 6),
#  ('mountain', 6),
#  ('mose', 6),
#  ('accept', 6),
#  ('kitchen', 6),
#  ('store-sh', 6),
#  ('horn', 6),
#  ('flight', 6),
#  ('main', 6),
#  ('trace', 6),
#  ('harness-room', 6),
#  ('open', 6),
#  ('knoll', 6),
#  ('crop', 6),
#  ('grass', 6),
#  ('snuf', 6),
#  ('pool', 6),
#  ('spot', 6),
#  ('matter', 6),
#  ('studi', 6),
#  ('reduc', 6),
#  ('hind', 6),
#  ('direct', 6),
#  ('fro', 6),
#  ('possibl', 6),
#  ('express', 6),
#  ('assembl', 6),
#  ('asid', 6),
#  ('retir', 6),
#  ('afternoon', 6),
#  ('variou', 6),
#  ('besid', 6),
#  ('attempt', 6),
#  ('refus', 6),
#  ('unabl', 6),
#  ('neighbour', 6),
#  ('farms', 6),
#  ('everywhere', 6),
#  ('pellet', 6),
#  ('blood', 6),
#  ('becam', 6),
#  ('weather', 6),
#  ('speeches', 6),
#  ('electr', 6),
#  ('floor', 6),
#  ('move', 6),
#  ('least', 6),
#  ('corner', 6),
#  ('relat', 6),
#  ('protest', 6),
#  ('warn', 6),
#  ('growl', 6),
#  ('quarry', 6),
#  ('terror', 6),
#  ('mrs.', 5),
#  ('middl', 5),
#  ('wish', 5),
#  ('twelv', 5),
#  ('grown', 5),
#  ('perch', 5),
#  ('approach', 5),
#  ('respect', 5),
#  ('donkey', 5),
#  ('instance', 5),
#  ('fli', 5),
#  ('spent', 5),
#  ('fell', 5),
#  ('draw', 5),
#  ('red', 5),
#  ('slept', 5),
#  ('month', 5),
#  ('real', 5),
#  ('scene', 5),
#  ('caus', 5),
#  ('eggs', 5),
#  ('weak', 5),
#  ('plough', 5),
#  ('laid', 5),
#  ('age', 5),
#  ('lead', 5),
#  ('sell', 5),
#  ('grow', 5),
#  ('prosper', 5),
#  ('serv', 5),
#  ('afterward', 5),
#  ('enemy', 5),
#  ('fight', 5),
#  ('alcohol', 5),
#  ('engag', 5),
#  ('sow', 5),
#  ('toil', 5),
#  ('clearli', 5),
#  ('teach', 5),
#  ('argu', 5),
#  ('difficult', 5),
#  ('skip', 5),
#  ('principl', 5),
#  ('master', 5),
#  ('starv', 5),
#  ('spirit', 5),
#  ('exist', 5),
#  ('season', 5),
#  ('grew', 5),
#  ('fallen', 5),
#  ('triumph', 5),
#  ('slip', 5),
#  ('sprang', 5),
#  ('chase', 5),
#  ('five-bar', 5),
#  ('hardli', 5),
#  ('mark', 5),
#  ('mouth', 5),
#  ('inspect', 5),
#  ('halt', 5),
#  ('today', 5),
#  ('write', 5),
#  ('book', 5),
#  ('writing', 5),
#  ('explain', 5),
#  ('wrong', 5),
#  ('loud', 5),
#  ('hours', 5),
#  ('task', 5),
#  ('mix', 5),
#  ('leadership', 5),
#  ('problem', 5),
#  ('nobodi', 5),
#  ('rations', 5),
#  ('leav', 5),
#  ('extra', 5),
#  ('brought', 5),
#  ('committe', 5),
#  ('leagu', 5),
#  ('immediately', 5),
#  ('effect', 5),
#  ('start', 5),
#  ('tire', 5),
#  ('instruct', 5),
#  ('stori', 5),
#  ('secretli', 5),
#  ('idea', 5),
#  ('rage', 5),
#  ('ahead', 5),
#  ('deal', 5),
#  ('hedge', 5),
#  ('line', 5),
#  ('shout', 5),
#  ('skull', 5),
#  ('stretch', 5),
#  ('oper', 5),
#  ('warm', 5),
#  ('increas', 5),
#  ('bound', 5),
#  ('sat', 5),
#  ('silent', 5),
#  ('previous', 5),
#  ('privat', 5),
#  ('expuls', 5),
#  ('deep', 5),
#  ("o'clock", 5),
#  ('fill', 5),
#  ('finally', 5),
#  ('meal', 5),
#  ('beds', 5),
#  ('rule', 5),
#  ('mill', 5),
#  ('traitor', 5),
#  ('pronounc', 5),
#  ('thick', 5),
#  ('th', 5),
#  ('plot', 5),
#  ('execut', 5),
#  ('disappear', 5),
#  ('pension', 5),
#  ('victory', 5),
#  ('perhap', 5),
#  ('bought', 5),
#  ('toast', 5),
#  ('shut', 4),
#  ('lantern', 4),
#  ('drew', 4),
#  ('flutter', 4),
#  ('readi', 4),
#  ('lose', 4),
#  ('platform', 4),
#  ('stout', 4),
#  ('cut', 4),
#  ('chew', 4),
#  ('mare', 4),
#  ('figur', 4),
#  ('strong', 4),
#  ('power', 4),
#  ('sooner', 4),
#  ('alon', 4),
#  ('devot', 4),
#  ('speaking', 4),
#  ('insid', 4),
#  ('promptli', 4),
#  ('foolish', 4),
#  ('lump', 4),
#  ('mane', 4),
#  ('moses', 4),
#  ('tame', 4),
#  ('raven', 4),
#  ('wait', 4),
#  ('duti', 4),
#  ('breath', 4),
#  ('instant', 4),
#  ('truth', 4),
#  ('land', 4),
#  ('soil', 4),
#  ('greater', 4),
#  ('twenti', 4),
#  ('digniti', 4),
#  ('answer', 4),
#  ('till', 4),
#  ('sold', 4),
#  ('return', 4),
#  ('fields', 4),
#  ('reach', 4),
#  ('muscl', 4),
#  ('knacker', 4),
#  ('rich', 4),
#  ('struggl', 4),
#  ('remember', 4),
#  ('dash', 4),
#  ('repeat', 4),
#  ('goe', 4),
#  ('adopt', 4),
#  ('house', 4),
#  ('trade', 4),
#  ('remind', 4),
#  ('sung', 4),
#  ('memori', 4),
#  ('coming', 4),
#  ('wheat', 4),
#  ('blow', 4),
#  ('peac', 4),
#  ('organis', 4),
#  ('best', 4),
#  ('fat', 4),
#  ('shrill', 4),
#  ('met', 4),
#  ('contrari', 4),
#  ('worth', 4),
#  ('mysteri', 4),
#  ('hate', 4),
#  ('achiev', 4),
#  ('occasion', 4),
#  ('drawing-room', 4),
#  ('help', 4),
#  ('lash', 4),
#  ('hungri', 4),
#  ('happening', 4),
#  ('possess', 4),
#  ('meanwhil', 4),
#  ('rubbish', 4),
#  ('wore', 4),
#  ('happened', 4),
#  ('excitement', 4),
#  ('hayfield', 4),
#  ('shoulder', 4),
#  ('fear', 4),
#  ('breakfast', 4),
#  ('ladder', 4),
#  ('commandments', 4),
#  ('inscrib', 4),
#  ('law', 4),
#  ('mash', 4),
#  ('bigger', 4),
#  ('understood', 4),
#  ('busi', 4),
#  ('supervis', 4),
#  ('needed', 4),
#  ('regular', 4),
#  ('excel', 4),
#  ('imposs', 4),
#  ('fail', 4),
#  ('hoist', 4),
#  ('flagstaff', 4),
#  ('object', 4),
#  ('product', 4),
#  ('treat', 4),
#  ('roof', 4),
#  ('autumn', 4),
#  ('maxim', 4),
#  ('bird', 4),
#  ('forth', 4),
#  ('collect', 4),
#  ('surely', 4),
#  ('whose', 4),
#  ('wonder', 4),
#  ('pretend', 4),
#  ('rapidli', 4),
#  ('chang', 4),
#  ('fulli', 4),
#  ('speed', 4),
#  ('charg', 4),
#  ('second', 4),
#  ('stick', 4),
#  ('signal', 4),
#  ('fled', 4),
#  ('rear', 4),
#  ('straight', 4),
#  ('iron', 4),
#  ('exclaim', 4),
#  ('somebody', 4),
#  ('alarm', 4),
#  ('celebr', 4),
#  ('times', 4),
#  ('solemn', 4),
#  ('realli', 4),
#  ('stroke', 4),
#  ('enjoy', 4),
#  ('mention', 4),
#  ('violent', 4),
#  ('complic', 4),
#  ('dynamo', 4),
#  ('shed', 4),
#  ('plans', 4),
#  ('lift', 4),
#  ('wast', 4),
#  ('cowsh', 4),
#  ('determin', 4),
#  ('spoken', 4),
#  ('doubt', 4),
#  ('huge', 4),
#  ('shock', 4),
#  ('thoughts', 4),
#  ('heavi', 4),
#  ('compos', 4),
#  ('realiti', 4),
#  ('beginning', 4),
#  ('meant', 4),
#  ('spoke', 4),
#  ('store', 4),
#  ('boulder', 4),
#  ('machineri', 4),
#  ('onward', 4),
#  ('visit', 4),
#  ('convinc', 4),
#  ('roar', 4),
#  ('potato', 4),
#  ('grain', 4),
#  ('decre', 4),
#  ('smell', 4),
#  ('ad', 4),
#  ('teeth', 4),
#  ('wors', 4),
#  ('agent', 4),
#  ('remembered', 4),
#  ('burst', 4),
#  ('paper', 4),
#  ('belli', 4),
#  ('deadli', 4),
#  ('paid', 4),
#  ('compani', 4),
#  ('mug', 4),
#  ('gentlemen', 4),
#  ('ring', 3),
#  ('bedroom', 3),
#  ('previou', 3),
#  ('rather', 3),
#  ('arriv', 3),
#  ('bluebell', 3),
#  ('settl', 3),
#  ('fourth', 3),
#  ('high', 3),
#  ('seldom', 3),
#  ('laugh', 3),
#  ('admit', 3),
#  ('paddock', 3),
#  ('graze', 3),
#  ('mother', 3),
#  ('asleep', 3),
#  ('els', 3),
#  ('living', 3),
#  ('capabl', 3),
#  ('slaughter', 3),
#  ('leisur', 3),
#  ('thousand', 3),
#  ('miser', 3),
#  ('stolen', 3),
#  ('abolish', 3),
#  ('pull', 3),
#  ('catch', 3),
#  ('prevent', 3),
#  ('dung', 3),
#  ('enemies', 3),
#  ('market', 3),
#  ('block', 3),
#  ('everyone', 3),
#  ('boil', 3),
#  ('neck', 3),
#  ('evil', 3),
#  ('messag', 3),
#  ('beneath', 3),
#  ('lives', 3),
#  ('argument', 3),
#  ('lies', 3),
#  ('perfect', 3),
#  ('uproar', 3),
#  ('caught', 3),
#  ('silence', 3),
#  ('wild', 3),
#  ('wings', 3),
#  ('clothes', 3),
#  ('smoke', 3),
#  ('simple', 3),
#  ('ago', 3),
#  ('taught', 3),
#  ('sang', 3),
#  ('joy', 3),
#  ('tide', 3),
#  ('fruit', 3),
#  ('vanish', 3),
#  ('buri', 3),
#  ('sale', 3),
#  ('fierce-look', 3),
#  ('talker', 3),
#  ('consid', 3),
#  ('refer', 3),
#  ('situat', 3),
#  ('somewher', 3),
#  ('sky', 3),
#  ('distanc', 3),
#  ('hedges', 3),
#  ('tale', 3),
#  ('faith', 3),
#  ('easili', 3),
#  ('expected', 3),
#  ('woke', 3),
#  ('hands', 3),
#  ('bear', 3),
#  ('defend', 3),
#  ('thrown', 3),
#  ('fetch', 3),
#  ('hat', 3),
#  ('everybody', 3),
#  ('gambol', 3),
#  ('roll', 3),
#  ('tour', 3),
#  ('survey', 3),
#  ('spinney', 3),
#  ('disturb', 3),
#  ('anything', 3),
#  ('room', 3),
#  ('manner', 3),
#  ('outside', 3),
#  ('hang', 3),
#  ('hous', 3),
#  ('unanim', 3),
#  ('spell', 3),
#  ('neatli', 3),
#  ('correct', 3),
#  ('benefit', 3),
#  ('nod', 3),
#  ('fairli', 3),
#  ('consider', 3),
#  ('disappeared', 3),
#  ('sweat', 3),
#  ('assum', 3),
#  ('course', 3),
#  ('duck', 3),
#  ('sun', 3),
#  ('moreover', 3),
#  ('sharp', 3),
#  ('eat', 3),
#  ('style', 3),
#  ('thresh', 3),
#  ('worker', 3),
#  ('mighti', 3),
#  ('push', 3),
#  ('else', 3),
#  ('bushel', 3),
#  ('stole', 3),
#  ('quarrel', 3),
#  ('mornings', 3),
#  ('reappear', 3),
#  ('slow', 3),
#  ('observ', 3),
#  ('debates', 3),
#  ('oppos', 3),
#  ('debat', 3),
#  ('clean', 3),
#  ('sparrow', 3),
#  ('paw', 3),
#  ('distance', 3),
#  ('alphabet', 3),
#  ('b', 3),
#  ('forelock', 3),
#  ('contain', 3),
#  ('thoroughli', 3),
#  ('develop', 3),
#  ('import', 3),
#  ('litter', 3),
#  ('share', 3),
#  ('explan', 3),
#  ('cried', 3),
#  ('imagine', 3),
#  ('dislik', 3),
#  ('sole', 3),
#  ('health', 3),
#  ...]

# %%
# let's make new list only with words whose frequency  > 25

moreThan10_freq = []

for i,j in f_list_new[0].items():
    if j >= 10:
        moreThan10_freq.append(i)

# %%
# 頻出単語top2のgameshとsaidが同時に現れる文を、ピックアップしカウントするプログラムを全ての単語に割り当てる試み。

count_s = {}

for wn1 in range(0, len(moreThan10_freq)-1):
    for wn2 in range(wn1+1, len(moreThan10_freq)):
        s = 0
    
        for sent in form_sent2:
            index1 = 0
            index2 = 0
            
            #remove duplicate
            if moreThan10_freq[wn1] != moreThan10_freq[wn2]:
                
                if moreThan10_freq[wn1] in sent.split():
                    index1 += 1
                if moreThan10_freq[wn2] in sent.split():
                    index2 += 1
              
                if index1 > 0 and index2 > 0:
                    s += 1
                
        count_s.update({( moreThan10_freq[wn1], moreThan10_freq[wn2]) :s })

# %%
#順位チェック
sorted(count_s.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('farm', 'anim'), 69),
#  (('anim', 'napoleon'), 31),
#  (('anim', 'work'), 30),
#  (('anim', 'would'), 26),
#  (('napoleon', 'comrad'), 24),
#  (('anim', 'could'), 23),
#  (('anim', 'time'), 21),
#  (('work', 'would'), 20),
#  (('one', 'anim'), 19),
#  (('farm', 'would'), 17),
#  (('pig', 'anim'), 17),
#  (('anim', 'snowbal'), 17),
#  (('never', 'anim'), 16),
#  (('england', "'beast"), 16),
#  (('snowbal', 'napoleon'), 16),
#  (('farm', 'work'), 15),
#  (('anim', 'ever'), 15),
#  (('boxer', 'clover'), 15),
#  (('dog', 'napoleon'), 15),
#  (('pig', 'napoleon'), 14),
#  (('anim', 'everi'), 14),
#  (('anim', 'even'), 14),
#  (('two', 'leg'), 14),
#  (('boxer', 'said'), 14),
#  (('farm', 'snowbal'), 13),
#  (('day', 'anim'), 13),
#  (('would', 'time'), 13),
#  (('would', 'napoleon'), 13),
#  (('good', 'four'), 13),
#  (('farm', 'pig'), 12),
#  (('day', 'one'), 12),
#  (('day', 'work'), 12),
#  (('order', 'anim'), 12),
#  (('one', 'would'), 12),
#  (('anim', 'two'), 12),
#  (('anim', 'human'), 12),
#  (('two', 'good'), 12),
#  (('two', 'four'), 12),
#  (('boxer', 'hoof'), 12),
#  (('good', 'leg'), 12),
#  (('four', 'leg'), 12),
#  (('farm', 'one'), 11),
#  (('farm', 'napoleon'), 11),
#  (('back', 'anim'), 11),
#  (('round', 'anim'), 11),
#  (('pig', 'work'), 11),
#  (('long', 'anim'), 11),
#  (('anim', 'first'), 11),
#  (('anim', 'set'), 11),
#  (('anim', 'england'), 11),
#  (('anim', 'snowball'), 11),
#  (('anim', 'seem'), 11),
#  (('boxer', 'napoleon'), 11),
#  (('would', 'said'), 11),
#  (('time', 'napoleon'), 11),
#  (('even', 'napoleon'), 11),
#  (('said', 'napoleon'), 11),
#  (('napoleon', 'snowball'), 11),
#  (('napoleon', 'announc'), 11),
#  (('yard', 'anim'), 10),
#  (('back', 'jone'), 10),
#  (('big', 'barn'), 10),
#  (('one', 'napoleon'), 10),
#  (('appear', 'napoleon'), 10),
#  (('anim', 'sheep'), 10),
#  (('anim', 'shall'), 10),
#  (('anim', 'week'), 10),
#  (('anim', 'squealer'), 10),
#  (('anim', 'frederick'), 10),
#  (('two', 'would'), 10),
#  (('two', 'napoleon'), 10),
#  (('two', 'bad'), 10),
#  (('work', 'hard'), 10),
#  (('napoleon', 'squealer'), 10),
#  (('seven', 'command'), 10),
#  (('pilkington', 'frederick'), 10),
#  (('farm', 'buildings'), 9),
#  (('farm', 'human'), 9),
#  (('farm', 'pilkington'), 9),
#  (('farm', 'windmill'), 9),
#  (('made', 'anim'), 9),
#  (('round', 'pig'), 9),
#  (('round', 'napoleon'), 9),
#  (('day', 'would'), 9),
#  (('day', 'later'), 9),
#  (('day', 'everi'), 9),
#  (('barn', 'anim'), 9),
#  (('alway', 'napoleon'), 9),
#  (('order', 'napoleon'), 9),
#  (('say', 'would'), 9),
#  (('one', 'even'), 9),
#  (('long', 'live'), 9),
#  (('anim', 'came'), 9),
#  (('anim', 'boxer'), 9),
#  (('anim', 'come'), 9),
#  (('anim', 'live'), 9),
#  (('anim', 'must'), 9),
#  (('anim', 'said'), 9),
#  (('anim', 'also'), 9),
#  (('anim', 'certain'), 9),
#  (('anim', 'call'), 9),
#  (('first', 'time'), 9),
#  (('sheep', 'two'), 9),
#  (('set', 'work'), 9),
#  (('work', 'even'), 9),
#  (('work', 'napoleon'), 9),
#  (('work', 'harder'), 9),
#  (('would', 'human'), 9),
#  (('would', 'announc'), 9),
#  (('sunday', 'morn'), 9),
#  (('good', 'bad'), 9),
#  (('everi', 'napoleon'), 9),
#  (('four', 'bad'), 9),
#  (('said', 'squealer'), 9),
#  (('leg', 'bad'), 9),
#  (('napoleon', 'frederick'), 9),
#  (('jones', 'day'), 8),
#  (('farm', 'back'), 8),
#  (('farm', 'made'), 8),
#  (('farm', 'never'), 8),
#  (('farm', 'time'), 8),
#  (('farm', 'everi'), 8),
#  (('farm', 'even'), 8),
#  (('farm', 'could'), 8),
#  (('farm', 'said'), 8),
#  (('farm', 'build'), 8),
#  (('farm', 'pinchfield'), 8),
#  (('farm', 'frederick'), 8),
#  (('rememb', 'anim'), 8),
#  (('jone', 'anim'), 8),
#  (('jone', 'men'), 8),
#  (('day', 'time'), 8),
#  (('old', 'benjamin'), 8),
#  (('still', 'anim'), 8),
#  (('pig', 'dog'), 8),
#  (('anim', 'much'), 8),
#  (('anim', 'littl'), 8),
#  (('anim', 'equal'), 8),
#  (('anim', 'field'), 8),
#  (('anim', 'believ'), 8),
#  (('anim', 'anoth'), 8),
#  (('two', 'boxer'), 8),
#  (('clover', 'benjamin'), 8),
#  (('would', 'come'), 8),
#  (('would', 'live'), 8),
#  (('would', 'everi'), 8),
#  (('would', 'even'), 8),
#  (('would', 'could'), 8),
#  (('would', 'need'), 8),
#  (('would', 'windmill'), 8),
#  (('well', 'napoleon'), 8),
#  (('could', 'said'), 8),
#  (('napoleon', 'right'), 8),
#  (('napoleon', 'pilkington'), 8),
#  (('napoleon', 'whymper'), 8),
#  (('jones', 'time'), 7),
#  (('farm', 'though'), 7),
#  (('farm', 'name'), 7),
#  (('farm', 'place'), 7),
#  (('farm', 'live'), 7),
#  (('farm', 'ever'), 7),
#  (('farm', 'squealer'), 7),
#  (('farm', 'foxwood'), 7),
#  (('back', 'boxer'), 7),
#  (('back', 'napoleon'), 7),
#  (('made', 'would'), 7),
#  (('way', 'anim'), 7),
#  (('old', 'major'), 7),
#  (('barn', 'end'), 7),
#  (('one', 'work'), 7),
#  (('one', 'said'), 7),
#  (('end', 'anim'), 7),
#  (('pig', 'time'), 7),
#  (('pig', 'four'), 7),
#  (('pig', 'young'), 7),
#  (('never', 'could'), 7),
#  (('anim', 'began'), 7),
#  (('anim', 'without'), 7),
#  (('anim', 'moment'), 7),
#  (('anim', 'speech'), 7),
#  (('anim', 'heard'), 7),
#  (('anim', 'use'), 7),
#  (('anim', 'labour'), 7),
#  (('anim', 'men'), 7),
#  (('anim', 'dog'), 7),
#  (('anim', 'morn'), 7),
#  (('anim', 'thing'), 7),
#  (('anim', 'command'), 7),
#  (('anim', 'pilkington'), 7),
#  (('anim', 'windmill'), 7),
#  (('sheep', 'good'), 7),
#  (('sheep', 'four'), 7),
#  (('sheep', 'leg'), 7),
#  (('boxer', 'work'), 7),
#  (('boxer', 'would'), 7),
#  (('boxer', 'even'), 7),
#  (('work', 'everi'), 7),
#  (('would', 'well'), 7),
#  (('moment', 'napoleon'), 7),
#  (('england', 'sing'), 7),
#  (('upon', 'napoleon'), 7),
#  (('even', 'could'), 7),
#  (('could', 'done'), 7),
#  (('napoleon', 'seem'), 7),
#  (('build', 'windmill'), 7),
#  (('fire', 'gun'), 7),
#  (('foxwood', 'pilkington'), 7),
#  (('jones', 'snowbal'), 6),
#  (('farm', 'round'), 6),
#  (('farm', 'long'), 6),
#  (('farm', 'make'), 6),
#  (('farm', 'come'), 6),
#  (('farm', 'anoth'), 6),
#  (('farm', 'go'), 6),
#  (('farm', 'summer'), 6),
#  (('side', 'tail'), 6),
#  (('back', 'came'), 6),
#  (('made', 'napoleon'), 6),
#  (('bed', 'sleep'), 6),
#  (('went', 'anim'), 6),
#  (('word', 'anim'), 6),
#  (('round', 'walk'), 6),
#  (('round', 'would'), 6),
#  (('day', 'pig'), 6),
#  (('day', 'three'), 6),
#  (('day', 'clover'), 6),
#  (('day', 'squealer'), 6),
#  (('meet', 'barn'), 6),
#  (('alway', 'right'), 6),
#  (('though', 'anim'), 6),
#  (('sleep', 'anim'), 6),
#  (('one', 'never'), 6),
#  (('one', 'time'), 6),
#  (('one', 'anoth'), 6),
#  (('end', 'would'), 6),
#  (('end', 'seven'), 6),
#  (('year', 'anim'), 6),
#  (('pig', 'dogs'), 6),
#  (('pig', 'sheep'), 6),
#  (('never', 'boxer'), 6),
#  (('never', 'time'), 6),
#  (('long', 'time'), 6),
#  (('anim', 'given'), 6),
#  (('anim', 'among'), 6),
#  (('anim', 'took'), 6),
#  (('anim', 'except'), 6),
#  (('anim', 'later'), 6),
#  (('anim', 'mani'), 6),
#  (('anim', 'yet'), 6),
#  (('anim', 'rebellion'), 6),
#  (('anim', 'kind'), 6),
#  (('anim', 'sing'), 6),
#  (('anim', 'complet'), 6),
#  (('anim', 'turn'), 6),
#  (('anim', 'talk'), 6),
#  (('anim', 'past'), 6),
#  (('anim', 'build'), 6),
#  (('anim', 'news'), 6),
#  (('anim', 'like'), 6),
#  (('anim', 'go'), 6),
#  (('anim', 'outsid'), 6),
#  (('anim', 'class'), 6),
#  (('make', 'would'), 6),
#  (('make', 'napoleon'), 6),
#  (('came', 'boxer'), 6),
#  (('sheep', 'bad'), 6),
#  (('two', 'everi'), 6),
#  (('boxer', 'benjamin'), 6),
#  (('boxer', 'take'), 6),
#  (('hoof', 'great'), 6),
#  (('work', 'come'), 6),
#  (('work', 'human'), 6),
#  (('muriel', 'read'), 6),
#  (('would', 'might'), 6),
#  (('would', 'go'), 6),
#  (('would', 'windmil'), 6),
#  (('sunday', 'napoleon'), 6),
#  (('moment', 'men'), 6),
#  (('moment', 'snowball'), 6),
#  (('speech', 'napoleon'), 6),
#  (('comrades', 'said'), 6),
#  (('everi', 'said'), 6),
#  (('everi', 'morn'), 6),
#  (('young', 'napoleon'), 6),
#  (('could', 'read'), 6),
#  (('week', 'napoleon'), 6),
#  (('said', 'snowball'), 6),
#  (('said', 'frederick'), 6),
#  (('sing', "'beast"), 6),
#  (('napoleon', 'black'), 6),
#  (('napoleon', 'cri'), 6),
#  (('napoleon', 'stood'), 6),
#  (('squealer', 'cri'), 6),
#  (('squealer', 'abl'), 6),
#  (('jones', 'farm'), 5),
#  (('jones', 'anim'), 5),
#  (('jones', 'gun'), 5),
#  (('farm', 'way'), 5),
#  (('farm', 'animals'), 5),
#  (('farm', 'order'), 5),
#  (('farm', 'first'), 5),
#  (('farm', 'boxer'), 5),
#  (('farm', 'set'), 5),
#  (('farm', 'without'), 5),
#  (('farm', 'whole'), 5),
#  (('farm', 'certain'), 5),
#  (('farm', 'attack'), 5),
#  (('night', 'major'), 5),
#  (('night', 'came'), 5),
#  (('night', 'work'), 5),
#  (('side', 'see'), 5),
#  (('back', 'made'), 5),
#  (('back', 'set'), 5),
#  (('back', 'work'), 5),
#  (('back', 'come'), 5),
#  (('back', 'even'), 5),
#  (('door', 'anim'), 5),
#  (('last', 'came'), 5),
#  (('made', 'round'), 5),
#  (('made', 'day'), 5),
#  (('made', 'squealer'), 5),
#  (('jone', 'come'), 5),
#  (('soon', 'napoleon'), 5),
#  (('buildings', 'anim'), 5),
#  (('round', 'dog'), 5),
#  (('round', 'squealer'), 5),
#  (('day', 'came'), 5),
#  (('day', 'boxer'), 5),
#  (('day', 'shall'), 5),
#  (('day', 'labour'), 5),
#  (('day', 'even'), 5),
#  (('day', 'better'), 5),
#  (('day', 'hay'), 5),
#  (('day', 'napoleon'), 5),
#  (('day', 'snowball'), 5),
#  (('day', 'seem'), 5),
#  (('old', 'year'), 5),
#  (('animals', 'anim'), 5),
#  (('meet', 'anim'), 5),
#  (('big', 'end'), 5),
#  (('barn', 'seven'), 5),
#  (('alway', 'pig'), 5),
#  (('alway', 'boxer'), 5),
#  (('though', 'one'), 5),
#  (('hour', 'would'), 5),
#  (('order', 'one'), 5),
#  (('order', 'would'), 5),
#  (('say', 'anim'), 5),
#  (('say', 'time'), 5),
#  (('say', 'napoleon'), 5),
#  (('one', 'clover'), 5),
#  (('one', 'except'), 5),
#  (('one', 'squealer'), 5),
#  (('end', 'two'), 5),
#  (('straw', 'stall'), 5),
#  (('year', 'work'), 5),
#  (('late', 'summer'), 5),
#  (('pig', 'mani'), 5),
#  (('pig', 'farmhous'), 5),
#  (('pig', 'seem'), 5),
#  (('never', 'work'), 5),
#  (('long', 'napoleon'), 5),
#  (('anim', 'three'), 5),
#  (('anim', 'walk'), 5),
#  (('anim', 'benjamin'), 5),
#  (('anim', 'saw'), 5),
#  (('anim', 'sunday'), 5),
#  (('anim', 'think'), 5),
#  (('anim', 'comrades'), 5),
#  (('anim', 'pass'), 5),
#  (('anim', 'know'), 5),
#  (('anim', 'good'), 5),
#  (('anim', 'might'), 5),
#  (('anim', 'drink'), 5),
#  (('anim', 'sinc'), 5),
#  (('anim', 'seven'), 5),
#  (('anim', 'hard'), 5),
#  (('anim', "'beast"), 5),
#  (('anim', 'agreement'), 5),
#  (('anim', 'learn'), 5),
#  (('anim', 'cri'), 5),
#  (('anim', 'comrad'), 5),
#  (('anim', 'half'), 5),
#  (('anim', 'flag'), 5),
#  (('anim', 'green'), 5),
#  (('anim', 'terribl'), 5),
#  (('anim', 'announc'), 5),
#  (('first', 'could'), 5),
#  (('first', 'snowbal'), 5),
#  (('first', 'napoleon'), 5),
#  (('came', 'dog'), 5),
#  (('came', 'napoleon'), 5),
#  (('two', 'moment'), 5),
#  (('two', 'dog'), 5),
#  (('two', 'better'), 5),
#  (('two', 'snowbal'), 5),
#  (('boxer', 'great'), 5),
#  (('boxer', 'without'), 5),
#  (('boxer', 'time'), 5),
#  (('boxer', 'could'), 5),
#  (('boxer', 'away'), 5),
#  (('hoof', 'would'), 5),
#  (('great', 'would'), 5),
#  (('beast', 'england'), 5),
#  (('hors', 'even'), 5),
#  (('work', 'time'), 5),
#  (('work', 'labour'), 5),
#  (('work', 'could'), 5),
#  (('work', 'week'), 5),
#  (('work', 'seem'), 5),
#  (('muriel', 'benjamin'), 5),
#  (('usual', 'napoleon'), 5),
#  (('would', 'ask'), 5),
#  (('would', 'listen'), 5),
#  (('would', 'later'), 5),
#  (('would', 'happen'), 5),
#  (('would', 'get'), 5),
#  (('would', 'also'), 5),
#  (('would', 'field'), 5),
#  (('would', 'morn'), 5),
#  (('noth', 'time'), 5),
#  (('noth', 'could'), 5),
#  (('sunday', 'everi'), 5),
#  (('sunday', 'announc'), 5),
#  (('wall', 'command'), 5),
#  (('moment', 'four'), 5),
#  (('moment', 'next'), 5),
#  (('think', 'could'), 5),
#  (('time', 'could'), 5),
#  (('time', 'seem'), 5),
#  (('let', 'dog'), 5),
#  (('live', 'napoleon'), 5),
#  (('upon', 'call'), 5),
#  (('human', 'could'), 5),
#  (('human', 'race'), 5),
#  (('ever', 'must'), 5),
#  (('everi', 'could'), 5),
#  (('men', 'frederick'), 5),
#  (('four', 'napoleon'), 5),
#  (('even', 'better'), 5),
#  (('even', 'squealer'), 5),
#  (('even', 'seen'), 5),
#  (('get', 'could'), 5),
#  (('could', 'squealer'), 5),
#  (('said', 'snowbal'), 5),
#  (('call', 'napoleon'), 5),
#  (('take', 'away'), 5),
#  (('snowbal', 'battl'), 5),
#  (('snowbal', 'windmill'), 5),
#  (('napoleon', 'death'), 5),
#  (('napoleon', 'agreement'), 5),
#  (('napoleon', 'follow'), 5),
#  (('napoleon', 'pile'), 5),
#  (('napoleon', 'confess'), 5),
#  (('flag', 'green'), 5),
#  (('foxwood', 'pinchfield'), 5),
#  (('pinchfield', 'frederick'), 5),
#  (('pile', 'timber'), 5),
#  (('jones', 'back'), 4),
#  (('jones', 'old'), 4),
#  (('jones', 'one'), 4),
#  (('jones', 'work'), 4),
#  (('jones', 'human'), 4),
#  (('jones', 'even'), 4),
#  (('jones', 'better'), 4),
#  (('jones', 'napoleon'), 4),
#  (('jones', 'past'), 4),
#  (('jones', 'battl'), 4),
#  (('farm', 'night'), 4),
#  (('farm', 'jone'), 4),
#  (('farm', 'day'), 4),
#  (('farm', 'willingdon'), 4),
#  (('farm', 'say'), 4),
#  (('farm', 'end'), 4),
#  (('farm', 'year'), 4),
#  (('farm', 'still'), 4),
#  (('farm', 'came'), 4),
#  (('farm', 'pigs'), 4),
#  (('farm', 'sheep'), 4),
#  (('farm', 'hors'), 4),
#  (('farm', 'heard'), 4),
#  (('farm', 'mani'), 4),
#  (('farm', 'much'), 4),
#  (('farm', 'happen'), 4),
#  (('farm', 'get'), 4),
#  (('farm', 'also'), 4),
#  (('farm', 'call'), 4),
#  (('farm', 'like'), 4),
#  (('farm', 'outsid'), 4),
#  (('farm', 'away'), 4),
#  (('farm', 'rumour'), 4),
#  (('farm', 'whymper'), 4),
#  (('night', 'last'), 4),
#  (('night', 'dream'), 4),
#  (('side', 'anim'), 4),
#  (('side', 'littl'), 4),
#  (('yard', 'back'), 4),
#  (('yard', 'round'), 4),
#  (('yard', 'one'), 4),
#  (('yard', 'moment'), 4),
#  (('yard', 'rush'), 4),
#  (('back', 'door'), 4),
#  (('back', 'went'), 4),
#  (('back', 'got'), 4),
#  (('back', 'face'), 4),
#  (('back', 'snowbal'), 4),
#  (('made', 'alreadi'), 4),
#  (('made', 'work'), 4),
#  (('way', 'round'), 4),
#  (('way', 'one'), 4),
#  (('way', 'napoleon'), 4),
#  (('bed', 'straw'), 4),
#  (('jone', 'would'), 4),
#  (('jone', 'use'), 4),
#  (('soon', 'anim'), 4),
#  (('went', 'end'), 4),
#  (('went', 'without'), 4),
#  (('went', 'napoleon'), 4),
#  (('word', 'round'), 4),
#  (('word', 'without'), 4),
#  (('word', 'england'), 4),
#  (('round', 'old'), 4),
#  (('round', 'one'), 4),
#  (('round', 'clover'), 4),
#  (('round', 'look'), 4),
#  (('round', 'even'), 4),
#  (('day', 'old'), 4),
#  (('day', 'england'), 4),
#  (('day', 'upon'), 4),
#  (('day', 'whole'), 4),
#  (('day', 'yet'), 4),
#  (('day', 'anoth'), 4),
#  (('old', 'clover'), 4),
#  (('old', 'time'), 4),
#  (('major', 'speech'), 4),
#  (('barn', 'two'), 4),
#  (('barn', 'wall'), 4),
#  (('barn', 'command'), 4),
#  (('alway', 'work'), 4),
#  (('though', 'sheep'), 4),
#  (('though', 'would'), 4),
#  (('though', 'even'), 4),
#  (('name', 'pig'), 4),
#  (('name', 'anim'), 4),
#  (('name', 'napoleon'), 4),
#  (('hour', 'work'), 4),
#  (('order', 'week'), 4),
#  (('say', 'someth'), 4),
#  (('one', 'began'), 4),
#  (('one', 'pigs'), 4),
#  (('one', 'sunday'), 4),
#  (('one', 'come'), 4),
#  (('one', 'comrad'), 4),
#  (('end', 'wall'), 4),
#  (('end', 'come'), 4),
#  (('end', 'napoleon'), 4),
#  (('end', 'command'), 4),
#  (('rais', 'napoleon'), 4),
#  (('year', 'mani'), 4),
#  (('year', 'past'), 4),
#  (('late', 'anim'), 4),
#  (('pig', 'appear'), 4),
#  (('pig', 'three'), 4),
#  (('pig', 'boxer'), 4),
#  (('pig', 'set'), 4),
#  (('pig', 'put'), 4),
#  (('pig', 'would'), 4),
#  (('pig', 'use'), 4),
#  (('pig', 'everi'), 4),
#  (('pig', 'even'), 4),
#  (('pig', 'snowbal'), 4),
#  (('pig', 'squealer'), 4),
#  (('appear', 'never'), 4),
#  (('appear', 'anim'), 4),
#  (('appear', 'dog'), 4),
#  (('never', 'would'), 4),
#  (('never', 'even'), 4),
#  (('never', 'napoleon'), 4),
#  (('long', 'boxer'), 4),
#  (('long', 'benjamin'), 4),
#  (('anim', 'make'), 4),
#  (('anim', 'great'), 4),
#  (('anim', 'small'), 4),
#  (('anim', 'got'), 4),
#  (('anim', 'hors'), 4),
#  (('anim', 'put'), 4),
#  (('anim', 'gave'), 4),
#  (('anim', 'noth'), 4),
#  (('anim', 'place'), 4),
#  (('anim', 'thought'), 4),
#  (('anim', 'well'), 4),
#  (('anim', 'face'), 4),
#  (('anim', 'food'), 4),
#  (('anim', 'give'), 4),
#  (('anim', 'rest'), 4),
#  (('anim', 'get'), 4),
#  (('anim', 'race'), 4),
#  (('anim', 'wear'), 4),
#  (('anim', 'tune'), 4),
#  (('anim', 'reason'), 4),
#  (('anim', 'death'), 4),
#  (('anim', 'need'), 4),
#  (('anim', 'harder'), 4),
#  (('anim', 'anyth'), 4),
#  (('anim', 'read'), 4),
#  (('anim', 'stand'), 4),
#  (('anim', 'found'), 4),
#  (('anim', 'minut'), 4),
#  (('anim', 'right'), 4),
#  (('anim', 'rush'), 4),
#  (('anim', 'sometim'), 4),
#  (('anim', 'notic'), 4),
#  (('anim', 'abl'), 4),
#  (('anim', 'case'), 4),
#  (('anim', 'battl'), 4),
#  (('anim', 'stood'), 4),
#  (('make', 'men'), 4),
#  (('make', 'might'), 4),
#  (('make', 'squealer'), 4),
#  (('first', 'came'), 4),
#  (('first', 'human'), 4),
#  (('first', 'class'), 4),
#  (('came', 'clover'), 4),
#  (('came', 'moment'), 4),
#  (('came', 'even'), 4),
#  (('came', 'news'), 4),
#  (('three', 'two'), 4),
#  (('three', 'time'), 4),
#  (('three', 'past'), 4),
#  (('pigs', 'work'), 4),
#  (('hen', 'napoleon'), 4),
#  (('hen', 'five'), 4),
#  (('sheep', 'cow'), 4),
#  (('sheep', 'lay'), 4),
#  (('sheep', 'even'), 4),
#  (('sheep', 'broke'), 4),
#  (('cow', 'milk'), 4),
#  (('two', 'work'), 4),
#  (('two', 'usual'), 4),
#  (('two', 'upon'), 4),
#  (('two', 'even'), 4),
#  (('two', 'legs'), 4),
#  (('two', 'command'), 4),
#  (('boxer', 'care'), 4),
#  (('boxer', 'small'), 4),
#  (('boxer', 'put'), 4),
#  (('boxer', 'come'), 4),
#  (('boxer', 'face'), 4),
#  (('boxer', 'squealer'), 4),
#  (('boxer', 'cri'), 4),
#  (('boxer', 'comrad'), 4),
#  (('boxer', 'van'), 4),
#  (('clover', 'hoof'), 4),
#  (('set', 'small'), 4),
#  (('set', 'orchard'), 4),
#  (('great', 'saw'), 4),
#  (('small', 'orchard'), 4),
#  (('life', 'said'), 4),
#  (('beast', 'everi'), 4),
#  (('put', 'seem'), 4),
#  (('tremend', 'four'), 4),
#  (('work', 'well'), 4),
#  (('work', 'done'), 4),
#  (('work', 'said'), 4),
#  (('work', 'kind'), 4),
#  (('work', 'plan'), 4),
#  (('work', 'like'), 4),
#  (('work', 'right'), 4),
#  (('work', 'windmil'), 4),
#  (('benjamin', 'except'), 4),
#  (('benjamin', 'time'), 4),
#  (('benjamin', 'could'), 4),
#  (('would', 'noth'), 4),
#  (('would', 'sunday'), 4),
#  (('would', 'know'), 4),
#  (('would', 'carri'), 4),
#  (('would', 'certain'), 4),
#  (('would', 'call'), 4),
#  (('would', 'snowbal'), 4),
#  (('would', 'hard'), 4),
#  (('would', 'anyon'), 4),
#  (('would', 'five'), 4),
#  (('would', 'right'), 4),
#  (('given', 'napoleon'), 4),
#  (('ask', 'said'), 4),
#  (('sunday', 'week'), 4),
#  (('beyond', 'orchard'), 4),
#  (('wall', 'seven'), 4),
#  (('moment', 'good'), 4),
#  (('moment', 'might'), 4),
#  (('moment', 'van'), 4),
#  (('took', 'away'), 4),
#  (('come', 'much'), 4),
#  (('come', 'time'), 4),
#  (('come', 'see'), 4),
#  (('come', 'said'), 4),
#  (('come', 'snowbal'), 4),
#  (('later', 'everi'), 4),
#  (('later', 'week'), 4),
#  (('time', 'said'), 4),
#  (('time', 'snowball'), 4),
#  (('time', 'anyon'), 4),
#  (('time', 'frederick'), 4),
#  (('thought', 'command'), 4),
#  (('let', 'us'), 4),
#  (('let', 'napoleon'), 4),
#  (('england', 'everi'), 4),
#  (('england', 'tune'), 4),
#  (('england', 'field'), 4),
#  (('upon', 'legs'), 4),
#  (('upon', 'comrad'), 4),
#  (('ever', 'seen'), 4),
#  (('give', 'napoleon'), 4),
#  (('everi', 'snowbal'), 4),
#  (('everi', 'squealer'), 4),
#  (('everi', 'turn'), 4),
#  (('everi', 'comrad'), 4),
#  (('four', 'young'), 4),
#  (('four', 'dog'), 4),
#  (('even', 'snowbal'), 4),
#  (('better', 'napoleon'), 4),
#  (('could', 'snowbal'), 4),
#  (('could', 'napoleon'), 4),
#  (('could', 'found'), 4),
#  (('could', 'thing'), 4),
#  (('rebellion', 'snowbal'), 4),
#  (('said', 'comrad'), 4),
#  (('said', 'pilkington'), 4),
#  (('said', 'windmill'), 4),
#  (('said', 'windmil'), 4),
#  (('littl', 'stood'), 4),
#  (('also', 'snowbal'), 4),
#  (('wear', 'napoleon'), 4),
#  (('knew', 'far'), 4),
#  (('voic', 'napoleon'), 4),
#  (('snowbal', 'turn'), 4),
#  (('snowbal', 'full'), 4),
#  (('snowbal', 'plan'), 4),
#  (('snowbal', 'pinchfield'), 4),
#  (('snowbal', 'attack'), 4),
#  (('napoleon', 'full'), 4),
#  (('napoleon', 'seen'), 4),
#  (('napoleon', 'fire'), 4),
#  (('napoleon', 'sent'), 4),
#  (('napoleon', 'forward'), 4),
#  (('napoleon', 'windmil'), 4),
#  (('death', 'frederick'), 4),
#  (('read', 'command'), 4),
#  (('go', 'windmil'), 4),
#  (('sent', 'foxwood'), 4),
#  (('away', 'van'), 4),
#  (('agreement', 'pilkington'), 4),
#  (('agreement', 'frederick'), 4),
#  (('pilkington', 'pinchfield'), 4),
#  (('pilkington', 'whymper'), 4),
#  (('frederick', 'attack'), 4),
#  (('frederick', 'windmill'), 4),
#  (('frederick', 'timber'), 4),
#  (('jones', 'never'), 3),
#  (('jones', 'make'), 3),
#  (('jones', 'first'), 3),
#  (('jones', 'three'), 3),
#  (('jones', 'use'), 3),
#  (('jones', 'rebellion'), 3),
#  (('jones', 'littl'), 3),
#  (('jones', 'turn'), 3),
#  (('jones', 'found'), 3),
#  (('jones', 'seen'), 3),
#  (('jones', 'thing'), 3),
#  (('jones', 'seem'), 3),
#  (('farm', 'alreadi'), 3),
#  (('farm', 'went'), 3),
#  (('farm', 'major'), 3),
#  (('farm', 'began'), 3),
#  (('farm', 'two'), 3),
#  (('farm', 'hand'), 3),
#  (('farm', 'given'), 3),
#  (('farm', 'saw'), 3),
#  (('farm', 'wall'), 3),
#  (('farm', 'took'), 3),
#  (('farm', 'speech'), 3),
#  (('farm', 'later'), 3),
#  (('farm', 'almost'), 3),
#  (('farm', 'rest'), 3),
#  (('farm', 'men'), 3),
#  (('farm', 'young'), 3),
#  (('farm', 'dog'), 3),
#  (('farm', 'week'), 3),
#  (('farm', 'littl'), 3),
#  (('farm', 'sinc'), 3),
#  (('farm', 'field'), 3),
#  (('farm', 'complet'), 3),
#  (('farm', 'take'), 3),
#  (('farm', 'death'), 3),
#  (('farm', 'need'), 3),
#  (('farm', 'news'), 3),
#  (('farm', 'success'), 3),
#  (('farm', 'command'), 3),
#  (('farm', 'sent'), 3),
#  (('farm', 'agreement'), 3),
#  (('farm', 'seem'), 3),
#  (('farm', 'comrad'), 3),
#  (('farm', 'half'), 3),
#  (('farm', 'windmil'), 3),
#  (('night', 'day'), 3),
#  (('night', 'old'), 3),
#  (('night', 'anim'), 3),
#  (('night', 'come'), 3),
#  (('night', 'england'), 3),
#  (('rememb', 'never'), 3),
#  (('rememb', 'clover'), 3),
#  (('rememb', 'could'), 3),
#  (('rememb', 'command'), 3),
#  (('side', 'way'), 3),
#  (('side', 'two'), 3),
#  (('side', 'clover'), 3),
#  (('side', 'small'), 3),
#  (('side', 'benjamin'), 3),
#  (('side', 'would'), 3),
#  (('side', 'sure'), 3),
#  (('side', 'napoleon'), 3),
#  (('yard', 'way'), 3),
#  (('yard', 'men'), 3),
#  (('yard', 'turn'), 3),
#  (('back', 'last'), 3),
#  (('back', 'way'), 3),
#  (('back', 'buildings'), 3),
#  (('back', 'round'), 3),
#  (('back', 'sheep'), 3),
#  (('back', 'would'), 3),
#  (('back', 'think'), 3),
#  (('back', 'dog'), 3),
#  (('back', 'could'), 3),
#  (('back', 'race'), 3),
#  (('back', 'sure'), 3),
#  (('back', 'squealer'), 3),
#  (('back', 'seen'), 3),
#  (('back', 'tri'), 3),
#  (('back', 'farmhouse'), 3),
#  (('back', 'farmhous'), 3),
#  (('door', 'walk'), 3),
#  (('door', 'moment'), 3),
#  (('door', 'napoleon'), 3),
#  (('door', 'farmhouse'), 3),
#  (('last', 'way'), 3),
#  (('last', 'word'), 3),
#  (('last', 'dream'), 3),
#  (('last', 'year'), 3),
#  (('last', 'boxer'), 3),
#  (('made', 'way'), 3),
#  (('made', 'though'), 3),
#  (('made', 'hour'), 3),
#  (('made', 'order'), 3),
#  (('made', 'one'), 3),
#  (('made', 'boxer'), 3),
#  (('made', 'look'), 3),
#  (('made', 'speech'), 3),
#  (('made', 'labour'), 3),
#  (('made', 'everi'), 3),
#  (('made', 'dog'), 3),
#  (('made', 'could'), 3),
#  (('made', 'said'), 3),
#  (('made', 'snowbal'), 3),
#  (('made', 'morn'), 3),
#  (('made', 'cri'), 3),
#  (('way', 'jone'), 3),
#  (('way', 'clover'), 3),
#  (('way', 'work'), 3),
#  (('way', 'would'), 3),
#  (('way', 'except'), 3),
#  (('way', 'time'), 3),
#  (('way', 'even'), 3),
#  (('way', 'could'), 3),
#  (('way', 'littl'), 3),
#  (('way', 'snowbal'), 3),
#  (('way', 'go'), 3),
#  (('bed', 'anim'), 3),
#  (('jone', 'meet'), 3),
#  (('jone', 'one'), 3),
#  (('jone', 'pig'), 3),
#  (('jone', 'got'), 3),
#  (('jone', 'among'), 3),
#  (('jone', 'time'), 3),
#  (('jone', 'almost'), 3),
#  (('jone', 'snowbal'), 3),
#  (('jone', 'anoth'), 3),
#  (('alreadi', 'anim'), 3),
#  (('alreadi', 'came'), 3),
#  (('alreadi', 'could'), 3),
#  (('alreadi', 'said'), 3),
#  (('alreadi', 'frederick'), 3),
#  (('soon', 'went'), 3),
#  (('soon', 'could'), 3),
#  (('soon', 'abl'), 3),
#  (('went', 'round'), 3),
#  (('went', 'day'), 3),
#  (('buildings', 'work'), 3),
#  (('word', 'long'), 3),
#  (('word', 'came'), 3),
#  (('word', 'everi'), 3),
#  (('word', "'beast"), 3),
#  (('gone', 'men'), 3),
#  (('round', 'day'), 3),
#  (('round', 'animals'), 3),
#  (('round', 'first'), 3),
#  (('round', 'came'), 3),
#  (('round', 'sheep'), 3),
#  (('round', 'two'), 3),
#  (('round', 'boxer'), 3),
#  (('round', 'without'), 3),
#  (('round', 'time'), 3),
#  (('round', 'everi'), 3),
#  (('round', 'utter'), 3),
#  (('day', 'willingdon'), 3),
#  (('day', 'hour'), 3),
#  (('day', 'order'), 3),
#  (('day', 'long'), 3),
#  (('day', 'pigs'), 3),
#  (('day', 'two'), 3),
#  (('day', 'die'), 3),
#  (('day', 'stall'), 3),
#  (('day', 'four'), 3),
#  (('day', 'could'), 3),
#  (('day', 'rebellion'), 3),
#  (('day', 'might'), 3),
#  (('day', 'carri'), 3),
#  (('day', 'however'), 3),
#  (('day', 'call'), 3),
#  (('day', 'field'), 3),
#  (('day', 'next'), 3),
#  (('day', 'read'), 3),
#  (('day', 'thing'), 3),
#  (('day', 'farmhouse'), 3),
#  (('day', 'sent'), 3),
#  (('old', 'name'), 3),
#  (('old', 'quit'), 3),
#  (('old', 'pig'), 3),
#  (('old', 'first'), 3),
#  (('old', 'three'), 3),
#  (('old', 'except'), 3),
#  (('old', 'know'), 3),
#  (('old', 'ever'), 3),
#  (('old', 'rebellion'), 3),
#  (('old', 'said'), 3),
#  (('old', 'sing'), 3),
#  (('old', 'found'), 3),
#  (('old', 'seem'), 3),
#  (('major', 'rais'), 3),
#  (('major', 'anim'), 3),
#  (('white', 'squealer'), 3),
#  (('animals', 'pig'), 3),
#  (('animals', 'set'), 3),
#  (('animals', 'upon'), 3),
#  (('animals', 'napoleon'), 3),
#  (('meet', 'work'), 3),
#  (('meet', 'would'), 3),
#  (('meet', 'napoleon'), 3),
#  (('big', 'anim'), 3),
#  (('big', 'wall'), 3),
#  (('big', 'napoleon'), 3),
#  (('big', 'seven'), 3),
#  (('barn', 'snowbal'), 3),
#  (('barn', 'napoleon'), 3),
#  (('alway', 'anim'), 3),
#  (('alway', 'make'), 3),
#  (('alway', 'two'), 3),
#  (('alway', 'would'), 3),
#  (('alway', 'everi'), 3),
#  (('alway', 'harder'), 3),
#  (('alway', 'comrad'), 3),
#  (('though', 'quit'), 3),
#  (('though', 'make'), 3),
#  (('though', 'dogs'), 3),
#  (('though', 'two'), 3),
#  (('though', 'noth'), 3),
#  (('though', 'moment'), 3),
#  (('though', 'human'), 3),
#  (('name', 'one'), 3),
#  (('name', 'among'), 3),
#  (('name', 'young'), 3),
#  (('name', 'dog'), 3),
#  (('willingdon', 'would'), 3),
#  (('hour', 'end'), 3),
#  (('hour', 'boxer'), 3),
#  (('hour', 'later'), 3),
#  (('hour', 'morn'), 3),
#  (('hour', 'half'), 3),
#  (('order', 'appear'), 3),
#  (('order', 'pigs'), 3),
#  (('order', 'work'), 3),
#  (('order', 'sunday'), 3),
#  (('order', 'squealer'), 3),
#  (('order', 'remain'), 3),
#  (('say', 'work'), 3),
#  (('say', 'think'), 3),
#  (('say', 'could'), 3),
#  (('say', 'right'), 3),
#  (('say', 'comrad'), 3),
#  (('one', 'pig'), 3),
#  (('one', 'make'), 3),
#  ...]

# %%
#namely

new = {tuple(sorted(x)):y for x, y in count_s.items()}

#順位チェック again !
new2 = dict(sorted(new.items(), key=lambda x: x[1], reverse=True))

new3 = dict((k, v) for k, v in new2.items() if v >= 2)

#順位チェック again !
new4 = dict(sorted(new3.items(), key=lambda x: x[1], reverse=True))
new4
# Out:
# {('anim', 'farm'): 69,
#  ('anim', 'napoleon'): 31,
#  ('anim', 'work'): 30,
#  ('anim', 'would'): 26,
#  ('comrad', 'napoleon'): 24,
#  ('anim', 'could'): 23,
#  ('anim', 'time'): 21,
#  ('work', 'would'): 20,
#  ('anim', 'one'): 19,
#  ('farm', 'would'): 17,
#  ('anim', 'pig'): 17,
#  ('anim', 'snowbal'): 17,
#  ('anim', 'never'): 16,
#  ("'beast", 'england'): 16,
#  ('napoleon', 'snowbal'): 16,
#  ('farm', 'work'): 15,
#  ('anim', 'ever'): 15,
#  ('boxer', 'clover'): 15,
#  ('dog', 'napoleon'): 15,
#  ('napoleon', 'pig'): 14,
#  ('anim', 'everi'): 14,
#  ('anim', 'even'): 14,
#  ('leg', 'two'): 14,
#  ('boxer', 'said'): 14,
#  ('farm', 'snowbal'): 13,
#  ('anim', 'day'): 13,
#  ('time', 'would'): 13,
#  ('napoleon', 'would'): 13,
#  ('four', 'good'): 13,
#  ('farm', 'pig'): 12,
#  ('day', 'one'): 12,
#  ('day', 'work'): 12,
#  ('anim', 'order'): 12,
#  ('one', 'would'): 12,
#  ('anim', 'two'): 12,
#  ('anim', 'human'): 12,
#  ('good', 'two'): 12,
#  ('four', 'two'): 12,
#  ('boxer', 'hoof'): 12,
#  ('good', 'leg'): 12,
#  ('four', 'leg'): 12,
#  ('farm', 'one'): 11,
#  ('farm', 'napoleon'): 11,
#  ('anim', 'back'): 11,
#  ('anim', 'round'): 11,
#  ('pig', 'work'): 11,
#  ('anim', 'long'): 11,
#  ('anim', 'first'): 11,
#  ('anim', 'set'): 11,
#  ('anim', 'england'): 11,
#  ('anim', 'snowball'): 11,
#  ('anim', 'seem'): 11,
#  ('boxer', 'napoleon'): 11,
#  ('said', 'would'): 11,
#  ('napoleon', 'time'): 11,
#  ('even', 'napoleon'): 11,
#  ('napoleon', 'said'): 11,
#  ('napoleon', 'snowball'): 11,
#  ('announc', 'napoleon'): 11,
#  ('anim', 'yard'): 10,
#  ('back', 'jone'): 10,
#  ('barn', 'big'): 10,
#  ('napoleon', 'one'): 10,
#  ('appear', 'napoleon'): 10,
#  ('anim', 'sheep'): 10,
#  ('anim', 'shall'): 10,
#  ('anim', 'week'): 10,
#  ('anim', 'squealer'): 10,
#  ('anim', 'frederick'): 10,
#  ('two', 'would'): 10,
#  ('napoleon', 'two'): 10,
#  ('bad', 'two'): 10,
#  ('hard', 'work'): 10,
#  ('napoleon', 'squealer'): 10,
#  ('command', 'seven'): 10,
#  ('frederick', 'pilkington'): 10,
#  ('buildings', 'farm'): 9,
#  ('farm', 'human'): 9,
#  ('farm', 'pilkington'): 9,
#  ('farm', 'windmill'): 9,
#  ('anim', 'made'): 9,
#  ('pig', 'round'): 9,
#  ('napoleon', 'round'): 9,
#  ('day', 'would'): 9,
#  ('day', 'later'): 9,
#  ('day', 'everi'): 9,
#  ('anim', 'barn'): 9,
#  ('alway', 'napoleon'): 9,
#  ('napoleon', 'order'): 9,
#  ('say', 'would'): 9,
#  ('even', 'one'): 9,
#  ('live', 'long'): 9,
#  ('anim', 'came'): 9,
#  ('anim', 'boxer'): 9,
#  ('anim', 'come'): 9,
#  ('anim', 'live'): 9,
#  ('anim', 'must'): 9,
#  ('anim', 'said'): 9,
#  ('also', 'anim'): 9,
#  ('anim', 'certain'): 9,
#  ('anim', 'call'): 9,
#  ('first', 'time'): 9,
#  ('sheep', 'two'): 9,
#  ('set', 'work'): 9,
#  ('even', 'work'): 9,
#  ('napoleon', 'work'): 9,
#  ('harder', 'work'): 9,
#  ('human', 'would'): 9,
#  ('announc', 'would'): 9,
#  ('morn', 'sunday'): 9,
#  ('bad', 'good'): 9,
#  ('everi', 'napoleon'): 9,
#  ('bad', 'four'): 9,
#  ('said', 'squealer'): 9,
#  ('bad', 'leg'): 9,
#  ('frederick', 'napoleon'): 9,
#  ('day', 'jones'): 8,
#  ('back', 'farm'): 8,
#  ('farm', 'made'): 8,
#  ('farm', 'never'): 8,
#  ('farm', 'time'): 8,
#  ('everi', 'farm'): 8,
#  ('even', 'farm'): 8,
#  ('could', 'farm'): 8,
#  ('farm', 'said'): 8,
#  ('build', 'farm'): 8,
#  ('farm', 'pinchfield'): 8,
#  ('farm', 'frederick'): 8,
#  ('anim', 'rememb'): 8,
#  ('anim', 'jone'): 8,
#  ('jone', 'men'): 8,
#  ('day', 'time'): 8,
#  ('benjamin', 'old'): 8,
#  ('anim', 'still'): 8,
#  ('dog', 'pig'): 8,
#  ('anim', 'much'): 8,
#  ('anim', 'littl'): 8,
#  ('anim', 'equal'): 8,
#  ('anim', 'field'): 8,
#  ('anim', 'believ'): 8,
#  ('anim', 'anoth'): 8,
#  ('boxer', 'two'): 8,
#  ('benjamin', 'clover'): 8,
#  ('come', 'would'): 8,
#  ('live', 'would'): 8,
#  ('everi', 'would'): 8,
#  ('even', 'would'): 8,
#  ('could', 'would'): 8,
#  ('need', 'would'): 8,
#  ('windmill', 'would'): 8,
#  ('napoleon', 'well'): 8,
#  ('could', 'said'): 8,
#  ('napoleon', 'right'): 8,
#  ('napoleon', 'pilkington'): 8,
#  ('napoleon', 'whymper'): 8,
#  ('jones', 'time'): 7,
#  ('farm', 'though'): 7,
#  ('farm', 'name'): 7,
#  ('farm', 'place'): 7,
#  ('farm', 'live'): 7,
#  ('ever', 'farm'): 7,
#  ('farm', 'squealer'): 7,
#  ('farm', 'foxwood'): 7,
#  ('back', 'boxer'): 7,
#  ('back', 'napoleon'): 7,
#  ('made', 'would'): 7,
#  ('anim', 'way'): 7,
#  ('major', 'old'): 7,
#  ('barn', 'end'): 7,
#  ('one', 'work'): 7,
#  ('one', 'said'): 7,
#  ('anim', 'end'): 7,
#  ('pig', 'time'): 7,
#  ('four', 'pig'): 7,
#  ('pig', 'young'): 7,
#  ('could', 'never'): 7,
#  ('anim', 'began'): 7,
#  ('anim', 'without'): 7,
#  ('anim', 'moment'): 7,
#  ('anim', 'speech'): 7,
#  ('anim', 'heard'): 7,
#  ('anim', 'use'): 7,
#  ('anim', 'labour'): 7,
#  ('anim', 'men'): 7,
#  ('anim', 'dog'): 7,
#  ('anim', 'morn'): 7,
#  ('anim', 'thing'): 7,
#  ('anim', 'command'): 7,
#  ('anim', 'pilkington'): 7,
#  ('anim', 'windmill'): 7,
#  ('good', 'sheep'): 7,
#  ('four', 'sheep'): 7,
#  ('leg', 'sheep'): 7,
#  ('boxer', 'work'): 7,
#  ('boxer', 'would'): 7,
#  ('boxer', 'even'): 7,
#  ('everi', 'work'): 7,
#  ('well', 'would'): 7,
#  ('moment', 'napoleon'): 7,
#  ('england', 'sing'): 7,
#  ('napoleon', 'upon'): 7,
#  ('could', 'even'): 7,
#  ('could', 'done'): 7,
#  ('napoleon', 'seem'): 7,
#  ('build', 'windmill'): 7,
#  ('fire', 'gun'): 7,
#  ('foxwood', 'pilkington'): 7,
#  ('jones', 'snowbal'): 6,
#  ('farm', 'round'): 6,
#  ('farm', 'long'): 6,
#  ('farm', 'make'): 6,
#  ('come', 'farm'): 6,
#  ('anoth', 'farm'): 6,
#  ('farm', 'go'): 6,
#  ('farm', 'summer'): 6,
#  ('side', 'tail'): 6,
#  ('back', 'came'): 6,
#  ('made', 'napoleon'): 6,
#  ('bed', 'sleep'): 6,
#  ('anim', 'went'): 6,
#  ('anim', 'word'): 6,
#  ('round', 'walk'): 6,
#  ('round', 'would'): 6,
#  ('day', 'pig'): 6,
#  ('day', 'three'): 6,
#  ('clover', 'day'): 6,
#  ('day', 'squealer'): 6,
#  ('barn', 'meet'): 6,
#  ('alway', 'right'): 6,
#  ('anim', 'though'): 6,
#  ('anim', 'sleep'): 6,
#  ('never', 'one'): 6,
#  ('one', 'time'): 6,
#  ('anoth', 'one'): 6,
#  ('end', 'would'): 6,
#  ('end', 'seven'): 6,
#  ('anim', 'year'): 6,
#  ('dogs', 'pig'): 6,
#  ('pig', 'sheep'): 6,
#  ('boxer', 'never'): 6,
#  ('never', 'time'): 6,
#  ('long', 'time'): 6,
#  ('anim', 'given'): 6,
#  ('among', 'anim'): 6,
#  ('anim', 'took'): 6,
#  ('anim', 'except'): 6,
#  ('anim', 'later'): 6,
#  ('anim', 'mani'): 6,
#  ('anim', 'yet'): 6,
#  ('anim', 'rebellion'): 6,
#  ('anim', 'kind'): 6,
#  ('anim', 'sing'): 6,
#  ('anim', 'complet'): 6,
#  ('anim', 'turn'): 6,
#  ('anim', 'talk'): 6,
#  ('anim', 'past'): 6,
#  ('anim', 'build'): 6,
#  ('anim', 'news'): 6,
#  ('anim', 'like'): 6,
#  ('anim', 'go'): 6,
#  ('anim', 'outsid'): 6,
#  ('anim', 'class'): 6,
#  ('make', 'would'): 6,
#  ('make', 'napoleon'): 6,
#  ('boxer', 'came'): 6,
#  ('bad', 'sheep'): 6,
#  ('everi', 'two'): 6,
#  ('benjamin', 'boxer'): 6,
#  ('boxer', 'take'): 6,
#  ('great', 'hoof'): 6,
#  ('come', 'work'): 6,
#  ('human', 'work'): 6,
#  ('muriel', 'read'): 6,
#  ('might', 'would'): 6,
#  ('go', 'would'): 6,
#  ('windmil', 'would'): 6,
#  ('napoleon', 'sunday'): 6,
#  ('men', 'moment'): 6,
#  ('moment', 'snowball'): 6,
#  ('napoleon', 'speech'): 6,
#  ('comrades', 'said'): 6,
#  ('everi', 'said'): 6,
#  ('everi', 'morn'): 6,
#  ('napoleon', 'young'): 6,
#  ('could', 'read'): 6,
#  ('napoleon', 'week'): 6,
#  ('said', 'snowball'): 6,
#  ('frederick', 'said'): 6,
#  ("'beast", 'sing'): 6,
#  ('black', 'napoleon'): 6,
#  ('cri', 'napoleon'): 6,
#  ('napoleon', 'stood'): 6,
#  ('cri', 'squealer'): 6,
#  ('abl', 'squealer'): 6,
#  ('farm', 'jones'): 5,
#  ('anim', 'jones'): 5,
#  ('gun', 'jones'): 5,
#  ('farm', 'way'): 5,
#  ('animals', 'farm'): 5,
#  ('farm', 'order'): 5,
#  ('farm', 'first'): 5,
#  ('boxer', 'farm'): 5,
#  ('farm', 'set'): 5,
#  ('farm', 'without'): 5,
#  ('farm', 'whole'): 5,
#  ('certain', 'farm'): 5,
#  ('attack', 'farm'): 5,
#  ('major', 'night'): 5,
#  ('came', 'night'): 5,
#  ('night', 'work'): 5,
#  ('see', 'side'): 5,
#  ('back', 'made'): 5,
#  ('back', 'set'): 5,
#  ('back', 'work'): 5,
#  ('back', 'come'): 5,
#  ('back', 'even'): 5,
#  ('anim', 'door'): 5,
#  ('came', 'last'): 5,
#  ('made', 'round'): 5,
#  ('day', 'made'): 5,
#  ('made', 'squealer'): 5,
#  ('come', 'jone'): 5,
#  ('napoleon', 'soon'): 5,
#  ('anim', 'buildings'): 5,
#  ('dog', 'round'): 5,
#  ('round', 'squealer'): 5,
#  ('came', 'day'): 5,
#  ('boxer', 'day'): 5,
#  ('day', 'shall'): 5,
#  ('day', 'labour'): 5,
#  ('day', 'even'): 5,
#  ('better', 'day'): 5,
#  ('day', 'hay'): 5,
#  ('day', 'napoleon'): 5,
#  ('day', 'snowball'): 5,
#  ('day', 'seem'): 5,
#  ('old', 'year'): 5,
#  ('anim', 'animals'): 5,
#  ('anim', 'meet'): 5,
#  ('big', 'end'): 5,
#  ('barn', 'seven'): 5,
#  ('alway', 'pig'): 5,
#  ('alway', 'boxer'): 5,
#  ('one', 'though'): 5,
#  ('hour', 'would'): 5,
#  ('one', 'order'): 5,
#  ('order', 'would'): 5,
#  ('anim', 'say'): 5,
#  ('say', 'time'): 5,
#  ('napoleon', 'say'): 5,
#  ('clover', 'one'): 5,
#  ('except', 'one'): 5,
#  ('one', 'squealer'): 5,
#  ('end', 'two'): 5,
#  ('stall', 'straw'): 5,
#  ('work', 'year'): 5,
#  ('late', 'summer'): 5,
#  ('mani', 'pig'): 5,
#  ('farmhous', 'pig'): 5,
#  ('pig', 'seem'): 5,
#  ('never', 'work'): 5,
#  ('long', 'napoleon'): 5,
#  ('anim', 'three'): 5,
#  ('anim', 'walk'): 5,
#  ('anim', 'benjamin'): 5,
#  ('anim', 'saw'): 5,
#  ('anim', 'sunday'): 5,
#  ('anim', 'think'): 5,
#  ('anim', 'comrades'): 5,
#  ('anim', 'pass'): 5,
#  ('anim', 'know'): 5,
#  ('anim', 'good'): 5,
#  ('anim', 'might'): 5,
#  ('anim', 'drink'): 5,
#  ('anim', 'sinc'): 5,
#  ('anim', 'seven'): 5,
#  ('anim', 'hard'): 5,
#  ("'beast", 'anim'): 5,
#  ('agreement', 'anim'): 5,
#  ('anim', 'learn'): 5,
#  ('anim', 'cri'): 5,
#  ('anim', 'comrad'): 5,
#  ('anim', 'half'): 5,
#  ('anim', 'flag'): 5,
#  ('anim', 'green'): 5,
#  ('anim', 'terribl'): 5,
#  ('anim', 'announc'): 5,
#  ('could', 'first'): 5,
#  ('first', 'snowbal'): 5,
#  ('first', 'napoleon'): 5,
#  ('came', 'dog'): 5,
#  ('came', 'napoleon'): 5,
#  ('moment', 'two'): 5,
#  ('dog', 'two'): 5,
#  ('better', 'two'): 5,
#  ('snowbal', 'two'): 5,
#  ('boxer', 'great'): 5,
#  ('boxer', 'without'): 5,
#  ('boxer', 'time'): 5,
#  ('boxer', 'could'): 5,
#  ('away', 'boxer'): 5,
#  ('hoof', 'would'): 5,
#  ('great', 'would'): 5,
#  ('beast', 'england'): 5,
#  ('even', 'hors'): 5,
#  ('time', 'work'): 5,
#  ('labour', 'work'): 5,
#  ('could', 'work'): 5,
#  ('week', 'work'): 5,
#  ('seem', 'work'): 5,
#  ('benjamin', 'muriel'): 5,
#  ('napoleon', 'usual'): 5,
#  ('ask', 'would'): 5,
#  ('listen', 'would'): 5,
#  ('later', 'would'): 5,
#  ('happen', 'would'): 5,
#  ('get', 'would'): 5,
#  ('also', 'would'): 5,
#  ('field', 'would'): 5,
#  ('morn', 'would'): 5,
#  ('noth', 'time'): 5,
#  ('could', 'noth'): 5,
#  ('everi', 'sunday'): 5,
#  ('announc', 'sunday'): 5,
#  ('command', 'wall'): 5,
#  ('four', 'moment'): 5,
#  ('moment', 'next'): 5,
#  ('could', 'think'): 5,
#  ('could', 'time'): 5,
#  ('seem', 'time'): 5,
#  ('dog', 'let'): 5,
#  ('live', 'napoleon'): 5,
#  ('call', 'upon'): 5,
#  ('could', 'human'): 5,
#  ('human', 'race'): 5,
#  ('ever', 'must'): 5,
#  ('could', 'everi'): 5,
#  ('frederick', 'men'): 5,
#  ('four', 'napoleon'): 5,
#  ('better', 'even'): 5,
#  ('even', 'squealer'): 5,
#  ('even', 'seen'): 5,
#  ('could', 'get'): 5,
#  ('could', 'squealer'): 5,
#  ('said', 'snowbal'): 5,
#  ('call', 'napoleon'): 5,
#  ('away', 'take'): 5,
#  ('battl', 'snowbal'): 5,
#  ('snowbal', 'windmill'): 5,
#  ('death', 'napoleon'): 5,
#  ('agreement', 'napoleon'): 5,
#  ('follow', 'napoleon'): 5,
#  ('napoleon', 'pile'): 5,
#  ('confess', 'napoleon'): 5,
#  ('flag', 'green'): 5,
#  ('foxwood', 'pinchfield'): 5,
#  ('frederick', 'pinchfield'): 5,
#  ('pile', 'timber'): 5,
#  ('back', 'jones'): 4,
#  ('jones', 'old'): 4,
#  ('jones', 'one'): 4,
#  ('jones', 'work'): 4,
#  ('human', 'jones'): 4,
#  ('even', 'jones'): 4,
#  ('better', 'jones'): 4,
#  ('jones', 'napoleon'): 4,
#  ('jones', 'past'): 4,
#  ('battl', 'jones'): 4,
#  ('farm', 'night'): 4,
#  ('farm', 'jone'): 4,
#  ('day', 'farm'): 4,
#  ('farm', 'willingdon'): 4,
#  ('farm', 'say'): 4,
#  ('end', 'farm'): 4,
#  ('farm', 'year'): 4,
#  ('farm', 'still'): 4,
#  ('came', 'farm'): 4,
#  ('farm', 'pigs'): 4,
#  ('farm', 'sheep'): 4,
#  ('farm', 'hors'): 4,
#  ('farm', 'heard'): 4,
#  ('farm', 'mani'): 4,
#  ('farm', 'much'): 4,
#  ('farm', 'happen'): 4,
#  ('farm', 'get'): 4,
#  ('also', 'farm'): 4,
#  ('call', 'farm'): 4,
#  ('farm', 'like'): 4,
#  ('farm', 'outsid'): 4,
#  ('away', 'farm'): 4,
#  ('farm', 'rumour'): 4,
#  ('farm', 'whymper'): 4,
#  ('last', 'night'): 4,
#  ('dream', 'night'): 4,
#  ('anim', 'side'): 4,
#  ('littl', 'side'): 4,
#  ('back', 'yard'): 4,
#  ('round', 'yard'): 4,
#  ('one', 'yard'): 4,
#  ('moment', 'yard'): 4,
#  ('rush', 'yard'): 4,
#  ('back', 'door'): 4,
#  ('back', 'went'): 4,
#  ('back', 'got'): 4,
#  ('back', 'face'): 4,
#  ('back', 'snowbal'): 4,
#  ('alreadi', 'made'): 4,
#  ('made', 'work'): 4,
#  ('round', 'way'): 4,
#  ('one', 'way'): 4,
#  ('napoleon', 'way'): 4,
#  ('bed', 'straw'): 4,
#  ('jone', 'would'): 4,
#  ('jone', 'use'): 4,
#  ('anim', 'soon'): 4,
#  ('end', 'went'): 4,
#  ('went', 'without'): 4,
#  ('napoleon', 'went'): 4,
#  ('round', 'word'): 4,
#  ('without', 'word'): 4,
#  ('england', 'word'): 4,
#  ('old', 'round'): 4,
#  ('one', 'round'): 4,
#  ('clover', 'round'): 4,
#  ('look', 'round'): 4,
#  ('even', 'round'): 4,
#  ('day', 'old'): 4,
#  ('day', 'england'): 4,
#  ('day', 'upon'): 4,
#  ('day', 'whole'): 4,
#  ('day', 'yet'): 4,
#  ('anoth', 'day'): 4,
#  ('clover', 'old'): 4,
#  ('old', 'time'): 4,
#  ('major', 'speech'): 4,
#  ('barn', 'two'): 4,
#  ('barn', 'wall'): 4,
#  ('barn', 'command'): 4,
#  ('alway', 'work'): 4,
#  ('sheep', 'though'): 4,
#  ('though', 'would'): 4,
#  ('even', 'though'): 4,
#  ('name', 'pig'): 4,
#  ('anim', 'name'): 4,
#  ('name', 'napoleon'): 4,
#  ('hour', 'work'): 4,
#  ('order', 'week'): 4,
#  ('say', 'someth'): 4,
#  ('began', 'one'): 4,
#  ('one', 'pigs'): 4,
#  ('one', 'sunday'): 4,
#  ('come', 'one'): 4,
#  ('comrad', 'one'): 4,
#  ('end', 'wall'): 4,
#  ('come', 'end'): 4,
#  ('end', 'napoleon'): 4,
#  ('command', 'end'): 4,
#  ('napoleon', 'rais'): 4,
#  ('mani', 'year'): 4,
#  ('past', 'year'): 4,
#  ('anim', 'late'): 4,
#  ('appear', 'pig'): 4,
#  ('pig', 'three'): 4,
#  ('boxer', 'pig'): 4,
#  ('pig', 'set'): 4,
#  ('pig', 'put'): 4,
#  ('pig', 'would'): 4,
#  ('pig', 'use'): 4,
#  ('everi', 'pig'): 4,
#  ('even', 'pig'): 4,
#  ('pig', 'snowbal'): 4,
#  ('pig', 'squealer'): 4,
#  ('appear', 'never'): 4,
#  ('anim', 'appear'): 4,
#  ('appear', 'dog'): 4,
#  ('never', 'would'): 4,
#  ('even', 'never'): 4,
#  ('napoleon', 'never'): 4,
#  ('boxer', 'long'): 4,
#  ('benjamin', 'long'): 4,
#  ('anim', 'make'): 4,
#  ('anim', 'great'): 4,
#  ('anim', 'small'): 4,
#  ('anim', 'got'): 4,
#  ('anim', 'hors'): 4,
#  ('anim', 'put'): 4,
#  ('anim', 'gave'): 4,
#  ('anim', 'noth'): 4,
#  ('anim', 'place'): 4,
#  ('anim', 'thought'): 4,
#  ('anim', 'well'): 4,
#  ('anim', 'face'): 4,
#  ('anim', 'food'): 4,
#  ('anim', 'give'): 4,
#  ('anim', 'rest'): 4,
#  ('anim', 'get'): 4,
#  ('anim', 'race'): 4,
#  ('anim', 'wear'): 4,
#  ('anim', 'tune'): 4,
#  ('anim', 'reason'): 4,
#  ('anim', 'death'): 4,
#  ('anim', 'need'): 4,
#  ('anim', 'harder'): 4,
#  ('anim', 'anyth'): 4,
#  ('anim', 'read'): 4,
#  ('anim', 'stand'): 4,
#  ('anim', 'found'): 4,
#  ('anim', 'minut'): 4,
#  ('anim', 'right'): 4,
#  ('anim', 'rush'): 4,
#  ('anim', 'sometim'): 4,
#  ('anim', 'notic'): 4,
#  ('abl', 'anim'): 4,
#  ('anim', 'case'): 4,
#  ('anim', 'battl'): 4,
#  ('anim', 'stood'): 4,
#  ('make', 'men'): 4,
#  ('make', 'might'): 4,
#  ('make', 'squealer'): 4,
#  ('came', 'first'): 4,
#  ('first', 'human'): 4,
#  ('class', 'first'): 4,
#  ('came', 'clover'): 4,
#  ('came', 'moment'): 4,
#  ('came', 'even'): 4,
#  ('came', 'news'): 4,
#  ('three', 'two'): 4,
#  ('three', 'time'): 4,
#  ('past', 'three'): 4,
#  ('pigs', 'work'): 4,
#  ('hen', 'napoleon'): 4,
#  ('five', 'hen'): 4,
#  ('cow', 'sheep'): 4,
#  ('lay', 'sheep'): 4,
#  ('even', 'sheep'): 4,
#  ('broke', 'sheep'): 4,
#  ('cow', 'milk'): 4,
#  ('two', 'work'): 4,
#  ('two', 'usual'): 4,
#  ('two', 'upon'): 4,
#  ('even', 'two'): 4,
#  ('legs', 'two'): 4,
#  ('command', 'two'): 4,
#  ('boxer', 'care'): 4,
#  ('boxer', 'small'): 4,
#  ('boxer', 'put'): 4,
#  ('boxer', 'come'): 4,
#  ('boxer', 'face'): 4,
#  ('boxer', 'squealer'): 4,
#  ('boxer', 'cri'): 4,
#  ('boxer', 'comrad'): 4,
#  ('boxer', 'van'): 4,
#  ('clover', 'hoof'): 4,
#  ('set', 'small'): 4,
#  ('orchard', 'set'): 4,
#  ('great', 'saw'): 4,
#  ('orchard', 'small'): 4,
#  ('life', 'said'): 4,
#  ('beast', 'everi'): 4,
#  ('put', 'seem'): 4,
#  ('four', 'tremend'): 4,
#  ('well', 'work'): 4,
#  ('done', 'work'): 4,
#  ('said', 'work'): 4,
#  ('kind', 'work'): 4,
#  ('plan', 'work'): 4,
#  ('like', 'work'): 4,
#  ('right', 'work'): 4,
#  ('windmil', 'work'): 4,
#  ('benjamin', 'except'): 4,
#  ('benjamin', 'time'): 4,
#  ('benjamin', 'could'): 4,
#  ('noth', 'would'): 4,
#  ('sunday', 'would'): 4,
#  ('know', 'would'): 4,
#  ('carri', 'would'): 4,
#  ('certain', 'would'): 4,
#  ('call', 'would'): 4,
#  ('snowbal', 'would'): 4,
#  ('hard', 'would'): 4,
#  ('anyon', 'would'): 4,
#  ('five', 'would'): 4,
#  ('right', 'would'): 4,
#  ('given', 'napoleon'): 4,
#  ('ask', 'said'): 4,
#  ('sunday', 'week'): 4,
#  ('beyond', 'orchard'): 4,
#  ('seven', 'wall'): 4,
#  ('good', 'moment'): 4,
#  ('might', 'moment'): 4,
#  ('moment', 'van'): 4,
#  ('away', 'took'): 4,
#  ('come', 'much'): 4,
#  ('come', 'time'): 4,
#  ('come', 'see'): 4,
#  ('come', 'said'): 4,
#  ('come', 'snowbal'): 4,
#  ('everi', 'later'): 4,
#  ('later', 'week'): 4,
#  ('said', 'time'): 4,
#  ('snowball', 'time'): 4,
#  ('anyon', 'time'): 4,
#  ('frederick', 'time'): 4,
#  ('command', 'thought'): 4,
#  ('let', 'us'): 4,
#  ('let', 'napoleon'): 4,
#  ('england', 'everi'): 4,
#  ('england', 'tune'): 4,
#  ('england', 'field'): 4,
#  ('legs', 'upon'): 4,
#  ('comrad', 'upon'): 4,
#  ('ever', 'seen'): 4,
#  ('give', 'napoleon'): 4,
#  ('everi', 'snowbal'): 4,
#  ('everi', 'squealer'): 4,
#  ('everi', 'turn'): 4,
#  ('comrad', 'everi'): 4,
#  ('four', 'young'): 4,
#  ('dog', 'four'): 4,
#  ('even', 'snowbal'): 4,
#  ('better', 'napoleon'): 4,
#  ('could', 'snowbal'): 4,
#  ('could', 'napoleon'): 4,
#  ('could', 'found'): 4,
#  ('could', 'thing'): 4,
#  ('rebellion', 'snowbal'): 4,
#  ('comrad', 'said'): 4,
#  ('pilkington', 'said'): 4,
#  ('said', 'windmill'): 4,
#  ('said', 'windmil'): 4,
#  ('littl', 'stood'): 4,
#  ('also', 'snowbal'): 4,
#  ('napoleon', 'wear'): 4,
#  ('far', 'knew'): 4,
#  ('napoleon', 'voic'): 4,
#  ('snowbal', 'turn'): 4,
#  ('full', 'snowbal'): 4,
#  ('plan', 'snowbal'): 4,
#  ('pinchfield', 'snowbal'): 4,
#  ('attack', 'snowbal'): 4,
#  ('full', 'napoleon'): 4,
#  ('napoleon', 'seen'): 4,
#  ('fire', 'napoleon'): 4,
#  ('napoleon', 'sent'): 4,
#  ('forward', 'napoleon'): 4,
#  ('napoleon', 'windmil'): 4,
#  ('death', 'frederick'): 4,
#  ('command', 'read'): 4,
#  ('go', 'windmil'): 4,
#  ('foxwood', 'sent'): 4,
#  ('away', 'van'): 4,
#  ('agreement', 'pilkington'): 4,
#  ('agreement', 'frederick'): 4,
#  ('pilkington', 'pinchfield'): 4,
#  ('pilkington', 'whymper'): 4,
#  ('attack', 'frederick'): 4,
#  ('frederick', 'windmill'): 4,
#  ('frederick', 'timber'): 4,
#  ('jones', 'never'): 3,
#  ('jones', 'make'): 3,
#  ('first', 'jones'): 3,
#  ('jones', 'three'): 3,
#  ('jones', 'use'): 3,
#  ('jones', 'rebellion'): 3,
#  ('jones', 'littl'): 3,
#  ('jones', 'turn'): 3,
#  ('found', 'jones'): 3,
#  ('jones', 'seen'): 3,
#  ('jones', 'thing'): 3,
#  ('jones', 'seem'): 3,
#  ('alreadi', 'farm'): 3,
#  ('farm', 'went'): 3,
#  ('farm', 'major'): 3,
#  ('began', 'farm'): 3,
#  ('farm', 'two'): 3,
#  ('farm', 'hand'): 3,
#  ('farm', 'given'): 3,
#  ('farm', 'saw'): 3,
#  ('farm', 'wall'): 3,
#  ('farm', 'took'): 3,
#  ('farm', 'speech'): 3,
#  ('farm', 'later'): 3,
#  ('almost', 'farm'): 3,
#  ('farm', 'rest'): 3,
#  ('farm', 'men'): 3,
#  ('farm', 'young'): 3,
#  ('dog', 'farm'): 3,
#  ('farm', 'week'): 3,
#  ('farm', 'littl'): 3,
#  ('farm', 'sinc'): 3,
#  ('farm', 'field'): 3,
#  ('complet', 'farm'): 3,
#  ('farm', 'take'): 3,
#  ('death', 'farm'): 3,
#  ('farm', 'need'): 3,
#  ('farm', 'news'): 3,
#  ('farm', 'success'): 3,
#  ('command', 'farm'): 3,
#  ('farm', 'sent'): 3,
#  ('agreement', 'farm'): 3,
#  ('farm', 'seem'): 3,
#  ('comrad', 'farm'): 3,
#  ('farm', 'half'): 3,
#  ('farm', 'windmil'): 3,
#  ('day', 'night'): 3,
#  ('night', 'old'): 3,
#  ('anim', 'night'): 3,
#  ('come', 'night'): 3,
#  ('england', 'night'): 3,
#  ('never', 'rememb'): 3,
#  ('clover', 'rememb'): 3,
#  ('could', 'rememb'): 3,
#  ('command', 'rememb'): 3,
#  ('side', 'way'): 3,
#  ('side', 'two'): 3,
#  ('clover', 'side'): 3,
#  ('side', 'small'): 3,
#  ('benjamin', 'side'): 3,
#  ('side', 'would'): 3,
#  ('side', 'sure'): 3,
#  ('napoleon', 'side'): 3,
#  ('way', 'yard'): 3,
#  ('men', 'yard'): 3,
#  ('turn', 'yard'): 3,
#  ('back', 'last'): 3,
#  ('back', 'way'): 3,
#  ('back', 'buildings'): 3,
#  ('back', 'round'): 3,
#  ('back', 'sheep'): 3,
#  ('back', 'would'): 3,
#  ('back', 'think'): 3,
#  ('back', 'dog'): 3,
#  ('back', 'could'): 3,
#  ('back', 'race'): 3,
#  ('back', 'sure'): 3,
#  ('back', 'squealer'): 3,
#  ('back', 'seen'): 3,
#  ('back', 'tri'): 3,
#  ('back', 'farmhouse'): 3,
#  ('back', 'farmhous'): 3,
#  ('door', 'walk'): 3,
#  ('door', 'moment'): 3,
#  ('door', 'napoleon'): 3,
#  ('door', 'farmhouse'): 3,
#  ('last', 'way'): 3,
#  ('last', 'word'): 3,
#  ('dream', 'last'): 3,
#  ('last', 'year'): 3,
#  ('boxer', 'last'): 3,
#  ('made', 'way'): 3,
#  ('made', 'though'): 3,
#  ('hour', 'made'): 3,
#  ('made', 'order'): 3,
#  ('made', 'one'): 3,
#  ('boxer', 'made'): 3,
#  ('look', 'made'): 3,
#  ('made', 'speech'): 3,
#  ('labour', 'made'): 3,
#  ('everi', 'made'): 3,
#  ('dog', 'made'): 3,
#  ('could', 'made'): 3,
#  ('made', 'said'): 3,
#  ('made', 'snowbal'): 3,
#  ('made', 'morn'): 3,
#  ('cri', 'made'): 3,
#  ('jone', 'way'): 3,
#  ('clover', 'way'): 3,
#  ('way', 'work'): 3,
#  ('way', 'would'): 3,
#  ('except', 'way'): 3,
#  ('time', 'way'): 3,
#  ('even', 'way'): 3,
#  ('could', 'way'): 3,
#  ('littl', 'way'): 3,
#  ('snowbal', 'way'): 3,
#  ('go', 'way'): 3,
#  ('anim', 'bed'): 3,
#  ('jone', 'meet'): 3,
#  ('jone', 'one'): 3,
#  ('jone', 'pig'): 3,
#  ('got', 'jone'): 3,
#  ('among', 'jone'): 3,
#  ('jone', 'time'): 3,
#  ('almost', 'jone'): 3,
#  ('jone', 'snowbal'): 3,
#  ('anoth', 'jone'): 3,
#  ('alreadi', 'anim'): 3,
#  ('alreadi', 'came'): 3,
#  ('alreadi', 'could'): 3,
#  ('alreadi', 'said'): 3,
#  ('alreadi', 'frederick'): 3,
#  ('soon', 'went'): 3,
#  ('could', 'soon'): 3,
#  ('abl', 'soon'): 3,
#  ('round', 'went'): 3,
#  ('day', 'went'): 3,
#  ('buildings', 'work'): 3,
#  ('long', 'word'): 3,
#  ('came', 'word'): 3,
#  ('everi', 'word'): 3,
#  ("'beast", 'word'): 3,
#  ('gone', 'men'): 3,
#  ('day', 'round'): 3,
#  ('animals', 'round'): 3,
#  ('first', 'round'): 3,
#  ('came', 'round'): 3,
#  ('round', 'sheep'): 3,
#  ('round', 'two'): 3,
#  ('boxer', 'round'): 3,
#  ('round', 'without'): 3,
#  ('round', 'time'): 3,
#  ('everi', 'round'): 3,
#  ('round', 'utter'): 3,
#  ('day', 'willingdon'): 3,
#  ('day', 'hour'): 3,
#  ('day', 'order'): 3,
#  ('day', 'long'): 3,
#  ('day', 'pigs'): 3,
#  ('day', 'two'): 3,
#  ('day', 'die'): 3,
#  ('day', 'stall'): 3,
#  ('day', 'four'): 3,
#  ('could', 'day'): 3,
#  ('day', 'rebellion'): 3,
#  ('day', 'might'): 3,
#  ('carri', 'day'): 3,
#  ('day', 'however'): 3,
#  ('call', 'day'): 3,
#  ('day', 'field'): 3,
#  ('day', 'next'): 3,
#  ('day', 'read'): 3,
#  ('day', 'thing'): 3,
#  ('day', 'farmhouse'): 3,
#  ('day', 'sent'): 3,
#  ('name', 'old'): 3,
#  ('old', 'quit'): 3,
#  ('old', 'pig'): 3,
#  ('first', 'old'): 3,
#  ('old', 'three'): 3,
#  ('except', 'old'): 3,
#  ('know', 'old'): 3,
#  ('ever', 'old'): 3,
#  ('old', 'rebellion'): 3,
#  ('old', 'said'): 3,
#  ('old', 'sing'): 3,
#  ('found', 'old'): 3,
#  ('old', 'seem'): 3,
#  ('major', 'rais'): 3,
#  ('anim', 'major'): 3,
#  ('squealer', 'white'): 3,
#  ('animals', 'pig'): 3,
#  ('animals', 'set'): 3,
#  ('animals', 'upon'): 3,
#  ('animals', 'napoleon'): 3,
#  ('meet', 'work'): 3,
#  ('meet', 'would'): 3,
#  ('meet', 'napoleon'): 3,
#  ('anim', 'big'): 3,
#  ('big', 'wall'): 3,
#  ('big', 'napoleon'): 3,
#  ('big', 'seven'): 3,
#  ('barn', 'snowbal'): 3,
#  ('barn', 'napoleon'): 3,
#  ('alway', 'anim'): 3,
#  ('alway', 'make'): 3,
#  ('alway', 'two'): 3,
#  ('alway', 'would'): 3,
#  ('alway', 'everi'): 3,
#  ('alway', 'harder'): 3,
#  ('alway', 'comrad'): 3,
#  ('quit', 'though'): 3,
#  ('make', 'though'): 3,
#  ('dogs', 'though'): 3,
#  ('though', 'two'): 3,
#  ('noth', 'though'): 3,
#  ('moment', 'though'): 3,
#  ('human', 'though'): 3,
#  ('name', 'one'): 3,
#  ('among', 'name'): 3,
#  ('name', 'young'): 3,
#  ('dog', 'name'): 3,
#  ('willingdon', 'would'): 3,
#  ('end', 'hour'): 3,
#  ('boxer', 'hour'): 3,
#  ('hour', 'later'): 3,
#  ('hour', 'morn'): 3,
#  ('half', 'hour'): 3,
#  ('appear', 'order'): 3,
#  ('order', 'pigs'): 3,
#  ('order', 'work'): 3,
#  ('order', 'sunday'): 3,
#  ('order', 'squealer'): 3,
#  ('order', 'remain'): 3,
#  ('say', 'work'): 3,
#  ('say', 'think'): 3,
#  ('could', 'say'): 3,
#  ('right', 'say'): 3,
#  ('comrad', 'say'): 3,
#  ('one', 'pig'): 3,
#  ('make', 'one'): 3,
#  ...}

# %%
import matplotlib.pyplot as plt

pair_count = []
for pair, count in new4.items():
    pair_count.append(count)
    
plt.figure(figsize=(20,10))
plt.plot(sorted(pair_count, reverse=True))

plt.title('Pair Count')
plt.ylabel('pair count')
plt.xlabel('rank')
plt.show()

# %%
#単語順位チェック
word_f = sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)

word_fdic = dict(word_f)
word_fdic
# Out:
# {'anim': 321,
#  'farm': 168,
#  'napoleon': 168,
#  'would': 138,
#  'boxer': 96,
#  'work': 95,
#  'said': 92,
#  'pig': 91,
#  'snowbal': 82,
#  'one': 80,
#  'time': 80,
#  'day': 77,
#  'could': 76,
#  'even': 70,
#  'two': 69,
#  'squealer': 67,
#  'everi': 58,
#  'back': 53,
#  'round': 52,
#  'never': 51,
#  'comrades': 51,
#  'came': 50,
#  'snowball': 49,
#  'clover': 47,
#  'come': 46,
#  'moment': 45,
#  'dog': 44,
#  'jones': 43,
#  'long': 41,
#  'human': 41,
#  'made': 40,
#  'old': 40,
#  'side': 39,
#  'jone': 39,
#  'first': 37,
#  'ever': 37,
#  'seem': 37,
#  'windmill': 37,
#  'men': 36,
#  'way': 35,
#  'upon': 35,
#  'four': 35,
#  'windmil': 35,
#  'sheep': 34,
#  'leg': 34,
#  'frederick': 34,
#  'end': 33,
#  'year': 33,
#  'make': 33,
#  'good': 33,
#  'three': 32,
#  'benjamin': 31,
#  'comrad': 30,
#  'went': 29,
#  'though': 29,
#  'say': 29,
#  'rebellion': 29,
#  'littl': 29,
#  'alway': 28,
#  'live': 28,
#  'use': 28,
#  'england': 28,
#  'go': 28,
#  'pilkington': 28,
#  'night': 27,
#  'last': 27,
#  'order': 27,
#  'appear': 27,
#  'set': 27,
#  'great': 27,
#  'yard': 26,
#  'animals': 26,
#  'much': 26,
#  'must': 26,
#  'read': 26,
#  'anoth': 26,
#  'cri': 26,
#  'without': 25,
#  'later': 25,
#  'shall': 25,
#  'away': 25,
#  'barn': 24,
#  'still': 24,
#  'look': 24,
#  'well': 24,
#  'almost': 24,
#  'better': 24,
#  'get': 24,
#  'also': 24,
#  'found': 24,
#  'thing': 24,
#  'word': 23,
#  'pigs': 23,
#  'hoof': 23,
#  'saw': 23,
#  'week': 23,
#  'morn': 23,
#  'life': 22,
#  'sunday': 22,
#  'took': 22,
#  'except': 22,
#  'mani': 22,
#  'man': 22,
#  'might': 22,
#  'call': 22,
#  'seen': 22,
#  'like': 22,
#  'major': 21,
#  'began': 21,
#  'put': 21,
#  'noth': 21,
#  'happen': 21,
#  'field': 21,
#  'believ': 21,
#  'hard': 21,
#  'build': 21,
#  'command': 21,
#  'rememb': 20,
#  'soon': 20,
#  'usual': 20,
#  'tail': 20,
#  'thought': 20,
#  'us': 20,
#  'labour': 20,
#  'turn': 20,
#  'battl': 20,
#  'announc': 20,
#  'meet': 19,
#  'given': 19,
#  'place': 19,
#  'face': 19,
#  'food': 19,
#  'know': 19,
#  'whole': 19,
#  'gun': 19,
#  'alreadi': 18,
#  'name': 18,
#  'lay': 18,
#  'wall': 18,
#  'heard': 18,
#  'enough': 18,
#  'done': 18,
#  'take': 18,
#  'death': 18,
#  'seven': 18,
#  'summer': 18,
#  'stone': 18,
#  'hour': 17,
#  'stall': 17,
#  'milk': 17,
#  'see': 17,
#  'carri': 17,
#  'suddenli': 17,
#  'sing': 17,
#  'hay': 17,
#  'need': 17,
#  'right': 17,
#  'farmhouse': 17,
#  'farmhous': 17,
#  'follow': 17,
#  'white': 16,
#  'hen': 16,
#  'among': 16,
#  'think': 16,
#  'give': 16,
#  'young': 16,
#  'certain': 16,
#  "'beast": 16,
#  'past': 16,
#  'half': 16,
#  'whymper': 16,
#  'van': 16,
#  'bed': 15,
#  'gone': 15,
#  'late': 15,
#  'fact': 15,
#  'walk': 15,
#  'hors': 15,
#  'run': 15,
#  'yet': 15,
#  'taken': 15,
#  'kind': 15,
#  'however': 15,
#  'harvest': 15,
#  'sent': 15,
#  'learn': 15,
#  'abl': 15,
#  'foxwood': 15,
#  'stood': 15,
#  'big': 14,
#  'sleep': 14,
#  'straw': 14,
#  'dogs': 14,
#  'muriel': 14,
#  'ask': 14,
#  'someth': 14,
#  'die': 14,
#  'race': 14,
#  'eye': 14,
#  'drink': 14,
#  'sinc': 14,
#  'mind': 14,
#  'comrade': 14,
#  'full': 14,
#  'forward': 14,
#  'bad': 14,
#  'terribl': 14,
#  'small': 13,
#  'got': 13,
#  'pass': 13,
#  'feet': 13,
#  'others': 13,
#  'plan': 13,
#  'fire': 13,
#  'corn': 13,
#  'sometim': 13,
#  'utter': 13,
#  'willingdon': 12,
#  'rais': 12,
#  'pigeon': 12,
#  'gave': 12,
#  'beyond': 12,
#  'speech': 12,
#  'let': 12,
#  'rest': 12,
#  'point': 12,
#  'legs': 12,
#  'black': 12,
#  'talk': 12,
#  'five': 12,
#  'written': 12,
#  'far': 12,
#  'ground': 12,
#  'flag': 12,
#  'green': 12,
#  'rumour': 12,
#  'door': 11,
#  'dream': 11,
#  'cow': 11,
#  'beast': 11,
#  'tremend': 11,
#  'orchard': 11,
#  'mollie': 11,
#  'speak': 11,
#  'part': 11,
#  'creatur': 11,
#  'equal': 11,
#  'knew': 11,
#  'known': 11,
#  'earli': 11,
#  'next': 11,
#  'whether': 11,
#  'harder': 11,
#  'led': 11,
#  'news': 11,
#  'stand': 11,
#  'remain': 11,
#  'piec': 11,
#  'notic': 11,
#  'pinchfield': 11,
#  'felt': 11,
#  'buildings': 10,
#  'quit': 10,
#  'behind': 10,
#  'care': 10,
#  'hand': 10,
#  'listen': 10,
#  'short': 10,
#  'money': 10,
#  'ration': 10,
#  'sure': 10,
#  'larg': 10,
#  'vote': 10,
#  'wear': 10,
#  'song': 10,
#  'tune': 10,
#  'voic': 10,
#  'complet': 10,
#  'reason': 10,
#  'sever': 10,
#  'sound': 10,
#  'anyth': 10,
#  'anyon': 10,
#  'days': 10,
#  'broke': 10,
#  'tri': 10,
#  'minut': 10,
#  'success': 10,
#  'broken': 10,
#  'rush': 10,
#  'outsid': 10,
#  'agreement': 10,
#  'case': 10,
#  'none': 10,
#  'class': 10,
#  'necessari': 10,
#  'attack': 10,
#  'pile': 10,
#  'winter': 10,
#  'timber': 10,
#  'confess': 10,
#  'light': 9,
#  'stir': 9,
#  'hear': 9,
#  'spite': 9,
#  'immedi': 9,
#  'together': 9,
#  'nearli': 9,
#  'keep': 9,
#  'togeth': 9,
#  'sugar': 9,
#  'feel': 9,
#  'understand': 9,
#  'number': 9,
#  'horses': 9,
#  'cows': 9,
#  'hundr': 9,
#  'beings': 9,
#  'hens': 9,
#  'egg': 9,
#  'sit': 9,
#  'spring': 9,
#  'gener': 9,
#  'tell': 9,
#  'save': 9,
#  'question': 9,
#  'whatev': 9,
#  'kill': 9,
#  'march': 9,
#  'secret': 9,
#  'held': 9,
#  'begin': 9,
#  'dead': 9,
#  'molli': 9,
#  'lie': 9,
#  'earlier': 9,
#  'accord': 9,
#  'flung': 9,
#  'pastur': 9,
#  'gaze': 9,
#  'air': 9,
#  'paint': 9,
#  'letter': 9,
#  'honour': 9,
#  'finish': 9,
#  'less': 9,
#  'nine': 9,
#  'cowshed': 9,
#  'close': 9,
#  'leader': 9,
#  'manor': 8,
#  'kick': 8,
#  'strang': 8,
#  'front': 8,
#  'slowli': 8,
#  'lost': 8,
#  'find': 8,
#  'hope': 8,
#  'ribbon': 8,
#  'final': 8,
#  'throughout': 8,
#  'clear': 8,
#  'longer': 8,
#  'singl': 8,
#  'produc': 8,
#  'enemi': 8,
#  'sight': 8,
#  'trotter': 8,
#  'mere': 8,
#  'toward': 8,
#  'spread': 8,
#  'new': 8,
#  'voice': 8,
#  'difficulti': 8,
#  'especi': 8,
#  'told': 8,
#  'everyth': 8,
#  'attend': 8,
#  'farmer': 8,
#  'world': 8,
#  'window': 8,
#  'act': 8,
#  'hide': 8,
#  'top': 8,
#  'yes': 8,
#  'hold': 8,
#  'form': 8,
#  'heart': 8,
#  'effort': 8,
#  'inch': 8,
#  'actual': 8,
#  'arrang': 8,
#  'either': 8,
#  'garden': 8,
#  'decid': 8,
#  'prove': 8,
#  'often': 8,
#  'bleat': 8,
#  'watch': 8,
#  'head': 8,
#  'receiv': 8,
#  'drag': 8,
#  'across': 7,
#  'comfort': 7,
#  'nose': 7,
#  'nevertheless': 7,
#  'cat': 7,
#  'present': 7,
#  'mean': 7,
#  'free': 7,
#  'continu': 7,
#  'bare': 7,
#  'drop': 7,
#  'allow': 7,
#  'bodi': 7,
#  'years': 7,
#  'resolut': 7,
#  'rat': 7,
#  'friend': 7,
#  'discov': 7,
#  'clever': 7,
#  'animal': 7,
#  'ran': 7,
#  'whip': 7,
#  'barley': 7,
#  'water': 7,
#  'foot': 7,
#  'eyes': 7,
#  'feed': 7,
#  'want': 7,
#  'hedg': 7,
#  'frighten': 7,
#  'road': 7,
#  'gate': 7,
#  'gallop': 7,
#  'destroy': 7,
#  'admir': 7,
#  'silenc': 7,
#  'enter': 7,
#  'six': 7,
#  'gather': 7,
#  'cockerel': 7,
#  'true': 7,
#  'kept': 7,
#  'ear': 7,
#  'indeed': 7,
#  'twice': 7,
#  'declar': 7,
#  'appl': 7,
#  'manag': 7,
#  'intend': 7,
#  'hero': 7,
#  'detail': 7,
#  'cover': 7,
#  'built': 7,
#  'cold': 7,
#  'special': 7,
#  'stop': 7,
#  'rebuild': 7,
#  'left': 7,
#  'glass': 6,
#  'beer': 6,
#  'boar': 6,
#  'agre': 6,
#  'everyon': 6,
#  'differ': 6,
#  'enorm': 6,
#  'somewhat': 6,
#  'stupid': 6,
#  'remark': 6,
#  'file': 6,
#  'near': 6,
#  'throat': 6,
#  'natur': 6,
#  'earth': 6,
#  'forc': 6,
#  'strength': 6,
#  'happi': 6,
#  'simpli': 6,
#  'support': 6,
#  'dozen': 6,
#  'bring': 6,
#  'cruel': 6,
#  'within': 6,
#  'becom': 6,
#  'futur': 6,
#  'interest': 6,
#  'crept': 6,
#  'hole': 6,
#  'forgotten': 6,
#  'words': 6,
#  'break': 6,
#  'gees': 6,
#  'prepar': 6,
#  'whisk': 6,
#  'somehow': 6,
#  'animalism': 6,
#  'sugarcandi': 6,
#  'mountain': 6,
#  'mose': 6,
#  'accept': 6,
#  'kitchen': 6,
#  'store-sh': 6,
#  'horn': 6,
#  'flight': 6,
#  'main': 6,
#  'trace': 6,
#  'harness-room': 6,
#  'open': 6,
#  'knoll': 6,
#  'crop': 6,
#  'grass': 6,
#  'snuf': 6,
#  'pool': 6,
#  'spot': 6,
#  'matter': 6,
#  'studi': 6,
#  'reduc': 6,
#  'hind': 6,
#  'direct': 6,
#  'fro': 6,
#  'possibl': 6,
#  'express': 6,
#  'assembl': 6,
#  'asid': 6,
#  'retir': 6,
#  'afternoon': 6,
#  'variou': 6,
#  'besid': 6,
#  'attempt': 6,
#  'refus': 6,
#  'unabl': 6,
#  'neighbour': 6,
#  'farms': 6,
#  'everywhere': 6,
#  'pellet': 6,
#  'blood': 6,
#  'becam': 6,
#  'weather': 6,
#  'speeches': 6,
#  'electr': 6,
#  'floor': 6,
#  'move': 6,
#  'least': 6,
#  'corner': 6,
#  'relat': 6,
#  'protest': 6,
#  'warn': 6,
#  'growl': 6,
#  'quarry': 6,
#  'terror': 6,
#  'mrs.': 5,
#  'middl': 5,
#  'wish': 5,
#  'twelv': 5,
#  'grown': 5,
#  'perch': 5,
#  'approach': 5,
#  'respect': 5,
#  'donkey': 5,
#  'instance': 5,
#  'fli': 5,
#  'spent': 5,
#  'fell': 5,
#  'draw': 5,
#  'red': 5,
#  'slept': 5,
#  'month': 5,
#  'real': 5,
#  'scene': 5,
#  'caus': 5,
#  'eggs': 5,
#  'weak': 5,
#  'plough': 5,
#  'laid': 5,
#  'age': 5,
#  'lead': 5,
#  'sell': 5,
#  'grow': 5,
#  'prosper': 5,
#  'serv': 5,
#  'afterward': 5,
#  'enemy': 5,
#  'fight': 5,
#  'alcohol': 5,
#  'engag': 5,
#  'sow': 5,
#  'toil': 5,
#  'clearli': 5,
#  'teach': 5,
#  'argu': 5,
#  'difficult': 5,
#  'skip': 5,
#  'principl': 5,
#  'master': 5,
#  'starv': 5,
#  'spirit': 5,
#  'exist': 5,
#  'season': 5,
#  'grew': 5,
#  'fallen': 5,
#  'triumph': 5,
#  'slip': 5,
#  'sprang': 5,
#  'chase': 5,
#  'five-bar': 5,
#  'hardli': 5,
#  'mark': 5,
#  'mouth': 5,
#  'inspect': 5,
#  'halt': 5,
#  'today': 5,
#  'write': 5,
#  'book': 5,
#  'writing': 5,
#  'explain': 5,
#  'wrong': 5,
#  'loud': 5,
#  'hours': 5,
#  'task': 5,
#  'mix': 5,
#  'leadership': 5,
#  'problem': 5,
#  'nobodi': 5,
#  'rations': 5,
#  'leav': 5,
#  'extra': 5,
#  'brought': 5,
#  'committe': 5,
#  'leagu': 5,
#  'immediately': 5,
#  'effect': 5,
#  'start': 5,
#  'tire': 5,
#  'instruct': 5,
#  'stori': 5,
#  'secretli': 5,
#  'idea': 5,
#  'rage': 5,
#  'ahead': 5,
#  'deal': 5,
#  'hedge': 5,
#  'line': 5,
#  'shout': 5,
#  'skull': 5,
#  'stretch': 5,
#  'oper': 5,
#  'warm': 5,
#  'increas': 5,
#  'bound': 5,
#  'sat': 5,
#  'silent': 5,
#  'previous': 5,
#  'privat': 5,
#  'expuls': 5,
#  'deep': 5,
#  "o'clock": 5,
#  'fill': 5,
#  'finally': 5,
#  'meal': 5,
#  'beds': 5,
#  'rule': 5,
#  'mill': 5,
#  'traitor': 5,
#  'pronounc': 5,
#  'thick': 5,
#  'th': 5,
#  'plot': 5,
#  'execut': 5,
#  'disappear': 5,
#  'pension': 5,
#  'victory': 5,
#  'perhap': 5,
#  'bought': 5,
#  'toast': 5,
#  'shut': 4,
#  'lantern': 4,
#  'drew': 4,
#  'flutter': 4,
#  'readi': 4,
#  'lose': 4,
#  'platform': 4,
#  'stout': 4,
#  'cut': 4,
#  'chew': 4,
#  'mare': 4,
#  'figur': 4,
#  'strong': 4,
#  'power': 4,
#  'sooner': 4,
#  'alon': 4,
#  'devot': 4,
#  'speaking': 4,
#  'insid': 4,
#  'promptli': 4,
#  'foolish': 4,
#  'lump': 4,
#  'mane': 4,
#  'moses': 4,
#  'tame': 4,
#  'raven': 4,
#  'wait': 4,
#  'duti': 4,
#  'breath': 4,
#  'instant': 4,
#  'truth': 4,
#  'land': 4,
#  'soil': 4,
#  'greater': 4,
#  'twenti': 4,
#  'digniti': 4,
#  'answer': 4,
#  'till': 4,
#  'sold': 4,
#  'return': 4,
#  'fields': 4,
#  'reach': 4,
#  'muscl': 4,
#  'knacker': 4,
#  'rich': 4,
#  'struggl': 4,
#  'remember': 4,
#  'dash': 4,
#  'repeat': 4,
#  'goe': 4,
#  'adopt': 4,
#  'house': 4,
#  'trade': 4,
#  'remind': 4,
#  'sung': 4,
#  'memori': 4,
#  'coming': 4,
#  'wheat': 4,
#  'blow': 4,
#  'peac': 4,
#  'organis': 4,
#  'best': 4,
#  'fat': 4,
#  'shrill': 4,
#  'met': 4,
#  'contrari': 4,
#  'worth': 4,
#  'mysteri': 4,
#  'hate': 4,
#  'achiev': 4,
#  'occasion': 4,
#  'drawing-room': 4,
#  'help': 4,
#  'lash': 4,
#  'hungri': 4,
#  'happening': 4,
#  'possess': 4,
#  'meanwhil': 4,
#  'rubbish': 4,
#  'wore': 4,
#  'happened': 4,
#  'excitement': 4,
#  'hayfield': 4,
#  'shoulder': 4,
#  'fear': 4,
#  'breakfast': 4,
#  'ladder': 4,
#  'commandments': 4,
#  'inscrib': 4,
#  'law': 4,
#  'mash': 4,
#  'bigger': 4,
#  'understood': 4,
#  'busi': 4,
#  'supervis': 4,
#  'needed': 4,
#  'regular': 4,
#  'excel': 4,
#  'imposs': 4,
#  'fail': 4,
#  'hoist': 4,
#  'flagstaff': 4,
#  'object': 4,
#  'product': 4,
#  'treat': 4,
#  'roof': 4,
#  'autumn': 4,
#  'maxim': 4,
#  'bird': 4,
#  'forth': 4,
#  'collect': 4,
#  'surely': 4,
#  'whose': 4,
#  'wonder': 4,
#  'pretend': 4,
#  'rapidli': 4,
#  'chang': 4,
#  'fulli': 4,
#  'speed': 4,
#  'charg': 4,
#  'second': 4,
#  'stick': 4,
#  'signal': 4,
#  'fled': 4,
#  'rear': 4,
#  'straight': 4,
#  'iron': 4,
#  'exclaim': 4,
#  'somebody': 4,
#  'alarm': 4,
#  'celebr': 4,
#  'times': 4,
#  'solemn': 4,
#  'realli': 4,
#  'stroke': 4,
#  'enjoy': 4,
#  'mention': 4,
#  'violent': 4,
#  'complic': 4,
#  'dynamo': 4,
#  'shed': 4,
#  'plans': 4,
#  'lift': 4,
#  'wast': 4,
#  'cowsh': 4,
#  'determin': 4,
#  'spoken': 4,
#  'doubt': 4,
#  'huge': 4,
#  'shock': 4,
#  'thoughts': 4,
#  'heavi': 4,
#  'compos': 4,
#  'realiti': 4,
#  'beginning': 4,
#  'meant': 4,
#  'spoke': 4,
#  'store': 4,
#  'boulder': 4,
#  'machineri': 4,
#  'onward': 4,
#  'visit': 4,
#  'convinc': 4,
#  'roar': 4,
#  'potato': 4,
#  'grain': 4,
#  'decre': 4,
#  'smell': 4,
#  'ad': 4,
#  'teeth': 4,
#  'wors': 4,
#  'agent': 4,
#  'remembered': 4,
#  'burst': 4,
#  'paper': 4,
#  'belli': 4,
#  'deadli': 4,
#  'paid': 4,
#  'compani': 4,
#  'mug': 4,
#  'gentlemen': 4,
#  'ring': 3,
#  'bedroom': 3,
#  'previou': 3,
#  'rather': 3,
#  'arriv': 3,
#  'bluebell': 3,
#  'settl': 3,
#  'fourth': 3,
#  'high': 3,
#  'seldom': 3,
#  'laugh': 3,
#  'admit': 3,
#  'paddock': 3,
#  'graze': 3,
#  'mother': 3,
#  'asleep': 3,
#  'els': 3,
#  'living': 3,
#  'capabl': 3,
#  'slaughter': 3,
#  'leisur': 3,
#  'thousand': 3,
#  'miser': 3,
#  'stolen': 3,
#  'abolish': 3,
#  'pull': 3,
#  'catch': 3,
#  'prevent': 3,
#  'dung': 3,
#  'enemies': 3,
#  'market': 3,
#  'block': 3,
#  'everyone': 3,
#  'boil': 3,
#  'neck': 3,
#  'evil': 3,
#  'messag': 3,
#  'beneath': 3,
#  'lives': 3,
#  'argument': 3,
#  'lies': 3,
#  'perfect': 3,
#  'uproar': 3,
#  'caught': 3,
#  'silence': 3,
#  'wild': 3,
#  'wings': 3,
#  'clothes': 3,
#  'smoke': 3,
#  'simple': 3,
#  'ago': 3,
#  'taught': 3,
#  'sang': 3,
#  'joy': 3,
#  'tide': 3,
#  'fruit': 3,
#  'vanish': 3,
#  'buri': 3,
#  'sale': 3,
#  'fierce-look': 3,
#  'talker': 3,
#  'consid': 3,
#  'refer': 3,
#  'situat': 3,
#  'somewher': 3,
#  'sky': 3,
#  'distanc': 3,
#  'hedges': 3,
#  'tale': 3,
#  'faith': 3,
#  'easili': 3,
#  'expected': 3,
#  'woke': 3,
#  'hands': 3,
#  'bear': 3,
#  'defend': 3,
#  'thrown': 3,
#  'fetch': 3,
#  'hat': 3,
#  'everybody': 3,
#  'gambol': 3,
#  'roll': 3,
#  'tour': 3,
#  'survey': 3,
#  'spinney': 3,
#  'disturb': 3,
#  'anything': 3,
#  'room': 3,
#  'manner': 3,
#  'outside': 3,
#  'hang': 3,
#  'hous': 3,
#  'unanim': 3,
#  'spell': 3,
#  'neatli': 3,
#  'correct': 3,
#  'benefit': 3,
#  'nod': 3,
#  'fairli': 3,
#  'consider': 3,
#  'disappeared': 3,
#  'sweat': 3,
#  'assum': 3,
#  'course': 3,
#  'duck': 3,
#  'sun': 3,
#  'moreover': 3,
#  'sharp': 3,
#  'eat': 3,
#  'style': 3,
#  'thresh': 3,
#  'worker': 3,
#  'mighti': 3,
#  'push': 3,
#  'else': 3,
#  'bushel': 3,
#  'stole': 3,
#  'quarrel': 3,
#  'mornings': 3,
#  'reappear': 3,
#  'slow': 3,
#  'observ': 3,
#  'debates': 3,
#  'oppos': 3,
#  'debat': 3,
#  'clean': 3,
#  'sparrow': 3,
#  'paw': 3,
#  'distance': 3,
#  'alphabet': 3,
#  'b': 3,
#  'forelock': 3,
#  'contain': 3,
#  'thoroughli': 3,
#  'develop': 3,
#  'import': 3,
#  'litter': 3,
#  'share': 3,
#  'explan': 3,
#  'cried': 3,
#  'imagine': 3,
#  'dislik': 3,
#  'sole': 3,
#  'health': 3,
#  ...}

# %%
count = 0
s_value = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    s_value.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
count = 0
p_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    p = (word_fdic[i[0]]  * word_fdic[i[1]]) * s * s
    p_values.append(p)
    
    count += 1
    
    if count == 1000:
        break

# %%
max(p_values)
# Out:
# 0.5714285714285714

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(p_values)

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_value)

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
s_value_top_5 = sorted(s_value, reverse=True)[:6]
s_value_top_5
# Out:
# [0.05,
#  0.03571428571428571,
#  0.034722222222222224,
#  0.030303030303030304,
#  0.030303030303030304,
#  0.030303030303030304]

# %%
print(s_value.index(s_value_top_5[0]))
print(s_value.index(s_value_top_5[1]))
print(s_value.index(s_value_top_5[2]))
print(s_value.index(s_value_top_5[3]))
print(s_value.index(s_value_top_5[4]))
# Out:
# 457
# 13
# 454
# 455
# 455

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[0]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == "pile":
        print(i,j)
    elif i ==  'timber':
        print(i,j)
# Out:
# ('pile', 'timber') 5
# pile 10
# timber 10

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[1]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'beast':
        print(i,j)
    elif i ==  "england":
        print(i,j)
# Out:
# ("'beast", 'england') 16
# england 28
# beast 11

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[2]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'flag':
        print(i,j)
    elif i ==  'green':
        print(i,j)
# Out:
# ('flag', 'green') 5
# flag 12
# green 12

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[3]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'foxwood':
        print(i,j)
    elif i ==  'pinchfield':
        print(i,j)
# Out:
# ('foxwood', 'pinchfield') 5
# foxwood 15
# pinchfield 11

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[4]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'foxwood':
        print(i,j)
    elif i ==  'pinchfield':
        print(i,j)
# Out:
# ('foxwood', 'pinchfield') 5
# foxwood 15
# pinchfield 11

# %%
from math import log
log_list = [log(y,10) for y in s_value]

#take a log
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_list, reverse=True))

plt.ylabel('s value(log scale)')
plt.xlabel('rank (Descending order of s value)')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(log_list)+1)
y = sorted(log_list, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('s value(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
from math import log

sorted_list = sorted(s_value, reverse=True)
sorted_list

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_value)+1)]


#take a log
import matplotlib.pyplot as plt
import numpy as np

x = np.array(log_x[:-700])
y = np.array(log_list[:-700])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
# i,j count
import numpy as np

len(word_f)
# Out:
# 3483

# %%
i = np.arange(len(word_f), 0, -1)
j = np.arange(1,len(word_f)+1, 1)

def square(list):
    return [i ** -2 for i in list]
square(i)
# Out:
# [8.2431471214641742e-08,
#  8.247882521120353e-08,
#  8.2526220024310571e-08,
#  8.2573655700885196e-08,
#  8.2621132287917125e-08,
#  8.266864983246371e-08,
#  8.2716208381649936e-08,
#  8.2763807982668598e-08,
#  8.2811448682780391e-08,
#  8.2859130529314074e-08,
#  8.2906853569666502e-08,
#  8.2954617851302858e-08,
#  8.3002423421756647e-08,
#  8.3050270328629916e-08,
#  8.3098158619593336e-08,
#  8.3146088342386279e-08,
#  8.3194059544817017e-08,
#  8.3242072274762766e-08,
#  8.3290126580169864e-08,
#  8.333822250905387e-08,
#  8.3386360109499627e-08,
#  8.3434539429661513e-08,
#  8.3482760517763418e-08,
#  8.3531023422098963e-08,
#  8.3579328191031588e-08,
#  8.3627674872994647e-08,
#  8.3676063516491592e-08,
#  8.3724494170096016e-08,
#  8.3772966882451869e-08,
#  8.3821481702273472e-08,
#  8.3870038678345742e-08,
#  8.3918637859524227e-08,
#  8.3967279294735311e-08,
#  8.4015963032976264e-08,
#  8.4064689123315413e-08,
#  8.4113457614892249e-08,
#  8.4162268556917548e-08,
#  8.4211121998673511e-08,
#  8.4260017989513839e-08,
#  8.4308956578863947e-08,
#  8.4357937816221002e-08,
#  8.4406961751154099e-08,
#  8.4456028433304357e-08,
#  8.4505137912385068e-08,
#  8.4554290238181824e-08,
#  8.4603485460552611e-08,
#  8.4652723629427958e-08,
#  8.4702004794811091e-08,
#  8.4751329006777989e-08,
#  8.4800696315477582e-08,
#  8.4850106771131856e-08,
#  8.4899560424035948e-08,
#  8.4949057324558326e-08,
#  8.4998597523140862e-08,
#  8.5048181070299039e-08,
#  8.509780801662198e-08,
#  8.514747841277267e-08,
#  8.5197192309487998e-08,
#  8.5246949757578985e-08,
#  8.5296750807930828e-08,
#  8.5346595511503056e-08,
#  8.5396483919329695e-08,
#  8.5446416082519362e-08,
#  8.5496392052255401e-08,
#  8.5546411879795996e-08,
#  8.5596475616474374e-08,
#  8.5646583313698859e-08,
#  8.5696735022953013e-08,
#  8.5746930795795823e-08,
#  8.5797170683861796e-08,
#  8.5847454738861063e-08,
#  8.5897783012579564e-08,
#  8.5948155556879154e-08,
#  8.5998572423697762e-08,
#  8.6049033665049486e-08,
#  8.6099539333024746e-08,
#  8.6150089479790437e-08,
#  8.6200684157590027e-08,
#  8.6251323418743711e-08,
#  8.6302007315648561e-08,
#  8.6352735900778628e-08,
#  8.6403509226685131e-08,
#  8.6454327345996531e-08,
#  8.6505190311418685e-08,
#  8.655609817573502e-08,
#  8.6607050991806626e-08,
#  8.6658048812572414e-08,
#  8.6709091691049261e-08,
#  8.6760179680332117e-08,
#  8.6811312833594176e-08,
#  8.6862491204086985e-08,
#  8.6913714845140624e-08,
#  8.696498381016379e-08,
#  8.7016298152643992e-08,
#  8.7067657926147647e-08,
#  8.7119063184320237e-08,
#  8.7170513980886467e-08,
#  8.7222010369650375e-08,
#  8.7273552404495456e-08,
#  8.7325140139384897e-08,
#  8.7376773628361597e-08,
#  8.7428452925548381e-08,
#  8.748017808514813e-08,
#  8.753194916144393e-08,
#  8.7583766208799177e-08,
#  8.763562928165776e-08,
#  8.7687538434544196e-08,
#  8.7739493722063748e-08,
#  8.779149519890261e-08,
#  8.7843542919828013e-08,
#  8.7895636939688384e-08,
#  8.7947777313413519e-08,
#  8.7999964096014648e-08,
#  8.8052197342584686e-08,
#  8.8104477108298287e-08,
#  8.8156803448412056e-08,
#  8.8209176418264627e-08,
#  8.826159607327689e-08,
#  8.8314062468952081e-08,
#  8.8366575660875944e-08,
#  8.8419135704716873e-08,
#  8.8471742656226061e-08,
#  8.8524396571237656e-08,
#  8.8577097505668936e-08,
#  8.8629845515520372e-08,
#  8.8682640656875869e-08,
#  8.8735482985902856e-08,
#  8.8788372558852486e-08,
#  8.8841309432059718e-08,
#  8.8894293661943535e-08,
#  8.8947325305007045e-08,
#  8.9000404417837673e-08,
#  8.905353105710727e-08,
#  8.9106705279572284e-08,
#  8.9159927142073934e-08,
#  8.9213196701538325e-08,
#  8.92665140149766e-08,
#  8.9319879139485144e-08,
#  8.9373292132245655e-08,
#  8.9426753050525398e-08,
#  8.9480261951677262e-08,
#  8.9533818893139956e-08,
#  8.9587423932438187e-08,
#  8.9641077127182755e-08,
#  8.9694778535070791e-08,
#  8.9748528213885825e-08,
#  8.9802326221497981e-08,
#  8.9856172615864139e-08,
#  8.9910067455028105e-08,
#  8.9964010797120718e-08,
#  9.0018002700360047e-08,
#  9.0072043223051527e-08,
#  9.0126132423588139e-08,
#  9.0180270360450547e-08,
#  9.0234457092207255e-08,
#  9.0288692677514791e-08,
#  9.0342977175117841e-08,
#  9.0397310643849422e-08,
#  9.0451693142631011e-08,
#  9.050612473047276e-08,
#  9.05606054664736e-08,
#  9.0615135409821454e-08,
#  9.0669714619793329e-08,
#  9.0724343155755554e-08,
#  9.0779021077163899e-08,
#  9.0833748443563722e-08,
#  9.0888525314590179e-08,
#  9.0943351749968357e-08,
#  9.0998227809513406e-08,
#  9.1053153553130793e-08,
#  9.110812904081635e-08,
#  9.1163154332656543e-08,
#  9.1218229488828551e-08,
#  9.12733545696005e-08,
#  9.1328529635331576e-08,
#  9.1383754746472217e-08,
#  9.1439029963564288e-08,
#  9.1494355347241212e-08,
#  9.1549730958228146e-08,
#  9.1605156857342187e-08,
#  9.1660633105492496e-08,
#  9.1716159763680478e-08,
#  9.1771736892999934e-08,
#  9.1827364554637282e-08,
#  9.1883042809871663e-08,
#  9.1938771720075126e-08,
#  9.1994551346712843e-08,
#  9.2050381751343198e-08,
#  9.2106262995618039e-08,
#  9.21621951412828e-08,
#  9.221817825017667e-08,
#  9.2274212384232777e-08,
#  9.2330297605478367e-08,
#  9.2386433976034953e-08,
#  9.2442621558118536e-08,
#  9.2498860414039705e-08,
#  9.2555150606203837e-08,
#  9.2611492197111336e-08,
#  9.2667885249357698e-08,
#  9.2724329825633751e-08,
#  9.2780825988725826e-08,
#  9.2837373801515927e-08,
#  9.2893973326981868e-08,
#  9.2950624628197508e-08,
#  9.3007327768332881e-08,
#  9.3064082810654429e-08,
#  9.3120889818525072e-08,
#  9.3177748855404533e-08,
#  9.3234659984849371e-08,
#  9.3291623270513241e-08,
#  9.3348638776147071e-08,
#  9.3405706565599198e-08,
#  9.3462826702815594e-08,
#  9.3519999251840011e-08,
#  9.3577224276814162e-08,
#  9.3634501841977915e-08,
#  9.3691832011669509e-08,
#  9.3749214850325626e-08,
#  9.3806650422481706e-08,
#  9.3864138792772014e-08,
#  9.3921680025929892e-08,
#  9.3979274186787942e-08,
#  9.403692134027815e-08,
#  9.4094621551432118e-08,
#  9.4152374885381254e-08,
#  9.4210181407356914e-08,
#  9.4268041182690618e-08,
#  9.4325954276814231e-08,
#  9.4383920755260138e-08,
#  9.4441940683661428e-08,
#  9.4500014127752107e-08,
#  9.4558141153367254e-08,
#  9.4616321826443196e-08,
#  9.4674556213017758e-08,
#  9.4732844379230357e-08,
#  9.4791186391322278e-08,
#  9.4849582315636834e-08,
#  9.490803221861951e-08,
#  9.4966536166818219e-08,
#  9.5025094226883442e-08,
#  9.5083706465568429e-08,
#  9.5142372949729437e-08,
#  9.5201093746325838e-08,
#  9.5259868922420367e-08,
#  9.5318698545179294e-08,
#  9.5377582681872654e-08,
#  9.5436521399874347e-08,
#  9.5495514766662445e-08,
#  9.5554562849819286e-08,
#  9.5613665717031734e-08,
#  9.5672823436091372e-08,
#  9.5732036074894612e-08,
#  9.5791303701443033e-08,
#  9.5850626383843418e-08,
#  9.5910004190308085e-08,
#  9.5969437189154992e-08,
#  9.6028925448807989e-08,
#  9.608846903779698e-08,
#  9.6148068024758128e-08,
#  9.6207722478434074e-08,
#  9.6267432467674117e-08,
#  9.6327198061434403e-08,
#  9.6387019328778146e-08,
#  9.6446896338875816e-08,
#  9.650682916100534e-08,
#  9.6566817864552293e-08,
#  9.6626862519010132e-08,
#  9.6686963193980348e-08,
#  9.6747119959172719e-08,
#  9.6807332884405458e-08,
#  9.6867602039605477e-08,
#  9.6927927494808543e-08,
#  9.6988309320159479e-08,
#  9.7048747585912403e-08,
#  9.7109242362430923e-08,
#  9.7169793720188314e-08,
#  9.7230401729767737e-08,
#  9.7291066461862484e-08,
#  9.7351787987276118e-08,
#  9.7412566376922727e-08,
#  9.7473401701827109e-08,
#  9.7534294033124983e-08,
#  9.7595243442063216e-08,
#  9.7656250000000005e-08,
#  9.7717313778405079e-08,
#  9.7778434848859961e-08,
#  9.7839613283058116e-08,
#  9.7900849152805213e-08,
#  9.7962142530019273e-08,
#  9.8023493486730958e-08,
#  9.8084902095083706e-08,
#  9.8146368427333994e-08,
#  9.8207892555851561e-08,
#  9.8269474553119559e-08,
#  9.8331114491734825e-08,
#  9.8392812444408058e-08,
#  9.8454568483964065e-08,
#  9.851638268334194e-08,
#  9.8578255115595324e-08,
#  9.8640185853892575e-08,
#  9.8702174971517014e-08,
#  9.8764222541867141e-08,
#  9.8826328638456828e-08,
#  9.888849333491555e-08,
#  9.8950716704988631e-08,
#  9.9012998822537423e-08,
#  9.9075339761539534e-08,
#  9.9137739596089051e-08,
#  9.9200198400396807e-08,
#  9.9262716248790486e-08,
#  9.9325293215714968e-08,
#  9.9387929375732483e-08,
#  9.9450624803522857e-08,
#  9.9513379573883705e-08,
#  9.9576193761730697e-08,
#  9.9639067442097744e-08,
#  9.9702000690137248e-08,
#  9.9764993581120315e-08,
#  9.9828046190436969e-08,
#  9.9891158593596423e-08,
#  9.9954330866227219e-08,
#  1.0001756308407757e-07,
#  1.0008085532301547e-07,
#  1.00144207659029e-07,
#  1.0020762016822654e-07,
#  1.0027109292683699e-07,
#  1.0033462601120999e-07,
#  1.0039821949781614e-07,
#  1.0046187346324727e-07,
#  1.0052558798421668e-07,
#  1.0058936313755927e-07,
#  1.006531990002319e-07,
#  1.0071709564931354e-07,
#  1.0078105316200555e-07,
#  1.0084507161563184e-07,
#  1.0090915108763919e-07,
#  1.0097329165559746e-07,
#  1.010374933971998e-07,
#  1.0110175639026289e-07,
#  1.0116608071272718e-07,
#  1.0123046644265714e-07,
#  1.0129491365824149e-07,
#  1.0135942243779344e-07,
#  1.014239928597509e-07,
#  1.0148862500267676e-07,
#  1.0155331894525911e-07,
#  1.0161807476631146e-07,
#  1.0168289254477302e-07,
#  1.017477723597089e-07,
#  1.018127142903104e-07,
#  1.0187771841589521e-07,
#  1.0194278481590764e-07,
#  1.0200791356991893e-07,
#  1.0207310475762741e-07,
#  1.0213835845885882e-07,
#  1.022036747535665e-07,
#  1.0226905372183165e-07,
#  1.023344954438636e-07,
#  1.024e-07,
#  1.0246556747070714e-07,
#  1.0253119793658015e-07,
#  1.0259689147834323e-07,
#  1.0266264817684996e-07,
#  1.027284681130835e-07,
#  1.0279435136815684e-07,
#  1.0286029802331308e-07,
#  1.0292630815992567e-07,
#  1.0299238185949862e-07,
#  1.0305851920366682e-07,
#  1.0312472027419626e-07,
#  1.0319098515298425e-07,
#  1.0325731392205973e-07,
#  1.0332370666358349e-07,
#  1.0339016345984843e-07,
#  1.0345668439327982e-07,
#  1.0352326954643557e-07,
#  1.0358991900200644e-07,
#  1.0365663284281633e-07,
#  1.0372341115182255e-07,
#  1.0379025401211607e-07,
#  1.0385716150692172e-07,
#  1.0392413371959855e-07,
#  1.0399117073364003e-07,
#  1.0405827263267429e-07,
#  1.0412543950046445e-07,
#  1.041926714209088e-07,
#  1.0425996847804113e-07,
#  1.0432733075603095e-07,
#  1.0439475833918379e-07,
#  1.0446225131194141e-07,
#  1.0452980975888213e-07,
#  1.0459743376472104e-07,
#  1.046651234143103e-07,
#  1.0473287879263937e-07,
#  1.0480069998483534e-07,
#  1.0486858707616312e-07,
#  1.0493654015202576e-07,
#  1.0500455929796472e-07,
#  1.0507264459966009e-07,
#  1.0514079614293092e-07,
#  1.0520901401373546e-07,
#  1.0527729829817142e-07,
#  1.0534564908247627e-07,
#  1.0541406645302749e-07,
#  1.0548255049634287e-07,
#  1.0555110129908073e-07,
#  1.0561971894804027e-07,
#  1.0568840353016178e-07,
#  1.0575715513252694e-07,
#  1.0582597384235909e-07,
#  1.0589485974702353e-07,
#  1.0596381293402777e-07,
#  1.0603283349102183e-07,
#  1.0610192150579847e-07,
#  1.0617107706629354e-07,
#  1.0624030026058621e-07,
#  1.0630959117689926e-07,
#  1.063789499035994e-07,
#  1.0644837652919745e-07,
#  1.0651787114234878e-07,
#  1.0658743383185342e-07,
#  1.0665706468665648e-07,
#  1.0672676379584835e-07,
#  1.0679653124866504e-07,
#  1.0686636713448844e-07,
#  1.0693627154284658e-07,
#  1.0700624456341398e-07,
#  1.070762862860119e-07,
#  1.0714639680060859e-07,
#  1.0721657619731967e-07,
#  1.0728682456640835e-07,
#  1.0735714199828572e-07,
#  1.0742752858351109e-07,
#  1.0749798441279226e-07,
#  1.0756850957698576e-07,
#  1.0763910416709723e-07,
#  1.0770976827428164e-07,
#  1.0778050198984362e-07,
#  1.0785130540523779e-07,
#  1.0792217861206897e-07,
#  1.0799312170209256e-07,
#  1.0806413476721472e-07,
#  1.0813521789949286e-07,
#  1.0820637119113573e-07,
#  1.0827759473450387e-07,
#  1.0834888862210985e-07,
#  1.0842025294661853e-07,
#  1.0849168780084745e-07,
#  1.0856319327776707e-07,
#  1.086347694705011e-07,
#  1.0870641647232677e-07,
#  1.0877813437667519e-07,
#  1.0884992327713158e-07,
#  1.0892178326743565e-07,
#  1.0899371444148187e-07,
#  1.0906571689331977e-07,
#  1.0913779071715425e-07,
#  1.092099360073459e-07,
#  1.0928215285841131e-07,
#  1.0935444136502338e-07,
#  1.094268016220116e-07,
#  1.094992337243624e-07,
#  1.0957173776721945e-07,
#  1.0964431384588396e-07,
#  1.0971696205581499e-07,
#  1.0978968249262981e-07,
#  1.0986247525210417e-07,
#  1.0993534043017259e-07,
#  1.1000827812292874e-07,
#  1.1008128842662576e-07,
#  1.1015437143767647e-07,
#  1.1022752725265384e-07,
#  1.1030075596829118e-07,
#  1.1037405768148254e-07,
#  1.1044743248928301e-07,
#  1.1052088048890901e-07,
#  1.1059440177773865e-07,
#  1.1066799645331206e-07,
#  1.1074166461333163e-07,
#  1.1081540635566248e-07,
#  1.1088922177833266e-07,
#  1.1096311097953352e-07,
#  1.1103707405762002e-07,
#  1.1111111111111111e-07,
#  1.1118522223868999e-07,
#  1.1125940753920448e-07,
#  1.1133366711166734e-07,
#  1.1140800105525658e-07,
#  1.1148240946931586e-07,
#  1.1155689245335472e-07,
#  1.1163145010704898e-07,
#  1.1170608253024106e-07,
#  1.1178078982294034e-07,
#  1.1185557208532343e-07,
#  1.1193042941773455e-07,
#  1.1200536192068587e-07,
#  1.1208036969485784e-07,
#  1.1215545284109949e-07,
#  1.1223061146042889e-07,
#  1.1230584565403331e-07,
#  1.123811555232697e-07,
#  1.1245654116966499e-07,
#  1.125320026949164e-07,
#  1.1260754020089185e-07,
#  1.1268315378963024e-07,
#  1.1275884356334182e-07,
#  1.1283460962440856e-07,
#  1.1291045207538443e-07,
#  1.1298637101899584e-07,
#  1.1306236655814187e-07,
#  1.1313843879589475e-07,
#  1.1321458783550011e-07,
#  1.1329081378037737e-07,
#  1.133671167341201e-07,
#  1.1344349680049634e-07,
#  1.1351995408344898e-07,
#  1.1359648868709608e-07,
#  1.1367310071573131e-07,
#  1.1374979027382418e-07,
#  1.1382655746602049e-07,
#  1.1390340239714266e-07,
#  1.1398032517219008e-07,
#  1.1405732589633945e-07,
#  1.1413440467494521e-07,
#  1.1421156161353983e-07,
#  1.1428879681783417e-07,
#  1.1436611039371792e-07,
#  1.1444350244725986e-07,
#  1.145209730847083e-07,
#  1.1459852241249142e-07,
#  1.1467615053721763e-07,
#  1.1475385756567593e-07,
#  1.148316436048363e-07,
#  1.1490950876185004e-07,
#  1.1498745314405019e-07,
#  1.1506547685895182e-07,
#  1.1514358001425247e-07,
#  1.1522176271783251e-07,
#  1.1530002507775546e-07,
#  1.1537836720226843e-07,
#  1.1545678919980247e-07,
#  1.1553529117897295e-07,
#  1.1561387324857989e-07,
#  1.1569253551760841e-07,
#  1.1577127809522906e-07,
#  1.1585010109079822e-07,
#  1.1592900461385846e-07,
#  1.1600798877413894e-07,
#  1.160870536815558e-07,
#  1.161661994462125e-07,
#  1.1624542617840023e-07,
#  1.1632473398859832e-07,
#  1.1640412298747456e-07,
#  1.1648359328588568e-07,
#  1.1656314499487763e-07,
#  1.1664277822568605e-07,
#  1.1672249308973661e-07,
#  1.1680228969864542e-07,
#  1.1688216816421944e-07,
#  1.1696212859845685e-07,
#  1.1704217111354741e-07,
#  1.1712229582187291e-07,
#  1.1720250283600756e-07,
#  1.1728279226871834e-07,
#  1.1736316423296542e-07,
#  1.1744361884190257e-07,
#  1.1752415620887757e-07,
#  1.1760477644743255e-07,
#  1.1768547967130445e-07,
#  1.1776626599442542e-07,
#  1.1784713553092315e-07,
#  1.1792808839512136e-07,
#  1.1800912470154017e-07,
#  1.180902445648965e-07,
#  1.1817144810010445e-07,
#  1.1825273542227579e-07,
#  1.1833410664672026e-07,
#  1.184155618889461e-07,
#  1.1849710126466032e-07,
#  1.1857872488976921e-07,
#  1.1866043288037878e-07,
#  1.1874222535279502e-07,
#  1.1882410242352451e-07,
#  1.1890606420927467e-07,
#  1.1898811082695428e-07,
#  1.1907024239367385e-07,
#  1.1915245902674604e-07,
#  1.1923476084368608e-07,
#  1.1931714796221226e-07,
#  1.1939962050024619e-07,
#  1.1948217857591342e-07,
#  1.1956482230754368e-07,
#  1.1964755181367144e-07,
#  1.1973036721303623e-07,
#  1.198132686245832e-07,
#  1.1989625616746342e-07,
#  1.1997932996103431e-07,
#  1.2006249012486018e-07,
#  1.2014573677871258e-07,
#  1.2022907004257071e-07,
#  1.2031249003662192e-07,
#  1.203959968812621e-07,
#  1.2047959069709612e-07,
#  1.2056327160493827e-07,
#  1.206470397258127e-07,
#  1.2073089518095389e-07,
#  1.2081483809180694e-07,
#  1.2089886858002828e-07,
#  1.2098298676748583e-07,
#  1.210671927762596e-07,
#  1.2115148672864211e-07,
#  1.2123586874713884e-07,
#  1.2132033895446861e-07,
#  1.2140489747356409e-07,
#  1.2148954442757225e-07,
#  1.2157427993985477e-07,
#  1.2165910413398851e-07,
#  1.21744017133766e-07,
#  1.2182901906319577e-07,
#  1.2191411004650292e-07,
#  1.2199929020812957e-07,
#  1.2208455967273526e-07,
#  1.2216991856519738e-07,
#  1.2225536701061177e-07,
#  1.2234090513429299e-07,
#  1.2242653306177495e-07,
#  1.2251225091881125e-07,
#  1.225980588313757e-07,
#  1.2268395692566271e-07,
#  1.2276994532808793e-07,
#  1.2285602416528853e-07,
#  1.2294219356412371e-07,
#  1.2302845365167521e-07,
#  1.2311480455524776e-07,
#  1.2320124640236959e-07,
#  1.2328777932079282e-07,
#  1.2337440343849398e-07,
#  1.2346111888367443e-07,
#  1.2354792578476097e-07,
#  1.2363482427040617e-07,
#  1.2372181446948891e-07,
#  1.2380889651111481e-07,
#  1.2389607052461685e-07,
#  1.2398333663955565e-07,
#  1.2407069498572009e-07,
#  1.2415814569312774e-07,
#  1.242456888920254e-07,
#  1.2433332471288949e-07,
#  1.2442105328642661e-07,
#  1.2450887474357397e-07,
#  1.2459678921549999e-07,
#  1.2468479683360465e-07,
#  1.2477289772952007e-07,
#  1.2486109203511093e-07,
#  1.2494937988247512e-07,
#  1.2503776140394399e-07,
#  1.2512623673208307e-07,
#  1.2521480599969248e-07,
#  1.2530346933980736e-07,
#  1.2539222688569845e-07,
#  1.2548107877087267e-07,
#  1.2557002512907344e-07,
#  1.2565906609428125e-07,
#  1.2574820180071426e-07,
#  1.2583743238282869e-07,
#  1.2592675797531937e-07,
#  1.2601617871312026e-07,
#  1.2610569473140496e-07,
#  1.2619530616558718e-07,
#  1.2628501315132126e-07,
#  1.2637481582450278e-07,
#  1.2646471432126894e-07,
#  1.2655470877799911e-07,
#  1.2664479933131545e-07,
#  1.2673498611808331e-07,
#  1.2682526927541173e-07,
#  1.2691564894065411e-07,
#  1.2700612525140861e-07,
#  1.2709669834551872e-07,
#  1.2718736836107376e-07,
#  1.2727813543640937e-07,
#  1.2736899971010817e-07,
#  1.2745996132100012e-07,
#  1.2755102040816326e-07,
#  1.27642177110924e-07,
#  1.2773343156885777e-07,
#  1.2782478392178964e-07,
#  1.279162343097947e-07,
#  1.2800778287319869e-07,
#  1.2809942975257851e-07,
#  1.2819117508876277e-07,
#  1.2828301902283233e-07,
#  1.2837496169612079e-07,
#  1.2846700325021519e-07,
#  1.285591438269563e-07,
#  1.2865138356843946e-07,
#  1.2874372261701485e-07,
#  1.2883616111528826e-07,
#  1.2892869920612155e-07,
#  1.2902133703263311e-07,
#  1.2911407473819861e-07,
#  1.2920691246645143e-07,
#  1.2929985036128317e-07,
#  1.2939288856684436e-07,
#  1.2948602722754488e-07,
#  1.295792664880546e-07,
#  1.2967260649330389e-07,
#  1.2976604738848426e-07,
#  1.2985958931904877e-07,
#  1.2995323243071283e-07,
#  1.3004697686945456e-07,
#  1.3014082278151542e-07,
#  1.3023477031340085e-07,
#  1.3032881961188078e-07,
#  1.3042297082399016e-07,
#  1.3051722409702963e-07,
#  1.3061157957856605e-07,
#  1.3070603741643309e-07,
#  1.3080059775873175e-07,
#  1.3089526075383105e-07,
#  1.3099002655036847e-07,
#  1.3108489529725073e-07,
#  1.3117986714365415e-07,
#  1.3127494223902541e-07,
#  1.3137012073308206e-07,
#  1.3146540277581309e-07,
#  1.3156078851747963e-07,
#  1.3165627810861538e-07,
#  1.3175187170002734e-07,
#  1.3184756944279635e-07,
#  1.3194337148827768e-07,
#  1.3203927798810169e-07,
#  1.3213528909417426e-07,
#  1.3223140495867768e-07,
#  1.3232762573407097e-07,
#  1.3242395157309061e-07,
#  1.3252038262875116e-07,
#  1.3261691905434587e-07,
#  1.3271356100344724e-07,
#  1.3281030862990761e-07,
#  1.3290716208785986e-07,
#  1.3300412153171803e-07,
#  1.3310118711617778e-07,
#  1.3319835899621716e-07,
#  1.3329563732709724e-07,
#  1.3339302226436257e-07,
#  1.3349051396384196e-07,
#  1.3358811258164906e-07,
#  1.3368581827418292e-07,
#  1.3378363119812875e-07,
#  1.3388155151045836e-07,
#  1.3397957936843098e-07,
#  1.3407771492959379e-07,
#  1.3417595835178253e-07,
#  1.3427430979312222e-07,
#  1.3437276941202776e-07,
#  1.3447133736720452e-07,
#  1.3457001381764902e-07,
#  1.346687989226496e-07,
#  1.3476769284178703e-07,
#  1.3486669573493514e-07,
#  1.349658077622615e-07,
#  1.3506502908422803e-07,
#  1.3516435986159171e-07,
#  1.3526380025540511e-07,
#  1.3536335042701723e-07,
#  1.3546301053807398e-07,
#  1.3556278075051895e-07,
#  1.3566266122659394e-07,
#  1.3576265212883983e-07,
#  1.3586275362009703e-07,
#  1.3596296586350625e-07,
#  1.3606328902250909e-07,
#  1.3616372326084885e-07,
#  1.3626426874257105e-07,
#  1.3636492563202415e-07,
#  1.3646569409386028e-07,
#  1.3656657429303581e-07,
#  1.3666756639481209e-07,
#  1.3676867056475614e-07,
#  1.3686988696874125e-07,
#  1.3697121577294774e-07,
#  1.3707265714386365e-07,
#  1.3717421124828532e-07,
#  1.372758782533182e-07,
#  1.3737765832637744e-07,
#  1.3747955163518865e-07,
#  1.3758155834778856e-07,
#  1.3768367863252569e-07,
#  1.377859126580611e-07,
#  1.3788826059336904e-07,
#  1.3799072260773765e-07,
#  1.3809329887076966e-07,
#  1.3819598955238318e-07,
#  1.3829879482281229e-07,
#  1.3840171485260771e-07,
#  1.3850474981263769e-07,
#  1.3860789987408858e-07,
#  1.3871116520846555e-07,
#  1.3881454598759331e-07,
#  1.389180423836169e-07,
#  1.390216545690023e-07,
#  1.3912538271653718e-07,
#  1.392292269993317e-07,
#  1.3933318759081912e-07,
#  1.3943726466475655e-07,
#  1.395414583952258e-07,
#  1.3964576895663383e-07,
#  1.3975019652371387e-07,
#  1.3985474127152575e-07,
#  1.3995940337545691e-07,
#  1.4006418301122306e-07,
#  1.4016908035486886e-07,
#  1.4027409558276873e-07,
#  1.4037922887162755e-07,
#  1.4048448039848143e-07,
#  1.4058985034069841e-07,
#  1.406953388759793e-07,
#  1.4080094618235834e-07,
#  1.4090667243820398e-07,
#  1.4101251782221961e-07,
#  1.4111848251344436e-07,
#  1.4122456669125386e-07,
#  1.4133077053536095e-07,
#  1.4143709422581649e-07,
#  1.4154353794301004e-07,
#  1.4165010186767077e-07,
#  1.4175678618086804e-07,
#  1.418635910640124e-07,
#  1.4197051669885611e-07,
#  1.4207756326749413e-07,
#  1.421847309523647e-07,
#  1.4229201993625032e-07,
#  1.4239943040227839e-07,
#  1.4250696253392199e-07,
#  1.4261461651500076e-07,
#  1.4272239252968162e-07,
#  1.4283029076247951e-07,
#  1.4293831139825829e-07,
#  1.4304645462223149e-07,
#  1.4315472061996301e-07,
#  1.432631095773681e-07,
#  1.4337162168071397e-07,
#  1.4348025711662076e-07,
#  1.4358901607206216e-07,
#  1.4369789873436639e-07,
#  1.438069052912169e-07,
#  1.439160359306532e-07,
#  1.440252908410717e-07,
#  1.4413467021122647e-07,
#  1.4424417423023015e-07,
#  1.4435380308755462e-07,
#  1.4446355697303198e-07,
#  1.4457343607685524e-07,
#  1.4468344058957922e-07,
#  1.4479357070212141e-07,
#  1.4490382660576262e-07,
#  1.4501420849214805e-07,
#  1.4512471655328798e-07,
#  1.452353509815586e-07,
#  1.4534611196970289e-07,
#  1.4545699971083148e-07,
#  1.4556801439842343e-07,
#  1.4567915622632712e-07,
#  1.4579042538876111e-07,
#  1.4590182208031486e-07,
#  1.4601334649594982e-07,
#  1.46124998831e-07,
#  1.4623677928117312e-07,
#  1.4634868804255117e-07,
#  1.4646072531159154e-07,
#  1.4657289128512765e-07,
#  1.4668518616037002e-07,
#  1.4679761013490699e-07,
#  1.4691016340670567e-07,
#  1.4702284617411268e-07,
#  1.4713565863585528e-07,
#  1.47248600991042e-07,
#  1.4736167343916358e-07,
#  1.4747487618009396e-07,
#  1.4758820941409104e-07,
#  1.4770167334179763e-07,
#  1.4781526816424228e-07,
#  1.4792899408284022e-07,
#  1.4804285129939432e-07,
#  1.4815684001609577e-07,
#  1.4827096043552518e-07,
#  1.4838521276065347e-07,
#  1.484995971948426e-07,
#  1.4861411394184671e-07,
#  1.487287632058128e-07,
#  1.4884354519128182e-07,
#  1.4895846010318948e-07,
#  1.4907350814686722e-07,
#  1.4918868952804308e-07,
#  1.4930400445284262e-07,
#  1.4941945312778995e-07,
#  1.4953503575980845e-07,
#  1.4965075255622191e-07,
#  1.4976660372475533e-07,
#  1.498825894735359e-07,
#  1.4999871001109391e-07,
#  1.5011496554636367e-07,
#  1.5023135628868456e-07,
#  1.5034788244780185e-07,
#  1.5046454423386765e-07,
#  1.5058134185744193e-07,
#  1.5069827552949346e-07,
#  1.5081534546140071e-07,
#  1.5093255186495281e-07,
#  1.5104989495235057e-07,
#  1.5116737493620736e-07,
#  1.5128499202955019e-07,
#  1.5140274644582052e-07,
#  1.5152063839887534e-07,
#  1.5163866810298813e-07,
#  1.5175683577284976e-07,
#  1.5187514162356957e-07,
#  1.5199358587067627e-07,
#  1.5211216873011893e-07,
#  1.5223089041826808e-07,
#  1.5234975115191648e-07,
#  1.5246875114828027e-07,
#  1.52587890625e-07,
#  1.5270716980014144e-07,
#  1.5282658889219673e-07,
#  1.5294614812008535e-07,
#  1.5306584770315511e-07,
#  1.5318568786118312e-07,
#  1.5330566881437689e-07,
#  1.5342579078337521e-07,
#  1.5354605398924933e-07,
#  1.536664586535038e-07,
#  1.5378700499807765e-07,
#  1.5390769324534532e-07,
#  1.5402852361811769e-07,
#  1.5414949633964312e-07,
#  1.5427061163360853e-07,
#  1.5439186972414032e-07,
#  1.5451327083580555e-07,
#  1.5463481519361283e-07,
#  1.5475650302301353e-07,
#  1.5487833454990264e-07,
#  1.5500031000062001e-07,
#  1.5512242960195119e-07,
#  1.5524469358112869e-07,
#  1.5536710216583295e-07,
#  1.5548965558419329e-07,
#  1.556123540647892e-07,
#  1.5573519783665122e-07,
#  1.5585818712926208e-07,
#  1.5598132217255777e-07,
#  1.5610460319692862e-07,
#  1.5622803043322034e-07,
#  1.5635160411273512e-07,
#  1.5647532446723281e-07,
#  1.5659919172893182e-07,
#  1.5672320613051031e-07,
#  1.5684736790510734e-07,
#  1.5697167728632387e-07,
#  1.570961345082239e-07,
#  1.5722073980533556e-07,
#  1.5734549341265224e-07,
#  1.5747039556563367e-07,
#  1.57595446500207e-07,
#  1.5772064645276804e-07,
#  1.578459956601822e-07,
#  1.5797149435978577e-07,
#  1.5809714278938693e-07,
#  1.5822294118726697e-07,
#  1.5834888979218132e-07,
#  1.5847498884336077e-07,
#  1.5860123858051257e-07,
#  1.5872763924382154e-07,
#  1.5885419107395122e-07,
#  1.5898089431204516e-07,
#  1.5910774919972779e-07,
#  1.5923475597910584e-07,
#  1.5936191489276934e-07,
#  1.5948922618379284e-07,
#  1.5961669009573649e-07,
#  1.5974430687264736e-07,
#  1.5987207675906048e-07,
#  1.6e-07,
#  1.601280768409805e-07,
#  1.60256307528008e-07,
#  1.6038469230758129e-07,
#  1.6051323142669297e-07,
#  1.6064192513283079e-07,
#  1.6077077367397874e-07,
#  1.6089977729861824e-07,
#  1.6102893625572942e-07,
#  1.6115825079479222e-07,
#  1.6128772116578764e-07,
#  1.6141734761919904e-07,
#  1.6154713040601318e-07,
#  1.6167706977772152e-07,
#  1.6180716598632146e-07,
#  1.6193741928431758e-07,
#  1.6206782992472274e-07,
#  ...]

# %%
middle = len(square(j)) / 2
print(int(middle))

middle = len(square(i)) / 2
print (int(middle))
# Out:
# 1741
# 1741

# %%
square(j)[int(middle)]
# Out:
# 3.2953663195108097e-07

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (int(middle)**2) / (x)

myu = integrate.quad(computePi, 1, int(middle)**2)

# 結果にはintegrated value and estimation error
myu
# Out:
# (45237155.843695015, 0.00010024230866712003)

# %%
(1741**2) * log(1741**2)
# Out:
# 45237155.84369501

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (3.2953663195108097e-07**2) / (x)

myu = integrate.quad(computePi, 1, (3.2953663195108097e-07**2))
print(myu)
# Out:
# (-9.12820133199114e-13, 1.0154184166325176e-12)
