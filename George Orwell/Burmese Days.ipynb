# %%
# https://biblio.wiki/wiki/Burmese_Days

import nltk
from nltk.corpus import stopwords
import math
# %matplotlib inline

raw1 = open('Burmese_Days.txt').read()

# %%
tokens1 = nltk.word_tokenize(raw1)
sentence1 = nltk.sent_tokenize(raw1)

#The number of token
len(tokens1)
# Out:
# 115774

# %%
len(sentence1)
# Out:
# 7391

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer() #to make base form

tokens_low = [w.lower() for w in tokens1]

#The number of sort of words
len(set(tokens_low))

#複数形や過去形を別の単語としてカウントしてしまっているため，実際の異なり語数はさらに少ない
# Out:
# 9651

# %%
print (len(set(tokens_low))/len(tokens1))
# Out:
# 0.08336068547342236

# %%
list1 = [tokens1]

text = []
for i in list1:
    text.append(nltk.Text(i))
    
freq_list = []
for i in text:
    freq_list.append(nltk.FreqDist(w.lower() for w in i))

stopwords = nltk.corpus.stopwords.words('english')
symbols = ["'", '"', '`', '.', ',', '-', '!', '?', ':', ';', '(', ')', '...', "'s", '’', '”', '“','–','—', '…', '*' ,'``', "''",'--','mr.',"n't", 'dr.','sir', '‘', 'mr', 'm.' ]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#順位チェック
sorted(freq_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('flory', 570),
#  ('one', 379),
#  ('like', 361),
#  ('said', 359),
#  ('would', 316),
#  ('elizabeth', 310),
#  ('could', 260),
#  ('even', 199),
#  ('back', 186),
#  ('club', 186),
#  ('two', 179),
#  ('came', 163),
#  ('doctor', 162),
#  ('face', 161),
#  ('time', 158),
#  ('lackersteen', 156),
#  ('po', 147),
#  ('kyin', 146),
#  ('ellis', 146),
#  ('man', 144),
#  ('never', 144),
#  ('go', 142),
#  ('see', 141),
#  ('macgregor', 141),
#  ('way', 139),
#  ("'i", 139),
#  ('away', 131),
#  ('verrall', 130),
#  ('u', 129),
#  ('come', 128),
#  ('almost', 126),
#  ('know', 125),
#  ('little', 121),
#  ('round', 121),
#  ('made', 119),
#  ('think', 119),
#  ('say', 115),
#  ('ko', 114),
#  ('white', 110),
#  ('old', 109),
#  ('men', 107),
#  ('quite', 105),
#  ('must', 103),
#  ('though', 100),
#  ('mrs', 100),
#  ('look', 99),
#  ('good', 99),
#  ("s'la", 99),
#  ('iss', 97),
#  ('moment', 96),
#  ('get', 94),
#  ('got', 94),
#  ("'ve", 94),
#  ('went', 91),
#  ('much', 91),
#  ('long', 90),
#  ('thought', 90),
#  ('head', 89),
#  ('something', 89),
#  ('life', 87),
#  ('turned', 86),
#  ('every', 84),
#  ('behind', 84),
#  ('girl', 83),
#  ("'ll", 83),
#  ('yet', 82),
#  ('going', 82),
#  ('put', 80),
#  ('years', 79),
#  ('house', 78),
#  ('rather', 77),
#  ('burmese', 77),
#  ('us', 77),
#  ('took', 76),
#  ('well', 76),
#  ('right', 76),
#  ('looked', 76),
#  ('jungle', 76),
#  ('may', 75),
#  ('hand', 75),
#  ('evening', 74),
#  ('people', 73),
#  ('take', 73),
#  ('morning', 73),
#  ('black', 72),
#  ('kyauktada', 71),
#  ('make', 71),
#  ('woman', 71),
#  ('westfield', 71),
#  ('without', 70),
#  ('veranda', 69),
#  ('course', 69),
#  ("'oh", 69),
#  ('day', 68),
#  ('ever', 68),
#  ('friend', 68),
#  ('nothing', 68),
#  ('thing', 67),
#  ('still', 67),
#  ("'what", 67),
#  ('god', 65),
#  ('english', 65),
#  ('let', 65),
#  ('hla', 63),
#  ("'re", 63),
#  ('talk', 63),
#  ('always', 62),
#  ('young', 62),
#  ('stood', 62),
#  ('europeans', 62),
#  ('heard', 62),
#  ('seemed', 62),
#  ('saw', 61),
#  ('shall', 61),
#  ('first', 61),
#  ('together', 61),
#  ('upon', 60),
#  ('done', 60),
#  ('eyes', 59),
#  ("'m", 59),
#  ('left', 58),
#  ('european', 58),
#  ('others', 57),
#  ('women', 57),
#  ('great', 56),
#  ("'the", 56),
#  ('home', 56),
#  ('burma', 55),
#  ("'d", 55),
#  ('air', 54),
#  ('another', 54),
#  ('tell', 54),
#  ('coming', 54),
#  ('kind', 53),
#  ('knew', 53),
#  ('voice', 53),
#  ('small', 52),
#  ('dear', 52),
#  ('last', 52),
#  ('veraswami', 52),
#  ('bloody', 52),
#  ('things', 52),
#  ('table', 51),
#  ('anything', 51),
#  ('mind', 51),
#  ('hear', 51),
#  ('road', 51),
#  ('across', 51),
#  ('servants', 51),
#  ('ba', 50),
#  ('night', 50),
#  ('word', 49),
#  ('yellow', 48),
#  ('brought', 48),
#  ('called', 48),
#  ('give', 48),
#  ('began', 48),
#  ('talking', 48),
#  ('flo', 48),
#  ('butler', 48),
#  ('feet', 47),
#  ('except', 47),
#  ('perhaps', 47),
#  ('indian', 47),
#  ('whole', 47),
#  ('matter', 47),
#  ('enough', 46),
#  ('hands', 46),
#  ('towards', 46),
#  ('kin', 46),
#  ('three', 45),
#  ('police', 45),
#  ('ca', 45),
#  ('country', 45),
#  ('happened', 45),
#  ('however', 44),
#  ('want', 44),
#  ('already', 44),
#  ('room', 44),
#  ('trees', 44),
#  ('gone', 44),
#  ('poor', 43),
#  ('four', 43),
#  ('found', 43),
#  ('days', 43),
#  ('keep', 43),
#  ('oh', 43),
#  ('really', 43),
#  ('water', 43),
#  ('half', 42),
#  ('side', 42),
#  ('among', 42),
#  ('everyone', 42),
#  ('also', 42),
#  ('place', 42),
#  ('hair', 42),
#  ('looking', 42),
#  ('rupees', 41),
#  ('end', 41),
#  ("'you", 41),
#  ('better', 41),
#  ('sat', 41),
#  ('felt', 40),
#  ("'no", 40),
#  ('native', 40),
#  ('speak', 40),
#  ('please', 40),
#  ('yards', 40),
#  ('body', 40),
#  ('sometimes', 39),
#  ('money', 39),
#  ('alone', 39),
#  ("'it", 39),
#  ('ah', 39),
#  ('might', 39),
#  ('outside', 39),
#  ('standing', 38),
#  ('hundred', 38),
#  ('short', 38),
#  ('dr', 38),
#  ('mean', 38),
#  ('green', 37),
#  ('arms', 37),
#  ('bad', 37),
#  ('letter', 37),
#  ('dark', 37),
#  ('seen', 37),
#  ('gate', 37),
#  ('gave', 37),
#  ('dreadful', 37),
#  ('village', 36),
#  ("'yes", 36),
#  ('far', 36),
#  ('told', 36),
#  ('bazaar', 36),
#  ('sun', 36),
#  ('burmans', 36),
#  ('rebellion', 36),
#  ('crowd', 36),
#  ('sitting', 35),
#  ('tree', 35),
#  ('taken', 35),
#  ('arm', 35),
#  ('walked', 35),
#  ("'but", 35),
#  ('birthmark', 35),
#  ('heat', 35),
#  ('path', 35),
#  ('sent', 34),
#  ('year', 34),
#  ('skin', 34),
#  ('hot', 34),
#  ('faces', 34),
#  ('bed', 34),
#  ('several', 33),
#  ('sound', 33),
#  ('notice', 33),
#  ('large', 33),
#  ('master', 33),
#  ('chair', 32),
#  ('believe', 32),
#  ('ten', 32),
#  ('rain', 32),
#  ('drink', 32),
#  ('making', 31),
#  ('low', 31),
#  ("'ah", 31),
#  ('hope', 31),
#  ('times', 31),
#  ('new', 31),
#  ('everything', 31),
#  ('india', 31),
#  ('cut', 31),
#  ('else', 30),
#  ('next', 30),
#  ('soon', 30),
#  ('suppose', 30),
#  ('maxwell', 30),
#  ('suddenly', 30),
#  ('door', 30),
#  ('passed', 30),
#  ('camp', 30),
#  ('light', 30),
#  ('week', 29),
#  ('since', 29),
#  ('simply', 29),
#  ('name', 29),
#  ("'well", 29),
#  ('boy', 29),
#  ('added', 29),
#  ('understand', 29),
#  ('set', 29),
#  ('flowers', 29),
#  ('books', 29),
#  ('shooting', 29),
#  ('marry', 29),
#  ('minutes', 28),
#  ('official', 28),
#  ('work', 28),
#  ('feeling', 28),
#  ('call', 28),
#  ('getting', 28),
#  ('clear', 28),
#  ('front', 28),
#  ('fact', 28),
#  ('afraid', 28),
#  ('dead', 28),
#  ('start', 28),
#  ('beyond', 27),
#  ('fifty', 27),
#  ('many', 27),
#  ('waiting', 27),
#  ('sein', 27),
#  ('usual', 27),
#  ('stick', 27),
#  ('stopped', 27),
#  ('someone', 27),
#  ('sahib', 27),
#  ('gun', 27),
#  ('heart', 27),
#  ('high', 26),
#  ('british', 26),
#  ('probably', 26),
#  ('five', 26),
#  ('six', 26),
#  ('appeared', 26),
#  ('trouble', 26),
#  ('within', 26),
#  ('dressed', 26),
#  ('maidan', 26),
#  ('whisky', 26),
#  ('hardly', 26),
#  ('knees', 26),
#  ('military', 26),
#  ('shoulder', 26),
#  ('leopard', 26),
#  ('past', 25),
#  ('help', 25),
#  ('shoulders', 25),
#  ('full', 25),
#  ('anyone', 25),
#  ("'my", 25),
#  ('live', 25),
#  ('river', 25),
#  ('indians', 25),
#  ('till', 25),
#  ('conversation', 25),
#  ('longer', 25),
#  ('ought', 25),
#  ('saying', 25),
#  ('lay', 25),
#  ('world', 25),
#  ('aunt', 25),
#  ('government', 24),
#  ('twenty', 24),
#  ('later', 24),
#  ('case', 24),
#  ('ask', 24),
#  ("'how", 24),
#  ('open', 24),
#  ('pale', 24),
#  ('near', 24),
#  ('blue', 24),
#  ('thousand', 24),
#  ('dog', 24),
#  ('damned', 24),
#  ('used', 24),
#  ('possible', 24),
#  ('find', 24),
#  ('girls', 24),
#  ('love', 24),
#  ('month', 23),
#  ('rest', 23),
#  ('best', 23),
#  ('leave', 23),
#  ('listen', 23),
#  ('jail', 23),
#  ('angry', 23),
#  ('least', 23),
#  ('church', 23),
#  ('big', 23),
#  ('grey', 23),
#  ('fellow', 23),
#  ('wearing', 23),
#  ('ass', 23),
#  ('train', 23),
#  ('fat', 22),
#  ('earth', 22),
#  ('answer', 22),
#  ('noise', 22),
#  ('ago', 22),
#  ('hour', 22),
#  ('wife', 22),
#  ('clothes', 22),
#  ('floor', 22),
#  ('business', 22),
#  ('oriental', 22),
#  ('youth', 22),
#  ('living', 22),
#  ('horrible', 22),
#  ('bring', 22),
#  ('sweat', 22),
#  ("'do", 22),
#  ('along', 22),
#  ('given', 22),
#  ('rangoon', 21),
#  ('chance', 21),
#  ('months', 21),
#  ('trying', 21),
#  ('question', 21),
#  ("'we", 21),
#  ('hurt', 21),
#  ('silk', 21),
#  ('middle', 21),
#  ('shirt', 21),
#  ('nearly', 21),
#  ('beside', 21),
#  ('asked', 21),
#  ('uncle', 21),
#  ('fool', 21),
#  ('general', 21),
#  ('forward', 21),
#  ('certain', 21),
#  ('wo', 21),
#  ('tea', 21),
#  ('ground', 21),
#  ('shot', 21),
#  ('naked', 20),
#  ('mandalay', 20),
#  ('honour', 20),
#  ('presently', 20),
#  ('children', 20),
#  ('etc', 20),
#  ('holding', 20),
#  ('letters', 20),
#  ('turn', 20),
#  ('close', 20),
#  ('yes', 20),
#  ('breakfast', 20),
#  ('remember', 20),
#  ('lived', 20),
#  ('feel', 20),
#  ('inside', 20),
#  ('hurried', 20),
#  ('foot', 20),
#  ('natives', 20),
#  ('repeated', 20),
#  ('care', 20),
#  ('weeks', 20),
#  ('spectacles', 20),
#  ('somehow', 20),
#  ('pukka', 20),
#  ('followed', 20),
#  ('scent', 20),
#  ('moon', 20),
#  ('begun', 20),
#  ('hours', 19),
#  ('vast', 19),
#  ('watching', 19),
#  ('remembered', 19),
#  ('news', 19),
#  ('commissioner', 19),
#  ('besides', 19),
#  ('district', 19),
#  ('known', 19),
#  ('finally', 19),
#  ('gold', 19),
#  ("'that", 19),
#  ('ran', 19),
#  ('subject', 19),
#  ('worse', 19),
#  ('hard', 19),
#  ('friends', 19),
#  ('stay', 19),
#  ('threw', 19),
#  ('free', 19),
#  ('started', 19),
#  ('noticed', 19),
#  ('wooden', 19),
#  ('real', 19),
#  ('chinese', 19),
#  ('bushes', 19),
#  ('watched', 19),
#  ('met', 19),
#  ('burst', 19),
#  ('member', 19),
#  ('hell', 19),
#  ('paris', 19),
#  ('england', 19),
#  ('cried', 19),
#  ('true', 19),
#  ('understood', 19),
#  ('longyi', 19),
#  ('distance', 19),
#  ('thakin', 19),
#  ('fire', 19),
#  ('scene', 19),
#  ('wanted', 19),
#  ('li', 19),
#  ('yeik', 19),
#  ('beaters', 19),
#  ('officer', 18),
#  ('evil', 18),
#  ('point', 18),
#  ('servant', 18),
#  ('headman', 18),
#  ('immediately', 18),
#  ('rail', 18),
#  ('steps', 18),
#  ('anonymous', 18),
#  ('brown', 18),
#  ('chairs', 18),
#  ('less', 18),
#  ('sit', 18),
#  ('cheek', 18),
#  ('sight', 18),
#  ('tiny', 18),
#  ('drunk', 18),
#  ('tennis', 18),
#  ('ice', 18),
#  ('idea', 18),
#  ("'good", 18),
#  ('queer', 18),
#  ('loved', 18),
#  ('fifteen', 18),
#  ('flat', 18),
#  ('leaves', 18),
#  ('forgotten', 18),
#  ('mother', 18),
#  ('beat', 18),
#  ('escape', 18),
#  ('caught', 17),
#  ('reached', 17),
#  ("'is", 17),
#  ('burman', 17),
#  ('happy', 17),
#  ('begin', 17),
#  ('move', 17),
#  ('cold', 17),
#  ('food', 17),
#  ('thin', 17),
#  ('bamboo', 17),
#  ('bent', 17),
#  ('garden', 17),
#  ('town', 17),
#  ('try', 17),
#  ('hat', 17),
#  ('spot', 17),
#  ('school', 17),
#  ('red', 17),
#  ('whether', 17),
#  ('tone', 17),
#  ('bitter', 17),
#  ('forest', 17),
#  ('thick', 17),
#  ('taking', 17),
#  ('either', 17),
#  ('words', 17),
#  ('meeting', 17),
#  ('hold', 17),
#  ('comes', 17),
#  ('silent', 17),
#  ('keeping', 17),
#  ('meet', 17),
#  ('bit', 17),
#  ('ways', 17),
#  ('lost', 17),
#  ('dogs', 17),
#  ('order', 17),
#  ('dare', 17),
#  ('hiss', 17),
#  ('sorry', 17),
#  ('perfectly', 17),
#  ('struck', 17),
#  ('led', 17),
#  ('heads', 17),
#  ('moved', 17),
#  ('job', 16),
#  ('holy', 16),
#  ('office', 16),
#  ('different', 16),
#  ('interest', 16),
#  ('lips', 16),
#  ('pe', 16),
#  ('talked', 16),
#  ('slowly', 16),
#  ('shouted', 16),
#  ('huge', 16),
#  ('pink', 16),
#  ('need', 16),
#  ('bottle', 16),
#  ('beer', 16),
#  ('bank', 16),
#  ('growing', 16),
#  ('spite', 16),
#  ('instead', 16),
#  ('eye', 16),
#  ('mouth', 16),
#  ('edge', 16),
#  ('sharply', 16),
#  ('polo', 16),
#  ("'em", 16),
#  ('lounge', 16),
#  ('reading', 16),
#  ("'look", 16),
#  ('drinking', 16),
#  ('seem', 16),
#  ('dirty', 16),
#  ('pulled', 16),
#  ('pay', 16),
#  ('manner', 16),
#  ('show', 16),
#  ('boys', 16),
#  ('touch', 16),
#  ('actually', 16),
#  ('row', 16),
#  ('pony', 16),
#  ('neck', 16),
#  ('use', 16),
#  ('blood', 16),
#  ('neither', 16),
#  ('fell', 16),
#  ('lovely', 16),
#  ('death', 16),
#  ('surely', 16),
#  ('riot', 16),
#  ('earthquake', 16),
#  ('beautiful', 15),
#  ('public', 15),
#  ('kept', 15),
#  ('thoughts', 15),
#  ('part', 15),
#  ('taik', 15),
#  ('send', 15),
#  ("'and", 15),
#  ('dozen', 15),
#  ('prestige', 15),
#  ('birds', 15),
#  ('ha', 15),
#  ('nose', 15),
#  ('carrying', 15),
#  ('hill', 15),
#  ('bird', 15),
#  ('shook', 15),
#  ('field', 15),
#  ('asking', 15),
#  ('married', 15),
#  ('hated', 15),
#  ('straight', 15),
#  ('ready', 15),
#  ('service', 15),
#  ('shoes', 15),
#  ('walk', 15),
#  ('indeed', 15),
#  ('late', 15),
#  ('grew', 15),
#  ('sense', 15),
#  ('bottom', 15),
#  ('often', 15),
#  ('station', 15),
#  ('dropped', 15),
#  ('crocodile', 15),
#  ('raised', 15),
#  ('bedroom', 15),
#  ('laid', 15),
#  ('thirty', 15),
#  ('pigeons', 15),
#  ('sprang', 15),
#  ('killed', 15),
#  ('sepoys', 15),
#  ('murder', 15),
#  ('horses', 15),
#  ('shoot', 15),
#  ('eight', 14),
#  ('officials', 14),
#  ('sooner', 14),
#  ('following', 14),
#  ('putting', 14),
#  ('clerk', 14),
#  ('broke', 14),
#  ('paper', 14),
#  ('miserable', 14),
#  ('etc.', 14),
#  ('read', 14),
#  ('fish', 14),
#  ('beginning', 14),
#  ('dinner', 14),
#  ('happen', 14),
#  ('disgusting', 14),
#  ('present', 14),
#  ('fashion', 14),
#  ('pleased', 14),
#  ('rose', 14),
#  ('francis', 14),
#  ('prickly', 14),
#  ('punkah', 14),
#  ('lying', 14),
#  ('chap', 14),
#  ('held', 14),
#  ('stream', 14),
#  ('orientals', 14),
#  ('reason', 14),
#  ('running', 14),
#  ("'come", 14),
#  ('beneath', 14),
#  ('miles', 14),
#  ('absolutely', 14),
#  ('empire', 14),
#  ('instant', 14),
#  ('natural', 14),
#  ('serious', 14),
#  ("'they", 14),
#  ('refused', 14),
#  ('smell', 14),
#  ('stepped', 14),
#  ('lackersteens', 14),
#  ('extraordinary', 14),
#  ('sea', 14),
#  ('quarrel', 14),
#  ('ponies', 14),
#  ('madam', 14),
#  ('wind', 13),
#  ('child', 13),
#  ('sort', 13),
#  ('villagers', 13),
#  ('share', 13),
#  ('backwards', 13),
#  ("'there", 13),
#  ('waved', 13),
#  ('affair', 13),
#  ('expect', 13),
#  ('ruined', 13),
#  ('enormous', 13),
#  ('rich', 13),
#  ('law', 13),
#  ('eurasians', 13),
#  ('shaking', 13),
#  ('gin', 13),
#  ('playing', 13),
#  ('nigger', 13),
#  ('policemen', 13),
#  ("'go", 13),
#  ('exclaimed', 13),
#  ('entered', 13),
#  ('doubt', 13),
#  ('run', 13),
#  ('rolled', 13),
#  ('lines', 13),
#  ('compound', 13),
#  ('fear', 13),
#  ('joy', 13),
#  ("'why", 13),
#  ('single', 13),
#  ('spent', 13),
#  ('book', 13),
#  ('stop', 13),
#  ('fired', 13),
#  ('strange', 13),
#  ('wonderful', 13),
#  ('silence', 13),
#  ('strong', 13),
#  ('second', 13),
#  ('pwe', 13),
#  ('ride', 13),
#  ('elected', 13),
#  ('pay-like', 13),
#  ('bare', 12),
#  ('thinking', 12),
#  ('heavy', 12),
#  ('tried', 12),
#  ('annas', 12),
#  ('tomorrow', 12),
#  ('tall', 12),
#  ('arrived', 12),
#  ('partly', 12),
#  ("'a", 12),
#  ('wrote', 12),
#  ('belly', 12),
#  ('ruin', 12),
#  ('rage', 12),
#  ('quickly', 12),
#  ('kill', 12),
#  ('stone', 12),
#  ('seeing', 12),
#  ('ingyi', 12),
#  ('wicker', 12),
#  ('papers', 12),
#  ('peepul', 12),
#  ('slender', 12),
#  ('changed', 12),
#  ('hospital', 12),
#  ('glare', 12),
#  ('art', 12),
#  ('flying', 12),
#  ('number', 12),
#  ('pain', 12),
#  ('firm', 12),
#  ('sleep', 12),
#  ('somebody', 12),
#  ('hate', 12),
#  ('war', 12),
#  ('clean', 12),
#  ('early', 12),
#  ('meanwhile', 12),
#  ('shop', 12),
#  ('good-bye', 12),
#  ('thank', 12),
#  ('music', 12),
#  ('frightened', 12),
#  ('oil', 12),
#  ('fall', 12),
#  ('uncomfortable', 12),
#  ('ugly', 12),
#  ('easily', 12),
#  ('meant', 12),
#  ('needed', 12),
#  ('coolies', 12),
#  ('explained', 12),
#  ('died', 12),
#  ('beastly', 12),
#  ('afterwards', 12),
#  ('de', 12),
#  ('struggled', 12),
#  ('dance', 12),
#  ('nga', 12),
#  ('horse', 12),
#  ('halted', 12),
#  ("'elizabeth", 12),
#  ('upper', 11),
#  ('stifling', 11),
#  ('dusty', 11),
#  ('rifles', 11),
#  ('grasped', 11),
#  ('wrong', 11),
#  ('position', 11),
#  ('danger', 11),
#  ('pagodas', 11),
#  ('seven', 11),
#  ('laugh', 11),
#  ('slipped', 11),
#  ('article', 11),
#  ('wretched', 11),
#  ('teeth', 11),
#  ('legs', 11),
#  ('attack', 11),
#  ('consider', 11),
#  ('deal', 11),
#  ('written', 11),
#  ('learned', 11),
#  ('wish', 11),
#  ('leaving', 11),
#  ('topi', 11),
#  ('top', 11),
#  ('mali', 11),
#  ('englishman', 11),
#  ('invisible', 11),
#  ('due', 11),
#  ('gets', 11),
#  ('pointed', 11),
#  ('garlic', 11),
#  ('damn', 11),
#  ('devil', 11),
#  ('forehead', 11),
#  ('padre', 11),
#  ('fools', 11),
#  ('husband', 11),
#  ('drinks', 11),
#  ('meaning', 11),
#  ('stand', 11),
#  ("'of", 11),
#  ('wild', 11),
#  ('creatures', 11),
#  ('narrow', 11),
#  ('throat', 11),
#  ('breast', 11),
#  ('remained', 11),
#  ('bore', 11),
#  ('decent', 11),
#  ('earlier', 11),
#  ('despised', 11),
#  ('dancing', 11),
#  ('shame', 11),
#  ('flung', 11),
#  ('fallen', 11),
#  ('broad', 11),
#  ('tears', 11),
#  ('cool', 10),
#  ('gazed', 10),
#  ('sunlight', 10),
#  ('heels', 10),
#  ('deputy', 10),
#  ('paid', 10),
#  ('worth', 10),
#  ('intended', 10),
#  ('level', 10),
#  ('beast', 10),
#  ('fingers', 10),
#  ('whose', 10),
#  ('smooth', 10),
#  ('answered', 10),
#  ('produced', 10),
#  ("'he", 10),
#  ('movement', 10),
#  ('quarter', 10),
#  ('civil', 10),
#  ('easy', 10),
#  ('difficult', 10),
#  ('timber', 10),
#  ('watch', 10),
#  ('spoke', 10),
#  ('deep', 10),
#  ('sure', 10),
#  ("'then", 10),
#  ('quick', 10),
#  ('forty', 10),
#  ('finished', 10),
#  ('pagoda', 10),
#  ('instance', 10),
#  ('shorts', 10),
#  ('carried', 10),
#  ('wall', 10),
#  ('power', 10),
#  ('samuel', 10),
#  ('eh', 10),
#  ('dust', 10),
#  ('niece', 10),
#  ('turning', 10),
#  ('christ', 10),
#  ('managed', 10),
#  ('rot', 10),
#  ('lowered', 10),
#  ('niggers', 10),
#  ('curious', 10),
#  ('filthy', 10),
#  ('breath', 10),
#  ('asleep', 10),
#  ('pushed', 10),
#  ('pretending', 10),
#  ('terrible', 10),
#  ('balls', 10),
#  ('pressed', 10),
#  ('shut', 10),
#  ('dull', 10),
#  ('disappeared', 10),
#  ('explain', 10),
#  ('forgive', 10),
#  ('coat', 10),
#  ('deadly', 10),
#  ("'if", 10),
#  ('tin', 10),
#  ('cigarettes', 10),
#  ('hass', 10),
#  ('imagine', 10),
#  ('helpless', 10),
#  ('play', 10),
#  ('necessary', 10),
#  ('worst', 10),
#  ('mattu', 10),
#  ('election', 10),
#  ('promised', 10),
#  ('carry', 10),
#  ("'get", 10),
#  ('mood', 10),
#  ('person', 10),
#  ('loneliness', 10),
#  ('screaming', 10),
#  ('dah', 10),
#  ('climbed', 10),
#  ('houses', 10),
#  ('opinion', 10),
#  ('cartridges', 10),
#  ('kick', 10),
#  ('nasty', 10),
#  ('realize', 10),
#  ('mud', 10),
#  ('grass', 10),
#  ('fresh', 10),
#  ('walking', 10),
#  ('riding', 10),
#  ('sudden', 10),
#  ('telling', 10),
#  ('wait', 10),
#  ('peg', 10),
#  ('drenched', 9),
#  ('sky', 9),
#  ('become', 9),
#  ('englishmen', 9),
#  ('bribes', 9),
#  ('loyal', 9),
#  ('die', 9),
#  ('lives', 9),
#  ('animal', 9),
#  ('merit', 9),
#  ('human', 9),
#  ('basket', 9),
#  ('progress', 9),
#  ('joke', 9),
#  ('patriot', 9),
#  ('type', 9),
#  ('entire', 9),
#  ...]

# %%
#Turn all words to basic form
basic_form = [ps.stem(word) for word in tokens_low if not word in stopwords + symbols]

#Textを使うためにreviewをlistにぶち込む
basic_form = [basic_form]

#原型に戻した単語で、再び文を再構築する。
text = []
for i in basic_form:
    text.append(nltk.Text(i))
    
#Textからwords listを作る。
for i in text:
    words = [word for word in i]
    
words
# Out:
# ['u',
#  'po',
#  'kyin',
#  'sub-division',
#  'magistr',
#  'kyauktada',
#  'upper',
#  'burma',
#  'sit',
#  'veranda',
#  'half',
#  'past',
#  'eight',
#  'month',
#  'april',
#  'close',
#  'air',
#  'threat',
#  'long',
#  'stifl',
#  'midday',
#  'hour',
#  'occasion',
#  'faint',
#  'breath',
#  'wind',
#  'seem',
#  'cool',
#  'contrast',
#  'stir',
#  'newli',
#  'drench',
#  'orchid',
#  'hung',
#  'eav',
#  'beyond',
#  'orchid',
#  'one',
#  'could',
#  'see',
#  'dusti',
#  'curv',
#  'trunk',
#  'palm',
#  'tree',
#  'blaze',
#  'ultramarin',
#  'sky',
#  'zenith',
#  'high',
#  'dazzl',
#  'one',
#  'look',
#  'vultur',
#  'circl',
#  'without',
#  'quiver',
#  'wing',
#  'unblink',
#  'rather',
#  'like',
#  'great',
#  'porcelain',
#  'idol',
#  'u',
#  'po',
#  'kyin',
#  'gaze',
#  'fierc',
#  'sunlight',
#  'man',
#  'fifti',
#  'fat',
#  'year',
#  'risen',
#  'chair',
#  'without',
#  'help',
#  'yet',
#  'shape',
#  'even',
#  'beauti',
#  'gross',
#  'burmes',
#  'sag',
#  'bulg',
#  'like',
#  'white',
#  'men',
#  'grow',
#  'fat',
#  'symmetr',
#  'like',
#  'fruit',
#  'swell',
#  'face',
#  'vast',
#  'yellow',
#  'quit',
#  'unwrinkl',
#  'eye',
#  'tawni',
#  'feet',
#  'squat',
#  'high-arch',
#  'feet',
#  'toe',
#  'length',
#  'bare',
#  'crop',
#  'head',
#  'wore',
#  'one',
#  'vivid',
#  'arakanes',
#  'longyi',
#  'green',
#  'magenta',
#  'check',
#  'burmes',
#  'wear',
#  'inform',
#  'occas',
#  'chew',
#  'betel',
#  'lacquer',
#  'box',
#  'tabl',
#  'think',
#  'past',
#  'life',
#  'brilliantli',
#  'success',
#  'life',
#  'u',
#  'po',
#  'kyin',
#  'earliest',
#  'memori',
#  'back',
#  'eighti',
#  'stand',
#  'nake',
#  'pot-belli',
#  'child',
#  'watch',
#  'british',
#  'troop',
#  'march',
#  'victori',
#  'mandalay',
#  'rememb',
#  'terror',
#  'felt',
#  'column',
#  'great',
#  'beef-f',
#  'men',
#  'red-fac',
#  'red-coat',
#  'long',
#  'rifl',
#  'shoulder',
#  'heavi',
#  'rhythmic',
#  'tramp',
#  'boot',
#  'taken',
#  'heel',
#  'watch',
#  'minut',
#  'childish',
#  'way',
#  'grasp',
#  'peopl',
#  'match',
#  'race',
#  'giant',
#  'fight',
#  'side',
#  'british',
#  'becom',
#  'parasit',
#  'upon',
#  'rule',
#  'ambit',
#  'even',
#  'child',
#  'seventeen',
#  'tri',
#  'govern',
#  'appoint',
#  'fail',
#  'get',
#  'poor',
#  'friendless',
#  'three',
#  'year',
#  'work',
#  'stink',
#  'labyrinth',
#  'mandalay',
#  'bazaar',
#  'clerk',
#  'rice',
#  'merchant',
#  'sometim',
#  'steal',
#  'twenti',
#  'lucki',
#  'stroke',
#  'blackmail',
#  'put',
#  'possess',
#  'four',
#  'hundr',
#  'rupe',
#  'went',
#  'rangoon',
#  'bought',
#  'way',
#  'govern',
#  'clerkship',
#  'job',
#  'lucr',
#  'one',
#  'though',
#  'salari',
#  'small',
#  'time',
#  'ring',
#  'clerk',
#  'make',
#  'steadi',
#  'incom',
#  'misappropri',
#  'govern',
#  'store',
#  'po',
#  'kyin',
#  'plain',
#  'po',
#  'kyin',
#  'honorif',
#  'u',
#  'came',
#  'year',
#  'later',
#  'took',
#  'natur',
#  'kind',
#  'thing',
#  'howev',
#  'much',
#  'talent',
#  'spend',
#  'life',
#  'clerkship',
#  'steal',
#  'miser',
#  'anna',
#  'pice',
#  'one',
#  'day',
#  'discov',
#  'govern',
#  'short',
#  'minor',
#  'offici',
#  'go',
#  'make',
#  'appoint',
#  'among',
#  'clerk',
#  'news',
#  'would',
#  'becom',
#  'public',
#  'anoth',
#  'week',
#  'one',
#  'po',
#  'kyin',
#  'qualiti',
#  'inform',
#  'alway',
#  'week',
#  'ahead',
#  'everyon',
#  'els',
#  'saw',
#  'chanc',
#  'denounc',
#  'confeder',
#  'could',
#  'take',
#  'alarm',
#  'sent',
#  'prison',
#  'po',
#  'kyin',
#  'made',
#  'assist',
#  'township',
#  'offic',
#  'reward',
#  'honesti',
#  'sinc',
#  'risen',
#  'steadili',
#  'fifty-six',
#  'sub-division',
#  'magistr',
#  'would',
#  'probabl',
#  'promot',
#  'still',
#  'made',
#  'act',
#  'deputi',
#  'commission',
#  'englishmen',
#  'equal',
#  'even',
#  'subordin',
#  'magistr',
#  'method',
#  'simpl',
#  'even',
#  'vastest',
#  'bribe',
#  'would',
#  'never',
#  'sell',
#  'decis',
#  'case',
#  'knew',
#  'magistr',
#  'give',
#  'wrong',
#  'judgment',
#  'caught',
#  'sooner',
#  'later',
#  'practic',
#  'much',
#  'safer',
#  'one',
#  'take',
#  'bribe',
#  'side',
#  'decid',
#  'case',
#  'strictli',
#  'legal',
#  'ground',
#  'use',
#  'reput',
#  'imparti',
#  'besid',
#  'revenu',
#  'litig',
#  'u',
#  'po',
#  'kyin',
#  'levi',
#  'ceaseless',
#  'toll',
#  'sort',
#  'privat',
#  'taxat',
#  'scheme',
#  'villag',
#  'jurisdict',
#  'villag',
#  'fail',
#  'tribut',
#  'u',
#  'po',
#  'kyin',
#  'took',
#  'punit',
#  'measur',
#  'gang',
#  'dacoit',
#  'attack',
#  'villag',
#  'lead',
#  'villag',
#  'arrest',
#  'fals',
#  'charg',
#  'forth',
#  'never',
#  'long',
#  'amount',
#  'paid',
#  'also',
#  'share',
#  'proce',
#  'larger-s',
#  'robberi',
#  'took',
#  'place',
#  'district',
#  'cours',
#  'known',
#  'everyon',
#  'except',
#  'u',
#  'po',
#  'kyin',
#  'offici',
#  'superior',
#  'british',
#  'offic',
#  'ever',
#  'believ',
#  'anyth',
#  'men',
#  'attempt',
#  'expos',
#  'invari',
#  'fail',
#  'support',
#  'kept',
#  'loyal',
#  'share',
#  'loot',
#  'numer',
#  'accus',
#  'brought',
#  'u',
#  'po',
#  'kyin',
#  'simpli',
#  'discredit',
#  'string',
#  'suborn',
#  'wit',
#  'follow',
#  'counter-accus',
#  'left',
#  'stronger',
#  'posit',
#  'ever',
#  'practic',
#  'invulner',
#  'fine',
#  'judg',
#  'men',
#  'ever',
#  'choos',
#  'wrong',
#  'instrument',
#  'also',
#  'absorb',
#  'intrigu',
#  'ever',
#  'fail',
#  'careless',
#  'ignor',
#  'one',
#  'could',
#  'say',
#  'practic',
#  'certainti',
#  'would',
#  'never',
#  'found',
#  'would',
#  'go',
#  'success',
#  'success',
#  'would',
#  'final',
#  'die',
#  'full',
#  'honour',
#  'worth',
#  'sever',
#  'lakh',
#  'rupe',
#  'even',
#  'beyond',
#  'grave',
#  'success',
#  'would',
#  'continu',
#  'accord',
#  'buddhist',
#  'belief',
#  'done',
#  'evil',
#  'live',
#  'spend',
#  'next',
#  'incarn',
#  'shape',
#  'rat',
#  'frog',
#  'low',
#  'anim',
#  'u',
#  'po',
#  'kyin',
#  'good',
#  'buddhist',
#  'intend',
#  'provid',
#  'danger',
#  'would',
#  'devot',
#  'close',
#  'year',
#  'good',
#  'work',
#  'would',
#  'pile',
#  'enough',
#  'merit',
#  'outweigh',
#  'rest',
#  'life',
#  'probabl',
#  'good',
#  'work',
#  'would',
#  'take',
#  'form',
#  'build',
#  'pagoda',
#  'four',
#  'pagoda',
#  'five',
#  'six',
#  'seven',
#  'priest',
#  'would',
#  'tell',
#  'mani',
#  'carv',
#  'stonework',
#  'gilt',
#  'umbrella',
#  'littl',
#  'bell',
#  'tinkl',
#  'wind',
#  'everi',
#  'tinkl',
#  'prayer',
#  'would',
#  'return',
#  'earth',
#  'male',
#  'human',
#  'shape',
#  'woman',
#  'rank',
#  'level',
#  'rat',
#  'frog',
#  'best',
#  'dignifi',
#  'beast',
#  'eleph',
#  'thought',
#  'flow',
#  'u',
#  'po',
#  'kyin',
#  'mind',
#  'swiftli',
#  'part',
#  'pictur',
#  'brain',
#  'though',
#  'cun',
#  'quit',
#  'barbar',
#  'never',
#  'work',
#  'except',
#  'definit',
#  'end',
#  'mere',
#  'medit',
#  'beyond',
#  'reach',
#  'point',
#  'thought',
#  'tend',
#  'put',
#  'smallish',
#  'triangular',
#  'hand',
#  'arm',
#  'chair',
#  'turn',
#  'littl',
#  'way',
#  'round',
#  'call',
#  'rather',
#  'wheezili',
#  "'ba",
#  'taik',
#  'hey',
#  'ba',
#  'taik',
#  'ba',
#  'taik',
#  'u',
#  'po',
#  'kyin',
#  'servant',
#  'appear',
#  'bead',
#  'curtain',
#  'veranda',
#  'under-s',
#  'pock-mark',
#  'man',
#  'timid',
#  'rather',
#  'hungri',
#  'express',
#  'u',
#  'po',
#  'kyin',
#  'paid',
#  'wage',
#  'convict',
#  'thief',
#  'word',
#  'would',
#  'send',
#  'prison',
#  'ba',
#  'taik',
#  'advanc',
#  'shiko',
#  'low',
#  'give',
#  'impress',
#  'step',
#  'backward',
#  "'most",
#  'holi',
#  'god',
#  'said',
#  "'i",
#  'anyon',
#  'wait',
#  'see',
#  'ba',
#  'taik',
#  'ba',
#  'taik',
#  'enumer',
#  'visitor',
#  'upon',
#  'finger',
#  "'there",
#  'headman',
#  'thitpingyi',
#  'villag',
#  'honour',
#  'brought',
#  'present',
#  'two',
#  'villag',
#  'assault',
#  'case',
#  'tri',
#  'honour',
#  'brought',
#  'present',
#  'ko',
#  'ba',
#  'sein',
#  'head',
#  'clerk',
#  'deputi',
#  'commission',
#  'offic',
#  'wish',
#  'see',
#  'ali',
#  'shah',
#  'polic',
#  'constabl',
#  'dacoit',
#  'whose',
#  'name',
#  'know',
#  'think',
#  'quarrel',
#  'gold',
#  'bangl',
#  'stolen',
#  'also',
#  'young',
#  'villag',
#  'girl',
#  'babi',
#  "'what",
#  'want',
#  'said',
#  'u',
#  'po',
#  'kyin',
#  "'she",
#  'say',
#  'babi',
#  'holi',
#  'one',
#  "'ah",
#  'much',
#  'headman',
#  'brought',
#  'ba',
#  'taik',
#  'thought',
#  'ten',
#  'rupe',
#  'basket',
#  'mango',
#  "'tell",
#  'headman',
#  'said',
#  'u',
#  'po',
#  'kyin',
#  "'that",
#  'twenti',
#  'rupe',
#  'troubl',
#  'villag',
#  'money',
#  'tomorrow',
#  'see',
#  'other',
#  'present',
#  'ask',
#  'ko',
#  'ba',
#  'sein',
#  'come',
#  'ba',
#  'sein',
#  'appear',
#  'moment',
#  'erect',
#  'narrow-should',
#  'man',
#  'tall',
#  'burman',
#  'curious',
#  'smooth',
#  'face',
#  'recal',
#  'coffe',
#  'blancmang',
#  'u',
#  'po',
#  'kyin',
#  'found',
#  'use',
#  'tool',
#  'unimagin',
#  'hardwork',
#  'excel',
#  'clerk',
#  'macgregor',
#  'deputi',
#  'commission',
#  'trust',
#  'offici',
#  'secret',
#  'u',
#  'po',
#  'kyin',
#  'put',
#  'good',
#  'temper',
#  'thought',
#  'greet',
#  'ba',
#  'sein',
#  'laugh',
#  'wave',
#  'betel',
#  'box',
#  "'well",
#  'ko',
#  'ba',
#  'sein',
#  'affair',
#  'progress',
#  'hope',
#  'dear',
#  'macgregor',
#  'would',
#  'say',
#  'u',
#  'po',
#  'kyin',
#  'broke',
#  'english',
#  'eet',
#  'ee',
#  'make',
#  'percept',
#  'progress',
#  'ba',
#  'sein',
#  'smile',
#  'small',
#  'joke',
#  'sit',
#  'stiff',
#  'long-back',
#  'vacant',
#  'chair',
#  'answer',
#  "'excel",
#  'copi',
#  'paper',
#  'arriv',
#  'morn',
#  'kindli',
#  'observ',
#  'produc',
#  'copi',
#  'bilingu',
#  'paper',
#  'call',
#  'burmes',
#  'patriot',
#  'miser',
#  'eight-pag',
#  'rag',
#  'villain',
#  'print',
#  'paper',
#  'bad',
#  'blot',
#  'paper',
#  'compos',
#  'partli',
#  'news',
#  'stolen',
#  'rangoon',
#  'gazett',
#  'partli',
#  'weak',
#  'nationalist',
#  'heroic',
#  'last',
#  'page',
#  'type',
#  'slip',
#  'left',
#  'entir',
#  'sheet',
#  'jet',
#  'black',
#  'though',
#  'mourn',
#  'small',
#  'paper',
#  'circul',
#  'articl',
#  'u',
#  'po',
#  'kyin',
#  'turn',
#  'rather',
#  'differ',
#  'stamp',
#  'rest',
#  'ran',
#  'happi',
#  'time',
#  'poor',
#  'black',
#  'uplift',
#  'mighti',
#  'western',
#  'civil',
#  'manifold',
#  'bless',
#  'cinematograph',
#  'machine-gun',
#  'syphili',
#  'etc.',
#  'subject',
#  'could',
#  'inspir',
#  'privat',
#  'live',
#  'european',
#  'benefactor',
#  'think',
#  'therefor',
#  'may',
#  'interest',
#  'reader',
#  'hear',
#  'someth',
#  'event',
#  'up-countri',
#  'district',
#  'kyauktada',
#  'especi',
#  'macgregor',
#  'honour',
#  'deputi',
#  'commission',
#  'said',
#  'district',
#  'macgregor',
#  'type',
#  'fine',
#  'old',
#  'english',
#  'gentleman',
#  'happi',
#  'day',
#  'mani',
#  'exampl',
#  'eye',
#  "'a",
#  'famili',
#  'man',
#  'dear',
#  'english',
#  'cousin',
#  'say',
#  'much',
#  'famili',
#  'man',
#  'macgregor',
#  'much',
#  'alreadi',
#  'three',
#  'children',
#  'district',
#  'kyauktada',
#  'year',
#  'last',
#  'district',
#  'shwemyo',
#  'left',
#  'six',
#  'young',
#  'progeni',
#  'behind',
#  'perhap',
#  'oversight',
#  'macgregor',
#  'part',
#  'left',
#  'young',
#  'infant',
#  'quit',
#  'unprovid',
#  'mother',
#  'danger',
#  'starvat',
#  'etc.',
#  'etc.',
#  'etc',
#  'column',
#  'similar',
#  'stuff',
#  'wretch',
#  'well',
#  'level',
#  'rest',
#  'paper',
#  'u',
#  'po',
#  'kyin',
#  'read',
#  'articl',
#  'care',
#  'hold',
#  'arm',
#  'length',
#  'long-',
#  'sight',
#  'draw',
#  'lip',
#  'medit',
#  'back',
#  'expos',
#  'great',
#  ...]

# %%
#Basic に直して、頻度を確認する
freq_list_basic = []
for i in text:
    freq_list_basic.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

#順位チェック
sorted(freq_list_basic[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('flori', 570),
#  ('one', 388),
#  ('like', 375),
#  ('said', 359),
#  ('would', 316),
#  ('elizabeth', 310),
#  ('even', 282),
#  ('could', 260),
#  ('go', 224),
#  ('look', 223),
#  ('face', 206),
#  ('come', 199),
#  ('back', 193),
#  ('club', 192),
#  ('time', 190),
#  ('two', 180),
#  ('lackersteen', 170),
#  ('came', 163),
#  ('doctor', 163),
#  ('way', 156),
#  ("'i", 156),
#  ('see', 155),
#  ('say', 148),
#  ('po', 147),
#  ('kyin', 147),
#  ('elli', 146),
#  ('man', 145),
#  ('never', 144),
#  ('macgregor', 141),
#  ('know', 140),
#  ('think', 133),
#  ('get', 133),
#  ('verral', 132),
#  ('away', 131),
#  ('u', 129),
#  ('hand', 129),
#  ('talk', 129),
#  ('almost', 126),
#  ('round', 124),
#  ('littl', 121),
#  ('european', 120),
#  ('thing', 119),
#  ('made', 119),
#  ('turn', 117),
#  ('ko', 114),
#  ('year', 113),
#  ('white', 111),
#  ('make', 111),
#  ('day', 111),
#  ('old', 109),
#  ('men', 107),
#  ('head', 107),
#  ('girl', 107),
#  ('moment', 106),
#  ('quit', 105),
#  ('thought', 105),
#  ('must', 103),
#  ('good', 101),
#  ('though', 100),
#  ("s'la", 99),
#  ('iss', 97),
#  ('put', 95),
#  ('long', 94),
#  ('got', 94),
#  ("'ve", 94),
#  ('went', 91),
#  ('much', 91),
#  ('take', 90),
#  ('someth', 89),
#  ('hous', 88),
#  ('seem', 87),
#  ('life', 87),
#  ('friend', 87),
#  ('everi', 84),
#  ('call', 84),
#  ('behind', 84),
#  ("'ll", 83),
#  ('yet', 82),
#  ('tree', 79),
#  ('right', 79),
#  ('arm', 78),
#  ('rather', 77),
#  ('burmes', 77),
#  ('eye', 77),
#  ('live', 77),
#  ('morn', 77),
#  ('us', 77),
#  ('jungl', 77),
#  ('took', 76),
#  ('well', 76),
#  ('may', 75),
#  ('peopl', 74),
#  ('black', 73),
#  ('woman', 72),
#  ('indian', 72),
#  ('kyauktada', 71),
#  ('veranda', 71),
#  ('want', 71),
#  ('westfield', 71),
#  ('without', 70),
#  ('cours', 70),
#  ('god', 70),
#  ('servant', 69),
#  ('let', 69),
#  ("'oh", 69),
#  ('still', 68),
#  ('ever', 68),
#  ('happen', 68),
#  ('noth', 68),
#  ('tell', 67),
#  ("'what", 67),
#  ('word', 66),
#  ('english', 65),
#  ('hla', 63),
#  ("'re", 63),
#  ('alway', 62),
#  ('give', 62),
#  ('young', 62),
#  ('stood', 62),
#  ('heard', 62),
#  ('keep', 62),
#  ('saw', 61),
#  ('ask', 61),
#  ('hear', 61),
#  ('shall', 61),
#  ('first', 61),
#  ('voic', 61),
#  ('togeth', 61),
#  ('great', 60),
#  ('upon', 60),
#  ('done', 60),
#  ('walk', 60),
#  ('nativ', 60),
#  ('love', 60),
#  ('drink', 59),
#  ("'m", 59),
#  ('left', 58),
#  ('mean', 58),
#  ('letter', 58),
#  ('kind', 57),
#  ('night', 57),
#  ('home', 57),
#  ('women', 57),
#  ('air', 56),
#  ('last', 56),
#  ("'the", 56),
#  ('burma', 55),
#  ('villag', 55),
#  ('pleas', 55),
#  ("'d", 55),
#  ('sit', 54),
#  ('anoth', 54),
#  ('place', 54),
#  ('mind', 54),
#  ('tabl', 53),
#  ('tri', 53),
#  ('small', 53),
#  ('knew', 53),
#  ('burman', 53),
#  ('leav', 53),
#  ('notic', 53),
#  ('matter', 53),
#  ('road', 53),
#  ('shoulder', 52),
#  ('dear', 52),
#  ('veraswami', 52),
#  ('bloodi', 52),
#  ('stand', 51),
#  ('anyth', 51),
#  ('feel', 51),
#  ('across', 51),
#  ('chair', 50),
#  ('use', 50),
#  ('except', 50),
#  ('end', 50),
#  ('ba', 50),
#  ('start', 50),
#  ('yellow', 49),
#  ('week', 49),
#  ('bodi', 49),
#  ('speak', 49),
#  ('watch', 48),
#  ('side', 48),
#  ('short', 48),
#  ('brought', 48),
#  ('began', 48),
#  ('flo', 48),
#  ('butler', 48),
#  ('dread', 48),
#  ('yard', 48),
#  ('feet', 47),
#  ('perhap', 47),
#  ('whole', 47),
#  ('rain', 47),
#  ('countri', 47),
#  ('work', 46),
#  ('enough', 46),
#  ('toward', 46),
#  ('kin', 46),
#  ('room', 46),
#  ('marri', 46),
#  ('water', 46),
#  ('three', 45),
#  ('found', 45),
#  ('polic', 45),
#  ('boy', 45),
#  ('sound', 45),
#  ('hair', 45),
#  ('stop', 45),
#  ('ca', 45),
#  ('shoot', 45),
#  ('month', 44),
#  ('four', 44),
#  ('rupe', 44),
#  ('howev', 44),
#  ('offici', 44),
#  ('step', 44),
#  ('alreadi', 44),
#  ('gone', 44),
#  ('poor', 43),
#  ('oh', 43),
#  ('realli', 43),
#  ('book', 43),
#  ('half', 42),
#  ('hundr', 42),
#  ('among', 42),
#  ('everyon', 42),
#  ('offic', 42),
#  ('also', 42),
#  ('believ', 42),
#  ('follow', 42),
#  ('present', 42),
#  ('name', 42),
#  ('hope', 42),
#  ('hour', 41),
#  ("'you", 41),
#  ('better', 41),
#  ('sat', 41),
#  ('dog', 41),
#  ('felt', 40),
#  ('besid', 40),
#  ('care', 40),
#  ("'no", 40),
#  ('skin', 40),
#  ('suppos', 40),
#  ('rememb', 39),
#  ('sometim', 39),
#  ('wait', 39),
#  ('money', 39),
#  ('hold', 39),
#  ('alon', 39),
#  ("'it", 39),
#  ('move', 39),
#  ('ah', 39),
#  ('dark', 39),
#  ('might', 39),
#  ('birthmark', 39),
#  ('outsid', 39),
#  ('pass', 39),
#  ('appear', 38),
#  ('dr', 38),
#  ('dress', 38),
#  ('crowd', 38),
#  ('green', 37),
#  ('bazaar', 37),
#  ('answer', 37),
#  ('bad', 37),
#  ('open', 37),
#  ('seen', 37),
#  ('gate', 37),
#  ('orient', 37),
#  ('heat', 37),
#  ('gave', 37),
#  ('possibl', 37),
#  ('rebellion', 37),
#  ("'ye", 36),
#  ('far', 36),
#  ('told', 36),
#  ('sun', 36),
#  ('usual', 36),
#  ('path', 36),
#  ('master', 36),
#  ('bed', 36),
#  ('taken', 35),
#  ('minut', 35),
#  ('honour', 35),
#  ('point', 35),
#  ("'but", 35),
#  ('carri', 35),
#  ('damn', 35),
#  ('meet', 35),
#  ('light', 35),
#  ('elect', 35),
#  ('sent', 34),
#  ('sever', 34),
#  ('low', 34),
#  ('begin', 34),
#  ('fire', 34),
#  ('set', 34),
#  ('hot', 34),
#  ('larg', 34),
#  ('door', 34),
#  ('clear', 34),
#  ('gun', 34),
#  ('cri', 34),
#  ('stick', 33),
#  ('flower', 33),
#  ('cut', 33),
#  ('fool', 33),
#  ('knee', 33),
#  ('ten', 32),
#  ('troubl', 32),
#  ('shout', 32),
#  ('sahib', 32),
#  ('camp', 32),
#  ('danc', 32),
#  ('natur', 31),
#  ("'ah", 31),
#  ('ad', 31),
#  ('stay', 31),
#  ('new', 31),
#  ('everyth', 31),
#  ('busi', 31),
#  ('india', 31),
#  ('bring', 31),
#  ('order', 31),
#  ('hate', 31),
#  ('close', 30),
#  ('els', 30),
#  ('case', 30),
#  ('next', 30),
#  ('read', 30),
#  ('listen', 30),
#  ('understand', 30),
#  ('soon', 30),
#  ('bird', 30),
#  ('need', 30),
#  ('touch', 30),
#  ('maxwel', 30),
#  ('find', 30),
#  ('youth', 30),
#  ('suddenli', 30),
#  ('sweat', 30),
#  ('poni', 30),
#  ('sinc', 29),
#  ('simpli', 29),
#  ("'well", 29),
#  ('ruin', 29),
#  ('lie', 29),
#  ('hurri', 29),
#  ('run', 29),
#  ('help', 28),
#  ('wear', 28),
#  ('probabl', 28),
#  ('rest', 28),
#  ('question', 28),
#  ('kill', 28),
#  ('bush', 28),
#  ('fellow', 28),
#  ('gener', 28),
#  ('convers', 28),
#  ('front', 28),
#  ('fact', 28),
#  ('afraid', 28),
#  ('dead', 28),
#  ('heart', 28),
#  ('dare', 28),
#  ('past', 27),
#  ('beyond', 27),
#  ('fifti', 27),
#  ('govern', 27),
#  ('six', 27),
#  ('mani', 27),
#  ('sein', 27),
#  ('differ', 27),
#  ('civil', 27),
#  ('maidan', 27),
#  ('pain', 27),
#  ('idea', 27),
#  ('whiski', 27),
#  ('play', 27),
#  ('member', 27),
#  ('horribl', 27),
#  ('someon', 27),
#  ('station', 27),
#  ('hors', 27),
#  ('beater', 27),
#  ('high', 26),
#  ('british', 26),
#  ('five', 26),
#  ('paper', 26),
#  ('within', 26),
#  ('sure', 26),
#  ('cloth', 26),
#  ('near', 26),
#  ('river', 26),
#  ('shirt', 26),
#  ('hardli', 26),
#  ('stream', 26),
#  ('militari', 26),
#  ('lay', 26),
#  ('world', 26),
#  ('train', 26),
#  ('escap', 26),
#  ('leopard', 26),
#  ('full', 25),
#  ('anyon', 25),
#  ('quarrel', 25),
#  ('arriv', 25),
#  ('school', 25),
#  ('nois', 25),
#  ('hurt', 25),
#  ("'mi", 25),
#  ('bottl', 25),
#  ('thousand', 25),
#  ('forward', 25),
#  ('till', 25),
#  ('longer', 25),
#  ('pull', 25),
#  ('yell', 25),
#  ('ought', 25),
#  ('drop', 25),
#  ('rais', 25),
#  ('kick', 25),
#  ('scream', 25),
#  ('beat', 25),
#  ('aunt', 25),
#  ('longyi', 24),
#  ('twenti', 24),
#  ('later', 24),
#  ('ground', 24),
#  ('part', 24),
#  ('interest', 24),
#  ('jail', 24),
#  ('wonder', 24),
#  ("'how", 24),
#  ('pale', 24),
#  ('cheek', 24),
#  ('blue', 24),
#  ('scent', 24),
#  ('show', 24),
#  ('roll', 24),
#  ('ride', 24),
#  ('fat', 23),
#  ('march', 23),
#  ('chanc', 23),
#  ('die', 23),
#  ('best', 23),
#  ('reach', 23),
#  ('laugh', 23),
#  ('mother', 23),
#  ('angri', 23),
#  ('bamboo', 23),
#  ('fear', 23),
#  ('least', 23),
#  ('church', 23),
#  ('big', 23),
#  ('grey', 23),
#  ('bore', 23),
#  ('nigger', 23),
#  ('spectacl', 23),
#  ('explain', 23),
#  ('ass', 23),
#  ('pigeon', 23),
#  ('shot', 23),
#  ('beauti', 22),
#  ('grow', 22),
#  ('bare', 22),
#  ('clerk', 22),
#  ('final', 22),
#  ('earth', 22),
#  ('expect', 22),
#  ('ago', 22),
#  ('ye', 22),
#  ('wife', 22),
#  ('floor', 22),
#  ('hat', 22),
#  ('hill', 22),
#  ('field', 22),
#  ('manag', 22),
#  ('bitter', 22),
#  ('silent', 22),
#  ('repeat', 22),
#  ("'do", 22),
#  ('along', 22),
#  ('given', 22),
#  ('moon', 22),
#  ('struggl', 22),
#  ('breath', 21),
#  ('rangoon', 21),
#  ('danger', 21),
#  ('pagoda', 21),
#  ('wave', 21),
#  ('sight', 21),
#  ('lip', 21),
#  ('promis', 21),
#  ('mouth', 21),
#  ("'we", 21),
#  ('stone', 21),
#  ('breakfast', 21),
#  ('silk', 21),
#  ('learn', 21),
#  ('refus', 21),
#  ('middl', 21),
#  ('nearli', 21),
#  ('forest', 21),
#  ('uncl', 21),
#  ('line', 21),
#  ('certain', 21),
#  ('wo', 21),
#  ('row', 21),
#  ('tea', 21),
#  ('murder', 21),
#  ('nake', 20),
#  ('mandalay', 20),
#  ('send', 20),
#  ('wish', 20),
#  ('happi', 20),
#  ('subject', 20),
#  ('children', 20),
#  ('etc', 20),
#  ('immedi', 20),
#  ('hard', 20),
#  ('nose', 20),
#  ('cover', 20),
#  ('spite', 20),
#  ('remark', 20),
#  ('insid', 20),
#  ('smell', 20),
#  ('foot', 20),
#  ('burst', 20),
#  ('pay', 20),
#  ('somehow', 20),
#  ('pukka', 20),
#  ('begun', 20),
#  ('scene', 20),
#  ('sepoy', 20),
#  ('tear', 20),
#  ('vast', 19),
#  ('news', 19),
#  ('commission', 19),
#  ('attack', 19),
#  ('district', 19),
#  ('known', 19),
#  ('posit', 19),
#  ('gold', 19),
#  ("'that", 19),
#  ('ran', 19),
#  ('rail', 19),
#  ('quarter', 19),
#  ('wors', 19),
#  ('anonym', 19),
#  ('disgust', 19),
#  ('threw', 19),
#  ('brown', 19),
#  ('garden', 19),
#  ('free', 19),
#  ('miss', 19),
#  ('bank', 19),
#  ('wall', 19),
#  ('wooden', 19),
#  ('real', 19),
#  ('chines', 19),
#  ('ice', 19),
#  ('loung', 19),
#  ('lower', 19),
#  ('met', 19),
#  ('hell', 19),
#  ('pari', 19),
#  ('enter', 19),
#  ('doubt', 19),
#  ('england', 19),
#  ('creatur', 19),
#  ('true', 19),
#  ('understood', 19),
#  ('kiss', 19),
#  ('distanc', 19),
#  ('neck', 19),
#  ('thakin', 19),
#  ('realiz', 19),
#  ('li', 19),
#  ('yeik', 19),
#  ('job', 18),
#  ('prison', 18),
#  ('evil', 18),
#  ('return', 18),
#  ('headman', 18),
#  ('number', 18),
#  ('cold', 18),
#  ('late', 18),
#  ('less', 18),
#  ('town', 18),
#  ('edg', 18),
#  ('tini', 18),
#  ('spot', 18),
#  ('drunk', 18),
#  ('tenni', 18),
#  ('thick', 18),
#  ("'good", 18),
#  ('queer', 18),
#  ('readi', 18),
#  ('fall', 18),
#  ('servic', 18),
#  ('bit', 18),
#  ('exclaim', 18),
#  ('pretend', 18),
#  ('mile', 18),
#  ('fifteen', 18),
#  ('flat', 18),
#  ('compound', 18),
#  ('hiss', 18),
#  ('imagin', 18),
#  ('actual', 18),
#  ('propos', 18),
#  ('breast', 18),
#  ('exist', 18),
#  ('forgotten', 18),
#  ('pick', 18),
#  ('second', 18),
#  ('earthquak', 18),
#  ('gaze', 17),
#  ('rifl', 17),
#  ('caught', 17),
#  ('holi', 17),
#  ('basket', 17),
#  ('leg', 17),
#  ('opinion', 17),
#  ('consid', 17),
#  ('food', 17),
#  ('thin', 17),
#  ('bent', 17),
#  ('colour', 17),
#  ('chang', 17),
#  ('law', 17),
#  ('red', 17),
#  ('whether', 17),
#  ('riot', 17),
#  ('tone', 17),
#  ('suffer', 17),
#  ('shake', 17),
#  ('chap', 17),
#  ('either', 17),
#  ('break', 17),
#  ('sign', 17),
#  ('reason', 17),
#  ('dirti', 17),
#  ('suit', 17),
#  ('lost', 17),
#  ('offend', 17),
#  ('absolut', 17),
#  ('manner', 17),
#  ('save', 17),
#  ('cigarett', 17),
#  ('crocodil', 17),
#  ('sorri', 17),
#  ('perfectli', 17),
#  ('struck', 17),
#  ('led', 17),
#  ('dah', 17),
#  ('disgrac', 17),
#  ('wind', 16),
#  ('race', 16),
#  ('fight', 16),
#  ('miser', 16),
#  ('share', 16),
#  ('ignor', 16),
#  ('pictur', 16),
#  ('pe', 16),
#  ('movement', 16),
#  ('fish', 16),
#  ('slowli', 16),
#  ('violent', 16),
#  ('huge', 16),
#  ('pink', 16),
#  ('beer', 16),
#  ('shave', 16),
#  ('instead', 16),
#  ('sharpli', 16),
#  ('polo', 16),
#  ('eurasian', 16),
#  ('glare', 16),
#  ("'em", 16),
#  ('fli', 16),
#  ("'look", 16),
#  ('sleep', 16),
#  ('devil', 16),
#  ('shoe', 16),
#  ('sens', 16),
#  ('thank', 16),
#  ('bear', 16),
#  ('bottom', 16),
#  ('strang', 16),
#  ('offer', 16),
#  ('remain', 16),
#  ('blood', 16),
#  ('neither', 16),
#  ('cooli', 16),
#  ('fell', 16),
#  ('death', 16),
#  ('success', 15),
#  ('heel', 15),
#  ('grasp', 15),
#  ('stroke', 15),
#  ('public', 15),
#  ('practic', 15),
#  ('kept', 15),
#  ('mere', 15),
#  ('taik', 15),
#  ('shiko', 15),
#  ('affair', 15),
#  ('rag', 15),
#  ("'a", 15),
#  ("'and", 15),
#  ('dozen', 15),
#  ('dinner', 15),
#  ('prestig', 15),
#  ('ha', 15),
#  ('fashion', 15),
#  ('topi', 15),
#  ('rose', 15),
#  ('punkah', 15),
#  ('shook', 15),
#  ('firm', 15),
#  ('straight', 15),
#  ('push', 15),
#  ('tin', 15),
#  ('inde', 15),
#  ('madam', 15),
#  ('grew', 15),
#  ('often', 15),
#  ('piec', 15),
#  ('ugli', 15),
#  ('bedroom', 15),
#  ('laid', 15),
#  ('thirti', 15),
#  ('cross', 15),
#  ('sprang', 15),
#  ('shame', 15),
#  ('eight', 14),
#  ('stir', 14),
#  ('anna', 14),
#  ('bribe', 14),
#  ('sooner', 14),
#  ('pile', 14),
#  ('impress', 14),
#  ('backward', 14),
#  ('finger', 14),
#  ('broke', 14),
#  ('produc', 14),
#  ('articl', 14),
#  ('etc.', 14),
#  ('wretch', 14),
#  ('scandal', 14),
#  ('eat', 14),
#  ('rich', 14),
#  ('age', 14),
#  ('patch', 14),
#  ('hospit', 14),
#  ('franci', 14),
#  ('prickli', 14),
#  ('bath', 14),
#  ('mosquito', 14),
#  ('held', 14),
#  ('allow', 14),
#  ("'come", 14),
#  ('chokra', 14),
#  ("'go", 14),
#  ('beneath', 14),
#  ('husband', 14),
#  ('agre', 14),
#  ('empir', 14),
#  ('tie', 14),
#  ('hit', 14),
#  ('instant', 14),
#  ('joy', 14),
#  ('utter', 14),
#  ('drive', 14),
#  ('beastli', 14),
#  ('seriou', 14),
#  ('uncomfort', 14),
#  ("'they", 14),
#  ('extraordinari', 14),
#  ('buffalo', 14),
#  ('sea', 14),
#  ('silenc', 14),
#  ('despis', 14),
#  ('cool', 13),
#  ('child', 13),
#  ('becom', 13),
#  ('rule', 13),
#  ('wrong', 13),
#  ('sort', 13),
#  ('privat', 13),
#  ('attempt', 13),
#  ('accus', 13),
#  ('express', 13),
#  ("'there", 13),
#  ('joke', 13),
#  ('slip', 13),
#  ('belli', 13),
#  ('direct', 13),
#  ('rage', 13),
#  ('deal', 13),
#  ('prepar', 13),
#  ('torment', 13),
#  ('enorm', 13),
#  ('ingyi', 13),
#  ('plan', 13),
#  ('art', 13),
#  ('remind', 13),
#  ('gin', 13),
#  ('insult', 13),
#  ('hang', 13),
#  ('policemen', 13),
#  ('forehead', 13),
#  ('clean', 13),
#  ('sigh', 13),
#  ('fan', 13),
#  ('ball', 13),
#  ('music', 13),
#  ('frighten', 13),
#  ("'whi", 13),
#  ('singl', 13),
#  ('strike', 13),
#  ('disappoint', 13),
#  ('spent', 13),
#  ('climb', 13),
#  ('cartridg', 13),
#  ('pour', 13),
#  ('decent', 13),
#  ('foreign', 13),
#  ('rebel', 13),
#  ('strong', 13),
#  ('surpris', 13),
#  ('pwe', 13),
#  ('pay-lik', 13),
#  ('heavi', 12),
#  ('fail', 12),
#  ('ring', 12),
#  ('lead', 12),
#  ('wit', 12),
#  ('intend', 12),
#  ('seven', 12),
#  ('level', 12),
#  ('tomorrow', 12),
#  ('tall', 12),
#  ('smooth', 12),
#  ('partli', 12),
#  ('entir', 12),
#  ('wrote', 12),
#  ('quickli', 12),
#  ('tast', 12),
#  ('power', 12),
#  ('wicker', 12),
#  ('court', 12),
#  ('cock', 12),
#  ('peepul', 12),
#  ('slender', 12),
#  ('grass', 12),
#  ('pocket', 12),
#  ('rot', 12),
#  ('somebodi', 12),
#  ('fit', 12),
#  ('retir', 12),
#  ('war', 12),
#  ('ladi', 12),
#  ('earli', 12),
#  ('terribl', 12),
#  ('shock', 12),
#  ('disappear', 12),
#  ('meanwhil', 12),
#  ('game', 12),
#  ('press', 12),
#  ('shop', 12),
#  ('good-by', 12),
#  ('coat', 12),
#  ('oil', 12),
#  ('easili', 12),
#  ('narrow', 12),
#  ('meant', 12),
#  ('person', 12),
#  ('ear', 12),
#  ('caus', 12),
#  ('crawl', 12),
#  ('bend', 12),
#  ('gleam', 12),
#  ('seiz', 12),
#  ('afterward', 12),
#  ('de', 12),
#  ('nga', 12),
#  ('halt', 12),
#  ("'elizabeth", 12),
#  ('upper', 11),
#  ('stifl', 11),
#  ('dusti', 11),
#  ('crop', 11),
#  ('decid', 11),
#  ('grave', 11),
#  ('anim', 11),
#  ('form', 11),
#  ('build', 11),
#  ('rank', 11),
#  ('trust', 11),
#  ('secret', 11),
#  ('greet', 11),
#  ('teeth', 11),
#  ('cure', 11),
#  ('written', 11),
#  ('spoke', 11),
#  ('discuss', 11),
#  ('bow', 11),
#  ('dri', 11),
#  ('forti', 11),
#  ('mat', 11),
#  ('corner', 11),
#  ('habit', 11),
#  ('stock', 11),
#  ('stretch', 11),
#  ('top', 11),
#  ('admit', 11),
#  ('son', 11),
#  ('mali', 11),
#  ('englishman', 11),
#  ('cloud', 11),
#  ('beetl', 11),
#  ('invis', 11),
#  ('booz', 11),
#  ('niec', 11),
#  ('due', 11),
#  ('peg', 11),
#  ('suggest', 11),
#  ('garlic', 11),
#  ('filthi', 11),
#  ('excit', 11),
#  ('padr', 11),
#  ('evid', 11),
#  ('shut', 11),
#  ('dull', 11),
#  ('forgiv', 11),
#  ('fill', 11),
#  ('float', 11),
#  ("'of", 11),
#  ('rub', 11),
#  ('wild', 11),
#  ('hut', 11),
#  ('receiv', 11),
#  ('settl', 11),
#  ('throat', 11),
#  ('tail', 11),
#  ('loneli', 11),
#  ('bullock', 11),
#  ('roof', 11),
#  ('father', 11),
#  ('wash', 11),
#  ('earlier', 11),
#  ('flung', 11),
#  ('fallen', 11),
#  ('drag', 11),
#  ('broad', 11),
#  ('detail', 11),
#  ('drench', 10),
#  ('sky', 10),
#  ('sunlight', 10),
#  ('shape', 10),
#  ('squat', 10),
#  ('toe', 10),
#  ('assist', 10),
#  ('act', 10),
#  ('deputi', 10),
#  ('paid', 10),
#  ('worth', 10),
#  ('continu', 10),
#  ('accord', 10),
#  ('beast', 10),
#  ('constabl', 10),
#  ('whose', 10),
#  ('smile', 10),
#  ('patriot', 10),
#  ('type', 10),
#  ('stamp', 10),
#  ("'he", 10),
#  ('rise', 10),
#  ('easi', 10),
#  ('difficult', 10),
#  ('timber', 10),
#  ('import', 10),
#  ('deep', 10),
#  ("'then", 10),
#  ('quick', 10),
#  ('meal', 10),
#  ('finish', 10),
#  ('smoke', 10),
#  ('view', 10),
#  ('effort', 10),
#  ('disapprov', 10),
#  ('instanc', 10),
#  ('spear', 10),
#  ('samuel', 10),
#  ('aw', 10),
#  ('eh', 10),
#  ...]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#文章を小文字化
sentence_small = [w.lower() for w in sentence1]

#いけそう。文ごとに取り出し、それぞれの単語を原型に戻す。それを再び再構築する！
form_sent = []
for sentence in sentence_small:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    form_sent.append(" ".join(form))
    
    
#ピリオドやカンマを消しまーす。Delte period and comma...めんどい...
form_sent2 = []

for i in form_sent:
    tokens = nltk.word_tokenize(i)
    form = [word for word in tokens if not word in stopwords + symbols]
    form_sent2.append(" ".join(form))
    
    
#次にこの新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化したい
text = []

for i in form_sent2:
    tokens = nltk.word_tokenize(i)
    for j in tokens:
        text.append(j)
        
text = [text]

# %%
#新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化

import matplotlib.pyplot as plt
# %matplotlib inline

f_list_new = []
for i in text:
    f_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in f_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
log_freq  = []
for i in f_list_new[0].values():
    log_freq.append(i)

#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_freq, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('freq(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#順位チェック
sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('flori', 399),
#  ('one', 384),
#  ('like', 369),
#  ('said', 359),
#  ('would', 316),
#  ('elizabeth', 310),
#  ('could', 260),
#  ('even', 231),
#  ('look', 219),
#  ('go', 211),
#  ('back', 191),
#  ('club', 189),
#  ('face', 187),
#  ('come', 180),
#  ('two', 179),
#  ('time', 176),
#  ('flory', 171),
#  ('came', 163),
#  ('doctor', 163),
#  ('lackersteen', 163),
#  ('see', 155),
#  ('way', 149),
#  ('po', 147),
#  ('kyin', 146),
#  ('man', 145),
#  ("'i", 145),
#  ('never', 144),
#  ('macgregor', 140),
#  ('say', 139),
#  ('know', 138),
#  ('get', 133),
#  ('think', 131),
#  ('away', 131),
#  ('u', 129),
#  ('almost', 126),
#  ('round', 124),
#  ('made', 118),
#  ('turn', 115),
#  ('littl', 114),
#  ('ko', 114),
#  ('talk', 113),
#  ('white', 111),
#  ('make', 110),
#  ('hand', 109),
#  ('old', 109),
#  ('men', 107),
#  ('quit', 103),
#  ('must', 103),
#  ('moment', 102),
#  ('thing', 101),
#  ('good', 101),
#  ('though', 100),
#  ('girl', 100),
#  ('head', 99),
#  ('thought', 99),
#  ("s'la", 99),
#  ('european', 97),
#  ('iss', 97),
#  ('put', 95),
#  ('day', 94),
#  ('got', 94),
#  ('long', 93),
#  ('elli', 93),
#  ('went', 91),
#  ('much', 91),
#  ('take', 90),
#  ('year', 89),
#  ('life', 87),
#  ('verral', 87),
#  ('everi', 84),
#  ('behind', 84),
#  ('seem', 83),
#  ('friend', 83),
#  ('yet', 82),
#  ('call', 80),
#  ('right', 79),
#  ('rather', 77),
#  ('us', 77),
#  ('took', 76),
#  ('well', 76),
#  ('may', 75),
#  ("'ll", 74),
#  ('black', 73),
#  ('someth', 72),
#  ('kyauktada', 71),
#  ('woman', 71),
#  ('westfield', 71),
#  ('veranda', 70),
#  ('without', 70),
#  ('god', 69),
#  ('let', 69),
#  ("'oh", 69),
#  ('still', 68),
#  ('ever', 68),
#  ('arm', 68),
#  ('want', 68),
#  ('live', 67),
#  ('tell', 67),
#  ("'what", 67),
#  ('english', 65),
#  ('indian', 65),
#  ('burmes', 64),
#  ('hla', 63),
#  ('tree', 62),
#  ('alway', 62),
#  ('give', 62),
#  ('young', 62),
#  ('stood', 62),
#  ('heard', 62),
#  ('keep', 62),
#  ('saw', 61),
#  ('shall', 61),
#  ('first', 61),
#  ('upon', 60),
#  ('done', 60),
#  ('ask', 60),
#  ('hear', 59),
#  ("'m", 59),
#  ('great', 58),
#  ('left', 58),
#  ('word', 58),
#  ('kind', 57),
#  ('walk', 57),
#  ('home', 57),
#  ('women', 57),
#  ('air', 56),
#  ('last', 56),
#  ('night', 56),
#  ('burma', 55),
#  ("'d", 55),
#  ('love', 55),
#  ('mind', 54),
#  ('small', 53),
#  ('knew', 53),
#  ("'the", 53),
#  ('letter', 53),
#  ('ellis', 53),
#  ('sit', 52),
#  ('dear', 52),
#  ('veraswami', 52),
#  ('mean', 52),
#  ('eye', 51),
#  ('matter', 51),
#  ('road', 51),
#  ('across', 51),
#  ('tri', 50),
#  ('ba', 50),
#  ('yellow', 49),
#  ('except', 49),
#  ('servant', 49),
#  ('peopl', 48),
#  ('use', 48),
#  ('place', 48),
#  ('course', 48),
#  ('brought', 48),
#  ('end', 48),
#  ('began', 48),
#  ('noth', 48),
#  ('flo', 48),
#  ('bloodi', 48),
#  ('speak', 48),
#  ('butler', 48),
#  ('evening', 48),
#  ('feet', 47),
#  ('nativ', 47),
#  ('whole', 47),
#  ('drink', 47),
#  ('enough', 46),
#  ('burman', 46),
#  ('feel', 46),
#  ('toward', 46),
#  ('kin', 46),
#  ('notic', 46),
#  ('watch', 45),
#  ('three', 45),
#  ('found', 45),
#  ('room', 45),
#  ('stand', 45),
#  ('hair', 45),
#  ('ca', 45),
#  ('verrall', 45),
#  ('chair', 44),
#  ('side', 44),
#  ('anoth', 44),
#  ('sound', 44),
#  ('jungle', 44),
#  ('rain', 44),
#  ('gone', 44),
#  ('water', 44),
#  ('poor', 43),
#  ('four', 43),
#  ('oh', 43),
#  ('yard', 43),
#  ('house', 43),
#  ('half', 42),
#  ('however', 42),
#  ('short', 42),
#  ('among', 42),
#  ('villag', 42),
#  ('also', 42),
#  ('shoulder', 42),
#  ('week', 41),
#  ('hous', 41),
#  ('better', 41),
#  ('sat', 41),
#  ('start', 41),
#  ('month', 40),
#  ('felt', 40),
#  ('hundr', 40),
#  ('anyth', 40),
#  ("'you", 40),
#  ("'no", 40),
#  ('work', 39),
#  ('money', 39),
#  ('hope', 39),
#  ('morning', 39),
#  ('hold', 39),
#  ('leav', 39),
#  ('boy', 39),
#  ("'it", 39),
#  ('move', 39),
#  ('ah', 39),
#  ('might', 39),
#  ('birthmark', 39),
#  ('stop', 39),
#  ('dr', 38),
#  ('skin', 38),
#  ('together', 38),
#  ('dread', 38),
#  ('crowd', 38),
#  ('green', 37),
#  ('step', 37),
#  ('wait', 37),
#  ('name', 37),
#  ('bad', 37),
#  ('perhap', 37),
#  ('morn', 37),
#  ('dress', 37),
#  ('dark', 37),
#  ('seen', 37),
#  ('gate', 37),
#  ('gave', 37),
#  ("'yes", 36),
#  ('far', 36),
#  ('open', 36),
#  ('told', 36),
#  ('bazaar', 36),
#  ('sun', 36),
#  ('heat', 36),
#  ('path', 36),
#  ('voic', 36),
#  ('pleas', 36),
#  ('marri', 36),
#  ('rebellion', 36),
#  ('taken', 35),
#  ('offici', 35),
#  ('follow', 35),
#  ('care', 35),
#  ('happen', 35),
#  ("'but", 35),
#  ('usual', 35),
#  ('master', 35),
#  ('light', 35),
#  ('bed', 35),
#  ('sent', 34),
#  ('sever', 34),
#  ('point', 34),
#  ('polic', 34),
#  ('etc', 34),
#  ('set', 34),
#  ('carri', 34),
#  ('hot', 34),
#  ('realli', 34),
#  ('door', 34),
#  ('clear', 34),
#  ('everyon', 33),
#  ('low', 33),
#  ('present', 33),
#  ('jungl', 33),
#  ('ten', 32),
#  ('answer', 32),
#  ('hour', 32),
#  ('bodi', 32),
#  ('dog', 32),
#  ('possibl', 32),
#  ('cut', 32),
#  ('book', 32),
#  ('gun', 32),
#  ('besid', 31),
#  ('believ', 31),
#  ('honour', 31),
#  ('th', 31),
#  ("'ah", 31),
#  ('fire', 31),
#  ('soon', 31),
#  ('new', 31),
#  ('stick', 31),
#  ('india', 31),
#  ('damn', 31),
#  ('bring', 31),
#  ("i'v", 31),
#  ('pass', 31),
#  ('camp', 31),
#  ('rememb', 30),
#  ('sometim', 30),
#  ('next', 30),
#  ('begin', 30),
#  ('understand', 30),
#  ('touch', 30),
#  ('find', 30),
#  ('fool', 30),
#  ('country', 30),
#  ('suppos', 30),
#  ('sinc', 29),
#  ('simpli', 29),
#  ('appear', 29),
#  ("'well", 29),
#  ('listen', 29),
#  ('stay', 29),
#  ('order', 29),
#  ('happened', 29),
#  ('alreadi', 28),
#  ('read', 28),
#  ('tabl', 28),
#  ('hate', 28),
#  ('run', 28),
#  ('sweat', 28),
#  ('front', 28),
#  ('fact', 28),
#  ('afraid', 28),
#  ('sahib', 28),
#  ('dead', 28),
#  ('heart', 28),
#  ('shoot', 28),
#  ('past', 27),
#  ('beyond', 27),
#  ('help', 27),
#  ('wear', 27),
#  ('offic', 27),
#  ('rest', 27),
#  ('six', 27),
#  ('sein', 27),
#  ('rupe', 27),
#  ('shout', 27),
#  ('maidan', 27),
#  ('orient', 27),
#  ('fellow', 27),
#  ('elect', 27),
#  ('close', 26),
#  ('high', 26),
#  ('british', 26),
#  ('case', 26),
#  ('five', 26),
#  ('eyes', 26),
#  ('within', 26),
#  ('near', 26),
#  ('river', 26),
#  ('larg', 26),
#  ('hardli', 26),
#  ('youth', 26),
#  ('meet', 26),
#  ('people', 26),
#  ('militari', 26),
#  ('lay', 26),
#  ('dare', 26),
#  ('train', 26),
#  ('leopard', 26),
#  ('table', 25),
#  ('natur', 25),
#  ('full', 25),
#  ('mani', 25),
#  ('question', 25),
#  ('kill', 25),
#  ("'mi", 25),
#  ('shirt', 25),
#  ('thousand', 25),
#  ('forward', 25),
#  ('till', 25),
#  ('lie', 25),
#  ('play', 25),
#  ('stream', 25),
#  ('others', 25),
#  ('longer', 25),
#  ('ought', 25),
#  ('world', 25),
#  ('aunt', 25),
#  ('later', 24),
#  ('differ', 24),
#  ('civil', 24),
#  ('jail', 24),
#  ("'how", 24),
#  ('hurt', 24),
#  ('sure', 24),
#  ('pale', 24),
#  ('need', 24),
#  ('blue', 24),
#  ('pain', 24),
#  ('hurri', 24),
#  ('gener', 24),
#  ('horribl', 24),
#  ('scent', 24),
#  ('pull', 24),
#  ('show', 24),
#  ('years', 24),
#  ('rais', 24),
#  ('beat', 24),
#  ('longyi', 23),
#  ('probabl', 23),
#  ('best', 23),
#  ('part', 23),
#  ('reach', 23),
#  ('anyon', 23),
#  ('europeans', 23),
#  ('least', 23),
#  ('alone', 23),
#  ('church', 23),
#  ('big', 23),
#  ('grey', 23),
#  ('voice', 23),
#  ('member', 23),
#  ('togeth', 23),
#  ('station', 23),
#  ('fifti', 23),
#  ('drop', 23),
#  ('roll', 23),
#  ('ass', 23),
#  ('kick', 23),
#  ('ground', 23),
#  ('fat', 22),
#  ('earth', 22),
#  ('interest', 22),
#  ('ago', 22),
#  ('bird', 22),
#  ('wife', 22),
#  ('floor', 22),
#  ('bottl', 22),
#  ('flowers', 22),
#  ('idea', 22),
#  ('suddenli', 22),
#  ('outsid', 22),
#  ("'do", 22),
#  ('someon', 22),
#  ('along', 22),
#  ('given', 22),
#  ('cours', 22),
#  ('danc', 22),
#  ('knee', 22),
#  ('shot', 22),
#  ('beater', 22),
#  ('bare', 21),
#  ('march', 21),
#  ('twenti', 21),
#  ('rangoon', 21),
#  ('wave', 21),
#  ('ruin', 21),
#  ('breakfast', 21),
#  ('silk', 21),
#  ('learn', 21),
#  ('cheek', 21),
#  ('nearli', 21),
#  ("they'r", 21),
#  ('explain', 21),
#  ('fear', 21),
#  ('certain', 21),
#  ('wo', 21),
#  ('cri', 21),
#  ('tea', 21),
#  ('moon', 21),
#  ('ride', 21),
#  ('breath', 20),
#  ('grow', 20),
#  ('mandalay', 20),
#  ('final', 20),
#  ('send', 20),
#  ('wish', 20),
#  ('subject', 20),
#  ('children', 20),
#  ('mother', 20),
#  ('promis', 20),
#  ('school', 20),
#  ('mouth', 20),
#  ("'we", 20),
#  ('hard', 20),
#  ('yes', 20),
#  ('els', 20),
#  ('cover', 20),
#  ('bamboo', 20),
#  ('middl', 20),
#  ('spite', 20),
#  ('hat', 20),
#  ('sight', 20),
#  ('smell', 20),
#  ('hands', 20),
#  ('bitter', 20),
#  ('forest', 20),
#  ('foot', 20),
#  ("we'r", 20),
#  ('burst', 20),
#  ('pay', 20),
#  ('somehow', 20),
#  ('pukka', 20),
#  ('nothing', 20),
#  ('row', 20),
#  ('servants', 20),
#  ('scream', 20),
#  ('begun', 20),
#  ('scene', 20),
#  ('struggl', 20),
#  ('vast', 19),
#  ('clerk', 19),
#  ('news', 19),
#  ('attack', 19),
#  ('district', 19),
#  ('known', 19),
#  ('die', 19),
#  ('gold', 19),
#  ("'that", 19),
#  ('troubl', 19),
#  ('ran', 19),
#  ('expect', 19),
#  ('anonym', 19),
#  ('threw', 19),
#  ('brown', 19),
#  ('nose', 19),
#  ('free', 19),
#  ('wooden', 19),
#  ('real', 19),
#  ('chines', 19),
#  ('lower', 19),
#  ('silent', 19),
#  ('met', 19),
#  ('hell', 19),
#  ("you'r", 19),
#  ('england', 19),
#  ('busi', 19),
#  ('true', 19),
#  ('understood', 19),
#  ('kiss', 19),
#  ('thakin', 19),
#  ('murder', 19),
#  ('li', 19),
#  ('yeik', 19),
#  ('nake', 18),
#  ('govern', 18),
#  ('job', 18),
#  ('evil', 18),
#  ('headman', 18),
#  ('quarrel', 18),
#  ('paper', 18),
#  ('rail', 18),
#  ('less', 18),
#  ('town', 18),
#  ('bank', 18),
#  ('spot', 18),
#  ('drunk', 18),
#  ('wonder', 18),
#  ('everyth', 18),
#  ('ice', 18),
#  ('field', 18),
#  ('thick', 18),
#  ("'good", 18),
#  ('whiski', 18),
#  ('queer', 18),
#  ('nigger', 18),
#  ("we'v", 18),
#  ('yell', 18),
#  ('enter', 18),
#  ('pretend', 18),
#  ('fifteen', 18),
#  ('flat', 18),
#  ('hiss', 18),
#  ('things', 18),
#  ('actual', 18),
#  ("you'v", 18),
#  ('propos', 18),
#  ('minut', 18),
#  ('bush', 18),
#  ('neck', 18),
#  ('forgotten', 18),
#  ('pick', 18),
#  ('gaze', 17),
#  ('rupees', 17),
#  ('caught', 17),
#  ('danger', 17),
#  ('arriv', 17),
#  ('days', 17),
#  ('number', 17),
#  ('angri', 17),
#  ('cold', 17),
#  ('stone', 17),
#  ('food', 17),
#  ('thin', 17),
#  ('bent', 17),
#  ('garden', 17),
#  ('refus', 17),
#  ('something', 17),
#  ('miss', 17),
#  ('hill', 17),
#  ('trees', 17),
#  ('chang', 17),
#  ('red', 17),
#  ('whether', 17),
#  ('riot', 17),
#  ('bore', 17),
#  ('tone', 17),
#  ('remark', 17),
#  ('cloth', 17),
#  ('manag', 17),
#  ('suffer', 17),
#  ('maxwell', 17),
#  ('either', 17),
#  ('ad', 17),
#  ('break', 17),
#  ('convers', 17),
#  ('faces', 17),
#  ('bit', 17),
#  ('outside', 17),
#  ('lost', 17),
#  ('save', 17),
#  ('compound', 17),
#  ('struck', 17),
#  ('led', 17),
#  ('shooting', 17),
#  ('realiz', 17),
#  ('sepoy', 17),
#  ('escap', 17),
#  ('chanc', 16),
#  ('return', 16),
#  ('basket', 16),
#  ('laugh', 16),
#  ('alon', 16),
#  ('pe', 16),
#  ('wors', 16),
#  ('consid', 16),
#  ('huge', 16),
#  ('pink', 16),
#  ('beer', 16),
#  ('instead', 16),
#  ('edg', 16),
#  ('polo', 16),
#  ('glare', 16),
#  ("'em", 16),
#  ('already', 16),
#  ('fli', 16),
#  ("'look", 16),
#  ('shake', 16),
#  ('sign', 16),
#  ('reason', 16),
#  ('fall', 16),
#  ('mile', 16),
#  ('doubt', 16),
#  ('manner', 16),
#  ('late', 16),
#  ('offer', 16),
#  ('pigeon', 16),
#  ('dah', 16),
#  ('remain', 16),
#  ('blood', 16),
#  ('neither', 16),
#  ('tear', 16),
#  ('fell', 16),
#  ('death', 16),
#  ('wind', 15),
#  ('miser', 15),
#  ('public', 15),
#  ('share', 15),
#  ('kept', 15),
#  ('posit', 15),
#  ('mere', 15),
#  ('taik', 15),
#  ('holi', 15),
#  ("'a", 15),
#  ("'and", 15),
#  ('nois', 15),
#  ('fish', 15),
#  ('dozen', 15),
#  ('dinner', 15),
#  ('ha', 15),
#  ('fashion', 15),
#  ('pagoda', 15),
#  ('topi', 15),
#  ('colour', 15),
#  ('wall', 15),
#  ('rose', 15),
#  ('tenni', 15),
#  ('punkah', 15),
#  ('shook', 15),
#  ('chap', 15),
#  ('straight', 15),
#  ('readi', 15),
#  ('push', 15),
#  ('offend', 15),
#  ('countri', 15),
#  ('grew', 15),
#  ('sens', 15),
#  ('bottom', 15),
#  ('often', 15),
#  ('immedi', 15),
#  ('piec', 15),
#  ("they'v", 15),
#  ('bedroom', 15),
#  ('laid', 15),
#  ('sprang', 15),
#  ('second', 15),
#  ('eight', 14),
#  ('minutes', 14),
#  ('fight', 14),
#  ('affair', 14),
#  ('broke', 14),
#  ('happi', 14),
#  ('times', 14),
#  ('lip', 14),
#  ('violent', 14),
#  ('shave', 14),
#  ('prickli', 14),
#  ('sleep', 14),
#  ('held', 14),
#  ('insid', 14),
#  ('devil', 14),
#  ("'come", 14),
#  ('please', 14),
#  ('suit', 14),
#  ('beneath', 14),
#  ('absolut', 14),
#  ('indeed', 14),
#  ('tie', 14),
#  ('hit', 14),
#  ('thank', 14),
#  ('instant', 14),
#  ('joy', 14),
#  ('drive', 14),
#  ('cross', 14),
#  ('sea', 14),
#  ('madam', 14),
#  ('success', 13),
#  ('child', 13),
#  ('race', 13),
#  ('becom', 13),
#  ('rule', 13),
#  ('wrong', 13),
#  ('sooner', 13),
#  ('sort', 13),
#  ('pile', 13),
#  ("'there", 13),
#  ('produc', 13),
#  ('articl', 13),
#  ('h', 13),
#  ('added', 13),
#  ('deal', 13),
#  ('torment', 13),
#  ('ingyi', 13),
#  ('rich', 13),
#  ('everything', 13),
#  ('age', 13),
#  ('tini', 13),
#  ('patch', 13),
#  ('law', 13),
#  ('art', 13),
#  ('bath', 13),
#  ('loung', 13),
#  ('firm', 13),
#  ('remind', 13),
#  ('gin', 13),
#  ('maxwel', 13),
#  ('going', 13),
#  ('burmese', 13),
#  ('policemen', 13),
#  ('dirti', 13),
#  ('forehead', 13),
#  ('chokra', 13),
#  ("'go", 13),
#  ('paris', 13),
#  ('clean', 13),
#  ('fan', 13),
#  ('tin', 13),
#  ('bear', 13),
#  ('music', 13),
#  ('line', 13),
#  ('opinion', 13),
#  ('singl', 13),
#  ('strike', 13),
#  ('spent', 13),
#  ('eat', 13),
#  ('breast', 13),
#  ('strang', 13),
#  ('body', 13),
#  ('climb', 13),
#  ('extraordinari', 13),
#  ('buffalo', 13),
#  ('pour', 13),
#  ('thirti', 13),
#  ('strong', 13),
#  ('poni', 13),
#  ('hors', 13),
#  ('pwe', 13),
#  ('pay-like', 13),
#  ('cool', 12),
#  ('beauti', 12),
#  ('rifl', 12),
#  ('grasp', 12),
#  ('stroke', 12),
#  ('ring', 12),
#  ('prison', 12),
#  ('attempt', 12),
#  ('seven', 12),
#  ('level', 12),
#  ('tomorrow', 12),
#  ('tall', 12),
#  ('smooth', 12),
#  ('partli', 12),
#  ('wretch', 12),
#  ('wrote', 12),
#  ('movement', 12),
#  ('quarter', 12),
#  ('rage', 12),
#  ('slowli', 12),
#  ('enorm', 12),
#  ('wicker', 12),
#  ('peepul', 12),
#  ('slender', 12),
#  ('allow', 12),
#  ('fit', 12),
#  ('war', 12),
#  ('shoe', 12),
#  ('husband', 12),
#  ('press', 12),
#  ('shop', 12),
#  ('coat', 12),
#  ('creatur', 12),
#  ('talking', 12),
#  ('oil', 12),
#  ('crocodile', 12),
#  ('imagin', 12),
#  ("'they", 12),
#  ('narrow', 12),
#  ('meant', 12),
#  ('person', 12),
#  ('decent', 12),
#  ('bend', 12),
#  ('seiz', 12),
#  ('de', 12),
#  ('shame', 12),
#  ('nga', 12),
#  ("'elizabeth", 12),
#  ('earthquake', 12),
#  ('upper', 11),
#  ('stir', 11),
#  ('commissioner', 11),
#  ('privat', 11),
#  ('lead', 11),
#  ('practic', 11),
#  ('form', 11),
#  ('impress', 11),
#  ('joke', 11),
#  ('rag', 11),
#  ('entir', 11),
#  ('teeth', 11),
#  ('scandal', 11),
#  ('written', 11),
#  ('spoke', 11),
#  ('disgust', 11),
#  ('prepar', 11),
#  ('discuss', 11),
#  ('direct', 11),
#  ('cock', 11),
#  ('stretch', 11),
#  ('top', 11),
#  ('power', 11),
#  ('admit', 11),
#  ('grass', 11),
#  ('mali', 11),
#  ('flower', 11),
#  ('englishman', 11),
#  ('police', 11),
#  ('coming', 11),
#  ('leg', 11),
#  ('mosquito', 11),
#  ('due', 11),
#  ('peg', 11),
#  ('insult', 11),
#  ('garlic', 11),
#  ('hang', 11),
#  ('repeat', 11),
#  ('spectacles', 11),
#  ('knees', 11),
#  ('shut', 11),
#  ('dull', 11),
#  ('natives', 11),
#  ('fill', 11),
#  ('float', 11),
#  ("'of", 11),
#  ('shock', 11),
#  ('rub', 11),
#  ('wild', 11),
#  ('ignor', 11),
#  ('trouble', 11),
#  ('sorry', 11),
#  ('settl', 11),
#  ('books', 11),
#  ('throat', 11),
#  ('repeated', 11),
#  ('tail', 11),
#  ('distanc', 11),
#  ('caus', 11),
#  ('crawl', 11),
#  ('wash', 11),
#  ('shiko', 11),
#  ('uncle', 11),
#  ('perfectli', 11),
#  ('earlier', 11),
#  ('despis', 11),
#  ('flung', 11),
#  ('fallen', 11),
#  ('drag', 11),
#  ('anything', 11),
#  ('broad', 11),
#  ('detail', 11),
#  ('sunlight', 10),
#  ('shape', 10),
#  ('crop', 10),
#  ('heel', 10),
#  ('fail', 10),
#  ('anna', 10),
#  ('else', 10),
#  ('act', 10),
#  ('deputi', 10),
#  ('bribe', 10),
#  ('paid', 10),
#  ('worth', 10),
#  ('accord', 10),
#  ('intend', 10),
#  ('rank', 10),
#  ('beast', 10),
#  ('whose', 10),
#  ('trust', 10),
#  ('greet', 10),
#  ("'he", 10),
#  ('rise', 10),
#  ('another', 10),
#  ('difficult', 10),
#  ('believe', 10),
#  ('timber', 10),
#  ('deep', 10),
#  ("'then", 10),
#  ('quick', 10),
#  ('tast', 10),
#  ('corner', 10),
#  ('view', 10),
#  ('effort', 10),
#  ('plan', 10),
#  ('business', 10),
#  ('spear', 10),
#  ('eurasian', 10),
#  ('samuel', 10),
#  ('son', 10),
#  ('bushes', 10),
#  ('backward', 10),
#  ('suppose', 10),
#  ('cloud', 10),
#  ('eh', 10),
#  ('dusti', 10),
#  ('dust', 10),
#  ('christ', 10),
#  ('uncl', 10),
#  ('married', 10),
#  ('enjoy', 10),
#  ('rot', 10),
#  ('heavi', 10),
#  ('anger', 10),
#  ('complet', 10),
#  ('asleep', 10),
#  ('ladi', 10),
#  ('evid', 10),
#  ('gather', 10),
#  ('game', 10),
#  ('forgiv', 10),
#  ('perhaps', 10),
#  ("'if", 10),
#  ('shade', 10),
#  ('conversation', 10),
#  ('hass', 10),
#  ('utter', 10),
#  ('snub', 10),
#  ('helpless', 10),
#  ('worst', 10),
#  ('mattu', 10),
#  ('hut', 10),
#  ('serious', 10),
#  ('seriou', 10),
#  ('uncomfort', 10),
#  ('receiv', 10),
#  ('ugli', 10),
#  ("'whi", 10),
#  ('visit', 10),
#  ("'get", 10),
#  ('mood', 10),
#  ('twist', 10),
#  ('ear', 10),
#  ('plung', 10),
#  ('roof', 10),
#  ...]

# %%
# let's make new list only with words whose frequency  > 25

moreThan40_freq = []

for i,j in f_list_new[0].items():
    if j >= 40:
        moreThan40_freq.append(i)

# %%
# 頻出単語top2のgameshとsaidが同時に現れる文を、ピックアップしカウントするプログラムを全ての単語に割り当てる試み。

count_s = {}

for wn1 in range(0, len(moreThan40_freq)-1):
    for wn2 in range(wn1+1, len(moreThan40_freq)):
        s = 0
    
        for sent in form_sent2:
            index1 = 0
            index2 = 0
            
            #remove duplicate
            if moreThan40_freq[wn1] != moreThan40_freq[wn2]:
                
                if moreThan40_freq[wn1] in sent.split():
                    index1 += 1
                if moreThan40_freq[wn2] in sent.split():
                    index2 += 1
              
                if index1 > 0 and index2 > 0:
                    s += 1
                
        count_s.update({( moreThan40_freq[wn1], moreThan40_freq[wn2]) :s })

# %%
#順位チェック
sorted(count_s.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('po', 'kyin'), 142),
#  (('u', 'po'), 125),
#  (('u', 'kyin'), 124),
#  (('ko', "s'la"), 94),
#  (('may', 'hla'), 57),
#  (('flori', 'elizabeth'), 53),
#  (('said', 'flori'), 47),
#  (('said', "'i"), 33),
#  (('look', 'face'), 32),
#  (('could', 'see'), 31),
#  (('man', 'white'), 29),
#  (('elizabeth', 'verral'), 28),
#  (('one', 'like'), 27),
#  (('look', 'like'), 26),
#  (('one', 'could'), 25),
#  (('even', 'would'), 25),
#  (('said', 'westfield'), 23),
#  (('flori', 'club'), 23),
#  (('back', 'flori'), 22),
#  (('said', 'lackersteen'), 22),
#  (('one', 'flori'), 21),
#  (('could', 'face'), 21),
#  (('back', 'go'), 21),
#  (('turn', 'away'), 21),
#  (('said', 'elli'), 21),
#  (("'i", "'m"), 21),
#  (('away', 'yard'), 21),
#  (('could', 'even'), 20),
#  (('could', 'flori'), 19),
#  (('could', 'elizabeth'), 19),
#  (('like', 'white'), 19),
#  (('like', 'face'), 19),
#  (('face', 'yellow'), 19),
#  (('european', 'club'), 19),
#  (('lackersteen', 'elizabeth'), 19),
#  (('even', 'elizabeth'), 18),
#  (('turn', 'round'), 18),
#  (('said', 'elizabeth'), 18),
#  (('two', 'elizabeth'), 18),
#  (('ko', 'flori'), 18),
#  (('away', 'flori'), 18),
#  (('flori', "s'la"), 18),
#  (('one', 'see'), 17),
#  (('one', 'thing'), 17),
#  (('one', 'two'), 17),
#  (('tree', 'like'), 17),
#  (('like', 'almost'), 17),
#  (('went', 'flori'), 17),
#  (('came', 'flori'), 17),
#  (('would', 'never'), 17),
#  (('one', 'would'), 16),
#  (('could', 'like'), 16),
#  (('look', 'flori'), 16),
#  (('like', 'would'), 16),
#  (('like', 'flori'), 16),
#  (('even', 'club'), 16),
#  (('back', 'come'), 16),
#  (('came', 'elizabeth'), 16),
#  (('would', 'flori'), 16),
#  (('one', 'hand'), 15),
#  (('like', 'black'), 15),
#  (('white', 'men'), 15),
#  (('face', 'turn'), 15),
#  (('back', 'came'), 15),
#  (('time', 'flori'), 15),
#  (('said', 'girl'), 15),
#  (('said', 'macgregor'), 15),
#  (('ask', 'flori'), 15),
#  (('veranda', 'flori'), 14),
#  (('long', 'time'), 14),
#  (('look', 'elizabeth'), 14),
#  (('took', 'flori'), 14),
#  (('would', 'doctor'), 14),
#  (('turn', 'flori'), 14),
#  (('ba', 'ko'), 14),
#  (('said', 'flory'), 14),
#  (('two', 'women'), 14),
#  (('one', 'look'), 13),
#  (('one', 'never'), 13),
#  (('one', 'littl'), 13),
#  (('could', 'hear'), 13),
#  (('see', 'face'), 13),
#  (('like', 'round'), 13),
#  (('year', 'two'), 13),
#  (('even', 'flori'), 13),
#  (('back', 'day'), 13),
#  (('back', 'elizabeth'), 13),
#  (('go', 'let'), 13),
#  (('go', 'must'), 13),
#  (('would', 'say'), 13),
#  (('would', 'said'), 13),
#  (('would', 'ask'), 13),
#  (('would', 'come'), 13),
#  (('littl', 'flori'), 13),
#  (('said', 'old'), 13),
#  (('said', "'the"), 13),
#  (('said', 'doctor'), 13),
#  (('last', 'night'), 13),
#  (('doctor', 'flori'), 13),
#  (('one', 'even'), 12),
#  (('one', 'make'), 12),
#  (('one', 'except'), 12),
#  (('one', 'elizabeth'), 12),
#  (('could', 'look'), 12),
#  (('could', 'go'), 12),
#  (('could', 'feel'), 12),
#  (('see', 'like'), 12),
#  (('see', 'elizabeth'), 12),
#  (('like', 'man'), 12),
#  (('like', 'yellow'), 12),
#  (('like', 'two'), 12),
#  (('like', 'lackersteen'), 12),
#  (('year', 'time'), 12),
#  (('even', 'face'), 12),
#  (('even', 'everi'), 12),
#  (('back', 'lackersteen'), 12),
#  (('put', 'hand'), 12),
#  (('go', 'said'), 12),
#  (('go', 'away'), 12),
#  (('go', 'club'), 12),
#  (('would', 'club'), 12),
#  (('would', 'elizabeth'), 12),
#  (('never', 'flori'), 12),
#  (('flory', 'elizabeth'), 12),
#  (('flori', 'across'), 12),
#  (('club', 'lackersteen'), 12),
#  (('almost', 'elizabeth'), 12),
#  (('long', 'like'), 11),
#  (('one', 'man'), 11),
#  (('one', 'white'), 11),
#  (('one', 'face'), 11),
#  (('one', 'life'), 11),
#  (('one', 'way'), 11),
#  (('one', 'say'), 11),
#  (('could', 'get'), 11),
#  (('could', 'would'), 11),
#  (('look', 'back'), 11),
#  (('look', 'round'), 11),
#  (('like', 'old'), 11),
#  (('like', 'talk'), 11),
#  (('man', 'even'), 11),
#  (('man', 'said'), 11),
#  (('man', 'old'), 11),
#  (('yet', 'even'), 11),
#  (('face', 'round'), 11),
#  (('face', 'flori'), 11),
#  (('think', "'i"), 11),
#  (('think', 'know'), 11),
#  (('back', 'would'), 11),
#  (('back', 'take'), 11),
#  (('came', 'ko'), 11),
#  (('came', "s'la"), 11),
#  (('go', 'would'), 11),
#  (('go', 'home'), 11),
#  (('arm', 'round'), 11),
#  (('two', 'flori'), 11),
#  (('macgregor', 'club'), 11),
#  (('walk', 'flori'), 11),
#  (('flori', 'sat'), 11),
#  (('club', 'elizabeth'), 11),
#  (('u', 'doctor'), 10),
#  (('po', 'would'), 10),
#  (('po', 'doctor'), 10),
#  (('kyin', 'would'), 10),
#  (('kyin', 'doctor'), 10),
#  (('long', 'one'), 10),
#  (('one', 'eye'), 10),
#  (('one', 'back'), 10),
#  (('one', 'came'), 10),
#  (('one', 'anoth'), 10),
#  (('one', 'come'), 10),
#  (('one', 'must'), 10),
#  (('one', 'club'), 10),
#  (('one', 'almost'), 10),
#  (('could', 'said'), 10),
#  (('could', 'moment'), 10),
#  (('see', 'flori'), 10),
#  (('like', 'great'), 10),
#  (('like', 'yet'), 10),
#  (('like', 'way'), 10),
#  (('like', 'go'), 10),
#  (('like', 'come'), 10),
#  (('like', 'elizabeth'), 10),
#  (('man', 'face'), 10),
#  (('man', 'would'), 10),
#  (('yet', 'elizabeth'), 10),
#  (('even', 'time'), 10),
#  (('even', 'never'), 10),
#  (('white', 'black'), 10),
#  (('men', 'two'), 10),
#  (('back', 'way'), 10),
#  (('way', 'made'), 10),
#  (('time', 'day'), 10),
#  (('time', 'would'), 10),
#  (('time', 'come'), 10),
#  (('time', 'first'), 10),
#  (('make', 'would'), 10),
#  (('came', 'would'), 10),
#  (('came', 'club'), 10),
#  (('day', 'everi'), 10),
#  (('saw', 'elizabeth'), 10),
#  (('take', 'said'), 10),
#  (('say', 'said'), 10),
#  (('hand', 'stood'), 10),
#  (('said', 'come'), 10),
#  (('said', 'ellis'), 10),
#  (('ko', 'flory'), 10),
#  (('girl', 'flori'), 10),
#  (('come', 'club'), 10),
#  (('doctor', 'flory'), 10),
#  (('nativ', 'club'), 10),
#  (('friend', 'iss'), 10),
#  (('flory', "s'la"), 10),
#  (('flori', 'talk'), 10),
#  (('shoulder', 'elizabeth'), 10),
#  (('u', 'time'), 9),
#  (('u', 'hand'), 9),
#  (('po', 'time'), 9),
#  (('po', 'hand'), 9),
#  (('po', 'ko'), 9),
#  (('kyin', 'time'), 9),
#  (('kyin', 'hand'), 9),
#  (('kyin', 'ko'), 9),
#  (('kyauktada', 'back'), 9),
#  (('kyauktada', 'come'), 9),
#  (('kyauktada', 'flori'), 9),
#  (('burma', 'would'), 9),
#  (('long', 'two'), 9),
#  (('seem', 'like'), 9),
#  (('one', 'yet'), 9),
#  (('one', 'men'), 9),
#  (('one', 'though'), 9),
#  (('one', 'much'), 9),
#  (('one', 'everi'), 9),
#  (('one', 'know'), 9),
#  (('one', 'english'), 9),
#  (('one', 'european'), 9),
#  (('one', 'away'), 9),
#  (('one', 'lackersteen'), 9),
#  (('could', 'though'), 9),
#  (('could', 'never'), 9),
#  (('could', 'thought'), 9),
#  (('could', 'almost'), 9),
#  (('see', 'club'), 9),
#  (('look', 'though'), 9),
#  (('rather', 'said'), 9),
#  (('like', 'even'), 9),
#  (('like', 'men'), 9),
#  (('like', 'littl'), 9),
#  (('like', 'hand'), 9),
#  (('like', 'sound'), 9),
#  (('like', 'club'), 9),
#  (('man', 'never'), 9),
#  (('even', 'come'), 9),
#  (('even', 'verral'), 9),
#  (('face', 'girl'), 9),
#  (('face', 'black'), 9),
#  (('face', 'almost'), 9),
#  (('face', 'elizabeth'), 9),
#  (('head', 'flori'), 9),
#  (('life', 'elizabeth'), 9),
#  (('back', 'turn'), 9),
#  (('back', 'said'), 9),
#  (('back', 'two'), 9),
#  (('back', 'club'), 9),
#  (('way', 'flori'), 9),
#  (('get', 'flori'), 9),
#  (('put', 'would'), 9),
#  (('though', 'flori'), 9),
#  (('came', 'round'), 9),
#  (('came', 'two'), 9),
#  (('came', 'moment'), 9),
#  (('much', 'elizabeth'), 9),
#  (('go', 'say'), 9),
#  (('would', 'two'), 9),
#  (('would', 'moment'), 9),
#  (('would', 'verral'), 9),
#  (('saw', 'flori'), 9),
#  (('still', 'flori'), 9),
#  (('still', 'elizabeth'), 9),
#  (('never', 'elizabeth'), 9),
#  (('say', "'i"), 9),
#  (('hand', 'behind'), 9),
#  (('hand', 'flori'), 9),
#  (('said', "'you"), 9),
#  (('said', "'oh"), 9),
#  (("'i", 'know'), 9),
#  (('ask', 'come'), 9),
#  (('come', 'elizabeth'), 9),
#  (('moment', 'flori'), 9),
#  (('away', 'elizabeth'), 9),
#  (('doctor', 'club'), 9),
#  (('flori', 'first'), 9),
#  (('flori', 'almost'), 9),
#  (('westfield', 'elli'), 9),
#  (('u', 'even'), 8),
#  (('u', 'would'), 8),
#  (('po', 'one'), 8),
#  (('po', 'even'), 8),
#  (('po', 'said'), 8),
#  (('kyin', 'one'), 8),
#  (('kyin', 'even'), 8),
#  (('kyin', 'said'), 8),
#  (('kyauktada', 'three'), 8),
#  (('veranda', 'look'), 8),
#  (('veranda', 'went'), 8),
#  (('one', 'year'), 8),
#  (('one', 'time'), 8),
#  (('one', 'go'), 8),
#  (('one', 'still'), 8),
#  (('one', 'left'), 8),
#  (('one', 'arm'), 8),
#  (('one', 'round'), 8),
#  (('could', 'man'), 8),
#  (('could', 'make'), 8),
#  (('could', 'everi'), 8),
#  (('could', 'word'), 8),
#  (('could', 'well'), 8),
#  (('look', 'yellow'), 8),
#  (('look', 'upon'), 8),
#  (('look', 'would'), 8),
#  (('look', 'stood'), 8),
#  (('look', 'away'), 8),
#  (('like', 'eye'), 8),
#  (('like', 'small'), 8),
#  (('like', 'make'), 8),
#  (('like', 'thing'), 8),
#  (('like', "'ll"), 8),
#  (('man', 'two'), 8),
#  (('year', 'would'), 8),
#  (('chair', 'lackersteen'), 8),
#  (('even', 'make'), 8),
#  (('even', 'made'), 8),
#  (('even', 'right'), 8),
#  (('even', 'doctor'), 8),
#  (('even', 'lackersteen'), 8),
#  (('even', 'elli'), 8),
#  (('face', 'though'), 8),
#  (('face', 'came'), 8),
#  (('face', 'hair'), 8),
#  (('head', 'came'), 8),
#  (('think', 'way'), 8),
#  (('life', 'live'), 8),
#  (('back', 'went'), 8),
#  (('back', 'time'), 8),
#  (('back', 'away'), 8),
#  (('way', 'round'), 8),
#  (('way', 'said'), 8),
#  (('put', 'round'), 8),
#  (('went', 'elizabeth'), 8),
#  (('though', 'almost'), 8),
#  (('though', 'elizabeth'), 8),
#  (('time', 'came'), 8),
#  (('time', 'said'), 8),
#  (('took', 'elizabeth'), 8),
#  (('kind', 'thing'), 8),
#  (('much', 'flori'), 8),
#  (('day', 'go'), 8),
#  (('day', 'flori'), 8),
#  (('go', 'flori'), 8),
#  (('go', 'lackersteen'), 8),
#  (('would', 'take'), 8),
#  (('would', 'knew'), 8),
#  (('would', 'ever'), 8),
#  (('would', 'talk'), 8),
#  (('would', 'lackersteen'), 8),
#  (('made', 'lackersteen'), 8),
#  (('made', 'elizabeth'), 8),
#  (('say', 'come'), 8),
#  (('say', 'must'), 8),
#  (('good', 'said'), 8),
#  (('littl', 'two'), 8),
#  (('littl', 'away'), 8),
#  (('arm', 'elizabeth'), 8),
#  (('turn', 'elizabeth'), 8),
#  (('round', 'club'), 8),
#  (('said', 'ko'), 8),
#  (('two', 'black'), 8),
#  (('moment', 'elizabeth'), 8),
#  (('macgregor', 'lackersteen'), 8),
#  (('call', 'doctor'), 8),
#  (('call', 'flori'), 8),
#  (('behind', 'flori'), 8),
#  (('stood', 'flori'), 8),
#  (('right', "'ll"), 8),
#  (('flori', 'heard'), 8),
#  (('flori', 'road'), 8),
#  (('flori', 'home'), 8),
#  (('flori', 'house'), 8),
#  (('talk', 'elizabeth'), 8),
#  (('club', 'evening'), 8),
#  (('flo', "s'la"), 8),
#  (('home', 'elizabeth'), 8),
#  (('u', 'one'), 7),
#  (('u', 'turn'), 7),
#  (('u', 'letter'), 7),
#  (('po', 'turn'), 7),
#  (('po', 'letter'), 7),
#  (('kyin', 'turn'), 7),
#  (('kyin', 'letter'), 7),
#  (('kyauktada', 'day'), 7),
#  (('veranda', 'back'), 7),
#  (('veranda', 'doctor'), 7),
#  (('air', 'came'), 7),
#  (('long', 'back'), 7),
#  (('long', 'elizabeth'), 7),
#  (('seem', 'one'), 7),
#  (('one', 'head'), 7),
#  (('one', 'think'), 7),
#  (('one', 'get'), 7),
#  (('one', 'took'), 7),
#  (('one', 'day'), 7),
#  (('one', 'made'), 7),
#  (('one', 'use'), 7),
#  (('one', 'good'), 7),
#  (('one', 'moment'), 7),
#  (('one', 'old'), 7),
#  (('one', 'flory'), 7),
#  (('one', 'talk'), 7),
#  (('one', 'keep'), 7),
#  (('one', 'across'), 7),
#  (('could', 'without'), 7),
#  (('could', 'think'), 7),
#  (('could', 'tell'), 7),
#  (('could', 'hand'), 7),
#  (('could', 'know'), 7),
#  (('could', 'doctor'), 7),
#  (('see', 'look'), 7),
#  (('see', 'thing'), 7),
#  (('see', 'would'), 7),
#  (('look', 'time'), 7),
#  (('look', 'toward'), 7),
#  (('look', 'almost'), 7),
#  (('without', 'even'), 7),
#  (('without', 'would'), 7),
#  (('rather', 'like'), 7),
#  (('rather', 'would'), 7),
#  (('like', 'head'), 7),
#  (('like', 'back'), 7),
#  (('like', 'though'), 7),
#  (('like', 'place'), 7),
#  (('like', 'god'), 7),
#  (('like', "'d"), 7),
#  (('like', 'home'), 7),
#  (('man', 'came'), 7),
#  (('man', 'good'), 7),
#  (('even', 'eye'), 7),
#  (('even', 'came'), 7),
#  (('even', 'ask'), 7),
#  (('even', 'macgregor'), 7),
#  (('burmes', 'woman'), 7),
#  (('white', 'face'), 7),
#  (('men', 'flori'), 7),
#  (('face', 'stood'), 7),
#  (('yellow', 'almost'), 7),
#  (('quit', 'time'), 7),
#  (('quit', 'said'), 7),
#  (('feet', 'flori'), 7),
#  (('head', 'turn'), 7),
#  (('head', 'hair'), 7),
#  (('think', 'said'), 7),
#  (('think', "'d"), 7),
#  (('back', 'upon'), 7),
#  (('back', 'doctor'), 7),
#  (('watch', 'stood'), 7),
#  (('felt', 'flori'), 7),
#  (('way', 'would'), 7),
#  (('way', 'littl'), 7),
#  (('way', 'elizabeth'), 7),
#  (('get', "'ll"), 7),
#  (('three', 'week'), 7),
#  (('put', "s'la"), 7),
#  (('hundr', 'two'), 7),
#  (('time', 'two'), 7),
#  (('time', 'club'), 7),
#  (('make', 'elizabeth'), 7),
#  (('came', 'flory'), 7),
#  (('came', 'hair'), 7),
#  (('much', 'never'), 7),
#  (('day', 'elizabeth'), 7),
#  (('go', "'i"), 7),
#  (('go', "'m"), 7),
#  (('would', 'made'), 7),
#  (('would', 'still'), 7),
#  (('would', 'place'), 7),
#  (('would', 'anyth'), 7),
#  (('would', 'enough'), 7),
#  (('would', 'everi'), 7),
#  (('would', 'european'), 7),
#  (('alway', 'flori'), 7),
#  (('take', 'away'), 7),
#  (('made', 'flori'), 7),
#  (('except', 'two'), 7),
#  (('brought', 'flori'), 7),
#  (('left', 'lackersteen'), 7),
#  (('say', 'someth'), 7),
#  (('say', 'shall'), 7),
#  (('say', 'club'), 7),
#  (('done', 'said'), 7),
#  (('everi', 'word'), 7),
#  (('everi', 'evening'), 7),
#  (('woman', 'said'), 7),
#  (('thought', 'flori'), 7),
#  (('hand', 'arm'), 7),
#  (('hand', 'away'), 7),
#  (('arm', 'flori'), 7),
#  (('arm', 'toward'), 7),
#  (('turn', 'moment'), 7),
#  (('round', 'almost'), 7),
#  (('round', 'elizabeth'), 7),
#  (('ba', 'said'), 7),
#  (('ba', "s'la"), 7),
#  (('said', 'two'), 7),
#  (('said', 'english'), 7),
#  (('said', 'away'), 7),
#  (('said', 'right'), 7),
#  (('said', 'club'), 7),
#  (('said', "'m"), 7),
#  (('said', "s'la"), 7),
#  (('two', 'old'), 7),
#  (('two', 'away'), 7),
#  (('ko', 'behind'), 7),
#  (('ko', 'flo'), 7),
#  (('know', 'iss'), 7),
#  (("'what", 'mean'), 7),
#  (('want', 'club'), 7),
#  (('come', 'flory'), 7),
#  (('come', 'flori'), 7),
#  (('dear', 'old'), 7),
#  (('black', 'hair'), 7),
#  (('behind', "s'la"), 7),
#  (('behind', 'elizabeth'), 7),
#  (("'the", 'flori'), 7),
#  (('walk', 'club'), 7),
#  (('veraswami', 'club'), 7),
#  (('letter', 'flori'), 7),
#  (('flori', 'stand'), 7),
#  (('flori', 'keep'), 7),
#  (('flori', 'jungle'), 7),
#  (('flori', 'water'), 7),
#  (('notic', 'elizabeth'), 7),
#  (('club', 'elli'), 7),
#  (('evening', 'elizabeth'), 7),
#  (('elizabeth', 'verrall'), 7),
#  (('u', 'back'), 6),
#  (('u', 'ba'), 6),
#  (('u', 'said'), 6),
#  (('po', 'back'), 6),
#  (('po', 'ba'), 6),
#  (('kyin', 'back'), 6),
#  (('kyin', 'ba'), 6),
#  (('kyauktada', 'month'), 6),
#  (('kyauktada', 'go'), 6),
#  (('kyauktada', 'european'), 6),
#  (('kyauktada', 'club'), 6),
#  (('sit', 'would'), 6),
#  (('sit', 'elizabeth'), 6),
#  (('veranda', 'came'), 6),
#  (('long', 'chair'), 6),
#  (('long', 'would'), 6),
#  (('long', 'flori'), 6),
#  (('long', 'talk'), 6),
#  (('long', 'club'), 6),
#  (('seem', 'flori'), 6),
#  (('one', 'tree'), 6),
#  (('one', 'side'), 6),
#  (('one', 'went'), 6),
#  (('one', 'ever'), 6),
#  (('one', 'thought'), 6),
#  (('one', 'mind'), 6),
#  (('one', 'girl'), 6),
#  (('one', 'macgregor'), 6),
#  (('one', 'hear'), 6),
#  (('one', "'the"), 6),
#  (('one', 'nativ'), 6),
#  (('one', 'letter'), 6),
#  (('one', 'verral'), 6),
#  (('could', 'yet'), 6),
#  (('could', 'eye'), 6),
#  (('could', 'way'), 6),
#  (('could', 'came'), 6),
#  (('could', 'took'), 6),
#  (('could', 'made'), 6),
#  (('could', 'say'), 6),
#  (('could', 'done'), 6),
#  (('could', 'come'), 6),
#  (('could', 'someth'), 6),
#  (('could', 'right'), 6),
#  (('could', 'talk'), 6),
#  (('could', 'club'), 6),
#  (('could', 'keep'), 6),
#  (('could', 'speak'), 6),
#  (('see', 'even'), 6),
#  (('see', 'go'), 6),
#  (('see', 'said'), 6),
#  (('see', "'ll"), 6),
#  (('see', 'evening'), 6),
#  (('tree', 'great'), 6),
#  (('tree', 'elizabeth'), 6),
#  (('look', 'white'), 6),
#  (('look', 'head'), 6),
#  (('look', 'two'), 6),
#  (('look', 'come'), 6),
#  (('without', 'go'), 6),
#  (('like', 'year'), 6),
#  (('like', 'burmes'), 6),
#  (('like', 'quit'), 6),
#  (('like', 'feet'), 6),
#  (('like', 'peopl'), 6),
#  (('like', 'upon'), 6),
#  (('like', 'knew'), 6),
#  (('like', 'everi'), 6),
#  (('like', 'thought'), 6),
#  (('like', 'said'), 6),
#  (('like', 'stood'), 6),
#  (('like', 'hair'), 6),
#  (('man', 'back'), 6),
#  (('man', 'way'), 6),
#  (('man', 'kind'), 6),
#  (('man', 'littl'), 6),
#  (('man', 'everi'), 6),
#  (('man', 'black'), 6),
#  (('man', 'doctor'), 6),
#  (('man', 'flori'), 6),
#  (('year', 'even'), 6),
#  (('year', 'three'), 6),
#  (('year', 'left'), 6),
#  (('year', 'everi'), 6),
#  (('chair', 'back'), 6),
#  (('yet', 'talk'), 6),
#  (('even', 'white'), 6),
#  (('even', 'quit'), 6),
#  (('even', 'way'), 6),
#  (('even', 'went'), 6),
#  (('even', 'still'), 6),
#  (('even', 'knew'), 6),
#  (('even', 'say'), 6),
#  (('even', 'good'), 6),
#  (('even', 'thought'), 6),
#  (('even', 'know'), 6),
#  (('even', 'notic'), 6),
#  (('even', 'almost'), 6),
#  (('even', 'verrall'), 6),
#  (('burmes', 'girl'), 6),
#  (('white', 'round'), 6),
#  (('men', 'quit'), 6),
#  (('men', 'way'), 6),
#  (('men', 'young'), 6),
#  (('men', 'club'), 6),
#  (('men', 'elizabeth'), 6),
#  (('face', 'head'), 6),
#  (('face', 'back'), 6),
#  (('face', 'went'), 6),
#  (('face', 'never'), 6),
#  (('face', 'littl'), 6),
#  (('face', 'moment'), 6),
#  (('face', 'macgregor'), 6),
#  (('face', 'old'), 6),
#  (('face', 'away'), 6),
#  (('head', 'would'), 6),
#  (('head', 'elizabeth'), 6),
#  (('think', 'back'), 6),
#  (('think', 'say'), 6),
#  (('life', 'would'), 6),
#  (('life', 'never'), 6),
#  (('back', 'thought'), 6),
#  (('back', 'moment'), 6),
#  (('back', 'macgregor'), 6),
#  (('back', 'may'), 6),
#  (('back', 'walk'), 6),
#  (('back', 'got'), 6),
#  (('back', 'must'), 6),
#  (('back', 'flory'), 6),
#  (('back', 'sat'), 6),
#  (('back', 'road'), 6),
#  (('back', 'gone'), 6),
#  (('watch', 'flori'), 6),
#  (('watch', 'elizabeth'), 6),
#  (('way', 'put'), 6),
#  (('way', 'know'), 6),
#  (('way', 'come'), 6),
#  (('way', 'macgregor'), 6),
#  (('way', 'old'), 6),
#  (('get', 'time'), 6),
#  (('get', 'never'), 6),
#  (('get', 'said'), 6),
#  (('get', 'well'), 6),
#  (('get', 'home'), 6),
#  (('put', 'arm'), 6),
#  (('put', 'ko'), 6),
#  (('put', 'flori'), 6),
#  (('four', 'flori'), 6),
#  (('though', 'would'), 6),
#  (('though', 'never'), 6),
#  (('though', 'away'), 6),
#  (('time', 'short'), 6),
#  (('time', 'good'), 6),
#  (('time', 'flory'), 6),
#  (('time', 'talk'), 6),
#  (('time', 'lackersteen'), 6),
#  (('make', 'two'), 6),
#  (('make', 'lackersteen'), 6),
#  (('came', 'old'), 6),
#  (('came', 'behind'), 6),
#  (('came', 'sat'), 6),
#  (('came', 'road'), 6),
#  (('came', 'flo'), 6),
#  (('thing', 'would'), 6),
#  (('thing', 'said'), 6),
#  (('much', 'said'), 6),
#  (('much', 'two'), 6),
#  (('much', 'doctor'), 6),
#  (('day', 'first'), 6),
#  (('day', 'night'), 6),
#  (('short', 'hair'), 6),
#  (('go', 'know'), 6),
#  (('go', 'us'), 6),
#  (('go', 'veraswami'), 6),
#  (('go', 'got'), 6),
#  (('go', "'ll"), 6),
#  (('go', 'elizabeth'), 6),
#  (('would', 'week'), 6),
#  (('would', 'good'), 6),
#  (('would', 'woman'), 6),
#  (('would', 'turn'), 6),
#  (('would', 'away'), 6),
#  (('would', 'better'), 6),
#  (('would', 'home'), 6),
#  (('would', 'love'), 6),
#  (('made', 'macgregor'), 6),
#  (('made', 'flory'), 6),
#  (('made', 'club'), 6),
#  (('never', 'thought'), 6),
#  (('never', 'talk'), 6),
#  (('never', 'almost'), 6),
#  (('give', "'ll"), 6),
#  (('left', 'right'), 6),
#  (('left', 'flori'), 6),
#  (('say', 'flori'), 6),
#  (('say', 'mean'), 6),
#  (('say', 'elli'), 6),
#  (('found', 'flori'), 6),
#  (('good', 'flori'), 6),
#  (('good', 'evening'), 6),
#  (('enough', 'well'), 6),
#  (('enough', 'flori'), 6),
#  (('tell', 'said'), 6),
#  (('littl', 'turn'), 6),
#  (('littl', 'round'), 6),
#  (('littl', 'said'), 6),
#  (('littl', 'doctor'), 6),
#  (('littl', 'talk'), 6),
#  (('littl', 'elli'), 6),
#  (('everi', 'doctor'), 6),
#  (('woman', 'old'), 6),
#  (('thought', 'flory'), 6),
#  (('hand', 'lackersteen'), 6),
#  (('hand', 'elizabeth'), 6),
#  (('arm', 'flory'), 6),
#  (('round', 'black'), 6),
#  (('round', 'flory'), 6),
#  (('round', 'shoulder'), 6),
#  (('servant', 'ko'), 6),
#  (('servant', "s'la"), 6),
#  (('god', 'oh'), 6),
#  (('said', 'well'), 6),
#  (('said', 'friend'), 6),
#  (('said', 'butler'), 6),
#  (('said', 'verrall'), 6),
#  (("'i", 'want'), 6),
#  (("'i", 'shall'), 6),
#  (("'i", 'must'), 6),
#  (('two', 'stood'), 6),
#  (('two', 'letter'), 6),
#  (('two', 'club'), 6),
#  (('know', 'us'), 6),
#  (('know', 'mean'), 6),
#  (('girl', 'elizabeth'), 6),
#  (('ask', 'elizabeth'), 6),
#  (('come', 'may'), 6),
#  (('come', 'let'), 6),
#  (('come', 'us'), 6),
#  (('come', 'drink'), 6),
#  (('moment', 'almost'), 6),
#  (('macgregor', 'old'), 6),
#  (('macgregor', 'elli'), 6),
#  (('macgregor', 'elizabeth'), 6),
#  (('dear', 'friend'), 6),
#  (('last', 'lackersteen'), 6),
#  (('european', 'doctor'), 6),
#  (('european', 'friend'), 6),
#  (('may', 'flory'), 6),
#  (('old', 'westfield'), 6),
#  (('old', 'elizabeth'), 6),
#  (('hla', 'flory'), 6),
#  (('sound', 'lackersteen'), 6),
#  (('away', 'keep'), 6),
#  (('walk', 'road'), 6),
#  (('veraswami', 'flori'), 6),
#  (('got', 'flori'), 6),
#  (('doctor', 'friend'), 6),
#  (('friend', 'flori'), 6),
#  (('flory', 'almost'), 6),
#  (('flory', 'shoulder'), 6),
#  (('flory', 'iss'), 6),
#  (('flori', 'notic'), 6),
#  (('flori', 'lackersteen'), 6),
#  (('flori', 'ellis'), 6),
#  (('sat', 'elizabeth'), 6),
#  (('room', 'elizabeth'), 6),
#  (('heard', 'elizabeth'), 6),
#  (('lackersteen', 'butler'), 6),
#  (('yard', 'elizabeth'), 6),
#  (('u', 'came'), 5),
#  (('u', 'kin'), 5),
#  (('po', 'came'), 5),
#  (('po', 'much'), 5),
#  (('po', 'ever'), 5),
#  (('po', 'good'), 5),
#  (('po', 'european'), 5),
#  (('po', 'kin'), 5),
#  (('kyin', 'came'), 5),
#  (('kyin', 'much'), 5),
#  (('kyin', 'ever'), 5),
#  (('kyin', 'good'), 5),
#  (('kyin', 'european'), 5),
#  (('kyin', 'kin'), 5),
#  (('kyauktada', 'burma'), 5),
#  (('kyauktada', 'would'), 5),
#  (('sit', 'one'), 5),
#  (('sit', 'chair'), 5),
#  (('sit', 'white'), 5),
#  (('sit', 'back'), 5),
#  (('sit', 'said'), 5),
#  (('sit', 'two'), 5),
#  (('veranda', 'face'), 5),
#  (('half', 'lackersteen'), 5),
#  (('month', 'go'), 5),
#  (('air', 'flori'), 5),
#  (('long', 'way'), 5),
#  (('long', 'never'), 5),
#  (('long', 'flory'), 5),
#  (('seem', 'even'), 5),
#  (('seem', 'make'), 5),
#  (('seem', 'never'), 5),
#  (('one', 'great'), 5),
#  (('one', 'chair'), 5),
#  (('one', 'three'), 5),
#  (('one', 'four'), 5),
#  (('one', 'kind'), 5),
#  (('one', 'however'), 5),
#  (('one', 'among'), 5),
#  (('one', 'live'), 5),
#  (('one', 'turn'), 5),
#  (('one', 'said'), 5),
#  (('one', 'ask'), 5),
#  (('one', 'black'), 5),
#  (('one', 'someth'), 5),
#  (('one', 'indian'), 5),
#  (('one', 'whole'), 5),
#  (('one', 'first'), 5),
#  (('one', 'night'), 5),
#  (('one', 'butler'), 5),
#  (('could', 'tree'), 5),
#  (('could', 'great'), 5),
#  (('could', 'back'), 5),
#  (('could', 'put'), 5),
#  (('could', 'much'), 5),
#  (('could', 'alway'), 5),
#  (('could', 'take'), 5),
#  (('could', 'knew'), 5),
#  (('could', 'two'), 5),
#  (('could', 'away'), 5),
#  (('could', 'walk'), 5),
#  (('could', 'flory'), 5),
#  (('could', 'stand'), 5),
#  (('could', 'night'), 5),
#  (('could', 'love'), 5),
#  (('could', 'verral'), 5),
#  (('see', 'rather'), 5),
#  (('see', 'time'), 5),
#  (('see', 'shall'), 5),
#  (('see', 'us'), 5),
#  (('see', 'feel'), 5),
#  (('tree', 'came'), 5),
#  (('look', 'even'), 5),
#  (('look', 'way'), 5),
#  (('look', 'saw'), 5),
#  (('look', 'turn'), 5),
#  (('look', 'girl'), 5),
#  (('look', 'want'), 5),
#  (('look', 'old'), 5),
#  (('look', 'stand'), 5),
#  (('look', 'club'), 5),
#  (('look', 'lackersteen'), 5),
#  (('without', 'like'), 5),
#  (('without', 'word'), 5),
#  (('without', 'flori'), 5),
#  (('rather', 'think'), 5),
#  (('rather', 'littl'), 5),
#  (('like', 'chair'), 5),
#  (('like', 'think'), 5),
#  (('like', 'put'), 5),
#  (('like', 'came'), 5),
#  (('like', 'still'), 5),
#  (('like', 'never'), 5),
#  (('like', 'say'), 5),
#  (('like', 'live'), 5),
#  (('like', 'good'), 5),
#  (('like', 'woman'), 5),
#  (('like', 'end'), 5),
#  (('like', 'arm'), 5),
#  (('like', 'word'), 5),
#  (('like', 'know'), 5),
#  (('like', 'girl'), 5),
#  (('like', 'moment'), 5),
#  (('like', 'burman'), 5),
#  (('like', 'someth'), 5),
#  (('like', 'away'), 5),
#  (('like', 'right'), 5),
#  (('like', 'us'), 5),
#  (('like', 'doctor'), 5),
#  (('like', 'feel'), 5),
#  (('like', 'across'), 5),
#  (('great', 'thing'), 5),
#  (('great', 'lackersteen'), 5),
#  (('man', 'year'), 5),
#  (('man', 'think'), 5),
#  (('man', 'time'), 5),
#  (('man', 'take'), 5),
#  (('man', 'woman'), 5),
#  (('man', 'young'), 5),
#  (('man', 'stand'), 5),
#  (('man', 'hair'), 5),
#  (('man', 'almost'), 5),
#  (('man', 'house'), 5),
#  (('man', 'elizabeth'), 5),
#  (('year', 'hundr'), 5),
#  (('year', 'never'), 5),
#  (('year', 'live'), 5),
#  (('year', 'last'), 5),
#  (('year', 'old'), 5),
#  (('year', 'flori'), 5),
#  (('year', 'talk'), 5),
#  (('chair', 'came'), 5),
#  (('chair', 'would'), 5),
#  (('chair', 'said'), 5),
#  (('chair', 'behind'), 5),
#  (('chair', 'doctor'), 5),
#  (('chair', 'flori'), 5),
#  (('yet', 'would'), 5),
#  (('yet', 'never'), 5),
#  (('yet', 'flori'), 5),
#  (('yet', 'verral'), 5),
#  (('even', 'burmes'), 5),
#  (('even', 'though'), 5),
#  (('even', 'took'), 5),
#  (('even', 'kind'), 5),
#  (('even', 'go'), 5),
#  (('even', 'give'), 5),
#  (('even', 'live'), 5),
#  (('even', 'littl'), 5),
#  (('even', 'woman'), 5),
#  (('even', 'two'), 5),
#  (('even', 'moment'), 5),
#  (('even', 'talk'), 5),
#  (('burmes', 'women'), 5),
#  (('white', 'everi'), 5),
#  (('white', 'woman'), 5),
#  (('white', 'talk'), 5),
#  (('white', 'elizabeth'), 5),
#  (('men', 'three'), 5),
#  (('men', 'came'), 5),
#  (('men', 'arm'), 5),
#  (('men', 'girl'), 5),
#  (('men', 'whole'), 5),
#  (('face', 'upon'), 5),
#  (('face', 'put'), 5),
#  (('face', 'arm'), 5),
#  (('face', 'flory'), 5),
#  (('face', 'toward'), 5),
#  (('yellow', 'hair'), 5),
#  (('quit', 'way'), 5),
#  (('quit', 'came'), 5),
#  (('quit', 'girl'), 5),
#  (('quit', 'doctor'), 5),
#  (('quit', 'elli'), 5),
#  (('eye', 'flori'), 5),
#  (('feet', 'head'), 5),
#  (('head', 'though'), 5),
#  (('head', 'moment'), 5),
#  (('head', 'behind'), 5),
#  (('head', 'away'), 5),
#  (('think', 'get'), 5),
#  (('think', 'day'), 5),
#  (('think', 'go'), 5),
#  (('think', 'would'), 5),
#  (('think', 'girl'), 5),
#  (('think', 'someth'), 5),
#  (('think', 'club'), 5),
#  ...]

# %%
#namely

new = {tuple(sorted(x)):y for x, y in count_s.items()}

#順位チェック again !
new2 = dict(sorted(new.items(), key=lambda x: x[1], reverse=True))

new3 = dict((k, v) for k, v in new2.items() if v >= 2)

#順位チェック again !
new4 = dict(sorted(new3.items(), key=lambda x: x[1], reverse=True))
new4
# Out:
# {('kyin', 'po'): 142,
#  ('po', 'u'): 125,
#  ('kyin', 'u'): 124,
#  ('ko', "s'la"): 94,
#  ('hla', 'may'): 57,
#  ('elizabeth', 'flori'): 53,
#  ('flori', 'said'): 47,
#  ("'i", 'said'): 33,
#  ('face', 'look'): 32,
#  ('could', 'see'): 31,
#  ('man', 'white'): 29,
#  ('elizabeth', 'verral'): 28,
#  ('like', 'one'): 27,
#  ('like', 'look'): 26,
#  ('could', 'one'): 25,
#  ('even', 'would'): 25,
#  ('said', 'westfield'): 23,
#  ('club', 'flori'): 23,
#  ('back', 'flori'): 22,
#  ('lackersteen', 'said'): 22,
#  ('flori', 'one'): 21,
#  ('could', 'face'): 21,
#  ('back', 'go'): 21,
#  ('away', 'turn'): 21,
#  ('elli', 'said'): 21,
#  ("'i", "'m"): 21,
#  ('away', 'yard'): 21,
#  ('could', 'even'): 20,
#  ('could', 'flori'): 19,
#  ('could', 'elizabeth'): 19,
#  ('like', 'white'): 19,
#  ('face', 'like'): 19,
#  ('face', 'yellow'): 19,
#  ('club', 'european'): 19,
#  ('elizabeth', 'lackersteen'): 19,
#  ('elizabeth', 'even'): 18,
#  ('round', 'turn'): 18,
#  ('elizabeth', 'said'): 18,
#  ('elizabeth', 'two'): 18,
#  ('flori', 'ko'): 18,
#  ('away', 'flori'): 18,
#  ('flori', "s'la"): 18,
#  ('one', 'see'): 17,
#  ('one', 'thing'): 17,
#  ('one', 'two'): 17,
#  ('like', 'tree'): 17,
#  ('almost', 'like'): 17,
#  ('flori', 'went'): 17,
#  ('came', 'flori'): 17,
#  ('never', 'would'): 17,
#  ('one', 'would'): 16,
#  ('could', 'like'): 16,
#  ('flori', 'look'): 16,
#  ('like', 'would'): 16,
#  ('flori', 'like'): 16,
#  ('club', 'even'): 16,
#  ('back', 'come'): 16,
#  ('came', 'elizabeth'): 16,
#  ('flori', 'would'): 16,
#  ('hand', 'one'): 15,
#  ('black', 'like'): 15,
#  ('men', 'white'): 15,
#  ('face', 'turn'): 15,
#  ('back', 'came'): 15,
#  ('flori', 'time'): 15,
#  ('girl', 'said'): 15,
#  ('macgregor', 'said'): 15,
#  ('ask', 'flori'): 15,
#  ('flori', 'veranda'): 14,
#  ('long', 'time'): 14,
#  ('elizabeth', 'look'): 14,
#  ('flori', 'took'): 14,
#  ('doctor', 'would'): 14,
#  ('flori', 'turn'): 14,
#  ('ba', 'ko'): 14,
#  ('flory', 'said'): 14,
#  ('two', 'women'): 14,
#  ('look', 'one'): 13,
#  ('never', 'one'): 13,
#  ('littl', 'one'): 13,
#  ('could', 'hear'): 13,
#  ('face', 'see'): 13,
#  ('like', 'round'): 13,
#  ('two', 'year'): 13,
#  ('even', 'flori'): 13,
#  ('back', 'day'): 13,
#  ('back', 'elizabeth'): 13,
#  ('go', 'let'): 13,
#  ('go', 'must'): 13,
#  ('say', 'would'): 13,
#  ('said', 'would'): 13,
#  ('ask', 'would'): 13,
#  ('come', 'would'): 13,
#  ('flori', 'littl'): 13,
#  ('old', 'said'): 13,
#  ("'the", 'said'): 13,
#  ('doctor', 'said'): 13,
#  ('last', 'night'): 13,
#  ('doctor', 'flori'): 13,
#  ('even', 'one'): 12,
#  ('make', 'one'): 12,
#  ('except', 'one'): 12,
#  ('elizabeth', 'one'): 12,
#  ('could', 'look'): 12,
#  ('could', 'go'): 12,
#  ('could', 'feel'): 12,
#  ('like', 'see'): 12,
#  ('elizabeth', 'see'): 12,
#  ('like', 'man'): 12,
#  ('like', 'yellow'): 12,
#  ('like', 'two'): 12,
#  ('lackersteen', 'like'): 12,
#  ('time', 'year'): 12,
#  ('even', 'face'): 12,
#  ('even', 'everi'): 12,
#  ('back', 'lackersteen'): 12,
#  ('hand', 'put'): 12,
#  ('go', 'said'): 12,
#  ('away', 'go'): 12,
#  ('club', 'go'): 12,
#  ('club', 'would'): 12,
#  ('elizabeth', 'would'): 12,
#  ('flori', 'never'): 12,
#  ('elizabeth', 'flory'): 12,
#  ('across', 'flori'): 12,
#  ('club', 'lackersteen'): 12,
#  ('almost', 'elizabeth'): 12,
#  ('like', 'long'): 11,
#  ('man', 'one'): 11,
#  ('one', 'white'): 11,
#  ('face', 'one'): 11,
#  ('life', 'one'): 11,
#  ('one', 'way'): 11,
#  ('one', 'say'): 11,
#  ('could', 'get'): 11,
#  ('could', 'would'): 11,
#  ('back', 'look'): 11,
#  ('look', 'round'): 11,
#  ('like', 'old'): 11,
#  ('like', 'talk'): 11,
#  ('even', 'man'): 11,
#  ('man', 'said'): 11,
#  ('man', 'old'): 11,
#  ('even', 'yet'): 11,
#  ('face', 'round'): 11,
#  ('face', 'flori'): 11,
#  ("'i", 'think'): 11,
#  ('know', 'think'): 11,
#  ('back', 'would'): 11,
#  ('back', 'take'): 11,
#  ('came', 'ko'): 11,
#  ('came', "s'la"): 11,
#  ('go', 'would'): 11,
#  ('go', 'home'): 11,
#  ('arm', 'round'): 11,
#  ('flori', 'two'): 11,
#  ('club', 'macgregor'): 11,
#  ('flori', 'walk'): 11,
#  ('flori', 'sat'): 11,
#  ('club', 'elizabeth'): 11,
#  ('doctor', 'u'): 10,
#  ('po', 'would'): 10,
#  ('doctor', 'po'): 10,
#  ('kyin', 'would'): 10,
#  ('doctor', 'kyin'): 10,
#  ('long', 'one'): 10,
#  ('eye', 'one'): 10,
#  ('back', 'one'): 10,
#  ('came', 'one'): 10,
#  ('anoth', 'one'): 10,
#  ('come', 'one'): 10,
#  ('must', 'one'): 10,
#  ('club', 'one'): 10,
#  ('almost', 'one'): 10,
#  ('could', 'said'): 10,
#  ('could', 'moment'): 10,
#  ('flori', 'see'): 10,
#  ('great', 'like'): 10,
#  ('like', 'yet'): 10,
#  ('like', 'way'): 10,
#  ('go', 'like'): 10,
#  ('come', 'like'): 10,
#  ('elizabeth', 'like'): 10,
#  ('face', 'man'): 10,
#  ('man', 'would'): 10,
#  ('elizabeth', 'yet'): 10,
#  ('even', 'time'): 10,
#  ('even', 'never'): 10,
#  ('black', 'white'): 10,
#  ('men', 'two'): 10,
#  ('back', 'way'): 10,
#  ('made', 'way'): 10,
#  ('day', 'time'): 10,
#  ('time', 'would'): 10,
#  ('come', 'time'): 10,
#  ('first', 'time'): 10,
#  ('make', 'would'): 10,
#  ('came', 'would'): 10,
#  ('came', 'club'): 10,
#  ('day', 'everi'): 10,
#  ('elizabeth', 'saw'): 10,
#  ('said', 'take'): 10,
#  ('said', 'say'): 10,
#  ('hand', 'stood'): 10,
#  ('come', 'said'): 10,
#  ('ellis', 'said'): 10,
#  ('flory', 'ko'): 10,
#  ('flori', 'girl'): 10,
#  ('club', 'come'): 10,
#  ('doctor', 'flory'): 10,
#  ('club', 'nativ'): 10,
#  ('friend', 'iss'): 10,
#  ('flory', "s'la"): 10,
#  ('flori', 'talk'): 10,
#  ('elizabeth', 'shoulder'): 10,
#  ('time', 'u'): 9,
#  ('hand', 'u'): 9,
#  ('po', 'time'): 9,
#  ('hand', 'po'): 9,
#  ('ko', 'po'): 9,
#  ('kyin', 'time'): 9,
#  ('hand', 'kyin'): 9,
#  ('ko', 'kyin'): 9,
#  ('back', 'kyauktada'): 9,
#  ('come', 'kyauktada'): 9,
#  ('flori', 'kyauktada'): 9,
#  ('burma', 'would'): 9,
#  ('long', 'two'): 9,
#  ('like', 'seem'): 9,
#  ('one', 'yet'): 9,
#  ('men', 'one'): 9,
#  ('one', 'though'): 9,
#  ('much', 'one'): 9,
#  ('everi', 'one'): 9,
#  ('know', 'one'): 9,
#  ('english', 'one'): 9,
#  ('european', 'one'): 9,
#  ('away', 'one'): 9,
#  ('lackersteen', 'one'): 9,
#  ('could', 'though'): 9,
#  ('could', 'never'): 9,
#  ('could', 'thought'): 9,
#  ('almost', 'could'): 9,
#  ('club', 'see'): 9,
#  ('look', 'though'): 9,
#  ('rather', 'said'): 9,
#  ('even', 'like'): 9,
#  ('like', 'men'): 9,
#  ('like', 'littl'): 9,
#  ('hand', 'like'): 9,
#  ('like', 'sound'): 9,
#  ('club', 'like'): 9,
#  ('man', 'never'): 9,
#  ('come', 'even'): 9,
#  ('even', 'verral'): 9,
#  ('face', 'girl'): 9,
#  ('black', 'face'): 9,
#  ('almost', 'face'): 9,
#  ('elizabeth', 'face'): 9,
#  ('flori', 'head'): 9,
#  ('elizabeth', 'life'): 9,
#  ('back', 'turn'): 9,
#  ('back', 'said'): 9,
#  ('back', 'two'): 9,
#  ('back', 'club'): 9,
#  ('flori', 'way'): 9,
#  ('flori', 'get'): 9,
#  ('put', 'would'): 9,
#  ('flori', 'though'): 9,
#  ('came', 'round'): 9,
#  ('came', 'two'): 9,
#  ('came', 'moment'): 9,
#  ('elizabeth', 'much'): 9,
#  ('go', 'say'): 9,
#  ('two', 'would'): 9,
#  ('moment', 'would'): 9,
#  ('verral', 'would'): 9,
#  ('flori', 'saw'): 9,
#  ('flori', 'still'): 9,
#  ('elizabeth', 'still'): 9,
#  ('elizabeth', 'never'): 9,
#  ("'i", 'say'): 9,
#  ('behind', 'hand'): 9,
#  ('flori', 'hand'): 9,
#  ("'you", 'said'): 9,
#  ("'oh", 'said'): 9,
#  ("'i", 'know'): 9,
#  ('ask', 'come'): 9,
#  ('come', 'elizabeth'): 9,
#  ('flori', 'moment'): 9,
#  ('away', 'elizabeth'): 9,
#  ('club', 'doctor'): 9,
#  ('first', 'flori'): 9,
#  ('almost', 'flori'): 9,
#  ('elli', 'westfield'): 9,
#  ('even', 'u'): 8,
#  ('u', 'would'): 8,
#  ('one', 'po'): 8,
#  ('even', 'po'): 8,
#  ('po', 'said'): 8,
#  ('kyin', 'one'): 8,
#  ('even', 'kyin'): 8,
#  ('kyin', 'said'): 8,
#  ('kyauktada', 'three'): 8,
#  ('look', 'veranda'): 8,
#  ('veranda', 'went'): 8,
#  ('one', 'year'): 8,
#  ('one', 'time'): 8,
#  ('go', 'one'): 8,
#  ('one', 'still'): 8,
#  ('left', 'one'): 8,
#  ('arm', 'one'): 8,
#  ('one', 'round'): 8,
#  ('could', 'man'): 8,
#  ('could', 'make'): 8,
#  ('could', 'everi'): 8,
#  ('could', 'word'): 8,
#  ('could', 'well'): 8,
#  ('look', 'yellow'): 8,
#  ('look', 'upon'): 8,
#  ('look', 'would'): 8,
#  ('look', 'stood'): 8,
#  ('away', 'look'): 8,
#  ('eye', 'like'): 8,
#  ('like', 'small'): 8,
#  ('like', 'make'): 8,
#  ('like', 'thing'): 8,
#  ("'ll", 'like'): 8,
#  ('man', 'two'): 8,
#  ('would', 'year'): 8,
#  ('chair', 'lackersteen'): 8,
#  ('even', 'make'): 8,
#  ('even', 'made'): 8,
#  ('even', 'right'): 8,
#  ('doctor', 'even'): 8,
#  ('even', 'lackersteen'): 8,
#  ('elli', 'even'): 8,
#  ('face', 'though'): 8,
#  ('came', 'face'): 8,
#  ('face', 'hair'): 8,
#  ('came', 'head'): 8,
#  ('think', 'way'): 8,
#  ('life', 'live'): 8,
#  ('back', 'went'): 8,
#  ('back', 'time'): 8,
#  ('away', 'back'): 8,
#  ('round', 'way'): 8,
#  ('said', 'way'): 8,
#  ('put', 'round'): 8,
#  ('elizabeth', 'went'): 8,
#  ('almost', 'though'): 8,
#  ('elizabeth', 'though'): 8,
#  ('came', 'time'): 8,
#  ('said', 'time'): 8,
#  ('elizabeth', 'took'): 8,
#  ('kind', 'thing'): 8,
#  ('flori', 'much'): 8,
#  ('day', 'go'): 8,
#  ('day', 'flori'): 8,
#  ('flori', 'go'): 8,
#  ('go', 'lackersteen'): 8,
#  ('take', 'would'): 8,
#  ('knew', 'would'): 8,
#  ('ever', 'would'): 8,
#  ('talk', 'would'): 8,
#  ('lackersteen', 'would'): 8,
#  ('lackersteen', 'made'): 8,
#  ('elizabeth', 'made'): 8,
#  ('come', 'say'): 8,
#  ('must', 'say'): 8,
#  ('good', 'said'): 8,
#  ('littl', 'two'): 8,
#  ('away', 'littl'): 8,
#  ('arm', 'elizabeth'): 8,
#  ('elizabeth', 'turn'): 8,
#  ('club', 'round'): 8,
#  ('ko', 'said'): 8,
#  ('black', 'two'): 8,
#  ('elizabeth', 'moment'): 8,
#  ('lackersteen', 'macgregor'): 8,
#  ('call', 'doctor'): 8,
#  ('call', 'flori'): 8,
#  ('behind', 'flori'): 8,
#  ('flori', 'stood'): 8,
#  ("'ll", 'right'): 8,
#  ('flori', 'heard'): 8,
#  ('flori', 'road'): 8,
#  ('flori', 'home'): 8,
#  ('flori', 'house'): 8,
#  ('elizabeth', 'talk'): 8,
#  ('club', 'evening'): 8,
#  ('flo', "s'la"): 8,
#  ('elizabeth', 'home'): 8,
#  ('one', 'u'): 7,
#  ('turn', 'u'): 7,
#  ('letter', 'u'): 7,
#  ('po', 'turn'): 7,
#  ('letter', 'po'): 7,
#  ('kyin', 'turn'): 7,
#  ('kyin', 'letter'): 7,
#  ('day', 'kyauktada'): 7,
#  ('back', 'veranda'): 7,
#  ('doctor', 'veranda'): 7,
#  ('air', 'came'): 7,
#  ('back', 'long'): 7,
#  ('elizabeth', 'long'): 7,
#  ('one', 'seem'): 7,
#  ('head', 'one'): 7,
#  ('one', 'think'): 7,
#  ('get', 'one'): 7,
#  ('one', 'took'): 7,
#  ('day', 'one'): 7,
#  ('made', 'one'): 7,
#  ('one', 'use'): 7,
#  ('good', 'one'): 7,
#  ('moment', 'one'): 7,
#  ('old', 'one'): 7,
#  ('flory', 'one'): 7,
#  ('one', 'talk'): 7,
#  ('keep', 'one'): 7,
#  ('across', 'one'): 7,
#  ('could', 'without'): 7,
#  ('could', 'think'): 7,
#  ('could', 'tell'): 7,
#  ('could', 'hand'): 7,
#  ('could', 'know'): 7,
#  ('could', 'doctor'): 7,
#  ('look', 'see'): 7,
#  ('see', 'thing'): 7,
#  ('see', 'would'): 7,
#  ('look', 'time'): 7,
#  ('look', 'toward'): 7,
#  ('almost', 'look'): 7,
#  ('even', 'without'): 7,
#  ('without', 'would'): 7,
#  ('like', 'rather'): 7,
#  ('rather', 'would'): 7,
#  ('head', 'like'): 7,
#  ('back', 'like'): 7,
#  ('like', 'though'): 7,
#  ('like', 'place'): 7,
#  ('god', 'like'): 7,
#  ("'d", 'like'): 7,
#  ('home', 'like'): 7,
#  ('came', 'man'): 7,
#  ('good', 'man'): 7,
#  ('even', 'eye'): 7,
#  ('came', 'even'): 7,
#  ('ask', 'even'): 7,
#  ('even', 'macgregor'): 7,
#  ('burmes', 'woman'): 7,
#  ('face', 'white'): 7,
#  ('flori', 'men'): 7,
#  ('face', 'stood'): 7,
#  ('almost', 'yellow'): 7,
#  ('quit', 'time'): 7,
#  ('quit', 'said'): 7,
#  ('feet', 'flori'): 7,
#  ('head', 'turn'): 7,
#  ('hair', 'head'): 7,
#  ('said', 'think'): 7,
#  ("'d", 'think'): 7,
#  ('back', 'upon'): 7,
#  ('back', 'doctor'): 7,
#  ('stood', 'watch'): 7,
#  ('felt', 'flori'): 7,
#  ('way', 'would'): 7,
#  ('littl', 'way'): 7,
#  ('elizabeth', 'way'): 7,
#  ("'ll", 'get'): 7,
#  ('three', 'week'): 7,
#  ('put', "s'la"): 7,
#  ('hundr', 'two'): 7,
#  ('time', 'two'): 7,
#  ('club', 'time'): 7,
#  ('elizabeth', 'make'): 7,
#  ('came', 'flory'): 7,
#  ('came', 'hair'): 7,
#  ('much', 'never'): 7,
#  ('day', 'elizabeth'): 7,
#  ("'i", 'go'): 7,
#  ("'m", 'go'): 7,
#  ('made', 'would'): 7,
#  ('still', 'would'): 7,
#  ('place', 'would'): 7,
#  ('anyth', 'would'): 7,
#  ('enough', 'would'): 7,
#  ('everi', 'would'): 7,
#  ('european', 'would'): 7,
#  ('alway', 'flori'): 7,
#  ('away', 'take'): 7,
#  ('flori', 'made'): 7,
#  ('except', 'two'): 7,
#  ('brought', 'flori'): 7,
#  ('lackersteen', 'left'): 7,
#  ('say', 'someth'): 7,
#  ('say', 'shall'): 7,
#  ('club', 'say'): 7,
#  ('done', 'said'): 7,
#  ('everi', 'word'): 7,
#  ('evening', 'everi'): 7,
#  ('said', 'woman'): 7,
#  ('flori', 'thought'): 7,
#  ('arm', 'hand'): 7,
#  ('away', 'hand'): 7,
#  ('arm', 'flori'): 7,
#  ('arm', 'toward'): 7,
#  ('moment', 'turn'): 7,
#  ('almost', 'round'): 7,
#  ('elizabeth', 'round'): 7,
#  ('ba', 'said'): 7,
#  ('ba', "s'la"): 7,
#  ('said', 'two'): 7,
#  ('english', 'said'): 7,
#  ('away', 'said'): 7,
#  ('right', 'said'): 7,
#  ('club', 'said'): 7,
#  ("'m", 'said'): 7,
#  ("s'la", 'said'): 7,
#  ('old', 'two'): 7,
#  ('away', 'two'): 7,
#  ('behind', 'ko'): 7,
#  ('flo', 'ko'): 7,
#  ('iss', 'know'): 7,
#  ("'what", 'mean'): 7,
#  ('club', 'want'): 7,
#  ('come', 'flory'): 7,
#  ('come', 'flori'): 7,
#  ('dear', 'old'): 7,
#  ('black', 'hair'): 7,
#  ('behind', "s'la"): 7,
#  ('behind', 'elizabeth'): 7,
#  ("'the", 'flori'): 7,
#  ('club', 'walk'): 7,
#  ('club', 'veraswami'): 7,
#  ('flori', 'letter'): 7,
#  ('flori', 'stand'): 7,
#  ('flori', 'keep'): 7,
#  ('flori', 'jungle'): 7,
#  ('flori', 'water'): 7,
#  ('elizabeth', 'notic'): 7,
#  ('club', 'elli'): 7,
#  ('elizabeth', 'evening'): 7,
#  ('elizabeth', 'verrall'): 7,
#  ('back', 'u'): 6,
#  ('ba', 'u'): 6,
#  ('said', 'u'): 6,
#  ('back', 'po'): 6,
#  ('ba', 'po'): 6,
#  ('back', 'kyin'): 6,
#  ('ba', 'kyin'): 6,
#  ('kyauktada', 'month'): 6,
#  ('go', 'kyauktada'): 6,
#  ('european', 'kyauktada'): 6,
#  ('club', 'kyauktada'): 6,
#  ('sit', 'would'): 6,
#  ('elizabeth', 'sit'): 6,
#  ('came', 'veranda'): 6,
#  ('chair', 'long'): 6,
#  ('long', 'would'): 6,
#  ('flori', 'long'): 6,
#  ('long', 'talk'): 6,
#  ('club', 'long'): 6,
#  ('flori', 'seem'): 6,
#  ('one', 'tree'): 6,
#  ('one', 'side'): 6,
#  ('one', 'went'): 6,
#  ('ever', 'one'): 6,
#  ('one', 'thought'): 6,
#  ('mind', 'one'): 6,
#  ('girl', 'one'): 6,
#  ('macgregor', 'one'): 6,
#  ('hear', 'one'): 6,
#  ("'the", 'one'): 6,
#  ('nativ', 'one'): 6,
#  ('letter', 'one'): 6,
#  ('one', 'verral'): 6,
#  ('could', 'yet'): 6,
#  ('could', 'eye'): 6,
#  ('could', 'way'): 6,
#  ('came', 'could'): 6,
#  ('could', 'took'): 6,
#  ('could', 'made'): 6,
#  ('could', 'say'): 6,
#  ('could', 'done'): 6,
#  ('come', 'could'): 6,
#  ('could', 'someth'): 6,
#  ('could', 'right'): 6,
#  ('could', 'talk'): 6,
#  ('club', 'could'): 6,
#  ('could', 'keep'): 6,
#  ('could', 'speak'): 6,
#  ('even', 'see'): 6,
#  ('go', 'see'): 6,
#  ('said', 'see'): 6,
#  ("'ll", 'see'): 6,
#  ('evening', 'see'): 6,
#  ('great', 'tree'): 6,
#  ('elizabeth', 'tree'): 6,
#  ('look', 'white'): 6,
#  ('head', 'look'): 6,
#  ('look', 'two'): 6,
#  ('come', 'look'): 6,
#  ('go', 'without'): 6,
#  ('like', 'year'): 6,
#  ('burmes', 'like'): 6,
#  ('like', 'quit'): 6,
#  ('feet', 'like'): 6,
#  ('like', 'peopl'): 6,
#  ('like', 'upon'): 6,
#  ('knew', 'like'): 6,
#  ('everi', 'like'): 6,
#  ('like', 'thought'): 6,
#  ('like', 'said'): 6,
#  ('like', 'stood'): 6,
#  ('hair', 'like'): 6,
#  ('back', 'man'): 6,
#  ('man', 'way'): 6,
#  ('kind', 'man'): 6,
#  ('littl', 'man'): 6,
#  ('everi', 'man'): 6,
#  ('black', 'man'): 6,
#  ('doctor', 'man'): 6,
#  ('flori', 'man'): 6,
#  ('even', 'year'): 6,
#  ('three', 'year'): 6,
#  ('left', 'year'): 6,
#  ('everi', 'year'): 6,
#  ('back', 'chair'): 6,
#  ('talk', 'yet'): 6,
#  ('even', 'white'): 6,
#  ('even', 'quit'): 6,
#  ('even', 'way'): 6,
#  ('even', 'went'): 6,
#  ('even', 'still'): 6,
#  ('even', 'knew'): 6,
#  ('even', 'say'): 6,
#  ('even', 'good'): 6,
#  ('even', 'thought'): 6,
#  ('even', 'know'): 6,
#  ('even', 'notic'): 6,
#  ('almost', 'even'): 6,
#  ('even', 'verrall'): 6,
#  ('burmes', 'girl'): 6,
#  ('round', 'white'): 6,
#  ('men', 'quit'): 6,
#  ('men', 'way'): 6,
#  ('men', 'young'): 6,
#  ('club', 'men'): 6,
#  ('elizabeth', 'men'): 6,
#  ('face', 'head'): 6,
#  ('back', 'face'): 6,
#  ('face', 'went'): 6,
#  ('face', 'never'): 6,
#  ('face', 'littl'): 6,
#  ('face', 'moment'): 6,
#  ('face', 'macgregor'): 6,
#  ('face', 'old'): 6,
#  ('away', 'face'): 6,
#  ('head', 'would'): 6,
#  ('elizabeth', 'head'): 6,
#  ('back', 'think'): 6,
#  ('say', 'think'): 6,
#  ('life', 'would'): 6,
#  ('life', 'never'): 6,
#  ('back', 'thought'): 6,
#  ('back', 'moment'): 6,
#  ('back', 'macgregor'): 6,
#  ('back', 'may'): 6,
#  ('back', 'walk'): 6,
#  ('back', 'got'): 6,
#  ('back', 'must'): 6,
#  ('back', 'flory'): 6,
#  ('back', 'sat'): 6,
#  ('back', 'road'): 6,
#  ('back', 'gone'): 6,
#  ('flori', 'watch'): 6,
#  ('elizabeth', 'watch'): 6,
#  ('put', 'way'): 6,
#  ('know', 'way'): 6,
#  ('come', 'way'): 6,
#  ('macgregor', 'way'): 6,
#  ('old', 'way'): 6,
#  ('get', 'time'): 6,
#  ('get', 'never'): 6,
#  ('get', 'said'): 6,
#  ('get', 'well'): 6,
#  ('get', 'home'): 6,
#  ('arm', 'put'): 6,
#  ('ko', 'put'): 6,
#  ('flori', 'put'): 6,
#  ('flori', 'four'): 6,
#  ('though', 'would'): 6,
#  ('never', 'though'): 6,
#  ('away', 'though'): 6,
#  ('short', 'time'): 6,
#  ('good', 'time'): 6,
#  ('flory', 'time'): 6,
#  ('talk', 'time'): 6,
#  ('lackersteen', 'time'): 6,
#  ('make', 'two'): 6,
#  ('lackersteen', 'make'): 6,
#  ('came', 'old'): 6,
#  ('behind', 'came'): 6,
#  ('came', 'sat'): 6,
#  ('came', 'road'): 6,
#  ('came', 'flo'): 6,
#  ('thing', 'would'): 6,
#  ('said', 'thing'): 6,
#  ('much', 'said'): 6,
#  ('much', 'two'): 6,
#  ('doctor', 'much'): 6,
#  ('day', 'first'): 6,
#  ('day', 'night'): 6,
#  ('hair', 'short'): 6,
#  ('go', 'know'): 6,
#  ('go', 'us'): 6,
#  ('go', 'veraswami'): 6,
#  ('go', 'got'): 6,
#  ("'ll", 'go'): 6,
#  ('elizabeth', 'go'): 6,
#  ('week', 'would'): 6,
#  ('good', 'would'): 6,
#  ('woman', 'would'): 6,
#  ('turn', 'would'): 6,
#  ('away', 'would'): 6,
#  ('better', 'would'): 6,
#  ('home', 'would'): 6,
#  ('love', 'would'): 6,
#  ('macgregor', 'made'): 6,
#  ('flory', 'made'): 6,
#  ('club', 'made'): 6,
#  ('never', 'thought'): 6,
#  ('never', 'talk'): 6,
#  ('almost', 'never'): 6,
#  ("'ll", 'give'): 6,
#  ('left', 'right'): 6,
#  ('flori', 'left'): 6,
#  ('flori', 'say'): 6,
#  ('mean', 'say'): 6,
#  ('elli', 'say'): 6,
#  ('flori', 'found'): 6,
#  ('flori', 'good'): 6,
#  ('evening', 'good'): 6,
#  ('enough', 'well'): 6,
#  ('enough', 'flori'): 6,
#  ('said', 'tell'): 6,
#  ('littl', 'turn'): 6,
#  ('littl', 'round'): 6,
#  ('littl', 'said'): 6,
#  ('doctor', 'littl'): 6,
#  ('littl', 'talk'): 6,
#  ('elli', 'littl'): 6,
#  ('doctor', 'everi'): 6,
#  ('old', 'woman'): 6,
#  ('flory', 'thought'): 6,
#  ('hand', 'lackersteen'): 6,
#  ('elizabeth', 'hand'): 6,
#  ('arm', 'flory'): 6,
#  ('black', 'round'): 6,
#  ('flory', 'round'): 6,
#  ('round', 'shoulder'): 6,
#  ('ko', 'servant'): 6,
#  ("s'la", 'servant'): 6,
#  ('god', 'oh'): 6,
#  ('said', 'well'): 6,
#  ('friend', 'said'): 6,
#  ('butler', 'said'): 6,
#  ('said', 'verrall'): 6,
#  ("'i", 'want'): 6,
#  ("'i", 'shall'): 6,
#  ("'i", 'must'): 6,
#  ('stood', 'two'): 6,
#  ('letter', 'two'): 6,
#  ('club', 'two'): 6,
#  ('know', 'us'): 6,
#  ('know', 'mean'): 6,
#  ('elizabeth', 'girl'): 6,
#  ('ask', 'elizabeth'): 6,
#  ('come', 'may'): 6,
#  ('come', 'let'): 6,
#  ('come', 'us'): 6,
#  ('come', 'drink'): 6,
#  ('almost', 'moment'): 6,
#  ('macgregor', 'old'): 6,
#  ('elli', 'macgregor'): 6,
#  ('elizabeth', 'macgregor'): 6,
#  ('dear', 'friend'): 6,
#  ('lackersteen', 'last'): 6,
#  ('doctor', 'european'): 6,
#  ('european', 'friend'): 6,
#  ('flory', 'may'): 6,
#  ('old', 'westfield'): 6,
#  ('elizabeth', 'old'): 6,
#  ('flory', 'hla'): 6,
#  ('lackersteen', 'sound'): 6,
#  ('away', 'keep'): 6,
#  ('road', 'walk'): 6,
#  ('flori', 'veraswami'): 6,
#  ('flori', 'got'): 6,
#  ('doctor', 'friend'): 6,
#  ('flori', 'friend'): 6,
#  ('almost', 'flory'): 6,
#  ('flory', 'shoulder'): 6,
#  ('flory', 'iss'): 6,
#  ('flori', 'notic'): 6,
#  ('flori', 'lackersteen'): 6,
#  ('ellis', 'flori'): 6,
#  ('elizabeth', 'sat'): 6,
#  ('elizabeth', 'room'): 6,
#  ('elizabeth', 'heard'): 6,
#  ('butler', 'lackersteen'): 6,
#  ('elizabeth', 'yard'): 6,
#  ('came', 'u'): 5,
#  ('kin', 'u'): 5,
#  ('came', 'po'): 5,
#  ('much', 'po'): 5,
#  ('ever', 'po'): 5,
#  ('good', 'po'): 5,
#  ('european', 'po'): 5,
#  ('kin', 'po'): 5,
#  ('came', 'kyin'): 5,
#  ('kyin', 'much'): 5,
#  ('ever', 'kyin'): 5,
#  ('good', 'kyin'): 5,
#  ('european', 'kyin'): 5,
#  ('kin', 'kyin'): 5,
#  ('burma', 'kyauktada'): 5,
#  ('kyauktada', 'would'): 5,
#  ('one', 'sit'): 5,
#  ('chair', 'sit'): 5,
#  ('sit', 'white'): 5,
#  ('back', 'sit'): 5,
#  ('said', 'sit'): 5,
#  ('sit', 'two'): 5,
#  ('face', 'veranda'): 5,
#  ('half', 'lackersteen'): 5,
#  ('go', 'month'): 5,
#  ('air', 'flori'): 5,
#  ('long', 'way'): 5,
#  ('long', 'never'): 5,
#  ('flory', 'long'): 5,
#  ('even', 'seem'): 5,
#  ('make', 'seem'): 5,
#  ('never', 'seem'): 5,
#  ('great', 'one'): 5,
#  ('chair', 'one'): 5,
#  ('one', 'three'): 5,
#  ('four', 'one'): 5,
#  ('kind', 'one'): 5,
#  ('however', 'one'): 5,
#  ('among', 'one'): 5,
#  ('live', 'one'): 5,
#  ('one', 'turn'): 5,
#  ('one', 'said'): 5,
#  ('ask', 'one'): 5,
#  ('black', 'one'): 5,
#  ('one', 'someth'): 5,
#  ('indian', 'one'): 5,
#  ('one', 'whole'): 5,
#  ('first', 'one'): 5,
#  ('night', 'one'): 5,
#  ('butler', 'one'): 5,
#  ('could', 'tree'): 5,
#  ('could', 'great'): 5,
#  ('back', 'could'): 5,
#  ('could', 'put'): 5,
#  ('could', 'much'): 5,
#  ('alway', 'could'): 5,
#  ('could', 'take'): 5,
#  ('could', 'knew'): 5,
#  ('could', 'two'): 5,
#  ('away', 'could'): 5,
#  ('could', 'walk'): 5,
#  ('could', 'flory'): 5,
#  ('could', 'stand'): 5,
#  ('could', 'night'): 5,
#  ('could', 'love'): 5,
#  ('could', 'verral'): 5,
#  ('rather', 'see'): 5,
#  ('see', 'time'): 5,
#  ('see', 'shall'): 5,
#  ('see', 'us'): 5,
#  ('feel', 'see'): 5,
#  ('came', 'tree'): 5,
#  ('even', 'look'): 5,
#  ('look', 'way'): 5,
#  ('look', 'saw'): 5,
#  ('look', 'turn'): 5,
#  ('girl', 'look'): 5,
#  ('look', 'want'): 5,
#  ('look', 'old'): 5,
#  ('look', 'stand'): 5,
#  ('club', 'look'): 5,
#  ('lackersteen', 'look'): 5,
#  ('like', 'without'): 5,
#  ('without', 'word'): 5,
#  ('flori', 'without'): 5,
#  ('rather', 'think'): 5,
#  ('littl', 'rather'): 5,
#  ('chair', 'like'): 5,
#  ('like', 'think'): 5,
#  ('like', 'put'): 5,
#  ('came', 'like'): 5,
#  ('like', 'still'): 5,
#  ('like', 'never'): 5,
#  ('like', 'say'): 5,
#  ('like', 'live'): 5,
#  ('good', 'like'): 5,
#  ('like', 'woman'): 5,
#  ('end', 'like'): 5,
#  ('arm', 'like'): 5,
#  ('like', 'word'): 5,
#  ('know', 'like'): 5,
#  ('girl', 'like'): 5,
#  ('like', 'moment'): 5,
#  ('burman', 'like'): 5,
#  ('like', 'someth'): 5,
#  ('away', 'like'): 5,
#  ('like', 'right'): 5,
#  ('like', 'us'): 5,
#  ('doctor', 'like'): 5,
#  ('feel', 'like'): 5,
#  ('across', 'like'): 5,
#  ('great', 'thing'): 5,
#  ('great', 'lackersteen'): 5,
#  ('man', 'year'): 5,
#  ('man', 'think'): 5,
#  ('man', 'time'): 5,
#  ('man', 'take'): 5,
#  ('man', 'woman'): 5,
#  ('man', 'young'): 5,
#  ('man', 'stand'): 5,
#  ('hair', 'man'): 5,
#  ('almost', 'man'): 5,
#  ('house', 'man'): 5,
#  ('elizabeth', 'man'): 5,
#  ('hundr', 'year'): 5,
#  ('never', 'year'): 5,
#  ('live', 'year'): 5,
#  ('last', 'year'): 5,
#  ('old', 'year'): 5,
#  ('flori', 'year'): 5,
#  ('talk', 'year'): 5,
#  ('came', 'chair'): 5,
#  ('chair', 'would'): 5,
#  ('chair', 'said'): 5,
#  ('behind', 'chair'): 5,
#  ('chair', 'doctor'): 5,
#  ('chair', 'flori'): 5,
#  ('would', 'yet'): 5,
#  ('never', 'yet'): 5,
#  ('flori', 'yet'): 5,
#  ('verral', 'yet'): 5,
#  ('burmes', 'even'): 5,
#  ('even', 'though'): 5,
#  ('even', 'took'): 5,
#  ('even', 'kind'): 5,
#  ('even', 'go'): 5,
#  ('even', 'give'): 5,
#  ('even', 'live'): 5,
#  ('even', 'littl'): 5,
#  ('even', 'woman'): 5,
#  ('even', 'two'): 5,
#  ('even', 'moment'): 5,
#  ('even', 'talk'): 5,
#  ('burmes', 'women'): 5,
#  ('everi', 'white'): 5,
#  ('white', 'woman'): 5,
#  ('talk', 'white'): 5,
#  ('elizabeth', 'white'): 5,
#  ('men', 'three'): 5,
#  ('came', 'men'): 5,
#  ('arm', 'men'): 5,
#  ('girl', 'men'): 5,
#  ('men', 'whole'): 5,
#  ('face', 'upon'): 5,
#  ('face', 'put'): 5,
#  ('arm', 'face'): 5,
#  ('face', 'flory'): 5,
#  ('face', 'toward'): 5,
#  ('hair', 'yellow'): 5,
#  ('quit', 'way'): 5,
#  ('came', 'quit'): 5,
#  ('girl', 'quit'): 5,
#  ('doctor', 'quit'): 5,
#  ('elli', 'quit'): 5,
#  ('eye', 'flori'): 5,
#  ('feet', 'head'): 5,
#  ('head', 'though'): 5,
#  ('head', 'moment'): 5,
#  ('behind', 'head'): 5,
#  ('away', 'head'): 5,
#  ('get', 'think'): 5,
#  ('day', 'think'): 5,
#  ('go', 'think'): 5,
#  ('think', 'would'): 5,
#  ('girl', 'think'): 5,
#  ('someth', 'think'): 5,
#  ('club', 'think'): 5,
#  ...}

# %%
import matplotlib.pyplot as plt

pair_count = []
for pair, count in new4.items():
    pair_count.append(count)
    
plt.figure(figsize=(20,10))
plt.plot(sorted(pair_count, reverse=True))

plt.ylabel('frequency')
plt.xlabel('rank')
plt.title('word pair frequency in "Burmese Days"')
plt.show()

# %%
#単語順位チェック
word_f = sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)

word_fdic = dict(word_f)
word_fdic
# Out:
# {'flori': 399,
#  'one': 384,
#  'like': 369,
#  'said': 359,
#  'would': 316,
#  'elizabeth': 310,
#  'could': 260,
#  'even': 231,
#  'look': 219,
#  'go': 211,
#  'back': 191,
#  'club': 189,
#  'face': 187,
#  'come': 180,
#  'two': 179,
#  'time': 176,
#  'flory': 171,
#  'came': 163,
#  'doctor': 163,
#  'lackersteen': 163,
#  'see': 155,
#  'way': 149,
#  'po': 147,
#  'kyin': 146,
#  'man': 145,
#  "'i": 145,
#  'never': 144,
#  'macgregor': 140,
#  'say': 139,
#  'know': 138,
#  'get': 133,
#  'think': 131,
#  'away': 131,
#  'u': 129,
#  'almost': 126,
#  'round': 124,
#  'made': 118,
#  'turn': 115,
#  'littl': 114,
#  'ko': 114,
#  'talk': 113,
#  'white': 111,
#  'make': 110,
#  'hand': 109,
#  'old': 109,
#  'men': 107,
#  'quit': 103,
#  'must': 103,
#  'moment': 102,
#  'thing': 101,
#  'good': 101,
#  'though': 100,
#  'girl': 100,
#  'head': 99,
#  'thought': 99,
#  "s'la": 99,
#  'european': 97,
#  'iss': 97,
#  'put': 95,
#  'day': 94,
#  'got': 94,
#  'long': 93,
#  'elli': 93,
#  'went': 91,
#  'much': 91,
#  'take': 90,
#  'year': 89,
#  'life': 87,
#  'verral': 87,
#  'everi': 84,
#  'behind': 84,
#  'seem': 83,
#  'friend': 83,
#  'yet': 82,
#  'call': 80,
#  'right': 79,
#  'rather': 77,
#  'us': 77,
#  'took': 76,
#  'well': 76,
#  'may': 75,
#  "'ll": 74,
#  'black': 73,
#  'someth': 72,
#  'kyauktada': 71,
#  'woman': 71,
#  'westfield': 71,
#  'veranda': 70,
#  'without': 70,
#  'god': 69,
#  'let': 69,
#  "'oh": 69,
#  'still': 68,
#  'ever': 68,
#  'arm': 68,
#  'want': 68,
#  'live': 67,
#  'tell': 67,
#  "'what": 67,
#  'english': 65,
#  'indian': 65,
#  'burmes': 64,
#  'hla': 63,
#  'tree': 62,
#  'alway': 62,
#  'give': 62,
#  'young': 62,
#  'stood': 62,
#  'heard': 62,
#  'keep': 62,
#  'saw': 61,
#  'shall': 61,
#  'first': 61,
#  'upon': 60,
#  'done': 60,
#  'ask': 60,
#  'hear': 59,
#  "'m": 59,
#  'great': 58,
#  'left': 58,
#  'word': 58,
#  'kind': 57,
#  'walk': 57,
#  'home': 57,
#  'women': 57,
#  'air': 56,
#  'last': 56,
#  'night': 56,
#  'burma': 55,
#  "'d": 55,
#  'love': 55,
#  'mind': 54,
#  'small': 53,
#  'knew': 53,
#  "'the": 53,
#  'letter': 53,
#  'ellis': 53,
#  'sit': 52,
#  'dear': 52,
#  'veraswami': 52,
#  'mean': 52,
#  'eye': 51,
#  'matter': 51,
#  'road': 51,
#  'across': 51,
#  'tri': 50,
#  'ba': 50,
#  'yellow': 49,
#  'except': 49,
#  'servant': 49,
#  'peopl': 48,
#  'use': 48,
#  'place': 48,
#  'course': 48,
#  'brought': 48,
#  'end': 48,
#  'began': 48,
#  'noth': 48,
#  'flo': 48,
#  'bloodi': 48,
#  'speak': 48,
#  'butler': 48,
#  'evening': 48,
#  'feet': 47,
#  'nativ': 47,
#  'whole': 47,
#  'drink': 47,
#  'enough': 46,
#  'burman': 46,
#  'feel': 46,
#  'toward': 46,
#  'kin': 46,
#  'notic': 46,
#  'watch': 45,
#  'three': 45,
#  'found': 45,
#  'room': 45,
#  'stand': 45,
#  'hair': 45,
#  'ca': 45,
#  'verrall': 45,
#  'chair': 44,
#  'side': 44,
#  'anoth': 44,
#  'sound': 44,
#  'jungle': 44,
#  'rain': 44,
#  'gone': 44,
#  'water': 44,
#  'poor': 43,
#  'four': 43,
#  'oh': 43,
#  'yard': 43,
#  'house': 43,
#  'half': 42,
#  'however': 42,
#  'short': 42,
#  'among': 42,
#  'villag': 42,
#  'also': 42,
#  'shoulder': 42,
#  'week': 41,
#  'hous': 41,
#  'better': 41,
#  'sat': 41,
#  'start': 41,
#  'month': 40,
#  'felt': 40,
#  'hundr': 40,
#  'anyth': 40,
#  "'you": 40,
#  "'no": 40,
#  'work': 39,
#  'money': 39,
#  'hope': 39,
#  'morning': 39,
#  'hold': 39,
#  'leav': 39,
#  'boy': 39,
#  "'it": 39,
#  'move': 39,
#  'ah': 39,
#  'might': 39,
#  'birthmark': 39,
#  'stop': 39,
#  'dr': 38,
#  'skin': 38,
#  'together': 38,
#  'dread': 38,
#  'crowd': 38,
#  'green': 37,
#  'step': 37,
#  'wait': 37,
#  'name': 37,
#  'bad': 37,
#  'perhap': 37,
#  'morn': 37,
#  'dress': 37,
#  'dark': 37,
#  'seen': 37,
#  'gate': 37,
#  'gave': 37,
#  "'yes": 36,
#  'far': 36,
#  'open': 36,
#  'told': 36,
#  'bazaar': 36,
#  'sun': 36,
#  'heat': 36,
#  'path': 36,
#  'voic': 36,
#  'pleas': 36,
#  'marri': 36,
#  'rebellion': 36,
#  'taken': 35,
#  'offici': 35,
#  'follow': 35,
#  'care': 35,
#  'happen': 35,
#  "'but": 35,
#  'usual': 35,
#  'master': 35,
#  'light': 35,
#  'bed': 35,
#  'sent': 34,
#  'sever': 34,
#  'point': 34,
#  'polic': 34,
#  'etc': 34,
#  'set': 34,
#  'carri': 34,
#  'hot': 34,
#  'realli': 34,
#  'door': 34,
#  'clear': 34,
#  'everyon': 33,
#  'low': 33,
#  'present': 33,
#  'jungl': 33,
#  'ten': 32,
#  'answer': 32,
#  'hour': 32,
#  'bodi': 32,
#  'dog': 32,
#  'possibl': 32,
#  'cut': 32,
#  'book': 32,
#  'gun': 32,
#  'besid': 31,
#  'believ': 31,
#  'honour': 31,
#  'th': 31,
#  "'ah": 31,
#  'fire': 31,
#  'soon': 31,
#  'new': 31,
#  'stick': 31,
#  'india': 31,
#  'damn': 31,
#  'bring': 31,
#  "i'v": 31,
#  'pass': 31,
#  'camp': 31,
#  'rememb': 30,
#  'sometim': 30,
#  'next': 30,
#  'begin': 30,
#  'understand': 30,
#  'touch': 30,
#  'find': 30,
#  'fool': 30,
#  'country': 30,
#  'suppos': 30,
#  'sinc': 29,
#  'simpli': 29,
#  'appear': 29,
#  "'well": 29,
#  'listen': 29,
#  'stay': 29,
#  'order': 29,
#  'happened': 29,
#  'alreadi': 28,
#  'read': 28,
#  'tabl': 28,
#  'hate': 28,
#  'run': 28,
#  'sweat': 28,
#  'front': 28,
#  'fact': 28,
#  'afraid': 28,
#  'sahib': 28,
#  'dead': 28,
#  'heart': 28,
#  'shoot': 28,
#  'past': 27,
#  'beyond': 27,
#  'help': 27,
#  'wear': 27,
#  'offic': 27,
#  'rest': 27,
#  'six': 27,
#  'sein': 27,
#  'rupe': 27,
#  'shout': 27,
#  'maidan': 27,
#  'orient': 27,
#  'fellow': 27,
#  'elect': 27,
#  'close': 26,
#  'high': 26,
#  'british': 26,
#  'case': 26,
#  'five': 26,
#  'eyes': 26,
#  'within': 26,
#  'near': 26,
#  'river': 26,
#  'larg': 26,
#  'hardli': 26,
#  'youth': 26,
#  'meet': 26,
#  'people': 26,
#  'militari': 26,
#  'lay': 26,
#  'dare': 26,
#  'train': 26,
#  'leopard': 26,
#  'table': 25,
#  'natur': 25,
#  'full': 25,
#  'mani': 25,
#  'question': 25,
#  'kill': 25,
#  "'mi": 25,
#  'shirt': 25,
#  'thousand': 25,
#  'forward': 25,
#  'till': 25,
#  'lie': 25,
#  'play': 25,
#  'stream': 25,
#  'others': 25,
#  'longer': 25,
#  'ought': 25,
#  'world': 25,
#  'aunt': 25,
#  'later': 24,
#  'differ': 24,
#  'civil': 24,
#  'jail': 24,
#  "'how": 24,
#  'hurt': 24,
#  'sure': 24,
#  'pale': 24,
#  'need': 24,
#  'blue': 24,
#  'pain': 24,
#  'hurri': 24,
#  'gener': 24,
#  'horribl': 24,
#  'scent': 24,
#  'pull': 24,
#  'show': 24,
#  'years': 24,
#  'rais': 24,
#  'beat': 24,
#  'longyi': 23,
#  'probabl': 23,
#  'best': 23,
#  'part': 23,
#  'reach': 23,
#  'anyon': 23,
#  'europeans': 23,
#  'least': 23,
#  'alone': 23,
#  'church': 23,
#  'big': 23,
#  'grey': 23,
#  'voice': 23,
#  'member': 23,
#  'togeth': 23,
#  'station': 23,
#  'fifti': 23,
#  'drop': 23,
#  'roll': 23,
#  'ass': 23,
#  'kick': 23,
#  'ground': 23,
#  'fat': 22,
#  'earth': 22,
#  'interest': 22,
#  'ago': 22,
#  'bird': 22,
#  'wife': 22,
#  'floor': 22,
#  'bottl': 22,
#  'flowers': 22,
#  'idea': 22,
#  'suddenli': 22,
#  'outsid': 22,
#  "'do": 22,
#  'someon': 22,
#  'along': 22,
#  'given': 22,
#  'cours': 22,
#  'danc': 22,
#  'knee': 22,
#  'shot': 22,
#  'beater': 22,
#  'bare': 21,
#  'march': 21,
#  'twenti': 21,
#  'rangoon': 21,
#  'wave': 21,
#  'ruin': 21,
#  'breakfast': 21,
#  'silk': 21,
#  'learn': 21,
#  'cheek': 21,
#  'nearli': 21,
#  "they'r": 21,
#  'explain': 21,
#  'fear': 21,
#  'certain': 21,
#  'wo': 21,
#  'cri': 21,
#  'tea': 21,
#  'moon': 21,
#  'ride': 21,
#  'breath': 20,
#  'grow': 20,
#  'mandalay': 20,
#  'final': 20,
#  'send': 20,
#  'wish': 20,
#  'subject': 20,
#  'children': 20,
#  'mother': 20,
#  'promis': 20,
#  'school': 20,
#  'mouth': 20,
#  "'we": 20,
#  'hard': 20,
#  'yes': 20,
#  'els': 20,
#  'cover': 20,
#  'bamboo': 20,
#  'middl': 20,
#  'spite': 20,
#  'hat': 20,
#  'sight': 20,
#  'smell': 20,
#  'hands': 20,
#  'bitter': 20,
#  'forest': 20,
#  'foot': 20,
#  "we'r": 20,
#  'burst': 20,
#  'pay': 20,
#  'somehow': 20,
#  'pukka': 20,
#  'nothing': 20,
#  'row': 20,
#  'servants': 20,
#  'scream': 20,
#  'begun': 20,
#  'scene': 20,
#  'struggl': 20,
#  'vast': 19,
#  'clerk': 19,
#  'news': 19,
#  'attack': 19,
#  'district': 19,
#  'known': 19,
#  'die': 19,
#  'gold': 19,
#  "'that": 19,
#  'troubl': 19,
#  'ran': 19,
#  'expect': 19,
#  'anonym': 19,
#  'threw': 19,
#  'brown': 19,
#  'nose': 19,
#  'free': 19,
#  'wooden': 19,
#  'real': 19,
#  'chines': 19,
#  'lower': 19,
#  'silent': 19,
#  'met': 19,
#  'hell': 19,
#  "you'r": 19,
#  'england': 19,
#  'busi': 19,
#  'true': 19,
#  'understood': 19,
#  'kiss': 19,
#  'thakin': 19,
#  'murder': 19,
#  'li': 19,
#  'yeik': 19,
#  'nake': 18,
#  'govern': 18,
#  'job': 18,
#  'evil': 18,
#  'headman': 18,
#  'quarrel': 18,
#  'paper': 18,
#  'rail': 18,
#  'less': 18,
#  'town': 18,
#  'bank': 18,
#  'spot': 18,
#  'drunk': 18,
#  'wonder': 18,
#  'everyth': 18,
#  'ice': 18,
#  'field': 18,
#  'thick': 18,
#  "'good": 18,
#  'whiski': 18,
#  'queer': 18,
#  'nigger': 18,
#  "we'v": 18,
#  'yell': 18,
#  'enter': 18,
#  'pretend': 18,
#  'fifteen': 18,
#  'flat': 18,
#  'hiss': 18,
#  'things': 18,
#  'actual': 18,
#  "you'v": 18,
#  'propos': 18,
#  'minut': 18,
#  'bush': 18,
#  'neck': 18,
#  'forgotten': 18,
#  'pick': 18,
#  'gaze': 17,
#  'rupees': 17,
#  'caught': 17,
#  'danger': 17,
#  'arriv': 17,
#  'days': 17,
#  'number': 17,
#  'angri': 17,
#  'cold': 17,
#  'stone': 17,
#  'food': 17,
#  'thin': 17,
#  'bent': 17,
#  'garden': 17,
#  'refus': 17,
#  'something': 17,
#  'miss': 17,
#  'hill': 17,
#  'trees': 17,
#  'chang': 17,
#  'red': 17,
#  'whether': 17,
#  'riot': 17,
#  'bore': 17,
#  'tone': 17,
#  'remark': 17,
#  'cloth': 17,
#  'manag': 17,
#  'suffer': 17,
#  'maxwell': 17,
#  'either': 17,
#  'ad': 17,
#  'break': 17,
#  'convers': 17,
#  'faces': 17,
#  'bit': 17,
#  'outside': 17,
#  'lost': 17,
#  'save': 17,
#  'compound': 17,
#  'struck': 17,
#  'led': 17,
#  'shooting': 17,
#  'realiz': 17,
#  'sepoy': 17,
#  'escap': 17,
#  'chanc': 16,
#  'return': 16,
#  'basket': 16,
#  'laugh': 16,
#  'alon': 16,
#  'pe': 16,
#  'wors': 16,
#  'consid': 16,
#  'huge': 16,
#  'pink': 16,
#  'beer': 16,
#  'instead': 16,
#  'edg': 16,
#  'polo': 16,
#  'glare': 16,
#  "'em": 16,
#  'already': 16,
#  'fli': 16,
#  "'look": 16,
#  'shake': 16,
#  'sign': 16,
#  'reason': 16,
#  'fall': 16,
#  'mile': 16,
#  'doubt': 16,
#  'manner': 16,
#  'late': 16,
#  'offer': 16,
#  'pigeon': 16,
#  'dah': 16,
#  'remain': 16,
#  'blood': 16,
#  'neither': 16,
#  'tear': 16,
#  'fell': 16,
#  'death': 16,
#  'wind': 15,
#  'miser': 15,
#  'public': 15,
#  'share': 15,
#  'kept': 15,
#  'posit': 15,
#  'mere': 15,
#  'taik': 15,
#  'holi': 15,
#  "'a": 15,
#  "'and": 15,
#  'nois': 15,
#  'fish': 15,
#  'dozen': 15,
#  'dinner': 15,
#  'ha': 15,
#  'fashion': 15,
#  'pagoda': 15,
#  'topi': 15,
#  'colour': 15,
#  'wall': 15,
#  'rose': 15,
#  'tenni': 15,
#  'punkah': 15,
#  'shook': 15,
#  'chap': 15,
#  'straight': 15,
#  'readi': 15,
#  'push': 15,
#  'offend': 15,
#  'countri': 15,
#  'grew': 15,
#  'sens': 15,
#  'bottom': 15,
#  'often': 15,
#  'immedi': 15,
#  'piec': 15,
#  "they'v": 15,
#  'bedroom': 15,
#  'laid': 15,
#  'sprang': 15,
#  'second': 15,
#  'eight': 14,
#  'minutes': 14,
#  'fight': 14,
#  'affair': 14,
#  'broke': 14,
#  'happi': 14,
#  'times': 14,
#  'lip': 14,
#  'violent': 14,
#  'shave': 14,
#  'prickli': 14,
#  'sleep': 14,
#  'held': 14,
#  'insid': 14,
#  'devil': 14,
#  "'come": 14,
#  'please': 14,
#  'suit': 14,
#  'beneath': 14,
#  'absolut': 14,
#  'indeed': 14,
#  'tie': 14,
#  'hit': 14,
#  'thank': 14,
#  'instant': 14,
#  'joy': 14,
#  'drive': 14,
#  'cross': 14,
#  'sea': 14,
#  'madam': 14,
#  'success': 13,
#  'child': 13,
#  'race': 13,
#  'becom': 13,
#  'rule': 13,
#  'wrong': 13,
#  'sooner': 13,
#  'sort': 13,
#  'pile': 13,
#  "'there": 13,
#  'produc': 13,
#  'articl': 13,
#  'h': 13,
#  'added': 13,
#  'deal': 13,
#  'torment': 13,
#  'ingyi': 13,
#  'rich': 13,
#  'everything': 13,
#  'age': 13,
#  'tini': 13,
#  'patch': 13,
#  'law': 13,
#  'art': 13,
#  'bath': 13,
#  'loung': 13,
#  'firm': 13,
#  'remind': 13,
#  'gin': 13,
#  'maxwel': 13,
#  'going': 13,
#  'burmese': 13,
#  'policemen': 13,
#  'dirti': 13,
#  'forehead': 13,
#  'chokra': 13,
#  "'go": 13,
#  'paris': 13,
#  'clean': 13,
#  'fan': 13,
#  'tin': 13,
#  'bear': 13,
#  'music': 13,
#  'line': 13,
#  'opinion': 13,
#  'singl': 13,
#  'strike': 13,
#  'spent': 13,
#  'eat': 13,
#  'breast': 13,
#  'strang': 13,
#  'body': 13,
#  'climb': 13,
#  'extraordinari': 13,
#  'buffalo': 13,
#  'pour': 13,
#  'thirti': 13,
#  'strong': 13,
#  'poni': 13,
#  'hors': 13,
#  'pwe': 13,
#  'pay-like': 13,
#  'cool': 12,
#  'beauti': 12,
#  'rifl': 12,
#  'grasp': 12,
#  'stroke': 12,
#  'ring': 12,
#  'prison': 12,
#  'attempt': 12,
#  'seven': 12,
#  'level': 12,
#  'tomorrow': 12,
#  'tall': 12,
#  'smooth': 12,
#  'partli': 12,
#  'wretch': 12,
#  'wrote': 12,
#  'movement': 12,
#  'quarter': 12,
#  'rage': 12,
#  'slowli': 12,
#  'enorm': 12,
#  'wicker': 12,
#  'peepul': 12,
#  'slender': 12,
#  'allow': 12,
#  'fit': 12,
#  'war': 12,
#  'shoe': 12,
#  'husband': 12,
#  'press': 12,
#  'shop': 12,
#  'coat': 12,
#  'creatur': 12,
#  'talking': 12,
#  'oil': 12,
#  'crocodile': 12,
#  'imagin': 12,
#  "'they": 12,
#  'narrow': 12,
#  'meant': 12,
#  'person': 12,
#  'decent': 12,
#  'bend': 12,
#  'seiz': 12,
#  'de': 12,
#  'shame': 12,
#  'nga': 12,
#  "'elizabeth": 12,
#  'earthquake': 12,
#  'upper': 11,
#  'stir': 11,
#  'commissioner': 11,
#  'privat': 11,
#  'lead': 11,
#  'practic': 11,
#  'form': 11,
#  'impress': 11,
#  'joke': 11,
#  'rag': 11,
#  'entir': 11,
#  'teeth': 11,
#  'scandal': 11,
#  'written': 11,
#  'spoke': 11,
#  'disgust': 11,
#  'prepar': 11,
#  'discuss': 11,
#  'direct': 11,
#  'cock': 11,
#  'stretch': 11,
#  'top': 11,
#  'power': 11,
#  'admit': 11,
#  'grass': 11,
#  'mali': 11,
#  'flower': 11,
#  'englishman': 11,
#  'police': 11,
#  'coming': 11,
#  'leg': 11,
#  'mosquito': 11,
#  'due': 11,
#  'peg': 11,
#  'insult': 11,
#  'garlic': 11,
#  'hang': 11,
#  'repeat': 11,
#  'spectacles': 11,
#  'knees': 11,
#  'shut': 11,
#  'dull': 11,
#  'natives': 11,
#  'fill': 11,
#  'float': 11,
#  "'of": 11,
#  'shock': 11,
#  'rub': 11,
#  'wild': 11,
#  'ignor': 11,
#  'trouble': 11,
#  'sorry': 11,
#  'settl': 11,
#  'books': 11,
#  'throat': 11,
#  'repeated': 11,
#  'tail': 11,
#  'distanc': 11,
#  'caus': 11,
#  'crawl': 11,
#  'wash': 11,
#  'shiko': 11,
#  'uncle': 11,
#  'perfectli': 11,
#  'earlier': 11,
#  'despis': 11,
#  'flung': 11,
#  'fallen': 11,
#  'drag': 11,
#  'anything': 11,
#  'broad': 11,
#  'detail': 11,
#  'sunlight': 10,
#  'shape': 10,
#  'crop': 10,
#  'heel': 10,
#  'fail': 10,
#  'anna': 10,
#  'else': 10,
#  'act': 10,
#  'deputi': 10,
#  'bribe': 10,
#  'paid': 10,
#  'worth': 10,
#  'accord': 10,
#  'intend': 10,
#  'rank': 10,
#  'beast': 10,
#  'whose': 10,
#  'trust': 10,
#  'greet': 10,
#  "'he": 10,
#  'rise': 10,
#  'another': 10,
#  'difficult': 10,
#  'believe': 10,
#  'timber': 10,
#  'deep': 10,
#  "'then": 10,
#  'quick': 10,
#  'tast': 10,
#  'corner': 10,
#  'view': 10,
#  'effort': 10,
#  'plan': 10,
#  'business': 10,
#  'spear': 10,
#  'eurasian': 10,
#  'samuel': 10,
#  'son': 10,
#  'bushes': 10,
#  'backward': 10,
#  'suppose': 10,
#  'cloud': 10,
#  'eh': 10,
#  'dusti': 10,
#  'dust': 10,
#  'christ': 10,
#  'uncl': 10,
#  'married': 10,
#  'enjoy': 10,
#  'rot': 10,
#  'heavi': 10,
#  'anger': 10,
#  'complet': 10,
#  'asleep': 10,
#  'ladi': 10,
#  'evid': 10,
#  'gather': 10,
#  'game': 10,
#  'forgiv': 10,
#  'perhaps': 10,
#  "'if": 10,
#  'shade': 10,
#  'conversation': 10,
#  'hass': 10,
#  'utter': 10,
#  'snub': 10,
#  'helpless': 10,
#  'worst': 10,
#  'mattu': 10,
#  'hut': 10,
#  'serious': 10,
#  'seriou': 10,
#  'uncomfort': 10,
#  'receiv': 10,
#  'ugli': 10,
#  "'whi": 10,
#  'visit': 10,
#  "'get": 10,
#  'mood': 10,
#  'twist': 10,
#  'ear': 10,
#  'plung': 10,
#  'roof': 10,
#  ...}

# %%
count = 0
s_value = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    s_value.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
count = 0
p_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    p = (word_fdic[i[0]]  * word_fdic[i[1]]) * s * s
    p_values.append(p)
    
    count += 1
    
    if count == 1000:
        break

# %%
max(p_values)
# Out:
# 0.9395210138850061

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(p_values)

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_value)

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
s_value_top_5 = sorted(s_value, reverse=True)[:6]
s_value_top_5
# Out:
# [0.012063492063492064,
#  0.008328903065745172,
#  0.006616345168204268,
#  0.006591784000421874,
#  0.006583837740256982,
#  0.004145408163265306]

# %%
print(s_value.index(s_value_top_5[0]))
print(s_value.index(s_value_top_5[1]))
print(s_value.index(s_value_top_5[2]))
print(s_value.index(s_value_top_5[3]))
print(s_value.index(s_value_top_5[4]))
# Out:
# 4
# 3
# 0
# 1
# 2

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[0]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'hla':
        print(i,j)
    elif i ==  'may':
        print(i,j)
# Out:
# ('hla', 'may') 57
# may 75
# hla 63

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[1]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'ko':
        print(i,j)
    elif i ==  "s'la":
        print(i,j)
# Out:
# ('ko', "s'la") 94
# ko 114
# s'la 99

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[2]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'kyin':
        print(i,j)
    elif i ==  'po':
        print(i,j)
# Out:
# ('kyin', 'po') 142
# po 147
# kyin 146

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[3]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'po':
        print(i,j)
    elif i ==  'u':
        print(i,j)
# Out:
# ('po', 'u') 125
# po 147
# u 129

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[4]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'kyin':
        print(i,j)
    elif i ==  'u':
        print(i,j)
# Out:
# ('kyin', 'u') 124
# kyin 146
# u 129

# %%
from math import log
log_list = [log(y,10) for y in s_value]

#take a log
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_list, reverse=True))

plt.ylabel('s value(log scale)')
plt.xlabel('rank (Descending order of s value)')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(log_list)+1)
y = sorted(log_list, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('s value(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
from math import log

sorted_list = sorted(s_value, reverse=True)
sorted_list

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_value)+1)]


#take a log
import matplotlib.pyplot as plt
import numpy as np

x = np.array(log_x[:-700])
y = np.array(log_list[:-700])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
# i,j count
import numpy as np

len(word_f)
# Out:
# 8659

# %%
i = np.arange(len(word_f), 0, -1)
j = np.arange(1,len(word_f)+1, 1)

def square(list):
    return [i ** -2 for i in list]
square(i)
# Out:
# [1.3337195607351948e-08,
#  1.3340276680540021e-08,
#  1.3343358821506009e-08,
#  1.334644203074337e-08,
#  1.3349526308745842e-08,
#  1.3352611656007455e-08,
#  1.335569807302252e-08,
#  1.3358785560285635e-08,
#  1.3361874118291683e-08,
#  1.3364963747535834e-08,
#  1.3368054448513546e-08,
#  1.337114622172056e-08,
#  1.3374239067652907e-08,
#  1.3377332986806899e-08,
#  1.3380427979679144e-08,
#  1.338352404676653e-08,
#  1.3386621188566236e-08,
#  1.3389719405575726e-08,
#  1.3392818698292755e-08,
#  1.3395919067215363e-08,
#  1.3399020512841883e-08,
#  1.3402123035670929e-08,
#  1.3405226636201412e-08,
#  1.3408331314932526e-08,
#  1.3411437072363756e-08,
#  1.3414543908994876e-08,
#  1.3417651825325949e-08,
#  1.3420760821857331e-08,
#  1.3423870899089661e-08,
#  1.3426982057523876e-08,
#  1.3430094297661199e-08,
#  1.3433207620003142e-08,
#  1.3436322025051511e-08,
#  1.3439437513308402e-08,
#  1.3442554085276202e-08,
#  1.3445671741457589e-08,
#  1.3448790482355529e-08,
#  1.3451910308473289e-08,
#  1.3455031220314416e-08,
#  1.345815321838276e-08,
#  1.3461276303182458e-08,
#  1.3464400475217936e-08,
#  1.346752573499392e-08,
#  1.3470652083015426e-08,
#  1.3473779519787761e-08,
#  1.3476908045816528e-08,
#  1.3480037661607622e-08,
#  1.3483168367667233e-08,
#  1.3486300164501844e-08,
#  1.3489433052618231e-08,
#  1.3492567032523469e-08,
#  1.349570210472492e-08,
#  1.3498838269730249e-08,
#  1.3501975528047411e-08,
#  1.3505113880184656e-08,
#  1.3508253326650531e-08,
#  1.3511393867953877e-08,
#  1.3514535504603834e-08,
#  1.3517678237109836e-08,
#  1.3520822065981612e-08,
#  1.3523966991729188e-08,
#  1.3527113014862888e-08,
#  1.3530260135893332e-08,
#  1.3533408355331437e-08,
#  1.3536557673688417e-08,
#  1.3539708091475785e-08,
#  1.3542859609205346e-08,
#  1.3546012227389214e-08,
#  1.3549165946539788e-08,
#  1.3552320767169775e-08,
#  1.3555476689792174e-08,
#  1.355863371492029e-08,
#  1.3561791843067719e-08,
#  1.356495107474836e-08,
#  1.3568111410476413e-08,
#  1.3571272850766376e-08,
#  1.3574435396133043e-08,
#  1.3577599047091512e-08,
#  1.3580763804157183e-08,
#  1.3583929667845751e-08,
#  1.3587096638673217e-08,
#  1.3590264717155878e-08,
#  1.3593433903810334e-08,
#  1.3596604199153487e-08,
#  1.3599775603702539e-08,
#  1.3602948117974995e-08,
#  1.3606121742488662e-08,
#  1.3609296477761648e-08,
#  1.3612472324312362e-08,
#  1.3615649282659518e-08,
#  1.3618827353322131e-08,
#  1.3622006536819521e-08,
#  1.3625186833671308e-08,
#  1.3628368244397418e-08,
#  1.363155076951808e-08,
#  1.3634734409553826e-08,
#  1.363791916502549e-08,
#  1.3641105036454217e-08,
#  1.3644292024361447e-08,
#  1.3647480129268931e-08,
#  1.3650669351698725e-08,
#  1.3653859692173187e-08,
#  1.3657051151214981e-08,
#  1.3660243729347077e-08,
#  1.3663437427092753e-08,
#  1.3666632244975586e-08,
#  1.3669828183519466e-08,
#  1.3673025243248588e-08,
#  1.3676223424687451e-08,
#  1.3679422728360864e-08,
#  1.3682623154793937e-08,
#  1.3685824704512096e-08,
#  1.3689027378041068e-08,
#  1.3692231175906888e-08,
#  1.3695436098635901e-08,
#  1.3698642146754759e-08,
#  1.3701849320790423e-08,
#  1.3705057621270161e-08,
#  1.3708267048721552e-08,
#  1.3711477603672483e-08,
#  1.3714689286651146e-08,
#  1.3717902098186049e-08,
#  1.3721116038806005e-08,
#  1.372433110904014e-08,
#  1.3727547309417887e-08,
#  1.3730764640468991e-08,
#  1.3733983102723506e-08,
#  1.3737202696711798e-08,
#  1.3740423422964542e-08,
#  1.3743645282012729e-08,
#  1.3746868274387656e-08,
#  1.3750092400620932e-08,
#  1.375331766124448e-08,
#  1.3756544056790536e-08,
#  1.3759771587791643e-08,
#  1.376300025478066e-08,
#  1.3766230058290761e-08,
#  1.3769460998855427e-08,
#  1.3772693077008457e-08,
#  1.377592629328396e-08,
#  1.3779160648216362e-08,
#  1.3782396142340397e-08,
#  1.378563277619112e-08,
#  1.3788870550303896e-08,
#  1.3792109465214404e-08,
#  1.3795349521458639e-08,
#  1.379859071957291e-08,
#  1.3801833060093844e-08,
#  1.3805076543558378e-08,
#  1.3808321170503768e-08,
#  1.3811566941467587e-08,
#  1.381481385698772e-08,
#  1.3818061917602372e-08,
#  1.3821311123850061e-08,
#  1.3824561476269621e-08,
#  1.3827812975400211e-08,
#  1.3831065621781294e-08,
#  1.3834319415952664e-08,
#  1.3837574358454422e-08,
#  1.384083044982699e-08,
#  1.3844087690611109e-08,
#  1.3847346081347841e-08,
#  1.3850605622578559e-08,
#  1.385386631484496e-08,
#  1.3857128158689061e-08,
#  1.3860391154653192e-08,
#  1.3863655303280006e-08,
#  1.3866920605112478e-08,
#  1.3870187060693899e-08,
#  1.3873454670567882e-08,
#  1.3876723435278358e-08,
#  1.3879993355369581e-08,
#  1.3883264431386123e-08,
#  1.388653666387288e-08,
#  1.3889810053375068e-08,
#  1.3893084600438222e-08,
#  1.38963603056082e-08,
#  1.3899637169431184e-08,
#  1.3902915192453676e-08,
#  1.3906194375222499e-08,
#  1.3909474718284801e-08,
#  1.3912756222188053e-08,
#  1.3916038887480045e-08,
#  1.3919322714708893e-08,
#  1.3922607704423038e-08,
#  1.3925893857171242e-08,
#  1.3929181173502591e-08,
#  1.3932469653966497e-08,
#  1.3935759299112693e-08,
#  1.3939050109491238e-08,
#  1.3942342085652521e-08,
#  1.3945635228147245e-08,
#  1.394892953752645e-08,
#  1.3952225014341492e-08,
#  1.395552165914406e-08,
#  1.3958819472486161e-08,
#  1.3962118454920138e-08,
#  1.3965418606998652e-08,
#  1.3968719929274695e-08,
#  1.3972022422301583e-08,
#  1.3975326086632962e-08,
#  1.3978630922822805e-08,
#  1.3981936931425409e-08,
#  1.3985244112995402e-08,
#  1.3988552468087741e-08,
#  1.3991861997257707e-08,
#  1.3995172701060913e-08,
#  1.3998484580053302e-08,
#  1.4001797634791141e-08,
#  1.4005111865831028e-08,
#  1.4008427273729895e-08,
#  1.4011743859044995e-08,
#  1.4015061622333919e-08,
#  1.4018380564154586e-08,
#  1.4021700685065241e-08,
#  1.4025021985624465e-08,
#  1.4028344466391166e-08,
#  1.4031668127924585e-08,
#  1.4034992970784296e-08,
#  1.4038318995530199e-08,
#  1.4041646202722532e-08,
#  1.4044974592921861e-08,
#  1.4048304166689085e-08,
#  1.4051634924585437e-08,
#  1.4054966867172482e-08,
#  1.4058299995012115e-08,
#  1.4061634308666569e-08,
#  1.4064969808698407e-08,
#  1.4068306495670527e-08,
#  1.4071644370146163e-08,
#  1.4074983432688876e-08,
#  1.4078323683862569e-08,
#  1.4081665124231478e-08,
#  1.4085007754360168e-08,
#  1.4088351574813549e-08,
#  1.4091696586156858e-08,
#  1.4095042788955672e-08,
#  1.40983901837759e-08,
#  1.4101738771183791e-08,
#  1.4105088551745927e-08,
#  1.4108439526029232e-08,
#  1.4111791694600958e-08,
#  1.4115145058028703e-08,
#  1.4118499616880394e-08,
#  1.4121855371724304e-08,
#  1.4125212323129036e-08,
#  1.4128570471663534e-08,
#  1.4131929817897083e-08,
#  1.4135290362399301e-08,
#  1.4138652105740152e-08,
#  1.414201504848993e-08,
#  1.4145379191219273e-08,
#  1.414874453449916e-08,
#  1.4152111078900906e-08,
#  1.4155478824996169e-08,
#  1.4158847773356945e-08,
#  1.4162217924555571e-08,
#  1.4165589279164724e-08,
#  1.4168961837757424e-08,
#  1.4172335600907029e-08,
#  1.4175710569187242e-08,
#  1.4179086743172103e-08,
#  1.4182464123435999e-08,
#  1.4185842710553655e-08,
#  1.4189222505100138e-08,
#  1.4192603507650864e-08,
#  1.4195985718781583e-08,
#  1.4199369139068394e-08,
#  1.4202753769087737e-08,
#  1.4206139609416397e-08,
#  1.4209526660631501e-08,
#  1.4212914923310523e-08,
#  1.4216304398031275e-08,
#  1.4219695085371921e-08,
#  1.4223086985910966e-08,
#  1.422648010022726e-08,
#  1.4229874428899999e-08,
#  1.4233269972508724e-08,
#  1.4236666731633322e-08,
#  1.4240064706854028e-08,
#  1.424346389875142e-08,
#  1.4246864307906422e-08,
#  1.4250265934900311e-08,
#  1.4253668780314703e-08,
#  1.4257072844731567e-08,
#  1.4260478128733216e-08,
#  1.4263884632902311e-08,
#  1.4267292357821866e-08,
#  1.4270701304075238e-08,
#  1.4274111472246132e-08,
#  1.4277522862918604e-08,
#  1.4280935476677062e-08,
#  1.4284349314106256e-08,
#  1.4287764375791292e-08,
#  1.4291180662317622e-08,
#  1.4294598174271049e-08,
#  1.4298016912237729e-08,
#  1.4301436876804162e-08,
#  1.4304858068557205e-08,
#  1.4308280488084064e-08,
#  1.4311704135972296e-08,
#  1.4315129012809808e-08,
#  1.4318555119184861e-08,
#  1.4321982455686067e-08,
#  1.4325411022902392e-08,
#  1.4328840821423153e-08,
#  1.4332271851838019e-08,
#  1.4335704114737012e-08,
#  1.4339137610710509e-08,
#  1.4342572340349242e-08,
#  1.4346008304244291e-08,
#  1.4349445502987096e-08,
#  1.4352883937169447e-08,
#  1.4356323607383492e-08,
#  1.4359764514221731e-08,
#  1.4363206658277022e-08,
#  1.4366650040142575e-08,
#  1.4370094660411959e-08,
#  1.4373540519679094e-08,
#  1.4376987618538264e-08,
#  1.4380435957584099e-08,
#  1.4383885537411594e-08,
#  1.4387336358616099e-08,
#  1.4390788421793317e-08,
#  1.4394241727539315e-08,
#  1.4397696276450512e-08,
#  1.4401152069123687e-08,
#  1.4404609106155977e-08,
#  1.4408067388144878e-08,
#  1.4411526915688245e-08,
#  1.4414987689384288e-08,
#  1.4418449709831584e-08,
#  1.442191297762906e-08,
#  1.442537749337601e-08,
#  1.4428843257672087e-08,
#  1.4432310271117299e-08,
#  1.4435778534312019e-08,
#  1.4439248047856982e-08,
#  1.4442718812353279e-08,
#  1.4446190828402367e-08,
#  1.4449664096606062e-08,
#  1.4453138617566542e-08,
#  1.4456614391886347e-08,
#  1.446009142016838e-08,
#  1.4463569703015907e-08,
#  1.4467049241032556e-08,
#  1.4470530034822317e-08,
#  1.4474012084989545e-08,
#  1.447749539213896e-08,
#  1.4480979956875641e-08,
#  1.4484465779805036e-08,
#  1.4487952861532955e-08,
#  1.4491441202665574e-08,
#  1.4494930803809431e-08,
#  1.4498421665571432e-08,
#  1.4501913788558848e-08,
#  1.4505407173379317e-08,
#  1.4508901820640839e-08,
#  1.4512397730951786e-08,
#  1.4515894904920888e-08,
#  1.4519393343157252e-08,
#  1.4522893046270344e-08,
#  1.4526394014870001e-08,
#  1.4529896249566428e-08,
#  1.4533399750970195e-08,
#  1.4536904519692243e-08,
#  1.4540410556343881e-08,
#  1.4543917861536783e-08,
#  1.4547426435882995e-08,
#  1.4550936279994937e-08,
#  1.4554447394485387e-08,
#  1.4557959779967501e-08,
#  1.4561473437054805e-08,
#  1.4564988366361193e-08,
#  1.4568504568500926e-08,
#  1.4572022044088644e-08,
#  1.457554079373935e-08,
#  1.4579060818068424e-08,
#  1.4582582117691616e-08,
#  1.4586104693225046e-08,
#  1.4589628545285208e-08,
#  1.4593153674488967e-08,
#  1.4596680081453562e-08,
#  1.4600207766796605e-08,
#  1.4603736731136079e-08,
#  1.4607266975090345e-08,
#  1.4610798499278132e-08,
#  1.4614331304318547e-08,
#  1.4617865390831069e-08,
#  1.4621400759435555e-08,
#  1.4624937410752233e-08,
#  1.4628475345401708e-08,
#  1.4632014564004961e-08,
#  1.4635555067183345e-08,
#  1.4639096855558592e-08,
#  1.4642639929752813e-08,
#  1.4646184290388491e-08,
#  1.4649729938088483e-08,
#  1.4653276873476031e-08,
#  1.465682509717475e-08,
#  1.4660374609808632e-08,
#  1.4663925412002047e-08,
#  1.4667477504379746e-08,
#  1.4671030887566853e-08,
#  1.4674585562188875e-08,
#  1.4678141528871698e-08,
#  1.4681698788241587e-08,
#  1.4685257340925181e-08,
#  1.4688817187549505e-08,
#  1.4692378328741965e-08,
#  1.4695940765130341e-08,
#  1.46995044973428e-08,
#  1.4703069526007885e-08,
#  1.4706635851754522e-08,
#  1.471020347521202e-08,
#  1.4713772397010067e-08,
#  1.4717342617778736e-08,
#  1.4720914138148477e-08,
#  1.4724486958750131e-08,
#  1.4728061080214913e-08,
#  1.4731636503174424e-08,
#  1.4735213228260653e-08,
#  1.4738791256105969e-08,
#  1.474237058734312e-08,
#  1.4745951222605248e-08,
#  1.4749533162525873e-08,
#  1.4753116407738901e-08,
#  1.4756700958878623e-08,
#  1.4760286816579717e-08,
#  1.4763873981477244e-08,
#  1.4767462454206652e-08,
#  1.4771052235403777e-08,
#  1.477464332570484e-08,
#  1.4778235725746447e-08,
#  1.4781829436165594e-08,
#  1.4785424457599661e-08,
#  1.4789020790686419e-08,
#  1.4792618436064025e-08,
#  1.4796217394371025e-08,
#  1.4799817666246352e-08,
#  1.480341925232933e-08,
#  1.4807022153259668e-08,
#  1.4810626369677471e-08,
#  1.4814231902223226e-08,
#  1.4817838751537815e-08,
#  1.4821446918262506e-08,
#  1.4825056403038964e-08,
#  1.482866720650924e-08,
#  1.4832279329315774e-08,
#  1.48358927721014e-08,
#  1.4839507535509346e-08,
#  1.4843123620183227e-08,
#  1.4846741026767056e-08,
#  1.4850359755905231e-08,
#  1.4853979808242547e-08,
#  1.4857601184424194e-08,
#  1.4861223885095751e-08,
#  1.4864847910903194e-08,
#  1.486847326249289e-08,
#  1.48720999405116e-08,
#  1.4875727945606484e-08,
#  1.4879357278425093e-08,
#  1.4882987939615371e-08,
#  1.4886619929825665e-08,
#  1.4890253249704708e-08,
#  1.4893887899901635e-08,
#  1.4897523881065976e-08,
#  1.4901161193847656e-08,
#  1.4904799838896999e-08,
#  1.4908439816864725e-08,
#  1.491208112840195e-08,
#  1.4915723774160192e-08,
#  1.4919367754791358e-08,
#  1.4923013070947766e-08,
#  1.4926659723282118e-08,
#  1.4930307712447529e-08,
#  1.4933957039097502e-08,
#  1.4937607703885946e-08,
#  1.4941259707467167e-08,
#  1.4944913050495874e-08,
#  1.4948567733627165e-08,
#  1.4952223757516559e-08,
#  1.4955881122819953e-08,
#  1.4959539830193666e-08,
#  1.4963199880294399e-08,
#  1.4966861273779276e-08,
#  1.4970524011305798e-08,
#  1.4974188093531892e-08,
#  1.4977853521115874e-08,
#  1.4981520294716466e-08,
#  1.4985188414992796e-08,
#  1.4988857882604387e-08,
#  1.4992528698211177e-08,
#  1.4996200862473503e-08,
#  1.4999874376052101e-08,
#  1.5003549239608123e-08,
#  1.5007225453803115e-08,
#  1.5010903019299037e-08,
#  1.5014581936758252e-08,
#  1.5018262206843523e-08,
#  1.5021943830218025e-08,
#  1.5025626807545342e-08,
#  1.5029311139489457e-08,
#  1.5032996826714766e-08,
#  1.5036683869886071e-08,
#  1.504037226966858e-08,
#  1.5044062026727912e-08,
#  1.5047753141730093e-08,
#  1.5051445615341553e-08,
#  1.5055139448229139e-08,
#  1.5058834641060104e-08,
#  1.5062531194502104e-08,
#  1.5066229109223215e-08,
#  1.5069928385891917e-08,
#  1.5073629025177105e-08,
#  1.5077331027748078e-08,
#  1.5081034394274552e-08,
#  1.5084739125426649e-08,
#  1.5088445221874909e-08,
#  1.5092152684290276e-08,
#  1.5095861513344116e-08,
#  1.5099571709708196e-08,
#  1.5103283274054708e-08,
#  1.5106996207056247e-08,
#  1.5110710509385827e-08,
#  1.5114426181716876e-08,
#  1.511814322472323e-08,
#  1.5121861639079149e-08,
#  1.5125581425459297e-08,
#  1.512930258453876e-08,
#  1.513302511699304e-08,
#  1.5136749023498048e-08,
#  1.5140474304730116e-08,
#  1.5144200961365991e-08,
#  1.5147928994082841e-08,
#  1.5151658403558239e-08,
#  1.5155389190470189e-08,
#  1.51591213554971e-08,
#  1.5162854899317811e-08,
#  1.5166589822611565e-08,
#  1.5170326126058038e-08,
#  1.5174063810337314e-08,
#  1.5177802876129897e-08,
#  1.518154332411672e-08,
#  1.5185285154979122e-08,
#  1.518902836939887e-08,
#  1.5192772968058152e-08,
#  1.519651895163957e-08,
#  1.5200266320826156e-08,
#  1.520401507630135e-08,
#  1.5207765218749029e-08,
#  1.5211516748853476e-08,
#  1.5215269667299415e-08,
#  1.5219023974771971e-08,
#  1.5222779671956709e-08,
#  1.5226536759539608e-08,
#  1.5230295238207072e-08,
#  1.5234055108645929e-08,
#  1.5237816371543433e-08,
#  1.5241579027587257e-08,
#  1.5245343077465506e-08,
#  1.5249108521866704e-08,
#  1.5252875361479801e-08,
#  1.5256643596994172e-08,
#  1.5260413229099623e-08,
#  1.5264184258486384e-08,
#  1.5267956685845103e-08,
#  1.5271730511866867e-08,
#  1.5275505737243185e-08,
#  1.5279282362665992e-08,
#  1.528306038882765e-08,
#  1.5286839816420953e-08,
#  1.5290620646139121e-08,
#  1.5294402878675802e-08,
#  1.5298186514725079e-08,
#  1.5301971554981454e-08,
#  1.5305758000139863e-08,
#  1.5309545850895679e-08,
#  1.5313335107944695e-08,
#  1.5317125771983139e-08,
#  1.532091784370767e-08,
#  1.5324711323815379e-08,
#  1.5328506213003788e-08,
#  1.5332302511970849e-08,
#  1.5336100221414946e-08,
#  1.5339899342034903e-08,
#  1.5343699874529964e-08,
#  1.5347501819599816e-08,
#  1.5351305177944577e-08,
#  1.5355109950264799e-08,
#  1.5358916137261466e-08,
#  1.5362723739636e-08,
#  1.5366532758090254e-08,
#  1.5370343193326517e-08,
#  1.5374155046047516e-08,
#  1.5377968316956414e-08,
#  1.53817830067568e-08,
#  1.5385599116152719e-08,
#  1.5389416645848633e-08,
#  1.5393235596549452e-08,
#  1.5397055968960521e-08,
#  1.5400877763787622e-08,
#  1.5404700981736972e-08,
#  1.5408525623515233e-08,
#  1.5412351689829504e-08,
#  1.5416179181387319e-08,
#  1.5420008098896653e-08,
#  1.5423838443065922e-08,
#  1.5427670214603985e-08,
#  1.5431503414220131e-08,
#  1.5435338042624098e-08,
#  1.5439174100526068e-08,
#  1.5443011588636654e-08,
#  1.5446850507666922e-08,
#  1.5450690858328367e-08,
#  1.5454532641332936e-08,
#  1.5458375857393019e-08,
#  1.5462220507221444e-08,
#  1.5466066591531483e-08,
#  1.5469914111036855e-08,
#  1.5473763066451721e-08,
#  1.5477613458490683e-08,
#  1.548146528786879e-08,
#  1.548531855530154e-08,
#  1.5489173261504875e-08,
#  1.5493029407195172e-08,
#  1.5496886993089273e-08,
#  1.5500746019904446e-08,
#  1.550460648835842e-08,
#  1.5508468399169368e-08,
#  1.5512331753055902e-08,
#  1.5516196550737094e-08,
#  1.5520062792932456e-08,
#  1.5523930480361948e-08,
#  1.5527799613745986e-08,
#  1.5531670193805424e-08,
#  1.5535542221261573e-08,
#  1.5539415696836193e-08,
#  1.5543290621251493e-08,
#  1.554716699523013e-08,
#  1.5551044819495214e-08,
#  1.5554924094770303e-08,
#  1.5558804821779415e-08,
#  1.5562687001247006e-08,
#  1.5566570633897999e-08,
#  1.5570455720457753e-08,
#  1.5574342261652095e-08,
#  1.5578230258207296e-08,
#  1.5582119710850085e-08,
#  1.5586010620307636e-08,
#  1.558990298730759e-08,
#  1.5593796812578031e-08,
#  1.5597692096847507e-08,
#  1.5601588840845008e-08,
#  1.5605487045299997e-08,
#  1.5609386710942379e-08,
#  1.5613287838502519e-08,
#  1.5617190428711242e-08,
#  1.5621094482299824e-08,
#  1.5624999999999999e-08,
#  1.5628906982543965e-08,
#  1.5632815430664369e-08,
#  1.563672534509432e-08,
#  1.5640636726567386e-08,
#  1.5644549575817594e-08,
#  1.564846389357943e-08,
#  1.5652379680587835e-08,
#  1.5656296937578218e-08,
#  1.5660215665286443e-08,
#  1.5664135864448835e-08,
#  1.5668057535802179e-08,
#  1.5671980680083719e-08,
#  1.5675905298031173e-08,
#  1.5679831390382706e-08,
#  1.5683758957876952e-08,
#  1.5687688001253008e-08,
#  1.569161852125043e-08,
#  1.5695550518609242e-08,
#  1.5699483994069928e-08,
#  1.5703418948373441e-08,
#  1.5707355382261192e-08,
#  1.5711293296475059e-08,
#  1.5715232691757389e-08,
#  1.5719173568850988e-08,
#  1.5723115928499132e-08,
#  1.5727059771445561e-08,
#  1.5731005098434485e-08,
#  1.5734951910210573e-08,
#  1.5738900207518973e-08,
#  1.574284999110529e-08,
#  1.57468012617156e-08,
#  1.575075402009645e-08,
#  1.5754708266994851e-08,
#  1.5758664003158289e-08,
#  1.5762621229334712e-08,
#  1.5766579946272541e-08,
#  1.5770540154720668e-08,
#  1.5774501855428457e-08,
#  1.5778465049145738e-08,
#  1.5782429736622811e-08,
#  1.5786395918610457e-08,
#  1.5790363595859919e-08,
#  1.5794332769122912e-08,
#  1.5798303439151634e-08,
#  1.5802275606698744e-08,
#  1.5806249272517379e-08,
#  1.5810224437361147e-08,
#  1.581420110198414e-08,
#  1.5818179267140908e-08,
#  1.5822158933586488e-08,
#  1.5826140102076388e-08,
#  1.583012277336659e-08,
#  1.5834106948213556e-08,
#  1.5838092627374218e-08,
#  1.5842079811605985e-08,
#  1.5846068501666754e-08,
#  1.5850058698314881e-08,
#  1.5854050402309211e-08,
#  1.5858043614409069e-08,
#  1.5862038335374251e-08,
#  1.5866034565965031e-08,
#  1.5870032306942167e-08,
#  1.5874031559066898e-08,
#  1.5878032323100938e-08,
#  1.5882034599806477e-08,
#  1.5886038389946195e-08,
#  1.589004369428325e-08,
#  1.5894050513581274e-08,
#  1.5898058848604392e-08,
#  1.5902068700117198e-08,
#  1.5906080068884778e-08,
#  1.5910092955672699e-08,
#  1.5914107361247006e-08,
#  1.5918123286374233e-08,
#  1.5922140731821392e-08,
#  1.5926159698355988e-08,
#  1.5930180186745998e-08,
#  1.5934202197759893e-08,
#  1.5938225732166626e-08,
#  1.5942250790735639e-08,
#  1.5946277374236853e-08,
#  1.5950305483440682e-08,
#  1.5954335119118018e-08,
#  1.595836628204025e-08,
#  1.5962398972979251e-08,
#  1.5966433192707375e-08,
#  1.5970468941997477e-08,
#  1.5974506221622886e-08,
#  1.5978545032357434e-08,
#  1.5982585374975426e-08,
#  1.5986627250251672e-08,
#  1.5990670658961465e-08,
#  1.5994715601880589e-08,
#  1.5998762079785316e-08,
#  1.6002810093452411e-08,
#  1.6006859643659133e-08,
#  1.601091073118323e-08,
#  1.6014963356802941e-08,
#  1.6019017521297002e-08,
#  1.6023073225444639e-08,
#  1.6027130470025571e-08,
#  1.6031189255820011e-08,
#  1.6035249583608666e-08,
#  1.6039311454172736e-08,
#  1.6043374868293918e-08,
#  1.6047439826754408e-08,
#  1.6051506330336886e-08,
#  1.605557437982454e-08,
#  1.6059643976001047e-08,
#  1.6063715119650583e-08,
#  1.6067787811557821e-08,
#  1.6071862052507932e-08,
#  1.6075937843286581e-08,
#  1.6080015184679941e-08,
#  1.608409407747467e-08,
#  1.6088174522457933e-08,
#  1.6092256520417395e-08,
#  1.609634007214122e-08,
#  1.6100425178418069e-08,
#  1.6104511840037104e-08,
#  1.6108600057787993e-08,
#  1.6112689832460897e-08,
#  1.6116781164846483e-08,
#  1.6120874055735921e-08,
#  1.6124968505920888e-08,
#  1.612906451619355e-08,
#  1.6133162087346585e-08,
#  1.6137261220173176e-08,
#  1.614136191546701e-08,
#  1.6145464174022269e-08,
#  1.6149567996633656e-08,
#  1.615367338409636e-08,
#  1.615778033720609e-08,
#  1.6161888856759053e-08,
#  1.6165998943551968e-08,
#  1.6170110598382059e-08,
#  1.6174223822047048e-08,
#  1.6178338615345179e-08,
#  1.6182454979075194e-08,
#  1.6186572914036348e-08,
#  1.6190692421028401e-08,
#  1.6194813500851621e-08,
#  1.6198936154306789e-08,
#  1.6203060382195194e-08,
#  1.620718618531864e-08,
#  1.6211313564479431e-08,
#  1.6215442520480387e-08,
#  1.6219573054124845e-08,
#  1.6223705166216646e-08,
#  1.6227838857560143e-08,
#  1.6231974128960211e-08,
#  1.6236110981222222e-08,
#  1.6240249415152078e-08,
#  1.6244389431556181e-08,
#  1.6248531031241455e-08,
#  1.6252674215015339e-08,
#  1.6256818983685778e-08,
#  1.626096533806124e-08,
#  1.626511327895071e-08,
#  1.6269262807163681e-08,
#  1.6273413923510171e-08,
#  1.6277566628800704e-08,
#  1.6281720923846338e-08,
#  1.628587680945863e-08,
#  1.6290034286449665e-08,
#  1.6294193355632046e-08,
#  1.6298354017818892e-08,
#  1.6302516273823846e-08,
#  1.6306680124461061e-08,
#  1.6310845570545223e-08,
#  1.6315012612891525e-08,
#  1.6319181252315693e-08,
#  1.6323351489633962e-08,
#  1.6327523325663097e-08,
#  1.6331696761220386e-08,
#  1.6335871797123632e-08,
#  1.6340048434191165e-08,
#  1.6344226673241841e-08,
#  1.6348406515095031e-08,
#  1.6352587960570641e-08,
#  1.6356771010489089e-08,
#  1.636095566567133e-08,
#  1.6365141926938839e-08,
#  1.6369329795113611e-08,
#  1.6373519271018174e-08,
#  1.6377710355475584e-08,
#  1.6381903049309414e-08,
#  1.6386097353343774e-08,
#  1.6390293268403294e-08,
#  1.6394490795313144e-08,
#  1.6398689934899004e-08,
#  1.6402890687987099e-08,
#  1.6407093055404176e-08,
#  1.6411297037977512e-08,
#  1.6415502636534916e-08,
#  1.6419709851904727e-08,
#  1.642391868491581e-08,
#  1.6428129136397565e-08,
#  1.6432341207179928e-08,
#  1.6436554898093361e-08,
#  1.6440770209968857e-08,
#  1.644498714363795e-08,
#  1.6449205699932702e-08,
#  1.6453425879685705e-08,
#  1.6457647683730091e-08,
#  1.646187111289953e-08,
#  1.6466096168028213e-08,
#  1.6470322849950878e-08,
#  1.6474551159502798e-08,
#  1.6478781097519778e-08,
#  1.6483012664838162e-08,
#  1.6487245862294829e-08,
#  1.6491480690727197e-08,
#  1.6495717150973224e-08,
#  1.6499955243871401e-08,
#  1.6504194970260762e-08,
#  1.6508436330980875e-08,
#  1.6512679326871855e-08,
#  1.6516923958774351e-08,
#  1.6521170227529558e-08,
#  1.65254181339792e-08,
#  1.6529667678965556e-08,
#  1.6533918863331437e-08,
#  1.6538171687920201e-08,
#  1.6542426153575749e-08,
#  1.6546682261142518e-08,
#  1.6550940011465499e-08,
#  1.6555199405390216e-08,
#  1.6559460443762739e-08,
#  1.6563723127429691e-08,
#  1.6567987457238231e-08,
#  1.6572253434036066e-08,
#  1.6576521058671454e-08,
#  1.6580790331993185e-08,
#  1.6585061254850613e-08,
#  1.6589333828093626e-08,
#  1.6593608052572665e-08,
#  1.6597883929138719e-08,
#  1.6602161458643327e-08,
#  1.6606440641938568e-08,
#  1.6610721479877082e-08,
#  1.6615003973312051e-08,
#  1.6619288123097204e-08,
#  1.6623573930086834e-08,
#  1.6627861395135768e-08,
#  1.6632150519099398e-08,
#  1.6636441302833657e-08,
#  1.6640733747195037e-08,
#  1.6645027853040585e-08,
#  1.6649323621227886e-08,
#  1.6653621052615099e-08,
#  1.6657920148060926e-08,
#  1.6662220908424616e-08,
#  1.666652333456599e-08,
#  1.6670827427345409e-08,
#  1.6675133187623795e-08,
#  1.667944061626263e-08,
#  1.6683749714123947e-08,
#  1.6688060482070339e-08,
#  1.6692372920964952e-08,
#  1.6696687031671495e-08,
#  1.670100281505423e-08,
#  1.6705320271977984e-08,
#  1.6709639403308133e-08,
#  1.6713960209910627e-08,
#  1.671828269265196e-08,
#  1.6722606852399199e-08,
#  1.6726932690019962e-08,
#  1.6731260206382436e-08,
#  1.6735589402355367e-08,
#  1.6739920278808059e-08,
#  1.6744252836610384e-08,
#  1.6748587076632775e-08,
#  1.6752922999746227e-08,
#  1.6757260606822301e-08,
#  1.6761599898733118e-08,
#  1.6765940876351372e-08,
#  1.6770283540550309e-08,
#  1.6774627892203758e-08,
#  1.6778973932186098e-08,
#  1.6783321661372284e-08,
#  1.6787671080637833e-08,
#  1.679202219085883e-08,
#  1.679637499291193e-08,
#  1.6800729487674355e-08,
#  1.6805085676023895e-08,
#  1.6809443558838911e-08,
#  1.6813803136998329e-08,
#  1.6818164411381653e-08,
#  1.6822527382868947e-08,
#  1.6826892052340857e-08,
#  1.6831258420678589e-08,
#  1.6835626488763927e-08,
#  1.6839996257479232e-08,
#  1.6844367727707425e-08,
#  1.6848740900332013e-08,
#  1.6853115776237069e-08,
#  1.685749235630724e-08,
#  1.686187064142775e-08,
#  1.6866250632484399e-08,
#  1.6870632330363557e-08,
#  1.6875015735952175e-08,
#  1.6879400850137777e-08,
#  1.6883787673808465e-08,
#  1.6888176207852917e-08,
#  1.6892566453160392e-08,
#  1.6896958410620727e-08,
#  1.6901352081124326e-08,
#  1.6905747465562188e-08,
#  1.6910144564825885e-08,
#  1.6914543379807565e-08,
#  1.6918943911399956e-08,
#  1.6923346160496378e-08,
#  1.6927750127990719e-08,
#  1.6932155814777455e-08,
#  1.6936563221751642e-08,
#  1.6940972349808921e-08,
#  1.6945383199845513e-08,
#  1.6949795772758223e-08,
#  1.6954210069444444e-08,
#  1.6958626090802147e-08,
#  1.6963043837729893e-08,
#  1.6967463311126826e-08,
#  1.6971884511892676e-08,
#  1.6976307440927757e-08,
#  1.698073209913297e-08,
#  1.698515848740981e-08,
#  1.6989586606660352e-08,
#  1.6994016457787263e-08,
#  1.6998448041693792e-08,
#  1.7002881359283787e-08,
#  1.7007316411461679e-08,
#  1.7011753199132491e-08,
#  1.7016191723201829e-08,
#  1.7020631984575903e-08,
#  1.7025073984161505e-08,
#  1.7029517722866023e-08,
#  1.7033963201597432e-08,
#  1.7038410421264304e-08,
#  1.7042859382775804e-08,
#  ...]

# %%
middle = len(square(j)) / 2
print(int(middle))

middle = len(square(i)) / 2
print (int(middle))
# Out:
# 4329
# 4329

# %%
square(j)[int(middle)]
# Out:
# 5.333646240579447e-08

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (int(middle)**2) / (x)

myu = integrate.quad(computePi, 1, int(middle)**2)

# 結果にはintegrated value and estimation error
myu
# Out:
# (313827518.272396, 0.2987217007126901)

# %%
(4329**2) * log(4329**2)
# Out:
# 313827518.2723959

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (5.333646240579447e-08**2) / (x)

myu = integrate.quad(computePi, 1, (5.333646240579447e-08**2))
print(myu)
# Out:
# (-2.3912568527702252e-14, 2.6600270512636902e-14)
