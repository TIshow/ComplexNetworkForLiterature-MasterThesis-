# %%
# https://biblio.wiki/wiki/Nineteen_Eighty-Four

import nltk
from nltk.corpus import stopwords
import math
# %matplotlib inline

raw1 = open('Nineteen_Eighty-Four.txt').read()

# %%
tokens1 = nltk.word_tokenize(raw1)
sentence1 = nltk.sent_tokenize(raw1)

#The number of token
len(tokens1)
# Out:
# 114827

# %%
len(sentence1)
# Out:
# 6505

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer() #to make base form

tokens_low = [w.lower() for w in tokens1]

#The number of sort of words
len(set(tokens_low))

#複数形や過去形を別の単語としてカウントしてしまっているため，実際の異なり語数はさらに少ない
# Out:
# 9058

# %%
print (len(set(tokens_low))/len(tokens1))
# Out:
# 0.0788838861940136

# %%
list1 = [tokens1]

text = []
for i in list1:
    text.append(nltk.Text(i))
    
freq_list = []
for i in text:
    freq_list.append(nltk.FreqDist(w.lower() for w in i))

stopwords = nltk.corpus.stopwords.words('english')
symbols = ["'", '"', '`', '.', ',', '-', '!', '?', ':', ';', '(', ')', '...', "'s", '’', '”', '“','–','—', '…', '*' ,'``', "''",'--','mr.',"n't", 'dr.','sir', '‘', 'mr', 'm.' ]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#順位チェック
sorted(freq_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('winston', 523),
#  ('one', 412),
#  ('could', 402),
#  ('said', 341),
#  ('would', 338),
#  ('even', 297),
#  ('party', 281),
#  ('like', 199),
#  ('face', 194),
#  ('time', 194),
#  ("o'brien", 191),
#  ('thought', 176),
#  ('seemed', 172),
#  ('never', 171),
#  ('two', 156),
#  ('back', 152),
#  ('moment', 152),
#  ('man', 147),
#  ('still', 145),
#  ('always', 141),
#  ('know', 130),
#  ('another', 124),
#  ('though', 121),
#  ('way', 121),
#  ('eyes', 120),
#  ('war', 120),
#  ('years', 119),
#  ('might', 118),
#  ('almost', 117),
#  ('little', 113),
#  ('thing', 108),
#  ('long', 107),
#  ('old', 106),
#  ('made', 106),
#  ('knew', 106),
#  ('round', 106),
#  ('people', 104),
#  ('must', 104),
#  ('three', 103),
#  ('away', 100),
#  ('past', 100),
#  ('say', 100),
#  ('voice', 98),
#  ('something', 97),
#  ('world', 97),
#  ('ever', 97),
#  ('mind', 96),
#  ("'i", 95),
#  ('julia', 95),
#  ('telescreen', 92),
#  ('see', 92),
#  ("'you", 92),
#  ('big', 91),
#  ('perhaps', 91),
#  ('without', 91),
#  ('every', 90),
#  ('place', 90),
#  ('kind', 88),
#  ('make', 87),
#  ('day', 82),
#  ('looked', 82),
#  ('room', 81),
#  ('life', 81),
#  ('body', 80),
#  ('power', 80),
#  ('brother', 79),
#  ('much', 79),
#  ('hand', 79),
#  ('nothing', 78),
#  ('first', 78),
#  ('came', 77),
#  ('got', 75),
#  ('turned', 74),
#  ('get', 72),
#  ('human', 72),
#  ('anything', 71),
#  ('remember', 71),
#  ('end', 69),
#  ('seen', 68),
#  ('sort', 68),
#  ('feeling', 68),
#  ('pain', 68),
#  ('right', 67),
#  ('went', 67),
#  ('happened', 67),
#  ('girl', 67),
#  ('whole', 66),
#  ('except', 65),
#  ('work', 65),
#  ('table', 64),
#  ('already', 64),
#  ('enough', 63),
#  ('head', 63),
#  ('look', 63),
#  ('side', 63),
#  ('also', 63),
#  ('come', 63),
#  ('word', 62),
#  ('four', 62),
#  ('everything', 62),
#  ('suddenly', 62),
#  ('ministry', 61),
#  ('white', 61),
#  ('possible', 61),
#  ('since', 60),
#  ('minutes', 60),
#  ('called', 59),
#  ('go', 59),
#  ('woman', 59),
#  ('yet', 58),
#  ('think', 58),
#  ("'it", 58),
#  ('merely', 57),
#  ('bed', 57),
#  ('times', 56),
#  ('oceania', 56),
#  ('quite', 56),
#  ('took', 56),
#  ('small', 56),
#  ('words', 55),
#  ('far', 55),
#  ('sometimes', 55),
#  ('hands', 55),
#  ('behind', 54),
#  ('well', 54),
#  ('whether', 54),
#  ('saw', 53),
#  ('felt', 53),
#  ('necessary', 53),
#  ('different', 52),
#  ('sat', 52),
#  ('actually', 52),
#  ('air', 50),
#  ('put', 50),
#  ('glass', 49),
#  ('simply', 49),
#  ('across', 49),
#  ('course', 48),
#  ('true', 48),
#  ('men', 48),
#  ('fact', 48),
#  ('hours', 47),
#  ('hair', 47),
#  ('love', 47),
#  ('began', 47),
#  ('good', 47),
#  ('become', 47),
#  ('memory', 46),
#  ('newspeak', 46),
#  ('certain', 46),
#  ('proles', 46),
#  ('better', 46),
#  ('days', 46),
#  ('new', 46),
#  ("'the", 46),
#  ("'yes", 46),
#  ('police', 45),
#  ('impossible', 45),
#  ('act', 45),
#  ('ago', 45),
#  ('done', 45),
#  ('take', 45),
#  ('outside', 44),
#  ('paper', 44),
#  ('used', 44),
#  ('upon', 44),
#  ('last', 44),
#  ('great', 44),
#  ('heart', 44),
#  ('inside', 43),
#  ('street', 43),
#  ('front', 43),
#  ('towards', 43),
#  ("'m", 43),
#  ("'ve", 43),
#  ('five', 43),
#  ('victory', 42),
#  ('enormous', 42),
#  ('matter', 42),
#  ('left', 42),
#  ('children', 42),
#  ('death', 41),
#  ('full', 41),
#  ('stopped', 41),
#  ('alone', 41),
#  ('less', 41),
#  ('door', 41),
#  ('fingers', 41),
#  ('tell', 40),
#  ('longer', 40),
#  ('things', 40),
#  ('somewhere', 40),
#  ('middle', 40),
#  ('many', 40),
#  ('parsons', 40),
#  ("'re", 40),
#  ('mother', 40),
#  ('understand', 40),
#  ('book', 39),
#  ('keep', 39),
#  ('others', 39),
#  ('light', 39),
#  ('large', 38),
#  ('set', 38),
#  ('gave', 38),
#  ('arm', 38),
#  ('shall', 38),
#  ('appeared', 38),
#  ('together', 38),
#  ('stood', 37),
#  ('next', 37),
#  ('floor', 37),
#  ('members', 37),
#  ('seconds', 37),
#  ('member', 37),
#  ('inner', 37),
#  ('eurasia', 37),
#  ('exist', 37),
#  ('black', 36),
#  ('dark', 36),
#  ('really', 36),
#  ('half', 36),
#  ('taken', 36),
#  ('soon', 36),
#  ('give', 36),
#  ('wall', 35),
#  ('hate', 35),
#  ('heard', 35),
#  ('real', 35),
#  ('changed', 35),
#  ('young', 35),
#  ('later', 35),
#  ('syme', 35),
#  ('part', 34),
#  ('truth', 34),
#  ('held', 34),
#  ('hold', 34),
#  ('passed', 34),
#  ('goldstein', 34),
#  ('thirty', 34),
#  ('brought', 34),
#  ('dead', 34),
#  ('within', 33),
#  ('kept', 33),
#  ('gin', 33),
#  ('gone', 33),
#  ('going', 33),
#  ('eastasia', 33),
#  ('else', 33),
#  ('piece', 33),
#  ("'ll", 33),
#  ('ten', 33),
#  ('believe', 33),
#  ('us', 33),
#  ('week', 32),
#  ('water', 32),
#  ('fear', 32),
#  ('person', 32),
#  ('remembered', 32),
#  ('reality', 32),
#  ('control', 32),
#  ('whose', 32),
#  ('however', 31),
#  ('sitting', 31),
#  ('probably', 31),
#  ('near', 31),
#  ('revolution', 31),
#  ('trying', 30),
#  ('opposite', 30),
#  ('future', 30),
#  ('enemy', 30),
#  ('mouth', 30),
#  ('standing', 30),
#  ('known', 30),
#  ('want', 30),
#  ('prisoners', 30),
#  ("'we", 30),
#  ('history', 30),
#  ('society', 30),
#  ('use', 29),
#  ('present', 29),
#  ('able', 29),
#  ('written', 29),
#  ('sure', 29),
#  ('occurred', 29),
#  ('started', 29),
#  ('happen', 29),
#  ('name', 29),
#  ('feel', 29),
#  ('existed', 29),
#  ('told', 29),
#  ('cell', 29),
#  ("'what", 29),
#  ('question', 29),
#  ('top', 29),
#  ('overalls', 28),
#  ('smell', 28),
#  ('diary', 28),
#  ('doublethink', 28),
#  ('needed', 28),
#  ('arms', 28),
#  ('general', 28),
#  ('women', 28),
#  ('important', 28),
#  ('alive', 28),
#  ('lay', 28),
#  ('may', 28),
#  ('turn', 28),
#  ('effort', 27),
#  ('deep', 27),
#  ('wanted', 27),
#  ('became', 27),
#  ('nearly', 27),
#  ('reason', 27),
#  ('open', 27),
#  ('sense', 27),
#  ('either', 27),
#  ('case', 27),
#  ('night', 27),
#  ('let', 27),
#  ('records', 27),
#  ('idea', 27),
#  ('faces', 27),
#  ('everyone', 27),
#  ('feet', 27),
#  ('looking', 27),
#  ('difference', 27),
#  ('talking', 27),
#  ("'that", 27),
#  ('several', 26),
#  ('sound', 26),
#  ('london', 26),
#  ('read', 26),
#  ('age', 26),
#  ('among', 26),
#  ('point', 26),
#  ('department', 26),
#  ('exactly', 26),
#  ('hatred', 26),
#  ('thinking', 26),
#  ('ca', 26),
#  ('hour', 26),
#  ('physical', 26),
#  ('change', 26),
#  ('earlier', 26),
#  ('speak', 26),
#  ('immediately', 25),
#  ('ingsoc', 25),
#  ('given', 25),
#  ('movement', 25),
#  ('fell', 25),
#  ('usual', 25),
#  ('year', 25),
#  ('nose', 25),
#  ('lies', 25),
#  ('existence', 25),
#  ('whatever', 25),
#  ('coming', 25),
#  ("'no", 25),
#  ('heavy', 24),
#  ('window', 24),
#  ('instant', 24),
#  ('aware', 24),
#  ('although', 24),
#  ('morning', 24),
#  ('somehow', 24),
#  ('boots', 24),
#  ('struck', 24),
#  ('sleep', 24),
#  ('early', 24),
#  ('added', 24),
#  ('charrington', 24),
#  ('corner', 23),
#  ('freedom', 23),
#  ('conscious', 23),
#  ('forgotten', 23),
#  ('boy', 23),
#  ('books', 23),
#  ('hardly', 23),
#  ('evening', 23),
#  ('six', 23),
#  ('clothes', 23),
#  ('knowledge', 23),
#  ('stop', 23),
#  ('need', 23),
#  ('working', 22),
#  ('completely', 22),
#  ('often', 22),
#  ('stuff', 22),
#  ('home', 22),
#  ('second', 22),
#  ('music', 22),
#  ('worked', 22),
#  ('spectacles', 22),
#  ('brotherhood', 22),
#  ('consciousness', 22),
#  ("'d", 22),
#  ('noticed', 22),
#  ('dream', 22),
#  ('broken', 22),
#  ('difficult', 22),
#  ('pushed', 22),
#  ('speaking', 22),
#  ('coffee', 22),
#  ('singing', 22),
#  ('century', 22),
#  ('bells', 22),
#  ('shut', 21),
#  ('picked', 21),
#  ('knowing', 21),
#  ('tried', 21),
#  ('sight', 21),
#  ('appearance', 21),
#  ('order', 21),
#  ('quarter', 21),
#  ('easy', 21),
#  ('followed', 21),
#  ('continued', 21),
#  ('group', 21),
#  ('eurasian', 21),
#  ('secret', 21),
#  ('caught', 21),
#  ('mean', 21),
#  ('pieces', 21),
#  ('meet', 21),
#  ('wondered', 21),
#  ("'and", 21),
#  ("'do", 21),
#  ('lived', 21),
#  ('cold', 20),
#  ('skin', 20),
#  ('single', 20),
#  ('vast', 20),
#  ('guards', 20),
#  ('tiny', 20),
#  ('writing', 20),
#  ('short', 20),
#  ('lost', 20),
#  ('making', 20),
#  ('running', 20),
#  ('today', 20),
#  ('movements', 20),
#  ('dangerous', 20),
#  ('filled', 20),
#  ('found', 20),
#  ('yes', 20),
#  ('opened', 20),
#  ('thoughts', 20),
#  ('comrade', 20),
#  ('sister', 20),
#  ('walked', 20),
#  ('meant', 20),
#  ('chocolate', 20),
#  ('fighting', 20),
#  ('lie', 20),
#  ('process', 20),
#  ('grown', 20),
#  ('picture', 20),
#  ('high', 20),
#  ('dust', 19),
#  ('low', 19),
#  ('metres', 19),
#  ('food', 19),
#  ('complete', 19),
#  ('date', 19),
#  ('curious', 19),
#  ('shouting', 19),
#  ('child', 19),
#  ('hundred', 19),
#  ('disappeared', 19),
#  ('beyond', 19),
#  ('produced', 19),
#  ('hear', 19),
#  ('means', 19),
#  ('evidence', 19),
#  ('care', 19),
#  ('silent', 19),
#  ('knees', 19),
#  ('line', 19),
#  ('afternoon', 19),
#  ('danger', 19),
#  ('happening', 19),
#  ('flat', 18),
#  ('sun', 18),
#  ('live', 18),
#  ('expression', 18),
#  ('glance', 18),
#  ('wrote', 18),
#  ('believed', 18),
#  ('weeks', 18),
#  ('finally', 18),
#  ('nobody', 18),
#  ('job', 18),
#  ('ones', 18),
#  ('spies', 18),
#  ('couple', 18),
#  ('minute', 18),
#  ('saying', 18),
#  ('forward', 18),
#  ('pocket', 18),
#  ('hundreds', 18),
#  ('continuous', 18),
#  ('public', 18),
#  ("'there", 18),
#  ('pulled', 18),
#  ('grew', 18),
#  ('seven', 17),
#  ('slowly', 17),
#  ('watching', 17),
#  ('reading', 17),
#  ('blue', 17),
#  ('rate', 17),
#  ('walls', 17),
#  ('peace', 17),
#  ('bread', 17),
#  ('beautiful', 17),
#  ('lying', 17),
#  ('free', 17),
#  ('huge', 17),
#  ('bring', 17),
#  ('hope', 17),
#  ('political', 17),
#  ('indeed', 17),
#  ('chair', 17),
#  ('teeth', 17),
#  ('powerful', 17),
#  ('torture', 17),
#  ('help', 17),
#  ('rest', 17),
#  ('faint', 17),
#  ('slightly', 17),
#  ('twenty', 17),
#  ('earth', 17),
#  ('altered', 17),
#  ('meaning', 17),
#  ('easily', 17),
#  ('natural', 17),
#  ('katharine', 17),
#  ('st', 17),
#  ('quickly', 16),
#  ('cut', 16),
#  ('move', 16),
#  ('moved', 16),
#  ('simultaneously', 16),
#  ('darkness', 16),
#  ('bombs', 16),
#  ('news', 16),
#  ('streets', 16),
#  ('thick', 16),
#  ('position', 16),
#  ('instead', 16),
#  ('remain', 16),
#  ('least', 16),
#  ('desire', 16),
#  ('nature', 16),
#  ('military', 16),
#  ('impression', 16),
#  ('gesture', 16),
#  ('talk', 16),
#  ('voices', 16),
#  ('straight', 16),
#  ('flung', 16),
#  ('shoot', 16),
#  ('message', 16),
#  ('following', 16),
#  ('sooner', 16),
#  ('vaguely', 16),
#  ('someone', 16),
#  ("'they", 16),
#  ('interest', 16),
#  ('leave', 16),
#  ('walking', 16),
#  ('paused', 16),
#  ('living', 16),
#  ('strong', 16),
#  ('step', 16),
#  ('therefore', 16),
#  ('forth', 16),
#  ('shoulders', 16),
#  ('till', 16),
#  ('telescreens', 16),
#  ('crowd', 16),
#  ('shop', 16),
#  ('sit', 16),
#  ('dial', 16),
#  ('along', 15),
#  ('ran', 15),
#  ('figure', 15),
#  ('razor', 15),
#  ('level', 15),
#  ('distance', 15),
#  ('remained', 15),
#  ('instinct', 15),
#  ('strength', 15),
#  ('contained', 15),
#  ('names', 15),
#  ('belly', 15),
#  ('apart', 15),
#  ('rubbish', 15),
#  ('curiously', 15),
#  ('crimes', 15),
#  ('violent', 15),
#  ('shoulder', 15),
#  ('vaporized', 15),
#  ('call', 15),
#  ('common', 15),
#  ('building', 15),
#  ('sweat', 15),
#  ('find', 15),
#  ('killed', 15),
#  ('exists', 15),
#  ('country', 15),
#  ('bit', 15),
#  ('memories', 15),
#  ('pure', 15),
#  ('thousands', 15),
#  ('dropped', 15),
#  ('direction', 15),
#  ("'how", 15),
#  ('says', 15),
#  ('ruling', 15),
#  ('groups', 15),
#  ('101', 15),
#  ('beneath', 14),
#  ('figures', 14),
#  ('colour', 14),
#  ('individual', 14),
#  ('hidden', 14),
#  ('partly', 14),
#  ('supposed', 14),
#  ('ordinary', 14),
#  ('carried', 14),
#  ('centre', 14),
#  ('league', 14),
#  ('waist', 14),
#  ('manner', 14),
#  ('anyone', 14),
#  ('speech', 14),
#  ('powers', 14),
#  ('waiting', 14),
#  ('terrible', 14),
#  ('capable', 14),
#  ('wife', 14),
#  ('falling', 14),
#  ('dirty', 14),
#  ('filthy', 14),
#  ('clear', 14),
#  ('stand', 14),
#  ('rocket', 14),
#  ('fro', 14),
#  ('rather', 14),
#  ('instance', 14),
#  ('die', 14),
#  ('intellectual', 14),
#  ('tube', 14),
#  ('tears', 14),
#  ('comes', 14),
#  ('months', 14),
#  ('numbers', 14),
#  ('number', 14),
#  ('expected', 14),
#  ('class', 14),
#  ('learn', 14),
#  ('obviously', 14),
#  ('photograph', 14),
#  ('walk', 14),
#  ('clock', 14),
#  ('beginning', 14),
#  ('guard', 14),
#  ('paperweight', 14),
#  ('confess', 14),
#  ('rats', 14),
#  ('super-states', 14),
#  ('gazed', 13),
#  ('vision', 13),
#  ('watched', 13),
#  ('object', 13),
#  ('thousand', 13),
#  ('law', 13),
#  ('plenty', 13),
#  ('crossed', 13),
#  ('normal', 13),
#  ('fifty', 13),
#  ('bomb', 13),
#  ('suppose', 13),
#  ('realized', 13),
#  ('taking', 13),
#  ('carrying', 13),
#  ('narrow', 13),
#  ('brien', 13),
#  ('neck', 13),
#  ('edge', 13),
#  ('occasionally', 13),
#  ('endless', 13),
#  ('besides', 13),
#  ('state', 13),
#  ('rose', 13),
#  ('lunatic', 13),
#  ('moments', 13),
#  ('mere', 13),
#  ('conversation', 13),
#  ('hard', 13),
#  ('mrs', 13),
#  ('mass', 13),
#  ('fragment', 13),
#  ('blow', 13),
#  ('seem', 13),
#  ('attention', 13),
#  ('bad', 13),
#  ('asleep', 13),
#  ('fallen', 13),
#  ('example', 13),
#  ('show', 13),
#  ('wrong', 13),
#  ('allowed', 13),
#  ('millions', 13),
#  ('ampleforth', 13),
#  ('problem', 13),
#  ('aim', 13),
#  ('beings', 13),
#  ('listening', 13),
#  ('growing', 13),
#  ('stirred', 13),
#  ('pressed', 13),
#  ('confessed', 13),
#  ('destroy', 13),
#  ('beer', 13),
#  ('bones', 13),
#  ('pavement', 13),
#  ('effect', 13),
#  ("'but", 13),
#  ('martin', 13),
#  ('safe', 13),
#  ('breast', 12),
#  ('best', 12),
#  ('sky', 12),
#  ('helicopter', 12),
#  ('everybody', 12),
#  ('whenever', 12),
#  ('vague', 12),
#  ('houses', 12),
#  ('larger', 12),
#  ('structure', 12),
#  ('ground', 12),
#  ('concerned', 12),
#  ('frightening', 12),
#  ('outer', 12),
#  ('canteen', 12),
#  ('cigarette', 12),
#  ('purpose', 12),
#  ('difficulty', 12),
#  ('spoken', 12),
#  ('seeing', 12),
#  ('community', 12),
#  ('anywhere', 12),
#  ('belief', 12),
#  ('burst', 12),
#  ('betrayed', 12),
#  ('subject', 12),
#  ('dictionary', 12),
#  ('ask', 12),
#  ('broke', 12),
#  ('met', 12),
#  ('likely', 12),
#  ('imagined', 12),
#  ('committed', 12),
#  ('laid', 12),
#  ('worst', 12),
#  ('stupid', 12),
#  ('passage', 12),
#  ('constantly', 12),
#  ('holding', 12),
#  ('answer', 12),
#  ('recognized', 12),
#  ('carefully', 12),
#  ('obvious', 12),
#  ('facts', 12),
#  ('masses', 12),
#  ('aside', 12),
#  ('late', 12),
#  ('crowded', 12),
#  ("'em", 12),
#  ('controls', 12),
#  ('forget', 12),
#  ('touch', 12),
#  ('perfectly', 12),
#  ('speakwrite', 12),
#  ('hole', 12),
#  ('africa', 12),
#  ('population', 12),
#  ('close', 12),
#  ('main', 12),
#  ('presently', 12),
#  ('brain', 12),
#  ('getting', 12),
#  ('defeat', 12),
#  ('intelligent', 12),
#  ('tree', 12),
#  ('married', 12),
#  ('imagine', 12),
#  ('empty', 12),
#  ('folly', 12),
#  ('labour', 12),
#  ('square', 12),
#  ('dear', 12),
#  ('officer', 12),
#  ('cage', 12),
#  ('smith', 11),
#  ('surface', 11),
#  ('sank', 11),
#  ('everywhere', 11),
#  ('moreover', 11),
#  ('habit', 11),
#  ('childhood', 11),
#  ('places', 11),
#  ('slogans', 11),
#  ('kitchen', 11),
#  ('leaving', 11),
#  ('bottle', 11),
#  ('red', 11),
#  ('older', 11),
#  ('bought', 11),
#  ('particular', 11),
#  ('possession', 11),
#  ('literally', 11),
#  ('house', 11),
#  ('stream', 11),
#  ('corridor', 11),
#  ('evidently', 11),
#  ('stay', 11),
#  ('screen', 11),
#  ('breaking', 11),
#  ('strange', 11),
#  ('hated', 11),
#  ('kill', 11),
#  ('feelings', 11),
#  ('eye', 11),
#  ('repeated', 11),
#  ('banners', 11),
#  ('raised', 11),
#  ('helpless', 11),
#  ('please', 11),
#  ('ration', 11),
#  ('wearing', 11),
#  ('creature', 11),
#  ('swallowed', 11),
#  ('lips', 11),
#  ('loved', 11),
#  ('bodies', 11),
#  ('promptly', 11),
#  ('capitalists', 11),
#  ('invented', 11),
#  ('destruction', 11),
#  ('original', 11),
#  ('led', 11),
#  ('nearer', 11),
#  ('special', 11),
#  ('settled', 11),
#  ('blade', 11),
#  ('tongue', 11),
#  ('spoke', 11),
#  ('nevertheless', 11),
#  ('solid', 11),
#  ('bloody', 11),
#  ('girls', 11),
#  ('principle', 11),
#  ('force', 11),
#  ('coat', 11),
#  ('rutherford', 11),
#  ('yellow', 11),
#  ('impulse', 11),
#  ('generation', 11),
#  ("'e", 11),
#  ('yard', 11),
#  ('church', 11),
#  ('clement', 11),
#  ('smile', 11),
#  ('twentieth', 11),
#  ('wealth', 11),
#  ('slipped', 10),
#  ('poster', 10),
#  ('varicose', 10),
#  ('metal', 10),
#  ('torn', 10),
#  ('patrols', 10),
#  ('wire', 10),
#  ('sides', 10),
#  ('similar', 10),
#  ('official', 10),
#  ('pen', 10),
#  ('nowadays', 10),
#  ('page', 10),
#  ('ready', 10),
#  ('shot', 10),
#  ('lot', 10),
#  ('eleven', 10),
#  ('fiction', 10),
#  ('atmosphere', 10),
#  ('managed', 10),
#  ('carry', 10),
#  ('spite', 10),
#  ('orthodoxy', 10),
#  ('cubicle', 10),
#  ('machine', 10),
#  ('engaged', 10),
#  ('thin', 10),
#  ('attack', 10),
#  ('covered', 10),
#  ('army', 10),
#  ('generally', 10),
#  ('fresh', 10),
#  ('mention', 10),
#  ('opening', 10),
#  ('contrary', 10),
#  ('avoid', 10),
#  ('uttered', 10),
#  ('horror', 10),
#  ('story', 10),
#  ('event', 10),
#  ('slid', 10),
#  ('altogether', 10),
#  ('invariably', 10),
#  ('majority', 10),
#  ('warm', 10),
#  ('worse', 10),
#  ('using', 10),
#  ('wood', 10),
#  ('hanging', 10),
#  ('month', 10),
#  ('principles', 10),
#  ('shape', 10),
#  ('moving', 10),
#  ('lives', 10),
#  ('woke', 10),
#  ('note', 10),
#  ('fifteen', 10),
#  ('period', 10),
#  ('simple', 10),
#  ('sent', 10),
#  ('destroyed', 10),
#  ('throughout', 10),
#  ('copy', 10),
#  ('clean', 10),
#  ('million', 10),
#  ('arrested', 10),
#  ('triumph', 10),
#  ('finished', 10),
#  ('fire', 10),
#  ('struggle', 10),
#  ('lamp', 10),
#  ('passing', 10),
#  ("'if", 10),
#  ('glasses', 10),
#  ('played', 10),
#  ('ai', 10),
#  ('run', 10),
#  ('wars', 10),
#  ('choose', 10),
#  ('failed', 10),
#  ('interested', 10),
#  ('fixed', 10),
#  ('chance', 10),
#  ('murmured', 10),
#  ('prepared', 10),
#  ('realize', 10),
#  ('happens', 10),
#  ('bench', 10),
#  ('chinless', 10),
#  ('wind', 9),
#  ('prevent', 9),
#  ('wide', 9),
#  ('seldom', 9),
#  ('current', 9),
#  ('somewhat', 9),
#  ('ended', 9),
#  ('posters', 9),
#  ('windows', 9),
#  ('series', 9),
#  ('slavery', 9),
#  ('steel', 9),
#  ('abruptly', 9),
#  ('lunch', 9),
#  ('scarlet', 9),
#  ('cigarettes', 9),
#  ('intended', 9),
#  ('smooth', 9),
#  ('guess', 9),
#  ('quick', 9),
#  ('certainty', 9),
#  ('listen', 9),
#  ('actual', 9),
#  ('panic', 9),
#  ('screaming', 9),
#  ('terror', 9),
#  ('peculiar', 9),
#  ('mixed', 9),
#  ('momentary', 9),
#  ('dozen', 9),
#  ('intelligence', 9),
#  ('monstrous', 9),
#  ...]

# %%
#Turn all words to basic form
basic_form = [ps.stem(word) for word in tokens_low if not word in stopwords + symbols]

#Textを使うためにreviewをlistにぶち込む
basic_form = [basic_form]

#原型に戻した単語で、再び文を再構築する。
text = []
for i in basic_form:
    text.append(nltk.Text(i))
    
#Textからwords listを作る。
for i in text:
    words = [word for word in i]
    
words
# Out:
# ['bright',
#  'cold',
#  'day',
#  'april',
#  'clock',
#  'strike',
#  'thirteen',
#  'winston',
#  'smith',
#  'chin',
#  'nuzzl',
#  'breast',
#  'effort',
#  'escap',
#  'vile',
#  'wind',
#  'slip',
#  'quickli',
#  'glass',
#  'door',
#  'victori',
#  'mansion',
#  'though',
#  'quickli',
#  'enough',
#  'prevent',
#  'swirl',
#  'gritti',
#  'dust',
#  'enter',
#  'along',
#  'hallway',
#  'smelt',
#  'boil',
#  'cabbag',
#  'old',
#  'rag',
#  'mat',
#  'one',
#  'end',
#  'colour',
#  'poster',
#  'larg',
#  'indoor',
#  'display',
#  'tack',
#  'wall',
#  'depict',
#  'simpli',
#  'enorm',
#  'face',
#  'metr',
#  'wide',
#  'face',
#  'man',
#  'forty-f',
#  'heavi',
#  'black',
#  'moustach',
#  'ruggedli',
#  'handsom',
#  'featur',
#  'winston',
#  'made',
#  'stair',
#  'use',
#  'tri',
#  'lift',
#  'even',
#  'best',
#  'time',
#  'seldom',
#  'work',
#  'present',
#  'electr',
#  'current',
#  'cut',
#  'daylight',
#  'hour',
#  'part',
#  'economi',
#  'drive',
#  'prepar',
#  'hate',
#  'week',
#  'flat',
#  'seven',
#  'flight',
#  'winston',
#  'thirty-nin',
#  'varicos',
#  'ulcer',
#  'right',
#  'ankl',
#  'went',
#  'slowli',
#  'rest',
#  'sever',
#  'time',
#  'way',
#  'land',
#  'opposit',
#  'lift-shaft',
#  'poster',
#  'enorm',
#  'face',
#  'gaze',
#  'wall',
#  'one',
#  'pictur',
#  'contriv',
#  'eye',
#  'follow',
#  'move',
#  'big',
#  'brother',
#  'watch',
#  'caption',
#  'beneath',
#  'ran',
#  'insid',
#  'flat',
#  'fruiti',
#  'voic',
#  'read',
#  'list',
#  'figur',
#  'someth',
#  'product',
#  'pig-iron',
#  'voic',
#  'came',
#  'oblong',
#  'metal',
#  'plaqu',
#  'like',
#  'dull',
#  'mirror',
#  'form',
#  'part',
#  'surfac',
#  'right-hand',
#  'wall',
#  'winston',
#  'turn',
#  'switch',
#  'voic',
#  'sank',
#  'somewhat',
#  'though',
#  'word',
#  'still',
#  'distinguish',
#  'instrument',
#  'telescreen',
#  'call',
#  'could',
#  'dim',
#  'way',
#  'shut',
#  'complet',
#  'move',
#  'window',
#  'smallish',
#  'frail',
#  'figur',
#  'meagr',
#  'bodi',
#  'mere',
#  'emphas',
#  'blue',
#  'overal',
#  'uniform',
#  'parti',
#  'hair',
#  'fair',
#  'face',
#  'natur',
#  'sanguin',
#  'skin',
#  'roughen',
#  'coars',
#  'soap',
#  'blunt',
#  'razor',
#  'blade',
#  'cold',
#  'winter',
#  'end',
#  'outsid',
#  'even',
#  'shut',
#  'window-pan',
#  'world',
#  'look',
#  'cold',
#  'street',
#  'littl',
#  'eddi',
#  'wind',
#  'whirl',
#  'dust',
#  'torn',
#  'paper',
#  'spiral',
#  'though',
#  'sun',
#  'shine',
#  'sky',
#  'harsh',
#  'blue',
#  'seem',
#  'colour',
#  'anyth',
#  'except',
#  'poster',
#  'plaster',
#  'everywher',
#  'black-moustachio',
#  'face',
#  'gaze',
#  'everi',
#  'command',
#  'corner',
#  'one',
#  'house-front',
#  'immedi',
#  'opposit',
#  'big',
#  'brother',
#  'watch',
#  'caption',
#  'said',
#  'dark',
#  'eye',
#  'look',
#  'deep',
#  'winston',
#  'street',
#  'level',
#  'anoth',
#  'poster',
#  'torn',
#  'one',
#  'corner',
#  'flap',
#  'fit',
#  'wind',
#  'altern',
#  'cover',
#  'uncov',
#  'singl',
#  'word',
#  'ingsoc',
#  'far',
#  'distanc',
#  'helicopt',
#  'skim',
#  'roof',
#  'hover',
#  'instant',
#  'like',
#  'bluebottl',
#  'dart',
#  'away',
#  'curv',
#  'flight',
#  'polic',
#  'patrol',
#  'snoop',
#  'peopl',
#  'window',
#  'patrol',
#  'matter',
#  'howev',
#  'thought',
#  'polic',
#  'matter',
#  'behind',
#  'winston',
#  'back',
#  'voic',
#  'telescreen',
#  'still',
#  'babbl',
#  'away',
#  'pig-iron',
#  'overfulfil',
#  'ninth',
#  'three-year',
#  'plan',
#  'telescreen',
#  'receiv',
#  'transmit',
#  'simultan',
#  'sound',
#  'winston',
#  'made',
#  'level',
#  'low',
#  'whisper',
#  'would',
#  'pick',
#  'moreov',
#  'long',
#  'remain',
#  'within',
#  'field',
#  'vision',
#  'metal',
#  'plaqu',
#  'command',
#  'could',
#  'seen',
#  'well',
#  'heard',
#  'cours',
#  'way',
#  'know',
#  'whether',
#  'watch',
#  'given',
#  'moment',
#  'often',
#  'system',
#  'thought',
#  'polic',
#  'plug',
#  'individu',
#  'wire',
#  'guesswork',
#  'even',
#  'conceiv',
#  'watch',
#  'everybodi',
#  'time',
#  'rate',
#  'could',
#  'plug',
#  'wire',
#  'whenev',
#  'want',
#  'live',
#  'live',
#  'habit',
#  'becam',
#  'instinct',
#  'assumpt',
#  'everi',
#  'sound',
#  'made',
#  'overheard',
#  'except',
#  'dark',
#  'everi',
#  'movement',
#  'scrutin',
#  'winston',
#  'kept',
#  'back',
#  'turn',
#  'telescreen',
#  'safer',
#  'though',
#  'well',
#  'knew',
#  'even',
#  'back',
#  'reveal',
#  'kilometr',
#  'away',
#  'ministri',
#  'truth',
#  'place',
#  'work',
#  'tower',
#  'vast',
#  'white',
#  'grimi',
#  'landscap',
#  'thought',
#  'sort',
#  'vagu',
#  'distast',
#  'london',
#  'chief',
#  'citi',
#  'airstrip',
#  'one',
#  'third',
#  'popul',
#  'provinc',
#  'oceania',
#  'tri',
#  'squeez',
#  'childhood',
#  'memori',
#  'tell',
#  'whether',
#  'london',
#  'alway',
#  'quit',
#  'like',
#  'alway',
#  'vista',
#  'rot',
#  'nineteenth-centuri',
#  'hous',
#  'side',
#  'shore',
#  'baulk',
#  'timber',
#  'window',
#  'patch',
#  'cardboard',
#  'roof',
#  'corrug',
#  'iron',
#  'crazi',
#  'garden',
#  'wall',
#  'sag',
#  'direct',
#  'bomb',
#  'site',
#  'plaster',
#  'dust',
#  'swirl',
#  'air',
#  'willow-herb',
#  'straggl',
#  'heap',
#  'rubbl',
#  'place',
#  'bomb',
#  'clear',
#  'larger',
#  'patch',
#  'sprung',
#  'sordid',
#  'coloni',
#  'wooden',
#  'dwell',
#  'like',
#  'chicken-hous',
#  'use',
#  'could',
#  'rememb',
#  'noth',
#  'remain',
#  'childhood',
#  'except',
#  'seri',
#  'bright-lit',
#  'tableaux',
#  'occur',
#  'background',
#  'mostli',
#  'unintellig',
#  'ministri',
#  'truth',
#  'minitru',
#  'newspeak',
#  '[',
#  '1',
#  ']',
#  'startlingli',
#  'differ',
#  'object',
#  'sight',
#  'enorm',
#  'pyramid',
#  'structur',
#  'glitter',
#  'white',
#  'concret',
#  'soar',
#  'terrac',
#  'terrac',
#  '300',
#  'metr',
#  'air',
#  'winston',
#  'stood',
#  'possibl',
#  'read',
#  'pick',
#  'white',
#  'face',
#  'eleg',
#  'letter',
#  'three',
#  'slogan',
#  'parti',
#  'war',
#  'peac',
#  'freedom',
#  'slaveri',
#  'ignor',
#  'strength',
#  'ministri',
#  'truth',
#  'contain',
#  'said',
#  'three',
#  'thousand',
#  'room',
#  'ground',
#  'level',
#  'correspond',
#  'ramif',
#  'scatter',
#  'london',
#  'three',
#  'build',
#  'similar',
#  'appear',
#  'size',
#  'complet',
#  'dwarf',
#  'surround',
#  'architectur',
#  'roof',
#  'victori',
#  'mansion',
#  'could',
#  'see',
#  'four',
#  'simultan',
#  'home',
#  'four',
#  'ministri',
#  'entir',
#  'apparatu',
#  'govern',
#  'divid',
#  'ministri',
#  'truth',
#  'concern',
#  'news',
#  'entertain',
#  'educ',
#  'fine',
#  'art',
#  'ministri',
#  'peac',
#  'concern',
#  'war',
#  'ministri',
#  'love',
#  'maintain',
#  'law',
#  'order',
#  'ministri',
#  'plenti',
#  'respons',
#  'econom',
#  'affair',
#  'name',
#  'newspeak',
#  'minitru',
#  'minipax',
#  'miniluv',
#  'miniplenti',
#  'ministri',
#  'love',
#  'realli',
#  'frighten',
#  'one',
#  'window',
#  'winston',
#  'never',
#  'insid',
#  'ministri',
#  'love',
#  'within',
#  'half',
#  'kilometr',
#  'place',
#  'imposs',
#  'enter',
#  'except',
#  'offici',
#  'busi',
#  'penetr',
#  'maze',
#  'barbed-wir',
#  'entangl',
#  'steel',
#  'door',
#  'hidden',
#  'machine-gun',
#  'nest',
#  'even',
#  'street',
#  'lead',
#  'outer',
#  'barrier',
#  'roam',
#  'gorilla-fac',
#  'guard',
#  'black',
#  'uniform',
#  'arm',
#  'joint',
#  'truncheon',
#  'winston',
#  'turn',
#  'round',
#  'abruptli',
#  'set',
#  'featur',
#  'express',
#  'quiet',
#  'optim',
#  'advis',
#  'wear',
#  'face',
#  'telescreen',
#  'cross',
#  'room',
#  'tini',
#  'kitchen',
#  'leav',
#  'ministri',
#  'time',
#  'day',
#  'sacrif',
#  'lunch',
#  'canteen',
#  'awar',
#  'food',
#  'kitchen',
#  'except',
#  'hunk',
#  'dark-colour',
#  'bread',
#  'got',
#  'save',
#  'tomorrow',
#  'breakfast',
#  'took',
#  'shelf',
#  'bottl',
#  'colourless',
#  'liquid',
#  'plain',
#  'white',
#  'label',
#  'mark',
#  'victori',
#  'gin',
#  'gave',
#  'sickli',
#  'oili',
#  'smell',
#  'chines',
#  'rice-spirit',
#  'winston',
#  'pour',
#  'nearli',
#  'teacup',
#  'nerv',
#  'shock',
#  'gulp',
#  'like',
#  'dose',
#  'medicin',
#  'instantli',
#  'face',
#  'turn',
#  'scarlet',
#  'water',
#  'ran',
#  'eye',
#  'stuff',
#  'like',
#  'nitric',
#  'acid',
#  'moreov',
#  'swallow',
#  'one',
#  'sensat',
#  'hit',
#  'back',
#  'head',
#  'rubber',
#  'club',
#  'next',
#  'moment',
#  'howev',
#  'burn',
#  'belli',
#  'die',
#  'world',
#  'began',
#  'look',
#  'cheer',
#  'took',
#  'cigarett',
#  'crumpl',
#  'packet',
#  'mark',
#  'victori',
#  'cigarett',
#  'incauti',
#  'held',
#  'upright',
#  'whereupon',
#  'tobacco',
#  'fell',
#  'floor',
#  'next',
#  'success',
#  'went',
#  'back',
#  'living-room',
#  'sat',
#  'small',
#  'tabl',
#  'stood',
#  'left',
#  'telescreen',
#  'tabl',
#  'drawer',
#  'took',
#  'penhold',
#  'bottl',
#  'ink',
#  'thick',
#  'quarto-s',
#  'blank',
#  'book',
#  'red',
#  'back',
#  'marbl',
#  'cover',
#  'reason',
#  'telescreen',
#  'living-room',
#  'unusu',
#  'posit',
#  'instead',
#  'place',
#  'normal',
#  'end',
#  'wall',
#  'could',
#  'command',
#  'whole',
#  'room',
#  'longer',
#  'wall',
#  'opposit',
#  'window',
#  'one',
#  'side',
#  'shallow',
#  'alcov',
#  'winston',
#  'sit',
#  'flat',
#  'built',
#  'probabl',
#  'intend',
#  'hold',
#  'bookshelv',
#  'sit',
#  'alcov',
#  'keep',
#  'well',
#  'back',
#  'winston',
#  'abl',
#  'remain',
#  'outsid',
#  'rang',
#  'telescreen',
#  'far',
#  'sight',
#  'went',
#  'could',
#  'heard',
#  'cours',
#  'long',
#  'stay',
#  'present',
#  'posit',
#  'could',
#  'seen',
#  'partli',
#  'unusu',
#  'geographi',
#  'room',
#  'suggest',
#  'thing',
#  'also',
#  'suggest',
#  'book',
#  'taken',
#  'drawer',
#  'peculiarli',
#  'beauti',
#  'book',
#  'smooth',
#  'creami',
#  'paper',
#  'littl',
#  'yellow',
#  'age',
#  'kind',
#  'manufactur',
#  'least',
#  'forti',
#  'year',
#  'past',
#  'could',
#  'guess',
#  'howev',
#  'book',
#  'much',
#  'older',
#  'seen',
#  'lie',
#  'window',
#  'frowsi',
#  'littl',
#  'junk-shop',
#  'slummi',
#  'quarter',
#  'town',
#  'quarter',
#  'rememb',
#  'stricken',
#  'immedi',
#  'overwhelm',
#  'desir',
#  'possess',
#  'parti',
#  'member',
#  'suppos',
#  'go',
#  'ordinari',
#  'shop',
#  'deal',
#  'free',
#  'market',
#  'call',
#  'rule',
#  'strictli',
#  'kept',
#  'variou',
#  'thing',
#  'shoelac',
#  'razor',
#  'blade',
#  'imposs',
#  'get',
#  'hold',
#  'way',
#  'given',
#  'quick',
#  'glanc',
#  'street',
#  'slip',
#  'insid',
#  'bought',
#  'book',
#  'two',
#  'dollar',
#  'fifti',
#  'time',
#  'consciou',
#  'want',
#  'particular',
#  'purpos',
#  'carri',
#  'guiltili',
#  'home',
#  'briefcas',
#  'even',
#  'noth',
#  'written',
#  'compromis',
#  'possess',
#  'thing',
#  'open',
#  'diari',
#  'illeg',
#  'noth',
#  'illeg',
#  'sinc',
#  'longer',
#  'law',
#  'detect',
#  'reason',
#  'certain',
#  'would',
#  'punish',
#  'death',
#  'least',
#  'twenty-f',
#  'year',
#  'forced-labour',
#  'camp',
#  'winston',
#  'fit',
#  'nib',
#  'penhold',
#  'suck',
#  'get',
#  'greas',
#  'pen',
#  'archaic',
#  'instrument',
#  'seldom',
#  'use',
#  'even',
#  'signatur',
#  'procur',
#  'one',
#  'furtiv',
#  'difficulti',
#  'simpli',
#  'feel',
#  'beauti',
#  'creami',
#  'paper',
#  'deserv',
#  'written',
#  'real',
#  'nib',
#  'instead',
#  'scratch',
#  'ink-pencil',
#  'actual',
#  'use',
#  'write',
#  'hand',
#  'apart',
#  'short',
#  'note',
#  'usual',
#  'dictat',
#  'everyth',
#  'speak-writ',
#  'cours',
#  'imposs',
#  'present',
#  'purpos',
#  'dip',
#  'pen',
#  'ink',
#  'falter',
#  'second',
#  'tremor',
#  'gone',
#  'bowel',
#  'mark',
#  'paper',
#  'decis',
#  'act',
#  'small',
#  'clumsi',
#  'letter',
#  'wrote',
#  'april',
#  '4th',
#  '1984',
#  'sat',
#  'back',
#  'sens',
#  'complet',
#  'helpless',
#  'descend',
#  'upon',
#  'begin',
#  'know',
#  'certainti',
#  '1984',
#  'must',
#  'round',
#  'date',
#  'sinc',
#  'fairli',
#  'sure',
#  'age',
#  'thirty-nin',
#  'believ',
#  'born',
#  '1944',
#  '1945',
#  'never',
#  'possibl',
#  'nowaday',
#  'pin',
#  'date',
#  'within',
#  'year',
#  'two',
#  ...]

# %%
#Basic に直して、頻度を確認する
freq_list_basic = []
for i in text:
    freq_list_basic.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

#順位チェック
sorted(freq_list_basic[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('winston', 523),
#  ('one', 430),
#  ('could', 402),
#  ('said', 341),
#  ('would', 338),
#  ('even', 327),
#  ('parti', 281),
#  ('time', 250),
#  ('face', 231),
#  ('like', 219),
#  ('thought', 199),
#  ('seem', 192),
#  ("o'brien", 191),
#  ('look', 173),
#  ('never', 171),
#  ('moment', 166),
#  ('know', 160),
#  ('two', 157),
#  ('back', 152),
#  ('thing', 148),
#  ('man', 147),
#  ('still', 146),
#  ('year', 144),
#  ('hand', 144),
#  ('alway', 141),
#  ('eye', 134),
#  ('say', 133),
#  ('war', 130),
#  ('way', 129),
#  ('day', 128),
#  ('happen', 126),
#  ('anoth', 124),
#  ('though', 121),
#  ('might', 118),
#  ('word', 117),
#  ('almost', 117),
#  ('voic', 115),
#  ('make', 115),
#  ('littl', 113),
#  ('work', 112),
#  ('power', 111),
#  ('exist', 111),
#  ('turn', 110),
#  ('long', 109),
#  ('telescreen', 108),
#  ('feel', 108),
#  ('rememb', 107),
#  ('old', 106),
#  ('made', 106),
#  ('peopl', 106),
#  ('knew', 106),
#  ('place', 106),
#  ('see', 106),
#  ('round', 106),
#  ('mind', 106),
#  ('three', 104),
#  ('must', 104),
#  ('come', 102),
#  ('past', 101),
#  ("'i", 101),
#  ('away', 100),
#  ('someth', 97),
#  ('world', 97),
#  ('ever', 97),
#  ('kind', 95),
#  ('julia', 95),
#  ('go', 92),
#  ("'you", 92),
#  ('big', 91),
#  ('bodi', 91),
#  ('perhap', 91),
#  ('without', 91),
#  ('everi', 90),
#  ('end', 87),
#  ('use', 87),
#  ('get', 86),
#  ('think', 86),
#  ('room', 85),
#  ('differ', 81),
#  ('life', 81),
#  ('brother', 79),
#  ('possibl', 79),
#  ('much', 79),
#  ('minut', 79),
#  ('pain', 79),
#  ('noth', 78),
#  ('first', 78),
#  ('girl', 78),
#  ('came', 77),
#  ('call', 77),
#  ('got', 75),
#  ('chang', 75),
#  ('human', 75),
#  ('member', 74),
#  ('hour', 73),
#  ('side', 73),
#  ('anyth', 71),
#  ('mere', 70),
#  ('except', 69),
#  ('sort', 69),
#  ('arm', 69),
#  ('right', 68),
#  ('seen', 68),
#  ('went', 67),
#  ('ministri', 67),
#  ('appear', 67),
#  ('tabl', 67),
#  ('stop', 67),
#  ('head', 66),
#  ('whole', 66),
#  ('live', 65),
#  ('need', 65),
#  ('love', 64),
#  ('alreadi', 64),
#  ('enough', 63),
#  ('four', 63),
#  ('also', 63),
#  ('white', 62),
#  ('memori', 62),
#  ('book', 62),
#  ('lie', 62),
#  ('actual', 62),
#  ('everyth', 62),
#  ('suddenli', 62),
#  ('take', 62),
#  ('sinc', 60),
#  ('continu', 60),
#  ('becom', 60),
#  ('fact', 60),
#  ('mean', 60),
#  ('glass', 59),
#  ('street', 59),
#  ('want', 59),
#  ('second', 59),
#  ('woman', 59),
#  ('tri', 58),
#  ('yet', 58),
#  ("'it", 58),
#  ('well', 57),
#  ('open', 57),
#  ('good', 57),
#  ('put', 57),
#  ('bed', 57),
#  ('oceania', 56),
#  ('quit', 56),
#  ('took', 56),
#  ('small', 56),
#  ('believ', 56),
#  ('far', 55),
#  ('matter', 55),
#  ('act', 55),
#  ('sometim', 55),
#  ('gener', 55),
#  ('behind', 54),
#  ('whether', 54),
#  ('saw', 54),
#  ('piec', 54),
#  ('paper', 53),
#  ('name', 53),
#  ('prole', 53),
#  ('felt', 53),
#  ('confess', 53),
#  ('necessari', 53),
#  ('wall', 52),
#  ('dark', 52),
#  ('sat', 52),
#  ('pass', 52),
#  ('talk', 52),
#  ('control', 52),
#  ('follow', 51),
#  ('week', 50),
#  ('air', 50),
#  ('walk', 50),
#  ('speak', 50),
#  ('simpli', 49),
#  ('hold', 49),
#  ('across', 49),
#  ('cours', 48),
#  ('true', 48),
#  ('men', 48),
#  ('light', 48),
#  ('finger', 48),
#  ('understand', 48),
#  ('part', 47),
#  ('hate', 47),
#  ('hair', 47),
#  ('imposs', 47),
#  ('began', 47),
#  ('sit', 47),
#  ('last', 47),
#  ('give', 47),
#  ('question', 47),
#  ('door', 46),
#  ('victori', 46),
#  ('tell', 46),
#  ('newspeak', 46),
#  ('certain', 46),
#  ('stand', 46),
#  ('heart', 46),
#  ('better', 46),
#  ('new', 46),
#  ("'the", 46),
#  ("'ye", 46),
#  ('larg', 45),
#  ('present', 45),
#  ('complet', 45),
#  ('polic', 45),
#  ('movement', 45),
#  ('keep', 45),
#  ('ago', 45),
#  ('done', 45),
#  ('enorm', 44),
#  ('move', 44),
#  ('outsid', 44),
#  ('upon', 44),
#  ('great', 44),
#  ('toward', 44),
#  ('insid', 43),
#  ('read', 43),
#  ('set', 43),
#  ('death', 43),
#  ('front', 43),
#  ('start', 43),
#  ('person', 43),
#  ("'m", 43),
#  ("'ve", 43),
#  ('five', 43),
#  ('left', 42),
#  ('age', 42),
#  ('children', 42),
#  ('mother', 42),
#  ('black', 41),
#  ('full', 41),
#  ('danger', 41),
#  ('alon', 41),
#  ('less', 41),
#  ('remain', 40),
#  ('reason', 40),
#  ('longer', 40),
#  ('somewher', 40),
#  ('care', 40),
#  ('middl', 40),
#  ('mani', 40),
#  ('parson', 40),
#  ("'re", 40),
#  ('record', 39),
#  ('group', 39),
#  ('enemi', 39),
#  ('watch', 38),
#  ('natur', 38),
#  ('gave', 38),
#  ('floor', 38),
#  ('shall', 38),
#  ('togeth', 38),
#  ('truth', 37),
#  ('occur', 37),
#  ('stood', 37),
#  ('next', 37),
#  ('carri', 37),
#  ('hundr', 37),
#  ('inner', 37),
#  ('eurasia', 37),
#  ('mouth', 37),
#  ('dream', 37),
#  ('opposit', 36),
#  ('realli', 36),
#  ('half', 36),
#  ('guard', 36),
#  ('taken', 36),
#  ('sure', 36),
#  ('import', 36),
#  ('thirti', 36),
#  ('produc', 36),
#  ('soon', 36),
#  ('prison', 36),
#  ('step', 36),
#  ('heard', 35),
#  ('leav', 35),
#  ('probabl', 35),
#  ('real', 35),
#  ('young', 35),
#  ('fear', 35),
#  ('goldstein', 35),
#  ('revolut', 35),
#  ('later', 35),
#  ('notic', 35),
#  ('alter', 35),
#  ('syme', 35),
#  ('bomb', 34),
#  ('water', 34),
#  ('held', 34),
#  ('case', 34),
#  ('shout', 34),
#  ('evid', 34),
#  ('lay', 34),
#  ('brought', 34),
#  ('interest', 34),
#  ('dead', 34),
#  ('ten', 34),
#  ('window', 33),
#  ('sound', 33),
#  ('within', 33),
#  ('kept', 33),
#  ('gin', 33),
#  ('rule', 33),
#  ('gone', 33),
#  ('near', 33),
#  ('eastasia', 33),
#  ('els', 33),
#  ("'ll", 33),
#  ('histori', 33),
#  ('us', 33),
#  ('cell', 33),
#  ('smell', 32),
#  ('usual', 32),
#  ('idea', 32),
#  ('realiti', 32),
#  ('crowd', 32),
#  ('whose', 32),
#  ('howev', 31),
#  ('pick', 31),
#  ('point', 31),
#  ('imagin', 31),
#  ('shoulder', 31),
#  ('line', 31),
#  ('meet', 31),
#  ('physic', 31),
#  ('societi', 31),
#  ('figur', 30),
#  ('vagu', 30),
#  ('direct', 30),
#  ('suppos', 30),
#  ('futur', 30),
#  ('run', 30),
#  ('top', 30),
#  ('known', 30),
#  ("'we", 30),
#  ('effort', 29),
#  ('sever', 29),
#  ('immedi', 29),
#  ('abl', 29),
#  ('written', 29),
#  ('wonder', 29),
#  ('night', 29),
#  ('let', 29),
#  ('fill', 29),
#  ('kill', 29),
#  ('comrad', 29),
#  ('process', 29),
#  ('push', 29),
#  ('told', 29),
#  ('number', 29),
#  ("'what", 29),
#  ('overal', 28),
#  ('corner', 28),
#  ('thousand', 28),
#  ('die', 28),
#  ('diari', 28),
#  ('write', 28),
#  ('short', 28),
#  ('sens', 28),
#  ('doublethink', 28),
#  ('depart', 28),
#  ('women', 28),
#  ('aliv', 28),
#  ('may', 28),
#  ('deep', 27),
#  ('becam', 27),
#  ('contain', 27),
#  ('nearli', 27),
#  ('glanc', 27),
#  ('either', 27),
#  ('nose', 27),
#  ('realiz', 27),
#  ('disappear', 27),
#  ('everyon', 27),
#  ('feet', 27),
#  ('sleep', 27),
#  ('close', 27),
#  ('mass', 27),
#  ('cloth', 27),
#  ("'that", 27),
#  ('shut', 26),
#  ('instinct', 26),
#  ('london', 26),
#  ('order', 26),
#  ('quarter', 26),
#  ('final', 26),
#  ('among', 26),
#  ('job', 26),
#  ('spi', 26),
#  ('hope', 26),
#  ('exactli', 26),
#  ('boot', 26),
#  ('hatr', 26),
#  ('ca', 26),
#  ('fight', 26),
#  ('earlier', 26),
#  ('knee', 26),
#  ('centuri', 26),
#  ('metr', 25),
#  ('ingsoc', 25),
#  ('given', 25),
#  ('often', 25),
#  ('home', 25),
#  ('fell', 25),
#  ('beauti', 25),
#  ('boy', 25),
#  ('conscious', 25),
#  ('tear', 25),
#  ('whatev', 25),
#  ('touch', 25),
#  ('destroy', 25),
#  ("'no", 25),
#  ('heavi', 24),
#  ('instant', 24),
#  ('object', 24),
#  ('awar', 24),
#  ('begin', 24),
#  ('although', 24),
#  ('show', 24),
#  ('morn', 24),
#  ('somehow', 24),
#  ('press', 24),
#  ('betray', 24),
#  ('struck', 24),
#  ('found', 24),
#  ('secret', 24),
#  ('messag', 24),
#  ('month', 24),
#  ('answer', 24),
#  ('earli', 24),
#  ('ad', 24),
#  ('sing', 24),
#  ('charrington', 24),
#  ('hous', 23),
#  ('freedom', 23),
#  ('possess', 23),
#  ('consciou', 23),
#  ('listen', 23),
#  ('forgotten', 23),
#  ('spectacl', 23),
#  ('intellig', 23),
#  ('ask', 23),
#  ('help', 23),
#  ('hardli', 23),
#  ('six', 23),
#  ('knowledg', 23),
#  ('countri', 23),
#  ('million', 23),
#  ('learn', 23),
#  ('bell', 23),
#  ('poster', 22),
#  ('flat', 22),
#  ('gaze', 22),
#  ('pictur', 22),
#  ('clear', 22),
#  ('peac', 22),
#  ('express', 22),
#  ('stuff', 22),
#  ('desir', 22),
#  ('date', 22),
#  ('music', 22),
#  ('chair', 22),
#  ('cri', 22),
#  ('besid', 22),
#  ('brotherhood', 22),
#  ('tortur', 22),
#  ('paus', 22),
#  ('hear', 22),
#  ('fall', 22),
#  ("'d", 22),
#  ('float', 22),
#  ('broken', 22),
#  ('difficult', 22),
#  ('coffe', 22),
#  ('cold', 21),
#  ('rest', 21),
#  ('form', 21),
#  ('cover', 21),
#  ('singl', 21),
#  ('individu', 21),
#  ('sight', 21),
#  ('cigarett', 21),
#  ('easi', 21),
#  ('eurasian', 21),
#  ('caught', 21),
#  ('arrest', 21),
#  ('commit', 21),
#  ('pocket', 21),
#  ('principl', 21),
#  ('recogn', 21),
#  ('drop', 21),
#  ('stir', 21),
#  ("'and", 21),
#  ('pull', 21),
#  ('photograph', 21),
#  ("'do", 21),
#  ('dust', 20),
#  ('prepar', 20),
#  ('skin', 20),
#  ('vast', 20),
#  ('frighten', 20),
#  ('tini', 20),
#  ('posit', 20),
#  ('shop', 20),
#  ('fifti', 20),
#  ('lost', 20),
#  ('equal', 20),
#  ('today', 20),
#  ('bring', 20),
#  ('impress', 20),
#  ('polit', 20),
#  ('crime', 20),
#  ('break', 20),
#  ('grow', 20),
#  ('subject', 20),
#  ('violent', 20),
#  ('utter', 20),
#  ('ye', 20),
#  ('yell', 20),
#  ('sister', 20),
#  ('rais', 20),
#  ('meant', 20),
#  ('chocol', 20),
#  ('silent', 20),
#  ('tree', 20),
#  ('bit', 20),
#  ('period', 20),
#  ('expect', 20),
#  ('play', 20),
#  ('aim', 20),
#  ('defeat', 20),
#  ('grown', 20),
#  ('afternoon', 20),
#  ('high', 20),
#  ('rat', 20),
#  ('colour', 19),
#  ('cut', 19),
#  ('blade', 19),
#  ('low', 19),
#  ('slogan', 19),
#  ('law', 19),
#  ('wear', 19),
#  ('food', 19),
#  ('stay', 19),
#  ('helpless', 19),
#  ('commun', 19),
#  ('curiou', 19),
#  ('child', 19),
#  ('beyond', 19),
#  ('state', 19),
#  ('shoot', 19),
#  ('murmur', 19),
#  ('faint', 19),
#  ('vapor', 19),
#  ('stupid', 19),
#  ('breath', 19),
#  ('youth', 19),
#  ('organ', 19),
#  ('forc', 19),
#  ('public', 19),
#  ('invent', 19),
#  ('allow', 19),
#  ('bone', 19),
#  ('dial', 19),
#  ('slip', 18),
#  ('sun', 18),
#  ('distanc', 18),
#  ('swallow', 18),
#  ('normal', 18),
#  ('purpos', 18),
#  ('wrote', 18),
#  ('hole', 18),
#  ('kick', 18),
#  ('nobodi', 18),
#  ('coupl', 18),
#  ('speech', 18),
#  ('edg', 18),
#  ('wait', 18),
#  ('forward', 18),
#  ('event', 18),
#  ('sweat', 18),
#  ('fragment', 18),
#  ('find', 18),
#  ('pure', 18),
#  ('accept', 18),
#  ("'there", 18),
#  ('smile', 18),
#  ('grew', 18),
#  ('wish', 18),
#  ('seven', 17),
#  ('slowli', 17),
#  ('blue', 17),
#  ('level', 17),
#  ('rate', 17),
#  ('build', 17),
#  ('bread', 17),
#  ('save', 17),
#  ('free', 17),
#  ('huge', 17),
#  ('centr', 17),
#  ('gestur', 17),
#  ('belief', 17),
#  ('inde', 17),
#  ('teeth', 17),
#  ('occasion', 17),
#  ('emot', 17),
#  ('slightli', 17),
#  ('anim', 17),
#  ('issu', 17),
#  ('hang', 17),
#  ('blow', 17),
#  ('twenti', 17),
#  ('intellectu', 17),
#  ('empti', 17),
#  ('struggl', 17),
#  ('definit', 17),
#  ('earth', 17),
#  ('claim', 17),
#  ('reach', 17),
#  ('class', 17),
#  ('ear', 17),
#  ('problem', 17),
#  ('easili', 17),
#  ('katharin', 17),
#  ('st', 17),
#  ('clock', 16),
#  ('breast', 16),
#  ('quickli', 16),
#  ('simultan', 16),
#  ('habit', 16),
#  ('popul', 16),
#  ('news', 16),
#  ('belli', 16),
#  ('thick', 16),
#  ('instead', 16),
#  ('least', 16),
#  ('doubt', 16),
#  ('militari', 16),
#  ('stream', 16),
#  ('corridor', 16),
#  ('manner', 16),
#  ('demand', 16),
#  ('terribl', 16),
#  ('straight', 16),
#  ('flung', 16),
#  ('roar', 16),
#  ('sooner', 16),
#  ('repeat', 16),
#  ('someon', 16),
#  ("'they", 16),
#  ('rocket', 16),
#  ('shape', 16),
#  ('strong', 16),
#  ('therefor', 16),
#  ('bare', 16),
#  ('forth', 16),
#  ('tube', 16),
#  ('forget', 16),
#  ('capitalist', 16),
#  ('agre', 16),
#  ('copi', 16),
#  ('till', 16),
#  ('pavement', 16),
#  ('effect', 16),
#  ('along', 15),
#  ('ran', 15),
#  ('razor', 15),
#  ('fit', 15),
#  ('helicopt', 15),
#  ('ignor', 15),
#  ('strength', 15),
#  ('cross', 15),
#  ('pour', 15),
#  ('apart', 15),
#  ('note', 15),
#  ('origin', 15),
#  ('dare', 15),
#  ('rubbish', 15),
#  ('waist', 15),
#  ('curious', 15),
#  ('burst', 15),
#  ('march', 15),
#  ('mention', 15),
#  ('deliber', 15),
#  ('convers', 15),
#  ('common', 15),
#  ('unconsci', 15),
#  ('song', 15),
#  ('remark', 15),
#  ('eat', 15),
#  ('offic', 15),
#  ('special', 15),
#  ('brain', 15),
#  ("'how", 15),
#  ('chanc', 15),
#  ('coat', 15),
#  ('astonish', 15),
#  ('fail', 15),
#  ('super-st', 15),
#  ('101', 15),
#  ('beneath', 14),
#  ('product', 14),
#  ('metal', 14),
#  ('uniform', 14),
#  ('concern', 14),
#  ('plenti', 14),
#  ('hidden', 14),
#  ('partli', 14),
#  ('suggest', 14),
#  ('ordinari', 14),
#  ('difficulti', 14),
#  ('liter', 14),
#  ('caus', 14),
#  ('narrow', 14),
#  ('leagu', 14),
#  ('anyon', 14),
#  ('capabl', 14),
#  ('draw', 14),
#  ('wife', 14),
#  ('game', 14),
#  ('dirti', 14),
#  ('filthi', 14),
#  ("'a", 14),
#  ('attent', 14),
#  ('bad', 14),
#  ('fro', 14),
#  ('wander', 14),
#  ('creatur', 14),
#  ('rather', 14),
#  ('instanc', 14),
#  ('surpris', 14),
#  ('opinion', 14),
#  ('perman', 14),
#  ('roll', 14),
#  ('happi', 14),
#  ('obvious', 14),
#  ('practic', 14),
#  ('accord', 14),
#  ('choos', 14),
#  ('paperweight', 14),
#  ('safe', 14),
#  ('cheek', 14),
#  ('sky', 13),
#  ('vision', 13),
#  ('entir', 13),
#  ('govern', 13),
#  ('success', 13),
#  ('born', 13),
#  ('scream', 13),
#  ('flash', 13),
#  ('cubicl', 13),
#  ('machin', 13),
#  ('brien', 13),
#  ('neck', 13),
#  ('civil', 13),
#  ('endless', 13),
#  ('newspap', 13),
#  ('refer', 13),
#  ('rose', 13),
#  ('wave', 13),
#  ('lunat', 13),
#  ('discov', 13),
#  ('action', 13),
#  ('hard', 13),
#  ('report', 13),
#  ('banner', 13),
#  ('pleas', 13),
#  ('ration', 13),
#  ('asleep', 13),
#  ('appeal', 13),
#  ('detail', 13),
#  ('interv', 13),
#  ('belong', 13),
#  ('return', 13),
#  ('late', 13),
#  ('fallen', 13),
#  ('station', 13),
#  ('grasp', 13),
#  ('exampl', 13),
#  ('sixti', 13),
#  ('speakwrit', 13),
#  ('wrong', 13),
#  ('ampleforth', 13),
#  ('rhyme', 13),
#  ('standard', 13),
#  ('drink', 13),
#  ('clasp', 13),
#  ('beer', 13),
#  ('impuls', 13),
#  ('labour', 13),
#  ("'but", 13),
#  ('fix', 13),
#  ('church', 13),
#  ('martin', 13),
#  ('squar', 13),
#  ('escap', 12),
#  ('best', 12),
#  ('surfac', 12),
#  ('command', 12),
#  ('patrol', 12),
#  ('plan', 12),
#  ('system', 12),
#  ('everybodi', 12),
#  ('whenev', 12),
#  ('kilometr', 12),
#  ('larger', 12),
#  ('structur', 12),
#  ('ground', 12),
#  ('surround', 12),
#  ('offici', 12),
#  ('outer', 12),
#  ('canteen', 12),
#  ('bottl', 12),
#  ('yellow', 12),
#  ('page', 12),
#  ('capit', 12),
#  ('comfort', 12),
#  ('suffer', 12),
#  ('spoken', 12),
#  ('anywher', 12),
#  ('approach', 12),
#  ('thin', 12),
#  ('armi', 12),
#  ('smash', 12),
#  ('stori', 12),
#  ('dictionari', 12),
#  ('heret', 12),
#  ('advanc', 12),
#  ('fade', 12),
#  ('broke', 12),
#  ('slow', 12),
#  ('met', 12),
#  ('execut', 12),
#  ('conceal', 12),
#  ('trial', 12),
#  ('laid', 12),
#  ('worst', 12),
#  ('sink', 12),
#  ('passag', 12),
#  ('constantli', 12),
#  ('clean', 12),
#  ('announc', 12),
#  ('obviou', 12),
#  ('asid', 12),
#  ("'em", 12),
#  ('aeroplan', 12),
#  ('perfectli', 12),
#  ('destruct', 12),
#  ('africa', 12),
#  ('materi', 12),
#  ('settl', 12),
#  ('main', 12),
#  ('assum', 12),
#  ('finish', 12),
#  ('train', 12),
#  ('fire', 12),
#  ('marri', 12),
#  ('condit', 12),
#  ('area', 12),
#  ('folli', 12),
#  ('buy', 12),
#  ('ceas', 12),
#  ('dear', 12),
#  ('mental', 12),
#  ('cage', 12),
#  ('smith', 11),
#  ('prevent', 11),
#  ('lift', 11),
#  ('sank', 11),
#  ('plaster', 11),
#  ('everywher', 11),
#  ('moreov', 11),
#  ('wire', 11),
#  ('childhood', 11),
#  ('kitchen', 11),
#  ('red', 11),
#  ('intend', 11),
#  ('older', 11),
#  ('bought', 11),
#  ('particular', 11),
#  ('readi', 11),
#  ('film', 11),
#  ('shot', 11),
#  ('drag', 11),
#  ('manag', 11),
#  ('recal', 11),
#  ('screen', 11),
#  ('engag', 11),
#  ('activ', 11),
#  ('foreign', 11),
#  ('attack', 11),
#  ('denounc', 11),
#  ('vanish', 11),
#  ('terrifi', 11),
#  ('strang', 11),
#  ('avoid', 11),
#  ('wrench', 11),
#  ('horror', 11),
#  ('lavatori', 11),
#  ('contact', 11),
#  ('essenti', 11),
#  ('seiz', 11),
#  ('hurri', 11),
#  ('attempt', 11),
#  ('demonstr', 11),
#  ('wood', 11),
#  ('dress', 11),
#  ('surviv', 11),
#  ('babi', 11),
#  ('privat', 11),
#  ('lip', 11),
#  ('leg', 11),
#  ('trust', 11),
#  ('absolut', 11),
#  ('promptli', 11),
#  ('ultim', 11),
#  ('involv', 11),
#  ('scrap', 11),
#  ('led', 11),
#  ('nearer', 11),
#  ('triumph', 11),
#  ('refus', 11),
#  ('tray', 11),
#  ('tongu', 11),
#  ('spoke', 11),
#  ('nevertheless', 11),
#  ('solid', 11),
#  ('bloodi', 11),
#  ('tast', 11),
#  ('elbow', 11),
#  ('lamp', 11),
#  ('achiev', 11),
#  ('servant', 11),
#  ('rutherford', 11),
#  ('murder', 11),
#  ("'e", 11),
#  ('suicid', 11),
#  ('soft', 11),
#  ('pretend', 11),
#  ('yard', 11),
#  ('clement', 11),
#  ('develop', 11),
#  ('meal', 11),
#  ('conquer', 11),
#  ('attitud', 11),
#  ('twentieth', 11),
#  ('wealth', 11),
#  ('rag', 10),
#  ('current', 10),
#  ('varicos', 10),
#  ('land', 10),
#  ('switch', 10),
#  ('instrument', 10),
#  ('coars', 10),
#  ('torn', 10),
#  ('receiv', 10),
#  ('iron', 10),
#  ('similar', 10),
#  ('mark', 10),
#  ('sensat', 10),
#  ('packet', 10),
#  ('smooth', 10),
#  ('guess', 10),
#  ('deal', 10),
#  ('pen', 10),
#  ('nowaday', 10),
#  ('unbear', 10),
#  ('panic', 10),
#  ('lot', 10),
#  ('decid', 10),
#  ('eleven', 10),
#  ('fiction', 10),
#  ('atmospher', 10),
#  ('hike', 10),
#  ('spite', 10),
#  ('dozen', 10),
#  ('orthodoxi', 10),
#  ('mysteri', 10),
#  ('traitor', 10),
#  ('doctrin', 10),
#  ('fresh', 10),
#  ('horribl', 10),
#  ('contrari', 10),
#  ('backward', 10),
#  ('battl', 10),
#  ('slid', 10),
#  ('altogeth', 10),
#  ('invari', 10),
#  ('shake', 10),
#  ('major', 10),
#  ('warm', 10),
#  ('block', 10),
#  ('motiv', 10),
#  ('committe', 10),
#  ('wors', 10),
#  ('thought-crimin', 10),
#  ('send', 10),
#  ('flit', 10),
#  ...]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#文章を小文字化
sentence_small = [w.lower() for w in sentence1]

#いけそう。文ごとに取り出し、それぞれの単語を原型に戻す。それを再び再構築する！
form_sent = []
for sentence in sentence_small:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    form_sent.append(" ".join(form))
    
    
#ピリオドやカンマを消しまーす。Delte period and comma...めんどい...
form_sent2 = []

for i in form_sent:
    tokens = nltk.word_tokenize(i)
    form = [word for word in tokens if not word in stopwords + symbols]
    form_sent2.append(" ".join(form))
    
    
#次にこの新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化したい
text = []

for i in form_sent2:
    tokens = nltk.word_tokenize(i)
    for j in tokens:
        text.append(j)
        
text = [text]

# %%
#新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化

import matplotlib.pyplot as plt
# %matplotlib inline

f_list_new = []
for i in text:
    f_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in f_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
log_freq  = []
for i in f_list_new[0].values():
    log_freq.append(i)

#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_freq, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('freq(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#順位チェック
sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('winston', 523),
#  ('one', 412),
#  ('could', 402),
#  ('said', 341),
#  ('would', 338),
#  ('even', 320),
#  ('time', 227),
#  ('face', 219),
#  ('like', 218),
#  ('parti', 199),
#  ('thought', 191),
#  ("o'brien", 191),
#  ('seem', 187),
#  ('look', 172),
#  ('never', 169),
#  ('moment', 163),
#  ('two', 157),
#  ('know', 155),
#  ('back', 152),
#  ('man', 147),
#  ('still', 145),
#  ('alway', 133),
#  ('thing', 129),
#  ('way', 126),
#  ('war', 124),
#  ('hand', 122),
#  ('though', 121),
#  ('might', 118),
#  ('almost', 117),
#  ('say', 115),
#  ('make', 114),
#  ('long', 109),
#  ('day', 107),
#  ('old', 106),
#  ('made', 106),
#  ('littl', 106),
#  ('knew', 106),
#  ('see', 106),
#  ('round', 106),
#  ('year', 106),
#  ('power', 106),
#  ('turn', 104),
#  ('must', 104),
#  ('place', 103),
#  ('mind', 103),
#  ('three', 102),
#  ('past', 101),
#  ('away', 100),
#  ('work', 99),
#  ('world', 97),
#  ('ever', 97),
#  ('telescreen', 96),
#  ('come', 96),
#  ('julia', 95),
#  ('eye', 94),
#  ('word', 94),
#  ("'i", 94),
#  ('kind', 92),
#  ('big', 91),
#  ('feel', 91),
#  ('without', 91),
#  ('everi', 90),
#  ('someth', 89),
#  ('go', 89),
#  ('anoth', 87),
#  ('rememb', 87),
#  ('get', 85),
#  ("'you", 85),
#  ('use', 84),
#  ('room', 84),
#  ('perhap', 84),
#  ('end', 83),
#  ('party', 82),
#  ('peopl', 82),
#  ('life', 81),
#  ('voic', 80),
#  ('happen', 80),
#  ('brother', 79),
#  ('much', 79),
#  ('first', 78),
#  ('pain', 77),
#  ('think', 77),
#  ('came', 76),
#  ('exist', 76),
#  ('got', 75),
#  ('girl', 75),
#  ('human', 73),
#  ('side', 70),
#  ('mere', 69),
#  ('sort', 69),
#  ('right', 68),
#  ('seen', 68),
#  ('went', 67),
#  ('except', 67),
#  ('whole', 66),
#  ('head', 64),
#  ('enough', 63),
#  ('also', 63),
#  ('white', 62),
#  ('four', 62),
#  ('love', 62),
#  ('call', 62),
#  ('take', 61),
#  ('ministri', 60),
#  ('arm', 60),
#  ('sinc', 60),
#  ('woman', 59),
#  ('becom', 59),
#  ('want', 58),
#  ('possibl', 58),
#  ('member', 58),
#  ('yet', 58),
#  ("'it", 58),
#  ('hour', 58),
#  ('glass', 57),
#  ('well', 57),
#  ('noth', 57),
#  ('chang', 57),
#  ('put', 57),
#  ('bed', 57),
#  ('tri', 56),
#  ('bodi', 56),
#  ('oceania', 56),
#  ('appear', 56),
#  ('took', 56),
#  ('need', 56),
#  ('fact', 56),
#  ('street', 55),
#  ('far', 55),
#  ('quit', 55),
#  ('small', 55),
#  ('suddenli', 55),
#  ('behind', 54),
#  ('whether', 54),
#  ('differ', 54),
#  ('actual', 54),
#  ('act', 54),
#  ('minut', 54),
#  ('good', 53),
#  ('saw', 53),
#  ('felt', 53),
#  ('live', 52),
#  ('sat', 52),
#  ('anyth', 52),
#  ('stop', 52),
#  ('sometim', 52),
#  ('talk', 52),
#  ('mean', 52),
#  ('lie', 51),
#  ('control', 51),
#  ('air', 50),
#  ('alreadi', 50),
#  ('walk', 50),
#  ('simpli', 49),
#  ('open', 49),
#  ('continu', 49),
#  ('across', 49),
#  ('paper', 48),
#  ('matter', 48),
#  ('hold', 48),
#  ('everyth', 48),
#  ('name', 48),
#  ('true', 48),
#  ('men', 48),
#  ('wall', 47),
#  ('hate', 47),
#  ('hair', 47),
#  ('began', 47),
#  ('book', 47),
#  ('believ', 47),
#  ('light', 47),
#  ('give', 47),
#  ('necessari', 47),
#  ('newspeak', 46),
#  ('certain', 46),
#  ('last', 46),
#  ('new', 46),
#  ('understand', 46),
#  ("'yes", 46),
#  ('tell', 45),
#  ('sit', 45),
#  ('second', 45),
#  ('ago', 45),
#  ('heart', 45),
#  ('better', 45),
#  ('confess', 45),
#  ('done', 45),
#  ("'the", 45),
#  ('week', 44),
#  ('keep', 44),
#  ('upon', 44),
#  ('great', 44),
#  ('toward', 44),
#  ('set', 43),
#  ('front', 43),
#  ('gener', 43),
#  ("'m", 43),
#  ('door', 42),
#  ('present', 42),
#  ('memori', 42),
#  ('left', 42),
#  ('children', 42),
#  ('stand', 42),
#  ('five', 42),
#  ('part', 41),
#  ('follow', 41),
#  ('move', 41),
#  ('insid', 41),
#  ('complet', 41),
#  ('death', 41),
#  ('full', 41),
#  ('pass', 41),
#  ('person', 41),
#  ('less', 41),
#  ('mother', 41),
#  ('speak', 41),
#  ('enorm', 40),
#  ('black', 40),
#  ('dark', 40),
#  ('eyes', 40),
#  ('longer', 40),
#  ('remain', 39),
#  ('tabl', 39),
#  ('piec', 39),
#  ('question', 39),
#  ('gave', 38),
#  ('floor', 38),
#  ('years', 38),
#  ('somewher', 38),
#  ('mani', 38),
#  ('shall', 38),
#  ('stood', 37),
#  ('next', 37),
#  ('start', 37),
#  ('group', 37),
#  ('inner', 37),
#  ('eurasia', 37),
#  ('another', 37),
#  ('truth', 36),
#  ('occur', 36),
#  ('half', 36),
#  ('reason', 36),
#  ('taken', 36),
#  ('carri', 36),
#  ('care', 36),
#  ('soon', 36),
#  ('read', 35),
#  ('heard', 35),
#  ('movement', 35),
#  ('age', 35),
#  ('prole', 35),
#  ('young', 35),
#  ('later', 35),
#  ('syme', 35),
#  ('larg', 34),
#  ('watch', 34),
#  ('imposs', 34),
#  ('water', 34),
#  ('held', 34),
#  ('real', 34),
#  ('sure', 34),
#  ('record', 34),
#  ('goldstein', 34),
#  ('lay', 34),
#  ('brought', 34),
#  ('dream', 34),
#  ('dead', 34),
#  ('ten', 34),
#  ('within', 33),
#  ('kept', 33),
#  ('gin', 33),
#  ('gone', 33),
#  ('case', 33),
#  ('fear', 33),
#  ('eastasia', 33),
#  ('mouth', 33),
#  ('step', 33),
#  ('us', 33),
#  ('natur', 32),
#  ('sound', 32),
#  ('realli', 32),
#  ('smell', 32),
#  ('usual', 32),
#  ('middl', 32),
#  ('danger', 32),
#  ('near', 32),
#  ('whose', 32),
#  ('victori', 31),
#  ('pick', 31),
#  ('bomb', 31),
#  ('voice', 31),
#  ('produc', 31),
#  ('finger', 31),
#  ('hundr', 31),
#  ('cell', 31),
#  ('opposit', 30),
#  ('probabl', 30),
#  ('point', 30),
#  ('idea', 30),
#  ('top', 30),
#  ('known', 30),
#  ("'ll", 30),
#  ('effort', 29),
#  ('window', 29),
#  ('outsid', 29),
#  ('rule', 29),
#  ('written', 29),
#  ('night', 29),
#  ('let', 29),
#  ('shout', 29),
#  ('fill', 29),
#  ('thirti', 29),
#  ('happened', 29),
#  ('interest', 29),
#  ('crowd', 29),
#  ('told', 29),
#  ("'what", 29),
#  ('sever', 28),
#  ('leav', 28),
#  ('suppos', 28),
#  ('doublethink', 28),
#  ('women', 28),
#  ('evid', 28),
#  ('table', 28),
#  ('may', 28),
#  ('physic', 28),
#  ('push', 28),
#  ('body', 28),
#  ('prison', 28),
#  ('corner', 27),
#  ('deep', 27),
#  ('becam', 27),
#  ('nearli', 27),
#  ('abl', 27),
#  ('either', 27),
#  ('feet', 27),
#  ('sleep', 27),
#  ('line', 27),
#  ('notic', 27),
#  ("'that", 27),
#  ('london', 26),
#  ('thousand', 26),
#  ('guard', 26),
#  ('course', 26),
#  ('wonder', 26),
#  ('among', 26),
#  ('nose', 26),
#  ('kill', 26),
#  ('shoulder', 26),
#  ('ca', 26),
#  ('earlier', 26),
#  ('shut', 25),
#  ('ingsoc', 25),
#  ('given', 25),
#  ('often', 25),
#  ('fell', 25),
#  ('quarter', 25),
#  ('short', 25),
#  ('boy', 25),
#  ('mass', 25),
#  ("'we", 25),
#  ('meet', 25),
#  ('number', 25),
#  ("'no", 25),
#  ('immedi', 24),
#  ('instant', 24),
#  ('polic', 24),
#  ('people', 24),
#  ('home', 24),
#  ('run', 24),
#  ('although', 24),
#  ('hope', 24),
#  ('somehow', 24),
#  ('contain', 24),
#  ('boot', 24),
#  ('struck', 24),
#  ('everyon', 24),
#  ('histori', 24),
#  ('process', 24),
#  ('charrington', 24),
#  ('vagu', 23),
#  ('freedom', 23),
#  ('order', 23),
#  ('die', 23),
#  ('glanc', 23),
#  ('write', 23),
#  ('forgotten', 23),
#  ('job', 23),
#  ('enemi', 23),
#  ('words', 23),
#  ('found', 23),
#  ('ask', 23),
#  ('help', 23),
#  ('els', 23),
#  ('hardli', 23),
#  ('parson', 23),
#  ('six', 23),
#  ('times', 23),
#  ('touch', 23),
#  ('metr', 22),
#  ('gaze', 22),
#  ('however', 22),
#  ('cours', 22),
#  ('instinct', 22),
#  ('stuff', 22),
#  ('date', 22),
#  ('listen', 22),
#  ('music', 22),
#  ('show', 22),
#  ('import', 22),
#  ('press', 22),
#  ('exactli', 22),
#  ('brotherhood', 22),
#  ('secret', 22),
#  ('nothing', 22),
#  ('fall', 22),
#  ('close', 22),
#  ("'d", 22),
#  ('float', 22),
#  ('whatev', 22),
#  ('broken', 22),
#  ('difficult', 22),
#  ('learn', 22),
#  ('singl', 21),
#  ('sight', 21),
#  ('begin', 21),
#  ('police', 21),
#  ('alone', 21),
#  ('betray', 21),
#  ('eurasian', 21),
#  ('direct', 21),
#  ('realiz', 21),
#  ('hands', 21),
#  ('hear', 21),
#  ('caught', 21),
#  ('imagin', 21),
#  ('pocket', 21),
#  ('obvious', 21),
#  ('days', 21),
#  ('fight', 21),
#  ("'and", 21),
#  ('societi', 21),
#  ("'do", 21),
#  ('cold', 20),
#  ('dust', 20),
#  ('rest', 20),
#  ('figur', 20),
#  ('form', 20),
#  ('skin', 20),
#  ('cover', 20),
#  ('vast', 20),
#  ('object', 20),
#  ('possess', 20),
#  ('lost', 20),
#  ('final', 20),
#  ('today', 20),
#  ('realiti', 20),
#  ('break', 20),
#  ('conscious', 20),
#  ('sister', 20),
#  ('meant', 20),
#  ('drop', 20),
#  ('silent', 20),
#  ('bit', 20),
#  ('ad', 20),
#  ('pull', 20),
#  ('togeth', 20),
#  ('alter', 20),
#  ('grown', 20),
#  ('afternoon', 20),
#  ('alon', 20),
#  ('bell', 20),
#  ('high', 20),
#  ('heavi', 19),
#  ('cut', 19),
#  ('flat', 19),
#  ('anything', 19),
#  ('low', 19),
#  ('clear', 19),
#  ('wear', 19),
#  ('awar', 19),
#  ('food', 19),
#  ('stay', 19),
#  ('shop', 19),
#  ('things', 19),
#  ('consciou', 19),
#  ('child', 19),
#  ('equal', 19),
#  ('chair', 19),
#  ('bring', 19),
#  ('beyond', 19),
#  ('revolut', 19),
#  ('grow', 19),
#  ('possible', 19),
#  ('shoot', 19),
#  ('yes', 19),
#  ('tear', 19),
#  ('youth', 19),
#  ('rais', 19),
#  ('answer', 19),
#  ('recogn', 19),
#  ('period', 19),
#  ('earli', 19),
#  ('public', 19),
#  ('allow', 19),
#  ('aim', 19),
#  ('prepar', 18),
#  ('sun', 18),
#  ('law', 18),
#  ('express', 18),
#  ('swallow', 18),
#  ('normal', 18),
#  ('beauti', 18),
#  ('wrote', 18),
#  ('sens', 18),
#  ('commun', 18),
#  ('nobodi', 18),
#  ('coupl', 18),
#  ('aliv', 18),
#  ('forward', 18),
#  ('messag', 18),
#  ('breath', 18),
#  ('sweat', 18),
#  ('fragment', 18),
#  ('find', 18),
#  ('minutes', 18),
#  ('cloth', 18),
#  ('together', 18),
#  ('pure', 18),
#  ("'there", 18),
#  ('knee', 18),
#  ('expect', 18),
#  ('million', 18),
#  ('proles', 18),
#  ('play', 18),
#  ('grew', 18),
#  ('slip', 17),
#  ('colour', 17),
#  ('poster', 17),
#  ('seven', 17),
#  ('blue', 17),
#  ('rate', 17),
#  ('peac', 17),
#  ('bread', 17),
#  ('save', 17),
#  ('desir', 17),
#  ('free', 17),
#  ('diary', 17),
#  ('huge', 17),
#  ('impress', 17),
#  ('curious', 17),
#  ('polit', 17),
#  ('teeth', 17),
#  ('cri', 17),
#  ('violent', 17),
#  ('utter', 17),
#  ('faint', 17),
#  ('event', 17),
#  ('commit', 17),
#  ('parsons', 17),
#  ('yell', 17),
#  ('month', 17),
#  ('knowledg', 17),
#  ('earth', 17),
#  ('invent', 17),
#  ('reach', 17),
#  ('class', 17),
#  ('problem', 17),
#  ('photograph', 17),
#  ('destroy', 17),
#  ('wish', 17),
#  ('st', 17),
#  ('smile', 17),
#  ('clock', 16),
#  ('pictur', 16),
#  ('remember', 16),
#  ('news', 16),
#  ('cigarett', 16),
#  ('thick', 16),
#  ('instead', 16),
#  ('least', 16),
#  ('helpless', 16),
#  ('militari', 16),
#  ('hole', 16),
#  ('stream', 16),
#  ('spi', 16),
#  ('edg', 16),
#  ('crime', 16),
#  ('demand', 16),
#  ('wait', 16),
#  ('straight', 16),
#  ('flung', 16),
#  ('difference', 16),
#  ('sooner', 16),
#  ('stupid', 16),
#  ('blow', 16),
#  ('forc', 16),
#  ('rocket', 16),
#  ('principl', 16),
#  ('shape', 16),
#  ('strong', 16),
#  ('th', 16),
#  ('forth', 16),
#  ('tube', 16),
#  ('accept', 16),
#  ("i'v", 16),
#  ('copi', 16),
#  ('defeat', 16),
#  ('till', 16),
#  ('fingers', 16),
#  ('members', 16),
#  ('effect', 16),
#  ('dial', 16),
#  ('breast', 15),
#  ('along', 15),
#  ('hours', 15),
#  ('ran', 15),
#  ('called', 15),
#  ('razor', 15),
#  ('outside', 15),
#  ('level', 15),
#  ('fit', 15),
#  ('individu', 15),
#  ('strength', 15),
#  ('tini', 15),
#  ('pour', 15),
#  ('apart', 15),
#  ('future', 15),
#  ('futur', 15),
#  ('curiou', 15),
#  ('dare', 15),
#  ('hous', 15),
#  ('rubbish', 15),
#  ('department', 15),
#  ('waist', 15),
#  ('overalls', 15),
#  ('manner', 15),
#  ('burst', 15),
#  ('march', 15),
#  ('books', 15),
#  ('state', 15),
#  ('subject', 15),
#  ('murmur', 15),
#  ('deliber', 15),
#  ('slightli', 15),
#  ('common', 15),
#  ('someon', 15),
#  ('issu', 15),
#  ('roar', 15),
#  ('twenti', 15),
#  ('memory', 15),
#  ('intellectu', 15),
#  ('tree', 15),
#  ('bare', 15),
#  ('claim', 15),
#  ('forget', 15),
#  ('easi', 15),
#  ('agre', 15),
#  ('special', 15),
#  ('coffee', 15),
#  ("'how", 15),
#  ('101', 15),
#  ('beneath', 14),
#  ('metal', 14),
#  ('slogan', 14),
#  ('frighten', 14),
#  ('hidden', 14),
#  ('cross', 14),
#  ('partli', 14),
#  ('suggest', 14),
#  ('doubt', 14),
#  ('origin', 14),
#  ('caus', 14),
#  ('corridor', 14),
#  ('spectacl', 14),
#  ('belief', 14),
#  ('indeed', 14),
#  ('speech', 14),
#  ('occasion', 14),
#  ('seconds', 14),
#  ('hatr', 14),
#  ('mention', 14),
#  ('existence', 14),
#  ('capabl', 14),
#  ('draw', 14),
#  ('everything', 14),
#  ('already', 14),
#  ('wife', 14),
#  ('filthi', 14),
#  ('stopped', 14),
#  ('remark', 14),
#  ('bad', 14),
#  ('chocol', 14),
#  ('fro', 14),
#  ('wander', 14),
#  ('rather', 14),
#  ('stir', 14),
#  ('fifti', 14),
#  ('definit', 14),
#  ('slowli', 14),
#  ('brain', 14),
#  ('roll', 14),
#  ('revolution', 14),
#  ('coat', 14),
#  ('accord', 14),
#  ('pavement', 14),
#  ('astonish', 14),
#  ('fail', 14),
#  ('paperweight', 14),
#  ('sing', 14),
#  ('safe', 14),
#  ('overal', 13),
#  ('blade', 13),
#  ('sky', 13),
#  ('vision', 13),
#  ('popul', 13),
#  ('entir', 13),
#  ('posit', 13),
#  ('ordinari', 13),
#  ('impossible', 13),
#  ('liter', 13),
#  ('flash', 13),
#  ('kick', 13),
#  ('narrow', 13),
#  ('brien', 13),
#  ('neck', 13),
#  ('gestur', 13),
#  ('anyon', 13),
#  ('disappeared', 13),
#  ('endless', 13),
#  ('refer', 13),
#  ('rose', 13),
#  ('paus', 13),
#  ('feeling', 13),
#  ('existed', 13),
#  ('arrest', 13),
#  ('hard', 13),
#  ('report', 13),
#  ('pieces', 13),
#  ("'they", 13),
#  ('organ', 13),
#  ("'a", 13),
#  ("you'r", 13),
#  ('asleep', 13),
#  ('appeal', 13),
#  ('instance', 13),
#  ('struggl', 13),
#  ('fallen', 13),
#  ('tortur', 13),
#  ('wrong', 13),
#  ('ampleforth', 13),
#  ('song', 13),
#  ('comrad', 13),
#  ('disappear', 13),
#  ('happening', 13),
#  ('clasp', 13),
#  ('beer', 13),
#  ('century', 13),
#  ('labour', 13),
#  ("'but", 13),
#  ('fix', 13),
#  ('martin', 13),
#  ('best', 12),
#  ('product', 12),
#  ('helicopt', 12),
#  ('plan', 12),
#  ('whenev', 12),
#  ('habit', 12),
#  ('darkness', 12),
#  ('larger', 12),
#  ('ground', 12),
#  ('outer', 12),
#  ('canteen', 12),
#  ('yellow', 12),
#  ('born', 12),
#  ('page', 12),
#  ('scream', 12),
#  ('morn', 12),
#  ('spoken', 12),
#  ('ones', 12),
#  ('depart', 12),
#  ('machin', 12),
#  ('besides', 12),
#  ('wave', 12),
#  ('broke', 12),
#  ('slow', 12),
#  ('met', 12),
#  ('hatred', 12),
#  ('trial', 12),
#  ('laid', 12),
#  ('worst', 12),
#  ('constantli', 12),
#  ('dirti', 12),
#  ('clean', 12),
#  ('morning', 12),
#  ('enemy', 12),
#  ('victory', 12),
#  ('ration', 12),
#  ('detail', 12),
#  ('return', 12),
#  ('note', 12),
#  ('empti', 12),
#  ('late', 12),
#  ('countri', 12),
#  ('grasp', 12),
#  ("'em", 12),
#  ('example', 12),
#  ('africa', 12),
#  ('ear', 12),
#  ('main', 12),
#  ('standard', 12),
#  ('assum', 12),
#  ('others', 12),
#  ('reality', 12),
#  ('drink', 12),
#  ('easili', 12),
#  ('eat', 12),
#  ('fire', 12),
#  ('telescreens', 12),
#  ('practic', 12),
#  ('impuls', 12),
#  ('buy', 12),
#  ('church', 12),
#  ('centuri', 12),
#  ('cheek', 12),
#  ('dear', 12),
#  ('super-st', 12),
#  ('mental', 12),
#  ('cage', 12),
#  ('smith', 11),
#  ('quickli', 11),
#  ('prevent', 11),
#  ('sank', 11),
#  ('uniform', 11),
#  ('plaster', 11),
#  ('command', 11),
#  ('wire', 11),
#  ('kilometr', 11),
#  ('childhood', 11),
#  ('ignor', 11),
#  ('govern', 11),
#  ('concern', 11),
#  ('offici', 11),
#  ('kitchen', 11),
#  ('red', 11),
#  ('intend', 11),
#  ('older', 11),
#  ('bought', 11),
#  ('particular', 11),
#  ('shot', 11),
#  ('suffer', 11),
#  ('diari', 11),
#  ('drag', 11),
#  ('large', 11),
#  ('screen', 11),
#  ('engag', 11),
#  ('thin', 11),
#  ('attack', 11),
#  ('faces', 11),
#  ('terribl', 11),
#  ('avoid', 11),
#  ('smash', 11),
#  ('emot', 11),
#  ('wrench', 11),
#  ('horror', 11),
#  ('action', 11),
#  ('essenti', 11),
#  ('conceal', 11),
#  ('seiz', 11),
#  ('attempt', 11),
#  ('sink', 11),
#  ('dress', 11),
#  ('hang', 11),
#  ('h', 11),
#  ('creatur', 11),
#  ('therefor', 11),
#  ('belong', 11),
#  ('privat', 11),
#  ('different', 11),
#  ('altered', 11),
#  ('opinion', 11),
#  ('ultim', 11),
#  ('capitalist', 11),
#  ('perfectli', 11),
#  ('scrap', 11),
#  ('led', 11),
#  ('materi', 11),
#  ('nearer', 11),
#  ('spoke', 11),
#  ('nevertheless', 11),
#  ('solid', 11),
#  ('chanc', 11),
#  ('train', 11),
#  ('lamp', 11),
#  ('rutherford', 11),
#  ('ceas', 11),
#  ('yard', 11),
#  ('clement', 11),
#  ('difficulti', 11),
#  ('conquer', 11),
#  ('rat', 11),
#  ('twentieth', 11),
#  ('wealth', 11),
#  ('lift', 10),
#  ('current', 10),
#  ('varicos', 10),
#  ('surfac', 10),
#  ('switch', 10),
#  ('instrument', 10),
#  ('torn', 10),
#  ('distanc', 10),
#  ('system', 10),
#  ('structur', 10),
#  ('similar', 10),
#  ('bottl', 10),
#  ('mark', 10),
#  ('belli', 10),
#  ('smooth', 10),
#  ('deal', 10),
#  ('pen', 10),
#  ('panic', 10),
#  ('comfort', 10),
#  ('lot', 10),
#  ('eleven', 10),
#  ('cubicl', 10),
#  ('fiction', 10),
#  ('movements', 10),
#  ('manag', 10),
#  ('spite', 10),
#  ('recal', 10),
#  ('dozen', 10),
#  ('fresh', 10),
#  ('fade', 10),
#  ('intellig', 10),
#  ('else', 10),
#  ('besid', 10),
#  ('contact', 10),
#  ('slid', 10),
#  ('success', 10),
#  ('invari', 10),
#  ('hurri', 10),
#  ('warm', 10),
#  ('block', 10),
#  ('game', 10),
#  ('wood', 10),
#  ('send', 10),
#  ('flit', 10),
#  ('announc', 10),
#  ('reduc', 10),
#  ('cent', 10),
#  ('alive', 10),
#  ('woke', 10),
#  ('fifteen', 10),
#  ('trust', 10),
#  ('involv', 10),
#  ('sent', 10),
#  ('throughout', 10),
#  ('rhyme', 10),
#  ('triumph', 10),
#  ('refus', 10),
#  ('convers', 10),
#  ('tray', 10),
#  ("we'r", 10),
#  ('bone', 10),
#  ('vaporized', 10),
#  ('bloodi', 10),
#  ('happi', 10),
#  ('elbow', 10),
#  ("'if", 10),
#  ('rich', 10),
#  ('condit', 10),
#  ('area', 10),
#  ('singing', 10),
#  ('says', 10),
#  ('ai', 10),
#  ('folly', 10),
#  ("'e", 10),
#  ('soft', 10),
#  ('society', 10),
#  ('bench', 10),
#  ('guards', 10),
#  ('chinless', 10),
#  ('escap', 9),
#  ('wind', 9),
#  ('rag', 9),
#  ('wide', 9),
#  ('seldom', 9),
#  ('list', 9),
#  ('somewhat', 9),
#  ('patrol', 9),
#  ('receiv', 9),
#  ('field', 9),
#  ('iron', 9),
#  ('seri', 9),
#  ('build', 9),
#  ('steel', 9),
#  ('lunch', 9),
#  ('scarlet', 9),
#  ('burn', 9),
#  ('packet', 9),
#  ...]

# %%
# let's make new list only with words whose frequency  > 25

moreThan40_freq = []

for i,j in f_list_new[0].items():
    if j >= 40:
        moreThan40_freq.append(i)

# %%
# 頻出単語top2のgameshとsaidが同時に現れる文を、ピックアップしカウントするプログラムを全ての単語に割り当てる試み。

count_s = {}

for wn1 in range(0, len(moreThan40_freq)-1):
    for wn2 in range(wn1+1, len(moreThan40_freq)):
        s = 0
    
        for sent in form_sent2:
            index1 = 0
            index2 = 0
            
            #remove duplicate
            if moreThan40_freq[wn1] != moreThan40_freq[wn2]:
                
                if moreThan40_freq[wn1] in sent.split():
                    index1 += 1
                if moreThan40_freq[wn2] in sent.split():
                    index2 += 1
              
                if index1 > 0 and index2 > 0:
                    s += 1
                
        count_s.update({( moreThan40_freq[wn1], moreThan40_freq[wn2]) :s })

# %%
#順位チェック
sorted(count_s.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('big', 'brother'), 71),
#  (('winston', 'said'), 58),
#  (('said', "o'brien"), 44),
#  (('parti', 'member'), 41),
#  (('old', 'man'), 40),
#  (('one', 'could'), 38),
#  (('even', 'could'), 36),
#  (('said', "'i"), 35),
#  (('even', 'would'), 33),
#  (('winston', 'one'), 29),
#  (('one', 'even'), 29),
#  (('could', 'would'), 29),
#  (('said', "'you"), 29),
#  (('could', 'see'), 27),
#  (('winston', 'face'), 26),
#  (('winston', 'could'), 26),
#  (('winston', 'back'), 26),
#  (('time', 'could'), 26),
#  (('winston', 'thought'), 25),
#  (('winston', 'look'), 24),
#  (('year', 'ago'), 24),
#  (('winston', 'time'), 23),
#  (('one', 'anoth'), 23),
#  (('could', 'never'), 23),
#  (('winston', 'even'), 22),
#  (('one', 'two'), 22),
#  (('even', 'seem'), 22),
#  (('winston', 'would'), 21),
#  (('winston', "o'brien"), 21),
#  (('one', 'time'), 21),
#  (('one', 'never'), 21),
#  (('like', 'could'), 21),
#  (('like', 'would'), 21),
#  (('said', 'julia'), 21),
#  (('thought', 'would'), 21),
#  (('three', 'two'), 21),
#  (('one', 'like'), 20),
#  (('could', 'parti'), 20),
#  (('oceania', 'war'), 20),
#  (('winston', 'eye'), 19),
#  (('face', 'look'), 19),
#  (('time', 'would'), 19),
#  (('could', 'rememb'), 19),
#  (('would', 'never'), 19),
#  (('one', 'seem'), 18),
#  (('one', 'would'), 18),
#  (('man', 'said'), 18),
#  (('even', 'never'), 18),
#  (('even', 'parti'), 18),
#  (('like', 'seem'), 18),
#  (('except', 'noth'), 18),
#  (('ministri', 'love'), 18),
#  (('winston', 'man'), 17),
#  (('winston', 'seem'), 17),
#  (('winston', 'moment'), 17),
#  (('one', 'thing'), 17),
#  (('face', 'eye'), 17),
#  (('time', 'first'), 17),
#  (('said', "'it"), 17),
#  (('day', 'one'), 16),
#  (('winston', 'turn'), 16),
#  (('winston', 'thing'), 16),
#  (('thought', 'parti'), 16),
#  (('two', 'minut'), 16),
#  (('winston', 'head'), 15),
#  (('old', 'said'), 15),
#  (('one', 'alway'), 15),
#  (('one', 'hand'), 15),
#  (('face', 'man'), 15),
#  (('face', 'hair'), 15),
#  (('even', 'time'), 15),
#  (('even', 'still'), 15),
#  (('time', 'long'), 15),
#  (('way', 'could'), 15),
#  (('voic', 'telescreen'), 15),
#  (('like', 'look'), 15),
#  (('could', 'place'), 15),
#  (('look', "o'brien"), 15),
#  (('would', "o'brien"), 15),
#  (('alway', 'war'), 15),
#  (('winston', 'way'), 14),
#  (('winston', 'two'), 14),
#  (('one', 'moment'), 14),
#  (('one', 'war'), 14),
#  (('even', 'back'), 14),
#  (('hate', 'minut'), 14),
#  (('could', 'thing'), 14),
#  (('could', 'get'), 14),
#  (('could', 'feel'), 14),
#  (('back', 'come'), 14),
#  (('never', 'parti'), 14),
#  (('thing', 'happen'), 14),
#  (('hand', "o'brien"), 14),
#  (('winston', 'though'), 13),
#  (('winston', 'anoth'), 13),
#  (('winston', 'know'), 13),
#  (('winston', 'room'), 13),
#  (('winston', 'almost'), 13),
#  (('face', 'turn'), 13),
#  (('face', "o'brien"), 13),
#  (('man', 'white'), 13),
#  (('even', 'work'), 13),
#  (('hate', 'two'), 13),
#  (('came', 'back'), 13),
#  (('could', 'world'), 13),
#  (('could', 'two'), 13),
#  (('could', 'yet'), 13),
#  (('could', 'ever'), 13),
#  (('could', "o'brien"), 13),
#  (('said', "'the"), 13),
#  (('thought', 'mind'), 13),
#  (('day', 'time'), 12),
#  (('winston', 'littl'), 12),
#  (('winston', 'knew'), 12),
#  (('winston', 'hand'), 12),
#  (('winston', 'heart'), 12),
#  (('though', 'seem'), 12),
#  (('one', 'word'), 12),
#  (('one', 'side'), 12),
#  (('one', 'past'), 12),
#  (('one', 'parti'), 12),
#  (('one', 'almost'), 12),
#  (('one', 'peopl'), 12),
#  (('one', 'ever'), 12),
#  (('face', 'seem'), 12),
#  (('even', 'thought'), 12),
#  (('turn', 'round'), 12),
#  (('could', 'seem'), 12),
#  (('could', 'long'), 12),
#  (('could', 'possibl'), 12),
#  (('world', 'would'), 12),
#  (('look', 'back'), 12),
#  (('look', 'round'), 12),
#  (('said', 'thing'), 12),
#  (('would', 'parti'), 12),
#  (('would', 'make'), 12),
#  (('arm', 'round'), 12),
#  (('winston', 'made'), 11),
#  (('winston', 'voic'), 11),
#  (('winston', 'still'), 11),
#  (('winston', 'telescreen'), 11),
#  (('winston', 'away'), 11),
#  (('winston', 'work'), 11),
#  (('winston', 'never'), 11),
#  (('winston', 'parti'), 11),
#  (('winston', 'toward'), 11),
#  (('though', 'could'), 11),
#  (('though', 'look'), 11),
#  (('enough', 'could'), 11),
#  (('one', 'way'), 11),
#  (('one', 'know'), 11),
#  (('one', 'make'), 11),
#  (('one', 'without'), 11),
#  (('face', 'even'), 11),
#  (('made', 'would'), 11),
#  (('even', 'way'), 11),
#  (('even', 'like'), 11),
#  (('even', 'whole'), 11),
#  (('even', 'thing'), 11),
#  (('even', 'make'), 11),
#  (('even', 'life'), 11),
#  (('time', 'seem'), 11),
#  (('time', 'never'), 11),
#  (('way', 'would'), 11),
#  (('eye', 'look'), 11),
#  (('big', 'parti'), 11),
#  (('brother', 'parti'), 11),
#  (('telescreen', 'could'), 11),
#  (('could', 'said'), 11),
#  (('could', 'knew'), 11),
#  (('could', 'without'), 11),
#  (('could', 'pain'), 11),
#  (('hair', 'dark'), 11),
#  (('said', 'go'), 11),
#  (('would', 'say'), 11),
#  (('four', 'two'), 11),
#  (('year', 'two'), 11),
#  (("'i", "'m"), 11),
#  (("o'brien", "'you"), 11),
#  (('day', 'work'), 10),
#  (('winston', 'side'), 10),
#  (('winston', 'see'), 10),
#  (('winston', 'sat'), 10),
#  (('winston', 'first'), 10),
#  (('winston', 'woman'), 10),
#  (('winston', 'girl'), 10),
#  (('winston', "'i"), 10),
#  (('winston', 'speak'), 10),
#  (('winston', 'julia'), 10),
#  (('door', 'open'), 10),
#  (('though', 'one'), 10),
#  (('though', 'face'), 10),
#  (('one', 'back'), 10),
#  (('one', 'knew'), 10),
#  (('one', 'three'), 10),
#  (('one', 'hold'), 10),
#  (('one', 'power'), 10),
#  (('face', 'see'), 10),
#  (('even', 'moment'), 10),
#  (('even', 'member'), 10),
#  (('even', 'power'), 10),
#  (('even', 'might'), 10),
#  (('time', 'make'), 10),
#  (('way', 'parti'), 10),
#  (('turn', 'away'), 10),
#  (('turn', 'back'), 10),
#  (('still', 'sat'), 10),
#  (('could', 'except'), 10),
#  (('could', 'thought'), 10),
#  (('could', 'moment'), 10),
#  (('could', 'three'), 10),
#  (('could', 'say'), 10),
#  (('could', 'make'), 10),
#  (('could', 'come'), 10),
#  (('seem', 'would'), 10),
#  (('seem', 'almost'), 10),
#  (('said', 'know'), 10),
#  (('would', 'possibl'), 10),
#  (('would', 'get'), 10),
#  (('would', 'ever'), 10),
#  (('know', "'i"), 10),
#  (('moment', 'power'), 10),
#  (('three', 'four'), 10),
#  (('day', 'could'), 9),
#  (('winston', 'big'), 9),
#  (('winston', 'long'), 9),
#  (('winston', 'arm'), 9),
#  (('winston', 'round'), 9),
#  (('winston', 'feel'), 9),
#  (('winston', 'mind'), 9),
#  (('winston', 'saw'), 9),
#  (('winston', 'take'), 9),
#  (('winston', 'rememb'), 9),
#  (('winston', "'you"), 9),
#  (('enough', 'even'), 9),
#  (('old', 'year'), 9),
#  (('one', 'enorm'), 9),
#  (('one', 'face'), 9),
#  (('one', 'look'), 9),
#  (('one', 'thought'), 9),
#  (('one', 'long'), 9),
#  (('one', 'air'), 9),
#  (('one', 'differ'), 9),
#  (('one', 'four'), 9),
#  (('one', 'might'), 9),
#  (('face', 'could'), 9),
#  (('face', 'back'), 9),
#  (('man', 'could'), 9),
#  (('black', 'white'), 9),
#  (('use', 'even'), 9),
#  (('even', 'word'), 9),
#  (('even', 'telescreen'), 9),
#  (('even', 'look'), 9),
#  (('even', 'everi'), 9),
#  (('even', 'alway'), 9),
#  (('even', 'three'), 9),
#  (('even', 'feel'), 9),
#  (('time', 'world'), 9),
#  (('time', 'back'), 9),
#  (('time', 'three'), 9),
#  (('hate', 'week'), 9),
#  (('went', 'back'), 9),
#  (('someth', 'like'), 9),
#  (('like', 'know'), 9),
#  (('like', 'round'), 9),
#  (('like', 'parti'), 9),
#  (('like', 'peopl'), 9),
#  (('word', 'could'), 9),
#  (('word', 'everi'), 9),
#  (('word', 'newspeak'), 9),
#  (('still', 'could'), 9),
#  (('could', 'work'), 9),
#  (('could', 'room'), 9),
#  (('could', 'much'), 9),
#  (('could', 'hand'), 9),
#  (('could', 'mind'), 9),
#  (('bodi', 'seem'), 9),
#  (('hair', 'girl'), 9),
#  (('look', 'seen'), 9),
#  (('littl', 'woman'), 9),
#  (('seem', 'moment'), 9),
#  (('seem', "o'brien"), 9),
#  (('except', 'never'), 9),
#  (('said', 'never'), 9),
#  (('said', 'say'), 9),
#  (('said', 'almost'), 9),
#  (('said', "'yes"), 9),
#  (('anoth', 'two'), 9),
#  (('thought', 'might'), 9),
#  (('thought', "o'brien"), 9),
#  (('would', 'knew'), 9),
#  (('would', 'go'), 9),
#  (('would', 'mind'), 9),
#  (('would', 'take'), 9),
#  (('moment', 'never'), 9),
#  (('three', 'men'), 9),
#  (('hold', 'get'), 9),
#  (('day', 'never'), 8),
#  (('winston', 'came'), 8),
#  (('winston', 'like'), 8),
#  (('winston', 'seen'), 8),
#  (('winston', 'place'), 8),
#  (('winston', 'sort'), 8),
#  (('winston', 'eyes'), 8),
#  (('winston', 'began'), 8),
#  (('winston', 'hold'), 8),
#  (('winston', 'year'), 8),
#  (('winston', 'go'), 8),
#  (('winston', 'bed'), 8),
#  (('though', 'man'), 8),
#  (('one', 'end'), 8),
#  (('one', 'simpli'), 8),
#  (('one', 'part'), 8),
#  (('one', 'everi'), 8),
#  (('one', 'behind'), 8),
#  (('one', 'place'), 8),
#  (('one', 'possibl'), 8),
#  (('one', 'see'), 8),
#  (('one', 'round'), 8),
#  (('one', 'whole'), 8),
#  (('one', 'much'), 8),
#  (('one', 'mind'), 8),
#  (('one', 'yet'), 8),
#  (('one', 'give'), 8),
#  (('man', 'like'), 8),
#  (('man', 'littl'), 8),
#  (('man', 'away'), 8),
#  (('man', 'side'), 8),
#  (('made', 'could'), 8),
#  (('even', 'voic'), 8),
#  (('even', 'long'), 8),
#  (('even', 'place'), 8),
#  (('even', 'two'), 8),
#  (('even', 'name'), 8),
#  (('even', 'without'), 8),
#  (('even', 'human'), 8),
#  (('time', 'like'), 8),
#  (('time', 'everi'), 8),
#  (('time', 'said'), 8),
#  (('time', 'work'), 8),
#  (('way', 'know'), 8),
#  (('like', 'turn'), 8),
#  (('like', 'word'), 8),
#  (('like', 'might'), 8),
#  (('turn', 'littl'), 8),
#  (('turn', 'seem'), 8),
#  (('still', 'would'), 8),
#  (('still', 'past'), 8),
#  (('telescreen', 'back'), 8),
#  (('could', 'far'), 8),
#  (('could', 'back'), 8),
#  (('could', 'whether'), 8),
#  (('could', 'want'), 8),
#  (('could', 'live'), 8),
#  (('could', 'must'), 8),
#  (('could', 'power'), 8),
#  (('could', 'happen'), 8),
#  (('could', 'gener'), 8),
#  (('world', 'parti'), 8),
#  (('world', 'peopl'), 8),
#  (('littl', 'girl'), 8),
#  (('seem', 'away'), 8),
#  (('seem', 'back'), 8),
#  (('seem', 'long'), 8),
#  (('seem', 'whole'), 8),
#  (('seem', 'julia'), 8),
#  (('said', 'would'), 8),
#  (('anoth', 'would'), 8),
#  (('far', 'away'), 8),
#  (('far', 'room'), 8),
#  (('would', 'place'), 8),
#  (('would', 'three'), 8),
#  (('would', 'two'), 8),
#  (('would', 'come'), 8),
#  (('long', 'ago'), 8),
#  (('know', 'whether'), 8),
#  (('know', 'without'), 8),
#  (('knew', 'never'), 8),
#  (('work', 'hour'), 8),
#  (('alway', 'never'), 8),
#  (('side', 'sit'), 8),
#  (('possibl', 'might'), 8),
#  (('three', 'power'), 8),
#  (('war', 'continu'), 8),
#  (('never', 'past'), 8),
#  (('past', 'control'), 8),
#  (('parti', 'understand'), 8),
#  (('go', "'m"), 8),
#  (('two', 'hour'), 8),
#  (('day', 'everi'), 7),
#  (('day', 'would'), 7),
#  (('winston', 'glass'), 7),
#  (('winston', 'went'), 7),
#  (('winston', 'brother'), 7),
#  (('winston', 'hair'), 7),
#  (('winston', 'behind'), 7),
#  (('winston', 'three'), 7),
#  (('winston', 'took'), 7),
#  (('winston', 'left'), 7),
#  (('winston', 'sit'), 7),
#  (('winston', 'must'), 7),
#  (('winston', 'stop'), 7),
#  (('winston', 'pain'), 7),
#  (('winston', 'alreadi'), 7),
#  (('winston', 'across'), 7),
#  (('though', 'even'), 7),
#  (('though', 'still'), 7),
#  (('though', 'moment'), 7),
#  (('though', 'knew'), 7),
#  (('though', 'never'), 7),
#  (('though', 'felt'), 7),
#  (('though', "o'brien"), 7),
#  (('one', 'use'), 7),
#  (('one', 'still'), 7),
#  (('one', 'far'), 7),
#  (('one', 'memori'), 7),
#  (('one', 'room'), 7),
#  (('one', 'love'), 7),
#  (('one', 'feel'), 7),
#  (('one', 'actual'), 7),
#  (('one', 'must'), 7),
#  (('one', 'first'), 7),
#  (('one', 'felt'), 7),
#  (('one', 'come'), 7),
#  (('one', 'name'), 7),
#  (('simpli', 'peopl'), 7),
#  (('face', 'like'), 7),
#  (('face', 'telescreen'), 7),
#  (('face', 'white'), 7),
#  (('face', 'round'), 7),
#  (('face', 'eyes'), 7),
#  (('face', 'hand'), 7),
#  (('face', 'almost'), 7),
#  (('man', 'eye'), 7),
#  (('man', 'back'), 7),
#  (('man', 'place'), 7),
#  (('man', 'small'), 7),
#  (('made', 'seem'), 7),
#  (('use', 'word'), 7),
#  (('use', 'could'), 7),
#  (('use', 'parti'), 7),
#  (('use', 'without'), 7),
#  (('tri', 'could'), 7),
#  (('even', 'turn'), 7),
#  (('even', 'world'), 7),
#  (('even', 'away'), 7),
#  (('even', 'know'), 7),
#  (('even', 'round'), 7),
#  (('even', 'set'), 7),
#  (('even', 'peopl'), 7),
#  (('even', 'perhap'), 7),
#  (('time', 'way'), 7),
#  (('time', 'still'), 7),
#  (('time', 'thought'), 7),
#  (('time', 'round'), 7),
#  (('time', 'parti'), 7),
#  (('time', 'sinc'), 7),
#  (('time', 'must'), 7),
#  (('time', 'might'), 7),
#  (('time', 'almost'), 7),
#  (('time', 'peopl'), 7),
#  (('time', 'rememb'), 7),
#  (('time', 'hour'), 7),
#  (('way', 'anoth'), 7),
#  (('eye', 'still'), 7),
#  (('eye', 'away'), 7),
#  (('insid', 'get'), 7),
#  (('like', 'world'), 7),
#  (('like', 'away'), 7),
#  (('like', 'back'), 7),
#  (('like', 'alway'), 7),
#  (('like', 'life'), 7),
#  (('turn', 'would'), 7),
#  (('still', 'seem'), 7),
#  (('still', 'hand'), 7),
#  (('could', 'look'), 7),
#  (('could', 'everi'), 7),
#  (('could', 'away'), 7),
#  (('could', 'whole'), 7),
#  (('could', 'woman'), 7),
#  (('could', 'julia'), 7),
#  (('mere', 'parti'), 7),
#  (('party', 'thought'), 7),
#  (('party', 'parti'), 7),
#  (('hair', 'white'), 7),
#  (('look', 'seem'), 7),
#  (('look', 'anoth'), 7),
#  (('look', 'eyes'), 7),
#  (('look', 'might'), 7),
#  (('seem', 'mind'), 7),
#  (('seem', 'say'), 7),
#  (('seem', 'peopl'), 7),
#  (('said', 'much'), 7),
#  (('said', 'ever'), 7),
#  (('dark', 'girl'), 7),
#  (('anoth', 'moment'), 7),
#  (('away', 'would'), 7),
#  (('thought', 'alway'), 7),
#  (('thought', 'possibl'), 7),
#  (('thought', 'member'), 7),
#  (('behind', 'back'), 7),
#  (('back', 'moment'), 7),
#  (('back', 'work'), 7),
#  (('back', 'sat'), 7),
#  (('back', 'two'), 7),
#  (('back', "o'brien"), 7),
#  (('would', 'know'), 7),
#  (('would', 'moment'), 7),
#  (('would', 'live'), 7),
#  (('would', 'work'), 7),
#  (('would', 'differ'), 7),
#  (('would', 'appear'), 7),
#  (('would', 'love'), 7),
#  (('would', 'thing'), 7),
#  (('would', 'feel'), 7),
#  (('would', 'hand'), 7),
#  (('would', 'believ'), 7),
#  (('would', 'power'), 7),
#  (('would', 'happen'), 7),
#  (('would', 'person'), 7),
#  (('would', 'perhap'), 7),
#  (('would', 'julia'), 7),
#  (('long', 'war'), 7),
#  (('seen', 'never'), 7),
#  (('know', 'parti'), 7),
#  (('moment', 'alway'), 7),
#  (('moment', 'first'), 7),
#  (('moment', "o'brien"), 7),
#  (('place', 'never'), 7),
#  (('three', 'war'), 7),
#  (('war', 'parti'), 7),
#  (('war', 'necessari'), 7),
#  (('love', 'make'), 7),
#  (('never', 'anyth'), 7),
#  (('never', 'peopl'), 7),
#  (('took', 'hold'), 7),
#  (('took', 'hand'), 7),
#  (('thing', 'better'), 7),
#  (('thing', 'think'), 7),
#  (('past', 'exist'), 7),
#  (('lie', 'parti'), 7),
#  (('parti', 'two'), 7),
#  (('parti', 'believ'), 7),
#  (('parti', 'might'), 7),
#  (('parti', 'peopl'), 7),
#  (('parti', 'life'), 7),
#  (('two', 'hand'), 7),
#  (('two', 'make'), 7),
#  (('two', 'ago'), 7),
#  (('second', 'perhap'), 7),
#  (('say', "'you"), 7),
#  (('think', "'i"), 7),
#  (('ever', 'human'), 7),
#  (('day', 'even'), 6),
#  (('day', 'almost'), 6),
#  (('day', "'the"), 6),
#  (('winston', 'right'), 6),
#  (('winston', 'party'), 6),
#  (('winston', 'far'), 6),
#  (('winston', 'well'), 6),
#  (('winston', 'alway'), 6),
#  (('winston', 'air'), 6),
#  (('winston', 'war'), 6),
#  (('winston', 'appear'), 6),
#  (('winston', 'four'), 6),
#  (('winston', 'small'), 6),
#  (('winston', 'lie'), 6),
#  (('winston', 'get'), 6),
#  (('winston', 'believ'), 6),
#  (('winston', 'suddenli'), 6),
#  (('winston', 'front'), 6),
#  (('winston', 'minut'), 6),
#  (('winston', 'peopl'), 6),
#  (('winston', 'perhap'), 6),
#  (('winston', 'ever'), 6),
#  (('glass', 'took'), 6),
#  (('though', 'back'), 6),
#  (('though', 'round'), 6),
#  (('though', 'two'), 6),
#  (('though', 'hand'), 6),
#  (('enough', 'time'), 6),
#  (('enough', 'would'), 6),
#  (('one', 'made'), 6),
#  (('one', 'move'), 6),
#  (('one', 'big'), 6),
#  (('one', 'telescreen'), 6),
#  (('one', 'mere'), 6),
#  (('one', 'world'), 6),
#  (('one', 'except'), 6),
#  (('one', 'said'), 6),
#  (('one', 'away'), 6),
#  (('one', 'well'), 6),
#  (('one', 'sort'), 6),
#  (('one', 'quit'), 6),
#  (('one', 'newspeak'), 6),
#  (('one', 'took'), 6),
#  (('one', 'eyes'), 6),
#  (('one', 'also'), 6),
#  (('one', 'year'), 6),
#  (('one', 'lie'), 6),
#  (('one', 'member'), 6),
#  (('one', 'open'), 6),
#  (('one', 'sinc'), 6),
#  (('one', 'woman'), 6),
#  (('one', 'minut'), 6),
#  (('one', 'take'), 6),
#  (('one', 'gener'), 6),
#  (('one', 'person'), 6),
#  (('one', 'life'), 6),
#  (('one', 'stand'), 6),
#  (('one', 'toward'), 6),
#  (('one', 'necessari'), 6),
#  (('one', 'julia'), 6),
#  (('end', 'would'), 6),
#  (('end', 'room'), 6),
#  (('end', 'come'), 6),
#  (('wall', 'side'), 6),
#  (('enorm', 'face'), 6),
#  (('enorm', 'even'), 6),
#  (('face', 'still'), 6),
#  (('face', 'away'), 6),
#  (('face', 'thought'), 6),
#  (('face', 'three'), 6),
#  (('face', 'suddenli'), 6),
#  (('face', 'chang'), 6),
#  (('face', 'power'), 6),
#  (('face', 'think'), 6),
#  (('face', 'light'), 6),
#  (('man', 'would'), 6),
#  (('made', 'parti'), 6),
#  (('made', 'two'), 6),
#  (('even', 'part'), 6),
#  (('even', 'paper'), 6),
#  (('even', 'whether'), 6),
#  (('even', 'live'), 6),
#  (('even', 'sort'), 6),
#  (('even', 'quit'), 6),
#  (('even', 'hold'), 6),
#  (('even', 'kind'), 6),
#  (('even', 'hand'), 6),
#  (('even', 'saw'), 6),
#  (('even', 'almost'), 6),
#  (('even', 'come'), 6),
#  (('even', 'sometim'), 6),
#  (('even', 'exist'), 6),
#  (('even', 'julia'), 6),
#  (('time', 'mere'), 6),
#  (('time', 'alway'), 6),
#  (('time', 'differ'), 6),
#  (('time', 'year'), 6),
#  (('time', 'past'), 6),
#  (('time', 'power'), 6),
#  (('time', 'perhap'), 6),
#  (('time', 'yet'), 6),
#  (('time', 'think'), 6),
#  (('right', 'arm'), 6),
#  (('right', 'parti'), 6),
#  (('eye', 'could'), 6),
#  (('eye', 'seem'), 6),
#  (('eye', 'back'), 6),
#  (('big', 'thought'), 6),
#  (('big', 'sort'), 6),
#  (('brother', 'thought'), 6),
#  (('insid', 'could'), 6),
#  (('someth', 'could'), 6),
#  (('someth', 'call'), 6),
#  (('like', 'bodi'), 6),
#  (('like', 'said'), 6),
#  (('like', 'anoth'), 6),
#  (('like', 'seen'), 6),
#  (('like', 'see'), 6),
#  (('like', 'power'), 6),
#  (('turn', "o'brien"), 6),
#  (('word', 'ever'), 6),
#  (('still', 'back'), 6),
#  (('still', 'almost'), 6),
#  (('telescreen', 'moment'), 6),
#  (('telescreen', 'room'), 6),
#  (('telescreen', 'keep'), 6),
#  (('could', 'littl'), 6),
#  (('could', 'anoth'), 6),
#  (('could', 'seen'), 6),
#  (('could', 'well'), 6),
#  (('could', 'noth'), 6),
#  (('could', 'war'), 6),
#  (('could', 'complet'), 6),
#  (('could', 'arm'), 6),
#  (('could', 'certain'), 6),
#  (('could', 'actual'), 6),
#  (('could', 'first'), 6),
#  (('could', 'might'), 6),
#  (('could', 'stop'), 6),
#  (('could', 'perhap'), 6),
#  (('could', 'talk'), 6),
#  (('could', 'less'), 6),
#  (('could', 'bed'), 6),
#  (('could', 'done'), 6),
#  (('could', 'hour'), 6),
#  (('could', 'give'), 6),
#  (('bodi', 'feel'), 6),
#  (('party', 'world'), 6),
#  (('party', 'member'), 6),
#  (('littl', 'would'), 6),
#  (('seem', 'thought'), 6),
#  (('seem', 'room'), 6),
#  (('seem', 'never'), 6),
#  (('seem', 'round'), 6),
#  (('seem', 'parti'), 6),
#  (('seem', 'suddenli'), 6),
#  (('seem', 'power'), 6),
#  (('seem', 'woman'), 6),
#  (('except', 'parti'), 6),
#  (('everi', 'parti'), 6),
#  (('said', 'thought'), 6),
#  (('said', 'moment'), 6),
#  (('said', 'place'), 6),
#  (('said', 'see'), 6),
#  (('said', 'must'), 6),
#  (('said', 'good'), 6),
#  (('said', 'without'), 6),
#  (('said', 'mean'), 6),
#  (('matter', 'would'), 6),
#  (('thought', 'back'), 6),
#  (('thought', 'moment'), 6),
#  (('thought', 'exist'), 6),
#  (('behind', 'head'), 6),
#  (('behind', 'hand'), 6),
#  (('back', 'white'), 6),
#  (('back', 'alway'), 6),
#  (('back', 'go'), 6),
#  (('back', 'bed'), 6),
#  (('would', 'whether'), 6),
#  (('would', 'lie'), 6),
#  (('would', 'certain'), 6),
#  (('would', 'might'), 6),
#  (('would', 'life'), 6),
#  (('would', 'heart'), 6),
#  (('would', 'bed'), 6),
#  (('would', 'think'), 6),
#  (('would', 'exist'), 6),
#  (('would', 'hour'), 6),
#  (('long', 'know'), 6),
#  (('well', 'say'), 6),
#  (('know', 'moment'), 6),
#  (('know', 'tell'), 6),
#  (('know', 'never'), 6),
#  (('know', 'say'), 6),
#  (('moment', 'two'), 6),
#  (('moment', 'almost'), 6),
#  (('moment', 'ever'), 6),
#  (('oceania', 'alway'), 6),
#  (('alway', 'kind'), 6),
#  (('quit', 'differ'), 6),
#  (('side', "o'brien"), 6),
#  (('noth', 'parti'), 6),
#  (('differ', 'make'), 6),
#  (('three', 'ago'), 6),
#  (('war', 'sinc'), 6),
#  (('see', 'thing'), 6),
#  (('see', 'two'), 6),
#  (('never', 'act'), 6),
#  (('never', 'almost'), 6),
#  (('arm', 'head'), 6),
#  (('arm', 'woman'), 6),
#  (('round', 'hand'), 6),
#  (('round', 'suddenli'), 6),
#  (('round', 'put'), 6),
#  (('took', "o'brien"), 6),
#  (('sat', 'hand'), 6),
#  (('small', 'two'), 6),
#  (('kind', 'might'), 6),
#  (('much', 'perhap'), 6),
#  (('lie', 'feel'), 6),
#  (('parti', 'upon'), 6),
#  (('parti', 'must'), 6),
#  (('parti', 'power'), 6),
#  (('parti', 'say'), 6),
#  (('two', 'might'), 6),
#  (('sinc', 'ever'), 6),
#  (('feel', 'make'), 6),
#  (('hand', 'almost'), 6),
#  (('upon', 'life'), 6),
#  (('mind', "o'brien"), 6),
#  (('say', "'i"), 6),
#  (('front', 'stand'), 6),
#  (('almost', 'without'), 6),
#  (('peopl', 'gener'), 6),
#  (('without', 'walk'), 6),
#  (('bed', 'light'), 6),
#  (('ever', "o'brien"), 6),
#  (('day', 'winston'), 5),
#  (('day', 'week'), 5),
#  (('day', 'follow'), 5),
#  (('day', 'telescreen'), 5),
#  (('day', 'look'), 5),
#  (('day', 'moment'), 5),
#  (('day', 'minut'), 5),
#  (('winston', 'enough'), 5),
#  (('winston', 'end'), 5),
#  (('winston', 'wall'), 5),
#  (('winston', 'part'), 5),
#  (('winston', 'move'), 5),
#  (('winston', 'someth'), 5),
#  (('winston', 'word'), 5),
#  (('winston', 'world'), 5),
#  (('winston', 'paper'), 5),
#  (('winston', 'whether'), 5),
#  (('winston', 'white'), 5),
#  (('winston', 'quit'), 5),
#  (('winston', 'got'), 5),
#  (('winston', 'second'), 5),
#  (('winston', 'upon'), 5),
#  (('winston', 'make'), 5),
#  (('winston', 'put'), 5),
#  (('winston', 'ago'), 5),
#  (('winston', 'fact'), 5),
#  (('winston', 'think'), 5),
#  (('winston', 'human'), 5),
#  (('winston', "'the"), 5),
#  (('winston', 'mother'), 5),
#  (('winston', "'yes"), 5),
#  (('glass', 'like'), 5),
#  (('though', 'tri'), 5),
#  (('though', 'eye'), 5),
#  (('though', 'voic'), 5),
#  (('though', 'like'), 5),
#  (('though', 'away'), 5),
#  (('though', 'thought'), 5),
#  (('though', 'would'), 5),
#  (('though', 'say'), 5),
#  (('though', 'almost'), 5),
#  (('enough', 'big'), 5),
#  (('enough', 'make'), 5),
#  (('old', 'one'), 5),
#  (('old', 'got'), 5),
#  (('old', 'almost'), 5),
#  (('old', "'i"), 5),
#  (('one', 'wall'), 5),
#  (('one', 'eye'), 5),
#  (('one', 'turn'), 5),
#  (('one', 'party'), 5),
#  (('one', 'littl'), 5),
#  (('one', 'live'), 5),
#  (('one', 'ministri'), 5),
#  (('one', 'work'), 5),
#  (('one', 'noth'), 5),
#  (('one', 'head'), 5),
#  (('one', 'small'), 5),
#  (('one', 'sit'), 5),
#  (('one', 'keep'), 5),
#  (('one', 'certain'), 5),
#  (('one', 'act'), 5),
#  (('one', 'suddenli'), 5),
#  (('one', 'great'), 5),
#  (('one', 'saw'), 5),
#  (('one', 'continu'), 5),
#  (('one', 'perhap'), 5),
#  (('one', 'men'), 5),
#  (('one', 'fact'), 5),
#  (('one', 'mean'), 5),
#  (('one', 'confess'), 5),
#  (('one', 'exist'), 5),
#  (('one', "'i"), 5),
#  (('one', 'new'), 5),
#  (('one', "o'brien"), 5),
#  (('one', 'hour'), 5),
#  (('end', 'war'), 5),
#  (('end', 'without'), 5),
#  (('end', 'pain'), 5),
#  (('simpli', 'like'), 5),
#  (('enorm', 'never'), 5),
#  (('face', 'way'), 5),
#  (('face', 'big'), 5),
#  (('face', 'brother'), 5),
#  (('face', 'someth'), 5),
#  (('face', 'came'), 5),
#  (('face', 'said'), 5),
#  (('face', 'dark'), 5),
#  (('face', 'would'), 5),
#  (('face', 'might'), 5),
#  (('man', 'turn'), 5),
#  (('man', 'look'), 5),
#  (('man', 'left'), 5),
#  (('man', 'full'), 5),
#  (('man', 'last'), 5),
#  (('made', 'mind'), 5),
#  (('made', 'say'), 5),
#  (('use', 'party'), 5),
#  (('use', 'littl'), 5),
#  (('use', 'newspeak'), 5),
#  (('use', 'make'), 5),
#  (('tri', 'time'), 5),
#  (('tri', 'keep'), 5),
#  (('even', 'week'), 5),
#  (('even', 'eye'), 5),
#  (('even', 'someth'), 5),
#  (('even', 'street'), 5),
#  (('even', 'anoth'), 5),
#  (('even', 'matter'), 5),
#  (('even', 'seen'), 5),
#  (('even', 'knew'), 5),
#  (('even', 'ministri'), 5),
#  (('even', 'newspeak'), 5),
#  (('even', 'differ'), 5),
#  (('even', 'possibl'), 5),
#  (('even', 'war'), 5),
#  (('even', 'complet'), 5),
#  (('even', 'four'), 5),
#  (('even', 'got'), 5),
#  (('even', 'small'), 5),
#  (('even', 'past'), 5),
#  (('even', 'much'), 5),
#  (('even', 'get'), 5),
#  (('even', 'open'), 5),
#  (('even', 'sinc'), 5),
#  (('even', 'certain'), 5),
#  (('even', 'suddenli'), 5),
#  (('even', 'mind'), 5),
#  (('even', 'happen'), 5),
#  (('even', 'pain'), 5),
#  (('even', 'yet'), 5),
#  (('even', 'heart'), 5),
#  (('even', 'think'), 5),
#  (('even', 'done'), 5),
#  (('even', 'hour'), 5),
#  (('time', 'went'), 5),
#  (('time', 'big'), 5),
#  (('time', 'brother'), 5),
#  (('time', 'came'), 5),
#  (('time', 'anoth'), 5),
#  (('time', 'whether'), 5),
#  (('time', 'want'), 5),
#  (('time', 'ministri'), 5),
#  (('time', 'possibl'), 5),
#  (('time', 'war'), 5),
#  (('time', 'much'), 5),
#  (('time', 'get'), 5),
#  (('time', 'feel'), 5),
#  (('time', 'name'), 5),
#  (('time', 'person'), 5),
#  (('time', 'life'), 5),
#  (('time', 'bed'), 5),
#  (('time', 'becom'), 5),
#  (('time', 'mean'), 5),
#  (('time', 'done'), 5),
#  (('hate', 'would'), 5),
#  (('week', 'would'), 5),
#  (('week', 'work'), 5),
#  (('went', 'work'), 5),
#  (('way', 'still'), 5),
#  (('way', 'differ'), 5),
#  (('way', 'possibl'), 5),
#  (('way', 'never'), 5),
#  (('way', 'member'), 5),
#  (('way', 'almost'), 5),
#  (('eye', 'see'), 5),
#  (('eye', 'open'), 5),
#  (('follow', 'would'), 5),
#  (('move', 'like'), 5),
#  (('move', 'could'), 5),
#  (('big', 'party'), 5),
#  (('big', 'look'), 5),
#  (('big', 'moment'), 5),
#  (('brother', 'party'), 5),
#  (('brother', 'sort'), 5),
#  (('insid', 'feel'), 5),
#  (('voic', 'still'), 5),
#  (('voic', 'could'), 5),
#  (('voic', 'seem'), 5),
#  (('voic', 'moment'), 5),
#  (('someth', 'look'), 5),
#  (('someth', 'seem'), 5),
#  (('someth', 'happen'), 5),
#  (('like', 'long'), 5),
#  (('like', 'whether'), 5),
#  (('like', 'quit'), 5),
#  (('like', 'room'), 5),
#  (('like', 'never'), 5),
#  (('like', 'left'), 5),
#  (('like', 'thing'), 5),
#  (('like', 'past'), 5),
#  (('like', 'suddenli'), 5),
#  (('like', 'anyth'), 5),
#  (('like', 'felt'), 5),
#  (('like', 'girl'), 5),
#  (('like', 'pass'), 5),
#  (('like', 'talk'), 5),
#  (('turn', 'look'), 5),
#  (('word', 'look'), 5),
#  (('word', 'know'), 5),
#  (('word', 'pass'), 5),
#  (('word', 'without'), 5),
#  (('still', 'telescreen'), 5),
#  (('still', 'world'), 5),
#  (('still', 'knew'), 5),
#  (('still', 'never'), 5),
#  (('still', 'keep'), 5),
#  (('still', 'less'), 5),
#  (('still', 'bed'), 5),
#  (('could', 'matter'), 5),
#  ...]

# %%
#namely

new = {tuple(sorted(x)):y for x, y in count_s.items()}

#順位チェック again !
new2 = dict(sorted(new.items(), key=lambda x: x[1], reverse=True))

new3 = dict((k, v) for k, v in new2.items() if v >= 2)

#順位チェック again !
new4 = dict(sorted(new3.items(), key=lambda x: x[1], reverse=True))
new4
# Out:
# {('big', 'brother'): 71,
#  ('said', 'winston'): 58,
#  ("o'brien", 'said'): 44,
#  ('member', 'parti'): 41,
#  ('man', 'old'): 40,
#  ('could', 'one'): 38,
#  ('could', 'even'): 36,
#  ("'i", 'said'): 35,
#  ('even', 'would'): 33,
#  ('one', 'winston'): 29,
#  ('even', 'one'): 29,
#  ('could', 'would'): 29,
#  ("'you", 'said'): 29,
#  ('could', 'see'): 27,
#  ('face', 'winston'): 26,
#  ('could', 'winston'): 26,
#  ('back', 'winston'): 26,
#  ('could', 'time'): 26,
#  ('thought', 'winston'): 25,
#  ('look', 'winston'): 24,
#  ('ago', 'year'): 24,
#  ('time', 'winston'): 23,
#  ('anoth', 'one'): 23,
#  ('could', 'never'): 23,
#  ('even', 'winston'): 22,
#  ('one', 'two'): 22,
#  ('even', 'seem'): 22,
#  ('winston', 'would'): 21,
#  ("o'brien", 'winston'): 21,
#  ('one', 'time'): 21,
#  ('never', 'one'): 21,
#  ('could', 'like'): 21,
#  ('like', 'would'): 21,
#  ('julia', 'said'): 21,
#  ('thought', 'would'): 21,
#  ('three', 'two'): 21,
#  ('like', 'one'): 20,
#  ('could', 'parti'): 20,
#  ('oceania', 'war'): 20,
#  ('eye', 'winston'): 19,
#  ('face', 'look'): 19,
#  ('time', 'would'): 19,
#  ('could', 'rememb'): 19,
#  ('never', 'would'): 19,
#  ('one', 'seem'): 18,
#  ('one', 'would'): 18,
#  ('man', 'said'): 18,
#  ('even', 'never'): 18,
#  ('even', 'parti'): 18,
#  ('like', 'seem'): 18,
#  ('except', 'noth'): 18,
#  ('love', 'ministri'): 18,
#  ('man', 'winston'): 17,
#  ('seem', 'winston'): 17,
#  ('moment', 'winston'): 17,
#  ('one', 'thing'): 17,
#  ('eye', 'face'): 17,
#  ('first', 'time'): 17,
#  ("'it", 'said'): 17,
#  ('day', 'one'): 16,
#  ('turn', 'winston'): 16,
#  ('thing', 'winston'): 16,
#  ('parti', 'thought'): 16,
#  ('minut', 'two'): 16,
#  ('head', 'winston'): 15,
#  ('old', 'said'): 15,
#  ('alway', 'one'): 15,
#  ('hand', 'one'): 15,
#  ('face', 'man'): 15,
#  ('face', 'hair'): 15,
#  ('even', 'time'): 15,
#  ('even', 'still'): 15,
#  ('long', 'time'): 15,
#  ('could', 'way'): 15,
#  ('telescreen', 'voic'): 15,
#  ('like', 'look'): 15,
#  ('could', 'place'): 15,
#  ('look', "o'brien"): 15,
#  ("o'brien", 'would'): 15,
#  ('alway', 'war'): 15,
#  ('way', 'winston'): 14,
#  ('two', 'winston'): 14,
#  ('moment', 'one'): 14,
#  ('one', 'war'): 14,
#  ('back', 'even'): 14,
#  ('hate', 'minut'): 14,
#  ('could', 'thing'): 14,
#  ('could', 'get'): 14,
#  ('could', 'feel'): 14,
#  ('back', 'come'): 14,
#  ('never', 'parti'): 14,
#  ('happen', 'thing'): 14,
#  ('hand', "o'brien"): 14,
#  ('though', 'winston'): 13,
#  ('anoth', 'winston'): 13,
#  ('know', 'winston'): 13,
#  ('room', 'winston'): 13,
#  ('almost', 'winston'): 13,
#  ('face', 'turn'): 13,
#  ('face', "o'brien"): 13,
#  ('man', 'white'): 13,
#  ('even', 'work'): 13,
#  ('hate', 'two'): 13,
#  ('back', 'came'): 13,
#  ('could', 'world'): 13,
#  ('could', 'two'): 13,
#  ('could', 'yet'): 13,
#  ('could', 'ever'): 13,
#  ('could', "o'brien"): 13,
#  ("'the", 'said'): 13,
#  ('mind', 'thought'): 13,
#  ('day', 'time'): 12,
#  ('littl', 'winston'): 12,
#  ('knew', 'winston'): 12,
#  ('hand', 'winston'): 12,
#  ('heart', 'winston'): 12,
#  ('seem', 'though'): 12,
#  ('one', 'word'): 12,
#  ('one', 'side'): 12,
#  ('one', 'past'): 12,
#  ('one', 'parti'): 12,
#  ('almost', 'one'): 12,
#  ('one', 'peopl'): 12,
#  ('ever', 'one'): 12,
#  ('face', 'seem'): 12,
#  ('even', 'thought'): 12,
#  ('round', 'turn'): 12,
#  ('could', 'seem'): 12,
#  ('could', 'long'): 12,
#  ('could', 'possibl'): 12,
#  ('world', 'would'): 12,
#  ('back', 'look'): 12,
#  ('look', 'round'): 12,
#  ('said', 'thing'): 12,
#  ('parti', 'would'): 12,
#  ('make', 'would'): 12,
#  ('arm', 'round'): 12,
#  ('made', 'winston'): 11,
#  ('voic', 'winston'): 11,
#  ('still', 'winston'): 11,
#  ('telescreen', 'winston'): 11,
#  ('away', 'winston'): 11,
#  ('winston', 'work'): 11,
#  ('never', 'winston'): 11,
#  ('parti', 'winston'): 11,
#  ('toward', 'winston'): 11,
#  ('could', 'though'): 11,
#  ('look', 'though'): 11,
#  ('could', 'enough'): 11,
#  ('one', 'way'): 11,
#  ('know', 'one'): 11,
#  ('make', 'one'): 11,
#  ('one', 'without'): 11,
#  ('even', 'face'): 11,
#  ('made', 'would'): 11,
#  ('even', 'way'): 11,
#  ('even', 'like'): 11,
#  ('even', 'whole'): 11,
#  ('even', 'thing'): 11,
#  ('even', 'make'): 11,
#  ('even', 'life'): 11,
#  ('seem', 'time'): 11,
#  ('never', 'time'): 11,
#  ('way', 'would'): 11,
#  ('eye', 'look'): 11,
#  ('big', 'parti'): 11,
#  ('brother', 'parti'): 11,
#  ('could', 'telescreen'): 11,
#  ('could', 'said'): 11,
#  ('could', 'knew'): 11,
#  ('could', 'without'): 11,
#  ('could', 'pain'): 11,
#  ('dark', 'hair'): 11,
#  ('go', 'said'): 11,
#  ('say', 'would'): 11,
#  ('four', 'two'): 11,
#  ('two', 'year'): 11,
#  ("'i", "'m"): 11,
#  ("'you", "o'brien"): 11,
#  ('day', 'work'): 10,
#  ('side', 'winston'): 10,
#  ('see', 'winston'): 10,
#  ('sat', 'winston'): 10,
#  ('first', 'winston'): 10,
#  ('winston', 'woman'): 10,
#  ('girl', 'winston'): 10,
#  ("'i", 'winston'): 10,
#  ('speak', 'winston'): 10,
#  ('julia', 'winston'): 10,
#  ('door', 'open'): 10,
#  ('one', 'though'): 10,
#  ('face', 'though'): 10,
#  ('back', 'one'): 10,
#  ('knew', 'one'): 10,
#  ('one', 'three'): 10,
#  ('hold', 'one'): 10,
#  ('one', 'power'): 10,
#  ('face', 'see'): 10,
#  ('even', 'moment'): 10,
#  ('even', 'member'): 10,
#  ('even', 'power'): 10,
#  ('even', 'might'): 10,
#  ('make', 'time'): 10,
#  ('parti', 'way'): 10,
#  ('away', 'turn'): 10,
#  ('back', 'turn'): 10,
#  ('sat', 'still'): 10,
#  ('could', 'except'): 10,
#  ('could', 'thought'): 10,
#  ('could', 'moment'): 10,
#  ('could', 'three'): 10,
#  ('could', 'say'): 10,
#  ('could', 'make'): 10,
#  ('come', 'could'): 10,
#  ('seem', 'would'): 10,
#  ('almost', 'seem'): 10,
#  ('know', 'said'): 10,
#  ('possibl', 'would'): 10,
#  ('get', 'would'): 10,
#  ('ever', 'would'): 10,
#  ("'i", 'know'): 10,
#  ('moment', 'power'): 10,
#  ('four', 'three'): 10,
#  ('could', 'day'): 9,
#  ('big', 'winston'): 9,
#  ('long', 'winston'): 9,
#  ('arm', 'winston'): 9,
#  ('round', 'winston'): 9,
#  ('feel', 'winston'): 9,
#  ('mind', 'winston'): 9,
#  ('saw', 'winston'): 9,
#  ('take', 'winston'): 9,
#  ('rememb', 'winston'): 9,
#  ("'you", 'winston'): 9,
#  ('enough', 'even'): 9,
#  ('old', 'year'): 9,
#  ('enorm', 'one'): 9,
#  ('face', 'one'): 9,
#  ('look', 'one'): 9,
#  ('one', 'thought'): 9,
#  ('long', 'one'): 9,
#  ('air', 'one'): 9,
#  ('differ', 'one'): 9,
#  ('four', 'one'): 9,
#  ('might', 'one'): 9,
#  ('could', 'face'): 9,
#  ('back', 'face'): 9,
#  ('could', 'man'): 9,
#  ('black', 'white'): 9,
#  ('even', 'use'): 9,
#  ('even', 'word'): 9,
#  ('even', 'telescreen'): 9,
#  ('even', 'look'): 9,
#  ('even', 'everi'): 9,
#  ('alway', 'even'): 9,
#  ('even', 'three'): 9,
#  ('even', 'feel'): 9,
#  ('time', 'world'): 9,
#  ('back', 'time'): 9,
#  ('three', 'time'): 9,
#  ('hate', 'week'): 9,
#  ('back', 'went'): 9,
#  ('like', 'someth'): 9,
#  ('know', 'like'): 9,
#  ('like', 'round'): 9,
#  ('like', 'parti'): 9,
#  ('like', 'peopl'): 9,
#  ('could', 'word'): 9,
#  ('everi', 'word'): 9,
#  ('newspeak', 'word'): 9,
#  ('could', 'still'): 9,
#  ('could', 'work'): 9,
#  ('could', 'room'): 9,
#  ('could', 'much'): 9,
#  ('could', 'hand'): 9,
#  ('could', 'mind'): 9,
#  ('bodi', 'seem'): 9,
#  ('girl', 'hair'): 9,
#  ('look', 'seen'): 9,
#  ('littl', 'woman'): 9,
#  ('moment', 'seem'): 9,
#  ("o'brien", 'seem'): 9,
#  ('except', 'never'): 9,
#  ('never', 'said'): 9,
#  ('said', 'say'): 9,
#  ('almost', 'said'): 9,
#  ("'yes", 'said'): 9,
#  ('anoth', 'two'): 9,
#  ('might', 'thought'): 9,
#  ("o'brien", 'thought'): 9,
#  ('knew', 'would'): 9,
#  ('go', 'would'): 9,
#  ('mind', 'would'): 9,
#  ('take', 'would'): 9,
#  ('moment', 'never'): 9,
#  ('men', 'three'): 9,
#  ('get', 'hold'): 9,
#  ('day', 'never'): 8,
#  ('came', 'winston'): 8,
#  ('like', 'winston'): 8,
#  ('seen', 'winston'): 8,
#  ('place', 'winston'): 8,
#  ('sort', 'winston'): 8,
#  ('eyes', 'winston'): 8,
#  ('began', 'winston'): 8,
#  ('hold', 'winston'): 8,
#  ('winston', 'year'): 8,
#  ('go', 'winston'): 8,
#  ('bed', 'winston'): 8,
#  ('man', 'though'): 8,
#  ('end', 'one'): 8,
#  ('one', 'simpli'): 8,
#  ('one', 'part'): 8,
#  ('everi', 'one'): 8,
#  ('behind', 'one'): 8,
#  ('one', 'place'): 8,
#  ('one', 'possibl'): 8,
#  ('one', 'see'): 8,
#  ('one', 'round'): 8,
#  ('one', 'whole'): 8,
#  ('much', 'one'): 8,
#  ('mind', 'one'): 8,
#  ('one', 'yet'): 8,
#  ('give', 'one'): 8,
#  ('like', 'man'): 8,
#  ('littl', 'man'): 8,
#  ('away', 'man'): 8,
#  ('man', 'side'): 8,
#  ('could', 'made'): 8,
#  ('even', 'voic'): 8,
#  ('even', 'long'): 8,
#  ('even', 'place'): 8,
#  ('even', 'two'): 8,
#  ('even', 'name'): 8,
#  ('even', 'without'): 8,
#  ('even', 'human'): 8,
#  ('like', 'time'): 8,
#  ('everi', 'time'): 8,
#  ('said', 'time'): 8,
#  ('time', 'work'): 8,
#  ('know', 'way'): 8,
#  ('like', 'turn'): 8,
#  ('like', 'word'): 8,
#  ('like', 'might'): 8,
#  ('littl', 'turn'): 8,
#  ('seem', 'turn'): 8,
#  ('still', 'would'): 8,
#  ('past', 'still'): 8,
#  ('back', 'telescreen'): 8,
#  ('could', 'far'): 8,
#  ('back', 'could'): 8,
#  ('could', 'whether'): 8,
#  ('could', 'want'): 8,
#  ('could', 'live'): 8,
#  ('could', 'must'): 8,
#  ('could', 'power'): 8,
#  ('could', 'happen'): 8,
#  ('could', 'gener'): 8,
#  ('parti', 'world'): 8,
#  ('peopl', 'world'): 8,
#  ('girl', 'littl'): 8,
#  ('away', 'seem'): 8,
#  ('back', 'seem'): 8,
#  ('long', 'seem'): 8,
#  ('seem', 'whole'): 8,
#  ('julia', 'seem'): 8,
#  ('said', 'would'): 8,
#  ('anoth', 'would'): 8,
#  ('away', 'far'): 8,
#  ('far', 'room'): 8,
#  ('place', 'would'): 8,
#  ('three', 'would'): 8,
#  ('two', 'would'): 8,
#  ('come', 'would'): 8,
#  ('ago', 'long'): 8,
#  ('know', 'whether'): 8,
#  ('know', 'without'): 8,
#  ('knew', 'never'): 8,
#  ('hour', 'work'): 8,
#  ('alway', 'never'): 8,
#  ('side', 'sit'): 8,
#  ('might', 'possibl'): 8,
#  ('power', 'three'): 8,
#  ('continu', 'war'): 8,
#  ('never', 'past'): 8,
#  ('control', 'past'): 8,
#  ('parti', 'understand'): 8,
#  ("'m", 'go'): 8,
#  ('hour', 'two'): 8,
#  ('day', 'everi'): 7,
#  ('day', 'would'): 7,
#  ('glass', 'winston'): 7,
#  ('went', 'winston'): 7,
#  ('brother', 'winston'): 7,
#  ('hair', 'winston'): 7,
#  ('behind', 'winston'): 7,
#  ('three', 'winston'): 7,
#  ('took', 'winston'): 7,
#  ('left', 'winston'): 7,
#  ('sit', 'winston'): 7,
#  ('must', 'winston'): 7,
#  ('stop', 'winston'): 7,
#  ('pain', 'winston'): 7,
#  ('alreadi', 'winston'): 7,
#  ('across', 'winston'): 7,
#  ('even', 'though'): 7,
#  ('still', 'though'): 7,
#  ('moment', 'though'): 7,
#  ('knew', 'though'): 7,
#  ('never', 'though'): 7,
#  ('felt', 'though'): 7,
#  ("o'brien", 'though'): 7,
#  ('one', 'use'): 7,
#  ('one', 'still'): 7,
#  ('far', 'one'): 7,
#  ('memori', 'one'): 7,
#  ('one', 'room'): 7,
#  ('love', 'one'): 7,
#  ('feel', 'one'): 7,
#  ('actual', 'one'): 7,
#  ('must', 'one'): 7,
#  ('first', 'one'): 7,
#  ('felt', 'one'): 7,
#  ('come', 'one'): 7,
#  ('name', 'one'): 7,
#  ('peopl', 'simpli'): 7,
#  ('face', 'like'): 7,
#  ('face', 'telescreen'): 7,
#  ('face', 'white'): 7,
#  ('face', 'round'): 7,
#  ('eyes', 'face'): 7,
#  ('face', 'hand'): 7,
#  ('almost', 'face'): 7,
#  ('eye', 'man'): 7,
#  ('back', 'man'): 7,
#  ('man', 'place'): 7,
#  ('man', 'small'): 7,
#  ('made', 'seem'): 7,
#  ('use', 'word'): 7,
#  ('could', 'use'): 7,
#  ('parti', 'use'): 7,
#  ('use', 'without'): 7,
#  ('could', 'tri'): 7,
#  ('even', 'turn'): 7,
#  ('even', 'world'): 7,
#  ('away', 'even'): 7,
#  ('even', 'know'): 7,
#  ('even', 'round'): 7,
#  ('even', 'set'): 7,
#  ('even', 'peopl'): 7,
#  ('even', 'perhap'): 7,
#  ('time', 'way'): 7,
#  ('still', 'time'): 7,
#  ('thought', 'time'): 7,
#  ('round', 'time'): 7,
#  ('parti', 'time'): 7,
#  ('sinc', 'time'): 7,
#  ('must', 'time'): 7,
#  ('might', 'time'): 7,
#  ('almost', 'time'): 7,
#  ('peopl', 'time'): 7,
#  ('rememb', 'time'): 7,
#  ('hour', 'time'): 7,
#  ('anoth', 'way'): 7,
#  ('eye', 'still'): 7,
#  ('away', 'eye'): 7,
#  ('get', 'insid'): 7,
#  ('like', 'world'): 7,
#  ('away', 'like'): 7,
#  ('back', 'like'): 7,
#  ('alway', 'like'): 7,
#  ('life', 'like'): 7,
#  ('turn', 'would'): 7,
#  ('seem', 'still'): 7,
#  ('hand', 'still'): 7,
#  ('could', 'look'): 7,
#  ('could', 'everi'): 7,
#  ('away', 'could'): 7,
#  ('could', 'whole'): 7,
#  ('could', 'woman'): 7,
#  ('could', 'julia'): 7,
#  ('mere', 'parti'): 7,
#  ('party', 'thought'): 7,
#  ('parti', 'party'): 7,
#  ('hair', 'white'): 7,
#  ('look', 'seem'): 7,
#  ('anoth', 'look'): 7,
#  ('eyes', 'look'): 7,
#  ('look', 'might'): 7,
#  ('mind', 'seem'): 7,
#  ('say', 'seem'): 7,
#  ('peopl', 'seem'): 7,
#  ('much', 'said'): 7,
#  ('ever', 'said'): 7,
#  ('dark', 'girl'): 7,
#  ('anoth', 'moment'): 7,
#  ('away', 'would'): 7,
#  ('alway', 'thought'): 7,
#  ('possibl', 'thought'): 7,
#  ('member', 'thought'): 7,
#  ('back', 'behind'): 7,
#  ('back', 'moment'): 7,
#  ('back', 'work'): 7,
#  ('back', 'sat'): 7,
#  ('back', 'two'): 7,
#  ('back', "o'brien"): 7,
#  ('know', 'would'): 7,
#  ('moment', 'would'): 7,
#  ('live', 'would'): 7,
#  ('work', 'would'): 7,
#  ('differ', 'would'): 7,
#  ('appear', 'would'): 7,
#  ('love', 'would'): 7,
#  ('thing', 'would'): 7,
#  ('feel', 'would'): 7,
#  ('hand', 'would'): 7,
#  ('believ', 'would'): 7,
#  ('power', 'would'): 7,
#  ('happen', 'would'): 7,
#  ('person', 'would'): 7,
#  ('perhap', 'would'): 7,
#  ('julia', 'would'): 7,
#  ('long', 'war'): 7,
#  ('never', 'seen'): 7,
#  ('know', 'parti'): 7,
#  ('alway', 'moment'): 7,
#  ('first', 'moment'): 7,
#  ('moment', "o'brien"): 7,
#  ('never', 'place'): 7,
#  ('three', 'war'): 7,
#  ('parti', 'war'): 7,
#  ('necessari', 'war'): 7,
#  ('love', 'make'): 7,
#  ('anyth', 'never'): 7,
#  ('never', 'peopl'): 7,
#  ('hold', 'took'): 7,
#  ('hand', 'took'): 7,
#  ('better', 'thing'): 7,
#  ('thing', 'think'): 7,
#  ('exist', 'past'): 7,
#  ('lie', 'parti'): 7,
#  ('parti', 'two'): 7,
#  ('believ', 'parti'): 7,
#  ('might', 'parti'): 7,
#  ('parti', 'peopl'): 7,
#  ('life', 'parti'): 7,
#  ('hand', 'two'): 7,
#  ('make', 'two'): 7,
#  ('ago', 'two'): 7,
#  ('perhap', 'second'): 7,
#  ("'you", 'say'): 7,
#  ("'i", 'think'): 7,
#  ('ever', 'human'): 7,
#  ('day', 'even'): 6,
#  ('almost', 'day'): 6,
#  ("'the", 'day'): 6,
#  ('right', 'winston'): 6,
#  ('party', 'winston'): 6,
#  ('far', 'winston'): 6,
#  ('well', 'winston'): 6,
#  ('alway', 'winston'): 6,
#  ('air', 'winston'): 6,
#  ('war', 'winston'): 6,
#  ('appear', 'winston'): 6,
#  ('four', 'winston'): 6,
#  ('small', 'winston'): 6,
#  ('lie', 'winston'): 6,
#  ('get', 'winston'): 6,
#  ('believ', 'winston'): 6,
#  ('suddenli', 'winston'): 6,
#  ('front', 'winston'): 6,
#  ('minut', 'winston'): 6,
#  ('peopl', 'winston'): 6,
#  ('perhap', 'winston'): 6,
#  ('ever', 'winston'): 6,
#  ('glass', 'took'): 6,
#  ('back', 'though'): 6,
#  ('round', 'though'): 6,
#  ('though', 'two'): 6,
#  ('hand', 'though'): 6,
#  ('enough', 'time'): 6,
#  ('enough', 'would'): 6,
#  ('made', 'one'): 6,
#  ('move', 'one'): 6,
#  ('big', 'one'): 6,
#  ('one', 'telescreen'): 6,
#  ('mere', 'one'): 6,
#  ('one', 'world'): 6,
#  ('except', 'one'): 6,
#  ('one', 'said'): 6,
#  ('away', 'one'): 6,
#  ('one', 'well'): 6,
#  ('one', 'sort'): 6,
#  ('one', 'quit'): 6,
#  ('newspeak', 'one'): 6,
#  ('one', 'took'): 6,
#  ('eyes', 'one'): 6,
#  ('also', 'one'): 6,
#  ('one', 'year'): 6,
#  ('lie', 'one'): 6,
#  ('member', 'one'): 6,
#  ('one', 'open'): 6,
#  ('one', 'sinc'): 6,
#  ('one', 'woman'): 6,
#  ('minut', 'one'): 6,
#  ('one', 'take'): 6,
#  ('gener', 'one'): 6,
#  ('one', 'person'): 6,
#  ('life', 'one'): 6,
#  ('one', 'stand'): 6,
#  ('one', 'toward'): 6,
#  ('necessari', 'one'): 6,
#  ('julia', 'one'): 6,
#  ('end', 'would'): 6,
#  ('end', 'room'): 6,
#  ('come', 'end'): 6,
#  ('side', 'wall'): 6,
#  ('enorm', 'face'): 6,
#  ('enorm', 'even'): 6,
#  ('face', 'still'): 6,
#  ('away', 'face'): 6,
#  ('face', 'thought'): 6,
#  ('face', 'three'): 6,
#  ('face', 'suddenli'): 6,
#  ('chang', 'face'): 6,
#  ('face', 'power'): 6,
#  ('face', 'think'): 6,
#  ('face', 'light'): 6,
#  ('man', 'would'): 6,
#  ('made', 'parti'): 6,
#  ('made', 'two'): 6,
#  ('even', 'part'): 6,
#  ('even', 'paper'): 6,
#  ('even', 'whether'): 6,
#  ('even', 'live'): 6,
#  ('even', 'sort'): 6,
#  ('even', 'quit'): 6,
#  ('even', 'hold'): 6,
#  ('even', 'kind'): 6,
#  ('even', 'hand'): 6,
#  ('even', 'saw'): 6,
#  ('almost', 'even'): 6,
#  ('come', 'even'): 6,
#  ('even', 'sometim'): 6,
#  ('even', 'exist'): 6,
#  ('even', 'julia'): 6,
#  ('mere', 'time'): 6,
#  ('alway', 'time'): 6,
#  ('differ', 'time'): 6,
#  ('time', 'year'): 6,
#  ('past', 'time'): 6,
#  ('power', 'time'): 6,
#  ('perhap', 'time'): 6,
#  ('time', 'yet'): 6,
#  ('think', 'time'): 6,
#  ('arm', 'right'): 6,
#  ('parti', 'right'): 6,
#  ('could', 'eye'): 6,
#  ('eye', 'seem'): 6,
#  ('back', 'eye'): 6,
#  ('big', 'thought'): 6,
#  ('big', 'sort'): 6,
#  ('brother', 'thought'): 6,
#  ('could', 'insid'): 6,
#  ('could', 'someth'): 6,
#  ('call', 'someth'): 6,
#  ('bodi', 'like'): 6,
#  ('like', 'said'): 6,
#  ('anoth', 'like'): 6,
#  ('like', 'seen'): 6,
#  ('like', 'see'): 6,
#  ('like', 'power'): 6,
#  ("o'brien", 'turn'): 6,
#  ('ever', 'word'): 6,
#  ('back', 'still'): 6,
#  ('almost', 'still'): 6,
#  ('moment', 'telescreen'): 6,
#  ('room', 'telescreen'): 6,
#  ('keep', 'telescreen'): 6,
#  ('could', 'littl'): 6,
#  ('anoth', 'could'): 6,
#  ('could', 'seen'): 6,
#  ('could', 'well'): 6,
#  ('could', 'noth'): 6,
#  ('could', 'war'): 6,
#  ('complet', 'could'): 6,
#  ('arm', 'could'): 6,
#  ('certain', 'could'): 6,
#  ('actual', 'could'): 6,
#  ('could', 'first'): 6,
#  ('could', 'might'): 6,
#  ('could', 'stop'): 6,
#  ('could', 'perhap'): 6,
#  ('could', 'talk'): 6,
#  ('could', 'less'): 6,
#  ('bed', 'could'): 6,
#  ('could', 'done'): 6,
#  ('could', 'hour'): 6,
#  ('could', 'give'): 6,
#  ('bodi', 'feel'): 6,
#  ('party', 'world'): 6,
#  ('member', 'party'): 6,
#  ('littl', 'would'): 6,
#  ('seem', 'thought'): 6,
#  ('room', 'seem'): 6,
#  ('never', 'seem'): 6,
#  ('round', 'seem'): 6,
#  ('parti', 'seem'): 6,
#  ('seem', 'suddenli'): 6,
#  ('power', 'seem'): 6,
#  ('seem', 'woman'): 6,
#  ('except', 'parti'): 6,
#  ('everi', 'parti'): 6,
#  ('said', 'thought'): 6,
#  ('moment', 'said'): 6,
#  ('place', 'said'): 6,
#  ('said', 'see'): 6,
#  ('must', 'said'): 6,
#  ('good', 'said'): 6,
#  ('said', 'without'): 6,
#  ('mean', 'said'): 6,
#  ('matter', 'would'): 6,
#  ('back', 'thought'): 6,
#  ('moment', 'thought'): 6,
#  ('exist', 'thought'): 6,
#  ('behind', 'head'): 6,
#  ('behind', 'hand'): 6,
#  ('back', 'white'): 6,
#  ('alway', 'back'): 6,
#  ('back', 'go'): 6,
#  ('back', 'bed'): 6,
#  ('whether', 'would'): 6,
#  ('lie', 'would'): 6,
#  ('certain', 'would'): 6,
#  ('might', 'would'): 6,
#  ('life', 'would'): 6,
#  ('heart', 'would'): 6,
#  ('bed', 'would'): 6,
#  ('think', 'would'): 6,
#  ('exist', 'would'): 6,
#  ('hour', 'would'): 6,
#  ('know', 'long'): 6,
#  ('say', 'well'): 6,
#  ('know', 'moment'): 6,
#  ('know', 'tell'): 6,
#  ('know', 'never'): 6,
#  ('know', 'say'): 6,
#  ('moment', 'two'): 6,
#  ('almost', 'moment'): 6,
#  ('ever', 'moment'): 6,
#  ('alway', 'oceania'): 6,
#  ('alway', 'kind'): 6,
#  ('differ', 'quit'): 6,
#  ("o'brien", 'side'): 6,
#  ('noth', 'parti'): 6,
#  ('differ', 'make'): 6,
#  ('ago', 'three'): 6,
#  ('sinc', 'war'): 6,
#  ('see', 'thing'): 6,
#  ('see', 'two'): 6,
#  ('act', 'never'): 6,
#  ('almost', 'never'): 6,
#  ('arm', 'head'): 6,
#  ('arm', 'woman'): 6,
#  ('hand', 'round'): 6,
#  ('round', 'suddenli'): 6,
#  ('put', 'round'): 6,
#  ("o'brien", 'took'): 6,
#  ('hand', 'sat'): 6,
#  ('small', 'two'): 6,
#  ('kind', 'might'): 6,
#  ('much', 'perhap'): 6,
#  ('feel', 'lie'): 6,
#  ('parti', 'upon'): 6,
#  ('must', 'parti'): 6,
#  ('parti', 'power'): 6,
#  ('parti', 'say'): 6,
#  ('might', 'two'): 6,
#  ('ever', 'sinc'): 6,
#  ('feel', 'make'): 6,
#  ('almost', 'hand'): 6,
#  ('life', 'upon'): 6,
#  ('mind', "o'brien"): 6,
#  ("'i", 'say'): 6,
#  ('front', 'stand'): 6,
#  ('almost', 'without'): 6,
#  ('gener', 'peopl'): 6,
#  ('walk', 'without'): 6,
#  ('bed', 'light'): 6,
#  ('ever', "o'brien"): 6,
#  ('day', 'winston'): 5,
#  ('day', 'week'): 5,
#  ('day', 'follow'): 5,
#  ('day', 'telescreen'): 5,
#  ('day', 'look'): 5,
#  ('day', 'moment'): 5,
#  ('day', 'minut'): 5,
#  ('enough', 'winston'): 5,
#  ('end', 'winston'): 5,
#  ('wall', 'winston'): 5,
#  ('part', 'winston'): 5,
#  ('move', 'winston'): 5,
#  ('someth', 'winston'): 5,
#  ('winston', 'word'): 5,
#  ('winston', 'world'): 5,
#  ('paper', 'winston'): 5,
#  ('whether', 'winston'): 5,
#  ('white', 'winston'): 5,
#  ('quit', 'winston'): 5,
#  ('got', 'winston'): 5,
#  ('second', 'winston'): 5,
#  ('upon', 'winston'): 5,
#  ('make', 'winston'): 5,
#  ('put', 'winston'): 5,
#  ('ago', 'winston'): 5,
#  ('fact', 'winston'): 5,
#  ('think', 'winston'): 5,
#  ('human', 'winston'): 5,
#  ("'the", 'winston'): 5,
#  ('mother', 'winston'): 5,
#  ("'yes", 'winston'): 5,
#  ('glass', 'like'): 5,
#  ('though', 'tri'): 5,
#  ('eye', 'though'): 5,
#  ('though', 'voic'): 5,
#  ('like', 'though'): 5,
#  ('away', 'though'): 5,
#  ('though', 'thought'): 5,
#  ('though', 'would'): 5,
#  ('say', 'though'): 5,
#  ('almost', 'though'): 5,
#  ('big', 'enough'): 5,
#  ('enough', 'make'): 5,
#  ('old', 'one'): 5,
#  ('got', 'old'): 5,
#  ('almost', 'old'): 5,
#  ("'i", 'old'): 5,
#  ('one', 'wall'): 5,
#  ('eye', 'one'): 5,
#  ('one', 'turn'): 5,
#  ('one', 'party'): 5,
#  ('littl', 'one'): 5,
#  ('live', 'one'): 5,
#  ('ministri', 'one'): 5,
#  ('one', 'work'): 5,
#  ('noth', 'one'): 5,
#  ('head', 'one'): 5,
#  ('one', 'small'): 5,
#  ('one', 'sit'): 5,
#  ('keep', 'one'): 5,
#  ('certain', 'one'): 5,
#  ('act', 'one'): 5,
#  ('one', 'suddenli'): 5,
#  ('great', 'one'): 5,
#  ('one', 'saw'): 5,
#  ('continu', 'one'): 5,
#  ('one', 'perhap'): 5,
#  ('men', 'one'): 5,
#  ('fact', 'one'): 5,
#  ('mean', 'one'): 5,
#  ('confess', 'one'): 5,
#  ('exist', 'one'): 5,
#  ("'i", 'one'): 5,
#  ('new', 'one'): 5,
#  ("o'brien", 'one'): 5,
#  ('hour', 'one'): 5,
#  ('end', 'war'): 5,
#  ('end', 'without'): 5,
#  ('end', 'pain'): 5,
#  ('like', 'simpli'): 5,
#  ('enorm', 'never'): 5,
#  ('face', 'way'): 5,
#  ('big', 'face'): 5,
#  ('brother', 'face'): 5,
#  ('face', 'someth'): 5,
#  ('came', 'face'): 5,
#  ('face', 'said'): 5,
#  ('dark', 'face'): 5,
#  ('face', 'would'): 5,
#  ('face', 'might'): 5,
#  ('man', 'turn'): 5,
#  ('look', 'man'): 5,
#  ('left', 'man'): 5,
#  ('full', 'man'): 5,
#  ('last', 'man'): 5,
#  ('made', 'mind'): 5,
#  ('made', 'say'): 5,
#  ('party', 'use'): 5,
#  ('littl', 'use'): 5,
#  ('newspeak', 'use'): 5,
#  ('make', 'use'): 5,
#  ('time', 'tri'): 5,
#  ('keep', 'tri'): 5,
#  ('even', 'week'): 5,
#  ('even', 'eye'): 5,
#  ('even', 'someth'): 5,
#  ('even', 'street'): 5,
#  ('anoth', 'even'): 5,
#  ('even', 'matter'): 5,
#  ('even', 'seen'): 5,
#  ('even', 'knew'): 5,
#  ('even', 'ministri'): 5,
#  ('even', 'newspeak'): 5,
#  ('differ', 'even'): 5,
#  ('even', 'possibl'): 5,
#  ('even', 'war'): 5,
#  ('complet', 'even'): 5,
#  ('even', 'four'): 5,
#  ('even', 'got'): 5,
#  ('even', 'small'): 5,
#  ('even', 'past'): 5,
#  ('even', 'much'): 5,
#  ('even', 'get'): 5,
#  ('even', 'open'): 5,
#  ('even', 'sinc'): 5,
#  ('certain', 'even'): 5,
#  ('even', 'suddenli'): 5,
#  ('even', 'mind'): 5,
#  ('even', 'happen'): 5,
#  ('even', 'pain'): 5,
#  ('even', 'yet'): 5,
#  ('even', 'heart'): 5,
#  ('even', 'think'): 5,
#  ('done', 'even'): 5,
#  ('even', 'hour'): 5,
#  ('time', 'went'): 5,
#  ('big', 'time'): 5,
#  ('brother', 'time'): 5,
#  ('came', 'time'): 5,
#  ('anoth', 'time'): 5,
#  ('time', 'whether'): 5,
#  ('time', 'want'): 5,
#  ('ministri', 'time'): 5,
#  ('possibl', 'time'): 5,
#  ('time', 'war'): 5,
#  ('much', 'time'): 5,
#  ('get', 'time'): 5,
#  ('feel', 'time'): 5,
#  ('name', 'time'): 5,
#  ('person', 'time'): 5,
#  ('life', 'time'): 5,
#  ('bed', 'time'): 5,
#  ('becom', 'time'): 5,
#  ('mean', 'time'): 5,
#  ('done', 'time'): 5,
#  ('hate', 'would'): 5,
#  ('week', 'would'): 5,
#  ('week', 'work'): 5,
#  ('went', 'work'): 5,
#  ('still', 'way'): 5,
#  ('differ', 'way'): 5,
#  ('possibl', 'way'): 5,
#  ('never', 'way'): 5,
#  ('member', 'way'): 5,
#  ('almost', 'way'): 5,
#  ('eye', 'see'): 5,
#  ('eye', 'open'): 5,
#  ('follow', 'would'): 5,
#  ('like', 'move'): 5,
#  ('could', 'move'): 5,
#  ('big', 'party'): 5,
#  ('big', 'look'): 5,
#  ('big', 'moment'): 5,
#  ('brother', 'party'): 5,
#  ('brother', 'sort'): 5,
#  ('feel', 'insid'): 5,
#  ('still', 'voic'): 5,
#  ('could', 'voic'): 5,
#  ('seem', 'voic'): 5,
#  ('moment', 'voic'): 5,
#  ('look', 'someth'): 5,
#  ('seem', 'someth'): 5,
#  ('happen', 'someth'): 5,
#  ('like', 'long'): 5,
#  ('like', 'whether'): 5,
#  ('like', 'quit'): 5,
#  ('like', 'room'): 5,
#  ('like', 'never'): 5,
#  ('left', 'like'): 5,
#  ('like', 'thing'): 5,
#  ('like', 'past'): 5,
#  ('like', 'suddenli'): 5,
#  ('anyth', 'like'): 5,
#  ('felt', 'like'): 5,
#  ('girl', 'like'): 5,
#  ('like', 'pass'): 5,
#  ('like', 'talk'): 5,
#  ('look', 'turn'): 5,
#  ('look', 'word'): 5,
#  ('know', 'word'): 5,
#  ('pass', 'word'): 5,
#  ('without', 'word'): 5,
#  ('still', 'telescreen'): 5,
#  ('still', 'world'): 5,
#  ('knew', 'still'): 5,
#  ('never', 'still'): 5,
#  ('keep', 'still'): 5,
#  ('less', 'still'): 5,
#  ('bed', 'still'): 5,
#  ('could', 'matter'): 5,
#  ...}

# %%
import matplotlib.pyplot as plt

pair_count = []
for pair, count in new4.items():
    pair_count.append(count)
    
plt.figure(figsize=(20,10))
plt.plot(sorted(pair_count, reverse=True))

plt.title('Pair Count')
plt.ylabel('pair count')
plt.xlabel('rank')
plt.show()

# %%
#単語順位チェック
word_f = sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)

word_fdic = dict(word_f)
word_fdic
# Out:
# {'winston': 523,
#  'one': 412,
#  'could': 402,
#  'said': 341,
#  'would': 338,
#  'even': 320,
#  'time': 227,
#  'face': 219,
#  'like': 218,
#  'parti': 199,
#  'thought': 191,
#  "o'brien": 191,
#  'seem': 187,
#  'look': 172,
#  'never': 169,
#  'moment': 163,
#  'two': 157,
#  'know': 155,
#  'back': 152,
#  'man': 147,
#  'still': 145,
#  'alway': 133,
#  'thing': 129,
#  'way': 126,
#  'war': 124,
#  'hand': 122,
#  'though': 121,
#  'might': 118,
#  'almost': 117,
#  'say': 115,
#  'make': 114,
#  'long': 109,
#  'day': 107,
#  'old': 106,
#  'made': 106,
#  'littl': 106,
#  'knew': 106,
#  'see': 106,
#  'round': 106,
#  'year': 106,
#  'power': 106,
#  'turn': 104,
#  'must': 104,
#  'place': 103,
#  'mind': 103,
#  'three': 102,
#  'past': 101,
#  'away': 100,
#  'work': 99,
#  'world': 97,
#  'ever': 97,
#  'telescreen': 96,
#  'come': 96,
#  'julia': 95,
#  'eye': 94,
#  'word': 94,
#  "'i": 94,
#  'kind': 92,
#  'big': 91,
#  'feel': 91,
#  'without': 91,
#  'everi': 90,
#  'someth': 89,
#  'go': 89,
#  'anoth': 87,
#  'rememb': 87,
#  'get': 85,
#  "'you": 85,
#  'use': 84,
#  'room': 84,
#  'perhap': 84,
#  'end': 83,
#  'party': 82,
#  'peopl': 82,
#  'life': 81,
#  'voic': 80,
#  'happen': 80,
#  'brother': 79,
#  'much': 79,
#  'first': 78,
#  'pain': 77,
#  'think': 77,
#  'came': 76,
#  'exist': 76,
#  'got': 75,
#  'girl': 75,
#  'human': 73,
#  'side': 70,
#  'mere': 69,
#  'sort': 69,
#  'right': 68,
#  'seen': 68,
#  'went': 67,
#  'except': 67,
#  'whole': 66,
#  'head': 64,
#  'enough': 63,
#  'also': 63,
#  'white': 62,
#  'four': 62,
#  'love': 62,
#  'call': 62,
#  'take': 61,
#  'ministri': 60,
#  'arm': 60,
#  'sinc': 60,
#  'woman': 59,
#  'becom': 59,
#  'want': 58,
#  'possibl': 58,
#  'member': 58,
#  'yet': 58,
#  "'it": 58,
#  'hour': 58,
#  'glass': 57,
#  'well': 57,
#  'noth': 57,
#  'chang': 57,
#  'put': 57,
#  'bed': 57,
#  'tri': 56,
#  'bodi': 56,
#  'oceania': 56,
#  'appear': 56,
#  'took': 56,
#  'need': 56,
#  'fact': 56,
#  'street': 55,
#  'far': 55,
#  'quit': 55,
#  'small': 55,
#  'suddenli': 55,
#  'behind': 54,
#  'whether': 54,
#  'differ': 54,
#  'actual': 54,
#  'act': 54,
#  'minut': 54,
#  'good': 53,
#  'saw': 53,
#  'felt': 53,
#  'live': 52,
#  'sat': 52,
#  'anyth': 52,
#  'stop': 52,
#  'sometim': 52,
#  'talk': 52,
#  'mean': 52,
#  'lie': 51,
#  'control': 51,
#  'air': 50,
#  'alreadi': 50,
#  'walk': 50,
#  'simpli': 49,
#  'open': 49,
#  'continu': 49,
#  'across': 49,
#  'paper': 48,
#  'matter': 48,
#  'hold': 48,
#  'everyth': 48,
#  'name': 48,
#  'true': 48,
#  'men': 48,
#  'wall': 47,
#  'hate': 47,
#  'hair': 47,
#  'began': 47,
#  'book': 47,
#  'believ': 47,
#  'light': 47,
#  'give': 47,
#  'necessari': 47,
#  'newspeak': 46,
#  'certain': 46,
#  'last': 46,
#  'new': 46,
#  'understand': 46,
#  "'yes": 46,
#  'tell': 45,
#  'sit': 45,
#  'second': 45,
#  'ago': 45,
#  'heart': 45,
#  'better': 45,
#  'confess': 45,
#  'done': 45,
#  "'the": 45,
#  'week': 44,
#  'keep': 44,
#  'upon': 44,
#  'great': 44,
#  'toward': 44,
#  'set': 43,
#  'front': 43,
#  'gener': 43,
#  "'m": 43,
#  'door': 42,
#  'present': 42,
#  'memori': 42,
#  'left': 42,
#  'children': 42,
#  'stand': 42,
#  'five': 42,
#  'part': 41,
#  'follow': 41,
#  'move': 41,
#  'insid': 41,
#  'complet': 41,
#  'death': 41,
#  'full': 41,
#  'pass': 41,
#  'person': 41,
#  'less': 41,
#  'mother': 41,
#  'speak': 41,
#  'enorm': 40,
#  'black': 40,
#  'dark': 40,
#  'eyes': 40,
#  'longer': 40,
#  'remain': 39,
#  'tabl': 39,
#  'piec': 39,
#  'question': 39,
#  'gave': 38,
#  'floor': 38,
#  'years': 38,
#  'somewher': 38,
#  'mani': 38,
#  'shall': 38,
#  'stood': 37,
#  'next': 37,
#  'start': 37,
#  'group': 37,
#  'inner': 37,
#  'eurasia': 37,
#  'another': 37,
#  'truth': 36,
#  'occur': 36,
#  'half': 36,
#  'reason': 36,
#  'taken': 36,
#  'carri': 36,
#  'care': 36,
#  'soon': 36,
#  'read': 35,
#  'heard': 35,
#  'movement': 35,
#  'age': 35,
#  'prole': 35,
#  'young': 35,
#  'later': 35,
#  'syme': 35,
#  'larg': 34,
#  'watch': 34,
#  'imposs': 34,
#  'water': 34,
#  'held': 34,
#  'real': 34,
#  'sure': 34,
#  'record': 34,
#  'goldstein': 34,
#  'lay': 34,
#  'brought': 34,
#  'dream': 34,
#  'dead': 34,
#  'ten': 34,
#  'within': 33,
#  'kept': 33,
#  'gin': 33,
#  'gone': 33,
#  'case': 33,
#  'fear': 33,
#  'eastasia': 33,
#  'mouth': 33,
#  'step': 33,
#  'us': 33,
#  'natur': 32,
#  'sound': 32,
#  'realli': 32,
#  'smell': 32,
#  'usual': 32,
#  'middl': 32,
#  'danger': 32,
#  'near': 32,
#  'whose': 32,
#  'victori': 31,
#  'pick': 31,
#  'bomb': 31,
#  'voice': 31,
#  'produc': 31,
#  'finger': 31,
#  'hundr': 31,
#  'cell': 31,
#  'opposit': 30,
#  'probabl': 30,
#  'point': 30,
#  'idea': 30,
#  'top': 30,
#  'known': 30,
#  "'ll": 30,
#  'effort': 29,
#  'window': 29,
#  'outsid': 29,
#  'rule': 29,
#  'written': 29,
#  'night': 29,
#  'let': 29,
#  'shout': 29,
#  'fill': 29,
#  'thirti': 29,
#  'happened': 29,
#  'interest': 29,
#  'crowd': 29,
#  'told': 29,
#  "'what": 29,
#  'sever': 28,
#  'leav': 28,
#  'suppos': 28,
#  'doublethink': 28,
#  'women': 28,
#  'evid': 28,
#  'table': 28,
#  'may': 28,
#  'physic': 28,
#  'push': 28,
#  'body': 28,
#  'prison': 28,
#  'corner': 27,
#  'deep': 27,
#  'becam': 27,
#  'nearli': 27,
#  'abl': 27,
#  'either': 27,
#  'feet': 27,
#  'sleep': 27,
#  'line': 27,
#  'notic': 27,
#  "'that": 27,
#  'london': 26,
#  'thousand': 26,
#  'guard': 26,
#  'course': 26,
#  'wonder': 26,
#  'among': 26,
#  'nose': 26,
#  'kill': 26,
#  'shoulder': 26,
#  'ca': 26,
#  'earlier': 26,
#  'shut': 25,
#  'ingsoc': 25,
#  'given': 25,
#  'often': 25,
#  'fell': 25,
#  'quarter': 25,
#  'short': 25,
#  'boy': 25,
#  'mass': 25,
#  "'we": 25,
#  'meet': 25,
#  'number': 25,
#  "'no": 25,
#  'immedi': 24,
#  'instant': 24,
#  'polic': 24,
#  'people': 24,
#  'home': 24,
#  'run': 24,
#  'although': 24,
#  'hope': 24,
#  'somehow': 24,
#  'contain': 24,
#  'boot': 24,
#  'struck': 24,
#  'everyon': 24,
#  'histori': 24,
#  'process': 24,
#  'charrington': 24,
#  'vagu': 23,
#  'freedom': 23,
#  'order': 23,
#  'die': 23,
#  'glanc': 23,
#  'write': 23,
#  'forgotten': 23,
#  'job': 23,
#  'enemi': 23,
#  'words': 23,
#  'found': 23,
#  'ask': 23,
#  'help': 23,
#  'els': 23,
#  'hardli': 23,
#  'parson': 23,
#  'six': 23,
#  'times': 23,
#  'touch': 23,
#  'metr': 22,
#  'gaze': 22,
#  'however': 22,
#  'cours': 22,
#  'instinct': 22,
#  'stuff': 22,
#  'date': 22,
#  'listen': 22,
#  'music': 22,
#  'show': 22,
#  'import': 22,
#  'press': 22,
#  'exactli': 22,
#  'brotherhood': 22,
#  'secret': 22,
#  'nothing': 22,
#  'fall': 22,
#  'close': 22,
#  "'d": 22,
#  'float': 22,
#  'whatev': 22,
#  'broken': 22,
#  'difficult': 22,
#  'learn': 22,
#  'singl': 21,
#  'sight': 21,
#  'begin': 21,
#  'police': 21,
#  'alone': 21,
#  'betray': 21,
#  'eurasian': 21,
#  'direct': 21,
#  'realiz': 21,
#  'hands': 21,
#  'hear': 21,
#  'caught': 21,
#  'imagin': 21,
#  'pocket': 21,
#  'obvious': 21,
#  'days': 21,
#  'fight': 21,
#  "'and": 21,
#  'societi': 21,
#  "'do": 21,
#  'cold': 20,
#  'dust': 20,
#  'rest': 20,
#  'figur': 20,
#  'form': 20,
#  'skin': 20,
#  'cover': 20,
#  'vast': 20,
#  'object': 20,
#  'possess': 20,
#  'lost': 20,
#  'final': 20,
#  'today': 20,
#  'realiti': 20,
#  'break': 20,
#  'conscious': 20,
#  'sister': 20,
#  'meant': 20,
#  'drop': 20,
#  'silent': 20,
#  'bit': 20,
#  'ad': 20,
#  'pull': 20,
#  'togeth': 20,
#  'alter': 20,
#  'grown': 20,
#  'afternoon': 20,
#  'alon': 20,
#  'bell': 20,
#  'high': 20,
#  'heavi': 19,
#  'cut': 19,
#  'flat': 19,
#  'anything': 19,
#  'low': 19,
#  'clear': 19,
#  'wear': 19,
#  'awar': 19,
#  'food': 19,
#  'stay': 19,
#  'shop': 19,
#  'things': 19,
#  'consciou': 19,
#  'child': 19,
#  'equal': 19,
#  'chair': 19,
#  'bring': 19,
#  'beyond': 19,
#  'revolut': 19,
#  'grow': 19,
#  'possible': 19,
#  'shoot': 19,
#  'yes': 19,
#  'tear': 19,
#  'youth': 19,
#  'rais': 19,
#  'answer': 19,
#  'recogn': 19,
#  'period': 19,
#  'earli': 19,
#  'public': 19,
#  'allow': 19,
#  'aim': 19,
#  'prepar': 18,
#  'sun': 18,
#  'law': 18,
#  'express': 18,
#  'swallow': 18,
#  'normal': 18,
#  'beauti': 18,
#  'wrote': 18,
#  'sens': 18,
#  'commun': 18,
#  'nobodi': 18,
#  'coupl': 18,
#  'aliv': 18,
#  'forward': 18,
#  'messag': 18,
#  'breath': 18,
#  'sweat': 18,
#  'fragment': 18,
#  'find': 18,
#  'minutes': 18,
#  'cloth': 18,
#  'together': 18,
#  'pure': 18,
#  "'there": 18,
#  'knee': 18,
#  'expect': 18,
#  'million': 18,
#  'proles': 18,
#  'play': 18,
#  'grew': 18,
#  'slip': 17,
#  'colour': 17,
#  'poster': 17,
#  'seven': 17,
#  'blue': 17,
#  'rate': 17,
#  'peac': 17,
#  'bread': 17,
#  'save': 17,
#  'desir': 17,
#  'free': 17,
#  'diary': 17,
#  'huge': 17,
#  'impress': 17,
#  'curious': 17,
#  'polit': 17,
#  'teeth': 17,
#  'cri': 17,
#  'violent': 17,
#  'utter': 17,
#  'faint': 17,
#  'event': 17,
#  'commit': 17,
#  'parsons': 17,
#  'yell': 17,
#  'month': 17,
#  'knowledg': 17,
#  'earth': 17,
#  'invent': 17,
#  'reach': 17,
#  'class': 17,
#  'problem': 17,
#  'photograph': 17,
#  'destroy': 17,
#  'wish': 17,
#  'st': 17,
#  'smile': 17,
#  'clock': 16,
#  'pictur': 16,
#  'remember': 16,
#  'news': 16,
#  'cigarett': 16,
#  'thick': 16,
#  'instead': 16,
#  'least': 16,
#  'helpless': 16,
#  'militari': 16,
#  'hole': 16,
#  'stream': 16,
#  'spi': 16,
#  'edg': 16,
#  'crime': 16,
#  'demand': 16,
#  'wait': 16,
#  'straight': 16,
#  'flung': 16,
#  'difference': 16,
#  'sooner': 16,
#  'stupid': 16,
#  'blow': 16,
#  'forc': 16,
#  'rocket': 16,
#  'principl': 16,
#  'shape': 16,
#  'strong': 16,
#  'th': 16,
#  'forth': 16,
#  'tube': 16,
#  'accept': 16,
#  "i'v": 16,
#  'copi': 16,
#  'defeat': 16,
#  'till': 16,
#  'fingers': 16,
#  'members': 16,
#  'effect': 16,
#  'dial': 16,
#  'breast': 15,
#  'along': 15,
#  'hours': 15,
#  'ran': 15,
#  'called': 15,
#  'razor': 15,
#  'outside': 15,
#  'level': 15,
#  'fit': 15,
#  'individu': 15,
#  'strength': 15,
#  'tini': 15,
#  'pour': 15,
#  'apart': 15,
#  'future': 15,
#  'futur': 15,
#  'curiou': 15,
#  'dare': 15,
#  'hous': 15,
#  'rubbish': 15,
#  'department': 15,
#  'waist': 15,
#  'overalls': 15,
#  'manner': 15,
#  'burst': 15,
#  'march': 15,
#  'books': 15,
#  'state': 15,
#  'subject': 15,
#  'murmur': 15,
#  'deliber': 15,
#  'slightli': 15,
#  'common': 15,
#  'someon': 15,
#  'issu': 15,
#  'roar': 15,
#  'twenti': 15,
#  'memory': 15,
#  'intellectu': 15,
#  'tree': 15,
#  'bare': 15,
#  'claim': 15,
#  'forget': 15,
#  'easi': 15,
#  'agre': 15,
#  'special': 15,
#  'coffee': 15,
#  "'how": 15,
#  '101': 15,
#  'beneath': 14,
#  'metal': 14,
#  'slogan': 14,
#  'frighten': 14,
#  'hidden': 14,
#  'cross': 14,
#  'partli': 14,
#  'suggest': 14,
#  'doubt': 14,
#  'origin': 14,
#  'caus': 14,
#  'corridor': 14,
#  'spectacl': 14,
#  'belief': 14,
#  'indeed': 14,
#  'speech': 14,
#  'occasion': 14,
#  'seconds': 14,
#  'hatr': 14,
#  'mention': 14,
#  'existence': 14,
#  'capabl': 14,
#  'draw': 14,
#  'everything': 14,
#  'already': 14,
#  'wife': 14,
#  'filthi': 14,
#  'stopped': 14,
#  'remark': 14,
#  'bad': 14,
#  'chocol': 14,
#  'fro': 14,
#  'wander': 14,
#  'rather': 14,
#  'stir': 14,
#  'fifti': 14,
#  'definit': 14,
#  'slowli': 14,
#  'brain': 14,
#  'roll': 14,
#  'revolution': 14,
#  'coat': 14,
#  'accord': 14,
#  'pavement': 14,
#  'astonish': 14,
#  'fail': 14,
#  'paperweight': 14,
#  'sing': 14,
#  'safe': 14,
#  'overal': 13,
#  'blade': 13,
#  'sky': 13,
#  'vision': 13,
#  'popul': 13,
#  'entir': 13,
#  'posit': 13,
#  'ordinari': 13,
#  'impossible': 13,
#  'liter': 13,
#  'flash': 13,
#  'kick': 13,
#  'narrow': 13,
#  'brien': 13,
#  'neck': 13,
#  'gestur': 13,
#  'anyon': 13,
#  'disappeared': 13,
#  'endless': 13,
#  'refer': 13,
#  'rose': 13,
#  'paus': 13,
#  'feeling': 13,
#  'existed': 13,
#  'arrest': 13,
#  'hard': 13,
#  'report': 13,
#  'pieces': 13,
#  "'they": 13,
#  'organ': 13,
#  "'a": 13,
#  "you'r": 13,
#  'asleep': 13,
#  'appeal': 13,
#  'instance': 13,
#  'struggl': 13,
#  'fallen': 13,
#  'tortur': 13,
#  'wrong': 13,
#  'ampleforth': 13,
#  'song': 13,
#  'comrad': 13,
#  'disappear': 13,
#  'happening': 13,
#  'clasp': 13,
#  'beer': 13,
#  'century': 13,
#  'labour': 13,
#  "'but": 13,
#  'fix': 13,
#  'martin': 13,
#  'best': 12,
#  'product': 12,
#  'helicopt': 12,
#  'plan': 12,
#  'whenev': 12,
#  'habit': 12,
#  'darkness': 12,
#  'larger': 12,
#  'ground': 12,
#  'outer': 12,
#  'canteen': 12,
#  'yellow': 12,
#  'born': 12,
#  'page': 12,
#  'scream': 12,
#  'morn': 12,
#  'spoken': 12,
#  'ones': 12,
#  'depart': 12,
#  'machin': 12,
#  'besides': 12,
#  'wave': 12,
#  'broke': 12,
#  'slow': 12,
#  'met': 12,
#  'hatred': 12,
#  'trial': 12,
#  'laid': 12,
#  'worst': 12,
#  'constantli': 12,
#  'dirti': 12,
#  'clean': 12,
#  'morning': 12,
#  'enemy': 12,
#  'victory': 12,
#  'ration': 12,
#  'detail': 12,
#  'return': 12,
#  'note': 12,
#  'empti': 12,
#  'late': 12,
#  'countri': 12,
#  'grasp': 12,
#  "'em": 12,
#  'example': 12,
#  'africa': 12,
#  'ear': 12,
#  'main': 12,
#  'standard': 12,
#  'assum': 12,
#  'others': 12,
#  'reality': 12,
#  'drink': 12,
#  'easili': 12,
#  'eat': 12,
#  'fire': 12,
#  'telescreens': 12,
#  'practic': 12,
#  'impuls': 12,
#  'buy': 12,
#  'church': 12,
#  'centuri': 12,
#  'cheek': 12,
#  'dear': 12,
#  'super-st': 12,
#  'mental': 12,
#  'cage': 12,
#  'smith': 11,
#  'quickli': 11,
#  'prevent': 11,
#  'sank': 11,
#  'uniform': 11,
#  'plaster': 11,
#  'command': 11,
#  'wire': 11,
#  'kilometr': 11,
#  'childhood': 11,
#  'ignor': 11,
#  'govern': 11,
#  'concern': 11,
#  'offici': 11,
#  'kitchen': 11,
#  'red': 11,
#  'intend': 11,
#  'older': 11,
#  'bought': 11,
#  'particular': 11,
#  'shot': 11,
#  'suffer': 11,
#  'diari': 11,
#  'drag': 11,
#  'large': 11,
#  'screen': 11,
#  'engag': 11,
#  'thin': 11,
#  'attack': 11,
#  'faces': 11,
#  'terribl': 11,
#  'avoid': 11,
#  'smash': 11,
#  'emot': 11,
#  'wrench': 11,
#  'horror': 11,
#  'action': 11,
#  'essenti': 11,
#  'conceal': 11,
#  'seiz': 11,
#  'attempt': 11,
#  'sink': 11,
#  'dress': 11,
#  'hang': 11,
#  'h': 11,
#  'creatur': 11,
#  'therefor': 11,
#  'belong': 11,
#  'privat': 11,
#  'different': 11,
#  'altered': 11,
#  'opinion': 11,
#  'ultim': 11,
#  'capitalist': 11,
#  'perfectli': 11,
#  'scrap': 11,
#  'led': 11,
#  'materi': 11,
#  'nearer': 11,
#  'spoke': 11,
#  'nevertheless': 11,
#  'solid': 11,
#  'chanc': 11,
#  'train': 11,
#  'lamp': 11,
#  'rutherford': 11,
#  'ceas': 11,
#  'yard': 11,
#  'clement': 11,
#  'difficulti': 11,
#  'conquer': 11,
#  'rat': 11,
#  'twentieth': 11,
#  'wealth': 11,
#  'lift': 10,
#  'current': 10,
#  'varicos': 10,
#  'surfac': 10,
#  'switch': 10,
#  'instrument': 10,
#  'torn': 10,
#  'distanc': 10,
#  'system': 10,
#  'structur': 10,
#  'similar': 10,
#  'bottl': 10,
#  'mark': 10,
#  'belli': 10,
#  'smooth': 10,
#  'deal': 10,
#  'pen': 10,
#  'panic': 10,
#  'comfort': 10,
#  'lot': 10,
#  'eleven': 10,
#  'cubicl': 10,
#  'fiction': 10,
#  'movements': 10,
#  'manag': 10,
#  'spite': 10,
#  'recal': 10,
#  'dozen': 10,
#  'fresh': 10,
#  'fade': 10,
#  'intellig': 10,
#  'else': 10,
#  'besid': 10,
#  'contact': 10,
#  'slid': 10,
#  'success': 10,
#  'invari': 10,
#  'hurri': 10,
#  'warm': 10,
#  'block': 10,
#  'game': 10,
#  'wood': 10,
#  'send': 10,
#  'flit': 10,
#  'announc': 10,
#  'reduc': 10,
#  'cent': 10,
#  'alive': 10,
#  'woke': 10,
#  'fifteen': 10,
#  'trust': 10,
#  'involv': 10,
#  'sent': 10,
#  'throughout': 10,
#  'rhyme': 10,
#  'triumph': 10,
#  'refus': 10,
#  'convers': 10,
#  'tray': 10,
#  "we'r": 10,
#  'bone': 10,
#  'vaporized': 10,
#  'bloodi': 10,
#  'happi': 10,
#  'elbow': 10,
#  "'if": 10,
#  'rich': 10,
#  'condit': 10,
#  'area': 10,
#  'singing': 10,
#  'says': 10,
#  'ai': 10,
#  'folly': 10,
#  "'e": 10,
#  'soft': 10,
#  'society': 10,
#  'bench': 10,
#  'guards': 10,
#  'chinless': 10,
#  'escap': 9,
#  'wind': 9,
#  'rag': 9,
#  'wide': 9,
#  'seldom': 9,
#  'list': 9,
#  'somewhat': 9,
#  'patrol': 9,
#  'receiv': 9,
#  'field': 9,
#  'iron': 9,
#  'seri': 9,
#  'build': 9,
#  'steel': 9,
#  'lunch': 9,
#  'scarlet': 9,
#  'burn': 9,
#  'packet': 9,
#  ...}

# %%
count = 0
s_value = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    s_value.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
count = 0
p_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    p = (word_fdic[i[0]]  * word_fdic[i[1]]) * s * s
    p_values.append(p)
    
    count += 1
    
    if count == 1000:
        break

# %%
max(p_values)
# Out:
# 0.7012101822228405

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(p_values)

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_value)

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
s_value_top_5 = sorted(s_value, reverse=True)[:6]
s_value_top_5
# Out:
# [0.009876199749617471,
#  0.005851063829787234,
#  0.005516154452324665,
#  0.005031446540880503,
#  0.004859086491739553,
#  0.004838709677419355]

# %%
print(s_value.index(s_value_top_5[0]))
print(s_value.index(s_value_top_5[1]))
print(s_value.index(s_value_top_5[2]))
print(s_value.index(s_value_top_5[3]))
print(s_value.index(s_value_top_5[4]))
# Out:
# 0
# 172
# 85
# 20
# 189

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[0]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == "big":
        print(i,j)
    elif i ==  'brother':
        print(i,j)
# Out:
# ('big', 'brother') 71
# big 91
# brother 79

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[1]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'dark':
        print(i,j)
    elif i ==  "hair":
        print(i,j)
# Out:
# ('dark', 'hair') 11
# hair 47
# dark 40

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[2]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'hate':
        print(i,j)
    elif i ==  'minut':
        print(i,j)
# Out:
# ('hate', 'minut') 14
# minut 54
# hate 47

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[3]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'ago':
        print(i,j)
    elif i ==  'year':
        print(i,j)
# Out:
# ('ago', 'year') 24
# year 106
# ago 45

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[4]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'door':
        print(i,j)
    elif i ==  'open':
        print(i,j)
# Out:
# ('door', 'open') 10
# open 49
# door 42

# %%
from math import log
log_list = [log(y,10) for y in s_value]

#take a log
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_list, reverse=True))

plt.ylabel('s value(log scale)')
plt.xlabel('rank (Descending order of s value)')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(log_list)+1)
y = sorted(log_list, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('s value(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
from math import log

sorted_list = sorted(s_value, reverse=True)
sorted_list

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_value)+1)]


#take a log
import matplotlib.pyplot as plt
import numpy as np

x = np.array(log_x[:-700])
y = np.array(log_list[:-700])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
# i,j count
import numpy as np

len(word_f)
# Out:
# 8183

# %%
i = np.arange(len(word_f), 0, -1)
j = np.arange(1,len(word_f)+1, 1)

def square(list):
    return [i ** -2 for i in list]
square(i)
# Out:
# [1.4933957039097502e-08,
#  1.4937607703885946e-08,
#  1.4941259707467167e-08,
#  1.4944913050495874e-08,
#  1.4948567733627165e-08,
#  1.4952223757516559e-08,
#  1.4955881122819953e-08,
#  1.4959539830193666e-08,
#  1.4963199880294399e-08,
#  1.4966861273779276e-08,
#  1.4970524011305798e-08,
#  1.4974188093531892e-08,
#  1.4977853521115874e-08,
#  1.4981520294716466e-08,
#  1.4985188414992796e-08,
#  1.4988857882604387e-08,
#  1.4992528698211177e-08,
#  1.4996200862473503e-08,
#  1.4999874376052101e-08,
#  1.5003549239608123e-08,
#  1.5007225453803115e-08,
#  1.5010903019299037e-08,
#  1.5014581936758252e-08,
#  1.5018262206843523e-08,
#  1.5021943830218025e-08,
#  1.5025626807545342e-08,
#  1.5029311139489457e-08,
#  1.5032996826714766e-08,
#  1.5036683869886071e-08,
#  1.504037226966858e-08,
#  1.5044062026727912e-08,
#  1.5047753141730093e-08,
#  1.5051445615341553e-08,
#  1.5055139448229139e-08,
#  1.5058834641060104e-08,
#  1.5062531194502104e-08,
#  1.5066229109223215e-08,
#  1.5069928385891917e-08,
#  1.5073629025177105e-08,
#  1.5077331027748078e-08,
#  1.5081034394274552e-08,
#  1.5084739125426649e-08,
#  1.5088445221874909e-08,
#  1.5092152684290276e-08,
#  1.5095861513344116e-08,
#  1.5099571709708196e-08,
#  1.5103283274054708e-08,
#  1.5106996207056247e-08,
#  1.5110710509385827e-08,
#  1.5114426181716876e-08,
#  1.511814322472323e-08,
#  1.5121861639079149e-08,
#  1.5125581425459297e-08,
#  1.512930258453876e-08,
#  1.513302511699304e-08,
#  1.5136749023498048e-08,
#  1.5140474304730116e-08,
#  1.5144200961365991e-08,
#  1.5147928994082841e-08,
#  1.5151658403558239e-08,
#  1.5155389190470189e-08,
#  1.51591213554971e-08,
#  1.5162854899317811e-08,
#  1.5166589822611565e-08,
#  1.5170326126058038e-08,
#  1.5174063810337314e-08,
#  1.5177802876129897e-08,
#  1.518154332411672e-08,
#  1.5185285154979122e-08,
#  1.518902836939887e-08,
#  1.5192772968058152e-08,
#  1.519651895163957e-08,
#  1.5200266320826156e-08,
#  1.520401507630135e-08,
#  1.5207765218749029e-08,
#  1.5211516748853476e-08,
#  1.5215269667299415e-08,
#  1.5219023974771971e-08,
#  1.5222779671956709e-08,
#  1.5226536759539608e-08,
#  1.5230295238207072e-08,
#  1.5234055108645929e-08,
#  1.5237816371543433e-08,
#  1.5241579027587257e-08,
#  1.5245343077465506e-08,
#  1.5249108521866704e-08,
#  1.5252875361479801e-08,
#  1.5256643596994172e-08,
#  1.5260413229099623e-08,
#  1.5264184258486384e-08,
#  1.5267956685845103e-08,
#  1.5271730511866867e-08,
#  1.5275505737243185e-08,
#  1.5279282362665992e-08,
#  1.528306038882765e-08,
#  1.5286839816420953e-08,
#  1.5290620646139121e-08,
#  1.5294402878675802e-08,
#  1.5298186514725079e-08,
#  1.5301971554981454e-08,
#  1.5305758000139863e-08,
#  1.5309545850895679e-08,
#  1.5313335107944695e-08,
#  1.5317125771983139e-08,
#  1.532091784370767e-08,
#  1.5324711323815379e-08,
#  1.5328506213003788e-08,
#  1.5332302511970849e-08,
#  1.5336100221414946e-08,
#  1.5339899342034903e-08,
#  1.5343699874529964e-08,
#  1.5347501819599816e-08,
#  1.5351305177944577e-08,
#  1.5355109950264799e-08,
#  1.5358916137261466e-08,
#  1.5362723739636e-08,
#  1.5366532758090254e-08,
#  1.5370343193326517e-08,
#  1.5374155046047516e-08,
#  1.5377968316956414e-08,
#  1.53817830067568e-08,
#  1.5385599116152719e-08,
#  1.5389416645848633e-08,
#  1.5393235596549452e-08,
#  1.5397055968960521e-08,
#  1.5400877763787622e-08,
#  1.5404700981736972e-08,
#  1.5408525623515233e-08,
#  1.5412351689829504e-08,
#  1.5416179181387319e-08,
#  1.5420008098896653e-08,
#  1.5423838443065922e-08,
#  1.5427670214603985e-08,
#  1.5431503414220131e-08,
#  1.5435338042624098e-08,
#  1.5439174100526068e-08,
#  1.5443011588636654e-08,
#  1.5446850507666922e-08,
#  1.5450690858328367e-08,
#  1.5454532641332936e-08,
#  1.5458375857393019e-08,
#  1.5462220507221444e-08,
#  1.5466066591531483e-08,
#  1.5469914111036855e-08,
#  1.5473763066451721e-08,
#  1.5477613458490683e-08,
#  1.548146528786879e-08,
#  1.548531855530154e-08,
#  1.5489173261504875e-08,
#  1.5493029407195172e-08,
#  1.5496886993089273e-08,
#  1.5500746019904446e-08,
#  1.550460648835842e-08,
#  1.5508468399169368e-08,
#  1.5512331753055902e-08,
#  1.5516196550737094e-08,
#  1.5520062792932456e-08,
#  1.5523930480361948e-08,
#  1.5527799613745986e-08,
#  1.5531670193805424e-08,
#  1.5535542221261573e-08,
#  1.5539415696836193e-08,
#  1.5543290621251493e-08,
#  1.554716699523013e-08,
#  1.5551044819495214e-08,
#  1.5554924094770303e-08,
#  1.5558804821779415e-08,
#  1.5562687001247006e-08,
#  1.5566570633897999e-08,
#  1.5570455720457753e-08,
#  1.5574342261652095e-08,
#  1.5578230258207296e-08,
#  1.5582119710850085e-08,
#  1.5586010620307636e-08,
#  1.558990298730759e-08,
#  1.5593796812578031e-08,
#  1.5597692096847507e-08,
#  1.5601588840845008e-08,
#  1.5605487045299997e-08,
#  1.5609386710942379e-08,
#  1.5613287838502519e-08,
#  1.5617190428711242e-08,
#  1.5621094482299824e-08,
#  1.5624999999999999e-08,
#  1.5628906982543965e-08,
#  1.5632815430664369e-08,
#  1.563672534509432e-08,
#  1.5640636726567386e-08,
#  1.5644549575817594e-08,
#  1.564846389357943e-08,
#  1.5652379680587835e-08,
#  1.5656296937578218e-08,
#  1.5660215665286443e-08,
#  1.5664135864448835e-08,
#  1.5668057535802179e-08,
#  1.5671980680083719e-08,
#  1.5675905298031173e-08,
#  1.5679831390382706e-08,
#  1.5683758957876952e-08,
#  1.5687688001253008e-08,
#  1.569161852125043e-08,
#  1.5695550518609242e-08,
#  1.5699483994069928e-08,
#  1.5703418948373441e-08,
#  1.5707355382261192e-08,
#  1.5711293296475059e-08,
#  1.5715232691757389e-08,
#  1.5719173568850988e-08,
#  1.5723115928499132e-08,
#  1.5727059771445561e-08,
#  1.5731005098434485e-08,
#  1.5734951910210573e-08,
#  1.5738900207518973e-08,
#  1.574284999110529e-08,
#  1.57468012617156e-08,
#  1.575075402009645e-08,
#  1.5754708266994851e-08,
#  1.5758664003158289e-08,
#  1.5762621229334712e-08,
#  1.5766579946272541e-08,
#  1.5770540154720668e-08,
#  1.5774501855428457e-08,
#  1.5778465049145738e-08,
#  1.5782429736622811e-08,
#  1.5786395918610457e-08,
#  1.5790363595859919e-08,
#  1.5794332769122912e-08,
#  1.5798303439151634e-08,
#  1.5802275606698744e-08,
#  1.5806249272517379e-08,
#  1.5810224437361147e-08,
#  1.581420110198414e-08,
#  1.5818179267140908e-08,
#  1.5822158933586488e-08,
#  1.5826140102076388e-08,
#  1.583012277336659e-08,
#  1.5834106948213556e-08,
#  1.5838092627374218e-08,
#  1.5842079811605985e-08,
#  1.5846068501666754e-08,
#  1.5850058698314881e-08,
#  1.5854050402309211e-08,
#  1.5858043614409069e-08,
#  1.5862038335374251e-08,
#  1.5866034565965031e-08,
#  1.5870032306942167e-08,
#  1.5874031559066898e-08,
#  1.5878032323100938e-08,
#  1.5882034599806477e-08,
#  1.5886038389946195e-08,
#  1.589004369428325e-08,
#  1.5894050513581274e-08,
#  1.5898058848604392e-08,
#  1.5902068700117198e-08,
#  1.5906080068884778e-08,
#  1.5910092955672699e-08,
#  1.5914107361247006e-08,
#  1.5918123286374233e-08,
#  1.5922140731821392e-08,
#  1.5926159698355988e-08,
#  1.5930180186745998e-08,
#  1.5934202197759893e-08,
#  1.5938225732166626e-08,
#  1.5942250790735639e-08,
#  1.5946277374236853e-08,
#  1.5950305483440682e-08,
#  1.5954335119118018e-08,
#  1.595836628204025e-08,
#  1.5962398972979251e-08,
#  1.5966433192707375e-08,
#  1.5970468941997477e-08,
#  1.5974506221622886e-08,
#  1.5978545032357434e-08,
#  1.5982585374975426e-08,
#  1.5986627250251672e-08,
#  1.5990670658961465e-08,
#  1.5994715601880589e-08,
#  1.5998762079785316e-08,
#  1.6002810093452411e-08,
#  1.6006859643659133e-08,
#  1.601091073118323e-08,
#  1.6014963356802941e-08,
#  1.6019017521297002e-08,
#  1.6023073225444639e-08,
#  1.6027130470025571e-08,
#  1.6031189255820011e-08,
#  1.6035249583608666e-08,
#  1.6039311454172736e-08,
#  1.6043374868293918e-08,
#  1.6047439826754408e-08,
#  1.6051506330336886e-08,
#  1.605557437982454e-08,
#  1.6059643976001047e-08,
#  1.6063715119650583e-08,
#  1.6067787811557821e-08,
#  1.6071862052507932e-08,
#  1.6075937843286581e-08,
#  1.6080015184679941e-08,
#  1.608409407747467e-08,
#  1.6088174522457933e-08,
#  1.6092256520417395e-08,
#  1.609634007214122e-08,
#  1.6100425178418069e-08,
#  1.6104511840037104e-08,
#  1.6108600057787993e-08,
#  1.6112689832460897e-08,
#  1.6116781164846483e-08,
#  1.6120874055735921e-08,
#  1.6124968505920888e-08,
#  1.612906451619355e-08,
#  1.6133162087346585e-08,
#  1.6137261220173176e-08,
#  1.614136191546701e-08,
#  1.6145464174022269e-08,
#  1.6149567996633656e-08,
#  1.615367338409636e-08,
#  1.615778033720609e-08,
#  1.6161888856759053e-08,
#  1.6165998943551968e-08,
#  1.6170110598382059e-08,
#  1.6174223822047048e-08,
#  1.6178338615345179e-08,
#  1.6182454979075194e-08,
#  1.6186572914036348e-08,
#  1.6190692421028401e-08,
#  1.6194813500851621e-08,
#  1.6198936154306789e-08,
#  1.6203060382195194e-08,
#  1.620718618531864e-08,
#  1.6211313564479431e-08,
#  1.6215442520480387e-08,
#  1.6219573054124845e-08,
#  1.6223705166216646e-08,
#  1.6227838857560143e-08,
#  1.6231974128960211e-08,
#  1.6236110981222222e-08,
#  1.6240249415152078e-08,
#  1.6244389431556181e-08,
#  1.6248531031241455e-08,
#  1.6252674215015339e-08,
#  1.6256818983685778e-08,
#  1.626096533806124e-08,
#  1.626511327895071e-08,
#  1.6269262807163681e-08,
#  1.6273413923510171e-08,
#  1.6277566628800704e-08,
#  1.6281720923846338e-08,
#  1.628587680945863e-08,
#  1.6290034286449665e-08,
#  1.6294193355632046e-08,
#  1.6298354017818892e-08,
#  1.6302516273823846e-08,
#  1.6306680124461061e-08,
#  1.6310845570545223e-08,
#  1.6315012612891525e-08,
#  1.6319181252315693e-08,
#  1.6323351489633962e-08,
#  1.6327523325663097e-08,
#  1.6331696761220386e-08,
#  1.6335871797123632e-08,
#  1.6340048434191165e-08,
#  1.6344226673241841e-08,
#  1.6348406515095031e-08,
#  1.6352587960570641e-08,
#  1.6356771010489089e-08,
#  1.636095566567133e-08,
#  1.6365141926938839e-08,
#  1.6369329795113611e-08,
#  1.6373519271018174e-08,
#  1.6377710355475584e-08,
#  1.6381903049309414e-08,
#  1.6386097353343774e-08,
#  1.6390293268403294e-08,
#  1.6394490795313144e-08,
#  1.6398689934899004e-08,
#  1.6402890687987099e-08,
#  1.6407093055404176e-08,
#  1.6411297037977512e-08,
#  1.6415502636534916e-08,
#  1.6419709851904727e-08,
#  1.642391868491581e-08,
#  1.6428129136397565e-08,
#  1.6432341207179928e-08,
#  1.6436554898093361e-08,
#  1.6440770209968857e-08,
#  1.644498714363795e-08,
#  1.6449205699932702e-08,
#  1.6453425879685705e-08,
#  1.6457647683730091e-08,
#  1.646187111289953e-08,
#  1.6466096168028213e-08,
#  1.6470322849950878e-08,
#  1.6474551159502798e-08,
#  1.6478781097519778e-08,
#  1.6483012664838162e-08,
#  1.6487245862294829e-08,
#  1.6491480690727197e-08,
#  1.6495717150973224e-08,
#  1.6499955243871401e-08,
#  1.6504194970260762e-08,
#  1.6508436330980875e-08,
#  1.6512679326871855e-08,
#  1.6516923958774351e-08,
#  1.6521170227529558e-08,
#  1.65254181339792e-08,
#  1.6529667678965556e-08,
#  1.6533918863331437e-08,
#  1.6538171687920201e-08,
#  1.6542426153575749e-08,
#  1.6546682261142518e-08,
#  1.6550940011465499e-08,
#  1.6555199405390216e-08,
#  1.6559460443762739e-08,
#  1.6563723127429691e-08,
#  1.6567987457238231e-08,
#  1.6572253434036066e-08,
#  1.6576521058671454e-08,
#  1.6580790331993185e-08,
#  1.6585061254850613e-08,
#  1.6589333828093626e-08,
#  1.6593608052572665e-08,
#  1.6597883929138719e-08,
#  1.6602161458643327e-08,
#  1.6606440641938568e-08,
#  1.6610721479877082e-08,
#  1.6615003973312051e-08,
#  1.6619288123097204e-08,
#  1.6623573930086834e-08,
#  1.6627861395135768e-08,
#  1.6632150519099398e-08,
#  1.6636441302833657e-08,
#  1.6640733747195037e-08,
#  1.6645027853040585e-08,
#  1.6649323621227886e-08,
#  1.6653621052615099e-08,
#  1.6657920148060926e-08,
#  1.6662220908424616e-08,
#  1.666652333456599e-08,
#  1.6670827427345409e-08,
#  1.6675133187623795e-08,
#  1.667944061626263e-08,
#  1.6683749714123947e-08,
#  1.6688060482070339e-08,
#  1.6692372920964952e-08,
#  1.6696687031671495e-08,
#  1.670100281505423e-08,
#  1.6705320271977984e-08,
#  1.6709639403308133e-08,
#  1.6713960209910627e-08,
#  1.671828269265196e-08,
#  1.6722606852399199e-08,
#  1.6726932690019962e-08,
#  1.6731260206382436e-08,
#  1.6735589402355367e-08,
#  1.6739920278808059e-08,
#  1.6744252836610384e-08,
#  1.6748587076632775e-08,
#  1.6752922999746227e-08,
#  1.6757260606822301e-08,
#  1.6761599898733118e-08,
#  1.6765940876351372e-08,
#  1.6770283540550309e-08,
#  1.6774627892203758e-08,
#  1.6778973932186098e-08,
#  1.6783321661372284e-08,
#  1.6787671080637833e-08,
#  1.679202219085883e-08,
#  1.679637499291193e-08,
#  1.6800729487674355e-08,
#  1.6805085676023895e-08,
#  1.6809443558838911e-08,
#  1.6813803136998329e-08,
#  1.6818164411381653e-08,
#  1.6822527382868947e-08,
#  1.6826892052340857e-08,
#  1.6831258420678589e-08,
#  1.6835626488763927e-08,
#  1.6839996257479232e-08,
#  1.6844367727707425e-08,
#  1.6848740900332013e-08,
#  1.6853115776237069e-08,
#  1.685749235630724e-08,
#  1.686187064142775e-08,
#  1.6866250632484399e-08,
#  1.6870632330363557e-08,
#  1.6875015735952175e-08,
#  1.6879400850137777e-08,
#  1.6883787673808465e-08,
#  1.6888176207852917e-08,
#  1.6892566453160392e-08,
#  1.6896958410620727e-08,
#  1.6901352081124326e-08,
#  1.6905747465562188e-08,
#  1.6910144564825885e-08,
#  1.6914543379807565e-08,
#  1.6918943911399956e-08,
#  1.6923346160496378e-08,
#  1.6927750127990719e-08,
#  1.6932155814777455e-08,
#  1.6936563221751642e-08,
#  1.6940972349808921e-08,
#  1.6945383199845513e-08,
#  1.6949795772758223e-08,
#  1.6954210069444444e-08,
#  1.6958626090802147e-08,
#  1.6963043837729893e-08,
#  1.6967463311126826e-08,
#  1.6971884511892676e-08,
#  1.6976307440927757e-08,
#  1.698073209913297e-08,
#  1.698515848740981e-08,
#  1.6989586606660352e-08,
#  1.6994016457787263e-08,
#  1.6998448041693792e-08,
#  1.7002881359283787e-08,
#  1.7007316411461679e-08,
#  1.7011753199132491e-08,
#  1.7016191723201829e-08,
#  1.7020631984575903e-08,
#  1.7025073984161505e-08,
#  1.7029517722866023e-08,
#  1.7033963201597432e-08,
#  1.7038410421264304e-08,
#  1.7042859382775804e-08,
#  1.7047310087041691e-08,
#  1.7051762534972311e-08,
#  1.7056216727478618e-08,
#  1.7060672665472147e-08,
#  1.7065130349865036e-08,
#  1.7069589781570017e-08,
#  1.7074050961500421e-08,
#  1.7078513890570173e-08,
#  1.7082978569693794e-08,
#  1.7087444999786408e-08,
#  1.7091913181763729e-08,
#  1.7096383116542078e-08,
#  1.7100854805038369e-08,
#  1.7105328248170124e-08,
#  1.7109803446855453e-08,
#  1.7114280402013077e-08,
#  1.7118759114562313e-08,
#  1.7123239585423083e-08,
#  1.7127721815515903e-08,
#  1.7132205805761902e-08,
#  1.7136691557082807e-08,
#  1.7141179070400947e-08,
#  1.7145668346639257e-08,
#  1.7150159386721275e-08,
#  1.7154652191571147e-08,
#  1.7159146762113621e-08,
#  1.7163643099274048e-08,
#  1.7168141203978395e-08,
#  1.7172641077153226e-08,
#  1.7177142719725716e-08,
#  1.7181646132623649e-08,
#  1.7186151316775417e-08,
#  1.7190658273110016e-08,
#  1.719516700255706e-08,
#  1.7199677506046763e-08,
#  1.7204189784509952e-08,
#  1.7208703838878071e-08,
#  1.7213219670083169e-08,
#  1.7217737279057907e-08,
#  1.7222256666735555e-08,
#  1.7226777834050004e-08,
#  1.7231300781935752e-08,
#  1.723582551132791e-08,
#  1.7240352023162206e-08,
#  1.724488031837498e-08,
#  1.7249410397903189e-08,
#  1.7253942262684404e-08,
#  1.7258475913656811e-08,
#  1.7263011351759215e-08,
#  1.7267548577931038e-08,
#  1.7272087593112314e-08,
#  1.7276628398243701e-08,
#  1.728117099426647e-08,
#  1.7285715382122518e-08,
#  1.7290261562754355e-08,
#  1.7294809537105113e-08,
#  1.7299359306118548e-08,
#  1.7303910870739026e-08,
#  1.7308464231911544e-08,
#  1.7313019390581719e-08,
#  1.7317576347695786e-08,
#  1.7322135104200611e-08,
#  1.7326695661043675e-08,
#  1.7331258019173085e-08,
#  1.7335822179537577e-08,
#  1.7340388143086503e-08,
#  1.7344955910769847e-08,
#  1.7349525483538215e-08,
#  1.7354096862342845e-08,
#  1.7358670048135593e-08,
#  1.7363245041868948e-08,
#  1.7367821844496027e-08,
#  1.7372400456970569e-08,
#  1.7376980880246953e-08,
#  1.7381563115280174e-08,
#  1.7386147163025869e-08,
#  1.7390733024440293e-08,
#  1.739532070048034e-08,
#  1.7399910192103533e-08,
#  1.7404501500268031e-08,
#  1.7409094625932613e-08,
#  1.74136895700567e-08,
#  1.7418286333600349e-08,
#  1.7422884917524243e-08,
#  1.7427485322789705e-08,
#  1.7432087550358686e-08,
#  1.7436691601193777e-08,
#  1.7441297476258207e-08,
#  1.7445905176515835e-08,
#  1.7450514702931162e-08,
#  1.7455126056469321e-08,
#  1.7459739238096089e-08,
#  1.7464354248777875e-08,
#  1.7468971089481728e-08,
#  1.7473589761175345e-08,
#  1.7478210264827045e-08,
#  1.7482832601405805e-08,
#  1.7487456771881232e-08,
#  1.749208277722358e-08,
#  1.7496710618403741e-08,
#  1.7501340296393248e-08,
#  1.7505971812164282e-08,
#  1.7510605166689665e-08,
#  1.7515240360942863e-08,
#  1.7519877395897983e-08,
#  1.7524516272529781e-08,
#  1.7529156991813656e-08,
#  1.7533799554725655e-08,
#  1.7538443962242465e-08,
#  1.7543090215341434e-08,
#  1.7547738315000537e-08,
#  1.7552388262198419e-08,
#  1.7557040057914355e-08,
#  1.756169370312828e-08,
#  1.756634919882077e-08,
#  1.7571006545973063e-08,
#  1.7575665745567036e-08,
#  1.7580326798585221e-08,
#  1.7584989706010801e-08,
#  1.7589654468827614e-08,
#  1.7594321088020148e-08,
#  1.7598989564573543e-08,
#  1.7603659899473595e-08,
#  1.7608332093706753e-08,
#  1.761300614826012e-08,
#  1.7617682064121457e-08,
#  1.7622359842279176e-08,
#  1.7627039483722347e-08,
#  1.7631720989440698e-08,
#  1.7636404360424615e-08,
#  1.7641089597665138e-08,
#  1.764577670215397e-08,
#  1.7650465674883472e-08,
#  1.7655156516846655e-08,
#  1.7659849229037208e-08,
#  1.7664543812449462e-08,
#  1.7669240268078422e-08,
#  1.7673938596919745e-08,
#  1.7678638799969755e-08,
#  1.7683340878225441e-08,
#  1.7688044832684451e-08,
#  1.7692750664345094e-08,
#  1.7697458374206351e-08,
#  1.770216796326786e-08,
#  1.7706879432529929e-08,
#  1.7711592782993527e-08,
#  1.7716308015660296e-08,
#  1.7721025131532535e-08,
#  1.7725744131613224e-08,
#  1.7730465016906e-08,
#  1.7735187788415167e-08,
#  1.7739912447145706e-08,
#  1.7744638994103263e-08,
#  1.774936743029415e-08,
#  1.7754097756725364e-08,
#  1.7758829974404553e-08,
#  1.7763564084340053e-08,
#  1.7768300087540862e-08,
#  1.7773037985016654e-08,
#  1.7777777777777777e-08,
#  1.7782519466835254e-08,
#  1.778726305320078e-08,
#  1.7792008537886721e-08,
#  1.7796755921906125e-08,
#  1.7801505206272716e-08,
#  1.7806256392000889e-08,
#  1.7811009480105718e-08,
#  1.7815764471602954e-08,
#  1.7820521367509031e-08,
#  1.7825280168841055e-08,
#  1.7830040876616811e-08,
#  1.7834803491854775e-08,
#  1.7839568015574085e-08,
#  1.7844334448794575e-08,
#  1.7849102792536756e-08,
#  1.7853873047821814e-08,
#  1.7858645215671626e-08,
#  1.7863419297108748e-08,
#  1.7868195293156423e-08,
#  1.7872973204838572e-08,
#  1.7877753033179803e-08,
#  1.7882534779205417e-08,
#  1.7887318443941385e-08,
#  1.7892104028414378e-08,
#  1.789689153365175e-08,
#  1.7901680960681536e-08,
#  1.7906472310532466e-08,
#  1.791126558423396e-08,
#  1.7916060782816119e-08,
#  1.792085790730974e-08,
#  1.7925656958746307e-08,
#  1.7930457938157995e-08,
#  1.7935260846577672e-08,
#  1.7940065685038897e-08,
#  1.794487245457592e-08,
#  1.7949681156223686e-08,
#  1.7954491791017832e-08,
#  1.7959304359994687e-08,
#  1.796411886419128e-08,
#  1.7968935304645328e-08,
#  1.7973753682395253e-08,
#  1.7978573998480163e-08,
#  1.7983396253939869e-08,
#  1.7988220449814881e-08,
#  1.7993046587146397e-08,
#  1.7997874666976328e-08,
#  1.8002704690347268e-08,
#  1.8007536658302525e-08,
#  1.8012370571886101e-08,
#  1.8017206432142695e-08,
#  1.8022044240117715e-08,
#  1.8026883996857266e-08,
#  1.8031725703408152e-08,
#  1.803656936081789e-08,
#  1.8041414970134693e-08,
#  1.8046262532407478e-08,
#  1.8051112048685872e-08,
#  1.8055963520020199e-08,
#  1.8060816947461498e-08,
#  1.8065672332061511e-08,
#  1.8070529674872682e-08,
#  1.8075388976948167e-08,
#  1.8080250239341832e-08,
#  1.8085113463108249e-08,
#  1.8089978649302699e-08,
#  1.8094845798981173e-08,
#  1.8099714913200373e-08,
#  1.8104585993017712e-08,
#  1.8109459039491314e-08,
#  1.8114334053680018e-08,
#  1.8119211036643369e-08,
#  1.8124089989441631e-08,
#  1.8128970913135779e-08,
#  1.8133853808787505e-08,
#  1.8138738677459215e-08,
#  1.8143625520214029e-08,
#  1.8148514338115786e-08,
#  1.815340513222904e-08,
#  1.8158297903619061e-08,
#  1.8163192653351836e-08,
#  1.8168089382494075e-08,
#  1.8172988092113208e-08,
#  1.8177888783277376e-08,
#  1.8182791457055446e-08,
#  1.8187696114517011e-08,
#  1.8192602756732371e-08,
#  1.8197511384772566e-08,
#  1.8202421999709344e-08,
#  1.8207334602615181e-08,
#  1.8212249194563281e-08,
#  1.8217165776627562e-08,
#  1.8222084349882678e-08,
#  1.8227004915404004e-08,
#  1.8231927474267641e-08,
#  1.8236852027550414e-08,
#  1.8241778576329877e-08,
#  1.8246707121684317e-08,
#  1.8251637664692741e-08,
#  1.8256570206434891e-08,
#  1.8261504747991233e-08,
#  1.8266441290442973e-08,
#  1.8271379834872039e-08,
#  1.8276320382361092e-08,
#  1.8281262933993526e-08,
#  1.8286207490853468e-08,
#  1.8291154054025777e-08,
#  1.8296102624596047e-08,
#  1.8301053203650606e-08,
#  1.8306005792276516e-08,
#  1.8310960391561578e-08,
#  1.8315917002594323e-08,
#  1.8320875626464022e-08,
#  1.8325836264260686e-08,
#  1.833079891707506e-08,
#  1.8335763585998628e-08,
#  1.8340730272123617e-08,
#  1.8345698976542989e-08,
#  1.8350669700350446e-08,
#  1.8355642444640437e-08,
#  1.8360617210508147e-08,
#  1.8365593999049507e-08,
#  1.8370572811361186e-08,
#  1.8375553648540598e-08,
#  1.8380536511685905e-08,
#  1.8385521401896007e-08,
#  1.8390508320270557e-08,
#  1.8395497267909943e-08,
#  1.8400488245915313e-08,
#  1.8405481255388549e-08,
#  1.8410476297432291e-08,
#  1.8415473373149921e-08,
#  1.8420472483645566e-08,
#  1.8425473630024118e-08,
#  1.8430476813391201e-08,
#  1.84354820348532e-08,
#  1.8440489295517251e-08,
#  1.8445498596491233e-08,
#  1.8450509938883794e-08,
#  1.8455523323804318e-08,
#  1.8460538752362947e-08,
#  1.846555622567059e-08,
#  1.8470575744838896e-08,
#  1.8475597310980275e-08,
#  1.8480620925207891e-08,
#  1.8485646588635671e-08,
#  1.8490674302378293e-08,
#  1.8495704067551196e-08,
#  1.8500735885270572e-08,
#  1.8505769756653383e-08,
#  1.8510805682817343e-08,
#  1.8515843664880932e-08,
#  1.8520883703963382e-08,
#  1.8525925801184691e-08,
#  1.853096995766563e-08,
#  1.8536016174527714e-08,
#  1.8541064452893238e-08,
#  1.8546114793885249e-08,
#  1.8551167198627571e-08,
#  1.8556221668244782e-08,
#  1.8561278203862231e-08,
#  1.8566336806606037e-08,
#  1.857139747760308e-08,
#  1.8576460217981015e-08,
#  1.8581525028868257e-08,
#  1.8586591911394e-08,
#  1.8591660866688197e-08,
#  1.8596731895881583e-08,
#  1.8601805000105658e-08,
#  1.8606880180492693e-08,
#  1.861195743817573e-08,
#  1.8617036774288592e-08,
#  1.8622118189965867e-08,
#  1.8627201686342922e-08,
#  1.8632287264555898e-08,
#  1.8637374925741711e-08,
#  1.8642464671038051e-08,
#  1.8647556501583391e-08,
#  1.865265041851698e-08,
#  1.8657746422978835e-08,
#  1.8662844516109767e-08,
#  1.8667944699051356e-08,
#  1.8673046972945966e-08,
#  1.8678151338936742e-08,
#  1.8683257798167605e-08,
#  1.8688366351783268e-08,
#  1.8693477000929216e-08,
#  1.8698589746751723e-08,
#  1.8703704590397848e-08,
#  1.8708821533015429e-08,
#  1.8713940575753095e-08,
#  1.8719061719760258e-08,
#  1.8724184966187119e-08,
#  1.8729310316184659e-08,
#  1.8734437770904655e-08,
#  1.8739567331499667e-08,
#  1.8744698999123046e-08,
#  1.8749832774928939e-08,
#  1.875496866007227e-08,
#  1.8760106655708763e-08,
#  1.8765246762994933e-08,
#  1.8770388983088087e-08,
#  1.877553331714632e-08,
#  1.878067976632853e-08,
#  1.8785828331794398e-08,
#  1.8790979014704412e-08,
#  1.8796131816219845e-08,
#  1.8801286737502772e-08,
#  1.8806443779716061e-08,
#  1.8811602944023387e-08,
#  1.8816764231589207e-08,
#  1.8821927643578794e-08,
#  1.8827093181158206e-08,
#  1.8832260845494312e-08,
#  1.8837430637754777e-08,
#  1.8842602559108066e-08,
#  1.884777661072345e-08,
#  1.8852952793771001e-08,
#  1.885813110942159e-08,
#  1.8863311558846903e-08,
#  1.8868494143219417e-08,
#  1.887367886371243e-08,
#  1.8878865721500031e-08,
#  1.8884054717757124e-08,
#  1.8889245853659422e-08,
#  1.8894439130383439e-08,
#  1.8899634549106505e-08,
#  1.8904832111006754e-08,
#  1.8910031817263136e-08,
#  1.8915233669055403e-08,
#  1.8920437667564126e-08,
#  1.8925643813970686e-08,
#  1.8930852109457278e-08,
#  1.8936062555206908e-08,
#  1.8941275152403395e-08,
#  1.8946489902231375e-08,
#  1.8951706805876303e-08,
#  1.8956925864524444e-08,
#  1.896214707936288e-08,
#  1.8967370451579518e-08,
#  1.8972595982363074e-08,
#  1.897782367290309e-08,
#  1.8983053524389921e-08,
#  1.8988285538014747e-08,
#  1.8993519714969569e-08,
#  1.8998756056447204e-08,
#  1.90039945636413e-08,
#  1.900923523774632e-08,
#  1.9014478079957552e-08,
#  1.9019723091471116e-08,
#  1.9024970273483947e-08,
#  1.903021962719381e-08,
#  1.9035471153799299e-08,
#  1.9040724854499824e-08,
#  1.9045980730495641e-08,
#  1.9051238782987816e-08,
#  1.9056499013178257e-08,
#  1.9061761422269693e-08,
#  1.9067026011465689e-08,
#  1.907229278197064e-08,
#  1.9077561734989774e-08,
#  1.9082832871729148e-08,
#  1.9088106193395654e-08,
#  1.9093381701197015e-08,
#  1.9098659396341796e-08,
#  1.9103939280039393e-08,
#  1.9109221353500032e-08,
#  1.9114505617934788e-08,
#  1.9119792074555564e-08,
#  1.9125080724575104e-08,
#  1.913037156920699e-08,
#  1.9135664609665641e-08,
#  1.9140959847166328e-08,
#  1.9146257282925145e-08,
#  1.9151556918159037e-08,
#  1.91568587540858e-08,
#  1.9162162791924052e-08,
#  1.9167469032893273e-08,
#  1.9172777478213782e-08,
#  1.9178088129106737e-08,
#  1.9183400986794147e-08,
#  1.918871605249887e-08,
#  1.9194033327444604e-08,
#  1.9199352812855901e-08,
#  1.9204674509958162e-08,
#  1.920999841997763e-08,
#  1.9215324544141404e-08,
#  1.9220652883677434e-08,
#  1.922598343981452e-08,
#  1.9231316213782311e-08,
#  1.9236651206811313e-08,
#  1.9241988420132885e-08,
#  1.9247327854979237e-08,
#  1.9252669512583438e-08,
#  1.9258013394179412e-08,
#  1.9263359501001936e-08,
#  1.9268707834286648e-08,
#  1.9274058395270039e-08,
#  1.9279411185189462e-08,
#  1.9284766205283135e-08,
#  1.9290123456790124e-08,
#  1.9295482940950362e-08,
#  1.9300844659004645e-08,
#  1.9306208612194625e-08,
#  1.9311574801762822e-08,
#  1.931694322895262e-08,
#  1.9322313895008264e-08,
#  1.9327686801174867e-08,
#  1.9333061948698406e-08,
#  1.9338439338825721e-08,
#  1.9343818972804525e-08,
#  1.9349200851883396e-08,
#  1.9354584977311783e-08,
#  1.9359971350339997e-08,
#  1.9365359972219229e-08,
#  1.9370750844201536e-08,
#  1.9376143967539845e-08,
#  ...]

# %%
middle = len(square(j)) / 2
print(int(middle))

middle = len(square(i)) / 2
print (int(middle))
# Out:
# 4091
# 4091

# %%
square(j)[int(middle)]
# Out:
# 5.9721230849790115e-08

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (int(middle)**2) / (x)

myu = integrate.quad(computePi, 1, int(middle)**2)

# 結果にはintegrated value and estimation error
myu
# Out:
# (278376058.6966643, 0.05925422119560153)

# %%
(4091**2) * log(4091**2)
# Out:
# 278376058.6966643

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (5.9721230849790115e-08**2) / (x)

myu = integrate.quad(computePi, 1, (5.9721230849790115e-08**2))
print(myu)
# Out:
# (-2.9980254338108795e-14, 3.334994626392314e-14)
