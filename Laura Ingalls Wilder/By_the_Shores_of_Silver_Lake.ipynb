# %%
# https://biblio.wiki/wiki/By_the_Shores_of_Silver_Lake
import nltk
from nltk.corpus import stopwords
import math
# %matplotlib inline

raw1 = open('By_the_Shores_of_Silver_Lake.txt').read()

# %%
tokens1 = nltk.word_tokenize(raw1)
sentence1 = nltk.sent_tokenize(raw1)

# %%
#The number of token
len(tokens1)
# Out:
# 71530

# %%
len(sentence1)
# Out:
# 3768

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer() #to make base form

tokens_low = [w.lower() for w in tokens1]

#The number of sort of words
len(set(tokens_low))

#複数形や過去形を別の単語としてカウントしてしまっているため，実際の異なり語数はさらに少ない
# Out:
# 4712

# %%
print (len(set(tokens_low))/len(tokens1))
# Out:
# 0.06587445826925765

# %%
list1 = [tokens1]

text = []
for i in list1:
    text.append(nltk.Text(i))
    
freq_list = []
for i in text:
    freq_list.append(nltk.FreqDist(w.lower() for w in i))

stopwords = nltk.corpus.stopwords.words('english')
symbols = ["'", '"', '`', '.', ',', '-', '!', '?', ':', ';', '(', ')', '...', "'s", '’', '”', '“','–','—', '…', '*' ,'``', "''",'--','mr.',"n't", 'dr.','sir', '‘', 'mr', 'm.' ]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#順位チェック
sorted(freq_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('laura', 687),
#  ('said', 642),
#  ('pa', 524),
#  ('mary', 249),
#  ('carrie', 198),
#  ('little', 190),
#  ('could', 177),
#  ('one', 173),
#  ('boast', 162),
#  ('came', 154),
#  ('back', 147),
#  ('go', 145),
#  ('would', 145),
#  ('big', 141),
#  ('went', 137),
#  ('grace', 122),
#  ('men', 115),
#  ('come', 114),
#  ('get', 114),
#  ('see', 113),
#  ('door', 109),
#  ('like', 107),
#  ('going', 105),
#  ('wagon', 103),
#  ('time', 101),
#  ('away', 99),
#  ('house', 94),
#  ('around', 93),
#  ('long', 91),
#  ('well', 88),
#  ('mrs.', 88),
#  ('good', 87),
#  ('man', 87),
#  ('prairie', 87),
#  ('got', 86),
#  ('night', 86),
#  ('pa.', 85),
#  ('know', 84),
#  ('asked', 83),
#  ('made', 82),
#  ('put', 81),
#  ('never', 80),
#  ('must', 79),
#  ('lake', 79),
#  ('every', 77),
#  ('day', 77),
#  ('morning', 74),
#  ('two', 74),
#  ('looked', 73),
#  ('wind', 73),
#  ('lena', 73),
#  ('caroline', 72),
#  ('told', 68),
#  ('grass', 67),
#  ('last', 67),
#  ('shanty', 66),
#  ('water', 65),
#  ('oh', 64),
#  ('make', 64),
#  ('let', 63),
#  ('behind', 63),
#  ('eyes', 62),
#  ('table', 61),
#  ('stood', 60),
#  ('west', 59),
#  ('take', 58),
#  ('want', 58),
#  ('way', 58),
#  ('yes', 58),
#  ('girls', 57),
#  ('even', 56),
#  ('charles', 56),
#  ('supper', 56),
#  ('cold', 56),
#  ('sky', 56),
#  ('far', 55),
#  ('horses', 55),
#  ('set', 55),
#  ('still', 54),
#  ('warm', 54),
#  ('look', 53),
#  ('heard', 53),
#  ('dark', 53),
#  ('across', 52),
#  ('along', 52),
#  ('stove', 52),
#  ('sat', 51),
#  ('railroad', 51),
#  ('place', 51),
#  ('thought', 51),
#  ('another', 51),
#  ('store', 51),
#  ('old', 50),
#  ('right', 50),
#  ('bed', 50),
#  ('ran', 50),
#  ('christmas', 50),
#  ('slough', 50),
#  ('coming', 49),
#  ('gone', 49),
#  ('say', 49),
#  ('wild', 49),
#  ('white', 49),
#  ('camp', 48),
#  ('saw', 47),
#  ('enough', 47),
#  ('dishes', 46),
#  ('black', 45),
#  ('low', 45),
#  ('room', 45),
#  ('took', 45),
#  ('grade', 45),
#  ('wanted', 44),
#  ('us', 44),
#  ('nothing', 44),
#  ('first', 44),
#  ('full', 44),
#  ('brought', 44),
#  ('silver', 44),
#  ('snow', 44),
#  ('blue', 43),
#  ('helped', 43),
#  ('work', 43),
#  ('much', 42),
#  ('till', 42),
#  ('stopped', 42),
#  ('feet', 42),
#  ('sun', 42),
#  ('light', 41),
#  ('land', 41),
#  ('always', 41),
#  ('whole', 41),
#  ('fiddle', 41),
#  ('dinner', 40),
#  ('next', 40),
#  ('ground', 40),
#  ('sang', 40),
#  ('team', 40),
#  ('horse', 39),
#  ('answered', 39),
#  ('anything', 39),
#  ('small', 39),
#  ('almost', 39),
#  ('jerry', 39),
#  ('docia', 38),
#  ('new', 38),
#  ('side', 38),
#  ('town', 38),
#  ('homestead', 37),
#  ('great', 37),
#  ('opened', 37),
#  ('think', 36),
#  ('knew', 36),
#  ('hand', 36),
#  ('together', 36),
#  ('aunt', 34),
#  ('fast', 34),
#  ('red', 34),
#  ('end', 34),
#  ('grasses', 34),
#  ('head', 33),
#  ('brown', 33),
#  ('better', 33),
#  ('train', 33),
#  ('box', 33),
#  ('quickly', 33),
#  ('soon', 33),
#  ('chapter', 32),
#  ('keep', 32),
#  ('pretty', 32),
#  ('slowly', 32),
#  ('stay', 32),
#  ('face', 32),
#  ('many', 32),
#  ('high', 32),
#  ('beside', 32),
#  ('crowd', 32),
#  ('tell', 31),
#  ('money', 31),
#  ('looking', 31),
#  ('hands', 31),
#  ('three', 31),
#  ('jack', 30),
#  ('hair', 30),
#  ('toward', 30),
#  ('sound', 30),
#  ('country', 30),
#  ('hardly', 30),
#  ('turned', 30),
#  ('kept', 30),
#  ('held', 30),
#  ('window', 30),
#  ('beyond', 30),
#  ('began', 30),
#  ('talking', 30),
#  ('singing', 30),
#  ('large', 30),
#  ('cut', 30),
#  ('claim', 30),
#  ('winter', 30),
#  ('reverend', 30),
#  ('seemed', 29),
#  ('glad', 29),
#  ('breakfast', 29),
#  ('hung', 29),
#  ('ponies', 29),
#  ('alden', 29),
#  ('care', 28),
#  ('help', 28),
#  ('cried', 28),
#  ('left', 28),
#  ('everything', 28),
#  ('open', 28),
#  ('eat', 28),
#  ('softly', 28),
#  ('settled', 27),
#  ('lay', 27),
#  ('uncle', 27),
#  ('sleep', 27),
#  ('floor', 27),
#  ('teams', 27),
#  ('stable', 27),
#  ('chair', 26),
#  ('hold', 26),
#  ('washed', 26),
#  ('round', 26),
#  ('top', 26),
#  ('voice', 26),
#  ('birds', 26),
#  ('curtain', 26),
#  ('started', 25),
#  ('ever', 25),
#  ('air', 25),
#  ('might', 25),
#  ('board', 25),
#  ('pay', 24),
#  ('laughing', 24),
#  ('gave', 24),
#  ('home', 24),
#  ('straight', 24),
#  ('guess', 24),
#  ('wide', 24),
#  ('hear', 24),
#  ('spring', 24),
#  ('hot', 24),
#  ('building', 24),
#  ('sunshine', 23),
#  ('beautiful', 23),
#  ('without', 23),
#  ('felt', 23),
#  ('wait', 23),
#  ('hard', 23),
#  ('bring', 23),
#  ('run', 23),
#  ('front', 23),
#  ('moving', 23),
#  ('farther', 23),
#  ('surveyors', 23),
#  ('tree', 23),
#  ('buggy', 22),
#  ('else', 22),
#  ('wolves', 22),
#  ('shut', 22),
#  ('tall', 22),
#  ('bright', 22),
#  ('east', 22),
#  ('wolf', 22),
#  ('hurried', 22),
#  ('creek', 21),
#  ('tired', 21),
#  ('working', 21),
#  ('thin', 21),
#  ('drove', 21),
#  ('seen', 21),
#  ('done', 21),
#  ('feel', 21),
#  ('afternoon', 21),
#  ('clean', 21),
#  ('young', 21),
#  ('earth', 21),
#  ('windows', 21),
#  ('ahead', 21),
#  ('south', 21),
#  ('yellow', 21),
#  ('near', 21),
#  ('pony', 21),
#  ('sit', 20),
#  ('early', 20),
#  ('doorway', 20),
#  ('best', 20),
#  ('suddenly', 20),
#  ('seat', 20),
#  ('tiny', 20),
#  ('blew', 20),
#  ('rough', 20),
#  ('shouted', 20),
#  ('laughed', 20),
#  ('beds', 20),
#  ('rocking', 19),
#  ('girl', 19),
#  ('henry', 19),
#  ('walls', 19),
#  ('tomorrow', 19),
#  ('short', 19),
#  ('moved', 19),
#  ('running', 19),
#  ('maybe', 19),
#  ('whispered', 19),
#  ('sweet', 19),
#  ('glass', 19),
#  ('sing', 19),
#  ('paper', 19),
#  ('find', 19),
#  ('road', 19),
#  ('stars', 19),
#  ('song', 19),
#  ('music', 19),
#  ('ingalls', 19),
#  ('rose', 19),
#  ('shore', 19),
#  ('laid', 19),
#  ('soft', 19),
#  ('close', 18),
#  ('company', 18),
#  ('folks', 18),
#  ('strong', 18),
#  ('it.', 18),
#  ('hat', 18),
#  ('ready', 18),
#  ('people', 18),
#  ('quiet', 18),
#  ('sure', 18),
#  ('pulled', 18),
#  ('ride', 18),
#  ('happy', 18),
#  ('found', 18),
#  ('drive', 18),
#  ('empty', 18),
#  ('blowing', 18),
#  ('edge', 18),
#  ('deep', 18),
#  ('exclaimed', 18),
#  ('biscuits', 18),
#  ('washing', 17),
#  ('strange', 17),
#  ('leave', 17),
#  ('hi', 17),
#  ('need', 17),
#  ('something', 17),
#  ('tried', 17),
#  ('rest', 17),
#  ('days', 17),
#  ('carefully', 17),
#  ('really', 17),
#  ('grew', 17),
#  ('trees', 17),
#  ('nobody', 17),
#  ('fresh', 17),
#  ('finished', 17),
#  ('geese', 17),
#  ('voices', 17),
#  ('milk', 17),
#  ('scraper', 17),
#  ('played', 17),
#  ('golden', 16),
#  ('potatoes', 16),
#  ('indian', 16),
#  ('gray', 16),
#  ('walk', 16),
#  ('making', 16),
#  ('faster', 16),
#  ('already', 16),
#  ('green', 16),
#  ('loud', 16),
#  ('breath', 16),
#  ('covered', 16),
#  ('office', 16),
#  ('half', 16),
#  ('jean', 16),
#  ('called', 16),
#  ('bank', 16),
#  ('buffalo', 16),
#  ('tea', 16),
#  ('evening', 16),
#  ('wrapped', 15),
#  ('boy', 15),
#  ('driving', 15),
#  ('yet', 15),
#  ('dress', 15),
#  ('territory', 15),
#  ('living', 15),
#  ('times', 15),
#  ('fine', 15),
#  ('riding', 15),
#  ('minute', 15),
#  ('outside', 15),
#  ('sides', 15),
#  ('shining', 15),
#  ('things', 15),
#  ('shanties', 15),
#  ('world', 15),
#  ('quietly', 15),
#  ('talked', 15),
#  ('lumber', 15),
#  ('spread', 15),
#  ('miles', 15),
#  ('lines', 15),
#  ('roof', 15),
#  ('anyway', 15),
#  ('weather', 15),
#  ('paymaster', 15),
#  ('though', 15),
#  ('wings', 15),
#  ('dust', 15),
#  ('fire', 15),
#  ('violets', 15),
#  ('plum', 14),
#  ('summer', 14),
#  ('bare', 14),
#  ('boards', 14),
#  ('engine', 14),
#  ('clear', 14),
#  ('everyone', 14),
#  ('move', 14),
#  ('thing', 14),
#  ('school', 14),
#  ('tight', 14),
#  ('followed', 14),
#  ('hole', 14),
#  ('wagons', 14),
#  ('north', 14),
#  ('lost', 14),
#  ('play', 14),
#  ('built', 14),
#  ('ducks', 14),
#  ('level', 14),
#  ('scrapers', 14),
#  ('downstairs', 14),
#  ('dry', 13),
#  ('married', 13),
#  ('dollars', 13),
#  ('hundred', 13),
#  ('gently', 13),
#  ('boys', 13),
#  ('live', 13),
#  ('smoke', 13),
#  ('ask', 13),
#  ('corner', 13),
#  ('watch', 13),
#  ('inside', 13),
#  ('flowers', 13),
#  ('wheels', 13),
#  ('outdoors', 13),
#  ('coat', 13),
#  ('filled', 13),
#  ('part', 13),
#  ('showed', 13),
#  ('candy', 13),
#  ('circle', 13),
#  ('strangers', 13),
#  ('rather', 13),
#  ('salt', 13),
#  ('shone', 13),
#  ('clothes', 13),
#  ('late', 13),
#  ('hang', 13),
#  ('flock', 13),
#  ('hurt', 13),
#  ('swan', 13),
#  ('mittens', 13),
#  ('alone', 12),
#  ('job', 12),
#  ('square', 12),
#  ('smooth', 12),
#  ('putting', 12),
#  ('lean-to', 12),
#  ('show', 12),
#  ('onto', 12),
#  ('paid', 12),
#  ('talk', 12),
#  ('heart', 12),
#  ('thick', 12),
#  ('car', 12),
#  ('use', 12),
#  ('cup', 12),
#  ('shelf', 12),
#  ('boxes', 12),
#  ('pieces', 12),
#  ('piece', 12),
#  ('line', 12),
#  ('hurry', 12),
#  ('china', 12),
#  ('ate', 12),
#  ('sight', 12),
#  ('among', 12),
#  ('worry', 12),
#  ('ellen', 12),
#  ('broom', 12),
#  ('plows', 12),
#  ('build', 12),
#  ('dump', 12),
#  ('coal', 12),
#  ('nearly', 12),
#  ('tracks', 12),
#  ('brookings', 12),
#  ('sighed', 11),
#  ('blind', 11),
#  ('saying', 11),
#  ('standing', 11),
#  ('worked', 11),
#  ('rode', 11),
#  ('anywhere', 11),
#  ('hope', 11),
#  ('legs', 11),
#  ('blanket', 11),
#  ('comfortable', 11),
#  ('shook', 11),
#  ('smiled', 11),
#  ('waiting', 11),
#  ('turn', 11),
#  ('nice', 11),
#  ('narrow', 11),
#  ('ends', 11),
#  ('seeing', 11),
#  ('listening', 11),
#  ('shot', 11),
#  ('lap', 11),
#  ('slid', 11),
#  ('higher', 11),
#  ('wall', 11),
#  ('mind', 11),
#  ('fill', 11),
#  ('passed', 11),
#  ('hotel', 11),
#  ('thank', 11),
#  ('rope', 11),
#  ('street', 11),
#  ('plate', 11),
#  ('except', 11),
#  ('heavy', 11),
#  ('rich', 11),
#  ('stretched', 11),
#  ('fell', 11),
#  ('laugh', 11),
#  ('dirt', 11),
#  ('river', 11),
#  ('gentle', 11),
#  ('johnny', 11),
#  ('life', 11),
#  ('pork', 11),
#  ('plowed', 11),
#  ('hill', 11),
#  ('flour', 11),
#  ('apron', 11),
#  ('coats', 11),
#  ('pantry', 11),
#  ('merry', 11),
#  ('week', 10),
#  ('word', 10),
#  ('turning', 10),
#  ('meant', 10),
#  ('woods', 10),
#  ('kind', 10),
#  ('arms', 10),
#  ('acres', 10),
#  ('give', 10),
#  ('traveling', 10),
#  ('trains', 10),
#  ('often', 10),
#  ('scared', 10),
#  ('cover', 10),
#  ('slept', 10),
#  ('perhaps', 10),
#  ('lonely', 10),
#  ('five', 10),
#  ('spoke', 10),
#  ('real', 10),
#  ('tied', 10),
#  ('may', 10),
#  ('lifted', 10),
#  ('rolled', 10),
#  ('enormous', 10),
#  ('cap', 10),
#  ('getting', 10),
#  ('quick', 10),
#  ('touched', 10),
#  ('holding', 10),
#  ('drink', 10),
#  ('noon', 10),
#  ('walked', 10),
#  ('boots', 10),
#  ('led', 10),
#  ('bowl', 10),
#  ('remember', 10),
#  ('dish', 10),
#  ('plenty', 10),
#  ('lamp', 10),
#  ('twinkled', 10),
#  ('liked', 10),
#  ('bedroom', 10),
#  ('picket', 10),
#  ('wish', 10),
#  ('dead', 10),
#  ('cool', 10),
#  ('loaded', 10),
#  ('bit', 10),
#  ('snug', 10),
#  ('shovel', 10),
#  ('stand', 10),
#  ('load', 10),
#  ('muddy', 10),
#  ('bag', 10),
#  ('somebody', 10),
#  ('ice', 10),
#  ('moonlight', 10),
#  ('brother', 10),
#  ('buildings', 10),
#  ('wondered', 9),
#  ('sunbonnet', 9),
#  ('hunting', 9),
#  ('fifty', 9),
#  ('caught', 9),
#  ('replied', 9),
#  ('agreed', 9),
#  ('afraid', 9),
#  ('used', 9),
#  ('taken', 9),
#  ('rise', 9),
#  ('watched', 9),
#  ('cows', 9),
#  ('rabbit', 9),
#  ('platform', 9),
#  ('noise', 9),
#  ('steps', 9),
#  ('wore', 9),
#  ('comes', 9),
#  ('fall', 9),
#  ('wonder', 9),
#  ('quite', 9),
#  ('cents', 9),
#  ('asleep', 9),
#  ('wonderful', 9),
#  ('yelled', 9),
#  ('words', 9),
#  ('boarding', 9),
#  ('beating', 9),
#  ('cloth', 9),
#  ('pail', 9),
#  ('eating', 9),
#  ('pie', 9),
#  ('year', 9),
#  ('curved', 9),
#  ('stop', 9),
#  ('moment', 9),
#  ('surprised', 9),
#  ('chilly', 9),
#  ('sleepy', 9),
#  ('fat', 9),
#  ('fun', 9),
#  ('pleasant', 9),
#  ('tails', 9),
#  ('wife', 9),
#  ('flew', 9),
#  ('yi', 9),
#  ('shirt', 9),
#  ('watching', 9),
#  ('flying', 9),
#  ('try', 9),
#  ('calling', 9),
#  ('payday', 9),
#  ('cousin', 9),
#  ('louisa', 9),
#  ('flutterbudget', 9),
#  ('waited', 9),
#  ('taking', 9),
#  ('s-down', 9),
#  ('iowa', 9),
#  ('oven', 9),
#  ('bottom', 9),
#  ('gravy', 9),
#  ('whatnot', 9),
#  ('stuart', 9),
#  ('huron', 9),
#  ('baby', 8),
#  ('poor', 8),
#  ('thinking', 8),
#  ('cow', 8),
#  ('worn', 8),
#  ('years', 8),
#  ('since', 8),
#  ('anybody', 8),
#  ('wisconsin', 8),
#  ('camps', 8),
#  ('sam', 8),
#  ('meat', 8),
#  ('sister', 8),
#  ('gets', 8),
#  ('couple', 8),
#  ('course', 8),
#  ('stiff', 8),
#  ('fellow', 8),
#  ('walking', 8),
#  ('mean', 8),
#  ('attic', 8),
#  ('packed', 8),
#  ('lived', 8),
#  ('lamplight', 8),
#  ('cars', 8),
#  ('weeks', 8),
#  ('crowded', 8),
#  ('satchels', 8),
#  ('bonnet', 8),
#  ('shoes', 8),
#  ('cost', 8),
#  ('happen', 8),
#  ('calico', 8),
#  ('sitting', 8),
#  ('meet', 8),
#  ('past', 8),
#  ('velvet', 8),
#  ('jerked', 8),
#  ('jolting', 8),
#  ('says', 8),
#  ('middle', 8),
#  ('handle', 8),
#  ('save', 8),
#  ('tasted', 8),
#  ('fitted', 8),
#  ('fried', 8),
#  ('wash', 8),
#  ('handkerchief', 8),
#  ('sewed', 8),
#  ('larger', 8),
#  ('awake', 8),
#  ('smaller', 8),
#  ('us.', 8),
#  ('takes', 8),
#  ('bunkhouse', 8),
#  ('start', 8),
#  ('bells', 8),
#  ('growing', 8),
#  ('grassy', 8),
#  ('sometimes', 8),
#  ('charles.', 8),
#  ('lie', 8),
#  ('dropped', 8),
#  ('heads', 8),
#  ('bedtime', 8),
#  ('teamster', 8),
#  ('teach', 8),
#  ('crackers', 8),
#  ('upstairs', 8),
#  ('covers', 8),
#  ('blankets', 8),
#  ('story', 8),
#  ('den', 8),
#  ('hood', 8),
#  ('presents', 8),
#  ('read', 8),
#  ('lying', 7),
#  ('woman', 7),
#  ('quilts', 7),
#  ('stayed', 7),
#  ('month', 7),
#  ('smoothed', 7),
#  ('lighted', 7),
#  ('listen', 7),
#  ('farm', 7),
#  ('exactly', 7),
#  ('driver', 7),
#  ('me.', 7),
#  ('longer', 7),
#  ('dog', 7),
#  ('minnesota', 7),
#  ('path', 7),
#  ('mouth', 7),
#  ('catch', 7),
#  ('fields', 7),
#  ('row', 7),
#  ('hurrying', 7),
#  ('steel', 7),
#  ('bow', 7),
#  ('starting', 7),
#  ('screamed', 7),
#  ('step', 7),
#  ('cheerfully', 7),
#  ('scattered', 7),
#  ('promised', 7),
#  ('tin', 7),
#  ('basket', 7),
#  ('reached', 7),
#  ('striped', 7),
#  ('finally', 7),
#  ('rails', 7),
#  ('bell', 7),
#  ('railroads', 7),
#  ('carrying', 7),
#  ('sounds', 7),
#  ('looks', 7),
#  ('noisy', 7),
#  ('bad', 7),
#  ('climbed', 7),
#  ('ended', 7),
#  ('overhead', 7),
#  ('cleared', 7),
#  ('teamsters', 7),
#  ('pale', 7),
#  ('different', 7),
#  ('strings', 7),
#  ('marry', 7),
#  ('ways', 7),
#  ('soberly', 7),
#  ('falling', 7),
#  ('swung', 7),
#  ('sioux', 7),
#  ('steadily', 7),
#  ('pick', 7),
#  ('tune', 7),
#  ('gun', 7),
#  ('free', 7),
#  ('bunks', 7),
#  ('hay', 7),
#  ('gathered', 7),
#  ('remembered', 7),
#  ('six', 7),
#  ('pushed', 7),
#  ('less', 5),
#  ('hour', 5),
#  ('eggs', 5),
#  ('ago', 5),
#  ('cheeks', 5),
#  ('seem', 5),
#  ('sixty', 5),
#  ('swept', 5),
#  ('depot', 5),
#  ('killed', 5),
#  ('rolling', 5),
#  ('manage', 5),
#  ('notice', 5),
#  ('bent', 5),
#  ('leaned', 5),
#  ('trotted', 5),
#  ('hitched', 5),
#  ('feeling', 5),
#  ('whenever', 5),
#  ('scratch', 5),
#  ('third', 5),
#  ('curled', 5),
#  ('safe', 5),
#  ('tip', 5),
#  ('gaily', 5),
#  ('believe', 5),
#  ('packing', 5),
#  ('tickets', 5),
#  ('counted', 5),
#  ('clouds', 5),
#  ('collar', 5),
#  ('joy', 5),
#  ('hit', 5),
#  ('anxiously', 5),
#  ('rows', 5),
#  ('jumped', 5),
#  ('brakeman', 5),
#  ('shivering', 5),
#  ...]

# %%
#Turn all words to basic form
basic_form = [ps.stem(word) for word in tokens_low if not word in stopwords + symbols]

#Textを使うためにreviewをlistにぶち込む
basic_form = [basic_form]

#原型に戻した単語で、再び文を再構築する。
text = []
for i in basic_form:
    text.append(nltk.Text(i))
    
#Textからwords listを作る。
for i in text:
    words = [word for word in i]
    
words
# Out:
# ['chapter',
#  '1',
#  'unexpect',
#  'visitor',
#  'laura',
#  'wash',
#  'dish',
#  'one',
#  'morn',
#  'old',
#  'jack',
#  'lie',
#  'sunshin',
#  'doorstep',
#  'growl',
#  'tell',
#  'someon',
#  'come',
#  'look',
#  'saw',
#  'buggi',
#  'cross',
#  'gravelli',
#  'ford',
#  'plum',
#  'creek',
#  'said',
#  'strang',
#  'woman',
#  'coming.',
#  'sigh',
#  'asham',
#  'untidi',
#  'hous',
#  'laura',
#  'weak',
#  'laura',
#  'tire',
#  'sad',
#  'care',
#  'much',
#  'mari',
#  'carri',
#  'babi',
#  'grace',
#  'scarlet',
#  'fever',
#  'nelson',
#  'across',
#  'creek',
#  'one',
#  'help',
#  'pa',
#  'laura',
#  'doctor',
#  'come',
#  'everi',
#  'day',
#  'pa',
#  'know',
#  'could',
#  'pay',
#  'bill',
#  'far',
#  'worst',
#  'fever',
#  'settl',
#  'mari',
#  'eye',
#  'mari',
#  'blind',
#  'abl',
#  'sit',
#  'wrap',
#  'quilt',
#  'old',
#  'hickori',
#  'rock',
#  'chair',
#  'long',
#  'time',
#  'week',
#  'week',
#  'could',
#  'still',
#  'see',
#  'littl',
#  'less',
#  'everi',
#  'day',
#  'never',
#  'cri',
#  'could',
#  'see',
#  'even',
#  'brightest',
#  'light',
#  'still',
#  'patient',
#  'brave',
#  'beauti',
#  'golden',
#  'hair',
#  'gone',
#  'pa',
#  'shave',
#  'close',
#  'fever',
#  'poor',
#  'shorn',
#  'head',
#  'look',
#  'like',
#  'boy',
#  'blue',
#  'eye',
#  'still',
#  'beauti',
#  'know',
#  'mari',
#  'could',
#  'never',
#  'look',
#  'tell',
#  'laura',
#  'think',
#  'without',
#  'say',
#  'word',
#  'hour',
#  'morn',
#  'mari',
#  'wonder',
#  'turn',
#  'ear',
#  'toward',
#  'sound',
#  'buggi',
#  'strang',
#  'woman',
#  'alon',
#  'buggi',
#  'wear',
#  'brown',
#  'sunbonnet',
#  'drive',
#  'bay',
#  'hors',
#  'laura',
#  'answer',
#  'pa',
#  'said',
#  'must',
#  'eye',
#  'mari',
#  'think',
#  'anyth',
#  'dinner',
#  'ask',
#  'meant',
#  'compani',
#  'dinner',
#  'woman',
#  'stay',
#  'till',
#  'dinnertim',
#  'bread',
#  'molass',
#  'potato',
#  'springtim',
#  'earli',
#  'garden',
#  'veget',
#  'cow',
#  'dri',
#  'hen',
#  'yet',
#  'begun',
#  'lay',
#  'summer',
#  'egg',
#  'small',
#  'fish',
#  'left',
#  'plum',
#  'creek',
#  'even',
#  'littl',
#  'cottontail',
#  'rabbit',
#  'hunt',
#  'scarc',
#  'pa',
#  'like',
#  'countri',
#  'old',
#  'worn',
#  'hunt',
#  'poor',
#  'want',
#  'go',
#  'west',
#  'two',
#  'year',
#  'want',
#  'go',
#  'west',
#  'take',
#  'homestead',
#  'want',
#  'leav',
#  'settl',
#  'countri',
#  'money',
#  'pa',
#  'made',
#  'two',
#  'poor',
#  'wheat',
#  'crop',
#  'sinc',
#  'grasshopp',
#  'came',
#  'bare',
#  'abl',
#  'keep',
#  'debt',
#  'doctor',
#  'bill',
#  'laura',
#  'answer',
#  'stoutli',
#  'good',
#  'enough',
#  'us',
#  'good',
#  'enough',
#  'anybodi',
#  'buggi',
#  'stop',
#  'strang',
#  'woman',
#  'sat',
#  'look',
#  'laura',
#  'doorway',
#  'pretti',
#  'woman',
#  'neat',
#  'brown',
#  'print',
#  'dress',
#  'sunbonnet',
#  'laura',
#  'felt',
#  'asham',
#  'bare',
#  'feet',
#  'limp',
#  'dress',
#  'uncomb',
#  'braid',
#  'said',
#  'slowli',
#  'docia',
#  'wonder',
#  'know',
#  'woman',
#  'said',
#  'good',
#  'deal',
#  'water',
#  'gone',
#  'bridg',
#  'sinc',
#  'folk',
#  'left',
#  'wisconsin.',
#  'pretti',
#  'aunt',
#  'docia',
#  'worn',
#  'dress',
#  'button',
#  'look',
#  'like',
#  'blackberri',
#  'long',
#  'ago',
#  'sugaring-off',
#  'danc',
#  'grandpa',
#  'hous',
#  'big',
#  'wood',
#  'wisconsin',
#  'marri',
#  'marri',
#  'widow',
#  'two',
#  'children',
#  'husband',
#  'contractor',
#  'work',
#  'new',
#  'railroad',
#  'west',
#  'aunt',
#  'docia',
#  'drive',
#  'alon',
#  'buggi',
#  'way',
#  'wisconsin',
#  'railroad',
#  'camp',
#  'dakota',
#  'territori',
#  'come',
#  'see',
#  'pa',
#  'would',
#  'go',
#  'husband',
#  'uncl',
#  'hi',
#  'want',
#  'good',
#  'manto',
#  'storekeep',
#  'bookkeep',
#  'timekeep',
#  'pa',
#  'could',
#  'job',
#  'pay',
#  'fifti',
#  'dollar',
#  'month',
#  'charl',
#  'said',
#  'kind',
#  'tight',
#  'smooth',
#  'pa',
#  'thin',
#  'cheek',
#  'blue',
#  'eye',
#  'light',
#  'said',
#  'slowli',
#  'seem',
#  'like',
#  'draw',
#  'good',
#  'pay',
#  'look',
#  'homestead',
#  'carolin',
#  'still',
#  'want',
#  'go',
#  'west',
#  'look',
#  'around',
#  'kitchen',
#  'carri',
#  'laura',
#  'stand',
#  'grace',
#  'arm',
#  'charl',
#  'know',
#  'said',
#  'seem',
#  'providenti',
#  'fifti',
#  'dollar',
#  'month',
#  'settl',
#  'got',
#  'farm.',
#  'listen',
#  'reason',
#  'carolin',
#  'pa',
#  'plead',
#  'get',
#  'hundr',
#  'sixti',
#  'acr',
#  'west',
#  'live',
#  'land',
#  'good',
#  'better',
#  'uncl',
#  'sam',
#  'will',
#  'give',
#  'us',
#  'farm',
#  'place',
#  'one',
#  'drove',
#  'us',
#  'indian',
#  'territori',
#  'say',
#  'let',
#  'take',
#  'hunt',
#  'good',
#  'west',
#  'man',
#  'get',
#  'meat',
#  'wants.',
#  'laura',
#  'want',
#  'much',
#  'go',
#  'could',
#  'hardli',
#  'keep',
#  'speak',
#  'could',
#  'go',
#  'ask',
#  'mari',
#  'strong',
#  'enough',
#  'travel.',
#  'said',
#  'pa.',
#  'fact.',
#  'ask',
#  'aunt',
#  'docia',
#  'job',
#  'wait',
#  'aunt',
#  'docia',
#  'said',
#  'charl',
#  'hi',
#  'need',
#  'man',
#  'right',
#  'take',
#  'leav',
#  'it.',
#  'fifti',
#  'dollar',
#  'month',
#  'carolin',
#  'said',
#  'pa.',
#  'homestead.',
#  'seem',
#  'long',
#  'time',
#  'said',
#  'gentli',
#  'well',
#  'charl',
#  'must',
#  'think',
#  'best.',
#  'take',
#  'docia',
#  'pa',
#  'got',
#  'clap',
#  'hat',
#  'way',
#  'go',
#  'see',
#  'nelson.',
#  'laura',
#  'excit',
#  'could',
#  'hardli',
#  'housework',
#  'properli',
#  'aunt',
#  'docia',
#  'help',
#  'work',
#  'told',
#  'news',
#  'wisconsin',
#  'sister',
#  'aunt',
#  'rubi',
#  'marri',
#  'two',
#  'boy',
#  'beauti',
#  'littl',
#  'babi',
#  'girl',
#  'name',
#  'dolli',
#  'varden',
#  'uncl',
#  'georg',
#  'lumberjack',
#  'log',
#  'mississippi',
#  'uncl',
#  'henri',
#  'folk',
#  'well',
#  'charley',
#  'turn',
#  'better',
#  'expect',
#  'consid',
#  'uncl',
#  'henri',
#  'spare',
#  'rod',
#  'spoil',
#  'child',
#  'grandpa',
#  'grandma',
#  'still',
#  'live',
#  'old',
#  'place',
#  'big',
#  'log',
#  'hous',
#  'could',
#  'afford',
#  'frame',
#  'hous',
#  'grandpa',
#  'declar',
#  'good',
#  'sound',
#  'oak',
#  'log',
#  'made',
#  'better',
#  'wall',
#  'thin',
#  'saw',
#  'board',
#  'even',
#  'black',
#  'susan',
#  'cat',
#  'laura',
#  'mari',
#  'left',
#  'behind',
#  'rode',
#  'away',
#  'littl',
#  'log',
#  'hous',
#  'wood',
#  'still',
#  'live',
#  'littl',
#  'log',
#  'hous',
#  'chang',
#  'hand',
#  'sever',
#  'time',
#  'corncrib',
#  'noth',
#  'would',
#  'persuad',
#  'cat',
#  'live',
#  'anywher',
#  'els',
#  'went',
#  'right',
#  'live',
#  'corncrib',
#  'sleek',
#  'plump',
#  'rat',
#  'caught',
#  'hardli',
#  'famili',
#  'countri',
#  'one',
#  'kitten',
#  'good',
#  'mouser',
#  'big-ear',
#  'long-tail',
#  'like',
#  'black',
#  'susan',
#  'dinner',
#  'readi',
#  'swept',
#  'neat',
#  'hous',
#  'pa',
#  'came',
#  'back',
#  'sold',
#  'farm',
#  'nelson',
#  'pay',
#  'two',
#  'hundr',
#  'dollar',
#  'cash',
#  'pa',
#  'jubil',
#  'squar',
#  'owe',
#  'leav',
#  'littl',
#  'someth',
#  'said',
#  'carolin',
#  'hope',
#  'best',
#  'charl',
#  'repli',
#  'how—',
#  'wait',
#  'till',
#  'tell',
#  'got',
#  'figur',
#  'pa',
#  'told',
#  'go',
#  'docia',
#  'tomorrow',
#  'morn',
#  'girl',
#  'stay',
#  'till',
#  'mari',
#  'get',
#  'well',
#  'strong',
#  'say',
#  'coupl',
#  'month',
#  'nelson',
#  'agre',
#  'haul',
#  'stuff',
#  'depot',
#  'come',
#  'train.',
#  'laura',
#  'stare',
#  'carri',
#  'mari',
#  'said',
#  'train',
#  'never',
#  'thought',
#  'travel',
#  'train',
#  'laura',
#  'knew',
#  'cours',
#  'peopl',
#  'travel',
#  'train',
#  'train',
#  'often',
#  'wreck',
#  'peopl',
#  'kill',
#  'exactli',
#  'afraid',
#  'excit',
#  'carri',
#  'eye',
#  'big',
#  'scare',
#  'peak',
#  'littl',
#  'face',
#  'seen',
#  'train',
#  'rush',
#  'across',
#  'prairi',
#  'long',
#  'roll',
#  'puff',
#  'black',
#  'smoke',
#  'stream',
#  'back',
#  'engin',
#  'heard',
#  'roar',
#  'wild',
#  'clear',
#  'whistl',
#  'hors',
#  'ranaway',
#  'driver',
#  'could',
#  'hold',
#  'saw',
#  'train',
#  'come',
#  'said',
#  'quiet',
#  'way',
#  'sure',
#  'manag',
#  'nice',
#  'laura',
#  'carri',
#  'help',
#  'me.',
#  'chapter',
#  '2',
#  'grown',
#  'great',
#  'deal',
#  'work',
#  'done',
#  'pa',
#  'must',
#  'leav',
#  'earli',
#  'next',
#  'morn',
#  'set',
#  'old',
#  'wagon',
#  'bow',
#  'wagon',
#  'pull',
#  'canva',
#  'cover',
#  'almost',
#  'worn',
#  'would',
#  'short',
#  'trip',
#  'aunt',
#  'docia',
#  'carri',
#  'help',
#  'pack',
#  'wagon',
#  'laura',
#  'wash',
#  'iron',
#  'bake',
#  'hardtack',
#  'journey',
#  'midst',
#  'jack',
#  'stood',
#  'look',
#  'everyon',
#  'busi',
#  'notic',
#  'old',
#  'bulldog',
#  'till',
#  'suddenli',
#  'laura',
#  'saw',
#  'stand',
#  'hous',
#  'wagon',
#  'frisk',
#  'cock',
#  'head',
#  'laugh',
#  'use',
#  'stood',
#  'brace',
#  'stiff',
#  'leg',
#  'troubl',
#  'rheumat',
#  'forehead',
#  'wrinkl',
#  'sadli',
#  'stub-tail',
#  'limp',
#  'good',
#  'old',
#  'jack',
#  'laura',
#  'told',
#  'wag',
#  'look',
#  'sorrow',
#  'look',
#  'pa.',
#  'look',
#  'jack',
#  'laura',
#  'said',
#  'bent',
#  'stroke',
#  'smooth',
#  'head',
#  'fine',
#  'hair',
#  'gray',
#  'first',
#  'nose',
#  'gray',
#  'jaw',
#  'even',
#  'ear',
#  'longer',
#  'brown',
#  'lean',
#  'head',
#  'sigh',
#  'one',
#  'instant',
#  'knew',
#  'old',
#  'dog',
#  'tire',
#  'walk',
#  'way',
#  'dakota',
#  'territori',
#  'wagon',
#  'troubl',
#  'saw',
#  'wagon',
#  'readi',
#  'go',
#  'travel',
#  'old',
#  'tire',
#  'pa',
#  'cri',
#  'jack',
#  'walk',
#  'far',
#  'oh',
#  'pa',
#  'leav',
#  'jack',
#  'hold',
#  'walk',
#  'fact',
#  'pa',
#  'said',
#  'forgot',
#  'move',
#  'feedsack',
#  'make',
#  'place',
#  'ride',
#  'wagon',
#  'like',
#  'go',
#  'ride',
#  'wagon',
#  'huh',
#  'old',
#  'fellow',
#  'jack',
#  'wag',
#  'one',
#  'polit',
#  'wag',
#  'turn',
#  'head',
#  'asid',
#  'want',
#  'go',
#  'even',
#  'wagon',
#  'laura',
#  'knelt',
#  'hug',
#  'use',
#  'littl',
#  'girl',
#  'jack',
#  'jack',
#  'go',
#  'west',
#  'want',
#  'go',
#  'west',
#  'jack',
#  'alway',
#  'eager',
#  'joy',
#  'saw',
#  'pa',
#  'put',
#  'cover',
#  'wagon',
#  'taken',
#  'place',
#  'start',
#  'long',
#  'way',
#  'wisconsin',
#  'indian',
#  'territori',
#  'back',
#  'minnesota',
#  'trot',
#  'wagon',
#  'shade',
#  'behind',
#  'hors',
#  'feet',
#  'wade',
#  'creek',
#  'swum',
#  'river',
#  'everi',
#  'night',
#  'laura',
#  'slept',
#  'wagon',
#  'guard',
#  'everi',
#  'morn',
#  'even',
#  'feet',
#  'sore',
#  'walk',
#  'glad',
#  'see',
#  'sun',
#  'rise',
#  'hors',
#  'hitch',
#  'alway',
#  'readi',
#  'new',
#  'day',
#  'travel',
#  'lean',
#  'laura',
#  'nudg',
#  'nose',
#  'hand',
#  'ask',
#  'pet',
#  'gentli',
#  'stroke',
#  'gray',
#  'head',
#  'smooth',
#  'ear',
#  'could',
#  'feel',
#  'tire',
#  'ever',
#  'sinc',
#  'mari',
#  'carri',
#  'sick',
#  'scarlet',
#  'fever',
#  'laura',
#  'neglect',
#  'jack',
#  'alway',
#  'help',
#  'everi',
#  'troubl',
#  'could',
#  'help',
#  'sick',
#  'hous',
#  'perhap',
#  'time',
#  'feel',
#  'lone',
#  'forgotten',
#  'mean',
#  'jack',
#  'laura',
#  'told',
#  'understood',
#  'alway',
#  'understood',
#  'taken',
#  ...]

# %%
#Basic に直して、頻度を確認する
freq_list_basic = []
for i in text:
    freq_list_basic.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

#順位チェック
sorted(freq_list_basic[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('laura', 687),
#  ('said', 642),
#  ('pa', 524),
#  ('go', 250),
#  ('mari', 249),
#  ('carri', 216),
#  ('littl', 190),
#  ('could', 177),
#  ('one', 175),
#  ('come', 172),
#  ('look', 164),
#  ('boast', 162),
#  ('came', 154),
#  ('back', 154),
#  ('would', 145),
#  ('big', 142),
#  ('went', 137),
#  ('get', 132),
#  ('see', 124),
#  ('grace', 122),
#  ('like', 122),
#  ('wagon', 117),
#  ('time', 116),
#  ('men', 115),
#  ('door', 111),
#  ('want', 107),
#  ('grass', 102),
#  ('hous', 99),
#  ('away', 99),
#  ('ask', 96),
#  ('day', 94),
#  ('hors', 94),
#  ('good', 93),
#  ('around', 93),
#  ('put', 93),
#  ('long', 91),
#  ('prairi', 89),
#  ('well', 88),
#  ('mrs.', 88),
#  ('man', 87),
#  ('night', 87),
#  ('know', 86),
#  ('got', 86),
#  ('pa.', 85),
#  ('make', 84),
#  ('lake', 83),
#  ('made', 82),
#  ('shanti', 81),
#  ('never', 80),
#  ('wind', 80),
#  ('help', 79),
#  ('even', 79),
#  ('must', 79),
#  ('morn', 78),
#  ('everi', 77),
#  ('bed', 77),
#  ('work', 76),
#  ('girl', 76),
#  ('take', 75),
#  ('hand', 75),
#  ('two', 74),
#  ('lena', 73),
#  ('carolin', 72),
#  ('say', 68),
#  ('told', 68),
#  ('last', 68),
#  ('eye', 67),
#  ('open', 67),
#  ('team', 67),
#  ('water', 66),
#  ('way', 65),
#  ('let', 64),
#  ('oh', 64),
#  ('behind', 63),
#  ('ye', 63),
#  ('set', 61),
#  ('tabl', 61),
#  ('still', 60),
#  ('railroad', 60),
#  ('stood', 60),
#  ('west', 59),
#  ('dish', 58),
#  ('stop', 58),
#  ('supper', 58),
#  ('dark', 58),
#  ('place', 57),
#  ('talk', 57),
#  ('warm', 57),
#  ('camp', 56),
#  ('charl', 56),
#  ('move', 56),
#  ('cold', 56),
#  ('sky', 56),
#  ('side', 56),
#  ('far', 55),
#  ('thought', 55),
#  ('laugh', 55),
#  ('slough', 55),
#  ('light', 53),
#  ('turn', 53),
#  ('heard', 53),
#  ('store', 53),
#  ('saw', 52),
#  ('across', 52),
#  ('along', 52),
#  ('end', 52),
#  ('stove', 52),
#  ('wash', 51),
#  ('sat', 51),
#  ('window', 51),
#  ('anoth', 51),
#  ('old', 50),
#  ('right', 50),
#  ('ran', 50),
#  ('christma', 50),
#  ('poni', 50),
#  ('care', 49),
#  ('gone', 49),
#  ('board', 49),
#  ('wild', 49),
#  ('room', 49),
#  ('white', 49),
#  ('sing', 49),
#  ('grade', 49),
#  ('enough', 47),
#  ('homestead', 46),
#  ('black', 46),
#  ('build', 46),
#  ('think', 45),
#  ('low', 45),
#  ('box', 45),
#  ('crowd', 45),
#  ('took', 45),
#  ('full', 45),
#  ('snow', 45),
#  ('us', 44),
#  ('noth', 44),
#  ('first', 44),
#  ('brought', 44),
#  ('silver', 44),
#  ('blue', 43),
#  ('stay', 43),
#  ('wait', 43),
#  ('train', 43),
#  ('run', 43),
#  ('voic', 43),
#  ('much', 42),
#  ('head', 42),
#  ('till', 42),
#  ('feet', 42),
#  ('land', 42),
#  ('sun', 42),
#  ('hurri', 42),
#  ('answer', 41),
#  ('dinner', 41),
#  ('alway', 41),
#  ('ground', 41),
#  ('whole', 41),
#  ('fiddl', 41),
#  ('next', 40),
#  ('start', 40),
#  ('tree', 40),
#  ('sang', 40),
#  ('sound', 39),
#  ('anyth', 39),
#  ('small', 39),
#  ('new', 39),
#  ('face', 39),
#  ('almost', 39),
#  ('jerri', 39),
#  ('keep', 38),
#  ('docia', 38),
#  ('seem', 38),
#  ('live', 38),
#  ('town', 38),
#  ('great', 37),
#  ('play', 37),
#  ('besid', 37),
#  ('eat', 37),
#  ('settl', 36),
#  ('knew', 36),
#  ('hold', 36),
#  ('cover', 36),
#  ('togeth', 36),
#  ('cut', 36),
#  ('cri', 35),
#  ('brown', 34),
#  ('aunt', 34),
#  ('walk', 34),
#  ('fast', 34),
#  ('red', 34),
#  ('drive', 33),
#  ('better', 33),
#  ('ride', 33),
#  ('shout', 33),
#  ('quickli', 33),
#  ('soon', 33),
#  ('claim', 33),
#  ('chapter', 32),
#  ('tell', 32),
#  ('chair', 32),
#  ('hair', 32),
#  ('pretti', 32),
#  ('slowli', 32),
#  ('glad', 32),
#  ('tri', 32),
#  ('sleep', 32),
#  ('mani', 32),
#  ('high', 32),
#  ('curtain', 32),
#  ('call', 32),
#  ('wonder', 31),
#  ('money', 31),
#  ('watch', 31),
#  ('three', 31),
#  ('line', 31),
#  ('larg', 31),
#  ('winter', 31),
#  ('scraper', 31),
#  ('jack', 30),
#  ('toward', 30),
#  ('countri', 30),
#  ('leav', 30),
#  ('hardli', 30),
#  ('wall', 30),
#  ('kept', 30),
#  ('held', 30),
#  ('beyond', 30),
#  ('began', 30),
#  ('bird', 30),
#  ('reverend', 30),
#  ('feel', 29),
#  ('breakfast', 29),
#  ('thing', 29),
#  ('hung', 29),
#  ('plow', 29),
#  ('alden', 29),
#  ('pay', 28),
#  ('sit', 28),
#  ('boy', 28),
#  ('lay', 28),
#  ('left', 28),
#  ('everyth', 28),
#  ('floor', 28),
#  ('fill', 28),
#  ('softli', 28),
#  ('stabl', 28),
#  ('uncl', 27),
#  ('air', 27),
#  ('round', 27),
#  ('bring', 27),
#  ('top', 27),
#  ('breath', 27),
#  ('show', 26),
#  ('front', 26),
#  ('hear', 26),
#  ('surveyor', 26),
#  ('listen', 25),
#  ('use', 25),
#  ('ever', 25),
#  ('clean', 25),
#  ('spring', 25),
#  ('might', 25),
#  ('guess', 25),
#  ('seat', 25),
#  ('beauti', 24),
#  ('quiet', 24),
#  ('sure', 24),
#  ('pull', 24),
#  ('gave', 24),
#  ('rest', 24),
#  ('home', 24),
#  ('straight', 24),
#  ('shut', 24),
#  ('wide', 24),
#  ('coat', 24),
#  ('bright', 24),
#  ('piec', 24),
#  ('hot', 24),
#  ('song', 24),
#  ('sunshin', 23),
#  ('without', 23),
#  ('felt', 23),
#  ('need', 23),
#  ('hard', 23),
#  ('follow', 23),
#  ('whisper', 23),
#  ('farther', 23),
#  ('paper', 23),
#  ('milk', 23),
#  ('buggi', 22),
#  ('creek', 22),
#  ('tire', 22),
#  ('close', 22),
#  ('dress', 22),
#  ('stand', 22),
#  ('els', 22),
#  ('travel', 22),
#  ('afternoon', 22),
#  ('step', 22),
#  ('wolv', 22),
#  ('empti', 22),
#  ('tall', 22),
#  ('thank', 22),
#  ('east', 22),
#  ('cloth', 22),
#  ('find', 22),
#  ('finish', 22),
#  ('near', 22),
#  ('wolf', 22),
#  ('shore', 22),
#  ('wrap', 21),
#  ('rock', 21),
#  ('thin', 21),
#  ('drove', 21),
#  ('seen', 21),
#  ('clear', 21),
#  ('done', 21),
#  ('young', 21),
#  ('earth', 21),
#  ('road', 21),
#  ('ahead', 21),
#  ('south', 21),
#  ('yellow', 21),
#  ('edg', 21),
#  ('load', 21),
#  ('earli', 20),
#  ('doorway', 20),
#  ('marri', 20),
#  ('smooth', 20),
#  ('arm', 20),
#  ('indian', 20),
#  ('hat', 20),
#  ('best', 20),
#  ('roll', 20),
#  ('suddenli', 20),
#  ('happi', 20),
#  ('car', 20),
#  ('tini', 20),
#  ('blew', 20),
#  ('glass', 20),
#  ('rough', 20),
#  ('circl', 20),
#  ('mile', 20),
#  ('star', 20),
#  ('blow', 20),
#  ('biscuit', 20),
#  ('word', 19),
#  ('dri', 19),
#  ('henri', 19),
#  ('tomorrow', 19),
#  ('short', 19),
#  ('blanket', 19),
#  ('minut', 19),
#  ('mayb', 19),
#  ('sweet', 19),
#  ('shine', 19),
#  ('curv', 19),
#  ('sew', 19),
#  ('rememb', 19),
#  ('music', 19),
#  ('ingal', 19),
#  ('flock', 19),
#  ('rose', 19),
#  ('laid', 19),
#  ('soft', 19),
#  ('strang', 18),
#  ('week', 18),
#  ('compani', 18),
#  ('folk', 18),
#  ('strong', 18),
#  ('it.', 18),
#  ('readi', 18),
#  ('squar', 18),
#  ('peopl', 18),
#  ('found', 18),
#  ('wheel', 18),
#  ('fresh', 18),
#  ('track', 18),
#  ('offic', 18),
#  ('deep', 18),
#  ('bank', 18),
#  ('buffalo', 18),
#  ('exclaim', 18),
#  ('dump', 18),
#  ('potato', 17),
#  ('cow', 17),
#  ('year', 17),
#  ('hi', 17),
#  ('someth', 17),
#  ('nice', 17),
#  ('comfort', 17),
#  ('smile', 17),
#  ('school', 17),
#  ('realli', 17),
#  ('grew', 17),
#  ('green', 17),
#  ('fall', 17),
#  ('nobodi', 17),
#  ('fri', 17),
#  ('plate', 17),
#  ('twinkl', 17),
#  ('weather', 17),
#  ('duck', 17),
#  ('gees', 17),
#  ('lie', 16),
#  ('golden', 16),
#  ('wood', 16),
#  ('pack', 16),
#  ('fine', 16),
#  ('gray', 16),
#  ('corner', 16),
#  ('faster', 16),
#  ('flower', 16),
#  ('alreadi', 16),
#  ('hole', 16),
#  ('loud', 16),
#  ('wish', 16),
#  ('yell', 16),
#  ('half', 16),
#  ('jean', 16),
#  ('roof', 16),
#  ('tea', 16),
#  ('sigh', 15),
#  ('yet', 15),
#  ('bare', 15),
#  ('territori', 15),
#  ('tight', 15),
#  ('rush', 15),
#  ('engin', 15),
#  ('outsid', 15),
#  ('happen', 15),
#  ('beat', 15),
#  ('handl', 15),
#  ('drink', 15),
#  ('bell', 15),
#  ('world', 15),
#  ('quietli', 15),
#  ('pail', 15),
#  ('fli', 15),
#  ('stretch', 15),
#  ('teamster', 15),
#  ('lumber', 15),
#  ('spread', 15),
#  ('salt', 15),
#  ('anyway', 15),
#  ('hang', 15),
#  ('crack', 15),
#  ('paymast', 15),
#  ('though', 15),
#  ('worri', 15),
#  ('wing', 15),
#  ('dust', 15),
#  ('level', 15),
#  ('apron', 15),
#  ('fire', 15),
#  ('stori', 15),
#  ('violet', 15),
#  ('plum', 14),
#  ('summer', 14),
#  ('dollar', 14),
#  ('kind', 14),
#  ('hope', 14),
#  ('scare', 14),
#  ('smoke', 14),
#  ('everyon', 14),
#  ('rise', 14),
#  ('late', 14),
#  ('tie', 14),
#  ('pass', 14),
#  ('jolt', 14),
#  ('reach', 14),
#  ('cup', 14),
#  ('stranger', 14),
#  ('north', 14),
#  ('surpris', 14),
#  ('lost', 14),
#  ('built', 14),
#  ('shovel', 14),
#  ('swan', 14),
#  ('downstair', 14),
#  ('hundr', 13),
#  ('gentli', 13),
#  ('excit', 13),
#  ('leg', 13),
#  ('trot', 13),
#  ('lone', 13),
#  ('climb', 13),
#  ('touch', 13),
#  ('slope', 13),
#  ('grow', 13),
#  ('insid', 13),
#  ('pick', 13),
#  ('heart', 13),
#  ('outdoor', 13),
#  ('lap', 13),
#  ('part', 13),
#  ('candi', 13),
#  ('rather', 13),
#  ('shone', 13),
#  ('shirt', 13),
#  ('wave', 13),
#  ('tune', 13),
#  ('skin', 13),
#  ('coal', 13),
#  ('hurt', 13),
#  ('file', 13),
#  ('mitten', 13),
#  ('present', 13),
#  ('alon', 12),
#  ('rabbit', 12),
#  ('job', 12),
#  ('give', 12),
#  ('anywher', 12),
#  ('haul', 12),
#  ('nose', 12),
#  ('river', 12),
#  ('lean-to', 12),
#  ('onto', 12),
#  ('row', 12),
#  ('paid', 12),
#  ('lift', 12),
#  ('scream', 12),
#  ('swell', 12),
#  ('thick', 12),
#  ('push', 12),
#  ('cheer', 12),
#  ('jump', 12),
#  ('glitter', 12),
#  ('shelf', 12),
#  ('mind', 12),
#  ('tast', 12),
#  ('rope', 12),
#  ('fit', 12),
#  ('china', 12),
#  ('bowl', 12),
#  ('ate', 12),
#  ('lamp', 12),
#  ('sight', 12),
#  ('bit', 12),
#  ('picket', 12),
#  ('cook', 12),
#  ('among', 12),
#  ('gun', 12),
#  ('bunk', 12),
#  ('johnni', 12),
#  ('ellen', 12),
#  ('broom', 12),
#  ('hill', 12),
#  ('nearli', 12),
#  ('flour', 12),
#  ('brook', 12),
#  ('hood', 12),
#  ('blind', 11),
#  ('hunt', 11),
#  ('danc', 11),
#  ('month', 11),
#  ('name', 11),
#  ('rode', 11),
#  ('often', 11),
#  ('fellow', 11),
#  ('mean', 11),
#  ('shook', 11),
#  ('mouth', 11),
#  ('cost', 11),
#  ('narrow', 11),
#  ('shot', 11),
#  ('slid', 11),
#  ('higher', 11),
#  ('color', 11),
#  ('quit', 11),
#  ('save', 11),
#  ('gather', 11),
#  ('hotel', 11),
#  ('street', 11),
#  ('boot', 11),
#  ('except', 11),
#  ('heavi', 11),
#  ('rich', 11),
#  ('fell', 11),
#  ('bedroom', 11),
#  ('mane', 11),
#  ('dirt', 11),
#  ('pile', 11),
#  ('sometim', 11),
#  ('drop', 11),
#  ('gentl', 11),
#  ('life', 11),
#  ('pork', 11),
#  ('point', 11),
#  ('bag', 11),
#  ('bedstead', 11),
#  ('nail', 11),
#  ('pantri', 11),
#  ('brother', 11),
#  ('merri', 11),
#  ('whatnot', 11),
#  ('mosquito', 11),
#  ('babi', 10),
#  ('quilt', 10),
#  ('meant', 10),
#  ('acr', 10),
#  ('agre', 10),
#  ('kill', 10),
#  ('busi', 10),
#  ('troubl', 10),
#  ('dog', 10),
#  ('slept', 10),
#  ('perhap', 10),
#  ('five', 10),
#  ('pleas', 10),
#  ('spoke', 10),
#  ('real', 10),
#  ('field', 10),
#  ('platform', 10),
#  ('may', 10),
#  ('enorm', 10),
#  ('cap', 10),
#  ('shoulder', 10),
#  ('jerk', 10),
#  ('quick', 10),
#  ('stripe', 10),
#  ('read', 10),
#  ('pour', 10),
#  ('noon', 10),
#  ('led', 10),
#  ('plenti', 10),
#  ('differ', 10),
#  ('cousin', 10),
#  ('tail', 10),
#  ('dead', 10),
#  ('cool', 10),
#  ('snug', 10),
#  ('bean', 10),
#  ('muddi', 10),
#  ('somebodi', 10),
#  ('teach', 10),
#  ('ice', 10),
#  ('moonlight', 10),
#  ('bottom', 10),
#  ('sunbonnet', 9),
#  ('fifti', 9),
#  ('caught', 9),
#  ('repli', 9),
#  ('figur', 9),
#  ('afraid', 9),
#  ('taken', 9),
#  ('safe', 9),
#  ('catch', 9),
#  ('cloud', 9),
#  ('love', 9),
#  ('meet', 9),
#  ('nois', 9),
#  ('wore', 9),
#  ('cent', 9),
#  ('asleep', 9),
#  ('smell', 9),
#  ('pie', 9),
#  ('awak', 9),
#  ('moment', 9),
#  ('chilli', 9),
#  ('sleepi', 9),
#  ('fat', 9),
#  ('bunkhous', 9),
#  ('fun', 9),
#  ('pleasant', 9),
#  ('wife', 9),
#  ('flew', 9),
#  ('yi', 9),
#  ('break', 9),
#  ('charg', 9),
#  ('payday', 9),
#  ('shadow', 9),
#  ('louisa', 9),
#  ('flutterbudget', 9),
#  ('slide', 9),
#  ('burn', 9),
#  ('s-down', 9),
#  ('muffler', 9),
#  ('iowa', 9),
#  ('oven', 9),
#  ('knit', 9),
#  ('gravi', 9),
#  ('fix', 9),
#  ('stuart', 9),
#  ('huron', 9),
#  ('poor', 8),
#  ('ear', 8),
#  ('worn', 8),
#  ('sinc', 8),
#  ('anybodi', 8),
#  ('wisconsin', 8),
#  ('sam', 8),
#  ('farm', 8),
#  ('meat', 8),
#  ('sister', 8),
#  ('declar', 8),
#  ('coupl', 8),
#  ('cours', 8),
#  ('whistl', 8),
#  ('driver', 8),
#  ('manag', 8),
#  ('bow', 8),
#  ('iron', 8),
#  ('stiff', 8),
#  ('joy', 8),
#  ('attic', 8),
#  ('tip', 8),
#  ('lamplight', 8),
#  ('path', 8),
#  ('satchel', 8),
#  ('bonnet', 8),
#  ('shoe', 8),
#  ('calico', 8),
#  ('flat', 8),
#  ('past', 8),
#  ('velvet', 8),
#  ('slant', 8),
#  ('middl', 8),
#  ('handkerchief', 8),
#  ('larger', 8),
#  ('smaller', 8),
#  ('us.', 8),
#  ('howl', 8),
#  ('tear', 8),
#  ('string', 8),
#  ('pound', 8),
#  ('gallop', 8),
#  ('mark', 8),
#  ('grassi', 8),
#  ('join', 8),
#  ('charles.', 8),
#  ('plant', 8),
#  ('rustl', 8),
#  ('hay', 8),
#  ('march', 8),
#  ('meal', 8),
#  ('slice', 8),
#  ('bedtim', 8),
#  ('ladi', 8),
#  ('frost', 8),
#  ('shawl', 8),
#  ('burst', 8),
#  ('pan', 8),
#  ('cracker', 8),
#  ('upstair', 8),
#  ('roast', 8),
#  ('hammer', 8),
#  ('stitch', 8),
#  ('den', 8),
#  ('packag', 8),
#  ('woman', 7),
#  ('hour', 7),
#  ('bread', 7),
#  ('fish', 7),
#  ('button', 7),
#  ('exactli', 7),
#  ('me.', 7),
#  ('notic', 7),
#  ('stroke', 7),
#  ('longer', 7),
#  ('minnesota', 7),
#  ('scratch', 7),
#  ('curl', 7),
#  ('count', 7),
#  ('steel', 7),
#  ('shake', 7),
#  ('scatter', 7),
#  ('promis', 7),
#  ('sheet', 7),
#  ('strip', 7),
#  ('tin', 7),
#  ('suppos', 7),
#  ('basket', 7),
#  ('final', 7),
#  ('rail', 7),
#  ('noisi', 7),
#  ('bad', 7),
#  ('overhead', 7),
#  ('pale', 7),
#  ('steadi', 7),
#  ('fold', 7),
#  ('toss', 7),
#  ('seed', 7),
#  ('slow', 7),
#  ('soberli', 7),
#  ('chase', 7),
#  ('swung', 7),
#  ('begin', 7),
#  ('measur', 7),
#  ('sioux', 7),
#  ('steadili', 7),
#  ('feed', 7),
#  ('chanc', 7),
#  ('hollow', 7),
#  ('free', 7),
#  ('six', 7),
#  ('hem', 7),
#  ('space', 7),
#  ('pocket', 7),
#  ('sack', 7),
#  ('lucki', 7),
#  ('sorri', 7),
#  ('known', 7),
#  ('merci', 7),
#  ('heat', 7),
#  ('stair', 7),
#  ('pot', 7),
#  ('cosi', 7),
#  ('blizzard', 7),
#  ('townsit', 7),
#  ('boil', 7),
#  ('popcorn', 7),
#  ('someon', 6),
#  ('fever', 6),
#  ('wear', 6),
#  ('neat', 6),
#  ('cheek', 6),
#  ('reason', 6),
#  ('speak', 6),
#  ('homestead.', 6),
#  ('charley', 6),
#  ('stream', 6),
#  ('roar', 6),
#  ('journey', 6),
#  ('wag', 6),
#  ('lean', 6),
#  ('forgotten', 6),
#  ('later', 6),
#  ('pool', 6),
#  ('chore', 6),
#  ('stir', 6),
#  ('somehow', 6),
#  ('believ', 6),
#  ('endless', 6),
#  ('ticket', 6),
#  ('sunni', 6),
#  ('clasp', 6),
#  ('collar', 6),
#  ('fidget', 6),
#  ('pink', 6),
#  ('laura.', 6),
#  ('huge', 6),
#  ('bigger', 6),
#  ('skirt', 6),
#  ('mary.', 6),
#  ('shiver', 6),
#  ('church', 6),
#  ('melt', 6),
#  ('fasten', 6),
#  ('spend', 6),
#  ('wooden', 6),
#  ('unload', 6),
#  ('you.', 6),
#  ('pitcher', 6),
#  ('wipe', 6),
#  ('clatter', 6),
#  ('screen', 6),
#  ('butter', 6),
#  ('food', 6),
#  ('coffe', 6),
#  ('sank', 6),
#  ('oat', 6),
#  ('sunset', 6),
#  ('neck', 6),
#  ('har', 6),
#  ('flutter', 6),
#  ('sail', 6),
#  ('flap', 6),
#  ('fair', 6),
#  ('trust', 6),
#  ('sun-up', 6),
#  ('knee', 6),
#  ('rippl', 6),
#  ('sharp', 6),
#  ('mud', 6),
#  ('trail', 6),
#  ('eaten', 6),
#  ('vast', 6),
#  ('thousand', 6),
#  ('fear', 6),
#  ('matter', 6),
#  ('root', 6),
#  ('lantern', 6),
#  ('gold', 6),
#  ('ring', 6),
#  ('stuf', 6),
#  ('shimmer', 6),
#  ('plain', 6),
#  ('ruffl', 6),
#  ('tend', 6),
#  ('boss', 6),
#  ('sell', 6),
#  ('serv', 6),
#  ('smudg', 6),
#  ('met', 6),
#  ('buy', 6),
#  ('sweat', 6),
#  ('earn', 6),
#  ('ma.', 6),
#  ('snowi', 6),
#  ('feather', 6),
#  ('dishpan', 6),
#  ('bet', 6),
#  ('neighbor', 6),
#  ('warmth', 6),
#  ('lid', 6),
#  ('shelv', 6),
#  ('sour', 6),
#  ('frozen', 6),
#  ('fifteen', 6),
#  ('shall', 6),
#  ('drift', 6),
#  ('game', 6),
#  ('night.', 6),
#  ('scrap', 6),
#  ('oyster', 6),
#  ('rais', 6),
#  ('kettl', 6),
#  ('pasteboard', 6),
#  ('scallop', 6),
#  ('colleg', 6),
#  ('fairi', 6),
#  ('doctor', 5),
#  ('less', 5),
#  ('egg', 5),
#  ('debt', 5),
#  ('ago', 5),
#  ('draw', 5),
#  ('sixti', 5),
#  ('log', 5),
#  ('expect', 5),
#  ('frame', 5),
#  ('swept', 5),
#  ('depot', 5),
#  ('bake', 5),
#  ('bent', 5),
#  ('eager', 5),
#  ('hitch', 5),
#  ('sick', 5),
#  ('whenev', 5),
#  ('third', 5),
#  ('spade', 5),
#  ('gaili', 5),
#  ('rattl', 5),
#  ('bench', 5),
#  ('ribbon', 5),
#  ('crane', 5),
#  ('excus', 5),
#  ('hit', 5),
#  ('crash', 5),
#  ('anxious', 5),
#  ('suit', 5),
#  ('brakeman', 5),
#  ('backward', 5),
#  ('underneath', 5),
#  ('swoop', 5),
#  ('spot', 5),
#  ('appl', 5),
#  ('grab', 5),
#  ('spill', 5),
#  ('decid', 5),
#  ('finger', 5),
#  ('clang', 5),
#  ('amaz', 5),
#  ('boarder', 5),
#  ('lot', 5),
#  ('dusti', 5),
#  ('neatli', 5),
#  ('platter', 5),
#  ('perfectli', 5),
#  ('twenty-f', 5),
#  ('stack', 5),
#  ('somewher', 5),
#  ('jiggl', 5),
#  ('dip', 5),
#  ('sunris', 5),
#  ('older', 5),
#  ('undress', 5),
#  ('woke', 5),
#  ('rang', 5),
#  ('squeal', 5),
#  ('throat', 5),
#  ('em', 5),
#  ('true', 5),
#  ('fade', 5),
#  ('yesterday', 5),
#  ('bend', 5),
#  ('mass', 5),
#  ('goe', 5),
#  ('hidden', 5),
#  ('silenc', 5),
#  ('due', 5),
#  ('broken', 5),
#  ('wallow', 5),
#  ('cattl', 5),
#  ('rider', 5),
#  ('nearer', 5),
#  ('neither', 5),
#  ('anyon', 5),
#  ...]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#文章を小文字化
sentence_small = [w.lower() for w in sentence1]

#いけそう。文ごとに取り出し、それぞれの単語を原型に戻す。それを再び再構築する！
form_sent = []
for sentence in sentence_small:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    form_sent.append(" ".join(form))
    
    
#ピリオドやカンマを消しまーす。Delte period and comma...めんどい...
form_sent2 = []

for i in form_sent:
    tokens = nltk.word_tokenize(i)
    form = [word for word in tokens if not word in stopwords + symbols]
    form_sent2.append(" ".join(form))
    
    
#次にこの新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化したい
text = []

for i in form_sent2:
    tokens = nltk.word_tokenize(i)
    for j in tokens:
        text.append(j)
        
text = [text]

# %%
#新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化

import matplotlib.pyplot as plt
# %matplotlib inline

f_list_new = []
for i in text:
    f_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in f_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
log_freq  = []
for i in f_list_new[0].values():
    log_freq.append(i)

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_freq, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('freq(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#順位チェック
sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('laura', 693),
#  ('said', 644),
#  ('pa', 525),
#  ('go', 241),
#  ('could', 179),
#  ('one', 174),
#  ('littl', 172),
#  ('mari', 168),
#  ('carri', 166),
#  ('boast', 163),
#  ('come', 160),
#  ('look', 158),
#  ('back', 156),
#  ('came', 154),
#  ('would', 146),
#  ('big', 142),
#  ('went', 137),
#  ('get', 132),
#  ('see', 124),
#  ('grace', 123),
#  ('like', 121),
#  ('men', 116),
#  ('time', 113),
#  ('wagon', 113),
#  ('door', 110),
#  ('want', 105),
#  ('away', 100),
#  ('day', 96),
#  ('good', 93),
#  ('around', 93),
#  ('put', 93),
#  ('night', 92),
#  ('long', 91),
#  ('man', 88),
#  ('well', 88),
#  ('mrs.', 88),
#  ('mary', 87),
#  ('got', 86),
#  ('know', 85),
#  ('pa.', 84),
#  ('grass', 84),
#  ('lake', 83),
#  ('made', 82),
#  ('make', 82),
#  ('wind', 81),
#  ('never', 80),
#  ('must', 80),
#  ('everi', 77),
#  ('help', 76),
#  ('even', 76),
#  ('two', 75),
#  ('take', 75),
#  ('lena', 73),
#  ('work', 72),
#  ('caroline', 72),
#  ('hand', 71),
#  ('bed', 71),
#  ('told', 69),
#  ('last', 68),
#  ('water', 66),
#  ('hors', 66),
#  ('team', 66),
#  ('way', 64),
#  ('charles', 64),
#  ('let', 64),
#  ('oh', 64),
#  ('say', 63),
#  ('behind', 63),
#  ('asked', 62),
#  ('prairi', 62),
#  ('west', 61),
#  ('set', 60),
#  ('stood', 60),
#  ('open', 60),
#  ('still', 59),
#  ('r', 59),
#  ('cold', 58),
#  ('yes', 58),
#  ('supper', 57),
#  ('dark', 57),
#  ('warm', 57),
#  ('railroad', 56),
#  ('sky', 56),
#  ('far', 55),
#  ('place', 54),
#  ('thought', 54),
#  ('camp', 53),
#  ('right', 53),
#  ('heard', 53),
#  ('side', 53),
#  ('stove', 53),
#  ('slough', 53),
#  ('saw', 52),
#  ('across', 52),
#  ('turn', 52),
#  ('us', 52),
#  ('hous', 52),
#  ('v', 52),
#  ('along', 52),
#  ('end', 52),
#  ('store', 52),
#  ('light', 51),
#  ('eye', 51),
#  ('sat', 51),
#  ('carrie', 51),
#  ('old', 50),
#  ('ran', 50),
#  ('morn', 49),
#  ('gone', 49),
#  ('girl', 49),
#  ('wild', 49),
#  ('move', 49),
#  ('room', 49),
#  ('white', 49),
#  ('talk', 48),
#  ('anoth', 48),
#  ('grade', 48),
#  ('house', 47),
#  ('enough', 47),
#  ('care', 46),
#  ('homestead', 46),
#  ('black', 46),
#  ('stay', 45),
#  ('low', 45),
#  ('took', 45),
#  ('snow', 45),
#  ('think', 44),
#  ('first', 44),
#  ('full', 44),
#  ('board', 44),
#  ('brought', 44),
#  ('silver', 44),
#  ('dish', 43),
#  ('blue', 43),
#  ('feet', 43),
#  ('land', 43),
#  ('crowd', 43),
#  ('much', 42),
#  ('dinner', 42),
#  ('till', 42),
#  ('sun', 42),
#  ('head', 41),
#  ('stop', 41),
#  ('train', 41),
#  ('next', 41),
#  ('alway', 41),
#  ('whole', 41),
#  ('ground', 41),
#  ('run', 40),
#  ('box', 40),
#  ('christma', 40),
#  ('shanti', 40),
#  ('sang', 40),
#  ('small', 39),
#  ('new', 39),
#  ('live', 39),
#  ('almost', 39),
#  ('town', 39),
#  ('keep', 38),
#  ('docia', 38),
#  ('window', 38),
#  ('shanty', 38),
#  ('sound', 37),
#  ('seem', 37),
#  ('wait', 37),
#  ('face', 37),
#  ('great', 37),
#  ('build', 37),
#  ('wash', 36),
#  ('knew', 36),
#  ('hold', 36),
#  ('tabl', 36),
#  ('noth', 35),
#  ('start', 35),
#  ('eat', 35),
#  ('sing', 35),
#  ('soon', 35),
#  ('brown', 34),
#  ('aunt', 34),
#  ('ask', 34),
#  ('sleep', 34),
#  ('play', 34),
#  ('fast', 34),
#  ('red', 34),
#  ('voic', 34),
#  ('cut', 34),
#  ('poni', 34),
#  ('claim', 34),
#  ('better', 33),
#  ('cover', 33),
#  ('ride', 33),
#  ('besid', 33),
#  ('hurri', 33),
#  ('tree', 33),
#  ('winter', 33),
#  ('chapter', 32),
#  ('tell', 32),
#  ('settl', 32),
#  ('hair', 32),
#  ('drive', 32),
#  ('mani', 32),
#  ('high', 32),
#  ('laugh', 32),
#  ('money', 31),
#  ('glad', 31),
#  ('three', 31),
#  ('jack', 30),
#  ('chair', 30),
#  ('morning', 30),
#  ('toward', 30),
#  ('left', 30),
#  ('hardli', 30),
#  ('walk', 30),
#  ('breakfast', 30),
#  ('kept', 30),
#  ('watch', 30),
#  ('held', 30),
#  ('girls', 30),
#  ('beyond', 30),
#  ('began', 30),
#  ('curtain', 30),
#  ('reverend', 30),
#  ('tri', 29),
#  ('thing', 29),
#  ('hung', 29),
#  ('alden', 29),
#  ('pay', 28),
#  ('sit', 28),
#  ('lay', 28),
#  ('prairie', 28),
#  ('feel', 28),
#  ('air', 28),
#  ('top', 28),
#  ('anyth', 27),
#  ('pretti', 27),
#  ('uncl', 27),
#  ('round', 27),
#  ('bring', 27),
#  ('home', 27),
#  ('spring', 27),
#  ('floor', 27),
#  ('fill', 27),
#  ('jerri', 27),
#  ('quiet', 26),
#  ('show', 26),
#  ('table', 26),
#  ('answered', 25),
#  ('wall', 25),
#  ('use', 25),
#  ('ever', 25),
#  ('might', 25),
#  ('front', 25),
#  ('guess', 25),
#  ('breath', 25),
#  ('hear', 25),
#  ('scraper', 25),
#  ('fiddl', 25),
#  ('leav', 24),
#  ('sure', 24),
#  ('pull', 24),
#  ('gave', 24),
#  ('clean', 24),
#  ('straight', 24),
#  ('shut', 24),
#  ('wide', 24),
#  ('seat', 24),
#  ('bright', 24),
#  ('thi', 24),
#  ('line', 24),
#  ('quickli', 24),
#  ('hot', 24),
#  ('bird', 24),
#  ('plow', 24),
#  ('without', 23),
#  ('dress', 23),
#  ('felt', 23),
#  ('afternoon', 23),
#  ('hard', 23),
#  ('farther', 23),
#  ('east', 23),
#  ('paper', 23),
#  ('larg', 23),
#  ('find', 23),
#  ('softli', 23),
#  ('creek', 22),
#  ('close', 22),
#  ('wonder', 22),
#  ('stand', 22),
#  ('done', 22),
#  ('rest', 22),
#  ('ahead', 22),
#  ('tall', 22),
#  ('coat', 22),
#  ('south', 22),
#  ('near', 22),
#  ('wolf', 22),
#  ('call', 22),
#  ('song', 22),
#  ('shore', 22),
#  ('doorway', 21),
#  ('thin', 21),
#  ('drove', 21),
#  ('need', 21),
#  ('best', 21),
#  ('tomorrow', 21),
#  ('seen', 21),
#  ('clear', 21),
#  ('slowli', 21),
#  ('young', 21),
#  ('earth', 21),
#  ('everyth', 21),
#  ('yellow', 21),
#  ('piec', 21),
#  ('milk', 21),
#  ('rock', 20),
#  ('smooth', 20),
#  ('travel', 20),
#  ('horses', 20),
#  ('together', 20),
#  ('follow', 20),
#  ('blew', 20),
#  ('rough', 20),
#  ('thank', 20),
#  ('road', 20),
#  ('load', 20),
#  ('boy', 19),
#  ('listen', 19),
#  ('hat', 19),
#  ('short', 19),
#  ('empti', 19),
#  ('car', 19),
#  ('mayb', 19),
#  ('sweet', 19),
#  ('glass', 19),
#  ('shout', 19),
#  ('cloth', 19),
#  ('music', 19),
#  ('flock', 19),
#  ('rose', 19),
#  ('laid', 19),
#  ('soft', 19),
#  ('little', 18),
#  ('beauti', 18),
#  ('earli', 18),
#  ('hi', 18),
#  ('indian', 18),
#  ('strong', 18),
#  ('roll', 18),
#  ('school', 18),
#  ('found', 18),
#  ('shine', 18),
#  ('curv', 18),
#  ('fresh', 18),
#  ('grasses', 18),
#  ('deep', 18),
#  ('bank', 18),
#  ('edg', 18),
#  ('buffalo', 18),
#  ('stabl', 18),
#  ('strang', 17),
#  ('wrap', 17),
#  ('readi', 17),
#  ('togeth', 17),
#  ('grew', 17),
#  ('green', 17),
#  ('world', 17),
#  ('sew', 17),
#  ('twinkl', 17),
#  ('weather', 17),
#  ('tea', 17),
#  ('dump', 17),
#  ('fiddle', 17),
#  ('lie', 16),
#  ('tire', 16),
#  ('cried', 16),
#  ('golden', 16),
#  ('yet', 16),
#  ('countri', 16),
#  ('year', 16),
#  ('answer', 16),
#  ('folk', 16),
#  ('marri', 16),
#  ('squar', 16),
#  ('suddenli', 16),
#  ('fine', 16),
#  ('gray', 16),
#  ('cri', 16),
#  ('blanket', 16),
#  ('step', 16),
#  ('faster', 16),
#  ('arm', 16),
#  ('tini', 16),
#  ('loud', 16),
#  ('track', 16),
#  ('wish', 16),
#  ('fri', 16),
#  ('plate', 16),
#  ('half', 16),
#  ('star', 16),
#  ('jean', 16),
#  ('blow', 16),
#  ('singing', 16),
#  ('ingalls', 16),
#  ('exclaimed', 16),
#  ('duck', 16),
#  ('fire', 16),
#  ('eyes', 15),
#  ('week', 15),
#  ('word', 15),
#  ('country', 15),
#  ('bare', 15),
#  ('tight', 15),
#  ('rush', 15),
#  ('pack', 15),
#  ('corner', 15),
#  ('realli', 15),
#  ('whispered', 15),
#  ('wheel', 15),
#  ('hole', 15),
#  ('drink', 15),
#  ('rememb', 15),
#  ('finish', 15),
#  ('stretch', 15),
#  ('lumber', 15),
#  ('spread', 15),
#  ('salt', 15),
#  ('dishes', 15),
#  ('roof', 15),
#  ('anyway', 15),
#  ('though', 15),
#  ('l', 15),
#  ('dust', 15),
#  ('level', 15),
#  ('sunshin', 14),
#  ('plum', 14),
#  ('dri', 14),
#  ('summer', 14),
#  ('smoke', 14),
#  ('nice', 14),
#  ('late', 14),
#  ('happi', 14),
#  ('outsid', 14),
#  ('tie', 14),
#  ('beat', 14),
#  ('jolt', 14),
#  ('reach', 14),
#  ('cup', 14),
#  ('teamster', 14),
#  ('north', 14),
#  ('offic', 14),
#  ('lost', 14),
#  ('hang', 14),
#  ('built', 14),
#  ('els', 14),
#  ('coal', 14),
#  ('swan', 14),
#  ('apron', 14),
#  ('coming', 13),
#  ('buggy', 13),
#  ('compani', 13),
#  ('kind', 13),
#  ('hope', 13),
#  ('scare', 13),
#  ('everyon', 13),
#  ('laughing', 13),
#  ('rise', 13),
#  ('lone', 13),
#  ('climb', 13),
#  ('smile', 13),
#  ('wolv', 13),
#  ('touch', 13),
#  ('slope', 13),
#  ('pick', 13),
#  ('heart', 13),
#  ('stopped', 13),
#  ('windows', 13),
#  ('lap', 13),
#  ('flower', 13),
#  ('fall', 13),
#  ('part', 13),
#  ('pail', 13),
#  ('rather', 13),
#  ('bit', 13),
#  ('mile', 13),
#  ('shone', 13),
#  ('shirt', 13),
#  ('surveyor', 13),
#  ('crack', 13),
#  ('surveyors', 13),
#  ('jerry', 13),
#  ('gees', 13),
#  ('skin', 13),
#  ('biscuit', 13),
#  ('hurt', 13),
#  ('file', 13),
#  ('cow', 12),
#  ('rabbit', 12),
#  ('job', 12),
#  ('dollar', 12),
#  ('hundr', 12),
#  ('give', 12),
#  ('someth', 12),
#  ('peopl', 12),
#  ('fellow', 12),
#  ('mean', 12),
#  ('lean-to', 12),
#  ('onto', 12),
#  ('row', 12),
#  ('paid', 12),
#  ('happen', 12),
#  ('anything', 12),
#  ('lift', 12),
#  ('thick', 12),
#  ('push', 12),
#  ('shelf', 12),
#  ('mind', 12),
#  ('fit', 12),
#  ('china', 12),
#  ('bowl', 12),
#  ('ate', 12),
#  ('sight', 12),
#  ('comfort', 12),
#  ('picket', 12),
#  ('mane', 12),
#  ('dirt', 12),
#  ('wave', 12),
#  ('among', 12),
#  ('tune', 12),
#  ('life', 12),
#  ('ellen', 12),
#  ('broom', 12),
#  ('shovel', 12),
#  ('nearli', 12),
#  ('flour', 12),
#  ('christmas', 12),
#  ('blind', 11),
#  ('slowly', 11),
#  ('wood', 11),
#  ('name', 11),
#  ('henri', 11),
#  ('rode', 11),
#  ('haul', 11),
#  ('often', 11),
#  ('leg', 11),
#  ('shook', 11),
#  ('grow', 11),
#  ('narrow', 11),
#  ('shot', 11),
#  ('engin', 11),
#  ('slid', 11),
#  ('higher', 11),
#  ('nobodi', 11),
#  ('color', 11),
#  ('save', 11),
#  ('tast', 11),
#  ('hotel', 11),
#  ('bell', 11),
#  ('rope', 11),
#  ('street', 11),
#  ('fli', 11),
#  ('except', 11),
#  ('lamp', 11),
#  ('rich', 11),
#  ('shouted', 11),
#  ('fell', 11),
#  ('pile', 11),
#  ('pony', 11),
#  ('river', 11),
#  ('paymast', 11),
#  ('wing', 11),
#  ('flutterbudget', 11),
#  ('gentl', 11),
#  ('pork', 11),
#  ('talking', 11),
#  ('hill', 11),
#  ('bag', 11),
#  ('iowa', 11),
#  ('brother', 11),
#  ('mosquito', 11),
#  ('meant', 10),
#  ('month', 10),
#  ('afraid', 10),
#  ('dog', 10),
#  ('trot', 10),
#  ('slept', 10),
#  ('five', 10),
#  ('spoke', 10),
#  ('real', 10),
#  ('minut', 10),
#  ('platform', 10),
#  ('cost', 10),
#  ('may', 10),
#  ('cap', 10),
#  ('going', 10),
#  ('glitter', 10),
#  ('quick', 10),
#  ('read', 10),
#  ('handl', 10),
#  ('pour', 10),
#  ('candy', 10),
#  ('quit', 10),
#  ('gather', 10),
#  ('noon', 10),
#  ('minute', 10),
#  ('circl', 10),
#  ('jump', 10),
#  ('led', 10),
#  ('plenti', 10),
#  ('laughed', 10),
#  ('bedroom', 10),
#  ('alreadi', 10),
#  ('dead', 10),
#  ('cool', 10),
#  ('gun', 10),
#  ('drop', 10),
#  ('snug', 10),
#  ('johnni', 10),
#  ('somebodi', 10),
#  ('teach', 10),
#  ('bedstead', 10),
#  ('nail', 10),
#  ('stranger', 10),
#  ('ice', 10),
#  ('moonlight', 10),
#  ('hood', 10),
#  ('merri', 10),
#  ('bottom', 10),
#  ('violets', 10),
#  ('huron', 10),
#  ('buggi', 9),
#  ('sunbonnet', 9),
#  ('horse', 9),
#  ('potatoes', 9),
#  ('wisconsin', 9),
#  ('territory', 9),
#  ('fifti', 9),
#  ('farm', 9),
#  ('acr', 9),
#  ('henry', 9),
#  ('else', 9),
#  ('caught', 9),
#  ('figur', 9),
#  ('troubl', 9),
#  ('taken', 9),
#  ('catch', 9),
#  ('cloud', 9),
#  ('love', 9),
#  ('pass', 9),
#  ('shoulder', 9),
#  ('wore', 9),
#  ('stripe', 9),
#  ('asleep', 9),
#  ('yell', 9),
#  ('quietly', 9),
#  ('quickly', 9),
#  ('pie', 9),
#  ('moment', 9),
#  ('fat', 9),
#  ('outdoor', 9),
#  ('fun', 9),
#  ('sunshine', 9),
#  ('pleasant', 9),
#  ('wife', 9),
#  ('flew', 9),
#  ('yi', 9),
#  ('kill', 9),
#  ('enorm', 9),
#  ('charg', 9),
#  ('payday', 9),
#  ('cousin', 9),
#  ('louisa', 9),
#  ('cook', 9),
#  ('nothing', 9),
#  ('boys', 9),
#  ('stable', 9),
#  ('whi', 9),
#  ('burn', 9),
#  ('muddi', 9),
#  ('s-down', 9),
#  ('oven', 9),
#  ('downstair', 9),
#  ('wolves', 9),
#  ('present', 9),
#  ('fix', 9),
#  ('whatnot', 9),
#  ('stuart', 9),
#  ('babi', 8),
#  ('poor', 8),
#  ('alon', 8),
#  ('worn', 8),
#  ('sinc', 8),
#  ('sam', 8),
#  ('meat', 8),
#  ('gently', 8),
#  ('excit', 8),
#  ('sister', 8),
#  ('anywher', 8),
#  ('coupl', 8),
#  ('driver', 8),
#  ('bow', 8),
#  ('stiff', 8),
#  ('nose', 8),
#  ('longer', 8),
#  ('tired', 8),
#  ('started', 8),
#  ('attic', 8),
#  ('sigh', 8),
#  ('safe', 8),
#  ('lamplight', 8),
#  ('path', 8),
#  ('field', 8),
#  ('washing', 8),
#  ('bonnet', 8),
#  ('calico', 8),
#  ('meet', 8),
#  ('swell', 8),
#  ('please', 8),
#  ('past', 8),
#  ('velvet', 8),
#  ('people', 8),
#  ('slant', 8),
#  ('smell', 8),
#  ('handkerchief', 8),
#  ('larger', 8),
#  ('everything', 8),
#  ('smaller', 8),
#  ('finished', 8),
#  ('large', 8),
#  ('tear', 8),
#  ('heavi', 8),
#  ('chase', 8),
#  ('break', 8),
#  ('mark', 8),
#  ('grassi', 8),
#  ('miles', 8),
#  ('join', 8),
#  ('shadow', 8),
#  ('bunk', 8),
#  ('boss', 8),
#  ('meal', 8),
#  ('potato', 8),
#  ('slice', 8),
#  ('bedtime', 8),
#  ('sometim', 8),
#  ('slide', 8),
#  ('frost', 8),
#  ('shawl', 8),
#  ('burst', 8),
#  ('pan', 8),
#  ('roast', 8),
#  ('mitten', 8),
#  ('blizzard', 8),
#  ('story', 8),
#  ('knit', 8),
#  ('stitch', 8),
#  ('den', 8),
#  ('biscuits', 8),
#  ('woman', 7),
#  ('sighed', 7),
#  ('quilt', 7),
#  ('hour', 7),
#  ('hunt', 7),
#  ('danc', 7),
#  ('replied', 7),
#  ('busi', 7),
#  ('stroke', 7),
#  ('territori', 7),
#  ('joy', 7),
#  ('minnesota', 7),
#  ('perhap', 7),
#  ('later', 7),
#  ('tip', 7),
#  ('mouth', 7),
#  ('count', 7),
#  ('insid', 7),
#  ('steel', 7),
#  ('scream', 7),
#  ('church', 7),
#  ('scatter', 7),
#  ('opened', 7),
#  ('sheet', 7),
#  ('middl', 7),
#  ('tin', 7),
#  ('suppos', 7),
#  ('basket', 7),
#  ('boot', 7),
#  ('bad', 7),
#  ('overhead', 7),
#  ('nois', 7),
#  ('pale', 7),
#  ('steadi', 7),
#  ('ponies', 7),
#  ('jerk', 7),
#  ('howl', 7),
#  ('toss', 7),
#  ('washed', 7),
#  ('gallop', 7),
#  ('circle', 7),
#  ('pound', 7),
#  ('swung', 7),
#  ('begin', 7),
#  ('sioux', 7),
#  ('trees', 7),
#  ('steadili', 7),
#  ('feed', 7),
#  ('anybodi', 7),
#  ('matter', 7),
#  ('free', 7),
#  ('plant', 7),
#  ('whisper', 7),
#  ('hay', 7),
#  ('six', 7),
#  ('worri', 7),
#  ('sell', 7),
#  ('hem', 7),
#  ('point', 7),
#  ('space', 7),
#  ('sack', 7),
#  ('lucki', 7),
#  ('known', 7),
#  ('brookings', 7),
#  ('muffler', 7),
#  ('heat', 7),
#  ('frozen', 7),
#  ('hammer', 7),
#  ('popcorn', 7),
#  ('building', 7),
#  ('violet', 7),
#  ('someon', 6),
#  ('fever', 6),
#  ('beautiful', 6),
#  ('wear', 6),
#  ('bread', 6),
#  ('fish', 6),
#  ('neat', 6),
#  ('button', 6),
#  ('reason', 6),
#  ('charley', 6),
#  ('stream', 6),
#  ('manag', 6),
#  ('journey', 6),
#  ('lean', 6),
#  ('sunni', 5),
#  ('shoe', 5),
#  ('ribbon', 5),
#  ('excus', 5),
#  ('whistl', 5),
#  ('hit', 5),
#  ('crash', 5),
#  ('skirt', 5),
#  ('suit', 5),
#  ('brakeman', 5),
#  ('shiver', 5),
#  ('underneath', 5),
#  ('swoop', 5),
#  ('promised', 5),
#  ('spot', 5),
#  ('grab', 5),
#  ('finger', 5),
#  ('hurry', 5),
#  ('walls', 5),
#  ('neatli', 5),
#  ('wipe', 5),
#  ('strangers', 5),
#  ...]

# %%
# let's make new list only with words whose frequency  > 25

moreThan25_freq = []

for i,j in f_list_new[0].items():
    if j >= 25:
        moreThan25_freq.append(i)

# %%
# 頻出単語top2のgameshとsaidが同時に現れる文を、ピックアップしカウントするプログラムを全ての単語に割り当てる試み。

count_s = {}

for wn1 in range(0, len(moreThan25_freq)-1):
    for wn2 in range(wn1+1, len(moreThan25_freq)):
        s = 0
    
        for sent in form_sent2:
            index1 = 0
            index2 = 0
            
            #remove duplicate
            if moreThan25_freq[wn1] != moreThan25_freq[wn2]:
                
                if moreThan25_freq[wn1] in sent.split():
                    index1 += 1
                if moreThan25_freq[wn2] in sent.split():
                    index2 += 1
              
                if index1 > 0 and index2 > 0:
                    s += 1
                
        count_s.update({( moreThan25_freq[wn1], moreThan25_freq[wn2]) :s })

# %%
#順位チェック
sorted(count_s.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('said', 'pa'), 147),
#  (('laura', 'said'), 140),
#  (('laura', 'pa'), 110),
#  (('laura', 'carri'), 88),
#  (('boast', 'mrs.'), 80),
#  (('said', 'pa.'), 78),
#  (('laura', 'mari'), 72),
#  (('said', 'go'), 61),
#  (('laura', 'go'), 54),
#  (('laura', 'could'), 49),
#  (('mari', 'carri'), 46),
#  (('laura', 'see'), 43),
#  (('said', 'boast'), 42),
#  (('pa', 'go'), 41),
#  (('pa', 'came'), 41),
#  (('laura', 'look'), 39),
#  (('laura', 'back'), 39),
#  (('said', 'mari'), 39),
#  (('said', 'charles'), 38),
#  (('silver', 'lake'), 36),
#  (('laura', 'come'), 35),
#  (('said', 'come'), 34),
#  (('said', 'know'), 33),
#  (('said', 'get'), 33),
#  (('said', 'well'), 33),
#  (('carri', 'grace'), 33),
#  (('could', 'see'), 32),
#  (('said', 'yes'), 31),
#  (('docia', 'aunt'), 31),
#  (('laura', 'one'), 30),
#  (('laura', 'mary'), 30),
#  (('pa', 'would'), 30),
#  (('laura', 'like'), 29),
#  (('laura', 'would'), 29),
#  (('v', 'got'), 29),
#  (('door', 'open'), 29),
#  (('laura', 'grace'), 28),
#  (('laura', 'asked'), 28),
#  (('said', 'caroline'), 28),
#  (('pa', 'boast'), 28),
#  (('laura', 'help'), 27),
#  (('laura', 'littl'), 27),
#  (('laura', 'went'), 27),
#  (('laura', 'put'), 27),
#  (('said', 'carri'), 27),
#  (('said', 'must'), 27),
#  (('pa', 'come'), 27),
#  (('pa', 'wagon'), 27),
#  (('big', 'slough'), 27),
#  (('laura', 'get'), 26),
#  (('said', 'want'), 26),
#  (('laura', 'time'), 25),
#  (('laura', 'thought'), 25),
#  (('laura', 'lena'), 25),
#  (('laura', 'boast'), 25),
#  (('said', 'time'), 25),
#  (('said', 'see'), 25),
#  (('said', 'like'), 25),
#  (('said', 'r'), 25),
#  (('pa', 'like'), 25),
#  (('want', 'go'), 25),
#  (('laura', 'never'), 24),
#  (('one', 'said'), 24),
#  (('mari', 'pa'), 24),
#  (('carri', 'pa'), 24),
#  (('laura', 'want'), 23),
#  (('laura', 'bed'), 23),
#  (('one', 'pa'), 23),
#  (('look', 'said'), 23),
#  (('pa', 'asked'), 23),
#  (('pa', 'big'), 23),
#  (('pa', 'get'), 23),
#  (('pa', 'back'), 23),
#  (('laura', 'told'), 22),
#  (('laura', 'make'), 22),
#  (('said', 'mary'), 22),
#  (('said', 'would'), 22),
#  (('said', 'mrs.'), 22),
#  (('pa', 'littl'), 22),
#  (('pa', 'door'), 22),
#  (('go', 'would'), 22),
#  (('go', 'back'), 22),
#  (('laura', 'came'), 21),
#  (('laura', 'big'), 21),
#  (('laura', 'let'), 21),
#  (('look', 'pa'), 21),
#  (('said', 'back'), 21),
#  (('pa', 'know'), 21),
#  (('pa', 'could'), 21),
#  (('pa', 'caroline'), 21),
#  (('go', 'west'), 21),
#  (('go', 'get'), 21),
#  (('big', 'jerri'), 21),
#  (('reverend', 'alden'), 21),
#  (('laura', 'wash'), 20),
#  (('laura', 'know'), 20),
#  (('laura', 'sat'), 20),
#  (('laura', 'hand'), 20),
#  (('laura', 'heard'), 20),
#  (('laura', 'mrs.'), 20),
#  (('said', 'littl'), 20),
#  (('said', 'take'), 20),
#  (('said', 'good'), 20),
#  (('said', 'work'), 20),
#  (('pa', 'went'), 20),
#  (('said', 'make'), 19),
#  (('said', 'men'), 19),
#  (('said', 'lena'), 19),
#  (('mari', 'grace'), 19),
#  (('grace', 'pa'), 19),
#  (('pa', 'time'), 19),
#  (('pa', 'see'), 19),
#  (('could', 'go'), 19),
#  (('laura', 'must'), 18),
#  (('laura', 'carrie'), 18),
#  (('laura', 'door'), 18),
#  (('one', 'day'), 18),
#  (('said', 'let'), 18),
#  (('said', 'away'), 18),
#  (('pa', 'must'), 18),
#  (('go', 'r'), 18),
#  (('laura', 'morn'), 17),
#  (('laura', 'pa.'), 17),
#  (('laura', 'set'), 17),
#  (('look', 'go'), 17),
#  (('said', 'could'), 17),
#  (('said', 'got'), 17),
#  (('said', 'right'), 17),
#  (('said', 'put'), 17),
#  (('care', 'take'), 17),
#  (('railroad', 'grade'), 17),
#  (('laura', 'still'), 16),
#  (('laura', 'eye'), 16),
#  (('laura', 'say'), 16),
#  (('laura', 'night'), 16),
#  (('look', 'like'), 16),
#  (('said', 'long'), 16),
#  (('said', 'never'), 16),
#  (('said', 'girl'), 16),
#  (('mari', 'go'), 16),
#  (('pa', 'even'), 16),
#  (('pa', 'work'), 16),
#  (('pa', 'well'), 16),
#  (('pa', 'put'), 16),
#  (('pa', 'store'), 16),
#  (('laura', 'saw'), 15),
#  (('laura', 'made'), 15),
#  (('laura', 'good'), 15),
#  (('laura', 'well'), 15),
#  (('laura', 'wagon'), 15),
#  (('laura', 'oh'), 15),
#  (('laura', 'tabl'), 15),
#  (('said', 'us'), 15),
#  (('said', 'v'), 15),
#  (('said', 'first'), 15),
#  (('said', 'night'), 15),
#  (('said', 'soon'), 15),
#  (('mari', 'could'), 15),
#  (('carri', 'help'), 15),
#  (('pa', 'good'), 15),
#  (('pa', 'oh'), 15),
#  (('pa', 'play'), 15),
#  (('pa', 'sang'), 15),
#  (('everi', 'day'), 15),
#  (('far', 'away'), 15),
#  (('went', 'back'), 15),
#  (('laura', 'dish'), 14),
#  (('laura', 'day'), 14),
#  (('laura', 'work'), 14),
#  (('laura', 'girl'), 14),
#  (('laura', 'away'), 14),
#  (('laura', 'supper'), 14),
#  (('laura', 'wind'), 14),
#  (('said', 'two'), 14),
#  (('said', 'supper'), 14),
#  (('mari', 'sat'), 14),
#  (('help', 'pa'), 14),
#  (('pa', 'day'), 14),
#  (('pa', 'take'), 14),
#  (('pa', 'homestead'), 14),
#  (('pa', 'let'), 14),
#  (('pa', 'man'), 14),
#  (('pa', 'hors'), 14),
#  (('pa', 'last'), 14),
#  (('pa', 'men'), 14),
#  (('pa', 'fiddl'), 14),
#  (('could', 'hardli'), 14),
#  (('go', 'let'), 14),
#  (('came', 'back'), 14),
#  (('grass', 'slough'), 14),
#  (('men', 'team'), 14),
#  (('chapter', 'pa'), 13),
#  (('laura', 'gone'), 13),
#  (('laura', 'take'), 13),
#  (('laura', 'knew'), 13),
#  (('laura', 'box'), 13),
#  (('laura', 'men'), 13),
#  (('look', 'around'), 13),
#  (('said', 'day'), 13),
#  (('said', 'carrie'), 13),
#  (('said', 'oh'), 13),
#  (('said', 'reverend'), 13),
#  (('grace', 'sat'), 13),
#  (('pa', 'think'), 13),
#  (('pa', 'want'), 13),
#  (('pa', 'two'), 13),
#  (('pa', 'r'), 13),
#  (('pa', 'told'), 13),
#  (('pa', 'make'), 13),
#  (('pa', 'night'), 13),
#  (('come', 'go'), 13),
#  (('come', 'back'), 13),
#  (('long', 'time'), 13),
#  (('never', 'would'), 13),
#  (('go', 'boast'), 13),
#  (('came', 'night'), 13),
#  (('laura', 'everi'), 12),
#  (('laura', 'even'), 12),
#  (('laura', 'water'), 12),
#  (('laura', 'way'), 12),
#  (('laura', 'yes'), 12),
#  (('wash', 'dish'), 12),
#  (('said', 'even'), 12),
#  (('said', 'think'), 12),
#  (('said', 'homestead'), 12),
#  (('said', 'came'), 12),
#  (('said', 'keep'), 12),
#  (('said', 'enough'), 12),
#  (('said', 'thought'), 12),
#  (('said', 'last'), 12),
#  (('said', 'girls'), 12),
#  (('said', 'alden'), 12),
#  (('carri', 'bed'), 12),
#  (('grace', 'littl'), 12),
#  (('pa', 'gone'), 12),
#  (('pa', 'made'), 12),
#  (('pa', 'railroad'), 12),
#  (('pa', 'behind'), 12),
#  (('pa', 'heard'), 12),
#  (('could', 'would'), 12),
#  (('could', 'get'), 12),
#  (('could', 'fast'), 12),
#  (('blue', 'eye'), 12),
#  (('go', 'wagon'), 12),
#  (('work', 'men'), 12),
#  (('set', 'tabl'), 12),
#  (('sky', 'lake'), 12),
#  (('laura', 'house'), 11),
#  (('laura', 'across'), 11),
#  (('laura', 'stay'), 11),
#  (('laura', 'till'), 11),
#  (('laura', 'feet'), 11),
#  (('laura', 'around'), 11),
#  (('laura', 'got'), 11),
#  (('laura', 'place'), 11),
#  (('laura', 'ask'), 11),
#  (('laura', 'hors'), 11),
#  (('laura', 'almost'), 11),
#  (('laura', 'stood'), 11),
#  (('laura', 'walk'), 11),
#  (('laura', 'grass'), 11),
#  (('laura', 'besid'), 11),
#  (('laura', 'began'), 11),
#  (('see', 'go'), 10),
#  (('see', 'would'), 10),
#  (('like', 'littl'), 10),
#  (('turn', 'around'), 10),
#  (('must', 'go'), 10),
#  (('go', 'pa.'), 10),
#  (('go', 'away'), 10),
#  (('came', 'behind'), 10),
#  (('came', 'door'), 10),
#  (('came', 'boast'), 10),
#  (('way', 'back'), 10),
#  (('away', 'went'), 10),
#  (('back', 'wagon'), 10),
#  (('set', 'stove'), 10),
#  (('make', 'boast'), 10),
#  (('sun', 'wind'), 10),
#  (('door', 'men'), 10),
#  (('cold', 'wind'), 10),
#  (('prairi', 'sky'), 10),
#  (('chapter', 'laura'), 9),
#  (('laura', 'long'), 9),
#  (('laura', 'two'), 9),
#  (('laura', 'hous'), 9),
#  (('laura', 'r'), 9),
#  (('laura', 'black'), 9),
#  (('laura', 'use'), 9),
#  (('laura', 'move'), 9),
#  (('laura', 'ride'), 9),
#  (('laura', 'breakfast'), 9),
#  (('laura', 'watch'), 9),
#  (('laura', 'held'), 9),
#  (('laura', 'along'), 9),
#  (('laura', 'white'), 9),
#  (('laura', 'took'), 9),
#  (('laura', 'talk'), 9),
#  (('laura', 'table'), 9),
#  (('dish', 'tabl'), 9),
#  (('one', 'carri'), 9),
#  (('one', 'everi'), 9),
#  (('one', 'time'), 9),
#  (('one', 'like'), 9),
#  (('one', 'two'), 9),
#  (('one', 'door'), 9),
#  (('look', 'see'), 9),
#  (('saw', 'pa'), 9),
#  (('said', 'settl'), 9),
#  (('said', 'say'), 9),
#  (('said', 'pretti'), 9),
#  (('said', 'hous'), 9),
#  (('said', 'man'), 9),
#  (('said', 'ask'), 9),
#  (('said', 'heard'), 9),
#  (('said', 'use'), 9),
#  (('said', 'bed'), 9),
#  (('said', 'thing'), 9),
#  (('said', 'start'), 9),
#  (('said', 'christma'), 9),
#  (('said', 'team'), 9),
#  (('said', 'build'), 9),
#  (('mari', 'want'), 9),
#  (('mari', 'oh'), 9),
#  (('mari', 'bed'), 9),
#  (('carri', 'water'), 9),
#  (('carri', 'get'), 9),
#  (('carri', 'back'), 9),
#  (('carri', 'put'), 9),
#  (('carri', 'besid'), 9),
#  (('grace', 'could'), 9),
#  (('help', 'get'), 9),
#  (('help', 'put'), 9),
#  (('pa', 'dinner'), 9),
#  (('pa', 'new'), 9),
#  (('pa', 'girl'), 9),
#  (('pa', 'set'), 9),
#  (('pa', 'first'), 9),
#  (('pa', 'alway'), 9),
#  (('pa', 'side'), 9),
#  (('pa', 'took'), 9),
#  (('pa', 'town'), 9),
#  (('pa', 'voic'), 9),
#  (('pa', 'build'), 9),
#  (('come', 'away'), 9),
#  (('come', 'wagon'), 9),
#  (('everi', 'time'), 9),
#  (('could', 'want'), 9),
#  (('could', 'talk'), 9),
#  (('far', 'sky'), 9),
#  (('time', 'get'), 9),
#  (('turn', 'back'), 9),
#  (('toward', 'big'), 9),
#  (('sound', 'made'), 9),
#  (('stay', 'go'), 9),
#  (('stay', 'get'), 9),
#  (('littl', 'way'), 9),
#  (('littl', 'back'), 9),
#  (('littl', 'wind'), 9),
#  (('littl', 'dark'), 9),
#  (('go', 'around'), 9),
#  (('go', 'well'), 9),
#  (('go', 'last'), 9),
#  (('two', 'came'), 9),
#  (('made', 'bed'), 9),
#  (('came', 'men'), 9),
#  (('docia', 'lena'), 9),
#  (('get', 'boast'), 9),
#  (('back', 'hors'), 9),
#  (('back', 'door'), 9),
#  (('wagon', 'team'), 9),
#  (('box', 'fiddl'), 9),
#  (('wind', 'prairi'), 9),
#  (('men', 'grade'), 9),
#  (('lena', 'poni'), 9),
#  (('lake', 'slough'), 9),
#  (('chapter', 'morn'), 8),
#  (('chapter', 'next'), 8),
#  (('laura', 'care'), 8),
#  (('laura', 'sit'), 8),
#  (('laura', 'turn'), 8),
#  (('laura', 'us'), 8),
#  (('laura', 'railroad'), 8),
#  (('laura', 'behind'), 8),
#  (('laura', 'next'), 8),
#  (('laura', 'feel'), 8),
#  (('laura', 'tri'), 8),
#  (('laura', 'dark'), 8),
#  (('laura', 'whole'), 8),
#  (('laura', 'christma'), 8),
#  (('laura', 'sang'), 8),
#  (('laura', 'hear'), 8),
#  (('laura', 'poni'), 8),
#  (('laura', 'fiddl'), 8),
#  (('one', 'see'), 8),
#  (('one', 'big'), 8),
#  (('one', 'went'), 8),
#  (('morn', 'pa'), 8),
#  (('morn', 'came'), 8),
#  (('look', 'pa.'), 8),
#  (('said', 'water'), 8),
#  (('said', 'wait'), 8),
#  (('said', 'hand'), 8),
#  (('said', 'went'), 8),
#  (('said', 'ride'), 8),
#  (('said', 'tri'), 8),
#  (('said', 'cold'), 8),
#  (('said', 'low'), 8),
#  (('said', 'spring'), 8),
#  (('said', 'sing'), 8),
#  (('said', 'warm'), 8),
#  (('mari', 'see'), 8),
#  (('mari', 'told'), 8),
#  (('mari', 'thought'), 8),
#  (('mari', 'boast'), 8),
#  (('carri', 'come'), 8),
#  (('carri', 'could'), 8),
#  (('carri', 'big'), 8),
#  (('carri', 'let'), 8),
#  (('carri', 'mrs.'), 8),
#  (('across', 'pa'), 8),
#  (('help', 'mrs.'), 8),
#  (('pa', 'still'), 8),
#  (('pa', 'light'), 8),
#  (('pa', 'sat'), 8),
#  (('pa', 'around'), 8),
#  (('pa', 'v'), 8),
#  (('pa', 'ask'), 8),
#  (('pa', 'knew'), 8),
#  (('pa', 'grass'), 8),
#  (('pa', 'along'), 8),
#  (('pa', 'yes'), 8),
#  (('pa', 'christma'), 8),
#  (('pa', 'team'), 8),
#  (('pa', 'warm'), 8),
#  (('come', 'night'), 8),
#  (('come', 'men'), 8),
#  (('everi', 'could'), 8),
#  (('everi', 'night'), 8),
#  (('day', 'long'), 8),
#  (('know', 'want'), 8),
#  (('know', 'boast'), 8),
#  (('could', 'even'), 8),
#  (('could', 'littl'), 8),
#  (('could', 'hors'), 8),
#  (('could', 'hear'), 8),
#  (('mary', 'see'), 8),
#  (('long', 'went'), 8),
#  (('time', 'see'), 8),
#  (('time', 'back'), 8),
#  (('time', 'mani'), 8),
#  (('see', 'like'), 8),
#  (('never', 'heard'), 8),
#  (('like', 'would'), 8),
#  (('like', 'pa.'), 8),
#  (('toward', 'slough'), 8),
#  (('littl', 'hous'), 8),
#  (('littl', 'prairi'), 8),
#  (('want', 'take'), 8),
#  (('go', 'big'), 8),
#  (('go', 'girl'), 8),
#  (('go', 'winter'), 8),
#  (('go', 'mrs.'), 8),
#  (('west', 'wagon'), 8),
#  (('homestead', 'get'), 8),
#  (('came', 'went'), 8),
#  (('came', 'wild'), 8),
#  (('us', 'let'), 8),
#  (('aunt', 'lena'), 8),
#  (('big', 'man'), 8),
#  (('big', 'went'), 8),
#  (('big', 'hors'), 8),
#  (('big', 'men'), 8),
#  (('work', 'railroad'), 8),
#  (('work', 'would'), 8),
#  (('railroad', 'men'), 8),
#  (('would', 'boast'), 8),
#  (('charles', 'yes'), 8),
#  (('caroline', 'well'), 8),
#  (('around', 'back'), 8),
#  (('around', 'crowd'), 8),
#  (('got', 'man'), 8),
#  (('get', 'away'), 8),
#  (('get', 'went'), 8),
#  (('pa.', 'boast'), 8),
#  (('went', 'breakfast'), 8),
#  (('back', 'end'), 8),
#  (('wild', 'wind'), 8),
#  (('hors', 'white'), 8),
#  (('wagon', 'ride'), 8),
#  (('wagon', 'put'), 8),
#  (('wagon', 'box'), 8),
#  (('night', 'last'), 8),
#  (('crowd', 'men'), 8),
#  (('sky', 'silver'), 8),
#  (('end', 'cut'), 8),
#  (('team', 'scraper'), 8),
#  (('warm', 'stove'), 8),
#  (('laura', 'jack'), 7),
#  (('laura', 'light'), 7),
#  (('laura', 'blue'), 7),
#  (('laura', 'toward'), 7),
#  (('laura', 'west'), 7),
#  (('laura', 'keep'), 7),
#  (('laura', 'live'), 7),
#  (('laura', 'man'), 7),
#  (('laura', 'hardli'), 7),
#  (('laura', 'wait'), 7),
#  (('laura', 'train'), 7),
#  (('laura', 'sun'), 7),
#  (('laura', 'play'), 7),
#  (('laura', 'low'), 7),
#  (('laura', 'high'), 7),
#  (('laura', 'room'), 7),
#  (('laura', 'hurri'), 7),
#  (('laura', 'board'), 7),
#  (('laura', 'sing'), 7),
#  (('laura', 'cut'), 7),
#  (('laura', 'soon'), 7),
#  (('one', 'old'), 7),
#  (('one', 'mari'), 7),
#  (('one', 'across'), 7),
#  (('one', 'long'), 7),
#  (('one', 'even'), 7),
#  (('one', 'made'), 7),
#  (('one', 'way'), 7),
#  (('one', 'night'), 7),
#  (('one', 'open'), 7),
#  (('one', 'anoth'), 7),
#  (('morn', 'come'), 7),
#  (('morn', 'everi'), 7),
#  (('morn', 'go'), 7),
#  (('morn', 'breakfast'), 7),
#  (('morn', 'door'), 7),
#  (('old', 'man'), 7),
#  (('tell', 'said'), 7),
#  (('look', 'mari'), 7),
#  (('look', 'carri'), 7),
#  (('look', 'could'), 7),
#  (('look', 'head'), 7),
#  (('look', 'eye'), 7),
#  (('look', 'littl'), 7),
#  (('look', 'came'), 7),
#  (('look', 'went'), 7),
#  (('look', 'stood'), 7),
#  (('said', 'pay'), 7),
#  (('said', 'west'), 7),
#  (('said', 'docia'), 7),
#  (('said', 'new'), 7),
#  (('said', 'live'), 7),
#  (('pa', 'lake'), 6),
#  (('pa', 'snow'), 6),
#  (('come', 'day'), 6),
#  (('come', 'like'), 6),
#  (('come', 'came'), 6),
#  (('come', 'enough'), 6),
#  (('come', 'us'), 6),
#  (('come', 'oh'), 6),
#  (('come', 'yes'), 6),
#  (('come', 'team'), 6),
#  (('everi', 'even'), 6),
#  (('everi', 'littl'), 6),
#  (('everi', 'would'), 6),
#  (('everi', 'wagon'), 6),
#  (('day', 'camp'), 6),
#  (('know', 'v'), 6),
#  (('know', 'pa.'), 6),
#  (('could', 'never'), 6),
#  (('could', 'sound'), 6),
#  (('could', 'must'), 6),
#  (('could', 'money'), 6),
#  (('could', 'keep'), 6),
#  (('could', 'good'), 6),
#  (('could', 'man'), 6),
#  (('could', 'away'), 6),
#  (('could', 'wagon'), 6),
#  (('could', 'almost'), 6),
#  (('could', 'ride'), 6),
#  (('far', 'light'), 6),
#  (('far', 'would'), 6),
#  (('settl', 'go'), 6),
#  (('mary', 'behind'), 6),
#  (('mary', 'carrie'), 6),
#  (('long', 'stay'), 6),
#  (('long', 'came'), 6),
#  (('long', 'wild'), 6),
#  (('long', 'low'), 6),
#  (('long', 'lake'), 6),
#  (('time', 'wagon'), 6),
#  (('time', 'move'), 6),
#  (('time', 'last'), 6),
#  (('see', 'want'), 6),
#  (('see', 'work'), 6),
#  (('never', 'anyth'), 6),
#  (('never', 'pa.'), 6),
#  (('light', 'window'), 6),
#  (('hair', 'eye'), 6),
#  (('like', 'land'), 6),
#  (('like', 'feel'), 6),
#  (('like', 'prairi'), 6),
#  (('blue', 'littl'), 6),
#  (('blue', 'white'), 6),
#  (('eye', 'face'), 6),
#  (('think', 'would'), 6),
#  (('think', 'pa.'), 6),
#  (('think', 'well'), 6),
#  (('say', 'would'), 6),
#  (('toward', 'went'), 6),
#  (('must', 'pa.'), 6),
#  (('asked', 'go'), 6),
#  (('till', 'came'), 6),
#  (('till', 'wait'), 6),
#  (('littl', 'two'), 6),
#  (('littl', 'got'), 6),
#  (('littl', 'black'), 6),
#  (('littl', 'went'), 6),
#  (('littl', 'wild'), 6),
#  (('littl', 'hors'), 6),
#  ...]

# %%
#namely

new = {tuple(sorted(x)):y for x, y in count_s.items()}

#順位チェック again !
new2 = dict(sorted(new.items(), key=lambda x: x[1], reverse=True))

new3 = dict((k, v) for k, v in new2.items() if v >= 2)

#順位チェック again !
new4 = dict(sorted(new3.items(), key=lambda x: x[1], reverse=True))
new4
# Out:
# {('pa', 'said'): 147,
#  ('laura', 'said'): 140,
#  ('laura', 'pa'): 110,
#  ('carri', 'laura'): 88,
#  ('boast', 'mrs.'): 80,
#  ('pa.', 'said'): 78,
#  ('laura', 'mari'): 72,
#  ('go', 'said'): 61,
#  ('go', 'laura'): 54,
#  ('could', 'laura'): 49,
#  ('carri', 'mari'): 46,
#  ('laura', 'see'): 43,
#  ('boast', 'said'): 42,
#  ('go', 'pa'): 41,
#  ('came', 'pa'): 41,
#  ('laura', 'look'): 39,
#  ('back', 'laura'): 39,
#  ('mari', 'said'): 39,
#  ('charles', 'said'): 38,
#  ('lake', 'silver'): 36,
#  ('come', 'laura'): 35,
#  ('come', 'said'): 34,
#  ('know', 'said'): 33,
#  ('get', 'said'): 33,
#  ('said', 'well'): 33,
#  ('carri', 'grace'): 33,
#  ('could', 'see'): 32,
#  ('said', 'yes'): 31,
#  ('aunt', 'docia'): 31,
#  ('laura', 'one'): 30,
#  ('laura', 'mary'): 30,
#  ('pa', 'would'): 30,
#  ('laura', 'like'): 29,
#  ('laura', 'would'): 29,
#  ('got', 'v'): 29,
#  ('door', 'open'): 29,
#  ('grace', 'laura'): 28,
#  ('asked', 'laura'): 28,
#  ('caroline', 'said'): 28,
#  ('boast', 'pa'): 28,
#  ('help', 'laura'): 27,
#  ('laura', 'littl'): 27,
#  ('laura', 'went'): 27,
#  ('laura', 'put'): 27,
#  ('carri', 'said'): 27,
#  ('must', 'said'): 27,
#  ('come', 'pa'): 27,
#  ('pa', 'wagon'): 27,
#  ('big', 'slough'): 27,
#  ('get', 'laura'): 26,
#  ('said', 'want'): 26,
#  ('laura', 'time'): 25,
#  ('laura', 'thought'): 25,
#  ('laura', 'lena'): 25,
#  ('boast', 'laura'): 25,
#  ('said', 'time'): 25,
#  ('said', 'see'): 25,
#  ('like', 'said'): 25,
#  ('r', 'said'): 25,
#  ('like', 'pa'): 25,
#  ('go', 'want'): 25,
#  ('laura', 'never'): 24,
#  ('one', 'said'): 24,
#  ('mari', 'pa'): 24,
#  ('carri', 'pa'): 24,
#  ('laura', 'want'): 23,
#  ('bed', 'laura'): 23,
#  ('one', 'pa'): 23,
#  ('look', 'said'): 23,
#  ('asked', 'pa'): 23,
#  ('big', 'pa'): 23,
#  ('get', 'pa'): 23,
#  ('back', 'pa'): 23,
#  ('laura', 'told'): 22,
#  ('laura', 'make'): 22,
#  ('mary', 'said'): 22,
#  ('said', 'would'): 22,
#  ('mrs.', 'said'): 22,
#  ('littl', 'pa'): 22,
#  ('door', 'pa'): 22,
#  ('go', 'would'): 22,
#  ('back', 'go'): 22,
#  ('came', 'laura'): 21,
#  ('big', 'laura'): 21,
#  ('laura', 'let'): 21,
#  ('look', 'pa'): 21,
#  ('back', 'said'): 21,
#  ('know', 'pa'): 21,
#  ('could', 'pa'): 21,
#  ('caroline', 'pa'): 21,
#  ('go', 'west'): 21,
#  ('get', 'go'): 21,
#  ('big', 'jerri'): 21,
#  ('alden', 'reverend'): 21,
#  ('laura', 'wash'): 20,
#  ('know', 'laura'): 20,
#  ('laura', 'sat'): 20,
#  ('hand', 'laura'): 20,
#  ('heard', 'laura'): 20,
#  ('laura', 'mrs.'): 20,
#  ('littl', 'said'): 20,
#  ('said', 'take'): 20,
#  ('good', 'said'): 20,
#  ('said', 'work'): 20,
#  ('pa', 'went'): 20,
#  ('make', 'said'): 19,
#  ('men', 'said'): 19,
#  ('lena', 'said'): 19,
#  ('grace', 'mari'): 19,
#  ('grace', 'pa'): 19,
#  ('pa', 'time'): 19,
#  ('pa', 'see'): 19,
#  ('could', 'go'): 19,
#  ('laura', 'must'): 18,
#  ('carrie', 'laura'): 18,
#  ('door', 'laura'): 18,
#  ('day', 'one'): 18,
#  ('let', 'said'): 18,
#  ('away', 'said'): 18,
#  ('must', 'pa'): 18,
#  ('go', 'r'): 18,
#  ('laura', 'morn'): 17,
#  ('laura', 'pa.'): 17,
#  ('laura', 'set'): 17,
#  ('go', 'look'): 17,
#  ('could', 'said'): 17,
#  ('got', 'said'): 17,
#  ('right', 'said'): 17,
#  ('put', 'said'): 17,
#  ('care', 'take'): 17,
#  ('grade', 'railroad'): 17,
#  ('laura', 'still'): 16,
#  ('eye', 'laura'): 16,
#  ('laura', 'say'): 16,
#  ('laura', 'night'): 16,
#  ('like', 'look'): 16,
#  ('long', 'said'): 16,
#  ('never', 'said'): 16,
#  ('girl', 'said'): 16,
#  ('go', 'mari'): 16,
#  ('even', 'pa'): 16,
#  ('pa', 'work'): 16,
#  ('pa', 'well'): 16,
#  ('pa', 'put'): 16,
#  ('pa', 'store'): 16,
#  ('laura', 'saw'): 15,
#  ('laura', 'made'): 15,
#  ('good', 'laura'): 15,
#  ('laura', 'well'): 15,
#  ('laura', 'wagon'): 15,
#  ('laura', 'oh'): 15,
#  ('laura', 'tabl'): 15,
#  ('said', 'us'): 15,
#  ('said', 'v'): 15,
#  ('first', 'said'): 15,
#  ('night', 'said'): 15,
#  ('said', 'soon'): 15,
#  ('could', 'mari'): 15,
#  ('carri', 'help'): 15,
#  ('good', 'pa'): 15,
#  ('oh', 'pa'): 15,
#  ('pa', 'play'): 15,
#  ('pa', 'sang'): 15,
#  ('day', 'everi'): 15,
#  ('away', 'far'): 15,
#  ('back', 'went'): 15,
#  ('dish', 'laura'): 14,
#  ('day', 'laura'): 14,
#  ('laura', 'work'): 14,
#  ('girl', 'laura'): 14,
#  ('away', 'laura'): 14,
#  ('laura', 'supper'): 14,
#  ('laura', 'wind'): 14,
#  ('said', 'two'): 14,
#  ('said', 'supper'): 14,
#  ('mari', 'sat'): 14,
#  ('help', 'pa'): 14,
#  ('day', 'pa'): 14,
#  ('pa', 'take'): 14,
#  ('homestead', 'pa'): 14,
#  ('let', 'pa'): 14,
#  ('man', 'pa'): 14,
#  ('hors', 'pa'): 14,
#  ('last', 'pa'): 14,
#  ('men', 'pa'): 14,
#  ('fiddl', 'pa'): 14,
#  ('could', 'hardli'): 14,
#  ('go', 'let'): 14,
#  ('back', 'came'): 14,
#  ('grass', 'slough'): 14,
#  ('men', 'team'): 14,
#  ('chapter', 'pa'): 13,
#  ('gone', 'laura'): 13,
#  ('laura', 'take'): 13,
#  ('knew', 'laura'): 13,
#  ('box', 'laura'): 13,
#  ('laura', 'men'): 13,
#  ('around', 'look'): 13,
#  ('day', 'said'): 13,
#  ('carrie', 'said'): 13,
#  ('oh', 'said'): 13,
#  ('reverend', 'said'): 13,
#  ('grace', 'sat'): 13,
#  ('pa', 'think'): 13,
#  ('pa', 'want'): 13,
#  ('pa', 'two'): 13,
#  ('pa', 'r'): 13,
#  ('pa', 'told'): 13,
#  ('make', 'pa'): 13,
#  ('night', 'pa'): 13,
#  ('come', 'go'): 13,
#  ('back', 'come'): 13,
#  ('long', 'time'): 13,
#  ('never', 'would'): 13,
#  ('boast', 'go'): 13,
#  ('came', 'night'): 13,
#  ('everi', 'laura'): 12,
#  ('even', 'laura'): 12,
#  ('laura', 'water'): 12,
#  ('laura', 'way'): 12,
#  ('laura', 'yes'): 12,
#  ('dish', 'wash'): 12,
#  ('even', 'said'): 12,
#  ('said', 'think'): 12,
#  ('homestead', 'said'): 12,
#  ('came', 'said'): 12,
#  ('keep', 'said'): 12,
#  ('enough', 'said'): 12,
#  ('said', 'thought'): 12,
#  ('last', 'said'): 12,
#  ('girls', 'said'): 12,
#  ('alden', 'said'): 12,
#  ('bed', 'carri'): 12,
#  ('grace', 'littl'): 12,
#  ('gone', 'pa'): 12,
#  ('made', 'pa'): 12,
#  ('pa', 'railroad'): 12,
#  ('behind', 'pa'): 12,
#  ('heard', 'pa'): 12,
#  ('could', 'would'): 12,
#  ('could', 'get'): 12,
#  ('could', 'fast'): 12,
#  ('blue', 'eye'): 12,
#  ('go', 'wagon'): 12,
#  ('men', 'work'): 12,
#  ('set', 'tabl'): 12,
#  ('lake', 'sky'): 12,
#  ('house', 'laura'): 11,
#  ('across', 'laura'): 11,
#  ('laura', 'stay'): 11,
#  ('laura', 'till'): 11,
#  ('feet', 'laura'): 11,
#  ('around', 'laura'): 11,
#  ('got', 'laura'): 11,
#  ('laura', 'place'): 11,
#  ('ask', 'laura'): 11,
#  ('hors', 'laura'): 11,
#  ('almost', 'laura'): 11,
#  ('laura', 'stood'): 11,
#  ('laura', 'walk'): 11,
#  ('grass', 'laura'): 11,
#  ('besid', 'laura'): 11,
#  ('began', 'laura'): 11,
#  ('lake', 'laura'): 11,
#  ('dinner', 'said'): 11,
#  ('said', 'stay'): 11,
#  ('said', 'till'): 11,
#  ('railroad', 'said'): 11,
#  ('land', 'said'): 11,
#  ('better', 'said'): 11,
#  ('said', 'wagon'): 11,
#  ('guess', 'said'): 11,
#  ('care', 'pa'): 11,
#  ('carri', 'littl'): 11,
#  ('carri', 'sat'): 11,
#  ('boast', 'carri'): 11,
#  ('grace', 'help'): 11,
#  ('bed', 'grace'): 11,
#  ('everi', 'pa'): 11,
#  ('answered', 'pa'): 11,
#  ('got', 'pa'): 11,
#  ('pa', 'pa.'): 11,
#  ('pa', 'right'): 11,
#  ('away', 'pa'): 11,
#  ('pa', 'talk'): 11,
#  ('brought', 'pa'): 11,
#  ('men', 'see'): 11,
#  ('sound', 'wind'): 11,
#  ('came', 'littl'): 11,
#  ('littl', 'water'): 11,
#  ('big', 'littl'): 11,
#  ('grass', 'littl'): 11,
#  ('men', 'two'): 11,
#  ('came', 'wagon'): 11,
#  ('lake', 'water'): 11,
#  ('big', 'white'): 11,
#  ('grade', 'work'): 11,
#  ('thought', 'would'): 11,
#  ('behind', 'wagon'): 11,
#  ('behind', 'door'): 11,
#  ('grass', 'wind'): 11,
#  ('grass', 'prairi'): 11,
#  ('laura', 'old'): 10,
#  ('laura', 'much'): 10,
#  ('far', 'laura'): 10,
#  ('head', 'laura'): 10,
#  ('laura', 'think'): 10,
#  ('answered', 'laura'): 10,
#  ('enough', 'laura'): 10,
#  ('alway', 'laura'): 10,
#  ('ever', 'laura'): 10,
#  ('bring', 'laura'): 10,
#  ('cold', 'laura'): 10,
#  ('laura', 'run'): 10,
#  ('last', 'laura'): 10,
#  ('laura', 'side'): 10,
#  ('full', 'laura'): 10,
#  ('laura', 'ran'): 10,
#  ('laura', 'open'): 10,
#  ('laura', 'shanti'): 10,
#  ('laura', 'warm'): 10,
#  ('littl', 'one'): 10,
#  ('go', 'one'): 10,
#  ('man', 'one'): 10,
#  ('morn', 'next'): 10,
#  ('back', 'look'): 10,
#  ('grace', 'said'): 10,
#  ('help', 'said'): 10,
#  ('everi', 'said'): 10,
#  ('said', 'sit'): 10,
#  ('big', 'said'): 10,
#  ('said', 'way'): 10,
#  ('around', 'said'): 10,
#  ('place', 'said'): 10,
#  ('hold', 'said'): 10,
#  ('glad', 'said'): 10,
#  ('eat', 'said'): 10,
#  ('brought', 'said'): 10,
#  ('said', 'winter'): 10,
#  ('mari', 'mary'): 10,
#  ('mari', 'would'): 10,
#  ('carri', 'go'): 10,
#  ('boast', 'help'): 10,
#  ('mary', 'pa'): 10,
#  ('long', 'pa'): 10,
#  ('never', 'pa'): 10,
#  ('pa', 'west'): 10,
#  ('money', 'pa'): 10,
#  ('hand', 'pa'): 10,
#  ('move', 'pa'): 10,
#  ('pa', 'supper'): 10,
#  ('box', 'pa'): 10,
#  ('laugh', 'pa'): 10,
#  ('grade', 'pa'): 10,
#  ('pa', 'soon'): 10,
#  ('mrs.', 'pa'): 10,
#  ('could', 'men'): 10,
#  ('go', 'long'): 10,
#  ('go', 'see'): 10,
#  ('see', 'would'): 10,
#  ('like', 'littl'): 10,
#  ('around', 'turn'): 10,
#  ('go', 'must'): 10,
#  ('go', 'pa.'): 10,
#  ('away', 'go'): 10,
#  ('behind', 'came'): 10,
#  ('came', 'door'): 10,
#  ('boast', 'came'): 10,
#  ('back', 'way'): 10,
#  ('away', 'went'): 10,
#  ('back', 'wagon'): 10,
#  ('set', 'stove'): 10,
#  ('boast', 'make'): 10,
#  ('sun', 'wind'): 10,
#  ('door', 'men'): 10,
#  ('cold', 'wind'): 10,
#  ('prairi', 'sky'): 10,
#  ('chapter', 'laura'): 9,
#  ('laura', 'long'): 9,
#  ('laura', 'two'): 9,
#  ('hous', 'laura'): 9,
#  ('laura', 'r'): 9,
#  ('black', 'laura'): 9,
#  ('laura', 'use'): 9,
#  ('laura', 'move'): 9,
#  ('laura', 'ride'): 9,
#  ('breakfast', 'laura'): 9,
#  ('laura', 'watch'): 9,
#  ('held', 'laura'): 9,
#  ('along', 'laura'): 9,
#  ('laura', 'white'): 9,
#  ('laura', 'took'): 9,
#  ('laura', 'talk'): 9,
#  ('laura', 'table'): 9,
#  ('dish', 'tabl'): 9,
#  ('carri', 'one'): 9,
#  ('everi', 'one'): 9,
#  ('one', 'time'): 9,
#  ('like', 'one'): 9,
#  ('one', 'two'): 9,
#  ('door', 'one'): 9,
#  ('look', 'see'): 9,
#  ('pa', 'saw'): 9,
#  ('said', 'settl'): 9,
#  ('said', 'say'): 9,
#  ('pretti', 'said'): 9,
#  ('hous', 'said'): 9,
#  ('man', 'said'): 9,
#  ('ask', 'said'): 9,
#  ('heard', 'said'): 9,
#  ('said', 'use'): 9,
#  ('bed', 'said'): 9,
#  ('said', 'thing'): 9,
#  ('said', 'start'): 9,
#  ('christma', 'said'): 9,
#  ('said', 'team'): 9,
#  ('build', 'said'): 9,
#  ('mari', 'want'): 9,
#  ('mari', 'oh'): 9,
#  ('bed', 'mari'): 9,
#  ('carri', 'water'): 9,
#  ('carri', 'get'): 9,
#  ('back', 'carri'): 9,
#  ('carri', 'put'): 9,
#  ('besid', 'carri'): 9,
#  ('could', 'grace'): 9,
#  ('get', 'help'): 9,
#  ('help', 'put'): 9,
#  ('dinner', 'pa'): 9,
#  ('new', 'pa'): 9,
#  ('girl', 'pa'): 9,
#  ('pa', 'set'): 9,
#  ('first', 'pa'): 9,
#  ('alway', 'pa'): 9,
#  ('pa', 'side'): 9,
#  ('pa', 'took'): 9,
#  ('pa', 'town'): 9,
#  ('pa', 'voic'): 9,
#  ('build', 'pa'): 9,
#  ('away', 'come'): 9,
#  ('come', 'wagon'): 9,
#  ('everi', 'time'): 9,
#  ('could', 'want'): 9,
#  ('could', 'talk'): 9,
#  ('far', 'sky'): 9,
#  ('get', 'time'): 9,
#  ('back', 'turn'): 9,
#  ('big', 'toward'): 9,
#  ('made', 'sound'): 9,
#  ('go', 'stay'): 9,
#  ('get', 'stay'): 9,
#  ('littl', 'way'): 9,
#  ('back', 'littl'): 9,
#  ('littl', 'wind'): 9,
#  ('dark', 'littl'): 9,
#  ('around', 'go'): 9,
#  ('go', 'well'): 9,
#  ('go', 'last'): 9,
#  ('came', 'two'): 9,
#  ('bed', 'made'): 9,
#  ('came', 'men'): 9,
#  ('docia', 'lena'): 9,
#  ('boast', 'get'): 9,
#  ('back', 'hors'): 9,
#  ('back', 'door'): 9,
#  ('team', 'wagon'): 9,
#  ('box', 'fiddl'): 9,
#  ('prairi', 'wind'): 9,
#  ('grade', 'men'): 9,
#  ('lena', 'poni'): 9,
#  ('lake', 'slough'): 9,
#  ('chapter', 'morn'): 8,
#  ('chapter', 'next'): 8,
#  ('care', 'laura'): 8,
#  ('laura', 'sit'): 8,
#  ('laura', 'turn'): 8,
#  ('laura', 'us'): 8,
#  ('laura', 'railroad'): 8,
#  ('behind', 'laura'): 8,
#  ('laura', 'next'): 8,
#  ('feel', 'laura'): 8,
#  ('laura', 'tri'): 8,
#  ('dark', 'laura'): 8,
#  ('laura', 'whole'): 8,
#  ('christma', 'laura'): 8,
#  ('laura', 'sang'): 8,
#  ('hear', 'laura'): 8,
#  ('laura', 'poni'): 8,
#  ('fiddl', 'laura'): 8,
#  ('one', 'see'): 8,
#  ('big', 'one'): 8,
#  ('one', 'went'): 8,
#  ('morn', 'pa'): 8,
#  ('came', 'morn'): 8,
#  ('look', 'pa.'): 8,
#  ('said', 'water'): 8,
#  ('said', 'wait'): 8,
#  ('hand', 'said'): 8,
#  ('said', 'went'): 8,
#  ('ride', 'said'): 8,
#  ('said', 'tri'): 8,
#  ('cold', 'said'): 8,
#  ('low', 'said'): 8,
#  ('said', 'spring'): 8,
#  ('said', 'sing'): 8,
#  ('said', 'warm'): 8,
#  ('mari', 'see'): 8,
#  ('mari', 'told'): 8,
#  ('mari', 'thought'): 8,
#  ('boast', 'mari'): 8,
#  ('carri', 'come'): 8,
#  ('carri', 'could'): 8,
#  ('big', 'carri'): 8,
#  ('carri', 'let'): 8,
#  ('carri', 'mrs.'): 8,
#  ('across', 'pa'): 8,
#  ('help', 'mrs.'): 8,
#  ('pa', 'still'): 8,
#  ('light', 'pa'): 8,
#  ('pa', 'sat'): 8,
#  ('around', 'pa'): 8,
#  ('pa', 'v'): 8,
#  ('ask', 'pa'): 8,
#  ('knew', 'pa'): 8,
#  ('grass', 'pa'): 8,
#  ('along', 'pa'): 8,
#  ('pa', 'yes'): 8,
#  ('christma', 'pa'): 8,
#  ('pa', 'team'): 8,
#  ('pa', 'warm'): 8,
#  ('come', 'night'): 8,
#  ('come', 'men'): 8,
#  ('could', 'everi'): 8,
#  ('everi', 'night'): 8,
#  ('day', 'long'): 8,
#  ('know', 'want'): 8,
#  ('boast', 'know'): 8,
#  ('could', 'even'): 8,
#  ('could', 'littl'): 8,
#  ('could', 'hors'): 8,
#  ('could', 'hear'): 8,
#  ('mary', 'see'): 8,
#  ('long', 'went'): 8,
#  ('see', 'time'): 8,
#  ('back', 'time'): 8,
#  ('mani', 'time'): 8,
#  ('like', 'see'): 8,
#  ('heard', 'never'): 8,
#  ('like', 'would'): 8,
#  ('like', 'pa.'): 8,
#  ('slough', 'toward'): 8,
#  ('hous', 'littl'): 8,
#  ('littl', 'prairi'): 8,
#  ('take', 'want'): 8,
#  ('big', 'go'): 8,
#  ('girl', 'go'): 8,
#  ('go', 'winter'): 8,
#  ('go', 'mrs.'): 8,
#  ('wagon', 'west'): 8,
#  ('get', 'homestead'): 8,
#  ('came', 'went'): 8,
#  ('came', 'wild'): 8,
#  ('let', 'us'): 8,
#  ('aunt', 'lena'): 8,
#  ('big', 'man'): 8,
#  ('big', 'went'): 8,
#  ('big', 'hors'): 8,
#  ('big', 'men'): 8,
#  ('railroad', 'work'): 8,
#  ('work', 'would'): 8,
#  ('men', 'railroad'): 8,
#  ('boast', 'would'): 8,
#  ('charles', 'yes'): 8,
#  ('caroline', 'well'): 8,
#  ('around', 'back'): 8,
#  ('around', 'crowd'): 8,
#  ('got', 'man'): 8,
#  ('away', 'get'): 8,
#  ('get', 'went'): 8,
#  ('boast', 'pa.'): 8,
#  ('breakfast', 'went'): 8,
#  ('back', 'end'): 8,
#  ('wild', 'wind'): 8,
#  ('hors', 'white'): 8,
#  ('ride', 'wagon'): 8,
#  ('put', 'wagon'): 8,
#  ('box', 'wagon'): 8,
#  ('last', 'night'): 8,
#  ('crowd', 'men'): 8,
#  ('silver', 'sky'): 8,
#  ('cut', 'end'): 8,
#  ('scraper', 'team'): 8,
#  ('stove', 'warm'): 8,
#  ('jack', 'laura'): 7,
#  ('laura', 'light'): 7,
#  ('blue', 'laura'): 7,
#  ('laura', 'toward'): 7,
#  ('laura', 'west'): 7,
#  ('keep', 'laura'): 7,
#  ('laura', 'live'): 7,
#  ('laura', 'man'): 7,
#  ('hardli', 'laura'): 7,
#  ('laura', 'wait'): 7,
#  ('laura', 'train'): 7,
#  ('laura', 'sun'): 7,
#  ('laura', 'play'): 7,
#  ('laura', 'low'): 7,
#  ('high', 'laura'): 7,
#  ('laura', 'room'): 7,
#  ('hurri', 'laura'): 7,
#  ('board', 'laura'): 7,
#  ('laura', 'sing'): 7,
#  ('cut', 'laura'): 7,
#  ('laura', 'soon'): 7,
#  ('old', 'one'): 7,
#  ('mari', 'one'): 7,
#  ('across', 'one'): 7,
#  ('long', 'one'): 7,
#  ('even', 'one'): 7,
#  ('made', 'one'): 7,
#  ('one', 'way'): 7,
#  ('night', 'one'): 7,
#  ('one', 'open'): 7,
#  ('anoth', 'one'): 7,
#  ('come', 'morn'): 7,
#  ('everi', 'morn'): 7,
#  ('go', 'morn'): 7,
#  ('breakfast', 'morn'): 7,
#  ('door', 'morn'): 7,
#  ('man', 'old'): 7,
#  ('said', 'tell'): 7,
#  ('look', 'mari'): 7,
#  ('carri', 'look'): 7,
#  ('could', 'look'): 7,
#  ('head', 'look'): 7,
#  ('eye', 'look'): 7,
#  ('littl', 'look'): 7,
#  ('came', 'look'): 7,
#  ('look', 'went'): 7,
#  ('look', 'stood'): 7,
#  ('pay', 'said'): 7,
#  ('said', 'west'): 7,
#  ('docia', 'said'): 7,
#  ('new', 'said'): 7,
#  ('live', 'said'): 7,
#  ('knew', 'said'): 7,
#  ('cover', 'said'): 7,
#  ('door', 'said'): 7,
#  ('along', 'said'): 7,
#  ('grade', 'said'): 7,
#  ('claim', 'said'): 7,
#  ('care', 'littl'): 7,
#  ('know', 'mari'): 7,
#  ('mari', 'still'): 7,
#  ('mari', 'never'): 7,
#  ('like', 'mari'): 7,
#  ('get', 'mari'): 7,
#  ('back', 'mari'): 7,
#  ('carrie', 'mari'): 7,
#  ('carri', 'mary'): 7,
#  ('carri', 'way'): 7,
#  ('behind', 'carri'): 7,
#  ('carri', 'hand'): 7,
#  ('came', 'grace'): 7,
#  ('behind', 'grace'): 7,
#  ('grace', 'sleep'): 7,
#  ('grace', 'took'): 7,
#  ('across', 'prairie'): 7,
#  ('pa', 'say'): 7,
#  ('pa', 'turn'): 7,
#  ('drive', 'pa'): 7,
#  ('pa', 'till'): 7,
#  ('lay', 'pa'): 7,
#  ('pa', 'way'): 7,
#  ('land', 'pa'): 7,
#  ('better', 'pa'): 7,
#  ('pa', 'place'): 7,
#  ('great', 'pa'): 7,
#  ('almost', 'pa'): 7,
#  ('breakfast', 'pa'): 7,
#  ('bed', 'pa'): 7,
#  ('pa', 'thing'): 7,
#  ('pa', 'shanti'): 7,
#  ('curtain', 'pa'): 7,
#  ('pa', 'stove'): 7,
#  ('jerri', 'pa'): 7,
#  ('come', 'could'): 7,
#  ('come', 'time'): 7,
#  ('come', 'see'): 7,
#  ('come', 'littl'): 7,
#  ('camp', 'come'): 7,
#  ('come', 'would'): 7,
#  ('come', 'get'): 7,
#  ('come', 'pa.'): 7,
#  ('come', 'door'): 7,
#  ('along', 'come'): 7,
#  ('boast', 'come'): 7,
#  ('everi', 'see'): 7,
#  ('came', 'everi'): 7,
#  ('day', 'time'): 7,
#  ('came', 'day'): 7,
#  ('day', 'would'): 7,
#  ('day', 'move'): 7,
#  ('go', 'know'): 7,
#  ('could', 'long'): 7,
#  ('could', 'time'): 7,
#  ('could', 'still'): 7,
#  ('could', 'eye'): 7,
#  ('could', 'say'): 7,
#  ('could', 'work'): 7,
#  ('could', 'noth'): 7,
#  ('back', 'could'): 7,
#  ('could', 'make'): 7,
#  ('men', 'pay'): 7,
#  ('back', 'far'): 7,
#  ('chair', 'mary'): 7,
#  ('bed', 'mary'): 7,
#  ('back', 'long'): 7,
#  ('long', 'night'): 7,
#  ('go', 'time'): 7,
#  ('talk', 'time'): 7,
#  ('men', 'time'): 7,
#  ('never', 'see'): 7,
#  ('see', 'told'): 7,
#  ('back', 'see'): 7,
#  ('go', 'never'): 7,
#  ('go', 'like'): 7,
#  ('like', 'place'): 7,
#  ('blue', 'sky'): 7,
#  ('eye', 'open'): 7,
#  ('grass', 'sound'): 7,
#  ('brown', 'prairi'): 7,
#  ('get', 'must'): 7,
#  ('stay', 'till'): 7,
#  ('get', 'till'): 7,
#  ('littl', 'made'): 7,
#  ('around', 'littl'): 7,
#  ('away', 'littl'): 7,
#  ('littl', 'run'): 7,
#  ('pa.', 'want'): 7,
#  ('back', 'want'): 7,
#  ('men', 'want'): 7,
#  ('go', 'homestead'): 7,
#  ('came', 'go'): 7,
#  ('go', 'thought'): 7,
#  ('carrie', 'go'): 7,
#  ('go', 'move'): 7,
#  ('go', 'sleep'): 7,
#  ('fast', 'go'): 7,
#  ('go', 'men'): 7,
#  ('go', 'lake'): 7,
#  ('went', 'west'): 7,
#  ('curtain', 'made'): 7,
#  ('came', 'water'): 7,
#  ('around', 'came'): 7,
#  ('came', 'wait'): 7,
#  ('came', 'store'): 7,
#  ('came', 'team'): 7,
#  ('good', 'supper'): 7,
#  ('grass', 'water'): 7,
#  ('around', 'big'): 7,
#  ('big', 'lake'): 7,
#  ('build', 'railroad'): 7,
#  ('camp', 'lake'): 7,
#  ('make', 'would'): 7,
#  ('sleep', 'would'): 7,
#  ('grass', 'would'): 7,
#  ('caroline', 'charles'): 7,
#  ('charles', 'pa.'): 7,
#  ('caroline', 'r'): 7,
#  ('caroline', 'pa.'): 7,
#  ('get', 'r'): 7,
#  ('get', 'pa.'): 7,
#  ('get', 'well'): 7,
#  ('get', 'supper'): 7,
#  ('get', 'hurri'): 7,
#  ('get', 'men'): 7,
#  ('get', 'soon'): 7,
#  ('land', 'sky'): 7,
#  ('pa.', 'yes'): 7,
#  ('away', 'wagon'): 7,
#  ('away', 'prairi'): 7,
#  ('away', 'sky'): 7,
#  ('hors', 'went'): 7,
#  ('night', 'went'): 7,
#  ('door', 'went'): 7,
#  ('men', 'went'): 7,
#  ('boast', 'went'): 7,
#  ('back', 'store'): 7,
#  ('back', 'team'): 7,
#  ('back', 'stove'): 7,
#  ('hors', 'men'): 7,
#  ('hors', 'jerri'): 7,
#  ('along', 'wagon'): 7,
#  ('brought', 'wagon'): 7,
#  ('bed', 'make'): 7,
#  ('put', 'stove'): 7,
#  ('door', 'night'): 7,
#  ('lake', 'night'): 7,
#  ('prairi', 'sun'): 7,
#  ('sky', 'sun'): 7,
#  ('door', 'front'): 7,
#  ('boast', 'door'): 7,
#  ('along', 'slough'): 7,
#  ('jerri', 'white'): 7,
#  ('board', 'shanti'): 7,
#  ('build', 'men'): 7,
#  ('cut', 'fill'): 7,
#  ('grade', 'team'): 7,
#  ('chapter', 'said'): 6,
#  ('chapter', 'day'): 6,
#  ('chair', 'laura'): 6,
#  ('hair', 'laura'): 6,
#  ('drive', 'laura'): 6,
#  ('homestead', 'laura'): 6,
#  ('laura', 'stop'): 6,
#  ('camp', 'laura'): 6,
#  ('hold', 'laura'): 6,
#  ('laura', 'mani'): 6,
#  ('home', 'laura'): 6,
#  ('laura', 'red'): 6,
#  ('hung', 'laura'): 6,
#  ('laura', 'town'): 6,
#  ('laura', 'voic'): 6,
#  ('anoth', 'laura'): 6,
#  ('brought', 'laura'): 6,
#  ('grade', 'laura'): 6,
#  ('laura', 'stove'): 6,
#  ('laura', 'silver'): 6,
#  ('get', 'wash'): 6,
#  ('tabl', 'wash'): 6,
#  ('dish', 'supper'): 6,
#  ('morn', 'one'): 6,
#  ('grace', 'one'): 6,
#  ('come', 'one'): 6,
#  ('one', 'think'): 6,
#  ('one', 'small'): 6,
#  ('came', 'one'): 6,
#  ('one', 'pa.'): 6,
#  ('back', 'one'): 6,
#  ('one', 'wild'): 6,
#  ('bed', 'one'): 6,
#  ('men', 'one'): 6,
#  ('one', 'stove'): 6,
#  ('boast', 'one'): 6,
#  ('morn', 'well'): 6,
#  ('old', 'said'): 6,
#  ('old', 'pa'): 6,
#  ('old', 'wagon'): 6,
#  ('jack', 'pa'): 6,
#  ('mari', 'tell'): 6,
#  ('grace', 'look'): 6,
#  ('look', 'would'): 6,
#  ('caroline', 'look'): 6,
#  ('come', 'saw'): 6,
#  ('back', 'saw'): 6,
#  ('house', 'said'): 6,
#  ('across', 'said'): 6,
#  ('said', 'still'): 6,
#  ('gone', 'said'): 6,
#  ('eye', 'said'): 6,
#  ('made', 'said'): 6,
#  ('camp', 'said'): 6,
#  ('behind', 'said'): 6,
#  ('next', 'said'): 6,
#  ('said', 'set'): 6,
#  ('move', 'said'): 6,
#  ('feel', 'said'): 6,
#  ('bring', 'said'): 6,
#  ('said', 'took'): 6,
#  ('said', 'town'): 6,
#  ('said', 'tree'): 6,
#  ('ground', 'said'): 6,
#  ('anoth', 'said'): 6,
#  ('said', 'shanty'): 6,
#  ('house', 'pa'): 6,
#  ('much', 'pa'): 6,
#  ('could', 'much'): 6,
#  ('help', 'mari'): 6,
#  ('even', 'mari'): 6,
#  ('eye', 'mari'): 6,
#  ('asked', 'mari'): 6,
#  ('big', 'mari'): 6,
#  ('ask', 'mari'): 6,
#  ('behind', 'mari'): 6,
#  ('mari', 'mrs.'): 6,
#  ('carri', 'see'): 6,
#  ('asked', 'carri'): 6,
#  ('came', 'carri'): 6,
#  ('carri', 'told'): 6,
#  ('carri', 'wagon'): 6,
#  ('carri', 'walk'): 6,
#  ('carri', 'make'): 6,
#  ('carri', 'supper'): 6,
#  ('box', 'carri'): 6,
#  ('carri', 'sang'): 6,
#  ('chair', 'grace'): 6,
#  ('grace', 'see'): 6,
#  ('grace', 'must'): 6,
#  ('around', 'grace'): 6,
#  ('grace', 'hold'): 6,
#  ('grace', 'ran'): 6,
#  ('across', 'went'): 6,
#  ('across', 'back'): 6,
#  ('across', 'lake'): 6,
#  ('help', 'work'): 6,
#  ('help', 'went'): 6,
#  ('help', 'wagon'): 6,
#  ('help', 'supper'): 6,
#  ('help', 'hurri'): 6,
#  ('eye', 'pa'): 6,
#  ('pa', 'toward'): 6,
#  ('pa', 'stop'): 6,
#  ('charles', 'pa'): 6,
#  ('pa', 'wait'): 6,
#  ('pa', 'thought'): 6,
#  ('carrie', 'pa'): 6,
#  ('next', 'pa'): 6,
#  ('pa', 'walk'): 6,
#  ('feel', 'pa'): 6,
#  ('pa', 'tabl'): 6,
#  ('pa', 'sleep'): 6,
#  ('home', 'pa'): 6,
#  ('pa', 'wind'): 6,
#  ('hung', 'pa'): 6,
#  ('board', 'pa'): 6,
#  ('open', 'pa'): 6,
#  ('pa', 'whole'): 6,
#  ('ground', 'pa'): 6,
#  ('anoth', 'pa'): 6,
#  ('pa', 'sing'): 6,
#  ('hear', 'pa'): 6,
#  ('lake', 'pa'): 6,
#  ('pa', 'snow'): 6,
#  ('come', 'day'): 6,
#  ('come', 'like'): 6,
#  ('came', 'come'): 6,
#  ('come', 'enough'): 6,
#  ('come', 'us'): 6,
#  ('come', 'oh'): 6,
#  ('come', 'yes'): 6,
#  ('come', 'team'): 6,
#  ('even', 'everi'): 6,
#  ('everi', 'littl'): 6,
#  ('everi', 'would'): 6,
#  ('everi', 'wagon'): 6,
#  ('camp', 'day'): 6,
#  ('know', 'v'): 6,
#  ('know', 'pa.'): 6,
#  ('could', 'never'): 6,
#  ('could', 'sound'): 6,
#  ('could', 'must'): 6,
#  ('could', 'money'): 6,
#  ('could', 'keep'): 6,
#  ('could', 'good'): 6,
#  ('could', 'man'): 6,
#  ('away', 'could'): 6,
#  ('could', 'wagon'): 6,
#  ('almost', 'could'): 6,
#  ('could', 'ride'): 6,
#  ('far', 'light'): 6,
#  ('far', 'would'): 6,
#  ('go', 'settl'): 6,
#  ('behind', 'mary'): 6,
#  ('carrie', 'mary'): 6,
#  ('long', 'stay'): 6,
#  ('came', 'long'): 6,
#  ('long', 'wild'): 6,
#  ('long', 'low'): 6,
#  ('lake', 'long'): 6,
#  ('time', 'wagon'): 6,
#  ('move', 'time'): 6,
#  ('last', 'time'): 6,
#  ('see', 'want'): 6,
#  ('see', 'work'): 6,
#  ('anyth', 'never'): 6,
#  ('never', 'pa.'): 6,
#  ('light', 'window'): 6,
#  ('eye', 'hair'): 6,
#  ('land', 'like'): 6,
#  ('feel', 'like'): 6,
#  ('like', 'prairi'): 6,
#  ('blue', 'littl'): 6,
#  ('blue', 'white'): 6,
#  ('eye', 'face'): 6,
#  ('think', 'would'): 6,
#  ('pa.', 'think'): 6,
#  ('think', 'well'): 6,
#  ('say', 'would'): 6,
#  ('toward', 'went'): 6,
#  ('must', 'pa.'): 6,
#  ('asked', 'go'): 6,
#  ('came', 'till'): 6,
#  ('till', 'wait'): 6,
#  ('littl', 'two'): 6,
#  ('got', 'littl'): 6,
#  ('black', 'littl'): 6,
#  ('littl', 'went'): 6,
#  ('littl', 'wild'): 6,
#  ('hors', 'littl'): 6,
#  ...}

# %%
import matplotlib.pyplot as plt

pair_count = []
for pair, count in new4.items():
    pair_count.append(count)
    
plt.figure(figsize=(20,10))
plt.plot(sorted(pair_count, reverse=True))

plt.title('Pair Count')
plt.ylabel('pair count')
plt.xlabel('rank')
plt.show()

# %%
#単語順位チェック
word_f = sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)

word_fdic = dict(word_f)
word_fdic
# Out:
# {'laura': 693,
#  'said': 644,
#  'pa': 525,
#  'go': 241,
#  'could': 179,
#  'one': 174,
#  'littl': 172,
#  'mari': 168,
#  'carri': 166,
#  'boast': 163,
#  'come': 160,
#  'look': 158,
#  'back': 156,
#  'came': 154,
#  'would': 146,
#  'big': 142,
#  'went': 137,
#  'get': 132,
#  'see': 124,
#  'grace': 123,
#  'like': 121,
#  'men': 116,
#  'time': 113,
#  'wagon': 113,
#  'door': 110,
#  'want': 105,
#  'away': 100,
#  'day': 96,
#  'good': 93,
#  'around': 93,
#  'put': 93,
#  'night': 92,
#  'long': 91,
#  'man': 88,
#  'well': 88,
#  'mrs.': 88,
#  'mary': 87,
#  'got': 86,
#  'know': 85,
#  'pa.': 84,
#  'grass': 84,
#  'lake': 83,
#  'made': 82,
#  'make': 82,
#  'wind': 81,
#  'never': 80,
#  'must': 80,
#  'everi': 77,
#  'help': 76,
#  'even': 76,
#  'two': 75,
#  'take': 75,
#  'lena': 73,
#  'work': 72,
#  'caroline': 72,
#  'hand': 71,
#  'bed': 71,
#  'told': 69,
#  'last': 68,
#  'water': 66,
#  'hors': 66,
#  'team': 66,
#  'way': 64,
#  'charles': 64,
#  'let': 64,
#  'oh': 64,
#  'say': 63,
#  'behind': 63,
#  'asked': 62,
#  'prairi': 62,
#  'west': 61,
#  'set': 60,
#  'stood': 60,
#  'open': 60,
#  'still': 59,
#  'r': 59,
#  'cold': 58,
#  'yes': 58,
#  'supper': 57,
#  'dark': 57,
#  'warm': 57,
#  'railroad': 56,
#  'sky': 56,
#  'far': 55,
#  'place': 54,
#  'thought': 54,
#  'camp': 53,
#  'right': 53,
#  'heard': 53,
#  'side': 53,
#  'stove': 53,
#  'slough': 53,
#  'saw': 52,
#  'across': 52,
#  'turn': 52,
#  'us': 52,
#  'hous': 52,
#  'v': 52,
#  'along': 52,
#  'end': 52,
#  'store': 52,
#  'light': 51,
#  'eye': 51,
#  'sat': 51,
#  'carrie': 51,
#  'old': 50,
#  'ran': 50,
#  'morn': 49,
#  'gone': 49,
#  'girl': 49,
#  'wild': 49,
#  'move': 49,
#  'room': 49,
#  'white': 49,
#  'talk': 48,
#  'anoth': 48,
#  'grade': 48,
#  'house': 47,
#  'enough': 47,
#  'care': 46,
#  'homestead': 46,
#  'black': 46,
#  'stay': 45,
#  'low': 45,
#  'took': 45,
#  'snow': 45,
#  'think': 44,
#  'first': 44,
#  'full': 44,
#  'board': 44,
#  'brought': 44,
#  'silver': 44,
#  'dish': 43,
#  'blue': 43,
#  'feet': 43,
#  'land': 43,
#  'crowd': 43,
#  'much': 42,
#  'dinner': 42,
#  'till': 42,
#  'sun': 42,
#  'head': 41,
#  'stop': 41,
#  'train': 41,
#  'next': 41,
#  'alway': 41,
#  'whole': 41,
#  'ground': 41,
#  'run': 40,
#  'box': 40,
#  'christma': 40,
#  'shanti': 40,
#  'sang': 40,
#  'small': 39,
#  'new': 39,
#  'live': 39,
#  'almost': 39,
#  'town': 39,
#  'keep': 38,
#  'docia': 38,
#  'window': 38,
#  'shanty': 38,
#  'sound': 37,
#  'seem': 37,
#  'wait': 37,
#  'face': 37,
#  'great': 37,
#  'build': 37,
#  'wash': 36,
#  'knew': 36,
#  'hold': 36,
#  'tabl': 36,
#  'noth': 35,
#  'start': 35,
#  'eat': 35,
#  'sing': 35,
#  'soon': 35,
#  'brown': 34,
#  'aunt': 34,
#  'ask': 34,
#  'sleep': 34,
#  'play': 34,
#  'fast': 34,
#  'red': 34,
#  'voic': 34,
#  'cut': 34,
#  'poni': 34,
#  'claim': 34,
#  'better': 33,
#  'cover': 33,
#  'ride': 33,
#  'besid': 33,
#  'hurri': 33,
#  'tree': 33,
#  'winter': 33,
#  'chapter': 32,
#  'tell': 32,
#  'settl': 32,
#  'hair': 32,
#  'drive': 32,
#  'mani': 32,
#  'high': 32,
#  'laugh': 32,
#  'money': 31,
#  'glad': 31,
#  'three': 31,
#  'jack': 30,
#  'chair': 30,
#  'morning': 30,
#  'toward': 30,
#  'left': 30,
#  'hardli': 30,
#  'walk': 30,
#  'breakfast': 30,
#  'kept': 30,
#  'watch': 30,
#  'held': 30,
#  'girls': 30,
#  'beyond': 30,
#  'began': 30,
#  'curtain': 30,
#  'reverend': 30,
#  'tri': 29,
#  'thing': 29,
#  'hung': 29,
#  'alden': 29,
#  'pay': 28,
#  'sit': 28,
#  'lay': 28,
#  'prairie': 28,
#  'feel': 28,
#  'air': 28,
#  'top': 28,
#  'anyth': 27,
#  'pretti': 27,
#  'uncl': 27,
#  'round': 27,
#  'bring': 27,
#  'home': 27,
#  'spring': 27,
#  'floor': 27,
#  'fill': 27,
#  'jerri': 27,
#  'quiet': 26,
#  'show': 26,
#  'table': 26,
#  'answered': 25,
#  'wall': 25,
#  'use': 25,
#  'ever': 25,
#  'might': 25,
#  'front': 25,
#  'guess': 25,
#  'breath': 25,
#  'hear': 25,
#  'scraper': 25,
#  'fiddl': 25,
#  'leav': 24,
#  'sure': 24,
#  'pull': 24,
#  'gave': 24,
#  'clean': 24,
#  'straight': 24,
#  'shut': 24,
#  'wide': 24,
#  'seat': 24,
#  'bright': 24,
#  'thi': 24,
#  'line': 24,
#  'quickli': 24,
#  'hot': 24,
#  'bird': 24,
#  'plow': 24,
#  'without': 23,
#  'dress': 23,
#  'felt': 23,
#  'afternoon': 23,
#  'hard': 23,
#  'farther': 23,
#  'east': 23,
#  'paper': 23,
#  'larg': 23,
#  'find': 23,
#  'softli': 23,
#  'creek': 22,
#  'close': 22,
#  'wonder': 22,
#  'stand': 22,
#  'done': 22,
#  'rest': 22,
#  'ahead': 22,
#  'tall': 22,
#  'coat': 22,
#  'south': 22,
#  'near': 22,
#  'wolf': 22,
#  'call': 22,
#  'song': 22,
#  'shore': 22,
#  'doorway': 21,
#  'thin': 21,
#  'drove': 21,
#  'need': 21,
#  'best': 21,
#  'tomorrow': 21,
#  'seen': 21,
#  'clear': 21,
#  'slowli': 21,
#  'young': 21,
#  'earth': 21,
#  'everyth': 21,
#  'yellow': 21,
#  'piec': 21,
#  'milk': 21,
#  'rock': 20,
#  'smooth': 20,
#  'travel': 20,
#  'horses': 20,
#  'together': 20,
#  'follow': 20,
#  'blew': 20,
#  'rough': 20,
#  'thank': 20,
#  'road': 20,
#  'load': 20,
#  'boy': 19,
#  'listen': 19,
#  'hat': 19,
#  'short': 19,
#  'empti': 19,
#  'car': 19,
#  'mayb': 19,
#  'sweet': 19,
#  'glass': 19,
#  'shout': 19,
#  'cloth': 19,
#  'music': 19,
#  'flock': 19,
#  'rose': 19,
#  'laid': 19,
#  'soft': 19,
#  'little': 18,
#  'beauti': 18,
#  'earli': 18,
#  'hi': 18,
#  'indian': 18,
#  'strong': 18,
#  'roll': 18,
#  'school': 18,
#  'found': 18,
#  'shine': 18,
#  'curv': 18,
#  'fresh': 18,
#  'grasses': 18,
#  'deep': 18,
#  'bank': 18,
#  'edg': 18,
#  'buffalo': 18,
#  'stabl': 18,
#  'strang': 17,
#  'wrap': 17,
#  'readi': 17,
#  'togeth': 17,
#  'grew': 17,
#  'green': 17,
#  'world': 17,
#  'sew': 17,
#  'twinkl': 17,
#  'weather': 17,
#  'tea': 17,
#  'dump': 17,
#  'fiddle': 17,
#  'lie': 16,
#  'tire': 16,
#  'cried': 16,
#  'golden': 16,
#  'yet': 16,
#  'countri': 16,
#  'year': 16,
#  'answer': 16,
#  'folk': 16,
#  'marri': 16,
#  'squar': 16,
#  'suddenli': 16,
#  'fine': 16,
#  'gray': 16,
#  'cri': 16,
#  'blanket': 16,
#  'step': 16,
#  'faster': 16,
#  'arm': 16,
#  'tini': 16,
#  'loud': 16,
#  'track': 16,
#  'wish': 16,
#  'fri': 16,
#  'plate': 16,
#  'half': 16,
#  'star': 16,
#  'jean': 16,
#  'blow': 16,
#  'singing': 16,
#  'ingalls': 16,
#  'exclaimed': 16,
#  'duck': 16,
#  'fire': 16,
#  'eyes': 15,
#  'week': 15,
#  'word': 15,
#  'country': 15,
#  'bare': 15,
#  'tight': 15,
#  'rush': 15,
#  'pack': 15,
#  'corner': 15,
#  'realli': 15,
#  'whispered': 15,
#  'wheel': 15,
#  'hole': 15,
#  'drink': 15,
#  'rememb': 15,
#  'finish': 15,
#  'stretch': 15,
#  'lumber': 15,
#  'spread': 15,
#  'salt': 15,
#  'dishes': 15,
#  'roof': 15,
#  'anyway': 15,
#  'though': 15,
#  'l': 15,
#  'dust': 15,
#  'level': 15,
#  'sunshin': 14,
#  'plum': 14,
#  'dri': 14,
#  'summer': 14,
#  'smoke': 14,
#  'nice': 14,
#  'late': 14,
#  'happi': 14,
#  'outsid': 14,
#  'tie': 14,
#  'beat': 14,
#  'jolt': 14,
#  'reach': 14,
#  'cup': 14,
#  'teamster': 14,
#  'north': 14,
#  'offic': 14,
#  'lost': 14,
#  'hang': 14,
#  'built': 14,
#  'els': 14,
#  'coal': 14,
#  'swan': 14,
#  'apron': 14,
#  'coming': 13,
#  'buggy': 13,
#  'compani': 13,
#  'kind': 13,
#  'hope': 13,
#  'scare': 13,
#  'everyon': 13,
#  'laughing': 13,
#  'rise': 13,
#  'lone': 13,
#  'climb': 13,
#  'smile': 13,
#  'wolv': 13,
#  'touch': 13,
#  'slope': 13,
#  'pick': 13,
#  'heart': 13,
#  'stopped': 13,
#  'windows': 13,
#  'lap': 13,
#  'flower': 13,
#  'fall': 13,
#  'part': 13,
#  'pail': 13,
#  'rather': 13,
#  'bit': 13,
#  'mile': 13,
#  'shone': 13,
#  'shirt': 13,
#  'surveyor': 13,
#  'crack': 13,
#  'surveyors': 13,
#  'jerry': 13,
#  'gees': 13,
#  'skin': 13,
#  'biscuit': 13,
#  'hurt': 13,
#  'file': 13,
#  'cow': 12,
#  'rabbit': 12,
#  'job': 12,
#  'dollar': 12,
#  'hundr': 12,
#  'give': 12,
#  'someth': 12,
#  'peopl': 12,
#  'fellow': 12,
#  'mean': 12,
#  'lean-to': 12,
#  'onto': 12,
#  'row': 12,
#  'paid': 12,
#  'happen': 12,
#  'anything': 12,
#  'lift': 12,
#  'thick': 12,
#  'push': 12,
#  'shelf': 12,
#  'mind': 12,
#  'fit': 12,
#  'china': 12,
#  'bowl': 12,
#  'ate': 12,
#  'sight': 12,
#  'comfort': 12,
#  'picket': 12,
#  'mane': 12,
#  'dirt': 12,
#  'wave': 12,
#  'among': 12,
#  'tune': 12,
#  'life': 12,
#  'ellen': 12,
#  'broom': 12,
#  'shovel': 12,
#  'nearli': 12,
#  'flour': 12,
#  'christmas': 12,
#  'blind': 11,
#  'slowly': 11,
#  'wood': 11,
#  'name': 11,
#  'henri': 11,
#  'rode': 11,
#  'haul': 11,
#  'often': 11,
#  'leg': 11,
#  'shook': 11,
#  'grow': 11,
#  'narrow': 11,
#  'shot': 11,
#  'engin': 11,
#  'slid': 11,
#  'higher': 11,
#  'nobodi': 11,
#  'color': 11,
#  'save': 11,
#  'tast': 11,
#  'hotel': 11,
#  'bell': 11,
#  'rope': 11,
#  'street': 11,
#  'fli': 11,
#  'except': 11,
#  'lamp': 11,
#  'rich': 11,
#  'shouted': 11,
#  'fell': 11,
#  'pile': 11,
#  'pony': 11,
#  'river': 11,
#  'paymast': 11,
#  'wing': 11,
#  'flutterbudget': 11,
#  'gentl': 11,
#  'pork': 11,
#  'talking': 11,
#  'hill': 11,
#  'bag': 11,
#  'iowa': 11,
#  'brother': 11,
#  'mosquito': 11,
#  'meant': 10,
#  'month': 10,
#  'afraid': 10,
#  'dog': 10,
#  'trot': 10,
#  'slept': 10,
#  'five': 10,
#  'spoke': 10,
#  'real': 10,
#  'minut': 10,
#  'platform': 10,
#  'cost': 10,
#  'may': 10,
#  'cap': 10,
#  'going': 10,
#  'glitter': 10,
#  'quick': 10,
#  'read': 10,
#  'handl': 10,
#  'pour': 10,
#  'candy': 10,
#  'quit': 10,
#  'gather': 10,
#  'noon': 10,
#  'minute': 10,
#  'circl': 10,
#  'jump': 10,
#  'led': 10,
#  'plenti': 10,
#  'laughed': 10,
#  'bedroom': 10,
#  'alreadi': 10,
#  'dead': 10,
#  'cool': 10,
#  'gun': 10,
#  'drop': 10,
#  'snug': 10,
#  'johnni': 10,
#  'somebodi': 10,
#  'teach': 10,
#  'bedstead': 10,
#  'nail': 10,
#  'stranger': 10,
#  'ice': 10,
#  'moonlight': 10,
#  'hood': 10,
#  'merri': 10,
#  'bottom': 10,
#  'violets': 10,
#  'huron': 10,
#  'buggi': 9,
#  'sunbonnet': 9,
#  'horse': 9,
#  'potatoes': 9,
#  'wisconsin': 9,
#  'territory': 9,
#  'fifti': 9,
#  'farm': 9,
#  'acr': 9,
#  'henry': 9,
#  'else': 9,
#  'caught': 9,
#  'figur': 9,
#  'troubl': 9,
#  'taken': 9,
#  'catch': 9,
#  'cloud': 9,
#  'love': 9,
#  'pass': 9,
#  'shoulder': 9,
#  'wore': 9,
#  'stripe': 9,
#  'asleep': 9,
#  'yell': 9,
#  'quietly': 9,
#  'quickly': 9,
#  'pie': 9,
#  'moment': 9,
#  'fat': 9,
#  'outdoor': 9,
#  'fun': 9,
#  'sunshine': 9,
#  'pleasant': 9,
#  'wife': 9,
#  'flew': 9,
#  'yi': 9,
#  'kill': 9,
#  'enorm': 9,
#  'charg': 9,
#  'payday': 9,
#  'cousin': 9,
#  'louisa': 9,
#  'cook': 9,
#  'nothing': 9,
#  'boys': 9,
#  'stable': 9,
#  'whi': 9,
#  'burn': 9,
#  'muddi': 9,
#  's-down': 9,
#  'oven': 9,
#  'downstair': 9,
#  'wolves': 9,
#  'present': 9,
#  'fix': 9,
#  'whatnot': 9,
#  'stuart': 9,
#  'babi': 8,
#  'poor': 8,
#  'alon': 8,
#  'worn': 8,
#  'sinc': 8,
#  'sam': 8,
#  'meat': 8,
#  'gently': 8,
#  'excit': 8,
#  'sister': 8,
#  'anywher': 8,
#  'coupl': 8,
#  'driver': 8,
#  'bow': 8,
#  'stiff': 8,
#  'nose': 8,
#  'longer': 8,
#  'tired': 8,
#  'started': 8,
#  'attic': 8,
#  'sigh': 8,
#  'safe': 8,
#  'lamplight': 8,
#  'path': 8,
#  'field': 8,
#  'washing': 8,
#  'bonnet': 8,
#  'calico': 8,
#  'meet': 8,
#  'swell': 8,
#  'please': 8,
#  'past': 8,
#  'velvet': 8,
#  'people': 8,
#  'slant': 8,
#  'smell': 8,
#  'handkerchief': 8,
#  'larger': 8,
#  'everything': 8,
#  'smaller': 8,
#  'finished': 8,
#  'large': 8,
#  'tear': 8,
#  'heavi': 8,
#  'chase': 8,
#  'break': 8,
#  'mark': 8,
#  'grassi': 8,
#  'miles': 8,
#  'join': 8,
#  'shadow': 8,
#  'bunk': 8,
#  'boss': 8,
#  'meal': 8,
#  'potato': 8,
#  'slice': 8,
#  'bedtime': 8,
#  'sometim': 8,
#  'slide': 8,
#  'frost': 8,
#  'shawl': 8,
#  'burst': 8,
#  'pan': 8,
#  'roast': 8,
#  'mitten': 8,
#  'blizzard': 8,
#  'story': 8,
#  'knit': 8,
#  'stitch': 8,
#  'den': 8,
#  'biscuits': 8,
#  'woman': 7,
#  'sighed': 7,
#  'quilt': 7,
#  'hour': 7,
#  'hunt': 7,
#  'danc': 7,
#  'replied': 7,
#  'busi': 7,
#  'stroke': 7,
#  'territori': 7,
#  'joy': 7,
#  'minnesota': 7,
#  'perhap': 7,
#  'later': 7,
#  'tip': 7,
#  'mouth': 7,
#  'count': 7,
#  'insid': 7,
#  'steel': 7,
#  'scream': 7,
#  'church': 7,
#  'scatter': 7,
#  'opened': 7,
#  'sheet': 7,
#  'middl': 7,
#  'tin': 7,
#  'suppos': 7,
#  'basket': 7,
#  'boot': 7,
#  'bad': 7,
#  'overhead': 7,
#  'nois': 7,
#  'pale': 7,
#  'steadi': 7,
#  'ponies': 7,
#  'jerk': 7,
#  'howl': 7,
#  'toss': 7,
#  'washed': 7,
#  'gallop': 7,
#  'circle': 7,
#  'pound': 7,
#  'swung': 7,
#  'begin': 7,
#  'sioux': 7,
#  'trees': 7,
#  'steadili': 7,
#  'feed': 7,
#  'anybodi': 7,
#  'matter': 7,
#  'free': 7,
#  'plant': 7,
#  'whisper': 7,
#  'hay': 7,
#  'six': 7,
#  'worri': 7,
#  'sell': 7,
#  'hem': 7,
#  'point': 7,
#  'space': 7,
#  'sack': 7,
#  'lucki': 7,
#  'known': 7,
#  'brookings': 7,
#  'muffler': 7,
#  'heat': 7,
#  'frozen': 7,
#  'hammer': 7,
#  'popcorn': 7,
#  'building': 7,
#  'violet': 7,
#  'someon': 6,
#  'fever': 6,
#  'beautiful': 6,
#  'wear': 6,
#  'bread': 6,
#  'fish': 6,
#  'neat': 6,
#  'button': 6,
#  'reason': 6,
#  'charley': 6,
#  'stream': 6,
#  'manag': 6,
#  'journey': 6,
#  'lean': 6,
#  'forgotten': 6,
#  'scratch': 6,
#  'curl': 6,
#  'pool': 6,
#  'stir': 6,
#  'somehow': 6,
#  'believ': 6,
#  'endless': 6,
#  'collar': 6,
#  'pink': 6,
#  'already': 6,
#  'huge': 6,
#  'bigger': 6,
#  'shake': 6,
#  'flat': 6,
#  'steps': 6,
#  'cheer': 6,
#  'melt': 6,
#  'fasten': 6,
#  'strip': 6,
#  'cents': 6,
#  'spend': 6,
#  'wooden': 6,
#  'iron': 6,
#  'unload': 6,
#  'yelled': 6,
#  'pitcher': 6,
#  'noisi': 6,
#  'butter': 6,
#  'food': 6,
#  'inside': 6,
#  'office': 6,
#  'sank': 6,
#  'awak': 6,
#  'oat': 6,
#  'surprised': 6,
#  'different': 6,
#  'sunset': 6,
#  'older': 6,
#  'sleepi': 6,
#  'neck': 6,
#  'fold': 6,
#  'seed': 6,
#  'lines': 6,
#  'flap': 6,
#  'tail': 6,
#  'fair': 6,
#  'trust': 6,
#  'slow': 6,
#  'yesterday': 6,
#  'sun-up': 6,
#  'sharp': 6,
#  'measur': 6,
#  'mud': 6,
#  'trail': 6,
#  'eaten': 6,
#  'vast': 6,
#  'thousand': 6,
#  'fear': 6,
#  'hollow': 6,
#  'worry': 6,
#  'rustl': 6,
#  'lantern': 6,
#  'gold': 6,
#  'birds': 6,
#  'shepherdess': 6,
#  'shimmer': 6,
#  'plain': 6,
#  'bean': 6,
#  'tonight': 6,
#  'tend': 6,
#  'serv': 6,
#  'met': 6,
#  'buy': 6,
#  'quietli': 6,
#  'scrapers': 6,
#  'sweat': 6,
#  'nobody': 6,
#  'called': 6,
#  'snowi': 6,
#  'feather': 6,
#  'dishpan': 6,
#  'bet': 6,
#  'agreed': 6,
#  'warmth': 6,
#  'lid': 6,
#  'sour': 6,
#  'pantry': 6,
#  'fifteen': 6,
#  'shall': 6,
#  'cosi': 6,
#  'drift': 6,
#  'sorri': 6,
#  'brook': 6,
#  'scrap': 6,
#  'oyster': 6,
#  'pot': 6,
#  'gravi': 6,
#  'rais': 6,
#  'pasteboard': 6,
#  'march': 6,
#  'shelter': 6,
#  'beds': 6,
#  'doctor': 5,
#  'less': 5,
#  'wondered': 5,
#  'ear': 5,
#  'begun': 5,
#  'debt': 5,
#  'ago': 5,
#  'cheek': 5,
#  'draw': 5,
#  'sixti': 5,
#  'log': 5,
#  'frame': 5,
#  'boards': 5,
#  'woods': 5,
#  'times': 5,
#  'swept': 5,
#  'depot': 5,
#  'exactli': 5,
#  'roar': 5,
#  'bake': 5,
#  'notic': 5,
#  'wag': 5,
#  'bent': 5,
#  'hitch': 5,
#  'sick': 5,
#  'whenev': 5,
#  'comfortable': 5,
#  'third': 5,
#  'cows': 5,
#  'spade': 5,
#  'gaili': 5,
#  'bench': 5,
#  'satchel': 5,
#  'sunni': 5,
#  'shoe': 5,
#  'ribbon': 5,
#  'excus': 5,
#  'whistl': 5,
#  'hit': 5,
#  'crash': 5,
#  'skirt': 5,
#  'suit': 5,
#  'brakeman': 5,
#  'shiver': 5,
#  'underneath': 5,
#  'swoop': 5,
#  'promised': 5,
#  'spot': 5,
#  'grab': 5,
#  'finger': 5,
#  'hurry': 5,
#  'walls': 5,
#  'neatli': 5,
#  'wipe': 5,
#  'strangers': 5,
#  ...}

# %%
count = 0
s_value = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    s_value.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
count = 0
p_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    p = (word_fdic[i[0]]  * word_fdic[i[1]]) * s * s
    p_values.append(p)
    
    count += 1
    
    if count == 1000:
        break

# %%
max(p_values)
# Out:
# 0.7438080495356036

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(p_values)

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_value)

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
s_value_top_5 = sorted(s_value, reverse=True)[:6]
s_value_top_5
# Out:
# [0.02413793103448276,
#  0.023993808049535603,
#  0.009857612267250822,
#  0.009,
#  0.007751937984496124,
#  0.007625272331154684]

# %%
print(s_value.index(s_value_top_5[0]))
print(s_value.index(s_value_top_5[1]))
print(s_value.index(s_value_top_5[2]))
print(s_value.index(s_value_top_5[3]))
print(s_value.index(s_value_top_5[4]))
# Out:
# 93
# 28
# 19
# 466
# 221

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[0]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'alden':
        print(i,j)
    elif i ==  'reverend':
        print(i,j)
# Out:
# ('alden', 'reverend') 21
# reverend 30
# alden 29

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[1]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'aunt':
        print(i,j)
    elif i ==  'docia':
        print(i,j)
# Out:
# ('aunt', 'docia') 31
# docia 38
# aunt 34

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[2]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'lake':
        print(i,j)
    elif i ==  'silver':
        print(i,j)
# Out:
# ('lake', 'silver') 36
# lake 83
# silver 44

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[3]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 
#  1.1215545284109949e-07,
#  1.1223061146042889e-07,
#  1.1230584565403331e-07,
#  1.123811555232697e-07,
#  1.1245654116966499e-07,
#  1.125320026949164e-07,
#  1.1260754020089185e-07,
#  1.1268315378963024e-07,
#  1.1275884356334182e-07,
#  1.1283460962440856e-07,
#  1.1291045207538443e-07,
#  1.1298637101899584e-07,
#  1.1306236655814187e-07,
#  1.1313843879589475e-07,
#  1.1321458783550011e-07,
#  1.1329081378037737e-07,
#  1.133671167341201e-07,
#  1.1344349680049634e-07,
#  1.1351995408344898e-07,
#  1.1359648868709608e-07,
#  1.1367310071573131e-07,
#  1.1374979027382418e-07,
#  1.1382655746602049e-07,
#  1.1390340239714266e-07,
#  1.1398032517219008e-07,
#  1.1405732589633945e-07,
#  1.1413440467494521e-07,
#  1.1421156161353983e-07,
#  1.1428879681783417e-07,
#  1.1436611039371792e-07,
#  1.1444350244725986e-07,
#  1.145209730847083e-07,
#  1.1459852241249142e-07,
#  1.1467615053721763e-07,
#  1.1475385756567593e-07,
#  1.148316436048363e-07,
#  1.1490950876185004e-07,
#  1.1498745314405019e-07,
#  1.1506547685895182e-07,
#  1.1514358001425247e-07,
#  1.1522176271783251e-07,
#  1.1530002507775546e-07,
#  1.1537836720226843e-07,
#  1.1545678919980247e-07,
#  1.1553529117897295e-07,
#  1.1561387324857989e-07,
#  1.1569253551760841e-07,
#  1.1577127809522906e-07,
#  1.1585010109079822e-07,
#  1.1592900461385846e-07,
#  1.1600798877413894e-07,
#  1.160870536815558e-07,
#  1.161661994462125e-07,
#  1.1624542617840023e-07,
#  1.1632473398859832e-07,
#  1.1640412298747456e-07,
#  1.1648359328588568e-07,
#  1.1656314499487763e-07,
#  1.1664277822568605e-07,
#  1.1672249308973661e-07,
#  1.1680228969864542e-07,
#  1.1688216816421944e-07,
#  1.1696212859845685e-07,
#  1.1704217111354741e-07,
#  1.1712229582187291e-07,
#  1.1720250283600756e-07,
#  1.1728279226871834e-07,
#  1.1736316423296542e-07,
#  1.1744361884190257e-07,
#  1.1752415620887757e-07,
#  1.1760477644743255e-07,
#  1.1768547967130445e-07,
#  1.1776626599442542e-07,
#  1.1784713553092315e-07,
#  1.1792808839512136e-07,
#  1.1800912470154017e-07,
#  1.180902445648965e-07,
#  1.1817144810010445e-07,
#  1.1825273542227579e-07,
#  1.1833410664672026e-07,
#  1.184155618889461e-07,
#  1.1849710126466032e-07,
#  1.1857872488976921e-07,
#  ...]

# %%
middle = len(square(j)) / 2
print(int(middle))

middle = len(square(i)) / 2
print (int(middle))
# Out:
# 1951
# 1951

# %%
square(j)[int(middle)]
# Out:
# 2.6244625100779358e-07

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (int(middle)**2) / (x)

myu = integrate.quad(computePi, 1, int(middle)**2)

# 結果にはintegrated value and estimation error
myu
# Out:
# (57675328.9868903, 0.003628321534694834)

# %%
(1951**2) * log(1951**2)
# Out:
# 57675328.9868903

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (3.1991564464282061e-07**2) / (x)

myu = integrate.quad(computePi, 1, (3.1991564464282061e-07**2))
print(myu)
# Out:
# (-8.602977168246314e-13, 9.569926359863322e-13)
