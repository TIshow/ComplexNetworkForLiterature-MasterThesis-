# %%
# https://biblio.wiki/wiki/The_Old_Man_and_the_Sea
import nltk
from nltk.corpus import stopwords
import math
# %matplotlib inline

raw1 = open('Oldman_Sea.txt').read()

# %%
raw1
# Out:
# 'He was an old man who fished alone in a skiff in the Gulf Stream and he had gone eighty-four days now without taking a fish. In the first forty days a boy had been with him. But after forty days without a fish the boy’s parents had told him that the old man was now definitely and finally salao, which is the worst form of unlucky, and the boy had gone at their orders in another boat which caught three good fish the first week. It made the boy sad to see the old man come in each day with his skiff empty and he always went down to help him carry either the coiled lines or the gaff and harpoon and the sail that was furled around the mast. The sail was patched with flour sacks and, furled, it looked like the flag of permanent defeat.\n\nThe old man was thin and gaunt with deep wrinkles in the back of his neck. The brown blotches of the benevolent skin cancer the sun brings from its reflection on the tropic sea were on his cheeks. The blotches ran well down the sides of his face and his h
# ...

# %%
tokens1 = nltk.word_tokenize(raw1)
sentence1 = nltk.sent_tokenize(raw1)

# %%
#The number of token
len(tokens1)
# Out:
# 30346

# %%
len(sentence1)
# Out:
# 1660

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer() #to make base form

tokens_low = [w.lower() for w in tokens1]

#The number of sort of words
len(set(tokens_low))

#複数形や過去形を別の単語としてカウントしてしまっているため，実際の異なり語数はさらに少ない
# Out:
# 2654

# %%
print (len(set(tokens_low))/len(tokens1))
# Out:
# 0.08745798457786859

# %%
list1 = [tokens1]

text = []
for i in list1:
    text.append(nltk.Text(i))
    
text
# Out:
# [<Text: He was an old man who fished alone...>]

# %%
freq_list = []
for i in text:
    freq_list.append(nltk.FreqDist(w.lower() for w in i))

stopwords = nltk.corpus.stopwords.words('english')
symbols = ["'", '"', '`', '.', ',', '-', '!', '?', ':', ';', '(', ')', '...', "'s", '’', '”', '“','–','—', '…', '*' ,'``', "''",'--','mr.',"n't", 'dr.','sir', '‘', 'mr', 'm.' ]

# %%
freq_list
# Out:
# [FreqDist({'he': 1167,
#            'was': 435,
#            'an': 29,
#            'old': 246,
#            'man': 257,
#            'who': 26,
#            'fished': 3,
#            'alone': 11,
#            'in': 359,
#            'a': 397,
#            'skiff': 48,
#            'the': 2312,
#            'gulf': 6,
#            'stream': 3,
#            'and': 1258,
#            'had': 205,
#            'gone': 21,
#            'eighty-four': 2,
#            'days': 12,
#            'now': 172,
#            'without': 18,
#            'taking': 4,
#            'fish': 279,
#            '.': 1616,
#            'first': 30,
#            'forty': 5,
#            'boy': 99,
#            'been': 43,
#            'with': 205,
#            'him': 223,
#            'but': 233,
#            'after': 33,
#            '’': 185,
#            's': 77,
#            'parents': 1,
#            'told': 11,
#            'that': 298,
#            'definitely': 1,
#            'finally': 6,
# ...

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
sorted(freq_list_new)
# Out:
# [FreqDist({'old': 246,
#            'man': 257,
#            'fished': 3,
#            'alone': 11,
#            'skiff': 48,
#            'gulf': 6,
#            'stream': 3,
#            'gone': 21,
#            'eighty-four': 2,
#            'days': 12,
#            'without': 18,
#            'taking': 4,
#            'fish': 279,
#            'first': 30,
#            'forty': 5,
#            'boy': 99,
#            'parents': 1,
#            'told': 11,
#            'definitely': 1,
#            'finally': 6,
#            'salao': 1,
#            'worst': 1,
#            'form': 2,
#            'unlucky': 1,
#            'orders': 1,
#            'another': 21,
#            'boat': 38,
#            'caught': 7,
#            'three': 12,
#            'good': 44,
#            'week': 2,
#            'made': 48,
#            'sad': 4,
#            'see': 67,
#            'come': 58,
#            'day': 24,
#            'empty': 2,
#            'always': 16,
# ...

# %%
#順位チェック
sorted(freq_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('fish', 279),
#  ('man', 257),
#  ('old', 246),
#  ('said', 189),
#  ('thought', 165),
#  ('line', 138),
#  ('could', 116),
#  ('water', 105),
#  ('boy', 99),
#  ('would', 95),
#  ('hand', 89),
#  ('back', 81),
#  ('one', 76),
#  ('must', 72),
#  ('see', 67),
#  ('great', 64),
#  ('head', 60),
#  ('come', 58),
#  ('two', 55),
#  ('left', 50),
#  ('skiff', 48),
#  ('made', 48),
#  ('sun', 46),
#  ('much', 46),
#  ('shark', 46),
#  ('saw', 46),
#  ('like', 45),
#  ('knew', 45),
#  ('time', 45),
#  ('good', 44),
#  ('go', 44),
#  ('think', 44),
#  ('eat', 44),
#  ('hands', 43),
#  ('get', 43),
#  ('sea', 42),
#  ('dark', 42),
#  ('came', 41),
#  ('let', 40),
#  ('felt', 40),
#  ('still', 39),
#  ('boat', 38),
#  ('looked', 37),
#  ('well', 37),
#  ('make', 37),
#  ('fast', 37),
#  ('went', 35),
#  ('big', 35),
#  ('know', 35),
#  ('aloud', 35),
#  ('cut', 33),
#  ('bow', 33),
#  ('put', 33),
#  ('right', 33),
#  ('long', 32),
#  ('side', 31),
#  ('first', 30),
#  ('took', 30),
# ...

# %%
#Turn all words to basic form
bf = [ps.stem(word) for word in tokens_low if not word in stopwords + symbols]

# %%
#Textを使うためにreviewをlistにぶち込む
bf = [bf]

# %%
#原型に戻した単語で、再び文を再構築する。
text = []
for i in bf:
    text.append(nltk.Text(i))
    
text
# Out:
# [<Text: old man fish alon skiff gulf stream gone...>]

# %%
#Textからwords listを作る。
for i in text:
    words = [word for word in i]
    
words
# Out:
# ['old',
#  'man',
#  'fish',
#  'alon',
#  'skiff',
#  'gulf',
#  'stream',
#  'gone',
#  'eighty-four',
#  'day',
#  'without',
#  'take',
#  'fish',
#  'first',
#  'forti',
#  'day',
#  'boy',
#  'forti',
#  'day',
#  'without',
#  'fish',
#  'boy',
#  'parent',
#  'told',
#  'old',
#  'man',
#  'definit',
#  'final',
#  'salao',
#  'worst',
#  'form',
#  'unlucki',
#  'boy',
#  'gone',
#  'order',
#  'anoth',
#  'boat',
#  'caught',
#  'three',
#  'good',
#  'fish',
#  'first',
#  'week',
#  'made',
#  'boy',
#  'sad',
#  'see',
#  'old',
#  'man',
#  'come',
#  'day',
#  'skiff',
#  'empti',
#  'alway',
#  'went',
#  'help',
#  'carri',
#  'either',
#  'coil',
#  'line',
#  'gaff',
#  'harpoon',
#  'sail',
#  'furl',
#  'around',
#  'mast',
#  'sail',
#  'patch',
#  'flour',
#  'sack',
#  'furl',
#  'look',
#  'like',
#  'flag',
#  'perman',
#  'defeat',
#  'old',
#  'man',
#  'thin',
#  'gaunt',
#  'deep',
#  'wrinkl',
#  'back',
#  'neck',
#  'brown',
#  'blotch',
# ...

# %%
 # Sentence bu sentence
sentence1
# Out:
# ['He was an old man who fished alone in a skiff in the Gulf Stream and he had gone eighty-four days now without taking a fish.',
#  'In the first forty days a boy had been with him.',
#  'But after forty days without a fish the boy’s parents had told him that the old man was now definitely and finally salao, which is the worst form of unlucky, and the boy had gone at their orders in another boat which caught three good fish the first week.',
#  'It made the boy sad to see the old man come in each day with his skiff empty and he always went down to help him carry either the coiled lines or the gaff and harpoon and the sail that was furled around the mast.',
#  'The sail was patched with flour sacks and, furled, it looked like the flag of permanent defeat.',
#  'The old man was thin and gaunt with deep wrinkles in the back of his neck.',
#  'The brown blotches of the benevolent skin cancer the sun brings from its reflection on the tropic sea were on his cheeks.',
# ...

# %%
#文章を小文字化
sentence_l1 = [w.lower() for w in sentence1]
sentence_l1
# Out:
# ['he was an old man who fished alone in a skiff in the gulf stream and he had gone eighty-four days now without taking a fish.',
#  'in the first forty days a boy had been with him.',
#  'but after forty days without a fish the boy’s parents had told him that the old man was now definitely and finally salao, which is the worst form of unlucky, and the boy had gone at their orders in another boat which caught three good fish the first week.',
#  'it made the boy sad to see the old man come in each day with his skiff empty and he always went down to help him carry either the coiled lines or the gaff and harpoon and the sail that was furled around the mast.',
#  'the sail was patched with flour sacks and, furled, it looked like the flag of permanent defeat.',
#  'the old man was thin and gaunt with deep wrinkles in the back of his neck.',
#  'the brown blotches of the benevolent skin cancer the sun brings from its reflection on the tropic sea were on his cheeks.',
# ...

# %%
#いけそう。文ごとに取り出し、それぞれの単語を原型に戻す。それを再び再構築する！
for sentence in sentence_l1:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    print (form)
# Out:
# ['old', 'man', 'fish', 'alon', 'skiff', 'gulf', 'stream', 'gone', 'eighty-four', 'day', 'without', 'take', 'fish.']
# ['first', 'forti', 'day', 'boy', 'him.']
# ['forti', 'day', 'without', 'fish', 'boy’', 'parent', 'told', 'old', 'man', 'definit', 'final', 'salao,', 'worst', 'form', 'unlucky,', 'boy', 'gone', 'order', 'anoth', 'boat', 'caught', 'three', 'good', 'fish', 'first', 'week.']
# ['made', 'boy', 'sad', 'see', 'old', 'man', 'come', 'day', 'skiff', 'empti', 'alway', 'went', 'help', 'carri', 'either', 'coil', 'line', 'gaff', 'harpoon', 'sail', 'furl', 'around', 'mast.']
# ['sail', 'patch', 'flour', 'sack', 'and,', 'furled,', 'look', 'like', 'flag', 'perman', 'defeat.']
# ['old', 'man', 'thin', 'gaunt', 'deep', 'wrinkl', 'back', 'neck.']
# ['brown', 'blotch', 'benevol', 'skin', 'cancer', 'sun', 'bring', 'reflect', 'tropic', 'sea', 'cheeks.']
# ['blotch', 'ran', 'well', 'side', 'face', 'hand', 'deep-creas', 'scar', 'handl', 'heavi', 'fish', 'cords.']
# ['none', 'scar', 'fresh.']
# ...

# %%
#上の本番
form_sent = []
for sentence in sentence_l1:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    form_sent.append(" ".join(form))

# %%
#ピリオドやカンマを消しまーす。Delte period and comma...めんどい...
form_sent2 = []

for i in form_sent:
    tokens = nltk.word_tokenize(i)
    form = [word for word in tokens if not word in stopwords + symbols]
    form_sent2.append(" ".join(form))

# %%
#次にこの新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化したい
text = []

for i in form_sent2:
    tokens = nltk.word_tokenize(i)
    for j in tokens:
        text.append(j)

# %%
text = [text]

# %%
#新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化

import matplotlib.pyplot as plt
# %matplotlib inline

f_list_new = []
for i in text:
    f_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in f_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
log_freq  = []
for i in f_list_new[0].values():
    log_freq.append(i)
    
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_freq, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('freq(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#順位チェック
sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('fish', 292),
#  ('man', 263),
#  ('old', 247),
#  ('said', 189),
#  ('thought', 168),
#  ('line', 153),
#  ('hand', 124),
#  ('could', 116),
#  ('water', 105),
#  ('boy', 101),
#  ('would', 95),
#  ('back', 89),
#  ('come', 77),
#  ('one', 77),
#  ('must', 72),
#  ('see', 69),
#  ('head', 68),
#  ('great', 65),
#  ('go', 63),
#  ('shark', 61),
#  ('look', 58),
#  ('two', 55),
#  ('eat', 55),
#  ('time', 55),
#  ('get', 52),
#  ('pull', 51),
#  ('like', 50),
#  ('left', 50),
#  ('skiff', 48),
#  ('made', 48),
#  ('think', 48),
#  ('make', 48),
#  ('good', 47),
#  ('saw', 47),
#  ('boat', 46),
#  ('sun', 46),
#  ('much', 46),
#  ('dark', 46),
#  ('know', 45),
#  ('knew', 45),
#  ('sea', 43),
#  ('cut', 42),
#  ('well', 41),
#  ('came', 41),
#  ('let', 41),
#  ('kill', 40),
#  ('felt', 40),
#  ('still', 39),
#  ('big', 37),
#  ('work', 37),
#  ('right', 37),
#  ('fast', 37),
#  ('put', 36),
#  ('day', 35),
#  ('went', 35),
#  ('side', 35),
#  ('feel', 35),
#  ('aloud', 35),
# ...

# %%
form_sent2
# Out:
# ['old man fish alon skiff gulf stream gone eighty-four day without take fish',
#  'first forti day boy',
#  'forti day without fish boy parent told old man definit final salao worst form unlucky boy gone order anoth boat caught three good fish first week',
#  'made boy sad see old man come day skiff empti alway went help carri either coil line gaff harpoon sail furl around mast',
#  'sail patch flour sack furled look like flag perman defeat',
#  'old man thin gaunt deep wrinkl back neck',
#  'brown blotch benevol skin cancer sun bring reflect tropic sea cheeks',
#  'blotch ran well side face hand deep-creas scar handl heavi fish cords',
#  'none scar fresh',
#  'old eros fishless desert',
#  'everyth old except eye color sea cheer undefeated',
#  'santiago boy said climb bank skiff haul',
#  'could go',
#  'v made money. old man taught boy fish boy love',
#  'old man said',
#  'r lucki boat',
# ...

# %%
text[0]
# Out:
# ['old',
#  'man',
#  'fish',
#  'alon',
#  'skiff',
#  'gulf',
#  'stream',
#  'gone',
#  'eighty-four',
#  'day',
#  'without',
#  'take',
#  'fish',
#  'first',
#  'forti',
#  'day',
#  'boy',
#  'forti',
#  'day',
#  'without',
#  'fish',
#  'boy',
#  'parent',
#  'told',
#  'old',
#  'man',
#  'definit',
#  'final',
#  'salao',
#  'worst',
#  'form',
#  'unlucky',
#  'boy',
#  'gone',
#  'order',
#  'anoth',
#  'boat',
#  'caught',
#  'three',
#  'good',
#  'fish',
#  'first',
#  'week',
#  'made',
#  'boy',
#  'sad',
#  'see',
#  'old',
#  'man',
#  'come',
#  'day',
#  'skiff',
#  'empti',
#  'alway',
#  'went',
#  'help',
#  'carri',
#  'either',
#  'coil',
#  'line',
#  'gaff',
#  'harpoon',
#  'sail',
#  'furl',
#  'around',
#  'mast',
#  'sail',
#  'patch',
#  'flour',
#  'sack',
#  'furled',
#  'look',
#  'like',
#  'flag',
#  'perman',
#  'defeat',
#  'old',
#  'man',
#  'thin',
#  'gaunt',
#  'deep',
#  'wrinkl',
#  'back',
#  'neck',
#  'brown',
#  'blotch',
# ...

# %%
# let's make new list only with words whose frequency  > 5

moreThan5_freq = []

for i,j in f_list_new[0].items():
    if j > 5:
        moreThan5_freq.append(i)

# %%
moreThan5_freq
# Out:
# ['old',
#  'man',
#  'fish',
#  'alon',
#  'skiff',
#  'gulf',
#  'gone',
#  'day',
#  'without',
#  'take',
#  'first',
#  'boy',
#  'told',
#  'anoth',
#  'boat',
#  'caught',
#  'three',
#  'good',
#  'made',
#  'see',
#  'come',
#  'alway',
#  'went',
#  'help',
#  'carri',
#  'coil',
#  'line',
#  'gaff',
#  'harpoon',
#  'sail',
#  'around',
#  'mast',
#  'patch',
#  'sack',
#  'look',
#  'like',
#  'deep',
#  'back',
#  'brown',
#  'skin',
#  'sun',
#  'bring',
#  'sea',
#  'well',
#  'side',
#  'face',
#  'hand',
#  'heavi',
#  'fresh',
#  'everyth',
#  'except',
#  'eye',
#  'said',
#  'could',
#  'go',
#  'love',
#  'r',
#  'stay',
#  'rememb',
#  'big',
#  'one',
#  'everi',
#  'remember',
#  'know',
#  'must',
#  'quit',
#  'much',
#  'yes',
#  'terrac',
#  'home',
#  'fishermen',
#  'mani',
#  'show',
#  'spoke',
#  'current',
#  'steadi',
#  'weather',
#  'seen',
#  'marlin',
#  'length',
#  'across',
#  'two',
#  'men',
#  'end',
#  'plank',
#  'wait',
#  'shark',
# ...

# %%
# 頻出単語top2のgameshとsaidが同時に現れる文を、ピックアップしカウントするプログラムを全ての単語に割り当てる試み。

count_s = {}

for wn1 in range(0, len(moreThan5_freq)-1):
    for wn2 in range(wn1+1, len(moreThan5_freq)):
        s = 0
    
        for sent in form_sent2:
            index1 = 0
            index2 = 0
            
            #remove duplicate
            if moreThan5_freq[wn1] != moreThan5_freq[wn2]:
                
                if moreThan5_freq[wn1] in sent.split():
                    index1 += 1
                if moreThan5_freq[wn2] in sent.split():
                    index2 += 1
              
                if index1 > 0 and index2 > 0:
                    s += 1
                
        count_s.update({( moreThan5_freq[wn1], moreThan5_freq[wn2]) :s })

# %%
count_s
# Out:
# {('old', 'man'): 220,
#  ('old', 'fish'): 49,
#  ('old', 'alon'): 3,
#  ('old', 'skiff'): 10,
#  ('old', 'gulf'): 1,
#  ('old', 'gone'): 4,
#  ('old', 'day'): 5,
#  ('old', 'without'): 4,
#  ('old', 'take'): 8,
#  ('old', 'first'): 6,
#  ('old', 'boy'): 26,
#  ('old', 'told'): 4,
#  ('old', 'anoth'): 3,
#  ('old', 'boat'): 11,
#  ('old', 'caught'): 2,
#  ('old', 'three'): 3,
#  ('old', 'good'): 3,
#  ('old', 'made'): 6,
#  ('old', 'see'): 21,
#  ('old', 'come'): 16,
#  ('old', 'alway'): 4,
#  ('old', 'went'): 12,
#  ('old', 'help'): 4,
#  ('old', 'carri'): 6,
#  ('old', 'coil'): 2,
#  ('old', 'line'): 26,
#  ('old', 'gaff'): 4,
#  ('old', 'harpoon'): 7,
#  ('old', 'sail'): 8,
#  ('old', 'around'): 3,
#  ('old', 'mast'): 5,
#  ('old', 'patch'): 0,
#  ('old', 'sack'): 0,
#  ('old', 'look'): 5,
#  ('old', 'like'): 8,
#  ('old', 'deep'): 4,
#  ('old', 'back'): 16,
#  ('old', 'brown'): 3,
#  ('old', 'skin'): 2,
#  ('old', 'sun'): 10,
#  ('old', 'bring'): 6,
#  ('old', 'sea'): 9,
# ...

# %%
#順位チェック
sorted(count_s.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('old', 'man'), 220),
#  (('man', 'said'), 65),
#  (('old', 'said'), 63),
#  (('man', 'fish'), 53),
#  (('old', 'fish'), 49),
#  (('boy', 'said'), 43),
#  (('fish', 'line'), 38),
#  (('fish', 'could'), 32),
#  (('said', 'aloud'), 32),
#  (('line', 'hand'), 31),
#  (('hand', 'left'), 31),
#  (('see', 'could'), 30),
#  (('man', 'line'), 28),
#  (('fish', 'water'), 28),
#  (('fish', 'said'), 27),
#  (('old', 'boy'), 26),
#  (('old', 'line'), 26),
#  (('man', 'boy'), 25),
#  (('man', 'could'), 24),
#  (('fish', 'great'), 24),
#  (('man', 'water'), 22),
#  (('fish', 'back'), 22),
#  (('fish', 'fli'), 22),
#  (('line', 'back'), 22),
#  (('line', 'could'), 22),
#  (('old', 'see'), 21),
#  (('old', 'could'), 21),
#  (('hand', 'right'), 21),
#  (('man', 'see'), 20),
#  (('old', 'water'), 19),
#  (('fish', 'thought'), 19),
#  (('line', 'water'), 19),
#  (('line', 'pull'), 19),
#  (('fish', 'see'), 18),
#  (('fish', 'would'), 18),
#  (('fish', 'head'), 18),
#  (('fish', 'pull'), 18),
# ...

# %%
#namely

new = {tuple(sorted(x)):y for x, y in count_s.items()}

# %%
#順位チェック again !
new2 = dict(sorted(new.items(), key=lambda x: x[1], reverse=True))
new2
# Out:
# {('man', 'old'): 220,
#  ('man', 'said'): 65,
#  ('old', 'said'): 63,
#  ('fish', 'man'): 53,
#  ('fish', 'old'): 49,
#  ('boy', 'said'): 43,
#  ('fish', 'line'): 38,
#  ('could', 'fish'): 32,
#  ('aloud', 'said'): 32,
#  ('hand', 'line'): 31,
#  ('hand', 'left'): 31,
#  ('could', 'see'): 30,
#  ('line', 'man'): 28,
#  ('fish', 'water'): 28,
#  ('fish', 'said'): 27,
#  ('boy', 'old'): 26,
#  ('line', 'old'): 26,
#  ('boy', 'man'): 25,
#  ('could', 'man'): 24,
#  ('fish', 'great'): 24,
#  ('man', 'water'): 22,
#  ('back', 'fish'): 22,
#  ('fish', 'fli'): 22,
#  ('back', 'line'): 22,
#  ('could', 'line'): 22,
#  ('old', 'see'): 21,
#  ('could', 'old'): 21,
#  ('hand', 'right'): 21,
#  ('man', 'see'): 20,
#  ('old', 'water'): 19,
#  ('fish', 'thought'): 19,
#  ('line', 'water'): 19,
#  ('line', 'pull'): 19,
#  ('fish', 'see'): 18,
#  ('fish', 'would'): 18,
#  ('fish', 'head'): 18,
#  ('fish', 'pull'): 18,
#  ('left', 'line'): 18,
#  ('dark', 'water'): 18,
#  ('back', 'man'): 17,
# ...

# %%
new3 = dict((k, v) for k, v in new2.items() if v >= 2)
new3
# Out:
# {('man', 'old'): 220,
#  ('man', 'said'): 65,
#  ('old', 'said'): 63,
#  ('fish', 'man'): 53,
#  ('fish', 'old'): 49,
#  ('boy', 'said'): 43,
#  ('fish', 'line'): 38,
#  ('could', 'fish'): 32,
#  ('aloud', 'said'): 32,
#  ('hand', 'line'): 31,
#  ('hand', 'left'): 31,
#  ('could', 'see'): 30,
#  ('line', 'man'): 28,
#  ('fish', 'water'): 28,
#  ('fish', 'said'): 27,
#  ('boy', 'old'): 26,
#  ('line', 'old'): 26,
#  ('boy', 'man'): 25,
#  ('could', 'man'): 24,
#  ('fish', 'great'): 24,
#  ('man', 'water'): 22,
#  ('back', 'fish'): 22,
#  ('fish', 'fli'): 22,
#  ('back', 'line'): 22,
#  ('could', 'line'): 22,
#  ('old', 'see'): 21,
#  ('could', 'old'): 21,
#  ('hand', 'right'): 21,
#  ('man', 'see'): 20,
#  ('old', 'water'): 19,
#  ('fish', 'thought'): 19,
#  ('line', 'water'): 19,
#  ('line', 'pull'): 19,
#  ('fish', 'see'): 18,
#  ('fish', 'would'): 18,
#  ('fish', 'head'): 18,
#  ('fish', 'pull'): 18,
#  ('left', 'line'): 18,
#  ('dark', 'water'): 18,
#  ('back', 'man'): 17,
# ...

# %%
#順位チェック again !
new4 = dict(sorted(new3.items(), key=lambda x: x[1], reverse=True))
new4
# Out:
# {('man', 'old'): 220,
#  ('man', 'said'): 65,
#  ('old', 'said'): 63,
#  ('fish', 'man'): 53,
#  ('fish', 'old'): 49,
#  ('boy', 'said'): 43,
#  ('fish', 'line'): 38,
#  ('could', 'fish'): 32,
#  ('aloud', 'said'): 32,
#  ('hand', 'line'): 31,
#  ('hand', 'left'): 31,
#  ('could', 'see'): 30,
#  ('line', 'man'): 28,
#  ('fish', 'water'): 28,
#  ('fish', 'said'): 27,
#  ('boy', 'old'): 26,
#  ('line', 'old'): 26,
#  ('boy', 'man'): 25,
#  ('could', 'man'): 24,
#  ('fish', 'great'): 24,
#  ('man', 'water'): 22,
#  ('back', 'fish'): 22,
#  ('fish', 'fli'): 22,
#  ('back', 'line'): 22,
#  ('could', 'line'): 22,
#  ('old', 'see'): 21,
#  ('could', 'old'): 21,
#  ('hand', 'right'): 21,
#  ('man', 'see'): 20,
#  ('old', 'water'): 19,
#  ('fish', 'thought'): 19,
#  ('line', 'water'): 19,
#  ('line', 'pull'): 19,
#  ('fish', 'see'): 18,
#  ('fish', 'would'): 18,
#  ('fish', 'head'): 18,
#  ('fish', 'pull'): 18,
#  ('left', 'line'): 18,
#  ('dark', 'water'): 18,
#  ('back', 'man'): 17,
# ...

# %%
pair_freq = []
for i,j in new4.items():
    pair_freq.append(j)
    
sorted(pair_freq, reverse=True)
# Out:
# [220,
#  65,
#  63,
#  53,
#  49,
#  43,
#  38,
#  32,
#  32,
#  31,
#  31,
#  30,
#  28,
#  28,
#  27,
#  26,
#  26,
#  25,
#  24,
#  24,
#  22,
#  22,
#  22,
#  22,
#  22,
#  21,
#  21,
#  21,
#  20,
#  19,
#  19,
#  19,
#  19,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  17,
#  17,
#  17,
#  17,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  15,
#  15,
#  15,
#  15,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(pair_freq, reverse=True))

plt.ylabel('frequency')
plt.xlabel('rank')
plt.title('word pair frequency in "The old man and sea"')
plt.show()

# %%
#take a log log graph
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(pair_freq)+1)
y = sorted(pair_freq, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(pair_freq, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(pair_freq)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
ax.set_title('The logarithmic graph of rank and frequency of word pair')
ax.set_xlabel('Log scaled rank')
ax.set_ylabel('Log scaled frequency')

#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
#単語順位チェック
word_f = sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
word_f
# Out:
# [('fish', 292),
#  ('man', 263),
#  ('old', 247),
#  ('said', 189),
#  ('thought', 168),
#  ('line', 153),
#  ('hand', 124),
#  ('could', 116),
#  ('water', 105),
#  ('boy', 101),
#  ('would', 95),
#  ('back', 89),
#  ('come', 77),
#  ('one', 77),
#  ('must', 72),
#  ('see', 69),
#  ('head', 68),
#  ('great', 65),
#  ('go', 63),
#  ('shark', 61),
#  ('look', 58),
#  ('two', 55),
#  ('eat', 55),
#  ('time', 55),
#  ('get', 52),
#  ('pull', 51),
#  ('like', 50),
#  ('left', 50),
#  ('skiff', 48),
#  ('made', 48),
#  ('think', 48),
#  ('make', 48),
#  ('good', 47),
#  ('saw', 47),
#  ('boat', 46),
#  ('sun', 46),
#  ('much', 46),
#  ('dark', 46),
#  ('know', 45),
#  ('knew', 45),
#  ('sea', 43),
#  ('cut', 42),
#  ('well', 41),
#  ('came', 41),
#  ('let', 41),
#  ('kill', 40),
#  ('felt', 40),
#  ('still', 39),
#  ('big', 37),
#  ('work', 37),
#  ('right', 37),
#  ('fast', 37),
#  ('put', 36),
#  ('day', 35),
#  ('went', 35),
#  ('side', 35),
#  ('feel', 35),
#  ('aloud', 35),
# ...

# %%
word_fdic = dict(word_f)
word_fdic
# Out:
# {'fish': 292,
#  'man': 263,
#  'old': 247,
#  'said': 189,
#  'thought': 168,
#  'line': 153,
#  'hand': 124,
#  'could': 116,
#  'water': 105,
#  'boy': 101,
#  'would': 95,
#  'back': 89,
#  'come': 77,
#  'one': 77,
#  'must': 72,
#  'see': 69,
#  'head': 68,
#  'great': 65,
#  'go': 63,
#  'shark': 61,
#  'look': 58,
#  'two': 55,
#  'eat': 55,
#  'time': 55,
#  'get': 52,
#  'pull': 51,
#  'like': 50,
#  'left': 50,
#  'skiff': 48,
#  'made': 48,
#  'think': 48,
#  'make': 48,
#  'good': 47,
#  'saw': 47,
#  'boat': 46,
#  'sun': 46,
#  'much': 46,
#  'dark': 46,
#  'know': 45,
#  'knew': 45,
#  'sea': 43,
#  'cut': 42,
#  'well': 41,
#  'came': 41,
#  'let': 41,
#  'kill': 40,
#  'felt': 40,
#  'still': 39,
#  'big': 37,
#  'work': 37,
#  'right': 37,
#  'fast': 37,
#  'put': 36,
#  'day': 35,
#  'went': 35,
#  'side': 35,
#  'feel': 35,
#  'aloud': 35,
#  'sail': 34,
#  'bow': 34,
#  'hook': 33,
#  'turn': 33,
#  'watch': 33,
#  'take': 32,
#  'tri': 32,
#  'bird': 32,
# ...

# %%
new2
# Out:
# {('man', 'old'): 220,
#  ('man', 'said'): 65,
#  ('old', 'said'): 63,
#  ('fish', 'man'): 53,
#  ('fish', 'old'): 49,
#  ('boy', 'said'): 43,
#  ('fish', 'line'): 38,
#  ('could', 'fish'): 32,
#  ('aloud', 'said'): 32,
#  ('hand', 'line'): 31,
#  ('hand', 'left'): 31,
#  ('could', 'see'): 30,
#  ('line', 'man'): 28,
#  ('fish', 'water'): 28,
#  ('fish', 'said'): 27,
#  ('boy', 'old'): 26,
#  ('line', 'old'): 26,
#  ('boy', 'man'): 25,
#  ('could', 'man'): 24,
#  ('fish', 'great'): 24,
#  ('man', 'water'): 22,
#  ('back', 'fish'): 22,
#  ('fish', 'fli'): 22,
#  ('back', 'line'): 22,
#  ('could', 'line'): 22,
#  ('old', 'see'): 21,
#  ('could', 'old'): 21,
#  ('hand', 'right'): 21,
#  ('man', 'see'): 20,
#  ('old', 'water'): 19,
#  ('fish', 'thought'): 19,
#  ('line', 'water'): 19,
#  ('line', 'pull'): 19,
#  ('fish', 'see'): 18,
#  ('fish', 'would'): 18,
#  ('fish', 'head'): 18,
#  ('fish', 'pull'): 18,
#  ('left', 'line'): 18,
#  ('dark', 'water'): 18,
#  ('back', 'man'): 17,
# ...

# %%
count = 0
s_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    s_values.append(s)
    
    count += 1
    
    if count == 1000:
        break

# %%
count = 0
p_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    p = (word_fdic[i[0]]  * word_fdic[i[1]]) * s * s
    p_values.append(p)
    
    count += 1
    
    if count == 1000:
        break

# %%
p_values
# Out:
# [0.7450624220686257,
#  0.08499808880037016,
#  0.08502024291497975,
#  0.03657742590759936,
#  0.03328988963451833,
#  0.09686206715909686,
#  0.0323216044408631,
#  0.030231459612659425,
#  0.1547996976568405,
#  0.05065359477124183,
#  0.155,
#  0.11244377811094453,
#  0.01948358557618231,
#  0.02557077625570776,
#  0.013209393346379647,
#  0.027097446586763933,
#  0.01788785689714482,
#  0.023528968866468398,
#  0.018880293693457454,
#  0.030347734457323496,
#  0.01752670650009053,
#  0.018623980298599352,
#  0.06906392694063926,
#  0.03554380553719615,
#  0.027270678386297046,
#  0.025875726104559058,
#  0.015391595700125646,
#  0.09612031386224934,
#  0.022042210833746623,
#  0.013919413919413919,
#  0.007358936725375081,
#  0.022471210706504825,
#  0.046264257336921695,
#  0.016081000595592615,
#  0.011679884643114636,
#  0.016317485898468976,
#  0.021756647864625302,
#  0.042352941176470586,
#  0.0670807453416149,
#  0.012346733883026444,
#  0.006540829259460438,
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.title('relation between p value and rank')
plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
s_values
# Out:
# [0.003386647373039208,
#  0.0013076629046210795,
#  0.001349527665317139,
#  0.0006901401114641388,
#  0.0006793855027452721,
#  0.0022526062130022524,
#  0.0008505685379174501,
#  0.000944733112895607,
#  0.004837490551776266,
#  0.0016339869281045752,
#  0.005,
#  0.0037481259370314842,
#  0.0006958423420065111,
#  0.0009132420091324201,
#  0.0004892367906066536,
#  0.0010422094841063053,
#  0.0006879944960440316,
#  0.0009411587546587359,
#  0.0007866789038940606,
#  0.0012644889357218123,
#  0.0007966684772768423,
#  0.0008465445590272433,
#  0.003139269406392694,
#  0.001615627524418007,
#  0.0012395762902862293,
#  0.0012321774335504313,
#  0.0007329331285774117,
#  0.004577157802964254,
#  0.0011021105416873312,
#  0.0007326007326007326,
#  0.00038731245923026743,
#  0.0011826953003423592,
#  0.002434960912469563,
#  0.0008933889219773674,
#  0.0006488824801730354,
#  0.0009065269943593876,
#  0.0012087026591458502,
#  0.002352941176470588,
#  0.0037267080745341614,
# ...

# %%
max(s_values)
# Out:
# 0.09523809523809523

# %%
count = 0
for i, j in new2.items():
    if count == 73:
        print(i,j)
    count += 1
# Out:
# ('kill', 'thought') 13

# %%
for i,j in word_fdic.items():
    if i == 'kill':
        print(i,j)
    elif i == 'thought':
        print(i,j)
# Out:
# thought 168
# kill 40

# %%
def second_largest(numbers):
    count = 0
    m1 = m2 = float('-inf')
    for x in numbers:
        count += 1
        if x > m2:
            if x >= m1:
                m1, m2 = x, m1            
            else:
                m2 = x
    return m2 if count >= 2 else None

# %%
second_largest(s_values)
# Out:
# 0.07575757575757576

# %%
s_values.index(second_largest(s_values))
# Out:
# 646

# %%
count = 0
for i, j in new2.items():
    if count == 70:
        print(i,j)
    count += 1
# Out:
# ('bow', 'line') 13

# %%
for i,j in word_fdic.items():
    if i == 'bow':
        print(i,j)
    elif i == 'line':
        print(i,j)
# Out:
# line 153
# bow 34

# %%
sorted(s_values, reverse=True)[:6]
# Out:
# [0.09523809523809523,
#  0.07575757575757576,
#  0.06593406593406594,
#  0.0625,
#  0.026143790849673203,
#  0.025974025974025976]

# %%
s_value_top_5 = sorted(s_values, reverse=True)[:6]
s_value_top_5
# Out:
# [0.09523809523809523,
#  0.07575757575757576,
#  0.06593406593406594,
#  0.0625,
#  0.026143790849673203,
#  0.025974025974025976]

# %%
print(s_values.index(s_value_top_5[0]))
print(s_values.index(s_value_top_5[1]))
print(s_values.index(s_value_top_5[2]))
print(s_values.index(s_value_top_5[3]))
print(s_values.index(s_value_top_5[4]))
# Out:
# 755
# 646
# 432
# 442
# 811

# %%
count = 0
for i, j in new2.items():
    if count == s_values.index(s_value_top_5[0]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'gulf':
        print(i,j)
    elif i ==  'weed':
        print(i,j)
# Out:
# ('gulf', 'weed') 4
# weed 7
# gulf 6

# %%
count = 0
for i, j in new2.items():
    if count == s_values.index(s_value_top_5[1]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'fathom':
        print(i,j)
    elif i ==  'hundr':
        print(i,j)
# Out:
# ('fathom', 'hundr') 5
# hundr 11
# fathom 6

# %%
count = 0
for i, j in new2.items():
    if count == s_values.index(s_value_top_5[2]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'weed':
        print(i,j)
    elif i ==  'yellow':
        print(i,j)
# Out:
# ('weed', 'yellow') 6
# yellow 13
# weed 7

# %%
count = 0
for i, j in new2.items():
    if count == s_values.index(s_value_top_5[3]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'purpl':
        print(i,j)
    elif i ==  'stripe':
        print(i,j)
# Out:
# ('purpl', 'stripe') 6
# purpl 12
# stripe 8

# %%
count = 0
for i, j in new2.items():
    if count == s_values.index(s_value_top_5[4]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'coil':
        print(i,j)
    elif i ==  'reserv':
        print(i,j)
# Out:
# ('coil', 'reserv') 4
# coil 17
# reserv 9

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_values)

plt.title('relation between s value and rank')
plt.ylabel('s value')
plt.xlabel('frequency rank of word pairs ')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_values, reverse=True))

plt.title('s value distribution')
plt.ylabel('s value')
plt.xlabel('rank of s value')
plt.show()

# %%
from math import log
log_list = [log(y,10) for y in s_values]
log_list
# Out:
# [-2.470230020927217,
#  -2.883504196020146,
#  -2.869818207979328,
#  -3.161062730337387,
#  -3.16788372467957,
#  -2.6473147223763,
#  -3.0702906856492067,
#  -3.0246908623554307,
#  -2.3153798702036137,
#  -2.786751422145561,
#  -2.301029995663981,
#  -2.4261858252445108,
#  -3.157489147965137,
#  -3.039414119176137,
#  -3.310480891462675,
#  -2.9820449790714902,
#  -3.1624150361064465,
#  -3.0263371136003627,
#  -3.1042024960050703,
#  -2.8980849663796677,
#  -3.0987223667374892,
#  -3.0723501772711246,
#  -2.503171412337818,
#  -2.791658756640305,
#  -2.906726739222311,
#  -2.9093267492630015,
#  -3.1349356477526644,
#  -2.3394041144953106,
#  -2.957774843563032,
#  -3.1351326513767748,
#  -3.411938532221452,
#  -2.9271271289347074,
#  -2.6135080059627063,
#  -3.0489594370823676,
#  -3.1878339516339596,
#  -3.042619259051348,
#  -2.917680522443048,
#  -2.6283889300503116,
#  -2.4286746256482057,
#  -3.1388968337563963,
#  -3.4148161088373463,
#  -3.020263765080911,
# ...

# %%
#take a log
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_list, reverse=True))

plt.ylabel('s value(log scale)')
plt.xlabel('rank (Descending order of s value)')
plt.show()

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_values, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('s value(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = np.array(log_x)
y = np.array(log_list)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-28239f2f9124> in <module>()
#       9 plt.figure(figsize=(20,10))
#      10 fig, ax = plt.subplots()
# ---> 11 a, b = np.polyfit(x, y, deg=1)
#      12 #fit = np.polyfit(x, y, deg=1)
#      13 # フィッティング直線
#
# /anaconda/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     561         raise TypeError("expected 1D or 2D array for y")
#     562     if x.shape[0] != y.shape[0]:
# --> 563         raise TypeError("expected x and y to have same length")
#     564
#     565     # set rcond
#
# TypeError: expected x and y to have same length

# %%
from math import log

sorted_list = sorted(s_values, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values)+1)]

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = np.array(log_x)
y = np.array(log_list)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(log_list)+1)
y = sorted(log_list, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log log graph
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(s_values)+1)
y = sorted(s_values, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
# i,j count
import numpy as np

len(word_f)
# Out:
# 2140

# %%
np.arange(1,len(word_f)+1, 1)
# Out:
# array([   1,    2,    3, ..., 2138, 2139, 2140])

# %%
np.arange(len(word_f), 0, -1)
# Out:
# array([2140, 2139, 2138, ...,    3,    2,    1])

# %%
i = np.arange(len(word_f), 0, -1)
j = np.arange(1,len(word_f)+1, 1)

# %%
def square(list):
    return [i ** -2 for i in list]

# %%
square(i)
# Out:
# [2.183596820683029e-07,
#  2.1856389966955324e-07,
#  2.1876840389197741e-07,
#  2.1897319527219354e-07,
#  2.1917827434807614e-07,
#  2.1938364165875973e-07,
#  2.1958929774464224e-07,
#  2.1979524314738876e-07,
#  2.2000147840993491e-07,
#  2.2020800407649057e-07,
#  2.2041482069254336e-07,
#  2.2062192880486233e-07,
#  2.2082932896150151e-07,
#  2.2103702171180352e-07,
#  2.2124500760640337e-07,
#  2.2145328719723183e-07,
#  2.2166186103751937e-07,
#  2.2187072968179965e-07,
#  2.220798936859133e-07,
#  2.2228935360701155e-07,
#  2.2249911000355999e-07,
#  2.2270916343534229e-07,
#  2.2291951446346395e-07,
#  2.2313016365035592e-07,
#  2.2334111155977858e-07,
#  2.2355235875682533e-07,
#  2.2376390580792643e-07,
#  2.2397575328085283e-07,
#  2.2418790174471992e-07,
#  2.2440035176999144e-07,
#  2.2461310392848319e-07,
#  2.24826158793367e-07,
#  2.2503951693917451e-07,
#  2.2525317894180111e-07,
#  2.2546714537850974e-07,
#  2.2568141682793484e-07,
#  2.258959938700863e-07,
# ...

# %%
square(j)
# Out:
# [1.0,
#  0.25,
#  0.1111111111111111,
#  0.0625,
#  0.040000000000000001,
#  0.027777777777777776,
#  0.020408163265306121,
#  0.015625,
#  0.012345679012345678,
#  0.01,
#  0.0082644628099173556,
#  0.0069444444444444441,
#  0.0059171597633136093,
#  0.0051020408163265302,
#  0.0044444444444444444,
#  0.00390625,
#  0.0034602076124567475,
#  0.0030864197530864196,
#  0.0027700831024930748,
#  0.0025000000000000001,
#  0.0022675736961451248,
#  0.0020661157024793389,
#  0.001890359168241966,
#  0.001736111111111111,
#  0.0016000000000000001,
#  0.0014792899408284023,
#  0.0013717421124828531,
#  0.0012755102040816326,
#  0.0011890606420927466,
#  0.0011111111111111111,
#  0.0010405827263267431,
#  0.0009765625,
#  0.00091827364554637281,
#  0.00086505190311418688,
#  0.00081632653061224493,
#  0.0007716049382716049,
#  0.00073046018991964939,
#  0.0006925207756232687,
#  0.00065746219592373442,
#  0.00062500000000000001,
#  0.00059488399762046404,
#  0.00056689342403628119,
# ...

# %%
meddle = len(square(j)) / 2
meddle
# Out:
# 1070.0

# %%
meddle = len(square(i)) / 2
meddle
# Out:
# 1070.0

# %%
square(j)[1070]
# Out:
# 8.7180841835644936e-07

# %%
square(i)[1070]
# Out:
# 8.734387282732116e-07

# %%
j[1069]
# Out:
# 1070

# %%
i[1070]
# Out:
# 1070

# %%
plt.title('rank distribution i and j ')
plt.ylabel('i')
plt.xlabel('j')
plt.plot(square(i), square(j))

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (1070**2) / (x)

myu = integrate.quad(computePi, 1, 1070**2)

# %%
# 結果にはintegrated value and estimation error
myu
# Out:
# (15972302.811088644, 0.013555658885252342)

# %%
(1070**2) * log(1070**2)
# Out:
# 15972302.811088638

# %% [markdown]
# # just try square¶

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (8.734387282732116e-07**2) / (x)

myu = integrate.quad(computePi, 1, (8.734387282732116e-07**2))

# %%
myu
# Out:
# (-6.412726268833555e-12, 7.1334977358678375e-12)

# %%
p_values
# Out:
# [0.7450624220686257,
#  0.08499808880037016,
#  0.08502024291497975,
#  0.03657742590759936,
#  0.03328988963451833,
#  0.09686206715909686,
#  0.0323216044408631,
#  0.030231459612659425,
#  0.1547996976568405,
#  0.05065359477124183,
#  0.155,
#  0.11244377811094453,
#  0.01948358557618231,
#  0.02557077625570776,
#  0.013209393346379647,
#  0.027097446586763933,
#  0.01788785689714482,
#  0.023528968866468398,
#  0.018880293693457454,
#  0.030347734457323496,
#  0.01752670650009053,
#  0.018623980298599352,
#  0.06906392694063926,
#  0.03554380553719615,
#  0.027270678386297046,
#  0.025875726104559058,
#  0.015391595700125646,
#  0.09612031386224934,
#  0.022042210833746623,
#  0.013919413919413919,
#  0.007358936725375081,
#  0.022471210706504825,
#  0.046264257336921695,
#  0.016081000595592615,
#  0.011679884643114636,
#  0.016317485898468976,
#  0.021756647864625302,
#  0.042352941176470586,
#  0.0670807453416149,
#  0.012346733883026444,
#  0.006540829259460438,
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.title('p value distribution')
plt.ylabel('p value')
plt.xlabel('rank of p value')
plt.show()

# %%
len(p_values)/2
# Out:
# 500.0

# %%
p_values[500]
# Out:
# 0.015318627450980392

# %% [markdown]
# # just try square

# %% [markdown]
# # Change the square of s_values 1/2

# %%
math.pow(27, (1.0/3.0))
# Out:
# 3.0

# %%
count = 0
s_values_1_2 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (1.0/2.0))
    s_values_1_2.append(s)
    
    count += 1
    
    if count == 1000:
        break

# %%
s_values_1_2
# Out:
# [0.8631699844576535,
#  0.29154431704351597,
#  0.2915823089883537,
#  0.1912522572614487,
#  0.18245517157515245,
#  0.3112267134406956,
#  0.17978210267115885,
#  0.17387196327372456,
#  0.3934459272337693,
#  0.2250635349656666,
#  0.39370039370059057,
#  0.33532637550742195,
#  0.13958361499897584,
#  0.15990864972135735,
#  0.11493212495372931,
#  0.16461302070846018,
#  0.13374549299750188,
#  0.15339155409105285,
#  0.13740558101277203,
#  0.17420601154186238,
#  0.13238846815372754,
#  0.1364697046915518,
#  0.26280016541212314,
#  0.18853064880065562,
#  0.1651383613407165,
#  0.16085933639226246,
#  0.12406286994957696,
#  0.31003276256268364,
#  0.14846619424551377,
#  0.11798056585477931,
#  0.08578424520490392,
#  0.1499040049715311,
#  0.2150912767569194,
#  0.12681088516208935,
#  0.10807351499379779,
#  0.1277399150558234,
#  0.14750134868747913,
#  0.20579830217101058,
#  0.25899950838102936,
#  0.11111585792777934,
#  0.08087539341147243,
#  0.12737745814145468,
# ...

# %%
max(s_values_1_2)
# Out:
# 0.8631699844576535

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_values_1_2)

plt.ylabel('s value')
plt.xlabel('words (Descending order of word pairs rank from)')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_values_1_2, reverse=True))

plt.title('')
plt.ylabel('s value')
plt.xlabel('rank of s value')
plt.show()

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_values_1_2, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('s value(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_1_2, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_1_2)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value (1/2 power)')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %% [markdown]
# # 1/3

# %%
count = 0
s_values_1_3 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (1.0/3.0))
    s_values_1_3.append(s)
    
    count += 1
    
    if count == 1000:
        break

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_values_1_3, reverse=True))

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_1_3, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_1_3)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value (1/3 power)')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %% [markdown]
# # 2/3

# %%
count = 0
s_values_1_2 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (1.0/2.0))
    s_values_1_2.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_1_2, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_1_2)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value (1/2 power)')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
count = 0
s_values_1_3 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (1.0/3.0))
    s_values_1_3.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_1_3, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_1_3)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
count = 0
s_values_2_3 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (2.0/3.0))
    s_values_2_3.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_2_3, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_2_3)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)

ax.set_title('The logarithmic graph of rank and s value (2/3 power)')
ax.set_xlabel('Log scaled rank of s value')
ax.set_ylabel('Log scaled s value')
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
