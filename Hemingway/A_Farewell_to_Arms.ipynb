# %%
# https://biblio.wiki/wiki/Casino_Royale
import nltk
from nltk.corpus import stopwords
import math
# %matplotlib inline

raw1 = open('A_Farewell_to_Arms.txt ').read()

# %%
raw1
# Out:
# 'In the late summer of that year we lived in a house in a village that looked across the river and the plain to the mountains. In the bed of the river there were pebbles and boulders, dry and white in the sun, and the water was clear and swiftly moving and blue in the channels. Troops went by the house and down the road and the dust they raised powdered the leaves of the trees. The trunks of the trees too were dusty and the leaves fell early that year and we saw the troops marching along the road and the dust rising and leaves, stirred by the breeze, falling and the soldiers marching and afterward the road bare and white except for the leaves.\n\nThe plain was rich with crops; there were many orchards of fruit trees and beyond the plain the mountains were brown and bare. There was fighting in the mountains and at night we could see the flashes from the artillery. In the dark it was like summer lightning, but the nights were cool and there was not the feeling of a storm coming.\n\nSometimes in the dark we heard the troops marching under the window and guns going past pulled by motor-tractors. There was much traffic at night and many mules on the roads with boxes of ammunition on each side of their pack-saddles and gray motor trucks that carried men, and other trucks with loads covered with canvas that moved slower in the traffic. There were big guns too that passed in the day drawn by tractors, the long barrels of the guns covered with green branches and green leafy branches and vines laid over the tractors. To the north we could look across a valley and see a forest of chestnut trees and behind it another mountain on this side of the river. There was fighting for that mountain too, but it was not successful, and in the fall when the rains came the leaves all fell from the chestnut trees and the branches were bare and the trunks black with rain. The vineyards were thin and bare-branched too and all the country wet and brown and dead with the autumn. There were mists over the river and clouds on the mountain and the trucks splashed mud on the road and the troops were muddy and wet in their capes; their rifles were wet and under their capes the two leather cartridge-boxes on the front of the belts, gray leather boxes heavy with the packs of clips of thin, long 6.5 mm. cartridges, bulged forward under the capes so that the men, passing on the road, marched as though they were six months gone with child.\n\nThere were small gray motor cars that passed going very fast; usually there was an officer on the seat with the driver and more officers in the back seat. They splashed more mud than the camions even and if one of the officers in the back was very small and sitting between two generals, he himself so small that you could not see his face but only the top of his cap and his narrow back, and if the car went especially fast it was probably the King. He lived in Udine and came out in this way nearly every day to see how things were going, and things went very badly.\n\nAt the start of the winter came the permanent rain and with the rain came the cholera. But it was checked and in the end only seven thousand died of it in the army.\n\n2\nThe next year there were many victories. The mountain that was beyond the valley and the hillside where the chestnut forest grew was captured and there were victories beyond the plain on the plateau to the south and we crossed the river in August and lived in a house in Gorizia that had a fountain and many thick shady trees in a walled garden and a wistaria vine purple on the side of the house. Now the fighting was in the next mountains beyond and was not a mile away. The town was very nice and our house was very fine. The river ran behind us and the town had been captured very handsomely but the mountains beyond it could not be taken and I was very glad the Austrians seemed to want to come back to the town some time, if the war should end, because they did not bombard it to destroy it but only a lit ...

# %%
tokens1 = nltk.word_tokenize(raw1)
sentence1 = nltk.sent_tokenize(raw1)

# %%
#The number of token
len(tokens1)
# Out:
# 86917

# %%
len(sentence1)
# Out:
# 5529

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer() #to make base form

tokens_low = [w.lower() for w in tokens1]

#The number of sort of words
len(set(tokens_low))

#複数形や過去形を別の単語としてカウントしてしまっているため，実際の異なり語数はさらに少ない
# Out:
# 5185

# %%
print (len(set(tokens_low))/len(tokens1))
# Out:
# 0.05965461302161833

# %%
list1 = [tokens1]

text = []
for i in list1:
    text.append(nltk.Text(i))
    
text
# Out:
# [<Text: In the late summer of that year we...>]

# %%
freq_list = []
for i in text:
    freq_list.append(nltk.FreqDist(w.lower() for w in i))

stopwords = nltk.corpus.stopwords.words('english')
symbols = ["'", '"', '`', '.', ',', '-', '!', '?', ':', ';', '(', ')', '...', "'s", '’', '”', '“','–','—', '…', '*' ,'``', "''",'--','mr.',"n't", 'dr.','sir', '‘', 'mr', 'm.' ]

# %%
freq_list
# Out:
# [FreqDist({'in': 1043,
#            'the': 4998,
#            'late': 13,
#            'summer': 14,
#            'of': 914,
#            'that': 566,
#            'year': 14,
#            'we': 832,
#            'lived': 15,
#            'a': 1366,
#            'house': 30,
#            'village': 9,
#            'looked': 189,
#            'across': 72,
#            'river': 64,
#            'and': 2453,
#            'plain': 23,
#            'to': 1424,
#            'mountains': 55,
#            '.': 5357,
#            'bed': 85,
#            'there': 462,
#            'were': 504,
#            'pebbles': 2,
#            'boulders': 1,
#            ',': 2424,
#            'dry': 14,
#            'white': 28,
#            'sun': 22,
#            'water': 55,
#            'was': 1152,
#            'clear': 24,
#            'swiftly': 5,
#            'moving': 14,
#            'blue': 3,
#            'channels': 3,
#            'troops': 27,
#            'went': 293,
#            'by': 107,
#            'down': 300,
#            'road': 169,
#            'dust': 10,
#            'they': 552,
#            'raised': 2,
#            'powdered': 1,
#            'leaves': 9,
#            'trees': 56,
#            'trunks': 3,
#            'too': 113,
#            'dusty': 5,
#            'fell': 11,
#            'early': 16,
#            'saw': 110,
#            'marching': 5,
#            'along': 97,
#            'rising': 6,
#            'stirred': 1,
#            'breeze': 4,
#            'falling': 16,
#            'soldiers': 9,
#            'afterward': 15,
#            'bare': 20,
#            'except': 20,
#            'for': 287,
#            'rich': 1,
#            'with': 486,
#            'crops': 1,
#            ';': 59,
#            'many': 62,
#            'orchards': 1,
#            'fruit': 1,
#            'beyond': 37,
#            'brown': 11,
#            'fighting': 15,
#            'at': 398,
#            'night': 79,
#            'could': 219,
#            'see': 212,
#            'flashes': 3,
#            'from': 179,
#            'artillery': 7,
#            'dark': 79,
#            'it': 1237,
#            'like': 177,
#            'lightning': 1,
#            'but': 370,
#            'nights': 9,
#            'cool': 10,
#            'not': 530,
#            'feeling': 20,
#            'storm': 9,
#            'coming': 53,
#            'sometimes': 37,
#            'heard': 48,
#            'under': 71,
#            'window': 57,
#            'guns': 25,
#            'going': 123,
#            'past': 15,
#            'pulled': 36,
#            'motor-tractors': 1,
#            'much': 83,
#            'traffic': 6,
#            'mules': 5,
#            'on': 613,
#            'roads': 19,
#            'boxes': 4,
#            'ammunition': 1,
#            'each': 31,
#            'side': 79,
#            'their': 83,
#            'pack-saddles': 1,
#            'gray': 22,
#            'motor': 14,
#            'trucks': 13,
#            'carried': 16,
#            'men': 44,
#            'other': 106,
#            'loads': 1,
#            'covered': 11,
#            'canvas': 18,
#            'moved': 19,
#            'slower': 2,
#            'big': 66,
#            'passed': 28,
#            'day': 37,
#            'drawn': 2,
#            'tractors': 2,
#            'long': 97,
#            'barrels': 1,
#            'green': 8,
#            'branches': 10,
#            'leafy': 1,
#            'vines': 5,
#            'laid': 5,
#            'over': 157,
#            'north': 22,
#            'look': 45,
#            'valley': 13,
#            'forest': 12,
#            'chestnut': 5,
#            'behind': 36,
#            'another': 65,
#            'mountain': 35,
#            'this': 150,
#            'successful': 2,
#            'fall': 17,
#            'when': 206,
#            'rains': 3,
#            'came': 185,
#            'all': 395,
#            'black': 11,
#            'rain': 87,
#            'vineyards': 4,
#            'thin': 21,
#            'bare-branched': 1,
#            'country': 39,
#            'wet': 48,
#            'dead': 23,
#            'autumn': 2,
#            'mists': 1,
#            'clouds': 8,
#            'splashed': 2,
#            'mud': 11,
#            'muddy': 13,
#            'capes': 4,
#            'rifles': 6,
#            'two': 130,
#            'leather': 6,
#            'cartridge-boxes': 1,
#            'front': 48,
#            'belts': 2,
#            'heavy': 7,
#            'packs': 2,
#            'clips': 2,
#            '6.5': 1,
#            'mm': 1,
#            'cartridges': 1,
#            'bulged': 1,
#            'forward': 17,
#            'so': 191,
#            'passing': 9,
#            'marched': 2,
#            'as': 194,
#            'though': 22,
#            'six': 4,
#            'months': 4,
#            'gone': 49,
#            'child': 11,
#            'small': 30,
#            'cars': 51,
#            'very': 301,
#            'fast': 22,
#            'usually': 9,
#            'an': 120,
#            'officer': 18,
#            'seat': 24,
#            'driver': 21,
#            'more': 66,
#            'officers': 37,
#            'back': 206,
#            'than': 42,
#            'camions': 3,
#            'even': 28,
#            'if': 208,
#            'one': 230,
#            'sitting': 28,
#            'between': 33,
#            'generals': 1,
#            'he': 696,
#            'himself': 5,
#            'you': 1414,
#            'his': 228,
#            'face': 50,
#            'only': 77,
#            'top': 20,
#            'cap': 11,
#            'narrow': 20,
#            'car': 57,
#            'especially': 4,
#            'probably': 21,
#            'king': 7,
#            'udine': 19,
#            'out': 338,
#            'way': 78,
#            'nearly': 17,
#            'every': 35,
#            'how': 122,
#            'things': 56,
#            'badly': 14,
#            'start': 29,
#            'winter': 26,
#            'permanent': 2,
#            'cholera': 1,
#            'checked': 1,
#            'end': 29,
#            'seven': 6,
#            'thousand': 3,
#            'died': 6,
#            'army': 24,
#            '2': 1,
#            'next': 25,
#            'victories': 4,
#            'hillside': 3,
#            'where': 169,
#            'grew': 4,
#            'captured': 4,
#            'plateau': 5,
#            'south': 15,
#            'crossed': 19,
#            'august': 1,
#            'gorizia': 9,
#            'had': 420,
#            'fountain': 3,
#            'thick': 7,
#            'shady': 1,
#            'walled': 1,
#            'garden': 16,
#            'wistaria': 1,
#            'vine': 2,
#            'purple': 1,
#            'now': 159,
#            'mile': 7,
#            'away': 102,
#            'town': 51,
#            'nice': 28,
#            'our': 54,
#            'fine': 63,
#            'ran': 19,
#            'us': 105,
#            'been': 145,
#            'handsomely': 1,
#            'be': 331,
#            'taken': 19,
#            'i': 2969,
#            'glad': 24,
#            'austrians': 27,
#            'seemed': 29,
#            'want': 145,
#            'come': 163,
#            'some': 133,
#            'time': 101,
#            'war': 78,
#            'should': 78,
#            'because': 57,
#            'did': 211,
#            'bombard': 1,
#            'destroy': 1,
#            'little': 127,
#            'military': 6,
#            'people': 42,
#            'hospitals': 9,
#            'cafés': 2,
#            'up': 354,
#            'streets': 6,
#            'bawdy': 2,
#            'houses': 21,
#            'shell-marked': 1,
#            'iron': 7,
#            'railway': 17,
#            'bridge': 51,
#            'smashed': 8,
#            'tunnel': 3,
#            'around': 48,
#            'square': 7,
#            'avenue': 1,
#            'led': 11,
#            'these': 14,
#            'being': 26,
#            'girls': 36,
#            'seeing': 12,
#            'necked': 1,
#            'body': 6,
#            'beard': 12,
#            'goat': 2,
#            '’': 1668,
#            's': 415,
#            'chin': 2,
#            'tuft': 1,
#            'sudden': 3,
#            'interiors': 1,
#            'lost': 11,
#            'wall': 30,
#            'through': 101,
#            'shelling': 6,
#            'plaster': 2,
#            'rubble': 3,
#            'gardens': 3,
#            'street': 24,
#            'whole': 13,
#            'thing': 29,
#            'well': 56,
#            'carso': 3,
#            'made': 47,
#            'different': 10,
#            'last': 12,
#            'changed': 3,
#            'oak': 2,
#            'into': 120,
#            'stumps': 3,
#            'broken': 15,
#            'ground': 10,
#            'torn': 3,
#            'cloud': 3,
#            'dull': 6,
#            'yellow': 5,
#            'then': 230,
#            'everything': 25,
#            'sky': 6,
#            'suddenly': 13,
#            'snow': 38,
#            'slanted': 1,
#            'wind': 33,
#            'projected': 1,
#            'paths': 4,
#            'latrines': 1,
#            'trenches': 3,
#            'later': 19,
#            'below': 21,
#            'watched': 36,
#            'looking': 56,
#            'sat': 83,
#            'friend': 10,
#            'glasses': 10,
#            'drinking': 4,
#            'bottle': 29,
#            'asti': 1,
#            'slowly': 16,
#            'heavily': 4,
#            'knew': 55,
#            'none': 6,
#            'left': 46,
#            'my': 294,
#            'priest': 84,
#            'mess': 20,
#            'walking': 14,
#            'carefully': 5,
#            'slush': 4,
#            'pounded': 1,
#            'attract': 1,
#            'attention': 3,
#            'smiled': 44,
#            'motioned': 4,
#            'him': 182,
#            'shook': 28,
#            'head': 57,
#            'after': 86,
#            'spaghetti': 7,
#            'course': 18,
#            'which': 18,
#            'ate': 19,
#            'quickly': 9,
#            'seriously': 1,
#            'lifting': 2,
#            'fork': 1,
#            'until': 31,
#            'loose': 3,
#            'strands': 2,
#            'hung': 12,
#            'lowering': 1,
#            'mouth': 7,
#            'or': 68,
#            'else': 19,
#            'using': 4,
#            'continuous': 1,
#            'lift': 4,
#            'sucking': 2,
#            'helping': 1,
#            'ourselves': 1,
#            'wine': 46,
#            'grass-covered': 1,
#            'gallon': 1,
#            'flask': 2,
#            'swung': 5,
#            'metal': 8,
#            'cradle': 1,
#            'neck': 15,
#            'forefinger': 1,
#            'red': 17,
#            'tannic': 1,
#            'lovely': 35,
#            'poured': 13,
#            'glass': 42,
#            'held': 53,
#            'same': 21,
#            'hand': 58,
#            'captain': 26,
#            'commenced': 10,
#            'picking': 1,
#            'young': 13,
#            'blushed': 3,
#            'easily': 10,
#            'wore': 24,
#            'uniform': 14,
#            'rest': 6,
#            'cross': 17,
#            'velvet': 1,
#            'above': 24,
#            'breast': 2,
#            'pocket': 7,
#            'tunic': 7,
#            'spoke': 13,
#            'pidgin': 2,
#            'italian': 39,
#            'doubtful': 2,
#            'benefit': 1,
#            'order': 11,
#            'might': 35,
#            'understand': 12,
#            'perfectly': 3,
#            'nothing': 65,
#            '“': 3185,
#            'to-day': 5,
#            '”': 3185,
#            'said': 944,
#            'me': 429,
#            'baited': 1,
#            'often': 8,
#            'true': 10,
#            '?': 814,
#            'asked': 111,
#            'girls.': 4,
#            'no': 268,
#            'amused': 1,
#            'baiting': 2,
#            'never': 73,
#            'explained': 4,
#            'took': 86,
#            'filled': 10,
#            'eyes': 19,
#            'losing': 6,
#            'sight': 27,
#            'five': 14,
#            'against': 38,
#            'one.': 10,
#            'table': 41,
#            'laughed': 22,
#            'gesture': 1,
#            'loudly': 1,
#            'accepted': 1,
#            'joke': 12,
#            'pope': 1,
#            'wants': 8,
#            'win': 6,
#            'major': 69,
#            'loves': 2,
#            'franz': 1,
#            'joseph': 1,
#            'money': 23,
#            'comes': 10,
#            'am': 73,
#            'atheist.': 1,
#            'ever': 32,
#            'read': 23,
#            'pig': 1,
#            'lieutenant': 20,
#            'will': 235,
#            'get': 198,
#            'copy': 3,
#            'faith.': 1,
#            'is': 352,
#            'filthy': 2,
#            'vile': 1,
#            'book': 2,
#            'do': 254,
#            'really': 42,
#            'it.': 45,
#            'valuable': 2,
#            'tells': 1,
#            'about': 158,
#            'those': 21,
#            'priests': 1,
#            'candle-light': 2,
#            'don': 260,
#            't': 585,
#            'thinking': 19,
#            'are': 269,
#            'atheists': 1,
#            'believe': 40,
#            'free': 2,
#            'masons': 2,
#            'however.': 1,
#            'noble': 2,
#            'organization.': 1,
#            'door': 70,
#            'opened': 30,
#            'offensive': 11,
#            'has': 34,
#            'certainly': 5,
#            'go': 319,
#            'leave': 30,
#            'rome': 12,
#            'naples': 3,
#            'sicily—': 1,
#            'visit': 2,
#            'amalfi': 3,
#            'write': 12,
#            'cards': 4,
#            'family': 9,
#            'love': 49,
#            'son.': 1,
#            'palermo.': 1,
#            'ought': 28,
#            'capri.': 2,
#            'would': 254,
#            'abruzzi': 9,
#            'capracotta': 2,
#            'listen': 7,
#            'talk': 42,
#            'here': 111,
#            'doesn': 24,
#            'peasants': 9,
#            'let': 90,
#            'centres': 1,
#            'culture': 1,
#            'civilization.': 1,
#            'have': 333,
#            'give': 48,
#            'addresses': 1,
#            'places': 9,
#            'beautiful': 26,
#            'girls—accompanied': 1,
#            'mothers': 1,
#            'ha': 4,
#            '!': 56,
#            'spread': 7,
#            'open': 35,
#            'thumb': 6,
#            'fingers': 7,
#            'outspread': 1,
#            'make': 54,
#            'shadow': 6,
#            'pictures': 1,
#            'again': 77,
#            'pointed': 10,
#            'touched': 9,
#            'finger': 11,
#            'its': 8,
#            'shadows': 2,
#            'started': 71,
#            'upright': 1,
#            'named': 2,
#            'four': 20,
#            'soto-tenente': 2,
#            '(': 7,
#            ')': 7,
#            'tenente': 58,
#            'first': 47,
#            'capitano': 2,
#            'maggiore': 2,
#            'tenentecolonello': 1,
#            'soto-colonello': 1,
#            'having': 15,
#            'great': 34,
#            'success': 3,
#            'games': 4,
#            'shouted': 11,
#            'must': 52,
#            'once': 23,
#            'show': 11,
#            'bring': 28,
#            'phonograph.': 1,
#            'good': 144,
#            'opera': 2,
#            'disks.': 1,
#            'caruso.': 1,
#            'caruso': 1,
#            'bellows.': 1,
#            'wish': 29,
#            'bellow': 1,
#            'bellows': 2,
#            'say': 66,
#            'others': 25,
#            'shouting': 1,
#            'hunting': 4,
#            'cold': 37,
#            'stay': 39,
#            'father': 19,
#            'famous': 1,
#            'hunter.': 1,
#            'whorehouse': 2,
#            'before': 53,
#            'shuts.': 1,
#            'good-night': 21,
#            '3': 1,
#            'still': 50,
#            'spring': 13,
#            'fields': 18,
#            'shoots': 1,
#            'sea': 4,
#            'hill': 10,
#            'old': 42,
#            'castle': 2,
#            'cup': 8,
#            'hills': 10,
#            'slopes': 2,
#            'new': 25,
#            'met': 9,
#            'british': 15,
#            'women': 6,
#            'few': 18,
#            'hit': 16,
#            'shell': 10,
#            'fire': 24,
#            'jt': 1,
#            'warm': 15,
#            'walked': 46,
#            'alleyway': 1,
#            'warmed': 3,
#            'found': 20,
#            'soldier': 26,
#            'bench': 6,
#            'outside': 64,
#            'ambulance': 15,
#            'waiting': 6,
#            'inside': 32,
#            'smell': 7,
#            'marble': 7,
#            'floors': 3,
#            'hospital': 42,
#            'room': 88,
#            'desk': 7,
#            'sunlight': 6,
#            'know': 139,
#            'whether': 9,
#            'report': 9,
#            'upstairs': 9,
#            'clean': 13,
#            'decided': 4,
#            'shared': 1,
#            'rinaldi': 97,
#            'courtyard': 6,
#            'blankets': 1,
#            'gas': 11,
#            'mask': 22,
#            'oblong': 1,
#            'tin': 4,
#            'can': 173,
#            'steel': 7,
#            'helmet': 4,
#            'peg': 1,
#            'foot': 13,
#            'flat': 16,
#            'trunk': 5,
#            'boots': 12,
#            'shiny': 3,
#            'oil': 4,
#            'austrian': 15,
#            'sniper': 1,
#            'rifle': 5,
#            'blued': 1,
#            'octagon': 1,
#            'barrel': 3,
#            'walnut': 1,
#            'cheek-fitted': 1,
#            'schutzen': 1,
#            'stock': 2,
#            'beds': 9,
#            'telescope': 1,
#            'fitted': 1,
#            'remembered': 6,
#            'locked': 5,
#            'lay': 37,
#            'asleep': 11,
#            'woke': 16,
#            'ciaou': 7,
#            'what': 240,
#            'kind': 8,
#            'magnificent.': 1,
#            'hands': 26,
#            'put': 101,
#            'arm': 24,
#            'kissed': 16,
#            'oughf': 1,
#            're': 120,
#            'dirty': 11,
#            'wash.': 2,
#            'tell': 73,
#            'once.': 3,
#            'everywhere': 4,
#            'milan': 20,
#            'florence': 1,
#            'villa': 22,
#            'san': 11,
#            'giovanni': 1,
#            'messina': 1,
#            'taormina—': 1,
#            'time-table': 1,
#            'any': 114,
#            'adventures': 2,
#            'yes.': 38,
#            'milano': 1,
#            'firenze': 1,
#            'roma': 2,
#            'napoli—': 1,
#            'enough': 19,
#            'best.': 2,
#            'milano.': 1,
#            'meet': 3,
#            'her': 192,
#            'cova': 3,
#            'feel': 52,
#            'before.': 3,
#            'wonderful.': 2,
#            'afternoon': 10,
#            'english': 37,
#            'miss': 37,
#            'barkley': 29,
#            'take': 95,
#            'call': 15,
#            'marry': 6,
#            'barkley.': 3,
#            'washed': 8,
#            'anybody': 8,
#            'work': 27,
#            'since': 5,
#            'frostbites': 1,
#            'chilblains': 1,
#            'jaundice': 2,
#            'gonorrhea': 1,
#            'self-inflicted': 2,
#            'wounds': 8,
#            'pneumonia': 1,
#            'hard': 37,
#            'soft': 6,
#            'chancres': 1,
#            'week': 3,
#            'gets': 1,
#            'wounded': 31,
#            'rock': 4,
#            'fragments': 4,
#            'real': 8,
#            'starts': 2,
#            'perhaps': 15,
#            'think': 115,
#            'right': 117,
#            'barkley—after': 1,
#            'absolutely': 1,
#            'basin': 7,
#            'full': 17,
#            'to-night': 8,
#            'sleep': 48,
#            'fresh': 2,
#            'off': 116,
#            'shirt': 9,
#            'while': 72,
#            'rubbed': 3,
#            'myself': 25,
#            'towel': 1,
#            'lying': 19,
#            'closed': 12,
#            'good-looking': 2,
#            'age': 4,
#            'loved': 8,
#            'surgeon': 2,
#            'friends': 7,
#            'loan': 2,
#            'fifty': 4,
#            'lire.': 3,
#            'dried': 6,
#            'pocket-book': 3,
#            'hanging': 2,
#            'note': 8,
#            'folded': 5,
#            'without': 22,
#            'slid': 2,
#            'breeches': 3,
#            'impression': 2,
#            'man': 57,
#            'sufficient': 1,
#            'wealth': 1,
#            'financial': 1,
#            'protector.': 1,
#            'hell': 19,
#            'disappointed': 3,
#            'hurt': 15,
#            'written': 4,
#            'preparations': 1,
#            'felt': 53,
#            'why': 58,
#            'wanted': 34,
#            'tried': 16,
#            'explain': 2,
#            'finally': 17,
#            'understood': 7,
#            'almost': 24,
#            'drunk': 22,
#            'coffee': 19,
#            'strega': 2,
#            'winefully': 1,
#            'such': 17,
#            'talking': 17,
#            'argued': 2,
#            'place': 57,
#            'frozen': 2,
#            'powdery': 1,
#            'hare-tracks': 1,
#            'hats': 6,
#            'called': 17,
#            'lord': 3,
#            'smoke': 8,
#            'whirled': 1,
#            'needed': 5,
#            'stop': 40,
#            'strange': 14,
#            'excitement': 1,
#            'waking': 4,
#            'knowing': 2,
#            'who': 73,
#            'world': 8,
#            'unreal': 2,
#            'exciting': 5,
#            'resume': 1,
#            'unknowing': 1,
#            'caring': 2,
#            'sure': 22,
#            'care': 16,
#            'wake': 13,
#            'morning': 32,
#            'sharp': 6,
#            'dispute': 1,
#            'cost': 3,
#            'pleasant': 17,
#            'fond': 3,
#            'breakfast': 20,
#            'lunch': 19,
#            'niceness': 1,
#            'always': 54,
#            'starting': 7,
#            'difference': 12,
#            'better': 58,
#            'unless': 5,
#            'tastes': 1,
#            'alike': 6,
#            'known': 4,
#            'learned': 4,
#            'able': 12,
#            'forget': 10,
#            'although': 6,
#            'meantime': 1,
#            'meal': 6,
#            'finished': 10,
#            'argument': 1,
#            'stopped': 46,
#            'happy': 19,
#            'listened': 8,
#            'attack': 28,
#            'suppose': 14,
#            'attack.': 4,
#            'shall': 2,
#            'nodded': 6,
#            'alone': 24,
#            'right.': 46,
#            'anything': 69,
#            'anyway': 18,
#            'got': 79,
#            '4': 1,
#            'battery': 4,
#            'gravel': 4,
#            'moist': 1,
#            'grass': 2,
#            'dew': 1,
#            'fired': 10,
#            'twice': 6,
#            'air': 12,
#            'blow': 9,
#            'pajamas': 1,
#            'flap': 1,
#            'evidently': 3,
#            'firing': 11,
#            'directly': 2,
#            'nuisance': 2,
#            'them': 209,
#            'comfort': 1,
#            'bigger': 3,
#            'truck': 6,
#            'dressed': 11,
#            'downstairs': 9,
#            'kitchen': 8,
#            'garage': 3,
#            'ten': 7,
#            'lined': 6,
#            'shed': 2,
#            'top-heavy': 1,
#            'blunt-nosed': 1,
#            'ambulances': 8,
#            'painted': 2,
#            'built': 3,
#            'moving-vans': 2,
#            'mechanics': 7,
#            'working': 12,
#            'yard': 3,
#            'three': 45,
#            'dressing': 21,
#            'stations': 4,
#            'tasked': 1,
#            'signor': 10,
#            'protected': 4,
#            'hill.': 1,
#            'bad': 50,
#            'machine': 3,
#            'march.': 1,
#            'permission': 2,
#            'wiped': 9,
#            'jumper': 1,
#            'grinned': 2,
#            'matter': 24,
#            'another.': 1,
#            'rings.': 1,
#            'disgraced': 1,
#            'empty': 24,
#            'engine': 9,
#            'parts': 3,
#            'moderately': 3,
#            'freshly': 3,
#            'tires': 1,
#            'cuts': 1,
#            'stone': 29,
#            'bruises': 1,
#            'condition': 3,
#            'imagined': 1,
#            'obtainable': 1,
#            'smooth': 7,
#            'functioning': 1,
#            'business': 5,
#            'removing': 1,
#            'sick': 13,
#            'hauling': 3,
#            'clearing': 4,
#            'station': 35,
#            'distributing': 1,
#            'papers': 30,
#            'depended': 1,
#            'considerable': 1,
#            'extent': 1,
#            'trouble': 17,
#            'getting': 19,
#            'sergeant': 13,
#            'mechanic': 1,
#            'tenente.': 13,
#            'gasoline': 1,
#            'park': 2,
#            'place.': 5,
#            'drank': 28,
#            'bowl': 2,
#            'pale': 3,
#            'sweet': 13,
#            'condensed': 1,
#            'milk': 3,
#            'beginning': 6,
#            'dryness': 1,
#            'nose': 6,
#            'meant': 5,
#            'hot': 25,
#            'visited': 1,
#            'posts': 6,
#            'run': 6,
#            'division': 1,
#            'worked': 13,
#            'told': 28,
#            ...})]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#順位チェック
sorted(freq_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('said', 944),
#  ('go', 319),
#  ('went', 293),
#  ('would', 254),
#  ('one', 230),
#  ('could', 219),
#  ('see', 212),
#  ('catherine', 209),
#  ('back', 206),
#  ('get', 198),
#  ('looked', 189),
#  ('came', 185),
#  ('like', 177),
#  ('road', 169),
#  ('come', 163),
#  ('want', 145),
#  ('good', 144),
#  ('know', 139),
#  ('two', 130),
#  ('little', 127),
#  ('going', 123),
#  ('right', 117),
#  ('think', 115),
#  ('asked', 111),
#  ('saw', 110),
#  ('us', 105),
#  ('yes', 105),
#  ('away', 102),
#  ('time', 101),
#  ('put', 101),
#  ('along', 97),
#  ('long', 97),
#  ('rinaldi', 97),
#  ('take', 95),
#  ('let', 90),
#  ('room', 88),
#  ('rain', 87),
#  ('took', 86),
#  ('bed', 85),
#  ('priest', 84),
#  ('much', 83),
#  ('sat', 83),
#  ('darling', 82),
#  ('piani', 80),
#  ('night', 79),
#  ('dark', 79),
#  ('side', 79),
#  ('got', 79),
#  ('way', 78),
#  ('war', 78),
#  ('something', 76),
#  ('never', 73),
#  ('tell', 73),
#  ('bonello', 73),
#  ('across', 72),
#  ('started', 71),
#  ('door', 70),
#  ('major', 69),
#  ('anything', 69),
#  ('big', 66),
#  ('say', 66),
#  ('another', 65),
#  ('nothing', 65),
#  ('thought', 65),
#  ('river', 64),
#  ('outside', 64),
#  ('fine', 63),
#  ('oh', 63),
#  ('many', 62),
#  ('hand', 58),
#  ('tenente', 58),
#  ('better', 58),
#  ('doctor', 58),
#  ('aymo', 58),
#  ('window', 57),
#  ('car', 57),
#  ('head', 57),
#  ('man', 57),
#  ('place', 57),
#  ('trees', 56),
#  ('things', 56),
#  ('well', 56),
#  ('looking', 56),
#  ('mountains', 55),
#  ('water', 55),
#  ('knew', 55),
#  ('baby', 55),
#  ('make', 54),
#  ('always', 54),
#  ('drink', 54),
#  ('coming', 53),
#  ('held', 53),
#  ('felt', 53),
#  ('lake', 53),
#  ('must', 52),
#  ('feel', 52),
#  ('tired', 52),
#  ('cars', 51),
#  ('town', 51),
#  ('bridge', 51),
#  ('face', 50),
#  ('still', 50),
#  ('bad', 50),
#  ('toward', 50),
#  ('gone', 49),
#  ('love', 49),
#  ('die', 49),
#  ('heard', 48),
#  ('wet', 48),
#  ('front', 48),
#  ('around', 48),
#  ('give', 48),
#  ('sleep', 48),
#  ('turned', 48),
#  ('line', 48),
#  ('made', 47),
#  ('first', 47),
#  ('stood', 47),
#  ('you.', 47),
#  ('left', 46),
#  ('wine', 46),
#  ('walked', 46),
#  ('stopped', 46),
#  ('right.', 46),
#  ('look', 45),
#  ('it.', 45),
#  ('three', 45),
#  ('men', 44),
#  ('smiled', 44),
#  ('ahead', 43),
#  ('light', 43),
#  ('people', 42),
#  ('glass', 42),
#  ('really', 42),
#  ('talk', 42),
#  ('old', 42),
#  ('hospital', 42),
#  ('please', 42),
#  ('table', 41),
#  ('nurse', 41),
#  ('believe', 40),
#  ('stop', 40),
#  ('beside', 40),
#  ('country', 39),
#  ('italian', 39),
#  ('stay', 39),
#  ('hall', 39),
#  ('snow', 38),
#  ('yes.', 38),
#  ('brought', 38),
#  ('maybe', 38),
#  ('beyond', 37),
#  ('sometimes', 37),
#  ('day', 37),
#  ('officers', 37),
#  ('cold', 37),
#  ('lay', 37),
#  ('english', 37),
#  ('miss', 37),
#  ('hard', 37),
#  ('close', 37),
#  ('pulled', 36),
#  ('behind', 36),
#  ('girls', 36),
#  ('watched', 36),
#  ('cut', 36),
#  ('boat', 36),
#  ('mountain', 35),
#  ('every', 35),
#  ('lovely', 35),
#  ('might', 35),
#  ('open', 35),
#  ('station', 35),
#  ('floor', 35),
#  ('eat', 35),
#  ('hotel', 35),
#  ('girl', 35),
#  ('great', 34),
#  ('wanted', 34),
#  ('far', 34),
#  ('wind', 33),
#  ('ferguson', 33),
#  ('ever', 32),
#  ('inside', 32),
#  ('morning', 32),
#  ('wounded', 31),
#  ('boy', 31),
#  ('train', 31),
#  ('house', 30),
#  ('small', 30),
#  ('wall', 30),
#  ('opened', 30),
#  ('leave', 30),
#  ('papers', 30),
#  ('afraid', 30),
#  ('me.', 30),
#  ('shore', 30),
#  ('start', 29),
#  ('end', 29),
#  ('seemed', 29),
#  ('thing', 29),
#  ('bottle', 29),
#  ('wish', 29),
#  ('barkley', 29),
#  ('stone', 29),
#  ('quite', 29),
#  ('white', 28),
#  ('passed', 28),
#  ('even', 28),
#  ('sitting', 28),
#  ('nice', 28),
#  ('shook', 28),
#  ('ought', 28),
#  ('bring', 28),
#  ('attack', 28),
#  ('drank', 28),
#  ('told', 28),
#  ('find', 28),
#  ('american', 28),
#  ('high', 28),
#  ('thank', 28),
#  ('troops', 27),
#  ('austrians', 27),
#  ('sight', 27),
#  ('work', 27),
#  ('bank', 27),
#  ('winter', 26),
#  ('captain', 26),
#  ('beautiful', 26),
#  ('soldier', 26),
#  ('hands', 26),
#  ('gave', 26),
#  ('try', 26),
#  ('guns', 25),
#  ('next', 25),
#  ('everything', 25),
#  ('others', 25),
#  ('new', 25),
#  ('hot', 25),
#  ('clear', 24),
#  ('seat', 24),
#  ('army', 24),
#  ('glad', 24),
#  ('street', 24),
#  ('wore', 24),
#  ('fire', 24),
#  ('arm', 24),
#  ('almost', 24),
#  ('alone', 24),
#  ('matter', 24),
#  ('empty', 24),
#  ('no.', 24),
#  ('kept', 24),
#  ('god', 24),
#  ('cheese', 24),
#  ('barman', 24),
#  ('plain', 23),
#  ('dead', 23),
#  ('money', 23),
#  ('read', 23),
#  ('keep', 23),
#  ('holding', 23),
#  ('orderly', 23),
#  ('hear', 23),
#  ('passini', 23),
#  ('sun', 22),
#  ('gray', 22),
#  ('north', 22),
#  ('though', 22),
#  ('fast', 22),
#  ('laughed', 22),
#  ('mask', 22),
#  ('villa', 22),
#  ('without', 22),
#  ('drunk', 22),
#  ('sure', 22),
#  ('germans', 22),
#  ('killed', 22),
#  ('now.', 22),
#  ('hold', 22),
#  ('standing', 22),
#  ('mind', 22),
#  ('soon', 22),
#  ('together', 22),
#  ('retreat', 22),
#  ('thin', 21),
#  ('driver', 21),
#  ('probably', 21),
#  ('houses', 21),
#  ('good-night', 21),
#  ('dressing', 21),
#  ('hair', 21),
#  ('shot', 21),
#  ('walk', 21),
#  ('shut', 21),
#  ('good-by', 21),
#  ('bare', 20),
#  ('except', 20),
#  ('feeling', 20),
#  ('top', 20),
#  ('narrow', 20),
#  ('mess', 20),
#  ('lieutenant', 20),
#  ('four', 20),
#  ('found', 20),
#  ('milan', 20),
#  ('breakfast', 20),
#  ('send', 20),
#  ('main', 20),
#  ('field', 20),
#  ('roads', 19),
#  ('moved', 19),
#  ('udine', 19),
#  ('crossed', 19),
#  ('ran', 19),
#  ('taken', 19),
#  ('later', 19),
#  ('ate', 19),
#  ('else', 19),
#  ('eyes', 19),
#  ('thinking', 19),
#  ('father', 19),
#  ('enough', 19),
#  ('lying', 19),
#  ('hell', 19),
#  ('coffee', 19),
#  ('lunch', 19),
#  ('happy', 19),
#  ('getting', 19),
#  ('splendid', 19),
#  ('married', 19),
#  ('drove', 19),
#  ('live', 19),
#  ('word', 19),
#  ('paper', 19),
#  ('brush', 19),
#  ('woman', 19),
#  ('canvas', 18),
#  ('officer', 18),
#  ('course', 18),
#  ('fields', 18),
#  ('anyway', 18),
#  ('second', 18),
#  ('done', 18),
#  ('life', 18),
#  ('hope', 18),
#  ('onto', 18),
#  ('seen', 18),
#  ('knee', 18),
#  ('carriage', 18),
#  ('embankment', 18),
#  ('cat', 18),
#  ('beer', 18),
#  ('fall', 17),
#  ('forward', 17),
#  ('nearly', 17),
#  ('railway', 17),
#  ('red', 17),
#  ('cross', 17),
#  ('full', 17),
#  ('finally', 17),
#  ('talking', 17),
#  ('called', 17),
#  ('pleasant', 17),
#  ('trouble', 17),
#  ('stairs', 17),
#  ('clock', 17),
#  ('everybody', 17),
#  ('sorry', 17),
#  ('play', 17),
#  ('post', 17),
#  ('drivers', 17),
#  ('clothes', 17),
#  ('manera', 17),
#  ('rowed', 17),
#  ('early', 16),
#  ('falling', 16),
#  ('carried', 16),
#  ('garden', 16),
#  ('slowly', 16),
#  ('hit', 16),
#  ('flat', 16),
#  ('woke', 16),
#  ('kissed', 16),
#  ('tried', 16),
#  ('care', 16),
#  ('much.', 16),
#  ('remember', 16),
#  ('shoulder', 16),
#  ('quiet', 16),
#  ('poor', 16),
#  ('dear', 16),
#  ('climbed', 16),
#  ('here.', 16),
#  ('column', 16),
#  ('woods', 16),
#  ('raining', 16),
#  ('windows', 16),
#  ('bags', 16),
#  ('montreux', 16),
#  ('lived', 15),
#  ('afterward', 15),
#  ('fighting', 15),
#  ('past', 15),
#  ('south', 15),
#  ('broken', 15),
#  ('neck', 15),
#  ('british', 15),
#  ('warm', 15),
#  ('ambulance', 15),
#  ('austrian', 15),
#  ('call', 15),
#  ('perhaps', 15),
#  ('hurt', 15),
#  ('near', 15),
#  ('awfully', 15),
#  ('may', 15),
#  ('home', 15),
#  ('italians', 15),
#  ('carabinieri', 15),
#  ('short', 15),
#  ('need', 15),
#  ('sit', 15),
#  ('watch', 15),
#  ('move', 15),
#  ('point', 15),
#  ('gordini', 15),
#  ('cognac', 15),
#  ('handed', 15),
#  ('legs', 15),
#  ('brandy', 15),
#  ('lights', 15),
#  ('coat', 15),
#  ('wife', 15),
#  ('official', 15),
#  ('summer', 14),
#  ('year', 14),
#  ('dry', 14),
#  ('moving', 14),
#  ('motor', 14),
#  ('badly', 14),
#  ('walking', 14),
#  ('uniform', 14),
#  ('five', 14),
#  ('strange', 14),
#  ('suppose', 14),
#  ('tall', 14),
#  ('know.', 14),
#  ('name', 14),
#  ('edge', 14),
#  ('yet', 14),
#  ('waited', 14),
#  ('war.', 14),
#  ('days', 14),
#  ('chair', 14),
#  ('henry', 14),
#  ('time.', 14),
#  ('again.', 14),
#  ('them.', 14),
#  ('wheels', 14),
#  ('low', 14),
#  ('shoot', 14),
#  ('stretcher', 14),
#  ('nurses', 14),
#  ('row', 14),
#  ('opposite', 14),
#  ('hay', 14),
#  ('bar', 14),
#  ('umbrella', 14),
#  ('late', 13),
#  ('trucks', 13),
#  ('valley', 13),
#  ('muddy', 13),
#  ('whole', 13),
#  ('suddenly', 13),
#  ('poured', 13),
#  ('young', 13),
#  ('spoke', 13),
#  ('spring', 13),
#  ('clean', 13),
#  ('foot', 13),
#  ('wake', 13),
#  ('sick', 13),
#  ('sergeant', 13),
#  ('tenente.', 13),
#  ('sweet', 13),
#  ('worked', 13),
#  ('wait', 13),
#  ('evening', 13),
#  ('drive', 13),
#  ('waved', 13),
#  ('worry', 13),
#  ('mean', 13),
#  ('lie', 13),
#  ('pretty', 13),
#  ('leg', 13),
#  ('christ', 13),
#  ('several', 13),
#  ('lifted', 13),
#  ('bag', 13),
#  ('count', 13),
#  ('grand', 13),
#  ('oars', 13),
#  ('forest', 12),
#  ('seeing', 12),
#  ('beard', 12),
#  ('last', 12),
#  ('hung', 12),
#  ('understand', 12),
#  ('joke', 12),
#  ('rome', 12),
#  ('write', 12),
#  ('boots', 12),
#  ('closed', 12),
#  ('difference', 12),
#  ('able', 12),
#  ('air', 12),
#  ('working', 12),
#  ('worse', 12),
#  ('too.', 12),
#  ('italy', 12),
#  ('wide', 12),
#  ('help', 12),
#  ('picked', 12),
#  ('arrest', 12),
#  ('turn', 12),
#  ('porter', 12),
#  ('talked', 12),
#  ('followed', 12),
#  ('fun', 12),
#  ('makes', 12),
#  ('stepped', 12),
#  ('gino', 12),
#  ('daylight', 12),
#  ('stayed', 12),
#  ('danger', 12),
#  ('switzerland', 12),
#  ('café', 12),
#  ('whiskey', 12),
#  ('fell', 11),
#  ('brown', 11),
#  ('covered', 11),
#  ('black', 11),
#  ('mud', 11),
#  ('child', 11),
#  ('cap', 11),
#  ('led', 11),
#  ('lost', 11),
#  ('order', 11),
#  ('offensive', 11),
#  ('finger', 11),
#  ('shouted', 11),
#  ('show', 11),
#  ('gas', 11),
#  ('asleep', 11),
#  ('dirty', 11),
#  ('san', 11),
#  ('firing', 11),
#  ('dressed', 11),
#  ('up.', 11),
#  ('sent', 11),
#  ('somebody', 11),
#  ('carts', 11),
#  ('out.', 11),
#  ('gotten', 11),
#  ('german', 11),
#  ('plenty', 11),
#  ('helmets', 11),
#  ('become', 11),
#  ('regiment', 11),
#  ('ride', 11),
#  ('happened', 11),
#  ('ask', 11),
#  ('ice', 11),
#  ('saint', 11),
#  ('to-morrow', 11),
#  ('sides', 11),
#  ('hoped', 11),
#  ('eating', 11),
#  ('feet', 11),
#  ('arms', 11),
#  ('straight', 11),
#  ('stomach', 11),
#  ('cape', 11),
#  ('farmhouse', 11),
#  ('sergeants', 11),
#  ('pushed', 11),
#  ('hat', 11),
#  ('greffi', 11),
#  ('dust', 10),
#  ('cool', 10),
#  ('branches', 10),
#  ('different', 10),
#  ('ground', 10),
#  ('friend', 10),
#  ('glasses', 10),
#  ('commenced', 10),
#  ('easily', 10),
#  ('true', 10),
#  ('filled', 10),
#  ('one.', 10),
#  ('comes', 10),
#  ('pointed', 10),
#  ('hill', 10),
#  ('hills', 10),
#  ('shell', 10),
#  ('afternoon', 10),
#  ('forget', 10),
#  ('finished', 10),
#  ('fired', 10),
#  ('signor', 10),
#  ('silly', 10),
#  ('realize', 10),
#  ('pass', 10),
#  ('kiss', 10),
#  ('funny', 10),
#  ('tight', 10),
#  ('pistol', 10),
#  ('driveway', 10),
#  ('medical', 10),
#  ('elevator', 10),
#  ('dropped', 10),
#  ('ridge', 10),
#  ('dugout', 10),
#  ('guard', 10),
#  ('bottles', 10),
#  ('soup', 10),
#  ('hundred', 10),
#  ('ready', 10),
#  ('awake', 10),
#  ('taking', 10),
#  ('ones', 10),
#  ('corridor', 10),
#  ('wonderful', 10),
#  ('corner', 10),
#  ('cheerful', 10),
#  ('expected', 10),
#  ('rowing', 10),
#  ('grow', 10),
#  ('eggs', 10),
#  ('locarno', 10),
#  ('village', 9),
#  ('leaves', 9),
#  ('soldiers', 9),
#  ('nights', 9),
#  ('storm', 9),
#  ('passing', 9),
#  ('usually', 9),
#  ('gorizia', 9),
#  ('hospitals', 9),
#  ('quickly', 9),
#  ('family', 9),
#  ('abruzzi', 9),
#  ('peasants', 9),
#  ('places', 9),
#  ('touched', 9),
#  ('met', 9),
#  ('whether', 9),
#  ('report', 9),
#  ('upstairs', 9),
#  ('beds', 9),
#  ('shirt', 9),
#  ('blow', 9),
#  ('downstairs', 9),
#  ('wiped', 9),
#  ('engine', 9),
#  ('her.', 9),
#  ('stick', 9),
#  ('crack', 9),
#  ('happen', 9),
#  ('either', 9),
#  ('half', 9),
#  ('rather', 9),
#  ('brave', 9),
#  ('us.', 9),
#  ('slapped', 9),
#  ('crying', 9),
#  ('wondered', 9),
#  ('wear', 9),
#  ('darling.', 9),
#  ('night.', 9),
#  ('away.', 9),
#  ('making', 9),
#  ('crossing', 9),
#  ('wished', 9),
#  ('blowing', 9),
#  ('watching', 9),
#  ('deep', 9),
#  ('shoulders', 9),
#  ('so.', 9),
#  ('pieces', 9),
#  ('piece', 9),
#  ('reached', 9),
#  ('stream', 9),
#  ('more.', 9),
#  ('vermouth', 9),
#  ('sister', 9),
#  ('sleepy', 9),
#  ('break', 9),
#  ('stove', 9),
#  ('hungry', 9),
#  ('cry', 9),
#  ('track', 9),
#  ('police', 9),
#  ('stern', 9),
#  ('swiss', 9),
#  ('fergy', 9),
#  ('sport', 9),
#  ('green', 8),
#  ('clouds', 8),
#  ('smashed', 8),
#  ('metal', 8),
#  ('often', 8),
#  ('wants', 8),
#  ('cup', 8),
#  ('kind', 8),
#  ('washed', 8),
#  ('anybody', 8),
#  ('wounds', 8),
#  ('real', 8),
#  ('to-night', 8),
#  ('loved', 8),
#  ('note', 8),
#  ('smoke', 8),
#  ('world', 8),
#  ('listened', 8),
#  ('kitchen', 8),
#  ('ambulances', 8),
#  ('minute', 8),
#  ('sort', 8),
#  ('blew', 8),
#  ('nobody', 8),
#  ('loaded', 8),
#  ('bit', 8),
#  ('burst', 8),
#  ('drop', 8),
#  ('game', 8),
#  ('patted', 8),
#  ('reading', 8),
#  ('wooden', 8),
#  ('walls', 8),
#  ('bloody', 8),
#  ('doctors', 8),
#  ('trying', 8),
#  ('crazy', 8),
#  ('running', 8),
#  ('handle', 8),
#  ('step', 8),
#  ('story', 8),
#  ('already', 8),
#  ('t.', 8),
#  ('box', 8),
#  ('dug', 8),
#  ('hour', 8),
#  ('tables', 8),
#  ('noise', 8),
#  ('mama', 8),
#  ('luck', 8),
#  ('bent', 8),
#  ('blood', 8),
#  ('slept', 8),
#  ('stars', 8),
#  ('times', 8),
#  ('realized', 8),
#  ('older', 8),
#  ('bainsizza', 8),
#  ('fine.', 8),
#  ('use', 8),
#  ('there.', 8),
#  ('champagne', 8),
#  ('hedge', 8),
#  ('questioning', 8),
#  ('timber', 8),
#  ('buy', 8),
#  ('moon', 8),
#  ('sport.', 8),
#  ('guttingen', 8),
#  ('dial', 8),
#  ('waiter', 8),
#  ('artillery', 7),
#  ('heavy', 7),
#  ('king', 7),
#  ('thick', 7),
#  ('mile', 7),
#  ('iron', 7),
#  ('square', 7),
#  ('spaghetti', 7),
#  ('mouth', 7),
#  ('pocket', 7),
#  ('tunic', 7),
#  ('listen', 7),
#  ('spread', 7),
#  ('fingers', 7),
#  ('smell', 7),
#  ('marble', 7),
#  ('desk', 7),
#  ('steel', 7),
#  ('ciaou', 7),
#  ('basin', 7),
#  ('friends', 7),
#  ('understood', 7),
#  ('starting', 7),
#  ('ten', 7),
#  ('mechanics', 7),
#  ('smooth', 7),
#  ('grappa', 7),
#  ('carrying', 7),
#  ('mother', 7),
#  ('him.', 7),
#  ('see.', 7),
#  ('stand', 7),
#  ('not.', 7),
#  ('learn', 7),
#  ('carry', 7),
#  ('lines', 7),
#  ('level', 7),
#  ('liked', 7),
#  ('flash', 7),
#  ('smelled', 7),
#  ('dinner', 7),
#  ('certain', 7),
#  ('knocked', 7),
#  ('also', 7),
#  ('back.', 7),
#  ('third', 7),
#  ('instead', 7),
#  ('rotten', 7),
#  ('closer', 7),
#  ('america', 7),
#  ('finish', 7),
#  ('french', 7),
#  ('austria', 7),
#  ('bacchus', 7),
#  ('best', 7),
#  ('go.', 7),
#  ('hello', 7),
#  ('caught', 7),
#  ('keeping', 7),
#  ('bombardment', 7),
#  ('packed', 7),
#  ('food', 7),
#  ('gavuzzi', 7),
#  ('smoking', 7),
#  ('breathed', 7),
#  ('wood', 7),
#  ('serious', 7),
#  ('fellow', 7),
#  ('born', 7),
#  ('that.', 7),
#  ('then.', 7),
#  ('over.', 7),
#  ('hours', 7),
#  ('machine-gunner', 7),
#  ('compartment', 7),
#  ('meat', 7),
#  ('bread', 7),
#  ('something.', 7),
#  ('brigade', 7),
#  ('rained', 7),
#  ('barto', 7),
#  ('tagliamento', 7),
#  ('vehicles', 7),
#  ('hurry', 7),
#  ('shots', 7),
#  ('barn', 7),
#  ('voice', 7),
#  ('questioned', 7),
#  ('oar', 7),
#  ('montreux.', 7),
#  ('mrs.', 7),
#  ('soda', 7),
#  ('pains', 7),
#  ('ham', 7),
#  ('rising', 6),
#  ('traffic', 6),
#  ('rifles', 6),
#  ('leather', 6),
#  ('seven', 6),
#  ('died', 6),
#  ('military', 6),
#  ('streets', 6),
#  ('body', 6),
#  ('shelling', 6),
#  ('dull', 6),
#  ('sky', 6),
#  ('none', 6),
#  ('rest', 6),
#  ('losing', 6),
#  ('win', 6),
#  ('thumb', 6),
#  ('shadow', 6),
#  ('women', 6),
#  ('bench', 6),
#  ('waiting', 6),
#  ('sunlight', 6),
#  ('courtyard', 6),
#  ('remembered', 6),
#  ('marry', 6),
#  ('soft', 6),
#  ('dried', 6),
#  ('hats', 6),
#  ('sharp', 6),
#  ('alike', 6),
#  ('although', 6),
#  ('meal', 6),
#  ('nodded', 6),
#  ('twice', 6),
#  ('truck', 6),
#  ('lined', 6),
#  ('beginning', 6),
#  ('nose', 6),
#  ('posts', 6),
#  ('run', 6),
#  ('supposed', 6),
#  ('till', 6),
#  ('years', 6),
#  ('fool', 6),
#  ('good.', 6),
#  ('fifteen', 6),
#  ('english.', 6),
#  ('lot', 6),
#  ('impossible', 6),
#  ('used', 6),
#  ('telephone', 6),
#  ('steadily', 6),
#  ('bright', 6),
#  ('leaned', 6),
#  ('lips', 6),
#  ('civilian', 6),
#  ('playing', 6),
#  ('bump', 6),
#  ('silver', 6),
#  ('island', 6),
#  ('bassi', 6),
#  ('federico', 6),
#  ('down.', 6),
#  ('lonely', 6),
#  ('rough', 6),
#  ('hardly', 6),
#  ('entrance', 6),
#  ('jam', 6),
#  ('goes', 6),
#  ('is.', 6),
#  ('stupid', 6),
#  ('mia', 6),
#  ('tied', 6),
#  ('besides', 6),
#  ('excited', 6),
#  ('mestre', 6),
#  ('mine', 6),
#  ('showed', 6),
#  ('pay', 6),
#  ('address', 6),
#  ('throw', 6),
#  ('busy', 6),
#  ('easy', 6),
#  ('comfortable', 6),
#  ('horses', 6),
#  ('ditch', 6),
#  ('younger', 6),
#  ('began', 6),
#  ('sweet.', 6),
#  ('abandoned', 6),
#  ('catch', 6),
#  ('path', 6),
#  ('carabiniere', 6),
#  ('paid', 6),
#  ('guards', 6),
#  ('lady', 6),
#  ('stresa', 6),
#  ('bought', 6),
#  ('custom', 6),
#  ('devout', 6),
#  ('pallanza', 6),
#  ('passports', 6),
#  ('toboggan', 6),
#  ('swiftly', 5),
#  ('dusty', 5),
#  ('marching', 5),
#  ('mules', 5),
#  ('vines', 5),
#  ('laid', 5),
#  ('chestnut', 5),
#  ('plateau', 5),
#  ('yellow', 5),
#  ('carefully', 5),
#  ('swung', 5),
#  ('to-day', 5),
#  ('certainly', 5),
#  ('trunk', 5),
#  ('rifle', 5),
#  ('locked', 5),
#  ('since', 5),
#  ('folded', 5),
#  ('needed', 5),
#  ('exciting', 5),
#  ('unless', 5),
#  ('business', 5),
#  ('place.', 5),
#  ('meant', 5),
#  ...]

# %%
#Turn all words to basic form
basic_form = [ps.stem(word) for word in tokens_low if not word in stopwords + symbols]

# %%
basic_form
# Out:
# ['late',
#  'summer',
#  'year',
#  'live',
#  'hous',
#  'villag',
#  'look',
#  'across',
#  'river',
#  'plain',
#  'mountain',
#  'bed',
#  'river',
#  'pebbl',
#  'boulder',
#  'dri',
#  'white',
#  'sun',
#  'water',
#  'clear',
#  'swiftli',
#  'move',
#  'blue',
#  'channel',
#  'troop',
#  'went',
#  'hous',
#  'road',
#  'dust',
#  'rais',
#  'powder',
#  'leav',
#  'tree',
#  'trunk',
#  'tree',
#  'dusti',
#  'leav',
#  'fell',
#  'earli',
#  'year',
#  'saw',
#  'troop',
#  'march',
#  'along',
#  'road',
#  'dust',
#  'rise',
#  'leav',
#  'stir',
#  'breez',
#  'fall',
#  'soldier',
#  'march',
#  'afterward',
#  'road',
#  'bare',
#  'white',
#  'except',
#  'leav',
#  'plain',
#  'rich',
#  'crop',
#  'mani',
#  'orchard',
#  'fruit',
#  'tree',
#  'beyond',
#  'plain',
#  'mountain',
#  'brown',
#  'bare',
#  'fight',
#  'mountain',
#  'night',
#  'could',
#  'see',
#  'flash',
#  'artilleri',
#  'dark',
#  'like',
#  'summer',
#  'lightn',
#  'night',
#  'cool',
#  'feel',
#  'storm',
#  'come',
#  'sometim',
#  'dark',
#  'heard',
#  'troop',
#  'march',
#  'window',
#  'gun',
#  'go',
#  'past',
#  'pull',
#  'motor-tractor',
#  'much',
#  'traffic',
#  'night',
#  'mani',
#  'mule',
#  'road',
#  'box',
#  'ammunit',
#  'side',
#  'pack-saddl',
#  'gray',
#  'motor',
#  'truck',
#  'carri',
#  'men',
#  'truck',
#  'load',
#  'cover',
#  'canva',
#  'move',
#  'slower',
#  'traffic',
#  'big',
#  'gun',
#  'pass',
#  'day',
#  'drawn',
#  'tractor',
#  'long',
#  'barrel',
#  'gun',
#  'cover',
#  'green',
#  'branch',
#  'green',
#  'leafi',
#  'branch',
#  'vine',
#  'laid',
#  'tractor',
#  'north',
#  'could',
#  'look',
#  'across',
#  'valley',
#  'see',
#  'forest',
#  'chestnut',
#  'tree',
#  'behind',
#  'anoth',
#  'mountain',
#  'side',
#  'river',
#  'fight',
#  'mountain',
#  'success',
#  'fall',
#  'rain',
#  'came',
#  'leav',
#  'fell',
#  'chestnut',
#  'tree',
#  'branch',
#  'bare',
#  'trunk',
#  'black',
#  'rain',
#  'vineyard',
#  'thin',
#  'bare-branch',
#  'countri',
#  'wet',
#  'brown',
#  'dead',
#  'autumn',
#  'mist',
#  'river',
#  'cloud',
#  'mountain',
#  'truck',
#  'splash',
#  'mud',
#  'road',
#  'troop',
#  'muddi',
#  'wet',
#  'cape',
#  'rifl',
#  'wet',
#  'cape',
#  'two',
#  'leather',
#  'cartridge-box',
#  'front',
#  'belt',
#  'gray',
#  'leather',
#  'box',
#  'heavi',
#  'pack',
#  'clip',
#  'thin',
#  'long',
#  '6.5',
#  'mm',
#  'cartridg',
#  'bulg',
#  'forward',
#  'cape',
#  'men',
#  'pass',
#  'road',
#  'march',
#  'though',
#  'six',
#  'month',
#  'gone',
#  'child',
#  'small',
#  'gray',
#  'motor',
#  'car',
#  'pass',
#  'go',
#  'fast',
#  'usual',
#  'offic',
#  'seat',
#  'driver',
#  'offic',
#  'back',
#  'seat',
#  'splash',
#  'mud',
#  'camion',
#  'even',
#  'one',
#  'offic',
#  'back',
#  'small',
#  'sit',
#  'two',
#  'gener',
#  'small',
#  'could',
#  'see',
#  'face',
#  'top',
#  'cap',
#  'narrow',
#  'back',
#  'car',
#  'went',
#  'especi',
#  'fast',
#  'probabl',
#  'king',
#  'live',
#  'udin',
#  'came',
#  'way',
#  'nearli',
#  'everi',
#  'day',
#  'see',
#  'thing',
#  'go',
#  'thing',
#  'went',
#  'badli',
#  'start',
#  'winter',
#  'came',
#  'perman',
#  'rain',
#  'rain',
#  'came',
#  'cholera',
#  'check',
#  'end',
#  'seven',
#  'thousand',
#  'die',
#  'armi',
#  '2',
#  'next',
#  'year',
#  'mani',
#  'victori',
#  'mountain',
#  'beyond',
#  'valley',
#  'hillsid',
#  'chestnut',
#  'forest',
#  'grew',
#  'captur',
#  'victori',
#  'beyond',
#  'plain',
#  'plateau',
#  'south',
#  'cross',
#  'river',
#  'august',
#  'live',
#  'hous',
#  'gorizia',
#  'fountain',
#  'mani',
#  'thick',
#  'shadi',
#  'tree',
#  'wall',
#  'garden',
#  'wistaria',
#  'vine',
#  'purpl',
#  'side',
#  'hous',
#  'fight',
#  'next',
#  'mountain',
#  'beyond',
#  'mile',
#  'away',
#  'town',
#  'nice',
#  'hous',
#  'fine',
#  'river',
#  'ran',
#  'behind',
#  'us',
#  'town',
#  'captur',
#  'handsom',
#  'mountain',
#  'beyond',
#  'could',
#  'taken',
#  'glad',
#  'austrian',
#  'seem',
#  'want',
#  'come',
#  'back',
#  'town',
#  'time',
#  'war',
#  'end',
#  'bombard',
#  'destroy',
#  'littl',
#  'militari',
#  'way',
#  'peopl',
#  'live',
#  'hospit',
#  'café',
#  'artilleri',
#  'side',
#  'street',
#  'two',
#  'bawdi',
#  'hous',
#  'one',
#  'troop',
#  'one',
#  'offic',
#  'end',
#  'summer',
#  'cool',
#  'night',
#  'fight',
#  'mountain',
#  'beyond',
#  'town',
#  'shell-mark',
#  'iron',
#  'railway',
#  'bridg',
#  'smash',
#  'tunnel',
#  'river',
#  'fight',
#  'tree',
#  'around',
#  'squar',
#  'long',
#  'avenu',
#  'tree',
#  'led',
#  'squar',
#  'girl',
#  'town',
#  'king',
#  'pass',
#  'motor',
#  'car',
#  'sometim',
#  'see',
#  'face',
#  'littl',
#  'long',
#  'neck',
#  'bodi',
#  'gray',
#  'beard',
#  'like',
#  'goat',
#  'chin',
#  'tuft',
#  'sudden',
#  'interior',
#  'hous',
#  'lost',
#  'wall',
#  'shell',
#  'plaster',
#  'rubbl',
#  'garden',
#  'sometim',
#  'street',
#  'whole',
#  'thing',
#  'go',
#  'well',
#  'carso',
#  'made',
#  'fall',
#  'differ',
#  'last',
#  'fall',
#  'countri',
#  'war',
#  'chang',
#  'forest',
#  'oak',
#  'tree',
#  'mountain',
#  'beyond',
#  'town',
#  'gone',
#  'forest',
#  'green',
#  'summer',
#  'come',
#  'town',
#  'stump',
#  'broken',
#  'trunk',
#  'ground',
#  'torn',
#  'one',
#  'day',
#  'end',
#  'fall',
#  'oak',
#  'forest',
#  'saw',
#  'cloud',
#  'come',
#  'mountain',
#  'came',
#  'fast',
#  'sun',
#  'went',
#  'dull',
#  'yellow',
#  'everyth',
#  'gray',
#  'sky',
#  'cover',
#  'cloud',
#  'came',
#  'mountain',
#  'suddenli',
#  'snow',
#  'snow',
#  'slant',
#  'across',
#  'wind',
#  'bare',
#  'ground',
#  'cover',
#  'stump',
#  'tree',
#  'project',
#  'snow',
#  'gun',
#  'path',
#  'snow',
#  'go',
#  'back',
#  'latrin',
#  'behind',
#  'trench',
#  'later',
#  'town',
#  'watch',
#  'snow',
#  'fall',
#  'look',
#  'window',
#  'bawdi',
#  'hous',
#  'hous',
#  'offic',
#  'sat',
#  'friend',
#  'two',
#  'glass',
#  'drink',
#  'bottl',
#  'asti',
#  'look',
#  'snow',
#  'fall',
#  'slowli',
#  'heavili',
#  'knew',
#  'year',
#  'river',
#  'mountain',
#  'taken',
#  'none',
#  'mountain',
#  'beyond',
#  'river',
#  'taken',
#  'left',
#  'next',
#  'year',
#  'friend',
#  'saw',
#  'priest',
#  'mess',
#  'go',
#  'street',
#  'walk',
#  'care',
#  'slush',
#  'pound',
#  'window',
#  'attract',
#  'attent',
#  'priest',
#  'look',
#  'saw',
#  'us',
#  'smile',
#  'friend',
#  'motion',
#  'come',
#  'priest',
#  'shook',
#  'head',
#  'went',
#  'night',
#  'mess',
#  'spaghetti',
#  'cours',
#  'everi',
#  'one',
#  'ate',
#  'quickli',
#  'serious',
#  'lift',
#  'spaghetti',
#  'fork',
#  'loos',
#  'strand',
#  'hung',
#  'clear',
#  'lower',
#  'mouth',
#  'els',
#  'use',
#  'continu',
#  'lift',
#  'suck',
#  'mouth',
#  'help',
#  'wine',
#  'grass-cov',
#  'gallon',
#  'flask',
#  'swung',
#  'metal',
#  'cradl',
#  'pull',
#  'neck',
#  'flask',
#  'forefing',
#  'wine',
#  'clear',
#  'red',
#  'tannic',
#  'love',
#  'pour',
#  'glass',
#  'held',
#  'hand',
#  'cours',
#  'captain',
#  'commenc',
#  'pick',
#  'priest',
#  'priest',
#  'young',
#  'blush',
#  'easili',
#  'wore',
#  'uniform',
#  'like',
#  'rest',
#  'us',
#  'cross',
#  'dark',
#  'red',
#  'velvet',
#  'left',
#  'breast',
#  'pocket',
#  'gray',
#  'tunic',
#  'captain',
#  'spoke',
#  'pidgin',
#  'italian',
#  'doubt',
#  'benefit',
#  'order',
#  'might',
#  'understand',
#  'perfectli',
#  'noth',
#  'lost',
#  'priest',
#  'to-day',
#  'girl',
#  'captain',
#  'said',
#  'look',
#  'priest',
#  'priest',
#  'smile',
#  'blush',
#  'shook',
#  'head',
#  'captain',
#  'bait',
#  'often',
#  'true',
#  'ask',
#  'captain',
#  'to-day',
#  'see',
#  'priest',
#  'girls.',
#  'said',
#  'priest',
#  'offic',
#  'amus',
#  'bait',
#  'priest',
#  'girl',
#  'went',
#  'captain',
#  'priest',
#  'never',
#  'girl',
#  'explain',
#  'took',
#  'glass',
#  'fill',
#  'look',
#  'eye',
#  'time',
#  'lose',
#  'sight',
#  'priest',
#  'priest',
#  'everi',
#  'night',
#  'five',
#  'one.',
#  'everi',
#  'one',
#  'tabl',
#  'laugh',
#  'understand',
#  'priest',
#  'everi',
#  'night',
#  'five',
#  'one.',
#  'made',
#  'gestur',
#  'laugh',
#  'loudli',
#  'priest',
#  'accept',
#  'joke',
#  'pope',
#  'want',
#  'austrian',
#  'win',
#  'war',
#  'major',
#  'said',
#  'love',
#  'franz',
#  'joseph',
#  'money',
#  'come',
#  'atheist.',
#  'ever',
#  'read',
#  'black',
#  'pig',
#  'ask',
#  'lieuten',
#  'get',
#  'copi',
#  'shook',
#  'faith.',
#  'filthi',
#  'vile',
#  'book',
#  'said',
#  'priest',
#  'realli',
#  'like',
#  'it.',
#  'valuabl',
#  'said',
#  'lieuten',
#  'tell',
#  'priest',
#  'like',
#  'said',
#  'smile',
#  'priest',
#  'smile',
#  'back',
#  'across',
#  'candle-light',
#  'read',
#  'said',
#  'get',
#  'said',
#  'lieuten',
#  'think',
#  'men',
#  'atheist',
#  'major',
#  'said',
#  'believ',
#  'free',
#  'mason',
#  'however.',
#  'believ',
#  'free',
#  'mason',
#  'lieuten',
#  'said',
#  'nobl',
#  'organization.',
#  'one',
#  'came',
#  'door',
#  'open',
#  'could',
#  'see',
#  'snow',
#  'fall',
#  'offens',
#  'snow',
#  'come',
#  'said',
#  'certainli',
#  'said',
#  'major',
#  'go',
#  'leav',
#  'go',
#  'rome',
#  'napl',
#  'sicily—',
#  'visit',
#  'amalfi',
#  'said',
#  'lieuten',
#  'write',
#  'card',
#  'famili',
#  'amalfi',
#  'love',
#  'like',
#  'son.',
#  'go',
#  'palermo.',
#  'ought',
#  'go',
#  'capri.',
#  'would',
#  'like',
#  'see',
#  'abruzzi',
#  'visit',
#  'famili',
#  'capracotta',
#  'said',
#  'priest',
#  'listen',
#  'talk',
#  'abruzzi',
#  'snow',
#  'want',
#  'see',
#  'peasant',
#  'let',
#  'go',
#  'centr',
#  'cultur',
#  'civilization.',
#  'fine',
#  'girl',
#  'give',
#  'address',
#  'place',
#  'napl',
#  'beauti',
#  'young',
#  'girls—accompani',
#  'mother',
#  'ha',
#  'ha',
#  'ha',
#  'captain',
#  'spread',
#  'hand',
#  'open',
#  'thumb',
#  'finger',
#  'outspread',
#  'make',
#  'shadow',
#  'pictur',
#  'shadow',
#  'hand',
#  'wall',
#  'spoke',
#  'pidgin',
#  'italian',
#  'go',
#  'away',
#  'like',
#  'point',
#  'thumb',
#  'come',
#  'back',
#  'like',
#  'touch',
#  'littl',
#  'finger',
#  'everi',
#  'one',
#  'laugh',
#  'look',
#  'said',
#  'captain',
#  'spread',
#  'hand',
#  'candle-light',
#  'made',
#  'shadow',
#  'wall',
#  'start',
#  'upright',
#  'thumb',
#  'name',
#  'order',
#  'thumb',
#  'four',
#  'finger',
#  'soto-tenent',
#  'thumb',
#  'tenent',
#  'first',
#  'finger',
#  'capitano',
#  'next',
#  'finger',
#  'maggior',
#  'next',
#  'littl',
#  'finger',
#  'tenentecolonello',
#  'littl',
#  'finger',
#  'go',
#  'away',
#  'soto-tenent',
#  'come',
#  'back',
#  'soto-colonello',
#  'laugh',
#  'captain',
#  'great',
#  'success',
#  'finger',
#  'game',
#  'look',
#  'priest',
#  'shout',
#  'everi',
#  'night',
#  'priest',
#  'five',
#  'one',
#  'laugh',
#  'must',
#  'go',
#  'leav',
#  'major',
#  'said',
#  'would',
#  'like',
#  'go',
#  'show',
#  'thing',
#  'lieuten',
#  'said',
#  'come',
#  'back',
#  'bring',
#  'phonograph.',
#  'bring',
#  'good',
#  'opera',
#  'disks.',
#  'bring',
#  'caruso.',
#  'bring',
#  'caruso',
#  'bellows.',
#  'wish',
#  'could',
#  'bellow',
#  'like',
#  'bellow',
#  'say',
#  'bellow',
#  'would',
#  'like',
#  'go',
#  'abruzzi',
#  'priest',
#  'said',
#  'other',
#  'shout',
#  'good',
#  'hunt',
#  'would',
#  'like',
#  'peopl',
#  'though',
#  'cold',
#  'clear',
#  'dri',
#  'could',
#  'stay',
#  'famili',
#  'father',
#  'famou',
#  'hunter.',
#  'come',
#  'said',
#  'captain',
#  'go',
#  'whorehous',
#  'shuts.',
#  'good-night',
#  'said',
#  'priest',
#  'good-night',
#  'said',
#  '3',
#  'came',
#  'back',
#  'front',
#  'still',
#  'live',
#  'town',
#  'mani',
#  'gun',
#  'countri',
#  ...]

# %%
#Textを使うためにreviewをlistにぶち込む
basic_form = [basic_form]

# %%
#原型に戻した単語で、再び文を再構築する。
text = []
for i in basic_form:
    text.append(nltk.Text(i))
    
text
# Out:
# [<Text: late summer year live hous villag look across...>]

# %%
#Textからwords listを作る。
for i in text:
    words = [word for word in i]
    
words
# Out:
# ['late',
#  'summer',
#  'year',
#  'live',
#  'hous',
#  'villag',
#  'look',
#  'across',
#  'river',
#  'plain',
#  'mountain',
#  'bed',
#  'river',
#  'pebbl',
#  'boulder',
#  'dri',
#  'white',
#  'sun',
#  'water',
#  'clear',
#  'swiftli',
#  'move',
#  'blue',
#  'channel',
#  'troop',
#  'went',
#  'hous',
#  'road',
#  'dust',
#  'rais',
#  'powder',
#  'leav',
#  'tree',
#  'trunk',
#  'tree',
#  'dusti',
#  'leav',
#  'fell',
#  'earli',
#  'year',
#  'saw',
#  'troop',
#  'march',
#  'along',
#  'road',
#  'dust',
#  'rise',
#  'leav',
#  'stir',
#  'breez',
#  'fall',
#  'soldier',
#  'march',
#  'afterward',
#  'road',
#  'bare',
#  'white',
#  'except',
#  'leav',
#  'plain',
#  'rich',
#  'crop',
#  'mani',
#  'orchard',
#  'fruit',
#  'tree',
#  'beyond',
#  'plain',
#  'mountain',
#  'brown',
#  'bare',
#  'fight',
#  'mountain',
#  'night',
#  'could',
#  'see',
#  'flash',
#  'artilleri',
#  'dark',
#  'like',
#  'summer',
#  'lightn',
#  'night',
#  'cool',
#  'feel',
#  'storm',
#  'come',
#  'sometim',
#  'dark',
#  'heard',
#  'troop',
#  'march',
#  'window',
#  'gun',
#  'go',
#  'past',
#  'pull',
#  'motor-tractor',
#  'much',
#  'traffic',
#  'night',
#  'mani',
#  'mule',
#  'road',
#  'box',
#  'ammunit',
#  'side',
#  'pack-saddl',
#  'gray',
#  'motor',
#  'truck',
#  'carri',
#  'men',
#  'truck',
#  'load',
#  'cover',
#  'canva',
#  'move',
#  'slower',
#  'traffic',
#  'big',
#  'gun',
#  'pass',
#  'day',
#  'drawn',
#  'tractor',
#  'long',
#  'barrel',
#  'gun',
#  'cover',
#  'green',
#  'branch',
#  'green',
#  'leafi',
#  'branch',
#  'vine',
#  'laid',
#  'tractor',
#  'north',
#  'could',
#  'look',
#  'across',
#  'valley',
#  'see',
#  'forest',
#  'chestnut',
#  'tree',
#  'behind',
#  'anoth',
#  'mountain',
#  'side',
#  'river',
#  'fight',
#  'mountain',
#  'success',
#  'fall',
#  'rain',
#  'came',
#  'leav',
#  'fell',
#  'chestnut',
#  'tree',
#  'branch',
#  'bare',
#  'trunk',
#  'black',
#  'rain',
#  'vineyard',
#  'thin',
#  'bare-branch',
#  'countri',
#  'wet',
#  'brown',
#  'dead',
#  'autumn',
#  'mist',
#  'river',
#  'cloud',
#  'mountain',
#  'truck',
#  'splash',
#  'mud',
#  'road',
#  'troop',
#  'muddi',
#  'wet',
#  'cape',
#  'rifl',
#  'wet',
#  'cape',
#  'two',
#  'leather',
#  'cartridge-box',
#  'front',
#  'belt',
#  'gray',
#  'leather',
#  'box',
#  'heavi',
#  'pack',
#  'clip',
#  'thin',
#  'long',
#  '6.5',
#  'mm',
#  'cartridg',
#  'bulg',
#  'forward',
#  'cape',
#  'men',
#  'pass',
#  'road',
#  'march',
#  'though',
#  'six',
#  'month',
#  'gone',
#  'child',
#  'small',
#  'gray',
#  'motor',
#  'car',
#  'pass',
#  'go',
#  'fast',
#  'usual',
#  'offic',
#  'seat',
#  'driver',
#  'offic',
#  'back',
#  'seat',
#  'splash',
#  'mud',
#  'camion',
#  'even',
#  'one',
#  'offic',
#  'back',
#  'small',
#  'sit',
#  'two',
#  'gener',
#  'small',
#  'could',
#  'see',
#  'face',
#  'top',
#  'cap',
#  'narrow',
#  'back',
#  'car',
#  'went',
#  'especi',
#  'fast',
#  'probabl',
#  'king',
#  'live',
#  'udin',
#  'came',
#  'way',
#  'nearli',
#  'everi',
#  'day',
#  'see',
#  'thing',
#  'go',
#  'thing',
#  'went',
#  'badli',
#  'start',
#  'winter',
#  'came',
#  'perman',
#  'rain',
#  'rain',
#  'came',
#  'cholera',
#  'check',
#  'end',
#  'seven',
#  'thousand',
#  'die',
#  'armi',
#  '2',
#  'next',
#  'year',
#  'mani',
#  'victori',
#  'mountain',
#  'beyond',
#  'valley',
#  'hillsid',
#  'chestnut',
#  'forest',
#  'grew',
#  'captur',
#  'victori',
#  'beyond',
#  'plain',
#  'plateau',
#  'south',
#  'cross',
#  'river',
#  'august',
#  'live',
#  'hous',
#  'gorizia',
#  'fountain',
#  'mani',
#  'thick',
#  'shadi',
#  'tree',
#  'wall',
#  'garden',
#  'wistaria',
#  'vine',
#  'purpl',
#  'side',
#  'hous',
#  'fight',
#  'next',
#  'mountain',
#  'beyond',
#  'mile',
#  'away',
#  'town',
#  'nice',
#  'hous',
#  'fine',
#  'river',
#  'ran',
#  'behind',
#  'us',
#  'town',
#  'captur',
#  'handsom',
#  'mountain',
#  'beyond',
#  'could',
#  'taken',
#  'glad',
#  'austrian',
#  'seem',
#  'want',
#  'come',
#  'back',
#  'town',
#  'time',
#  'war',
#  'end',
#  'bombard',
#  'destroy',
#  'littl',
#  'militari',
#  'way',
#  'peopl',
#  'live',
#  'hospit',
#  'café',
#  'artilleri',
#  'side',
#  'street',
#  'two',
#  'bawdi',
#  'hous',
#  'one',
#  'troop',
#  'one',
#  'offic',
#  'end',
#  'summer',
#  'cool',
#  'night',
#  'fight',
#  'mountain',
#  'beyond',
#  'town',
#  'shell-mark',
#  'iron',
#  'railway',
#  'bridg',
#  'smash',
#  'tunnel',
#  'river',
#  'fight',
#  'tree',
#  'around',
#  'squar',
#  'long',
#  'avenu',
#  'tree',
#  'led',
#  'squar',
#  'girl',
#  'town',
#  'king',
#  'pass',
#  'motor',
#  'car',
#  'sometim',
#  'see',
#  'face',
#  'littl',
#  'long',
#  'neck',
#  'bodi',
#  'gray',
#  'beard',
#  'like',
#  'goat',
#  'chin',
#  'tuft',
#  'sudden',
#  'interior',
#  'hous',
#  'lost',
#  'wall',
#  'shell',
#  'plaster',
#  'rubbl',
#  'garden',
#  'sometim',
#  'street',
#  'whole',
#  'thing',
#  'go',
#  'well',
#  'carso',
#  'made',
#  'fall',
#  'differ',
#  'last',
#  'fall',
#  'countri',
#  'war',
#  'chang',
#  'forest',
#  'oak',
#  'tree',
#  'mountain',
#  'beyond',
#  'town',
#  'gone',
#  'forest',
#  'green',
#  'summer',
#  'come',
#  'town',
#  'stump',
#  'broken',
#  'trunk',
#  'ground',
#  'torn',
#  'one',
#  'day',
#  'end',
#  'fall',
#  'oak',
#  'forest',
#  'saw',
#  'cloud',
#  'come',
#  'mountain',
#  'came',
#  'fast',
#  'sun',
#  'went',
#  'dull',
#  'yellow',
#  'everyth',
#  'gray',
#  'sky',
#  'cover',
#  'cloud',
#  'came',
#  'mountain',
#  'suddenli',
#  'snow',
#  'snow',
#  'slant',
#  'across',
#  'wind',
#  'bare',
#  'ground',
#  'cover',
#  'stump',
#  'tree',
#  'project',
#  'snow',
#  'gun',
#  'path',
#  'snow',
#  'go',
#  'back',
#  'latrin',
#  'behind',
#  'trench',
#  'later',
#  'town',
#  'watch',
#  'snow',
#  'fall',
#  'look',
#  'window',
#  'bawdi',
#  'hous',
#  'hous',
#  'offic',
#  'sat',
#  'friend',
#  'two',
#  'glass',
#  'drink',
#  'bottl',
#  'asti',
#  'look',
#  'snow',
#  'fall',
#  'slowli',
#  'heavili',
#  'knew',
#  'year',
#  'river',
#  'mountain',
#  'taken',
#  'none',
#  'mountain',
#  'beyond',
#  'river',
#  'taken',
#  'left',
#  'next',
#  'year',
#  'friend',
#  'saw',
#  'priest',
#  'mess',
#  'go',
#  'street',
#  'walk',
#  'care',
#  'slush',
#  'pound',
#  'window',
#  'attract',
#  'attent',
#  'priest',
#  'look',
#  'saw',
#  'us',
#  'smile',
#  'friend',
#  'motion',
#  'come',
#  'priest',
#  'shook',
#  'head',
#  'went',
#  'night',
#  'mess',
#  'spaghetti',
#  'cours',
#  'everi',
#  'one',
#  'ate',
#  'quickli',
#  'serious',
#  'lift',
#  'spaghetti',
#  'fork',
#  'loos',
#  'strand',
#  'hung',
#  'clear',
#  'lower',
#  'mouth',
#  'els',
#  'use',
#  'continu',
#  'lift',
#  'suck',
#  'mouth',
#  'help',
#  'wine',
#  'grass-cov',
#  'gallon',
#  'flask',
#  'swung',
#  'metal',
#  'cradl',
#  'pull',
#  'neck',
#  'flask',
#  'forefing',
#  'wine',
#  'clear',
#  'red',
#  'tannic',
#  'love',
#  'pour',
#  'glass',
#  'held',
#  'hand',
#  'cours',
#  'captain',
#  'commenc',
#  'pick',
#  'priest',
#  'priest',
#  'young',
#  'blush',
#  'easili',
#  'wore',
#  'uniform',
#  'like',
#  'rest',
#  'us',
#  'cross',
#  'dark',
#  'red',
#  'velvet',
#  'left',
#  'breast',
#  'pocket',
#  'gray',
#  'tunic',
#  'captain',
#  'spoke',
#  'pidgin',
#  'italian',
#  'doubt',
#  'benefit',
#  'order',
#  'might',
#  'understand',
#  'perfectli',
#  'noth',
#  'lost',
#  'priest',
#  'to-day',
#  'girl',
#  'captain',
#  'said',
#  'look',
#  'priest',
#  'priest',
#  'smile',
#  'blush',
#  'shook',
#  'head',
#  'captain',
#  'bait',
#  'often',
#  'true',
#  'ask',
#  'captain',
#  'to-day',
#  'see',
#  'priest',
#  'girls.',
#  'said',
#  'priest',
#  'offic',
#  'amus',
#  'bait',
#  'priest',
#  'girl',
#  'went',
#  'captain',
#  'priest',
#  'never',
#  'girl',
#  'explain',
#  'took',
#  'glass',
#  'fill',
#  'look',
#  'eye',
#  'time',
#  'lose',
#  'sight',
#  'priest',
#  'priest',
#  'everi',
#  'night',
#  'five',
#  'one.',
#  'everi',
#  'one',
#  'tabl',
#  'laugh',
#  'understand',
#  'priest',
#  'everi',
#  'night',
#  'five',
#  'one.',
#  'made',
#  'gestur',
#  'laugh',
#  'loudli',
#  'priest',
#  'accept',
#  'joke',
#  'pope',
#  'want',
#  'austrian',
#  'win',
#  'war',
#  'major',
#  'said',
#  'love',
#  'franz',
#  'joseph',
#  'money',
#  'come',
#  'atheist.',
#  'ever',
#  'read',
#  'black',
#  'pig',
#  'ask',
#  'lieuten',
#  'get',
#  'copi',
#  'shook',
#  'faith.',
#  'filthi',
#  'vile',
#  'book',
#  'said',
#  'priest',
#  'realli',
#  'like',
#  'it.',
#  'valuabl',
#  'said',
#  'lieuten',
#  'tell',
#  'priest',
#  'like',
#  'said',
#  'smile',
#  'priest',
#  'smile',
#  'back',
#  'across',
#  'candle-light',
#  'read',
#  'said',
#  'get',
#  'said',
#  'lieuten',
#  'think',
#  'men',
#  'atheist',
#  'major',
#  'said',
#  'believ',
#  'free',
#  'mason',
#  'however.',
#  'believ',
#  'free',
#  'mason',
#  'lieuten',
#  'said',
#  'nobl',
#  'organization.',
#  'one',
#  'came',
#  'door',
#  'open',
#  'could',
#  'see',
#  'snow',
#  'fall',
#  'offens',
#  'snow',
#  'come',
#  'said',
#  'certainli',
#  'said',
#  'major',
#  'go',
#  'leav',
#  'go',
#  'rome',
#  'napl',
#  'sicily—',
#  'visit',
#  'amalfi',
#  'said',
#  'lieuten',
#  'write',
#  'card',
#  'famili',
#  'amalfi',
#  'love',
#  'like',
#  'son.',
#  'go',
#  'palermo.',
#  'ought',
#  'go',
#  'capri.',
#  'would',
#  'like',
#  'see',
#  'abruzzi',
#  'visit',
#  'famili',
#  'capracotta',
#  'said',
#  'priest',
#  'listen',
#  'talk',
#  'abruzzi',
#  'snow',
#  'want',
#  'see',
#  'peasant',
#  'let',
#  'go',
#  'centr',
#  'cultur',
#  'civilization.',
#  'fine',
#  'girl',
#  'give',
#  'address',
#  'place',
#  'napl',
#  'beauti',
#  'young',
#  'girls—accompani',
#  'mother',
#  'ha',
#  'ha',
#  'ha',
#  'captain',
#  'spread',
#  'hand',
#  'open',
#  'thumb',
#  'finger',
#  'outspread',
#  'make',
#  'shadow',
#  'pictur',
#  'shadow',
#  'hand',
#  'wall',
#  'spoke',
#  'pidgin',
#  'italian',
#  'go',
#  'away',
#  'like',
#  'point',
#  'thumb',
#  'come',
#  'back',
#  'like',
#  'touch',
#  'littl',
#  'finger',
#  'everi',
#  'one',
#  'laugh',
#  'look',
#  'said',
#  'captain',
#  'spread',
#  'hand',
#  'candle-light',
#  'made',
#  'shadow',
#  'wall',
#  'start',
#  'upright',
#  'thumb',
#  'name',
#  'order',
#  'thumb',
#  'four',
#  'finger',
#  'soto-tenent',
#  'thumb',
#  'tenent',
#  'first',
#  'finger',
#  'capitano',
#  'next',
#  'finger',
#  'maggior',
#  'next',
#  'littl',
#  'finger',
#  'tenentecolonello',
#  'littl',
#  'finger',
#  'go',
#  'away',
#  'soto-tenent',
#  'come',
#  'back',
#  'soto-colonello',
#  'laugh',
#  'captain',
#  'great',
#  'success',
#  'finger',
#  'game',
#  'look',
#  'priest',
#  'shout',
#  'everi',
#  'night',
#  'priest',
#  'five',
#  'one',
#  'laugh',
#  'must',
#  'go',
#  'leav',
#  'major',
#  'said',
#  'would',
#  'like',
#  'go',
#  'show',
#  'thing',
#  'lieuten',
#  'said',
#  'come',
#  'back',
#  'bring',
#  'phonograph.',
#  'bring',
#  'good',
#  'opera',
#  'disks.',
#  'bring',
#  'caruso.',
#  'bring',
#  'caruso',
#  'bellows.',
#  'wish',
#  'could',
#  'bellow',
#  'like',
#  'bellow',
#  'say',
#  'bellow',
#  'would',
#  'like',
#  'go',
#  'abruzzi',
#  'priest',
#  'said',
#  'other',
#  'shout',
#  'good',
#  'hunt',
#  'would',
#  'like',
#  'peopl',
#  'though',
#  'cold',
#  'clear',
#  'dri',
#  'could',
#  'stay',
#  'famili',
#  'father',
#  'famou',
#  'hunter.',
#  'come',
#  'said',
#  'captain',
#  'go',
#  'whorehous',
#  'shuts.',
#  'good-night',
#  'said',
#  'priest',
#  'good-night',
#  'said',
#  '3',
#  'came',
#  'back',
#  'front',
#  'still',
#  'live',
#  'town',
#  'mani',
#  'gun',
#  'countri',
#  ...]

# %%
#Basic に直して、頻度を確認する
freq_list_basic = []
for i in text:
    freq_list_basic.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

# %%
freq_list_basic
# Out:
# [FreqDist({'late': 13,
#            'summer': 14,
#            'year': 20,
#            'live': 35,
#            'hous': 51,
#            'villag': 13,
#            'look': 293,
#            'across': 72,
#            'river': 65,
#            'plain': 23,
#            'mountain': 90,
#            'bed': 94,
#            'pebbl': 3,
#            'boulder': 1,
#            'dri': 20,
#            'white': 29,
#            'sun': 22,
#            'water': 55,
#            'clear': 31,
#            'swiftli': 5,
#            'move': 50,
#            'blue': 3,
#            'channel': 4,
#            'troop': 27,
#            'went': 293,
#            'road': 188,
#            'dust': 10,
#            'rais': 4,
#            'powder': 1,
#            'leav': 43,
#            'tree': 57,
#            'trunk': 8,
#            'dusti': 5,
#            'fell': 11,
#            'earli': 16,
#            'saw': 110,
#            'march': 9,
#            'along': 97,
#            'rise': 7,
#            'stir': 2,
#            'breez': 4,
#            'fall': 33,
#            'soldier': 36,
#            'afterward': 15,
#            'bare': 20,
#            'except': 20,
#            'rich': 1,
#            'crop': 1,
#            'mani': 62,
#            'orchard': 2,
#            'fruit': 2,
#            'beyond': 37,
#            'brown': 11,
#            'fight': 17,
#            'night': 88,
#            'could': 219,
#            'see': 225,
#            'flash': 12,
#            'artilleri': 7,
#            'dark': 80,
#            'like': 186,
#            'lightn': 1,
#            'cool': 11,
#            'feel': 76,
#            'storm': 10,
#            'come': 226,
#            'sometim': 37,
#            'heard': 48,
#            'window': 73,
#            'gun': 25,
#            'go': 442,
#            'past': 15,
#            'pull': 42,
#            'motor-tractor': 1,
#            'much': 83,
#            'traffic': 6,
#            'mule': 6,
#            'box': 17,
#            'ammunit': 1,
#            'side': 90,
#            'pack-saddl': 1,
#            'gray': 22,
#            'motor': 14,
#            'truck': 19,
#            'carri': 30,
#            'men': 44,
#            'load': 13,
#            'cover': 12,
#            'canva': 18,
#            'slower': 2,
#            'big': 66,
#            'pass': 47,
#            'day': 51,
#            'drawn': 2,
#            'tractor': 2,
#            'long': 97,
#            'barrel': 4,
#            'green': 8,
#            'branch': 11,
#            'leafi': 1,
#            'vine': 7,
#            'laid': 5,
#            'north': 22,
#            'valley': 14,
#            'forest': 12,
#            'chestnut': 6,
#            'behind': 36,
#            'anoth': 65,
#            'success': 7,
#            'rain': 113,
#            'came': 185,
#            'black': 12,
#            'vineyard': 4,
#            'thin': 21,
#            'bare-branch': 1,
#            'countri': 39,
#            'wet': 48,
#            'dead': 23,
#            'autumn': 2,
#            'mist': 5,
#            'cloud': 14,
#            'splash': 4,
#            'mud': 11,
#            'muddi': 13,
#            'cape': 15,
#            'rifl': 11,
#            'two': 130,
#            'leather': 7,
#            'cartridge-box': 1,
#            'front': 48,
#            'belt': 2,
#            'heavi': 7,
#            'pack': 13,
#            'clip': 5,
#            '6.5': 1,
#            'mm': 1,
#            'cartridg': 2,
#            'bulg': 2,
#            'forward': 17,
#            'though': 22,
#            'six': 4,
#            'month': 5,
#            'gone': 49,
#            'child': 11,
#            'small': 30,
#            'car': 108,
#            'fast': 22,
#            'usual': 9,
#            'offic': 59,
#            'seat': 24,
#            'driver': 38,
#            'back': 214,
#            'camion': 6,
#            'even': 41,
#            'one': 240,
#            'sit': 43,
#            'gener': 2,
#            'face': 58,
#            'top': 25,
#            'cap': 11,
#            'narrow': 21,
#            'especi': 4,
#            'probabl': 21,
#            'king': 7,
#            'udin': 19,
#            'way': 79,
#            'nearli': 17,
#            'everi': 35,
#            'thing': 85,
#            'badli': 14,
#            'start': 109,
#            'winter': 26,
#            'perman': 2,
#            'cholera': 1,
#            'check': 2,
#            'end': 33,
#            'seven': 6,
#            'thousand': 3,
#            'die': 57,
#            'armi': 26,
#            '2': 1,
#            'next': 25,
#            'victori': 8,
#            'hillsid': 3,
#            'grew': 4,
#            'captur': 4,
#            'plateau': 5,
#            'south': 15,
#            'cross': 46,
#            'august': 1,
#            'gorizia': 9,
#            'fountain': 3,
#            'thick': 7,
#            'shadi': 1,
#            'wall': 39,
#            'garden': 19,
#            'wistaria': 1,
#            'purpl': 1,
#            'mile': 9,
#            'away': 102,
#            'town': 51,
#            'nice': 29,
#            'fine': 63,
#            'ran': 19,
#            'us': 105,
#            'handsom': 2,
#            'taken': 19,
#            'glad': 24,
#            'austrian': 42,
#            'seem': 35,
#            'want': 187,
#            'time': 110,
#            'war': 81,
#            'bombard': 8,
#            'destroy': 1,
#            'littl': 127,
#            'militari': 6,
#            'peopl': 42,
#            'hospit': 51,
#            'café': 14,
#            'street': 30,
#            'bawdi': 2,
#            'shell-mark': 1,
#            'iron': 7,
#            'railway': 17,
#            'bridg': 52,
#            'smash': 8,
#            'tunnel': 3,
#            'around': 48,
#            'squar': 7,
#            'avenu': 1,
#            'led': 11,
#            'girl': 71,
#            'neck': 18,
#            'bodi': 7,
#            'beard': 14,
#            'goat': 2,
#            'chin': 3,
#            'tuft': 1,
#            'sudden': 3,
#            'interior': 1,
#            'lost': 11,
#            'shell': 20,
#            'plaster': 2,
#            'rubbl': 3,
#            'whole': 13,
#            'well': 56,
#            'carso': 3,
#            'made': 47,
#            'differ': 24,
#            'last': 14,
#            'chang': 9,
#            'oak': 2,
#            'stump': 5,
#            'broken': 15,
#            'ground': 11,
#            'torn': 3,
#            'dull': 7,
#            'yellow': 5,
#            'everyth': 25,
#            'sky': 6,
#            'suddenli': 13,
#            'snow': 42,
#            'slant': 2,
#            'wind': 34,
#            'project': 2,
#            'path': 10,
#            'latrin': 1,
#            'trench': 6,
#            'later': 19,
#            'watch': 60,
#            'sat': 83,
#            'friend': 17,
#            'glass': 52,
#            'drink': 59,
#            'bottl': 39,
#            'asti': 1,
#            'slowli': 16,
#            'heavili': 4,
#            'knew': 55,
#            'none': 6,
#            'left': 46,
#            'priest': 85,
#            'mess': 20,
#            'walk': 82,
#            'care': 25,
#            'slush': 4,
#            'pound': 1,
#            'attract': 3,
#            'attent': 3,
#            'smile': 47,
#            'motion': 4,
#            'shook': 28,
#            'head': 61,
#            'spaghetti': 7,
#            'cours': 18,
#            'ate': 19,
#            'quickli': 9,
#            'serious': 1,
#            'lift': 19,
#            'fork': 1,
#            'loos': 4,
#            'strand': 2,
#            'hung': 12,
#            'lower': 3,
#            'mouth': 10,
#            'els': 19,
#            'use': 19,
#            'continu': 1,
#            'suck': 5,
#            'help': 19,
#            'wine': 49,
#            'grass-cov': 1,
#            'gallon': 1,
#            'flask': 2,
#            'swung': 5,
#            'metal': 8,
#            'cradl': 1,
#            'forefing': 1,
#            'red': 17,
#            'tannic': 1,
#            'love': 98,
#            'pour': 15,
#            'held': 53,
#            'hand': 100,
#            'captain': 30,
#            'commenc': 11,
#            'pick': 16,
#            'young': 13,
#            'blush': 3,
#            'easili': 10,
#            'wore': 24,
#            'uniform': 17,
#            'rest': 11,
#            'velvet': 1,
#            'breast': 2,
#            'pocket': 9,
#            'tunic': 7,
#            'spoke': 13,
#            'pidgin': 2,
#            'italian': 54,
#            'doubt': 3,
#            'benefit': 1,
#            'order': 19,
#            'might': 35,
#            'understand': 12,
#            'perfectli': 3,
#            'noth': 65,
#            'to-day': 5,
#            'said': 944,
#            'bait': 4,
#            'often': 8,
#            'true': 10,
#            'ask': 127,
#            'girls.': 4,
#            'amus': 1,
#            'never': 73,
#            'explain': 6,
#            'took': 86,
#            'fill': 14,
#            'eye': 20,
#            'lose': 12,
#            'sight': 28,
#            'five': 14,
#            'one.': 10,
#            'tabl': 49,
#            'laugh': 29,
#            'gestur': 1,
#            'loudli': 1,
#            'accept': 1,
#            'joke': 12,
#            'pope': 1,
#            'win': 7,
#            'major': 69,
#            'franz': 1,
#            'joseph': 1,
#            'money': 23,
#            'atheist.': 1,
#            'ever': 32,
#            'read': 31,
#            'pig': 1,
#            'lieuten': 20,
#            'get': 218,
#            'copi': 3,
#            'faith.': 1,
#            'filthi': 2,
#            'vile': 1,
#            'book': 5,
#            'realli': 42,
#            'it.': 45,
#            'valuabl': 2,
#            'tell': 77,
#            'candle-light': 2,
#            'think': 136,
#            'atheist': 1,
#            'believ': 42,
#            'free': 2,
#            'mason': 2,
#            'however.': 1,
#            'nobl': 2,
#            'organization.': 1,
#            'door': 72,
#            'open': 68,
#            'offens': 11,
#            'certainli': 5,
#            'rome': 12,
#            'napl': 3,
#            'sicily—': 1,
#            'visit': 3,
#            'amalfi': 3,
#            'write': 12,
#            'card': 9,
#            'famili': 10,
#            'son.': 1,
#            'palermo.': 1,
#            'ought': 28,
#            'capri.': 2,
#            'would': 254,
#            'abruzzi': 9,
#            'capracotta': 2,
#            'listen': 16,
#            'talk': 72,
#            'peasant': 10,
#            'let': 91,
#            'centr': 4,
#            'cultur': 1,
#            'civilization.': 1,
#            'give': 50,
#            'address': 7,
#            'place': 68,
#            'beauti': 28,
#            'girls—accompani': 1,
#            'mother': 8,
#            'ha': 4,
#            'spread': 7,
#            'thumb': 7,
#            'finger': 18,
#            'outspread': 1,
#            'make': 75,
#            'shadow': 8,
#            'pictur': 2,
#            'point': 30,
#            'touch': 14,
#            'upright': 1,
#            'name': 21,
#            'four': 20,
#            'soto-tenent': 2,
#            'tenent': 58,
#            'first': 47,
#            'capitano': 2,
#            'maggior': 2,
#            'tenentecolonello': 1,
#            'soto-colonello': 1,
#            'great': 34,
#            'game': 12,
#            'shout': 13,
#            'must': 52,
#            'show': 20,
#            'bring': 29,
#            'phonograph.': 1,
#            'good': 145,
#            'opera': 2,
#            'disks.': 1,
#            'caruso.': 1,
#            'caruso': 1,
#            'bellows.': 1,
#            'wish': 41,
#            'bellow': 3,
#            'say': 72,
#            'hunt': 6,
#            'cold': 38,
#            'stay': 52,
#            'father': 19,
#            'famou': 1,
#            'hunter.': 1,
#            'whorehous': 2,
#            'shuts.': 1,
#            'good-night': 21,
#            '3': 1,
#            'still': 50,
#            'spring': 13,
#            'field': 38,
#            'shoot': 17,
#            'sea': 4,
#            'hill': 20,
#            'old': 42,
#            'castl': 2,
#            'cup': 9,
#            'slope': 5,
#            'new': 25,
#            'met': 9,
#            'british': 16,
#            'women': 6,
#            'hit': 17,
#            'fire': 45,
#            'jt': 1,
#            'warm': 18,
#            'alleyway': 1,
#            'found': 20,
#            'bench': 7,
#            'outsid': 64,
#            'ambul': 23,
#            'wait': 33,
#            'insid': 32,
#            'smell': 18,
#            'marbl': 8,
#            'floor': 38,
#            'room': 89,
#            'desk': 7,
#            'sunlight': 6,
#            'know': 146,
#            'whether': 9,
#            'report': 11,
#            'upstair': 9,
#            'clean': 16,
#            'decid': 4,
#            'share': 1,
#            'rinaldi': 97,
#            'courtyard': 6,
#            'blanket': 6,
#            'ga': 11,
#            'mask': 23,
#            'oblong': 1,
#            'tin': 6,
#            'steel': 7,
#            'helmet': 15,
#            'peg': 1,
#            'foot': 13,
#            'flat': 16,
#            'boot': 12,
#            'shini': 3,
#            'oil': 4,
#            'sniper': 1,
#            'blu': 1,
#            'octagon': 1,
#            'walnut': 1,
#            'cheek-fit': 1,
#            'schutzen': 1,
#            'stock': 3,
#            'telescop': 1,
#            'fit': 2,
#            'rememb': 22,
#            'lock': 5,
#            'lay': 37,
#            'asleep': 11,
#            'woke': 16,
#            'ciaou': 7,
#            'kind': 8,
#            'magnificent.': 1,
#            'put': 103,
#            'arm': 35,
#            'kiss': 26,
#            'oughf': 1,
#            'dirti': 11,
#            'wash.': 2,
#            'once.': 3,
#            'everywher': 4,
#            'milan': 20,
#            'florenc': 1,
#            'villa': 27,
#            'san': 11,
#            'giovanni': 1,
#            'messina': 1,
#            'taormina—': 1,
#            'time-t': 1,
#            'adventur': 2,
#            'yes.': 38,
#            'milano': 1,
#            'firenz': 1,
#            'roma': 2,
#            'napoli—': 1,
#            'enough': 19,
#            'best.': 2,
#            'milano.': 1,
#            'meet': 4,
#            'cova': 3,
#            'before.': 3,
#            'wonderful.': 2,
#            'afternoon': 10,
#            'english': 37,
#            'miss': 43,
#            'barkley': 29,
#            'take': 107,
#            'call': 34,
#            'marri': 25,
#            'barkley.': 3,
#            'wash': 13,
#            'anybodi': 8,
#            'work': 53,
#            'sinc': 5,
#            'frostbit': 1,
#            'chilblain': 1,
#            'jaundic': 2,
#            'gonorrhea': 1,
#            'self-inflict': 2,
#            'wound': 44,
#            'pneumonia': 1,
#            'hard': 38,
#            'soft': 6,
#            'chancr': 1,
#            'week': 6,
#            'rock': 7,
#            'fragment': 4,
#            'real': 8,
#            'perhap': 15,
#            'right': 118,
#            'barkley—aft': 1,
#            'absolut': 1,
#            'basin': 8,
#            'full': 17,
#            'to-night': 8,
#            'sleep': 54,
#            'fresh': 2,
#            'shirt': 11,
#            'rub': 3,
#            'towel': 1,
#            'lie': 34,
#            'close': 50,
#            'good-look': 2,
#            'age': 4,
#            'surgeon': 2,
#            'loan': 2,
#            'fifti': 4,
#            'lire.': 3,
#            'pocket-book': 3,
#            'hang': 6,
#            'note': 8,
#            'fold': 5,
#            'without': 22,
#            'slid': 2,
#            'breech': 3,
#            'impress': 7,
#            'man': 57,
#            'suffici': 1,
#            'wealth': 1,
#            'financi': 1,
#            'protector.': 1,
#            'hell': 19,
#            'disappoint': 3,
#            'hurt': 15,
#            'written': 4,
#            'prepar': 2,
#            'felt': 53,
#            'tri': 50,
#            'final': 17,
#            'understood': 7,
#            'almost': 24,
#            'drunk': 22,
#            'coffe': 19,
#            'strega': 2,
#            'argu': 2,
#            'frozen': 2,
#            'powderi': 1,
#            'hare-track': 1,
#            'hat': 17,
#            'lord': 3,
#            'smoke': 18,
#            'whirl': 1,
#            'need': 20,
#            'stop': 90,
#            'strang': 15,
#            'excit': 12,
#            'wake': 18,
#            'world': 8,
#            'unreal': 2,
#            'resum': 1,
#            'unknow': 1,
#            'sure': 22,
#            'morn': 32,
#            'sharp': 6,
#            'disput': 1,
#            'cost': 3,
#            'pleasant': 17,
#            'fond': 3,
#            'breakfast': 21,
#            'lunch': 19,
#            'alway': 54,
#            'better': 58,
#            'unless': 5,
#            'tast': 6,
#            'alik': 6,
#            'known': 4,
#            'learn': 12,
#            'abl': 12,
#            'forget': 10,
#            'although': 6,
#            'meantim': 1,
#            'meal': 6,
#            'finish': 18,
#            'argument': 1,
#            'happi': 20,
#            'attack': 30,
#            'suppos': 20,
#            'attack.': 4,
#            'shall': 2,
#            'nod': 6,
#            'alon': 24,
#            'right.': 46,
#            'anyth': 69,
#            'anyway': 18,
#            'got': 79,
#            '4': 1,
#            'batteri': 5,
#            'gravel': 4,
#            'moist': 1,
#            'grass': 2,
#            'dew': 1,
#            'twice': 6,
#            'air': 12,
#            'blow': 18,
#            'pajama': 1,
#            'flap': 1,
#            'evid': 4,
#            'directli': 2,
#            'nuisanc': 2,
#            'comfort': 10,
#            'bigger': 3,
#            'dress': 36,
#            'downstair': 9,
#            'kitchen': 8,
#            'garag': 3,
#            'ten': 7,
#            'line': 61,
#            'shed': 3,
#            'top-heavi': 1,
#            'blunt-nos': 1,
#            'paint': 4,
#            'built': 3,
#            'moving-van': 2,
#            'mechan': 8,
#            'yard': 8,
#            'three': 45,
#            'station': 39,
#            'task': 1,
#            'signor': 10,
#            'protect': 5,
#            'hill.': 1,
#            'bad': 50,
#            'machin': 4,
#            'march.': 1,
#            'permiss': 2,
#            'wipe': 10,
#            'jumper': 1,
#            'grin': 2,
#            'matter': 24,
#            'another.': 1,
#            'rings.': 1,
#            'disgrac': 3,
#            'empti': 25,
#            'engin': 13,
#            'part': 9,
#            'moder': 4,
#            'freshli': 3,
#            'tire': 53,
#            'cut': 38,
#            'stone': 29,
#            'bruis': 1,
#            'condit': 3,
#            'imagin': 2,
#            'obtain': 1,
#            'smooth': 7,
#            'function': 1,
#            'busi': 11,
#            'remov': 2,
#            'sick': 13,
#            'haul': 7,
#            'distribut': 1,
#            'paper': 49,
#            'depend': 5,
#            'consider': 1,
#            'extent': 1,
#            'troubl': 17,
#            'sergeant': 24,
#            'tenente.': 13,
#            'gasolin': 1,
#            'park': 3,
#            'place.': 5,
#            'drank': 28,
#            'bowl': 4,
#            'pale': 3,
#            'sweet': 13,
#            'condens': 1,
#            'milk': 3,
#            'begin': 8,
#            'dryness': 1,
#            'nose': 7,
#            'meant': 5,
#            'hot': 25,
#            'post': 23,
#            'run': 14,
#            'divis': 2,
#            'told': 28,
#            'gorg': 1,
#            'near': 15,
#            'keep': 33,
#            'select': 1,
#            'infantri': 3,
#            'gave': 26,
#            'fals': 3,
#            'hugo': 1,
#            'grammar': 1,
#            'hair': 22,
#            'shone': 5,
#            'splendid': 19,
#            'ye': 106,
#            'pleas': 47,
#            'her.': 9,
#            'till': 6,
#            'up.': 11,
#            'are.': 5,
#            'brush': 24,
#            'minut': 13,
#            'drink.': 4,
#            'grappa.': 1,
#            'extend': 2,
#            'grappa': 7,
#            'strong': 4,
#            'second': 18,
#            'stair': 17,
#            'german': 33,
#            'nurs': 56,
#            'toward': 50,
#            'salut': 6,
#            'oh': 63,
#            'no.': 24,
#            'odd': 2,
#            'thing—to': 1,
#            'army.': 4,
#            'ambulance.': 2,
#            'explan': 4,
#            'everything.': 2,
#            'brought': 38,
#            'was.': 3,
#            'aw': 20,
#            'nice.': 4,
#            'relief': 1,
#            'stick': 9,
#            'quit': 29,
#            'tall': 14,
#            'blond': 3,
#            'tawni': 1,
#            'skin': 5,
#            'thought': 65,
#            'rattan': 1,
#            'toy': 1,
#            'riding-crop': 1,
#            'bound': 2,
#            'belong': 1,
#            'boy': 32,
#            'kill': 32,
#            'year.': 2,
#            'sorry.': 2,
#            'somme.': 1,
#            'ghastli': 1,
#            'show.': 1,
#            'sort': 9,
#            'sent': 11,
#            'return': 7,
#            'things.': 5,
#            'engag': 1,
#            'eight': 2,
#            'together.': 3,
#            'fool': 7,
#            'given': 3,
#            'him.': 7,
#            'see.': 7,
#            'much.': 16,
#            'died.': 1,
#            'someth': 76,
#            'know.': 14,
#            'wors': 12,
#            'stand': 29,
#            'ferguson': 33,
#            'helen': 3,
#            'doctor': 66,
#            'good.': 6,
#            'rare': 2,
#            'find': 30,
#            'quite.': 1,
#            'silli': 10,
#            'now.': 22,
#            'done': 18,
#            'fifteen': 6,
#            'idea': 5,
#            'sabr': 2,
#            'bandag': 7,
#            'shot': 28,
#            'shoulder': 25,
#            'picturesque.': 1,
#            'picturesqu': 1,
#            'realiz': 18,
#            'franc': 6,
#            'blew': 8,
#            'bits.': 1,
#            'crack': 10,
#            'somewhere.': 1,
#            'somm': 1,
#            'crack.': 2,
#            'summer.': 1,
#            'may': 15,
#            'too.': 12,
#            'not.': 7,
#            'itali': 12,
#            'well.': 2,
#            'abbastanza': 1,
#            'bene': 1,
#            'translat': 5,
#            'england': 3,
#            'scotch': 4,
#            'blankli': 1,
#            'scotland': 2,
#            'england.': 1,
#            'pa': 1,
#            'encor': 1,
#            'english.': 6,
#            'literally.': 1,
#            'home': 15,
#            'prefer': 1,
#            'notic': 8,
#            '5': 1,
#            'drove': 19,
#            'duty—': 1,
#            'american': 32,
#            'am.': 3,
#            'happen': 28,
#            'join': 5,
#            'afraid': 30,
#            'italian.': 2,
#            'language.': 2,
#            'somebodi': 11,
#            'weeks.': 1,
#            'studi': 7,
#            'clock': 17,
#            'lot': 9,
#            'italians.': 2,
#            'languag': 1,
#            'uniforms.': 1,
#            'rivederci': 1,
#            'rivederla.': 1,
#            'imposs': 6,
#            'foreign': 4,
#            'embarrass': 5,
#            'export': 1,
#            'bridgehead': 2,
#            'plava': 5,
#            'advanc': 3,
#            'far': 34,
#            'lead': 6,
#            'pontoon': 4,
#            'machine-gun': 7,
#            'wide': 12,
#            'either': 9,
#            'transport': 3,
#            'shambl': 1,
#            'hold': 45,
#            'half': 9,
#            'nasti': 1,
#            'mutual': 1,
#            'toler': 1,
#            'kept': 24,
#            'repair': 1,
#            'smashed-down': 1,
#            'edg': 15,
#            'everybodi': 17,
#            'dugout': 12,
#            'rack': 4,
#            'rocket': 3,
#            'signal': 2,
#            'telephon': 6,
#            'wire': 5,
#            'quiet': 16,
#            'nobodi': 8,
#            'zig-zag': 1,
#            'turn': 64,
#            'system': 1,
#            'cart': 13,
#            'stretcher-bear': 5,
#            'level': 7,
#            'steadili': 6,
#            'shelter': 7,
#            'badlook': 1,
#            'bit': 8,
#            'drive': 17,
#            'yet': 14,
#            'grade': 2,
#            'metal-to-met': 1,
#            'brake': 2,
#            'carabinieri': 15,
#            'fallen': 2,
#            'seventy-seven': 1,
#            'whish': 1,
#            'rush': 5,
#            'bright': 6,
#            'burst': 8,
#            'wave': 20,
#            'land': 4,
#            'avoid': 3,
#            'high': 28,
#            'explos': 3,
#            'blast': 1,
#            ...})]

# %%
#順位チェック
sorted(freq_list_basic[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('said', 944),
#  ('go', 442),
#  ('look', 293),
#  ('went', 293),
#  ('would', 254),
#  ('one', 240),
#  ('come', 226),
#  ('see', 225),
#  ('could', 219),
#  ('get', 218),
#  ('back', 214),
#  ('catherin', 209),
#  ('road', 188),
#  ('want', 187),
#  ('like', 186),
#  ('came', 185),
#  ('know', 146),
#  ('good', 145),
#  ('think', 136),
#  ('two', 130),
#  ('littl', 127),
#  ('ask', 127),
#  ('right', 118),
#  ('rain', 113),
#  ('saw', 110),
#  ('time', 110),
#  ('start', 109),
#  ('car', 108),
#  ('take', 107),
#  ('ye', 106),
#  ('us', 105),
#  ('put', 103),
#  ('away', 102),
#  ('hand', 100),
#  ('love', 98),
#  ('along', 97),
#  ('long', 97),
#  ('rinaldi', 97),
#  ('bed', 94),
#  ('let', 91),
#  ('mountain', 90),
#  ('side', 90),
#  ('stop', 90),
#  ('room', 89),
#  ('night', 88),
#  ('took', 86),
#  ('thing', 85),
#  ('priest', 85),
#  ('much', 83),
#  ('sat', 83),
#  ('walk', 82),
#  ('darl', 82),
#  ('war', 81),
#  ('dark', 80),
#  ('piani', 80),
#  ('way', 79),
#  ('got', 79),
#  ('tell', 77),
#  ('feel', 76),
#  ('someth', 76),
#  ('make', 75),
#  ('window', 73),
#  ('never', 73),
#  ('bonello', 73),
#  ('across', 72),
#  ('door', 72),
#  ('talk', 72),
#  ('say', 72),
#  ('girl', 71),
#  ('major', 69),
#  ('anyth', 69),
#  ('open', 68),
#  ('place', 68),
#  ('big', 66),
#  ('doctor', 66),
#  ('river', 65),
#  ('anoth', 65),
#  ('noth', 65),
#  ('thought', 65),
#  ('outsid', 64),
#  ('turn', 64),
#  ('fine', 63),
#  ('oh', 63),
#  ('light', 63),
#  ('mani', 62),
#  ('head', 61),
#  ('line', 61),
#  ('watch', 60),
#  ('offic', 59),
#  ('drink', 59),
#  ('face', 58),
#  ('tenent', 58),
#  ('better', 58),
#  ('aymo', 58),
#  ('tree', 57),
#  ('die', 57),
#  ('man', 57),
#  ('babi', 57),
#  ('well', 56),
#  ('nurs', 56),
#  ('water', 55),
#  ('knew', 55),
#  ('italian', 54),
#  ('sleep', 54),
#  ('alway', 54),
#  ('lake', 54),
#  ('held', 53),
#  ('work', 53),
#  ('felt', 53),
#  ('tire', 53),
#  ('bridg', 52),
#  ('glass', 52),
#  ('must', 52),
#  ('stay', 52),
#  ('hous', 51),
#  ('day', 51),
#  ('town', 51),
#  ('hospit', 51),
#  ('move', 50),
#  ('give', 50),
#  ('still', 50),
#  ('close', 50),
#  ('tri', 50),
#  ('bad', 50),
#  ('toward', 50),
#  ('gone', 49),
#  ('wine', 49),
#  ('tabl', 49),
#  ('paper', 49),
#  ('heard', 48),
#  ('wet', 48),
#  ('front', 48),
#  ('around', 48),
#  ('pass', 47),
#  ('made', 47),
#  ('smile', 47),
#  ('first', 47),
#  ('pleas', 47),
#  ('stood', 47),
#  ('you.', 47),
#  ('cross', 46),
#  ('left', 46),
#  ('right.', 46),
#  ('besid', 46),
#  ('eat', 46),
#  ('it.', 45),
#  ('fire', 45),
#  ('three', 45),
#  ('hold', 45),
#  ('men', 44),
#  ('wound', 44),
#  ('row', 44),
#  ('leav', 43),
#  ('sit', 43),
#  ('miss', 43),
#  ('ahead', 43),
#  ('pull', 42),
#  ('austrian', 42),
#  ('peopl', 42),
#  ('snow', 42),
#  ('realli', 42),
#  ('believ', 42),
#  ('old', 42),
#  ('even', 41),
#  ('wish', 41),
#  ('hall', 40),
#  ('hotel', 40),
#  ('countri', 39),
#  ('wall', 39),
#  ('bottl', 39),
#  ('station', 39),
#  ('boat', 39),
#  ('driver', 38),
#  ('cold', 38),
#  ('field', 38),
#  ('floor', 38),
#  ('yes.', 38),
#  ('hard', 38),
#  ('cut', 38),
#  ('brought', 38),
#  ('mayb', 38),
#  ('beyond', 37),
#  ('sometim', 37),
#  ('lay', 37),
#  ('english', 37),
#  ('soldier', 36),
#  ('behind', 36),
#  ('dress', 36),
#  ('live', 35),
#  ('everi', 35),
#  ('seem', 35),
#  ('might', 35),
#  ('arm', 35),
#  ('wind', 34),
#  ('great', 34),
#  ('call', 34),
#  ('lie', 34),
#  ('far', 34),
#  ('fall', 33),
#  ('end', 33),
#  ('wait', 33),
#  ('keep', 33),
#  ('german', 33),
#  ('ferguson', 33),
#  ('ever', 32),
#  ('insid', 32),
#  ('morn', 32),
#  ('boy', 32),
#  ('kill', 32),
#  ('american', 32),
#  ('hope', 32),
#  ('train', 32),
#  ('clear', 31),
#  ('read', 31),
#  ('thank', 31),
#  ('carri', 30),
#  ('small', 30),
#  ('street', 30),
#  ('captain', 30),
#  ('point', 30),
#  ('attack', 30),
#  ('find', 30),
#  ('afraid', 30),
#  ('me.', 30),
#  ('shore', 30),
#  ('white', 29),
#  ('nice', 29),
#  ('laugh', 29),
#  ('bring', 29),
#  ('barkley', 29),
#  ('stone', 29),
#  ('quit', 29),
#  ('stand', 29),
#  ('bag', 29),
#  ('shook', 28),
#  ('sight', 28),
#  ('ought', 28),
#  ('beauti', 28),
#  ('drank', 28),
#  ('told', 28),
#  ('shot', 28),
#  ('happen', 28),
#  ('high', 28),
#  ('play', 28),
#  ('leg', 28),
#  ('bank', 28),
#  ('troop', 27),
#  ('villa', 27),
#  ('winter', 26),
#  ('armi', 26),
#  ('kiss', 26),
#  ('gave', 26),
#  ('gun', 25),
#  ('top', 25),
#  ('next', 25),
#  ('everyth', 25),
#  ('care', 25),
#  ('new', 25),
#  ('marri', 25),
#  ('empti', 25),
#  ('hot', 25),
#  ('shoulder', 25),
#  ('hear', 25),
#  ('seat', 24),
#  ('glad', 24),
#  ('differ', 24),
#  ('wore', 24),
#  ('almost', 24),
#  ('alon', 24),
#  ('matter', 24),
#  ('sergeant', 24),
#  ('brush', 24),
#  ('no.', 24),
#  ('kept', 24),
#  ('mind', 24),
#  ('wonder', 24),
#  ('god', 24),
#  ('step', 24),
#  ('wood', 24),
#  ('chees', 24),
#  ('barman', 24),
#  ('plain', 23),
#  ('dead', 23),
#  ('money', 23),
#  ('ambul', 23),
#  ('mask', 23),
#  ('post', 23),
#  ('word', 23),
#  ('orderli', 23),
#  ('cloth', 23),
#  ('passini', 23),
#  ('sun', 22),
#  ('gray', 22),
#  ('north', 22),
#  ('though', 22),
#  ('fast', 22),
#  ('rememb', 22),
#  ('without', 22),
#  ('drunk', 22),
#  ('sure', 22),
#  ('hair', 22),
#  ('now.', 22),
#  ('drop', 22),
#  ('question', 22),
#  ('soon', 22),
#  ('climb', 22),
#  ('send', 22),
#  ('togeth', 22),
#  ('wheel', 22),
#  ('retreat', 22),
#  ('thin', 21),
#  ('narrow', 21),
#  ('probabl', 21),
#  ('name', 21),
#  ('good-night', 21),
#  ('breakfast', 21),
#  ('cri', 21),
#  ('shut', 21),
#  ('good-bi', 21),
#  ('year', 20),
#  ('dri', 20),
#  ('bare', 20),
#  ('except', 20),
#  ('shell', 20),
#  ('mess', 20),
#  ('eye', 20),
#  ('lieuten', 20),
#  ('four', 20),
#  ('show', 20),
#  ('hill', 20),
#  ('found', 20),
#  ('milan', 20),
#  ('need', 20),
#  ('happi', 20),
#  ('suppos', 20),
#  ('aw', 20),
#  ('wave', 20),
#  ('main', 20),
#  ('oar', 20),
#  ('truck', 19),
#  ('udin', 19),
#  ('garden', 19),
#  ('ran', 19),
#  ('taken', 19),
#  ('later', 19),
#  ('ate', 19),
#  ('lift', 19),
#  ('els', 19),
#  ('use', 19),
#  ('help', 19),
#  ('order', 19),
#  ('father', 19),
#  ('enough', 19),
#  ('hell', 19),
#  ('coffe', 19),
#  ('lunch', 19),
#  ('splendid', 19),
#  ('drove', 19),
#  ('worri', 19),
#  ('column', 19),
#  ('breath', 19),
#  ('woman', 19),
#  ('canva', 18),
#  ('neck', 18),
#  ('cours', 18),
#  ('finger', 18),
#  ('warm', 18),
#  ('smell', 18),
#  ('smoke', 18),
#  ('wake', 18),
#  ('finish', 18),
#  ('anyway', 18),
#  ('blow', 18),
#  ('second', 18),
#  ('done', 18),
#  ('realiz', 18),
#  ('life', 18),
#  ('onto', 18),
#  ('piec', 18),
#  ('seen', 18),
#  ('knee', 18),
#  ('stretcher', 18),
#  ('carriag', 18),
#  ('embank', 18),
#  ('cat', 18),
#  ('beer', 18),
#  ('fight', 17),
#  ('box', 17),
#  ('forward', 17),
#  ('nearli', 17),
#  ('railway', 17),
#  ('friend', 17),
#  ('red', 17),
#  ('uniform', 17),
#  ('shoot', 17),
#  ('hit', 17),
#  ('full', 17),
#  ('final', 17),
#  ('hat', 17),
#  ('pleasant', 17),
#  ('troubl', 17),
#  ('stair', 17),
#  ('clock', 17),
#  ('everybodi', 17),
#  ('drive', 17),
#  ('sorri', 17),
#  ('chair', 17),
#  ('arrest', 17),
#  ('manera', 17),
#  ('guard', 17),
#  ('coat', 17),
#  ('earli', 16),
#  ('slowli', 16),
#  ('pick', 16),
#  ('listen', 16),
#  ('british', 16),
#  ('clean', 16),
#  ('flat', 16),
#  ('woke', 16),
#  ('much.', 16),
#  ('quiet', 16),
#  ('mean', 16),
#  ('poor', 16),
#  ('dear', 16),
#  ('here.', 16),
#  ('danger', 16),
#  ('bar', 16),
#  ('offici', 16),
#  ('montreux', 16),
#  ('afterward', 15),
#  ('past', 15),
#  ('cape', 15),
#  ('south', 15),
#  ('broken', 15),
#  ('pour', 15),
#  ('helmet', 15),
#  ('perhap', 15),
#  ('hurt', 15),
#  ('strang', 15),
#  ('near', 15),
#  ('may', 15),
#  ('home', 15),
#  ('edg', 15),
#  ('carabinieri', 15),
#  ('short', 15),
#  ('ride', 15),
#  ('gordini', 15),
#  ('hour', 15),
#  ('cognac', 15),
#  ('pain', 15),
#  ('brandi', 15),
#  ('cheer', 15),
#  ('wife', 15),
#  ('summer', 14),
#  ('motor', 14),
#  ('valley', 14),
#  ('cloud', 14),
#  ('badli', 14),
#  ('café', 14),
#  ('beard', 14),
#  ('last', 14),
#  ('fill', 14),
#  ('five', 14),
#  ('touch', 14),
#  ('run', 14),
#  ('tall', 14),
#  ('know.', 14),
#  ('yet', 14),
#  ('war.', 14),
#  ('henri', 14),
#  ('time.', 14),
#  ('again.', 14),
#  ('oper', 14),
#  ('them.', 14),
#  ('sever', 14),
#  ('hurri', 14),
#  ('low', 14),
#  ('track', 14),
#  ('opposit', 14),
#  ('push', 14),
#  ('hay', 14),
#  ('count', 14),
#  ('umbrella', 14),
#  ('late', 13),
#  ('villag', 13),
#  ('load', 13),
#  ('muddi', 13),
#  ('pack', 13),
#  ('whole', 13),
#  ('suddenli', 13),
#  ('young', 13),
#  ('spoke', 13),
#  ('shout', 13),
#  ('spring', 13),
#  ('foot', 13),
#  ('wash', 13),
#  ('engin', 13),
#  ('sick', 13),
#  ('tenente.', 13),
#  ('sweet', 13),
#  ('minut', 13),
#  ('cart', 13),
#  ('becom', 13),
#  ('regiment', 13),
#  ('pretti', 13),
#  ('christ', 13),
#  ('porter', 13),
#  ('follow', 13),
#  ('tie', 13),
#  ('break', 13),
#  ('grand', 13),
#  ('flash', 12),
#  ('cover', 12),
#  ('forest', 12),
#  ('black', 12),
#  ('hung', 12),
#  ('understand', 12),
#  ('lose', 12),
#  ('joke', 12),
#  ('rome', 12),
#  ('write', 12),
#  ('game', 12),
#  ('boot', 12),
#  ('excit', 12),
#  ('learn', 12),
#  ('abl', 12),
#  ('air', 12),
#  ('wors', 12),
#  ('too.', 12),
#  ('itali', 12),
#  ('wide', 12),
#  ('dugout', 12),
#  ('farmhous', 12),
#  ('reach', 12),
#  ('fun', 12),
#  ('gino', 12),
#  ('daylight', 12),
#  ('expect', 12),
#  ('switzerland', 12),
#  ('whiskey', 12),
#  ('fell', 11),
#  ('brown', 11),
#  ('cool', 11),
#  ('branch', 11),
#  ('mud', 11),
#  ('rifl', 11),
#  ('child', 11),
#  ('cap', 11),
#  ('led', 11),
#  ('lost', 11),
#  ('ground', 11),
#  ('commenc', 11),
#  ('rest', 11),
#  ('offens', 11),
#  ('report', 11),
#  ('ga', 11),
#  ('asleep', 11),
#  ('dirti', 11),
#  ('san', 11),
#  ('shirt', 11),
#  ('busi', 11),
#  ('up.', 11),
#  ('sent', 11),
#  ('somebodi', 11),
#  ('out.', 11),
#  ('gotten', 11),
#  ('plenti', 11),
#  ('wear', 11),
#  ('medic', 11),
#  ('elev', 11),
#  ('ice', 11),
#  ('saint', 11),
#  ('to-morrow', 11),
#  ('ridg', 11),
#  ('screen', 11),
#  ('feet', 11),
#  ('sister', 11),
#  ('straight', 11),
#  ('stomach', 11),
#  ('greffi', 11),
#  ('grow', 11),
#  ('dust', 10),
#  ('storm', 10),
#  ('path', 10),
#  ('mouth', 10),
#  ('easili', 10),
#  ('true', 10),
#  ('one.', 10),
#  ('famili', 10),
#  ('peasant', 10),
#  ('afternoon', 10),
#  ('forget', 10),
#  ('comfort', 10),
#  ('signor', 10),
#  ('wipe', 10),
#  ('silli', 10),
#  ('crack', 10),
#  ('funni', 10),
#  ('tight', 10),
#  ('pistol', 10),
#  ('driveway', 10),
#  ('sound', 10),
#  ('speak', 10),
#  ('sheet', 10),
#  ('scare', 10),
#  ('soup', 10),
#  ('hundr', 10),
#  ('readi', 10),
#  ('awak', 10),
#  ('vermouth', 10),
#  ('corridor', 10),
#  ('corner', 10),
#  ('hedg', 10),
#  ('egg', 10),
#  ('sport', 10),
#  ('locarno', 10),
#  ('march', 9),
#  ('usual', 9),
#  ('gorizia', 9),
#  ('mile', 9),
#  ('chang', 9),
#  ('quickli', 9),
#  ('pocket', 9),
#  ('card', 9),
#  ('abruzzi', 9),
#  ('cup', 9),
#  ('met', 9),
#  ('whether', 9),
#  ('upstair', 9),
#  ('downstair', 9),
#  ('part', 9),
#  ('her.', 9),
#  ('stick', 9),
#  ('sort', 9),
#  ('lot', 9),
#  ('either', 9),
#  ('half', 9),
#  ('rather', 9),
#  ('brave', 9),
#  ('us.', 9),
#  ('slap', 9),
#  ('darling.', 9),
#  ('night.', 9),
#  ('away.', 9),
#  ('hors', 9),
#  ('deep', 9),
#  ('so.', 9),
#  ('damn', 9),
#  ('stream', 9),
#  ('more.', 9),
#  ('sleepi', 9),
#  ('stove', 9),
#  ('hungri', 9),
#  ('polic', 9),
#  ('stern', 9),
#  ('swiss', 9),
#  ('fergi', 9),
#  ('toboggan', 9),
#  ('guttingen', 9),
#  ('waiter', 9),
#  ('trunk', 8),
#  ('green', 8),
#  ('victori', 8),
#  ('bombard', 8),
#  ('smash', 8),
#  ('metal', 8),
#  ('often', 8),
#  ('mother', 8),
#  ('shadow', 8),
#  ('marbl', 8),
#  ('kind', 8),
#  ('anybodi', 8),
#  ('real', 8),
#  ('basin', 8),
#  ('to-night', 8),
#  ('note', 8),
#  ('world', 8),
#  ('kitchen', 8),
#  ('mechan', 8),
#  ('yard', 8),
#  ('begin', 8),
#  ('blew', 8),
#  ('notic', 8),
#  ('nobodi', 8),
#  ('bit', 8),
#  ('burst', 8),
#  ('lean', 8),
#  ('pat', 8),
#  ('knock', 8),
#  ('wooden', 8),
#  ('bloodi', 8),
#  ('crazi', 8),
#  ('trip', 8),
#  ('sing', 8),
#  ('handl', 8),
#  ('stori', 8),
#  ('alreadi', 8),
#  ('t.', 8),
#  ('crowd', 8),
#  ('hole', 8),
#  ('dug', 8),
#  ('hate', 8),
#  ('nois', 8),
#  ('mama', 8),
#  ('luck', 8),
#  ('bent', 8),
#  ('blood', 8),
#  ('slept', 8),
#  ('star', 8),
#  ('mine', 8),
#  ('older', 8),
#  ('bainsizza', 8),
#  ('fine.', 8),
#  ('there.', 8),
#  ('champagn', 8),
#  ('barn', 8),
#  ('timber', 8),
#  ('buy', 8),
#  ('passport', 8),
#  ('custom', 8),
#  ('moon', 8),
#  ('sport.', 8),
#  ('dial', 8),
#  ('rise', 7),
#  ('artilleri', 7),
#  ('vine', 7),
#  ('success', 7),
#  ('leather', 7),
#  ('heavi', 7),
#  ('king', 7),
#  ('thick', 7),
#  ('iron', 7),
#  ('squar', 7),
#  ('bodi', 7),
#  ('dull', 7),
#  ('spaghetti', 7),
#  ('tunic', 7),
#  ('win', 7),
#  ('address', 7),
#  ('spread', 7),
#  ('thumb', 7),
#  ('bench', 7),
#  ('desk', 7),
#  ('steel', 7),
#  ('ciaou', 7),
#  ('rock', 7),
#  ('impress', 7),
#  ('understood', 7),
#  ('ten', 7),
#  ('smooth', 7),
#  ('haul', 7),
#  ('nose', 7),
#  ('grappa', 7),
#  ('return', 7),
#  ('fool', 7),
#  ('him.', 7),
#  ('see.', 7),
#  ('bandag', 7),
#  ('not.', 7),
#  ('studi', 7),
#  ('machine-gun', 7),
#  ('level', 7),
#  ('shelter', 7),
#  ('dinner', 7),
#  ('certain', 7),
#  ('complet', 7),
#  ('also', 7),
#  ('back.', 7),
#  ('third', 7),
#  ('brother', 7),
#  ('instead', 7),
#  ('rotten', 7),
#  ('collar', 7),
#  ('closer', 7),
#  ('america', 7),
#  ('french', 7),
#  ('austria', 7),
#  ('roof', 7),
#  ('bacchu', 7),
#  ('best', 7),
#  ('go.', 7),
#  ('hello', 7),
#  ('caught', 7),
#  ('rail', 7),
#  ('cigarett', 7),
#  ('food', 7),
#  ('gavuzzi', 7),
#  ('canteen', 7),
#  ('shoe', 7),
#  ('possibl', 7),
#  ('seriou', 7),
#  ('fellow', 7),
#  ('born', 7),
#  ('drip', 7),
#  ('declar', 7),
#  ('that.', 7),
#  ('number', 7),
#  ('save', 7),
#  ('then.', 7),
#  ('over.', 7),
#  ('machine-gunn', 7),
#  ('compart', 7),
#  ('throw', 7),
#  ('meat', 7),
#  ('bread', 7),
#  ('something.', 7),
#  ('brigad', 7),
#  ('barto', 7),
#  ('roll', 7),
#  ('tagliamento', 7),
#  ('ditch', 7),
#  ('vehicl', 7),
#  ('answer', 7),
#  ('voic', 7),
#  ('montreux.', 7),
#  ('mrs.', 7),
#  ('log', 7),
#  ('soda', 7),
#  ('ham', 7),
#  ('traffic', 6),
#  ('mule', 6),
#  ('chestnut', 6),
#  ('camion', 6),
#  ('seven', 6),
#  ('militari', 6),
#  ('sky', 6),
#  ('trench', 6),
#  ('none', 6),
#  ('explain', 6),
#  ('hunt', 6),
#  ('women', 6),
#  ('sunlight', 6),
#  ('courtyard', 6),
#  ('blanket', 6),
#  ('tin', 6),
#  ('soft', 6),
#  ('week', 6),
#  ('hang', 6),
#  ('sharp', 6),
#  ('tast', 6),
#  ('alik', 6),
#  ('although', 6),
#  ('meal', 6),
#  ('nod', 6),
#  ('twice', 6),
#  ('till', 6),
#  ('salut', 6),
#  ('good.', 6),
#  ('fifteen', 6),
#  ('franc', 6),
#  ('english.', 6),
#  ('imposs', 6),
#  ('lead', 6),
#  ('telephon', 6),
#  ('steadili', 6),
#  ('bright', 6),
#  ('lip', 6),
#  ('dog', 6),
#  ('pillow', 6),
#  ('civilian', 6),
#  ('jerk', 6),
#  ('bump', 6),
#  ('forehead', 6),
#  ('trouser', 6),
#  ('coupl', 6),
#  ('canal', 6),
#  ('silver', 6),
#  ('island', 6),
#  ('bassi', 6),
#  ('federico', 6),
#  ('down.', 6),
#  ('hail', 6),
#  ('lone', 6),
#  ('separ', 6),
#  ('rough', 6),
#  ('hardli', 6),
#  ('mat', 6),
#  ('entranc', 6),
#  ('jam', 6),
#  ('mustach', 6),
#  ('chanc', 6),
#  ('goe', 6),
#  ('defeat', 6),
#  ('nation', 6),
#  ('is.', 6),
#  ('stupid', 6),
#  ('board', 6),
#  ('mia', 6),
#  ('putte', 6),
#  ('son', 6),
#  ('mestr', 6),
#  ('cork', 6),
#  ('serv', 6),
#  ('reason', 6),
#  ('honor', 6),
#  ('pay', 6),
#  ('polit', 6),
#  ('easi', 6),
#  ('anarchist', 6),
#  ('younger', 6),
#  ('began', 6),
#  ('sob', 6),
#  ('virgin', 6),
#  ('sweet.', 6),
#  ('mirror', 6),
#  ('side-road', 6),
#  ('desert', 6),
#  ('abandon', 6),
#  ('catch', 6),
#  ('build', 6),
#  ('bicycl', 6),
#  ('socialist', 6),
#  ('carabinier', 6),
#  ('paid', 6),
#  ('ladi', 6),
#  ('stresa', 6),
#  ('bought', 6),
#  ('billiard', 6),
#  ('devout', 6),
#  ('pallanza', 6),
#  ('luge-', 6),
#  ('swiftli', 5),
#  ('dusti', 5),
#  ('laid', 5),
#  ('mist', 5),
#  ('clip', 5),
#  ('month', 5),
#  ('plateau', 5),
#  ('stump', 5),
#  ('yellow', 5),
#  ('suck', 5),
#  ('swung', 5),
#  ('to-day', 5),
#  ('book', 5),
#  ('certainli', 5),
#  ('slope', 5),
#  ('lock', 5),
#  ('sinc', 5),
#  ('fold', 5),
#  ('unless', 5),
#  ('batteri', 5),
#  ('protect', 5),
#  ('depend', 5),
#  ('place.', 5),
#  ('meant', 5),
#  ('shone', 5),
#  ('are.', 5),
#  ('skin', 5),
#  ('things.', 5),
#  ('idea', 5),
#  ('translat', 5),
#  ('join', 5),
#  ('embarrass', 5),
#  ('plava', 5),
#  ('wire', 5),
#  ('stretcher-bear', 5),
#  ('rush', 5),
#  ('angri', 5),
#  ('exactli', 5),
#  ('stroke', 5),
#  ('candl', 5),
#  ('uncomfort', 5),
#  ('pace', 5),
#  ('shame', 5),
#  ('sign', 5),
#  ('pretend', 5),
#  ('deal', 5),
#  ('slip', 5),
#  ('morning.', 5),
#  ('papers.', 5),
#  ('fat', 5),
#  ('supper', 5),
#  ('click', 5),
#  ('fli', 5),
#  ('chew', 5),
#  ('nothing.', 5),
#  ('hallway', 5),
#  ('posit', 5),
#  ('moment', 5),
#  ('anything.', 5),
#  ('anthoni', 5),
#  ('spill', 5),
#  ('chain', 5),
#  ('settl', 5),
#  ('bersaglieri', 5),
#  ('rang', 5),
#  ('brickyard', 5),
#  ('packag', 5),
#  ('off.', 5),
#  ('earth', 5),
#  ('forcep', 5),
#  ('patriot', 5),
#  ('eat.', 5),
#  ('float', 5),
#  ('choke', 5),
#  ('little.', 5),
#  ('sleev', 5),
#  ('blown', 5),
#  ('straighten', 5),
#  ('wrap', 5),
#  ...]

# %%
#Eliminate stopwords and symbols

import matplotlib.pyplot as plt
# %matplotlib inline

freq_list_new = []
for i in text:
    freq_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in freq_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
#文章を小文字化
sentence_small = [w.lower() for w in sentence1]
sentence_small
# Out:
# ['in the late summer of that year we lived in a house in a village that looked across the river and the plain to the mountains.',
#  'in the bed of the river there were pebbles and boulders, dry and white in the sun, and the water was clear and swiftly moving and blue in the channels.',
#  'troops went by the house and down the road and the dust they raised powdered the leaves of the trees.',
#  'the trunks of the trees too were dusty and the leaves fell early that year and we saw the troops marching along the road and the dust rising and leaves, stirred by the breeze, falling and the soldiers marching and afterward the road bare and white except for the leaves.',
#  'the plain was rich with crops; there were many orchards of fruit trees and beyond the plain the mountains were brown and bare.',
#  'there was fighting in the mountains and at night we could see the flashes from the artillery.',
#  'in the dark it was like summer lightning, but the nights were cool and there was not the feeling of a storm coming.',
#  'sometimes in the dark we heard the troops marching under the window and guns going past pulled by motor-tractors.',
#  'there was much traffic at night and many mules on the roads with boxes of ammunition on each side of their pack-saddles and gray motor trucks that carried men, and other trucks with loads covered with canvas that moved slower in the traffic.',
#  'there were big guns too that passed in the day drawn by tractors, the long barrels of the guns covered with green branches and green leafy branches and vines laid over the tractors.',
#  'to the north we could look across a valley and see a forest of chestnut trees and behind it another mountain on this side of the river.',
#  'there was fighting for that mountain too, but it was not successful, and in the fall when the rains came the leaves all fell from the chestnut trees and the branches were bare and the trunks black with rain.',
#  'the vineyards were thin and bare-branched too and all the country wet and brown and dead with the autumn.',
#  'there were mists over the river and clouds on the mountain and the trucks splashed mud on the road and the troops were muddy and wet in their capes; their rifles were wet and under their capes the two leather cartridge-boxes on the front of the belts, gray leather boxes heavy with the packs of clips of thin, long 6.5 mm.',
#  'cartridges, bulged forward under the capes so that the men, passing on the road, marched as though they were six months gone with child.',
#  'there were small gray motor cars that passed going very fast; usually there was an officer on the seat with the driver and more officers in the back seat.',
#  'they splashed more mud than the camions even and if one of the officers in the back was very small and sitting between two generals, he himself so small that you could not see his face but only the top of his cap and his narrow back, and if the car went especially fast it was probably the king.',
#  'he lived in udine and came out in this way nearly every day to see how things were going, and things went very badly.',
#  'at the start of the winter came the permanent rain and with the rain came the cholera.',
#  'but it was checked and in the end only seven thousand died of it in the army.',
#  '2\nthe next year there were many victories.',
#  'the mountain that was beyond the valley and the hillside where the chestnut forest grew was captured and there were victories beyond the plain on the plateau to the south and we crossed the river in august and lived in a house in gorizia that had a fountain and many thick shady trees in a walled garden and a wistaria vine purple on the side of the house.',
#  'now the fighting was in the next mountains beyond and was not a mile away.',
#  'the town was very nice and our house was very fine.',
#  'the river ran behind us and the town had been captured very handsomely but the mountains beyond it could not be taken and i was very glad the austrians seemed to want to come back to the town some time, if the war should end, because they did not bombard it to destroy it but only a little in a military way.',
#  'people lived on in it and there were hospitals and cafés and artillery up side streets and two bawdy houses, one for troops and one for officers, and with the end of the summer, the cool nights, the fighting in the mountains beyond the town, the shell-marked iron of the railway bridge, the smashed tunnel by the river where the fighting had been, the trees around the square and the long avenue of trees that led to the square; these with there being girls in the town, the king passing in his motor car, sometimes now seeing his face and little long necked body and gray beard like a goat’s chin tuft; all these with the sudden interiors of houses that had lost a wall through shelling, with plaster and rubble in their gardens and sometimes in the street, and the whole thing going well on the carso made the fall very different from the last fall when we had been in the country.',
#  'the war was changed too.',
#  'the forest of oak trees on the mountain beyond the town was gone.',
#  'the forest had been green in the summer when we had come into the town but now there were the stumps and the broken trunks and the ground torn up, and one day at the end of the fall when i was out where the oak forest had been i saw a cloud coming over the mountain.',
#  'it came very fast and the sun went a dull yellow and then everything was gray and the sky was covered and the cloud came on down the mountain and suddenly we were in it and it was snow.',
#  'the snow slanted across the wind, the bare ground was covered, the stumps of trees projected, there was snow on the guns and there were paths in the snow going back to the latrines behind trenches.',
#  'later, below in the town, i watched the snow falling, looking out of the window of the bawdy house, the house for officers, where i sat with a friend and two glasses drinking a bottle of asti, and, looking out at the snow falling slowly and heavily, we knew it was all over for that year.',
#  'up the river the mountains had not been taken; none of the mountains beyond the river had been taken.',
#  'that was all left for next year.',
#  'my friend saw the priest from our mess going by in the street, walking carefully in the slush, and pounded on the window to attract his attention.',
#  'the priest looked up.',
#  'he saw us and smiled.',
#  'my friend motioned for him to come in.',
#  'the priest shook his head and went on.',
#  'that night in the mess after the spaghetti course, which every one ate very quickly and seriously, lifting the spaghetti on the fork until the loose strands hung clear then lowering it into the mouth, or else using a continuous lift and sucking into the mouth, helping ourselves to wine from the grass-covered gallon flask; it swung in a metal cradle and you pulled the neck of the flask down with the forefinger and the wine, clear red, tannic and lovely, poured out into the glass held with the same hand; after this course, the captain commenced picking on the priest.',
#  'the priest was young and blushed easily and wore a uniform like the rest of us but with a cross in dark red velvet above the left breast pocket of his gray tunic.',
#  'the captain spoke pidgin italian for my doubtful benefit, in order that i might understand perfectly, that nothing should be lost.',
#  '“priest to-day with girls,” the captain said looking at the priest and at me.',
#  'the priest smiled and blushed and shook his head.',
#  'this captain baited him often.',
#  '“not true?” asked the captain.',
#  '“to-day i see priest with girls.”\n\n“no,” said the priest.',
#  'the other officers were amused at the baiting.',
#  '“priest not with girls,” went on the captain.',
#  '“priest never with girls,” he explained to me.',
#  'he took my glass and filled it, looking at my eyes all the time, but not losing sight of the priest.',
#  '“priest every night five against one.” every one at the table laughed.',
#  '“you understand?',
#  'priest every night five against one.” he made a gesture and laughed loudly.',
#  'the priest accepted it as a joke.',
#  '“the pope wants the austrians to win the war,” the major said.',
#  '“he loves franz joseph.',
#  'that’s where the money comes from.',
#  'i am an atheist.”\n\n“did you ever read the black pig?” asked the lieutenant.',
#  '“i will get you a copy.',
#  'it was that which shook my faith.”\n\n“it is a filthy and vile book,” said the priest.',
#  '“you do not really like it.”\n\n“it is very valuable,” said the lieutenant.',
#  '“it tells you about those priests.',
#  'you will like it,” he said to me.',
#  'i smiled at the priest and he smiled back across the candle-light.',
#  '“don’t you read it,” he said.',
#  '“i will get it for you,” said the lieutenant.',
#  '“all thinking men are atheists,” the major said.',
#  '“i do not believe in the free masons however.”\n\n“i believe in the free masons,” the lieutenant said.',
#  '“it is a noble organization.” some one came in and as the door opened i could see the snow falling.',
#  '“there will be no more offensive now that the snow has come,” i said.',
#  '“certainly not,” said the major.',
#  '“you should go on leave.',
#  'you should go to rome, naples, sicily—”\n\n“he should visit amalfi,” said the lieutenant.',
#  '“i will write you cards to my family in amalfi.',
#  'they will love you like a son.”\n\n“he should go to palermo.”\n\n“he ought to go to capri.”\n\n“i would like you to see abruzzi and visit my family at capracotta,” said the priest.',
#  '“listen to him talk about the abruzzi.',
#  'there’s more snow there than here.',
#  'he doesn’t want to see peasants.',
#  'let him go to centres of culture and civilization.”\n\n“he should have fine girls.',
#  'i will give you the addresses of places in naples.',
#  'beautiful young girls—accompanied by their mothers.',
#  'ha!',
#  'ha!',
#  'ha!” the captain spread his hand open, the thumb up and fingers outspread as when you make shadow pictures.',
#  'there was a shadow from his hand on the wall.',
#  'he spoke again in pidgin italian.',
#  '“you go away like this,” he pointed to the thumb, “and come back like this,” he touched the little finger.',
#  'every one laughed.',
#  '“look,” said the captain.',
#  'he spread the hand again.',
#  'again the candle-light made its shadows on the wall.',
#  'he started with the upright thumb and named in their order the thumb and four fingers, “soto-tenente (the thumb), tenente (first finger), capitano (next finger), maggiore (next to the little finger), and tenentecolonello (the little finger).',
#  'you go away soto-tenente!',
#  'you come back soto-colonello!” they all laughed.',
#  'the captain was having a great success with finger games.',
#  'he looked at the priest and shouted, “every night priest five against one!” they all laughed again.',
#  '“you must go on leave at once,” the major said.',
#  '“i would like to go with you and show you things,” the lieutenant said.',
#  '“when you come back bring a phonograph.”\n\n“bring good opera disks.”\n\n“bring caruso.”\n\n“don’t bring caruso.',
#  'he bellows.”\n\n“don’t you wish you could bellow like him?”\n\n“he bellows.',
#  'i say he bellows!”\n\n“i would like you to go to abruzzi,” the priest said.',
#  'the others were shouting.',
#  '“there is good hunting.',
#  'you would like the people and though it is cold it is clear and dry.',
#  'you could stay with my family.',
#  'my father is a famous hunter.”\n\n“come on,” said the captain.',
#  '“we go whorehouse before it shuts.”\n\n“good-night,” i said to the priest.',
#  '“good-night,” he said.',
#  '3\nwhen i came back to the front we still lived in that town.',
#  'there were many more guns in the country around and the spring had come.',
#  'the fields were green and there were small green shoots on the vines, the trees along the road had small leaves and a breeze came from the sea.',
#  'i saw the town with the hill and the old castle above it in a cup in the hills with the mountains beyond, brown mountains with a little green on their slopes.',
#  'in the town there were more guns, there were some new hospitals, you met british men and sometimes women, on the street, and a few more houses had been hit by shell fire.',
#  'jt was warm and like the spring and i walked down the alleyway of trees, warmed from the sun on the wall, and found we still lived in the same house and that it all looked the same as when i had left it.',
#  'the door was open, there was a soldier sitting on a bench outside in the sun, an ambulance was waiting by the side door and inside the door, as i went in, there was the smell of marble floors and hospital.',
#  'it was all as i had left it except that now it was spring.',
#  'i looked in the door of the big room and saw the major sitting at his desk, the window open and the sunlight coming into the room.',
#  'he did not see me and i did not know whether to go in and report or go upstairs first and clean up.',
#  'i decided to go on upstairs.',
#  'the room i shared with the lieutenant rinaldi looked out on the courtyard.',
#  'the window was open, my bed was made up with blankets and my things hung on the wall, the gas mask in an oblong tin can, the steel helmet on the same peg.',
#  'at the foot of the bed was my flat trunk, and my winter boots, the leather shiny with oil, were on the trunk.',
#  'my austrian sniper’s rifle with its blued octagon barrel and the lovely dark walnut, cheek-fitted, schutzen stock, hung over the two beds.',
#  'the telescope that fitted it was, i remembered, locked in the trunk.',
#  'the lieutenant, rinaldi, lay asleep on the other bed.',
#  'he woke when he heard me in the room and sat up.',
#  '“ciaou!” he said.',
#  '“what kind of time did you have?”\n\n“magnificent.”\n\nwe shook hands and he put his arm around my neck and kissed me.',
#  '“oughf,” i said.',
#  '“you’re dirty,” he said.',
#  '“you ought to wash. where did you go and what did you do?',
#  'tell me everything at once.”\n\n“i went everywhere.',
#  'milan, florence, rome, naples, villa san giovanni, messina, taormina—”\n\n“you talk like a time-table.',
#  'did you have any beautiful adventures?”\n\n“yes.”\n\n“where?”\n\n“milano, firenze, roma, napoli—”\n\n“that’s enough.',
#  'tell me really what was the best.”\n\n“in milano.”\n\n“that was because it was first.',
#  'where did you meet her?',
#  'in the cova?',
#  'where did you go?',
#  'how did you feel?',
#  'tell me everything at once.',
#  'did you stay all night?”\n\n“yes.”\n\n“that’s nothing.',
#  'here now we have beautiful girls.',
#  'new girls never been to the front before.”\n\n“wonderful.”\n\n“you don’t believe me?',
#  'we will go now this afternoon and see.',
#  'and in the town we have beautiful english girls.',
#  'i am now in love with miss barkley.',
#  'i will take you to call.',
#  'i will probably marry miss barkley.”\n\n“i have to get washed and report.',
#  'doesn’t anybody work now?”\n\n“since you are gone we have nothing but frostbites, chilblains, jaundice, gonorrhea, self-inflicted wounds, pneumonia and hard and soft chancres.',
#  'every week some one gets wounded by rock fragments.',
#  'there are a few real wounded.',
#  'next week the war starts again.',
#  'perhaps it start again.',
#  'they say so.',
#  'do you think i would do right to marry miss barkley—after the war of course?”\n\n“absolutely,” i said and poured the basin full of water.',
#  '“to-night you will tell me everything,” said rinaldi.',
#  '“now i must go back to sleep to be fresh and beautiful for miss barkley.”\n\ni took off my tunic and shirt and washed in the cold water in the basin.',
#  'while i rubbed myself with a towel i looked around the room and out the window and at rinaldi lying with his eyes closed on the bed.',
#  'he was good-looking, was my age, and he came from amalfi.',
#  'he loved being a surgeon and we were great friends.',
#  'while i was looking at him he opened his eyes.',
#  '“have you any money?”\n\n“yes.”\n\n“loan me fifty lire.”\n\ni dried my hands and took out my pocket-book from the inside of my tunic hanging on the wall.',
#  'rinaldi took the note, folded it without rising from the bed and slid it in his breeches pocket.',
#  'he smiled, “i must make on miss barkley the impression of a man of sufficient wealth.',
#  'you are my great and good friend and financial protector.”\n\n“go to hell,” i said.',
#  'that night at the mess i sat next to the priest and he was disappointed and suddenly hurt that i had not gone to the abruzzi.',
#  'he had written to his father that i was coming and they had made preparations.',
#  'i myself felt as badly as he did and could not understand why i had not gone.',
#  'it was what i had wanted to do and i tried to explain how one thing had led to another and finally he saw it and understood that i had really wanted to go and it was almost all right.',
#  'i had drunk much wine and afterward coffee and strega and i explained, winefully, how we did not do the things we wanted to do; we never did such things.',
#  'we two were talking while the others argued.',
#  'i had wanted to go to abruzzi.',
#  'i had gone to no place where the roads were frozen and hard as iron, where it was clear cold and dry and the snow was dry and powdery and hare-tracks in the snow and the peasants took off their hats and called you lord and there was good hunting.',
#  'i had gone to no such place but to the smoke of cafés and nights when the room whirled and you needed to look at the wall to make it stop, nights in bed, drunk, when you knew that that was all there was, and the strange excitement of waking and not knowing who it was with you, and the world all unreal in the dark and so exciting that you must resume again unknowing and not caring in the night, sure that this was all and all and all and not caring.',
#  'suddenly to care very much and to sleep to wake with it sometimes morning and all that had been there gone and everything sharp and hard and clear and sometimes a dispute about the cost.',
#  'sometimes still pleasant and fond and warm and breakfast and lunch.',
#  'sometimes all niceness gone and glad to get out on the street but always another day starting and then another night.',
#  'i tried to tell about the night and the difference between the night and the day and how the night was better unless the day was very clean and cold and i could not tell it; as i cannot tell it now.',
#  'but if you have had it you know.',
#  'he had not had it but he understood that i had really wanted to go to the abruzzi but had not gone and we were still friends, with many tastes alike, but with the difference between us.',
#  'he had always known what i did not know and what, when i learned it, i was always able to forget.',
#  'but i did not know that then, although i learned it later.',
#  'in the meantime we were all at the mess, the meal was finished, and the argument went on.',
#  'we two stopped talking and the captain shouted, “priest not happy.',
#  'priest not happy without girls.”\n\n“i am happy,” said the priest.',
#  '“priest not happy.',
#  'priest wants austrians to win the war,” the captain said.',
#  'the others listened.',
#  'the priest shook his head.',
#  '“no,” he said.',
#  '“priest wants us never to attack.',
#  'don’t you want us never to attack?”\n\n“no.',
#  'if there is a war i suppose we must attack.”\n\n“must attack.',
#  'shall attack!”\n\nthe priest nodded.',
#  '“leave him alone,” the major said.',
#  '“he’s all right.”\n\n“he can’t do anything about it anyway,” the captain said.',
#  'we all got up and left the table.',
#  '4\nthe battery in the next garden woke me in the morning and i saw the sun coming through the window and got out of the bed.',
#  'i went to the window and looked out.',
#  'the gravel paths were moist and the grass was wet with dew.',
#  'the battery fired twice and the air came each time like a blow and shook the window and made the front of my pajamas flap.',
#  'i could not see the guns but they were evidently firing directly over us.',
#  'it was a nuisance to have them there but it was a comfort that they were no bigger.',
#  'as i looked out at the garden i heard a motor truck starting on the road.',
#  'i dressed, went downstairs, had some coffee in the kitchen and went out to the garage.',
#  'ten cars were lined up side by side under the long shed.',
#  'they were top-heavy, blunt-nosed ambulances, painted gray and built like moving-vans.',
#  'the mechanics were working on one out in the yard.',
#  'three others were up in the mountains at dressing stations.',
#  '“do they ever shell that battery?” tasked one of the mechanics.',
#  '“no, signor tenente.',
#  'it is protected by the little hill.”\n\n“how’s everything?”\n\n“not so bad.',
#  'this machine is no good but the others march.” he stopped working and smiled.',
#  '“were you on permission?”\n\n“yes.”\n\nhe wiped his hands on his jumper and grinned.',
#  '“you have a good time?” the others all grinned too.',
#  '“fine,” i said.',
#  '“what’s the matter with this machine?”\n\n“it’s no good.',
#  'one thing after another.”\n\n“what’s the matter now?”\n\n“new rings.”\n\ni left them working, the car looking disgraced and empty with the engine open and parts spread on the work bench, and went in under the shed and looked at each of the cars.',
#  'they were moderately clean, a few freshly washed, the others dusty.',
#  'i looked at the tires carefully, looking for cuts or stone bruises.',
#  'everything seemed in good condition.',
#  'it evidently made no difference whether i was there to look after things or not.',
#  'i had imagined that the condition of the cars, whether or not things were obtainable, the smooth functioning of the business of removing wounded and sick from the dressing stations, hauling them back from the mountains to the clearing station and then distributing them to the hospitals named on their papers, depended to a considerable extent on myself.',
#  'evidently it did not matter whether i was there or not.',
#  '“has there been any trouble getting parts?” i asked the sergeant mechanic.',
#  '“no, signor tenente.”\n\n“where is the gasoline park now?”\n\n“at the same place.”\n\n“good,” i said and went back to the house and drank another bowl of coffee at the mess table.',
#  'the coffee was a pale gray and sweet with condensed milk.',
#  'outside the window it was a lovely spring morning.',
#  'there was that beginning of a feeling of dryness in the nose that meant the day would be hot later on.',
#  'that day i visited the posts in the mountains and was back in town late in the afternoon.',
#  'the whole thing seemed to run better while i was away.',
#  'the offensive was going to start again i heard.',
#  'the division for which we worked were to attack at a place up the river and the major told me that i would see about the posts for during the attack.',
#  'the attack would cross the river up above the narrow gorge and spread up the hillside.',
#  'the posts for the cars would have to be as near the river as they could get and keep covered.',
#  'they would, of course, be selected by the infantry but we were supposed to work it out.',
#  'it was one of those things that gave you a false feeling of soldiering.',
#  'i was very dusty and dirty and went up to my room to wash. rinaldi was sitting on the bed with a copy of hugo’s english grammar.',
#  'he was dressed, wore his black boots, and his hair shone.',
#  '“splendid,” he said when he saw me.',
#  '“you will come with me to see miss barkley.”\n\n"no.',
#  '“yes.',
#  'you will please come and make me a good impression on her.”\n\n“all right.',
#  'wait till i get cleaned up.”\n\n“wash up and come as you are.”\n\ni washed, brushed my hair and we started.',
#  '“wait a minute,” rinaldi said.',
#  '“perhaps we should have a drink.” he opened his trunk and took out a bottle.',
#  '“not strega,” i said.',
#  '“no.',
#  'grappa.”\n\n“all right.”\n\nhe poured two glasses and we touched them, first fingers extended.',
#  'the grappa was very strong.',
#  '“another?”\n\n“all right,” i said.',
#  'we drank the second grappa, rinaldi put away the bottle and we went down the stairs.',
#  'it was hot walking through the town but the sun was starting to go down and it was very pleasant.',
#  'the british hospital was a big villa built by germans before the war.',
#  'miss barkley was in the garden.',
#  'another nurse was with her.',
#  'we saw their white uniforms through the trees and walked toward them.',
#  'rinaldi saluted.',
#  'i saluted too but more moderately.',
#  '“how do you do?” miss barkley said.',
#  '“you’re not an italian, are you?”\n\n“oh, no.”\n\nrinaldi was talking with the other nurse.',
#  'they were laughing.',
#  '“what an odd thing—to be in the italian army.”\n\n“it’s not really the army.',
#  'it’s only the ambulance.”\n\n“it’s very odd though.',
#  'why did you do it?”\n\n“i don’t know,” i said.',
#  '“there isn’t always an explanation for everything.”\n\n“oh, isn’t there?',
#  'i was brought up to think there was.”\n\n“that’s awfully nice.”\n\n“do we have to go on and talk this way?”\n\n“no,” i said.',
#  '“that’s a relief.',
#  'isn’t it?”\n\n“what is the stick?” i asked.',
#  'miss barkley was quite tall.',
#  'she wore what seemed to me to be a nurse’s uniform, was blonde and had a tawny skin and gray eyes.',
#  'i thought she was very beautiful.',
#  'she was carrying a thin rattan stick like a toy riding-crop, bound in leather.',
#  '“it belonged to a boy who was killed last year.”\n\n“i’m awfully sorry.”\n\n“he was a very nice boy.',
#  'he was going to marry me and he was killed in the somme.”\n\n“it was a ghastly show.”\n\n“were you there?”\n\n“no.”\n\n“i’ve heard about it,” she said.',
#  '“there’s not really any war of that sort down here.',
#  'they sent me the little stick.',
#  'his mother sent it to me.',
#  'they returned it with his things.”\n\n“had you been engaged long?”\n\n“eight years.',
#  'we grew up together.”\n\n“and why didn’t you marry?”\n\n“i don’t know,” she said.',
#  '“i was a fool not to.',
#  'i could have given him that anyway.',
#  'but i thought it would be bad for him.”\n\n“i see.”\n\n“have you ever loved any one?”\n\n“no,” i said.',
#  'we sat down on a bench and i looked at her.',
#  '“you have beautiful hair,” i said.',
#  '“do you like it?”\n\n“very much.”\n\n“i was going to cut it all off when he died.”\n\n“no.”\n\n“i wanted to do something for him.',
#  'you see i didn’t care about the other thing and he could have had it all.',
#  'he could have had anything he wanted if i would have known.',
#  'i would have married him or anything.',
#  'i know all about it now.',
#  'but then he wanted to go to war and i didn’t know.”\n\ni did not say anything.',
#  '“i didn’t know about anything then.',
#  'i thought it would be worse for him.',
#  'i thought perhaps he couldn’t stand it and then of course he was killed and that was the end of it.”\n\n“i don’t know.”\n\n“oh, yes,” she said.',
#  '“that’s the end of it.”\n\nwe looked at rinaldi talking with the other nurse.',
#  '“what is her name?”\n\n“ferguson.',
#  'helen ferguson.',
#  'your friend is a doctor, isn’t he?”\n\n“yes.',
#  'he’s very good.”\n\n“that’s splendid.',
#  'you rarely find any one any good this close to the front.',
#  'this is close to the front, isn’t it?”\n\n“quite.”\n\n“it’s a silly front,” she said.',
#  '“but it’s very beautiful.',
#  'are they going to have an offensive?”\n\n“yes.”\n\n“then we’ll have to work.',
#  'there’s no work now.”\n\n“have you done nursing long?”\n\n“since the end of’fifteen.',
#  'i started when he did.',
#  'i remember having a silly idea he might come to the hospital where i was.',
#  'with a sabre cut, i suppose, and a bandage around his head.',
#  'or shot through the shoulder.',
#  'something picturesque.”\n\n“this is the picturesque front,” i said.',
#  '“yes,” she said.',
#  '“people can’t realize what france is like.',
#  'if they did, it couldn’t all go on.',
#  'he didn’t have a sabre cut.',
#  'they blew him all to bits.”\n\ni didn’t say anything.',
#  '“do you suppose it will always go on?”\n\n“no.”\n\n“what’s to stop it?”\n\n“it will crack somewhere.”\n\n“we’ll crack.',
#  'we’ll crack in france.',
#  'they can’t go on doing things like the somme and not crack.”\n\n“they won’t crack here,” i said.',
#  '“you think not?”\n\n“no.',
#  'they did very well last summer.”\n\n“they may crack,” she said.',
#  '“anybody may crack.”\n\n“the germans too.”\n\n“no,” she said.',
#  '“i think not.”\n\nwe went over toward rinaldi and miss ferguson.',
#  '“you love italy?” rinaldi asked miss ferguson in english.',
#  '“quite well.”\n\n“no understand,” rinaldi shook his head.',
#  '“abbastanza bene,” i translated.',
#  'he shook his head.',
#  '“that is not good.',
#  'you love england?”\n\n“not too well.',
#  'i’m scotch, you see.”\n\nrinaldi looked at me blankly.',
#  '“she’s scotch, so she loves scotland better than england,” i said in italian.',
#  '“but scotland is england.”\n\ni translated this for miss ferguson.',
#  '“pas encore,” said miss ferguson.',
#  '“not really?”\n\n“never.',
#  'we do not like the english.”\n\n“not like the english?',
#  'not like miss barkley?”\n\n“oh, that’s different.',
#  'you mustn’t take everything so literally.”\n\nafter a while we said good-night and left.',
#  'walking home rinaldi said, “miss barkley prefers you to me.',
#  'that is very clear.',
#  'but the little scotch one is very nice.”\n\n“very,” i said.',
#  'i had not noticed her.',
#  '“you like her?”\n\n“no,” said rinaldi.',
#  '5\nthe next afternoon i went to call on miss barkley again.',
#  'she was not in the garden and i went to the side door of the villa where the ambulances drove up.',
#  'inside i saw the head nurse, who said miss barkley was on duty—“there’s a war on, you know.”\n\ni said i knew.',
#  '“you’re the american in the italian army?” she asked.',
#  '“yes, ma’am.”\n\n“how did you happen to do that?',
#  'why didn’t you join up with us?”\n\n“i don’t know,” i said.',
#  '“could i join now?”\n\n“i’m afraid not now.',
#  'tell me.',
#  'why did you join up with the italians?”\n\n“i was in italy,” i said, “and i spoke italian.”\n\n“oh,” she said.',
#  '“i’m learning it.',
#  'it’s beautiful language.”\n\n“somebody said you should be able to learn it in two weeks.”\n\n“oh, i’ll not learn it in two weeks.',
#  'i’ve studied it for months now.',
#  'you may come and see her after seven o’clock if you wish.',
#  'she’ll be off then.',
#  'but don’t bring a lot of italians.”\n\n“not even for the beautiful language?”\n\n“no.',
#  'nor for the beautiful uniforms.”\n\n“good evening,” i said.',
#  '“a rivederci, tenente.”\n\n“a rivederla.” i saluted and went out.',
#  'it was impossible to salute foreigners as an italian, without embarrassment.',
#  'the italian salute never seemed made for export.',
#  'the day had been hot.',
#  'i had been up the river to the bridgehead at plava.',
#  'it was there that the offensive was to begin.',
#  'it had been impossible to advance on the far side the year before because there was only one road leading down from the pass to the pontoon bridge and it was under machine-gun and shell fire for nearly a mile.',
#  'it was not wide enough either to carry all the transport for an offensive and the austrians could make a shambles out of it.',
#  'but the italians had crossed and spread out a little way on the far side to hold about a mile and a half on the austrian side of the river.',
#  'it was a nasty place and the austrians should not have let them hold it.',
#  'i suppose it was mutual tolerance because the austrians still kept a bridgehead further down the river.',
#  'the austrian trenches were above on the hillside only a few yards from the italian lines.',
#  'there had been a little town but it was all rubble.',
#  'there was what was left of a railway station and a smashed permanent bridge that could not be repaired and used because it was in plain sight.',
#  'i went along the narrow road down toward the river, left the car at the dressing station under the hill, crossed the pontoon bridge, which was protected by a shoulder of the mountain, and went through the trenches in the smashed-down town and along the edge of the slope.',
#  'everybody was in the dugouts.',
#  'there were racks of rockets standing to be touched off to call for help from the artillery or to signal with if the telephone wires were cut.',
#  'it was quiet, hot and dirty.',
#  'i looked across the wire at the austrian lines.',
#  'nobody was in sight.',
#  'i had a drink with a captain that i knew in one of the dugouts and went back across the bridge.',
#  'a new wide road was being finished that would go over the mountain and zig-zag down to the bridge.',
#  'when this road was finished the offensive would start.',
#  'it came down through the forest in sharp turns.',
#  'the system was to bring everything down the new road and take the empty trucks, carts and loaded ambulances and all returning traffic up the old narrow road.',
#  'the dressing station was on the austrian side of the river under the edge of the hill and stretcher-bearers would bring the wounded back across the pontoon bridge.',
#  'it would be the same when the offensive started.',
#  'as far as i could make out the last mile or so of the new road where it started to level out would be able to be shelled steadily by the austrians.',
#  'it looked as though it might be a mess.',
#  'but i found a place where the cars would be sheltered after they passed that last badlooking bit and could wait for the wounded to be brought across the pontoon bridge.',
#  'i would have liked to drive over the new road but it was not yet finished.',
#  'it looked wide and well made with a good grade and the turns looked very impressive where you could see them through openings in the forest on the mountain side.',
#  'the cars would be all right with their good metal-to-metal brakes and anyway, coming down, they would not be loaded.',
#  'i drove back up the narrow road.',
#  'two carabinieri held the car up.',
#  'a shell had fallen and while we waited three others fell up the road.',
#  'they were seventy-sevens and came with a whishing rush of air, a hard bright burst and flash and then gray smoke that blew across the road.',
#  'the carabinieri waved us to go on.',
#  'passing where the shells had landed i avoided the small broken places and smelled the high explosive and the smell of blasted clay and stone and freshly shattered flint.',
#  'i drove back to gorizia and our villa and, as i said, went to call on miss barkley, who was on duty.',
#  'at dinner i ate very quickly and left for the villa where the british had their hospital.',
#  'it was really very large and beautiful and there were fine trees in the grounds.',
#  'miss barkley was sitting on a bench in the garden.',
#  'miss ferguson was with her.',
#  'they seemed glad to see me and in a little while miss ferguson excused herself and went away.',
#  '“i’ll leave you two,” she said.',
#  '“you get along very well without me.”\n\n“don’t go, helen,” miss barkley said.',
#  '“i’d really rather.',
#  'i must write some letters.”\n\n“good-night,” i said.',
#  '“good-night, mr. henry.”\n\n“don’t write anything that will bother the censor.”\n\n“don’t worry.',
#  'i only write about what a beautiful place we live in and how brave the italians are.”\n\n“that way you’ll be decorated.”\n\n“that will be nice.',
#  'good-night, catherine.”\n\n“i’ll see you in a little while,” miss barkley said.',
#  'miss ferguson walked away in the dark.',
#  '“she’s nice,” i said.',
#  '“oh, yes, she’s very nice.',
#  'she’s a nurse.”\n\n“aren’t you a nurse?”\n\n“oh, no.',
#  'i’m something called a v. a. d. we work very hard but no one trusts us.”\n\n“why not?”\n\n“they don’t trust us when there’s nothing going on.',
#  'when there is really work they trust us.”\n\n“what is the difference?”\n\n“a nurse is like a doctor.',
#  'it takes a long time to be.',
#  'a v. a. d. is a short cut.”\n\n“i see.”\n\n“the italians didn’t want women so near the front.',
#  'so we’re all on very special behavior.',
#  'we don’t go out.”\n\n“i can come here though.”\n\n“oh, yes.',
#  'we’re not cloistered.”\n\n“let’s drop the war.”\n\n“it’s very hard.',
#  'there’s no place to drop it.”\n\n“let’s drop it anyway.”\n\n“all right.”\n\nwe looked at each other in the dark.',
#  'i thought she was very beautiful and i took her hand.',
#  'she let me take it and i held it and put my arm around under her arm.',
#  '“no,” she said.',
#  'i kept my arm where it was.',
#  '“why not?”\n\n“no.”\n\n“yes,” i said.',
#  '“please.” i leaned forward in the dark to kiss her and there was a sharp stinging flash.',
#  'she had slapped my face hard.',
#  'her hand had hit my nose and eyes, and tears came in my eyes from the reflex.',
#  '“i’m so sorry,” she said.',
#  'i felt i had a certain advantage.',
#  '“you were quite right.”\n\n“i’m dreadfully sorry,” she said.',
#  '“i just couldn’t stand the nurse’s-eveningoff aspect of it.',
#  'i didn’t mean to hurt you.',
#  'i did hurt you, didn’t i?”\n\nshe was looking at me in the dark.',
#  'i was angry and yet certain, seeing it all ahead like the moves in a chess game.',
#  '“you did exactly right,” i said.',
#  '“i don’t mind at all.”\n\n“poor man.”\n\n“you see i’ve been leading a sort of a funny life.',
#  'and i never even talk english.',
#  'and then you are so very beautiful.” i looked at her.',
#  '“you don’t need to say a lot of nonsense.',
#  'i said i was sorry.',
#  'we do get along.”\n\n“yes,” i said.',
#  '“and we have gotten away from the war.”\n\nshe laughed.',
#  'it was the first time i had ever heard her laugh.',
#  'i watched her face.',
#  '“you are sweet,” she said.',
#  '“no, i’m not.”\n\n“yes.',
#  'you are a dear.',
#  'i’d be glad to kiss you if you don’t mind.”\n\ni looked in her eyes and put my arm around her as i had before and kissed her.',
#  'i kissed her hard and held her tight and tried to open her lips; they were closed tight.',
#  'i was still angry and as i held her suddenly she shivered.',
#  'i held her close against me and could feel her heart beating and her lips opened and her head went back against my hand and then she was crying on my shoulder.',
#  '“oh, darling,” she said.',
#  '“you will be good to me, won’t you?”\n\nwhat the hell, i thought.',
#  'i stroked her hair and patted her shoulder.',
#  'she was crying.',
#  '“you will, won’ t you?” she looked up at me.',
#  '“because we’re going to have a strange life.”\n\nafter a while i walked with her to the door of the villa and she went in and i walked home.',
#  'back at the villa i went upstairs to the room.',
#  'rinaldi was lying on his bed.',
#  'he looked at me.',
#  '“so you make progress with miss barkley?”\n\n“we are friends.”\n\n“you have that pleasant air of a dog in heat.”\n\ni did not understand the word.',
#  '“of a what?”\n\nhe explained.',
#  '“you,” i said, “have that pleasant air of a dog who—”\n\n“stop it,” he said.',
#  '“in a little while we would say insulting things.” he laughed.',
#  '“good-night,” i said.',
#  '“good-night, little puppy.”\n\ni knocked over his candle with the pillow and got into bed in the dark.',
#  'rinaldi picked up the candle, lit it and went on reading.',
#  '6\ni was away for two days at the posts.',
#  'when i got home it was too late and i did not see miss barkley until the next evening.',
#  'she was not in the garden and i had to wait in the office of the hospital until she came down.',
#  'there were many marble busts on painted wooden pillars along the walls of the room they used for an office.',
#  'the hall too, that the office opened on, was lined with them.',
#  'they had the complete marble quality of all looking alike.',
#  'sculpture had always seemed a dull business—still, bronzes looked like something.',
#  'but marble busts all looked like a cemetery.',
#  'there was one fine cemetery though—the one at pisa.',
#  'genoa was the place to see the bad marbles.',
#  'this had been the villa of a very wealthy german and the busts must have cost him plenty.',
#  'i wondered who had done them and how much he got.',
#  'i tried to make out whether they were members of the family or what; but they were all uniformly classical.',
#  'you could not tell anything about them.',
#  'i sat on a chair and held my cap.',
#  'we were supposed to wear steel helmets even in gorizia but they were uncomfortable and too bloody theatrical in a town where the civilian inhabitants had not been evacuated.',
#  'i wore one when we went up to the posts and carried an english gas mask.',
#  'we were just beginning to get some of them.',
#  'they were a real mask.',
#  'also we were required to wear an automatic pistol; even doctors and sanitary officers.',
#  'i felt it against the back of the chair.',
#  'you were liable to arrest if you did not have one worn in plain sight.',
#  'rinaldi carried a holster stuffed with toilet paper.',
#  'i wore a real one and felt like a gunman until i practised firing it.',
#  'it was an astra 7.65 caliber with a short barrel and it jumped so sharply when you let it off that there was no question of hitting anything.',
#  'i practised with it, holding below the target and trying to master the jerk of the ridiculous short barrel until i could hit within a yard of where i aimed at twenty paces and then the ridiculousness of carrying a pistol at all came over me and i soon forgot it and carried it flopping against the small of my back with no feeling at all except a vague sort of shame when i met english-speaking people.',
#  'i sat now in the chair and an orderly of some sort looked at me disapprovingly from behind a desk while i looked at the marble floor, the pillars with the marble busts, and the frescoes on the wall and waited for miss barkley.',
#  'the frescoes were not bad.',
#  'any frescoes were good when they started to peel and flake off.',
#  'i saw catherine barkley coming down the hall, and stood up.',
#  'she did not seem tall walking toward me but she looked very lovely.',
#  '“good-evening, mr. henry,” she said.',
#  '“how do you do?” i said.',
#  'the orderly was listening behind the desk.',
#  '“shall we sit here or go out in the garden?”\n\n“let’s go out.',
#  'it’s much cooler.”\n\ni walked behind her out into the garden, the orderly looking after us.',
#  'when we were out on the gravel drive she said, “where have you been?”\n\n“i’ve been out on post.”\n\n“you couldn’t have sent me a note?”\n\n“no,” i said.',
#  '“not very well.',
#  'i thought i was coming back.”\n\n“you ought to have let me know, darling.”\n\nwe were off the driveway, walking under the trees.',
#  'i took her hands, then stopped and kissed her.',
#  '“isn’t there anywhere we can go?”\n\n“no,” she said.',
#  '“we have to just walk here.',
#  'you’ve been away a long time.”\n\n“this is the third day.',
#  'but i’m back now.”\n\nshe looked at me, “and you do love me?”\n\n“yes.”\n\n“you did say you loved me, didn’t you?”\n\n“yes,” i lied.',
#  '“i love you.” i had not said it before.',
#  '“and you call me catherine?”\n\n“catherine.”\n\nwe walked on a way and were stopped under a tree.',
#  '“say,’i’ve come back to catherine in the night.”\n\n“i’ve come back to catherine in the night.”\n\n“oh, darling, you have come back, haven’t you?”\n\n“yes.”\n\n“i love you so and it’s been awful.',
#  'you won’t go away?”\n\n“no.',
#  'i’ll always come back.”\n\n“oh, i love you so.',
#  'please put your hand there again.”\n\n“it’s not been away.” i turned her so i could see her face when i kissed her and i saw that her eyes were shut.',
#  'i kissed both her shut eyes.',
#  'i thought she was probably a little crazy.',
#  'it was all right if she was.',
#  'i did not care what i was getting into.',
#  'this was better than going every evening to the house for officers where the girls climbed all over you and put your cap on backward as a sign of affection between their trips upstairs with brother officers.',
#  'i knew i did not love catherine barkley nor had any idea of loving her.',
#  'this was a game, like bridge, in which you said things instead of playing cards.',
#  'like bridge you had to pretend you were playing for money or playing for some stakes.',
#  'nobody had mentioned what the stakes were.',
#  'it was all right with me.',
#  '“i wish there was some place we could go,” i said.',
#  'i was experiencing the masculine difficulty of making love very long standing up.',
#  '“there isn’t any place,” she said.',
#  'she came back from wherever she had been.',
#  '“we might sit there just for a little while.”\n\nwe sat on the flat stone bench and i held catherine barkley’ s hand.',
#  'she would not let me put my arm around her.',
#  '“are you very tired?” she asked.',
#  '“no.”\n\nshe looked down at the grass.',
#  '“this is a rotten game we play, isn’t it?”\n\n“what game?”\n\n“don’t be dull.”\n\n“i’m not, on purpose.”\n\n“you’re a nice boy,” she said.',
#  '“and you play it as well as you know how.',
#  'but it’s a rotten game.”\n\n“do you always know what people think?”\n\n“not always.',
#  'but i do with you.',
#  'you don’t have to pretend you love me.',
#  'that’s over for the evening.',
#  'is there anything you’d like to talk about?”\n\n“but i do love you.”\n\n“please let’s not lie when we don’t have to.',
#  'i had a very fine little show and i’m all right now.',
#  'you see i’m not mad and i’m not gone off.',
#  'it’s only a little sometimes.”\n\ni pressed her hand, “dear catherine.”\n\n“it sounds very funny now—catherine.',
#  'you don’t pronounce it very much alike.',
#  'but you’re very nice.',
#  'you’re a very good boy.”\n\n“that’s what the priest said.”\n\n“yes, you’re very good.',
#  'and you will come and see me?”\n\n“of course.”\n\n“and you don’t have to say you love me.',
#  'that’s all over for a while.” she stood up and put out her hand.',
#  '“good-night.”\n\ni wanted to kiss her.',
#  '“no,” she said.',
#  '“i’m awfully tired.”\n\n“kiss me, though,” i said.',
#  '“i’m awfully tired, darling.”\n\n“kiss me.”\n\n“do you want to very much?”\n\n“yes.”\n\nwe kissed and she broke away suddenly.',
#  '“no.',
#  'good-night, please, darling.” we walked to the door and i saw her go in and down the hall.',
#  'i liked to watch her move.',
#  'she went on down the hall.',
#  'i went on home.',
#  'it was a hot night and there was a good deal going on up in the mountains.',
#  'i watched the flashes on san gabriele.',
#  'i stopped in front of the villa rossa.',
#  'the shutters were up but it was still going on inside.',
#  'somebody was singing.',
#  'i went on home.',
#  'rinaldi came in while i was undressing.',
#  '“ah, ha!” he said.',
#  '“it does not go so well.',
#  'baby is puzzled.”\n\n“where have you been?”\n\n“at the villa rossa.',
#  'it was very edifying, baby.',
#  'we all sang.',
#  'where have you been?”\n\n“calling on the british.”\n\n“thank god i did not become involved with the british.”\n\n7\ni came back the next afternoon from our first mountain post and stopped the car at the smistimento where the wounded and sick were sorted by their papers and the papers marked for the different hospitals.',
#  'i had been driving and i sat in the car and the driver took the papers in.',
#  'it was a hot day and the sky was very bright and blue and the road was white and dusty.',
#  'i sat in the high seat of the fiat and thought about nothing.',
#  'a regiment went by in the road and i watched them pass.',
#  'the men were hot and sweating.',
#  'some wore their steel helmets but most of them carried them slung from their packs.',
#  'most of the helmets were too big and came down almost over the ears of the men who wore them.',
#  'the officers all wore helmets; better-fitting helmets.',
#  'it was half of the brigata basilicata.',
#  'i identified them by their red and white striped collar mark.',
#  'there were stragglers going by long after the regiment had passed—men who could not keep up with their platoons.',
#  'they were sweaty, dusty and tired.',
#  'some looked pretty bad.',
#  'a soldier came along after the last of the stragglers.',
#  'he was walking with a limp.',
#  'he stopped and sat down beside the road.',
#  'i got down and went over.',
#  '“what’s the matter?”\n\nhe looked at me, then stood up.',
#  '“i’m going on.”\n\n“what’s the trouble?”\n\n“—the war.”\n\n“what’s wrong with your leg?”\n\n“it’s not my leg.',
#  'i got a rupture.”\n\n“why don’t you ride with the transport?” i asked.',
#  '“why don’t you go to the hospital?”\n\n“they won’t let me.',
#  'the lieutenant said i slipped the truss on purpose.”\n\n“let me feel it.”\n\n“it’s way out.”\n\n“which side is it on?”\n\n“here.”\n\ni felt it.',
#  '“cough,” i said.',
#  '“i’m afraid it will make it bigger.',
#  'it’s twice as big as it was this morning.”\n\n“sit down,” i said.',
# ...
#  'that’s what it’s for.”\n\n“all right,” i said.',
#  'i undid the clasp of the gold chain and put it around my neck and clasped it.',
#  'the saint hung down on the outside of my uniform and i undid the throat of my tunic, unbuttoned the shirt collar and dropped him in under the shirt.',
#  'i felt him in his metal box against my chest while we drove.',
#  'then i forgot about him.',
#  'after i was wounded i never found him.',
#  'some one probably got it at one of the dressing stations.',
#  'we drove fast when we were over the bridge and soon we saw the dust of the other cars ahead down the road.',
#  'the road curved and we saw the three cars looking quite small, the dust rising from the wheels and going off through the trees.',
#  'we caught them and passed them and turned off on a road that climbed up into the hills.',
#  'driving in convoy is not unpleasant if you are the first car and i settled back in the seat and watched the country.',
#  'we were in the foothills on the near side of the river and as the road mounted there were the high mountains off to the north with snow still on the tops.',
#  'i looked back and saw the three cars all climbing, spaced by the interval of their dust.',
#  'we passed a long column of loaded mules, the drivers walking along beside the mules wearing red fezzes.',
#  'they were bersaglieri.',
#  'beyond the mule train the road was empty and we climbed through the hills and then went down over the shoulder of a long hill into a river-valley.',
#  'there were trees along both sides of the road and through the right line of trees i saw the river, the water clear, fast and shallow.',
#  'the river was low and there were stretches of sand and pebbles with a narrow channel of water and sometimes the water spread like a sheen over the pebbly bed.',
#  'close to the bank i saw deep pools, the water blue like the sky.',
#  'i saw arched stone bridges over the river where tracks turned off from the road and we passed stone farmhouses with pear trees candelabraed against their south walls and low stone walls in the fields.',
#  'the road went up the valley a long way and then we turned off and commenced to climb into the hills again.',
#  'the road climbed steeply going up and back and forth through chestnut woods to level finally along a ridge.',
#  'i could look down through the woods and see, far below, with the sun on it, the line of the river that separated the two armies.',
#  'we went along the rough new military road that followed the crest of the ridge and i looked to the north at the two ranges of mountains, green and dark to the snow-line and then white and lovely in the sun.',
#  'then, as the road mounted along the ridge, i saw a third range of mountains, higher snow mountains, that looked chalky white and furrowed, with strange planes, and then there were mountains far off beyond all these that you could hardly tell if you really saw.',
#  'those were all the austrians’mountains and we had nothing like them.',
#  'ahead there was a rounded turn-off in the road to the right and looking down i could see the road dropping through the trees.',
#  'there were troops on this road and motor trucks and mules with mountain guns and as we went down, keeping to the side, i could see the river far down below, the line of ties and rails running along it, the old bridge where the railway crossed to the other side and across, under a hill beyond the river, the broken houses of the little town that was to be taken.',
#  'it was nearly dark when we came down and turned onto the main road that ran beside the river.',
#  '9\nthe road was crowded and there were screens of corn-stalk and straw matting on both sides and matting over the top so that it was like the entrance at a circus or a native village.',
#  'we drove slowly in this matting-covered tunnel and came out onto a bare cleared space where the railway station had been.',
#  'the road here was below the level of the river bank and all along the side of the sunken road there were holes dug in the bank with infantry in them.',
#  'the sun was going down and looking up along the bank as we drove i saw the austrian observation balloons above the hills on the other side dark against the sunset.',
#  'we parked the cars beyond a brickyard.',
#  'the ovens and some deep holes had been equipped as dressing stations.',
#  'there were three doctors that i knew.',
#  'i talked with the major and learned that when it should start and our cars should be loaded we would drive them back along the screened road and up to the main road along the ridge where there would be a post and other cars to clear them.',
#  'he hoped the road would not jam.',
#  'it was a one-road show.',
#  'the road was screened because it was in sight of the austrians across the river.',
#  'here at the brickyard we were sheltered from rifle or machine-gun fire by the river bank.',
#  'there was one smashed bridge across the river.',
#  'they were going to put over another bridge when the bombardment started and some troops were to cross at the shallows up above at the bend of the river.',
#  'the major was a little man with upturned mustaches.',
#  'he had been in the war in libya and wore two woundstripes.',
#  'he said that if the thing went well he would see that i was decorated.',
#  'i said i hoped it would go well but that he was too kind.',
#  'i asked him if there was a big dugout where the drivers could stay and he sent a soldier to show me.',
#  'i went with him and found the dugout, which was very good.',
#  'the drivers were pleased with it and i left them there.',
#  'the major asked me to have a drink with him and two other officers.',
#  'we drank rum and it was very friendly.',
#  'outside it was getting dark.',
#  'i asked what time the attack was to he and they said as soon as it was dark.',
#  'i went back to the drivers.',
#  'they were sitting in the dugout talking and when i came in they stopped.',
#  'i gave them each a package of cigarettes, macedonias, loosely packed cigarettes that spilled tobacco and needed to have the ends twisted before you smoked them.',
#  'manera lit his lighter and passed it around.',
#  'the lighter was shaped like a fiat radiator.',
#  'i told them what i had heard.',
#  '“why didn’t we see the post when we came down?” passini asked.',
#  '“it was just beyond where we turned off.”\n\n“that road will be a dirty mess,” manera said.',
#  '“they’ll shell the — out of us.”\n\n“probably.”\n\n“what about eating, lieutenant?',
#  'we won’t get a chance to eat after this thing starts.”\n\n“i’ll go and see now,” i said.',
#  '“you want us to stay here or can we look around?”\n\n“better stay here.”\n\ni went back to the major’s dugout and he said the field kitchen would be along and the drivers could come and get their stew.',
#  'he would loan them mess tins if they did not have them.',
#  'i said i thought they had them.',
#  'i went back and told the drivers i would get them as soon as the food came.',
#  'manera said he hoped it would come before the bombardment started.',
#  'they were silent until i went out.',
#  'they were all mechanics and hated the war.',
#  'i went out to look at the cars and see what was going on and then came back and sat down in the dugout with the four drivers.',
#  'we sat on the ground with our backs against the wall and smoked.',
#  'outside it was nearly dark.',
#  'the earth of the dugout was warm and dry and i let my shoulders back against the wall, sitting on the small of my back, and relaxed.',
#  '“who goes to the attack?” asked gavuzzi.',
#  '“bersaglieri.”\n\n“all bersaglieri?”\n\n“i think so.”\n\n“there aren’t enough troops here for a real attack.”\n\n“it is probably to draw attention from where the real attack will be.”\n\n“do the men know that who attack?”\n\n“i don’t think so.”\n\n“of course they don’t,” manera said.',
#  '“they wouldn’t attack if they did.”\n\n“yes, they would,” passini said.',
#  '“bersaglieri are fools.”\n\n“they are brave and have good discipline,” i said.',
#  '“they are big through the chest by measurement, and healthy.',
#  'but they are still fools.”\n\n“the granatieri are tall,” manera said.',
#  'this was a joke.',
#  'they all laughed.',
#  '“were you there, tenente, when they wouldn’t attack and they shot every tenth man?”\n\n“no.”\n\n“it is true.',
#  'they lined them up afterward and took every tenth man.',
#  'carabinieri shot them.”\n\n“carabinieri,” said passini and spat on the floor.',
#  '“but those grenadiers; all over six feet.',
#  'they wouldn’t attack.”\n\n“if everybody would not attack the war would be over,” manera said.',
#  '“it wasn’t that way with the granatieri.',
#  'they were afraid.',
#  'the officers all came from such good families.”\n\n“some of the officers went alone.”\n\n“a sergeant shot two officers who would not get out.”\n\n“some troops went out.”\n\n“those that went out were not lined up when they took the tenth men.”\n\n“one of those shot by the carabinieri is from my town,” passini said.',
#  '“he was a big smart tall boy to be in the granatieri.',
#  'always in rome.',
#  'always with the girls.',
#  'always with the carabinieri.” he laughed.',
#  '“now they have a guard outside his house with a bayonet and nobody can come to see his mother and father and sisters and his father loses his civil rights and cannot even vote.',
#  'they are all without law to protect them.',
#  'anybody can take their property.”\n\n“if it wasn’t that that happens to their families nobody would go to the attack.”\n\n“yes.',
#  'alpini would.',
#  'these v. e. soldiers would.',
#  'some bersaglieri.”\n\n“bersaglieri have run too.',
#  'now they try to forget it.”\n\n“you should not let us talk this way, tenente.',
#  'evviva l’esercito,” passini said sarcastically.',
#  '“i know how you talk,” i said.',
#  '“but as long as you drive the cars and behave—”\n\n“—and don’t talk so other officers can hear,” manera finished.',
#  '“i believe we should get the war over,” i said.',
#  '“it would not finish it if one side stopped fighting.',
#  'it would only be worse if we stopped fighting.”\n\n“it could not be worse,” passini said respectfully.',
#  '“there is nothing worse than war.”\n\n“defeat is worse.”\n\n“i do not believe it,” passini said still respectfully.',
#  '“what is defeat?',
#  'you go home.”\n\n“they come after you.',
#  'they take your home.',
#  'they take your sisters.”\n\n“i don’t believe it,” passini said.',
#  '“they can’t do that to everybody.',
#  'let everybody defend his home.',
#  'let them keep their sisters in the house.”\n\n“they hang you.',
#  'they come and make you be a soldier again.',
#  'not in the auto-ambulance, in the infantry.”\n\n“they can’t hang every one.”\n\n“an outside nation can’t make you be a soldier,” manera said.',
#  '“at the first battle you all run.”\n\n“like the tchecos.”\n\n“i think you do not know anything about being conquered and so you think it is not bad.”\n\n“tenente,” passini said.',
#  '“we understand you let us talk.',
#  'listen.',
#  'there is nothing as bad as war.',
#  'we in the auto-ambulance cannot even realize at all how bad it is.',
#  'when people realize how bad it is they cannot do anything to stop it because they go crazy.',
#  'there are some people who never realize.',
#  'there are people who are afraid of their officers.',
#  'it is with them the war is made.”\n\n“i know it is bad but we must finish it.”\n\n“it doesn’t finish.',
#  'there is no finish to a war.”\n\n“yes there is.”\n\npassini shook his head.',
#  '“war is not won by victory.',
#  'what if we take san gabriele?',
#  'what if we take the carso and monfalcone and trieste?',
#  'where are we then?',
#  'did you see all the far mountains to-day?',
#  'do you think we could take all them too?',
#  'only if the austrians stop fighting.',
#  'one side must stop fighting.',
#  'why don’t we stop fighting?',
#  'if they come down into italy they will get tired and go away.',
#  'they have their own country.',
#  'but no, instead there is a war.”\n\n“you’re an orator.”\n\n“we think.',
#  'we read.',
#  'we are not peasants.',
#  'we are mechanics.',
#  'but even the peasants know better than to believe in a war.',
#  'everybody hates this war.”\n\n“there is a class that controls a country that is stupid and does not realize anything and never can.',
#  'that is why we have this war.”\n\n“also they make money out of it.”\n\n“most of them don’t,” said passini.',
#  '“they are too stupid.',
#  'they do it for nothing.',
#  'for stupidity.”\n\n“we must shut up,” said manera.',
#  '“we talk too much even for the tenente.”\n\n“he likes it,” said passini.',
#  '“we will convert him.”\n\n“but now we will shut up,” manera said.',
#  '“do we eat yet, tenente?” gavuzzi asked.',
#  '“i will go and see,” i said.',
#  'gordini stood up and went outside with me.',
#  '“is there anything i can do, tenente?',
#  'can i help in any way?” he was the quietest one of the four.',
#  '“come with me if you want,” i said, “and we’ll see.”\n\nit was dark outside and the long light from the search-lights was moving over the mountains.',
#  'there were big search-lights on that front mounted on camions that you passed sometimes on the roads at night, close behind the lines, the camion stopped a little off the road, an officer directing the light and the crew scared.',
#  'we crossed the brickyard, and stopped at the main dressing station.',
#  'there was a little shelter of green branches outside over the entrance and in the dark the night wind rustled the leaves dried by the sun.',
#  'inside there was a light.',
#  'the major was at the telephone sitting on a box.',
#  'one of the medical captains said the attack had been put forward an hour.',
#  'he offered me a glass of cognac.',
#  'i looked at the board tables, the instruments shining in the light, the basins and the stoppered bottles.',
#  'gordini stood behind me.',
#  'the major got up from the telephone.',
#  '“it starts now,” he said.',
#  '“it has been put back again.”\n\ni looked outside, it was dark and the austrian search-lights were moving on the mountains behind us.',
#  'it was quiet for a moment still, then from all the guns behind us the bombardment started.',
#  '“savoia,” said the major.',
#  '“about the soup, major,” i said.',
#  'he did not hear me.',
#  'i repeated it.',
#  '“it hasn’t come up.”\n\na big shell came in and burst outside in the brickyard.',
#  'another burst and in the noise you could hear the smaller noise of the brick and dirt raining down.',
#  '“what is there to eat?”\n\n“we have a little pasta asciutta,” the major said.',
#  '“i’ll take what you can give me.”\n\nthe major spoke to an orderly who went out of sight in the back and came back with a metal basin of cold cooked macaroni.',
#  'i handed it to gordini.',
#  '“have you any cheese?”\n\nthe major spoke grudgingly to the orderly who ducked back into the hole again and came out with a quarter of a white cheese.',
#  '“thank you very much,” i said.',
#  '“you’d better not go out.”\n\noutside something was set down beside the entrance.',
#  'one of the two men who had carried it looked in.',
#  '“bring him in,” said the major.',
#  '“what’s the matter with you?',
#  'do you want us to come outside and get him?”\n\nthe two stretcher-bearers picked up the man under the arms and by the legs and brought him in.',
#  '“slit the tunic,” the major said.',
#  'he held a forceps with some gauze in the end.',
#  'the two captains took off their coats.',
#  '“get out of here,” the major said to the two stretcher-bearers.',
#  '“come on,” i said to gordini.',
#  '“you better wait until the shelling is over,” the major said over his shoulder.',
#  '“they want to eat,” i said.',
#  '“as you wish.”\n\noutside we ran across the brickyard.',
#  'a shell burst short near the river bank.',
#  'then there was one that we did not hear coming until the sudden rush.',
#  'we both went flat and with the flash and bump of the burst and the smell heard the singing off of the fragments and the rattle of falling brick.',
#  'gordini got up and ran for the dugout.',
#  'i was after him, holding the cheese, its smooth surface covered with brick dust.',
#  'inside the dugout were the three drivers sitting against the wall, smoking.',
#  ...]

# %%
#いけそう。文ごとに取り出し、それぞれの単語を原型に戻す。それを再び再構築する！
for sentence in sentence_small:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    print (form)
# Out:
# ['late', 'summer', 'year', 'live', 'hous', 'villag', 'look', 'across', 'river', 'plain', 'mountains.']
# ['bed', 'river', 'pebbl', 'boulders,', 'dri', 'white', 'sun,', 'water', 'clear', 'swiftli', 'move', 'blue', 'channels.']
# ['troop', 'went', 'hous', 'road', 'dust', 'rais', 'powder', 'leav', 'trees.']
# ['trunk', 'tree', 'dusti', 'leav', 'fell', 'earli', 'year', 'saw', 'troop', 'march', 'along', 'road', 'dust', 'rise', 'leaves,', 'stir', 'breeze,', 'fall', 'soldier', 'march', 'afterward', 'road', 'bare', 'white', 'except', 'leaves.']
# ['plain', 'rich', 'crops;', 'mani', 'orchard', 'fruit', 'tree', 'beyond', 'plain', 'mountain', 'brown', 'bare.']
# ['fight', 'mountain', 'night', 'could', 'see', 'flash', 'artillery.']
# ['dark', 'like', 'summer', 'lightning,', 'night', 'cool', 'feel', 'storm', 'coming.']
# ['sometim', 'dark', 'heard', 'troop', 'march', 'window', 'gun', 'go', 'past', 'pull', 'motor-tractors.']
# ['much', 'traffic', 'night', 'mani', 'mule', 'road', 'box', 'ammunit', 'side', 'pack-saddl', 'gray', 'motor', 'truck', 'carri', 'men,', 'truck', 'load', 'cover', 'canva', 'move', 'slower', 'traffic.']
# ['big', 'gun', 'pass', 'day', 'drawn', 'tractors,', 'long', 'barrel', 'gun', 'cover', 'green', 'branch', 'green', 'leafi', 'branch', 'vine', 'laid', 'tractors.']
# ['north', 'could', 'look', 'across', 'valley', 'see', 'forest', 'chestnut', 'tree', 'behind', 'anoth', 'mountain', 'side', 'river.']
# ['fight', 'mountain', 'too,', 'successful,', 'fall', 'rain', 'came', 'leav', 'fell', 'chestnut', 'tree', 'branch', 'bare', 'trunk', 'black', 'rain.']
# ['vineyard', 'thin', 'bare-branch', 'countri', 'wet', 'brown', 'dead', 'autumn.']
# ['mist', 'river', 'cloud', 'mountain', 'truck', 'splash', 'mud', 'road', 'troop', 'muddi', 'wet', 'capes;', 'rifl', 'wet', 'cape', 'two', 'leather', 'cartridge-box', 'front', 'belts,', 'gray', 'leather', 'box', 'heavi', 'pack', 'clip', 'thin,', 'long', '6.5', 'mm.']
# ['cartridges,', 'bulg', 'forward', 'cape', 'men,', 'pass', 'road,', 'march', 'though', 'six', 'month', 'gone', 'child.']
# ['small', 'gray', 'motor', 'car', 'pass', 'go', 'fast;', 'usual', 'offic', 'seat', 'driver', 'offic', 'back', 'seat.']
# ['splash', 'mud', 'camion', 'even', 'one', 'offic', 'back', 'small', 'sit', 'two', 'generals,', 'small', 'could', 'see', 'face', 'top', 'cap', 'narrow', 'back,', 'car', 'went', 'especi', 'fast', 'probabl', 'king.']
# ['live', 'udin', 'came', 'way', 'nearli', 'everi', 'day', 'see', 'thing', 'going,', 'thing', 'went', 'badly.']
# ['start', 'winter', 'came', 'perman', 'rain', 'rain', 'came', 'cholera.']
# ['check', 'end', 'seven', 'thousand', 'die', 'army.']
# ['2', 'next', 'year', 'mani', 'victories.']
# ['mountain', 'beyond', 'valley', 'hillsid', 'chestnut', 'forest', 'grew', 'captur', 'victori', 'beyond', 'plain', 'plateau', 'south', 'cross', 'river', 'august', 'live', 'hous', 'gorizia', 'fountain', 'mani', 'thick', 'shadi', 'tree', 'wall', 'garden', 'wistaria', 'vine', 'purpl', 'side', 'house.']
# ['fight', 'next', 'mountain', 'beyond', 'mile', 'away.']
# ['town', 'nice', 'hous', 'fine.']
# ['river', 'ran', 'behind', 'us', 'town', 'captur', 'handsom', 'mountain', 'beyond', 'could', 'taken', 'glad', 'austrian', 'seem', 'want', 'come', 'back', 'town', 'time,', 'war', 'end,', 'bombard', 'destroy', 'littl', 'militari', 'way.']
# ['peopl', 'live', 'hospit', 'café', 'artilleri', 'side', 'street', 'two', 'bawdi', 'houses,', 'one', 'troop', 'one', 'officers,', 'end', 'summer,', 'cool', 'nights,', 'fight', 'mountain', 'beyond', 'town,', 'shell-mark', 'iron', 'railway', 'bridge,', 'smash', 'tunnel', 'river', 'fight', 'been,', 'tree', 'around', 'squar', 'long', 'avenu', 'tree', 'led', 'square;', 'girl', 'town,', 'king', 'pass', 'motor', 'car,', 'sometim', 'see', 'face', 'littl', 'long', 'neck', 'bodi', 'gray', 'beard', 'like', 'goat’', 'chin', 'tuft;', 'sudden', 'interior', 'hous', 'lost', 'wall', 'shelling,', 'plaster', 'rubbl', 'garden', 'sometim', 'street,', 'whole', 'thing', 'go', 'well', 'carso', 'made', 'fall', 'differ', 'last', 'fall', 'country.']
# ['war', 'chang', 'too.']
# ['forest', 'oak', 'tree', 'mountain', 'beyond', 'town', 'gone.']
# ['forest', 'green', 'summer', 'come', 'town', 'stump', 'broken', 'trunk', 'ground', 'torn', 'up,', 'one', 'day', 'end', 'fall', 'oak', 'forest', 'saw', 'cloud', 'come', 'mountain.']
# ['came', 'fast', 'sun', 'went', 'dull', 'yellow', 'everyth', 'gray', 'sky', 'cover', 'cloud', 'came', 'mountain', 'suddenli', 'snow.']
# ['snow', 'slant', 'across', 'wind,', 'bare', 'ground', 'covered,', 'stump', 'tree', 'projected,', 'snow', 'gun', 'path', 'snow', 'go', 'back', 'latrin', 'behind', 'trenches.']
# ['later,', 'town,', 'watch', 'snow', 'falling,', 'look', 'window', 'bawdi', 'house,', 'hous', 'officers,', 'sat', 'friend', 'two', 'glass', 'drink', 'bottl', 'asti,', 'and,', 'look', 'snow', 'fall', 'slowli', 'heavily,', 'knew', 'year.']
# ['river', 'mountain', 'taken;', 'none', 'mountain', 'beyond', 'river', 'taken.']
# ['left', 'next', 'year.']
# ['friend', 'saw', 'priest', 'mess', 'go', 'street,', 'walk', 'care', 'slush,', 'pound', 'window', 'attract', 'attention.']
# ['priest', 'look', 'up.']
# ['saw', 'us', 'smiled.']
# ['friend', 'motion', 'come', 'in.']
# ['priest', 'shook', 'head', 'went', 'on.']
# ['night', 'mess', 'spaghetti', 'course,', 'everi', 'one', 'ate', 'quickli', 'seriously,', 'lift', 'spaghetti', 'fork', 'loos', 'strand', 'hung', 'clear', 'lower', 'mouth,', 'els', 'use', 'continu', 'lift', 'suck', 'mouth,', 'help', 'wine', 'grass-cov', 'gallon', 'flask;', 'swung', 'metal', 'cradl', 'pull', 'neck', 'flask', 'forefing', 'wine,', 'clear', 'red,', 'tannic', 'lovely,', 'pour', 'glass', 'held', 'hand;', 'course,', 'captain', 'commenc', 'pick', 'priest.']
# ['priest', 'young', 'blush', 'easili', 'wore', 'uniform', 'like', 'rest', 'us', 'cross', 'dark', 'red', 'velvet', 'left', 'breast', 'pocket', 'gray', 'tunic.']
# ['captain', 'spoke', 'pidgin', 'italian', 'doubt', 'benefit,', 'order', 'might', 'understand', 'perfectly,', 'noth', 'lost.']
# ['“priest', 'to-day', 'girls,”', 'captain', 'said', 'look', 'priest', 'me.']
# ['priest', 'smile', 'blush', 'shook', 'head.']
# ['captain', 'bait', 'often.']
# ['“not', 'true?”', 'ask', 'captain.']
# ['“to-day', 'see', 'priest', 'girls.”', '“no,”', 'said', 'priest.']
# ['offic', 'amus', 'baiting.']
# ['“priest', 'girls,”', 'went', 'captain.']
# ['“priest', 'never', 'girls,”', 'explain', 'me.']
# ['took', 'glass', 'fill', 'it,', 'look', 'eye', 'time,', 'lose', 'sight', 'priest.']
# ['“priest', 'everi', 'night', 'five', 'one.”', 'everi', 'one', 'tabl', 'laughed.']
# ['“you', 'understand?']
# ['priest', 'everi', 'night', 'five', 'one.”', 'made', 'gestur', 'laugh', 'loudly.']
# ['priest', 'accept', 'joke.']
# ['“the', 'pope', 'want', 'austrian', 'win', 'war,”', 'major', 'said.']
# ['“he', 'love', 'franz', 'joseph.']
# ['that’', 'money', 'come', 'from.']
# ['atheist.”', '“did', 'ever', 'read', 'black', 'pig?”', 'ask', 'lieutenant.']
# ['“i', 'get', 'copy.']
# ['shook', 'faith.”', '“it', 'filthi', 'vile', 'book,”', 'said', 'priest.']
# ['“you', 'realli', 'like', 'it.”', '“it', 'valuable,”', 'said', 'lieutenant.']
# ['“it', 'tell', 'priests.']
# ['like', 'it,”', 'said', 'me.']
# ['smile', 'priest', 'smile', 'back', 'across', 'candle-light.']
# ['“don’t', 'read', 'it,”', 'said.']
# ['“i', 'get', 'you,”', 'said', 'lieutenant.']
# ['“all', 'think', 'men', 'atheists,”', 'major', 'said.']
# ['“i', 'believ', 'free', 'mason', 'however.”', '“i', 'believ', 'free', 'masons,”', 'lieuten', 'said.']
# ['“it', 'nobl', 'organization.”', 'one', 'came', 'door', 'open', 'could', 'see', 'snow', 'falling.']
# ['“there', 'offens', 'snow', 'come,”', 'said.']
# ['“certainli', 'not,”', 'said', 'major.']
# ['“you', 'go', 'leave.']
# ['go', 'rome,', 'naples,', 'sicily—”', '“he', 'visit', 'amalfi,”', 'said', 'lieutenant.']
# ['“i', 'write', 'card', 'famili', 'amalfi.']
# ['love', 'like', 'son.”', '“he', 'go', 'palermo.”', '“he', 'ought', 'go', 'capri.”', '“i', 'would', 'like', 'see', 'abruzzi', 'visit', 'famili', 'capracotta,”', 'said', 'priest.']
# ['“listen', 'talk', 'abruzzi.']
# ['there’', 'snow', 'here.']
# ['doesn’t', 'want', 'see', 'peasants.']
# ['let', 'go', 'centr', 'cultur', 'civilization.”', '“he', 'fine', 'girls.']
# ['give', 'address', 'place', 'naples.']
# ['beauti', 'young', 'girls—accompani', 'mothers.']
# ['ha!']
# ['ha!']
# ['ha!”', 'captain', 'spread', 'hand', 'open,', 'thumb', 'finger', 'outspread', 'make', 'shadow', 'pictures.']
# ['shadow', 'hand', 'wall.']
# ['spoke', 'pidgin', 'italian.']
# ['“you', 'go', 'away', 'like', 'this,”', 'point', 'thumb,', '“and', 'come', 'back', 'like', 'this,”', 'touch', 'littl', 'finger.']
# ['everi', 'one', 'laughed.']
# ['“look,”', 'said', 'captain.']
# ['spread', 'hand', 'again.']
# ['candle-light', 'made', 'shadow', 'wall.']
# ['start', 'upright', 'thumb', 'name', 'order', 'thumb', 'four', 'fingers,', '“soto-tenent', '(the', 'thumb),', 'tenent', '(first', 'finger),', 'capitano', '(next', 'finger),', 'maggior', '(next', 'littl', 'finger),', 'tenentecolonello', '(the', 'littl', 'finger).']
# ['go', 'away', 'soto-tenente!']
# ['come', 'back', 'soto-colonello!”', 'laughed.']
# ['captain', 'great', 'success', 'finger', 'games.']
# ['look', 'priest', 'shouted,', '“everi', 'night', 'priest', 'five', 'one!”', 'laugh', 'again.']
# ['“you', 'must', 'go', 'leav', 'once,”', 'major', 'said.']
# ['“i', 'would', 'like', 'go', 'show', 'things,”', 'lieuten', 'said.']
# ['“when', 'come', 'back', 'bring', 'phonograph.”', '“bring', 'good', 'opera', 'disks.”', '“bring', 'caruso.”', '“don’t', 'bring', 'caruso.']
# ['bellows.”', '“don’t', 'wish', 'could', 'bellow', 'like', 'him?”', '“he', 'bellows.']
# ['say', 'bellows!”', '“i', 'would', 'like', 'go', 'abruzzi,”', 'priest', 'said.']
# ['other', 'shouting.']
# ['“there', 'good', 'hunting.']
# ['would', 'like', 'peopl', 'though', 'cold', 'clear', 'dry.']
# ['could', 'stay', 'family.']
# ['father', 'famou', 'hunter.”', '“come', 'on,”', 'said', 'captain.']
# ['“we', 'go', 'whorehous', 'shuts.”', '“good-night,”', 'said', 'priest.']
# ['“good-night,”', 'said.']
# ['3', 'came', 'back', 'front', 'still', 'live', 'town.']
# ['mani', 'gun', 'countri', 'around', 'spring', 'come.']
# ['field', 'green', 'small', 'green', 'shoot', 'vines,', 'tree', 'along', 'road', 'small', 'leav', 'breez', 'came', 'sea.']
# ['saw', 'town', 'hill', 'old', 'castl', 'cup', 'hill', 'mountain', 'beyond,', 'brown', 'mountain', 'littl', 'green', 'slopes.']
# ['town', 'guns,', 'new', 'hospitals,', 'met', 'british', 'men', 'sometim', 'women,', 'street,', 'hous', 'hit', 'shell', 'fire.']
# ['jt', 'warm', 'like', 'spring', 'walk', 'alleyway', 'trees,', 'warm', 'sun', 'wall,', 'found', 'still', 'live', 'hous', 'look', 'left', 'it.']
# ['door', 'open,', 'soldier', 'sit', 'bench', 'outsid', 'sun,', 'ambul', 'wait', 'side', 'door', 'insid', 'door,', 'went', 'in,', 'smell', 'marbl', 'floor', 'hospital.']
# ['left', 'except', 'spring.']
# ['look', 'door', 'big', 'room', 'saw', 'major', 'sit', 'desk,', 'window', 'open', 'sunlight', 'come', 'room.']
# ['see', 'know', 'whether', 'go', 'report', 'go', 'upstair', 'first', 'clean', 'up.']
# ['decid', 'go', 'upstairs.']
# ['room', 'share', 'lieuten', 'rinaldi', 'look', 'courtyard.']
# ['window', 'open,', 'bed', 'made', 'blanket', 'thing', 'hung', 'wall,', 'ga', 'mask', 'oblong', 'tin', 'can,', 'steel', 'helmet', 'peg.']
# ['foot', 'bed', 'flat', 'trunk,', 'winter', 'boots,', 'leather', 'shini', 'oil,', 'trunk.']
# ['austrian', 'sniper’', 'rifl', 'blu', 'octagon', 'barrel', 'love', 'dark', 'walnut,', 'cheek-fitted,', 'schutzen', 'stock,', 'hung', 'two', 'beds.']
# ['telescop', 'fit', 'was,', 'remembered,', 'lock', 'trunk.']
# ['lieutenant,', 'rinaldi,', 'lay', 'asleep', 'bed.']
# ['woke', 'heard', 'room', 'sat', 'up.']
# ['“ciaou!”', 'said.']
# ['“what', 'kind', 'time', 'have?”', '“magnificent.”', 'shook', 'hand', 'put', 'arm', 'around', 'neck', 'kiss', 'me.']
# ['“oughf,”', 'said.']
# ['“you’r', 'dirty,”', 'said.']
# ['“you', 'ought', 'wash.', 'go', 'do?']
# ['tell', 'everyth', 'once.”', '“i', 'went', 'everywhere.']
# ['milan,', 'florence,', 'rome,', 'naples,', 'villa', 'san', 'giovanni,', 'messina,', 'taormina—”', '“you', 'talk', 'like', 'time-table.']
# ['beauti', 'adventures?”', '“yes.”', '“where?”', '“milano,', 'firenze,', 'roma,', 'napoli—”', '“that’', 'enough.']
# ['tell', 'realli', 'best.”', '“in', 'milano.”', '“that', 'first.']
# ['meet', 'her?']
# ['cova?']
# ['go?']
# ['feel?']
# ['tell', 'everyth', 'once.']
# ['stay', 'night?”', '“yes.”', '“that’', 'nothing.']
# ['beauti', 'girls.']
# ['new', 'girl', 'never', 'front', 'before.”', '“wonderful.”', '“you', 'don’t', 'believ', 'me?']
# ['go', 'afternoon', 'see.']
# ['town', 'beauti', 'english', 'girls.']
# ['love', 'miss', 'barkley.']
# ['take', 'call.']
# ['probabl', 'marri', 'miss', 'barkley.”', '“i', 'get', 'wash', 'report.']
# ['doesn’t', 'anybodi', 'work', 'now?”', '“sinc', 'gone', 'noth', 'frostbites,', 'chilblains,', 'jaundice,', 'gonorrhea,', 'self-inflict', 'wounds,', 'pneumonia', 'hard', 'soft', 'chancres.']
# ['everi', 'week', 'one', 'get', 'wound', 'rock', 'fragments.']
# ['real', 'wounded.']
# ['next', 'week', 'war', 'start', 'again.']
# ['perhap', 'start', 'again.']
# ['say', 'so.']
# ['think', 'would', 'right', 'marri', 'miss', 'barkley—aft', 'war', 'course?”', '“absolutely,”', 'said', 'pour', 'basin', 'full', 'water.']
# ['“to-night', 'tell', 'everything,”', 'said', 'rinaldi.']
# ['“now', 'must', 'go', 'back', 'sleep', 'fresh', 'beauti', 'miss', 'barkley.”', 'took', 'tunic', 'shirt', 'wash', 'cold', 'water', 'basin.']
# ['rub', 'towel', 'look', 'around', 'room', 'window', 'rinaldi', 'lie', 'eye', 'close', 'bed.']
# ['good-looking,', 'age,', 'came', 'amalfi.']
# ['love', 'surgeon', 'great', 'friends.']
# ['look', 'open', 'eyes.']
# ['“have', 'money?”', '“yes.”', '“loan', 'fifti', 'lire.”', 'dri', 'hand', 'took', 'pocket-book', 'insid', 'tunic', 'hang', 'wall.']
# ['rinaldi', 'took', 'note,', 'fold', 'without', 'rise', 'bed', 'slid', 'breech', 'pocket.']
# ['smiled,', '“i', 'must', 'make', 'miss', 'barkley', 'impress', 'man', 'suffici', 'wealth.']
# ['great', 'good', 'friend', 'financi', 'protector.”', '“go', 'hell,”', 'said.']
# ['night', 'mess', 'sat', 'next', 'priest', 'disappoint', 'suddenli', 'hurt', 'gone', 'abruzzi.']
# ['written', 'father', 'come', 'made', 'preparations.']
# ['felt', 'badli', 'could', 'understand', 'gone.']
# ['want', 'tri', 'explain', 'one', 'thing', 'led', 'anoth', 'final', 'saw', 'understood', 'realli', 'want', 'go', 'almost', 'right.']
# ['drunk', 'much', 'wine', 'afterward', 'coffe', 'strega', 'explained,', 'winefully,', 'thing', 'want', 'do;', 'never', 'things.']
# ['two', 'talk', 'other', 'argued.']
# ['want', 'go', 'abruzzi.']
# ['gone', 'place', 'road', 'frozen', 'hard', 'iron,', 'clear', 'cold', 'dri', 'snow', 'dri', 'powderi', 'hare-track', 'snow', 'peasant', 'took', 'hat', 'call', 'lord', 'good', 'hunting.']
# ['gone', 'place', 'smoke', 'café', 'night', 'room', 'whirl', 'need', 'look', 'wall', 'make', 'stop,', 'night', 'bed,', 'drunk,', 'knew', 'was,', 'strang', 'excit', 'wake', 'know', 'you,', 'world', 'unreal', 'dark', 'excit', 'must', 'resum', 'unknow', 'care', 'night,', 'sure', 'caring.']
# ['suddenli', 'care', 'much', 'sleep', 'wake', 'sometim', 'morn', 'gone', 'everyth', 'sharp', 'hard', 'clear', 'sometim', 'disput', 'cost.']
# ['sometim', 'still', 'pleasant', 'fond', 'warm', 'breakfast', 'lunch.']
# ['sometim', 'nice', 'gone', 'glad', 'get', 'street', 'alway', 'anoth', 'day', 'start', 'anoth', 'night.']
# ['tri', 'tell', 'night', 'differ', 'night', 'day', 'night', 'better', 'unless', 'day', 'clean', 'cold', 'could', 'tell', 'it;', 'cannot', 'tell', 'now.']
# ['know.']
# ['understood', 'realli', 'want', 'go', 'abruzzi', 'gone', 'still', 'friends,', 'mani', 'tast', 'alike,', 'differ', 'us.']
# ['alway', 'known', 'know', 'what,', 'learn', 'it,', 'alway', 'abl', 'forget.']
# ['know', 'then,', 'although', 'learn', 'later.']
# ['meantim', 'mess,', 'meal', 'finished,', 'argument', 'went', 'on.']
# ['two', 'stop', 'talk', 'captain', 'shouted,', '“priest', 'happy.']
# ['priest', 'happi', 'without', 'girls.”', '“i', 'happy,”', 'said', 'priest.']
# ['“priest', 'happy.']
# ['priest', 'want', 'austrian', 'win', 'war,”', 'captain', 'said.']
# ['other', 'listened.']
# ['priest', 'shook', 'head.']
# ['“no,”', 'said.']
# ['“priest', 'want', 'us', 'never', 'attack.']
# ['don’t', 'want', 'us', 'never', 'attack?”', '“no.']
# ['war', 'suppos', 'must', 'attack.”', '“must', 'attack.']
# ['shall', 'attack!”', 'priest', 'nodded.']
# ['“leav', 'alone,”', 'major', 'said.']
# ['“he’', 'right.”', '“he', 'can’t', 'anyth', 'anyway,”', 'captain', 'said.']
# ['got', 'left', 'table.']
# ['4', 'batteri', 'next', 'garden', 'woke', 'morn', 'saw', 'sun', 'come', 'window', 'got', 'bed.']
# ['went', 'window', 'look', 'out.']
# ['gravel', 'path', 'moist', 'grass', 'wet', 'dew.']
# ['batteri', 'fire', 'twice', 'air', 'came', 'time', 'like', 'blow', 'shook', 'window', 'made', 'front', 'pajama', 'flap.']
# ['could', 'see', 'gun', 'evid', 'fire', 'directli', 'us.']
# ['nuisanc', 'comfort', 'bigger.']
# ['look', 'garden', 'heard', 'motor', 'truck', 'start', 'road.']
# ['dressed,', 'went', 'downstairs,', 'coffe', 'kitchen', 'went', 'garage.']
# ['ten', 'car', 'line', 'side', 'side', 'long', 'shed.']
# ['top-heavy,', 'blunt-nos', 'ambulances,', 'paint', 'gray', 'built', 'like', 'moving-vans.']
# ['mechan', 'work', 'one', 'yard.']
# ['three', 'other', 'mountain', 'dress', 'stations.']
# ['“do', 'ever', 'shell', 'battery?”', 'task', 'one', 'mechanics.']
# ['“no,', 'signor', 'tenente.']
# ['protect', 'littl', 'hill.”', '“how’', 'everything?”', '“not', 'bad.']
# ['machin', 'good', 'other', 'march.”', 'stop', 'work', 'smiled.']
# ['“were', 'permission?”', '“yes.”', 'wipe', 'hand', 'jumper', 'grinned.']
# ['“you', 'good', 'time?”', 'other', 'grin', 'too.']
# ['“fine,”', 'said.']
# ['“what’', 'matter', 'machine?”', '“it’', 'good.']
# ['one', 'thing', 'another.”', '“what’', 'matter', 'now?”', '“new', 'rings.”', 'left', 'working,', 'car', 'look', 'disgrac', 'empti', 'engin', 'open', 'part', 'spread', 'work', 'bench,', 'went', 'shed', 'look', 'cars.']
# ['moder', 'clean,', 'freshli', 'washed,', 'other', 'dusty.']
# ['look', 'tire', 'carefully,', 'look', 'cut', 'stone', 'bruises.']
# ['everyth', 'seem', 'good', 'condition.']
# ['evid', 'made', 'differ', 'whether', 'look', 'thing', 'not.']
# ['imagin', 'condit', 'cars,', 'whether', 'thing', 'obtainable,', 'smooth', 'function', 'busi', 'remov', 'wound', 'sick', 'dress', 'stations,', 'haul', 'back', 'mountain', 'clear', 'station', 'distribut', 'hospit', 'name', 'papers,', 'depend', 'consider', 'extent', 'myself.']
# ['evid', 'matter', 'whether', 'not.']
# ['“ha', 'troubl', 'get', 'parts?”', 'ask', 'sergeant', 'mechanic.']
# ['“no,', 'signor', 'tenente.”', '“where', 'gasolin', 'park', 'now?”', '“at', 'place.”', '“good,”', 'said', 'went', 'back', 'hous', 'drank', 'anoth', 'bowl', 'coffe', 'mess', 'table.']
# ['coffe', 'pale', 'gray', 'sweet', 'condens', 'milk.']
# ['outsid', 'window', 'love', 'spring', 'morning.']
# ['begin', 'feel', 'dryness', 'nose', 'meant', 'day', 'would', 'hot', 'later', 'on.']
# ['day', 'visit', 'post', 'mountain', 'back', 'town', 'late', 'afternoon.']
# ['whole', 'thing', 'seem', 'run', 'better', 'away.']
# ['offens', 'go', 'start', 'heard.']
# ['divis', 'work', 'attack', 'place', 'river', 'major', 'told', 'would', 'see', 'post', 'attack.']
# ['attack', 'would', 'cross', 'river', 'narrow', 'gorg', 'spread', 'hillside.']
# ['post', 'car', 'would', 'near', 'river', 'could', 'get', 'keep', 'covered.']
# ['would,', 'course,', 'select', 'infantri', 'suppos', 'work', 'out.']
# ['one', 'thing', 'gave', 'fals', 'feel', 'soldiering.']
# ['dusti', 'dirti', 'went', 'room', 'wash.', 'rinaldi', 'sit', 'bed', 'copi', 'hugo’', 'english', 'grammar.']
# ['dressed,', 'wore', 'black', 'boots,', 'hair', 'shone.']
# ['“splendid,”', 'said', 'saw', 'me.']
# ['“you', 'come', 'see', 'miss', 'barkley.”', '"no.']
# ['“yes.']
# ['pleas', 'come', 'make', 'good', 'impress', 'her.”', '“all', 'right.']
# ['wait', 'till', 'get', 'clean', 'up.”', '“wash', 'come', 'are.”', 'washed,', 'brush', 'hair', 'started.']
# ['“wait', 'minute,”', 'rinaldi', 'said.']
# ['“perhap', 'drink.”', 'open', 'trunk', 'took', 'bottle.']
# ['“not', 'strega,”', 'said.']
# ['“no.']
# ['grappa.”', '“all', 'right.”', 'pour', 'two', 'glass', 'touch', 'them,', 'first', 'finger', 'extended.']
# ['grappa', 'strong.']
# ['“another?”', '“all', 'right,”', 'said.']
# ['drank', 'second', 'grappa,', 'rinaldi', 'put', 'away', 'bottl', 'went', 'stairs.']
# ['hot', 'walk', 'town', 'sun', 'start', 'go', 'pleasant.']
# ['british', 'hospit', 'big', 'villa', 'built', 'german', 'war.']
# ['miss', 'barkley', 'garden.']
# ['anoth', 'nurs', 'her.']
# ['saw', 'white', 'uniform', 'tree', 'walk', 'toward', 'them.']
# ['rinaldi', 'saluted.']
# ['salut', 'moderately.']
# ['“how', 'do?”', 'miss', 'barkley', 'said.']
# ['“you’r', 'italian,', 'you?”', '“oh,', 'no.”', 'rinaldi', 'talk', 'nurse.']
# ['laughing.']
# ['“what', 'odd', 'thing—to', 'italian', 'army.”', '“it’', 'realli', 'army.']
# ['it’', 'ambulance.”', '“it’', 'odd', 'though.']
# ['it?”', '“i', 'don’t', 'know,”', 'said.']
# ['“there', 'isn’t', 'alway', 'explan', 'everything.”', '“oh,', 'isn’t', 'there?']
# ['brought', 'think', 'was.”', '“that’', 'aw', 'nice.”', '“do', 'go', 'talk', 'way?”', '“no,”', 'said.']
# ['“that’', 'relief.']
# ['isn’t', 'it?”', '“what', 'stick?”', 'asked.']
# ['miss', 'barkley', 'quit', 'tall.']
# ['wore', 'seem', 'nurse’', 'uniform,', 'blond', 'tawni', 'skin', 'gray', 'eyes.']
# ['thought', 'beautiful.']
# ['carri', 'thin', 'rattan', 'stick', 'like', 'toy', 'riding-crop,', 'bound', 'leather.']
# ['“it', 'belong', 'boy', 'kill', 'last', 'year.”', '“i’m', 'aw', 'sorry.”', '“he', 'nice', 'boy.']
# ['go', 'marri', 'kill', 'somme.”', '“it', 'ghastli', 'show.”', '“were', 'there?”', '“no.”', '“i’v', 'heard', 'it,”', 'said.']
# ['“there’', 'realli', 'war', 'sort', 'here.']
# ['sent', 'littl', 'stick.']
# ['mother', 'sent', 'me.']
# ['return', 'things.”', '“had', 'engag', 'long?”', '“eight', 'years.']
# ['grew', 'together.”', '“and', 'didn’t', 'marry?”', '“i', 'don’t', 'know,”', 'said.']
# ['“i', 'fool', 'to.']
# ['could', 'given', 'anyway.']
# ['thought', 'would', 'bad', 'him.”', '“i', 'see.”', '“have', 'ever', 'love', 'one?”', '“no,”', 'said.']
# ['sat', 'bench', 'look', 'her.']
# ['“you', 'beauti', 'hair,”', 'said.']
# ['“do', 'like', 'it?”', '“veri', 'much.”', '“i', 'go', 'cut', 'died.”', '“no.”', '“i', 'want', 'someth', 'him.']
# ['see', 'didn’t', 'care', 'thing', 'could', 'all.']
# ['could', 'anyth', 'want', 'would', 'known.']
# ['would', 'marri', 'anything.']
# ['know', 'now.']
# ['want', 'go', 'war', 'didn’t', 'know.”', 'say', 'anything.']
# ['“i', 'didn’t', 'know', 'anyth', 'then.']
# ['thought', 'would', 'wors', 'him.']
# ['thought', 'perhap', 'couldn’t', 'stand', 'cours', 'kill', 'end', 'it.”', '“i', 'don’t', 'know.”', '“oh,', 'yes,”', 'said.']
# ['“that’', 'end', 'it.”', 'look', 'rinaldi', 'talk', 'nurse.']
# ['“what', 'name?”', '“ferguson.']
# ['helen', 'ferguson.']
# ['friend', 'doctor,', 'isn’t', 'he?”', '“yes.']
# ['he’', 'good.”', '“that’', 'splendid.']
# ['rare', 'find', 'one', 'good', 'close', 'front.']
# ['close', 'front,', 'isn’t', 'it?”', '“quite.”', '“it’', 'silli', 'front,”', 'said.']
# ['“but', 'it’', 'beautiful.']
# ['go', 'offensive?”', '“yes.”', '“then', 'we’ll', 'work.']
# ['there’', 'work', 'now.”', '“have', 'done', 'nurs', 'long?”', '“sinc', 'end', 'of’fifteen.']
# ['start', 'did.']
# ['rememb', 'silli', 'idea', 'might', 'come', 'hospit', 'was.']
# ['sabr', 'cut,', 'suppose,', 'bandag', 'around', 'head.']
# ['shot', 'shoulder.']
# ['someth', 'picturesque.”', '“thi', 'picturesqu', 'front,”', 'said.']
# ['“yes,”', 'said.']
# ['“peopl', 'can’t', 'realiz', 'franc', 'like.']
# ['did,', 'couldn’t', 'go', 'on.']
# ['didn’t', 'sabr', 'cut.']
# ['blew', 'bits.”', 'didn’t', 'say', 'anything.']
# ['“do', 'suppos', 'alway', 'go', 'on?”', '“no.”', '“what’', 'stop', 'it?”', '“it', 'crack', 'somewhere.”', '“we’ll', 'crack.']
# ['we’ll', 'crack', 'france.']
# ['can’t', 'go', 'thing', 'like', 'somm', 'crack.”', '“they', 'won’t', 'crack', 'here,”', 'said.']
# ['“you', 'think', 'not?”', '“no.']
# ['well', 'last', 'summer.”', '“they', 'may', 'crack,”', 'said.']
# ['“anybodi', 'may', 'crack.”', '“the', 'german', 'too.”', '“no,”', 'said.']
# ['“i', 'think', 'not.”', 'went', 'toward', 'rinaldi', 'miss', 'ferguson.']
# ['“you', 'love', 'italy?”', 'rinaldi', 'ask', 'miss', 'ferguson', 'english.']
# ['“quit', 'well.”', '“no', 'understand,”', 'rinaldi', 'shook', 'head.']
# ['“abbastanza', 'bene,”', 'translated.']
# ['shook', 'head.']
# ['“that', 'good.']
# ['love', 'england?”', '“not', 'well.']
# ['i’m', 'scotch,', 'see.”', 'rinaldi', 'look', 'blankly.']
# ['“she’', 'scotch,', 'love', 'scotland', 'better', 'england,”', 'said', 'italian.']
# ['“but', 'scotland', 'england.”', 'translat', 'miss', 'ferguson.']
# ['“pa', 'encore,”', 'said', 'miss', 'ferguson.']
# ['“not', 'really?”', '“never.']
# ['like', 'english.”', '“not', 'like', 'english?']
# ['like', 'miss', 'barkley?”', '“oh,', 'that’', 'different.']
# ['mustn’t', 'take', 'everyth', 'literally.”', 'said', 'good-night', 'left.']
# ['walk', 'home', 'rinaldi', 'said,', '“miss', 'barkley', 'prefer', 'me.']
# ['clear.']
# ['littl', 'scotch', 'one', 'nice.”', '“very,”', 'said.']
# ['notic', 'her.']
# ['“you', 'like', 'her?”', '“no,”', 'said', 'rinaldi.']
# ['5', 'next', 'afternoon', 'went', 'call', 'miss', 'barkley', 'again.']
# ['garden', 'went', 'side', 'door', 'villa', 'ambul', 'drove', 'up.']
# ['insid', 'saw', 'head', 'nurse,', 'said', 'miss', 'barkley', 'duty—“there’', 'war', 'on,', 'know.”', 'said', 'knew.']
# ['“you’r', 'american', 'italian', 'army?”', 'asked.']
# ['“yes,', 'ma’am.”', '“how', 'happen', 'that?']
# ['didn’t', 'join', 'us?”', '“i', 'don’t', 'know,”', 'said.']
# ['“could', 'join', 'now?”', '“i’m', 'afraid', 'now.']
# ['tell', 'me.']
# ['join', 'italians?”', '“i', 'italy,”', 'said,', '“and', 'spoke', 'italian.”', '“oh,”', 'said.']
# ['“i’m', 'learn', 'it.']
# ['it’', 'beauti', 'language.”', '“somebodi', 'said', 'abl', 'learn', 'two', 'weeks.”', '“oh,', 'i’ll', 'learn', 'two', 'weeks.']
# ['i’v', 'studi', 'month', 'now.']
# ['may', 'come', 'see', 'seven', 'o’clock', 'wish.']
# ['she’ll', 'then.']
# ['don’t', 'bring', 'lot', 'italians.”', '“not', 'even', 'beauti', 'language?”', '“no.']
# ['beauti', 'uniforms.”', '“good', 'evening,”', 'said.']
# ['“a', 'rivederci,', 'tenente.”', '“a', 'rivederla.”', 'salut', 'went', 'out.']
# ['imposs', 'salut', 'foreign', 'italian,', 'without', 'embarrassment.']
# ['italian', 'salut', 'never', 'seem', 'made', 'export.']
# ['day', 'hot.']
# ['river', 'bridgehead', 'plava.']
# ['offens', 'begin.']
# ['imposs', 'advanc', 'far', 'side', 'year', 'one', 'road', 'lead', 'pass', 'pontoon', 'bridg', 'machine-gun', 'shell', 'fire', 'nearli', 'mile.']
# ['wide', 'enough', 'either', 'carri', 'transport', 'offens', 'austrian', 'could', 'make', 'shambl', 'it.']
# ['italian', 'cross', 'spread', 'littl', 'way', 'far', 'side', 'hold', 'mile', 'half', 'austrian', 'side', 'river.']
# ['nasti', 'place', 'austrian', 'let', 'hold', 'it.']
# ['suppos', 'mutual', 'toler', 'austrian', 'still', 'kept', 'bridgehead', 'river.']
# ['austrian', 'trench', 'hillsid', 'yard', 'italian', 'lines.']
# ['littl', 'town', 'rubble.']
# ['left', 'railway', 'station', 'smash', 'perman', 'bridg', 'could', 'repair', 'use', 'plain', 'sight.']
# ['went', 'along', 'narrow', 'road', 'toward', 'river,', 'left', 'car', 'dress', 'station', 'hill,', 'cross', 'pontoon', 'bridge,', 'protect', 'shoulder', 'mountain,', 'went', 'trench', 'smashed-down', 'town', 'along', 'edg', 'slope.']
# ['everybodi', 'dugouts.']
# ['rack', 'rocket', 'stand', 'touch', 'call', 'help', 'artilleri', 'signal', 'telephon', 'wire', 'cut.']
# ['quiet,', 'hot', 'dirty.']
# ['look', 'across', 'wire', 'austrian', 'lines.']
# ['nobodi', 'sight.']
# ['drink', 'captain', 'knew', 'one', 'dugout', 'went', 'back', 'across', 'bridge.']
# ['new', 'wide', 'road', 'finish', 'would', 'go', 'mountain', 'zig-zag', 'bridge.']
# ['road', 'finish', 'offens', 'would', 'start.']
# ['came', 'forest', 'sharp', 'turns.']
# ['system', 'bring', 'everyth', 'new', 'road', 'take', 'empti', 'trucks,', 'cart', 'load', 'ambul', 'return', 'traffic', 'old', 'narrow', 'road.']
# ['dress', 'station', 'austrian', 'side', 'river', 'edg', 'hill', 'stretcher-bear', 'would', 'bring', 'wound', 'back', 'across', 'pontoon', 'bridge.']
# ['would', 'offens', 'started.']
# ['far', 'could', 'make', 'last', 'mile', 'new', 'road', 'start', 'level', 'would', 'abl', 'shell', 'steadili', 'austrians.']
# ['look', 'though', 'might', 'mess.']
# ['found', 'place', 'car', 'would', 'shelter', 'pass', 'last', 'badlook', 'bit', 'could', 'wait', 'wound', 'brought', 'across', 'pontoon', 'bridge.']
# ['would', 'like', 'drive', 'new', 'road', 'yet', 'finished.']
# ['look', 'wide', 'well', 'made', 'good', 'grade', 'turn', 'look', 'impress', 'could', 'see', 'open', 'forest', 'mountain', 'side.']
# ['car', 'would', 'right', 'good', 'metal-to-met', 'brake', 'anyway,', 'come', 'down,', 'would', 'loaded.']
# ['drove', 'back', 'narrow', 'road.']
# ['two', 'carabinieri', 'held', 'car', 'up.']
# ['shell', 'fallen', 'wait', 'three', 'other', 'fell', 'road.']
# ['seventy-seven', 'came', 'whish', 'rush', 'air,', 'hard', 'bright', 'burst', 'flash', 'gray', 'smoke', 'blew', 'across', 'road.']
# ['carabinieri', 'wave', 'us', 'go', 'on.']
# ['pass', 'shell', 'land', 'avoid', 'small', 'broken', 'place', 'smell', 'high', 'explos', 'smell', 'blast', 'clay', 'stone', 'freshli', 'shatter', 'flint.']
# ['drove', 'back', 'gorizia', 'villa', 'and,', 'said,', 'went', 'call', 'miss', 'barkley,', 'duty.']
# ['dinner', 'ate', 'quickli', 'left', 'villa', 'british', 'hospital.']
# ['realli', 'larg', 'beauti', 'fine', 'tree', 'grounds.']
# ['miss', 'barkley', 'sit', 'bench', 'garden.']
# ['miss', 'ferguson', 'her.']
# ['seem', 'glad', 'see', 'littl', 'miss', 'ferguson', 'excus', 'went', 'away.']
# ['“i’ll', 'leav', 'two,”', 'said.']
# ['“you', 'get', 'along', 'well', 'without', 'me.”', '“don’t', 'go,', 'helen,”', 'miss', 'barkley', 'said.']
# ['“i’d', 'realli', 'rather.']
# ['must', 'write', 'letters.”', '“good-night,”', 'said.']
# ['“good-night,', 'henry.”', '“don’t', 'write', 'anyth', 'bother', 'censor.”', '“don’t', 'worry.']
# ['write', 'beauti', 'place', 'live', 'brave', 'italian', 'are.”', '“that', 'way', 'you’ll', 'decorated.”', '“that', 'nice.']
# ['good-night,', 'catherine.”', '“i’ll', 'see', 'littl', 'while,”', 'miss', 'barkley', 'said.']
# ['miss', 'ferguson', 'walk', 'away', 'dark.']
# ['“she’', 'nice,”', 'said.']
# ['“oh,', 'yes,', 'she’', 'nice.']
# ['she’', 'nurse.”', '“aren’t', 'nurse?”', '“oh,', 'no.']
# ['i’m', 'someth', 'call', 'v.', 'a.', 'd.', 'work', 'hard', 'one', 'trust', 'us.”', '“whi', 'not?”', '“they', 'don’t', 'trust', 'us', 'there’', 'noth', 'go', 'on.']
# ['realli', 'work', 'trust', 'us.”', '“what', 'difference?”', '“a', 'nurs', 'like', 'doctor.']
# ['take', 'long', 'time', 'be.']
# ['v.', 'a.', 'd.', 'short', 'cut.”', '“i', 'see.”', '“the', 'italian', 'didn’t', 'want', 'women', 'near', 'front.']
# ['we’r', 'special', 'behavior.']
# ['don’t', 'go', 'out.”', '“i', 'come', 'though.”', '“oh,', 'yes.']
# ['we’r', 'cloistered.”', '“let’', 'drop', 'war.”', '“it’', 'hard.']
# ['there’', 'place', 'drop', 'it.”', '“let’', 'drop', 'anyway.”', '“all', 'right.”', 'look', 'dark.']
# ['thought', 'beauti', 'took', 'hand.']
# ['let', 'take', 'held', 'put', 'arm', 'around', 'arm.']
# ['“no,”', 'said.']
# ['kept', 'arm', 'was.']
# ['“whi', 'not?”', '“no.”', '“yes,”', 'said.']
# ['“please.”', 'lean', 'forward', 'dark', 'kiss', 'sharp', 'sting', 'flash.']
# ['slap', 'face', 'hard.']
# ['hand', 'hit', 'nose', 'eyes,', 'tear', 'came', 'eye', 'reflex.']
# ['“i’m', 'sorry,”', 'said.']
# ['felt', 'certain', 'advantage.']
# ['“you', 'quit', 'right.”', '“i’m', 'dread', 'sorry,”', 'said.']
# ['“i', 'couldn’t', 'stand', 'nurse’s-eveningoff', 'aspect', 'it.']
# ['didn’t', 'mean', 'hurt', 'you.']
# ['hurt', 'you,', 'didn’t', 'i?”', 'look', 'dark.']
# ['angri', 'yet', 'certain,', 'see', 'ahead', 'like', 'move', 'chess', 'game.']
# ['“you', 'exactli', 'right,”', 'said.']
# ['“i', 'don’t', 'mind', 'all.”', '“poor', 'man.”', '“you', 'see', 'i’v', 'lead', 'sort', 'funni', 'life.']
# ['never', 'even', 'talk', 'english.']
# ['beautiful.”', 'look', 'her.']
# ['“you', 'don’t', 'need', 'say', 'lot', 'nonsense.']
# ['said', 'sorry.']
# ['get', 'along.”', '“yes,”', 'said.']
# ['“and', 'gotten', 'away', 'war.”', 'laughed.']
# ['first', 'time', 'ever', 'heard', 'laugh.']
# ['watch', 'face.']
# ['“you', 'sweet,”', 'said.']
# ['“no,', 'i’m', 'not.”', '“yes.']
# ['dear.']
# ['i’d', 'glad', 'kiss', 'don’t', 'mind.”', 'look', 'eye', 'put', 'arm', 'around', 'kiss', 'her.']
# ['kiss', 'hard', 'held', 'tight', 'tri', 'open', 'lips;', 'close', 'tight.']
# ['still', 'angri', 'held', 'suddenli', 'shivered.']
# ['held', 'close', 'could', 'feel', 'heart', 'beat', 'lip', 'open', 'head', 'went', 'back', 'hand', 'cri', 'shoulder.']
# ['“oh,', 'darling,”', 'said.']
# ['“you', 'good', 'me,', 'won’t', 'you?”', 'hell,', 'thought.']
# ['stroke', 'hair', 'pat', 'shoulder.']
# ['crying.']
# ['“you', 'will,', 'won’', 'you?”', 'look', 'me.']
# ['“becaus', 'we’r', 'go', 'strang', 'life.”', 'walk', 'door', 'villa', 'went', 'walk', 'home.']
# ['back', 'villa', 'went', 'upstair', 'room.']
# ['rinaldi', 'lie', 'bed.']
# ['look', 'me.']
# ['“so', 'make', 'progress', 'miss', 'barkley?”', '“we', 'friends.”', '“you', 'pleasant', 'air', 'dog', 'heat.”', 'understand', 'word.']
# ['“of', 'what?”', 'explained.']
# ['“you,”', 'said,', '“have', 'pleasant', 'air', 'dog', 'who—”', '“stop', 'it,”', 'said.']
# ['“in', 'littl', 'would', 'say', 'insult', 'things.”', 'laughed.']
# ['“good-night,”', 'said.']
# ['“good-night,', 'littl', 'puppy.”', 'knock', 'candl', 'pillow', 'got', 'bed', 'dark.']
# ['rinaldi', 'pick', 'candle,', 'lit', 'went', 'reading.']
# ['6', 'away', 'two', 'day', 'posts.']
# ['got', 'home', 'late', 'see', 'miss', 'barkley', 'next', 'evening.']
# ['garden', 'wait', 'offic', 'hospit', 'came', 'down.']
# ['mani', 'marbl', 'bust', 'paint', 'wooden', 'pillar', 'along', 'wall', 'room', 'use', 'office.']
# ['hall', 'too,', 'offic', 'open', 'on,', 'line', 'them.']
# ['complet', 'marbl', 'qualiti', 'look', 'alike.']
# ['sculptur', 'alway', 'seem', 'dull', 'business—still,', 'bronz', 'look', 'like', 'something.']
# ['marbl', 'bust', 'look', 'like', 'cemetery.']
# ['one', 'fine', 'cemeteri', 'though—th', 'one', 'pisa.']
# ['genoa', 'place', 'see', 'bad', 'marbles.']
# ['villa', 'wealthi', 'german', 'bust', 'must', 'cost', 'plenty.']
# ['wonder', 'done', 'much', 'got.']
# ['tri', 'make', 'whether', 'member', 'famili', 'what;', 'uniformli', 'classical.']
# ['could', 'tell', 'anyth', 'them.']
# ['sat', 'chair', 'held', 'cap.']
# ['suppos', 'wear', 'steel', 'helmet', 'even', 'gorizia', 'uncomfort', 'bloodi', 'theatric', 'town', 'civilian', 'inhabit', 'evacuated.']
# ['wore', 'one', 'went', 'post', 'carri', 'english', 'ga', 'mask.']
# ['begin', 'get', 'them.']
# ['real', 'mask.']
# ['also', 'requir', 'wear', 'automat', 'pistol;', 'even', 'doctor', 'sanitari', 'officers.']
# ['felt', 'back', 'chair.']
# ['liabl', 'arrest', 'one', 'worn', 'plain', 'sight.']
# ['rinaldi', 'carri', 'holster', 'stuf', 'toilet', 'paper.']
# ['wore', 'real', 'one', 'felt', 'like', 'gunman', 'practis', 'fire', 'it.']
# ['astra', '7.65', 'calib', 'short', 'barrel', 'jump', 'sharpli', 'let', 'question', 'hit', 'anything.']
# ['practis', 'it,', 'hold', 'target', 'tri', 'master', 'jerk', 'ridicul', 'short', 'barrel', 'could', 'hit', 'within', 'yard', 'aim', 'twenti', 'pace', 'ridicul', 'carri', 'pistol', 'came', 'soon', 'forgot', 'carri', 'flop', 'small', 'back', 'feel', 'except', 'vagu', 'sort', 'shame', 'met', 'english-speak', 'people.']
# ['sat', 'chair', 'orderli', 'sort', 'look', 'disapprovingli', 'behind', 'desk', 'look', 'marbl', 'floor,', 'pillar', 'marbl', 'busts,', 'fresco', 'wall', 'wait', 'miss', 'barkley.']
# ['fresco', 'bad.']
# ['fresco', 'good', 'start', 'peel', 'flake', 'off.']
# ['saw', 'catherin', 'barkley', 'come', 'hall,', 'stood', 'up.']
# ['seem', 'tall', 'walk', 'toward', 'look', 'lovely.']
# ['“good-evening,', 'henry,”', 'said.']
# ['“how', 'do?”', 'said.']
# ['orderli', 'listen', 'behind', 'desk.']
# ['“shall', 'sit', 'go', 'garden?”', '“let’', 'go', 'out.']
# ['it’', 'much', 'cooler.”', 'walk', 'behind', 'garden,', 'orderli', 'look', 'us.']
# ['gravel', 'drive', 'said,', '“where', 'been?”', '“i’v', 'post.”', '“you', 'couldn’t', 'sent', 'note?”', '“no,”', 'said.']
# ['“not', 'well.']
# ['thought', 'come', 'back.”', '“you', 'ought', 'let', 'know,', 'darling.”', 'driveway,', 'walk', 'trees.']
# ['took', 'hands,', 'stop', 'kiss', 'her.']
# ['“isn’t', 'anywher', 'go?”', '“no,”', 'said.']
# ['“we', 'walk', 'here.']
# ['you’v', 'away', 'long', 'time.”', '“thi', 'third', 'day.']
# ['i’m', 'back', 'now.”', 'look', 'me,', '“and', 'love', 'me?”', '“yes.”', '“you', 'say', 'love', 'me,', 'didn’t', 'you?”', '“yes,”', 'lied.']
# ['“i', 'love', 'you.”', 'said', 'before.']
# ['“and', 'call', 'catherine?”', '“catherine.”', 'walk', 'way', 'stop', 'tree.']
# ['“say,’i’v', 'come', 'back', 'catherin', 'night.”', '“i’v', 'come', 'back', 'catherin', 'night.”', '“oh,', 'darling,', 'come', 'back,', 'haven’t', 'you?”', '“yes.”', '“i', 'love', 'it’', 'awful.']
# ['won’t', 'go', 'away?”', '“no.']
# ['i’ll', 'alway', 'come', 'back.”', '“oh,', 'love', 'so.']
# ['pleas', 'put', 'hand', 'again.”', '“it’', 'away.”', 'turn', 'could', 'see', 'face', 'kiss', 'saw', 'eye', 'shut.']
# ['kiss', 'shut', 'eyes.']
# ['thought', 'probabl', 'littl', 'crazy.']
# ['right', 'was.']
# ['care', 'get', 'into.']
# ['better', 'go', 'everi', 'even', 'hous', 'offic', 'girl', 'climb', 'put', 'cap', 'backward', 'sign', 'affect', 'trip', 'upstair', 'brother', 'officers.']
# ['knew', 'love', 'catherin', 'barkley', 'idea', 'love', 'her.']
# ['game,', 'like', 'bridge,', 'said', 'thing', 'instead', 'play', 'cards.']
# ['like', 'bridg', 'pretend', 'play', 'money', 'play', 'stakes.']
# ['nobodi', 'mention', 'stake', 'were.']
# ['right', 'me.']
# ['“i', 'wish', 'place', 'could', 'go,”', 'said.']
# ['experienc', 'masculin', 'difficulti', 'make', 'love', 'long', 'stand', 'up.']
# ['“there', 'isn’t', 'place,”', 'said.']
# ['came', 'back', 'wherev', 'been.']
# ['“we', 'might', 'sit', 'littl', 'while.”', 'sat', 'flat', 'stone', 'bench', 'held', 'catherin', 'barkley’', 'hand.']
# ['would', 'let', 'put', 'arm', 'around', 'her.']
# ['“are', 'tired?”', 'asked.']
# ['“no.”', 'look', 'grass.']
# ['“thi', 'rotten', 'game', 'play,', 'isn’t', 'it?”', '“what', 'game?”', '“don’t', 'dull.”', '“i’m', 'not,', 'purpose.”', '“you’r', 'nice', 'boy,”', 'said.']
# ['“and', 'play', 'well', 'know', 'how.']
# ['it’', 'rotten', 'game.”', '“do', 'alway', 'know', 'peopl', 'think?”', '“not', 'always.']
# ['you.']
# ['don’t', 'pretend', 'love', 'me.']
# ['that’', 'evening.']
# ['anyth', 'you’d', 'like', 'talk', 'about?”', '“but', 'love', 'you.”', '“pleas', 'let’', 'lie', 'don’t', 'to.']
# ['fine', 'littl', 'show', 'i’m', 'right', 'now.']
# ['see', 'i’m', 'mad', 'i’m', 'gone', 'off.']
# ['it’', 'littl', 'sometimes.”', 'press', 'hand,', '“dear', 'catherine.”', '“it', 'sound', 'funni', 'now—catherine.']
# ['don’t', 'pronounc', 'much', 'alike.']
# ['you’r', 'nice.']
# ['you’r', 'good', 'boy.”', '“that’', 'priest', 'said.”', '“yes,', 'you’r', 'good.']
# ['come', 'see', 'me?”', '“of', 'course.”', '“and', 'don’t', 'say', 'love', 'me.']
# ['that’', 'while.”', 'stood', 'put', 'hand.']
# ['“good-night.”', 'want', 'kiss', 'her.']
# ['“no,”', 'said.']
# ['“i’m', 'aw', 'tired.”', '“kiss', 'me,', 'though,”', 'said.']
# ['“i’m', 'aw', 'tired,', 'darling.”', '“kiss', 'me.”', '“do', 'want', 'much?”', '“yes.”', 'kiss', 'broke', 'away', 'suddenly.']
# ['“no.']
# ['good-night,', 'please,', 'darling.”', 'walk', 'door', 'saw', 'go', 'hall.']
# ['like', 'watch', 'move.']
# ['went', 'hall.']
# ['went', 'home.']
# ['hot', 'night', 'good', 'deal', 'go', 'mountains.']
# ['watch', 'flash', 'san', 'gabriele.']
# ['stop', 'front', 'villa', 'rossa.']
# ['shutter', 'still', 'go', 'inside.']
# ['somebodi', 'singing.']
# ['went', 'home.']
# ['rinaldi', 'came', 'undressing.']
# ['“ah,', 'ha!”', 'said.']
# ['“it', 'go', 'well.']
# ['babi', 'puzzled.”', '“where', 'been?”', '“at', 'villa', 'rossa.']
# ['edifying,', 'baby.']
# ['sang.']
# ['been?”', '“call', 'british.”', '“thank', 'god', 'becom', 'involv', 'british.”', '7', 'came', 'back', 'next', 'afternoon', 'first', 'mountain', 'post', 'stop', 'car', 'smistimento', 'wound', 'sick', 'sort', 'paper', 'paper', 'mark', 'differ', 'hospitals.']
# ['drive', 'sat', 'car', 'driver', 'took', 'paper', 'in.']
# ['hot', 'day', 'sky', 'bright', 'blue', 'road', 'white', 'dusty.']
# ['sat', 'high', 'seat', 'fiat', 'thought', 'nothing.']
# ['regiment', 'went', 'road', 'watch', 'pass.']
# ['men', 'hot', 'sweating.']
# ['wore', 'steel', 'helmet', 'carri', 'slung', 'packs.']
# ['helmet', 'big', 'came', 'almost', 'ear', 'men', 'wore', 'them.']
# ['offic', 'wore', 'helmets;', 'better-fit', 'helmets.']
# ['half', 'brigata', 'basilicata.']
# ['identifi', 'red', 'white', 'stripe', 'collar', 'mark.']
# ['straggler', 'go', 'long', 'regiment', 'passed—men', 'could', 'keep', 'platoons.']
# ['sweaty,', 'dusti', 'tired.']
# ['look', 'pretti', 'bad.']
# ['soldier', 'came', 'along', 'last', 'stragglers.']
# ['walk', 'limp.']
# ['stop', 'sat', 'besid', 'road.']
# ['got', 'went', 'over.']
# ['“what’', 'matter?”', 'look', 'me,', 'stood', 'up.']
# ['“i’m', 'go', 'on.”', '“what’', 'trouble?”', '“—the', 'war.”', '“what’', 'wrong', 'leg?”', '“it’', 'leg.']
# ['got', 'rupture.”', '“whi', 'don’t', 'ride', 'transport?”', 'asked.']
# ['“whi', 'don’t', 'go', 'hospital?”', '“they', 'won’t', 'let', 'me.']
# ['lieuten', 'said', 'slip', 'truss', 'purpose.”', '“let', 'feel', 'it.”', '“it’', 'way', 'out.”', '“which', 'side', 'on?”', '“here.”', 'felt', 'it.']
# ['“cough,”', 'said.']
# ['“i’m', 'afraid', 'make', 'bigger.']
# ['it’', 'twice', 'big', 'morning.”', '“sit', 'down,”', 'said.']
# ['“a', 'soon', 'get', 'paper', 'wound', 'i’ll', 'take', 'along', 'road', 'drop', 'medic', 'officers.”', '“he’ll', 'say', 'purpose.”', '“they', 'can’t', 'anything,”', 'said.']
# ['“it’', 'wound.']
# ['you’v', 'before,', 'haven’t', 'you?”', '“but', 'lost', 'truss.”', '“they’ll', 'send', 'hospital.”', '“can’t', 'stay', 'here,', 'tenente?”', '“no,', 'haven’t', 'paper', 'you.”', 'driver', 'came', 'door', 'paper', 'wound', 'car.']
# ['“four', '105.']
# ['two', '132,”', 'said.']
# ['hospit', 'beyond', 'river.']
# ['“you', 'drive,”', 'said.']
# ['help', 'soldier', 'ruptur', 'seat', 'us.']
# ['“you', 'speak', 'english?”', 'asked.']
# ['“sure.”', '“how', 'like', 'goddam', 'war?”', '“rotten.”', '“i', 'say', 'it’', 'rotten.']
# ['jesu', 'christ,', 'say', 'it’', 'rotten.”', '“were', 'states?”', '“sure.']
# ['pittsburgh.']
# ['knew', 'american.”', '“don’t', 'talk', 'italian', 'good', 'enough?”', '“i', 'knew', 'american', 'right.”', '“anoth', 'american,”', 'said', 'driver', 'italian', 'look', 'hernia', 'man.']
# ['“listen,', 'lootenant.']
# ['take', 'regiment?”', '“yes.”', '“becaus', 'captain', 'doctor', 'knew', 'rupture.']
# ['threw', 'away', 'goddam', 'truss', 'would', 'get', 'bad', 'wouldn’t', 'go', 'line', 'again.”', '“i', 'see.”', '“couldn’t', 'take', 'place', 'else?”', '“if', 'closer', 'front', 'could', 'take', 'first', 'medic', 'post.']
# ['back', 'you’v', 'got', 'papers.”', '“if', 'go', 'back', 'they’ll', 'make', 'get', 'oper', 'they’ll', 'put', 'line', 'time.”', 'thought', 'over.']
# ['“you', 'wouldn’t', 'want', 'go', 'line', 'time,', 'would', 'you?”', 'asked.']
# ['“no.”', '“jesu', 'christ,', 'ain’t', 'goddam', 'war?”', '“listen,”', 'said.']
# ['“you', 'get', 'fall', 'road', 'get', 'bump', 'head', 'i’ll', 'pick', 'way', 'back', 'take', 'hospital.']
# ['we’ll', 'stop', 'road', 'here,', 'aldo.”', 'stop', 'side', 'road.']
# ['help', 'down.']
# ['“i’ll', 'right', 'here,', 'lieutenant,”', 'said.']
# ['“so', 'long,”', 'said.']
# ['went', 'pass', 'regiment', 'mile', 'ahead,', 'cross', 'river,', 'cloudi', 'snow-wat', 'run', 'fast', 'spile', 'bridge,', 'ride', 'along', 'road', 'across', 'plain', 'deliv', 'wound', 'two', 'hospitals.']
# ['drove', 'come', 'back', 'went', 'fast', 'empti', 'car', 'find', 'man', 'pittsburgh.']
# ['first', 'pass', 'regiment,', 'hotter', 'slower', 'ever:', 'stragglers.']
# ['saw', 'hors', 'ambul', 'stop', 'road.']
# ['two', 'men', 'lift', 'hernia', 'man', 'put', 'in.']
# ['come', 'back', 'him.']
# ['shook', 'head', 'me.']
# ['helmet', 'forehead', 'bleed', 'hair', 'line.']
# ['nose', 'skin', 'dust', 'bloodi', 'patch', 'dust', 'hair.']
# ['“look', 'bump,', 'lieutenant!”', 'shouted.']
# ['“noth', 'do.']
# ['come', 'back', 'me.”', 'got', 'back', 'villa', 'five', 'o’clock', 'went', 'wash', 'cars,', 'take', 'shower.']
# ['made', 'report', 'room,', 'sit', 'trouser', 'undershirt', 'front', 'open', 'window.']
# ['two', 'day', 'offens', 'start', 'would', 'go', 'car', 'plava.']
# ['long', 'time', 'sinc', 'written', 'state', 'knew', 'write', 'let', 'go', 'long', 'almost', 'imposs', 'write', 'now.']
# ['noth', 'write', 'about.']
# ['sent', 'coupl', 'armi', 'zona', 'di', 'guerra', 'post-cards,', 'cross', 'everyth', 'except,', 'well.']
# ['handl', 'them.']
# ['post-card', 'would', 'fine', 'america;', 'strang', 'mysterious.']
# ['strang', 'mysteri', 'war', 'zone', 'suppos', 'quit', 'well', 'run', 'grim', 'compar', 'war', 'austrians.']
# ['austrian', 'armi', 'creat', 'give', 'napoleon', 'victories;', 'napoleon.']
# ['wish', 'napoleon,', 'instead', 'ii', 'general', 'cadorna,', 'fat', 'prosper', 'vittorio', 'emmanuele,', 'tini', 'man', 'long', 'thin', 'neck', 'goat', 'beard.']
# ['right', 'duke', 'aosta.']
# ['mayb', 'good-look', 'a.', 'great', 'gener', 'look', 'like', 'man.']
# ['lot', 'would', 'like', 'king.']
# ['look', 'like', 'king.']
# ['king’', 'uncl', 'command', 'third', 'army.']
# ['second', 'army.']
# ['british', 'batteri', 'third', 'army.']
# ['met', 'two', 'gunner', 'lot,', 'milan.']
# ['nice', 'big', 'evening.']
# ['big', 'shi', 'embarrass', 'appreci', 'togeth', 'anyth', 'happened.']
# ['wish', 'british.']
# ['would', 'much', 'simpler.']
# ['still', 'would', 'probabl', 'killed.']
# ['ambul', 'business.']
# ['yes,', 'even', 'ambul', 'business.']
# ['british', 'ambul', 'driver', 'kill', 'sometimes.']
# ['well,', 'knew', 'would', 'killed.']
# ['war.']
# ['anyth', 'me.']
# ['seem', 'danger', 'war', 'movies.']
# ['wish', 'god', 'though.']
# ['mayb', 'would', 'finish', 'summer.']
# ['mayb', 'austrian', 'would', 'crack.']
# ['alway', 'crack', 'wars.']
# ['matter', 'war?']
# ['everybodi', 'said', 'french', 'through.']
# ['rinaldi', 'said', 'french', 'mutini', 'troop', 'march', 'paris.']
# ['ask', 'happen', 'said,', '“oh,', 'stop', 'them.”', 'want', 'go', 'austria', 'without', 'war.']
# ['want', 'go', 'black', 'forest.']
# ['want', 'go', 'hartz', 'mountains.']
# ['hartz', 'mountain', 'anyway?']
# ['fight', 'carpathians.']
# ['want', 'go', 'anyway.']
# ['might', 'good', 'though.']
# ['could', 'go', 'spain', 'war.']
# ['sun', 'go', 'day', 'cool', 'off.']
# ['supper', 'would', 'go', 'see', 'catherin', 'barkley.']
# ['wish', 'now.']
# ['wish', 'milan', 'her.']
# ['would', 'like', 'eat', 'cova', 'walk', 'via', 'manzoni', 'hot', 'even', 'cross', 'turn', 'along', 'canal', 'go', 'hotel', 'catherin', 'barkley.']
# ['mayb', 'would.']
# ['mayb', 'would', 'pretend', 'boy', 'kill', 'would', 'go', 'front', 'door', 'porter', 'would', 'take', 'cap', 'would', 'stop', 'concierge’', 'desk', 'ask', 'key', 'would', 'stand', 'elev', 'would', 'get', 'elev', 'would', 'go', 'slowli', 'click', 'floor', 'floor', 'boy', 'would', 'open', 'door', 'stand', 'would', 'step', 'would', 'step', 'would', 'walk', 'hall', 'would', 'put', 'key', 'door', 'open', 'go', 'take', 'telephon', 'ask', 'send', 'bottl', 'capri', 'bianca', 'silver', 'bucket', 'full', 'ice', 'would', 'hear', 'ice', 'pail', 'come', 'condor', 'boy', 'would', 'knock', 'would', 'say', 'leav', 'outsid', 'door', 'please.']
# ['would', 'wear', 'cloth', 'hot', 'window', 'open', 'swallow', 'fli', 'roof', 'hous', 'dark', 'afterward', 'went', 'window', 'small', 'bat', 'hunt', 'hous', 'close', 'tree', 'would', 'drink', 'capri', 'door', 'lock', 'hot', 'sheet', 'whole', 'night', 'would', 'love', 'night', 'hot', 'night', 'milan.']
# ['ought', 'be.']
# ['would', 'eat', 'quickli', 'go', 'see', 'catherin', 'barkley.']
# ['talk', 'much', 'mess', 'drank', 'wine', 'tonight', 'brother', 'unless', 'drank', 'littl', 'talk', 'priest', 'archbishop', 'ireland', 'was,', 'seemed,', 'nobl', 'man', 'whose', 'injustice,', 'injustic', 'receiv', 'particip', 'american,', 'never', 'heard,', 'feign', 'acquaintance.']
# ['would', 'impolit', 'known', 'someth', 'listen', 'splendid', 'explan', 'caus', 'were,', 'all,', 'seemed,', 'misunderstandings.']
# ['thought', 'fine', 'name', 'came', 'minnesota', 'made', 'love', 'name:', 'ireland', 'minnesota,', 'ireland', 'wisconsin,', 'ireland', 'michigan.']
# ['made', 'pretti', 'sound', 'like', 'island.']
# ['wasn’t', 'it.']
# ['that.']
# ['yes,', 'father.']
# ['true,', 'father.']
# ['perhaps,', 'father.']
# ...
# ['“did', 'tell', 'could', 'it?”', 'asked.']
# ['“yes.”', '“isn’t', 'grand.']
# ['hour.']
# ['i’m', 'almost', 'done,', 'darling.']
# ['i’m', 'go', 'pieces.']
# ['pleas', 'give', 'that.']
# ['doesn’t', 'work.']
# ['oh,', 'doesn’t', 'work!”', '“breath', 'deeply.”', '“i', 'am.']
# ['oh,', 'doesn’t', 'work', 'more.']
# ['doesn’t', 'work!”', '“get', 'anoth', 'cylinder,”', 'said', 'nurse.']
# ['“that', 'new', 'cylinder.”', '“i’m', 'fool,', 'darling,”', 'catherin', 'said.']
# ['“but', 'doesn’t', 'work', 'more.”', 'began', 'cry.']
# ['“oh,', 'want', 'babi', 'make', 'trouble,', 'i’m', 'done', 'gone', 'piec', 'doesn’t', 'work.']
# ['oh,', 'darling,', 'doesn’t', 'work', 'all.']
# ['don’t', 'care', 'die', 'stop.']
# ['oh,', 'please,', 'darling,', 'pleas', 'make', 'stop.']
# ['comes.']
# ['oh', 'oh', 'oh!”', 'breath', 'sobbingli', 'mask.']
# ['“it', 'doesn’t', 'work.']
# ['doesn’t', 'work.']
# ['doesn’t', 'work.']
# ['don’t', 'mind', 'me,', 'darling.']
# ['pleas', 'don’t', 'cry.']
# ['don’t', 'mind', 'me.']
# ['i’m', 'gone', 'pieces.']
# ['poor', 'sweet.']
# ['love', 'i’ll', 'good', 'again.']
# ['i’ll', 'good', 'time.']
# ['can’t', 'give', 'something?']
# ['could', 'give', 'something.”', '“i’ll', 'make', 'work.']
# ['i’ll', 'turn', 'way.”', '“give', 'now.”', 'turn', 'dial', 'way', 'breath', 'hard', 'deep', 'hand', 'relax', 'mask.']
# ['shut', 'ga', 'lift', 'mask.']
# ['came', 'back', 'long', 'way', 'away.']
# ['“that', 'lovely,', 'darling.']
# ['oh,', 'you’r', 'good', 'me.”', '“you', 'brave,', 'can’t', 'time.']
# ['might', 'kill', 'you.”', '“i’m', 'brave', 'more,', 'darling.']
# ['i’m', 'broken.']
# ['they’v', 'broken', 'me.']
# ['know', 'now.”', '“everybodi', 'way.”', '“but', 'it’', 'awful.']
# ['keep', 'till', 'break', 'you.”', '“in', 'hour', 'over.”', '“isn’t', 'lovely?']
# ['darling,', 'won’t', 'die,', 'i?”', '“no.']
# ['promis', 'won’t.”', '“becaus', 'don’t', 'want', 'die', 'leav', 'you,', 'get', 'tire', 'feel', 'i’m', 'go', 'die.”', '“nonsense.']
# ['everybodi', 'feel', 'that.”', '“sometim', 'know', 'i’m', 'go', 'die.”', '“you', 'won’t.']
# ['can’t.”', '“but', 'should?”', '“i', 'won’t', 'let', 'you.”', '“give', 'quick.']
# ['give', 'me!”', 'afterward,', '“i', 'won’t', 'die.']
# ['won’t', 'let', 'die.”', '“of', 'cours', 'won’t.”', '“you’ll', 'stay', 'me?”', '“not', 'watch', 'it.”', '“no,', 'there.”', '“sure.']
# ['i’ll', 'time.”', '“you’r', 'good', 'me.']
# ['there,', 'give', 'me.']
# ['give', 'more.']
# ['it’', 'working!”', 'turn', 'dial', 'three', 'four.']
# ['wish', 'doctor', 'would', 'come', 'back.']
# ['afraid', 'number', 'two.']
# ['final', 'new', 'doctor', 'came', 'two', 'nurs', 'lift', 'catherin', 'onto', 'wheel', 'stretcher', 'start', 'hall.']
# ['stretcher', 'went', 'rapidli', 'hall', 'elev', 'everi', 'one', 'crowd', 'wall', 'make', 'room;', 'up,', 'open', 'door', 'elev', 'hall', 'rubber', 'wheel', 'oper', 'room.']
# ['recogn', 'doctor', 'cap', 'mask', 'on.']
# ['anoth', 'doctor', 'nurses.']
# ['“they’v', 'got', 'give', 'something,”', 'catherin', 'said.']
# ['“they’v', 'got', 'give', 'something.']
# ['oh', 'please,', 'doctor,', 'give', 'enough', 'good!”', 'one', 'doctor', 'put', 'mask', 'face', 'look', 'door', 'saw', 'bright', 'small', 'amphitheatr', 'oper', 'room.']
# ['“you', 'go', 'door', 'sit', 'there,”', 'nurs', 'said', 'me.']
# ['bench', 'behind', 'rail', 'look', 'white', 'tabl', 'lights.']
# ['look', 'catherine.']
# ['mask', 'face', 'quiet', 'now.']
# ['wheel', 'stretcher', 'forward.']
# ['turn', 'away', 'walk', 'hall.']
# ['two', 'nurs', 'hurri', 'toward', 'entranc', 'gallery.']
# ['“it’', 'caesarean,”', 'one', 'said.']
# ['“they’r', 'go', 'caesarean.”', 'one', 'laughed,', '“we’r', 'time.']
# ['aren’t', 'lucky?”', 'went', 'door', 'led', 'gallery.']
# ['anoth', 'nurs', 'came', 'along.']
# ['hurri', 'too.']
# ['“you', 'go', 'right', 'there.']
# ['go', 'right', 'in,”', 'said.']
# ['“i’m', 'stay', 'outside.”', 'hurri', 'in.']
# ['walk', 'hall.']
# ['afraid', 'go', 'in.']
# ['look', 'window.']
# ['dark', 'light', 'window', 'could', 'see', 'raining.']
# ['went', 'room', 'far', 'end', 'hall', 'look', 'label', 'bottl', 'glass', 'case.']
# ['came', 'stood', 'empti', 'hall', 'watch', 'door', 'oper', 'room.']
# ['doctor', 'came', 'follow', 'nurse.']
# ['held', 'someth', 'two', 'hand', 'look', 'like', 'freshli', 'skin', 'rabbit', 'hurri', 'across', 'corridor', 'anoth', 'door.']
# ['went', 'door', 'gone', 'found', 'room', 'thing', 'new-born', 'child.']
# ['doctor', 'held', 'see.']
# ['held', 'heel', 'slap', 'him.']
# ['“i', 'right?”', '“he’', 'magnificent.']
# ['he’ll', 'weigh', 'five', 'kilos.”', 'feel', 'him.']
# ['seem', 'anyth', 'me.']
# ['felt', 'feel', 'fatherhood.']
# ['“aren’t', 'proud', 'son?”', 'nurs', 'asked.']
# ['wash', 'wrap', 'something.']
# ['saw', 'littl', 'dark', 'face', 'dark', 'hand,', 'see', 'move', 'hear', 'cry.']
# ['doctor', 'someth', 'again.']
# ['look', 'upset.']
# ['“no,”', 'said.']
# ['“he', 'nearli', 'kill', 'mother.”', '“it', 'isn’t', 'littl', 'darling’', 'fault.']
# ['didn’t', 'want', 'boy?”', '“no,”', 'said.']
# ['doctor', 'busi', 'him.']
# ['held', 'feet', 'slap', 'him.']
# ['wait', 'see', 'it.']
# ['went', 'hail.']
# ['could', 'go', 'see.']
# ['went', 'door', 'littl', 'way', 'gallery.']
# ['nurs', 'sit', 'rail', 'motion', 'come', 'were.']
# ['shook', 'head.']
# ['could', 'see', 'enough', 'was.']
# ['thought', 'catherin', 'dead.']
# ['look', 'dead.']
# ['face', 'gray,', 'part', 'could', 'see.']
# ['below,', 'light,', 'doctor', 'sew', 'great', 'long,', 'forcep-spread,', 'thickedged,', 'wound.']
# ['anoth', 'doctor', 'mask', 'gave', 'anaesthetic.']
# ['two', 'nurs', 'mask', 'hand', 'things.']
# ['look', 'like', 'draw', 'inquisition.']
# ['knew', 'watch', 'could', 'watch', 'all,', 'glad', 'hadn’t.']
# ['think', 'could', 'watch', 'cut,', 'watch', 'wound', 'close', 'high', 'welt', 'ridg', 'quick', 'skilful-look', 'stitch', 'like', 'cobbler’s,', 'glad.']
# ['wound', 'close', 'went', 'hall', 'walk', 'again.']
# ['doctor', 'came', 'out.']
# ['“how', 'she?”', '“she', 'right.']
# ['watch?”', 'look', 'tired.']
# ['“i', 'saw', 'sew', 'up.']
# ['incis', 'look', 'long.”', '“you', 'thought', 'so?”', '“yes.']
# ['scar', 'flatten', 'out?”', '“oh,', 'yes.”', 'brought', 'wheel', 'stretcher', 'took', 'rapidli', 'hallway', 'elevator.']
# ['went', 'along', 'besid', 'it.']
# ['catherin', 'moaning.']
# ['downstair', 'put', 'bed', 'room.']
# ['sat', 'chair', 'foot', 'bed.']
# ['nurs', 'room.']
# ['got', 'stood', 'bed.']
# ['dark', 'room.']
# ['catherin', 'put', 'hand.']
# ['“hello,', 'darling,”', 'said.']
# ['voic', 'weak', 'tired.']
# ['“hello,', 'sweet.”', '“what', 'sort', 'babi', 'it?”', '“sh—don’t', 'talk,”', 'nurs', 'said.']
# ['“a', 'boy.']
# ['he’', 'long', 'wide', 'dark.”', '“i', 'right?”', '“yes,”', 'said.']
# ['“he’', 'fine.”', 'saw', 'nurs', 'look', 'strangely.']
# ['“i’m', 'aw', 'tired,”', 'catherin', 'said.']
# ['“and', 'hurt', 'like', 'hell.']
# ['right,', 'darling?”', '“i’m', 'fine.']
# ['don’t', 'talk.”', '“you', 'love', 'me.']
# ['oh,', 'darling,', 'hurt', 'dreadfully.']
# ['look', 'like?”', '“he', 'look', 'like', 'skin', 'rabbit', 'puckered-up', 'old-man’', 'face.”', '“you', 'must', 'go', 'out,”', 'nurs', 'said.']
# ['“madam', 'henri', 'must', 'talk.”', '“i’ll', 'outside.”', '“go', 'get', 'someth', 'eat.”', '“no.']
# ['i’ll', 'outside.”', 'kiss', 'catherine.']
# ['gray', 'weak', 'tired.']
# ['“may', 'speak', 'you?”', 'said', 'nurse.']
# ['came', 'hall', 'me.']
# ['walk', 'littl', 'way', 'hall.']
# ['“what’', 'matter', 'baby?”', 'asked.']
# ['“didn’t', 'know?”', '“no.”', '“he', 'wasn’t', 'alive.”', '“he', 'dead?”', '“they', 'couldn’t', 'start', 'breathing.']
# ['cord', 'caught', 'around', 'neck', 'something.”', '“so', 'he’', 'dead.”', '“yes.']
# ['it’', 'shame.']
# ['fine', 'big', 'boy.']
# ['thought', 'knew.”', '“no,”', 'said.']
# ['“you', 'better', 'go', 'back', 'madame.”', 'sat', 'chair', 'front', 'tabl', 'nurses’report', 'hung', 'clip', 'side', 'look', 'window.']
# ['could', 'see', 'noth', 'dark', 'rain', 'fall', 'across', 'light', 'window.']
# ['it.']
# ['babi', 'dead.']
# ['doctor', 'look', 'tired.']
# ['act', 'way', 'room', 'him?']
# ['suppos', 'would', 'come', 'around', 'start', 'breath', 'probably.']
# ['religion', 'knew', 'ought', 'baptized.']
# ['never', 'breath', 'all.']
# ['hadn’t.']
# ['never', 'alive.']
# ['except', 'catherine.']
# ['i’d', 'felt', 'kick', 'often', 'enough.']
# ['hadn’t', 'week.']
# ['mayb', 'choke', 'time.']
# ['poor', 'littl', 'kid.']
# ['wish', 'hell', 'i’d', 'choke', 'like', 'that.']
# ['didn’t.']
# ['still', 'would', 'die', 'go', 'through.']
# ['catherin', 'would', 'die.']
# ['did.']
# ['died.']
# ['know', 'about.']
# ['never', 'time', 'learn.']
# ['threw', 'told', 'rule', 'first', 'time', 'caught', 'base', 'kill', 'you.']
# ['kill', 'gratuit', 'like', 'aymo.']
# ['gave', 'syphili', 'like', 'rinaldi.']
# ['kill', 'end.']
# ['could', 'count', 'that.']
# ['stay', 'around', 'would', 'kill', 'you.']
# ['camp', 'put', 'log', 'top', 'fire', 'full', 'ants.']
# ['commenc', 'burn,', 'ant', 'swarm', 'went', 'first', 'toward', 'centr', 'fire', 'was;', 'turn', 'back', 'ran', 'toward', 'end.']
# ['enough', 'end', 'fell', 'fire.']
# ['got', 'out,', 'bodi', 'burnt', 'flattened,', 'went', 'know', 'going.']
# ['went', 'toward', 'fire', 'back', 'toward', 'end', 'swarm', 'cool', 'end', 'final', 'fell', 'fire.']
# ['rememb', 'think', 'time', 'end', 'world', 'splendid', 'chanc', 'messiah', 'lift', 'log', 'fire', 'throw', 'ant', 'could', 'get', 'onto', 'ground.']
# ['anyth', 'throw', 'tin', 'cup', 'water', 'log,', 'would', 'cup', 'empti', 'put', 'whiskey', 'ad', 'water', 'it.']
# ['think', 'cup', 'water', 'burn', 'log', 'steam', 'ants.']
# ['sat', 'hall', 'wait', 'hear', 'catherin', 'was.']
# ['nurs', 'come', 'out,', 'went', 'door', 'open', 'softli', 'look', 'in.']
# ['could', 'see', 'first', 'bright', 'light', 'hall', 'dark', 'room.']
# ['saw', 'nurs', 'sit', 'bed', 'catherine’', 'head', 'pillow,', 'flat', 'sheet.']
# ['nurs', 'put', 'finger', 'lips,', 'stood', 'came', 'door.']
# ['“how', 'she?”', 'asked.']
# ['“she’', 'right,”', 'nurs', 'said.']
# ['“you', 'go', 'supper', 'come', 'back', 'wish.”', 'went', 'hall', 'stair', 'door', 'hospit', 'dark', 'street', 'rain', 'café.']
# ['brightli', 'light', 'insid', 'mani', 'peopl', 'tables.']
# ['see', 'place', 'sit,', 'waiter', 'came', 'took', 'wet', 'coat', 'hat', 'show', 'place', 'tabl', 'across', 'elderli', 'man', 'drink', 'beer', 'read', 'even', 'paper.']
# ['sat', 'ask', 'waiter', 'plat', 'du', 'jour', 'was.']
# ['“veal', 'stew—but', 'finished.”', '“what', 'eat?”', '“ham', 'eggs,', 'egg', 'cheese,', 'choucroute.”', '“i', 'choucrout', 'noon,”', 'said.']
# ['“that’', 'true,”', 'said.']
# ['“that’', 'true.']
# ['ate', 'choucrout', 'noon.”', 'middle-ag', 'man', 'bald', 'top', 'head', 'hair', 'slick', 'it.']
# ['kind', 'face.']
# ['“what', 'want?']
# ['ham', 'egg', 'egg', 'cheese?”', '“ham', 'eggs,”', 'said,', '“and', 'beer.”', '“a', 'demi-blonde?”', '“yes,”', 'said.']
# ['“i', 'remembered,”', 'said.']
# ['“you', 'took', 'demi-blond', 'noon.”', 'ate', 'ham', 'egg', 'drank', 'beer.']
# ['ham', 'egg', 'round', 'dish—th', 'ham', 'underneath', 'egg', 'top.']
# ['hot', 'first', 'mouth', 'take', 'drink', 'beer', 'cool', 'mouth.']
# ['hungri', 'ask', 'waiter', 'anoth', 'order.']
# ['drank', 'sever', 'glass', 'beer.']
# ['think', 'read', 'paper', 'man', 'opposit', 'me.']
# ['break', 'british', 'front.']
# ['realiz', 'read', 'back', 'paper', 'fold', 'over.']
# ['thought', 'ask', 'waiter', 'paper,', 'could', 'concentrate.']
# ['hot', 'café', 'air', 'bad.']
# ['mani', 'peopl', 'tabl', 'knew', 'one', 'another.']
# ['sever', 'card', 'game', 'go', 'on.']
# ['waiter', 'busi', 'bring', 'drink', 'bar', 'tables.']
# ['two', 'men', 'came', 'could', 'find', 'place', 'sit.']
# ['stood', 'opposit', 'tabl', 'was.']
# ['order', 'anoth', 'beer.']
# ['readi', 'leav', 'yet.']
# ['soon', 'go', 'back', 'hospital.']
# ['tri', 'think', 'perfectli', 'calm.']
# ['men', 'stood', 'around', 'one', 'leaving,', 'went', 'out.']
# ['drank', 'anoth', 'beer.']
# ['quit', 'pile', 'saucer', 'tabl', 'front', 'me.']
# ['man', 'opposit', 'taken', 'spectacles,', 'put', 'away', 'case,', 'fold', 'paper', 'put', 'pocket', 'sat', 'hold', 'liqueur', 'glass', 'look', 'room.']
# ['suddenli', 'knew', 'get', 'back.']
# ['call', 'waiter,', 'paid', 'reckoning,', 'got', 'coat,', 'put', 'hat', 'start', 'door.']
# ['walk', 'rain', 'hospital.']
# ['upstair', 'met', 'nurs', 'come', 'hall.']
# ['“i', 'call', 'hotel,”', 'said.']
# ['someth', 'drop', 'insid', 'me.']
# ['“what', 'wrong?”', '“mrs.']
# ['henri', 'hemorrhage.”', '“can', 'go', 'in?”', '“no,', 'yet.']
# ['doctor', 'her.”', '“i', 'dangerous?”', '“it', 'dangerous.”', 'nurs', 'went', 'room', 'shut', 'door.']
# ['sat', 'outsid', 'hail.']
# ['everyth', 'gone', 'insid', 'me.']
# ['think.']
# ['could', 'think.']
# ['knew', 'go', 'die', 'pray', 'would', 'not.']
# ['don’t', 'let', 'die.']
# ['oh,', 'god,', 'pleas', 'don’t', 'let', 'die.']
# ['i’ll', 'anyth', 'won’t', 'let', 'die.']
# ['please,', 'please,', 'please,', 'dear', 'god,', 'don’t', 'let', 'die.']
# ['dear', 'god,', 'don’t', 'let', 'die.']
# ['please,', 'please,', 'pleas', 'don’t', 'let', 'die.']
# ['god', 'pleas', 'make', 'die.']
# ['i’ll', 'anyth', 'say', 'don’t', 'let', 'die.']
# ['took', 'babi', 'don’t', 'let', 'die.']
# ['right', 'don’t', 'let', 'die.']
# ['please,', 'please,', 'dear', 'god,', 'don’t', 'let', 'die.']
# ['nurs', 'open', 'door', 'motion', 'finger', 'come.']
# ['follow', 'room.']
# ['catherin', 'look', 'came', 'in.']
# ['went', 'side', 'bed.']
# ['doctor', 'stand', 'bed', 'opposit', 'side.']
# ['catherin', 'look', 'smiled.']
# ['bent', 'bed', 'start', 'cry.']
# ['“poor', 'darling,”', 'catherin', 'said', 'softly.']
# ['look', 'gray.']
# ['“you’r', 'right,', 'cat,”', 'said.']
# ['“you’r', 'go', 'right.”', '“i’m', 'go', 'die,”', 'said;', 'wait', 'said,', '“i', 'hate', 'it.”', 'took', 'hand.']
# ['“don’t', 'touch', 'me,”', 'said.']
# ['let', 'go', 'hand.']
# ['smiled.']
# ['“poor', 'darling.']
# ['touch', 'want.”', '“you’ll', 'right,', 'cat.']
# ['know', 'you’ll', 'right.”', '“i', 'meant', 'write', 'letter', 'anyth', 'happened,', 'didn’t', 'it.”', '“do', 'want', 'get', 'priest', 'one', 'come', 'see', 'you?”', '“just', 'you,”', 'said.']
# ['littl', 'later,', '“i’m', 'afraid.']
# ['hate', 'it.”', '“you', 'must', 'talk', 'much,”', 'doctor', 'said.']
# ['“all', 'right,”', 'catherin', 'said.']
# ['“do', 'want', 'anything,', 'cat?']
# ['get', 'anything?”', 'catherin', 'smiled,', '“no.”', 'littl', 'later,', '“you', 'won’t', 'thing', 'anoth', 'girl,', 'say', 'things,', 'you?”', '“never.”', '“i', 'want', 'girls,', 'though.”', '“i', 'don’t', 'want', 'them.”', '“you', 'talk', 'much,”', 'doctor', 'said.']
# ['“mr.']
# ['henri', 'must', 'go', 'out.']
# ['come', 'back', 'later.']
# ['go', 'die.']
# ['must', 'silly.”', '“all', 'right,”', 'catherin', 'said.']
# ['“i’ll', 'come', 'stay', 'nights,”', 'said.']
# ['hard', 'talk.']
# ['“pleas', 'go', 'room,”', 'doctor', 'said.']
# ['“you', 'cannot', 'talk.”', 'catherin', 'wink', 'me,', 'face', 'gray.']
# ['“i’ll', 'right', 'outside,”', 'said.']
# ['“don’t', 'worry,', 'darling,”', 'catherin', 'said.']
# ['“i’m', 'bit', 'afraid.']
# ['it’', 'dirti', 'trick.”', '“you', 'dear,', 'brave', 'sweet.”', 'wait', 'outsid', 'hall.']
# ['wait', 'long', 'time.']
# ['nurs', 'came', 'door', 'came', 'me.']
# ['“i’m', 'afraid', 'mrs.', 'henri', 'ill,”', 'said.']
# ['“i’m', 'afraid', 'her.”', '“i', 'dead?”', '“no,', 'unconscious.”', 'seem', 'one', 'hemorrhag', 'another.']
# ['couldn’t', 'stop', 'it.']
# ['went', 'room', 'stay', 'catherin', 'died.']
# ['unconsci', 'time,', 'take', 'long', 'die.']
# ['outsid', 'room,', 'hall,', 'spoke', 'doctor,', '“i', 'anyth', 'to-night?”', '“no.']
# ['noth', 'do.']
# ['take', 'hotel?”', '“no,', 'thank', 'you.']
# ['go', 'stay', 'while.”', '“i', 'know', 'noth', 'say.']
# ['cannot', 'tell', 'you—”', '“no,”', 'said.']
# ['“there’', 'noth', 'say.”', '“good-night,”', 'said.']
# ['“i', 'cannot', 'take', 'hotel?”', '“no,', 'thank', 'you.”', '“it', 'thing', 'do,”', 'said.']
# ['“the', 'oper', 'proved—”', '“i', 'want', 'talk', 'it,”', 'said.']
# ['“i', 'would', 'like', 'take', 'hotel.”', '“no,', 'thank', 'you.”', 'went', 'hall.']
# ['went', 'door', 'room.']
# ['“you', 'can’t', 'come', 'now,”', 'one', 'nurs', 'said.']
# ['“ye', 'can,”', 'said.']
# ['“you', 'can’t', 'come', 'yet.”', '“you', 'get', 'out,”', 'said.']
# ['“the', 'one', 'too.”', 'got', 'shut', 'door', 'turn', 'light', 'wasn’t', 'good.']
# ['like', 'say', 'good-bi', 'statue.']
# ['went', 'left', 'hospit', 'walk', 'back', 'hotel', 'rain.']

# %%
#上の本番
form_sent = []
for sentence in sentence_small:
    form = [ps.stem(word)  for word in sentence.split() if not word in stopwords + symbols]
    form_sent.append(" ".join(form))

# %%
#ピリオドやカンマを消しまーす。Delte period and comma...めんどい...
form_sent2 = []

for i in form_sent:
    tokens = nltk.word_tokenize(i)
    form = [word for word in tokens if not word in stopwords + symbols]
    form_sent2.append(" ".join(form))

# %%
#次にこの新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化したい
text = []

for i in form_sent2:
    tokens = nltk.word_tokenize(i)
    for j in tokens:
        text.append(j)

# %%
text = [text]

# %%
#新しく、原型に戻し、stopwordを取り除いた単語数をグラフ化

import matplotlib.pyplot as plt
# %matplotlib inline

f_list_new = []
for i in text:
    f_list_new.append(nltk.FreqDist(w.lower() for w in i if w.lower() not in stopwords + symbols))

for i in f_list_new:
    plt.figure(figsize=(20,10))
    i.plot(50)

# %%
log_freq  = []
for i in f_list_new[0].values():
    log_freq.append(i)

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_freq, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('freq(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#順位チェック
sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('said', 945),
#  ('go', 441),
#  ('went', 293),
#  ('look', 290),
#  ('would', 254),
#  ('one', 245),
#  ('see', 232),
#  ('could', 219),
#  ('back', 219),
#  ('get', 218),
#  ('come', 215),
#  ('want', 188),
#  ('road', 187),
#  ('like', 186),
#  ('came', 186),
#  ('catherin', 178),
#  ('right', 164),
#  ('know', 159),
#  ('good', 150),
#  ('yes', 136),
#  ('think', 132),
#  ('two', 131),
#  ('time', 121),
#  ('r', 120),
#  ('littl', 118),
#  ('us', 114),
#  ('away', 111),
#  ('saw', 110),
#  ('rain', 107),
#  ('take', 107),
#  ('put', 103),
#  ('much', 99),
#  ('long', 99),
#  ('bed', 98),
#  ('along', 98),
#  ('rinaldi', 98),
#  ('car', 97),
#  ('love', 94),
#  ('room', 94),
#  ('night', 93),
#  ('war', 93),
#  ('hand', 93),
#  ('let', 91),
#  ('darling', 91),
#  ('start', 90),
#  ('side', 87),
#  ('priest', 87),
#  ('took', 86),
#  ('dark', 84),
#  ('way', 84),
#  ('walk', 84),
#  ('sat', 83),
#  ('stop', 83),
#  ('piani', 80),
#  ('got', 79),
#  ('tell', 77),
#  ('make', 75),
#  ('bonello', 75),
#  ('feel', 74),
#  ('thing', 74),
#  ('never', 74),
#  ('say', 73),
#  ('across', 72),
#  ('mountain', 72),
#  ('window', 72),
#  ('fine', 71),
#  ('door', 71),
#  ('talk', 71),
#  ('place', 70),
#  ('major', 69),
#  ('open', 69),
#  ('tenente', 69),
#  ('big', 67),
#  ('doctor', 67),
#  ('asked', 66),
#  ('river', 65),
#  ('thought', 65),
#  ('someth', 64),
#  ('drink', 63),
#  ('better', 63),
#  ('oh', 63),
#  ('mani', 62),
#  ('head', 62),
#  ('v', 62),
#  ('ask', 61),
#  ('turn', 61),
#  ('anoth', 60),
#  ('girl', 60),
#  ('man', 59),
#  ('line', 59),
#  ('aymo', 59),
#  ('lake', 59),
#  ('face', 58),
#  ('well', 58),
#  ('die', 57),
#  ('watch', 57),
#  ('light', 57),
#  ('water', 56),
#  ('knew', 56),
#  ('outsid', 55),
#  ('stay', 54),
#  ('sleep', 54),
#  ('town', 53),
#  ('glass', 53),
#  ('held', 53),
#  ('italian', 53),
#  ('felt', 53),
#  ('must', 52),
#  ('alway', 52),
#  ('gone', 51),
#  ('bad', 51),
#  ('wine', 50),
#  ('give', 50),
#  ('first', 50),
#  ('still', 50),
#  ('close', 50),
#  ('tri', 50),
#  ('toward', 50),
#  ('front', 49),
#  ('around', 49),
#  ('work', 49),
#  ('heard', 48),
#  ('wet', 48),
#  ('made', 48),
#  ('eat', 48),
#  ('move', 47),
#  ('day', 47),
#  ('left', 47),
#  ('anyth', 47),
#  ('stood', 47),
#  ('men', 46),
#  ('three', 46),
#  ('cross', 45),
#  ('wish', 45),
#  ('hold', 45),
#  ('ahead', 45),
#  ('old', 44),
#  ('baby', 44),
#  ('besid', 44),
#  ('sit', 43),
#  ('noth', 43),
#  ('english', 43),
#  ('miss', 43),
#  ('pass', 42),
#  ('snow', 42),
#  ('believ', 42),
#  ('hotel', 42),
#  ('boat', 42),
#  ('tree', 41),
#  ('offic', 41),
#  ('row', 41),
#  ('pull', 40),
#  ('fire', 40),
#  ('nurs', 40),
#  ('hall', 40),
#  ('peopl', 39),
#  ('cut', 39),
#  ('paper', 39),
#  ('austrian', 38),
#  ('cold', 38),
#  ('hard', 38),
#  ('brought', 38),
#  ('hous', 37),
#  ('beyond', 37),
#  ('floor', 37),
#  ('lay', 37),
#  ('leav', 36),
#  ('behind', 36),
#  ('wall', 36),
#  ('field', 36),
#  ('station', 36),
#  ('boy', 36),
#  ('driver', 35),
#  ('even', 35),
#  ('everi', 35),
#  ('wind', 35),
#  ('might', 35),
#  ('american', 35),
#  ('far', 35),
#  ('catherine', 35),
#  ('mayb', 35),
#  ('live', 34),
#  ('sometim', 34),
#  ('great', 34),
#  ('train', 34),
#  ('soldier', 33),
#  ('small', 33),
#  ('nice', 33),
#  ('seem', 33),
#  ('realli', 33),
#  ('arm', 33),
#  ('attack', 33),
#  ('keep', 33),
#  ('ferguson', 33),
#  ('ever', 32),
#  ('barkley', 32),
#  ('call', 32),
#  ('lie', 32),
#  ('pleas', 32),
#  ('end', 31),
#  ('hope', 31),
#  ('shore', 31),
#  ('clear', 30),
#  ('street', 30),
#  ('captain', 30),
#  ('point', 30),
#  ('wound', 30),
#  ('afraid', 30),
#  ('white', 29),
#  ('carri', 29),
#  ('hospit', 29),
#  ('bring', 29),
#  ('wait', 29),
#  ('tire', 29),
#  ('stone', 29),
#  ('quit', 29),
#  ('kill', 29),
#  ('stand', 29),
#  ('find', 29),
#  ('bridg', 29),
#  ('thank', 29),
#  ('fall', 28),
#  ('bottl', 28),
#  ('shook', 28),
#  ('sight', 28),
#  ('read', 28),
#  ('ought', 28),
#  ('dress', 28),
#  ('drank', 28),
#  ('told', 28),
#  ('high', 28),
#  ('play', 28),
#  ('bank', 28),
#  ('dead', 27),
#  ('nothing', 27),
#  ('anything', 27),
#  ('tired', 27),
#  ('though', 26),
#  ('winter', 26),
#  ('insid', 26),
#  ('kiss', 26),
#  ('sure', 26),
#  ('matter', 26),
#  ('sergeant', 26),
#  ('gave', 26),
#  ('brush', 26),
#  ('shot', 26),
#  ('seat', 25),
#  ('next', 25),
#  ('smiled', 25),
#  ('new', 25),
#  ('villa', 25),
#  ('almost', 25),
#  ('hot', 25),
#  ('german', 25),
#  ('mind', 25),
#  ('god', 25),
#  ('hear', 25),
#  ('retreat', 25),
#  ('barman', 25),
#  ('top', 24),
#  ('glad', 24),
#  ('bridge', 24),
#  ('wore', 24),
#  ('money', 24),
#  ('beauti', 24),
#  ('good-night', 24),
#  ('drunk', 24),
#  ('breakfast', 24),
#  ('kept', 24),
#  ('soon', 24),
#  ('plain', 23),
#  ('mess', 23),
#  ('hospital', 23),
#  ('mask', 23),
#  ('table', 23),
#  ('word', 23),
#  ('leg', 23),
#  ('step', 23),
#  ('passini', 23),
#  ('montreux', 23),
#  ('sun', 22),
#  ('gray', 22),
#  ('north', 22),
#  ('countri', 22),
#  ('fast', 22),
#  ('smile', 22),
#  ('father', 22),
#  ('without', 22),
#  ('hell', 22),
#  ('post', 22),
#  ('hair', 22),
#  ('drop', 22),
#  ('send', 22),
#  ('thin', 21),
#  ('narrow', 21),
#  ('care', 21),
#  ('tabl', 21),
#  ('show', 21),
#  ('enough', 21),
#  ('anyway', 21),
#  ('shut', 21),
#  ('good-by', 21),
#  ('main', 21),
#  ('cat', 21),
#  ('year', 20),
#  ('bare', 20),
#  ('except', 20),
#  ('neck', 20),
#  ('country', 20),
#  ('name', 20),
#  ('four', 20),
#  ('found', 20),
#  ('milan', 20),
#  ('need', 20),
#  ('lunch', 20),
#  ('empti', 20),
#  ('splendid', 20),
#  ('started', 20),
#  ('shoulder', 20),
#  ('whi', 20),
#  ('wonder', 20),
#  ('orderli', 20),
#  ('climb', 20),
#  ('wood', 20),
#  ('woman', 20),
#  ('bag', 20),
#  ('beer', 20),
#  ('mountains', 19),
#  ('dri', 19),
#  ('troop', 19),
#  ('probabl', 19),
#  ('ran', 19),
#  ('taken', 19),
#  ('later', 19),
#  ('ate', 19),
#  ('help', 19),
#  ('things', 19),
#  ('hill', 19),
#  ('british', 19),
#  ('warm', 19),
#  ('morn', 19),
#  ('suppos', 19),
#  ('sweet', 19),
#  ('home', 19),
#  ('drove', 19),
#  ('yet', 19),
#  ('life', 19),
#  ('something', 19),
#  ('knee', 19),
#  ('gun', 18),
#  ('garden', 18),
#  ('lift', 18),
#  ('use', 18),
#  ('order', 18),
#  ('girls', 18),
#  ('laughed', 18),
#  ('shell', 18),
#  ('wake', 18),
#  ('morning', 18),
#  ('second', 18),
#  ('aw', 18),
#  ('done', 18),
#  ('happen', 18),
#  ('clock', 18),
#  ('question', 18),
#  ('ride', 18),
#  ('onto', 18),
#  ('seen', 18),
#  ('breath', 18),
#  ('forward', 17),
#  ('nearli', 17),
#  ('railway', 17),
#  ('everyth', 17),
#  ('red', 17),
#  ('uniform', 17),
#  ('hit', 17),
#  ('smell', 17),
#  ('full', 17),
#  ('final', 17),
#  ('pleasant', 17),
#  ('happy', 17),
#  ('thi', 17),
#  ('realiz', 17),
#  ('drive', 17),
#  ('wave', 17),
#  ('wheel', 17),
#  ('column', 17),
#  ('manera', 17),
#  ('guard', 17),
#  ('coat', 17),
#  ('wife', 17),
#  ('grand', 17),
#  ('oar', 17),
#  ('sport', 17),
#  ('trees', 16),
#  ('friend', 16),
#  ('pick', 16),
#  ('shoot', 16),
#  ('ambul', 16),
#  ('clean', 16),
#  ('flat', 16),
#  ('woke', 16),
#  ('blow', 16),
#  ('cars', 16),
#  ('rememb', 16),
#  ('quiet', 16),
#  ('carabinieri', 16),
#  ('please', 16),
#  ('mean', 16),
#  ('poor', 16),
#  ('dear', 16),
#  ('chair', 16),
#  ('arrest', 16),
#  ('cloth', 16),
#  ('stretcher', 16),
#  ('umbrella', 16),
#  ('late', 15),
#  ('summer', 15),
#  ('afterward', 15),
#  ('past', 15),
#  ('box', 15),
#  ('truck', 15),
#  ('army', 15),
#  ('south', 15),
#  ('café', 15),
#  ('differ', 15),
#  ('broken', 15),
#  ('pour', 15),
#  ('fill', 15),
#  ('five', 15),
#  ('finger', 15),
#  ('marri', 15),
#  ('hurt', 15),
#  ('hat', 15),
#  ('papers', 15),
#  ('near', 15),
#  ('nurse', 15),
#  ('together', 15),
#  ('may', 15),
#  ('finish', 15),
#  ('short', 15),
#  ('low', 15),
#  ('gordini', 15),
#  ('hour', 15),
#  ('cognac', 15),
#  ('alon', 15),
#  ('udine', 15),
#  ('push', 15),
#  ('bar', 15),
#  ('earli', 14),
#  ('fight', 14),
#  ('motor', 14),
#  ('valley', 14),
#  ('officers', 14),
#  ('beard', 14),
#  ('last', 14),
#  ('understand', 14),
#  ('listen', 14),
#  ('touch', 14),
#  ('perhap', 14),
#  ('sick', 14),
#  ('tall', 14),
#  ('edg', 14),
#  ('babi', 14),
#  ('armi', 14),
#  ('danger', 14),
#  ('sever', 14),
#  ('to-morrow', 14),
#  ('piec', 14),
#  ('little', 14),
#  ('embankment', 14),
#  ('hay', 14),
#  ('count', 14),
#  ('switzerland', 14),
#  ('offici', 14),
#  ('load', 13),
#  ('canva', 13),
#  ('cloud', 13),
#  ('cape', 13),
#  ('whole', 13),
#  ('slowli', 13),
#  ('young', 13),
#  ('rest', 13),
#  ('spoke', 13),
#  ('eye', 13),
#  ('joke', 13),
#  ('rome', 13),
#  ('spring', 13),
#  ('foot', 13),
#  ('learn', 13),
#  ('run', 13),
#  ('becom', 13),
#  ('regiment', 13),
#  ('pretti', 13),
#  ('trouble', 13),
#  ('christ', 13),
#  ('porter', 13),
#  ('outside', 13),
#  ('follow', 13),
#  ('tie', 13),
#  ('cheese', 13),
#  ('married', 13),
#  ('break', 13),
#  ('fergy', 13),
#  ('whiskey', 13),
#  ('flash', 12),
#  ('forest', 12),
#  ('black', 12),
#  ('hung', 12),
#  ('true', 12),
#  ('write', 12),
#  ('coffe', 12),
#  ('strang', 12),
#  ('abl', 12),
#  ('air', 12),
#  ('engin', 12),
#  ('crack', 12),
#  ('really', 12),
#  ('wide', 12),
#  ('everybodi', 12),
#  ('cart', 12),
#  ('wear', 12),
#  ('else', 12),
#  ('ice', 12),
#  ('hurri', 12),
#  ('chees', 12),
#  ('straight', 12),
#  ('reach', 12),
#  ('fun', 12),
#  ('carriag', 12),
#  ('gino', 12),
#  ('daylight', 12),
#  ('opposit', 12),
#  ('greffi', 12),
#  ('fell', 11),
#  ('brown', 11),
#  ('cool', 11),
#  ('mud', 11),
#  ('child', 11),
#  ('cap', 11),
#  ('led', 11),
#  ('lost', 11),
#  ('suddenli', 11),
#  ('commenc', 11),
#  ('lieutenant', 11),
#  ('asleep', 11),
#  ('san', 11),
#  ('wounded', 11),
#  ('smoke', 11),
#  ('alone', 11),
#  ('sorry', 11),
#  ('sent', 11),
#  ('cours', 11),
#  ('dugout', 11),
#  ('game', 11),
#  ('gotten', 11),
#  ('pistol', 11),
#  ('medic', 11),
#  ('saint', 11),
#  ('track', 11),
#  ('screen', 11),
#  ('feet', 11),
#  ('sister', 11),
#  ('luck', 11),
#  ('stomach', 11),
#  ('pain', 11),
#  ('stair', 11),
#  ('expect', 11),
#  ('grow', 11),
#  ('locarno', 11),
#  ('dust', 10),
#  ('storm', 10),
#  ('muddi', 10),
#  ('house', 10),
#  ('ground', 10),
#  ('course', 10),
#  ('mouth', 10),
#  ('lose', 10),
#  ('abruzzi', 10),
#  ('report', 10),
#  ('helmet', 10),
#  ('afternoon', 10),
#  ('wash', 10),
#  ('to-night', 10),
#  ('everything', 10),
#  ('shirt', 10),
#  ('badli', 10),
#  ('forget', 10),
#  ('signor', 10),
#  ('wipe', 10),
#  ('bottle', 10),
#  ('sort', 10),
#  ('fool', 10),
#  ('silli', 10),
#  ('somebodi', 10),
#  ('henry', 10),
#  ('worry', 10),
#  ('tight', 10),
#  ('driveway', 10),
#  ('trip', 10),
#  ('rotten', 10),
#  ('sound', 10),
#  ('oper', 10),
#  ('togeth', 10),
#  ('soup', 10),
#  ('brandy', 10),
#  ('corridor', 10),
#  ('corner', 10),
#  ('bags', 10),
#  ('march', 9),
#  ('rifl', 9),
#  ('pack', 9),
#  ('usual', 9),
#  ('going', 9),
#  ('gorizia', 9),
#  ('mile', 9),
#  ('chang', 9),
#  ('dull', 9),
#  ('path', 9),
#  ('els', 9),
#  ('pocket', 9),
#  ('lieuten', 9),
#  ('offens', 9),
#  ('met', 9),
#  ('whether', 9),
#  ('best', 9),
#  ('world', 9),
#  ('kitchen', 9),
#  ('part', 9),
#  ('dirti', 9),
#  ('minute', 9),
#  ('stick', 9),
#  ('mother', 9),
#  ('wors', 9),
#  ('lot', 9),
#  ('either', 9),
#  ('half', 9),
#  ('dinner', 9),
#  ('rather', 9),
#  ('brave', 9),
#  ('slap', 9),
#  ('crying', 9),
#  ('speak', 9),
#  ('deep', 9),
#  ('stupid', 9),
#  ('damn', 9),
#  ('hundr', 9),
#  ('stream', 9),
#  ('vermouth', 9),
#  ('bainsizza', 9),
#  ('germans', 9),
#  ('stove', 9),
#  ('barto', 9),
#  ('troops', 9),
#  ('hungry', 9),
#  ('barn', 9),
#  ('stern', 9),
#  ('swiss', 9),
#  ('waiter', 9),
#  ('trunk', 8),
#  ('coming', 8),
#  ('cover', 8),
#  ('green', 8),
#  ('bombard', 8),
#  ('metal', 8),
#  ('lovely', 8),
#  ('often', 8),
#  ('card', 8),
#  ('shadow', 8),
#  ('cup', 8),
#  ('kind', 8),
#  ('real', 8),
#  ('basin', 8),
#  ('eyes', 8),
#  ('lire', 8),
#  ('note', 8),
#  ('happi', 8),
#  ('comfort', 8),
#  ('troubl', 8),
#  ('begin', 8),
#  ('grappa', 8),
#  ('blew', 8),
#  ('nobodi', 8),
#  ('bit', 8),
#  ('burst', 8),
#  ('lean', 8),
#  ('pat', 8),
#  ('wooden', 8),
#  ('bloodi', 8),
#  ('hands', 8),
#  ('crazy', 8),
#  ('happened', 8),
#  ('french', 8),
#  ('sheet', 8),
#  ('coffee', 8),
#  ('sorri', 8),
#  ('ridg', 8),
#  ('dug', 8),
#  ('food', 8),
#  ('hate', 8),
#  ('ye', 8),
#  ('nois', 8),
#  ('mama', 8),
#  ('worri', 8),
#  ('bent', 8),
#  ('blood', 8),
#  ('slept', 8),
#  ('plenti', 8),
#  ('older', 8),
#  ('cheer', 8),
#  ('meat', 8),
#  ('mi', 8),
#  ('cry', 8),
#  ('timber', 8),
#  ('buy', 8),
#  ('custom', 8),
#  ('moon', 8),
#  ('egg', 8),
#  ('guttingen', 8),
#  ('dial', 8),
#  ('soda', 8),
#  ('villag', 7),
#  ('rise', 7),
#  ('branch', 7),
#  ('leather', 7),
#  ('heavi', 7),
#  ('king', 7),
#  ('thick', 7),
#  ('iron', 7),
#  ('smash', 7),
#  ('bodi', 7),
#  ('spaghetti', 7),
#  ('tunic', 7),
#  ('laugh', 7),
#  ('son', 7),
#  ('address', 7),
#  ('ha', 7),
#  ('spread', 7),
#  ('thumb', 7),
#  ('shouted', 7),
#  ('family', 7),
#  ('guns', 7),
#  ('bench', 7),
#  ('marbl', 7),
#  ('desk', 7),
#  ('ga', 7),
#  ('steel', 7),
#  ('ciaou', 7),
#  ('understood', 7),
#  ('ten', 7),
#  ('yard', 7),
#  ('smooth', 7),
#  ('haul', 7),
#  ('nose', 7),
#  ('return', 7),
#  ('italy', 7),
#  ('notic', 7),
#  ('studi', 7),
#  ('evening', 7),
#  ('machine-gun', 7),
#  ('level', 7),
#  ('shelter', 7),
#  ('certain', 7),
#  ('knock', 7),
#  ('also', 7),
#  ('third', 7),
#  ('brother', 7),
#  ('instead', 7),
#  ('closer', 7),
#  ('bump', 7),
#  ('hors', 7),
#  ('handl', 7),
#  ('america', 7),
#  ('business', 7),
#  ('austria', 7),
#  ('roof', 7),
#  ('everybody', 7),
#  ('stori', 7),
#  ('hello', 7),
#  ('caught', 7),
#  ('moment', 7),
#  ('t.', 7),
#  ('bersaglieri', 7),
#  ('farmhous', 7),
#  ('rough', 7),
#  ('crowd', 7),
#  ('hole', 7),
#  ('stopped', 7),
#  ('gavuzzi', 7),
#  ('fighting', 7),
#  ('sing', 7),
#  ('scare', 7),
#  ('canteen', 7),
#  ('mia', 7),
#  ('shoe', 7),
#  ('others', 7),
#  ('fellow', 7),
#  ('born', 7),
#  ('declar', 7),
#  ('officer', 7),
#  ('number', 7),
#  ('save', 7),
#  ('wise', 7),
#  ('mine', 7),
#  ('stiff', 7),
#  ('throw', 7),
#  ('comes', 7),
#  ('bread', 7),
#  ('sleepy', 7),
#  ('clothes', 7),
#  ('boot', 7),
#  ('roll', 7),
#  ('tagliamento', 7),
#  ('ditch', 7),
#  ('answer', 7),
#  ('stresa', 7),
#  ('passport', 7),
#  ('toboggan', 7),
#  ('mrs.', 7),
#  ('ham', 7),
#  ('traffic', 6),
#  ('chestnut', 6),
#  ('camion', 6),
#  ('seven', 6),
#  ('artilleri', 6),
#  ('sky', 6),
#  ('none', 6),
#  ('win', 6),
#  ('famili', 6),
#  ('capri', 6),
#  ('success', 6),
#  ('women', 6),
#  ('sunlight', 6),
#  ('upstair', 6),
#  ('courtyard', 6),
#  ('blanket', 6),
#  ('tin', 6),
#  ('wonderful', 6),
#  ('anybodi', 6),
#  ('soft', 6),
#  ('friends', 6),
#  ('hang', 6),
#  ('peasant', 6),
#  ('excit', 6),
#  ('sharp', 6),
#  ('tast', 6),
#  ('although', 6),
#  ('meal', 6),
#  ('twice', 6),
#  ('another', 6),
#  ('till', 6),
#  ('stairs', 6),
#  ('ambulance', 6),
#  ('fifteen', 6),
#  ('plava', 6),
#  ('lead', 6),
#  ('bright', 6),
#  ('difference', 6),
#  ('becaus', 6),
#  ('dog', 6),
#  ('pillow', 6),
#  ('civilian', 6),
#  ('jerk', 6),
#  ('people', 6),
#  ('sometimes', 6),
#  ('inside', 6),
#  ('collar', 6),
#  ('forehead', 6),
#  ('trouser', 6),
#  ('elev', 6),
#  ('silver', 6),
#  ('island', 6),
#  ('teeth', 6),
#  ('bassi', 6),
#  ('federico', 6),
#  ('hail', 6),
#  ('hardli', 6),
#  ('rail', 6),
#  ('jam', 6),
#  ('goe', 6),
#  ('defeat', 6),
#  ('itali', 6),
#  ('board', 6),
#  ('tables', 6),
#  ('shout', 6),
#  ('legs', 6),
#  ('readi', 6),
#  ('possibl', 6),
#  ('brandi', 6),
#  ('easily', 6),
#  ('awak', 6),
#  ('talking', 6),
#  ('cork', 6),
#  ('serv', 6),
#  ('reason', 6),
#  ('pay', 6),
#  ('carriage', 6),
#  ('compart', 6),
#  ('cheerful', 6),
#  ('thinking', 6),
#  ('wisdom', 6),
#  ('pordenone', 6),
#  ('bartolomeo', 6),
#  ('lights', 6),
#  ('younger', 6),
#  ('minut', 6),
#  ('began', 6),
#  ('mirror', 6),
#  ('side-road', 6),
#  ('hedg', 6),
#  ('abandon', 6),
#  ('feeling', 6),
#  ('catch', 6),
#  ('paid', 6),
#  ('downstair', 6),
#  ('bought', 6),
#  ('billiard', 6),
#  ('devout', 6),
#  ('pallanza', 6),
#  ('ski', 6),
#  ('log', 6),
#  ('caesarean', 6),
#  ('vine', 5),
#  ('laid', 5),
#  ('mist', 5),
#  ('clip', 5),
#  ('month', 5),
#  ('plateau', 5),
#  ('militari', 5),
#  ('houses', 5),
#  ('yellow', 5),
#  ('falling', 5),
#  ('suck', 5),
#  ('swung', 5),
#  ('to-day', 5),
#  ('book', 5),
#  ('certainli', 5),
#  ('leave', 5),
#  ('boots', 5),
#  ('oil', 5),
#  ('lock', 5),
#  ('sinc', 5),
#  ('rock', 5),
#  ('fold', 5),
#  ('impress', 5),
#  ('unless', 5),
#  ('alike', 5),
#  ('dressed', 5),
#  ('mechan', 5),
#  ('protect', 5),
#  ('busi', 5),
#  ('depend', 5),
#  ('meant', 5),
#  ('shone', 5),
#  ('salut', 5),
#  ('skin', 5),
#  ('idea', 5),
#  ('different', 5),
#  ('join', 5),
#  ('italians', 5),
#  ('trench', 5),
#  ('telephon', 5),
#  ('steadili', 5),
#  ('austrians', 5),
#  ('rush', 5),
#  ('exactli', 5),
#  ('funni', 5),
#  ('nonsense', 5),
#  ('heat', 5),
#  ('complet', 5),
#  ('pace', 5),
#  ('shame', 5),
#  ('sign', 5),
#  ('pretend', 5),
#  ('deal', 5),
#  ('gabriele', 5),
#  ('helmets', 5),
#  ('slip', 5),
#  ('coupl', 5),
#  ('napoleon', 5),
#  ('fat', 5),
#  ('supper', 5),
#  ('click', 5),
#  ('fli', 5),
#  ('alreadi', 5),
#  ('hallway', 5),
#  ('lone', 5),
#  ('empty', 5),
#  ('spill', 5),
#  ('chain', 5),
#  ('settl', 5),
#  ('separ', 5),
#  ('rang', 5),
#  ('mat', 5),
#  ('entranc', 5),
#  ('brickyard', 5),
#  ('earth', 5),
#  ('worse', 5),
#  ('nation', 5),
#  ...]

# %%
# let's make new list only with words whose frequency  > 25

moreThan25_freq = []

for i,j in f_list_new[0].items():
    if j >= 25:
        moreThan25_freq.append(i)

# %%
# 頻出単語top2のgameshとsaidが同時に現れる文を、ピックアップしカウントするプログラムを全ての単語に割り当てる試み。

count_s = {}

for wn1 in range(0, len(moreThan25_freq)-1):
    for wn2 in range(wn1+1, len(moreThan25_freq)):
        s = 0
    
        for sent in form_sent2:
            index1 = 0
            index2 = 0
            
            #remove duplicate
            if moreThan25_freq[wn1] != moreThan25_freq[wn2]:
                
                if moreThan25_freq[wn1] in sent.split():
                    index1 += 1
                if moreThan25_freq[wn2] in sent.split():
                    index2 += 1
              
                if index1 > 0 and index2 > 0:
                    s += 1
                
        count_s.update({( moreThan25_freq[wn1], moreThan25_freq[wn2]) :s })

# %%
count_s
# Out:
# {('live', 'hous'): 6,
#  ('live', 'look'): 3,
#  ('live', 'across'): 1,
#  ('live', 'river'): 3,
#  ('live', 'bed'): 0,
#  ('live', 'white'): 0,
#  ('live', 'water'): 1,
#  ('live', 'clear'): 0,
#  ('live', 'move'): 0,
#  ('live', 'went'): 3,
#  ('live', 'road'): 1,
#  ('live', 'leav'): 0,
#  ('live', 'tree'): 3,
#  ('live', 'saw'): 1,
#  ('live', 'along'): 1,
#  ('live', 'fall'): 1,
#  ('live', 'soldier'): 0,
#  ('live', 'mani'): 2,
#  ('live', 'beyond'): 2,
#  ('live', 'mountain'): 5,
#  ('live', 'night'): 1,
#  ('live', 'could'): 2,
#  ('live', 'see'): 3,
#  ('live', 'dark'): 0,
#  ('live', 'like'): 8,
#  ('live', 'feel'): 0,
#  ('live', 'sometim'): 2,
#  ('live', 'heard'): 0,
#  ('live', 'window'): 1,
#  ('live', 'go'): 3,
#  ('live', 'pull'): 1,
#  ('live', 'much'): 0,
#  ('live', 'side'): 4,
#  ('live', 'carri'): 0,
#  ('live', 'men'): 0,
#  ('live', 'big'): 1,
#  ('live', 'pass'): 1,
#  ('live', 'day'): 1,
#  ('live', 'long'): 3,
#  ('live', 'behind'): 0,
#  ('live', 'anoth'): 0,
#  ('live', 'rain'): 0,
#  ('live', 'came'): 2,
#  ('live', 'wet'): 0,
#  ('live', 'dead'): 1,
#  ('live', 'two'): 2,
#  ('live', 'front'): 2,
#  ('live', 'though'): 0,
#  ('live', 'gone'): 0,
#  ('live', 'small'): 0,
#  ('live', 'car'): 1,
#  ('live', 'offic'): 0,
#  ('live', 'seat'): 0,
#  ('live', 'driver'): 0,
#  ('live', 'back'): 1,
#  ('live', 'even'): 1,
#  ('live', 'one'): 2,
#  ('live', 'sit'): 0,
#  ('live', 'face'): 1,
#  ('live', 'way'): 3,
#  ('live', 'everi'): 1,
#  ('live', 'thing'): 3,
#  ('live', 'start'): 0,
#  ('live', 'winter'): 2,
#  ('live', 'end'): 1,
#  ('live', 'die'): 1,
#  ('live', 'next'): 0,
#  ('live', 'cross'): 1,
#  ('live', 'wall'): 4,
#  ('live', 'away'): 1,
#  ('live', 'town'): 4,
#  ('live', 'nice'): 1,
#  ('live', 'fine'): 1,
#  ('live', 'us'): 0,
#  ('live', 'austrian'): 0,
#  ('live', 'seem'): 1,
#  ('live', 'want'): 1,
#  ('live', 'come'): 0,
#  ('live', 'time'): 0,
#  ('live', 'war'): 0,
#  ('live', 'littl'): 2,
#  ('live', 'peopl'): 1,
#  ('live', 'hospit'): 1,
#  ('live', 'street'): 1,
#  ('live', 'around'): 1,
#  ('live', 'girl'): 1,
#  ('live', 'well'): 1,
#  ('live', 'made'): 2,
#  ('live', 'snow'): 0,
#  ('live', 'wind'): 1,
#  ('live', 'watch'): 1,
#  ('live', 'sat'): 1,
#  ('live', 'glass'): 0,
#  ('live', 'drink'): 0,
#  ('live', 'bottl'): 0,
#  ('live', 'knew'): 0,
#  ('live', 'left'): 1,
#  ('live', 'priest'): 0,
#  ('live', 'walk'): 1,
#  ('live', 'smiled'): 1,
#  ('live', 'shook'): 0,
#  ('live', 'head'): 0,
#  ('live', 'wine'): 0,
#  ('live', 'held'): 0,
#  ('live', 'hand'): 0,
#  ('live', 'captain'): 0,
#  ('live', 'italian'): 1,
#  ('live', 'might'): 1,
#  ('live', 'noth'): 1,
#  ('live', 'said'): 4,
#  ('live', 'ask'): 1,
#  ('live', 'never'): 2,
#  ('live', 'took'): 0,
#  ('live', 'sight'): 1,
#  ('live', 'major'): 1,
#  ('live', 'love'): 1,
#  ('live', 'ever'): 3,
#  ('live', 'read'): 0,
#  ('live', 'get'): 0,
#  ('live', 'realli'): 0,
#  ('live', 'tell'): 0,
#  ('live', 'think'): 0,
#  ('live', 'believ'): 0,
#  ('live', 'door'): 0,
#  ('live', 'open'): 0,
#  ('live', 'ought'): 0,
#  ('live', 'would'): 3,
#  ('live', 'talk'): 1,
#  ('live', 'let'): 0,
#  ('live', 'give'): 0,
#  ('live', 'place'): 2,
#  ('live', 'make'): 1,
#  ('live', 'point'): 0,
#  ('live', 'first'): 0,
#  ('live', 'great'): 1,
#  ('live', 'must'): 0,
#  ('live', 'bring'): 0,
#  ('live', 'good'): 0,
#  ('live', 'wish'): 1,
#  ('live', 'say'): 0,
#  ('live', 'cold'): 0,
#  ('live', 'stay'): 0,
#  ('live', 'still'): 2,
#  ('live', 'field'): 1,
#  ('live', 'old'): 2,
#  ('live', 'new'): 0,
#  ('live', 'fire'): 0,
#  ('live', 'outsid'): 0,
#  ('live', 'wait'): 0,
#  ('live', 'insid'): 0,
#  ('live', 'floor'): 0,
#  ('live', 'room'): 1,
#  ('live', 'know'): 0,
#  ('live', 'rinaldi'): 2,
#  ('live', 'lay'): 0,
#  ('live', 'put'): 0,
#  ('live', 'arm'): 0,
#  ('live', 'kiss'): 0,
#  ('live', 'r'): 1,
#  ('live', 'villa'): 0,
#  ('live', 'yes'): 0,
#  ('live', 'nothing'): 0,
#  ('live', 'english'): 1,
#  ('live', 'miss'): 0,
#  ('live', 'barkley'): 0,
#  ('live', 'take'): 0,
#  ('live', 'call'): 1,
#  ('live', 'work'): 0,
#  ('live', 'hard'): 0,
#  ('live', 'wound'): 0,
#  ('live', 'right'): 0,
#  ('live', 'sleep'): 0,
#  ('live', 'lie'): 0,
#  ('live', 'close'): 0,
#  ('live', 'man'): 0,
#  ('live', 'felt'): 2,
#  ('live', 'tri'): 0,
#  ('live', 'almost'): 0,
#  ('live', 'stop'): 0,
#  ('live', 'sure'): 0,
#  ('live', 'alway'): 1,
#  ('live', 'better'): 0,
#  ('live', 'attack'): 0,
#  ('live', 'anyth'): 0,
#  ('live', 'got'): 0,
#  ('live', 'line'): 1,
#  ('live', 'three'): 1,
#  ('live', 'dress'): 0,
#  ('live', 'tenente'): 0,
#  ('live', 'bad'): 0,
#  ('live', 'matter'): 0,
#  ('live', 'tire'): 0,
#  ('live', 'cut'): 0,
#  ('live', 'stone'): 1,
#  ('live', 'station'): 0,
#  ('live', 'sergeant'): 0,
#  ('live', 'drank'): 0,
#  ('live', 'hot'): 0,
#  ('live', 'told'): 0,
#  ('live', 'keep'): 0,
#  ('live', 'gave'): 0,
#  ('live', 'pleas'): 0,
#  ('live', 'brush'): 1,
#  ('live', 'german'): 0,
#  ('live', 'nurs'): 0,
#  ('live', 'toward'): 2,
#  ('live', 'oh'): 0,
#  ('live', 'brought'): 0,
#  ('live', 'asked'): 0,
#  ('live', 'quit'): 0,
#  ('live', 'thought'): 0,
#  ('live', 'boy'): 0,
#  ('live', 'kill'): 0,
#  ('live', 'v'): 1,
#  ('live', 'someth'): 0,
#  ('live', 'anything'): 0,
#  ('live', 'stand'): 0,
#  ('live', 'ferguson'): 0,
#  ('live', 'doctor'): 0,
#  ('live', 'find'): 1,
#  ('live', 'shot'): 0,
#  ('live', 'american'): 1,
#  ('live', 'afraid'): 0,
#  ('live', 'far'): 0,
#  ('live', 'bridg'): 0,
#  ('live', 'hold'): 0,
#  ('live', 'turn'): 0,
#  ('live', 'high'): 0,
#  ('live', 'catherine'): 0,
#  ('live', 'ahead'): 0,
#  ('live', 'mind'): 0,
#  ('live', 'darling'): 1,
#  ('live', 'hall'): 1,
#  ('live', 'paper'): 0,
#  ('live', 'catherin'): 0,
#  ('live', 'stood'): 0,
#  ('live', 'play'): 1,
#  ('live', 'tired'): 0,
#  ('live', 'baby'): 0,
#  ('live', 'thank'): 1,
#  ('live', 'god'): 1,
#  ('live', 'besid'): 0,
#  ('live', 'mayb'): 0,
#  ('live', 'eat'): 0,
#  ('live', 'hotel'): 0,
#  ('live', 'hear'): 1,
#  ('live', 'light'): 0,
#  ('live', 'hope'): 1,
#  ('live', 'train'): 0,
#  ('live', 'bank'): 0,
#  ('live', 'row'): 0,
#  ('live', 'retreat'): 0,
#  ('live', 'bonello'): 0,
#  ('live', 'piani'): 0,
#  ('live', 'aymo'): 0,
#  ('live', 'shore'): 1,
#  ('live', 'boat'): 0,
#  ('live', 'lake'): 1,
#  ('live', 'barman'): 0,
#  ('hous', 'look'): 5,
#  ('hous', 'across'): 2,
#  ('hous', 'river'): 4,
#  ('hous', 'bed'): 0,
#  ('hous', 'white'): 0,
#  ('hous', 'water'): 1,
#  ('hous', 'clear'): 0,
#  ('hous', 'move'): 0,
#  ('hous', 'went'): 9,
#  ('hous', 'road'): 5,
#  ('hous', 'leav'): 1,
#  ('hous', 'tree'): 5,
#  ('hous', 'saw'): 2,
#  ('hous', 'along'): 4,
#  ('hous', 'fall'): 2,
#  ('hous', 'soldier'): 0,
#  ('hous', 'mani'): 4,
#  ('hous', 'beyond'): 3,
#  ('hous', 'mountain'): 6,
#  ('hous', 'night'): 2,
#  ('hous', 'could'): 1,
#  ('hous', 'see'): 3,
#  ('hous', 'dark'): 2,
#  ('hous', 'like'): 2,
#  ('hous', 'feel'): 0,
#  ('hous', 'sometim'): 2,
#  ('hous', 'heard'): 0,
#  ('hous', 'window'): 2,
#  ('hous', 'go'): 2,
#  ('hous', 'pull'): 0,
#  ('hous', 'much'): 1,
#  ('hous', 'side'): 5,
#  ('hous', 'carri'): 0,
#  ('hous', 'men'): 1,
#  ('hous', 'big'): 0,
#  ('hous', 'pass'): 1,
#  ('hous', 'day'): 2,
#  ('hous', 'long'): 2,
#  ('hous', 'behind'): 0,
#  ('hous', 'anoth'): 1,
#  ('hous', 'rain'): 0,
#  ('hous', 'came'): 2,
#  ('hous', 'wet'): 1,
#  ('hous', 'dead'): 1,
#  ('hous', 'two'): 3,
#  ('hous', 'front'): 1,
#  ('hous', 'though'): 0,
#  ('hous', 'gone'): 0,
#  ('hous', 'small'): 1,
#  ('hous', 'car'): 1,
#  ('hous', 'offic'): 1,
#  ('hous', 'seat'): 0,
#  ('hous', 'driver'): 0,
#  ('hous', 'back'): 4,
#  ('hous', 'even'): 2,
#  ('hous', 'one'): 1,
#  ('hous', 'sit'): 0,
#  ('hous', 'face'): 1,
#  ('hous', 'way'): 2,
#  ('hous', 'everi'): 2,
#  ('hous', 'thing'): 2,
#  ('hous', 'start'): 0,
#  ('hous', 'winter'): 1,
#  ('hous', 'end'): 1,
#  ('hous', 'die'): 0,
#  ('hous', 'next'): 0,
#  ('hous', 'cross'): 2,
#  ('hous', 'wall'): 4,
#  ('hous', 'away'): 0,
#  ('hous', 'town'): 7,
#  ('hous', 'nice'): 1,
#  ('hous', 'fine'): 2,
#  ('hous', 'us'): 1,
#  ('hous', 'austrian'): 0,
#  ('hous', 'seem'): 0,
#  ('hous', 'want'): 0,
#  ('hous', 'come'): 1,
#  ('hous', 'time'): 0,
#  ('hous', 'war'): 0,
#  ('hous', 'littl'): 3,
#  ('hous', 'peopl'): 1,
#  ('hous', 'hospit'): 1,
#  ('hous', 'street'): 3,
#  ('hous', 'around'): 1,
#  ('hous', 'girl'): 3,
#  ('hous', 'well'): 3,
#  ('hous', 'made'): 1,
#  ('hous', 'snow'): 1,
#  ('hous', 'wind'): 1,
#  ('hous', 'watch'): 1,
#  ('hous', 'sat'): 2,
#  ('hous', 'glass'): 1,
#  ('hous', 'drink'): 2,
#  ('hous', 'bottl'): 1,
#  ('hous', 'knew'): 1,
#  ('hous', 'left'): 2,
#  ('hous', 'priest'): 0,
#  ('hous', 'walk'): 2,
#  ('hous', 'smiled'): 0,
#  ('hous', 'shook'): 0,
#  ('hous', 'head'): 0,
#  ('hous', 'wine'): 0,
#  ('hous', 'held'): 0,
#  ('hous', 'hand'): 0,
#  ('hous', 'captain'): 0,
#  ('hous', 'italian'): 0,
#  ('hous', 'might'): 0,
#  ('hous', 'noth'): 0,
#  ('hous', 'said'): 3,
#  ('hous', 'ask'): 0,
#  ('hous', 'never'): 0,
#  ('hous', 'took'): 1,
#  ('hous', 'sight'): 0,
#  ('hous', 'major'): 0,
#  ('hous', 'love'): 1,
#  ('hous', 'ever'): 0,
#  ('hous', 'read'): 0,
#  ('hous', 'get'): 0,
#  ('hous', 'realli'): 0,
#  ('hous', 'tell'): 0,
#  ('hous', 'think'): 0,
#  ('hous', 'believ'): 0,
#  ('hous', 'door'): 3,
#  ('hous', 'open'): 2,
#  ('hous', 'ought'): 0,
#  ('hous', 'would'): 1,
#  ('hous', 'talk'): 0,
#  ('hous', 'let'): 0,
#  ('hous', 'give'): 0,
#  ('hous', 'place'): 0,
#  ('hous', 'make'): 0,
#  ('hous', 'point'): 0,
#  ('hous', 'first'): 0,
#  ('hous', 'great'): 0,
#  ('hous', 'must'): 0,
#  ('hous', 'bring'): 0,
#  ('hous', 'good'): 2,
#  ('hous', 'wish'): 0,
#  ('hous', 'say'): 0,
#  ('hous', 'cold'): 1,
#  ('hous', 'stay'): 0,
#  ('hous', 'still'): 1,
#  ('hous', 'field'): 2,
#  ('hous', 'old'): 1,
#  ('hous', 'new'): 1,
#  ('hous', 'fire'): 1,
#  ('hous', 'outsid'): 2,
#  ('hous', 'wait'): 1,
#  ('hous', 'insid'): 0,
#  ('hous', 'floor'): 0,
#  ('hous', 'room'): 0,
#  ('hous', 'know'): 0,
#  ('hous', 'rinaldi'): 0,
#  ('hous', 'lay'): 0,
#  ('hous', 'put'): 1,
#  ('hous', 'arm'): 0,
#  ('hous', 'kiss'): 0,
#  ('hous', 'r'): 0,
#  ('hous', 'villa'): 2,
#  ('hous', 'yes'): 0,
#  ('hous', 'nothing'): 0,
#  ('hous', 'english'): 0,
#  ('hous', 'miss'): 0,
#  ('hous', 'barkley'): 0,
#  ('hous', 'take'): 0,
#  ('hous', 'call'): 0,
#  ('hous', 'work'): 0,
#  ('hous', 'hard'): 1,
#  ('hous', 'wound'): 0,
#  ('hous', 'right'): 1,
#  ('hous', 'sleep'): 0,
#  ('hous', 'lie'): 0,
#  ('hous', 'close'): 1,
#  ('hous', 'man'): 0,
#  ('hous', 'felt'): 0,
#  ('hous', 'tri'): 0,
#  ('hous', 'almost'): 0,
#  ('hous', 'stop'): 1,
#  ('hous', 'sure'): 0,
#  ('hous', 'alway'): 0,
#  ('hous', 'better'): 1,
#  ('hous', 'attack'): 0,
#  ('hous', 'anyth'): 0,
#  ('hous', 'got'): 0,
#  ('hous', 'line'): 1,
#  ('hous', 'three'): 0,
#  ('hous', 'dress'): 0,
#  ('hous', 'tenente'): 0,
#  ('hous', 'bad'): 0,
#  ('hous', 'matter'): 0,
#  ('hous', 'tire'): 0,
#  ('hous', 'cut'): 0,
#  ('hous', 'stone'): 5,
#  ('hous', 'station'): 0,
#  ('hous', 'sergeant'): 0,
#  ('hous', 'drank'): 1,
#  ('hous', 'hot'): 1,
#  ('hous', 'told'): 0,
#  ('hous', 'keep'): 1,
#  ('hous', 'gave'): 0,
#  ('hous', 'pleas'): 0,
#  ('hous', 'brush'): 0,
#  ('hous', 'german'): 0,
#  ('hous', 'nurs'): 0,
#  ('hous', 'toward'): 0,
#  ('hous', 'oh'): 0,
#  ('hous', 'brought'): 0,
#  ('hous', 'asked'): 0,
#  ('hous', 'quit'): 0,
#  ('hous', 'thought'): 0,
#  ('hous', 'boy'): 0,
#  ('hous', 'kill'): 0,
#  ('hous', 'v'): 0,
#  ('hous', 'someth'): 0,
#  ('hous', 'anything'): 0,
#  ('hous', 'stand'): 0,
#  ('hous', 'ferguson'): 0,
#  ('hous', 'doctor'): 0,
#  ('hous', 'find'): 0,
#  ('hous', 'shot'): 0,
#  ('hous', 'american'): 0,
#  ('hous', 'afraid'): 0,
#  ('hous', 'far'): 1,
#  ('hous', 'bridg'): 1,
#  ('hous', 'hold'): 0,
#  ('hous', 'turn'): 0,
#  ('hous', 'high'): 0,
#  ('hous', 'catherine'): 0,
#  ('hous', 'ahead'): 0,
#  ('hous', 'mind'): 0,
#  ('hous', 'darling'): 0,
#  ('hous', 'hall'): 0,
#  ('hous', 'paper'): 0,
#  ('hous', 'catherin'): 0,
#  ('hous', 'stood'): 0,
#  ('hous', 'play'): 0,
#  ('hous', 'tired'): 0,
#  ('hous', 'baby'): 0,
#  ('hous', 'thank'): 0,
#  ('hous', 'god'): 0,
#  ('hous', 'besid'): 1,
#  ('hous', 'mayb'): 0,
#  ('hous', 'eat'): 1,
#  ('hous', 'hotel'): 0,
#  ('hous', 'hear'): 0,
#  ('hous', 'light'): 0,
#  ('hous', 'hope'): 0,
#  ('hous', 'train'): 0,
#  ('hous', 'bank'): 0,
#  ('hous', 'row'): 0,
#  ('hous', 'retreat'): 0,
#  ('hous', 'bonello'): 0,
#  ('hous', 'piani'): 0,
#  ('hous', 'aymo'): 0,
#  ('hous', 'shore'): 2,
#  ('hous', 'boat'): 0,
#  ('hous', 'lake'): 1,
#  ('hous', 'barman'): 0,
#  ('look', 'across'): 9,
#  ('look', 'river'): 4,
#  ('look', 'bed'): 6,
#  ('look', 'white'): 5,
#  ('look', 'water'): 4,
#  ('look', 'clear'): 0,
#  ('look', 'move'): 2,
#  ('look', 'went'): 18,
#  ('look', 'road'): 18,
#  ('look', 'leav'): 0,
#  ('look', 'tree'): 4,
#  ('look', 'saw'): 19,
#  ('look', 'along'): 8,
#  ('look', 'fall'): 4,
#  ('look', 'soldier'): 0,
#  ('look', 'mani'): 2,
#  ('look', 'beyond'): 3,
#  ('look', 'mountain'): 6,
#  ('look', 'night'): 3,
#  ('look', 'could'): 20,
#  ('look', 'see'): 19,
#  ('look', 'dark'): 12,
#  ('look', 'like'): 19,
#  ('look', 'feel'): 1,
#  ('look', 'sometim'): 0,
#  ('look', 'heard'): 1,
#  ('look', 'window'): 26,
#  ('look', 'go'): 12,
#  ('look', 'pull'): 2,
#  ('look', 'much'): 3,
#  ('look', 'side'): 6,
#  ('look', 'carri'): 2,
#  ('look', 'men'): 4,
#  ('look', 'big'): 7,
#  ('look', 'pass'): 4,
#  ('look', 'day'): 1,
#  ('look', 'long'): 4,
#  ('look', 'behind'): 10,
#  ('look', 'anoth'): 4,
#  ('look', 'rain'): 4,
#  ('look', 'came'): 13,
#  ('look', 'wet'): 4,
#  ('look', 'dead'): 3,
#  ('look', 'two'): 11,
#  ('look', 'front'): 3,
#  ('look', 'though'): 3,
#  ('look', 'gone'): 1,
#  ('look', 'small'): 2,
#  ('look', 'car'): 12,
#  ('look', 'offic'): 1,
#  ('look', 'seat'): 1,
#  ('look', 'driver'): 5,
#  ('look', 'back'): 21,
#  ('look', 'even'): 3,
#  ('look', 'one'): 11,
#  ('look', 'sit'): 5,
#  ('look', 'face'): 3,
#  ('look', 'way'): 2,
#  ('look', 'everi'): 2,
#  ('look', 'thing'): 4,
#  ('look', 'start'): 2,
#  ('look', 'winter'): 0,
#  ('look', 'end'): 2,
#  ('look', 'die'): 0,
#  ('look', 'next'): 0,
#  ('look', 'cross'): 5,
#  ('look', 'wall'): 4,
#  ('look', 'away'): 5,
#  ('look', 'town'): 3,
#  ('look', 'nice'): 0,
#  ('look', 'fine'): 1,
#  ('look', 'us'): 9,
#  ('look', 'austrian'): 3,
#  ('look', 'seem'): 2,
#  ('look', 'want'): 4,
#  ('look', 'come'): 9,
#  ('look', 'time'): 2,
#  ('look', 'war'): 0,
#  ('look', 'littl'): 7,
#  ('look', 'peopl'): 0,
#  ('look', 'hospit'): 1,
#  ('look', 'street'): 2,
#  ('look', 'around'): 10,
#  ('look', 'girl'): 4,
#  ('look', 'well'): 2,
#  ('look', 'made'): 3,
#  ('look', 'snow'): 5,
#  ('look', 'wind'): 1,
#  ('look', 'watch'): 13,
#  ('look', 'sat'): 12,
#  ('look', 'glass'): 12,
#  ('look', 'drink'): 3,
#  ('look', 'bottl'): 3,
#  ('look', 'knew'): 3,
#  ('look', 'left'): 2,
#  ('look', 'priest'): 9,
#  ('look', 'walk'): 7,
#  ('look', 'smiled'): 3,
#  ('look', 'shook'): 1,
#  ('look', 'head'): 4,
#  ('look', 'wine'): 0,
#  ('look', 'held'): 3,
#  ('look', 'hand'): 4,
#  ('look', 'captain'): 3,
#  ('look', 'italian'): 1,
#  ('look', 'might'): 2,
#  ('look', 'noth'): 1,
#  ('look', 'said'): 17,
#  ('look', 'ask'): 2,
#  ('look', 'never'): 2,
#  ('look', 'took'): 5,
#  ('look', 'sight'): 1,
#  ('look', 'major'): 4,
#  ('look', 'love'): 4,
#  ('look', 'ever'): 0,
#  ('look', 'read'): 0,
#  ('look', 'get'): 2,
#  ('look', 'realli'): 1,
#  ('look', 'tell'): 2,
#  ('look', 'think'): 4,
#  ('look', 'believ'): 1,
#  ('look', 'door'): 6,
#  ('look', 'open'): 6,
#  ('look', 'ought'): 0,
#  ('look', 'would'): 6,
#  ('look', 'talk'): 2,
#  ('look', 'let'): 1,
#  ('look', 'give'): 1,
#  ('look', 'place'): 4,
#  ('look', 'make'): 4,
#  ('look', 'point'): 3,
#  ('look', 'first'): 2,
#  ('look', 'great'): 2,
#  ('look', 'must'): 3,
#  ('look', 'bring'): 1,
#  ('look', 'good'): 3,
#  ('look', 'wish'): 1,
#  ('look', 'say'): 2,
#  ('look', 'cold'): 1,
#  ('look', 'stay'): 1,
#  ('look', 'still'): 5,
#  ('look', 'field'): 4,
#  ('look', 'old'): 2,
#  ('look', 'new'): 4,
#  ('look', 'fire'): 0,
#  ('look', 'outsid'): 2,
#  ('look', 'wait'): 1,
#  ('look', 'insid'): 0,
#  ('look', 'floor'): 6,
#  ('look', 'room'): 13,
#  ('look', 'know'): 2,
#  ('look', 'rinaldi'): 9,
#  ('look', 'lay'): 3,
#  ('look', 'put'): 6,
#  ('look', 'arm'): 1,
#  ('look', 'kiss'): 1,
#  ('look', 'r'): 1,
#  ('look', 'villa'): 1,
#  ('look', 'yes'): 3,
#  ('look', 'nothing'): 0,
#  ('look', 'english'): 1,
#  ('look', 'miss'): 1,
#  ('look', 'barkley'): 1,
#  ('look', 'take'): 4,
#  ('look', 'call'): 0,
#  ('look', 'work'): 2,
#  ('look', 'hard'): 1,
#  ('look', 'wound'): 0,
#  ('look', 'right'): 2,
#  ('look', 'sleep'): 0,
#  ('look', 'lie'): 4,
#  ('look', 'close'): 4,
#  ('look', 'man'): 5,
#  ('look', 'felt'): 2,
#  ('look', 'tri'): 2,
#  ('look', 'almost'): 0,
#  ('look', 'stop'): 4,
#  ('look', 'sure'): 2,
#  ('look', 'alway'): 3,
#  ('look', 'better'): 4,
#  ('look', 'attack'): 0,
#  ('look', 'anyth'): 4,
#  ('look', 'got'): 1,
#  ('look', 'line'): 6,
#  ('look', 'three'): 3,
#  ('look', 'dress'): 2,
#  ('look', 'tenente'): 2,
#  ('look', 'bad'): 1,
#  ('look', 'matter'): 3,
#  ('look', 'tire'): 3,
#  ('look', 'cut'): 3,
#  ('look', 'stone'): 3,
#  ('look', 'station'): 1,
#  ('look', 'sergeant'): 5,
#  ('look', 'drank'): 1,
#  ('look', 'hot'): 0,
#  ('look', 'told'): 0,
#  ('look', 'keep'): 1,
#  ('look', 'gave'): 0,
#  ('look', 'pleas'): 1,
#  ('look', 'brush'): 0,
#  ('look', 'german'): 1,
#  ('look', 'nurs'): 5,
#  ('look', 'toward'): 7,
#  ('look', 'oh'): 3,
#  ('look', 'brought'): 3,
#  ('look', 'asked'): 0,
#  ('look', 'quit'): 1,
#  ('look', 'thought'): 3,
#  ('look', 'boy'): 0,
#  ('look', 'kill'): 0,
#  ('look', 'v'): 2,
#  ('look', 'someth'): 3,
#  ('look', 'anything'): 0,
#  ('look', 'stand'): 5,
#  ('look', 'ferguson'): 0,
#  ('look', 'doctor'): 4,
#  ('look', 'find'): 3,
#  ('look', 'shot'): 0,
#  ('look', 'american'): 2,
#  ('look', 'afraid'): 2,
#  ('look', 'far'): 3,
#  ('look', 'bridg'): 2,
#  ('look', 'hold'): 4,
#  ('look', 'turn'): 3,
#  ('look', 'high'): 4,
#  ('look', 'catherine'): 3,
#  ('look', 'ahead'): 8,
#  ('look', 'mind'): 0,
#  ('look', 'darling'): 4,
#  ('look', 'hall'): 2,
#  ('look', 'paper'): 4,
#  ('look', 'catherin'): 10,
#  ('look', 'stood'): 4,
#  ('look', 'play'): 1,
#  ('look', 'tired'): 5,
#  ('look', 'baby'): 2,
#  ('look', 'thank'): 0,
#  ('look', 'god'): 0,
#  ('look', 'besid'): 2,
#  ('look', 'mayb'): 2,
#  ('look', 'eat'): 2,
#  ('look', 'hotel'): 0,
#  ('look', 'hear'): 0,
#  ('look', 'light'): 6,
#  ('look', 'hope'): 0,
#  ('look', 'train'): 0,
#  ('look', 'bank'): 4,
#  ('look', 'row'): 1,
#  ('look', 'retreat'): 1,
#  ('look', 'bonello'): 2,
#  ('look', 'piani'): 6,
#  ('look', 'aymo'): 2,
#  ('look', 'shore'): 3,
#  ('look', 'boat'): 0,
#  ('look', 'lake'): 6,
#  ('look', 'barman'): 0,
#  ('across', 'river'): 11,
#  ('across', 'bed'): 4,
#  ('across', 'white'): 0,
#  ('across', 'water'): 1,
#  ('across', 'clear'): 1,
#  ('across', 'move'): 2,
#  ('across', 'went'): 11,
#  ('across', 'road'): 15,
#  ('across', 'leav'): 0,
#  ('across', 'tree'): 4,
#  ('across', 'saw'): 2,
#  ('across', 'along'): 5,
#  ('across', 'fall'): 1,
#  ('across', 'soldier'): 0,
#  ('across', 'mani'): 1,
#  ('across', 'beyond'): 1,
#  ('across', 'mountain'): 7,
#  ('across', 'night'): 1,
#  ('across', 'could'): 13,
#  ('across', 'see'): 10,
#  ('across', 'dark'): 2,
#  ('across', 'like'): 1,
#  ('across', 'feel'): 0,
#  ('across', 'sometim'): 0,
#  ('across', 'heard'): 2,
#  ('across', 'window'): 4,
#  ('across', 'go'): 3,
#  ('across', 'pull'): 1,
#  ('across', 'much'): 0,
#  ('across', 'side'): 7,
#  ('across', 'carri'): 1,
#  ('across', 'men'): 1,
#  ('across', 'big'): 0,
#  ('across', 'pass'): 3,
#  ('across', 'day'): 0,
#  ('across', 'long'): 2,
#  ('across', 'behind'): 3,
#  ('across', 'anoth'): 3,
#  ('across', 'rain'): 6,
#  ('across', 'came'): 7,
#  ('across', 'wet'): 3,
#  ('across', 'dead'): 0,
#  ('across', 'two'): 4,
#  ('across', 'front'): 1,
#  ('across', 'though'): 0,
#  ('across', 'gone'): 0,
#  ('across', 'small'): 1,
#  ('across', 'car'): 3,
#  ('across', 'offic'): 0,
#  ('across', 'seat'): 0,
#  ('across', 'driver'): 0,
#  ('across', 'back'): 9,
#  ('across', 'even'): 1,
#  ('across', 'one'): 3,
#  ('across', 'sit'): 2,
#  ('across', 'face'): 2,
#  ('across', 'way'): 4,
#  ('across', 'everi'): 0,
#  ('across', 'thing'): 0,
#  ('across', 'start'): 3,
#  ('across', 'winter'): 0,
#  ('across', 'end'): 1,
#  ('across', 'die'): 0,
#  ('across', 'next'): 0,
#  ('across', 'cross'): 5,
#  ('across', 'wall'): 2,
#  ('across', 'away'): 1,
#  ('across', 'town'): 3,
#  ('across', 'nice'): 0,
#  ('across', 'fine'): 0,
#  ('across', 'us'): 1,
#  ('across', 'austrian'): 3,
#  ('across', 'seem'): 0,
#  ('across', 'want'): 1,
#  ('across', 'come'): 5,
#  ('across', 'time'): 1,
#  ('across', 'war'): 0,
#  ('across', 'littl'): 1,
#  ('across', 'peopl'): 1,
#  ('across', 'hospit'): 0,
#  ('across', 'street'): 1,
#  ('across', 'around'): 2,
#  ('across', 'girl'): 0,
#  ('across', 'well'): 0,
#  ('across', 'made'): 0,
#  ('across', 'snow'): 1,
#  ('across', 'wind'): 3,
#  ('across', 'watch'): 1,
#  ('across', 'sat'): 0,
#  ('across', 'glass'): 1,
#  ('across', 'drink'): 2,
#  ('across', 'bottl'): 1,
#  ('across', 'knew'): 5,
#  ('across', 'left'): 1,
#  ('across', 'priest'): 1,
#  ('across', 'walk'): 4,
#  ('across', 'smiled'): 0,
#  ('across', 'shook'): 1,
#  ('across', 'head'): 2,
#  ('across', 'wine'): 0,
#  ('across', 'held'): 2,
#  ('across', 'hand'): 2,
#  ('across', 'captain'): 1,
#  ('across', 'italian'): 0,
#  ('across', 'might'): 2,
#  ('across', 'noth'): 1,
#  ('across', 'said'): 5,
#  ('across', 'ask'): 0,
#  ('across', 'never'): 0,
#  ('across', 'took'): 1,
#  ('across', 'sight'): 1,
#  ('across', 'major'): 0,
#  ('across', 'love'): 0,
#  ('across', 'ever'): 1,
#  ('across', 'read'): 1,
#  ('across', 'get'): 8,
#  ('across', 'realli'): 0,
#  ('across', 'tell'): 0,
#  ('across', 'think'): 1,
#  ('across', 'believ'): 0,
#  ('across', 'door'): 1,
#  ('across', 'open'): 0,
#  ('across', 'ought'): 0,
#  ('across', 'would'): 2,
#  ('across', 'talk'): 1,
#  ('across', 'let'): 0,
#  ('across', 'give'): 0,
#  ('across', 'place'): 3,
#  ('across', 'make'): 0,
#  ('across', 'point'): 0,
#  ('across', 'first'): 0,
#  ('across', 'great'): 1,
#  ('across', 'must'): 0,
#  ('across', 'bring'): 1,
#  ('across', 'good'): 0,
#  ('across', 'wish'): 0,
#  ('across', 'say'): 1,
#  ('across', 'cold'): 0,
#  ('across', 'stay'): 0,
#  ('across', 'still'): 0,
#  ('across', 'field'): 8,
#  ('across', 'old'): 1,
#  ('across', 'new'): 0,
#  ('across', 'fire'): 2,
#  ('across', 'outsid'): 1,
#  ('across', 'wait'): 1,
#  ('across', 'insid'): 0,
#  ('across', 'floor'): 1,
#  ('across', 'room'): 1,
#  ('across', 'know'): 0,
#  ('across', 'rinaldi'): 1,
#  ('across', 'lay'): 1,
#  ('across', 'put'): 0,
#  ('across', 'arm'): 0,
#  ('across', 'kiss'): 0,
#  ('across', 'r'): 1,
#  ('across', 'villa'): 0,
#  ('across', 'yes'): 1,
#  ('across', 'nothing'): 0,
#  ('across', 'english'): 0,
#  ('across', 'miss'): 0,
#  ('across', 'barkley'): 0,
#  ('across', 'take'): 2,
#  ('across', 'call'): 0,
#  ('across', 'work'): 4,
#  ('across', 'hard'): 2,
#  ('across', 'wound'): 4,
#  ('across', 'right'): 0,
#  ('across', 'sleep'): 0,
#  ('across', 'lie'): 0,
#  ('across', 'close'): 2,
#  ('across', 'man'): 1,
#  ('across', 'felt'): 0,
#  ('across', 'tri'): 2,
#  ('across', 'almost'): 1,
#  ('across', 'stop'): 1,
#  ('across', 'sure'): 0,
#  ('across', 'alway'): 0,
#  ('across', 'better'): 2,
#  ('across', 'attack'): 0,
#  ('across', 'anyth'): 0,
#  ('across', 'got'): 1,
#  ('across', 'line'): 5,
#  ('across', 'three'): 1,
#  ('across', 'dress'): 2,
#  ('across', 'tenente'): 0,
#  ('across', 'bad'): 0,
#  ('across', 'matter'): 0,
#  ('across', 'tire'): 0,
#  ('across', 'cut'): 1,
#  ('across', 'stone'): 0,
#  ('across', 'station'): 2,
#  ('across', 'sergeant'): 1,
#  ('across', 'drank'): 0,
#  ('across', 'hot'): 0,
#  ('across', 'told'): 1,
#  ('across', 'keep'): 1,
#  ('across', 'gave'): 0,
#  ('across', 'pleas'): 0,
#  ('across', 'brush'): 0,
#  ('across', 'german'): 1,
#  ('across', 'nurs'): 0,
#  ('across', 'toward'): 2,
#  ('across', 'oh'): 0,
#  ('across', 'brought'): 3,
#  ('across', 'asked'): 0,
#  ('across', 'quit'): 0,
#  ('across', 'thought'): 3,
#  ('across', 'boy'): 0,
#  ('across', 'kill'): 0,
#  ('across', 'v'): 0,
#  ('across', 'someth'): 1,
#  ('across', 'anything'): 0,
#  ('across', 'stand'): 0,
#  ('across', 'ferguson'): 0,
#  ('across', 'doctor'): 0,
#  ('across', 'find'): 1,
#  ('across', 'shot'): 0,
#  ('across', 'american'): 0,
#  ('across', 'afraid'): 0,
#  ('across', 'far'): 3,
#  ('across', 'bridg'): 8,
#  ('across', 'hold'): 1,
#  ('across', 'turn'): 1,
#  ('across', 'high'): 0,
#  ('across', 'catherine'): 1,
#  ...}

# %%
#順位チェック
sorted(count_s.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('go', 'said'), 102),
#  (('could', 'see'), 78),
#  (('said', 'catherin'), 71),
#  (('said', 'get'), 50),
#  (('went', 'back'), 48),
#  (('said', 'rinaldi'), 42),
#  (('said', 'right'), 40),
#  (('said', 'piani'), 40),
#  (('go', 'would'), 39),
#  (('want', 'said'), 39),
#  (('said', 'bonello'), 38),
#  (('road', 'along'), 37),
#  (('said', 'major'), 37),
#  (('said', 'would'), 37),
#  (('come', 'said'), 36),
#  (('said', 'good'), 36),
#  (('said', 'r'), 36),
#  (('go', 'want'), 35),
#  (('one', 'said'), 35),
#  (('like', 'said'), 33),
#  (('said', 'know'), 33),
#  (('go', 'back'), 32),
#  (('go', 'get'), 32),
#  (('back', 'come'), 31),
#  (('see', 'go'), 30),
#  (('said', 'yes'), 28),
#  (('look', 'window'), 26),
#  (('go', 'away'), 26),
#  (('said', 'think'), 26),
#  (('said', 'take'), 26),
#  (('said', 'darling'), 26),
#  (('came', 'back'), 25),
#  (('priest', 'said'), 25),
#  (('said', 'aymo'), 25),
#  (('went', 'door'), 24),
#  (('road', 'side'), 24),
#  (('see', 'said'), 24),
#  (('said', 'tenente'), 24),
#  (('could', 'said'), 23),
#  (('like', 'go'), 23),
#  (('like', 'would'), 23),
#  (('go', 'let'), 23),
#  (('went', 'go'), 22),
#  (('went', 'said'), 22),
#  (('went', 'room'), 22),
#  (('go', 'come'), 22),
#  (('back', 'said'), 22),
#  (('look', 'back'), 21),
#  (('went', 'road'), 21),
#  (('road', 'could'), 21),
#  (('could', 'go'), 21),
#  (('said', 'sleep'), 21),
#  (('look', 'could'), 20),
#  (('one', 'would'), 20),
#  (('come', 'would'), 20),
#  (('war', 'said'), 20),
#  (('door', 'open'), 20),
#  (('miss', 'barkley'), 20),
#  (('look', 'saw'), 19),
#  (('look', 'see'), 19),
#  (('look', 'like'), 19),
#  (('go', 'one'), 19),
#  (('long', 'time'), 19),
#  (('look', 'went'), 18),
#  (('look', 'road'), 18),
#  (('went', 'came'), 18),
#  (('see', 'want'), 18),
#  (('littl', 'said'), 18),
#  (('shook', 'head'), 18),
#  (('get', 'would'), 18),
#  (('look', 'said'), 17),
#  (('went', 'see'), 17),
#  (('much', 'said'), 17),
#  (('car', 'back'), 17),
#  (('come', 'get'), 17),
#  (('said', 'love'), 17),
#  (('said', 'better'), 17),
#  (('said', 'v'), 17),
#  (('said', 'doctor'), 17),
#  (('went', 'open'), 16),
#  (('road', 'go'), 16),
#  (('could', 'would'), 16),
#  (('see', 'would'), 16),
#  (('back', 'get'), 16),
#  (('one', 'everi'), 16),
#  (('fine', 'said'), 16),
#  (('us', 'said'), 16),
#  (('time', 'said'), 16),
#  (('said', 'must'), 16),
#  (('darling', 'catherin'), 16),
#  (('across', 'road'), 15),
#  (('went', 'catherin'), 15),
#  (('road', 'saw'), 15),
#  (('could', 'get'), 15),
#  (('go', 'think'), 15),
#  (('go', 'r'), 15),
#  (('go', 'sleep'), 15),
#  (('go', 'darling'), 15),
#  (('go', 'catherin'), 15),
#  (('long', 'way'), 15),
#  (('start', 'said'), 15),
#  (('held', 'hand'), 15),
#  (('hand', 'put'), 15),
#  (('said', 'tell'), 15),
#  (('said', 'talk'), 15),
#  (('went', 'along'), 14),
#  (('road', 'pass'), 14),
#  (('road', 'car'), 14),
#  (('along', 'could'), 14),
#  (('along', 'walk'), 14),
#  (('see', 'come'), 14),
#  (('go', 'right'), 14),
#  (('knew', 'would'), 14),
#  (('said', 'someth'), 14),
#  (('said', 'eat'), 14),
#  (('look', 'came'), 13),
#  (('look', 'watch'), 13),
#  (('look', 'room'), 13),
#  (('across', 'could'), 13),
#  (('river', 'road'), 13),
#  (('went', 'one'), 13),
#  (('went', 'come'), 13),
#  (('went', 'littl'), 13),
#  (('went', 'hall'), 13),
#  (('road', 'back'), 13),
#  (('road', 'start'), 13),
#  (('road', 'turn'), 13),
#  (('road', 'ahead'), 13),
#  (('saw', 'come'), 13),
#  (('along', 'go'), 13),
#  (('mountain', 'side'), 13),
#  (('could', 'back'), 13),
#  (('could', 'one'), 13),
#  (('see', 'came'), 13),
#  (('see', 'catherin'), 13),
#  (('go', 'must'), 13),
#  (('came', 'two'), 13),
#  (('two', 'car'), 13),
#  (('thing', 'said'), 13),
#  (('want', 'get'), 13),
#  (('well', 'said'), 13),
#  (('said', 'let'), 13),
#  (('said', 'place'), 13),
#  (('think', 'would'), 13),
#  (('look', 'dark'), 12),
#  (('look', 'go'), 12),
#  (('look', 'car'), 12),
#  (('look', 'sat'), 12),
#  (('look', 'glass'), 12),
#  (('bed', 'window'), 12),
#  (('bed', 'room'), 12),
#  (('bed', 'lay'), 12),
#  (('road', 'tree'), 12),
#  (('road', 'beyond'), 12),
#  (('road', 'mountain'), 12),
#  (('road', 'see'), 12),
#  (('saw', 'came'), 12),
#  (('saw', 'one'), 12),
#  (('along', 'see'), 12),
#  (('beyond', 'mountain'), 12),
#  (('could', 'rain'), 12),
#  (('could', 'come'), 12),
#  (('see', 'rain'), 12),
#  (('window', 'open'), 12),
#  (('go', 'car'), 12),
#  (('go', 'war'), 12),
#  (('go', 'know'), 12),
#  (('anoth', 'said'), 12),
#  (('came', 'one'), 12),
#  (('two', 'said'), 12),
#  (('back', 'would'), 12),
#  (('one', 'thing'), 12),
#  (('one', 'come'), 12),
#  (('away', 'said'), 12),
#  (('us', 'want'), 12),
#  (('said', 'give'), 12),
#  (('said', 'make'), 12),
#  (('said', 'first'), 12),
#  (('said', 'stay'), 12),
#  (('said', 'room'), 12),
#  (('said', 'nurs'), 12),
#  (('door', 'room'), 12),
#  (('bonello', 'piani'), 12),
#  (('look', 'two'), 11),
#  (('look', 'one'), 11),
#  (('across', 'river'), 11),
#  (('across', 'went'), 11),
#  (('river', 'cross'), 11),
#  (('bed', 'back'), 11),
#  (('bed', 'rinaldi'), 11),
#  (('went', 'could'), 11),
#  (('went', 'two'), 11),
#  (('went', 'would'), 11),
#  (('went', 'rinaldi'), 11),
#  (('went', 'sleep'), 11),
#  (('road', 'came'), 11),
#  (('road', 'field'), 11),
#  (('mountain', 'could'), 11),
#  (('mountain', 'see'), 11),
#  (('could', 'side'), 11),
#  (('could', 'car'), 11),
#  (('could', 'think'), 11),
#  (('could', 'catherin'), 11),
#  (('see', 'one'), 11),
#  (('go', 'walk'), 11),
#  (('go', 'place'), 11),
#  (('go', 'say'), 11),
#  (('go', 'stop'), 11),
#  (('side', 'one'), 11),
#  (('want', 'know'), 11),
#  (('time', 'catherin'), 11),
#  (('drink', 'said'), 11),
#  (('said', 'miss'), 11),
#  (('said', 'oh'), 11),
#  (('said', 'boy'), 11),
#  (('said', 'mayb'), 11),
#  (('read', 'paper'), 11),
#  (('would', 'thought'), 11),
#  (('say', 'anything'), 11),
#  (('tenente', 'bonello'), 11),
#  (('look', 'behind'), 10),
#  (('look', 'around'), 10),
#  (('look', 'catherin'), 10),
#  (('across', 'see'), 10),
#  (('river', 'along'), 10),
#  (('river', 'side'), 10),
#  (('bed', 'sat'), 10),
#  (('went', 'sat'), 10),
#  (('road', 'walk'), 10),
#  (('tree', 'field'), 10),
#  (('along', 'side'), 10),
#  (('mountain', 'lake'), 10),
#  (('could', 'feel'), 10),
#  (('could', 'window'), 10),
#  (('could', 'way'), 10),
#  (('could', 'place'), 10),
#  (('see', 'way'), 10),
#  (('dark', 'outsid'), 10),
#  (('feel', 'said'), 10),
#  (('window', 'room'), 10),
#  (('go', 'start'), 10),
#  (('go', 'yes'), 10),
#  (('go', 'take'), 10),
#  (('rain', 'stop'), 10),
#  (('back', 'sat'), 10),
#  (('back', 'take'), 10),
#  (('one', 'time'), 10),
#  (('one', 'knew'), 10),
#  (('one', 'know'), 10),
#  (('die', 'let'), 10),
#  (('want', 'would'), 10),
#  (('come', 'catherin'), 10),
#  (('war', 'would'), 10),
#  (('said', 'believ'), 10),
#  (('said', 'ought'), 10),
#  (('said', 'got'), 10),
#  (('said', 'thought'), 10),
#  (('said', 'find'), 10),
#  (('said', 'american'), 10),
#  (('get', 'say'), 10),
#  (('think', 'know'), 10),
#  (('would', 'take'), 10),
#  (('good', 'r'), 10),
#  (('r', 'darling'), 10),
#  (('got', 'v'), 10),
#  (('dress', 'station'), 10),
#  (('hous', 'went'), 9),
#  (('look', 'across'), 9),
#  (('look', 'us'), 9),
#  (('look', 'come'), 9),
#  (('look', 'priest'), 9),
#  (('look', 'rinaldi'), 9),
#  (('across', 'back'), 9),
#  (('river', 'mountain'), 9),
#  (('river', 'bank'), 9),
#  (('bed', 'went'), 9),
#  (('went', 'dark'), 9),
#  (('went', 'window'), 9),
#  (('went', 'side'), 9),
#  (('went', 'away'), 9),
#  (('went', 'got'), 9),
#  (('road', 'two'), 9),
#  (('road', 'cross'), 9),
#  (('road', 'line'), 9),
#  (('saw', 'close'), 9),
#  (('mountain', 'came'), 9),
#  (('mountain', 'town'), 9),
#  (('night', 'go'), 9),
#  (('night', 'said'), 9),
#  (('could', 'long'), 9),
#  (('could', 'came'), 9),
#  (('could', 'us'), 9),
#  (('could', 'take'), 9),
#  (('see', 'dark'), 9),
#  (('see', 'side'), 9),
#  (('see', 'car'), 9),
#  (('see', 'littl'), 9),
#  (('see', 'think'), 9),
#  (('like', 'feel'), 9),
#  (('go', 'time'), 9),
#  (('go', 'bonello'), 9),
#  (('big', 'one'), 9),
#  (('big', 'said'), 9),
#  (('long', 'away'), 9),
#  (('long', 'said'), 9),
#  (('came', 'door'), 9),
#  (('two', 'one'), 9),
#  (('back', 'one'), 9),
#  (('back', 'got'), 9),
#  (('one', 'hand'), 9),
#  (('way', 'littl'), 9),
#  (('way', 'said'), 9),
#  (('wall', 'room'), 9),
#  (('town', 'littl'), 9),
#  (('austrian', 'said'), 9),
#  (('want', 'think'), 9),
#  (('come', 'door'), 9),
#  (('around', 'arm'), 9),
#  (('drink', 'took'), 9),
#  (('hand', 'said'), 9),
#  (('captain', 'said'), 9),
#  (('italian', 'said'), 9),
#  (('said', 'say'), 9),
#  (('said', 'old'), 9),
#  (('said', 'tri'), 9),
#  (('said', 'stop'), 9),
#  (('said', 'alway'), 9),
#  (('said', 'bad'), 9),
#  (('get', 'know'), 9),
#  (('room', 'hall'), 9),
#  (('put', 'arm'), 9),
#  (('miss', 'ferguson'), 9),
#  (('oh', 'darling'), 9),
#  (('doctor', 'catherin'), 9),
#  (('live', 'like'), 8),
#  (('look', 'along'), 8),
#  (('look', 'ahead'), 8),
#  (('across', 'get'), 8),
#  (('across', 'field'), 8),
#  (('across', 'bridg'), 8),
#  (('river', 'bridg'), 8),
#  (('went', 'car'), 8),
#  (('went', 'want'), 8),
#  (('went', 'get'), 8),
#  (('went', 'think'), 8),
#  (('went', 'take'), 8),
#  (('went', 'toward'), 8),
#  (('went', 'turn'), 8),
#  (('went', 'lake'), 8),
#  (('road', 'mani'), 8),
#  (('road', 'way'), 8),
#  (('road', 'said'), 8),
#  (('road', 'would'), 8),
#  (('road', 'stop'), 8),
#  (('tree', 'mountain'), 8),
#  (('tree', 'side'), 8),
#  (('saw', 'along'), 8),
#  (('saw', 'go'), 8),
#  (('saw', 'face'), 8),
#  (('saw', 'light'), 8),
#  (('along', 'pass'), 8),
#  (('along', 'cross'), 8),
#  (('along', 'field'), 8),
#  (('mountain', 'shore'), 8),
#  (('night', 'one'), 8),
#  (('night', 'everi'), 8),
#  (('could', 'dark'), 8),
#  (('could', 'two'), 8),
#  (('could', 'littl'), 8),
#  (('could', 'stay'), 8),
#  (('could', 'close'), 8),
#  (('could', 'hear'), 8),
#  (('see', 'like'), 8),
#  (('see', 'even'), 8),
#  (('see', 'away'), 8),
#  (('see', 'us'), 8),
#  (('see', 'put'), 8),
#  (('see', 'shore'), 8),
#  (('dark', 'get'), 8),
#  (('dark', 'light'), 8),
#  (('window', 'come'), 8),
#  (('go', 'front'), 8),
#  (('go', 'die'), 8),
#  (('go', 'littl'), 8),
#  (('go', 'street'), 8),
#  (('go', 'knew'), 8),
#  (('go', 'door'), 8),
#  (('go', 'tri'), 8),
#  (('go', 'pleas'), 8),
#  (('go', 'someth'), 8),
#  (('go', 'eat'), 8),
#  (('go', 'piani'), 8),
#  (('much', 'think'), 8),
#  (('long', 'one'), 8),
#  (('rain', 'came'), 8),
#  (('came', 'car'), 8),
#  (('came', 'us'), 8),
#  (('came', 'time'), 8),
#  (('came', 'hand'), 8),
#  (('two', 'bottl'), 8),
#  (('car', 'aymo'), 8),
#  (('offic', 'said'), 8),
#  (('back', 'way'), 8),
#  (('back', 'us'), 8),
#  (('back', 'want'), 8),
#  (('back', 'hand'), 8),
#  (('back', 'aymo'), 8),
#  (('one', 'took'), 8),
#  (('one', 'get'), 8),
#  (('one', 'door'), 8),
#  (('start', 'would'), 8),
#  (('want', 'come'), 8),
#  (('want', 'war'), 8),
#  (('want', 'stay'), 8),
#  (('want', 'anyth'), 8),
#  (('come', 'outsid'), 8),
#  (('around', 'put'), 8),
#  (('girl', 'said'), 8),
#  (('wind', 'lake'), 8),
#  (('priest', 'rinaldi'), 8),
#  (('walk', 'toward'), 8),
#  (('wine', 'drank'), 8),
#  (('said', 'ask'), 8),
#  (('said', 'nothing'), 8),
#  (('said', 'anyth'), 8),
#  (('said', 'german'), 8),
#  (('said', 'ferguson'), 8),
#  (('said', 'baby'), 8),
#  (('love', 'catherin'), 8),
#  (('get', 'think'), 8),
#  (('get', 'catherin'), 8),
#  (('think', 'r'), 8),
#  (('door', 'hall'), 8),
#  (('would', 'wish'), 8),
#  (('would', 'yes'), 8),
#  (('would', 'stop'), 8),
#  (('would', 'bad'), 8),
#  (('would', 'catherin'), 8),
#  (('would', 'hope'), 8),
#  (('know', 'r'), 8),
#  (('know', 'anyth'), 8),
#  (('barkley', 'catherin'), 8),
#  (('hous', 'town'), 7),
#  (('look', 'big'), 7),
#  (('look', 'littl'), 7),
#  (('look', 'walk'), 7),
#  (('look', 'toward'), 7),
#  (('across', 'mountain'), 7),
#  (('across', 'side'), 7),
#  (('across', 'came'), 7),
#  (('river', 'beyond'), 7),
#  (('bed', 'go'), 7),
#  (('bed', 'one'), 7),
#  (('water', 'cold'), 7),
#  (('went', 'saw'), 7),
#  (('went', 'rain'), 7),
#  (('went', 'way'), 7),
#  (('went', 'left'), 7),
#  (('went', 'walk'), 7),
#  (('went', 'took'), 7),
#  (('went', 'put'), 7),
#  (('went', 'paper'), 7),
#  (('went', 'aymo'), 7),
#  (('road', 'come'), 7),
#  (('road', 'get'), 7),
#  (('road', 'stone'), 7),
#  (('road', 'besid'), 7),
#  (('leav', 'want'), 7),
#  (('leav', 'said'), 7),
#  (('tree', 'along'), 7),
#  (('tree', 'see'), 7),
#  (('along', 'mountain'), 7),
#  (('along', 'us'), 7),
#  (('along', 'bank'), 7),
#  (('beyond', 'littl'), 7),
#  (('night', 'rain'), 7),
#  (('could', 'away'), 7),
#  (('could', 'want'), 7),
#  (('could', 'snow'), 7),
#  (('could', 'keep'), 7),
#  (('could', 'thought'), 7),
#  (('could', 'far'), 7),
#  (('see', 'window'), 7),
#  (('see', 'back'), 7),
#  (('see', 'get'), 7),
#  (('see', 'let'), 7),
#  (('see', 'field'), 7),
#  (('see', 'got'), 7),
#  (('see', 'lake'), 7),
#  (('dark', 'rain'), 7),
#  (('like', 'two'), 7),
#  (('like', 'littl'), 7),
#  (('like', 'get'), 7),
#  (('like', 'think'), 7),
#  (('like', 'wish'), 7),
#  (('like', 'r'), 7),
#  (('like', 'baby'), 7),
#  (('window', 'light'), 7),
#  (('go', 'side'), 7),
#  (('go', 'men'), 7),
#  (('go', 'long'), 7),
#  (('go', 'thing'), 7),
#  (('go', 'well'), 7),
#  (('go', 'drink'), 7),
#  (('go', 'ought'), 7),
#  (('go', 'first'), 7),
#  (('go', 'stay'), 7),
#  (('go', 'outsid'), 7),
#  (('go', 'put'), 7),
#  (('go', 'cut'), 7),
#  (('go', 'doctor'), 7),
#  (('go', 'lake'), 7),
#  (('much', 'want'), 7),
#  (('much', 'get'), 7),
#  (('much', 'would'), 7),
#  (('much', 'talk'), 7),
#  (('side', 'lake'), 7),
#  (('men', 'two'), 7),
#  (('big', 'came'), 7),
#  (('long', 'row'), 7),
#  (('came', 'come'), 7),
#  (('came', 'said'), 7),
#  (('two', 'back'), 7),
#  (('two', 'girl'), 7),
#  (('car', 'said'), 7),
#  (('car', 'would'), 7),
#  (('back', 'put'), 7),
#  (('back', 'sleep'), 7),
#  (('one', 'us'), 7),
#  (('one', 'want'), 7),
#  (('one', 'held'), 7),
#  (('one', 'open'), 7),
#  (('one', 'good'), 7),
#  (('one', 'catherin'), 7),
#  (('sit', 'said'), 7),
#  (('way', 'think'), 7),
#  (('thing', 'get'), 7),
#  (('wall', 'stone'), 7),
#  (('away', 'want'), 7),
#  (('away', 'come'), 7),
#  (('away', 'take'), 7),
#  (('us', 'bonello'), 7),
#  (('want', 'darling'), 7),
#  (('want', 'catherin'), 7),
#  (('come', 'nurs'), 7),
#  (('come', 'hall'), 7),
#  (('time', 'good'), 7),
#  (('time', 'bad'), 7),
#  (('littl', 'sat'), 7),
#  (('littl', 'catherin'), 7),
#  (('hospit', 'said'), 7),
#  (('sat', 'besid'), 7),
#  (('drink', 'wine'), 7),
#  (('knew', 'get'), 7),
#  (('walk', 'hall'), 7),
#  (('italian', 'talk'), 7),
#  (('said', 'realli'), 7),
#  (('said', 'wait'), 7),
#  (('said', 'put'), 7),
#  (('said', 'barkley'), 7),
#  (('said', 'lie'), 7),
#  (('said', 'keep'), 7),
#  (('said', 'kill'), 7),
#  (('said', 'catherine'), 7),
#  (('said', 'thank'), 7),
#  (('said', 'god'), 7),
#  (('never', 'get'), 7),
#  (('never', 'would'), 7),
#  (('get', 'right'), 7),
#  (('get', 'tri'), 7),
#  (('tell', 'would'), 7),
#  (('door', 'outsid'), 7),
#  (('open', 'outsid'), 7),
#  (('would', 'make'), 7),
#  (('would', 'good'), 7),
#  (('would', 'put'), 7),
#  (('good', 'take'), 7),
#  (('say', 'catherin'), 7),
#  (('old', 'man'), 7),
#  (('room', 'doctor'), 7),
#  (('room', 'catherin'), 7),
#  (('r', 'catherin'), 7),
#  (('yes', 'oh'), 7),
#  (('close', 'shore'), 7),
#  (('tenente', 'asked'), 7),
#  (('asked', 'bonello'), 7),
#  (('asked', 'aymo'), 7),
#  (('turn', 'catherin'), 7),
#  (('shore', 'lake'), 7),
#  (('live', 'hous'), 6),
#  (('hous', 'mountain'), 6),
#  (('look', 'bed'), 6),
#  (('look', 'mountain'), 6),
#  (('look', 'side'), 6),
#  (('look', 'door'), 6),
#  (('look', 'open'), 6),
#  (('look', 'would'), 6),
#  (('look', 'floor'), 6),
#  (('look', 'put'), 6),
#  (('look', 'line'), 6),
#  (('look', 'light'), 6),
#  (('look', 'piani'), 6),
#  (('look', 'lake'), 6),
#  (('across', 'rain'), 6),
#  (('across', 'ahead'), 6),
#  (('across', 'lake'), 6),
#  (('river', 'could'), 6),
#  (('river', 'go'), 6),
#  (('river', 'two'), 6),
#  (('river', 'austrian'), 6),
#  (('bed', 'could'), 6),
#  (('bed', 'see'), 6),
#  (('bed', 'come'), 6),
#  (('bed', 'made'), 6),
#  (('bed', 'catherin'), 6),
#  (('water', 'saw'), 6),
#  (('water', 'could'), 6),
#  (('water', 'dark'), 6),
#  (('move', 'could'), 6),
#  (('move', 'see'), 6),
#  (('went', 'mountain'), 6),
#  (('went', 'long'), 6),
#  (('went', 'thing'), 6),
#  (('went', 'start'), 6),
#  (('went', 'cross'), 6),
#  (('went', 'drink'), 6),
#  (('went', 'let'), 6),
#  (('went', 'field'), 6),
#  (('went', 'outsid'), 6),
#  (('went', 'close'), 6),
#  (('went', 'station'), 6),
#  (('went', 'stood'), 6),
#  (('went', 'bonello'), 6),
#  (('went', 'piani'), 6),
#  (('road', 'leav'), 6),
#  (('road', 'night'), 6),
#  (('road', 'behind'), 6),
#  (('road', 'wet'), 6),
#  (('road', 'front'), 6),
#  (('road', 'snow'), 6),
#  (('road', 'new'), 6),
#  (('road', 'take'), 6),
#  (('road', 'work'), 6),
#  (('road', 'toward'), 6),
#  (('road', 'far'), 6),
#  (('road', 'bridg'), 6),
#  (('leav', 'go'), 6),
#  (('tree', 'saw'), 6),
#  (('tree', 'could'), 6),
#  (('tree', 'rain'), 6),
#  (('saw', 'mountain'), 6),
#  (('saw', 'dark'), 6),
#  (('saw', 'window'), 6),
#  (('saw', 'car'), 6),
#  (('saw', 'back'), 6),
#  (('saw', 'town'), 6),
#  (('saw', 'lake'), 6),
#  (('along', 'came'), 6),
#  (('along', 'back'), 6),
#  (('along', 'said'), 6),
#  (('fall', 'rain'), 6),
#  (('mani', 'peopl'), 6),
#  (('beyond', 'could'), 6),
#  (('beyond', 'side'), 6),
#  (('mountain', 'back'), 6),
#  (('mountain', 'littl'), 6),
#  (('mountain', 'snow'), 6),
#  (('night', 'dark'), 6),
#  (('night', 'cold'), 6),
#  (('night', 'catherin'), 6),
#  (('could', 'wind'), 6),
#  (('could', 'walk'), 6),
#  (('could', 'hand'), 6),
#  (('could', 'tell'), 6),
#  (('could', 'open'), 6),
#  (('could', 'first'), 6),
#  (('could', 'tri'), 6),
#  (('could', 'line'), 6),
#  (('could', 'ahead'), 6),
#  (('could', 'eat'), 6),
#  (('could', 'light'), 6),
#  (('could', 'shore'), 6),
#  (('could', 'lake'), 6),
#  (('see', 'long'), 6),
#  (('see', 'face'), 6),
#  (('see', 'thing'), 6),
#  (('see', 'door'), 6),
#  (('see', 'open'), 6),
#  (('see', 'place'), 6),
#  (('see', 'still'), 6),
#  (('see', 'know'), 6),
#  (('see', 'r'), 6),
#  (('see', 'miss'), 6),
#  (('see', 'right'), 6),
#  (('see', 'man'), 6),
#  (('see', 'ahead'), 6),
#  (('see', 'light'), 6),
#  (('dark', 'window'), 6),
#  (('dark', 'wind'), 6),
#  (('dark', 'room'), 6),
#  (('dark', 'lake'), 6),
#  (('like', 'time'), 6),
#  (('like', 'realli'), 6),
#  (('like', 'talk'), 6),
#  (('like', 'know'), 6),
#  (('feel', 'come'), 6),
#  (('feel', 'good'), 6),
#  (('sometim', 'go'), 6),
#  (('heard', 'go'), 6),
#  (('window', 'go'), 6),
#  (('window', 'door'), 6),
#  (('window', 'outsid'), 6),
#  (('go', 'much'), 6),
#  (('go', 'day'), 6),
#  (('go', 'rain'), 6),
#  (('go', 'way'), 6),
#  (('go', 'town'), 6),
#  (('go', 'us'), 6),
#  (('go', 'wind'), 6),
#  (('go', 'priest'), 6),
#  (('go', 'give'), 6),
#  (('go', 'make'), 6),
#  (('go', 'better'), 6),
#  (('go', 'got'), 6),
#  (('go', 'tenente'), 6),
#  (('go', 'asked'), 6),
#  (('go', 'v'), 6),
#  (('go', 'mayb'), 6),
#  (('much', 'thank'), 6),
#  (('side', 'far'), 6),
#  (('side', 'hold'), 6),
#  (('pass', 'car'), 6),
#  (('long', 'stay'), 6),
#  (('anoth', 'one'), 6),
#  (('rain', 'wet'), 6),
#  (('rain', 'come'), 6),
#  (('rain', 'three'), 6),
#  (('came', 'snow'), 6),
#  (('came', 'sat'), 6),
#  (('came', 'walk'), 6),
#  (('came', 'room'), 6),
#  (('came', 'catherin'), 6),
#  (('two', 'face'), 6),
#  (('two', 'want'), 6),
#  (('two', 'took'), 6),
#  (('two', 'get'), 6),
#  (('two', 'sergeant'), 6),
#  (('car', 'start'), 6),
#  (('car', 'take'), 6),
#  (('car', 'stop'), 6),
#  (('car', 'got'), 6),
#  (('offic', 'one'), 6),
#  (('seat', 'back'), 6),
#  (('back', 'walk'), 6),
#  (('back', 'head'), 6),
#  (('back', 'first'), 6),
#  (('back', 'lay'), 6),
#  (('back', 'line'), 6),
#  (('back', 'turn'), 6),
#  (('back', 'catherin'), 6),
#  (('even', 'would'), 6),
#  (('one', 'littl'), 6),
#  (('one', 'priest'), 6),
#  (('one', 'tell'), 6),
#  (('one', 'close'), 6),
#  (('one', 'light'), 6),
#  (('way', 'away'), 6),
#  (('die', 'would'), 6),
#  (('away', 'littl'), 6),
#  (('away', 'took'), 6),
#  (('away', 'get'), 6),
#  (('away', 'put'), 6),
#  (('away', 'right'), 6),
#  (('town', 'walk'), 6),
#  (('fine', 'r'), 6),
#  (('us', 'come'), 6),
#  (('us', 'littl'), 6),
#  (('want', 'take'), 6),
#  (('come', 'time'), 6),
#  (('come', 'littl'), 6),
#  (('come', 'snow'), 6),
#  (('come', 'walk'), 6),
#  (('come', 'open'), 6),
#  (('come', 'yes'), 6),
#  (('time', 'get'), 6),
#  (('peopl', 'know'), 6),
#  (('girl', 'english'), 6),
#  (('wind', 'cold'), 6),
#  (('watch', 'turn'), 6),
#  (('sat', 'catherin'), 6),
#  (('glass', 'held'), 6),
#  (('glass', 'drank'), 6),
#  (('priest', 'shook'), 6),
#  (('walk', 'catherin'), 6),
#  (('walk', 'besid'), 6),
#  (('head', 'said'), 6),
#  (('wine', 'said'), 6),
#  (('might', 'thought'), 6),
#  (('noth', 'said'), 6),
#  (('said', 'never'), 6),
#  (('said', 'ever'), 6),
#  (('said', 'wish'), 6),
#  (('said', 'english'), 6),
#  (('said', 'call'), 6),
#  (('said', 'man'), 6),
#  (('said', 'attack'), 6),
#  (('said', 'matter'), 6),
#  (('said', 'cut'), 6),
#  (('said', 'hope'), 6),
#  (('love', 'yes'), 6),
#  (('love', 'oh'), 6),
#  (('ever', 'get'), 6),
#  (('get', 'place'), 6),
#  (('get', 'good'), 6),
#  (('get', 'outsid'), 6),
#  (('get', 'yes'), 6),
#  (('get', 'take'), 6),
#  (('get', 'better'), 6),
#  (('get', 'got'), 6),
#  (('get', 'line'), 6),
#  (('get', 'someth'), 6),
#  (('think', 'ought'), 6),
#  (('think', 'tri'), 6),
#  (('think', 'catherin'), 6),
#  (('door', 'put'), 6),
#  (('door', 'nurs'), 6),
#  (('open', 'room'), 6),
#  (('open', 'close'), 6),
#  (('let', 'place'), 6),
#  (('let', 'take'), 6),
#  (('place', 'find'), 6),
#  (('good', 'boy'), 6),
#  (('good', 'catherin'), 6),
#  (('outsid', 'hall'), 6),
#  (('outsid', 'light'), 6),
#  (('floor', 'put'), 6),
#  (('room', 'rinaldi'), 6),
#  (('room', 'dress'), 6),
#  (('know', 'stop'), 6),
#  (('know', 'darling'), 6),
#  (('sleep', 'piani'), 6),
#  (('station', 'light'), 6),
#  (('pleas', 'darling'), 6),
#  (('nurs', 'doctor'), 6),
#  (('asked', 'catherin'), 6),
#  (('live', 'mountain'), 5),
#  (('hous', 'look'), 5),
#  (('hous', 'road'), 5),
#  (('hous', 'tree'), 5),
#  (('hous', 'side'), 5),
#  (('hous', 'stone'), 5),
#  (('look', 'white'), 5),
#  (('look', 'driver'), 5),
#  (('look', 'sit'), 5),
#  (('look', 'cross'), 5),
#  (('look', 'away'), 5),
#  (('look', 'snow'), 5),
#  (('look', 'took'), 5),
#  (('look', 'still'), 5),
#  (('look', 'man'), 5),
#  (('look', 'sergeant'), 5),
#  (('look', 'nurs'), 5),
#  (('look', 'stand'), 5),
#  (('look', 'tired'), 5),
#  (('across', 'along'), 5),
#  (('across', 'cross'), 5),
#  (('across', 'come'), 5),
#  (('across', 'knew'), 5),
#  (('across', 'said'), 5),
#  (('across', 'line'), 5),
#  (('river', 'water'), 5),
#  (('river', 'tree'), 5),
#  (('river', 'see'), 5),
#  (('bed', 'night'), 5),
#  (('bed', 'dark'), 5),
#  (('bed', 'side'), 5),
#  (('bed', 'came'), 5),
#  (('bed', 'floor'), 5),
#  (('bed', 'put'), 5),
#  (('bed', 'sleep'), 5),
#  (('bed', 'lie'), 5),
#  (('bed', 'got'), 5),
#  (('white', 'went'), 5),
#  (('white', 'road'), 5),
#  (('white', 'saw'), 5),
#  (('water', 'along'), 5),
#  (('water', 'lake'), 5),
#  (('clear', 'road'), 5),
#  (('clear', 'night'), 5),
#  (('clear', 'rain'), 5),
#  (('clear', 'cold'), 5),
#  (('clear', 'station'), 5),
#  (('move', 'road'), 5),
#  (('move', 'along'), 5),
#  (('move', 'rain'), 5),
#  (('went', 'gone'), 5),
#  (('went', 'sit'), 5),
#  (('went', 'end'), 5),
#  (('went', 'wall'), 5),
#  (('went', 'town'), 5),
#  (('went', 'time'), 5),
#  (('went', 'hospit'), 5),
#  (('went', 'street'), 5),
#  (('went', 'watch'), 5),
#  (('went', 'glass'), 5),
#  (('went', 'bottl'), 5),
#  (('went', 'held'), 5),
#  (('went', 'make'), 5),
#  (('went', 'good'), 5),
#  (('went', 'stay'), 5),
#  (('went', 'villa'), 5),
#  (('went', 'call'), 5),
#  (('went', 'ferguson'), 5),
#  (('went', 'far'), 5),
#  (('went', 'hotel'), 5),
#  (('road', 'sometim'), 5),
#  (('road', 'men'), 5),
#  (('road', 'long'), 5),
#  (('road', 'littl'), 5),
#  (('road', 'took'), 5),
#  (('road', 'hard'), 5),
#  (('road', 'close'), 5),
#  (('tree', 'beyond'), 5),
#  (('tree', 'two'), 5),
#  (('saw', 'pass'), 5),
#  (('saw', 'littl'), 5),
#  (('saw', 'watch'), 5),
#  (('saw', 'stand'), 5),
#  (('saw', 'ahead'), 5),
#  (('along', 'mani'), 5),
#  (('along', 'beyond'), 5),
#  (('along', 'dark'), 5),
#  (('along', 'pull'), 5),
#  (('along', 'way'), 5),
#  (('along', 'town'), 5),
#  (('along', 'line'), 5),
#  (('along', 'stone'), 5),
#  (('along', 'besid'), 5),
#  (('along', 'row'), 5),
#  (('along', 'lake'), 5),
#  (('soldier', 'outsid'), 5),
#  (('mani', 'way'), 5),
#  (('beyond', 'see'), 5),
#  (('beyond', 'cross'), 5),
#  (('beyond', 'town'), 5),
#  (('mountain', 'go'), 5),
#  (('mountain', 'two'), 5),
#  (('mountain', 'come'), 5),
#  (('mountain', 'line'), 5),
#  (('mountain', 'high'), 5),
#  (('night', 'see'), 5),
#  (('night', 'window'), 5),
#  (('night', 'come'), 5),
#  (('night', 'priest'), 5),
#  (('night', 'get'), 5),
#  (('could', 'big'), 5),
#  (('could', 'face'), 5),
#  (('could', 'time'), 5),
#  (('could', 'knew'), 5),
#  (('could', 'make'), 5),
#  (('could', 'field'), 5),
#  (('could', 'room'), 5),
#  (('could', 'put'), 5),
#  (('could', 'anyth'), 5),
#  (('could', 'turn'), 5),
#  (('see', 'two'), 5),
#  (('see', 'fine'), 5),
#  (('see', 'time'), 5),
#  (('see', 'well'), 5),
#  (('see', 'priest'), 5),
#  (('see', 'ask'), 5),
#  (('see', 'take'), 5),
#  (('see', 'v'), 5),
#  (('see', 'hotel'), 5),
#  (('see', 'hope'), 5),
#  (('dark', 'back'), 5),
#  (('dark', 'cold'), 5),
#  (('like', 'much'), 5),
#  (('like', 'long'), 5),
#  (('like', 'back'), 5),
#  (('like', 'one'), 5),
#  (('like', 'nice'), 5),
#  (('like', 'priest'), 5),
#  (('like', 'never'), 5),
#  (('like', 'love'), 5),
#  (('like', 'place'), 5),
#  (('like', 'say'), 5),
#  (('like', 'alway'), 5),
#  (('like', 'someth'), 5),
#  (('feel', 'way'), 5),
#  (('heard', 'said'), 5),
#  (('window', 'came'), 5),
#  (('window', 'sat'), 5),
#  (('go', 'pass'), 5),
#  (('go', 'two'), 5),
#  (('go', 'everi'), 5),
#  (('go', 'cross'), 5),
#  (('go', 'ask'), 5),
#  (('go', 'took'), 5),
#  (('go', 'major'), 5),
#  ...]

# %%
#namely

new = {tuple(sorted(x)):y for x, y in count_s.items()}

# %%
#順位チェック again !
new2 = dict(sorted(new.items(), key=lambda x: x[1], reverse=True))
new2
# Out:
# {('go', 'said'): 102,
#  ('could', 'see'): 78,
#  ('catherin', 'said'): 71,
#  ('get', 'said'): 50,
#  ('back', 'went'): 48,
#  ('rinaldi', 'said'): 42,
#  ('right', 'said'): 40,
#  ('piani', 'said'): 40,
#  ('go', 'would'): 39,
#  ('said', 'want'): 39,
#  ('bonello', 'said'): 38,
#  ('along', 'road'): 37,
#  ('major', 'said'): 37,
#  ('said', 'would'): 37,
#  ('come', 'said'): 36,
#  ('good', 'said'): 36,
#  ('r', 'said'): 36,
#  ('go', 'want'): 35,
#  ('one', 'said'): 35,
#  ('like', 'said'): 33,
#  ('know', 'said'): 33,
#  ('back', 'go'): 32,
#  ('get', 'go'): 32,
#  ('back', 'come'): 31,
#  ('go', 'see'): 30,
#  ('said', 'yes'): 28,
#  ('look', 'window'): 26,
#  ('away', 'go'): 26,
#  ('said', 'think'): 26,
#  ('said', 'take'): 26,
#  ('darling', 'said'): 26,
#  ('back', 'came'): 25,
#  ('priest', 'said'): 25,
#  ('aymo', 'said'): 25,
#  ('door', 'went'): 24,
#  ('road', 'side'): 24,
#  ('said', 'see'): 24,
#  ('said', 'tenente'): 24,
#  ('could', 'said'): 23,
#  ('go', 'like'): 23,
#  ('like', 'would'): 23,
#  ('go', 'let'): 23,
#  ('go', 'went'): 22,
#  ('said', 'went'): 22,
#  ('room', 'went'): 22,
#  ('come', 'go'): 22,
#  ('back', 'said'): 22,
#  ('back', 'look'): 21,
#  ('road', 'went'): 21,
#  ('could', 'road'): 21,
#  ('could', 'go'): 21,
#  ('said', 'sleep'): 21,
#  ('could', 'look'): 20,
#  ('one', 'would'): 20,
#  ('come', 'would'): 20,
#  ('said', 'war'): 20,
#  ('door', 'open'): 20,
#  ('barkley', 'miss'): 20,
#  ('look', 'saw'): 19,
#  ('look', 'see'): 19,
#  ('like', 'look'): 19,
#  ('go', 'one'): 19,
#  ('long', 'time'): 19,
#  ('look', 'went'): 18,
#  ('look', 'road'): 18,
#  ('came', 'went'): 18,
#  ('see', 'want'): 18,
#  ('littl', 'said'): 18,
#  ('head', 'shook'): 18,
#  ('get', 'would'): 18,
#  ('look', 'said'): 17,
#  ('see', 'went'): 17,
#  ('much', 'said'): 17,
#  ('back', 'car'): 17,
#  ('come', 'get'): 17,
#  ('love', 'said'): 17,
#  ('better', 'said'): 17,
#  ('said', 'v'): 17,
#  ('doctor', 'said'): 17,
#  ('open', 'went'): 16,
#  ('go', 'road'): 16,
#  ('could', 'would'): 16,
#  ('see', 'would'): 16,
#  ('back', 'get'): 16,
#  ('everi', 'one'): 16,
#  ('fine', 'said'): 16,
#  ('said', 'us'): 16,
#  ('said', 'time'): 16,
#  ('must', 'said'): 16,
#  ('catherin', 'darling'): 16,
#  ('across', 'road'): 15,
#  ('catherin', 'went'): 15,
#  ('road', 'saw'): 15,
#  ('could', 'get'): 15,
#  ('go', 'think'): 15,
#  ('go', 'r'): 15,
#  ('go', 'sleep'): 15,
#  ('darling', 'go'): 15,
#  ('catherin', 'go'): 15,
#  ('long', 'way'): 15,
#  ('said', 'start'): 15,
#  ('hand', 'held'): 15,
#  ('hand', 'put'): 15,
#  ('said', 'tell'): 15,
#  ('said', 'talk'): 15,
#  ('along', 'went'): 14,
#  ('pass', 'road'): 14,
#  ('car', 'road'): 14,
#  ('along', 'could'): 14,
#  ('along', 'walk'): 14,
#  ('come', 'see'): 14,
#  ('go', 'right'): 14,
#  ('knew', 'would'): 14,
#  ('said', 'someth'): 14,
#  ('eat', 'said'): 14,
#  ('came', 'look'): 13,
#  ('look', 'watch'): 13,
#  ('look', 'room'): 13,
#  ('across', 'could'): 13,
#  ('river', 'road'): 13,
#  ('one', 'went'): 13,
#  ('come', 'went'): 13,
#  ('littl', 'went'): 13,
#  ('hall', 'went'): 13,
#  ('back', 'road'): 13,
#  ('road', 'start'): 13,
#  ('road', 'turn'): 13,
#  ('ahead', 'road'): 13,
#  ('come', 'saw'): 13,
#  ('along', 'go'): 13,
#  ('mountain', 'side'): 13,
#  ('back', 'could'): 13,
#  ('could', 'one'): 13,
#  ('came', 'see'): 13,
#  ('catherin', 'see'): 13,
#  ('go', 'must'): 13,
#  ('came', 'two'): 13,
#  ('car', 'two'): 13,
#  ('said', 'thing'): 13,
#  ('get', 'want'): 13,
#  ('said', 'well'): 13,
#  ('let', 'said'): 13,
#  ('place', 'said'): 13,
#  ('think', 'would'): 13,
#  ('dark', 'look'): 12,
#  ('go', 'look'): 12,
#  ('car', 'look'): 12,
#  ('look', 'sat'): 12,
#  ('glass', 'look'): 12,
#  ('bed', 'window'): 12,
#  ('bed', 'room'): 12,
#  ('bed', 'lay'): 12,
#  ('road', 'tree'): 12,
#  ('beyond', 'road'): 12,
#  ('mountain', 'road'): 12,
#  ('road', 'see'): 12,
#  ('came', 'saw'): 12,
#  ('one', 'saw'): 12,
#  ('along', 'see'): 12,
#  ('beyond', 'mountain'): 12,
#  ('could', 'rain'): 12,
#  ('come', 'could'): 12,
#  ('rain', 'see'): 12,
#  ('open', 'window'): 12,
#  ('car', 'go'): 12,
#  ('go', 'war'): 12,
#  ('go', 'know'): 12,
#  ('anoth', 'said'): 12,
#  ('came', 'one'): 12,
#  ('said', 'two'): 12,
#  ('back', 'would'): 12,
#  ('one', 'thing'): 12,
#  ('come', 'one'): 12,
#  ('away', 'said'): 12,
#  ('us', 'want'): 12,
#  ('give', 'said'): 12,
#  ('make', 'said'): 12,
#  ('first', 'said'): 12,
#  ('said', 'stay'): 12,
#  ('room', 'said'): 12,
#  ('nurs', 'said'): 12,
#  ('door', 'room'): 12,
#  ('bonello', 'piani'): 12,
#  ('look', 'two'): 11,
#  ('look', 'one'): 11,
#  ('across', 'river'): 11,
#  ('across', 'went'): 11,
#  ('cross', 'river'): 11,
#  ('back', 'bed'): 11,
#  ('bed', 'rinaldi'): 11,
#  ('could', 'went'): 11,
#  ('two', 'went'): 11,
#  ('went', 'would'): 11,
#  ('rinaldi', 'went'): 11,
#  ('sleep', 'went'): 11,
#  ('came', 'road'): 11,
#  ('field', 'road'): 11,
#  ('could', 'mountain'): 11,
#  ('mountain', 'see'): 11,
#  ('could', 'side'): 11,
#  ('car', 'could'): 11,
#  ('could', 'think'): 11,
#  ('catherin', 'could'): 11,
#  ('one', 'see'): 11,
#  ('go', 'walk'): 11,
#  ('go', 'place'): 11,
#  ('go', 'say'): 11,
#  ('go', 'stop'): 11,
#  ('one', 'side'): 11,
#  ('know', 'want'): 11,
#  ('catherin', 'time'): 11,
#  ('drink', 'said'): 11,
#  ('miss', 'said'): 11,
#  ('oh', 'said'): 11,
#  ('boy', 'said'): 11,
#  ('mayb', 'said'): 11,
#  ('paper', 'read'): 11,
#  ('thought', 'would'): 11,
#  ('anything', 'say'): 11,
#  ('bonello', 'tenente'): 11,
#  ('behind', 'look'): 10,
#  ('around', 'look'): 10,
#  ('catherin', 'look'): 10,
#  ('across', 'see'): 10,
#  ('along', 'river'): 10,
#  ('river', 'side'): 10,
#  ('bed', 'sat'): 10,
#  ('sat', 'went'): 10,
#  ('road', 'walk'): 10,
#  ('field', 'tree'): 10,
#  ('along', 'side'): 10,
#  ('lake', 'mountain'): 10,
#  ('could', 'feel'): 10,
#  ('could', 'window'): 10,
#  ('could', 'way'): 10,
#  ('could', 'place'): 10,
#  ('see', 'way'): 10,
#  ('dark', 'outsid'): 10,
#  ('feel', 'said'): 10,
#  ('room', 'window'): 10,
#  ('go', 'start'): 10,
#  ('go', 'yes'): 10,
#  ('go', 'take'): 10,
#  ('rain', 'stop'): 10,
#  ('back', 'sat'): 10,
#  ('back', 'take'): 10,
#  ('one', 'time'): 10,
#  ('knew', 'one'): 10,
#  ('know', 'one'): 10,
#  ('die', 'let'): 10,
#  ('want', 'would'): 10,
#  ('catherin', 'come'): 10,
#  ('war', 'would'): 10,
#  ('believ', 'said'): 10,
#  ('ought', 'said'): 10,
#  ('got', 'said'): 10,
#  ('said', 'thought'): 10,
#  ('find', 'said'): 10,
#  ('american', 'said'): 10,
#  ('get', 'say'): 10,
#  ('know', 'think'): 10,
#  ('take', 'would'): 10,
#  ('good', 'r'): 10,
#  ('darling', 'r'): 10,
#  ('got', 'v'): 10,
#  ('dress', 'station'): 10,
#  ('hous', 'went'): 9,
#  ('across', 'look'): 9,
#  ('look', 'us'): 9,
#  ('come', 'look'): 9,
#  ('look', 'priest'): 9,
#  ('look', 'rinaldi'): 9,
#  ('across', 'back'): 9,
#  ('mountain', 'river'): 9,
#  ('bank', 'river'): 9,
#  ('bed', 'went'): 9,
#  ('dark', 'went'): 9,
#  ('went', 'window'): 9,
#  ('side', 'went'): 9,
#  ('away', 'went'): 9,
#  ('got', 'went'): 9,
#  ('road', 'two'): 9,
#  ('cross', 'road'): 9,
#  ('line', 'road'): 9,
#  ('close', 'saw'): 9,
#  ('came', 'mountain'): 9,
#  ('mountain', 'town'): 9,
#  ('go', 'night'): 9,
#  ('night', 'said'): 9,
#  ('could', 'long'): 9,
#  ('came', 'could'): 9,
#  ('could', 'us'): 9,
#  ('could', 'take'): 9,
#  ('dark', 'see'): 9,
#  ('see', 'side'): 9,
#  ('car', 'see'): 9,
#  ('littl', 'see'): 9,
#  ('see', 'think'): 9,
#  ('feel', 'like'): 9,
#  ('go', 'time'): 9,
#  ('bonello', 'go'): 9,
#  ('big', 'one'): 9,
#  ('big', 'said'): 9,
#  ('away', 'long'): 9,
#  ('long', 'said'): 9,
#  ('came', 'door'): 9,
#  ('one', 'two'): 9,
#  ('back', 'one'): 9,
#  ('back', 'got'): 9,
#  ('hand', 'one'): 9,
#  ('littl', 'way'): 9,
#  ('said', 'way'): 9,
#  ('room', 'wall'): 9,
#  ('littl', 'town'): 9,
#  ('austrian', 'said'): 9,
#  ('think', 'want'): 9,
#  ('come', 'door'): 9,
#  ('arm', 'around'): 9,
#  ('drink', 'took'): 9,
#  ('hand', 'said'): 9,
#  ('captain', 'said'): 9,
#  ('italian', 'said'): 9,
#  ('said', 'say'): 9,
#  ('old', 'said'): 9,
#  ('said', 'tri'): 9,
#  ('said', 'stop'): 9,
#  ('alway', 'said'): 9,
#  ('bad', 'said'): 9,
#  ('get', 'know'): 9,
#  ('hall', 'room'): 9,
#  ('arm', 'put'): 9,
#  ('ferguson', 'miss'): 9,
#  ('darling', 'oh'): 9,
#  ('catherin', 'doctor'): 9,
#  ('like', 'live'): 8,
#  ('along', 'look'): 8,
#  ('ahead', 'look'): 8,
#  ('across', 'get'): 8,
#  ('across', 'field'): 8,
#  ('across', 'bridg'): 8,
#  ('bridg', 'river'): 8,
#  ('car', 'went'): 8,
#  ('want', 'went'): 8,
#  ('get', 'went'): 8,
#  ('think', 'went'): 8,
#  ('take', 'went'): 8,
#  ('toward', 'went'): 8,
#  ('turn', 'went'): 8,
#  ('lake', 'went'): 8,
#  ('mani', 'road'): 8,
#  ('road', 'way'): 8,
#  ('road', 'said'): 8,
#  ('road', 'would'): 8,
#  ('road', 'stop'): 8,
#  ('mountain', 'tree'): 8,
#  ('side', 'tree'): 8,
#  ('along', 'saw'): 8,
#  ('go', 'saw'): 8,
#  ('face', 'saw'): 8,
#  ('light', 'saw'): 8,
#  ('along', 'pass'): 8,
#  ('along', 'cross'): 8,
#  ('along', 'field'): 8,
#  ('mountain', 'shore'): 8,
#  ('night', 'one'): 8,
#  ('everi', 'night'): 8,
#  ('could', 'dark'): 8,
#  ('could', 'two'): 8,
#  ('could', 'littl'): 8,
#  ('could', 'stay'): 8,
#  ('close', 'could'): 8,
#  ('could', 'hear'): 8,
#  ('like', 'see'): 8,
#  ('even', 'see'): 8,
#  ('away', 'see'): 8,
#  ('see', 'us'): 8,
#  ('put', 'see'): 8,
#  ('see', 'shore'): 8,
#  ('dark', 'get'): 8,
#  ('dark', 'light'): 8,
#  ('come', 'window'): 8,
#  ('front', 'go'): 8,
#  ('die', 'go'): 8,
#  ('go', 'littl'): 8,
#  ('go', 'street'): 8,
#  ('go', 'knew'): 8,
#  ('door', 'go'): 8,
#  ('go', 'tri'): 8,
#  ('go', 'pleas'): 8,
#  ('go', 'someth'): 8,
#  ('eat', 'go'): 8,
#  ('go', 'piani'): 8,
#  ('much', 'think'): 8,
#  ('long', 'one'): 8,
#  ('came', 'rain'): 8,
#  ('came', 'car'): 8,
#  ('came', 'us'): 8,
#  ('came', 'time'): 8,
#  ('came', 'hand'): 8,
#  ('bottl', 'two'): 8,
#  ('aymo', 'car'): 8,
#  ('offic', 'said'): 8,
#  ('back', 'way'): 8,
#  ('back', 'us'): 8,
#  ('back', 'want'): 8,
#  ('back', 'hand'): 8,
#  ('aymo', 'back'): 8,
#  ('one', 'took'): 8,
#  ('get', 'one'): 8,
#  ('door', 'one'): 8,
#  ('start', 'would'): 8,
#  ('come', 'want'): 8,
#  ('want', 'war'): 8,
#  ('stay', 'want'): 8,
#  ('anyth', 'want'): 8,
#  ('come', 'outsid'): 8,
#  ('around', 'put'): 8,
#  ('girl', 'said'): 8,
#  ('lake', 'wind'): 8,
#  ('priest', 'rinaldi'): 8,
#  ('toward', 'walk'): 8,
#  ('drank', 'wine'): 8,
#  ('ask', 'said'): 8,
#  ('nothing', 'said'): 8,
#  ('anyth', 'said'): 8,
#  ('german', 'said'): 8,
#  ('ferguson', 'said'): 8,
#  ('baby', 'said'): 8,
#  ('catherin', 'love'): 8,
#  ('get', 'think'): 8,
#  ('catherin', 'get'): 8,
#  ('r', 'think'): 8,
#  ('door', 'hall'): 8,
#  ('wish', 'would'): 8,
#  ('would', 'yes'): 8,
#  ('stop', 'would'): 8,
#  ('bad', 'would'): 8,
#  ('catherin', 'would'): 8,
#  ('hope', 'would'): 8,
#  ('know', 'r'): 8,
#  ('anyth', 'know'): 8,
#  ('barkley', 'catherin'): 8,
#  ('hous', 'town'): 7,
#  ('big', 'look'): 7,
#  ('littl', 'look'): 7,
#  ('look', 'walk'): 7,
#  ('look', 'toward'): 7,
#  ('across', 'mountain'): 7,
#  ('across', 'side'): 7,
#  ('across', 'came'): 7,
#  ('beyond', 'river'): 7,
#  ('bed', 'go'): 7,
#  ('bed', 'one'): 7,
#  ('cold', 'water'): 7,
#  ('saw', 'went'): 7,
#  ('rain', 'went'): 7,
#  ('way', 'went'): 7,
#  ('left', 'went'): 7,
#  ('walk', 'went'): 7,
#  ('took', 'went'): 7,
#  ('put', 'went'): 7,
#  ('paper', 'went'): 7,
#  ('aymo', 'went'): 7,
#  ('come', 'road'): 7,
#  ('get', 'road'): 7,
#  ('road', 'stone'): 7,
#  ('besid', 'road'): 7,
#  ('leav', 'want'): 7,
#  ('leav', 'said'): 7,
#  ('along', 'tree'): 7,
#  ('see', 'tree'): 7,
#  ('along', 'mountain'): 7,
#  ('along', 'us'): 7,
#  ('along', 'bank'): 7,
#  ('beyond', 'littl'): 7,
#  ('night', 'rain'): 7,
#  ('away', 'could'): 7,
#  ('could', 'want'): 7,
#  ('could', 'snow'): 7,
#  ('could', 'keep'): 7,
#  ('could', 'thought'): 7,
#  ('could', 'far'): 7,
#  ('see', 'window'): 7,
#  ('back', 'see'): 7,
#  ('get', 'see'): 7,
#  ('let', 'see'): 7,
#  ('field', 'see'): 7,
#  ('got', 'see'): 7,
#  ('lake', 'see'): 7,
#  ('dark', 'rain'): 7,
#  ('like', 'two'): 7,
#  ('like', 'littl'): 7,
#  ('get', 'like'): 7,
#  ('like', 'think'): 7,
#  ('like', 'wish'): 7,
#  ('like', 'r'): 7,
#  ('baby', 'like'): 7,
#  ('light', 'window'): 7,
#  ('go', 'side'): 7,
#  ('go', 'men'): 7,
#  ('go', 'long'): 7,
#  ('go', 'thing'): 7,
#  ('go', 'well'): 7,
#  ('drink', 'go'): 7,
#  ('go', 'ought'): 7,
#  ('first', 'go'): 7,
#  ('go', 'stay'): 7,
#  ('go', 'outsid'): 7,
#  ('go', 'put'): 7,
#  ('cut', 'go'): 7,
#  ('doctor', 'go'): 7,
#  ('go', 'lake'): 7,
#  ('much', 'want'): 7,
#  ('get', 'much'): 7,
#  ('much', 'would'): 7,
#  ('much', 'talk'): 7,
#  ('lake', 'side'): 7,
#  ('men', 'two'): 7,
#  ('big', 'came'): 7,
#  ('long', 'row'): 7,
#  ('came', 'come'): 7,
#  ('came', 'said'): 7,
#  ('back', 'two'): 7,
#  ('girl', 'two'): 7,
#  ('car', 'said'): 7,
#  ('car', 'would'): 7,
#  ('back', 'put'): 7,
#  ('back', 'sleep'): 7,
#  ('one', 'us'): 7,
#  ('one', 'want'): 7,
#  ('held', 'one'): 7,
#  ('one', 'open'): 7,
#  ('good', 'one'): 7,
#  ('catherin', 'one'): 7,
#  ('said', 'sit'): 7,
#  ('think', 'way'): 7,
#  ('get', 'thing'): 7,
#  ('stone', 'wall'): 7,
#  ('away', 'want'): 7,
#  ('away', 'come'): 7,
#  ('away', 'take'): 7,
#  ('bonello', 'us'): 7,
#  ('darling', 'want'): 7,
#  ('catherin', 'want'): 7,
#  ('come', 'nurs'): 7,
#  ('come', 'hall'): 7,
#  ('good', 'time'): 7,
#  ('bad', 'time'): 7,
#  ('littl', 'sat'): 7,
#  ('catherin', 'littl'): 7,
#  ('hospit', 'said'): 7,
#  ('besid', 'sat'): 7,
#  ('drink', 'wine'): 7,
#  ('get', 'knew'): 7,
#  ('hall', 'walk'): 7,
#  ('italian', 'talk'): 7,
#  ('realli', 'said'): 7,
#  ('said', 'wait'): 7,
#  ('put', 'said'): 7,
#  ('barkley', 'said'): 7,
#  ('lie', 'said'): 7,
#  ('keep', 'said'): 7,
#  ('kill', 'said'): 7,
#  ('catherine', 'said'): 7,
#  ('said', 'thank'): 7,
#  ('god', 'said'): 7,
#  ('get', 'never'): 7,
#  ('never', 'would'): 7,
#  ('get', 'right'): 7,
#  ('get', 'tri'): 7,
#  ('tell', 'would'): 7,
#  ('door', 'outsid'): 7,
#  ('open', 'outsid'): 7,
#  ('make', 'would'): 7,
#  ('good', 'would'): 7,
#  ('put', 'would'): 7,
#  ('good', 'take'): 7,
#  ('catherin', 'say'): 7,
#  ('man', 'old'): 7,
#  ('doctor', 'room'): 7,
#  ('catherin', 'room'): 7,
#  ('catherin', 'r'): 7,
#  ('oh', 'yes'): 7,
#  ('close', 'shore'): 7,
#  ('asked', 'tenente'): 7,
#  ('asked', 'bonello'): 7,
#  ('asked', 'aymo'): 7,
#  ('catherin', 'turn'): 7,
#  ('lake', 'shore'): 7,
#  ('hous', 'live'): 6,
#  ('hous', 'mountain'): 6,
#  ('bed', 'look'): 6,
#  ('look', 'mountain'): 6,
#  ('look', 'side'): 6,
#  ('door', 'look'): 6,
#  ('look', 'open'): 6,
#  ('look', 'would'): 6,
#  ('floor', 'look'): 6,
#  ('look', 'put'): 6,
#  ('line', 'look'): 6,
#  ('light', 'look'): 6,
#  ('look', 'piani'): 6,
#  ('lake', 'look'): 6,
#  ('across', 'rain'): 6,
#  ('across', 'ahead'): 6,
#  ('across', 'lake'): 6,
#  ('could', 'river'): 6,
#  ('go', 'river'): 6,
#  ('river', 'two'): 6,
#  ('austrian', 'river'): 6,
#  ('bed', 'could'): 6,
#  ('bed', 'see'): 6,
#  ('bed', 'come'): 6,
#  ('bed', 'made'): 6,
#  ('bed', 'catherin'): 6,
#  ('saw', 'water'): 6,
#  ('could', 'water'): 6,
#  ('dark', 'water'): 6,
#  ('could', 'move'): 6,
#  ('move', 'see'): 6,
#  ('mountain', 'went'): 6,
#  ('long', 'went'): 6,
#  ('thing', 'went'): 6,
#  ('start', 'went'): 6,
#  ('cross', 'went'): 6,
#  ('drink', 'went'): 6,
#  ('let', 'went'): 6,
#  ('field', 'went'): 6,
#  ('outsid', 'went'): 6,
#  ('close', 'went'): 6,
#  ('station', 'went'): 6,
#  ('stood', 'went'): 6,
#  ('bonello', 'went'): 6,
#  ('piani', 'went'): 6,
#  ('leav', 'road'): 6,
#  ('night', 'road'): 6,
#  ('behind', 'road'): 6,
#  ('road', 'wet'): 6,
#  ('front', 'road'): 6,
#  ('road', 'snow'): 6,
#  ('new', 'road'): 6,
#  ('road', 'take'): 6,
#  ('road', 'work'): 6,
#  ('road', 'toward'): 6,
#  ('far', 'road'): 6,
#  ('bridg', 'road'): 6,
#  ('go', 'leav'): 6,
#  ('saw', 'tree'): 6,
#  ('could', 'tree'): 6,
#  ('rain', 'tree'): 6,
#  ('mountain', 'saw'): 6,
#  ('dark', 'saw'): 6,
#  ('saw', 'window'): 6,
#  ('car', 'saw'): 6,
#  ('back', 'saw'): 6,
#  ('saw', 'town'): 6,
#  ('lake', 'saw'): 6,
#  ('along', 'came'): 6,
#  ('along', 'back'): 6,
#  ('along', 'said'): 6,
#  ('fall', 'rain'): 6,
#  ('mani', 'peopl'): 6,
#  ('beyond', 'could'): 6,
#  ('beyond', 'side'): 6,
#  ('back', 'mountain'): 6,
#  ('littl', 'mountain'): 6,
#  ('mountain', 'snow'): 6,
#  ('dark', 'night'): 6,
#  ('cold', 'night'): 6,
#  ('catherin', 'night'): 6,
#  ('could', 'wind'): 6,
#  ('could', 'walk'): 6,
#  ('could', 'hand'): 6,
#  ('could', 'tell'): 6,
#  ('could', 'open'): 6,
#  ('could', 'first'): 6,
#  ('could', 'tri'): 6,
#  ('could', 'line'): 6,
#  ('ahead', 'could'): 6,
#  ('could', 'eat'): 6,
#  ('could', 'light'): 6,
#  ('could', 'shore'): 6,
#  ('could', 'lake'): 6,
#  ('long', 'see'): 6,
#  ('face', 'see'): 6,
#  ('see', 'thing'): 6,
#  ('door', 'see'): 6,
#  ('open', 'see'): 6,
#  ('place', 'see'): 6,
#  ('see', 'still'): 6,
#  ('know', 'see'): 6,
#  ('r', 'see'): 6,
#  ('miss', 'see'): 6,
#  ('right', 'see'): 6,
#  ('man', 'see'): 6,
#  ('ahead', 'see'): 6,
#  ('light', 'see'): 6,
#  ('dark', 'window'): 6,
#  ('dark', 'wind'): 6,
#  ('dark', 'room'): 6,
#  ('dark', 'lake'): 6,
#  ('like', 'time'): 6,
#  ('like', 'realli'): 6,
#  ('like', 'talk'): 6,
#  ('know', 'like'): 6,
#  ('come', 'feel'): 6,
#  ('feel', 'good'): 6,
#  ('go', 'sometim'): 6,
#  ('go', 'heard'): 6,
#  ('go', 'window'): 6,
#  ('door', 'window'): 6,
#  ('outsid', 'window'): 6,
#  ('go', 'much'): 6,
#  ('day', 'go'): 6,
#  ('go', 'rain'): 6,
#  ('go', 'way'): 6,
#  ('go', 'town'): 6,
#  ('go', 'us'): 6,
#  ('go', 'wind'): 6,
#  ('go', 'priest'): 6,
#  ('give', 'go'): 6,
#  ('go', 'make'): 6,
#  ('better', 'go'): 6,
#  ('go', 'got'): 6,
#  ('go', 'tenente'): 6,
#  ('asked', 'go'): 6,
#  ('go', 'v'): 6,
#  ('go', 'mayb'): 6,
#  ('much', 'thank'): 6,
#  ('far', 'side'): 6,
#  ('hold', 'side'): 6,
#  ('car', 'pass'): 6,
#  ('long', 'stay'): 6,
#  ('anoth', 'one'): 6,
#  ('rain', 'wet'): 6,
#  ('come', 'rain'): 6,
#  ('rain', 'three'): 6,
#  ('came', 'snow'): 6,
#  ('came', 'sat'): 6,
#  ('came', 'walk'): 6,
#  ('came', 'room'): 6,
#  ('came', 'catherin'): 6,
#  ('face', 'two'): 6,
#  ('two', 'want'): 6,
#  ('took', 'two'): 6,
#  ('get', 'two'): 6,
#  ('sergeant', 'two'): 6,
#  ('car', 'start'): 6,
#  ('car', 'take'): 6,
#  ('car', 'stop'): 6,
#  ('car', 'got'): 6,
#  ('offic', 'one'): 6,
#  ('back', 'seat'): 6,
#  ('back', 'walk'): 6,
#  ('back', 'head'): 6,
#  ('back', 'first'): 6,
#  ('back', 'lay'): 6,
#  ('back', 'line'): 6,
#  ('back', 'turn'): 6,
#  ('back', 'catherin'): 6,
#  ('even', 'would'): 6,
#  ('littl', 'one'): 6,
#  ('one', 'priest'): 6,
#  ('one', 'tell'): 6,
#  ('close', 'one'): 6,
#  ('light', 'one'): 6,
#  ('away', 'way'): 6,
#  ('die', 'would'): 6,
#  ('away', 'littl'): 6,
#  ('away', 'took'): 6,
#  ('away', 'get'): 6,
#  ('away', 'put'): 6,
#  ('away', 'right'): 6,
#  ('town', 'walk'): 6,
#  ('fine', 'r'): 6,
#  ('come', 'us'): 6,
#  ('littl', 'us'): 6,
#  ('take', 'want'): 6,
#  ('come', 'time'): 6,
#  ('come', 'littl'): 6,
#  ('come', 'snow'): 6,
#  ('come', 'walk'): 6,
#  ('come', 'open'): 6,
#  ('come', 'yes'): 6,
#  ('get', 'time'): 6,
#  ('know', 'peopl'): 6,
#  ('english', 'girl'): 6,
#  ('cold', 'wind'): 6,
#  ('turn', 'watch'): 6,
#  ('catherin', 'sat'): 6,
#  ('glass', 'held'): 6,
#  ('drank', 'glass'): 6,
#  ('priest', 'shook'): 6,
#  ('catherin', 'walk'): 6,
#  ('besid', 'walk'): 6,
#  ('head', 'said'): 6,
#  ('said', 'wine'): 6,
#  ('might', 'thought'): 6,
#  ('noth', 'said'): 6,
#  ('never', 'said'): 6,
#  ('ever', 'said'): 6,
#  ('said', 'wish'): 6,
#  ('english', 'said'): 6,
#  ('call', 'said'): 6,
#  ('man', 'said'): 6,
#  ('attack', 'said'): 6,
#  ('matter', 'said'): 6,
#  ('cut', 'said'): 6,
#  ('hope', 'said'): 6,
#  ('love', 'yes'): 6,
#  ('love', 'oh'): 6,
#  ('ever', 'get'): 6,
#  ('get', 'place'): 6,
#  ('get', 'good'): 6,
#  ('get', 'outsid'): 6,
#  ('get', 'yes'): 6,
#  ('get', 'take'): 6,
#  ('better', 'get'): 6,
#  ('get', 'got'): 6,
#  ('get', 'line'): 6,
#  ('get', 'someth'): 6,
#  ('ought', 'think'): 6,
#  ('think', 'tri'): 6,
#  ('catherin', 'think'): 6,
#  ('door', 'put'): 6,
#  ('door', 'nurs'): 6,
#  ('open', 'room'): 6,
#  ('close', 'open'): 6,
#  ('let', 'place'): 6,
#  ('let', 'take'): 6,
#  ('find', 'place'): 6,
#  ('boy', 'good'): 6,
#  ('catherin', 'good'): 6,
#  ('hall', 'outsid'): 6,
#  ('light', 'outsid'): 6,
#  ('floor', 'put'): 6,
#  ('rinaldi', 'room'): 6,
#  ('dress', 'room'): 6,
#  ('know', 'stop'): 6,
#  ('darling', 'know'): 6,
#  ('piani', 'sleep'): 6,
#  ('light', 'station'): 6,
#  ('darling', 'pleas'): 6,
#  ('doctor', 'nurs'): 6,
#  ('asked', 'catherin'): 6,
#  ('live', 'mountain'): 5,
#  ('hous', 'look'): 5,
#  ('hous', 'road'): 5,
#  ('hous', 'tree'): 5,
#  ('hous', 'side'): 5,
#  ('hous', 'stone'): 5,
#  ('look', 'white'): 5,
#  ('driver', 'look'): 5,
#  ('look', 'sit'): 5,
#  ('cross', 'look'): 5,
#  ('away', 'look'): 5,
#  ('look', 'snow'): 5,
#  ('look', 'took'): 5,
#  ('look', 'still'): 5,
#  ('look', 'man'): 5,
#  ('look', 'sergeant'): 5,
#  ('look', 'nurs'): 5,
#  ('look', 'stand'): 5,
#  ('look', 'tired'): 5,
#  ('across', 'along'): 5,
#  ('across', 'cross'): 5,
#  ('across', 'come'): 5,
#  ('across', 'knew'): 5,
#  ('across', 'said'): 5,
#  ('across', 'line'): 5,
#  ('river', 'water'): 5,
#  ('river', 'tree'): 5,
#  ('river', 'see'): 5,
#  ('bed', 'night'): 5,
#  ('bed', 'dark'): 5,
#  ('bed', 'side'): 5,
#  ('bed', 'came'): 5,
#  ('bed', 'floor'): 5,
#  ('bed', 'put'): 5,
#  ('bed', 'sleep'): 5,
#  ('bed', 'lie'): 5,
#  ('bed', 'got'): 5,
#  ('went', 'white'): 5,
#  ('road', 'white'): 5,
#  ('saw', 'white'): 5,
#  ('along', 'water'): 5,
#  ('lake', 'water'): 5,
#  ('clear', 'road'): 5,
#  ('clear', 'night'): 5,
#  ('clear', 'rain'): 5,
#  ('clear', 'cold'): 5,
#  ('clear', 'station'): 5,
#  ('move', 'road'): 5,
#  ('along', 'move'): 5,
#  ('move', 'rain'): 5,
#  ('gone', 'went'): 5,
#  ('sit', 'went'): 5,
#  ('end', 'went'): 5,
#  ('wall', 'went'): 5,
#  ('town', 'went'): 5,
#  ('time', 'went'): 5,
#  ('hospit', 'went'): 5,
#  ('street', 'went'): 5,
#  ('watch', 'went'): 5,
#  ('glass', 'went'): 5,
#  ('bottl', 'went'): 5,
#  ('held', 'went'): 5,
#  ('make', 'went'): 5,
#  ('good', 'went'): 5,
#  ('stay', 'went'): 5,
#  ('villa', 'went'): 5,
#  ('call', 'went'): 5,
#  ('ferguson', 'went'): 5,
#  ('far', 'went'): 5,
#  ('hotel', 'went'): 5,
#  ('road', 'sometim'): 5,
#  ('men', 'road'): 5,
#  ('long', 'road'): 5,
#  ('littl', 'road'): 5,
#  ('road', 'took'): 5,
#  ('hard', 'road'): 5,
#  ('close', 'road'): 5,
#  ('beyond', 'tree'): 5,
#  ('tree', 'two'): 5,
#  ('pass', 'saw'): 5,
#  ('littl', 'saw'): 5,
#  ('saw', 'watch'): 5,
#  ('saw', 'stand'): 5,
#  ('ahead', 'saw'): 5,
#  ('along', 'mani'): 5,
#  ('along', 'beyond'): 5,
#  ('along', 'dark'): 5,
#  ('along', 'pull'): 5,
#  ('along', 'way'): 5,
#  ('along', 'town'): 5,
#  ('along', 'line'): 5,
#  ('along', 'stone'): 5,
#  ('along', 'besid'): 5,
#  ('along', 'row'): 5,
#  ('along', 'lake'): 5,
#  ('outsid', 'soldier'): 5,
#  ('mani', 'way'): 5,
#  ('beyond', 'see'): 5,
#  ('beyond', 'cross'): 5,
#  ('beyond', 'town'): 5,
#  ('go', 'mountain'): 5,
#  ('mountain', 'two'): 5,
#  ('come', 'mountain'): 5,
#  ('line', 'mountain'): 5,
#  ('high', 'mountain'): 5,
#  ('night', 'see'): 5,
#  ('night', 'window'): 5,
#  ('come', 'night'): 5,
#  ('night', 'priest'): 5,
#  ('get', 'night'): 5,
#  ('big', 'could'): 5,
#  ('could', 'face'): 5,
#  ('could', 'time'): 5,
#  ('could', 'knew'): 5,
#  ('could', 'make'): 5,
#  ('could', 'field'): 5,
#  ('could', 'room'): 5,
#  ('could', 'put'): 5,
#  ('anyth', 'could'): 5,
#  ('could', 'turn'): 5,
#  ('see', 'two'): 5,
#  ('fine', 'see'): 5,
#  ('see', 'time'): 5,
#  ('see', 'well'): 5,
#  ('priest', 'see'): 5,
#  ('ask', 'see'): 5,
#  ('see', 'take'): 5,
#  ('see', 'v'): 5,
#  ('hotel', 'see'): 5,
#  ('hope', 'see'): 5,
#  ('back', 'dark'): 5,
#  ('cold', 'dark'): 5,
#  ('like', 'much'): 5,
#  ('like', 'long'): 5,
#  ('back', 'like'): 5,
#  ('like', 'one'): 5,
#  ('like', 'nice'): 5,
#  ('like', 'priest'): 5,
#  ('like', 'never'): 5,
#  ('like', 'love'): 5,
#  ('like', 'place'): 5,
#  ('like', 'say'): 5,
#  ('alway', 'like'): 5,
#  ('like', 'someth'): 5,
#  ('feel', 'way'): 5,
#  ('heard', 'said'): 5,
#  ('came', 'window'): 5,
#  ('sat', 'window'): 5,
#  ('go', 'pass'): 5,
#  ('go', 'two'): 5,
#  ('everi', 'go'): 5,
#  ('cross', 'go'): 5,
#  ('ask', 'go'): 5,
#  ('go', 'took'): 5,
#  ('go', 'major'): 5,
#  ...}

# %%
new3 = dict((k, v) for k, v in new2.items() if v >= 2)
new3
# Out:
# {('go', 'said'): 102,
#  ('could', 'see'): 78,
#  ('catherin', 'said'): 71,
#  ('get', 'said'): 50,
#  ('back', 'went'): 48,
#  ('rinaldi', 'said'): 42,
#  ('right', 'said'): 40,
#  ('piani', 'said'): 40,
#  ('go', 'would'): 39,
#  ('said', 'want'): 39,
#  ('bonello', 'said'): 38,
#  ('along', 'road'): 37,
#  ('major', 'said'): 37,
#  ('said', 'would'): 37,
#  ('come', 'said'): 36,
#  ('good', 'said'): 36,
#  ('r', 'said'): 36,
#  ('go', 'want'): 35,
#  ('one', 'said'): 35,
#  ('like', 'said'): 33,
#  ('know', 'said'): 33,
#  ('back', 'go'): 32,
#  ('get', 'go'): 32,
#  ('back', 'come'): 31,
#  ('go', 'see'): 30,
#  ('said', 'yes'): 28,
#  ('look', 'window'): 26,
#  ('away', 'go'): 26,
#  ('said', 'think'): 26,
#  ('said', 'take'): 26,
#  ('darling', 'said'): 26,
#  ('back', 'came'): 25,
#  ('priest', 'said'): 25,
#  ('aymo', 'said'): 25,
#  ('door', 'went'): 24,
#  ('road', 'side'): 24,
#  ('said', 'see'): 24,
#  ('said', 'tenente'): 24,
#  ('could', 'said'): 23,
#  ('go', 'like'): 23,
#  ('like', 'would'): 23,
#  ('go', 'let'): 23,
#  ('go', 'went'): 22,
#  ('said', 'went'): 22,
#  ('room', 'went'): 22,
#  ('come', 'go'): 22,
#  ('back', 'said'): 22,
#  ('back', 'look'): 21,
#  ('road', 'went'): 21,
#  ('could', 'road'): 21,
#  ('could', 'go'): 21,
#  ('said', 'sleep'): 21,
#  ('could', 'look'): 20,
#  ('one', 'would'): 20,
#  ('come', 'would'): 20,
#  ('said', 'war'): 20,
#  ('door', 'open'): 20,
#  ('barkley', 'miss'): 20,
#  ('look', 'saw'): 19,
#  ('look', 'see'): 19,
#  ('like', 'look'): 19,
#  ('go', 'one'): 19,
#  ('long', 'time'): 19,
#  ('look', 'went'): 18,
#  ('look', 'road'): 18,
#  ('came', 'went'): 18,
#  ('see', 'want'): 18,
#  ('littl', 'said'): 18,
#  ('head', 'shook'): 18,
#  ('get', 'would'): 18,
#  ('look', 'said'): 17,
#  ('see', 'went'): 17,
#  ('much', 'said'): 17,
#  ('back', 'car'): 17,
#  ('come', 'get'): 17,
#  ('love', 'said'): 17,
#  ('better', 'said'): 17,
#  ('said', 'v'): 17,
#  ('doctor', 'said'): 17,
#  ('open', 'went'): 16,
#  ('go', 'road'): 16,
#  ('could', 'would'): 16,
#  ('see', 'would'): 16,
#  ('back', 'get'): 16,
#  ('everi', 'one'): 16,
#  ('fine', 'said'): 16,
#  ('said', 'us'): 16,
#  ('said', 'time'): 16,
#  ('must', 'said'): 16,
#  ('catherin', 'darling'): 16,
#  ('across', 'road'): 15,
#  ('catherin', 'went'): 15,
#  ('road', 'saw'): 15,
#  ('could', 'get'): 15,
#  ('go', 'think'): 15,
#  ('go', 'r'): 15,
#  ('go', 'sleep'): 15,
#  ('darling', 'go'): 15,
#  ('catherin', 'go'): 15,
#  ('long', 'way'): 15,
#  ('said', 'start'): 15,
#  ('hand', 'held'): 15,
#  ('hand', 'put'): 15,
#  ('said', 'tell'): 15,
#  ('said', 'talk'): 15,
#  ('along', 'went'): 14,
#  ('pass', 'road'): 14,
#  ('car', 'road'): 14,
#  ('along', 'could'): 14,
#  ('along', 'walk'): 14,
#  ('come', 'see'): 14,
#  ('go', 'right'): 14,
#  ('knew', 'would'): 14,
#  ('said', 'someth'): 14,
#  ('eat', 'said'): 14,
#  ('came', 'look'): 13,
#  ('look', 'watch'): 13,
#  ('look', 'room'): 13,
#  ('across', 'could'): 13,
#  ('river', 'road'): 13,
#  ('one', 'went'): 13,
#  ('come', 'went'): 13,
#  ('littl', 'went'): 13,
#  ('hall', 'went'): 13,
#  ('back', 'road'): 13,
#  ('road', 'start'): 13,
#  ('road', 'turn'): 13,
#  ('ahead', 'road'): 13,
#  ('come', 'saw'): 13,
#  ('along', 'go'): 13,
#  ('mountain', 'side'): 13,
#  ('back', 'could'): 13,
#  ('could', 'one'): 13,
#  ('came', 'see'): 13,
#  ('catherin', 'see'): 13,
#  ('go', 'must'): 13,
#  ('came', 'two'): 13,
#  ('car', 'two'): 13,
#  ('said', 'thing'): 13,
#  ('get', 'want'): 13,
#  ('said', 'well'): 13,
#  ('let', 'said'): 13,
#  ('place', 'said'): 13,
#  ('think', 'would'): 13,
#  ('dark', 'look'): 12,
#  ('go', 'look'): 12,
#  ('car', 'look'): 12,
#  ('look', 'sat'): 12,
#  ('glass', 'look'): 12,
#  ('bed', 'window'): 12,
#  ('bed', 'room'): 12,
#  ('bed', 'lay'): 12,
#  ('road', 'tree'): 12,
#  ('beyond', 'road'): 12,
#  ('mountain', 'road'): 12,
#  ('road', 'see'): 12,
#  ('came', 'saw'): 12,
#  ('one', 'saw'): 12,
#  ('along', 'see'): 12,
#  ('beyond', 'mountain'): 12,
#  ('could', 'rain'): 12,
#  ('come', 'could'): 12,
#  ('rain', 'see'): 12,
#  ('open', 'window'): 12,
#  ('car', 'go'): 12,
#  ('go', 'war'): 12,
#  ('go', 'know'): 12,
#  ('anoth', 'said'): 12,
#  ('came', 'one'): 12,
#  ('said', 'two'): 12,
#  ('back', 'would'): 12,
#  ('one', 'thing'): 12,
#  ('come', 'one'): 12,
#  ('away', 'said'): 12,
#  ('us', 'want'): 12,
#  ('give', 'said'): 12,
#  ('make', 'said'): 12,
#  ('first', 'said'): 12,
#  ('said', 'stay'): 12,
#  ('room', 'said'): 12,
#  ('nurs', 'said'): 12,
#  ('door', 'room'): 12,
#  ('bonello', 'piani'): 12,
#  ('look', 'two'): 11,
#  ('look', 'one'): 11,
#  ('across', 'river'): 11,
#  ('across', 'went'): 11,
#  ('cross', 'river'): 11,
#  ('back', 'bed'): 11,
#  ('bed', 'rinaldi'): 11,
#  ('could', 'went'): 11,
#  ('two', 'went'): 11,
#  ('went', 'would'): 11,
#  ('rinaldi', 'went'): 11,
#  ('sleep', 'went'): 11,
#  ('came', 'road'): 11,
#  ('field', 'road'): 11,
#  ('could', 'mountain'): 11,
#  ('mountain', 'see'): 11,
#  ('could', 'side'): 11,
#  ('car', 'could'): 11,
#  ('could', 'think'): 11,
#  ('catherin', 'could'): 11,
#  ('one', 'see'): 11,
#  ('go', 'walk'): 11,
#  ('go', 'place'): 11,
#  ('go', 'say'): 11,
#  ('go', 'stop'): 11,
#  ('one', 'side'): 11,
#  ('know', 'want'): 11,
#  ('catherin', 'time'): 11,
#  ('drink', 'said'): 11,
#  ('miss', 'said'): 11,
#  ('oh', 'said'): 11,
#  ('boy', 'said'): 11,
#  ('mayb', 'said'): 11,
#  ('paper', 'read'): 11,
#  ('thought', 'would'): 11,
#  ('anything', 'say'): 11,
#  ('bonello', 'tenente'): 11,
#  ('behind', 'look'): 10,
#  ('around', 'look'): 10,
#  ('catherin', 'look'): 10,
#  ('across', 'see'): 10,
#  ('along', 'river'): 10,
#  ('river', 'side'): 10,
#  ('bed', 'sat'): 10,
#  ('sat', 'went'): 10,
#  ('road', 'walk'): 10,
#  ('field', 'tree'): 10,
#  ('along', 'side'): 10,
#  ('lake', 'mountain'): 10,
#  ('could', 'feel'): 10,
#  ('could', 'window'): 10,
#  ('could', 'way'): 10,
#  ('could', 'place'): 10,
#  ('see', 'way'): 10,
#  ('dark', 'outsid'): 10,
#  ('feel', 'said'): 10,
#  ('room', 'window'): 10,
#  ('go', 'start'): 10,
#  ('go', 'yes'): 10,
#  ('go', 'take'): 10,
#  ('rain', 'stop'): 10,
#  ('back', 'sat'): 10,
#  ('back', 'take'): 10,
#  ('one', 'time'): 10,
#  ('knew', 'one'): 10,
#  ('know', 'one'): 10,
#  ('die', 'let'): 10,
#  ('want', 'would'): 10,
#  ('catherin', 'come'): 10,
#  ('war', 'would'): 10,
#  ('believ', 'said'): 10,
#  ('ought', 'said'): 10,
#  ('got', 'said'): 10,
#  ('said', 'thought'): 10,
#  ('find', 'said'): 10,
#  ('american', 'said'): 10,
#  ('get', 'say'): 10,
#  ('know', 'think'): 10,
#  ('take', 'would'): 10,
#  ('good', 'r'): 10,
#  ('darling', 'r'): 10,
#  ('got', 'v'): 10,
#  ('dress', 'station'): 10,
#  ('hous', 'went'): 9,
#  ('across', 'look'): 9,
#  ('look', 'us'): 9,
#  ('come', 'look'): 9,
#  ('look', 'priest'): 9,
#  ('look', 'rinaldi'): 9,
#  ('across', 'back'): 9,
#  ('mountain', 'river'): 9,
#  ('bank', 'river'): 9,
#  ('bed', 'went'): 9,
#  ('dark', 'went'): 9,
#  ('went', 'window'): 9,
#  ('side', 'went'): 9,
#  ('away', 'went'): 9,
#  ('got', 'went'): 9,
#  ('road', 'two'): 9,
#  ('cross', 'road'): 9,
#  ('line', 'road'): 9,
#  ('close', 'saw'): 9,
#  ('came', 'mountain'): 9,
#  ('mountain', 'town'): 9,
#  ('go', 'night'): 9,
#  ('night', 'said'): 9,
#  ('could', 'long'): 9,
#  ('came', 'could'): 9,
#  ('could', 'us'): 9,
#  ('could', 'take'): 9,
#  ('dark', 'see'): 9,
#  ('see', 'side'): 9,
#  ('car', 'see'): 9,
#  ('littl', 'see'): 9,
#  ('see', 'think'): 9,
#  ('feel', 'like'): 9,
#  ('go', 'time'): 9,
#  ('bonello', 'go'): 9,
#  ('big', 'one'): 9,
#  ('big', 'said'): 9,
#  ('away', 'long'): 9,
#  ('long', 'said'): 9,
#  ('came', 'door'): 9,
#  ('one', 'two'): 9,
#  ('back', 'one'): 9,
#  ('back', 'got'): 9,
#  ('hand', 'one'): 9,
#  ('littl', 'way'): 9,
#  ('said', 'way'): 9,
#  ('room', 'wall'): 9,
#  ('littl', 'town'): 9,
#  ('austrian', 'said'): 9,
#  ('think', 'want'): 9,
#  ('come', 'door'): 9,
#  ('arm', 'around'): 9,
#  ('drink', 'took'): 9,
#  ('hand', 'said'): 9,
#  ('captain', 'said'): 9,
#  ('italian', 'said'): 9,
#  ('said', 'say'): 9,
#  ('old', 'said'): 9,
#  ('said', 'tri'): 9,
#  ('said', 'stop'): 9,
#  ('alway', 'said'): 9,
#  ('bad', 'said'): 9,
#  ('get', 'know'): 9,
#  ('hall', 'room'): 9,
#  ('arm', 'put'): 9,
#  ('ferguson', 'miss'): 9,
#  ('darling', 'oh'): 9,
#  ('catherin', 'doctor'): 9,
#  ('like', 'live'): 8,
#  ('along', 'look'): 8,
#  ('ahead', 'look'): 8,
#  ('across', 'get'): 8,
#  ('across', 'field'): 8,
#  ('across', 'bridg'): 8,
#  ('bridg', 'river'): 8,
#  ('car', 'went'): 8,
#  ('want', 'went'): 8,
#  ('get', 'went'): 8,
#  ('think', 'went'): 8,
#  ('take', 'went'): 8,
#  ('toward', 'went'): 8,
#  ('turn', 'went'): 8,
#  ('lake', 'went'): 8,
#  ('mani', 'road'): 8,
#  ('road', 'way'): 8,
#  ('road', 'said'): 8,
#  ('road', 'would'): 8,
#  ('road', 'stop'): 8,
#  ('mountain', 'tree'): 8,
#  ('side', 'tree'): 8,
#  ('along', 'saw'): 8,
#  ('go', 'saw'): 8,
#  ('face', 'saw'): 8,
#  ('light', 'saw'): 8,
#  ('along', 'pass'): 8,
#  ('along', 'cross'): 8,
#  ('along', 'field'): 8,
#  ('mountain', 'shore'): 8,
#  ('night', 'one'): 8,
#  ('everi', 'night'): 8,
#  ('could', 'dark'): 8,
#  ('could', 'two'): 8,
#  ('could', 'littl'): 8,
#  ('could', 'stay'): 8,
#  ('close', 'could'): 8,
#  ('could', 'hear'): 8,
#  ('like', 'see'): 8,
#  ('even', 'see'): 8,
#  ('away', 'see'): 8,
#  ('see', 'us'): 8,
#  ('put', 'see'): 8,
#  ('see', 'shore'): 8,
#  ('dark', 'get'): 8,
#  ('dark', 'light'): 8,
#  ('come', 'window'): 8,
#  ('front', 'go'): 8,
#  ('die', 'go'): 8,
#  ('go', 'littl'): 8,
#  ('go', 'street'): 8,
#  ('go', 'knew'): 8,
#  ('door', 'go'): 8,
#  ('go', 'tri'): 8,
#  ('go', 'pleas'): 8,
#  ('go', 'someth'): 8,
#  ('eat', 'go'): 8,
#  ('go', 'piani'): 8,
#  ('much', 'think'): 8,
#  ('long', 'one'): 8,
#  ('came', 'rain'): 8,
#  ('came', 'car'): 8,
#  ('came', 'us'): 8,
#  ('came', 'time'): 8,
#  ('came', 'hand'): 8,
#  ('bottl', 'two'): 8,
#  ('aymo', 'car'): 8,
#  ('offic', 'said'): 8,
#  ('back', 'way'): 8,
#  ('back', 'us'): 8,
#  ('back', 'want'): 8,
#  ('back', 'hand'): 8,
#  ('aymo', 'back'): 8,
#  ('one', 'took'): 8,
#  ('get', 'one'): 8,
#  ('door', 'one'): 8,
#  ('start', 'would'): 8,
#  ('come', 'want'): 8,
#  ('want', 'war'): 8,
#  ('stay', 'want'): 8,
#  ('anyth', 'want'): 8,
#  ('come', 'outsid'): 8,
#  ('around', 'put'): 8,
#  ('girl', 'said'): 8,
#  ('lake', 'wind'): 8,
#  ('priest', 'rinaldi'): 8,
#  ('toward', 'walk'): 8,
#  ('drank', 'wine'): 8,
#  ('ask', 'said'): 8,
#  ('nothing', 'said'): 8,
#  ('anyth', 'said'): 8,
#  ('german', 'said'): 8,
#  ('ferguson', 'said'): 8,
#  ('baby', 'said'): 8,
#  ('catherin', 'love'): 8,
#  ('get', 'think'): 8,
#  ('catherin', 'get'): 8,
#  ('r', 'think'): 8,
#  ('door', 'hall'): 8,
#  ('wish', 'would'): 8,
#  ('would', 'yes'): 8,
#  ('stop', 'would'): 8,
#  ('bad', 'would'): 8,
#  ('catherin', 'would'): 8,
#  ('hope', 'would'): 8,
#  ('know', 'r'): 8,
#  ('anyth', 'know'): 8,
#  ('barkley', 'catherin'): 8,
#  ('hous', 'town'): 7,
#  ('big', 'look'): 7,
#  ('littl', 'look'): 7,
#  ('look', 'walk'): 7,
#  ('look', 'toward'): 7,
#  ('across', 'mountain'): 7,
#  ('across', 'side'): 7,
#  ('across', 'came'): 7,
#  ('beyond', 'river'): 7,
#  ('bed', 'go'): 7,
#  ('bed', 'one'): 7,
#  ('cold', 'water'): 7,
#  ('saw', 'went'): 7,
#  ('rain', 'went'): 7,
#  ('way', 'went'): 7,
#  ('left', 'went'): 7,
#  ('walk', 'went'): 7,
#  ('took', 'went'): 7,
#  ('put', 'went'): 7,
#  ('paper', 'went'): 7,
#  ('aymo', 'went'): 7,
#  ('come', 'road'): 7,
#  ('get', 'road'): 7,
#  ('road', 'stone'): 7,
#  ('besid', 'road'): 7,
#  ('leav', 'want'): 7,
#  ('leav', 'said'): 7,
#  ('along', 'tree'): 7,
#  ('see', 'tree'): 7,
#  ('along', 'mountain'): 7,
#  ('along', 'us'): 7,
#  ('along', 'bank'): 7,
#  ('beyond', 'littl'): 7,
#  ('night', 'rain'): 7,
#  ('away', 'could'): 7,
#  ('could', 'want'): 7,
#  ('could', 'snow'): 7,
#  ('could', 'keep'): 7,
#  ('could', 'thought'): 7,
#  ('could', 'far'): 7,
#  ('see', 'window'): 7,
#  ('back', 'see'): 7,
#  ('get', 'see'): 7,
#  ('let', 'see'): 7,
#  ('field', 'see'): 7,
#  ('got', 'see'): 7,
#  ('lake', 'see'): 7,
#  ('dark', 'rain'): 7,
#  ('like', 'two'): 7,
#  ('like', 'littl'): 7,
#  ('get', 'like'): 7,
#  ('like', 'think'): 7,
#  ('like', 'wish'): 7,
#  ('like', 'r'): 7,
#  ('baby', 'like'): 7,
#  ('light', 'window'): 7,
#  ('go', 'side'): 7,
#  ('go', 'men'): 7,
#  ('go', 'long'): 7,
#  ('go', 'thing'): 7,
#  ('go', 'well'): 7,
#  ('drink', 'go'): 7,
#  ('go', 'ought'): 7,
#  ('first', 'go'): 7,
#  ('go', 'stay'): 7,
#  ('go', 'outsid'): 7,
#  ('go', 'put'): 7,
#  ('cut', 'go'): 7,
#  ('doctor', 'go'): 7,
#  ('go', 'lake'): 7,
#  ('much', 'want'): 7,
#  ('get', 'much'): 7,
#  ('much', 'would'): 7,
#  ('much', 'talk'): 7,
#  ('lake', 'side'): 7,
#  ('men', 'two'): 7,
#  ('big', 'came'): 7,
#  ('long', 'row'): 7,
#  ('came', 'come'): 7,
#  ('came', 'said'): 7,
#  ('back', 'two'): 7,
#  ('girl', 'two'): 7,
#  ('car', 'said'): 7,
#  ('car', 'would'): 7,
#  ('back', 'put'): 7,
#  ('back', 'sleep'): 7,
#  ('one', 'us'): 7,
#  ('one', 'want'): 7,
#  ('held', 'one'): 7,
#  ('one', 'open'): 7,
#  ('good', 'one'): 7,
#  ('catherin', 'one'): 7,
#  ('said', 'sit'): 7,
#  ('think', 'way'): 7,
#  ('get', 'thing'): 7,
#  ('stone', 'wall'): 7,
#  ('away', 'want'): 7,
#  ('away', 'come'): 7,
#  ('away', 'take'): 7,
#  ('bonello', 'us'): 7,
#  ('darling', 'want'): 7,
#  ('catherin', 'want'): 7,
#  ('come', 'nurs'): 7,
#  ('come', 'hall'): 7,
#  ('good', 'time'): 7,
#  ('bad', 'time'): 7,
#  ('littl', 'sat'): 7,
#  ('catherin', 'littl'): 7,
#  ('hospit', 'said'): 7,
#  ('besid', 'sat'): 7,
#  ('drink', 'wine'): 7,
#  ('get', 'knew'): 7,
#  ('hall', 'walk'): 7,
#  ('italian', 'talk'): 7,
#  ('realli', 'said'): 7,
#  ('said', 'wait'): 7,
#  ('put', 'said'): 7,
#  ('barkley', 'said'): 7,
#  ('lie', 'said'): 7,
#  ('keep', 'said'): 7,
#  ('kill', 'said'): 7,
#  ('catherine', 'said'): 7,
#  ('said', 'thank'): 7,
#  ('god', 'said'): 7,
#  ('get', 'never'): 7,
#  ('never', 'would'): 7,
#  ('get', 'right'): 7,
#  ('get', 'tri'): 7,
#  ('tell', 'would'): 7,
#  ('door', 'outsid'): 7,
#  ('open', 'outsid'): 7,
#  ('make', 'would'): 7,
#  ('good', 'would'): 7,
#  ('put', 'would'): 7,
#  ('good', 'take'): 7,
#  ('catherin', 'say'): 7,
#  ('man', 'old'): 7,
#  ('doctor', 'room'): 7,
#  ('catherin', 'room'): 7,
#  ('catherin', 'r'): 7,
#  ('oh', 'yes'): 7,
#  ('close', 'shore'): 7,
#  ('asked', 'tenente'): 7,
#  ('asked', 'bonello'): 7,
#  ('asked', 'aymo'): 7,
#  ('catherin', 'turn'): 7,
#  ('lake', 'shore'): 7,
#  ('hous', 'live'): 6,
#  ('hous', 'mountain'): 6,
#  ('bed', 'look'): 6,
#  ('look', 'mountain'): 6,
#  ('look', 'side'): 6,
#  ('door', 'look'): 6,
#  ('look', 'open'): 6,
#  ('look', 'would'): 6,
#  ('floor', 'look'): 6,
#  ('look', 'put'): 6,
#  ('line', 'look'): 6,
#  ('light', 'look'): 6,
#  ('look', 'piani'): 6,
#  ('lake', 'look'): 6,
#  ('across', 'rain'): 6,
#  ('across', 'ahead'): 6,
#  ('across', 'lake'): 6,
#  ('could', 'river'): 6,
#  ('go', 'river'): 6,
#  ('river', 'two'): 6,
#  ('austrian', 'river'): 6,
#  ('bed', 'could'): 6,
#  ('bed', 'see'): 6,
#  ('bed', 'come'): 6,
#  ('bed', 'made'): 6,
#  ('bed', 'catherin'): 6,
#  ('saw', 'water'): 6,
#  ('could', 'water'): 6,
#  ('dark', 'water'): 6,
#  ('could', 'move'): 6,
#  ('move', 'see'): 6,
#  ('mountain', 'went'): 6,
#  ('long', 'went'): 6,
#  ('thing', 'went'): 6,
#  ('start', 'went'): 6,
#  ('cross', 'went'): 6,
#  ('drink', 'went'): 6,
#  ('let', 'went'): 6,
#  ('field', 'went'): 6,
#  ('outsid', 'went'): 6,
#  ('close', 'went'): 6,
#  ('station', 'went'): 6,
#  ('stood', 'went'): 6,
#  ('bonello', 'went'): 6,
#  ('piani', 'went'): 6,
#  ('leav', 'road'): 6,
#  ('night', 'road'): 6,
#  ('behind', 'road'): 6,
#  ('road', 'wet'): 6,
#  ('front', 'road'): 6,
#  ('road', 'snow'): 6,
#  ('new', 'road'): 6,
#  ('road', 'take'): 6,
#  ('road', 'work'): 6,
#  ('road', 'toward'): 6,
#  ('far', 'road'): 6,
#  ('bridg', 'road'): 6,
#  ('go', 'leav'): 6,
#  ('saw', 'tree'): 6,
#  ('could', 'tree'): 6,
#  ('rain', 'tree'): 6,
#  ('mountain', 'saw'): 6,
#  ('dark', 'saw'): 6,
#  ('saw', 'window'): 6,
#  ('car', 'saw'): 6,
#  ('back', 'saw'): 6,
#  ('saw', 'town'): 6,
#  ('lake', 'saw'): 6,
#  ('along', 'came'): 6,
#  ('along', 'back'): 6,
#  ('along', 'said'): 6,
#  ('fall', 'rain'): 6,
#  ('mani', 'peopl'): 6,
#  ('beyond', 'could'): 6,
#  ('beyond', 'side'): 6,
#  ('back', 'mountain'): 6,
#  ('littl', 'mountain'): 6,
#  ('mountain', 'snow'): 6,
#  ('dark', 'night'): 6,
#  ('cold', 'night'): 6,
#  ('catherin', 'night'): 6,
#  ('could', 'wind'): 6,
#  ('could', 'walk'): 6,
#  ('could', 'hand'): 6,
#  ('could', 'tell'): 6,
#  ('could', 'open'): 6,
#  ('could', 'first'): 6,
#  ('could', 'tri'): 6,
#  ('could', 'line'): 6,
#  ('ahead', 'could'): 6,
#  ('could', 'eat'): 6,
#  ('could', 'light'): 6,
#  ('could', 'shore'): 6,
#  ('could', 'lake'): 6,
#  ('long', 'see'): 6,
#  ('face', 'see'): 6,
#  ('see', 'thing'): 6,
#  ('door', 'see'): 6,
#  ('open', 'see'): 6,
#  ('place', 'see'): 6,
#  ('see', 'still'): 6,
#  ('know', 'see'): 6,
#  ('r', 'see'): 6,
#  ('miss', 'see'): 6,
#  ('right', 'see'): 6,
#  ('man', 'see'): 6,
#  ('ahead', 'see'): 6,
#  ('light', 'see'): 6,
#  ('dark', 'window'): 6,
#  ('dark', 'wind'): 6,
#  ('dark', 'room'): 6,
#  ('dark', 'lake'): 6,
#  ('like', 'time'): 6,
#  ('like', 'realli'): 6,
#  ('like', 'talk'): 6,
#  ('know', 'like'): 6,
#  ('come', 'feel'): 6,
#  ('feel', 'good'): 6,
#  ('go', 'sometim'): 6,
#  ('go', 'heard'): 6,
#  ('go', 'window'): 6,
#  ('door', 'window'): 6,
#  ('outsid', 'window'): 6,
#  ('go', 'much'): 6,
#  ('day', 'go'): 6,
#  ('go', 'rain'): 6,
#  ('go', 'way'): 6,
#  ('go', 'town'): 6,
#  ('go', 'us'): 6,
#  ('go', 'wind'): 6,
#  ('go', 'priest'): 6,
#  ('give', 'go'): 6,
#  ('go', 'make'): 6,
#  ('better', 'go'): 6,
#  ('go', 'got'): 6,
#  ('go', 'tenente'): 6,
#  ('asked', 'go'): 6,
#  ('go', 'v'): 6,
#  ('go', 'mayb'): 6,
#  ('much', 'thank'): 6,
#  ('far', 'side'): 6,
#  ('hold', 'side'): 6,
#  ('car', 'pass'): 6,
#  ('long', 'stay'): 6,
#  ('anoth', 'one'): 6,
#  ('rain', 'wet'): 6,
#  ('come', 'rain'): 6,
#  ('rain', 'three'): 6,
#  ('came', 'snow'): 6,
#  ('came', 'sat'): 6,
#  ('came', 'walk'): 6,
#  ('came', 'room'): 6,
#  ('came', 'catherin'): 6,
#  ('face', 'two'): 6,
#  ('two', 'want'): 6,
#  ('took', 'two'): 6,
#  ('get', 'two'): 6,
#  ('sergeant', 'two'): 6,
#  ('car', 'start'): 6,
#  ('car', 'take'): 6,
#  ('car', 'stop'): 6,
#  ('car', 'got'): 6,
#  ('offic', 'one'): 6,
#  ('back', 'seat'): 6,
#  ('back', 'walk'): 6,
#  ('back', 'head'): 6,
#  ('back', 'first'): 6,
#  ('back', 'lay'): 6,
#  ('back', 'line'): 6,
#  ('back', 'turn'): 6,
#  ('back', 'catherin'): 6,
#  ('even', 'would'): 6,
#  ('littl', 'one'): 6,
#  ('one', 'priest'): 6,
#  ('one', 'tell'): 6,
#  ('close', 'one'): 6,
#  ('light', 'one'): 6,
#  ('away', 'way'): 6,
#  ('die', 'would'): 6,
#  ('away', 'littl'): 6,
#  ('away', 'took'): 6,
#  ('away', 'get'): 6,
#  ('away', 'put'): 6,
#  ('away', 'right'): 6,
#  ('town', 'walk'): 6,
#  ('fine', 'r'): 6,
#  ('come', 'us'): 6,
#  ('littl', 'us'): 6,
#  ('take', 'want'): 6,
#  ('come', 'time'): 6,
#  ('come', 'littl'): 6,
#  ('come', 'snow'): 6,
#  ('come', 'walk'): 6,
#  ('come', 'open'): 6,
#  ('come', 'yes'): 6,
#  ('get', 'time'): 6,
#  ('know', 'peopl'): 6,
#  ('english', 'girl'): 6,
#  ('cold', 'wind'): 6,
#  ('turn', 'watch'): 6,
#  ('catherin', 'sat'): 6,
#  ('glass', 'held'): 6,
#  ('drank', 'glass'): 6,
#  ('priest', 'shook'): 6,
#  ('catherin', 'walk'): 6,
#  ('besid', 'walk'): 6,
#  ('head', 'said'): 6,
#  ('said', 'wine'): 6,
#  ('might', 'thought'): 6,
#  ('noth', 'said'): 6,
#  ('never', 'said'): 6,
#  ('ever', 'said'): 6,
#  ('said', 'wish'): 6,
#  ('english', 'said'): 6,
#  ('call', 'said'): 6,
#  ('man', 'said'): 6,
#  ('attack', 'said'): 6,
#  ('matter', 'said'): 6,
#  ('cut', 'said'): 6,
#  ('hope', 'said'): 6,
#  ('love', 'yes'): 6,
#  ('love', 'oh'): 6,
#  ('ever', 'get'): 6,
#  ('get', 'place'): 6,
#  ('get', 'good'): 6,
#  ('get', 'outsid'): 6,
#  ('get', 'yes'): 6,
#  ('get', 'take'): 6,
#  ('better', 'get'): 6,
#  ('get', 'got'): 6,
#  ('get', 'line'): 6,
#  ('get', 'someth'): 6,
#  ('ought', 'think'): 6,
#  ('think', 'tri'): 6,
#  ('catherin', 'think'): 6,
#  ('door', 'put'): 6,
#  ('door', 'nurs'): 6,
#  ('open', 'room'): 6,
#  ('close', 'open'): 6,
#  ('let', 'place'): 6,
#  ('let', 'take'): 6,
#  ('find', 'place'): 6,
#  ('boy', 'good'): 6,
#  ('catherin', 'good'): 6,
#  ('hall', 'outsid'): 6,
#  ('light', 'outsid'): 6,
#  ('floor', 'put'): 6,
#  ('rinaldi', 'room'): 6,
#  ('dress', 'room'): 6,
#  ('know', 'stop'): 6,
#  ('darling', 'know'): 6,
#  ('piani', 'sleep'): 6,
#  ('light', 'station'): 6,
#  ('darling', 'pleas'): 6,
#  ('doctor', 'nurs'): 6,
#  ('asked', 'catherin'): 6,
#  ('live', 'mountain'): 5,
#  ('hous', 'look'): 5,
#  ('hous', 'road'): 5,
#  ('hous', 'tree'): 5,
#  ('hous', 'side'): 5,
#  ('hous', 'stone'): 5,
#  ('look', 'white'): 5,
#  ('driver', 'look'): 5,
#  ('look', 'sit'): 5,
#  ('cross', 'look'): 5,
#  ('away', 'look'): 5,
#  ('look', 'snow'): 5,
#  ('look', 'took'): 5,
#  ('look', 'still'): 5,
#  ('look', 'man'): 5,
#  ('look', 'sergeant'): 5,
#  ('look', 'nurs'): 5,
#  ('look', 'stand'): 5,
#  ('look', 'tired'): 5,
#  ('across', 'along'): 5,
#  ('across', 'cross'): 5,
#  ('across', 'come'): 5,
#  ('across', 'knew'): 5,
#  ('across', 'said'): 5,
#  ('across', 'line'): 5,
#  ('river', 'water'): 5,
#  ('river', 'tree'): 5,
#  ('river', 'see'): 5,
#  ('bed', 'night'): 5,
#  ('bed', 'dark'): 5,
#  ('bed', 'side'): 5,
#  ('bed', 'came'): 5,
#  ('bed', 'floor'): 5,
#  ('bed', 'put'): 5,
#  ('bed', 'sleep'): 5,
#  ('bed', 'lie'): 5,
#  ('bed', 'got'): 5,
#  ('went', 'white'): 5,
#  ('road', 'white'): 5,
#  ('saw', 'white'): 5,
#  ('along', 'water'): 5,
#  ('lake', 'water'): 5,
#  ('clear', 'road'): 5,
#  ('clear', 'night'): 5,
#  ('clear', 'rain'): 5,
#  ('clear', 'cold'): 5,
#  ('clear', 'station'): 5,
#  ('move', 'road'): 5,
#  ('along', 'move'): 5,
#  ('move', 'rain'): 5,
#  ('gone', 'went'): 5,
#  ('sit', 'went'): 5,
#  ('end', 'went'): 5,
#  ('wall', 'went'): 5,
#  ('town', 'went'): 5,
#  ('time', 'went'): 5,
#  ('hospit', 'went'): 5,
#  ('street', 'went'): 5,
#  ('watch', 'went'): 5,
#  ('glass', 'went'): 5,
#  ('bottl', 'went'): 5,
#  ('held', 'went'): 5,
#  ('make', 'went'): 5,
#  ('good', 'went'): 5,
#  ('stay', 'went'): 5,
#  ('villa', 'went'): 5,
#  ('call', 'went'): 5,
#  ('ferguson', 'went'): 5,
#  ('far', 'went'): 5,
#  ('hotel', 'went'): 5,
#  ('road', 'sometim'): 5,
#  ('men', 'road'): 5,
#  ('long', 'road'): 5,
#  ('littl', 'road'): 5,
#  ('road', 'took'): 5,
#  ('hard', 'road'): 5,
#  ('close', 'road'): 5,
#  ('beyond', 'tree'): 5,
#  ('tree', 'two'): 5,
#  ('pass', 'saw'): 5,
#  ('littl', 'saw'): 5,
#  ('saw', 'watch'): 5,
#  ('saw', 'stand'): 5,
#  ('ahead', 'saw'): 5,
#  ('along', 'mani'): 5,
#  ('along', 'beyond'): 5,
#  ('along', 'dark'): 5,
#  ('along', 'pull'): 5,
#  ('along', 'way'): 5,
#  ('along', 'town'): 5,
#  ('along', 'line'): 5,
#  ('along', 'stone'): 5,
#  ('along', 'besid'): 5,
#  ('along', 'row'): 5,
#  ('along', 'lake'): 5,
#  ('outsid', 'soldier'): 5,
#  ('mani', 'way'): 5,
#  ('beyond', 'see'): 5,
#  ('beyond', 'cross'): 5,
#  ('beyond', 'town'): 5,
#  ('go', 'mountain'): 5,
#  ('mountain', 'two'): 5,
#  ('come', 'mountain'): 5,
#  ('line', 'mountain'): 5,
#  ('high', 'mountain'): 5,
#  ('night', 'see'): 5,
#  ('night', 'window'): 5,
#  ('come', 'night'): 5,
#  ('night', 'priest'): 5,
#  ('get', 'night'): 5,
#  ('big', 'could'): 5,
#  ('could', 'face'): 5,
#  ('could', 'time'): 5,
#  ('could', 'knew'): 5,
#  ('could', 'make'): 5,
#  ('could', 'field'): 5,
#  ('could', 'room'): 5,
#  ('could', 'put'): 5,
#  ('anyth', 'could'): 5,
#  ('could', 'turn'): 5,
#  ('see', 'two'): 5,
#  ('fine', 'see'): 5,
#  ('see', 'time'): 5,
#  ('see', 'well'): 5,
#  ('priest', 'see'): 5,
#  ('ask', 'see'): 5,
#  ('see', 'take'): 5,
#  ('see', 'v'): 5,
#  ('hotel', 'see'): 5,
#  ('hope', 'see'): 5,
#  ('back', 'dark'): 5,
#  ('cold', 'dark'): 5,
#  ('like', 'much'): 5,
#  ('like', 'long'): 5,
#  ('back', 'like'): 5,
#  ('like', 'one'): 5,
#  ('like', 'nice'): 5,
#  ('like', 'priest'): 5,
#  ('like', 'never'): 5,
#  ('like', 'love'): 5,
#  ('like', 'place'): 5,
#  ('like', 'say'): 5,
#  ('alway', 'like'): 5,
#  ('like', 'someth'): 5,
#  ('feel', 'way'): 5,
#  ('heard', 'said'): 5,
#  ('came', 'window'): 5,
#  ('sat', 'window'): 5,
#  ('go', 'pass'): 5,
#  ('go', 'two'): 5,
#  ('everi', 'go'): 5,
#  ('cross', 'go'): 5,
#  ('ask', 'go'): 5,
#  ('go', 'took'): 5,
#  ('go', 'major'): 5,
#  ...}

# %%
#順位チェック again !
new4 = dict(sorted(new3.items(), key=lambda x: x[1], reverse=True))
new4
# Out:
# {('go', 'said'): 102,
#  ('could', 'see'): 78,
#  ('catherin', 'said'): 71,
#  ('get', 'said'): 50,
#  ('back', 'went'): 48,
#  ('rinaldi', 'said'): 42,
#  ('right', 'said'): 40,
#  ('piani', 'said'): 40,
#  ('go', 'would'): 39,
#  ('said', 'want'): 39,
#  ('bonello', 'said'): 38,
#  ('along', 'road'): 37,
#  ('major', 'said'): 37,
#  ('said', 'would'): 37,
#  ('come', 'said'): 36,
#  ('good', 'said'): 36,
#  ('r', 'said'): 36,
#  ('go', 'want'): 35,
#  ('one', 'said'): 35,
#  ('like', 'said'): 33,
#  ('know', 'said'): 33,
#  ('back', 'go'): 32,
#  ('get', 'go'): 32,
#  ('back', 'come'): 31,
#  ('go', 'see'): 30,
#  ('said', 'yes'): 28,
#  ('look', 'window'): 26,
#  ('away', 'go'): 26,
#  ('said', 'think'): 26,
#  ('said', 'take'): 26,
#  ('darling', 'said'): 26,
#  ('back', 'came'): 25,
#  ('priest', 'said'): 25,
#  ('aymo', 'said'): 25,
#  ('door', 'went'): 24,
#  ('road', 'side'): 24,
#  ('said', 'see'): 24,
#  ('said', 'tenente'): 24,
#  ('could', 'said'): 23,
#  ('go', 'like'): 23,
#  ('like', 'would'): 23,
#  ('go', 'let'): 23,
#  ('go', 'went'): 22,
#  ('said', 'went'): 22,
#  ('room', 'went'): 22,
#  ('come', 'go'): 22,
#  ('back', 'said'): 22,
#  ('back', 'look'): 21,
#  ('road', 'went'): 21,
#  ('could', 'road'): 21,
#  ('could', 'go'): 21,
#  ('said', 'sleep'): 21,
#  ('could', 'look'): 20,
#  ('one', 'would'): 20,
#  ('come', 'would'): 20,
#  ('said', 'war'): 20,
#  ('door', 'open'): 20,
#  ('barkley', 'miss'): 20,
#  ('look', 'saw'): 19,
#  ('look', 'see'): 19,
#  ('like', 'look'): 19,
#  ('go', 'one'): 19,
#  ('long', 'time'): 19,
#  ('look', 'went'): 18,
#  ('look', 'road'): 18,
#  ('came', 'went'): 18,
#  ('see', 'want'): 18,
#  ('littl', 'said'): 18,
#  ('head', 'shook'): 18,
#  ('get', 'would'): 18,
#  ('look', 'said'): 17,
#  ('see', 'went'): 17,
#  ('much', 'said'): 17,
#  ('back', 'car'): 17,
#  ('come', 'get'): 17,
#  ('love', 'said'): 17,
#  ('better', 'said'): 17,
#  ('said', 'v'): 17,
#  ('doctor', 'said'): 17,
#  ('open', 'went'): 16,
#  ('go', 'road'): 16,
#  ('could', 'would'): 16,
#  ('see', 'would'): 16,
#  ('back', 'get'): 16,
#  ('everi', 'one'): 16,
#  ('fine', 'said'): 16,
#  ('said', 'us'): 16,
#  ('said', 'time'): 16,
#  ('must', 'said'): 16,
#  ('catherin', 'darling'): 16,
#  ('across', 'road'): 15,
#  ('catherin', 'went'): 15,
#  ('road', 'saw'): 15,
#  ('could', 'get'): 15,
#  ('go', 'think'): 15,
#  ('go', 'r'): 15,
#  ('go', 'sleep'): 15,
#  ('darling', 'go'): 15,
#  ('catherin', 'go'): 15,
#  ('long', 'way'): 15,
#  ('said', 'start'): 15,
#  ('hand', 'held'): 15,
#  ('hand', 'put'): 15,
#  ('said', 'tell'): 15,
#  ('said', 'talk'): 15,
#  ('along', 'went'): 14,
#  ('pass', 'road'): 14,
#  ('car', 'road'): 14,
#  ('along', 'could'): 14,
#  ('along', 'walk'): 14,
#  ('come', 'see'): 14,
#  ('go', 'right'): 14,
#  ('knew', 'would'): 14,
#  ('said', 'someth'): 14,
#  ('eat', 'said'): 14,
#  ('came', 'look'): 13,
#  ('look', 'watch'): 13,
#  ('look', 'room'): 13,
#  ('across', 'could'): 13,
#  ('river', 'road'): 13,
#  ('one', 'went'): 13,
#  ('come', 'went'): 13,
#  ('littl', 'went'): 13,
#  ('hall', 'went'): 13,
#  ('back', 'road'): 13,
#  ('road', 'start'): 13,
#  ('road', 'turn'): 13,
#  ('ahead', 'road'): 13,
#  ('come', 'saw'): 13,
#  ('along', 'go'): 13,
#  ('mountain', 'side'): 13,
#  ('back', 'could'): 13,
#  ('could', 'one'): 13,
#  ('came', 'see'): 13,
#  ('catherin', 'see'): 13,
#  ('go', 'must'): 13,
#  ('came', 'two'): 13,
#  ('car', 'two'): 13,
#  ('said', 'thing'): 13,
#  ('get', 'want'): 13,
#  ('said', 'well'): 13,
#  ('let', 'said'): 13,
#  ('place', 'said'): 13,
#  ('think', 'would'): 13,
#  ('dark', 'look'): 12,
#  ('go', 'look'): 12,
#  ('car', 'look'): 12,
#  ('look', 'sat'): 12,
#  ('glass', 'look'): 12,
#  ('bed', 'window'): 12,
#  ('bed', 'room'): 12,
#  ('bed', 'lay'): 12,
#  ('road', 'tree'): 12,
#  ('beyond', 'road'): 12,
#  ('mountain', 'road'): 12,
#  ('road', 'see'): 12,
#  ('came', 'saw'): 12,
#  ('one', 'saw'): 12,
#  ('along', 'see'): 12,
#  ('beyond', 'mountain'): 12,
#  ('could', 'rain'): 12,
#  ('come', 'could'): 12,
#  ('rain', 'see'): 12,
#  ('open', 'window'): 12,
#  ('car', 'go'): 12,
#  ('go', 'war'): 12,
#  ('go', 'know'): 12,
#  ('anoth', 'said'): 12,
#  ('came', 'one'): 12,
#  ('said', 'two'): 12,
#  ('back', 'would'): 12,
#  ('one', 'thing'): 12,
#  ('come', 'one'): 12,
#  ('away', 'said'): 12,
#  ('us', 'want'): 12,
#  ('give', 'said'): 12,
#  ('make', 'said'): 12,
#  ('first', 'said'): 12,
#  ('said', 'stay'): 12,
#  ('room', 'said'): 12,
#  ('nurs', 'said'): 12,
#  ('door', 'room'): 12,
#  ('bonello', 'piani'): 12,
#  ('look', 'two'): 11,
#  ('look', 'one'): 11,
#  ('across', 'river'): 11,
#  ('across', 'went'): 11,
#  ('cross', 'river'): 11,
#  ('back', 'bed'): 11,
#  ('bed', 'rinaldi'): 11,
#  ('could', 'went'): 11,
#  ('two', 'went'): 11,
#  ('went', 'would'): 11,
#  ('rinaldi', 'went'): 11,
#  ('sleep', 'went'): 11,
#  ('came', 'road'): 11,
#  ('field', 'road'): 11,
#  ('could', 'mountain'): 11,
#  ('mountain', 'see'): 11,
#  ('could', 'side'): 11,
#  ('car', 'could'): 11,
#  ('could', 'think'): 11,
#  ('catherin', 'could'): 11,
#  ('one', 'see'): 11,
#  ('go', 'walk'): 11,
#  ('go', 'place'): 11,
#  ('go', 'say'): 11,
#  ('go', 'stop'): 11,
#  ('one', 'side'): 11,
#  ('know', 'want'): 11,
#  ('catherin', 'time'): 11,
#  ('drink', 'said'): 11,
#  ('miss', 'said'): 11,
#  ('oh', 'said'): 11,
#  ('boy', 'said'): 11,
#  ('mayb', 'said'): 11,
#  ('paper', 'read'): 11,
#  ('thought', 'would'): 11,
#  ('anything', 'say'): 11,
#  ('bonello', 'tenente'): 11,
#  ('behind', 'look'): 10,
#  ('around', 'look'): 10,
#  ('catherin', 'look'): 10,
#  ('across', 'see'): 10,
#  ('along', 'river'): 10,
#  ('river', 'side'): 10,
#  ('bed', 'sat'): 10,
#  ('sat', 'went'): 10,
#  ('road', 'walk'): 10,
#  ('field', 'tree'): 10,
#  ('along', 'side'): 10,
#  ('lake', 'mountain'): 10,
#  ('could', 'feel'): 10,
#  ('could', 'window'): 10,
#  ('could', 'way'): 10,
#  ('could', 'place'): 10,
#  ('see', 'way'): 10,
#  ('dark', 'outsid'): 10,
#  ('feel', 'said'): 10,
#  ('room', 'window'): 10,
#  ('go', 'start'): 10,
#  ('go', 'yes'): 10,
#  ('go', 'take'): 10,
#  ('rain', 'stop'): 10,
#  ('back', 'sat'): 10,
#  ('back', 'take'): 10,
#  ('one', 'time'): 10,
#  ('knew', 'one'): 10,
#  ('know', 'one'): 10,
#  ('die', 'let'): 10,
#  ('want', 'would'): 10,
#  ('catherin', 'come'): 10,
#  ('war', 'would'): 10,
#  ('believ', 'said'): 10,
#  ('ought', 'said'): 10,
#  ('got', 'said'): 10,
#  ('said', 'thought'): 10,
#  ('find', 'said'): 10,
#  ('american', 'said'): 10,
#  ('get', 'say'): 10,
#  ('know', 'think'): 10,
#  ('take', 'would'): 10,
#  ('good', 'r'): 10,
#  ('darling', 'r'): 10,
#  ('got', 'v'): 10,
#  ('dress', 'station'): 10,
#  ('hous', 'went'): 9,
#  ('across', 'look'): 9,
#  ('look', 'us'): 9,
#  ('come', 'look'): 9,
#  ('look', 'priest'): 9,
#  ('look', 'rinaldi'): 9,
#  ('across', 'back'): 9,
#  ('mountain', 'river'): 9,
#  ('bank', 'river'): 9,
#  ('bed', 'went'): 9,
#  ('dark', 'went'): 9,
#  ('went', 'window'): 9,
#  ('side', 'went'): 9,
#  ('away', 'went'): 9,
#  ('got', 'went'): 9,
#  ('road', 'two'): 9,
#  ('cross', 'road'): 9,
#  ('line', 'road'): 9,
#  ('close', 'saw'): 9,
#  ('came', 'mountain'): 9,
#  ('mountain', 'town'): 9,
#  ('go', 'night'): 9,
#  ('night', 'said'): 9,
#  ('could', 'long'): 9,
#  ('came', 'could'): 9,
#  ('could', 'us'): 9,
#  ('could', 'take'): 9,
#  ('dark', 'see'): 9,
#  ('see', 'side'): 9,
#  ('car', 'see'): 9,
#  ('littl', 'see'): 9,
#  ('see', 'think'): 9,
#  ('feel', 'like'): 9,
#  ('go', 'time'): 9,
#  ('bonello', 'go'): 9,
#  ('big', 'one'): 9,
#  ('big', 'said'): 9,
#  ('away', 'long'): 9,
#  ('long', 'said'): 9,
#  ('came', 'door'): 9,
#  ('one', 'two'): 9,
#  ('back', 'one'): 9,
#  ('back', 'got'): 9,
#  ('hand', 'one'): 9,
#  ('littl', 'way'): 9,
#  ('said', 'way'): 9,
#  ('room', 'wall'): 9,
#  ('littl', 'town'): 9,
#  ('austrian', 'said'): 9,
#  ('think', 'want'): 9,
#  ('come', 'door'): 9,
#  ('arm', 'around'): 9,
#  ('drink', 'took'): 9,
#  ('hand', 'said'): 9,
#  ('captain', 'said'): 9,
#  ('italian', 'said'): 9,
#  ('said', 'say'): 9,
#  ('old', 'said'): 9,
#  ('said', 'tri'): 9,
#  ('said', 'stop'): 9,
#  ('alway', 'said'): 9,
#  ('bad', 'said'): 9,
#  ('get', 'know'): 9,
#  ('hall', 'room'): 9,
#  ('arm', 'put'): 9,
#  ('ferguson', 'miss'): 9,
#  ('darling', 'oh'): 9,
#  ('catherin', 'doctor'): 9,
#  ('like', 'live'): 8,
#  ('along', 'look'): 8,
#  ('ahead', 'look'): 8,
#  ('across', 'get'): 8,
#  ('across', 'field'): 8,
#  ('across', 'bridg'): 8,
#  ('bridg', 'river'): 8,
#  ('car', 'went'): 8,
#  ('want', 'went'): 8,
#  ('get', 'went'): 8,
#  ('think', 'went'): 8,
#  ('take', 'went'): 8,
#  ('toward', 'went'): 8,
#  ('turn', 'went'): 8,
#  ('lake', 'went'): 8,
#  ('mani', 'road'): 8,
#  ('road', 'way'): 8,
#  ('road', 'said'): 8,
#  ('road', 'would'): 8,
#  ('road', 'stop'): 8,
#  ('mountain', 'tree'): 8,
#  ('side', 'tree'): 8,
#  ('along', 'saw'): 8,
#  ('go', 'saw'): 8,
#  ('face', 'saw'): 8,
#  ('light', 'saw'): 8,
#  ('along', 'pass'): 8,
#  ('along', 'cross'): 8,
#  ('along', 'field'): 8,
#  ('mountain', 'shore'): 8,
#  ('night', 'one'): 8,
#  ('everi', 'night'): 8,
#  ('could', 'dark'): 8,
#  ('could', 'two'): 8,
#  ('could', 'littl'): 8,
#  ('could', 'stay'): 8,
#  ('close', 'could'): 8,
#  ('could', 'hear'): 8,
#  ('like', 'see'): 8,
#  ('even', 'see'): 8,
#  ('away', 'see'): 8,
#  ('see', 'us'): 8,
#  ('put', 'see'): 8,
#  ('see', 'shore'): 8,
#  ('dark', 'get'): 8,
#  ('dark', 'light'): 8,
#  ('come', 'window'): 8,
#  ('front', 'go'): 8,
#  ('die', 'go'): 8,
#  ('go', 'littl'): 8,
#  ('go', 'street'): 8,
#  ('go', 'knew'): 8,
#  ('door', 'go'): 8,
#  ('go', 'tri'): 8,
#  ('go', 'pleas'): 8,
#  ('go', 'someth'): 8,
#  ('eat', 'go'): 8,
#  ('go', 'piani'): 8,
#  ('much', 'think'): 8,
#  ('long', 'one'): 8,
#  ('came', 'rain'): 8,
#  ('came', 'car'): 8,
#  ('came', 'us'): 8,
#  ('came', 'time'): 8,
#  ('came', 'hand'): 8,
#  ('bottl', 'two'): 8,
#  ('aymo', 'car'): 8,
#  ('offic', 'said'): 8,
#  ('back', 'way'): 8,
#  ('back', 'us'): 8,
#  ('back', 'want'): 8,
#  ('back', 'hand'): 8,
#  ('aymo', 'back'): 8,
#  ('one', 'took'): 8,
#  ('get', 'one'): 8,
#  ('door', 'one'): 8,
#  ('start', 'would'): 8,
#  ('come', 'want'): 8,
#  ('want', 'war'): 8,
#  ('stay', 'want'): 8,
#  ('anyth', 'want'): 8,
#  ('come', 'outsid'): 8,
#  ('around', 'put'): 8,
#  ('girl', 'said'): 8,
#  ('lake', 'wind'): 8,
#  ('priest', 'rinaldi'): 8,
#  ('toward', 'walk'): 8,
#  ('drank', 'wine'): 8,
#  ('ask', 'said'): 8,
#  ('nothing', 'said'): 8,
#  ('anyth', 'said'): 8,
#  ('german', 'said'): 8,
#  ('ferguson', 'said'): 8,
#  ('baby', 'said'): 8,
#  ('catherin', 'love'): 8,
#  ('get', 'think'): 8,
#  ('catherin', 'get'): 8,
#  ('r', 'think'): 8,
#  ('door', 'hall'): 8,
#  ('wish', 'would'): 8,
#  ('would', 'yes'): 8,
#  ('stop', 'would'): 8,
#  ('bad', 'would'): 8,
#  ('catherin', 'would'): 8,
#  ('hope', 'would'): 8,
#  ('know', 'r'): 8,
#  ('anyth', 'know'): 8,
#  ('barkley', 'catherin'): 8,
#  ('hous', 'town'): 7,
#  ('big', 'look'): 7,
#  ('littl', 'look'): 7,
#  ('look', 'walk'): 7,
#  ('look', 'toward'): 7,
#  ('across', 'mountain'): 7,
#  ('across', 'side'): 7,
#  ('across', 'came'): 7,
#  ('beyond', 'river'): 7,
#  ('bed', 'go'): 7,
#  ('bed', 'one'): 7,
#  ('cold', 'water'): 7,
#  ('saw', 'went'): 7,
#  ('rain', 'went'): 7,
#  ('way', 'went'): 7,
#  ('left', 'went'): 7,
#  ('walk', 'went'): 7,
#  ('took', 'went'): 7,
#  ('put', 'went'): 7,
#  ('paper', 'went'): 7,
#  ('aymo', 'went'): 7,
#  ('come', 'road'): 7,
#  ('get', 'road'): 7,
#  ('road', 'stone'): 7,
#  ('besid', 'road'): 7,
#  ('leav', 'want'): 7,
#  ('leav', 'said'): 7,
#  ('along', 'tree'): 7,
#  ('see', 'tree'): 7,
#  ('along', 'mountain'): 7,
#  ('along', 'us'): 7,
#  ('along', 'bank'): 7,
#  ('beyond', 'littl'): 7,
#  ('night', 'rain'): 7,
#  ('away', 'could'): 7,
#  ('could', 'want'): 7,
#  ('could', 'snow'): 7,
#  ('could', 'keep'): 7,
#  ('could', 'thought'): 7,
#  ('could', 'far'): 7,
#  ('see', 'window'): 7,
#  ('back', 'see'): 7,
#  ('get', 'see'): 7,
#  ('let', 'see'): 7,
#  ('field', 'see'): 7,
#  ('got', 'see'): 7,
#  ('lake', 'see'): 7,
#  ('dark', 'rain'): 7,
#  ('like', 'two'): 7,
#  ('like', 'littl'): 7,
#  ('get', 'like'): 7,
#  ('like', 'think'): 7,
#  ('like', 'wish'): 7,
#  ('like', 'r'): 7,
#  ('baby', 'like'): 7,
#  ('light', 'window'): 7,
#  ('go', 'side'): 7,
#  ('go', 'men'): 7,
#  ('go', 'long'): 7,
#  ('go', 'thing'): 7,
#  ('go', 'well'): 7,
#  ('drink', 'go'): 7,
#  ('go', 'ought'): 7,
#  ('first', 'go'): 7,
#  ('go', 'stay'): 7,
#  ('go', 'outsid'): 7,
#  ('go', 'put'): 7,
#  ('cut', 'go'): 7,
#  ('doctor', 'go'): 7,
#  ('go', 'lake'): 7,
#  ('much', 'want'): 7,
#  ('get', 'much'): 7,
#  ('much', 'would'): 7,
#  ('much', 'talk'): 7,
#  ('lake', 'side'): 7,
#  ('men', 'two'): 7,
#  ('big', 'came'): 7,
#  ('long', 'row'): 7,
#  ('came', 'come'): 7,
#  ('came', 'said'): 7,
#  ('back', 'two'): 7,
#  ('girl', 'two'): 7,
#  ('car', 'said'): 7,
#  ('car', 'would'): 7,
#  ('back', 'put'): 7,
#  ('back', 'sleep'): 7,
#  ('one', 'us'): 7,
#  ('one', 'want'): 7,
#  ('held', 'one'): 7,
#  ('one', 'open'): 7,
#  ('good', 'one'): 7,
#  ('catherin', 'one'): 7,
#  ('said', 'sit'): 7,
#  ('think', 'way'): 7,
#  ('get', 'thing'): 7,
#  ('stone', 'wall'): 7,
#  ('away', 'want'): 7,
#  ('away', 'come'): 7,
#  ('away', 'take'): 7,
#  ('bonello', 'us'): 7,
#  ('darling', 'want'): 7,
#  ('catherin', 'want'): 7,
#  ('come', 'nurs'): 7,
#  ('come', 'hall'): 7,
#  ('good', 'time'): 7,
#  ('bad', 'time'): 7,
#  ('littl', 'sat'): 7,
#  ('catherin', 'littl'): 7,
#  ('hospit', 'said'): 7,
#  ('besid', 'sat'): 7,
#  ('drink', 'wine'): 7,
#  ('get', 'knew'): 7,
#  ('hall', 'walk'): 7,
#  ('italian', 'talk'): 7,
#  ('realli', 'said'): 7,
#  ('said', 'wait'): 7,
#  ('put', 'said'): 7,
#  ('barkley', 'said'): 7,
#  ('lie', 'said'): 7,
#  ('keep', 'said'): 7,
#  ('kill', 'said'): 7,
#  ('catherine', 'said'): 7,
#  ('said', 'thank'): 7,
#  ('god', 'said'): 7,
#  ('get', 'never'): 7,
#  ('never', 'would'): 7,
#  ('get', 'right'): 7,
#  ('get', 'tri'): 7,
#  ('tell', 'would'): 7,
#  ('door', 'outsid'): 7,
#  ('open', 'outsid'): 7,
#  ('make', 'would'): 7,
#  ('good', 'would'): 7,
#  ('put', 'would'): 7,
#  ('good', 'take'): 7,
#  ('catherin', 'say'): 7,
#  ('man', 'old'): 7,
#  ('doctor', 'room'): 7,
#  ('catherin', 'room'): 7,
#  ('catherin', 'r'): 7,
#  ('oh', 'yes'): 7,
#  ('close', 'shore'): 7,
#  ('asked', 'tenente'): 7,
#  ('asked', 'bonello'): 7,
#  ('asked', 'aymo'): 7,
#  ('catherin', 'turn'): 7,
#  ('lake', 'shore'): 7,
#  ('hous', 'live'): 6,
#  ('hous', 'mountain'): 6,
#  ('bed', 'look'): 6,
#  ('look', 'mountain'): 6,
#  ('look', 'side'): 6,
#  ('door', 'look'): 6,
#  ('look', 'open'): 6,
#  ('look', 'would'): 6,
#  ('floor', 'look'): 6,
#  ('look', 'put'): 6,
#  ('line', 'look'): 6,
#  ('light', 'look'): 6,
#  ('look', 'piani'): 6,
#  ('lake', 'look'): 6,
#  ('across', 'rain'): 6,
#  ('across', 'ahead'): 6,
#  ('across', 'lake'): 6,
#  ('could', 'river'): 6,
#  ('go', 'river'): 6,
#  ('river', 'two'): 6,
#  ('austrian', 'river'): 6,
#  ('bed', 'could'): 6,
#  ('bed', 'see'): 6,
#  ('bed', 'come'): 6,
#  ('bed', 'made'): 6,
#  ('bed', 'catherin'): 6,
#  ('saw', 'water'): 6,
#  ('could', 'water'): 6,
#  ('dark', 'water'): 6,
#  ('could', 'move'): 6,
#  ('move', 'see'): 6,
#  ('mountain', 'went'): 6,
#  ('long', 'went'): 6,
#  ('thing', 'went'): 6,
#  ('start', 'went'): 6,
#  ('cross', 'went'): 6,
#  ('drink', 'went'): 6,
#  ('let', 'went'): 6,
#  ('field', 'went'): 6,
#  ('outsid', 'went'): 6,
#  ('close', 'went'): 6,
#  ('station', 'went'): 6,
#  ('stood', 'went'): 6,
#  ('bonello', 'went'): 6,
#  ('piani', 'went'): 6,
#  ('leav', 'road'): 6,
#  ('night', 'road'): 6,
#  ('behind', 'road'): 6,
#  ('road', 'wet'): 6,
#  ('front', 'road'): 6,
#  ('road', 'snow'): 6,
#  ('new', 'road'): 6,
#  ('road', 'take'): 6,
#  ('road', 'work'): 6,
#  ('road', 'toward'): 6,
#  ('far', 'road'): 6,
#  ('bridg', 'road'): 6,
#  ('go', 'leav'): 6,
#  ('saw', 'tree'): 6,
#  ('could', 'tree'): 6,
#  ('rain', 'tree'): 6,
#  ('mountain', 'saw'): 6,
#  ('dark', 'saw'): 6,
#  ('saw', 'window'): 6,
#  ('car', 'saw'): 6,
#  ('back', 'saw'): 6,
#  ('saw', 'town'): 6,
#  ('lake', 'saw'): 6,
#  ('along', 'came'): 6,
#  ('along', 'back'): 6,
#  ('along', 'said'): 6,
#  ('fall', 'rain'): 6,
#  ('mani', 'peopl'): 6,
#  ('beyond', 'could'): 6,
#  ('beyond', 'side'): 6,
#  ('back', 'mountain'): 6,
#  ('littl', 'mountain'): 6,
#  ('mountain', 'snow'): 6,
#  ('dark', 'night'): 6,
#  ('cold', 'night'): 6,
#  ('catherin', 'night'): 6,
#  ('could', 'wind'): 6,
#  ('could', 'walk'): 6,
#  ('could', 'hand'): 6,
#  ('could', 'tell'): 6,
#  ('could', 'open'): 6,
#  ('could', 'first'): 6,
#  ('could', 'tri'): 6,
#  ('could', 'line'): 6,
#  ('ahead', 'could'): 6,
#  ('could', 'eat'): 6,
#  ('could', 'light'): 6,
#  ('could', 'shore'): 6,
#  ('could', 'lake'): 6,
#  ('long', 'see'): 6,
#  ('face', 'see'): 6,
#  ('see', 'thing'): 6,
#  ('door', 'see'): 6,
#  ('open', 'see'): 6,
#  ('place', 'see'): 6,
#  ('see', 'still'): 6,
#  ('know', 'see'): 6,
#  ('r', 'see'): 6,
#  ('miss', 'see'): 6,
#  ('right', 'see'): 6,
#  ('man', 'see'): 6,
#  ('ahead', 'see'): 6,
#  ('light', 'see'): 6,
#  ('dark', 'window'): 6,
#  ('dark', 'wind'): 6,
#  ('dark', 'room'): 6,
#  ('dark', 'lake'): 6,
#  ('like', 'time'): 6,
#  ('like', 'realli'): 6,
#  ('like', 'talk'): 6,
#  ('know', 'like'): 6,
#  ('come', 'feel'): 6,
#  ('feel', 'good'): 6,
#  ('go', 'sometim'): 6,
#  ('go', 'heard'): 6,
#  ('go', 'window'): 6,
#  ('door', 'window'): 6,
#  ('outsid', 'window'): 6,
#  ('go', 'much'): 6,
#  ('day', 'go'): 6,
#  ('go', 'rain'): 6,
#  ('go', 'way'): 6,
#  ('go', 'town'): 6,
#  ('go', 'us'): 6,
#  ('go', 'wind'): 6,
#  ('go', 'priest'): 6,
#  ('give', 'go'): 6,
#  ('go', 'make'): 6,
#  ('better', 'go'): 6,
#  ('go', 'got'): 6,
#  ('go', 'tenente'): 6,
#  ('asked', 'go'): 6,
#  ('go', 'v'): 6,
#  ('go', 'mayb'): 6,
#  ('much', 'thank'): 6,
#  ('far', 'side'): 6,
#  ('hold', 'side'): 6,
#  ('car', 'pass'): 6,
#  ('long', 'stay'): 6,
#  ('anoth', 'one'): 6,
#  ('rain', 'wet'): 6,
#  ('come', 'rain'): 6,
#  ('rain', 'three'): 6,
#  ('came', 'snow'): 6,
#  ('came', 'sat'): 6,
#  ('came', 'walk'): 6,
#  ('came', 'room'): 6,
#  ('came', 'catherin'): 6,
#  ('face', 'two'): 6,
#  ('two', 'want'): 6,
#  ('took', 'two'): 6,
#  ('get', 'two'): 6,
#  ('sergeant', 'two'): 6,
#  ('car', 'start'): 6,
#  ('car', 'take'): 6,
#  ('car', 'stop'): 6,
#  ('car', 'got'): 6,
#  ('offic', 'one'): 6,
#  ('back', 'seat'): 6,
#  ('back', 'walk'): 6,
#  ('back', 'head'): 6,
#  ('back', 'first'): 6,
#  ('back', 'lay'): 6,
#  ('back', 'line'): 6,
#  ('back', 'turn'): 6,
#  ('back', 'catherin'): 6,
#  ('even', 'would'): 6,
#  ('littl', 'one'): 6,
#  ('one', 'priest'): 6,
#  ('one', 'tell'): 6,
#  ('close', 'one'): 6,
#  ('light', 'one'): 6,
#  ('away', 'way'): 6,
#  ('die', 'would'): 6,
#  ('away', 'littl'): 6,
#  ('away', 'took'): 6,
#  ('away', 'get'): 6,
#  ('away', 'put'): 6,
#  ('away', 'right'): 6,
#  ('town', 'walk'): 6,
#  ('fine', 'r'): 6,
#  ('come', 'us'): 6,
#  ('littl', 'us'): 6,
#  ('take', 'want'): 6,
#  ('come', 'time'): 6,
#  ('come', 'littl'): 6,
#  ('come', 'snow'): 6,
#  ('come', 'walk'): 6,
#  ('come', 'open'): 6,
#  ('come', 'yes'): 6,
#  ('get', 'time'): 6,
#  ('know', 'peopl'): 6,
#  ('english', 'girl'): 6,
#  ('cold', 'wind'): 6,
#  ('turn', 'watch'): 6,
#  ('catherin', 'sat'): 6,
#  ('glass', 'held'): 6,
#  ('drank', 'glass'): 6,
#  ('priest', 'shook'): 6,
#  ('catherin', 'walk'): 6,
#  ('besid', 'walk'): 6,
#  ('head', 'said'): 6,
#  ('said', 'wine'): 6,
#  ('might', 'thought'): 6,
#  ('noth', 'said'): 6,
#  ('never', 'said'): 6,
#  ('ever', 'said'): 6,
#  ('said', 'wish'): 6,
#  ('english', 'said'): 6,
#  ('call', 'said'): 6,
#  ('man', 'said'): 6,
#  ('attack', 'said'): 6,
#  ('matter', 'said'): 6,
#  ('cut', 'said'): 6,
#  ('hope', 'said'): 6,
#  ('love', 'yes'): 6,
#  ('love', 'oh'): 6,
#  ('ever', 'get'): 6,
#  ('get', 'place'): 6,
#  ('get', 'good'): 6,
#  ('get', 'outsid'): 6,
#  ('get', 'yes'): 6,
#  ('get', 'take'): 6,
#  ('better', 'get'): 6,
#  ('get', 'got'): 6,
#  ('get', 'line'): 6,
#  ('get', 'someth'): 6,
#  ('ought', 'think'): 6,
#  ('think', 'tri'): 6,
#  ('catherin', 'think'): 6,
#  ('door', 'put'): 6,
#  ('door', 'nurs'): 6,
#  ('open', 'room'): 6,
#  ('close', 'open'): 6,
#  ('let', 'place'): 6,
#  ('let', 'take'): 6,
#  ('find', 'place'): 6,
#  ('boy', 'good'): 6,
#  ('catherin', 'good'): 6,
#  ('hall', 'outsid'): 6,
#  ('light', 'outsid'): 6,
#  ('floor', 'put'): 6,
#  ('rinaldi', 'room'): 6,
#  ('dress', 'room'): 6,
#  ('know', 'stop'): 6,
#  ('darling', 'know'): 6,
#  ('piani', 'sleep'): 6,
#  ('light', 'station'): 6,
#  ('darling', 'pleas'): 6,
#  ('doctor', 'nurs'): 6,
#  ('asked', 'catherin'): 6,
#  ('live', 'mountain'): 5,
#  ('hous', 'look'): 5,
#  ('hous', 'road'): 5,
#  ('hous', 'tree'): 5,
#  ('hous', 'side'): 5,
#  ('hous', 'stone'): 5,
#  ('look', 'white'): 5,
#  ('driver', 'look'): 5,
#  ('look', 'sit'): 5,
#  ('cross', 'look'): 5,
#  ('away', 'look'): 5,
#  ('look', 'snow'): 5,
#  ('look', 'took'): 5,
#  ('look', 'still'): 5,
#  ('look', 'man'): 5,
#  ('look', 'sergeant'): 5,
#  ('look', 'nurs'): 5,
#  ('look', 'stand'): 5,
#  ('look', 'tired'): 5,
#  ('across', 'along'): 5,
#  ('across', 'cross'): 5,
#  ('across', 'come'): 5,
#  ('across', 'knew'): 5,
#  ('across', 'said'): 5,
#  ('across', 'line'): 5,
#  ('river', 'water'): 5,
#  ('river', 'tree'): 5,
#  ('river', 'see'): 5,
#  ('bed', 'night'): 5,
#  ('bed', 'dark'): 5,
#  ('bed', 'side'): 5,
#  ('bed', 'came'): 5,
#  ('bed', 'floor'): 5,
#  ('bed', 'put'): 5,
#  ('bed', 'sleep'): 5,
#  ('bed', 'lie'): 5,
#  ('bed', 'got'): 5,
#  ('went', 'white'): 5,
#  ('road', 'white'): 5,
#  ('saw', 'white'): 5,
#  ('along', 'water'): 5,
#  ('lake', 'water'): 5,
#  ('clear', 'road'): 5,
#  ('clear', 'night'): 5,
#  ('clear', 'rain'): 5,
#  ('clear', 'cold'): 5,
#  ('clear', 'station'): 5,
#  ('move', 'road'): 5,
#  ('along', 'move'): 5,
#  ('move', 'rain'): 5,
#  ('gone', 'went'): 5,
#  ('sit', 'went'): 5,
#  ('end', 'went'): 5,
#  ('wall', 'went'): 5,
#  ('town', 'went'): 5,
#  ('time', 'went'): 5,
#  ('hospit', 'went'): 5,
#  ('street', 'went'): 5,
#  ('watch', 'went'): 5,
#  ('glass', 'went'): 5,
#  ('bottl', 'went'): 5,
#  ('held', 'went'): 5,
#  ('make', 'went'): 5,
#  ('good', 'went'): 5,
#  ('stay', 'went'): 5,
#  ('villa', 'went'): 5,
#  ('call', 'went'): 5,
#  ('ferguson', 'went'): 5,
#  ('far', 'went'): 5,
#  ('hotel', 'went'): 5,
#  ('road', 'sometim'): 5,
#  ('men', 'road'): 5,
#  ('long', 'road'): 5,
#  ('littl', 'road'): 5,
#  ('road', 'took'): 5,
#  ('hard', 'road'): 5,
#  ('close', 'road'): 5,
#  ('beyond', 'tree'): 5,
#  ('tree', 'two'): 5,
#  ('pass', 'saw'): 5,
#  ('littl', 'saw'): 5,
#  ('saw', 'watch'): 5,
#  ('saw', 'stand'): 5,
#  ('ahead', 'saw'): 5,
#  ('along', 'mani'): 5,
#  ('along', 'beyond'): 5,
#  ('along', 'dark'): 5,
#  ('along', 'pull'): 5,
#  ('along', 'way'): 5,
#  ('along', 'town'): 5,
#  ('along', 'line'): 5,
#  ('along', 'stone'): 5,
#  ('along', 'besid'): 5,
#  ('along', 'row'): 5,
#  ('along', 'lake'): 5,
#  ('outsid', 'soldier'): 5,
#  ('mani', 'way'): 5,
#  ('beyond', 'see'): 5,
#  ('beyond', 'cross'): 5,
#  ('beyond', 'town'): 5,
#  ('go', 'mountain'): 5,
#  ('mountain', 'two'): 5,
#  ('come', 'mountain'): 5,
#  ('line', 'mountain'): 5,
#  ('high', 'mountain'): 5,
#  ('night', 'see'): 5,
#  ('night', 'window'): 5,
#  ('come', 'night'): 5,
#  ('night', 'priest'): 5,
#  ('get', 'night'): 5,
#  ('big', 'could'): 5,
#  ('could', 'face'): 5,
#  ('could', 'time'): 5,
#  ('could', 'knew'): 5,
#  ('could', 'make'): 5,
#  ('could', 'field'): 5,
#  ('could', 'room'): 5,
#  ('could', 'put'): 5,
#  ('anyth', 'could'): 5,
#  ('could', 'turn'): 5,
#  ('see', 'two'): 5,
#  ('fine', 'see'): 5,
#  ('see', 'time'): 5,
#  ('see', 'well'): 5,
#  ('priest', 'see'): 5,
#  ('ask', 'see'): 5,
#  ('see', 'take'): 5,
#  ('see', 'v'): 5,
#  ('hotel', 'see'): 5,
#  ('hope', 'see'): 5,
#  ('back', 'dark'): 5,
#  ('cold', 'dark'): 5,
#  ('like', 'much'): 5,
#  ('like', 'long'): 5,
#  ('back', 'like'): 5,
#  ('like', 'one'): 5,
#  ('like', 'nice'): 5,
#  ('like', 'priest'): 5,
#  ('like', 'never'): 5,
#  ('like', 'love'): 5,
#  ('like', 'place'): 5,
#  ('like', 'say'): 5,
#  ('alway', 'like'): 5,
#  ('like', 'someth'): 5,
#  ('feel', 'way'): 5,
#  ('heard', 'said'): 5,
#  ('came', 'window'): 5,
#  ('sat', 'window'): 5,
#  ('go', 'pass'): 5,
#  ('go', 'two'): 5,
#  ('everi', 'go'): 5,
#  ('cross', 'go'): 5,
#  ('ask', 'go'): 5,
#  ('go', 'took'): 5,
#  ('go', 'major'): 5,
#  ...}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.bar(range(len(new4)), new4.values(), align='center')
# plt.xticks(range(len(new2)), new2.keys())  too many....
#plt.xticks(range(len(new4)), new4.keys())  


# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x

plt.show()

# %%
#単語順位チェック
word_f = sorted(f_list_new[0].items(), key=lambda x: x[1], reverse=True)
word_f
# Out:
# [('said', 945),
#  ('go', 441),
#  ('went', 293),
#  ('look', 290),
#  ('would', 254),
#  ('one', 245),
#  ('see', 232),
#  ('could', 219),
#  ('back', 219),
#  ('get', 218),
#  ('come', 215),
#  ('want', 188),
#  ('road', 187),
#  ('like', 186),
#  ('came', 186),
#  ('catherin', 178),
#  ('right', 164),
#  ('know', 159),
#  ('good', 150),
#  ('yes', 136),
#  ('think', 132),
#  ('two', 131),
#  ('time', 121),
#  ('r', 120),
#  ('littl', 118),
#  ('us', 114),
#  ('away', 111),
#  ('saw', 110),
#  ('rain', 107),
#  ('take', 107),
#  ('put', 103),
#  ('much', 99),
#  ('long', 99),
#  ('bed', 98),
#  ('along', 98),
#  ('rinaldi', 98),
#  ('car', 97),
#  ('love', 94),
#  ('room', 94),
#  ('night', 93),
#  ('war', 93),
#  ('hand', 93),
#  ('let', 91),
#  ('darling', 91),
#  ('start', 90),
#  ('side', 87),
#  ('priest', 87),
#  ('took', 86),
#  ('dark', 84),
#  ('way', 84),
#  ('walk', 84),
#  ('sat', 83),
#  ('stop', 83),
#  ('piani', 80),
#  ('got', 79),
#  ('tell', 77),
#  ('make', 75),
#  ('bonello', 75),
#  ('feel', 74),
#  ('thing', 74),
#  ('never', 74),
#  ('say', 73),
#  ('across', 72),
#  ('mountain', 72),
#  ('window', 72),
#  ('fine', 71),
#  ('door', 71),
#  ('talk', 71),
#  ('place', 70),
#  ('major', 69),
#  ('open', 69),
#  ('tenente', 69),
#  ('big', 67),
#  ('doctor', 67),
#  ('asked', 66),
#  ('river', 65),
#  ('thought', 65),
#  ('someth', 64),
#  ('drink', 63),
#  ('better', 63),
#  ('oh', 63),
#  ('mani', 62),
#  ('head', 62),
#  ('v', 62),
#  ('ask', 61),
#  ('turn', 61),
#  ('anoth', 60),
#  ('girl', 60),
#  ('man', 59),
#  ('line', 59),
#  ('aymo', 59),
#  ('lake', 59),
#  ('face', 58),
#  ('well', 58),
#  ('die', 57),
#  ('watch', 57),
#  ('light', 57),
#  ('water', 56),
#  ('knew', 56),
#  ('outsid', 55),
#  ('stay', 54),
#  ('sleep', 54),
#  ('town', 53),
#  ('glass', 53),
#  ('held', 53),
#  ('italian', 53),
#  ('felt', 53),
#  ('must', 52),
#  ('alway', 52),
#  ('gone', 51),
#  ('bad', 51),
#  ('wine', 50),
#  ('give', 50),
#  ('first', 50),
#  ('still', 50),
#  ('close', 50),
#  ('tri', 50),
#  ('toward', 50),
#  ('front', 49),
#  ('around', 49),
#  ('work', 49),
#  ('heard', 48),
#  ('wet', 48),
#  ('made', 48),
#  ('eat', 48),
#  ('move', 47),
#  ('day', 47),
#  ('left', 47),
#  ('anyth', 47),
#  ('stood', 47),
#  ('men', 46),
#  ('three', 46),
#  ('cross', 45),
#  ('wish', 45),
#  ('hold', 45),
#  ('ahead', 45),
#  ('old', 44),
#  ('baby', 44),
#  ('besid', 44),
#  ('sit', 43),
#  ('noth', 43),
#  ('english', 43),
#  ('miss', 43),
#  ('pass', 42),
#  ('snow', 42),
#  ('believ', 42),
#  ('hotel', 42),
#  ('boat', 42),
#  ('tree', 41),
#  ('offic', 41),
#  ('row', 41),
#  ('pull', 40),
#  ('fire', 40),
#  ('nurs', 40),
#  ('hall', 40),
#  ('peopl', 39),
#  ('cut', 39),
#  ('paper', 39),
#  ('austrian', 38),
#  ('cold', 38),
#  ('hard', 38),
#  ('brought', 38),
#  ('hous', 37),
#  ('beyond', 37),
#  ('floor', 37),
#  ('lay', 37),
#  ('leav', 36),
#  ('behind', 36),
#  ('wall', 36),
#  ('field', 36),
#  ('station', 36),
#  ('boy', 36),
#  ('driver', 35),
#  ('even', 35),
#  ('everi', 35),
#  ('wind', 35),
#  ('might', 35),
#  ('american', 35),
#  ('far', 35),
#  ('catherine', 35),
#  ('mayb', 35),
#  ('live', 34),
#  ('sometim', 34),
#  ('great', 34),
#  ('train', 34),
#  ('soldier', 33),
#  ('small', 33),
#  ('nice', 33),
#  ('seem', 33),
#  ('realli', 33),
#  ('arm', 33),
#  ('attack', 33),
#  ('keep', 33),
#  ('ferguson', 33),
#  ('ever', 32),
#  ('barkley', 32),
#  ('call', 32),
#  ('lie', 32),
#  ('pleas', 32),
#  ('end', 31),
#  ('hope', 31),
#  ('shore', 31),
#  ('clear', 30),
#  ('street', 30),
#  ('captain', 30),
#  ('point', 30),
#  ('wound', 30),
#  ('afraid', 30),
#  ('white', 29),
#  ('carri', 29),
#  ('hospit', 29),
#  ('bring', 29),
#  ('wait', 29),
#  ('tire', 29),
#  ('stone', 29),
#  ('quit', 29),
#  ('kill', 29),
#  ('stand', 29),
#  ('find', 29),
#  ('bridg', 29),
#  ('thank', 29),
#  ('fall', 28),
#  ('bottl', 28),
#  ('shook', 28),
#  ('sight', 28),
#  ('read', 28),
#  ('ought', 28),
#  ('dress', 28),
#  ('drank', 28),
#  ('told', 28),
#  ('high', 28),
#  ('play', 28),
#  ('bank', 28),
#  ('dead', 27),
#  ('nothing', 27),
#  ('anything', 27),
#  ('tired', 27),
#  ('though', 26),
#  ('winter', 26),
#  ('insid', 26),
#  ('kiss', 26),
#  ('sure', 26),
#  ('matter', 26),
#  ('sergeant', 26),
#  ('gave', 26),
#  ('brush', 26),
#  ('shot', 26),
#  ('seat', 25),
#  ('next', 25),
#  ('smiled', 25),
#  ('new', 25),
#  ('villa', 25),
#  ('almost', 25),
#  ('hot', 25),
#  ('german', 25),
#  ('mind', 25),
#  ('god', 25),
#  ('hear', 25),
#  ('retreat', 25),
#  ('barman', 25),
#  ('top', 24),
#  ('glad', 24),
#  ('bridge', 24),
#  ('wore', 24),
#  ('money', 24),
#  ('beauti', 24),
#  ('good-night', 24),
#  ('drunk', 24),
#  ('breakfast', 24),
#  ('kept', 24),
#  ('soon', 24),
#  ('plain', 23),
#  ('mess', 23),
#  ('hospital', 23),
#  ('mask', 23),
#  ('table', 23),
#  ('word', 23),
#  ('leg', 23),
#  ('step', 23),
#  ('passini', 23),
#  ('montreux', 23),
#  ('sun', 22),
#  ('gray', 22),
#  ('north', 22),
#  ('countri', 22),
#  ('fast', 22),
#  ('smile', 22),
#  ('father', 22),
#  ('without', 22),
#  ('hell', 22),
#  ('post', 22),
#  ('hair', 22),
#  ('drop', 22),
#  ('send', 22),
#  ('thin', 21),
#  ('narrow', 21),
#  ('care', 21),
#  ('tabl', 21),
#  ('show', 21),
#  ('enough', 21),
#  ('anyway', 21),
#  ('shut', 21),
#  ('good-by', 21),
#  ('main', 21),
#  ('cat', 21),
#  ('year', 20),
#  ('bare', 20),
#  ('except', 20),
#  ('neck', 20),
#  ('country', 20),
#  ('name', 20),
#  ('four', 20),
#  ('found', 20),
#  ('milan', 20),
#  ('need', 20),
#  ('lunch', 20),
#  ('empti', 20),
#  ('splendid', 20),
#  ('started', 20),
#  ('shoulder', 20),
#  ('whi', 20),
#  ('wonder', 20),
#  ('orderli', 20),
#  ('climb', 20),
#  ('wood', 20),
#  ('woman', 20),
#  ('bag', 20),
#  ('beer', 20),
#  ('mountains', 19),
#  ('dri', 19),
#  ('troop', 19),
#  ('probabl', 19),
#  ('ran', 19),
#  ('taken', 19),
#  ('later', 19),
#  ('ate', 19),
#  ('help', 19),
#  ('things', 19),
#  ('hill', 19),
#  ('british', 19),
#  ('warm', 19),
#  ('morn', 19),
#  ('suppos', 19),
#  ('sweet', 19),
#  ('home', 19),
#  ('drove', 19),
#  ('yet', 19),
#  ('life', 19),
#  ('something', 19),
#  ('knee', 19),
#  ('gun', 18),
#  ('garden', 18),
#  ('lift', 18),
#  ('use', 18),
#  ('order', 18),
#  ('girls', 18),
#  ('laughed', 18),
#  ('shell', 18),
#  ('wake', 18),
#  ('morning', 18),
#  ('second', 18),
#  ('aw', 18),
#  ('done', 18),
#  ('happen', 18),
#  ('clock', 18),
#  ('question', 18),
#  ('ride', 18),
#  ('onto', 18),
#  ('seen', 18),
#  ('breath', 18),
#  ('forward', 17),
#  ('nearli', 17),
#  ('railway', 17),
#  ('everyth', 17),
#  ('red', 17),
#  ('uniform', 17),
#  ('hit', 17),
#  ('smell', 17),
#  ('full', 17),
#  ('final', 17),
#  ('pleasant', 17),
#  ('happy', 17),
#  ('thi', 17),
#  ('realiz', 17),
#  ('drive', 17),
#  ('wave', 17),
#  ('wheel', 17),
#  ('column', 17),
#  ('manera', 17),
#  ('guard', 17),
#  ('coat', 17),
#  ('wife', 17),
#  ('grand', 17),
#  ('oar', 17),
#  ('sport', 17),
#  ('trees', 16),
#  ('friend', 16),
#  ('pick', 16),
#  ('shoot', 16),
#  ('ambul', 16),
#  ('clean', 16),
#  ('flat', 16),
#  ('woke', 16),
#  ('blow', 16),
#  ('cars', 16),
#  ('rememb', 16),
#  ('quiet', 16),
#  ('carabinieri', 16),
#  ('please', 16),
#  ('mean', 16),
#  ('poor', 16),
#  ('dear', 16),
#  ('chair', 16),
#  ('arrest', 16),
#  ('cloth', 16),
#  ('stretcher', 16),
#  ('umbrella', 16),
#  ('late', 15),
#  ('summer', 15),
#  ('afterward', 15),
#  ('past', 15),
#  ('box', 15),
#  ('truck', 15),
#  ('army', 15),
#  ('south', 15),
#  ('café', 15),
#  ('differ', 15),
#  ('broken', 15),
#  ('pour', 15),
#  ('fill', 15),
#  ('five', 15),
#  ('finger', 15),
#  ('marri', 15),
#  ('hurt', 15),
#  ('hat', 15),
#  ('papers', 15),
#  ('near', 15),
#  ('nurse', 15),
#  ('together', 15),
#  ('may', 15),
#  ('finish', 15),
#  ('short', 15),
#  ('low', 15),
#  ('gordini', 15),
#  ('hour', 15),
#  ('cognac', 15),
#  ('alon', 15),
#  ('udine', 15),
#  ('push', 15),
#  ('bar', 15),
#  ('earli', 14),
#  ('fight', 14),
#  ('motor', 14),
#  ('valley', 14),
#  ('officers', 14),
#  ('beard', 14),
#  ('last', 14),
#  ('understand', 14),
#  ('listen', 14),
#  ('touch', 14),
#  ('perhap', 14),
#  ('sick', 14),
#  ('tall', 14),
#  ('edg', 14),
#  ('babi', 14),
#  ('armi', 14),
#  ('danger', 14),
#  ('sever', 14),
#  ('to-morrow', 14),
#  ('piec', 14),
#  ('little', 14),
#  ('embankment', 14),
#  ('hay', 14),
#  ('count', 14),
#  ('switzerland', 14),
#  ('offici', 14),
#  ('load', 13),
#  ('canva', 13),
#  ('cloud', 13),
#  ('cape', 13),
#  ('whole', 13),
#  ('slowli', 13),
#  ('young', 13),
#  ('rest', 13),
#  ('spoke', 13),
#  ('eye', 13),
#  ('joke', 13),
#  ('rome', 13),
#  ('spring', 13),
#  ('foot', 13),
#  ('learn', 13),
#  ('run', 13),
#  ('becom', 13),
#  ('regiment', 13),
#  ('pretti', 13),
#  ('trouble', 13),
#  ('christ', 13),
#  ('porter', 13),
#  ('outside', 13),
#  ('follow', 13),
#  ('tie', 13),
#  ('cheese', 13),
#  ('married', 13),
#  ('break', 13),
#  ('fergy', 13),
#  ('whiskey', 13),
#  ('flash', 12),
#  ('forest', 12),
#  ('black', 12),
#  ('hung', 12),
#  ('true', 12),
#  ('write', 12),
#  ('coffe', 12),
#  ('strang', 12),
#  ('abl', 12),
#  ('air', 12),
#  ('engin', 12),
#  ('crack', 12),
#  ('really', 12),
#  ('wide', 12),
#  ('everybodi', 12),
#  ('cart', 12),
#  ('wear', 12),
#  ('else', 12),
#  ('ice', 12),
#  ('hurri', 12),
#  ('chees', 12),
#  ('straight', 12),
#  ('reach', 12),
#  ('fun', 12),
#  ('carriag', 12),
#  ('gino', 12),
#  ('daylight', 12),
#  ('opposit', 12),
#  ('greffi', 12),
#  ('fell', 11),
#  ('brown', 11),
#  ('cool', 11),
#  ('mud', 11),
#  ('child', 11),
#  ('cap', 11),
#  ('led', 11),
#  ('lost', 11),
#  ('suddenli', 11),
#  ('commenc', 11),
#  ('lieutenant', 11),
#  ('asleep', 11),
#  ('san', 11),
#  ('wounded', 11),
#  ('smoke', 11),
#  ('alone', 11),
#  ('sorry', 11),
#  ('sent', 11),
#  ('cours', 11),
#  ('dugout', 11),
#  ('game', 11),
#  ('gotten', 11),
#  ('pistol', 11),
#  ('medic', 11),
#  ('saint', 11),
#  ('track', 11),
#  ('screen', 11),
#  ('feet', 11),
#  ('sister', 11),
#  ('luck', 11),
#  ('stomach', 11),
#  ('pain', 11),
#  ('stair', 11),
#  ('expect', 11),
#  ('grow', 11),
#  ('locarno', 11),
#  ('dust', 10),
#  ('storm', 10),
#  ('muddi', 10),
#  ('house', 10),
#  ('ground', 10),
#  ('course', 10),
#  ('mouth', 10),
#  ('lose', 10),
#  ('abruzzi', 10),
#  ('report', 10),
#  ('helmet', 10),
#  ('afternoon', 10),
#  ('wash', 10),
#  ('to-night', 10),
#  ('everything', 10),
#  ('shirt', 10),
#  ('badli', 10),
#  ('forget', 10),
#  ('signor', 10),
#  ('wipe', 10),
#  ('bottle', 10),
#  ('sort', 10),
#  ('fool', 10),
#  ('silli', 10),
#  ('somebodi', 10),
#  ('henry', 10),
#  ('worry', 10),
#  ('tight', 10),
#  ('driveway', 10),
#  ('trip', 10),
#  ('rotten', 10),
#  ('sound', 10),
#  ('oper', 10),
#  ('togeth', 10),
#  ('soup', 10),
#  ('brandy', 10),
#  ('corridor', 10),
#  ('corner', 10),
#  ('bags', 10),
#  ('march', 9),
#  ('rifl', 9),
#  ('pack', 9),
#  ('usual', 9),
#  ('going', 9),
#  ('gorizia', 9),
#  ('mile', 9),
#  ('chang', 9),
#  ('dull', 9),
#  ('path', 9),
#  ('els', 9),
#  ('pocket', 9),
#  ('lieuten', 9),
#  ('offens', 9),
#  ('met', 9),
#  ('whether', 9),
#  ('best', 9),
#  ('world', 9),
#  ('kitchen', 9),
#  ('part', 9),
#  ('dirti', 9),
#  ('minute', 9),
#  ('stick', 9),
#  ('mother', 9),
#  ('wors', 9),
#  ('lot', 9),
#  ('either', 9),
#  ('half', 9),
#  ('dinner', 9),
#  ('rather', 9),
#  ('brave', 9),
#  ('slap', 9),
#  ('crying', 9),
#  ('speak', 9),
#  ('deep', 9),
#  ('stupid', 9),
#  ('damn', 9),
#  ('hundr', 9),
#  ('stream', 9),
#  ('vermouth', 9),
#  ('bainsizza', 9),
#  ('germans', 9),
#  ('stove', 9),
#  ('barto', 9),
#  ('troops', 9),
#  ('hungry', 9),
#  ('barn', 9),
#  ('stern', 9),
#  ('swiss', 9),
#  ('waiter', 9),
#  ('trunk', 8),
#  ('coming', 8),
#  ('cover', 8),
#  ('green', 8),
#  ('bombard', 8),
#  ('metal', 8),
#  ('lovely', 8),
#  ('often', 8),
#  ('card', 8),
#  ('shadow', 8),
#  ('cup', 8),
#  ('kind', 8),
#  ('real', 8),
#  ('basin', 8),
#  ('eyes', 8),
#  ('lire', 8),
#  ('note', 8),
#  ('happi', 8),
#  ('comfort', 8),
#  ('troubl', 8),
#  ('begin', 8),
#  ('grappa', 8),
#  ('blew', 8),
#  ('nobodi', 8),
#  ('bit', 8),
#  ('burst', 8),
#  ('lean', 8),
#  ('pat', 8),
#  ('wooden', 8),
#  ('bloodi', 8),
#  ('hands', 8),
#  ('crazy', 8),
#  ('happened', 8),
#  ('french', 8),
#  ('sheet', 8),
#  ('coffee', 8),
#  ('sorri', 8),
#  ('ridg', 8),
#  ('dug', 8),
#  ('food', 8),
#  ('hate', 8),
#  ('ye', 8),
#  ('nois', 8),
#  ('mama', 8),
#  ('worri', 8),
#  ('bent', 8),
#  ('blood', 8),
#  ('slept', 8),
#  ('plenti', 8),
#  ('older', 8),
#  ('cheer', 8),
#  ('meat', 8),
#  ('mi', 8),
#  ('cry', 8),
#  ('timber', 8),
#  ('buy', 8),
#  ('custom', 8),
#  ('moon', 8),
#  ('egg', 8),
#  ('guttingen', 8),
#  ('dial', 8),
#  ('soda', 8),
#  ('villag', 7),
#  ('rise', 7),
#  ('branch', 7),
#  ('leather', 7),
#  ('heavi', 7),
#  ('king', 7),
#  ('thick', 7),
#  ('iron', 7),
#  ('smash', 7),
#  ('bodi', 7),
#  ('spaghetti', 7),
#  ('tunic', 7),
#  ('laugh', 7),
#  ('son', 7),
#  ('address', 7),
#  ('ha', 7),
#  ('spread', 7),
#  ('thumb', 7),
#  ('shouted', 7),
#  ('family', 7),
#  ('guns', 7),
#  ('bench', 7),
#  ('marbl', 7),
#  ('desk', 7),
#  ('ga', 7),
#  ('steel', 7),
#  ('ciaou', 7),
#  ('understood', 7),
#  ('ten', 7),
#  ('yard', 7),
#  ('smooth', 7),
#  ('haul', 7),
#  ('nose', 7),
#  ('return', 7),
#  ('italy', 7),
#  ('notic', 7),
#  ('studi', 7),
#  ('evening', 7),
#  ('machine-gun', 7),
#  ('level', 7),
#  ('shelter', 7),
#  ('certain', 7),
#  ('knock', 7),
#  ('also', 7),
#  ('third', 7),
#  ('brother', 7),
#  ('instead', 7),
#  ('closer', 7),
#  ('bump', 7),
#  ('hors', 7),
#  ('handl', 7),
#  ('america', 7),
#  ('business', 7),
#  ('austria', 7),
#  ('roof', 7),
#  ('everybody', 7),
#  ('stori', 7),
#  ('hello', 7),
#  ('caught', 7),
#  ('moment', 7),
#  ('t.', 7),
#  ('bersaglieri', 7),
#  ('farmhous', 7),
#  ('rough', 7),
#  ('crowd', 7),
#  ('hole', 7),
#  ('stopped', 7),
#  ('gavuzzi', 7),
#  ('fighting', 7),
#  ('sing', 7),
#  ('scare', 7),
#  ('canteen', 7),
#  ('mia', 7),
#  ('shoe', 7),
#  ('others', 7),
#  ('fellow', 7),
#  ('born', 7),
#  ('declar', 7),
#  ('officer', 7),
#  ('number', 7),
#  ('save', 7),
#  ('wise', 7),
#  ('mine', 7),
#  ('stiff', 7),
#  ('throw', 7),
#  ('comes', 7),
#  ('bread', 7),
#  ('sleepy', 7),
#  ('clothes', 7),
#  ('boot', 7),
#  ('roll', 7),
#  ('tagliamento', 7),
#  ('ditch', 7),
#  ('answer', 7),
#  ('stresa', 7),
#  ('passport', 7),
#  ('toboggan', 7),
#  ('mrs.', 7),
#  ('ham', 7),
#  ('traffic', 6),
#  ('chestnut', 6),
#  ('camion', 6),
#  ('seven', 6),
#  ('artilleri', 6),
#  ('sky', 6),
#  ('none', 6),
#  ('win', 6),
#  ('famili', 6),
#  ('capri', 6),
#  ('success', 6),
#  ('women', 6),
#  ('sunlight', 6),
#  ('upstair', 6),
#  ('courtyard', 6),
#  ('blanket', 6),
#  ('tin', 6),
#  ('wonderful', 6),
#  ('anybodi', 6),
#  ('soft', 6),
#  ('friends', 6),
#  ('hang', 6),
#  ('peasant', 6),
#  ('excit', 6),
#  ('sharp', 6),
#  ('tast', 6),
#  ('although', 6),
#  ('meal', 6),
#  ('twice', 6),
#  ('another', 6),
#  ('till', 6),
#  ('stairs', 6),
#  ('ambulance', 6),
#  ('fifteen', 6),
#  ('plava', 6),
#  ('lead', 6),
#  ('bright', 6),
#  ('difference', 6),
#  ('becaus', 6),
#  ('dog', 6),
#  ('pillow', 6),
#  ('civilian', 6),
#  ('jerk', 6),
#  ('people', 6),
#  ('sometimes', 6),
#  ('inside', 6),
#  ('collar', 6),
#  ('forehead', 6),
#  ('trouser', 6),
#  ('elev', 6),
#  ('silver', 6),
#  ('island', 6),
#  ('teeth', 6),
#  ('bassi', 6),
#  ('federico', 6),
#  ('hail', 6),
#  ('hardli', 6),
#  ('rail', 6),
#  ('jam', 6),
#  ('goe', 6),
#  ('defeat', 6),
#  ('itali', 6),
#  ('board', 6),
#  ('tables', 6),
#  ('shout', 6),
#  ('legs', 6),
#  ('readi', 6),
#  ('possibl', 6),
#  ('brandi', 6),
#  ('easily', 6),
#  ('awak', 6),
#  ('talking', 6),
#  ('cork', 6),
#  ('serv', 6),
#  ('reason', 6),
#  ('pay', 6),
#  ('carriage', 6),
#  ('compart', 6),
#  ('cheerful', 6),
#  ('thinking', 6),
#  ('wisdom', 6),
#  ('pordenone', 6),
#  ('bartolomeo', 6),
#  ('lights', 6),
#  ('younger', 6),
#  ('minut', 6),
#  ('began', 6),
#  ('mirror', 6),
#  ('side-road', 6),
#  ('hedg', 6),
#  ('abandon', 6),
#  ('feeling', 6),
#  ('catch', 6),
#  ('paid', 6),
#  ('downstair', 6),
#  ('bought', 6),
#  ('billiard', 6),
#  ('devout', 6),
#  ('pallanza', 6),
#  ('ski', 6),
#  ('log', 6),
#  ('caesarean', 6),
#  ('vine', 5),
#  ('laid', 5),
#  ('mist', 5),
#  ('clip', 5),
#  ('month', 5),
#  ('plateau', 5),
#  ('militari', 5),
#  ('houses', 5),
#  ('yellow', 5),
#  ('falling', 5),
#  ('suck', 5),
#  ('swung', 5),
#  ('to-day', 5),
#  ('book', 5),
#  ('certainli', 5),
#  ('leave', 5),
#  ('boots', 5),
#  ('oil', 5),
#  ('lock', 5),
#  ('sinc', 5),
#  ('rock', 5),
#  ('fold', 5),
#  ('impress', 5),
#  ('unless', 5),
#  ('alike', 5),
#  ('dressed', 5),
#  ('mechan', 5),
#  ('protect', 5),
#  ('busi', 5),
#  ('depend', 5),
#  ('meant', 5),
#  ('shone', 5),
#  ('salut', 5),
#  ('skin', 5),
#  ('idea', 5),
#  ('different', 5),
#  ('join', 5),
#  ('italians', 5),
#  ('trench', 5),
#  ('telephon', 5),
#  ('steadili', 5),
#  ('austrians', 5),
#  ('rush', 5),
#  ('exactli', 5),
#  ('funni', 5),
#  ('nonsense', 5),
#  ('heat', 5),
#  ('complet', 5),
#  ('pace', 5),
#  ('shame', 5),
#  ('sign', 5),
#  ('pretend', 5),
#  ('deal', 5),
#  ('gabriele', 5),
#  ('helmets', 5),
#  ('slip', 5),
#  ('coupl', 5),
#  ('napoleon', 5),
#  ('fat', 5),
#  ('supper', 5),
#  ('click', 5),
#  ('fli', 5),
#  ('alreadi', 5),
#  ('hallway', 5),
#  ('lone', 5),
#  ('empty', 5),
#  ('spill', 5),
#  ('chain', 5),
#  ('settl', 5),
#  ('separ', 5),
#  ('rang', 5),
#  ('mat', 5),
#  ('entranc', 5),
#  ('brickyard', 5),
#  ('earth', 5),
#  ('worse', 5),
#  ('nation', 5),
#  ...]

# %%
word_fdic = dict(word_f)
word_fdic
# Out:
# {'said': 945,
#  'go': 441,
#  'went': 293,
#  'look': 290,
#  'would': 254,
#  'one': 245,
#  'see': 232,
#  'could': 219,
#  'back': 219,
#  'get': 218,
#  'come': 215,
#  'want': 188,
#  'road': 187,
#  'like': 186,
#  'came': 186,
#  'catherin': 178,
#  'right': 164,
#  'know': 159,
#  'good': 150,
#  'yes': 136,
#  'think': 132,
#  'two': 131,
#  'time': 121,
#  'r': 120,
#  'littl': 118,
#  'us': 114,
#  'away': 111,
#  'saw': 110,
#  'rain': 107,
#  'take': 107,
#  'put': 103,
#  'much': 99,
#  'long': 99,
#  'bed': 98,
#  'along': 98,
#  'rinaldi': 98,
#  'car': 97,
#  'love': 94,
#  'room': 94,
#  'night': 93,
#  'war': 93,
#  'hand': 93,
#  'let': 91,
#  'darling': 91,
#  'start': 90,
#  'side': 87,
#  'priest': 87,
#  'took': 86,
#  'dark': 84,
#  'way': 84,
#  'walk': 84,
#  'sat': 83,
#  'stop': 83,
#  'piani': 80,
#  'got': 79,
#  'tell': 77,
#  'make': 75,
#  'bonello': 75,
#  'feel': 74,
#  'thing': 74,
#  'never': 74,
#  'say': 73,
#  'across': 72,
#  'mountain': 72,
#  'window': 72,
#  'fine': 71,
#  'door': 71,
#  'talk': 71,
#  'place': 70,
#  'major': 69,
#  'open': 69,
#  'tenente': 69,
#  'big': 67,
#  'doctor': 67,
#  'asked': 66,
#  'river': 65,
#  'thought': 65,
#  'someth': 64,
#  'drink': 63,
#  'better': 63,
#  'oh': 63,
#  'mani': 62,
#  'head': 62,
#  'v': 62,
#  'ask': 61,
#  'turn': 61,
#  'anoth': 60,
#  'girl': 60,
#  'man': 59,
#  'line': 59,
#  'aymo': 59,
#  'lake': 59,
#  'face': 58,
#  'well': 58,
#  'die': 57,
#  'watch': 57,
#  'light': 57,
#  'water': 56,
#  'knew': 56,
#  'outsid': 55,
#  'stay': 54,
#  'sleep': 54,
#  'town': 53,
#  'glass': 53,
#  'held': 53,
#  'italian': 53,
#  'felt': 53,
#  'must': 52,
#  'alway': 52,
#  'gone': 51,
#  'bad': 51,
#  'wine': 50,
#  'give': 50,
#  'first': 50,
#  'still': 50,
#  'close': 50,
#  'tri': 50,
#  'toward': 50,
#  'front': 49,
#  'around': 49,
#  'work': 49,
#  'heard': 48,
#  'wet': 48,
#  'made': 48,
#  'eat': 48,
#  'move': 47,
#  'day': 47,
#  'left': 47,
#  'anyth': 47,
#  'stood': 47,
#  'men': 46,
#  'three': 46,
#  'cross': 45,
#  'wish': 45,
#  'hold': 45,
#  'ahead': 45,
#  'old': 44,
#  'baby': 44,
#  'besid': 44,
#  'sit': 43,
#  'noth': 43,
#  'english': 43,
#  'miss': 43,
#  'pass': 42,
#  'snow': 42,
#  'believ': 42,
#  'hotel': 42,
#  'boat': 42,
#  'tree': 41,
#  'offic': 41,
#  'row': 41,
#  'pull': 40,
#  'fire': 40,
#  'nurs': 40,
#  'hall': 40,
#  'peopl': 39,
#  'cut': 39,
#  'paper': 39,
#  'austrian': 38,
#  'cold': 38,
#  'hard': 38,
#  'brought': 38,
#  'hous': 37,
#  'beyond': 37,
#  'floor': 37,
#  'lay': 37,
#  'leav': 36,
#  'behind': 36,
#  'wall': 36,
#  'field': 36,
#  'station': 36,
#  'boy': 36,
#  'driver': 35,
#  'even': 35,
#  'everi': 35,
#  'wind': 35,
#  'might': 35,
#  'american': 35,
#  'far': 35,
#  'catherine': 35,
#  'mayb': 35,
#  'live': 34,
#  'sometim': 34,
#  'great': 34,
#  'train': 34,
#  'soldier': 33,
#  'small': 33,
#  'nice': 33,
#  'seem': 33,
#  'realli': 33,
#  'arm': 33,
#  'attack': 33,
#  'keep': 33,
#  'ferguson': 33,
#  'ever': 32,
#  'barkley': 32,
#  'call': 32,
#  'lie': 32,
#  'pleas': 32,
#  'end': 31,
#  'hope': 31,
#  'shore': 31,
#  'clear': 30,
#  'street': 30,
#  'captain': 30,
#  'point': 30,
#  'wound': 30,
#  'afraid': 30,
#  'white': 29,
#  'carri': 29,
#  'hospit': 29,
#  'bring': 29,
#  'wait': 29,
#  'tire': 29,
#  'stone': 29,
#  'quit': 29,
#  'kill': 29,
#  'stand': 29,
#  'find': 29,
#  'bridg': 29,
#  'thank': 29,
#  'fall': 28,
#  'bottl': 28,
#  'shook': 28,
#  'sight': 28,
#  'read': 28,
#  'ought': 28,
#  'dress': 28,
#  'drank': 28,
#  'told': 28,
#  'high': 28,
#  'play': 28,
#  'bank': 28,
#  'dead': 27,
#  'nothing': 27,
#  'anything': 27,
#  'tired': 27,
#  'though': 26,
#  'winter': 26,
#  'insid': 26,
#  'kiss': 26,
#  'sure': 26,
#  'matter': 26,
#  'sergeant': 26,
#  'gave': 26,
#  'brush': 26,
#  'shot': 26,
#  'seat': 25,
#  'next': 25,
#  'smiled': 25,
#  'new': 25,
#  'villa': 25,
#  'almost': 25,
#  'hot': 25,
#  'german': 25,
#  'mind': 25,
#  'god': 25,
#  'hear': 25,
#  'retreat': 25,
#  'barman': 25,
#  'top': 24,
#  'glad': 24,
#  'bridge': 24,
#  'wore': 24,
#  'money': 24,
#  'beauti': 24,
#  'good-night': 24,
#  'drunk': 24,
#  'breakfast': 24,
#  'kept': 24,
#  'soon': 24,
#  'plain': 23,
#  'mess': 23,
#  'hospital': 23,
#  'mask': 23,
#  'table': 23,
#  'word': 23,
#  'leg': 23,
#  'step': 23,
#  'passini': 23,
#  'montreux': 23,
#  'sun': 22,
#  'gray': 22,
#  'north': 22,
#  'countri': 22,
#  'fast': 22,
#  'smile': 22,
#  'father': 22,
#  'without': 22,
#  'hell': 22,
#  'post': 22,
#  'hair': 22,
#  'drop': 22,
#  'send': 22,
#  'thin': 21,
#  'narrow': 21,
#  'care': 21,
#  'tabl': 21,
#  'show': 21,
#  'enough': 21,
#  'anyway': 21,
#  'shut': 21,
#  'good-by': 21,
#  'main': 21,
#  'cat': 21,
#  'year': 20,
#  'bare': 20,
#  'except': 20,
#  'neck': 20,
#  'country': 20,
#  'name': 20,
#  'four': 20,
#  'found': 20,
#  'milan': 20,
#  'need': 20,
#  'lunch': 20,
#  'empti': 20,
#  'splendid': 20,
#  'started': 20,
#  'shoulder': 20,
#  'whi': 20,
#  'wonder': 20,
#  'orderli': 20,
#  'climb': 20,
#  'wood': 20,
#  'woman': 20,
#  'bag': 20,
#  'beer': 20,
#  'mountains': 19,
#  'dri': 19,
#  'troop': 19,
#  'probabl': 19,
#  'ran': 19,
#  'taken': 19,
#  'later': 19,
#  'ate': 19,
#  'help': 19,
#  'things': 19,
#  'hill': 19,
#  'british': 19,
#  'warm': 19,
#  'morn': 19,
#  'suppos': 19,
#  'sweet': 19,
#  'home': 19,
#  'drove': 19,
#  'yet': 19,
#  'life': 19,
#  'something': 19,
#  'knee': 19,
#  'gun': 18,
#  'garden': 18,
#  'lift': 18,
#  'use': 18,
#  'order': 18,
#  'girls': 18,
#  'laughed': 18,
#  'shell': 18,
#  'wake': 18,
#  'morning': 18,
#  'second': 18,
#  'aw': 18,
#  'done': 18,
#  'happen': 18,
#  'clock': 18,
#  'question': 18,
#  'ride': 18,
#  'onto': 18,
#  'seen': 18,
#  'breath': 18,
#  'forward': 17,
#  'nearli': 17,
#  'railway': 17,
#  'everyth': 17,
#  'red': 17,
#  'uniform': 17,
#  'hit': 17,
#  'smell': 17,
#  'full': 17,
#  'final': 17,
#  'pleasant': 17,
#  'happy': 17,
#  'thi': 17,
#  'realiz': 17,
#  'drive': 17,
#  'wave': 17,
#  'wheel': 17,
#  'column': 17,
#  'manera': 17,
#  'guard': 17,
#  'coat': 17,
#  'wife': 17,
#  'grand': 17,
#  'oar': 17,
#  'sport': 17,
#  'trees': 16,
#  'friend': 16,
#  'pick': 16,
#  'shoot': 16,
#  'ambul': 16,
#  'clean': 16,
#  'flat': 16,
#  'woke': 16,
#  'blow': 16,
#  'cars': 16,
#  'rememb': 16,
#  'quiet': 16,
#  'carabinieri': 16,
#  'please': 16,
#  'mean': 16,
#  'poor': 16,
#  'dear': 16,
#  'chair': 16,
#  'arrest': 16,
#  'cloth': 16,
#  'stretcher': 16,
#  'umbrella': 16,
#  'late': 15,
#  'summer': 15,
#  'afterward': 15,
#  'past': 15,
#  'box': 15,
#  'truck': 15,
#  'army': 15,
#  'south': 15,
#  'café': 15,
#  'differ': 15,
#  'broken': 15,
#  'pour': 15,
#  'fill': 15,
#  'five': 15,
#  'finger': 15,
#  'marri': 15,
#  'hurt': 15,
#  'hat': 15,
#  'papers': 15,
#  'near': 15,
#  'nurse': 15,
#  'together': 15,
#  'may': 15,
#  'finish': 15,
#  'short': 15,
#  'low': 15,
#  'gordini': 15,
#  'hour': 15,
#  'cognac': 15,
#  'alon': 15,
#  'udine': 15,
#  'push': 15,
#  'bar': 15,
#  'earli': 14,
#  'fight': 14,
#  'motor': 14,
#  'valley': 14,
#  'officers': 14,
#  'beard': 14,
#  'last': 14,
#  'understand': 14,
#  'listen': 14,
#  'touch': 14,
#  'perhap': 14,
#  'sick': 14,
#  'tall': 14,
#  'edg': 14,
#  'babi': 14,
#  'armi': 14,
#  'danger': 14,
#  'sever': 14,
#  'to-morrow': 14,
#  'piec': 14,
#  'little': 14,
#  'embankment': 14,
#  'hay': 14,
#  'count': 14,
#  'switzerland': 14,
#  'offici': 14,
#  'load': 13,
#  'canva': 13,
#  'cloud': 13,
#  'cape': 13,
#  'whole': 13,
#  'slowli': 13,
#  'young': 13,
#  'rest': 13,
#  'spoke': 13,
#  'eye': 13,
#  'joke': 13,
#  'rome': 13,
#  'spring': 13,
#  'foot': 13,
#  'learn': 13,
#  'run': 13,
#  'becom': 13,
#  'regiment': 13,
#  'pretti': 13,
#  'trouble': 13,
#  'christ': 13,
#  'porter': 13,
#  'outside': 13,
#  'follow': 13,
#  'tie': 13,
#  'cheese': 13,
#  'married': 13,
#  'break': 13,
#  'fergy': 13,
#  'whiskey': 13,
#  'flash': 12,
#  'forest': 12,
#  'black': 12,
#  'hung': 12,
#  'true': 12,
#  'write': 12,
#  'coffe': 12,
#  'strang': 12,
#  'abl': 12,
#  'air': 12,
#  'engin': 12,
#  'crack': 12,
#  'really': 12,
#  'wide': 12,
#  'everybodi': 12,
#  'cart': 12,
#  'wear': 12,
#  'else': 12,
#  'ice': 12,
#  'hurri': 12,
#  'chees': 12,
#  'straight': 12,
#  'reach': 12,
#  'fun': 12,
#  'carriag': 12,
#  'gino': 12,
#  'daylight': 12,
#  'opposit': 12,
#  'greffi': 12,
#  'fell': 11,
#  'brown': 11,
#  'cool': 11,
#  'mud': 11,
#  'child': 11,
#  'cap': 11,
#  'led': 11,
#  'lost': 11,
#  'suddenli': 11,
#  'commenc': 11,
#  'lieutenant': 11,
#  'asleep': 11,
#  'san': 11,
#  'wounded': 11,
#  'smoke': 11,
#  'alone': 11,
#  'sorry': 11,
#  'sent': 11,
#  'cours': 11,
#  'dugout': 11,
#  'game': 11,
#  'gotten': 11,
#  'pistol': 11,
#  'medic': 11,
#  'saint': 11,
#  'track': 11,
#  'screen': 11,
#  'feet': 11,
#  'sister': 11,
#  'luck': 11,
#  'stomach': 11,
#  'pain': 11,
#  'stair': 11,
#  'expect': 11,
#  'grow': 11,
#  'locarno': 11,
#  'dust': 10,
#  'storm': 10,
#  'muddi': 10,
#  'house': 10,
#  'ground': 10,
#  'course': 10,
#  'mouth': 10,
#  'lose': 10,
#  'abruzzi': 10,
#  'report': 10,
#  'helmet': 10,
#  'afternoon': 10,
#  'wash': 10,
#  'to-night': 10,
#  'everything': 10,
#  'shirt': 10,
#  'badli': 10,
#  'forget': 10,
#  'signor': 10,
#  'wipe': 10,
#  'bottle': 10,
#  'sort': 10,
#  'fool': 10,
#  'silli': 10,
#  'somebodi': 10,
#  'henry': 10,
#  'worry': 10,
#  'tight': 10,
#  'driveway': 10,
#  'trip': 10,
#  'rotten': 10,
#  'sound': 10,
#  'oper': 10,
#  'togeth': 10,
#  'soup': 10,
#  'brandy': 10,
#  'corridor': 10,
#  'corner': 10,
#  'bags': 10,
#  'march': 9,
#  'rifl': 9,
#  'pack': 9,
#  'usual': 9,
#  'going': 9,
#  'gorizia': 9,
#  'mile': 9,
#  'chang': 9,
#  'dull': 9,
#  'path': 9,
#  'els': 9,
#  'pocket': 9,
#  'lieuten': 9,
#  'offens': 9,
#  'met': 9,
#  'whether': 9,
#  'best': 9,
#  'world': 9,
#  'kitchen': 9,
#  'part': 9,
#  'dirti': 9,
#  'minute': 9,
#  'stick': 9,
#  'mother': 9,
#  'wors': 9,
#  'lot': 9,
#  'either': 9,
#  'half': 9,
#  'dinner': 9,
#  'rather': 9,
#  'brave': 9,
#  'slap': 9,
#  'crying': 9,
#  'speak': 9,
#  'deep': 9,
#  'stupid': 9,
#  'damn': 9,
#  'hundr': 9,
#  'stream': 9,
#  'vermouth': 9,
#  'bainsizza': 9,
#  'germans': 9,
#  'stove': 9,
#  'barto': 9,
#  'troops': 9,
#  'hungry': 9,
#  'barn': 9,
#  'stern': 9,
#  'swiss': 9,
#  'waiter': 9,
#  'trunk': 8,
#  'coming': 8,
#  'cover': 8,
#  'green': 8,
#  'bombard': 8,
#  'metal': 8,
#  'lovely': 8,
#  'often': 8,
#  'card': 8,
#  'shadow': 8,
#  'cup': 8,
#  'kind': 8,
#  'real': 8,
#  'basin': 8,
#  'eyes': 8,
#  'lire': 8,
#  'note': 8,
#  'happi': 8,
#  'comfort': 8,
#  'troubl': 8,
#  'begin': 8,
#  'grappa': 8,
#  'blew': 8,
#  'nobodi': 8,
#  'bit': 8,
#  'burst': 8,
#  'lean': 8,
#  'pat': 8,
#  'wooden': 8,
#  'bloodi': 8,
#  'hands': 8,
#  'crazy': 8,
#  'happened': 8,
#  'french': 8,
#  'sheet': 8,
#  'coffee': 8,
#  'sorri': 8,
#  'ridg': 8,
#  'dug': 8,
#  'food': 8,
#  'hate': 8,
#  'ye': 8,
#  'nois': 8,
#  'mama': 8,
#  'worri': 8,
#  'bent': 8,
#  'blood': 8,
#  'slept': 8,
#  'plenti': 8,
#  'older': 8,
#  'cheer': 8,
#  'meat': 8,
#  'mi': 8,
#  'cry': 8,
#  'timber': 8,
#  'buy': 8,
#  'custom': 8,
#  'moon': 8,
#  'egg': 8,
#  'guttingen': 8,
#  'dial': 8,
#  'soda': 8,
#  'villag': 7,
#  'rise': 7,
#  'branch': 7,
#  'leather': 7,
#  'heavi': 7,
#  'king': 7,
#  'thick': 7,
#  'iron': 7,
#  'smash': 7,
#  'bodi': 7,
#  'spaghetti': 7,
#  'tunic': 7,
#  'laugh': 7,
#  'son': 7,
#  'address': 7,
#  'ha': 7,
#  'spread': 7,
#  'thumb': 7,
#  'shouted': 7,
#  'family': 7,
#  'guns': 7,
#  'bench': 7,
#  'marbl': 7,
#  'desk': 7,
#  'ga': 7,
#  'steel': 7,
#  'ciaou': 7,
#  'understood': 7,
#  'ten': 7,
#  'yard': 7,
#  'smooth': 7,
#  'haul': 7,
#  'nose': 7,
#  'return': 7,
#  'italy': 7,
#  'notic': 7,
#  'studi': 7,
#  'evening': 7,
#  'machine-gun': 7,
#  'level': 7,
#  'shelter': 7,
#  'certain': 7,
#  'knock': 7,
#  'also': 7,
#  'third': 7,
#  'brother': 7,
#  'instead': 7,
#  'closer': 7,
#  'bump': 7,
#  'hors': 7,
#  'handl': 7,
#  'america': 7,
#  'business': 7,
#  'austria': 7,
#  'roof': 7,
#  'everybody': 7,
#  'stori': 7,
#  'hello': 7,
#  'caught': 7,
#  'moment': 7,
#  't.': 7,
#  'bersaglieri': 7,
#  'farmhous': 7,
#  'rough': 7,
#  'crowd': 7,
#  'hole': 7,
#  'stopped': 7,
#  'gavuzzi': 7,
#  'fighting': 7,
#  'sing': 7,
#  'scare': 7,
#  'canteen': 7,
#  'mia': 7,
#  'shoe': 7,
#  'others': 7,
#  'fellow': 7,
#  'born': 7,
#  'declar': 7,
#  'officer': 7,
#  'number': 7,
#  'save': 7,
#  'wise': 7,
#  'mine': 7,
#  'stiff': 7,
#  'throw': 7,
#  'comes': 7,
#  'bread': 7,
#  'sleepy': 7,
#  'clothes': 7,
#  'boot': 7,
#  'roll': 7,
#  'tagliamento': 7,
#  'ditch': 7,
#  'answer': 7,
#  'stresa': 7,
#  'passport': 7,
#  'toboggan': 7,
#  'mrs.': 7,
#  'ham': 7,
#  'traffic': 6,
#  'chestnut': 6,
#  'camion': 6,
#  'seven': 6,
#  'artilleri': 6,
#  'sky': 6,
#  'none': 6,
#  'win': 6,
#  'famili': 6,
#  'capri': 6,
#  'success': 6,
#  'women': 6,
#  'sunlight': 6,
#  'upstair': 6,
#  'courtyard': 6,
#  'blanket': 6,
#  'tin': 6,
#  'wonderful': 6,
#  'anybodi': 6,
#  'soft': 6,
#  'friends': 6,
#  'hang': 6,
#  'peasant': 6,
#  'excit': 6,
#  'sharp': 6,
#  'tast': 6,
#  'although': 6,
#  'meal': 6,
#  'twice': 6,
#  'another': 6,
#  'till': 6,
#  'stairs': 6,
#  'ambulance': 6,
#  'fifteen': 6,
#  'plava': 6,
#  'lead': 6,
#  'bright': 6,
#  'difference': 6,
#  'becaus': 6,
#  'dog': 6,
#  'pillow': 6,
#  'civilian': 6,
#  'jerk': 6,
#  'people': 6,
#  'sometimes': 6,
#  'inside': 6,
#  'collar': 6,
#  'forehead': 6,
#  'trouser': 6,
#  'elev': 6,
#  'silver': 6,
#  'island': 6,
#  'teeth': 6,
#  'bassi': 6,
#  'federico': 6,
#  'hail': 6,
#  'hardli': 6,
#  'rail': 6,
#  'jam': 6,
#  'goe': 6,
#  'defeat': 6,
#  'itali': 6,
#  'board': 6,
#  'tables': 6,
#  'shout': 6,
#  'legs': 6,
#  'readi': 6,
#  'possibl': 6,
#  'brandi': 6,
#  'easily': 6,
#  'awak': 6,
#  'talking': 6,
#  'cork': 6,
#  'serv': 6,
#  'reason': 6,
#  'pay': 6,
#  'carriage': 6,
#  'compart': 6,
#  'cheerful': 6,
#  'thinking': 6,
#  'wisdom': 6,
#  'pordenone': 6,
#  'bartolomeo': 6,
#  'lights': 6,
#  'younger': 6,
#  'minut': 6,
#  'began': 6,
#  'mirror': 6,
#  'side-road': 6,
#  'hedg': 6,
#  'abandon': 6,
#  'feeling': 6,
#  'catch': 6,
#  'paid': 6,
#  'downstair': 6,
#  'bought': 6,
#  'billiard': 6,
#  'devout': 6,
#  'pallanza': 6,
#  'ski': 6,
#  'log': 6,
#  'caesarean': 6,
#  'vine': 5,
#  'laid': 5,
#  'mist': 5,
#  'clip': 5,
#  'month': 5,
#  'plateau': 5,
#  'militari': 5,
#  'houses': 5,
#  'yellow': 5,
#  'falling': 5,
#  'suck': 5,
#  'swung': 5,
#  'to-day': 5,
#  'book': 5,
#  'certainli': 5,
#  'leave': 5,
#  'boots': 5,
#  'oil': 5,
#  'lock': 5,
#  'sinc': 5,
#  'rock': 5,
#  'fold': 5,
#  'impress': 5,
#  'unless': 5,
#  'alike': 5,
#  'dressed': 5,
#  'mechan': 5,
#  'protect': 5,
#  'busi': 5,
#  'depend': 5,
#  'meant': 5,
#  'shone': 5,
#  'salut': 5,
#  'skin': 5,
#  'idea': 5,
#  'different': 5,
#  'join': 5,
#  'italians': 5,
#  'trench': 5,
#  'telephon': 5,
#  'steadili': 5,
#  'austrians': 5,
#  'rush': 5,
#  'exactli': 5,
#  'funni': 5,
#  'nonsense': 5,
#  'heat': 5,
#  'complet': 5,
#  'pace': 5,
#  'shame': 5,
#  'sign': 5,
#  'pretend': 5,
#  'deal': 5,
#  'gabriele': 5,
#  'helmets': 5,
#  'slip': 5,
#  'coupl': 5,
#  'napoleon': 5,
#  'fat': 5,
#  'supper': 5,
#  'click': 5,
#  'fli': 5,
#  'alreadi': 5,
#  'hallway': 5,
#  'lone': 5,
#  'empty': 5,
#  'spill': 5,
#  'chain': 5,
#  'settl': 5,
#  'separ': 5,
#  'rang': 5,
#  'mat': 5,
#  'entranc': 5,
#  'brickyard': 5,
#  'earth': 5,
#  'worse': 5,
#  'nation': 5,
#  ...}

# %%
count = 0
s_value = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    s_value.append(s)
    
    count += 1
    
    if count == 1000:
        break

# %%
count = 0
p_values = []

for i, j in new2.items():
    #print (i)
    
    s = j / (word_fdic[i[0]]  * word_fdic[i[1]])
    p = (word_fdic[i[0]]  * word_fdic[i[1]]) * s * s
    p_values.append(p)
    
    count += 1
    
    if count == 1000:
        break

# %%
p_values
# Out:
# [0.02496490659755966,
#  0.11974492205951819,
#  0.029968491766244575,
#  0.012135333236250666,
#  0.03590630698022348,
#  0.01904761904761905,
#  0.010323912762937152,
#  0.021164021164021166,
#  0.013578659810380844,
#  0.008561296859169199,
#  0.02037389770723104,
#  0.0747026083160537,
#  0.020995322444597807,
#  0.005703453734949798,
#  0.0063787375415282396,
#  0.009142857142857142,
#  0.011428571428571429,
#  0.014775413711583923,
#  0.005291005291005291,
#  0.006195596518177163,
#  0.007247678945792153,
#  0.010602719017591813,
#  0.010651355343360586,
#  0.02040989699479664,
#  0.008796622097114707,
#  0.006100217864923747,
#  0.032375478927203064,
#  0.013809728095442383,
#  0.005419272085938753,
#  0.006685457152746873,
#  0.007860922146636432,
#  0.015343447734079635,
#  0.007602019096271969,
#  0.011209756972468838,
#  0.02768831418545402,
#  0.03540475751429098,
#  0.002627257799671593,
#  0.00883367839889579,
#  0.0025561112319103184,
#  0.006449174651939629,
#  0.011197189061044789,
#  0.01318182950836012,
#  0.003745753136294336,
#  0.0017480181302706901,
#  0.017573160990487256,
#  0.0051046775299267,
#  0.0023386726583073617,
#  0.006943788379782711,
#  0.008048767133288313,
#  0.0107684418723903,
#  0.0045662100456621,
#  0.008641975308641974,
#  0.00629822075263738,
#  0.0064277679575767315,
#  0.007324665812122322,
#  0.004551402400864766,
#  0.08164931618697693,
#  0.29069767441860467,
#  0.011316614420062697,
#  0.00536563614744352,
#  0.006692621431219873,
#  0.003341200425748531,
#  0.030136071458385507,
#  0.0038131105095916204,
#  0.005974552830536604,
#  0.0059451722999009134,
#  0.007428466617754952,
#  0.0029055690072639227,
#  0.18663594470046083,
#  0.0058513328035830385,
#  0.0010545520890348477,
#  0.004251500529598682,
#  0.003089091977980867,
#  0.013604481476251,
#  0.006165991039044165,
#  0.0032534053810649556,
#  0.004854287393969934,
#  0.004932582351937191,
#  0.004564479191344863,
#  0.01266261067418509,
#  0.0031042720118350372,
#  0.004602164455470462,
#  0.004344284550638067,
#  0.00536215491600687,
#  0.029854227405247815,
#  0.0038154855056263507,
#  0.0023763111482409728,
#  0.002238838602474966,
#  0.00520960520960521,
#  0.015804420298802323,
#  0.016711229946524065,
#  0.004314146565939334,
#  0.010938259601361206,
#  0.004712831469146662,
#  0.0038651824366110078,
#  0.004251700680272109,
#  0.00944822373393802,
#  0.005606638259699485,
#  0.0028663150653519837,
#  0.027056277056277056,
#  0.002645502645502646,
#  0.04564820450395617,
#  0.02348888192922017,
#  0.003092145949288806,
#  0.00335345405767941,
#  0.006825938566552901,
#  0.024955436720142603,
#  0.01080544682727824,
#  0.0091324200913242,
#  0.023809523809523808,
#  0.003929430633520449,
#  0.0027100271002710027,
#  0.013779527559055118,
#  0.003240740740740741,
#  0.004320987654320987,
#  0.0031331108639228774,
#  0.010223835450695704,
#  0.006199559794570799,
#  0.01071790969051243,
#  0.013903743315508022,
#  0.0023542522811172252,
#  0.0026827525994126515,
#  0.004888066176895934,
#  0.014419795221843005,
#  0.0041266818059727,
#  0.010041592394533571,
#  0.014815464188656088,
#  0.020083184789067142,
#  0.007145877378435517,
#  0.003910407700495164,
#  0.02697956577266922,
#  0.0035236963366068273,
#  0.0031497530519056936,
#  0.003916388579903597,
#  0.004092406044168928,
#  0.007369614512471655,
#  0.006935894278913239,
#  0.013299756039977968,
#  0.0024167024167024167,
#  0.004123560413820027,
#  0.003083378945447911,
#  0.001965230536659108,
#  0.0025547996976568407,
#  0.005040563111429253,
#  0.005911330049261082,
#  0.0011259676284306826,
#  0.005119089939566299,
#  0.005982550893228085,
#  0.00936890045543266,
#  0.02040816326530612,
#  0.015631784628745114,
#  0.039713182570325425,
#  0.018781792095995828,
#  0.02081225610637375,
#  0.0106951871657754,
#  0.003319196016964779,
#  0.007038123167155425,
#  0.005343228200371058,
#  0.00633356790992259,
#  0.05405405405405406,
#  0.006145179874535911,
#  0.0030582988212806634,
#  0.005800837898807606,
#  0.02898550724637681,
#  0.003366294971596886,
#  0.003511081852095677,
#  0.002053651649338981,
#  0.0025396825396825397,
#  0.0031599736668861084,
#  0.001163213376953835,
#  0.0025887175062021357,
#  0.007942636514065085,
#  0.0027337446606549593,
#  0.0013728013728013728,
#  0.00671892497200448,
#  0.0030476190476190473,
#  0.0020317460317460317,
#  0.0030476190476190473,
#  0.0028218694885361554,
#  0.0016210739614994935,
#  0.0038095238095238095,
#  0.02157626610728199,
#  0.024,
#  0.0031850486970255334,
#  0.0017030260380014076,
#  0.025854700854700853,
#  0.005735684489950701,
#  0.041367521367521365,
#  0.005637871586990961,
#  0.012598917117867555,
#  0.0018857044898468061,
#  0.003152437276919469,
#  0.0016258633199860261,
#  0.004213972278331128,
#  0.007647579319934269,
#  0.003478810879190386,
#  0.01797385620915033,
#  0.0076737696600710295,
#  0.007243773946360154,
#  0.006350705925576025,
#  0.005695993974485712,
#  0.004185692541856925,
#  0.0031039967164332256,
#  0.0021287825475017593,
#  0.0032663859194471444,
#  0.003919663103336573,
#  0.0037585810579939738,
#  0.003305739966669399,
#  0.005676753460004692,
#  0.004047905794192426,
#  0.0056179775280898875,
#  0.0020324179054337786,
#  0.002977728559123908,
#  0.0020324179054337786,
#  0.0035567313345091123,
#  0.0036583522297808013,
#  0.11080586080586081,
#  0.0073288915808600846,
#  0.061390157280568236,
#  0.023381642512077295,
#  0.009578544061302681,
#  0.007037297677691766,
#  0.0019372336303758234,
#  0.005986590038314176,
#  0.015698587127158558,
#  0.01768346595932803,
#  0.012294074256208508,
#  0.004112011184670423,
#  0.006366182836771072,
#  0.06775067750677508,
#  0.01172882946281961,
#  0.023540489642184557,
#  0.0061705541157595955,
#  0.006341958396752917,
#  0.005435964340073929,
#  0.006523157208088715,
#  0.00513136288998358,
#  0.021645021645021644,
#  0.00143000143000143,
#  0.014775413711583925,
#  0.0025195263290501394,
#  0.0016673336001067091,
#  0.0021192277534066587,
#  0.011259993244004052,
#  0.00550145788633988,
#  0.004267486023983271,
#  0.0033732501264968798,
#  0.007288629737609329,
#  0.0025670645616737253,
#  0.0192789666473877,
#  0.0020941531244764618,
#  0.002613012803762738,
#  0.004233341800016934,
#  0.0025195263290501394,
#  0.003779289493575208,
#  0.0013394950103810864,
#  0.0016280016280016281,
#  0.0036489691662105455,
#  0.0030234315948601664,
#  0.006283775292195551,
#  0.00476462740613684,
#  0.0036794466112296713,
#  0.005555555555555556,
#  0.009157509157509158,
#  0.02041649652919559,
#  0.0992063492063492,
#  0.007471635457983581,
#  0.003879310344827586,
#  0.0024500907441016334,
#  0.0012991178829190057,
#  0.0032104637336504162,
#  0.0028501055594651655,
#  0.005136986301369863,
#  0.01730769230769231,
#  0.0445054945054945,
#  0.0028209235912795153,
#  0.0032910775231594345,
#  0.0038395904436860067,
#  0.0031775920913263505,
#  0.002490545152661194,
#  0.0034993735689290185,
#  0.003306527329877128,
#  0.009625668449197862,
#  0.0073416115290492155,
#  0.014727272727272728,
#  0.006048387096774194,
#  0.02122641509433962,
#  0.0019749835418038184,
#  0.0009216589861751152,
#  0.0037359900373599006,
#  0.001988510826336721,
#  0.0032444124008651765,
#  0.00345666367942645,
#  0.0041564039408867,
#  0.00401307966706302,
#  0.0035993601137575544,
#  0.002958796025715956,
#  0.0026449843260188087,
#  0.005884917175239756,
#  0.0015179625569235959,
#  0.0024489795918367346,
#  0.004934511117879988,
#  0.001279317697228145,
#  0.007371007371007371,
#  0.0008658008658008658,
#  0.006133575647432985,
#  0.0025237575946409096,
#  0.0015096449538719596,
#  0.00468181029998266,
#  0.003554970375246873,
#  0.008171912832929782,
#  0.0010204081632653062,
#  0.023936170212765957,
#  0.012951710905020786,
#  0.002255639097744361,
#  0.0032640232108317214,
#  0.005306256141500164,
#  0.05009276437847866,
#  0.014950166112956811,
#  0.0009216589861751152,
#  0.002857142857142857,
#  0.0016172506738544475,
#  0.0011741682974559687,
#  0.001948051948051948,
#  0.0017142857142857144,
#  0.0010327022375215148,
#  0.0016483516483516484,
#  0.001680672268907563,
#  0.0023368530379089493,
#  0.02154255319148936,
#  0.02383053839364519,
#  0.05708245243128964,
#  0.0141287284144427,
#  0.006791883280228073,
#  0.010120177103099304,
#  0.002251935256861365,
#  0.004904214559386973,
#  0.004077471967380225,
#  0.024691358024691357,
#  0.03065134099616858,
#  0.033952254641909804,
#  0.002251856021955596,
#  0.001161861883668579,
#  0.0010019726336224443,
#  0.0016547729858310063,
#  0.0020414021881279706,
#  0.004368600682593857,
#  0.0035808202316343087,
#  0.0037022039682998785,
#  0.005520096601690529,
#  0.004074357015533485,
#  0.000362165068047421,
#  0.0013474251547433576,
#  0.004123445654274854,
#  0.02168021680216802,
#  0.01794224838800112,
#  0.005936920222634508,
#  0.0013193156050298907,
#  0.010031347962382446,
#  0.010207336523125997,
#  0.015549076773566569,
#  0.014512471655328799,
#  0.018140589569160998,
#  0.02867383512544803,
#  0.0028088654816765418,
#  0.01966205837173579,
#  0.0034790171776473144,
#  0.002230820174979957,
#  0.0024765884993421562,
#  0.005411804498562489,
#  0.005844748858447489,
#  0.011689497716894977,
#  0.001483129403040415,
#  0.007881773399014776,
#  0.0024852438645542093,
#  0.0024198427102238356,
#  0.002678272514228323,
#  0.008898776418242492,
#  0.0034949759720401923,
#  0.013366750208855471,
#  0.004134366925064598,
#  0.002961728909250775,
#  0.0025460476588296138,
#  0.0012298704792651524,
#  0.004837490551776266,
#  0.0025915127955944283,
#  0.0020440100922998307,
#  0.0029024943310657597,
#  0.0045351473922902496,
#  0.0022675736961451248,
#  0.0030234315948601664,
#  0.0018140589569160999,
#  0.004897459442913988,
#  0.0026386312100597814,
#  0.00321575721033062,
#  0.003547278572220375,
#  0.003018298434257687,
#  0.002843686128143606,
#  0.003699849693606197,
#  0.017448200654307525,
#  0.011182946007338806,
#  0.0016518260420699444,
#  0.0034790171776473144,
#  0.002563486341424337,
#  0.001554454483629651,
#  0.00314233809593951,
#  0.0049531769986843124,
#  0.0030374940673943995,
#  0.001198277476128066,
#  0.0036792181661396955,
#  0.0027996500437445313,
#  0.0015833745670460165,
#  0.0036604895904827272,
#  0.006304176516942475,
#  0.007243096423721141,
#  0.005412262156448202,
#  0.012680800475530017,
#  0.0011287477954144618,
#  0.03099273607748184,
#  0.00750645085620455,
#  0.015238095238095238,
#  0.045714285714285714,
#  0.001110243733194553,
#  0.00250832843425436,
#  0.0014409546324439942,
#  0.002708994708994709,
#  0.0020522687189353855,
#  0.0015392015392015391,
#  0.0038250059765718384,
#  0.0022240756185710315,
#  0.0016493145036594165,
#  0.00404040404040404,
#  0.022535211267605635,
#  0.005599300087489063,
#  0.0018527095877721167,
#  0.0030357651076747937,
#  0.0049405589007256445,
#  0.0014155533929045387,
#  0.00812801625603251,
#  0.0033542976939203353,
#  0.008564164324902984,
#  0.011235955056179775,
#  0.024987251402345742,
#  0.002521873391662378,
#  0.0014319111630625365,
#  0.002011494252873563,
#  0.003379310344827586,
#  0.00945216049382716,
#  0.007822477650063856,
#  0.003658900836320191,
#  0.020374220374220375,
#  0.0011337868480725624,
#  0.0020408163265306124,
#  0.023026315789473683,
#  0.0015203226807322372,
#  0.0015629485502854773,
#  0.0019908987485779293,
#  0.003558202018735023,
#  0.0019908987485779293,
#  0.0019445987776807684,
#  0.001623645581364525,
#  0.004288089612321694,
#  0.0028344999132295942,
#  0.0012187538863325457,
#  0.0012019820438600795,
#  0.00903558915729301,
#  0.005955274671852213,
#  0.007239952718676123,
#  0.0014403292181069957,
#  0.012195121951219513,
#  0.0051513877207737604,
#  0.006944444444444444,
#  0.0043859649122807015,
#  0.017857142857142853,
#  0.011223087494273936,
#  0.004924128228318762,
#  0.0020157143444814673,
#  0.0011901292140289517,
#  0.00532724505327245,
#  0.006780130067801301,
#  0.003442219880576045,
#  0.00639269406392694,
#  0.0029334291187739464,
#  0.0009644150527475986,
#  0.0009688389750079089,
#  0.0023209549071618036,
#  0.005866858237547893,
#  0.002673505019642078,
#  0.0035797779076563413,
#  0.005451713395638629,
#  0.0020109989329393416,
#  0.0022325496628394386,
#  0.001208444312913091,
#  0.001995764092538286,
#  0.005854241338112306,
#  0.002195340501792115,
#  0.005987292277614858,
#  0.011939571150097465,
#  0.0012771392081736908,
#  0.0024154589371980675,
#  0.001122334455667789,
#  0.0015015015015015015,
#  0.0019157088122605365,
#  0.0017636684303350973,
#  0.003968253968253968,
#  0.0022222222222222222,
#  0.00205761316872428,
#  0.00202020202020202,
#  0.0010787486515641857,
#  0.0028490028490028487,
#  0.001658374792703151,
#  0.0018832391713747645,
#  0.0026327100795185904,
#  0.002270410527291261,
#  0.0019486200588562795,
#  0.006971119647175987,
#  0.009546074420416911,
#  0.00813143046797212,
#  0.003931953137538116,
#  0.012071938901207193,
#  0.0012253063265816454,
#  0.00027877339705296696,
#  0.00170797169646903,
#  0.0062340966921119595,
#  0.0005345551737304314,
#  0.0019887977920285743,
#  0.002172274681916921,
#  0.004143412819211906,
#  0.0017543859649122807,
#  0.0010638297872340428,
#  0.0037735849056603783,
#  0.002898550724637681,
#  0.0013333333333333333,
#  0.0011235955056179774,
#  0.0012058570198105081,
#  0.00441919191919192,
#  0.0030374411108356064,
#  0.04693486590038314,
#  0.0023480927736246886,
#  0.002053216006704379,
#  0.004125620948050855,
#  0.005730994152046784,
#  0.0028641571194762687,
#  0.0014642601004064067,
#  0.005697674418604652,
#  0.005697674418604652,
#  0.0026997245179063364,
#  0.007940366229136282,
#  0.005003063099857055,
#  0.002332888973528852,
#  0.0017879948914431678,
#  0.013417305585980284,
#  0.015555555555555555,
#  0.0040137614678899085,
#  0.014583333333333334,
#  0.013021525378687218,
#  0.0015712682379349046,
#  0.0017879948914431678,
#  0.00050341603739662,
#  0.0016203703703703705,
#  0.0016203703703703705,
#  0.0015712682379349046,
#  0.0017879948914431678,
#  0.0014814814814814816,
#  0.0017879948914431678,
#  0.002074074074074074,
#  0.0030374411108356064,
#  0.002606937646307725,
#  0.0013705526963526515,
#  0.004495412844036697,
#  0.0025053686471009306,
#  0.012548015364916773,
#  0.012911725955204215,
#  0.002572178477690288,
#  0.001286089238845144,
#  0.0018729454934638024,
#  0.0030529595015576323,
#  0.0037709712174849933,
#  0.018875192604006163,
#  0.007780247697681805,
#  0.0029285202008128134,
#  0.0022940074906367043,
#  0.005718954248366014,
#  0.03161290322580646,
#  0.010759771629336848,
#  0.009898989898989899,
#  0.012583461736004109,
#  0.004512801620924664,
#  0.026790595954073262,
#  0.02861685214626391,
#  0.013513513513513514,
#  0.001266713581984518,
#  0.0017241379310344827,
#  0.001426872770511296,
#  0.0017484215638659544,
#  0.0017991004497751122,
#  0.0004887320119467825,
#  0.0033550792171481826,
#  0.0012052226314027453,
#  0.002104032729398013,
#  0.0021778584392014516,
#  0.0015517241379310346,
#  0.002104032729398013,
#  0.004672897196261682,
#  0.011111111111111112,
#  0.00847457627118644,
#  0.002528977871443625,
#  0.0012558869701726845,
#  0.004227833235466823,
#  0.014574898785425103,
#  0.0016773832820799553,
#  0.0015833919774806476,
#  0.0017085904129093498,
#  0.007653061224489794,
#  0.0020637468470534283,
#  0.005844155844155844,
#  0.0029354207436399216,
#  0.007653061224489794,
#  0.003497522588166716,
#  0.003301540719002201,
#  0.001706484641638225,
#  0.0012410797393732549,
#  0.0016603634351074624,
#  0.0013651877133105802,
#  0.0027303754266211604,
#  0.0019502681618722576,
#  0.0013501856505269475,
#  0.00341296928327645,
#  0.002233943530871858,
#  0.0024573378839590444,
#  0.00341296928327645,
#  0.0026141892382543024,
#  0.0016382252559726963,
#  0.0015358361774744029,
#  0.0053475935828877,
#  0.0020700362256339485,
#  0.0053475935828877,
#  0.004010695187165775,
#  0.003928844264978719,
#  0.004583651642475171,
#  0.007700534759358288,
#  0.0017991903643360487,
#  0.003928844264978719,
#  0.003850267379679144,
#  0.0055003819709702065,
#  0.006638392033929558,
#  0.0022675736961451248,
#  0.007982261640798226,
#  0.004009355162044771,
#  0.008206063369044905,
#  0.004545454545454545,
#  0.003896103896103896,
#  0.004545454545454545,
#  0.003373945641986879,
#  0.00149439601494396,
#  0.0061749571183533445,
#  0.005546995377503852,
#  0.0019749835418038184,
#  0.0016773832820799553,
#  0.0003887269193391642,
#  0.012016021361815758,
#  0.01488833746898263,
#  0.004442798963346909,
#  0.011183597390493943,
#  0.00228310502283105,
#  0.00423728813559322,
#  0.011904761904761904,
#  0.004608294930875576,
#  0.010186757215619693,
#  0.0021747009786154403,
#  0.004696673189823875,
#  0.0019569471624266144,
#  0.0017675651789659744,
#  0.002134851449919943,
#  0.002382370458606313,
#  0.003287671232876712,
#  0.003287671232876712,
#  0.0027861620617599257,
#  0.003652968036529681,
#  0.003424657534246575,
#  0.002883922134102379,
#  0.005302695536897923,
#  0.0027861620617599257,
#  0.0015673981191222574,
#  0.00267538644470868,
#  0.002096924510717614,
#  0.002185526954832443,
#  0.0022488755622188904,
#  0.0022167487684729066,
#  0.0031034482758620693,
#  0.0009759271307742355,
#  0.001293103448275862,
#  0.0036086607858861267,
#  0.0009461732548359967,
#  0.002630040911747516,
#  0.0034482758620689655,
#  0.0027223230490018148,
#  0.005952380952380952,
#  0.012244897959183676,
#  0.004559270516717325,
#  0.007263922518159807,
#  0.0015995734470807784,
#  0.005865102639296188,
#  0.0027260336210813267,
#  0.0012172854534388314,
#  0.002262727844123193,
#  0.003243243243243243,
#  0.0024009603841536617,
#  0.0017006802721088437,
#  0.0011337868480725624,
#  0.007042253521126761,
#  0.00909090909090909,
#  0.0008245722531436818,
#  0.0017368649587494569,
#  0.0007629219912263969,
#  0.0009718172983479106,
#  0.0015402387370042352,
#  0.0007160759040458288,
#  0.0023323615160349854,
#  0.0009383063570255689,
#  0.0016326530612244899,
#  0.0010884353741496598,
#  0.0012957563977972141,
#  0.0010333247222939809,
#  0.0011830819284235432,
#  0.0012368583797155224,
#  0.0013166556945358788,
#  0.0023323615160349854,
#  0.01253918495297806,
#  0.011822660098522165,
#  0.009195402298850575,
#  0.008836524300441826,
#  0.0067340067340067354,
#  0.0024489795918367346,
#  0.0070093457943925215,
#  0.0015648772006085633,
#  0.007314099959366112,
#  0.004608294930875576,
#  0.0023319082782743876,
#  0.002304147465437788,
#  0.002059025394646534,
#  0.0010873504893077202,
#  0.0047380889707817845,
#  0.0014617508526879974,
#  0.003195455352387715,
#  0.0012605924784648784,
#  0.010569583088667059,
#  0.0041237113402061865,
#  0.003468542248771558,
#  0.0044714942243199605,
#  0.004697898995171604,
#  0.0035838725734196127,
#  0.006575342465753424,
#  0.0019569471624266144,
#  0.0026513477684489617,
#  0.003287671232876712,
#  0.004442798963346909,
#  0.0027861620617599257,
#  0.002694812485964518,
#  0.0009235031553024473,
#  0.0040494938132733405,
#  0.0012452438602559668,
#  0.0016889514426460237,
#  0.0019082957858468064,
#  0.0029387755102040815,
#  0.002577873254564984,
#  0.003861003861003861,
#  0.0024865312888520514,
#  0.002748511223087494,
#  0.003771213073538655,
#  0.0014877262583684603,
#  0.003148779847808974,
#  0.0019775873434410016,
#  0.008086253369272238,
#  0.004225352112676057,
#  0.0014687882496940024,
#  0.0026761819803746657,
#  0.0017896202028236234,
#  0.0013838170286373246,
#  0.0014189988175009854,
#  0.00398671096345515,
#  0.001993355481727575,
#  0.0024266936299292214,
#  0.0012311901504787962,
#  0.0013647736750322238,
#  0.005805515239477504,
#  0.013953488372093023,
#  0.02706766917293233,
#  0.010353753235547887,
#  0.002436713144713686,
#  0.012815948736205056,
#  0.02425876010781671,
#  0.014778325123152709,
#  0.002407704654895666,
#  0.00974025974025974,
#  0.0006144393241167435,
#  0.0007619047619047618,
#  0.015824175824175824,
#  0.0008859357696566999,
#  0.0005148005148005148,
#  0.0011904761904761906,
#  0.0008465608465608464,
#  0.0008859357696566999,
#  0.0011904761904761906,
#  0.000645682001614205,
#  0.0011544011544011544,
#  0.0014652014652014652,
#  0.0009768009768009768,
#  0.001228878648233487,
#  0.002816020025031289,
#  0.006079027355623101,
#  0.005160550458715597,
#  0.00235910878112713,
#  0.0011009174311926604,
#  0.0030025020850708915,
#  0.001214247166756611,
#  0.0015433421932607386,
#  0.002621231979030144,
#  0.002090349552897457,
#  0.0027989426216762556,
#  0.0025802752293577983,
#  0.00974025974025974,
#  0.005454545454545455,
#  0.0015321756894790604,
#  0.004922740325447833,
#  0.012676056338028166,
#  0.005550416281221092,
#  0.010434782608695653,
#  0.00565149136577708,
#  0.003697237342097155,
#  0.017733990147783252,
#  0.006666666666666666,
#  0.001348314606741573,
#  0.01636363636363637,
#  0.011483253588516746,
#  0.009446339543426923,
#  0.0039079461571862786,
#  0.013677811550151974,
#  0.00272789270288702,
#  0.002488077959776073,
#  0.008333333333333333,
#  0.017543859649122806,
#  0.012362637362637364,
#  0.013432835820895522,
#  0.003064351378958121,
#  0.010212418300653595,
#  0.002329916123019571,
#  0.003613238907356555,
#  0.016479894528675015,
#  0.007766387076731904,
#  0.023299161230195712,
#  0.002972651605231866,
#  0.002463054187192118,
#  0.002004811547714515,
#  0.0019157088122605365,
#  0.0007766387076731904,
#  0.002052545155993432,
#  0.0010024057738572574,
#  0.0017241379310344827,
#  0.0014611338398597311,
#  0.003315649867374005,
#  0.0021551724137931034,
#  0.002972651605231866,
#  0.0031928480204342275,
#  0.0035430839002267575,
#  0.007716049382716049,
#  0.0016149870801033593,
#  0.006200396825396825,
#  0.00036743092298647856,
#  0.005885122410546139,
#  0.006868131868131869,
#  0.009380863039399626,
#  0.0016578249336870025,
#  0.0027430326969497478,
#  0.0030369290573372208,
#  0.0029322073657049026,
#  0.0013715163484748739,
#  0.006894649751792609,
#  0.0024767188428769567,
#  0.00472411186696901,
#  0.007971938775510204,
#  0.0032291397571686904,
#  0.0029422148993762504,
#  0.004609994468006638,
#  0.007836990595611285,
#  0.00455539358600583,
#  0.007566585956416465,
#  0.00445632798573975,
#  0.008960573476702509,
#  0.00778816199376947,
#  0.021929824561403508,
#  0.023148148148148147,
#  0.002844464671748776,
#  0.005427702996092054,
#  0.00497116723006562,
#  0.0016730241584688482,
#  0.0019842844670211923,
#  0.002752394583287461,
#  0.0023701175578308684,
#  0.0016098911713568163,
#  0.0007051589428257129,
#  0.0029422148993762504,
#  0.002844141069397042,
#  0.0014969163523142325,
#  0.0016098911713568163,
#  0.003047294002925402,
#  0.0016098911713568163,
#  0.0011376564277588168,
#  0.0005688282138794084,
#  0.0015800783718872456,
#  0.0034129692832764505,
#  0.002666382252559727,
#  0.002585582790360947,
#  0.0024378352023403218,
#  0.0020315293352836015,
#  0.003932054105064486,
#  0.0029063008602650546,
#  0.0013504024199211364,
#  0.0011329647421372247,
#  0.0015545330182813082,
#  0.0035181536729524342,
#  0.0026737967914438505,
#  0.016479894528675015,
#  0.004654626698938745,
#  0.005411255411255411,
#  0.001926040061633282,
#  0.003987240829346092,
#  0.007836990595611285,
#  0.00505050505050505,
#  0.004114549045424622,
#  0.006894649751792609,
#  0.0030369290573372208,
#  0.0063775510204081625,
#  0.0030369290573372208,
#  0.004813246053138236,
#  0.004323763403666551,
#  0.008796622097114707,
#  0.0057977736549165125,
#  0.006222000995520159,
#  0.004323763403666551,
#  0.013774104683195593,
#  0.004800307219662059,
#  0.002912395153774464,
#  0.015015015015015015,
#  0.012748597654258032,
#  0.0007873519778281683,
#  0.002650551314673452,
#  0.0016149870801033593,
#  0.005885122410546139,
#  0.01240079365079365,
#  0.0011586948461253244,
#  0.0037335722819593787,
#  0.0012503125781445365,
#  0.0030898529230008647,
#  0.0012331064417480516,
#  0.0017038097185306344,
#  0.001968193985199181,
#  0.0009434318276161365,
#  0.0020384866275277233,
#  0.0015220700152207003,
#  0.0031709791983764585,
#  0.001214417565335665,
#  0.0011083034091412865,
#  0.00242883513067133,
#  0.001871397559697582,
#  0.0008225848907607265,
#  0.001517727051966974,
#  0.000890567113137646,
#  0.001857907253269917,
#  0.0012386048355132774,
#  0.0017665347654041833,
#  0.0010070899129874314,
#  0.0017380422691879868,
#  0.00256568144499179,
#  0.0034760845383759735,
#  0.0013589910850184822,
#  0.007832080200501253,
#  0.0013576626479852288,
#  0.0013576626479852288,
#  0.0006137379093631855,
#  0.0005486065393899496,
#  0.004072987943955686,
#  0.0015449264615004323,
#  0.001816332461493752,
#  0.0014298787462823156,
#  0.0019201228878648233,
#  0.0018412137280895567,
#  0.0025847808105872623,
#  0.0021001344086021504,
#  0.004021879021879022,
#  0.0005511463844797178,
#  0.0018667861409796893,
#  0.004183400267737617,
#  0.0013497462477054314,
#  0.00043274307178342076,
#  0.0016196954972465176,
#  0.0012597631645250697,
#  0.0009293334820266905,
#  0.0006591784000421874,
#  0.0008215846725163495]

# %%
max(p_values)
# Out:
# 0.29069767441860467

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(p_values)

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %%
s_value
# Out:
# [0.0002447539862505849,
#  0.0015351913084553613,
#  0.0004220914333273884,
#  0.00024270666472501334,
#  0.0007480480620879891,
#  0.00045351473922902497,
#  0.0002580978190734288,
#  0.0005291005291005291,
#  0.0003481707643687396,
#  0.00021952043228638972,
#  0.0005361552028218695,
#  0.0020189894139473973,
#  0.000567441147151292,
#  0.00015414739824188642,
#  0.00017718715393134,
#  0.00025396825396825396,
#  0.00031746031746031746,
#  0.0004221546774738264,
#  0.0001511715797430083,
#  0.0001877453490356716,
#  0.00021962663472097435,
#  0.0003313349692997442,
#  0.0003328548544800183,
#  0.0006583837740256982,
#  0.00029322073657049027,
#  0.00021786492374727668,
#  0.0012452107279693487,
#  0.0005311433882862455,
#  0.0002084335417668751,
#  0.00025713296741334125,
#  0.0003023431594860166,
#  0.0006137379093631855,
#  0.0003040807638508788,
#  0.0004483902788987535,
#  0.0011536797577272509,
#  0.0014751982297621243,
#  0.00010946907498631637,
#  0.0003680699332873246,
#  0.00011113527095262255,
#  0.00028039889791041866,
#  0.00048683430700194736,
#  0.0005731230221026139,
#  0.0001702615061951971,
#  7.945536955775864e-05,
#  0.000798780045022148,
#  0.00023203079681484998,
#  0.00010630330265033462,
#  0.00033065658951346243,
#  0.0003832746253946816,
#  0.0005127829463043,
#  0.00021743857360295715,
#  0.00041152263374485596,
#  0.000314911037631869,
#  0.0003213883978788366,
#  0.0003662332906061161,
#  0.00022757012004323833,
#  0.004082465809348847,
#  0.014534883720930232,
#  0.0005956112852664577,
#  0.00028240190249702736,
#  0.0003522432332220986,
#  0.00017585265398676478,
#  0.001586109024125553,
#  0.00021183947275509003,
#  0.000331919601696478,
#  0.0003302873499944952,
#  0.00041269258987527513,
#  0.00016142050040355126,
#  0.010368663594470046,
#  0.0003250740446435021,
#  6.203247582557927e-05,
#  0.00025008826644698127,
#  0.00018171129282240392,
#  0.0008002636162500589,
#  0.00036270535523789206,
#  0.00019137678712146799,
#  0.00028554631729234904,
#  0.0002901519030551289,
#  0.00026849877596146255,
#  0.0007914131671365682,
#  0.00019401700073968983,
#  0.00028763527846690395,
#  0.00027151778441487917,
#  0.0003351346822504294,
#  0.0018658892128279884,
#  0.00023846784410164692,
#  0.0001485194467650608,
#  0.00013992741265468538,
#  0.0003256003256003256,
#  0.0009877762686751452,
#  0.0011140819964349377,
#  0.00028760977106262226,
#  0.0007292173067574137,
#  0.00031418876460977753,
#  0.00025767882910740053,
#  0.0002834467120181406,
#  0.0006298815822625346,
#  0.00037377588397996563,
#  0.00019108767102346557,
#  0.0018037518037518038,
#  0.0001763668430335097,
#  0.0030432136335970784,
#  0.0015659254619480112,
#  0.00020614306328592042,
#  0.000223563603845294,
#  0.00048756704046806434,
#  0.0017825311942959,
#  0.0007718176305198743,
#  0.0006523157208088715,
#  0.0017006802721088435,
#  0.0002806736166800321,
#  0.00019357336430507162,
#  0.000984251968503937,
#  0.0002314814814814815,
#  0.00030864197530864197,
#  0.0002410085279940675,
#  0.0007864488808227465,
#  0.00047688921496698457,
#  0.0008244545915778792,
#  0.0010695187165775401,
#  0.00018109632931670962,
#  0.00020636558457020398,
#  0.0003760050905304564,
#  0.0011092150170648465,
#  0.00031743706199790004,
#  0.0007724301841948901,
#  0.0011396510914350837,
#  0.0015448603683897802,
#  0.0005496828752642706,
#  0.00030080059234578185,
#  0.002075351213282248,
#  0.0002710535643543713,
#  0.00024228869630043797,
#  0.0003012606599925844,
#  0.0003148004649360713,
#  0.0005668934240362812,
#  0.0005335303291471722,
#  0.001023058156921382,
#  0.0001859001859001859,
#  0.00031719695490923285,
#  0.00023718299580368545,
#  0.0001511715797430083,
#  0.00019652305366591082,
#  0.00038773562395609637,
#  0.0004926108374384236,
#  9.383063570255688e-05,
#  0.0004265908282971916,
#  0.0004985459077690071,
#  0.0007807417046193884,
#  0.0017006802721088435,
#  0.0013026487190620929,
#  0.003309431880860452,
#  0.0015651493413329856,
#  0.001734354675531146,
#  0.00089126559714795,
#  0.0002765996680803983,
#  0.0005865102639296188,
#  0.0004452690166975881,
#  0.0005277973258268825,
#  0.0045045045045045045,
#  0.0005120983228779926,
#  0.0002548582351067219,
#  0.00048340315823396714,
#  0.0024154589371980675,
#  0.0002805245809664072,
#  0.0002925901543413064,
#  0.00017113763744491507,
#  0.00021164021164021165,
#  0.00026333113890717575,
#  9.693444807948625e-05,
#  0.00021572645885017797,
#  0.0006618863761720904,
#  0.00022781205505457996,
#  0.0001144001144001144,
#  0.0005599104143337066,
#  0.00025396825396825396,
#  0.00016931216931216931,
#  0.00025396825396825396,
#  0.00023515579071134627,
#  0.00013508949679162446,
#  0.00031746031746031746,
#  0.0017980221756068325,
#  0.002,
#  0.00028954988154777575,
#  0.00015482054890921887,
#  0.0023504273504273503,
#  0.000521425862722791,
#  0.0037606837606837607,
#  0.0005125337806355419,
#  0.0011453561016243233,
#  0.00017142768089516418,
#  0.00028658520699267903,
#  0.00014780575636236598,
#  0.0003830883889391934,
#  0.0006952344836303881,
#  0.00031625553447185326,
#  0.0016339869281045752,
#  0.0006976154236428209,
#  0.0006585249042145594,
#  0.0005773369023250931,
#  0.0005178176340441557,
#  0.000380517503805175,
#  0.0002821815196757478,
#  0.00019352568613652358,
#  0.0002969441744951949,
#  0.0003563330093942339,
#  0.00034168918709036127,
#  0.0003005218151517635,
#  0.0005160684963640629,
#  0.0003679914358356751,
#  0.0005107252298263534,
#  0.0001847652641303435,
#  0.00027070259628399164,
#  0.0001847652641303435,
#  0.0003233392122281011,
#  0.0003325774754346183,
#  0.010073260073260074,
#  0.0006662628709872804,
#  0.005580923389142567,
#  0.0021256038647342996,
#  0.0009578544061302681,
#  0.0007037297677691766,
#  0.00019372336303758234,
#  0.0005986590038314176,
#  0.0015698587127158557,
#  0.0017683465959328027,
#  0.0012294074256208507,
#  0.00041120111846704226,
#  0.0006366182836771072,
#  0.006775067750677507,
#  0.001172882946281961,
#  0.0023540489642184556,
#  0.0006170554115759595,
#  0.0006341958396752917,
#  0.0005435964340073929,
#  0.0006523157208088715,
#  0.000513136288998358,
#  0.0021645021645021645,
#  0.000143000143000143,
#  0.0014775413711583924,
#  0.0002519526329050139,
#  0.00016673336001067092,
#  0.00021192277534066585,
#  0.0011259993244004053,
#  0.000550145788633988,
#  0.00042674860239832714,
#  0.00033732501264968796,
#  0.0007288629737609329,
#  0.0002567064561673726,
#  0.00192789666473877,
#  0.00020941531244764617,
#  0.0002613012803762738,
#  0.00042333418000169333,
#  0.0002519526329050139,
#  0.0003779289493575208,
#  0.00013394950103810864,
#  0.0001628001628001628,
#  0.00036489691662105453,
#  0.0003023431594860166,
#  0.0006283775292195551,
#  0.000476462740613684,
#  0.0003679446611229671,
#  0.0005555555555555556,
#  0.0009157509157509158,
#  0.002041649652919559,
#  0.00992063492063492,
#  0.0008301817175537312,
#  0.0004310344827586207,
#  0.0002722323049001815,
#  0.00014434643143544507,
#  0.000356718192627824,
#  0.0003166783954961295,
#  0.0005707762557077625,
#  0.0019230769230769232,
#  0.004945054945054945,
#  0.0003134359545866128,
#  0.0003656752803510483,
#  0.0004266211604095563,
#  0.00035306578792515005,
#  0.0002767272391845771,
#  0.00038881928543655763,
#  0.0003673919255419031,
#  0.0010695187165775401,
#  0.0008157346143388018,
#  0.0016363636363636363,
#  0.0006720430107526882,
#  0.0023584905660377358,
#  0.00021944261575597982,
#  0.00010240655401945725,
#  0.00041511000415110004,
#  0.0002209456473707468,
#  0.0003604902667627974,
#  0.00038407374215849446,
#  0.00046182266009852215,
#  0.00044589774078478004,
#  0.00039992890152861714,
#  0.0003287551139684395,
#  0.0002938871473354232,
#  0.0006538796861377507,
#  0.00016866250632484398,
#  0.00027210884353741496,
#  0.0005482790130977764,
#  0.00014214641080312722,
#  0.000819000819000819,
#  9.62000962000962e-05,
#  0.0006815084052703317,
#  0.00028041751051565664,
#  0.00016773832820799552,
#  0.0005202011444425178,
#  0.00039499670836076365,
#  0.0009079903147699758,
#  0.00011337868480725624,
#  0.0026595744680851063,
#  0.001439078989446754,
#  0.0002506265664160401,
#  0.00036266924564796907,
#  0.0005895840157222404,
#  0.0055658627087198514,
#  0.0016611295681063123,
#  0.00010240655401945725,
#  0.00031746031746031746,
#  0.00017969451931716083,
#  0.0001304631441617743,
#  0.00021645021645021645,
#  0.00019047619047619048,
#  0.00011474469305794607,
#  0.00018315018315018315,
#  0.00018674136321195143,
#  0.0002596503375454388,
#  0.0023936170212765957,
#  0.00264783759929391,
#  0.006342494714587738,
#  0.0015698587127158557,
#  0.0007546536978031192,
#  0.001265022137887413,
#  0.00028149190710767064,
#  0.0006130268199233716,
#  0.0005096839959225281,
#  0.0030864197530864196,
#  0.0038314176245210726,
#  0.004244031830238726,
#  0.0002814820027444495,
#  0.00014523273545857237,
#  0.00012524657920280554,
#  0.0002068466232288758,
#  0.0002551752735159963,
#  0.0005460750853242321,
#  0.0004476025289542886,
#  0.0004627754960374848,
#  0.0006900120752113162,
#  0.0005092946269416857,
#  4.5270633505927626e-05,
#  0.0001684281443429197,
#  0.0005154307067843567,
#  0.0027100271002710027,
#  0.00224278104850014,
#  0.0007421150278293135,
#  0.00016491445062873634,
#  0.0012539184952978057,
#  0.0012759170653907496,
#  0.001943634596695821,
#  0.0018140589569160999,
#  0.0022675736961451248,
#  0.0035842293906810036,
#  0.0003511081852095677,
#  0.002457757296466974,
#  0.0004348771472059143,
#  0.00027885252187249466,
#  0.00030957356241776953,
#  0.0006764755623203111,
#  0.0007305936073059361,
#  0.0014611872146118722,
#  0.0001853911753800519,
#  0.0009852216748768472,
#  0.00031065548306927616,
#  0.00030248033877797946,
#  0.00033478406427854036,
#  0.0011123470522803114,
#  0.00043687199650502403,
#  0.001670843776106934,
#  0.0005167958656330749,
#  0.0003702161136563469,
#  0.0003182559573537017,
#  0.00015373380990814405,
#  0.0006046863189720333,
#  0.00032393909944930353,
#  0.00025550126153747884,
#  0.00036281179138321996,
#  0.0005668934240362812,
#  0.0002834467120181406,
#  0.0003779289493575208,
#  0.00022675736961451248,
#  0.0006121824303642485,
#  0.0003298289012574727,
#  0.0004019696512913275,
#  0.00044340982152754686,
#  0.0003772873042822109,
#  0.0003554607660179508,
#  0.00046248121170077463,
#  0.0021810250817884407,
#  0.001397868250917351,
#  0.00020647825525874305,
#  0.0004348771472059143,
#  0.0003204357926780421,
#  0.0001943068104537064,
#  0.00039279226199243875,
#  0.0006191471248355391,
#  0.00037968675842429994,
#  0.00014978468451600825,
#  0.00045990227076746193,
#  0.00034995625546806647,
#  0.0001979218208807521,
#  0.0004575611988103409,
#  0.0007880220646178094,
#  0.0009053870529651426,
#  0.0006765327695560253,
#  0.0015851000594412521,
#  0.00014109347442680775,
#  0.00387409200968523,
#  0.0009383063570255688,
#  0.0019047619047619048,
#  0.005714285714285714,
#  0.00013878046664931912,
#  0.000313541054281795,
#  0.00018011932905549928,
#  0.00033862433862433863,
#  0.0002565335898669232,
#  0.0001924001924001924,
#  0.0004781257470714798,
#  0.00027800945232137893,
#  0.00020616431295742706,
#  0.000505050505050505,
#  0.0028169014084507044,
#  0.0006999125109361329,
#  0.0002315886984715146,
#  0.0003794706384593492,
#  0.0006175698625907056,
#  0.00017694417411306734,
#  0.001016002032004064,
#  0.0004192872117400419,
#  0.001070520540612873,
#  0.0014044943820224719,
#  0.0035696073431922487,
#  0.0003602676273803397,
#  0.00020455873758036235,
#  0.00028735632183908046,
#  0.0004827586206896552,
#  0.0013503086419753086,
#  0.0011174968071519795,
#  0.000522700119474313,
#  0.0029106029106029108,
#  0.00016196954972465177,
#  0.0002915451895043732,
#  0.003289473684210526,
#  0.0002171889543903196,
#  0.00022327836432649677,
#  0.0002844141069397042,
#  0.0005083145741050033,
#  0.0002844141069397042,
#  0.0002777998253829669,
#  0.00023194936876636072,
#  0.0006125842303316706,
#  0.0004049285590327992,
#  0.00017410769804750652,
#  0.00017171172055143992,
#  0.0012907984510418587,
#  0.000850753524550316,
#  0.0010342789598108747,
#  0.00020576131687242798,
#  0.0017421602787456446,
#  0.0007359125315391085,
#  0.000992063492063492,
#  0.0006265664160401002,
#  0.002551020408163265,
#  0.001603298213467705,
#  0.0007034468897598232,
#  0.0002879591920687811,
#  0.0001700184591469931,
#  0.00076103500761035,
#  0.0009685900096859,
#  0.0004917456972251493,
#  0.0009132420091324201,
#  0.00041906130268199235,
#  0.00013777357896394268,
#  0.0001384055678582727,
#  0.0003315649867374005,
#  0.0008381226053639847,
#  0.00038192928852029683,
#  0.0005113968439509059,
#  0.000778816199376947,
#  0.0002872855618484774,
#  0.0003189356661199198,
#  0.00017263490184472725,
#  0.000285109156076898,
#  0.0008363201911589009,
#  0.0003136200716845878,
#  0.000855327468230694,
#  0.001705653021442495,
#  0.00018244845831052726,
#  0.0003450655624568668,
#  0.000160333493666827,
#  0.0002145002145002145,
#  0.0002736726874657909,
#  0.0002519526329050139,
#  0.0005668934240362812,
#  0.00031746031746031746,
#  0.00029394473838918284,
#  0.0002886002886002886,
#  0.0001541069502234551,
#  0.000407000407000407,
#  0.00023691068467187872,
#  0.0002690341673392521,
#  0.0003761014399312272,
#  0.00032434436104160873,
#  0.00027837429412232563,
#  0.0009958742353108551,
#  0.0013637249172024158,
#  0.0011616329239960172,
#  0.0005617075910768737,
#  0.0017245627001724563,
#  0.00017504376094023506,
#  3.982477100756671e-05,
#  0.00024399595663843286,
#  0.0008905852417302799,
#  7.636502481863306e-05,
#  0.00028411397028979627,
#  0.0003103249545595602,
#  0.0005919161170302722,
#  0.0002506265664160401,
#  0.00015197568389057752,
#  0.0005390835579514825,
#  0.00041407867494824016,
#  0.00019047619047619048,
#  0.00016051364365971107,
#  0.0001722652885443583,
#  0.0006313131313131314,
#  0.0004339201586908009,
#  0.006704980842911878,
#  0.0003354418248035269,
#  0.00029331657238633983,
#  0.0005893744211501221,
#  0.0008187134502923977,
#  0.0004091653027823241,
#  0.0002091800143437724,
#  0.0008139534883720931,
#  0.0008139534883720931,
#  0.0003856749311294766,
#  0.0011343380327337547,
#  0.0007147232999795794,
#  0.00033326985336126454,
#  0.0002554278416347382,
#  0.0019167579408543264,
#  0.0022222222222222222,
#  0.0005733944954128441,
#  0.0020833333333333333,
#  0.0018602179112410311,
#  0.0002244668911335578,
#  0.0002554278416347382,
#  7.191657677094571e-05,
#  0.0002314814814814815,
#  0.0002314814814814815,
#  0.0002244668911335578,
#  0.0002554278416347382,
#  0.00021164021164021165,
#  0.0002554278416347382,
#  0.0002962962962962963,
#  0.0004339201586908009,
#  0.0003724196637582464,
#  0.00019579324233609307,
#  0.0006422018348623853,
#  0.00035790980672870435,
#  0.001792573623559539,
#  0.001844532279314888,
#  0.0003674540682414698,
#  0.0001837270341207349,
#  0.00026756364192340035,
#  0.00043613707165109035,
#  0.0005387101739264276,
#  0.002696456086286595,
#  0.0011114639568116863,
#  0.0004183600286875448,
#  0.00032771535580524347,
#  0.0008169934640522876,
#  0.004516129032258065,
#  0.0015371102327624067,
#  0.0014141414141414141,
#  0.0017976373908577298,
#  0.0006446859458463806,
#  0.0038272279934390375,
#  0.0047694753577106515,
#  0.0022522522522522522,
#  0.000211118930330753,
#  0.00028735632183908046,
#  0.00023781212841854935,
#  0.0002914035939776591,
#  0.0002998500749625187,
#  8.145533532446375e-05,
#  0.0005591798695246971,
#  0.0002008704385671242,
#  0.00035067212156633545,
#  0.0003629764065335753,
#  0.0002586206896551724,
#  0.00035067212156633545,
#  0.000778816199376947,
#  0.001851851851851852,
#  0.0014124293785310734,
#  0.00042149631190727084,
#  0.00020931449502878074,
#  0.0007046388725778039,
#  0.0024291497975708503,
#  0.0002795638803466592,
#  0.00026389866291344125,
#  0.00028476506881822496,
#  0.0012755102040816326,
#  0.000343957807842238,
#  0.000974025974025974,
#  0.0004892367906066536,
#  0.0012755102040816326,
#  0.0005829204313611193,
#  0.0005502567865003668,
#  0.0002844141069397042,
#  0.0002068466232288758,
#  0.0002767272391845771,
#  0.00022753128555176336,
#  0.0004550625711035267,
#  0.00032504469364537625,
#  0.00022503094175449124,
#  0.0005688282138794084,
#  0.0003723239218119764,
#  0.00040955631399317407,
#  0.0005688282138794084,
#  0.00043569820637571707,
#  0.00027303754266211604,
#  0.0002559726962457338,
#  0.00089126559714795,
#  0.0003450060376056581,
#  0.00089126559714795,
#  0.0006684491978609625,
#  0.0006548073774964531,
#  0.0007639419404125286,
#  0.0012834224598930481,
#  0.0002998650607226748,
#  0.0006548073774964531,
#  0.0006417112299465241,
#  0.0009167303284950344,
#  0.0011063986723215931,
#  0.0003779289493575208,
#  0.0013303769401330377,
#  0.0006682258603407952,
#  0.0013676772281741509,
#  0.0007575757575757576,
#  0.0006493506493506494,
#  0.0007575757575757576,
#  0.0005623242736644799,
#  0.00024906600249066,
#  0.0010291595197255575,
#  0.0009244992295839754,
#  0.0003291639236339697,
#  0.0002795638803466592,
#  6.47878198898607e-05,
#  0.0020026702269692926,
#  0.0024813895781637717,
#  0.0007404664938911515,
#  0.001863932898415657,
#  0.000380517503805175,
#  0.0007062146892655367,
#  0.001984126984126984,
#  0.0007680491551459293,
#  0.001697792869269949,
#  0.0003624501631025734,
#  0.0007827788649706458,
#  0.00032615786040443573,
#  0.0002945941964943291,
#  0.0003558085749866572,
#  0.0003970617431010522,
#  0.000547945205479452,
#  0.000547945205479452,
#  0.0004643603436266543,
#  0.0006088280060882801,
#  0.0005707762557077625,
#  0.0004806536890170632,
#  0.0008837825894829872,
#  0.0004643603436266543,
#  0.00026123301985370953,
#  0.00044589774078478004,
#  0.0003494874184529357,
#  0.0003642544924720738,
#  0.0003748125937031484,
#  0.00036945812807881776,
#  0.0005172413793103448,
#  0.00016265452179570593,
#  0.00021551724137931034,
#  0.0006014434643143544,
#  0.0001576955424726661,
#  0.00043834015195791935,
#  0.0005747126436781609,
#  0.00045372050816696913,
#  0.000992063492063492,
#  0.0020408163265306124,
#  0.0007598784194528875,
#  0.0012106537530266344,
#  0.00026659557451346307,
#  0.0009775171065493646,
#  0.00045433893684688776,
#  0.0002028809089064719,
#  0.0003771213073538655,
#  0.0005405405405405405,
#  0.00040016006402561027,
#  0.0002834467120181406,
#  0.0001889644746787604,
#  0.0011737089201877935,
#  0.0015151515151515152,
#  0.0001374287088572803,
#  0.0002894774931249095,
#  0.0001271536652043995,
#  0.00016196954972465177,
#  0.0002567064561673726,
#  0.00011934598400763814,
#  0.00038872691933916425,
#  0.0001563843928375948,
#  0.00027210884353741496,
#  0.00018140589569160998,
#  0.00021595939963286903,
#  0.0001722207870489968,
#  0.00019718032140392388,
#  0.00020614306328592042,
#  0.00021944261575597982,
#  0.00038872691933916425,
#  0.0020898641588296763,
#  0.0019704433497536944,
#  0.0015325670498084292,
#  0.0014727540500736377,
#  0.001122334455667789,
#  0.00040816326530612246,
#  0.0011682242990654205,
#  0.0002608128667680939,
#  0.001219016659894352,
#  0.0007680491551459293,
#  0.000388651379712398,
#  0.00038402457757296467,
#  0.00034317089910775565,
#  0.0001812250815512867,
#  0.0007896814951302974,
#  0.00024362514211466623,
#  0.0005325758920646192,
#  0.00021009874641081307,
#  0.0017615971814445098,
#  0.0006872852233676976,
#  0.0005780903747952597,
#  0.0007452490373866601,
#  0.000782983165861934,
#  0.0005973120955699353,
#  0.001095890410958904,
#  0.00032615786040443573,
#  0.0004418912947414936,
#  0.000547945205479452,
#  0.0007404664938911515,
#  0.0004643603436266543,
#  0.00044913541432741973,
#  0.00015391719255040788,
#  0.0006749156355455568,
#  0.00020754064337599447,
#  0.00028149190710767064,
#  0.0003180492976411344,
#  0.0004897959183673469,
#  0.0004296455424274973,
#  0.0006435006435006435,
#  0.0004144218814753419,
#  0.0004580852038479157,
#  0.0006285355122564425,
#  0.0002479543763947434,
#  0.0005247966413014956,
#  0.0003295978905735003,
#  0.0013477088948787063,
#  0.0007042253521126761,
#  0.0002447980416156671,
#  0.00044603033006244426,
#  0.0002982700338039372,
#  0.00023063617143955411,
#  0.0002364998029168309,
#  0.000664451827242525,
#  0.0003322259136212625,
#  0.0004044489383215369,
#  0.0002051983584131327,
#  0.0002274622791720373,
#  0.0009675858732462506,
#  0.002325581395348837,
#  0.004511278195488722,
#  0.001725625539257981,
#  0.000406118857452281,
#  0.002135991456034176,
#  0.004043126684636119,
#  0.0024630541871921183,
#  0.0004012841091492777,
#  0.0016233766233766235,
#  0.00010240655401945725,
#  0.00012698412698412698,
#  0.0026373626373626374,
#  0.00014765596160944998,
#  8.58000858000858e-05,
#  0.0001984126984126984,
#  0.00014109347442680775,
#  0.00014765596160944998,
#  0.0001984126984126984,
#  0.00010761366693570084,
#  0.0001924001924001924,
#  0.0002442002442002442,
#  0.0001628001628001628,
#  0.0002048131080389145,
#  0.00046933667083854817,
#  0.0010131712259371835,
#  0.0008600917431192661,
#  0.00039318479685452164,
#  0.0001834862385321101,
#  0.000500417014178482,
#  0.00020237452779276849,
#  0.00025722369887678983,
#  0.00043687199650502403,
#  0.00034839159214957615,
#  0.0004664904369460426,
#  0.00043004587155963305,
#  0.0016233766233766235,
#  0.0009090909090909091,
#  0.0002553626149131767,
#  0.0008204567209079721,
#  0.002112676056338028,
#  0.0009250693802035153,
#  0.0017391304347826088,
#  0.0009419152276295133,
#  0.0006162062236828592,
#  0.002955665024630542,
#  0.0011111111111111111,
#  0.00022471910112359551,
#  0.0027272727272727275,
#  0.0019138755980861245,
#  0.001574389923904487,
#  0.0006513243595310464,
#  0.0022796352583586625,
#  0.0004546487838145033,
#  0.00041467965996267884,
#  0.001388888888888889,
#  0.0029239766081871343,
#  0.0020604395604395605,
#  0.002238805970149254,
#  0.0005107252298263534,
#  0.002042483660130719,
#  0.00046598322460391424,
#  0.0007226477814713109,
#  0.0032959789057350032,
#  0.0015532774153463808,
#  0.004659832246039142,
#  0.0005945303210463733,
#  0.0004926108374384236,
#  0.00040096230954290296,
#  0.0003831417624521073,
#  0.00015532774153463808,
#  0.00041050903119868636,
#  0.00020048115477145148,
#  0.0003448275862068965,
#  0.0002922267679719462,
#  0.000663129973474801,
#  0.0004310344827586207,
#  0.0005945303210463733,
#  0.0006385696040868455,
#  0.0007086167800453515,
#  0.0015432098765432098,
#  0.00032299741602067185,
#  0.001240079365079365,
#  7.348618459729571e-05,
#  0.0011770244821092278,
#  0.0013736263736263737,
#  0.001876172607879925,
#  0.0003315649867374005,
#  0.0005486065393899496,
#  0.0006073858114674441,
#  0.0005864414731409805,
#  0.0002743032696949748,
#  0.0013789299503585218,
#  0.0004953437685753913,
#  0.000944822373393802,
#  0.0015943877551020409,
#  0.0006458279514337381,
#  0.0005884429798752501,
#  0.0009219988936013276,
#  0.001567398119122257,
#  0.0009110787172011661,
#  0.001513317191283293,
#  0.00089126559714795,
#  0.0017921146953405018,
#  0.001557632398753894,
#  0.0043859649122807015,
#  0.004629629629629629,
#  0.0005688929343497553,
#  0.0010855405992184109,
#  0.000994233446013124,
#  0.00033460483169376964,
#  0.00039685689340423846,
#  0.0005504789166574921,
#  0.00047402351156617366,
#  0.00032197823427136327,
#  0.00014103178856514259,
#  0.0005884429798752501,
#  0.0005688282138794084,
#  0.0002993832704628465,
#  0.00032197823427136327,
#  0.0006094588005850804,
#  0.00032197823427136327,
#  0.00022753128555176336,
#  0.00011376564277588168,
#  0.0003160156743774491,
#  0.0006825938566552901,
#  0.0005332764505119454,
#  0.0005171165580721895,
#  0.00048756704046806434,
#  0.0004063058670567203,
#  0.0007864108210128972,
#  0.0005812601720530109,
#  0.0002700804839842273,
#  0.00022659294842744494,
#  0.00031090660365626165,
#  0.0007036307345904869,
#  0.0005347593582887701,
#  0.0032959789057350032,
#  0.000930925339787749,
#  0.0010822510822510823,
#  0.0003852080123266564,
#  0.0007974481658692185,
#  0.001567398119122257,
#  0.00101010101010101,
#  0.0008229098090849243,
#  0.0013789299503585218,
#  0.0006073858114674441,
#  0.0012755102040816326,
#  0.0006073858114674441,
#  0.0009626492106276473,
#  0.0008647526807333103,
#  0.0017593244194229415,
#  0.0011595547309833025,
#  0.0012444001991040318,
#  0.0008647526807333103,
#  0.0027548209366391185,
#  0.0009600614439324117,
#  0.0005824790307548928,
#  0.003003003003003003,
#  0.0025497195308516064,
#  0.00015747039556563366,
#  0.0005301102629346904,
#  0.00032299741602067185,
#  0.0011770244821092278,
#  0.00248015873015873,
#  0.0002317389692250649,
#  0.0007467144563918758,
#  0.00025006251562890725,
#  0.000617970584600173,
#  0.00024662128834961034,
#  0.0003407619437061269,
#  0.00039363879703983623,
#  0.0001886863655232273,
#  0.00040769732550554466,
#  0.00030441400304414006,
#  0.0006341958396752917,
#  0.000242883513067133,
#  0.0002216606818282573,
#  0.000485767026134266,
#  0.0003742795119395164,
#  0.0001645169781521453,
#  0.00030354541039339484,
#  0.0001781134226275292,
#  0.0003715814506539834,
#  0.00024772096710265555,
#  0.00035330695308083665,
#  0.0002014179825974863,
#  0.00034760845383759734,
#  0.000513136288998358,
#  0.0006952169076751947,
#  0.00027179821700369644,
#  0.0015664160401002505,
#  0.00027153252959704574,
#  0.00027153252959704574,
#  0.0001227475818726371,
#  0.00010972130787798991,
#  0.0008145975887911372,
#  0.0003089852923000865,
#  0.0003632664922987504,
#  0.0002859757492564631,
#  0.00038402457757296467,
#  0.00036824274561791134,
#  0.0005169561621174524,
#  0.0004200268817204301,
#  0.0008043758043758043,
#  0.00011022927689594356,
#  0.0003733572281959379,
#  0.0008366800535475234,
#  0.00026994924954108627,
#  8.654861435668415e-05,
#  0.00032393909944930353,
#  0.0002519526329050139,
#  0.0001858666964053381,
#  0.00013183568000843749,
#  0.0001643169345032699]

# %%
print(max(s_value))
print(s_value.index(max(s_value)))
print(s_value[155])
# Out:
# 0.014534883720930232
# 57
# 0.0002765996680803983

# %%
def second_largest(numbers):
    count = 0
    m1 = m2 = float('-inf')
    for x in numbers:
        count += 1
        if x > m2:
            if x >= m1:
                m1, m2 = x, m1            
            else:
                m2 = x
    return m2 if count >= 2 else None

# %%
s_value_top_5 = sorted(s_value, reverse=True)[:6]
s_value_top_5
# Out:
# [0.014534883720930232,
#  0.010368663594470046,
#  0.010073260073260074,
#  0.00992063492063492,
#  0.006775067750677507,
#  0.006704980842911878]

# %%
print(s_value.index(s_value_top_5[0]))
print(s_value.index(s_value_top_5[1]))
print(s_value.index(s_value_top_5[2]))
print(s_value.index(s_value_top_5[3]))
print(s_value.index(s_value_top_5[4]))
# Out:
# 57
# 68
# 216
# 265
# 229

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[0]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'barkley':
        print(i,j)
    elif i ==  'miss':
        print(i,j)
# Out:
# ('barkley', 'miss') 20
# miss 43
# barkley 32

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[1]):
        print(i,j)
    count += 1
    
for i,j in word_fdic.items():
    if i == 'head':
        print(i,j)
    elif i ==  'shook':
        print(i,j)
# Out:
# ('head', 'shook') 18
# head 62
# shook 28

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[2]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'paper':
        print(i,j)
    elif i ==  'read':
        print(i,j)
# Out:
# ('paper', 'read') 11
# paper 39
# read 28

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[3]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'dress':
        print(i,j)
    elif i ==  'station':
        print(i,j)
# Out:
# ('dress', 'station') 10
# station 36
# dress 28

# %%
count = 0
for i, j in new2.items():
    if count == s_value.index(s_value_top_5[4]):
        print(i,j)
    count += 1
    
    
for i,j in word_fdic.items():
    if i == 'field':
        print(i,j)
    elif i ==  'tree':
        print(i,j)
# Out:
# ('field', 'tree') 10
# tree 41
# field 36

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(s_value)

plt.ylabel('s value')
plt.xlabel('words (Descending order of word pairs rank from)')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))

plt.ylabel('s value')
plt.xlabel('rank')
plt.show()

# %%
from math import log
log_list = [log(y,10) for y in s_value]
log_list
# Out:
# [-3.6112702262151837,
#  -2.8138374970405375,
#  -3.3745934620990816,
#  -3.614918297777849,
#  -3.12607049781864,
#  -3.343408593803857,
#  -3.588215665228998,
#  -3.276461804173244,
#  -3.458207699061277,
#  -3.658525050746443,
#  -3.2707094752841526,
#  -2.6948659581619987,
#  -3.2460791751795233,
#  -3.8120638010622057,
#  -3.7515677676575803,
#  -3.5952205667976567,
#  -3.4983105537896,
#  -3.3745283943812425,
#  -3.820529848523519,
#  -3.7264308128492916,
#  -3.6583149929518264,
#  -3.4797327259880504,
#  -3.4777451047525374,
#  -3.181520880921451,
#  -3.5328053196390754,
#  -3.661812685537261,
#  -2.9047571463594064,
#  -3.2747882202836776,
#  -3.6810323917442944,
#  -3.5898422382236546,
#  -3.519499852859538,
#  -3.212017050385997,
#  -3.5170110524558433,
#  -3.3483438114793693,
#  -2.937914727361578,
#  -2.831149617443511,
#  -3.9607085516885565,
#  -3.434069657534912,
#  -3.9541480873317885,
#  -3.5522236976681616,
#  -3.312618824820261,
#  -3.241752145771339,
#  -3.7688835289997416,
#  -4.099876748041166,
#  -3.0975727931316017,
#  -3.634454368561237,
#  -3.973453242527175,
#  -3.4806228180051546,
#  -3.416489932156689,
#  -3.2900664266426976,
#  -3.6626634095740376,
#  -3.3856062735983117,
#  -3.501812117075093,
#  -3.492969805320489,
#  -3.436242180871562,
#  -3.6428847613992166,
#  -2.389077443792349,
#  -1.837588438235511,
#  -3.2250370821043517,
#  -3.549132381837026,
#  -3.453157341164043,
#  -3.754851072879542,
#  -2.799666963961171,
#  -3.673993113149759,
#  -3.4789670993321486,
#  -3.481108059468719,
#  -3.3843733290512734,
#  -3.792041310712082,
#  -1.9842772157371666,
#  -3.488017705121237,
#  -4.207380885029945,
#  -3.6019066838667344,
#  -3.740618081728538,
#  -3.096766927728089,
#  -3.440446032141936,
#  -3.718110740730687,
#  -3.54432343658457,
#  -3.5373745766292424,
#  -3.5710576898318145,
#  -3.1015967284354398,
#  -3.712160213348412,
#  -3.5411578488041315,
#  -3.566201718854913,
#  -3.474780625788798,
#  -2.7291141460588833,
#  -3.622570174572413,
#  -3.8282166771898103,
#  -3.8540971961697874,
#  -3.4873151694881375,
#  -3.0053414119740625,
#  -2.9530828439120858,
#  -3.5411963636073223,
#  -3.1371430326390426,
#  -3.5028093493890418,
#  -3.588921261618007,
#  -3.5475285764597815,
#  -3.2007410902351254,
#  -3.4273887227332507,
#  -3.718767332721051,
#  -2.74382322160375,
#  -3.7535830588929064,
#  -2.516667559099043,
#  -2.805228914203426,
#  -3.685831274626063,
#  -3.6505988981726567,
#  -3.3119656603683656,
#  -2.748962861256161,
#  -3.1124853051245056,
#  -3.185542154854375,
#  -2.769377326076138,
#  -3.551798409128266,
#  -3.713154401837298,
#  -3.0068937079479,
#  -3.6354837468149115,
#  -3.510545010206612,
#  -3.6179675898100356,
#  -3.1043295012646106,
#  -3.321582499191818,
#  -3.0838332589645496,
#  -2.9708116108725178,
#  -3.7420903524118048,
#  -3.685362727962878,
#  -3.4248062753533977,
#  -2.954984259375235,
#  -3.4983423690697806,
#  -3.112140763668987,
#  -2.943228089240429,
#  -2.8111107680050056,
#  -3.2598877927669934,
#  -3.5217213128534963,
#  -2.6829083967430503,
#  -3.5669448773734,
#  -3.6156668468978133,
#  -3.521057576801979,
#  -3.501964634892956,
#  -3.2464985807958007,
#  -3.2728408875668435,
#  -2.9900996776151723,
#  -3.730720175933402,
#  -3.4986709905614473,
#  -3.6249164497653634,
#  -3.820529848523519,
#  -3.7065864962166826,
#  -3.4114642955189507,
#  -3.3074960379132126,
#  -4.02765534131917,
#  -3.3699884861175757,
#  -3.3022948442274047,
#  -3.10749262145212,
#  -2.769377326076138,
#  -2.8851726832445683,
#  -2.480246553711865,
#  -2.8054442172086094,
#  -2.760862084555869,
#  -3.049992856920142,
#  -3.5581483453797738,
#  -3.2317243833285163,
#  -3.3513775234751324,
#  -3.2775328145357694,
#  -2.3463529744506384,
#  -3.290646646477703,
#  -3.5937013287080988,
#  -3.315690516528484,
#  -2.6170003411208986,
#  -3.552029077686458,
#  -3.5337402919741483,
#  -3.766654467740665,
#  -3.674401812845282,
#  -3.579497782534824,
#  -4.013521858117402,
#  -3.666096585412431,
#  -3.1792165580478837,
#  -3.642423298232513,
#  -3.9415735412482955,
#  -3.251881454552527,
#  -3.5952205667976567,
#  -3.7713118258533376,
#  -3.5952205667976567,
#  -3.628644322284606,
#  -3.8693784160613367,
#  -3.4983105537896,
#  -2.745204956271149,
#  -2.6989700043360183,
#  -3.5382766083964947,
#  -3.810171397105263,
#  -2.628853167915899,
#  -3.2828074316271527,
#  -2.4247331852599743,
#  -3.2902775053743882,
#  -2.9410594662267644,
#  -3.7659190500360027,
#  -3.5427462308516486,
#  -3.830308651815822,
#  -3.416701010888379,
#  -3.157868695018853,
#  -3.4999618655961897,
#  -2.786751422145561,
#  -3.1563839261131617,
#  -3.1814277961639426,
#  -3.2385706823005114,
#  -3.285823163948138,
#  -3.4196253608877427,
#  -3.549471431990787,
#  -3.7132613840972066,
#  -3.5273251903714953,
#  -3.44814394432387,
#  -3.466368764430069,
#  -3.522123996685687,
#  -3.287292651824926,
#  -3.434162288425906,
#  -3.2918126874671185,
#  -3.7333796728046194,
#  -3.5675075789306243,
#  -3.7333796728046194,
#  -3.490341624118325,
#  -3.4781071677013133,
#  -1.9968299532104932,
#  -3.1763543881045684,
#  -2.253293939121218,
#  -2.67251766897073,
#  -3.0187004986662433,
#  -3.1525940779274695,
#  -3.71281800020785,
#  -3.222820481322168,
#  -2.80413943233535,
#  -2.752432609261474,
#  -2.9103041680685684,
#  -3.385945712730183,
#  -3.19612089259838,
#  -2.1690863574870223,
#  -2.9307453283111133,
#  -2.6281845080734123,
#  -3.2096758345710943,
#  -3.1977766112713866,
#  -3.2647234009019996,
#  -3.185542154854375,
#  -3.289767270952781,
#  -2.6646419755561253,
#  -3.844663528240239,
#  -2.830460350030967,
#  -3.598681098907163,
#  -3.7779774978380556,
#  -3.673822367153048,
#  -2.948461870061283,
#  -3.2595222072161922,
#  -3.3698278925253278,
#  -3.4719514546809824,
#  -3.1373541113707324,
#  -3.590563208684984,
#  -2.7149162479935844,
#  -3.6789915658836176,
#  -3.5828584622244986,
#  -3.373316665173873,
#  -3.598681098907163,
#  -3.4225898398514816,
#  -3.8730588997997035,
#  -3.7883451651521183,
#  -3.4378298064082187,
#  -3.519499852859538,
#  -3.2017793537250605,
#  -3.3219710555263013,
#  -3.4342174943051473,
#  -3.255272505103306,
#  -3.038222638368718,
#  -2.690018780788695,
#  -2.0034605321095063,
#  -3.0808268349817793,
#  -3.3654879848908994,
#  -3.5650603397961036,
#  -3.8405939483752363,
#  -3.4476747410782496,
#  -3.4993815641521255,
#  -3.243534101832062,
#  -2.716003343634799,
#  -2.30582887854575,
#  -3.5038511866072786,
#  -3.436904396976666,
#  -3.3699576073460524,
#  -3.4521443635334026,
#  -3.5579480897014415,
#  -3.4102522022052257,
#  -3.4348703927529383,
#  -2.9708116108725178,
#  -3.088451108739318,
#  -2.786120180054919,
#  -3.1726029312098594,
#  -2.6273658565927325,
#  -3.6586790285824486,
#  -3.9896722476238726,
#  -3.381836799998343,
#  -3.65571454961871,
#  -3.4431064567372656,
#  -3.4155853830860026,
#  -3.3355247615134562,
#  -3.350764728070193,
#  -3.3980172097178194,
#  -3.4831274827576997,
#  -3.531819406657424,
#  -3.1845021545095675,
#  -3.7729814503449637,
#  -3.5652573434202135,
#  -3.260998377626034,
#  -3.847264101770764,
#  -3.086715663944882,
#  -4.016824493667487,
#  -3.1665287834976663,
#  -3.552194870580972,
#  -3.7753676897653254,
#  -3.2838286966912342,
#  -3.4034065234791426,
#  -3.041918783928682,
#  -3.9454685851318194,
#  -2.575187844927661,
#  -2.8419153674675894,
#  -3.600972895686748,
#  -3.4404892710302044,
#  -3.229454299195355,
#  -2.254467510467076,
#  -2.7795964912578244,
#  -3.9896722476238726,
#  -3.4983105537896,
#  -3.7454651686707265,
#  -3.8845121591903937,
#  -3.664641975556125,
#  -3.720159303405956,
#  -3.940267391446011,
#  -3.737192642704737,
#  -3.7287594751678736,
#  -3.5856111084857307,
#  -2.6209453354883356,
#  -2.5771086551437343,
#  -2.197739886018149,
#  -2.80413943233535,
#  -3.1222522955703953,
#  -2.8979018742682277,
#  -3.550534086599507,
#  -3.212520524682356,
#  -3.2926990030439294,
#  -2.5105450102066116,
#  -2.416640507338281,
#  -2.372221367549868,
#  -3.55054936762841,
#  -3.8379354826258454,
#  -3.90223412696677,
#  -3.684351564568016,
#  -3.593161411047375,
#  -3.262747637698184,
#  -3.3491074683729325,
#  -3.33462964500431,
#  -3.161143309042809,
#  -3.2930309056064364,
#  -4.344183428053818,
#  -3.7735853361644933,
#  -3.287829711920629,
#  -2.56702636615906,
#  -2.64921312234641,
#  -3.1295287738587763,
#  -3.7827412876341198,
#  -2.9017306917292185,
#  -2.8941775538387726,
#  -2.7113853790984512,
#  -2.741348602475895,
#  -2.644438589467838,
#  -2.4456042032735974,
#  -3.4545590459265236,
#  -2.609461005912267,
#  -3.361633413910056,
#  -3.5546254235039387,
#  -3.5092361351542998,
#  -3.169747887671143,
#  -3.1363241321841935,
#  -2.8352941365202122,
#  -3.7319109421168717,
#  -3.0064660422492313,
#  -3.507720976685613,
#  -3.5193028492354284,
#  -3.475235222604128,
#  -2.9537596917332283,
#  -3.359645792674543,
#  -2.7770641547424293,
#  -3.28668096935493,
#  -3.4315446825044083,
#  -3.497223458148386,
#  -3.81323060978202,
#  -3.218469857195557,
#  -3.4895366294820946,
#  -3.59260695119497,
#  -3.4403186068119136,
#  -3.2464985807958007,
#  -3.5475285764597815,
#  -3.4225898398514816,
#  -3.644438589467838,
#  -3.213119138811456,
#  -3.4817112919701385,
#  -3.395806734911182,
#  -3.3531946914922175,
#  -3.423327808562445,
#  -3.4492083275424226,
#  -3.3349059057799075,
#  -2.6613393400060397,
#  -2.8545337589164452,
#  -3.6851256782370547,
#  -3.361633413910056,
#  -3.494258979184647,
#  -3.7115119771118543,
#  -3.4058370764021095,
#  -3.2082061394903185,
#  -3.4205745486161563,
#  -3.824532590977193,
#  -3.337334446091664,
#  -3.455986239067319,
#  -3.7035063221873408,
#  -3.339550810825671,
#  -3.1034616220947044,
#  -3.0431657202074534,
#  -3.1697111624179053,
#  -2.799943317741742,
#  -3.8504930719009627,
#  -2.411830069000476,
#  -3.0276553413191696,
#  -2.7201593034059566,
#  -2.2430380486862944,
#  -3.857671656528086,
#  -3.503705585676306,
#  -3.7444396794530364,
#  -3.4702818301893568,
#  -3.590855761395207,
#  -3.7157944980035063,
#  -3.3204578689166486,
#  -3.5559404378185104,
#  -3.6857865089215545,
#  -3.296665190261531,
#  -2.5502283530550938,
#  -3.1549562434033382,
#  -3.6352826379982113,
#  -3.420821822004068,
#  -3.2093139057259306,
#  -3.752163731936888,
#  -2.993105423462267,
#  -3.3774883833761327,
#  -2.970404995264225,
#  -2.852479993636856,
#  -2.4473795536535268,
#  -3.4433747605855256,
#  -3.6891819651908238,
#  -3.5415792439465803,
#  -3.316269962220718,
#  -2.8695669528482797,
#  -2.95175370903563,
#  -3.2817474006349276,
#  -2.5360170406955933,
#  -3.790566625146076,
#  -3.53529412004277,
#  -2.4828735836087534,
#  -3.6631622654980776,
#  -3.651153358025062,
#  -3.5460488664017342,
#  -3.2938674382755697,
#  -3.5460488664017342,
#  -3.5562680315834205,
#  -3.634606805045024,
#  -3.2128341873663517,
#  -3.392621591981997,
#  -3.759182026437847,
#  -3.765200060126847,
#  -2.8891415644211977,
#  -3.0701962430084295,
#  -2.98536231001671,
#  -3.686636269262293,
#  -2.7589118923979736,
#  -3.133173801596378,
#  -3.0034605321095063,
#  -3.2030328870147105,
#  -2.5932860670204567,
#  -2.794985691358863,
#  -3.1527686862248876,
#  -3.5406690536125187,
#  -3.769503924089541,
#  -3.1185953652237615,
#  -3.013860014703749,
#  -3.308259431468717,
#  -3.039414119176137,
#  -3.377722441307911,
#  -3.860834059716761,
#  -3.8588464384812475,
#  -3.4794313371977363,
#  -3.0766924456439297,
#  -3.418017036167084,
#  -3.2912419565187867,
#  -3.1085650237328344,
#  -3.5416861998594236,
#  -3.4962969115097846,
#  -3.762871397808264,
#  -3.544988835409509,
#  -3.077627417979003,
#  -3.503596150251284,
#  -3.0678675806898466,
#  -2.7681093120895026,
#  -3.7388598020722004,
#  -3.4620983811351556,
#  -3.7949757440511314,
#  -3.6685722691845575,
#  -3.5627685430165186,
#  -3.598681098907163,
#  -3.2464985807958007,
#  -3.4983105537896,
#  -3.5317343092765494,
#  -3.5397032389478253,
#  -3.8121777741587533,
#  -3.3904051564800803,
#  -3.6254153521544077,
#  -3.5701925610957255,
#  -3.4246950038469723,
#  -3.488993648187898,
#  -3.5553708712032313,
#  -3.0017955033023678,
#  -2.8652732242465055,
#  -2.9349310873230814,
#  -3.2504897069044856,
#  -2.763321011303028,
#  -3.756853364119265,
#  -4.399846712712922,
#  -3.6126173704816256,
#  -3.050324506025151,
#  -4.11710550276125,
#  -3.546507410871926,
#  -3.5081832995310336,
#  -3.2277398346488297,
#  -3.600972895686748,
#  -3.8182258936139553,
#  -3.2683439139510644,
#  -3.3829171350875304,
#  -3.720159303405956,
#  -3.794488046659169,
#  -3.7638022240745928,
#  -3.1997551772534747,
#  -3.362590173321324,
#  -2.1736024586519864,
#  -3.47438278803608,
#  -3.532663398688005,
#  -3.22960871645761,
#  -3.0868680747139154,
#  -3.388101201570516,
#  -3.679479811558317,
#  -3.0894004112293105,
#  -3.0894004112293105,
#  -3.4137785893578743,
#  -2.945257506400129,
#  -3.145862059667942,
#  -3.4772039696007617,
#  -3.5927317663939617,
#  -2.7174327288480042,
#  -2.6532125137753435,
#  -3.2415464805965484,
#  -2.681241237375587,
#  -2.7304361783056073,
#  -3.6488477083728936,
#  -3.5927317663939617,
#  -4.143170993200178,
#  -3.6354837468149115,
#  -3.6354837468149115,
#  -3.6488477083728936,
#  -3.5927317663939617,
#  -3.674401812845282,
#  -3.5927317663939617,
#  -3.528273777167043,
#  -3.362590173321324,
#  -3.4289673963366574,
#  -3.708202301638046,
#  -3.1923284579263664,
#  -3.446226401778163,
#  -2.746522998199062,
#  -2.7341137402172424,
#  -3.4347969399973812,
#  -3.735826935661362,
#  -3.572572901310853,
#  -3.3603769967266337,
#  -3.2686448224150926,
#  -2.5692066481140743,
#  -2.9541046162862683,
#  -3.3784498158943355,
#  -3.484503208342262,
#  -3.087781417809542,
#  -2.3452336581560345,
#  -2.8132949862648666,
#  -2.8495071589193115,
#  -2.7452979071697556,
#  -3.190651797305404,
#  -2.41711566546216,
#  -2.3215293907256065,
#  -2.6473829701146196,
#  -3.6754728232078073,
#  -3.5415792439465803,
#  -3.623766000133931,
#  -3.5355050962343872,
#  -3.5230958382525674,
#  -4.08908046413525,
#  -3.252448471582307,
#  -3.6970839722204847,
#  -3.455098759157456,
#  -3.4401216031878037,
#  -3.5873367345072555,
#  -3.455098759157456,
#  -3.1085650237328344,
#  -2.7323937598229686,
#  -2.850033257689769,
#  -3.37520622109933,
#  -3.6792006957270504,
#  -3.152033401914976,
#  -2.614545702876022,
#  -3.5535189401489693,
#  -3.5785628101997506,
#  -3.545513285224456,
#  -2.894316062684438,
#  -3.463494827617745,
#  -3.0114294617807817,
#  -3.310480891462675,
#  -2.894316062684438,
#  -3.2343907223921917,
#  -3.2594345924429735,
#  -3.5460488664017342,
#  -3.684351564568016,
#  -3.5579480897014415,
#  -3.6429588794097905,
#  -3.341928883745809,
#  -3.4880569194240474,
#  -3.647757762291559,
#  -3.2450188707377525,
#  -3.4290790594647094,
#  -3.3876863743064844,
#  -3.2450188707377525,
#  -3.360814227906183,
#  -3.5637776333621654,
#  -3.591806356962409,
#  -3.049992856920142,
#  -3.4621733047067904,
#  -3.049992856920142,
#  -3.1749315935284423,
#  -3.1838864361813686,
#  -3.1169396465507555,
#  -2.8916303648248927,
#  -3.523074133838065,
#  -3.1838864361813686,
#  -3.192660360488874,
#  -3.037758400503131,
#  -2.9560883540518113,
#  -3.4225898398514816,
#  -2.8760252914943165,
#  -3.1750767211762096,
#  -2.8640163840213013,
#  -3.1205739312058496,
#  -3.1875207208364627,
#  -3.1205739312058496,
#  -3.250013169040826,
#  -3.603685549614699,
#  -2.98751730437537,
#  -3.0340934464167253,
#  -3.482587769526767,
#  -3.5535189401489693,
#  -4.188506633818114,
#  -2.698390558643785,
#  -2.605305046141109,
#  -3.1304945885234696,
#  -2.72956972630197,
#  -3.4196253608877427,
#  -3.1510632533537497,
#  -2.702430536445525,
#  -3.1146109842321725,
#  -2.7701152947871015,
#  -3.440751700479185,
#  -3.10636090880675,
#  -3.486572150518356,
#  -3.5307758130104094,
#  -3.448783589628956,
#  -3.40114195519373,
#  -3.2612628687924934,
#  -3.2612628687924934,
#  -3.3331448760986184,
#  -3.2155053782318177,
#  -3.243534101832062,
#  -3.3181677201289657,
#  -3.053654558290747,
#  -3.3331448760986184,
#  -3.5829719291048057,
#  -3.350764728070193,
#  -3.456568454238232,
#  -3.438595083226331,
#  -3.4261858252445108,
#  -3.4324347745215125,
#  -3.2863067388432743,
#  -3.788733858827707,
#  -3.6665179805548807,
#  -3.220805190086842,
#  -3.802180582554954,
#  -3.3581887461493998,
#  -3.2405492482825995,
#  -3.343211590179747,
#  -3.0034605321095063,
#  -2.6901960800285134,
#  -3.1192558892779365,
#  -2.916980047320382,
#  -3.574147064150722,
#  -3.0098756337121597,
#  -3.3426200425533477,
#  -3.6927588181547235,
#  -3.4235189292629373,
#  -3.2671717284030133,
#  -3.3977662561264497,
#  -3.5475285764597815,
#  -3.7236198355154633,
#  -2.9304395947666997,
#  -2.8195439355418683,
#  -3.8619225336817444,
#  -3.5383851970199123,
#  -3.895671116769404,
#  -3.790566625146076,
#  -3.590563208684984,
#  -3.9231921904206675,
#  -3.41035538343447,
#  -3.805806591702813,
#  -3.5652573434202135,
#  -3.7413486024758944,
#  -3.6656278885377764,
#  -3.763914430374636,
#  -3.7051364298214504,
#  -3.685831274626063,
#  -3.6586790285824486,
#  -3.41035538343447,
#  -2.6798819421128623,
#  -2.70543604658525,
#  -2.8145805160103183,
#  -2.8318697742805017,
#  -2.9498777040368744,
#  -3.389166084364532,
#  -2.932473764677153,
#  -3.583670987217171,
#  -2.9139903589831397,
#  -3.1146109842321725,
#  -3.4104397862103464,
#  -3.415640979896154,
#  -3.464489547433971,
#  -3.7417816961431667,
#  -3.1025480388350575,
#  -3.6132778945357997,
#  -3.273618496515688,
#  -3.677576538876725,
#  -2.7540933932429383,
#  -3.1628629933219257,
#  -3.2380042615678106,
#  -3.1276985762586746,
#  -3.1062475751730423,
#  -3.223798690700624,
#  -2.960232873128512,
#  -3.486572150518356,
#  -3.354684553954728,
#  -3.2612628687924934,
#  -3.1304945885234696,
#  -3.3331448760986184,
#  -3.3476226994672413,
#  -3.8127128667653682,
#  -3.17075051058657,
#  -3.682896841287014,
#  -3.550534086599507,
#  -3.4975055591533706,
#  -3.3099848383169075,
#  -3.3668896896533798,
#  -3.1914510144648953,
#  -3.382557321908785,
#  -3.3390537357091388,
#  -3.201670179646581,
#  -3.605628222007618,
#  -3.2800089531081857,
#  -3.4820155764507117,
#  -2.870403905279027,
#  -3.1522883443830563,
#  -3.6111920608684343,
#  -3.350635608258954,
#  -3.5253903765652455,
#  -3.6370725798484114,
#  -3.626169216838087,
#  -3.177536499929862,
#  -3.4785664955938436,
#  -3.3931363002692163,
#  -3.687826117902179,
#  -3.643090613537411,
#  -3.014310480963307,
#  -2.633468455579586,
#  -2.345700390583442,
#  -2.7630534402996143,
#  -3.391346844301324,
#  -2.670400488817934,
#  -2.3932826505593643,
#  -2.608526033577194,
#  -3.396548037987132,
#  -2.789580712164425,
#  -3.9896722476238726,
#  -3.896250562461638,
#  -2.578830150609487,
#  -3.8307490137052054,
#  -4.066512277856595,
#  -3.702430536445525,
#  -3.8504930719009627,
#  -3.8307490137052054,
#  -3.702430536445525,
#  -3.968132569767763,
#  -3.7157944980035063,
#  -3.612253906096437,
#  -3.7883451651521183,
#  -3.688642251959892,
#  -3.3285155115862723,
#  -2.9943171526696366,
#  -3.065455221540867,
#  -3.4054032832352177,
#  -3.736396502276642,
#  -3.3006679327152044,
#  -3.693844151591178,
#  -3.589689020906171,
#  -3.359645792674543,
#  -3.4579323345114026,
#  -3.331157254863105,
#  -3.366485217204848,
#  -2.789580712164425,
#  -3.0413926851582245,
#  -3.5928426831311,
#  -3.0859443230406036,
#  -2.6751670896633937,
#  -3.03382569395331,
#  -2.75966784468963,
#  -3.0259881819517065,
#  -3.2102739196226593,
#  -2.5293447875295687,
#  -2.9542425094393248,
#  -3.648360010980931,
#  -2.5642714304385623,
#  -2.7180862947830913,
#  -2.802887698388523,
#  -3.1862026789085496,
#  -2.642134634558274,
#  -3.342323966312881,
#  -3.3822872662579013,
#  -2.857332496431268,
#  -2.5340261060561344,
#  -2.6860401202573554,
#  -2.6499835436451447,
#  -3.2918126874671185,
#  -2.6898414091375047,
#  -3.331629717629932,
#  -3.141073326267475,
#  -2.4820155764507117,
#  -2.8087509723495945,
#  -2.331629717629932,
#  -3.2258259914618934,
#  -3.3074960379132126,
#  -3.3968964491425235,
#  -3.4166405073382804,
#  -3.808750972349594,
#  -3.3866772839608377,
#  -3.697926444806505,
#  -3.4623979978989556,
#  -3.534280005205081,
#  -3.178401341533755,
#  -3.3654879848908994,
#  -3.2258259914618934,
#  -3.1947917577219243,
#  -3.1495885677877444,
#  -2.811575005870593,
#  -3.4908009520108547,
#  -2.90655051910145,
#  -4.133794300604512,
#  -2.9292145037373936,
#  -2.8621313793130367,
#  -2.726727209026572,
#  -3.4794313371977363,
#  -3.2607390199104107,
#  -3.2165353574183575,
#  -3.2317753239750946,
#  -3.561769015574392,
#  -2.8604577954234705,
#  -3.305093296061648,
#  -3.0246498311794445,
#  -2.7974060496763817,
#  -3.1898831626469173,
#  -3.2302956139170464,
#  -3.035269600099436,
#  -2.804820678721162,
#  -3.040444098362676,
#  -2.8200700343123253,
#  -3.049992856920142,
#  -2.746634198937578,
#  -2.807535028068853,
#  -2.3579348470004535,
#  -2.3344537511509307,
#  -3.2449694601361974,
#  -2.9643539292921934,
#  -3.002511631284908,
#  -3.475467792116027,
#  -3.4013660715976766,
#  -3.259259309852363,
#  -3.3242001167853776,
#  -3.4921734856188795,
#  -3.8506829863345406,
#  -3.2302956139170464,
#  -3.2450188707377525,
#  -3.5237724716905814,
#  -3.4921734856188795,
#  -3.2150556473603094,
#  -3.4921734856188795,
#  -3.6429588794097905,
#  -3.9439888750737717,
#  -3.500291375841059,
#  -3.165837624690128,
#  -3.273047594337996,
#  -3.286411555895978,
#  -3.3119656603683656,
#  -3.3911469064159907,
#  -3.104350519242735,
#  -3.235629433882054,
#  -3.56850679679803,
#  -3.644753609506605,
#  -3.5073700534440473,
#  -3.15265519881729,
#  -3.2718416065364986,
#  -2.4820155764507117,
#  -3.0310851480394807,
#  -2.9656719712201065,
#  -3.414304688128331,
#  -3.0982975364946976,
#  -2.804820678721162,
#  -2.9956351945975497,
#  -3.08464776085473,
#  -2.8604577954234705,
#  -3.2165353574183575,
#  -2.894316062684438,
#  -3.2165353574183575,
#  -3.0165319409572646,
#  -3.0631080829986197,
#  -2.754654069255432,
#  -2.935708747842663,
#  -2.9050399280762114,
#  -3.0631080829986197,
#  -2.559906625036112,
#  -3.0177009712241163,
#  -3.2347197046218756,
#  -2.5224442335063197,
#  -2.593507589331765,
#  -3.8028010815630884,
#  -3.2756337877510138,
#  -3.4908009520108547,
#  -2.9292145037373936,
#  -2.6055205234374688,
#  -3.635000929108816,
#  -3.1268454406491846,
#  -3.6019514041335214,
#  -3.2090321968365347,
#  -3.60796943782252,
#  -3.4675489132049253,
#  -3.404902104067036,
#  -3.7242594808205496,
#  -3.3896621375103,
#  -3.516535373895799,
#  -3.1977766112713866,
#  -3.614601964103798,
#  -3.6543113352092713,
#  -3.313571968439817,
#  -3.4268039455148664,
#  -3.7837892762106446,
#  -3.517776329273956,
#  -3.7493033508713305,
#  -3.4299459741178175,
#  -3.606037233173499,
#  -3.4518478155656473,
#  -3.6959017582400904,
#  -3.4589096700531345,
#  -3.289767270952781,
#  -3.1578796743891533,
#  -3.565753396565981,
#  -2.805092878342673,
#  -3.566178134479447,
#  -3.566178134479447,
#  -3.910987054722016,
#  -3.95970902424643,
#  -3.089056879759785,
#  -3.5100621925005155,
#  -3.439774659612873,
#  -3.543670793481596,
#  -3.415640979896154,
#  -3.433865800002353,
#  -3.2865462835166963,
#  -3.3767229138657844,
#  -3.0945410014568386,
#  -3.957703041548831,
#  -3.427875436313166,
#  -3.0774405844713235,
#  -3.5687178755297198,
#  -4.062739880787583,
#  -3.4895366294820946,
#  -3.598681098907163,
#  -3.730798420142586,
#  -3.879967036375387,
#  -3.784317675869074]

# %%
#take a log
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(log_list, reverse=True))

plt.ylabel('s value(log scale)')
plt.xlabel('rank (Descending order of s value)')
plt.show()

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(log_list)+1)
y = sorted(log_list, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log log graph
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(s_value, reverse=True))
plt.xscale("log")
plt.yscale("log")
plt.ylabel('s value(log scale)')
plt.xlabel('rank (log scale)')
plt.show()

# %%
#take a log log graph
import matplotlib.pyplot as plt
import numpy as np

x = range(1, len(s_value)+1)
y = sorted(s_value, reverse=True)


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_value, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_value)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
# i,j count
import numpy as np

len(word_f)
# Out:
# 4214

# %%
i = np.arange(len(word_f), 0, -1)
j = np.arange(1,len(word_f)+1, 1)

# %%
def square(list):
    return [i ** -2 for i in list]
square(i)
# Out:
# [5.6313294735450277e-08,
#  5.6340031017440673e-08,
#  5.6366786344627434e-08,
#  5.6393560735103599e-08,
#  5.6420354206983709e-08,
#  5.6447166778403832e-08,
#  5.6473998467521575e-08,
#  5.6500849292516144e-08,
#  5.6527719271588331e-08,
#  5.6554608422960608e-08,
#  5.6581516764877092e-08,
#  5.6608444315603625e-08,
#  5.663539109342778e-08,
#  5.6662357116658896e-08,
#  5.6689342403628116e-08,
#  5.6716346972688413e-08,
#  5.674337084221462e-08,
#  5.6770414030603457e-08,
#  5.6797476556273577e-08,
#  5.6824558437665589e-08,
#  5.6851659693242091e-08,
#  5.6878780341487684e-08,
#  5.690592040090904e-08,
#  5.6933079890034897e-08,
#  5.6960258827416112e-08,
#  5.6987457231625689e-08,
#  5.7014675121258812e-08,
#  5.7041912514932862e-08,
#  5.7069169431287462e-08,
#  5.7096445888984527e-08,
#  5.7123741906708247e-08,
#  5.7151057503165167e-08,
#  5.7178392697084197e-08,
#  5.7205747507216648e-08,
#  5.7233121952336258e-08,
#  5.726051605123923e-08,
#  5.7287929822744268e-08,
#  5.7315363285692613e-08,
#  5.7342816458948047e-08,
#  5.737028936139697e-08,
#  5.7397782011948385e-08,
#  5.7425294429533969e-08,
#  5.7452826633108089e-08,
#  5.7480378641647837e-08,
#  5.7507950474153055e-08,
#  5.7535542149646376e-08,
#  5.7563153687173269e-08,
#  5.7590785105802049e-08,
#  5.761843642462391e-08,
#  5.7646107662752979e-08,
#  5.7673798839326336e-08,
#  5.7701509973504041e-08,
#  5.7729241084469197e-08,
#  5.7756992191427927e-08,
#  5.7784763313609467e-08,
#  5.7812554470266167e-08,
#  5.784036568067352e-08,
#  5.7868196964130225e-08,
#  5.7896048339958182e-08,
#  5.7923919827502565e-08,
#  5.7951811446131821e-08,
#  5.7979723215237724e-08,
#  5.8007655154235394e-08,
#  5.8035607282563357e-08,
#  5.8063579619683551e-08,
#  5.8091572185081375e-08,
#  5.811958499826571e-08,
#  5.8147618078768972e-08,
#  5.8175671446147131e-08,
#  5.8203745119979746e-08,
#  5.8231839119870005e-08,
#  5.8259953465444772e-08,
#  5.8288088176354576e-08,
#  5.8316243272273697e-08,
#  5.8344418772900184e-08,
#  5.8372614697955869e-08,
#  5.8400831067186419e-08,
#  5.8429067900361379e-08,
#  5.8457325217274188e-08,
#  5.8485603037742221e-08,
#  5.8513901381606834e-08,
#  5.8542220268733378e-08,
#  5.8570559719011253e-08,
#  5.8598919752353932e-08,
#  5.8627300388699002e-08,
#  5.865570164800819e-08,
#  5.8684123550267411e-08,
#  5.8712566115486793e-08,
#  5.8741029363700723e-08,
#  5.8769513314967861e-08,
#  5.87980179893712e-08,
#  5.8826543407018089e-08,
#  5.8855089588040267e-08,
#  5.8883656552593908e-08,
#  5.8912244320859651e-08,
#  5.8940852913042613e-08,
#  5.8969482349372482e-08,
#  5.899813265010349e-08,
#  5.9026803835514493e-08,
#  5.9055495925908977e-08,
#  5.9084208941615109e-08,
#  5.9112942902985789e-08,
#  5.9141697830398643e-08,
#  5.9170473744256102e-08,
#  5.919927066498541e-08,
#  5.9228088613038674e-08,
#  5.9256927608892902e-08,
#  5.9285787673050025e-08,
#  5.9314668826036958e-08,
#  5.93435710884056e-08,
#  5.937249448073291e-08,
#  5.9401439023620925e-08,
#  5.9430404737696776e-08,
#  5.9459391643612776e-08,
#  5.9488399762046401e-08,
#  5.9517429113700373e-08,
#  5.9546479719302662e-08,
#  5.957555159960654e-08,
#  5.9604644775390625e-08,
#  5.9633759267458901e-08,
#  5.9662895096640768e-08,
#  5.9692052283791063e-08,
#  5.9721230849790115e-08,
#  5.9750430815543783e-08,
#  5.9779652201983495e-08,
#  5.9808895030066235e-08,
#  5.9838159320774663e-08,
#  5.9867445095117104e-08,
#  5.9896752374127568e-08,
#  5.9926081178865862e-08,
#  5.9955431530417549e-08,
#  5.998480344989401e-08,
#  6.0014196958432491e-08,
#  6.0043612077196148e-08,
#  6.0073048827374093e-08,
#  6.0102507230181366e-08,
#  6.0131987306859064e-08,
#  6.0161489078674318e-08,
#  6.0191012566920372e-08,
#  6.0220557792916556e-08,
#  6.0250124778008418e-08,
#  6.027971354356767e-08,
#  6.0309324110992311e-08,
#  6.0338956501706596e-08,
#  6.0368610737161105e-08,
#  6.0398286838832783e-08,
#  6.0427984828224989e-08,
#  6.0457704726867503e-08,
#  6.0487446556316596e-08,
#  6.051721033815504e-08,
#  6.0546996093992194e-08,
#  6.0576803845463965e-08,
#  6.0606633614232956e-08,
#  6.06364854219884e-08,
#  6.0666359290446262e-08,
#  6.0696255241349255e-08,
#  6.0726173296466881e-08,
#  6.0756113477595482e-08,
#  6.0786075806558278e-08,
#  6.0816060305205399e-08,
#  6.0846066995413905e-08,
#  6.0876095899087882e-08,
#  6.0906147038158431e-08,
#  6.0936220434583715e-08,
#  6.096631611034903e-08,
#  6.0996434087466818e-08,
#  6.1026574387976689e-08,
#  6.1056737033945535e-08,
#  6.1086922047467466e-08,
#  6.1117129450663968e-08,
#  6.1147359265683812e-08,
#  6.1177611514703209e-08,
#  6.1207886219925816e-08,
#  6.1238183403582716e-08,
#  6.1268503087932556e-08,
#  6.1298845295261516e-08,
#  6.1329210047883395e-08,
#  6.1359597368139612e-08,
#  6.1390007278399263e-08,
#  6.1420439801059196e-08,
#  6.1450894958543999e-08,
#  6.1481372773306067e-08,
#  6.1511873267825655e-08,
#  6.1542396464610876e-08,
#  6.157294238619781e-08,
#  6.1603511055150487e-08,
#  6.1634102494060932e-08,
#  6.1664716725549277e-08,
#  6.1695353772263689e-08,
#  6.1726013656880523e-08,
#  6.1756696402104272e-08,
#  6.1787402030667687e-08,
#  6.1818130565331745e-08,
#  6.1848882028885778e-08,
#  6.1879656444147422e-08,
#  6.1910453833962731e-08,
#  6.1941274221206161e-08,
#  6.1972117628780689e-08,
#  6.2002984079617786e-08,
#  6.2033873596677471e-08,
#  6.2064786202948378e-08,
#  6.2095721921447792e-08,
#  6.2126680775221694e-08,
#  6.215766278734477e-08,
#  6.2188667980920519e-08,
#  6.2219696379081211e-08,
#  6.2250748004988023e-08,
#  6.2281822881831011e-08,
#  6.2312921032829185e-08,
#  6.2344042481230545e-08,
#  6.2375187250312124e-08,
#  6.2406355363380033e-08,
#  6.2437546843769515e-08,
#  6.2468761714844967e-08,
#  6.2499999999999997e-08,
#  6.2531261722657474e-08,
#  6.2562546906269545e-08,
#  6.2593855574317721e-08,
#  6.2625187750312872e-08,
#  6.2656543457795341e-08,
#  6.2687922720334878e-08,
#  6.2719325561530826e-08,
#  6.2750752005012031e-08,
#  6.2782202074436968e-08,
#  6.2813675793493763e-08,
#  6.2845173185900237e-08,
#  6.2876694275403951e-08,
#  6.2908239085782246e-08,
#  6.2939807640842292e-08,
#  6.2971399964421159e-08,
#  6.3003016080385799e-08,
#  6.3034656012633157e-08,
#  6.3066319785090165e-08,
#  6.3098007421713828e-08,
#  6.3129718946491245e-08,
#  6.3161454383439677e-08,
#  6.3193213756606536e-08,
#  6.3224997090069514e-08,
#  6.3256804407936559e-08,
#  6.3288635734345952e-08,
#  6.3320491093466362e-08,
#  6.3352370509496872e-08,
#  6.3384274006667018e-08,
#  6.3416201609236843e-08,
#  6.3448153341497002e-08,
#  6.348012922776867e-08,
#  6.3512129292403752e-08,
#  6.3544153559784781e-08,
#  6.3576202054325098e-08,
#  6.3608274800468791e-08,
#  6.3640371822690797e-08,
#  6.3672493145496932e-08,
#  6.3704638793423952e-08,
#  6.3736808791039571e-08,
#  6.3769003162942555e-08,
#  6.3801221933762726e-08,
#  6.3833465128161001e-08,
#  6.3865732770829501e-08,
#  6.3898024886491542e-08,
#  6.3930341499901703e-08,
#  6.3962682635845862e-08,
#  6.3995048319141263e-08,
#  6.4027438574636531e-08,
#  6.4059853427211763e-08,
#  6.4092292901778556e-08,
#  6.4124757023280044e-08,
#  6.4157245816690942e-08,
#  6.4189759307017634e-08,
#  6.4222297519298162e-08,
#  6.4254860478602332e-08,
#  6.4287448210031728e-08,
#  6.4320060738719763e-08,
#  6.4352698089831732e-08,
#  6.4385360288564881e-08,
#  6.4418047360148417e-08,
#  6.4450759329843588e-08,
#  6.4483496222943686e-08,
#  6.4516258064774201e-08,
#  6.4549044880692705e-08,
#  6.4581856696089078e-08,
#  6.4614693536385438e-08,
#  6.4647555427036211e-08,
#  6.4680442393528234e-08,
#  6.4713354461380718e-08,
#  6.474629165614539e-08,
#  6.4779254003406484e-08,
#  6.4812241528780777e-08,
#  6.4845254257917725e-08,
#  6.4878292216499379e-08,
#  6.4911355430240574e-08,
#  6.4944443924888889e-08,
#  6.4977557726224723e-08,
#  6.5010696860061354e-08,
#  6.504386135224496e-08,
#  6.5077051228654725e-08,
#  6.5110266515202818e-08,
#  6.5143507237834519e-08,
#  6.5176773422528184e-08,
#  6.5210065095295386e-08,
#  6.5243382282180894e-08,
#  6.5276725009262773e-08,
#  6.531009330265239e-08,
#  6.5343487188494528e-08,
#  6.5376906692967362e-08,
#  6.5410351842282566e-08,
#  6.5443822662685322e-08,
#  6.5477319180454444e-08,
#  6.5510841421902336e-08,
#  6.5544389413375096e-08,
#  6.5577963181252575e-08,
#  6.5611562751948395e-08,
#  6.5645188151910049e-08,
#  6.567883940761891e-08,
#  6.5712516545590259e-08,
#  6.5746219592373443e-08,
#  6.5779948574551799e-08,
#  6.581370351874282e-08,
#  6.584748445159812e-08,
#  6.5881291399803511e-08,
#  6.5915124390079112e-08,
#  6.5948983449179317e-08,
#  6.5982868603892894e-08,
#  6.6016779881043048e-08,
#  6.6050717307487418e-08,
#  6.608468091011823e-08,
#  6.6118670715862224e-08,
#  6.6152686751680803e-08,
#  6.6186729044570072e-08,
#  6.6220797621560863e-08,
#  6.6254892509718764e-08,
#  6.6289013736144264e-08,
#  6.6323161327972738e-08,
#  6.6357335312374502e-08,
#  6.6391535716554878e-08,
#  6.6425762567754272e-08,
#  6.6460015893248205e-08,
#  6.6494295720347336e-08,
#  6.6528602076397593e-08,
#  6.656293498878015e-08,
#  6.6597294484911544e-08,
#  6.6631680592243704e-08,
#  6.666609333826396e-08,
#  6.6700532750495179e-08,
#  6.6734998856495789e-08,
#  6.6769491683859807e-08,
#  6.680401126021692e-08,
#  6.6838557613232532e-08,
#  6.6873130770607839e-08,
#  6.6907730760079846e-08,
#  6.6942357609421468e-08,
#  6.6977011346441536e-08,
#  6.701169199898491e-08,
#  6.7046399594932472e-08,
#  6.7081134162201237e-08,
#  6.7115895728744392e-08,
#  6.7150684322551333e-08,
#  6.7185499971647719e-08,
#  6.722034270409558e-08,
#  6.7255212547993316e-08,
#  6.7290109531475787e-08,
#  6.7325033682714355e-08,
#  6.7359985029916927e-08,
#  6.7394963601328052e-08,
#  6.7429969425228958e-08,
#  6.7465002529937597e-08,
#  6.75000629438087e-08,
#  6.753515069523386e-08,
#  6.7570265812641567e-08,
#  6.7605408324497303e-08,
#  6.7640578259303541e-08,
#  6.7675775645599825e-08,
#  6.7711000511962876e-08,
#  6.7746252887006567e-08,
#  6.7781532799382051e-08,
#  6.7816840277777778e-08,
#  6.7852175350919573e-08,
#  6.7887538047570704e-08,
#  6.7922928396531879e-08,
#  6.7958346426641406e-08,
#  6.7993792166775169e-08,
#  6.8029265645846716e-08,
#  6.8064766892807315e-08,
#  6.8100295936646021e-08,
#  6.8135852806389727e-08,
#  6.8171437531103216e-08,
#  6.8207050139889244e-08,
#  6.824269066188859e-08,
#  6.8278359126280069e-08,
#  6.8314055562280693e-08,
#  6.8349779999145631e-08,
#  6.8385532466168312e-08,
#  6.8421312992680495e-08,
#  6.8457121608052307e-08,
#  6.8492958341692333e-08,
#  6.8528823223047609e-08,
#  6.8564716281603787e-08,
#  6.8600637546885102e-08,
#  6.8636587048454485e-08,
#  6.8672564815913581e-08,
#  6.8708570878902865e-08,
#  6.874460526710167e-08,
#  6.8780668010228239e-08,
#  6.8816759138039807e-08,
#  6.8852878680332676e-08,
#  6.8889026666942219e-08,
#  6.8925203127743009e-08,
#  6.8961408092648823e-08,
#  6.8997641591612758e-08,
#  6.9033903654627243e-08,
#  6.907019431172415e-08,
#  6.9106513592974803e-08,
#  6.9142861528490072e-08,
#  6.9179238148420452e-08,
#  6.9215643482956102e-08,
#  6.9252077562326875e-08,
#  6.9288540416802445e-08,
#  6.9325032076692339e-08,
#  6.9361552572346011e-08,
#  6.939810193415286e-08,
#  6.9434680192542371e-08,
#  6.9471287377984108e-08,
#  6.9507923520987812e-08,
#  6.9544588652103474e-08,
#  6.9581282801921359e-08,
#  6.9618006001072122e-08,
#  6.9654758280226801e-08,
#  6.9691539670096971e-08,
#  6.9728350201434745e-08,
#  6.9765189905032827e-08,
#  6.9802058811724647e-08,
#  6.9838956952384358e-08,
#  6.9875884357926913e-08,
#  6.9912841059308179e-08,
#  6.9949827087524929e-08,
#  6.9986842473614964e-08,
#  7.0023887248657129e-08,
#  7.0060961443771452e-08,
#  7.0098065090119125e-08,
#  7.0135198218902618e-08,
#  7.0172360861365734e-08,
#  7.0209553048793675e-08,
#  7.024677481251312e-08,
#  7.0284026183892253e-08,
#  7.0321307194340884e-08,
#  7.0358617875310456e-08,
#  7.0395958258294171e-08,
#  7.0433328374827013e-08,
#  7.0470728256485827e-08,
#  7.0508157934889387e-08,
#  7.0545617441698462e-08,
#  7.0583106808615879e-08,
#  7.062062606738662e-08,
#  7.0658175249797847e-08,
#  7.069575438767898e-08,
#  7.0733363512901765e-08,
#  7.0771002657380377e-08,
#  7.0808671853071439e-08,
#  7.0846371131974106e-08,
#  7.0884100526130141e-08,
#  7.0921860067624e-08,
#  7.0959649788582822e-08,
#  7.0997469721176601e-08,
#  7.1035319897618211e-08,
#  7.1073200350163448e-08,
#  7.1111111111111108e-08,
#  7.1149052212803119e-08,
#  7.1187023687624501e-08,
#  7.1225025568003554e-08,
#  7.1263057886411816e-08,
#  7.130112067536422e-08,
#  7.1339213967419099e-08,
#  7.1377337795178301e-08,
#  7.1415492191287256e-08,
#  7.1453677188434991e-08,
#  7.1491892819354287e-08,
#  7.1530139116821666e-08,
#  7.1568416113657511e-08,
#  7.1606723842726144e-08,
#  7.164506233693584e-08,
#  7.1683431629238961e-08,
#  7.172183175263198e-08,
#  7.1760262740155587e-08,
#  7.1798724624894743e-08,
#  7.1837217439978747e-08,
#  7.1875741218581314e-08,
#  7.1914295993920652e-08,
#  7.1952881799259522e-08,
#  7.1991498667905311e-08,
#  7.2030146633210098e-08,
#  7.2068825728570779e-08,
#  7.2107535987429062e-08,
#  7.214627744327156e-08,
#  7.2185050129629913e-08,
#  7.2223854080080796e-08,
#  7.2262689328246046e-08,
#  7.2301555907792667e-08,
#  7.2340453852432994e-08,
#  7.2379383195924692e-08,
#  7.2418343972070846e-08,
#  7.2457336214720072e-08,
#  7.2496359957766525e-08,
#  7.2535415235150022e-08,
#  7.2574502080856117e-08,
#  7.261362052891616e-08,
#  7.2652770613407346e-08,
#  7.2691952368452832e-08,
#  7.2731165828221782e-08,
#  7.2770411026929485e-08,
#  7.2809687998837376e-08,
#  7.2848996778253122e-08,
#  7.2888337399530713e-08,
#  7.2927709897070564e-08,
#  7.2967114305319508e-08,
#  7.3006550658770963e-08,
#  7.3046018991964933e-08,
#  7.3085519339488157e-08,
#  7.3125051735974104e-08,
#  7.3164616216103109e-08,
#  7.3204212814602424e-08,
#  7.3243841566246313e-08,
#  7.3283502505856086e-08,
#  7.3323195668300241e-08,
#  7.3362921088494466e-08,
#  7.3402678801401782e-08,
#  7.3442468842032588e-08,
#  7.3482291245444743e-08,
#  7.3522146046743621e-08,
#  7.3562033281082227e-08,
#  7.3601952983661252e-08,
#  7.3641905189729165e-08,
#  7.3681889934582265e-08,
#  7.3721907253564802e-08,
#  7.3761957182069003e-08,
#  7.3802039755535175e-08,
#  7.3842155009451789e-08,
#  7.3882302979355584e-08,
#  7.3922483700831563e-08,
#  7.3962697209513174e-08,
#  7.4002943541082287e-08,
#  7.4043222731269373e-08,
#  7.4083534815853526e-08,
#  7.4123879830662521e-08,
#  7.4164257811572953e-08,
#  7.4204668794510282e-08,
#  7.4245112815448925e-08,
#  7.4285589910412319e-08,
#  7.4326100115473029e-08,
#  7.4366643466752789e-08,
#  7.4407220000422633e-08,
#  7.4447829752702919e-08,
#  7.4488472759863466e-08,
#  7.4529149058223592e-08,
#  7.4569858684152204e-08,
#  7.461060167406792e-08,
#  7.465137806443907e-08,
#  7.4692187891783863e-08,
#  7.473303119267042e-08,
#  7.4773908003716862e-08,
#  7.4814818361591391e-08,
#  7.4855762303012381e-08,
#  7.4896739864748474e-08,
#  7.4937751083618619e-08,
#  7.4978795996492186e-08,
#  7.5019874640289078e-08,
#  7.5060987051979731e-08,
#  7.5102133268585279e-08,
#  7.514331332717759e-08,
#  7.5184527264879378e-08,
#  7.5225775118864245e-08,
#  7.5267056926356828e-08,
#  7.5308372724632823e-08,
#  7.5349722551019106e-08,
#  7.5391106442893799e-08,
#  7.543252443768636e-08,
#  7.5473976572877668e-08,
#  7.5515462886000122e-08,
#  7.5556983414637686e-08,
#  7.559853819642602e-08,
#  7.5640127269052543e-08,
#  7.5681750670256505e-08,
#  7.5723408437829114e-08,
#  7.5765100609613579e-08,
#  7.5806827223505214e-08,
#  7.5848588317451518e-08,
#  7.5890383929452297e-08,
#  7.5932214097559683e-08,
#  7.5974078859878276e-08,
#  7.6015978254565201e-08,
#  7.6057912319830208e-08,
#  7.6099881093935787e-08,
#  7.6141884615197195e-08,
#  7.6183922921982562e-08,
#  7.6225996052713027e-08,
#  7.6268104045862756e-08,
#  7.6310246939959098e-08,
#  7.6352424773582615e-08,
#  7.6394637585367182e-08,
#  7.6436885414000129e-08,
#  7.6479168298222255e-08,
#  7.652148627682796e-08,
#  7.6563839388665311e-08,
#  7.660622767263615e-08,
#  7.664865116769621e-08,
#  7.669110991285513e-08,
#  7.6733603947176587e-08,
#  7.6776133309778416e-08,
#  7.6818698039832648e-08,
#  7.6861298176565617e-08,
#  7.690393375925808e-08,
#  7.6946604827245252e-08,
#  7.6989311419916946e-08,
#  7.7032053576717647e-08,
#  7.7074831337146591e-08,
#  7.7117644740757849e-08,
#  7.7160493827160495e-08,
#  7.7203378636018579e-08,
#  7.724629920705129e-08,
#  7.7289255580033058e-08,
#  7.7332247794793623e-08,
#  7.7375275891218098e-08,
#  7.7418339909247131e-08,
#  7.7461439888876916e-08,
#  7.750457587015938e-08,
#  7.7547747893202168e-08,
#  7.7590955998168856e-08,
#  7.7634200225278924e-08,
#  7.7677480614807941e-08,
#  7.7720797207087608e-08,
#  7.7764150042505882e-08,
#  7.7807539161507054e-08,
#  7.7850964604591831e-08,
#  7.7894426412317473e-08,
#  7.7937924625297835e-08,
#  7.7981459284203508e-08,
#  7.8025030429761861e-08,
#  7.8068638102757226e-08,
#  7.8112282344030858e-08,
#  7.8155963194481187e-08,
#  7.8199680695063791e-08,
#  7.824343488679153e-08,
#  7.8287225810734687e-08,
#  7.8331053508020976e-08,
#  7.8374918019835757e-08,
#  7.8418819387421979e-08,
#  7.8462757652080438e-08,
#  7.8506732855169754e-08,
#  7.8550745038106531e-08,
#  7.8594794242365445e-08,
#  7.8638880509479288e-08,
#  7.8683003881039164e-08,
#  7.8727164398694517e-08,
#  7.8771362104153223e-08,
#  7.8815597039181762e-08,
#  7.8859869245605204e-08,
#  7.890417876530741e-08,
#  7.8948525640231096e-08,
#  7.8992909912377898e-08,
#  7.9037331623808536e-08,
#  7.908179081664286e-08,
#  7.9126287533059948e-08,
#  7.9170821815298276e-08,
#  7.9215393705655718e-08,
#  7.9260003246489732e-08,
#  7.930465048021741e-08,
#  7.9349335449315617e-08,
#  7.9394058196321023e-08,
#  7.9438818763830293e-08,
#  7.9483617194500152e-08,
#  7.9528453531047437e-08,
#  7.9573327816249271e-08,
#  7.9618240092943154e-08,
#  7.9663190404027004e-08,
#  7.9708178792459354e-08,
#  7.9753205301259353e-08,
#  7.9798269973506978e-08,
#  7.9843372852343018e-08,
#  7.9888513980969279e-08,
#  7.993369340264863e-08,
#  7.9978911160705151e-08,
#  8.0024167298524149e-08,
#  8.0069461859552404e-08,
#  8.0114794887298108e-08,
#  8.0160166425331127e-08,
#  8.0205576517282975e-08,
#  8.0251025206847014e-08,
#  8.0296512537778503e-08,
#  8.0342038553894721e-08,
#  8.0387603299075086e-08,
#  8.0433206817261217e-08,
#  8.0478849152457126e-08,
#  8.0524530348729199e-08,
#  8.0570250450206422e-08,
#  8.061600950108041e-08,
#  8.0661807545605578e-08,
#  8.0707644628099179e-08,
#  8.0753520792941425e-08,
#  8.0799436084575685e-08,
#  8.0845390547508431e-08,
#  8.0891384226309505e-08,
#  8.0937417165612116e-08,
#  8.0983489410113029e-08,
#  8.1029601004572575e-08,
#  8.1075751993814891e-08,
#  8.1121942422727904e-08,
#  8.1168172336263508e-08,
#  8.1214441779437654e-08,
#  8.1260750797330492e-08,
#  8.1307099435086404e-08,
#  8.1353487737914213e-08,
#  8.1399915751087193e-08,
#  8.1446383519943287e-08,
#  8.1492891089885114e-08,
#  8.1539438506380132e-08,
#  8.1586025814960771e-08,
#  8.1632653061224493e-08,
#  8.167932029083392e-08,
#  8.1726027549516984e-08,
#  8.1772774883066974e-08,
#  8.1819562337342717e-08,
#  8.1866389958268604e-08,
#  8.1913257791834821e-08,
#  8.1960165884097339e-08,
#  8.2007114281178123e-08,
#  8.2054103029265165e-08,
#  8.2101132174612683e-08,
#  8.2148201763541164e-08,
#  8.2195311842437508e-08,
#  8.2242462457755131e-08,
#  8.2289653656014103e-08,
#  8.2336885483801249e-08,
#  8.2384157987770243e-08,
#  8.2431471214641742e-08,
#  8.247882521120353e-08,
#  8.2526220024310571e-08,
#  8.2573655700885196e-08,
#  8.2621132287917125e-08,
#  8.266864983246371e-08,
#  8.2716208381649936e-08,
#  8.2763807982668598e-08,
#  8.2811448682780391e-08,
#  8.2859130529314074e-08,
#  8.2906853569666502e-08,
#  8.2954617851302858e-08,
#  8.3002423421756647e-08,
#  8.3050270328629916e-08,
#  8.3098158619593336e-08,
#  8.3146088342386279e-08,
#  8.3194059544817017e-08,
#  8.3242072274762766e-08,
#  8.3290126580169864e-08,
#  8.333822250905387e-08,
#  8.3386360109499627e-08,
#  8.3434539429661513e-08,
#  8.3482760517763418e-08,
#  8.3531023422098963e-08,
#  8.3579328191031588e-08,
#  8.3627674872994647e-08,
#  8.3676063516491592e-08,
#  8.3724494170096016e-08,
#  8.3772966882451869e-08,
#  8.3821481702273472e-08,
#  8.3870038678345742e-08,
#  8.3918637859524227e-08,
#  8.3967279294735311e-08,
#  8.4015963032976264e-08,
#  8.4064689123315413e-08,
#  8.4113457614892249e-08,
#  8.4162268556917548e-08,
#  8.4211121998673511e-08,
#  8.4260017989513839e-08,
#  8.4308956578863947e-08,
#  8.4357937816221002e-08,
#  8.4406961751154099e-08,
#  8.4456028433304357e-08,
#  8.4505137912385068e-08,
#  8.4554290238181824e-08,
#  8.4603485460552611e-08,
#  8.4652723629427958e-08,
#  8.4702004794811091e-08,
#  8.4751329006777989e-08,
#  8.4800696315477582e-08,
#  8.4850106771131856e-08,
#  8.4899560424035948e-08,
#  8.4949057324558326e-08,
#  8.4998597523140862e-08,
#  8.5048181070299039e-08,
#  8.509780801662198e-08,
#  8.514747841277267e-08,
#  8.5197192309487998e-08,
#  8.5246949757578985e-08,
#  8.5296750807930828e-08,
#  8.5346595511503056e-08,
#  8.5396483919329695e-08,
#  8.5446416082519362e-08,
#  8.5496392052255401e-08,
#  8.5546411879795996e-08,
#  8.5596475616474374e-08,
#  8.5646583313698859e-08,
#  8.5696735022953013e-08,
#  8.5746930795795823e-08,
#  8.5797170683861796e-08,
#  8.5847454738861063e-08,
#  8.5897783012579564e-08,
#  8.5948155556879154e-08,
#  8.5998572423697762e-08,
#  8.6049033665049486e-08,
#  8.6099539333024746e-08,
#  8.6150089479790437e-08,
#  8.6200684157590027e-08,
#  8.6251323418743711e-08,
#  8.6302007315648561e-08,
#  8.6352735900778628e-08,
#  8.6403509226685131e-08,
#  8.6454327345996531e-08,
#  8.6505190311418685e-08,
#  8.655609817573502e-08,
#  8.6607050991806626e-08,
#  8.6658048812572414e-08,
#  8.6709091691049261e-08,
#  8.6760179680332117e-08,
#  8.6811312833594176e-08,
#  8.6862491204086985e-08,
#  8.6913714845140624e-08,
#  8.696498381016379e-08,
#  8.7016298152643992e-08,
#  8.7067657926147647e-08,
#  8.7119063184320237e-08,
#  8.7170513980886467e-08,
#  8.7222010369650375e-08,
#  8.7273552404495456e-08,
#  8.7325140139384897e-08,
#  8.7376773628361597e-08,
#  8.7428452925548381e-08,
#  8.748017808514813e-08,
#  8.753194916144393e-08,
#  8.7583766208799177e-08,
#  8.763562928165776e-08,
#  8.7687538434544196e-08,
#  8.7739493722063748e-08,
#  8.779149519890261e-08,
#  8.7843542919828013e-08,
#  8.7895636939688384e-08,
#  8.7947777313413519e-08,
#  8.7999964096014648e-08,
#  8.8052197342584686e-08,
#  8.8104477108298287e-08,
#  8.8156803448412056e-08,
#  8.8209176418264627e-08,
#  8.826159607327689e-08,
#  8.8314062468952081e-08,
#  8.8366575660875944e-08,
#  8.8419135704716873e-08,
#  8.8471742656226061e-08,
#  8.8524396571237656e-08,
#  8.8577097505668936e-08,
#  8.8629845515520372e-08,
#  8.8682640656875869e-08,
#  8.8735482985902856e-08,
#  8.8788372558852486e-08,
#  8.8841309432059718e-08,
#  8.8894293661943535e-08,
#  8.8947325305007045e-08,
#  8.9000404417837673e-08,
#  8.905353105710727e-08,
#  8.9106705279572284e-08,
#  8.9159927142073934e-08,
#  8.9213196701538325e-08,
#  8.92665140149766e-08,
#  8.9319879139485144e-08,
#  8.9373292132245655e-08,
#  8.9426753050525398e-08,
#  8.9480261951677262e-08,
#  8.9533818893139956e-08,
#  8.9587423932438187e-08,
#  8.9641077127182755e-08,
#  8.9694778535070791e-08,
#  8.9748528213885825e-08,
#  8.9802326221497981e-08,
#  8.9856172615864139e-08,
#  8.9910067455028105e-08,
#  8.9964010797120718e-08,
#  9.0018002700360047e-08,
#  9.0072043223051527e-08,
#  9.0126132423588139e-08,
#  9.0180270360450547e-08,
#  9.0234457092207255e-08,
#  9.0288692677514791e-08,
#  9.0342977175117841e-08,
#  9.0397310643849422e-08,
#  9.0451693142631011e-08,
#  9.050612473047276e-08,
#  9.05606054664736e-08,
#  9.0615135409821454e-08,
#  9.0669714619793329e-08,
#  9.0724343155755554e-08,
#  9.0779021077163899e-08,
#  9.0833748443563722e-08,
#  9.0888525314590179e-08,
#  9.0943351749968357e-08,
#  9.0998227809513406e-08,
#  9.1053153553130793e-08,
#  9.110812904081635e-08,
#  9.1163154332656543e-08,
#  9.1218229488828551e-08,
#  9.12733545696005e-08,
#  9.1328529635331576e-08,
#  9.1383754746472217e-08,
#  9.1439029963564288e-08,
#  9.1494355347241212e-08,
#  9.1549730958228146e-08,
#  9.1605156857342187e-08,
#  9.1660633105492496e-08,
#  9.1716159763680478e-08,
#  9.1771736892999934e-08,
#  9.1827364554637282e-08,
#  9.1883042809871663e-08,
#  9.1938771720075126e-08,
#  9.1994551346712843e-08,
#  9.2050381751343198e-08,
#  9.2106262995618039e-08,
#  9.21621951412828e-08,
#  9.221817825017667e-08,
#  9.2274212384232777e-08,
#  9.2330297605478367e-08,
#  9.2386433976034953e-08,
#  9.2442621558118536e-08,
#  9.2498860414039705e-08,
#  9.2555150606203837e-08,
#  9.2611492197111336e-08,
#  9.2667885249357698e-08,
#  9.2724329825633751e-08,
#  9.2780825988725826e-08,
#  9.2837373801515927e-08,
#  9.2893973326981868e-08,
#  9.2950624628197508e-08,
#  9.3007327768332881e-08,
#  9.3064082810654429e-08,
#  9.3120889818525072e-08,
#  9.3177748855404533e-08,
#  9.3234659984849371e-08,
#  9.3291623270513241e-08,
#  9.3348638776147071e-08,
#  9.3405706565599198e-08,
#  9.3462826702815594e-08,
#  9.3519999251840011e-08,
#  9.3577224276814162e-08,
#  9.3634501841977915e-08,
#  9.3691832011669509e-08,
#  9.3749214850325626e-08,
#  9.3806650422481706e-08,
#  9.3864138792772014e-08,
#  9.3921680025929892e-08,
#  9.3979274186787942e-08,
#  9.403692134027815e-08,
#  9.4094621551432118e-08,
#  9.4152374885381254e-08,
#  9.4210181407356914e-08,
#  9.4268041182690618e-08,
#  9.4325954276814231e-08,
#  9.4383920755260138e-08,
#  9.4441940683661428e-08,
#  9.4500014127752107e-08,
#  9.4558141153367254e-08,
#  9.4616321826443196e-08,
#  9.4674556213017758e-08,
#  9.4732844379230357e-08,
#  9.4791186391322278e-08,
#  9.4849582315636834e-08,
#  9.490803221861951e-08,
#  9.4966536166818219e-08,
#  9.5025094226883442e-08,
#  9.5083706465568429e-08,
#  9.5142372949729437e-08,
#  9.5201093746325838e-08,
#  9.5259868922420367e-08,
#  9.5318698545179294e-08,
#  9.5377582681872654e-08,
#  9.5436521399874347e-08,
#  9.5495514766662445e-08,
#  9.5554562849819286e-08,
#  9.5613665717031734e-08,
#  9.5672823436091372e-08,
#  9.5732036074894612e-08,
#  9.5791303701443033e-08,
#  9.5850626383843418e-08,
#  9.5910004190308085e-08,
#  9.5969437189154992e-08,
#  9.6028925448807989e-08,
#  9.608846903779698e-08,
#  9.6148068024758128e-08,
#  9.6207722478434074e-08,
#  9.6267432467674117e-08,
#  9.6327198061434403e-08,
#  9.6387019328778146e-08,
#  9.6446896338875816e-08,
#  9.650682916100534e-08,
#  9.6566817864552293e-08,
#  9.6626862519010132e-08,
#  9.6686963193980348e-08,
#  9.6747119959172719e-08,
#  ...]

# %%
meddle = len(square(j)) / 2
print(meddle)

meddle = len(square(i)) / 2
print (meddle)
# Out:
# 2107.0
# 2107.0

# %%
square(j)[2107]
# Out:
# 2.2503951693917451e-07

# %%
plt.plot(square(i), square(j))

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (2107**2) / (x)

myu = integrate.quad(computePi, 1, 2107**2)

# %%
# 結果にはintegrated value and estimation error
myu
# Out:
# (67950387.64608519, 0.0348692431210651)

# %%
(2107**2) * log(2107**2)
# Out:
# 67950387.64608519

# %%
import numpy as np
from scipy import integrate

def computePi(x):
    return (2.2503951693917451e-07**2) / (x)

myu = integrate.quad(computePi, 1, (2.2503951693917451e-07**2))
print(myu)
# Out:
# (-4.256919002928117e-13, 4.735384109662624e-13)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(sorted(p_values, reverse=True))

plt.ylabel('p value')
plt.xlabel('rank')
plt.show()

# %% [markdown]
# # 1/2, 1/3, 2/3

# %%
count = 0
s_values_1_2 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (1.0/2.0))
    s_values_1_2.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_1_2, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_1_2)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
count = 0
s_values_1_3 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (1.0/3.0))
    s_values_1_3.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_1_3, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_1_3)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()

# %%
count = 0
s_values_2_3 = []

for i, j in new2.items():
    #print (i)
    
    s = j / math.pow((word_fdic[i[0]]  * word_fdic[i[1]]), (2.0/3.0))
    s_values_2_3.append(s)
    
    count += 1
    
    if count == 1000:
        break
        
        
#take a log
import matplotlib.pyplot as plt
import numpy as np
from math import log

sorted_list = sorted(s_values_2_3, reverse=True)

log_list = [log(i) for i in sorted_list]
log_x = [log(i) for i in  range(1, len(s_values_2_3)+1)]

x = np.array(log_x[:-500])
y = np.array(log_list[:-500])


plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
a, b = np.polyfit(x, y, deg=1)
#fit = np.polyfit(x, y, deg=1)
# フィッティング直線
y2 = a * x + b

ax.plot(x, y2, color='red')
ax.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
ax.scatter(x, y)
#plt.figure(figsize=(20,10))
#plt.plot(x, y)

#plt.ylabel('s value')
#plt.xlabel('words (Descending order of s value)')
#plt.show()
